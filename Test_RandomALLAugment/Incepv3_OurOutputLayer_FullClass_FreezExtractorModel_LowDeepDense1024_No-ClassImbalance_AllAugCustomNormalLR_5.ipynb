# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.30),
  layers.RandomZoom(height_factor=0.125,width_factor=0.125),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 45s 333ms/step - loss: 1.4611 - accuracy: 0.6136 - val_loss: 0.5992 - val_accuracy: 0.8215
# Epoch 2/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.4169 - accuracy: 0.8769 - val_loss: 0.3312 - val_accuracy: 0.9082
# Epoch 3/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.2452 - accuracy: 0.9260 - val_loss: 0.2962 - val_accuracy: 0.9146
# Epoch 4/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.1373 - accuracy: 0.9658 - val_loss: 0.2736 - val_accuracy: 0.9237
# Epoch 5/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.1014 - accuracy: 0.9751 - val_loss: 0.2595 - val_accuracy: 0.9159
# Epoch 6/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0760 - accuracy: 0.9800 - val_loss: 0.2791 - val_accuracy: 0.9082
# Epoch 7/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0669 - accuracy: 0.9819 - val_loss: 0.2446 - val_accuracy: 0.9120
# Epoch 8/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0499 - accuracy: 0.9877 - val_loss: 0.2892 - val_accuracy: 0.9069
# Epoch 9/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0369 - accuracy: 0.9958 - val_loss: 0.2587 - val_accuracy: 0.9094
# Epoch 10/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0358 - accuracy: 0.9906 - val_loss: 0.2542 - val_accuracy: 0.9185
# Epoch 11/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0358 - accuracy: 0.9922 - val_loss: 0.2811 - val_accuracy: 0.9094
# Epoch 12/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0274 - accuracy: 0.9942 - val_loss: 0.2193 - val_accuracy: 0.9211
# Epoch 13/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0292 - accuracy: 0.9935 - val_loss: 0.2255 - val_accuracy: 0.9263
# Epoch 14/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0257 - accuracy: 0.9945 - val_loss: 0.2376 - val_accuracy: 0.9211
# Epoch 15/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0165 - accuracy: 0.9968 - val_loss: 0.2162 - val_accuracy: 0.9353
# Epoch 16/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0099 - accuracy: 0.9997 - val_loss: 0.1874 - val_accuracy: 0.9418
# Epoch 17/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9431
# Epoch 18/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9379
# Epoch 19/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.9327
# Epoch 20/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 0.9366
# Epoch 21/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.1732 - val_accuracy: 0.9418
# Epoch 22/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9366
# Epoch 23/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9314
# Epoch 24/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9405
# Epoch 25/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1913 - val_accuracy: 0.9340
# Epoch 26/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9379
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 27/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1734 - val_accuracy: 0.9444
# Epoch 28/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9431
# Epoch 29/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9444
# Epoch 30/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9431
# Epoch 31/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9444
# Epoch 32/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9431
# Epoch 33/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9483
# Epoch 34/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9483
# Epoch 35/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9444
# Epoch 36/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9444
# Epoch 37/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9444
# Epoch 38/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9457
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 39/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9444
# Epoch 40/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9483
# Epoch 41/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9495
# Epoch 42/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9483
# Epoch 43/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9470
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 44/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9470
# Epoch 45/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9470
# Epoch 46/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.7822e-04 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9483
# Epoch 47/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9483
# Epoch 48/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9470
# Epoch 49/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9470
# Epoch 50/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9470
# Epoch 51/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9470
# Epoch 52/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9470
# Epoch 53/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9470
# Epoch 54/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9444
# Epoch 55/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9457
# Epoch 56/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9457
# Epoch 57/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9470
# Epoch 58/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9457
# Epoch 59/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9444
# Epoch 60/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9457
# Epoch 61/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9457
# Epoch 62/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.6299e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9444
# Epoch 63/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9457
# Epoch 64/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9444
# Epoch 65/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9457
# Epoch 66/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9457
# Epoch 67/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9444
# Epoch 68/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.7331e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9457
# Epoch 69/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9457
# Epoch 70/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9444
# Epoch 71/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9457
# Epoch 72/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.7282e-04 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9457
# Epoch 73/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9470
# Epoch 74/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.9169e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9470
# Epoch 75/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9470
# Epoch 76/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9457
# Epoch 77/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.8628e-04 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9457
# Epoch 78/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9444
# Epoch 79/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9457
# Epoch 80/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9457
# Epoch 81/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9431
# Epoch 82/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9431
# Epoch 83/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.9414e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9431
# Epoch 84/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9431
# Epoch 85/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9444
# Epoch 86/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.7902e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9457
# Epoch 87/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9431
# Epoch 88/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.9349e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9444
# Epoch 89/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9444
# Epoch 90/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9470
# Epoch 91/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.8756e-04 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9457
# Epoch 92/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.8727e-04 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9470
# Epoch 93/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.7984e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9470
# Epoch 94/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.9237e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9470
# Epoch 95/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.6985e-04 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9470
# Epoch 96/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.9503e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9470
# Epoch 97/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.6216e-04 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9470
# Epoch 98/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.3884e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9470
# Epoch 99/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.3860e-04 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9431
# Epoch 100/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.4015e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9431
# Epoch 101/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9444
# Epoch 102/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.9024e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9457
# Epoch 103/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9457
# Epoch 104/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.6230e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9444
# Epoch 105/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.1324e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9444
# Epoch 106/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.3498e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9444
# Epoch 107/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9444
# Epoch 108/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.0945e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9444
# Epoch 109/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.6690e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9444
# Epoch 110/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.7686e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9470
# Epoch 111/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5005e-04 - accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9470
# Epoch 112/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.4067e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9457
# Epoch 113/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.3664e-04 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9470
# Epoch 114/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.6645e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9457
# Epoch 115/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.3073e-04 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9470
# Epoch 116/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.9261e-04 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9457
# Epoch 117/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.1711e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9444
# Epoch 118/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.3770e-04 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9457
# Epoch 119/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9457
# Epoch 120/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.6946e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9470
# Epoch 121/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.8561e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9483
# Epoch 122/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5577e-04 - accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9495
# Epoch 123/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.6981e-04 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9495
# Epoch 124/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5251e-04 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9483
# Epoch 125/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3921e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9470
# Epoch 126/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.2084e-04 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9483
# Epoch 127/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.9288e-04 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9495
# Epoch 128/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2402e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9495
# Epoch 129/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.7282e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9483
# Epoch 130/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.8144e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9483
# Epoch 131/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.0946e-04 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9483
# Epoch 132/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.0005e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9483
# Epoch 133/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5811e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9483
# Epoch 134/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.7507e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9495
# Epoch 135/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5524e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9483
# Epoch 136/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.1803e-04 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9495
# Epoch 137/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2680e-04 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9483
# Epoch 138/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.1573e-04 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9495
# Epoch 139/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2086e-04 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9495
# Epoch 140/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5504e-04 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9470
# Epoch 141/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 7.8605e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9483
# Epoch 142/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.1823e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9508
# Epoch 143/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.1978e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9495
# Epoch 144/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2559e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9495
# Epoch 145/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5951e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9483
# Epoch 146/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5725e-04 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9483
# Epoch 147/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.7017e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9457
# Epoch 148/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6772e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9483
# Epoch 149/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5916e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9483
# Epoch 150/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.0073e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9495
# Epoch 151/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3572e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9495
# Epoch 152/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3936e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9495
# Epoch 153/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.4438e-04 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9495
# Epoch 154/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2253e-04 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9495
# Epoch 155/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.4269e-04 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9483
# Epoch 156/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3482e-04 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9495
# Epoch 157/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2354e-04 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9495
# Epoch 158/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.1426e-04 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9483
# Epoch 159/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.8938e-04 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9457
# Epoch 160/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.4532e-04 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9495
# Epoch 161/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8633e-04 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9470
# Epoch 162/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.4497e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9457
# Epoch 163/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6213e-04 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9483
# Epoch 164/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.4197e-04 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9483
# Epoch 165/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1898e-04 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9470
# Epoch 166/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5433e-04 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9444
# Epoch 167/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8469e-04 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9457
# Epoch 168/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6464e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9444
# Epoch 169/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0616e-04 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9457
# Epoch 170/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7714e-04 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9444
# Epoch 171/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1271e-04 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9483
# Epoch 172/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6216e-04 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9495
# Epoch 173/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8999e-04 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9483
# Epoch 174/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9517e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9483
# Epoch 175/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5002e-04 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9483
# Epoch 176/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5660e-04 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9457
# Epoch 177/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3521e-04 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9457
# Epoch 178/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4688e-04 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9444
# Epoch 179/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0472e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9457
# Epoch 180/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5808e-04 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9457
# Epoch 181/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3136e-04 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9483
# Epoch 182/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8335e-04 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9495
# Epoch 183/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9856e-04 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9495
# Epoch 184/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2713e-04 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9495
# Epoch 185/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0405e-04 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9495
# Epoch 186/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1238e-04 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9495
# Epoch 187/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7877e-04 - accuracy: 1.0000 - val_loss: 0.1704 - val_accuracy: 0.9495
# Epoch 188/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8551e-04 - accuracy: 1.0000 - val_loss: 0.1736 - val_accuracy: 0.9431
# Epoch 189/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5417e-04 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9495
# Epoch 190/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5909e-04 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9508
# Epoch 191/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1833e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9508
# Epoch 192/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 6.1889e-04 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9508
# Epoch 193/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8910e-04 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9521
# Epoch 194/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0362e-04 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9508
# Epoch 195/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6839e-04 - accuracy: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9457
# Epoch 196/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8501e-04 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9483
# Epoch 197/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6898e-04 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9495
# Epoch 198/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8902e-04 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9508
# Epoch 199/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9707e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9483
# Epoch 200/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5263e-04 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9483
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 5.7792e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9495
# Epoch 202/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.3436e-04 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9470
# Epoch 203/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.5776e-04 - accuracy: 1.0000 - val_loss: 0.1698 - val_accuracy: 0.9508
# Epoch 204/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9946e-04 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9521
# Epoch 205/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.4875e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9508
# Epoch 206/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.4249e-04 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9495
# Epoch 207/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0789e-04 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9495
# Epoch 208/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6471e-04 - accuracy: 1.0000 - val_loss: 0.1708 - val_accuracy: 0.9508
# Epoch 209/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8616e-04 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9483
# Epoch 210/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7760e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9483
# Epoch 211/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3392e-04 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9483
# Epoch 212/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2840e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9495
# Epoch 213/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0768e-04 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9470
# Epoch 214/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7546e-04 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9521
# Epoch 215/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0655e-04 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9483
# Epoch 216/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3089e-04 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9495
# Epoch 217/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7254e-04 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9483
# Epoch 218/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.3479e-04 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9470
# Epoch 219/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8585e-04 - accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9483
# Epoch 220/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8117e-04 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9483
# Epoch 221/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2144e-04 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9483
# Epoch 222/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.5290e-04 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9508
# Epoch 223/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.8991e-04 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9508
# Epoch 224/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7212e-04 - accuracy: 1.0000 - val_loss: 0.1717 - val_accuracy: 0.9521
# Epoch 225/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6749e-04 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9495
# Epoch 226/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6908e-04 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9508
# Epoch 227/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2359e-04 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9483
# Epoch 228/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3952e-04 - accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9508
# Epoch 229/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4567e-04 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9508
# Epoch 230/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0646e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9495
# Epoch 231/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3016e-04 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9483
# Epoch 232/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3750e-04 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9508
# Epoch 233/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4294e-04 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9508
# Epoch 234/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4903e-04 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9483
# Epoch 235/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3808e-04 - accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.9457
# Epoch 236/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3430e-04 - accuracy: 1.0000 - val_loss: 0.1750 - val_accuracy: 0.9483
# Epoch 237/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9067e-04 - accuracy: 1.0000 - val_loss: 0.1755 - val_accuracy: 0.9495
# Epoch 238/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8449e-04 - accuracy: 1.0000 - val_loss: 0.1767 - val_accuracy: 0.9483
# Epoch 239/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9971e-04 - accuracy: 1.0000 - val_loss: 0.1777 - val_accuracy: 0.9495
# Epoch 240/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2225e-04 - accuracy: 1.0000 - val_loss: 0.1746 - val_accuracy: 0.9495
# Epoch 241/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6369e-04 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9508
# Epoch 242/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9322e-04 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9508
# Epoch 243/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7791e-04 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9483
# Epoch 244/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6295e-04 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9508
# Epoch 245/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6144e-04 - accuracy: 1.0000 - val_loss: 0.1736 - val_accuracy: 0.9521
# Epoch 246/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2920e-04 - accuracy: 1.0000 - val_loss: 0.1743 - val_accuracy: 0.9495
# Epoch 247/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.8770e-04 - accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.9508
# Epoch 248/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9873e-04 - accuracy: 1.0000 - val_loss: 0.1736 - val_accuracy: 0.9470
# Epoch 249/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7357e-04 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9495
# Epoch 250/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7881e-04 - accuracy: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.9470
# Epoch 251/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6116e-04 - accuracy: 1.0000 - val_loss: 0.1755 - val_accuracy: 0.9508
# Epoch 252/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3557e-04 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9508
# Epoch 253/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3810e-04 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9508
# Epoch 254/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6270e-04 - accuracy: 1.0000 - val_loss: 0.1753 - val_accuracy: 0.9508
# Epoch 255/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7964e-04 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9495
# Epoch 256/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7962e-04 - accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9495
# Epoch 257/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8217e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9470
# Epoch 258/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6051e-04 - accuracy: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9521
# Epoch 259/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2794e-04 - accuracy: 1.0000 - val_loss: 0.1734 - val_accuracy: 0.9508
# Epoch 260/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4913e-04 - accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9508
# Epoch 261/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0500e-04 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9521
# Epoch 262/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1300e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9521
# Epoch 263/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3638e-04 - accuracy: 1.0000 - val_loss: 0.1757 - val_accuracy: 0.9470
# Epoch 264/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2878e-04 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9508
# Epoch 265/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4146e-04 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9457
# Epoch 266/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6459e-04 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9470
# Epoch 267/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5193e-04 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9521
# Epoch 268/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0361e-04 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9521
# Epoch 269/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9680e-04 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9508
# Epoch 270/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1972e-04 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.9508
# Epoch 271/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0569e-04 - accuracy: 1.0000 - val_loss: 0.1747 - val_accuracy: 0.9521
# Epoch 272/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1244e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9495
# Epoch 273/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0931e-04 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.9495
# Epoch 274/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2771e-04 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9495
# Epoch 275/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0663e-04 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9508
# Epoch 276/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7419e-04 - accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9508
# Epoch 277/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0256e-04 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9508
# Epoch 278/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9590e-04 - accuracy: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9534
# Epoch 279/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8879e-04 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9470
# Epoch 280/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6675e-04 - accuracy: 1.0000 - val_loss: 0.1767 - val_accuracy: 0.9521
# Epoch 281/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7325e-04 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.9508
# Epoch 282/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6219e-04 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9508
# Epoch 283/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0860e-04 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9483
# Epoch 284/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7770e-04 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9457
# Epoch 285/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5030e-04 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9483
# Epoch 286/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7799e-04 - accuracy: 1.0000 - val_loss: 0.1728 - val_accuracy: 0.9495
# Epoch 287/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4909e-04 - accuracy: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.9495
# Epoch 288/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3966e-04 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9495
# Epoch 289/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8996e-04 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9521
# Epoch 290/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6227e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9470
# Epoch 291/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4371e-04 - accuracy: 1.0000 - val_loss: 0.1787 - val_accuracy: 0.9483
# Epoch 292/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5993e-04 - accuracy: 1.0000 - val_loss: 0.1792 - val_accuracy: 0.9508
# Epoch 293/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4848e-04 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 0.9508
# Epoch 294/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6508e-04 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.9521
# Epoch 295/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6555e-04 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9495
# Epoch 296/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4270e-04 - accuracy: 1.0000 - val_loss: 0.1776 - val_accuracy: 0.9495
# Epoch 297/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4652e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9508
# Epoch 298/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3732e-04 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9508
# Epoch 299/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3580e-04 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9508
# Epoch 300/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3398e-04 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9508
# Epoch 301/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3294e-04 - accuracy: 1.0000 - val_loss: 0.1776 - val_accuracy: 0.9508
# Epoch 302/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2740e-04 - accuracy: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.9508
# Epoch 303/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5660e-04 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9508
# Epoch 304/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3627e-04 - accuracy: 1.0000 - val_loss: 0.1786 - val_accuracy: 0.9495
# Epoch 305/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1327e-04 - accuracy: 1.0000 - val_loss: 0.1788 - val_accuracy: 0.9483
# Epoch 306/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2627e-04 - accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.9521
# Epoch 307/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1603e-04 - accuracy: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9483
# Epoch 308/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1373e-04 - accuracy: 1.0000 - val_loss: 0.1807 - val_accuracy: 0.9495
# Epoch 309/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2685e-04 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 0.9495
# Epoch 310/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1198e-04 - accuracy: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9495
# Epoch 311/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3696e-04 - accuracy: 1.0000 - val_loss: 0.1779 - val_accuracy: 0.9521
# Epoch 312/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1115e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9495
# Epoch 313/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2609e-04 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9495
# Epoch 314/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3075e-04 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9483
# Epoch 315/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0673e-04 - accuracy: 1.0000 - val_loss: 0.1817 - val_accuracy: 0.9495
# Epoch 316/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1557e-04 - accuracy: 1.0000 - val_loss: 0.1780 - val_accuracy: 0.9508
# Epoch 317/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8952e-04 - accuracy: 1.0000 - val_loss: 0.1799 - val_accuracy: 0.9495
# Epoch 318/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1684e-04 - accuracy: 1.0000 - val_loss: 0.1803 - val_accuracy: 0.9508
# Epoch 319/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.0277e-04 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9483
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3933e-07 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9521
# Epoch 1898/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6372e-07 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9521
# Epoch 1899/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8622e-07 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9521
# Epoch 1900/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9796e-07 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9521
# Epoch 1901/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8452e-07 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9521
# Epoch 1902/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5269e-07 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9521
# Epoch 1903/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7424e-07 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.9521
# Epoch 1904/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1445e-07 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9521
# Epoch 1905/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5775e-07 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9521
# Epoch 1906/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1476e-07 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9534
# Epoch 1907/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8529e-07 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9534
# Epoch 1908/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1656e-07 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9534
# Epoch 1909/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.9417e-07 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9534
# Epoch 1910/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3024e-07 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9534
# Epoch 1911/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5914e-07 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9534
# Epoch 1912/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8225e-07 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9534
# Epoch 1913/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4400e-07 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9547
# Epoch 1914/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1449e-07 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9534
# Epoch 1915/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2190e-07 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9521
# Epoch 1916/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6157e-07 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9521
# Epoch 1917/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9180e-07 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9521
# Epoch 1918/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3120e-07 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9521
# Epoch 1919/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4562e-07 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9521
# Epoch 1920/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7435e-07 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.9521
# Epoch 1921/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8548e-07 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9508
# Epoch 1922/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4728e-07 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9508
# Epoch 1923/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.1961e-07 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9521
# Epoch 1924/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3367e-07 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9521
# Epoch 1925/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8140e-07 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9521
# Epoch 1926/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3066e-07 - accuracy: 1.0000 - val_loss: 0.2562 - val_accuracy: 0.9521
# Epoch 1927/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8691e-07 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9521
# Epoch 1928/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5425e-07 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9521
# Epoch 1929/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9350e-07 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9521
# Epoch 1930/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6661e-07 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9521
# Epoch 1931/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2292e-07 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9521
# Epoch 1932/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3860e-07 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9521
# Epoch 1933/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2967e-07 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9521
# Epoch 1934/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7634e-07 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9521
# Epoch 1935/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2594e-07 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9521
# Epoch 1936/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4366e-07 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9521
# Epoch 1937/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6992e-07 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9521
# Epoch 1938/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9939e-07 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9508
# Epoch 1939/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7840e-07 - accuracy: 1.0000 - val_loss: 0.2597 - val_accuracy: 0.9508
# Epoch 1940/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7551e-07 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9508
# Epoch 1941/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3699e-07 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9508
# Epoch 1942/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0921e-07 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9521
# Epoch 1943/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4916e-07 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9508
# Epoch 1944/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0590e-07 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9495
# Epoch 1945/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1499e-07 - accuracy: 1.0000 - val_loss: 0.2610 - val_accuracy: 0.9495
# Epoch 1946/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1244e-07 - accuracy: 1.0000 - val_loss: 0.2633 - val_accuracy: 0.9495
# Epoch 1947/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1013e-07 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9508
# Epoch 1948/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5906e-07 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9495
# Epoch 1949/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4720e-07 - accuracy: 1.0000 - val_loss: 0.2616 - val_accuracy: 0.9508
# Epoch 1950/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4390e-07 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9534
# Epoch 1951/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5124e-07 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.9534
# Epoch 1952/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2885e-07 - accuracy: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.9521
# Epoch 1953/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0046e-07 - accuracy: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9521
# Epoch 1954/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7605e-07 - accuracy: 1.0000 - val_loss: 0.2601 - val_accuracy: 0.9521
# Epoch 1955/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.7216e-06 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9521
# Epoch 1956/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0728e-07 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9521
# Epoch 1957/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2812e-07 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9521
# Epoch 1958/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5392e-07 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9521
# Epoch 1959/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1626e-07 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9521
# Epoch 1960/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0917e-07 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9534
# Epoch 1961/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7713e-07 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9534
# Epoch 1962/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9223e-07 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9534
# Epoch 1963/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7871e-07 - accuracy: 1.0000 - val_loss: 0.2583 - val_accuracy: 0.9534
# Epoch 1964/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7204e-07 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9534
# Epoch 1965/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3686e-07 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9534
# Epoch 1966/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9488e-07 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9534
# Epoch 1967/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1472e-07 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9534
# Epoch 1968/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.4878e-07 - accuracy: 1.0000 - val_loss: 0.2618 - val_accuracy: 0.9547
# Epoch 1969/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1710e-07 - accuracy: 1.0000 - val_loss: 0.2616 - val_accuracy: 0.9547
# Epoch 1970/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5174e-07 - accuracy: 1.0000 - val_loss: 0.2621 - val_accuracy: 0.9547
# Epoch 1971/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9176e-07 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9534
# Epoch 1972/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1834e-07 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9534
# Epoch 1973/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8864e-07 - accuracy: 1.0000 - val_loss: 0.2604 - val_accuracy: 0.9521
# Epoch 1974/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5787e-07 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9521
# Epoch 1975/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4300e-07 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9521
# Epoch 1976/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1962e-07 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9521
# Epoch 1977/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0882e-07 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9521
# Epoch 1978/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7439e-07 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9521
# Epoch 1979/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0008e-07 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9508
# Epoch 1980/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7405e-07 - accuracy: 1.0000 - val_loss: 0.2594 - val_accuracy: 0.9508
# Epoch 1981/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4897e-07 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9508
# Epoch 1982/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6330e-07 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9508
# Epoch 1983/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9072e-07 - accuracy: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.9508
# Epoch 1984/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1985e-07 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9508
# Epoch 1985/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8514e-07 - accuracy: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9521
# Epoch 1986/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5475e-07 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9521
# Epoch 1987/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7568e-07 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9521
# Epoch 1988/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5972e-07 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9508
# Epoch 1989/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6908e-07 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9521
# Epoch 1990/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6083e-07 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9521
# Epoch 1991/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8622e-07 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9508
# Epoch 1992/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2771e-07 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9508
# Epoch 1993/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5332e-07 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9508
# Epoch 1994/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5795e-07 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9508
# Epoch 1995/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 7.0602e-07 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9508
# Epoch 1996/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4562e-07 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9508
# Epoch 1997/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5490e-07 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9508
# Epoch 1998/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7181e-07 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9508
# Epoch 1999/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0790e-07 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9508
# Epoch 2000/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7817e-07 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9508
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 342ms/step - loss: 0.9893 - accuracy: 0.8250
# test_indoor_ds_results:test loss, test acc: [0.989298939704895, 0.8249721527099609]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 416ms/step - loss: 2.0074 - accuracy: 0.7465
# test_outdoor_ds_results:test loss, test acc: [2.007415294647217, 0.7464967966079712]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 192ms/step - loss: 2.3315 - accuracy: 0.7158
# test_belt_ds_results:test loss, test acc: [2.331515312194824, 0.7157751321792603]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_5/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6369 - accuracy: 0.8272
# 50/50 [==============================] - 7s 134ms/step - loss: 1.2889 - accuracy: 0.7424
# 35/35 [==============================] - 5s 135ms/step - loss: 1.4332 - accuracy: 0.7180
# Epoch200
#  test_indoor_acc=0.827201783657074
#  test_outdoor_acc=0.7423567175865173
#  test_belt_acc=0.718041718006134
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7105 - accuracy: 0.8244
# 50/50 [==============================] - 7s 137ms/step - loss: 1.4259 - accuracy: 0.7424
# 35/35 [==============================] - 5s 137ms/step - loss: 1.6222 - accuracy: 0.7131
# Epoch400
#  test_indoor_acc=0.8244147300720215
#  test_outdoor_acc=0.7423567175865173
#  test_belt_acc=0.7130553126335144
# 29/29 [==============================] - 7s 133ms/step - loss: 0.7758 - accuracy: 0.8261
# 50/50 [==============================] - 7s 135ms/step - loss: 1.5584 - accuracy: 0.7494
# 35/35 [==============================] - 5s 136ms/step - loss: 1.7780 - accuracy: 0.7158
# Epoch600
#  test_indoor_acc=0.8260869383811951
#  test_outdoor_acc=0.7493630647659302
#  test_belt_acc=0.7157751321792603
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8316 - accuracy: 0.8261
# 50/50 [==============================] - 7s 137ms/step - loss: 1.6694 - accuracy: 0.7465
# 35/35 [==============================] - 5s 137ms/step - loss: 1.9238 - accuracy: 0.7185
# Epoch800
#  test_indoor_acc=0.8260869383811951
#  test_outdoor_acc=0.7464967966079712
#  test_belt_acc=0.7184950113296509
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8475 - accuracy: 0.8317
# 50/50 [==============================] - 7s 136ms/step - loss: 1.7717 - accuracy: 0.7519
# 35/35 [==============================] - 5s 137ms/step - loss: 2.0617 - accuracy: 0.7171
# Epoch1000
#  test_indoor_acc=0.8316611051559448
#  test_outdoor_acc=0.7519108057022095
#  test_belt_acc=0.7171350717544556
# 29/29 [==============================] - 6s 135ms/step - loss: 0.9006 - accuracy: 0.8266
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8495 - accuracy: 0.7487
# 35/35 [==============================] - 5s 137ms/step - loss: 2.1177 - accuracy: 0.7162
# Epoch1200
#  test_indoor_acc=0.8266443610191345
#  test_outdoor_acc=0.7487261295318604
#  test_belt_acc=0.7162284851074219
# 29/29 [==============================] - 5s 136ms/step - loss: 0.9520 - accuracy: 0.8239
# 50/50 [==============================] - 7s 138ms/step - loss: 1.9042 - accuracy: 0.7497
# 35/35 [==============================] - 5s 138ms/step - loss: 2.2076 - accuracy: 0.7126
# Epoch1400
#  test_indoor_acc=0.823857307434082
#  test_outdoor_acc=0.7496815323829651
#  test_belt_acc=0.7126020193099976
# 29/29 [==============================] - 5s 136ms/step - loss: 0.9539 - accuracy: 0.8255
# 50/50 [==============================] - 7s 137ms/step - loss: 1.9423 - accuracy: 0.7481
# 35/35 [==============================] - 5s 137ms/step - loss: 2.2450 - accuracy: 0.7171
# Epoch1600
#  test_indoor_acc=0.8255295157432556
#  test_outdoor_acc=0.7480891942977905
#  test_belt_acc=0.7171350717544556
# 29/29 [==============================] - 5s 136ms/step - loss: 0.9718 - accuracy: 0.8272
# 50/50 [==============================] - 7s 138ms/step - loss: 1.9847 - accuracy: 0.7478
# 35/35 [==============================] - 5s 139ms/step - loss: 2.2942 - accuracy: 0.7149
# Epoch1800
#  test_indoor_acc=0.827201783657074
#  test_outdoor_acc=0.7477707266807556
#  test_belt_acc=0.7148685455322266
# 29/29 [==============================] - 5s 135ms/step - loss: 0.9893 - accuracy: 0.8250
# 50/50 [==============================] - 7s 136ms/step - loss: 2.0074 - accuracy: 0.7465
# 35/35 [==============================] - 5s 137ms/step - loss: 2.3315 - accuracy: 0.7158
# Epoch2000
#  test_indoor_acc=0.8249721527099609
#  test_outdoor_acc=0.7464967966079712
#  test_belt_acc=0.7157751321792603

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7669023275375366
# max index -> 4
# The [Epoch] of max acc -> 1000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.827201783657074,
#  0.8244147300720215,
#  0.8260869383811951,
#  0.8260869383811951,
#  0.8316611051559448,
#  0.8266443610191345,
#  0.823857307434082,
#  0.8255295157432556,
#  0.827201783657074,
#  0.8249721527099609]

# %%
test_outdoor_acc
# Out:
# [0.7423567175865173,
#  0.7423567175865173,
#  0.7493630647659302,
#  0.7464967966079712,
#  0.7519108057022095,
#  0.7487261295318604,
#  0.7496815323829651,
#  0.7480891942977905,
#  0.7477707266807556,
#  0.7464967966079712]

# %%
test_belt_acc
# Out:
# [0.718041718006134,
#  0.7130553126335144,
#  0.7157751321792603,
#  0.7184950113296509,
#  0.7171350717544556,
#  0.7162284851074219,
#  0.7126020193099976,
#  0.7171350717544556,
#  0.7148685455322266,
#  0.7157751321792603]

# %%
test_indoor_loss
# Out:
# [0.6369105577468872,
#  0.7104735970497131,
#  0.7757842540740967,
#  0.8315706849098206,
#  0.8474684953689575,
#  0.9005822539329529,
#  0.9520466327667236,
#  0.9539061188697815,
#  0.9717941284179688,
#  0.989298939704895]

# %%
test_outdoor_loss
# Out:
# [1.288851022720337,
#  1.425869107246399,
#  1.558439016342163,
#  1.6694397926330566,
#  1.7716865539550781,
#  1.8494503498077393,
#  1.9041895866394043,
#  1.942282795906067,
#  1.9846915006637573,
#  2.007415294647217]

# %%
test_belt_loss
# Out:
# [1.4331547021865845,
#  1.622151494026184,
#  1.7780078649520874,
#  1.923779010772705,
#  2.0616843700408936,
#  2.117715358734131,
#  2.2076117992401123,
#  2.2450146675109863,
#  2.2941935062408447,
#  2.331515312194824]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5435
# FP=1705
# acc=0.761204481792717
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 78.44827586206897%
# 2WayConnectorforFoley acc = 86.39455782312925%
# 2WayFoleyCatheter acc = 72.38805970149254%
# 3WayConnectorforFoley acc = 90.5982905982906%
# 3Waystopcock acc = 96.3963963963964%
# AlcoholBottle acc = 85.0%
# AlcoholPad acc = 42.06349206349206%
# BootCover acc = 51.204819277108435%
# CottonBall acc = 87.42514970059881%
# CottonSwap acc = 81.11888111888112%
# Dilator acc = 68.37606837606837%
# DisposableInfusionSet acc = 48.67256637168141%
# ExtensionTube acc = 37.39837398373984%
# FaceShield acc = 77.77777777777779%
# FrontLoadSyringe acc = 61.06194690265486%
# GauzePad acc = 64.20454545454545%
# Glove acc = 84.22619047619048%
# GuideWire acc = 41.07142857142857%
# LiquidBottle acc = 67.93893129770993%
# Mask acc = 95.32467532467533%
# NGTube acc = 45.806451612903224%
# NasalCannula acc = 46.017699115044245%
# Needle acc = 87.5%
# OxygenMask acc = 87.21804511278195%
# PPESuit acc = 91.12903225806451%
# PharmaceuticalProduct acc = 64.01869158878505%
# Pill acc = 96.35854341736695%
# PillBottle acc = 75.1937984496124%
# PrefilledHumidifier acc = 78.63247863247864%
# PressureConnectingTube acc = 68.70229007633588%
# ReusableHumidifier acc = 87.28813559322035%
# SodiumChlorideBag acc = 84.25196850393701%
# SterileHumidifierAdapter acc = 75.45454545454545%
# SurgicalBlade acc = 89.38053097345133%
# SurgicalCap acc = 87.38738738738738%
# SurgicalSuit acc = 45.45454545454545%
# Syringe acc = 96.95817490494296%
# TrachealTube acc = 36.69724770642202%
# UrineBag acc = 68.33333333333333%
# Vaccinebottle acc = 78.40375586854461%
# WingedInfusionSet acc = 65.78947368421053%
#
#
#
# all_avg_eachclass = 72.51381844404494%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 91,   0,   0, ...,   0,   0,   0],
#        [  1, 127,   0, ...,   0,   0,   0],
#        [  0,   0,  97, ...,   0,   1,  11],
#        ...,
#        [  0,   0,   0, ...,  82,   0,   0],
#        [  0,   0,   0, ...,   2, 167,   0],
#        [  0,   1,   0, ...,   0,   2,  75]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[78.44827586,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.68027211, 86.39455782,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 72.3880597 , ...,  0.        ,
#          0.74626866,  8.20895522],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 68.33333333,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.93896714,
#         78.40375587,  0.        ],
#        [ 0.        ,  0.87719298,  0.        , ...,  0.        ,
#          1.75438596, 65.78947368]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
