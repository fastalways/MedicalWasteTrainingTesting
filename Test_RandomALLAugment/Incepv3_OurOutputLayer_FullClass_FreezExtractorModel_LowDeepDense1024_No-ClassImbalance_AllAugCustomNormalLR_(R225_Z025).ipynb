# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.225),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 333ms/step - loss: 1.5976 - accuracy: 0.5861 - val_loss: 0.6893 - val_accuracy: 0.7891
# Epoch 2/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.4718 - accuracy: 0.8601 - val_loss: 0.4243 - val_accuracy: 0.8887
# Epoch 3/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.2801 - accuracy: 0.9166 - val_loss: 0.3285 - val_accuracy: 0.9056
# Epoch 4/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1661 - accuracy: 0.9567 - val_loss: 0.2694 - val_accuracy: 0.9250
# Epoch 5/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1172 - accuracy: 0.9716 - val_loss: 0.2503 - val_accuracy: 0.9211
# Epoch 6/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0942 - accuracy: 0.9758 - val_loss: 0.2600 - val_accuracy: 0.9237
# Epoch 7/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0795 - accuracy: 0.9822 - val_loss: 0.2923 - val_accuracy: 0.9030
# Epoch 8/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0543 - accuracy: 0.9884 - val_loss: 0.2224 - val_accuracy: 0.9211
# Epoch 9/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0558 - accuracy: 0.9858 - val_loss: 0.2217 - val_accuracy: 0.9301
# Epoch 10/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0516 - accuracy: 0.9861 - val_loss: 0.2039 - val_accuracy: 0.9301
# Epoch 11/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0449 - accuracy: 0.9916 - val_loss: 0.2230 - val_accuracy: 0.9263
# Epoch 12/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0447 - accuracy: 0.9880 - val_loss: 0.2428 - val_accuracy: 0.9133
# Epoch 13/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0292 - accuracy: 0.9935 - val_loss: 0.2548 - val_accuracy: 0.9146
# Epoch 14/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0281 - accuracy: 0.9935 - val_loss: 0.2400 - val_accuracy: 0.9224
# Epoch 15/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0135 - accuracy: 0.9987 - val_loss: 0.2073 - val_accuracy: 0.9314
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.1491 - val_accuracy: 0.9534
# Epoch 17/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.1463 - val_accuracy: 0.9534
# Epoch 18/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.1441 - val_accuracy: 0.9560
# Epoch 19/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9547
# Epoch 20/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9534
# Epoch 21/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9547
# Epoch 22/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9560
# Epoch 23/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9599
# Epoch 24/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9599
# Epoch 25/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9599
# Epoch 26/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9586
# Epoch 27/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9573
# Epoch 28/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9560
# Epoch 29/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9560
# Epoch 30/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 31/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9573
# Epoch 32/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9599
# Epoch 33/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9586
# Epoch 34/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9586
# Epoch 35/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9573
# Epoch 36/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9573
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 37/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9586
# Epoch 38/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9599
# Epoch 39/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9573
# Epoch 40/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9573
# Epoch 41/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9586
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 42/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9586
# Epoch 43/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9586
# Epoch 44/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9586
# Epoch 45/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9586
# Epoch 46/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9586
# Epoch 47/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9586
# Epoch 48/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9573
# Epoch 49/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9573
# Epoch 50/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9573
# Epoch 51/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9586
# Epoch 52/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9586
# Epoch 53/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9586
# Epoch 54/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9586
# Epoch 55/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9573
# Epoch 56/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9573
# Epoch 57/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9573
# Epoch 58/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9573
# Epoch 59/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9586
# Epoch 60/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9573
# Epoch 61/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9573
# Epoch 62/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9573
# Epoch 63/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9586
# Epoch 64/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9586
# Epoch 65/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9586
# Epoch 66/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9586
# Epoch 67/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9586
# Epoch 68/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9586
# Epoch 69/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9586
# Epoch 70/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9586
# Epoch 71/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9586
# Epoch 72/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9573
# Epoch 73/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9586
# Epoch 74/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9586
# Epoch 75/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9599
# Epoch 76/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9599
# Epoch 77/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9599
# Epoch 78/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9599
# Epoch 79/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9586
# Epoch 80/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9599
# Epoch 81/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9586
# Epoch 82/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9586
# Epoch 83/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9586
# Epoch 84/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9586
# Epoch 85/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9573
# Epoch 86/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9586
# Epoch 87/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9599
# Epoch 88/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9599
# Epoch 89/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9599
# Epoch 90/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9599
# Epoch 91/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9599
# Epoch 92/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9599
# Epoch 93/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9599
# Epoch 94/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9599
# Epoch 95/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9599
# Epoch 96/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9599
# Epoch 97/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9599
# Epoch 98/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9599
# Epoch 99/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9599
# Epoch 100/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9599
# Epoch 101/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9599
# Epoch 102/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9599
# Epoch 103/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9612
# Epoch 104/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9599
# Epoch 105/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9573
# Epoch 106/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9586
# Epoch 107/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9612
# Epoch 108/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9599
# Epoch 109/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9586
# Epoch 110/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9599
# Epoch 111/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9599
# Epoch 112/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9599
# Epoch 113/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9586
# Epoch 114/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9599
# Epoch 115/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9599
# Epoch 116/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9599
# Epoch 117/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9586
# Epoch 118/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9599
# Epoch 119/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9586
# Epoch 120/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9599
# Epoch 121/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9599
# Epoch 122/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9586
# Epoch 123/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9586
# Epoch 124/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9586
# Epoch 125/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 126/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9599
# Epoch 127/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9599
# Epoch 128/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9599
# Epoch 129/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9599
# Epoch 130/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9586
# Epoch 131/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9586
# Epoch 132/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9586
# Epoch 133/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9573
# Epoch 134/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9573
# Epoch 135/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9573
# Epoch 136/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9586
# Epoch 137/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9586
# Epoch 138/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9599
# Epoch 139/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 140/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9586
# Epoch 141/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 142/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9599
# Epoch 143/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9599
# Epoch 144/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9599
# Epoch 145/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9612
# Epoch 146/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9599
# Epoch 147/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9612
# Epoch 148/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9586
# Epoch 149/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9599
# Epoch 150/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9599
# Epoch 151/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9560
# Epoch 152/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9573
# Epoch 153/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9547
# Epoch 154/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9573
# Epoch 155/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9573
# Epoch 156/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9573
# Epoch 157/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9573
# Epoch 158/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9573
# Epoch 159/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9560
# Epoch 160/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9573
# Epoch 161/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9573
# Epoch 162/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9560
# Epoch 163/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9560
# Epoch 164/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9573
# Epoch 165/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9599
# Epoch 166/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9560
# Epoch 167/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9573
# Epoch 168/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9586
# Epoch 169/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9599
# Epoch 170/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9560
# Epoch 171/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9560
# Epoch 172/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9612
# Epoch 173/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9547
# Epoch 174/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9573
# Epoch 175/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9599
# Epoch 176/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9586
# Epoch 177/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9560
# Epoch 178/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9573
# Epoch 179/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9573
# Epoch 180/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9586
# Epoch 181/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9560
# Epoch 182/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9573
# Epoch 183/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9573
# Epoch 184/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9573
# Epoch 185/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9573
# Epoch 186/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9560
# Epoch 187/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9573
# Epoch 188/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.8381e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9586
# Epoch 189/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9560
# Epoch 190/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9573
# Epoch 191/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.8770e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9573
# Epoch 192/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.4358e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9573
# Epoch 193/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.7306e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9625
# Epoch 194/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.9615e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9599
# Epoch 195/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.6414e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9560
# Epoch 196/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.8235e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9573
# Epoch 197/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.9251e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9586
# Epoch 198/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0851e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9586
# Epoch 199/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9599
# Epoch 200/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.2849e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9599
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.2940e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 202/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.1152e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9573
# Epoch 203/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.5930e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9573
# Epoch 204/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.0967e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9573
# Epoch 205/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.2599e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9586
# Epoch 206/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.6596e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9586
# Epoch 207/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.4647e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9586
# Epoch 208/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.6719e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9573
# Epoch 209/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.6280e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9599
# Epoch 210/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.6929e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9573
# Epoch 211/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.4752e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9573
# Epoch 212/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.9668e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9560
# Epoch 213/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.3103e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9560
# Epoch 214/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.5538e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9560
# Epoch 215/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1420e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9560
# Epoch 216/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.6451e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 217/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.2187e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9573
# Epoch 218/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1495e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9573
# Epoch 219/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.1310e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9560
# Epoch 220/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.0236e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9573
# Epoch 221/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.8939e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 222/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.5899e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9573
# Epoch 223/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.4580e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9573
# Epoch 224/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.9436e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9586
# Epoch 225/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.6923e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9573
# Epoch 226/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.0056e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9547
# Epoch 227/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2508e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9573
# Epoch 228/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.5234e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9573
# Epoch 229/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.8346e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9573
# Epoch 230/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3507e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9573
# Epoch 231/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.5130e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9573
# Epoch 232/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8662e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9586
# Epoch 233/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0353e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9573
# Epoch 234/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.6067e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9599
# Epoch 235/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.3101e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9586
# Epoch 236/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.2779e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9599
# Epoch 237/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.2547e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9586
# Epoch 238/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.9593e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9573
# Epoch 239/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.5216e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9573
# Epoch 240/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.9754e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9573
# Epoch 241/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.3274e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 242/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.5897e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9573
# Epoch 243/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.4462e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9560
# Epoch 244/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.1054e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9573
# Epoch 245/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.7842e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9599
# Epoch 246/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.0628e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9612
# Epoch 247/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.0903e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9599
# Epoch 248/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.7608e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9586
# Epoch 249/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.2676e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9560
# Epoch 250/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.8145e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9573
# Epoch 251/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.5214e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9586
# Epoch 252/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.8930e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9560
# Epoch 253/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.7622e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9586
# Epoch 254/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9824e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9586
# Epoch 255/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.5520e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9560
# Epoch 256/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.2506e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9560
# Epoch 257/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.5939e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9586
# Epoch 258/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.7770e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9573
# Epoch 259/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.3167e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9599
# Epoch 260/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.4856e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9599
# Epoch 261/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.2101e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9599
# Epoch 262/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.6492e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9586
# Epoch 263/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.4926e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9573
# Epoch 264/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.3249e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9573
# Epoch 265/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.3744e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9586
# Epoch 266/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2977e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9599
# Epoch 267/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.1494e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9573
# Epoch 268/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.4105e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9586
# Epoch 269/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8846e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9599
# Epoch 270/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8877e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9573
# Epoch 271/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.2662e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9586
# Epoch 272/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.0531e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9586
# Epoch 273/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2320e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9560
# Epoch 274/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8948e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9599
# Epoch 275/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.3775e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9612
# Epoch 276/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.3756e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9586
# Epoch 277/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.1424e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9547
# Epoch 278/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.6498e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9560
# Epoch 279/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.6099e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9560
# Epoch 280/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2063e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9573
# Epoch 281/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.4844e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9586
# Epoch 282/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.5157e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9599
# Epoch 283/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.4375e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 284/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.4360e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9573
# Epoch 285/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4746e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9560
# Epoch 286/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.6690e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9586
# Epoch 287/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.5243e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9573
# Epoch 288/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.7849e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 289/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.5394e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9573
# Epoch 290/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8530e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9573
# Epoch 291/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.5157e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9560
# Epoch 292/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.1294e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9573
# Epoch 293/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.4755e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9586
# Epoch 294/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.7973e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9560
# Epoch 295/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.1200e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9586
# Epoch 296/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.0035e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9560
# Epoch 297/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.3831e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9560
# Epoch 298/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.2474e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9573
# Epoch 299/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.0939e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9573
# Epoch 300/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1071e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9586
# Epoch 301/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.1729e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9599
# Epoch 302/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0034e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9586
# Epoch 303/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.0925e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9560
# Epoch 304/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.1663e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9560
# Epoch 305/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6010e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9560
# Epoch 306/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7119e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9547
# Epoch 307/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.7728e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9573
# Epoch 308/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.9161e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9560
# Epoch 309/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.8446e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9599
# Epoch 310/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.6808e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9599
# Epoch 311/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.6981e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9599
# Epoch 312/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.7880e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9599
# Epoch 313/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9330e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9599
# Epoch 314/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.6180e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9612
# Epoch 315/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.3155e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9560
# Epoch 316/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.3836e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9586
# Epoch 317/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6727e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9599
# Epoch 318/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3755e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9599
# Epoch 319/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.4294e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9599
# Epoch 320/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1403e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9599
# Epoch 321/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.9030e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9612
# Epoch 322/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.3223e-07 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 0.9638
# Epoch 1898/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7807e-07 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9638
# Epoch 1899/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3910e-07 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9638
# Epoch 1900/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2283e-07 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9638
# Epoch 1901/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 4.4451e-07 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9651
# Epoch 1902/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6402e-07 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.9651
# Epoch 1903/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1776e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9651
# Epoch 1904/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4881e-07 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9651
# Epoch 1905/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.7247e-07 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9651
# Epoch 1906/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0118e-07 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9638
# Epoch 1907/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9781e-07 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9638
# Epoch 1908/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0504e-07 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9638
# Epoch 1909/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3960e-07 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9638
# Epoch 1910/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1734e-07 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9638
# Epoch 1911/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5285e-07 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9638
# Epoch 1912/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4965e-07 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9625
# Epoch 1913/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.1301e-07 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9625
# Epoch 1914/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2466e-07 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9638
# Epoch 1915/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9454e-07 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9638
# Epoch 1916/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8340e-07 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9638
# Epoch 1917/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 6.0625e-07 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9638
# Epoch 1918/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6980e-07 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9638
# Epoch 1919/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0031e-07 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9638
# Epoch 1920/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.8536e-07 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9638
# Epoch 1921/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.9334e-07 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.9664
# Epoch 1922/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.1944e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9664
# Epoch 1923/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1803e-07 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9651
# Epoch 1924/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2620e-07 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9638
# Epoch 1925/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.8797e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9638
# Epoch 1926/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6694e-07 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9664
# Epoch 1927/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.8447e-07 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9651
# Epoch 1928/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1322e-07 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9651
# Epoch 1929/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3783e-07 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9651
# Epoch 1930/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5019e-07 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9651
# Epoch 1931/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.2847e-07 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9651
# Epoch 1932/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.5410e-07 - accuracy: 1.0000 - val_loss: 0.1865 - val_accuracy: 0.9664
# Epoch 1933/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6702e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9651
# Epoch 1934/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4746e-07 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9651
# Epoch 1935/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8822e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9651
# Epoch 1936/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0850e-07 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9638
# Epoch 1937/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2223e-07 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9625
# Epoch 1938/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3694e-07 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9638
# Epoch 1939/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3922e-07 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9625
# Epoch 1940/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5535e-07 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9638
# Epoch 1941/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.6225e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9651
# Epoch 1942/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9384e-07 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9651
# Epoch 1943/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7636e-07 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.9651
# Epoch 1944/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5023e-07 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9651
# Epoch 1945/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5693e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9651
# Epoch 1946/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0331e-07 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9651
# Epoch 1947/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.5281e-07 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.9651
# Epoch 1948/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1164e-07 - accuracy: 1.0000 - val_loss: 0.1879 - val_accuracy: 0.9651
# Epoch 1949/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8248e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9638
# Epoch 1950/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.1859e-07 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9651
# Epoch 1951/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7049e-07 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9638
# Epoch 1952/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8302e-07 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9651
# Epoch 1953/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.8452e-07 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.9638
# Epoch 1954/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0312e-07 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9638
# Epoch 1955/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.9482e-07 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 0.9651
# Epoch 1956/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2716e-07 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9651
# Epoch 1957/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3979e-07 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9651
# Epoch 1958/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0482e-07 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9651
# Epoch 1959/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6275e-07 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9638
# Epoch 1960/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9677e-07 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9638
# Epoch 1961/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4081e-07 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9638
# Epoch 1962/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.2043e-07 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9638
# Epoch 1963/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.3948e-07 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9638
# Epoch 1964/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.1509e-07 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9638
# Epoch 1965/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 7.2382e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9638
# Epoch 1966/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.7169e-07 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9638
# Epoch 1967/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0181e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9638
# Epoch 1968/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6584e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9638
# Epoch 1969/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1587e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9638
# Epoch 1970/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0262e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9638
# Epoch 1971/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2920e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9638
# Epoch 1972/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9130e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9638
# Epoch 1973/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5843e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9638
# Epoch 1974/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0351e-07 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9638
# Epoch 1975/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2566e-07 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9638
# Epoch 1976/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2916e-07 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9638
# Epoch 1977/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.7411e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9638
# Epoch 1978/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.9292e-07 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9638
# Epoch 1979/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5801e-07 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9651
# Epoch 1980/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 4.0187e-07 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.9638
# Epoch 1981/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4680e-07 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 0.9638
# Epoch 1982/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1403e-07 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9638
# Epoch 1983/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2479e-07 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9638
# Epoch 1984/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1476e-07 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9638
# Epoch 1985/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8606e-07 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9638
# Epoch 1986/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8175e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9638
# Epoch 1987/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9685e-07 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9638
# Epoch 1988/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3945e-07 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9638
# Epoch 1989/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5493e-07 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9638
# Epoch 1990/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.6169e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9664
# Epoch 1991/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5501e-07 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9664
# Epoch 1992/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0205e-07 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9664
# Epoch 1993/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5970e-07 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9651
# Epoch 1994/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5239e-07 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9651
# Epoch 1995/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4133e-07 - accuracy: 1.0000 - val_loss: 0.1865 - val_accuracy: 0.9651
# Epoch 1996/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3740e-07 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 0.9638
# Epoch 1997/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8895e-07 - accuracy: 1.0000 - val_loss: 0.1875 - val_accuracy: 0.9638
# Epoch 1998/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2881e-07 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9638
# Epoch 1999/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4990e-07 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9638
# Epoch 2000/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0586e-07 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9638
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 347ms/step - loss: 0.8751 - accuracy: 0.8495
# test_indoor_ds_results:test loss, test acc: [0.8750526905059814, 0.8494983315467834]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 421ms/step - loss: 2.0253 - accuracy: 0.7475
# test_outdoor_ds_results:test loss, test acc: [2.025339365005493, 0.7474522590637207]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 199ms/step - loss: 2.2308 - accuracy: 0.7235
# test_belt_ds_results:test loss, test acc: [2.2308263778686523, 0.7234814167022705]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR225-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 138ms/step - loss: 0.5721 - accuracy: 0.8478
# 50/50 [==============================] - 7s 138ms/step - loss: 1.2124 - accuracy: 0.7439
# 35/35 [==============================] - 5s 138ms/step - loss: 1.4046 - accuracy: 0.7185
# Epoch200
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7439490556716919
#  test_belt_acc=0.7184950113296509
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6170 - accuracy: 0.8489
# 50/50 [==============================] - 7s 137ms/step - loss: 1.3695 - accuracy: 0.7427
# 35/35 [==============================] - 5s 138ms/step - loss: 1.5635 - accuracy: 0.7185
# Epoch400
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.7426751852035522
#  test_belt_acc=0.7184950113296509
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6801 - accuracy: 0.8467
# 50/50 [==============================] - 7s 137ms/step - loss: 1.4900 - accuracy: 0.7446
# 35/35 [==============================] - 5s 138ms/step - loss: 1.7075 - accuracy: 0.7180
# Epoch600
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.7445859909057617
#  test_belt_acc=0.718041718006134
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7400 - accuracy: 0.8428
# 50/50 [==============================] - 7s 136ms/step - loss: 1.6524 - accuracy: 0.7433
# 35/35 [==============================] - 5s 137ms/step - loss: 1.8705 - accuracy: 0.7153
# Epoch800
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.7433121204376221
#  test_belt_acc=0.7153218388557434
# 29/29 [==============================] - 5s 135ms/step - loss: 0.7701 - accuracy: 0.8467
# 50/50 [==============================] - 7s 137ms/step - loss: 1.7500 - accuracy: 0.7468
# 35/35 [==============================] - 5s 137ms/step - loss: 1.9684 - accuracy: 0.7208
# Epoch1000
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.7468152642250061
#  test_belt_acc=0.7207615375518799
# 29/29 [==============================] - 5s 135ms/step - loss: 0.7988 - accuracy: 0.8484
# 50/50 [==============================] - 7s 136ms/step - loss: 1.8322 - accuracy: 0.7465
# 35/35 [==============================] - 5s 137ms/step - loss: 2.0415 - accuracy: 0.7199
# Epoch1200
#  test_indoor_acc=0.8483834862709045
#  test_outdoor_acc=0.7464967966079712
#  test_belt_acc=0.7198549509048462
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8338 - accuracy: 0.8450
# 50/50 [==============================] - 7s 136ms/step - loss: 1.9082 - accuracy: 0.7462
# 35/35 [==============================] - 5s 137ms/step - loss: 2.1308 - accuracy: 0.7180
# Epoch1400
#  test_indoor_acc=0.8450390100479126
#  test_outdoor_acc=0.7461783289909363
#  test_belt_acc=0.718041718006134
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8477 - accuracy: 0.8473
# 50/50 [==============================] - 7s 137ms/step - loss: 1.9480 - accuracy: 0.7481
# 35/35 [==============================] - 5s 137ms/step - loss: 2.1587 - accuracy: 0.7230
# Epoch1600
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7480891942977905
#  test_belt_acc=0.7230281233787537
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8627 - accuracy: 0.8512
# 50/50 [==============================] - 7s 138ms/step - loss: 1.9820 - accuracy: 0.7471
# 35/35 [==============================] - 5s 139ms/step - loss: 2.2150 - accuracy: 0.7217
# Epoch1800
#  test_indoor_acc=0.851170539855957
#  test_outdoor_acc=0.747133731842041
#  test_belt_acc=0.7216681838035583
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8751 - accuracy: 0.8495
# 50/50 [==============================] - 7s 138ms/step - loss: 2.0253 - accuracy: 0.7475
# 35/35 [==============================] - 5s 139ms/step - loss: 2.2308 - accuracy: 0.7235
# Epoch2000
#  test_indoor_acc=0.8494983315467834
#  test_outdoor_acc=0.7474522590637207
#  test_belt_acc=0.7234814167022705

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7734773357709249
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8478260636329651,
#  0.848940908908844,
#  0.846711277961731,
#  0.8428093791007996,
#  0.846711277961731,
#  0.8483834862709045,
#  0.8450390100479126,
#  0.8472687005996704,
#  0.851170539855957,
#  0.8494983315467834]

# %%
test_outdoor_acc
# Out:
# [0.7439490556716919,
#  0.7426751852035522,
#  0.7445859909057617,
#  0.7433121204376221,
#  0.7468152642250061,
#  0.7464967966079712,
#  0.7461783289909363,
#  0.7480891942977905,
#  0.747133731842041,
#  0.7474522590637207]

# %%
test_belt_acc
# Out:
# [0.7184950113296509,
#  0.7184950113296509,
#  0.718041718006134,
#  0.7153218388557434,
#  0.7207615375518799,
#  0.7198549509048462,
#  0.718041718006134,
#  0.7230281233787537,
#  0.7216681838035583,
#  0.7234814167022705]

# %%
test_indoor_loss
# Out:
# [0.5720646381378174,
#  0.617016613483429,
#  0.680060088634491,
#  0.7400364875793457,
#  0.7701400518417358,
#  0.7988311648368835,
#  0.8337991833686829,
#  0.8477274775505066,
#  0.8626541495323181,
#  0.8750526905059814]

# %%
test_outdoor_loss
# Out:
# [1.2123832702636719,
#  1.3694729804992676,
#  1.4899660348892212,
#  1.6523661613464355,
#  1.7500088214874268,
#  1.8321616649627686,
#  1.9081919193267822,
#  1.9480081796646118,
#  1.9819750785827637,
#  2.025339365005493]

# %%
test_belt_loss
# Out:
# [1.4046169519424438,
#  1.563517689704895,
#  1.7075228691101074,
#  1.8705377578735352,
#  1.9684234857559204,
#  2.0415124893188477,
#  2.130786418914795,
#  2.1587460041046143,
#  2.214968204498291,
#  2.2308263778686523]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5467
# FP=1673
# acc=0.765686274509804
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 83.62068965517241%
# 2WayConnectorforFoley acc = 89.1156462585034%
# 2WayFoleyCatheter acc = 71.64179104477611%
# 3WayConnectorforFoley acc = 88.88888888888889%
# 3Waystopcock acc = 98.1981981981982%
# AlcoholBottle acc = 84.375%
# AlcoholPad acc = 50.79365079365079%
# BootCover acc = 61.44578313253012%
# CottonBall acc = 85.02994011976048%
# CottonSwap acc = 63.63636363636363%
# Dilator acc = 57.26495726495726%
# DisposableInfusionSet acc = 51.32743362831859%
# ExtensionTube acc = 48.78048780487805%
# FaceShield acc = 85.80246913580247%
# FrontLoadSyringe acc = 50.442477876106196%
# GauzePad acc = 63.06818181818182%
# Glove acc = 74.70238095238095%
# GuideWire acc = 39.285714285714285%
# LiquidBottle acc = 64.50381679389314%
# Mask acc = 94.8051948051948%
# NGTube acc = 41.935483870967744%
# NasalCannula acc = 61.06194690265486%
# Needle acc = 86.07142857142858%
# OxygenMask acc = 87.96992481203007%
# PPESuit acc = 91.12903225806451%
# PharmaceuticalProduct acc = 72.89719626168224%
# Pill acc = 97.61904761904762%
# PillBottle acc = 70.54263565891473%
# PrefilledHumidifier acc = 79.48717948717949%
# PressureConnectingTube acc = 62.59541984732825%
# ReusableHumidifier acc = 84.7457627118644%
# SodiumChlorideBag acc = 88.9763779527559%
# SterileHumidifierAdapter acc = 80.9090909090909%
# SurgicalBlade acc = 89.38053097345133%
# SurgicalCap acc = 92.7927927927928%
# SurgicalSuit acc = 46.96969696969697%
# Syringe acc = 96.95817490494296%
# TrachealTube acc = 39.44954128440367%
# UrineBag acc = 67.5%
# Vaccinebottle acc = 82.62910798122066%
# WingedInfusionSet acc = 63.1578947368421%
#
#
#
# all_avg_eachclass = 72.96359347803978%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 97,   0,   0, ...,   0,   0,   0],
#        [  1, 131,   0, ...,   0,   0,   0],
#        [  0,   0,  96, ...,   1,   0,  15],
#        ...,
#        [  0,   0,   0, ...,  81,   1,   0],
#        [  0,   0,   0, ...,   0, 176,   1],
#        [  0,   0,   0, ...,   0,   1,  72]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[83.62068966,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.68027211, 89.11564626,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 71.64179104, ...,  0.74626866,
#          0.        , 11.19402985],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 67.5       ,
#          0.83333333,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         82.62910798,  0.46948357],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.87719298, 63.15789474]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
