# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.30),
  layers.RandomZoom(height_factor=0.050,width_factor=0.050),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 333ms/step - loss: 1.3645 - accuracy: 0.6330 - val_loss: 0.5482 - val_accuracy: 0.8473
# Epoch 2/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.4040 - accuracy: 0.8792 - val_loss: 0.3919 - val_accuracy: 0.8836
# Epoch 3/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.2229 - accuracy: 0.9325 - val_loss: 0.3068 - val_accuracy: 0.8978
# Epoch 4/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.1480 - accuracy: 0.9616 - val_loss: 0.2850 - val_accuracy: 0.9030
# Epoch 5/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.1011 - accuracy: 0.9716 - val_loss: 0.2605 - val_accuracy: 0.9107
# Epoch 6/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0714 - accuracy: 0.9842 - val_loss: 0.2880 - val_accuracy: 0.8913
# Epoch 7/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0581 - accuracy: 0.9861 - val_loss: 0.2412 - val_accuracy: 0.9185
# Epoch 8/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0455 - accuracy: 0.9910 - val_loss: 0.2556 - val_accuracy: 0.9069
# Epoch 9/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0498 - accuracy: 0.9864 - val_loss: 0.3013 - val_accuracy: 0.8952
# Epoch 10/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0362 - accuracy: 0.9903 - val_loss: 0.3223 - val_accuracy: 0.9004
# Epoch 11/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0358 - accuracy: 0.9922 - val_loss: 0.1868 - val_accuracy: 0.9392
# Epoch 12/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0344 - accuracy: 0.9926 - val_loss: 0.1985 - val_accuracy: 0.9483
# Epoch 13/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0161 - accuracy: 0.9971 - val_loss: 0.1976 - val_accuracy: 0.9431
# Epoch 14/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0112 - accuracy: 0.9990 - val_loss: 0.1855 - val_accuracy: 0.9457
# Epoch 15/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0088 - accuracy: 0.9990 - val_loss: 0.1613 - val_accuracy: 0.9495
# Epoch 16/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0095 - accuracy: 0.9990 - val_loss: 0.1632 - val_accuracy: 0.9508
# Epoch 17/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.1584 - val_accuracy: 0.9495
# Epoch 18/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.1613 - val_accuracy: 0.9508
# Epoch 19/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9547
# Epoch 20/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9534
# Epoch 21/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 22/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9547
# Epoch 23/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9560
# Epoch 24/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9573
# Epoch 25/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9560
# Epoch 26/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9560
# Epoch 27/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9547
# Epoch 28/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9586
# Epoch 29/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9560
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 30/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
# Epoch 31/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9586
# Epoch 32/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9586
# Epoch 33/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9586
# Epoch 34/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9599
# Epoch 35/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9586
# Epoch 36/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9612
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 37/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.9585e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9599
# Epoch 38/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.3995e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9612
# Epoch 39/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9612
# Epoch 40/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.4142e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9612
# Epoch 41/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 42/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.8357e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
# Epoch 43/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 44/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.5789e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 45/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.3552e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 46/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 47/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
# Epoch 48/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.9886e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 49/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.2572e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 50/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9612
# Epoch 51/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.2601e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9612
# Epoch 52/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.3851e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9612
# Epoch 53/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.7997e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 54/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.5629e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 55/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.3911e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 56/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.9832e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 57/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 58/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.7511e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 59/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 60/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.9686e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 61/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.8626e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 62/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2651e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 63/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.3770e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 64/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.4341e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 65/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.9563e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 66/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2751e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9599
# Epoch 67/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.6596e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9599
# Epoch 68/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.7398e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 69/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2689e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 70/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.7018e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 71/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9599
# Epoch 72/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2811e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9599
# Epoch 73/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.8222e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 74/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 75/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.6446e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 76/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.6183e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 77/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.4090e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 78/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.6294e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 79/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.8901e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9586
# Epoch 80/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2685e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9586
# Epoch 81/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.8205e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9586
# Epoch 82/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.0654e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9586
# Epoch 83/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2154e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9586
# Epoch 84/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.3571e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9599
# Epoch 85/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.3605e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9599
# Epoch 86/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.5504e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 87/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.3732e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9599
# Epoch 88/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.6501e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 89/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.8504e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9599
# Epoch 90/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.6089e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9599
# Epoch 91/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.0983e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 92/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.4017e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9586
# Epoch 93/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.1936e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9586
# Epoch 94/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.9106e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9573
# Epoch 95/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.8442e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9573
# Epoch 96/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.0527e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9599
# Epoch 97/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.2799e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9612
# Epoch 98/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.7128e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9612
# Epoch 99/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.0883e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 100/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.7253e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 101/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2187e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 102/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.8455e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9612
# Epoch 103/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.4235e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9612
# Epoch 104/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.3183e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 105/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.7606e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9612
# Epoch 106/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.8942e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9612
# Epoch 107/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.4404e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 108/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.4125e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 109/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.3617e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9599
# Epoch 110/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.9191e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9599
# Epoch 111/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.9003e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 112/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.6472e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 113/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.8584e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 114/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.8096e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9612
# Epoch 115/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.9969e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 116/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2889e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 117/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.6259e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9612
# Epoch 118/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.7190e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9586
# Epoch 119/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7113e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9586
# Epoch 120/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.2504e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9586
# Epoch 121/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.6151e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9599
# Epoch 122/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.2693e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
# Epoch 123/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.7980e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 124/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.6776e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 125/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.5939e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 126/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7721e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9612
# Epoch 127/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9805e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 128/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.2941e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9599
# Epoch 129/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.3694e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9599
# Epoch 130/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7379e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 131/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.4457e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9599
# Epoch 132/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.4251e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 133/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.4505e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9599
# Epoch 134/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7247e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 135/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.2913e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 136/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3535e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9599
# Epoch 137/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9383e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9599
# Epoch 138/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2694e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9573
# Epoch 139/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9111e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9612
# Epoch 140/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9858e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9599
# Epoch 141/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0337e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9599
# Epoch 142/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9713e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9586
# Epoch 143/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1484e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9599
# Epoch 144/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.6235e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9599
# Epoch 145/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6336e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9612
# Epoch 146/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9694e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9612
# Epoch 147/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2555e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9612
# Epoch 148/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9637e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9599
# Epoch 149/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1531e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9599
# Epoch 150/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3365e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9586
# Epoch 151/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.6886e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9586
# Epoch 152/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3762e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9612
# Epoch 153/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2354e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9612
# Epoch 154/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3257e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9599
# Epoch 155/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5671e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9612
# Epoch 156/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3296e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9599
# Epoch 157/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5810e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9612
# Epoch 158/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7746e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 159/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1907e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9625
# Epoch 160/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8715e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9586
# Epoch 161/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7321e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9586
# Epoch 162/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8115e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 163/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1825e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9599
# Epoch 164/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2125e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9573
# Epoch 165/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7999e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9586
# Epoch 166/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9180e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9612
# Epoch 167/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4851e-04 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9625
# Epoch 168/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.9025e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9625
# Epoch 169/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7552e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9599
# Epoch 170/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5734e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9625
# Epoch 171/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.9783e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9612
# Epoch 172/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.0787e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9612
# Epoch 173/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9856e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9612
# Epoch 174/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7329e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9612
# Epoch 175/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6941e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9599
# Epoch 176/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5785e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9612
# Epoch 177/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.9901e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9599
# Epoch 178/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4880e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9612
# Epoch 179/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5987e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9612
# Epoch 180/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4306e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9625
# Epoch 181/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5186e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9625
# Epoch 182/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.6229e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9612
# Epoch 183/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.2036e-04 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9625
# Epoch 184/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1897e-04 - accuracy: 1.0000 - val_loss: 0.1435 - val_accuracy: 0.9625
# Epoch 185/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1154e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9612
# Epoch 186/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8695e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9612
# Epoch 187/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.6806e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9625
# Epoch 188/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5604e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9625
# Epoch 189/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5888e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9625
# Epoch 190/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.4398e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9625
# Epoch 191/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.3581e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9625
# Epoch 192/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.9745e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9625
# Epoch 193/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.9588e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9599
# Epoch 194/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.9112e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 195/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.1487e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9599
# Epoch 196/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.2399e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9599
# Epoch 197/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5429e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9586
# Epoch 198/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5040e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 199/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.0711e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 200/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5794e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9625
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.4485e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 202/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.1348e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 203/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.8865e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
# Epoch 204/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.9577e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9599
# Epoch 205/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.0930e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9612
# Epoch 206/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.8968e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 207/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.4080e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9625
# Epoch 208/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.0110e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9612
# Epoch 209/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6883e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9625
# Epoch 210/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6928e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9612
# Epoch 211/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.9026e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9612
# Epoch 212/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5167e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 213/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.7298e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 214/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1432e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9599
# Epoch 215/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6325e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9599
# Epoch 216/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6942e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9612
# Epoch 217/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.2702e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9612
# Epoch 218/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3743e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9625
# Epoch 219/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6824e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9625
# Epoch 220/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1335e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9625
# Epoch 221/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5857e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9625
# Epoch 222/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.8628e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9625
# Epoch 223/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.4488e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9625
# Epoch 224/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8936e-04 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9638
# Epoch 225/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0189e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9599
# Epoch 226/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3945e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9638
# Epoch 227/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.2105e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9625
# Epoch 228/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2489e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9625
# Epoch 229/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.9115e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9625
# Epoch 230/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8086e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9625
# Epoch 231/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0231e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9638
# Epoch 232/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.9647e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9625
# Epoch 233/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7267e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9638
# Epoch 234/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5935e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9586
# Epoch 235/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6907e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9638
# Epoch 236/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7216e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9612
# Epoch 237/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.4210e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9612
# Epoch 238/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7928e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 239/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.9023e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9612
# Epoch 240/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2919e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9625
# Epoch 241/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5370e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9638
# Epoch 242/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5711e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9612
# Epoch 243/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3749e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9599
# Epoch 244/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0209e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9625
# Epoch 245/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2665e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9612
# Epoch 246/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2045e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9625
# Epoch 247/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3896e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9612
# Epoch 248/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6375e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9625
# Epoch 249/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0174e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9599
# Epoch 250/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7884e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9599
# Epoch 251/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1762e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9599
# Epoch 252/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3170e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9612
# Epoch 253/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2869e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9599
# Epoch 254/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.4195e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 255/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2551e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9638
# Epoch 256/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1121e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9625
# Epoch 257/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8589e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9625
# Epoch 258/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9480e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 259/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1124e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9625
# Epoch 260/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6139e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 261/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8733e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 262/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0337e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9612
# Epoch 263/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1125e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9638
# Epoch 264/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5454e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9638
# Epoch 265/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1158e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9612
# Epoch 266/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8655e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9638
# Epoch 267/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8271e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9638
# Epoch 268/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0925e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9638
# Epoch 269/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6618e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9638
# Epoch 270/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9112e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9625
# Epoch 271/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8025e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9625
# Epoch 272/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3639e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9638
# Epoch 273/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8434e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9612
# Epoch 274/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7419e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9625
# Epoch 275/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.4876e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9638
# Epoch 276/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7094e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 277/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5264e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9612
# Epoch 278/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5452e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9638
# Epoch 279/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5608e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9612
# Epoch 280/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6246e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9599
# Epoch 281/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7864e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9612
# Epoch 282/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3045e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9625
# Epoch 283/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3327e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9612
# Epoch 284/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.4424e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9625
# Epoch 285/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2937e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9625
# Epoch 286/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2535e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9625
# Epoch 287/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3000e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 288/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2803e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9625
# Epoch 289/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.4011e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9625
# Epoch 290/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.4267e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9625
# Epoch 291/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1445e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9638
# Epoch 292/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3629e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9625
# Epoch 293/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2199e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9625
# Epoch 294/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1057e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9638
# Epoch 295/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2785e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9625
# Epoch 296/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1267e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9625
# Epoch 297/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.9480e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9638
# Epoch 298/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.0876e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9638
# Epoch 299/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.0531e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9625
# Epoch 300/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1335e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9612
# Epoch 301/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.0972e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9625
# Epoch 302/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.9768e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9625
# Epoch 303/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1375e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9638
# Epoch 304/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1373e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9625
# Epoch 305/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.8723e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9625
# Epoch 306/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.7759e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9612
# Epoch 307/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2165e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9612
# Epoch 308/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.9028e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9625
# Epoch 309/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.8270e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9612
# Epoch 310/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.0087e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9625
# Epoch 311/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.0049e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9625
# Epoch 312/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.7780e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9638
# Epoch 313/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.8519e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9638
# Epoch 314/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.9515e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9625
# Epoch 315/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.9869e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9625
# Epoch 316/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.8355e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9625
# Epoch 317/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.7222e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9625
# Epoch 318/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.8163e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9625
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3796e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9651
# Epoch 1898/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9261e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1899/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3599e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9651
# Epoch 1900/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3726e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9651
# Epoch 1901/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5691e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1902/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.8629e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1903/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5228e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1904/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2494e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1905/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3919e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9651
# Epoch 1906/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5221e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1907/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5964e-07 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9651
# Epoch 1908/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6234e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1909/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3946e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9651
# Epoch 1910/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2621e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9651
# Epoch 1911/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6653e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9651
# Epoch 1912/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.0883e-07 - accuracy: 1.0000 - val_loss: 0.2138 - val_accuracy: 0.9651
# Epoch 1913/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.3930e-07 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9651
# Epoch 1914/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4435e-07 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9651
# Epoch 1915/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6861e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9651
# Epoch 1916/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.8614e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9651
# Epoch 1917/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2652e-07 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9651
# Epoch 1918/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.5358e-07 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9651
# Epoch 1919/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3137e-07 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9651
# Epoch 1920/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 4.7978e-07 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9651
# Epoch 1921/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9053e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9651
# Epoch 1922/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5945e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9651
# Epoch 1923/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2759e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9651
# Epoch 1924/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6765e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9651
# Epoch 1925/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.1966e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9651
# Epoch 1926/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9950e-07 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9651
# Epoch 1927/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.0173e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9651
# Epoch 1928/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2089e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9651
# Epoch 1929/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9295e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9651
# Epoch 1930/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4635e-07 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9651
# Epoch 1931/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.2419e-07 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9651
# Epoch 1932/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6380e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9651
# Epoch 1933/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4670e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9651
# Epoch 1934/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4874e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9651
# Epoch 1935/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.0825e-07 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9651
# Epoch 1936/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.3988e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9651
# Epoch 1937/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.2750e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9651
# Epoch 1938/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4011e-07 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9651
# Epoch 1939/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.1893e-07 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9651
# Epoch 1940/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2216e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9651
# Epoch 1941/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.2076e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9651
# Epoch 1942/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.0499e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9651
# Epoch 1943/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6630e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9651
# Epoch 1944/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.7474e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9651
# Epoch 1945/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4932e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9651
# Epoch 1946/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.0397e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9651
# Epoch 1947/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5348e-07 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9651
# Epoch 1948/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3946e-07 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9651
# Epoch 1949/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4739e-07 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9651
# Epoch 1950/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9584e-07 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9651
# Epoch 1951/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4812e-07 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9651
# Epoch 1952/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4531e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9651
# Epoch 1953/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2609e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9651
# Epoch 1954/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.2232e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9651
# Epoch 1955/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.1772e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9651
# Epoch 1956/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.4622e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9651
# Epoch 1957/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.1727e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9651
# Epoch 1958/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.1712e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9651
# Epoch 1959/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6245e-07 - accuracy: 1.0000 - val_loss: 0.2137 - val_accuracy: 0.9651
# Epoch 1960/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6522e-07 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9651
# Epoch 1961/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.9704e-07 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9651
# Epoch 1962/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.0036e-07 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9651
# Epoch 1963/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6491e-07 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9651
# Epoch 1964/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.3497e-07 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9651
# Epoch 1965/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5436e-07 - accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9651
# Epoch 1966/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9269e-07 - accuracy: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.9638
# Epoch 1967/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.1496e-07 - accuracy: 1.0000 - val_loss: 0.2164 - val_accuracy: 0.9651
# Epoch 1968/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.8864e-07 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.9651
# Epoch 1969/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5255e-07 - accuracy: 1.0000 - val_loss: 0.2159 - val_accuracy: 0.9651
# Epoch 1970/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.4793e-07 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9651
# Epoch 1971/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.1209e-07 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9651
# Epoch 1972/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4955e-07 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9651
# Epoch 1973/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3110e-07 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9651
# Epoch 1974/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.3645e-07 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9651
# Epoch 1975/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.5275e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9651
# Epoch 1976/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2636e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9651
# Epoch 1977/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4531e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9651
# Epoch 1978/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.7057e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9651
# Epoch 1979/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.8745e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9651
# Epoch 1980/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.4333e-07 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9651
# Epoch 1981/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3187e-07 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9651
# Epoch 1982/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.8737e-07 - accuracy: 1.0000 - val_loss: 0.2138 - val_accuracy: 0.9651
# Epoch 1983/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9411e-07 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9664
# Epoch 1984/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.7528e-07 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9664
# Epoch 1985/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.0483e-07 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9664
# Epoch 1986/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.5232e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9664
# Epoch 1987/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.3718e-07 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9664
# Epoch 1988/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.6988e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9664
# Epoch 1989/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.1743e-07 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9664
# Epoch 1990/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.9323e-07 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9664
# Epoch 1991/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 2.1092e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9664
# Epoch 1992/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 3.0011e-07 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9664
# Epoch 1993/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6333e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9664
# Epoch 1994/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2887e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9664
# Epoch 1995/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.3385e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9664
# Epoch 1996/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.6010e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9664
# Epoch 1997/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.2706e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9664
# Epoch 1998/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.3938e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9664
# Epoch 1999/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.2409e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9664
# Epoch 2000/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 2.4161e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9664
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 344ms/step - loss: 0.8517 - accuracy: 0.8467
# test_indoor_ds_results:test loss, test acc: [0.8517175316810608, 0.846711277961731]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 420ms/step - loss: 2.1880 - accuracy: 0.7376
# test_outdoor_ds_results:test loss, test acc: [2.1879992485046387, 0.7375796437263489]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 195ms/step - loss: 2.1708 - accuracy: 0.7276
# test_belt_ds_results:test loss, test acc: [2.1708297729492188, 0.7275611758232117]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustom-NormalLR_3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 132ms/step - loss: 0.5786 - accuracy: 0.8350
# 50/50 [==============================] - 7s 134ms/step - loss: 1.4044 - accuracy: 0.7309
# 35/35 [==============================] - 5s 134ms/step - loss: 1.4029 - accuracy: 0.7199
# Epoch200
#  test_indoor_acc=0.8350055813789368
#  test_outdoor_acc=0.7308917045593262
#  test_belt_acc=0.7198549509048462
# 29/29 [==============================] - 5s 134ms/step - loss: 0.6251 - accuracy: 0.8400
# 50/50 [==============================] - 7s 136ms/step - loss: 1.5658 - accuracy: 0.7334
# 35/35 [==============================] - 5s 136ms/step - loss: 1.5576 - accuracy: 0.7208
# Epoch400
#  test_indoor_acc=0.8400223255157471
#  test_outdoor_acc=0.7334395051002502
#  test_belt_acc=0.7207615375518799
# 29/29 [==============================] - 5s 134ms/step - loss: 0.6754 - accuracy: 0.8417
# 50/50 [==============================] - 7s 135ms/step - loss: 1.7434 - accuracy: 0.7331
# 35/35 [==============================] - 5s 136ms/step - loss: 1.7206 - accuracy: 0.7221
# Epoch600
#  test_indoor_acc=0.8416945338249207
#  test_outdoor_acc=0.7331210374832153
#  test_belt_acc=0.7221214771270752
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7204 - accuracy: 0.8428
# 50/50 [==============================] - 7s 136ms/step - loss: 1.8270 - accuracy: 0.7354
# 35/35 [==============================] - 5s 136ms/step - loss: 1.8238 - accuracy: 0.7235
# Epoch800
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.7353503108024597
#  test_belt_acc=0.7234814167022705
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7541 - accuracy: 0.8456
# 50/50 [==============================] - 7s 135ms/step - loss: 1.9299 - accuracy: 0.7363
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9139 - accuracy: 0.7239
# Epoch1000
#  test_indoor_acc=0.845596432685852
#  test_outdoor_acc=0.7363057136535645
#  test_belt_acc=0.7239347100257874
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7889 - accuracy: 0.8439
# 50/50 [==============================] - 7s 135ms/step - loss: 2.0314 - accuracy: 0.7360
# 35/35 [==============================] - 5s 136ms/step - loss: 2.0211 - accuracy: 0.7226
# Epoch1200
#  test_indoor_acc=0.8439241647720337
#  test_outdoor_acc=0.7359872460365295
#  test_belt_acc=0.722574770450592
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8143 - accuracy: 0.8428
# 50/50 [==============================] - 7s 136ms/step - loss: 2.1021 - accuracy: 0.7344
# 35/35 [==============================] - 5s 137ms/step - loss: 2.0883 - accuracy: 0.7230
# Epoch1400
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.734394907951355
#  test_belt_acc=0.7230281233787537
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8286 - accuracy: 0.8428
# 50/50 [==============================] - 7s 136ms/step - loss: 2.1238 - accuracy: 0.7344
# 35/35 [==============================] - 5s 137ms/step - loss: 2.1212 - accuracy: 0.7253
# Epoch1600
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.734394907951355
#  test_belt_acc=0.7252946496009827
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8450 - accuracy: 0.8445
# 50/50 [==============================] - 7s 135ms/step - loss: 2.1852 - accuracy: 0.7350
# 35/35 [==============================] - 5s 136ms/step - loss: 2.1570 - accuracy: 0.7271
# Epoch1800
#  test_indoor_acc=0.8444815874099731
#  test_outdoor_acc=0.7350318431854248
#  test_belt_acc=0.7271078824996948
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8517 - accuracy: 0.8467
# 50/50 [==============================] - 7s 135ms/step - loss: 2.1880 - accuracy: 0.7376
# 35/35 [==============================] - 5s 136ms/step - loss: 2.1708 - accuracy: 0.7276
# Epoch2000
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.7375796437263489
#  test_belt_acc=0.7275611758232117

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7706173658370972
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8350055813789368,
#  0.8400223255157471,
#  0.8416945338249207,
#  0.8428093791007996,
#  0.845596432685852,
#  0.8439241647720337,
#  0.8428093791007996,
#  0.8428093791007996,
#  0.8444815874099731,
#  0.846711277961731]

# %%
test_outdoor_acc
# Out:
# [0.7308917045593262,
#  0.7334395051002502,
#  0.7331210374832153,
#  0.7353503108024597,
#  0.7363057136535645,
#  0.7359872460365295,
#  0.734394907951355,
#  0.734394907951355,
#  0.7350318431854248,
#  0.7375796437263489]

# %%
test_belt_acc
# Out:
# [0.7198549509048462,
#  0.7207615375518799,
#  0.7221214771270752,
#  0.7234814167022705,
#  0.7239347100257874,
#  0.722574770450592,
#  0.7230281233787537,
#  0.7252946496009827,
#  0.7271078824996948,
#  0.7275611758232117]

# %%
test_indoor_loss
# Out:
# [0.578569233417511,
#  0.6250853538513184,
#  0.6754109859466553,
#  0.7204429507255554,
#  0.7540976405143738,
#  0.7888504862785339,
#  0.8142766356468201,
#  0.8285539746284485,
#  0.8450005054473877,
#  0.8517175316810608]

# %%
test_outdoor_loss
# Out:
# [1.4043642282485962,
#  1.5658153295516968,
#  1.7434296607971191,
#  1.8269917964935303,
#  1.9299113750457764,
#  2.0314300060272217,
#  2.1021265983581543,
#  2.1237990856170654,
#  2.1852147579193115,
#  2.1879992485046387]

# %%
test_belt_loss
# Out:
# [1.4028736352920532,
#  1.5576010942459106,
#  1.7206050157546997,
#  1.8237544298171997,
#  1.9139354228973389,
#  2.021054267883301,
#  2.088297128677368,
#  2.121155023574829,
#  2.157042980194092,
#  2.1708297729492188]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5440
# FP=1700
# acc=0.7619047619047619
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 69.82758620689656%
# 2WayConnectorforFoley acc = 91.15646258503402%
# 2WayFoleyCatheter acc = 75.3731343283582%
# 3WayConnectorforFoley acc = 82.90598290598291%
# 3Waystopcock acc = 100.0%
# AlcoholBottle acc = 82.5%
# AlcoholPad acc = 54.761904761904766%
# BootCover acc = 62.048192771084345%
# CottonBall acc = 91.01796407185628%
# CottonSwap acc = 79.72027972027972%
# Dilator acc = 67.52136752136752%
# DisposableInfusionSet acc = 46.017699115044245%
# ExtensionTube acc = 24.390243902439025%
# FaceShield acc = 79.01234567901234%
# FrontLoadSyringe acc = 43.36283185840708%
# GauzePad acc = 63.06818181818182%
# Glove acc = 75.0%
# GuideWire acc = 59.82142857142857%
# LiquidBottle acc = 66.03053435114504%
# Mask acc = 96.36363636363636%
# NGTube acc = 44.516129032258064%
# NasalCannula acc = 49.557522123893804%
# Needle acc = 82.14285714285714%
# OxygenMask acc = 89.47368421052632%
# PPESuit acc = 94.35483870967742%
# PharmaceuticalProduct acc = 62.149532710280376%
# Pill acc = 97.19887955182072%
# PillBottle acc = 76.74418604651163%
# PrefilledHumidifier acc = 80.34188034188034%
# PressureConnectingTube acc = 64.8854961832061%
# ReusableHumidifier acc = 85.59322033898306%
# SodiumChlorideBag acc = 86.61417322834646%
# SterileHumidifierAdapter acc = 84.54545454545455%
# SurgicalBlade acc = 84.95575221238938%
# SurgicalCap acc = 90.990990990991%
# SurgicalSuit acc = 47.72727272727273%
# Syringe acc = 98.09885931558935%
# TrachealTube acc = 42.201834862385326%
# UrineBag acc = 70.83333333333334%
# Vaccinebottle acc = 84.50704225352112%
# WingedInfusionSet acc = 63.1578947368421%
#
#
#
# all_avg_eachclass = 72.93879539341654%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 81,   0,   0, ...,   0,   5,   0],
#        [  1, 134,   0, ...,   0,   0,   0],
#        [  0,   0, 101, ...,   0,   1,   6],
#        ...,
#        [  0,   0,   0, ...,  85,   0,   0],
#        [  0,   0,   0, ...,   1, 180,   0],
#        [  0,   0,   0, ...,   1,   0,  72]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[69.82758621,  0.        ,  0.        , ...,  0.        ,
#          4.31034483,  0.        ],
#        [ 0.68027211, 91.15646259,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 75.37313433, ...,  0.        ,
#          0.74626866,  4.47761194],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 70.83333333,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.46948357,
#         84.50704225,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.87719298,
#          0.        , 63.15789474]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
