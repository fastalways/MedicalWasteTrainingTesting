# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.275),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 45s 334ms/step - loss: 1.5060 - accuracy: 0.5942 - val_loss: 0.6071 - val_accuracy: 0.8473
# Epoch 2/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.4364 - accuracy: 0.8669 - val_loss: 0.4266 - val_accuracy: 0.8706
# Epoch 3/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.2568 - accuracy: 0.9267 - val_loss: 0.3088 - val_accuracy: 0.9043
# Epoch 4/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.1541 - accuracy: 0.9557 - val_loss: 0.2794 - val_accuracy: 0.9172
# Epoch 5/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1082 - accuracy: 0.9712 - val_loss: 0.2509 - val_accuracy: 0.9237
# Epoch 6/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0731 - accuracy: 0.9835 - val_loss: 0.2186 - val_accuracy: 0.9276
# Epoch 7/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0761 - accuracy: 0.9803 - val_loss: 0.2408 - val_accuracy: 0.9159
# Epoch 8/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0536 - accuracy: 0.9877 - val_loss: 0.2025 - val_accuracy: 0.9379
# Epoch 9/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0444 - accuracy: 0.9893 - val_loss: 0.2164 - val_accuracy: 0.9276
# Epoch 10/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0441 - accuracy: 0.9887 - val_loss: 0.2115 - val_accuracy: 0.9263
# Epoch 11/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0331 - accuracy: 0.9926 - val_loss: 0.1903 - val_accuracy: 0.9444
# Epoch 12/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0261 - accuracy: 0.9945 - val_loss: 0.2049 - val_accuracy: 0.9185
# Epoch 13/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0201 - accuracy: 0.9977 - val_loss: 0.1804 - val_accuracy: 0.9353
# Epoch 14/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0149 - accuracy: 0.9987 - val_loss: 0.1979 - val_accuracy: 0.9340
# Epoch 15/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0170 - accuracy: 0.9968 - val_loss: 0.1851 - val_accuracy: 0.9392
# Epoch 16/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.1750 - val_accuracy: 0.9405
# Epoch 17/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9470
# Epoch 18/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9521
# Epoch 19/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0095 - accuracy: 0.9990 - val_loss: 0.1367 - val_accuracy: 0.9521
# Epoch 20/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.1483 - val_accuracy: 0.9483
# Epoch 21/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9470
# Epoch 22/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9457
# Epoch 23/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9470
# Epoch 24/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9508
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 25/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9508
# Epoch 26/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9521
# Epoch 27/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9547
# Epoch 28/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9547
# Epoch 29/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9560
# Epoch 30/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9534
# Epoch 31/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 32/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9508
# Epoch 33/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9508
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 34/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9508
# Epoch 35/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9508
# Epoch 36/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9508
# Epoch 37/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9508
# Epoch 38/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9508
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 39/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9508
# Epoch 40/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9508
# Epoch 41/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9508
# Epoch 42/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 43/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9508
# Epoch 44/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9508
# Epoch 45/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 46/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 47/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 48/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 49/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 50/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9508
# Epoch 51/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9508
# Epoch 52/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9508
# Epoch 53/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9508
# Epoch 54/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9508
# Epoch 55/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9508
# Epoch 56/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9508
# Epoch 57/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9508
# Epoch 58/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9521
# Epoch 59/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9521
# Epoch 60/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9521
# Epoch 61/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9521
# Epoch 62/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9521
# Epoch 63/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9521
# Epoch 64/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9521
# Epoch 65/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9521
# Epoch 66/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9534
# Epoch 67/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9521
# Epoch 68/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9521
# Epoch 69/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9508
# Epoch 70/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9521
# Epoch 71/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9521
# Epoch 72/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9521
# Epoch 73/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9521
# Epoch 74/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9521
# Epoch 75/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9521
# Epoch 76/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9521
# Epoch 77/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9508
# Epoch 78/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9508
# Epoch 79/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9508
# Epoch 80/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9521
# Epoch 81/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9521
# Epoch 82/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9508
# Epoch 83/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9508
# Epoch 84/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9508
# Epoch 85/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9508
# Epoch 86/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9508
# Epoch 87/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9508
# Epoch 88/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9508
# Epoch 89/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9508
# Epoch 90/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9521
# Epoch 91/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9521
# Epoch 92/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9521
# Epoch 93/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 94/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9521
# Epoch 95/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9508
# Epoch 96/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9508
# Epoch 97/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9508
# Epoch 98/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 99/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9521
# Epoch 100/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9521
# Epoch 101/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9521
# Epoch 102/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9508
# Epoch 103/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 104/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 105/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 106/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9521
# Epoch 107/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9521
# Epoch 108/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9521
# Epoch 109/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9521
# Epoch 110/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9521
# Epoch 111/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9521
# Epoch 112/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9521
# Epoch 113/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9521
# Epoch 114/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9521
# Epoch 115/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 116/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9508
# Epoch 117/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9508
# Epoch 118/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.7896e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9508
# Epoch 119/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9508
# Epoch 120/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9508
# Epoch 121/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.7801e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9521
# Epoch 122/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.8693e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9521
# Epoch 123/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 124/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 125/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 126/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.8226e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 127/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9508
# Epoch 128/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9508
# Epoch 129/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9521
# Epoch 130/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.7079e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9521
# Epoch 131/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9521
# Epoch 132/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9521
# Epoch 133/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.4697e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9534
# Epoch 134/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2641e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9521
# Epoch 135/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9534
# Epoch 136/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.8610e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9521
# Epoch 137/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.1196e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9534
# Epoch 138/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.8582e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9521
# Epoch 139/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.6487e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9508
# Epoch 140/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.5464e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9508
# Epoch 141/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9508
# Epoch 142/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.5731e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 143/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 144/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.6221e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9534
# Epoch 145/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.8187e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9508
# Epoch 146/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9534
# Epoch 147/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9521
# Epoch 148/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.6283e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9534
# Epoch 149/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.1012e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9534
# Epoch 150/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3339e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9521
# Epoch 151/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0012e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9508
# Epoch 152/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2932e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9521
# Epoch 153/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2817e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 154/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6682e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9521
# Epoch 155/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.9569e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9508
# Epoch 156/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6728e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9534
# Epoch 157/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6801e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9508
# Epoch 158/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1520e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 159/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3587e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9521
# Epoch 160/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.7638e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9534
# Epoch 161/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6912e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9534
# Epoch 162/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7739e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9521
# Epoch 163/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6880e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9521
# Epoch 164/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0151e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9534
# Epoch 165/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4850e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9534
# Epoch 166/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0817e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9534
# Epoch 167/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0891e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9495
# Epoch 168/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.1875e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 169/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3319e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 170/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9622e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9521
# Epoch 171/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0853e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9521
# Epoch 172/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2202e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9521
# Epoch 173/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1949e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9508
# Epoch 174/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2389e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9547
# Epoch 175/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5846e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9534
# Epoch 176/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4671e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9534
# Epoch 177/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.5594e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9508
# Epoch 178/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4203e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9495
# Epoch 179/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.8582e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9508
# Epoch 180/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.2440e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9521
# Epoch 181/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.6401e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 182/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 8.3956e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9521
# Epoch 183/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.5273e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9521
# Epoch 184/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.3768e-04 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9534
# Epoch 185/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 7.0631e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9534
# Epoch 186/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 6.6681e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9508
# Epoch 187/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.4899e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9495
# Epoch 188/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.4748e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9483
# Epoch 189/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.1107e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9521
# Epoch 190/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.1214e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9521
# Epoch 191/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 6.6220e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9547
# Epoch 192/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 6.7221e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9573
# Epoch 193/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.2363e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9521
# Epoch 194/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 6.7568e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9521
# Epoch 195/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 6.6388e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9521
# Epoch 196/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 7.0760e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9534
# Epoch 197/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 6.7769e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9547
# Epoch 198/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 6.8405e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9521
# Epoch 199/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 6.7008e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9521
# Epoch 200/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 6.0060e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9495
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.2108e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9521
# Epoch 202/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.1385e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9521
# Epoch 203/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.7569e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9508
# Epoch 204/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.2191e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9521
# Epoch 205/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.1581e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9534
# Epoch 206/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.8073e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9560
# Epoch 207/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.5515e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9534
# Epoch 208/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6112e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9547
# Epoch 209/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.0279e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9508
# Epoch 210/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.8483e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9508
# Epoch 211/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.7049e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9534
# Epoch 212/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.7340e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9547
# Epoch 213/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.1210e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9547
# Epoch 214/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.8826e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9560
# Epoch 215/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 6.4612e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9547
# Epoch 216/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.5260e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9534
# Epoch 217/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.2937e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9521
# Epoch 218/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.3986e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 219/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.3854e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9521
# Epoch 220/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.2289e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9483
# Epoch 221/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.0793e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9508
# Epoch 222/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.0154e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9495
# Epoch 223/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.5864e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9534
# Epoch 224/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.5808e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9521
# Epoch 225/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.1757e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9521
# Epoch 226/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.1128e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9495
# Epoch 227/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.3415e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9521
# Epoch 228/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.8199e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9534
# Epoch 229/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.8622e-04 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9495
# Epoch 230/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.0257e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9521
# Epoch 231/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.8510e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9508
# Epoch 232/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.0984e-04 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9521
# Epoch 233/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 5.2075e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9521
# Epoch 234/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.1576e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9534
# Epoch 235/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.8975e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9521
# Epoch 236/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.5201e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9521
# Epoch 237/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.5146e-04 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9495
# Epoch 238/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.4204e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9508
# Epoch 239/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 4.2084e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9508
# Epoch 240/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.8222e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9508
# Epoch 241/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2559e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9508
# Epoch 242/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.3279e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9521
# Epoch 243/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.9256e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9534
# Epoch 244/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.4980e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9521
# Epoch 245/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1432e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9495
# Epoch 246/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.1599e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9521
# Epoch 247/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0956e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9508
# Epoch 248/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.4755e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9534
# Epoch 249/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.7360e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9534
# Epoch 250/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2120e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9534
# Epoch 251/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.1810e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9547
# Epoch 252/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.8120e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9534
# Epoch 253/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 4.2026e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9534
# Epoch 254/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.9291e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9508
# Epoch 255/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.5961e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9521
# Epoch 256/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.9640e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9534
# Epoch 257/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.4559e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9521
# Epoch 258/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6997e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9534
# Epoch 259/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0813e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9547
# Epoch 260/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.7356e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9534
# Epoch 261/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.8505e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9521
# Epoch 262/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 3.9193e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9508
# Epoch 263/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.6257e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9521
# Epoch 264/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.8907e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 265/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.7530e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9560
# Epoch 266/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.6515e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9560
# Epoch 267/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.4701e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9534
# Epoch 268/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.3081e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9521
# Epoch 269/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5671e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9560
# Epoch 270/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7307e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9521
# Epoch 271/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6567e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9521
# Epoch 272/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.2065e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9560
# Epoch 273/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.5591e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9534
# Epoch 274/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2183e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9534
# Epoch 275/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2092e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9547
# Epoch 276/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2317e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9521
# Epoch 277/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.1349e-04 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9534
# Epoch 278/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.2702e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9534
# Epoch 279/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.1130e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 280/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.0491e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9534
# Epoch 281/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.2169e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9560
# Epoch 282/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.2485e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9560
# Epoch 283/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.9134e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9547
# Epoch 284/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.1915e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9534
# Epoch 285/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.1188e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9534
# Epoch 286/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.0007e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9534
# Epoch 287/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.9501e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9534
# Epoch 288/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.3249e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9534
# Epoch 289/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.0458e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9534
# Epoch 290/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2768e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9534
# Epoch 291/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.9509e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 292/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.8347e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 293/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.9245e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9508
# Epoch 294/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 3.1399e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9534
# Epoch 295/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.8403e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9534
# Epoch 296/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.7873e-04 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9521
# Epoch 297/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.7174e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9521
# Epoch 298/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.8728e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9521
# Epoch 299/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.6019e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9508
# Epoch 300/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.6849e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9508
# Epoch 301/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.5262e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9495
# Epoch 302/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.6112e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9495
# Epoch 303/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.5354e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9521
# Epoch 304/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.5113e-04 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9521
# Epoch 305/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.6217e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9534
# Epoch 306/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.5523e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9534
# Epoch 307/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.3945e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 308/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.4560e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9534
# Epoch 309/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.3994e-04 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9534
# Epoch 310/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.6469e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 311/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.5306e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9560
# Epoch 312/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.8563e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9560
# Epoch 313/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.3639e-04 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9534
# Epoch 314/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.4962e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9534
# Epoch 315/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.3678e-04 - accuracy: 1.0000 - val_loss: 0.1435 - val_accuracy: 0.9534
# Epoch 316/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.2500e-04 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9547
# Epoch 317/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.3721e-04 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9534
# Epoch 318/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 2.2908e-04 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9547
# Epoch 319/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.3293e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9547
# Epoch 320/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.3211e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9534
# Epoch 321/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7262e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9560
# Epoch 1898/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9373e-07 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9560
# Epoch 1899/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3070e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9560
# Epoch 1900/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9392e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 1901/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7907e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9560
# Epoch 1902/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1691e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9560
# Epoch 1903/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8281e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9560
# Epoch 1904/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7026e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9547
# Epoch 1905/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4187e-07 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9547
# Epoch 1906/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0151e-07 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9547
# Epoch 1907/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4619e-07 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9560
# Epoch 1908/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6723e-07 - accuracy: 1.0000 - val_loss: 0.2013 - val_accuracy: 0.9560
# Epoch 1909/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.9179e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9560
# Epoch 1910/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8529e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9547
# Epoch 1911/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8718e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9560
# Epoch 1912/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6617e-07 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9560
# Epoch 1913/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2982e-07 - accuracy: 1.0000 - val_loss: 0.2013 - val_accuracy: 0.9560
# Epoch 1914/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0390e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 1915/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5085e-07 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9560
# Epoch 1916/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3856e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9560
# Epoch 1917/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2331e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9560
# Epoch 1918/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1951e-07 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9547
# Epoch 1919/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4749e-07 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9547
# Epoch 1920/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1036e-07 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9560
# Epoch 1921/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9024e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9560
# Epoch 1922/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2770e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9560
# Epoch 1923/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8485e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9547
# Epoch 1924/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9833e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9547
# Epoch 1925/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1314e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9547
# Epoch 1926/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0667e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9547
# Epoch 1927/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3132e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9547
# Epoch 1928/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5847e-07 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9560
# Epoch 1929/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7901e-07 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9560
# Epoch 1930/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2296e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9560
# Epoch 1931/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6596e-07 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9560
# Epoch 1932/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7996e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 1933/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4909e-07 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9560
# Epoch 1934/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6410e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9560
# Epoch 1935/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9677e-07 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9560
# Epoch 1936/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8564e-07 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9560
# Epoch 1937/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0326e-07 - accuracy: 1.0000 - val_loss: 0.2018 - val_accuracy: 0.9560
# Epoch 1938/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.7732e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9560
# Epoch 1939/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4087e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9560
# Epoch 1940/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.6881e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9547
# Epoch 1941/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7532e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9547
# Epoch 1942/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9219e-07 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9547
# Epoch 1943/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6289e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9560
# Epoch 1944/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8501e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9560
# Epoch 1945/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.2768e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9560
# Epoch 1946/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8610e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9560
# Epoch 1947/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1857e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9560
# Epoch 1948/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3975e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9560
# Epoch 1949/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6761e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9560
# Epoch 1950/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0216e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9560
# Epoch 1951/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5640e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9560
# Epoch 1952/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6137e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9560
# Epoch 1953/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3428e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9560
# Epoch 1954/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0741e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9560
# Epoch 1955/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1052e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9560
# Epoch 1956/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8364e-07 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9560
# Epoch 1957/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8304e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9560
# Epoch 1958/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5350e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9560
# Epoch 1959/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4080e-07 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9547
# Epoch 1960/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0813e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9534
# Epoch 1961/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5566e-07 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9534
# Epoch 1962/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2323e-07 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9560
# Epoch 1963/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3448e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 1964/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9704e-07 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9560
# Epoch 1965/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.2424e-07 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9560
# Epoch 1966/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5587e-07 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9560
# Epoch 1967/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4306e-07 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9560
# Epoch 1968/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0875e-07 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9560
# Epoch 1969/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6861e-07 - accuracy: 1.0000 - val_loss: 0.2016 - val_accuracy: 0.9560
# Epoch 1970/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6295e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 1971/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4820e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9560
# Epoch 1972/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2077e-07 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.9573
# Epoch 1973/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1667e-07 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9547
# Epoch 1974/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9669e-07 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9547
# Epoch 1975/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4033e-07 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9547
# Epoch 1976/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9453e-07 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9547
# Epoch 1977/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2431e-07 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9547
# Epoch 1978/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6018e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9547
# Epoch 1979/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9469e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9547
# Epoch 1980/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9195e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9560
# Epoch 1981/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3059e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9560
# Epoch 1982/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5171e-07 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9560
# Epoch 1983/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6445e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9560
# Epoch 1984/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4495e-07 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9547
# Epoch 1985/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4439e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9560
# Epoch 1986/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2111e-07 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9560
# Epoch 1987/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5625e-07 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9560
# Epoch 1988/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6114e-07 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9547
# Epoch 1989/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8803e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9560
# Epoch 1990/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7767e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9560
# Epoch 1991/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9538e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9560
# Epoch 1992/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8808e-07 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9560
# Epoch 1993/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7501e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9560
# Epoch 1994/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4441e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9560
# Epoch 1995/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4643e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9560
# Epoch 1996/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7582e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9560
# Epoch 1997/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8635e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9560
# Epoch 1998/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7763e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9560
# Epoch 1999/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8799e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9560
# Epoch 2000/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1218e-07 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9560
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 347ms/step - loss: 0.9975 - accuracy: 0.8278
# test_indoor_ds_results:test loss, test acc: [0.9974706172943115, 0.8277592062950134]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 410ms/step - loss: 2.2322 - accuracy: 0.7360
# test_outdoor_ds_results:test loss, test acc: [2.232170343399048, 0.7359872460365295]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 197ms/step - loss: 2.2551 - accuracy: 0.7353
# test_belt_ds_results:test loss, test acc: [2.255121946334839, 0.7352674603462219]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR275-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6444 - accuracy: 0.8278
# 50/50 [==============================] - 7s 135ms/step - loss: 1.3916 - accuracy: 0.7299
# 35/35 [==============================] - 5s 136ms/step - loss: 1.4274 - accuracy: 0.7167
# Epoch200
#  test_indoor_acc=0.8277592062950134
#  test_outdoor_acc=0.7299363017082214
#  test_belt_acc=0.7166817784309387
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7192 - accuracy: 0.8272
# 50/50 [==============================] - 7s 137ms/step - loss: 1.5770 - accuracy: 0.7299
# 35/35 [==============================] - 5s 137ms/step - loss: 1.5891 - accuracy: 0.7235
# Epoch400
#  test_indoor_acc=0.827201783657074
#  test_outdoor_acc=0.7299363017082214
#  test_belt_acc=0.7234814167022705
# 29/29 [==============================] - 5s 135ms/step - loss: 0.7720 - accuracy: 0.8289
# 50/50 [==============================] - 7s 137ms/step - loss: 1.6979 - accuracy: 0.7360
# 35/35 [==============================] - 5s 138ms/step - loss: 1.7310 - accuracy: 0.7289
# Epoch600
#  test_indoor_acc=0.8288740515708923
#  test_outdoor_acc=0.7359872460365295
#  test_belt_acc=0.728921115398407
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8269 - accuracy: 0.8317
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8596 - accuracy: 0.7357
# 35/35 [==============================] - 5s 137ms/step - loss: 1.8746 - accuracy: 0.7276
# Epoch800
#  test_indoor_acc=0.8316611051559448
#  test_outdoor_acc=0.7356687784194946
#  test_belt_acc=0.7275611758232117
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8682 - accuracy: 0.8294
# 50/50 [==============================] - 7s 135ms/step - loss: 1.9617 - accuracy: 0.7338
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9841 - accuracy: 0.7303
# Epoch1000
#  test_indoor_acc=0.829431414604187
#  test_outdoor_acc=0.7337579727172852
#  test_belt_acc=0.7302810549736023
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8986 - accuracy: 0.8344
# 50/50 [==============================] - 7s 135ms/step - loss: 2.0550 - accuracy: 0.7354
# 35/35 [==============================] - 5s 136ms/step - loss: 2.0534 - accuracy: 0.7339
# Epoch1200
#  test_indoor_acc=0.8344481587409973
#  test_outdoor_acc=0.7353503108024597
#  test_belt_acc=0.7339075207710266
# 29/29 [==============================] - 5s 135ms/step - loss: 0.9345 - accuracy: 0.8305
# 50/50 [==============================] - 7s 137ms/step - loss: 2.1371 - accuracy: 0.7334
# 35/35 [==============================] - 5s 137ms/step - loss: 2.1321 - accuracy: 0.7303
# Epoch1400
#  test_indoor_acc=0.8305462598800659
#  test_outdoor_acc=0.7334395051002502
#  test_belt_acc=0.7302810549736023
# 29/29 [==============================] - 5s 136ms/step - loss: 0.9577 - accuracy: 0.8317
# 50/50 [==============================] - 7s 137ms/step - loss: 2.1624 - accuracy: 0.7354
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1837 - accuracy: 0.7312
# Epoch1600
#  test_indoor_acc=0.8316611051559448
#  test_outdoor_acc=0.7353503108024597
#  test_belt_acc=0.731187641620636
# 29/29 [==============================] - 5s 138ms/step - loss: 0.9819 - accuracy: 0.8311
# 50/50 [==============================] - 7s 139ms/step - loss: 2.2175 - accuracy: 0.7341
# 35/35 [==============================] - 5s 140ms/step - loss: 2.2185 - accuracy: 0.7321
# Epoch1800
#  test_indoor_acc=0.8311036825180054
#  test_outdoor_acc=0.7340764403343201
#  test_belt_acc=0.7320942878723145
# 29/29 [==============================] - 5s 135ms/step - loss: 0.9975 - accuracy: 0.8278
# 50/50 [==============================] - 7s 137ms/step - loss: 2.2322 - accuracy: 0.7360
# 35/35 [==============================] - 5s 138ms/step - loss: 2.2551 - accuracy: 0.7353
# Epoch2000
#  test_indoor_acc=0.8277592062950134
#  test_outdoor_acc=0.7359872460365295
#  test_belt_acc=0.7352674603462219

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7679019967714945
# max index -> 5
# The [Epoch] of max acc -> 1200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8277592062950134,
#  0.827201783657074,
#  0.8288740515708923,
#  0.8316611051559448,
#  0.829431414604187,
#  0.8344481587409973,
#  0.8305462598800659,
#  0.8316611051559448,
#  0.8311036825180054,
#  0.8277592062950134]

# %%
test_outdoor_acc
# Out:
# [0.7299363017082214,
#  0.7299363017082214,
#  0.7359872460365295,
#  0.7356687784194946,
#  0.7337579727172852,
#  0.7353503108024597,
#  0.7334395051002502,
#  0.7353503108024597,
#  0.7340764403343201,
#  0.7359872460365295]

# %%
test_belt_acc
# Out:
# [0.7166817784309387,
#  0.7234814167022705,
#  0.728921115398407,
#  0.7275611758232117,
#  0.7302810549736023,
#  0.7339075207710266,
#  0.7302810549736023,
#  0.731187641620636,
#  0.7320942878723145,
#  0.7352674603462219]

# %%
test_indoor_loss
# Out:
# [0.6444168090820312,
#  0.7192153930664062,
#  0.7719914317131042,
#  0.8269234895706177,
#  0.8682376146316528,
#  0.8986412286758423,
#  0.9344624876976013,
#  0.9576786160469055,
#  0.9818520545959473,
#  0.9974706172943115]

# %%
test_outdoor_loss
# Out:
# [1.391579270362854,
#  1.5770039558410645,
#  1.6979238986968994,
#  1.8595521450042725,
#  1.9617382287979126,
#  2.055049419403076,
#  2.1370716094970703,
#  2.162351131439209,
#  2.2174556255340576,
#  2.232170343399048]

# %%
test_belt_loss
# Out:
# [1.4274353981018066,
#  1.5890580415725708,
#  1.731048822402954,
#  1.8745708465576172,
#  1.9841111898422241,
#  2.053358554840088,
#  2.1321003437042236,
#  2.1836960315704346,
#  2.21854567527771,
#  2.255121946334839]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5425
# FP=1715
# acc=0.7598039215686274
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 75.86206896551724%
# 2WayConnectorforFoley acc = 85.71428571428571%
# 2WayFoleyCatheter acc = 76.11940298507463%
# 3WayConnectorforFoley acc = 88.03418803418803%
# 3Waystopcock acc = 97.2972972972973%
# AlcoholBottle acc = 83.75%
# AlcoholPad acc = 50.0%
# BootCover acc = 57.831325301204814%
# CottonBall acc = 84.4311377245509%
# CottonSwap acc = 81.81818181818183%
# Dilator acc = 62.39316239316239%
# DisposableInfusionSet acc = 44.24778761061947%
# ExtensionTube acc = 39.83739837398374%
# FaceShield acc = 72.22222222222221%
# FrontLoadSyringe acc = 36.283185840707965%
# GauzePad acc = 65.3409090909091%
# Glove acc = 72.91666666666666%
# GuideWire acc = 26.785714285714285%
# LiquidBottle acc = 66.03053435114504%
# Mask acc = 95.06493506493506%
# NGTube acc = 45.16129032258064%
# NasalCannula acc = 56.63716814159292%
# Needle acc = 87.14285714285714%
# OxygenMask acc = 97.74436090225564%
# PPESuit acc = 88.70967741935483%
# PharmaceuticalProduct acc = 60.747663551401864%
# Pill acc = 97.3389355742297%
# PillBottle acc = 79.84496124031007%
# PrefilledHumidifier acc = 84.61538461538461%
# PressureConnectingTube acc = 66.41221374045801%
# ReusableHumidifier acc = 84.7457627118644%
# SodiumChlorideBag acc = 90.5511811023622%
# SterileHumidifierAdapter acc = 85.45454545454545%
# SurgicalBlade acc = 86.72566371681415%
# SurgicalCap acc = 92.7927927927928%
# SurgicalSuit acc = 50.0%
# Syringe acc = 98.09885931558935%
# TrachealTube acc = 41.284403669724774%
# UrineBag acc = 71.66666666666667%
# Vaccinebottle acc = 85.91549295774648%
# WingedInfusionSet acc = 68.42105263157895%
#
#
#
# all_avg_eachclass = 72.73149603440187%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 88,   0,   0, ...,   0,   2,   0],
#        [  6, 126,   0, ...,   0,   0,   0],
#        [  0,   0, 102, ...,   0,   3,  13],
#        ...,
#        [  0,   0,   0, ...,  86,   0,   0],
#        [  0,   0,   0, ...,   0, 183,   1],
#        [  0,   0,   0, ...,   0,   0,  78]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[75.86206897,  0.        ,  0.        , ...,  0.        ,
#          1.72413793,  0.        ],
#        [ 4.08163265, 85.71428571,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 76.11940299, ...,  0.        ,
#          2.23880597,  9.70149254],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 71.66666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         85.91549296,  0.46948357],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 68.42105263]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
