# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.250),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 47s 336ms/step - loss: 1.4806 - accuracy: 0.6191 - val_loss: 0.6129 - val_accuracy: 0.8279
# Epoch 2/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.4521 - accuracy: 0.8569 - val_loss: 0.4128 - val_accuracy: 0.8693
# Epoch 3/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.2634 - accuracy: 0.9183 - val_loss: 0.3101 - val_accuracy: 0.9094
# Epoch 4/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1563 - accuracy: 0.9564 - val_loss: 0.3037 - val_accuracy: 0.9043
# Epoch 5/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.1150 - accuracy: 0.9696 - val_loss: 0.2877 - val_accuracy: 0.9056
# Epoch 6/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0793 - accuracy: 0.9826 - val_loss: 0.2403 - val_accuracy: 0.9224
# Epoch 7/2000
# 49/49 [==============================] - 9s 173ms/step - loss: 0.0553 - accuracy: 0.9906 - val_loss: 0.2352 - val_accuracy: 0.9288
# Epoch 8/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0504 - accuracy: 0.9900 - val_loss: 0.2112 - val_accuracy: 0.9418
# Epoch 9/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0407 - accuracy: 0.9910 - val_loss: 0.2103 - val_accuracy: 0.9379
# Epoch 10/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0343 - accuracy: 0.9929 - val_loss: 0.2358 - val_accuracy: 0.9250
# Epoch 11/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0319 - accuracy: 0.9942 - val_loss: 0.2133 - val_accuracy: 0.9276
# Epoch 12/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0231 - accuracy: 0.9964 - val_loss: 0.2052 - val_accuracy: 0.9366
# Epoch 13/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0175 - accuracy: 0.9984 - val_loss: 0.2208 - val_accuracy: 0.9301
# Epoch 14/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.1921 - val_accuracy: 0.9392
# Epoch 15/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9418
# Epoch 16/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.1803 - val_accuracy: 0.9431
# Epoch 17/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9392
# Epoch 18/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0064 - accuracy: 0.9997 - val_loss: 0.1571 - val_accuracy: 0.9560
# Epoch 19/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9405
# Epoch 20/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.1586 - val_accuracy: 0.9521
# Epoch 21/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 0.1659 - val_accuracy: 0.9495
# Epoch 22/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 0.1653 - val_accuracy: 0.9547
# Epoch 23/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.1726 - val_accuracy: 0.9470
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 24/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.9534
# Epoch 25/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9508
# Epoch 26/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9534
# Epoch 27/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9547
# Epoch 28/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9534
# Epoch 29/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9560
# Epoch 30/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9521
# Epoch 31/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9534
# Epoch 32/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9560
# Epoch 33/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9573
# Epoch 34/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9547
# Epoch 35/2000
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9521
# Epoch 36/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9534
# Epoch 37/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9521
# Epoch 38/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9586
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 39/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9547
# Epoch 40/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9560
# Epoch 41/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9560
# Epoch 42/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9547
# Epoch 43/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9547
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 44/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9534
# Epoch 45/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9534
# Epoch 46/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 47/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9534
# Epoch 48/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 49/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9521
# Epoch 50/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9508
# Epoch 51/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9508
# Epoch 52/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9508
# Epoch 53/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9508
# Epoch 54/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9508
# Epoch 55/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9521
# Epoch 56/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9508
# Epoch 57/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9534
# Epoch 58/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9521
# Epoch 59/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9521
# Epoch 60/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9521
# Epoch 61/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9534
# Epoch 62/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9521
# Epoch 63/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9521
# Epoch 64/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9534
# Epoch 65/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9534
# Epoch 66/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9547
# Epoch 67/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9521
# Epoch 68/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9521
# Epoch 69/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9521
# Epoch 70/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9521
# Epoch 71/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9534
# Epoch 72/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9521
# Epoch 73/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9521
# Epoch 74/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 75/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9521
# Epoch 76/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9521
# Epoch 77/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9508
# Epoch 78/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9508
# Epoch 79/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9508
# Epoch 80/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9521
# Epoch 81/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9521
# Epoch 82/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9508
# Epoch 83/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9508
# Epoch 84/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9508
# Epoch 85/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9521
# Epoch 86/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9521
# Epoch 87/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9521
# Epoch 88/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9521
# Epoch 89/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9521
# Epoch 90/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9521
# Epoch 91/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9521
# Epoch 92/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9521
# Epoch 93/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9521
# Epoch 94/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9521
# Epoch 95/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9521
# Epoch 96/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9521
# Epoch 97/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9521
# Epoch 98/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9508
# Epoch 99/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9495
# Epoch 100/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9521
# Epoch 101/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9521
# Epoch 102/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9521
# Epoch 103/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9521
# Epoch 104/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 105/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9521
# Epoch 106/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9521
# Epoch 107/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9521
# Epoch 108/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9521
# Epoch 109/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9534
# Epoch 110/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9521
# Epoch 111/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9534
# Epoch 112/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9508
# Epoch 113/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9534
# Epoch 114/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9521
# Epoch 115/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9534
# Epoch 116/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9534
# Epoch 117/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9521
# Epoch 118/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.9508
# Epoch 119/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 120/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9495
# Epoch 121/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9483
# Epoch 122/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9495
# Epoch 123/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9534
# Epoch 124/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9521
# Epoch 125/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9508
# Epoch 126/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9508
# Epoch 127/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9521
# Epoch 128/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9521
# Epoch 129/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9521
# Epoch 130/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9508
# Epoch 131/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9534
# Epoch 132/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9534
# Epoch 133/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9521
# Epoch 134/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9521
# Epoch 135/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9534
# Epoch 136/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9547
# Epoch 137/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9547
# Epoch 138/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9534
# Epoch 139/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 140/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9521
# Epoch 141/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9521
# Epoch 142/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9521
# Epoch 143/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9508
# Epoch 144/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9508
# Epoch 145/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 146/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 147/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9508
# Epoch 148/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9521
# Epoch 149/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9547
# Epoch 150/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9521
# Epoch 151/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9521
# Epoch 152/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9508
# Epoch 153/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9508
# Epoch 154/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9508
# Epoch 155/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9521
# Epoch 156/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9521
# Epoch 157/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9508
# Epoch 158/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.6279e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9508
# Epoch 159/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9495
# Epoch 160/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9521
# Epoch 161/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.5101e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9521
# Epoch 162/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.9011e-04 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9495
# Epoch 163/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.3889e-04 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9508
# Epoch 164/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.0803e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9508
# Epoch 165/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.9385e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9521
# Epoch 166/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.1199e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9534
# Epoch 167/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.3883e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 168/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.6547e-04 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9521
# Epoch 169/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.0623e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9521
# Epoch 170/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.5188e-04 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.9508
# Epoch 171/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.9602e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9495
# Epoch 172/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.0576e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9521
# Epoch 173/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 9.0482e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 174/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.2309e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9495
# Epoch 175/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.7811e-04 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9495
# Epoch 176/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.4783e-04 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9508
# Epoch 177/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.3078e-04 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9521
# Epoch 178/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.4980e-04 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9521
# Epoch 179/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.2189e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9521
# Epoch 180/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.4344e-04 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9521
# Epoch 181/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.1903e-04 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9521
# Epoch 182/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.4126e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9521
# Epoch 183/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.4020e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9521
# Epoch 184/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.0257e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9521
# Epoch 185/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.8313e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9508
# Epoch 186/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.8725e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 187/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.5945e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9521
# Epoch 188/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 8.5613e-04 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9508
# Epoch 189/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.5946e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 190/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.8606e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9534
# Epoch 191/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.1953e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9521
# Epoch 192/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.5154e-04 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9534
# Epoch 193/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.5360e-04 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9521
# Epoch 194/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.8952e-04 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9521
# Epoch 195/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.9676e-04 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9521
# Epoch 196/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.7674e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9508
# Epoch 197/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.2921e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9495
# Epoch 198/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.3790e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9521
# Epoch 199/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.1348e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9521
# Epoch 200/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.8380e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9534
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9182e-04 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9508
# Epoch 202/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.2108e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9521
# Epoch 203/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5066e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9508
# Epoch 204/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4513e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9521
# Epoch 205/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0073e-04 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9508
# Epoch 206/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 6.8356e-04 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9547
# Epoch 207/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 7.0461e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9521
# Epoch 208/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6608e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9508
# Epoch 209/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9864e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 210/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 6.4503e-04 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9495
# Epoch 211/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7649e-04 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9508
# Epoch 212/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 6.3925e-04 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9495
# Epoch 213/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 6.5796e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9508
# Epoch 214/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 6.2608e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9521
# Epoch 215/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2351e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9534
# Epoch 216/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1726e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9521
# Epoch 217/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7683e-04 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9534
# Epoch 218/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5263e-04 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9534
# Epoch 219/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6707e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 220/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4579e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9521
# Epoch 221/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0003e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9521
# Epoch 222/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2874e-04 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9534
# Epoch 223/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2559e-04 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9534
# Epoch 224/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0743e-04 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9534
# Epoch 225/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.6845e-04 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9547
# Epoch 226/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8004e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9547
# Epoch 227/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7088e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9534
# Epoch 228/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.0994e-04 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9547
# Epoch 229/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.4004e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9547
# Epoch 230/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.6775e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 231/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0080e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9547
# Epoch 232/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9267e-04 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9547
# Epoch 233/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5857e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9521
# Epoch 234/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2993e-04 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9521
# Epoch 235/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0073e-04 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9521
# Epoch 236/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2451e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9495
# Epoch 237/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8106e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9508
# Epoch 238/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1735e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9534
# Epoch 239/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9643e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9534
# Epoch 240/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7777e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9534
# Epoch 241/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1535e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9521
# Epoch 242/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0253e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9521
# Epoch 243/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2899e-04 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9521
# Epoch 244/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.1530e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9521
# Epoch 245/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3623e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9521
# Epoch 246/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0323e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9508
# Epoch 247/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8445e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9495
# Epoch 248/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2350e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9495
# Epoch 249/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7367e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9495
# Epoch 250/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6260e-04 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9521
# Epoch 251/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6184e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9521
# Epoch 252/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4904e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9508
# Epoch 253/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3272e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9521
# Epoch 254/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1748e-04 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9508
# Epoch 255/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.2543e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9521
# Epoch 256/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4271e-04 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9508
# Epoch 257/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4386e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9521
# Epoch 258/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4256e-04 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9521
# Epoch 259/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6203e-04 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9521
# Epoch 260/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.3306e-04 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9521
# Epoch 261/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2355e-04 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9521
# Epoch 262/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.5172e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9534
# Epoch 263/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0564e-04 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9521
# Epoch 264/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2346e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9508
# Epoch 265/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.7018e-04 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9508
# Epoch 266/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.1176e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9508
# Epoch 267/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9396e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9534
# Epoch 268/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2378e-04 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9521
# Epoch 269/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0594e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9521
# Epoch 270/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.0426e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9534
# Epoch 271/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8647e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9534
# Epoch 272/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1876e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9521
# Epoch 273/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4637e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9521
# Epoch 274/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0818e-04 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9521
# Epoch 275/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7338e-04 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9534
# Epoch 276/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9440e-04 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9534
# Epoch 277/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5441e-04 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9534
# Epoch 278/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.6508e-04 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9534
# Epoch 279/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.5657e-04 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9521
# Epoch 280/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0586e-04 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.9521
# Epoch 281/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0070e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9534
# Epoch 282/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6120e-04 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9508
# Epoch 283/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2250e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9534
# Epoch 284/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8046e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9560
# Epoch 285/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4453e-04 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9508
# Epoch 286/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4078e-04 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9534
# Epoch 287/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4394e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9534
# Epoch 288/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4445e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9534
# Epoch 289/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5498e-04 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9521
# Epoch 290/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3576e-04 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9508
# Epoch 291/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5872e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9495
# Epoch 292/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6750e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9534
# Epoch 293/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8107e-04 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9521
# Epoch 294/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2579e-04 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9508
# Epoch 295/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6400e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9508
# Epoch 296/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.3433e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9495
# Epoch 297/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0355e-04 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9495
# Epoch 298/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2223e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9495
# Epoch 299/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0382e-04 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9521
# Epoch 300/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4305e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9534
# Epoch 301/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0004e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9534
# Epoch 302/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1725e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9534
# Epoch 303/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1046e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9534
# Epoch 304/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8031e-04 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9495
# Epoch 305/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0319e-04 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.9521
# Epoch 306/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3169e-04 - accuracy: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.9521
# Epoch 307/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7532e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9521
# Epoch 308/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9066e-04 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9508
# Epoch 309/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9051e-04 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9508
# Epoch 310/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9886e-04 - accuracy: 1.0000 - val_loss: 0.1604 - val_accuracy: 0.9495
# Epoch 311/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8011e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9508
# Epoch 312/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0444e-04 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9508
# Epoch 313/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7965e-04 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9508
# Epoch 314/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0063e-04 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.9521
# Epoch 315/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0678e-04 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9534
# Epoch 316/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6038e-04 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.9521
# Epoch 317/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7231e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9534
# Epoch 318/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6989e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9521
# Epoch 319/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8358e-04 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9521
# Epoch 320/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4236e-04 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9521
# Epoch 321/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7842e-07 - accuracy: 1.0000 - val_loss: 0.2150 - val_accuracy: 0.9547
# Epoch 1898/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8936e-07 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9547
# Epoch 1899/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4919e-07 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9560
# Epoch 1900/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1738e-07 - accuracy: 1.0000 - val_loss: 0.2153 - val_accuracy: 0.9534
# Epoch 1901/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1803e-07 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.9521
# Epoch 1902/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3174e-07 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9534
# Epoch 1903/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8248e-07 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9547
# Epoch 1904/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3367e-07 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9547
# Epoch 1905/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0393e-07 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9547
# Epoch 1906/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0871e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9547
# Epoch 1907/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6903e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9547
# Epoch 1908/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2136e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9547
# Epoch 1909/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4719e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9547
# Epoch 1910/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4810e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9547
# Epoch 1911/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9723e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9560
# Epoch 1912/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9380e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9547
# Epoch 1913/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9576e-07 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9547
# Epoch 1914/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8783e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9547
# Epoch 1915/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4376e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9547
# Epoch 1916/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2130e-07 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9547
# Epoch 1917/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1857e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9560
# Epoch 1918/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6829e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9560
# Epoch 1919/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4507e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9560
# Epoch 1920/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4056e-07 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9560
# Epoch 1921/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8851e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9560
# Epoch 1922/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8041e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9560
# Epoch 1923/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8225e-07 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9560
# Epoch 1924/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0654e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9560
# Epoch 1925/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8167e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9560
# Epoch 1926/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1341e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9560
# Epoch 1927/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6271e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9560
# Epoch 1928/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4407e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9560
# Epoch 1929/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4457e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9560
# Epoch 1930/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0143e-07 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9560
# Epoch 1931/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.9119e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9560
# Epoch 1932/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9331e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9560
# Epoch 1933/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0763e-07 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9560
# Epoch 1934/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6141e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9560
# Epoch 1935/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9806e-07 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9560
# Epoch 1936/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2627e-07 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9560
# Epoch 1937/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5739e-07 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9560
# Epoch 1938/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9003e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9547
# Epoch 1939/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0946e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9560
# Epoch 1940/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8333e-07 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9547
# Epoch 1941/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2086e-07 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.9521
# Epoch 1942/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9843e-07 - accuracy: 1.0000 - val_loss: 0.2163 - val_accuracy: 0.9521
# Epoch 1943/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8590e-07 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9547
# Epoch 1944/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9348e-07 - accuracy: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.9547
# Epoch 1945/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0297e-07 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9547
# Epoch 1946/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0555e-07 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9547
# Epoch 1947/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1010e-07 - accuracy: 1.0000 - val_loss: 0.2137 - val_accuracy: 0.9534
# Epoch 1948/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6248e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9534
# Epoch 1949/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8934e-07 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9534
# Epoch 1950/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8304e-07 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9547
# Epoch 1951/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1287e-07 - accuracy: 1.0000 - val_loss: 0.2138 - val_accuracy: 0.9547
# Epoch 1952/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6810e-07 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9534
# Epoch 1953/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9361e-07 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9534
# Epoch 1954/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4441e-07 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9547
# Epoch 1955/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8452e-07 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9547
# Epoch 1956/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0908e-07 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9534
# Epoch 1957/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2947e-07 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9534
# Epoch 1958/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7874e-07 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9534
# Epoch 1959/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0249e-07 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9521
# Epoch 1960/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3517e-07 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9534
# Epoch 1961/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0359e-07 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9534
# Epoch 1962/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0936e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9534
# Epoch 1963/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0078e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9534
# Epoch 1964/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1780e-07 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9547
# Epoch 1965/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1584e-07 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9547
# Epoch 1966/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3706e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9547
# Epoch 1967/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4661e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9547
# Epoch 1968/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8506e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9547
# Epoch 1969/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4034e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9547
# Epoch 1970/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2196e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9534
# Epoch 1971/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2234e-07 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9534
# Epoch 1972/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3798e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9534
# Epoch 1973/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7570e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9534
# Epoch 1974/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1233e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9534
# Epoch 1975/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3301e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9547
# Epoch 1976/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9024e-07 - accuracy: 1.0000 - val_loss: 0.2128 - val_accuracy: 0.9521
# Epoch 1977/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2017e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9547
# Epoch 1978/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0293e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9560
# Epoch 1979/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0158e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9560
# Epoch 1980/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8683e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9547
# Epoch 1981/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9900e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9547
# Epoch 1982/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0771e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9534
# Epoch 1983/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3617e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9534
# Epoch 1984/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7639e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9547
# Epoch 1985/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3101e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9547
# Epoch 1986/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0979e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9534
# Epoch 1987/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0112e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9534
# Epoch 1988/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.8789e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9534
# Epoch 1989/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.5772e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9547
# Epoch 1990/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2275e-07 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9547
# Epoch 1991/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5042e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9560
# Epoch 1992/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0262e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9560
# Epoch 1993/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1403e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9560
# Epoch 1994/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4703e-07 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9560
# Epoch 1995/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6942e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9560
# Epoch 1996/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4669e-07 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9560
# Epoch 1997/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7004e-07 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9560
# Epoch 1998/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8460e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9560
# Epoch 1999/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5731e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9560
# Epoch 2000/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6703e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9560
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 348ms/step - loss: 0.8969 - accuracy: 0.8384
# test_indoor_ds_results:test loss, test acc: [0.8969098329544067, 0.8383500576019287]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 27s 453ms/step - loss: 2.3100 - accuracy: 0.7344
# test_outdoor_ds_results:test loss, test acc: [2.3100147247314453, 0.734394907951355]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 9s 201ms/step - loss: 2.2579 - accuracy: 0.7375
# test_belt_ds_results:test loss, test acc: [2.2578635215759277, 0.7375339865684509]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR250-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 137ms/step - loss: 0.5922 - accuracy: 0.8328
# 50/50 [==============================] - 7s 137ms/step - loss: 1.4197 - accuracy: 0.7299
# 35/35 [==============================] - 5s 137ms/step - loss: 1.4091 - accuracy: 0.7276
# Epoch200
#  test_indoor_acc=0.832775890827179
#  test_outdoor_acc=0.7299363017082214
#  test_belt_acc=0.7275611758232117
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6455 - accuracy: 0.8350
# 50/50 [==============================] - 7s 137ms/step - loss: 1.5641 - accuracy: 0.7373
# 35/35 [==============================] - 5s 138ms/step - loss: 1.5705 - accuracy: 0.7289
# Epoch400
#  test_indoor_acc=0.8350055813789368
#  test_outdoor_acc=0.737261176109314
#  test_belt_acc=0.728921115398407
# 29/29 [==============================] - 5s 138ms/step - loss: 0.6956 - accuracy: 0.8372
# 50/50 [==============================] - 7s 140ms/step - loss: 1.7278 - accuracy: 0.7379
# 35/35 [==============================] - 5s 140ms/step - loss: 1.7087 - accuracy: 0.7330
# Epoch600
#  test_indoor_acc=0.8372352123260498
#  test_outdoor_acc=0.7378981113433838
#  test_belt_acc=0.7330009341239929
# 29/29 [==============================] - 5s 135ms/step - loss: 0.7453 - accuracy: 0.8372
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8849 - accuracy: 0.7347
# 35/35 [==============================] - 5s 137ms/step - loss: 1.8795 - accuracy: 0.7335
# Epoch800
#  test_indoor_acc=0.8372352123260498
#  test_outdoor_acc=0.7347133755683899
#  test_belt_acc=0.7334542274475098
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8007 - accuracy: 0.8322
# 50/50 [==============================] - 7s 138ms/step - loss: 2.0115 - accuracy: 0.7338
# 35/35 [==============================] - 5s 139ms/step - loss: 1.9927 - accuracy: 0.7325
# Epoch1000
#  test_indoor_acc=0.8322185277938843
#  test_outdoor_acc=0.7337579727172852
#  test_belt_acc=0.7325475811958313
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8136 - accuracy: 0.8395
# 50/50 [==============================] - 7s 137ms/step - loss: 2.0657 - accuracy: 0.7366
# 35/35 [==============================] - 5s 137ms/step - loss: 2.0558 - accuracy: 0.7357
# Epoch1200
#  test_indoor_acc=0.8394649028778076
#  test_outdoor_acc=0.7366241812705994
#  test_belt_acc=0.7357207536697388
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8478 - accuracy: 0.8389
# 50/50 [==============================] - 7s 138ms/step - loss: 2.1535 - accuracy: 0.7363
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1242 - accuracy: 0.7371
# Epoch1400
#  test_indoor_acc=0.8389074802398682
#  test_outdoor_acc=0.7363057136535645
#  test_belt_acc=0.7370806932449341
# 29/29 [==============================] - 5s 138ms/step - loss: 0.8746 - accuracy: 0.8384
# 50/50 [==============================] - 7s 139ms/step - loss: 2.2071 - accuracy: 0.7376
# 35/35 [==============================] - 5s 140ms/step - loss: 2.1864 - accuracy: 0.7353
# Epoch1600
#  test_indoor_acc=0.8383500576019287
#  test_outdoor_acc=0.7375796437263489
#  test_belt_acc=0.7352674603462219
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8869 - accuracy: 0.8406
# 50/50 [==============================] - 7s 136ms/step - loss: 2.2666 - accuracy: 0.7334
# 35/35 [==============================] - 5s 138ms/step - loss: 2.2299 - accuracy: 0.7353
# Epoch1800
#  test_indoor_acc=0.8405796885490417
#  test_outdoor_acc=0.7334395051002502
#  test_belt_acc=0.7352674603462219
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8969 - accuracy: 0.8384
# 50/50 [==============================] - 7s 139ms/step - loss: 2.3100 - accuracy: 0.7344
# 35/35 [==============================] - 5s 140ms/step - loss: 2.2579 - accuracy: 0.7375
# Epoch2000
#  test_indoor_acc=0.8383500576019287
#  test_outdoor_acc=0.734394907951355
#  test_belt_acc=0.7375339865684509

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7707646290461222
# max index -> 6
# The [Epoch] of max acc -> 1400

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.832775890827179,
#  0.8350055813789368,
#  0.8372352123260498,
#  0.8372352123260498,
#  0.8322185277938843,
#  0.8394649028778076,
#  0.8389074802398682,
#  0.8383500576019287,
#  0.8405796885490417,
#  0.8383500576019287]

# %%
test_outdoor_acc
# Out:
# [0.7299363017082214,
#  0.737261176109314,
#  0.7378981113433838,
#  0.7347133755683899,
#  0.7337579727172852,
#  0.7366241812705994,
#  0.7363057136535645,
#  0.7375796437263489,
#  0.7334395051002502,
#  0.734394907951355]

# %%
test_belt_acc
# Out:
# [0.7275611758232117,
#  0.728921115398407,
#  0.7330009341239929,
#  0.7334542274475098,
#  0.7325475811958313,
#  0.7357207536697388,
#  0.7370806932449341,
#  0.7352674603462219,
#  0.7352674603462219,
#  0.7375339865684509]

# %%
test_indoor_loss
# Out:
# [0.5921880006790161,
#  0.6454941630363464,
#  0.6955859065055847,
#  0.7453132271766663,
#  0.8007322549819946,
#  0.813585638999939,
#  0.8477686047554016,
#  0.8745632171630859,
#  0.8869464993476868,
#  0.8969098329544067]

# %%
test_outdoor_loss
# Out:
# [1.419700264930725,
#  1.5640993118286133,
#  1.7278180122375488,
#  1.8849457502365112,
#  2.0114521980285645,
#  2.0656509399414062,
#  2.1535043716430664,
#  2.207082509994507,
#  2.2666213512420654,
#  2.3100147247314453]

# %%
test_belt_loss
# Out:
# [1.4091054201126099,
#  1.570480227470398,
#  1.7086682319641113,
#  1.8795355558395386,
#  1.9927072525024414,
#  2.0557827949523926,
#  2.1242055892944336,
#  2.1864449977874756,
#  2.2298738956451416,
#  2.2578635215759277]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5443
# FP=1697
# acc=0.7623249299719888
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 73.27586206896551%
# 2WayConnectorforFoley acc = 90.47619047619048%
# 2WayFoleyCatheter acc = 69.40298507462687%
# 3WayConnectorforFoley acc = 83.76068376068376%
# 3Waystopcock acc = 97.2972972972973%
# AlcoholBottle acc = 90.0%
# AlcoholPad acc = 56.34920634920635%
# BootCover acc = 59.63855421686747%
# CottonBall acc = 91.01796407185628%
# CottonSwap acc = 82.51748251748252%
# Dilator acc = 70.08547008547008%
# DisposableInfusionSet acc = 42.47787610619469%
# ExtensionTube acc = 33.33333333333333%
# FaceShield acc = 77.1604938271605%
# FrontLoadSyringe acc = 51.32743362831859%
# GauzePad acc = 57.95454545454546%
# Glove acc = 69.94047619047619%
# GuideWire acc = 33.035714285714285%
# LiquidBottle acc = 64.50381679389314%
# Mask acc = 94.28571428571428%
# NGTube acc = 44.516129032258064%
# NasalCannula acc = 54.86725663716814%
# Needle acc = 85.35714285714285%
# OxygenMask acc = 94.73684210526315%
# PPESuit acc = 92.74193548387096%
# PharmaceuticalProduct acc = 67.5233644859813%
# Pill acc = 97.05882352941177%
# PillBottle acc = 71.31782945736434%
# PrefilledHumidifier acc = 82.90598290598291%
# PressureConnectingTube acc = 71.7557251908397%
# ReusableHumidifier acc = 83.89830508474576%
# SodiumChlorideBag acc = 87.4015748031496%
# SterileHumidifierAdapter acc = 81.81818181818183%
# SurgicalBlade acc = 88.49557522123894%
# SurgicalCap acc = 90.09009009009009%
# SurgicalSuit acc = 51.515151515151516%
# Syringe acc = 97.71863117870723%
# TrachealTube acc = 55.04587155963303%
# UrineBag acc = 69.16666666666667%
# Vaccinebottle acc = 76.99530516431925%
# WingedInfusionSet acc = 64.91228070175438%
#
#
#
# all_avg_eachclass = 73.11414061738826%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 85,   0,   0, ...,   0,   4,   0],
#        [  1, 133,   0, ...,   0,   0,   0],
#        [  0,   0,  93, ...,   0,   1,  19],
#        ...,
#        [  0,   0,   0, ...,  83,   0,   0],
#        [  0,   0,   0, ...,   1, 164,   0],
#        [  0,   0,   0, ...,   0,   3,  74]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[73.27586207,  0.        ,  0.        , ...,  0.        ,
#          3.44827586,  0.        ],
#        [ 0.68027211, 90.47619048,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 69.40298507, ...,  0.        ,
#          0.74626866, 14.17910448],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 69.16666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.46948357,
#         76.99530516,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          2.63157895, 64.9122807 ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
