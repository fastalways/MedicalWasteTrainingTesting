# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.175),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 328ms/step - loss: 1.7315 - accuracy: 0.5680 - val_loss: 0.7533 - val_accuracy: 0.8266
# Epoch 2/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.5057 - accuracy: 0.8501 - val_loss: 0.4566 - val_accuracy: 0.8655
# Epoch 3/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.2852 - accuracy: 0.9234 - val_loss: 0.3750 - val_accuracy: 0.8887
# Epoch 4/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.1893 - accuracy: 0.9551 - val_loss: 0.2769 - val_accuracy: 0.9198
# Epoch 5/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.1201 - accuracy: 0.9703 - val_loss: 0.2509 - val_accuracy: 0.9237
# Epoch 6/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0846 - accuracy: 0.9826 - val_loss: 0.2192 - val_accuracy: 0.9353
# Epoch 7/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0590 - accuracy: 0.9893 - val_loss: 0.2184 - val_accuracy: 0.9263
# Epoch 8/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0453 - accuracy: 0.9935 - val_loss: 0.2072 - val_accuracy: 0.9392
# Epoch 9/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0384 - accuracy: 0.9952 - val_loss: 0.2084 - val_accuracy: 0.9353
# Epoch 10/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0328 - accuracy: 0.9939 - val_loss: 0.1885 - val_accuracy: 0.9405
# Epoch 11/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0260 - accuracy: 0.9964 - val_loss: 0.2565 - val_accuracy: 0.9107
# Epoch 12/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0249 - accuracy: 0.9964 - val_loss: 0.2074 - val_accuracy: 0.9288
# Epoch 13/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0145 - accuracy: 0.9994 - val_loss: 0.2046 - val_accuracy: 0.9353
# Epoch 14/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0147 - accuracy: 0.9981 - val_loss: 0.2008 - val_accuracy: 0.9392
# Epoch 15/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0114 - accuracy: 0.9994 - val_loss: 0.1723 - val_accuracy: 0.9483
# Epoch 16/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0098 - accuracy: 0.9997 - val_loss: 0.1786 - val_accuracy: 0.9392
# Epoch 17/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0095 - accuracy: 0.9994 - val_loss: 0.1630 - val_accuracy: 0.9495
# Epoch 18/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.1558 - val_accuracy: 0.9534
# Epoch 19/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0065 - accuracy: 0.9997 - val_loss: 0.1625 - val_accuracy: 0.9495
# Epoch 20/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.1479 - val_accuracy: 0.9586
# Epoch 21/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.1529 - val_accuracy: 0.9495
# Epoch 22/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0068 - accuracy: 0.9990 - val_loss: 0.1639 - val_accuracy: 0.9534
# Epoch 23/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9573
# Epoch 24/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9612
# Epoch 25/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9586
# Epoch 26/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9612
# Epoch 27/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.1446 - val_accuracy: 0.9586
# Epoch 28/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9560
# Epoch 29/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9547
# Epoch 30/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9560
# Epoch 31/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 32/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9495
# Epoch 33/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9599
# Epoch 34/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9534
# Epoch 35/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9586
# Epoch 36/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9573
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 37/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9560
# Epoch 38/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9560
# Epoch 39/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9560
# Epoch 40/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9560
# Epoch 41/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9547
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 42/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9547
# Epoch 43/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 44/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9547
# Epoch 45/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9560
# Epoch 46/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9560
# Epoch 47/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9547
# Epoch 48/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 49/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 50/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9560
# Epoch 51/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9560
# Epoch 52/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9560
# Epoch 53/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9547
# Epoch 54/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 55/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9547
# Epoch 56/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9560
# Epoch 57/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9560
# Epoch 58/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9547
# Epoch 59/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9547
# Epoch 60/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9547
# Epoch 61/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9547
# Epoch 62/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9547
# Epoch 63/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 64/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 65/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 66/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 67/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 68/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 69/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9547
# Epoch 70/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9547
# Epoch 71/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 72/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9547
# Epoch 73/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 74/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9547
# Epoch 75/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 76/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9547
# Epoch 77/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9547
# Epoch 78/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9547
# Epoch 79/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9547
# Epoch 80/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9547
# Epoch 81/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9547
# Epoch 82/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9547
# Epoch 83/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 84/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9547
# Epoch 85/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 86/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 87/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9547
# Epoch 88/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9547
# Epoch 89/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9547
# Epoch 90/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9560
# Epoch 91/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9560
# Epoch 92/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9547
# Epoch 93/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9547
# Epoch 94/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9547
# Epoch 95/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9547
# Epoch 96/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9547
# Epoch 97/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9547
# Epoch 98/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9547
# Epoch 99/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9547
# Epoch 100/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9547
# Epoch 101/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9560
# Epoch 102/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 103/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9547
# Epoch 104/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9547
# Epoch 105/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9547
# Epoch 106/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9547
# Epoch 107/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 108/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9586
# Epoch 109/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 110/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9547
# Epoch 111/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9534
# Epoch 112/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9534
# Epoch 113/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9547
# Epoch 114/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9547
# Epoch 115/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9547
# Epoch 116/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9534
# Epoch 117/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9547
# Epoch 118/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.9883e-04 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9547
# Epoch 119/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9560
# Epoch 120/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9534
# Epoch 121/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9521
# Epoch 122/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9521
# Epoch 123/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9534
# Epoch 124/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9534
# Epoch 125/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9534
# Epoch 126/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9560
# Epoch 127/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9560
# Epoch 128/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.8571e-04 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9560
# Epoch 129/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9560
# Epoch 130/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.7180e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9547
# Epoch 131/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9547
# Epoch 132/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9534
# Epoch 133/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9534
# Epoch 134/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9534
# Epoch 135/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9547
# Epoch 136/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9560
# Epoch 137/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9560
# Epoch 138/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.5843e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9547
# Epoch 139/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.9623e-04 - accuracy: 1.0000 - val_loss: 0.1435 - val_accuracy: 0.9560
# Epoch 140/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9547
# Epoch 141/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9547
# Epoch 142/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1426 - val_accuracy: 0.9573
# Epoch 143/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9547
# Epoch 144/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9547
# Epoch 145/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.5671e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9534
# Epoch 146/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.3201e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9547
# Epoch 147/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.7916e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9547
# Epoch 148/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9547
# Epoch 149/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9560
# Epoch 150/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.1173e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9573
# Epoch 151/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.2560e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9547
# Epoch 152/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.3559e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9560
# Epoch 153/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.7433e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9534
# Epoch 154/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4894e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9547
# Epoch 155/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.9762e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9547
# Epoch 156/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.7297e-04 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9547
# Epoch 157/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.8862e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9534
# Epoch 158/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.5427e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9534
# Epoch 159/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.0026e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9560
# Epoch 160/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.9743e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9547
# Epoch 161/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3262e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9534
# Epoch 162/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.9389e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 163/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.9524e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9521
# Epoch 164/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.6823e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 165/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3681e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9547
# Epoch 166/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 9.1960e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9560
# Epoch 167/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2246e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9586
# Epoch 168/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.1695e-04 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9586
# Epoch 169/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.4632e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9534
# Epoch 170/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.4591e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9560
# Epoch 171/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.7887e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9521
# Epoch 172/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.8710e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9560
# Epoch 173/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.8687e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9547
# Epoch 174/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.7616e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9534
# Epoch 175/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9862e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9534
# Epoch 176/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.8581e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9521
# Epoch 177/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.4058e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9560
# Epoch 178/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.3923e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9547
# Epoch 179/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.0312e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9534
# Epoch 180/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.1599e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9573
# Epoch 181/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.6461e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9560
# Epoch 182/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.8816e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9521
# Epoch 183/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.9836e-04 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9573
# Epoch 184/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1666e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9573
# Epoch 185/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.5483e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9586
# Epoch 186/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.6875e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9547
# Epoch 187/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.3662e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9573
# Epoch 188/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.4125e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9560
# Epoch 189/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5556e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9547
# Epoch 190/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.7527e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9534
# Epoch 191/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.6278e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9534
# Epoch 192/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.9629e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 193/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.8943e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9573
# Epoch 194/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.0599e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9573
# Epoch 195/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4430e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9586
# Epoch 196/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.0345e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 197/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0146e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9573
# Epoch 198/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.6826e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9521
# Epoch 199/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.3461e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9508
# Epoch 200/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.8996e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9495
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.7521e-04 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9586
# Epoch 202/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.6664e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9521
# Epoch 203/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.8238e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9573
# Epoch 204/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.9360e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9573
# Epoch 205/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.1254e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9547
# Epoch 206/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.0528e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9534
# Epoch 207/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.6224e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9534
# Epoch 208/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.4360e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9547
# Epoch 209/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.0968e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9534
# Epoch 210/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.6369e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9534
# Epoch 211/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.5143e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9534
# Epoch 212/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.5595e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9547
# Epoch 213/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.8078e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9560
# Epoch 214/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9153e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9560
# Epoch 215/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.0775e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9547
# Epoch 216/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.5842e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 217/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.7808e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9560
# Epoch 218/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.3691e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9547
# Epoch 219/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.9162e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9560
# Epoch 220/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.9432e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9547
# Epoch 221/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6800e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 222/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.4695e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9560
# Epoch 223/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.1044e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9560
# Epoch 224/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9000e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9573
# Epoch 225/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.1355e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9560
# Epoch 226/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.4009e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9560
# Epoch 227/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.5061e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9560
# Epoch 228/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6260e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 229/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.6860e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9560
# Epoch 230/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.6112e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9573
# Epoch 231/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.4020e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9547
# Epoch 232/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.9366e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9560
# Epoch 233/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.8574e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9560
# Epoch 234/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.1073e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9547
# Epoch 235/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.3686e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 236/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8846e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9560
# Epoch 237/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2538e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9560
# Epoch 238/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.7406e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9560
# Epoch 239/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2063e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9534
# Epoch 240/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2547e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 241/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.5342e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9573
# Epoch 242/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.0944e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9560
# Epoch 243/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8898e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9560
# Epoch 244/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.1120e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9560
# Epoch 245/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.9385e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 246/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.7430e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9573
# Epoch 247/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.9819e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9534
# Epoch 248/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.5192e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 249/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8133e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 250/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.6650e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9534
# Epoch 251/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4630e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9560
# Epoch 252/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.5235e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9534
# Epoch 253/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.7550e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 254/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.4232e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9573
# Epoch 255/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.5011e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9547
# Epoch 256/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.8078e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9534
# Epoch 257/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 4.8574e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9560
# Epoch 258/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1954e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9547
# Epoch 259/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.6381e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9560
# Epoch 260/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4538e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9560
# Epoch 261/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.3058e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9573
# Epoch 262/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.6502e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9573
# Epoch 263/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1580e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 264/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.8316e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9534
# Epoch 265/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.7013e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9521
# Epoch 266/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9372e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9521
# Epoch 267/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9421e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 268/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0859e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9612
# Epoch 269/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8047e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9534
# Epoch 270/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.8311e-04 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9547
# Epoch 271/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.3563e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9534
# Epoch 272/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.9993e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9547
# Epoch 273/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7932e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 274/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5606e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 275/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.4238e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9573
# Epoch 276/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9799e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9560
# Epoch 277/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8849e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9521
# Epoch 278/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5697e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9534
# Epoch 279/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5561e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9560
# Epoch 280/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.7787e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9573
# Epoch 281/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.2226e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9573
# Epoch 282/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5221e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9560
# Epoch 283/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.6676e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9560
# Epoch 284/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5929e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 285/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.2036e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9560
# Epoch 286/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2029e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9547
# Epoch 287/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.3465e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9560
# Epoch 288/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.4368e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9547
# Epoch 289/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.2255e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9560
# Epoch 290/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6297e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9586
# Epoch 291/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3860e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 292/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2689e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9573
# Epoch 293/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.7798e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9573
# Epoch 294/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.3422e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9547
# Epoch 295/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.2356e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9547
# Epoch 296/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5120e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9573
# Epoch 297/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.9253e-04 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9560
# Epoch 298/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.4320e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9560
# Epoch 299/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0388e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9560
# Epoch 300/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1083e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9573
# Epoch 301/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9700e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9573
# Epoch 302/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.4069e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 303/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1859e-04 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9534
# Epoch 304/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9283e-04 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.9547
# Epoch 305/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3738e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9599
# Epoch 306/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0260e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9573
# Epoch 307/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.8272e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9560
# Epoch 308/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8652e-04 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.9560
# Epoch 309/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.8720e-04 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9560
# Epoch 310/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.9969e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9560
# Epoch 311/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7788e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9586
# Epoch 312/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.5898e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9586
# Epoch 313/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.9206e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9573
# Epoch 314/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7249e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9586
# Epoch 315/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.8099e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 316/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9462e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9534
# Epoch 317/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.8269e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9573
# Epoch 318/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.8084e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9547
# Epoch 319/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.7146e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9573
# Epoch 320/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.6517e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9560
# Epoch 321/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1482e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9612
# Epoch 1898/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.5303e-07 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9625
# Epoch 1899/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2923e-07 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9625
# Epoch 1900/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.7369e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9612
# Epoch 1901/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.7323e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9612
# Epoch 1902/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.4536e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9625
# Epoch 1903/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1243e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9625
# Epoch 1904/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8971e-07 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9625
# Epoch 1905/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9918e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9625
# Epoch 1906/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.5432e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9599
# Epoch 1907/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.7621e-07 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9625
# Epoch 1908/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2468e-07 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9625
# Epoch 1909/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.7881e-07 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9625
# Epoch 1910/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2160e-07 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9612
# Epoch 1911/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.9898e-07 - accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9625
# Epoch 1912/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.7398e-07 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9625
# Epoch 1913/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.6921e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9625
# Epoch 1914/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2846e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9625
# Epoch 1915/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8289e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9599
# Epoch 1916/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1856e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9586
# Epoch 1917/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.4495e-07 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9612
# Epoch 1918/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1644e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9612
# Epoch 1919/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.3485e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9612
# Epoch 1920/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1894e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9612
# Epoch 1921/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8744e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9612
# Epoch 1922/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0542e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9599
# Epoch 1923/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1267e-07 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9625
# Epoch 1924/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.4469e-07 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9625
# Epoch 1925/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9718e-07 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9625
# Epoch 1926/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.3027e-07 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9625
# Epoch 1927/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 6.2584e-07 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9625
# Epoch 1928/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.5381e-07 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9625
# Epoch 1929/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6529e-07 - accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9625
# Epoch 1930/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6387e-07 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9625
# Epoch 1931/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0192e-07 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9625
# Epoch 1932/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.5218e-07 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9625
# Epoch 1933/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1983e-07 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9625
# Epoch 1934/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0850e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9612
# Epoch 1935/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8547e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9612
# Epoch 1936/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8909e-07 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9625
# Epoch 1937/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1251e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9625
# Epoch 1938/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8293e-07 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9625
# Epoch 1939/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.5414e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9625
# Epoch 1940/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 1.1088e-06 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9625
# Epoch 1941/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6737e-07 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9625
# Epoch 1942/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.5641e-07 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9625
# Epoch 1943/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2202e-07 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9625
# Epoch 1944/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.5734e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9599
# Epoch 1945/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.2647e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9573
# Epoch 1946/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.3232e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9560
# Epoch 1947/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9221e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9560
# Epoch 1948/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0392e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9573
# Epoch 1949/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1702e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9586
# Epoch 1950/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9071e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9586
# Epoch 1951/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.8133e-07 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9586
# Epoch 1952/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9880e-07 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9599
# Epoch 1953/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 7.2879e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9560
# Epoch 1954/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.1546e-07 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9560
# Epoch 1955/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.3794e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9560
# Epoch 1956/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.1946e-07 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9560
# Epoch 1957/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1205e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9560
# Epoch 1958/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0685e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9586
# Epoch 1959/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.7417e-07 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9586
# Epoch 1960/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2855e-07 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9586
# Epoch 1961/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0219e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9586
# Epoch 1962/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6652e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9599
# Epoch 1963/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0950e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9599
# Epoch 1964/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.4168e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9612
# Epoch 1965/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6856e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9612
# Epoch 1966/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2188e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9625
# Epoch 1967/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.3308e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9586
# Epoch 1968/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.0771e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9612
# Epoch 1969/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.4596e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9612
# Epoch 1970/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9915e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9599
# Epoch 1971/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0589e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9599
# Epoch 1972/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.5092e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9625
# Epoch 1973/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 2.9754e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9625
# Epoch 1974/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.1877e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9625
# Epoch 1975/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.0463e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9612
# Epoch 1976/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.5901e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9625
# Epoch 1977/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.3361e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9625
# Epoch 1978/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1104e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9625
# Epoch 1979/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.3398e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9625
# Epoch 1980/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.3167e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9625
# Epoch 1981/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2218e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9625
# Epoch 1982/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.8116e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9638
# Epoch 1983/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.0859e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9625
# Epoch 1984/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0735e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9625
# Epoch 1985/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2951e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9612
# Epoch 1986/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.6498e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9625
# Epoch 1987/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.7291e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9625
# Epoch 1988/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.2545e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9612
# Epoch 1989/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1562e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9625
# Epoch 1990/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.2785e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9612
# Epoch 1991/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1929e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9625
# Epoch 1992/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 2.6588e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9625
# Epoch 1993/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 3.5890e-07 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9625
# Epoch 1994/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.5605e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9625
# Epoch 1995/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.7452e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9612
# Epoch 1996/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 5.0524e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9612
# Epoch 1997/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.9232e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9612
# Epoch 1998/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.1228e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9625
# Epoch 1999/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 3.7215e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9625
# Epoch 2000/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 4.0958e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9625
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 339ms/step - loss: 0.8973 - accuracy: 0.8467
# test_indoor_ds_results:test loss, test acc: [0.8973415493965149, 0.846711277961731]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 422ms/step - loss: 2.1978 - accuracy: 0.7290
# test_outdoor_ds_results:test loss, test acc: [2.197798013687134, 0.7289808988571167]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 194ms/step - loss: 2.2039 - accuracy: 0.7212
# test_belt_ds_results:test loss, test acc: [2.2039029598236084, 0.7212148904800415]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR175-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 138ms/step - loss: 0.5896 - accuracy: 0.8445
# 50/50 [==============================] - 7s 137ms/step - loss: 1.3968 - accuracy: 0.7274
# 35/35 [==============================] - 5s 138ms/step - loss: 1.3883 - accuracy: 0.7167
# Epoch200
#  test_indoor_acc=0.8444815874099731
#  test_outdoor_acc=0.7273885607719421
#  test_belt_acc=0.7166817784309387
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6386 - accuracy: 0.8462
# 50/50 [==============================] - 7s 136ms/step - loss: 1.5247 - accuracy: 0.7296
# 35/35 [==============================] - 5s 137ms/step - loss: 1.5367 - accuracy: 0.7217
# Epoch400
#  test_indoor_acc=0.8461538553237915
#  test_outdoor_acc=0.7296178340911865
#  test_belt_acc=0.7216681838035583
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6909 - accuracy: 0.8439
# 50/50 [==============================] - 7s 137ms/step - loss: 1.6883 - accuracy: 0.7245
# 35/35 [==============================] - 5s 137ms/step - loss: 1.6920 - accuracy: 0.7194
# Epoch600
#  test_indoor_acc=0.8439241647720337
#  test_outdoor_acc=0.7245222926139832
#  test_belt_acc=0.7194016575813293
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7364 - accuracy: 0.8467
# 50/50 [==============================] - 7s 136ms/step - loss: 1.7957 - accuracy: 0.7280
# 35/35 [==============================] - 5s 136ms/step - loss: 1.7916 - accuracy: 0.7230
# Epoch800
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.728025496006012
#  test_belt_acc=0.7230281233787537
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7796 - accuracy: 0.8478
# 50/50 [==============================] - 7s 137ms/step - loss: 1.9165 - accuracy: 0.7293
# 35/35 [==============================] - 5s 138ms/step - loss: 1.9255 - accuracy: 0.7189
# Epoch1000
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7292993664741516
#  test_belt_acc=0.7189483046531677
# 29/29 [==============================] - 7s 136ms/step - loss: 0.8112 - accuracy: 0.8462
# 50/50 [==============================] - 7s 138ms/step - loss: 1.9943 - accuracy: 0.7299
# 35/35 [==============================] - 5s 138ms/step - loss: 1.9974 - accuracy: 0.7217
# Epoch1200
#  test_indoor_acc=0.8461538553237915
#  test_outdoor_acc=0.7299363017082214
#  test_belt_acc=0.7216681838035583
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8291 - accuracy: 0.8495
# 50/50 [==============================] - 7s 136ms/step - loss: 2.0738 - accuracy: 0.7303
# 35/35 [==============================] - 5s 137ms/step - loss: 2.0689 - accuracy: 0.7221
# Epoch1400
#  test_indoor_acc=0.8494983315467834
#  test_outdoor_acc=0.7302547693252563
#  test_belt_acc=0.7221214771270752
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8478 - accuracy: 0.8512
# 50/50 [==============================] - 7s 137ms/step - loss: 2.0978 - accuracy: 0.7293
# 35/35 [==============================] - 5s 137ms/step - loss: 2.1252 - accuracy: 0.7208
# Epoch1600
#  test_indoor_acc=0.851170539855957
#  test_outdoor_acc=0.7292993664741516
#  test_belt_acc=0.7207615375518799
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8761 - accuracy: 0.8478
# 50/50 [==============================] - 7s 137ms/step - loss: 2.1752 - accuracy: 0.7258
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1729 - accuracy: 0.7217
# Epoch1800
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7257961630821228
#  test_belt_acc=0.7216681838035583
# 29/29 [==============================] - 7s 135ms/step - loss: 0.8973 - accuracy: 0.8467
# 50/50 [==============================] - 7s 137ms/step - loss: 2.1978 - accuracy: 0.7290
# 35/35 [==============================] - 5s 137ms/step - loss: 2.2039 - accuracy: 0.7212
# Epoch2000
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.7289808988571167
#  test_belt_acc=0.7212148904800415

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.767291525999705
# max index -> 6
# The [Epoch] of max acc -> 1400

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8444815874099731,
#  0.8461538553237915,
#  0.8439241647720337,
#  0.846711277961731,
#  0.8478260636329651,
#  0.8461538553237915,
#  0.8494983315467834,
#  0.851170539855957,
#  0.8478260636329651,
#  0.846711277961731]

# %%
test_outdoor_acc
# Out:
# [0.7273885607719421,
#  0.7296178340911865,
#  0.7245222926139832,
#  0.728025496006012,
#  0.7292993664741516,
#  0.7299363017082214,
#  0.7302547693252563,
#  0.7292993664741516,
#  0.7257961630821228,
#  0.7289808988571167]

# %%
test_belt_acc
# Out:
# [0.7166817784309387,
#  0.7216681838035583,
#  0.7194016575813293,
#  0.7230281233787537,
#  0.7189483046531677,
#  0.7216681838035583,
#  0.7221214771270752,
#  0.7207615375518799,
#  0.7216681838035583,
#  0.7212148904800415]

# %%
test_indoor_loss
# Out:
# [0.58955317735672,
#  0.6386430263519287,
#  0.6909207105636597,
#  0.7364233136177063,
#  0.7795522212982178,
#  0.8112329840660095,
#  0.8290823101997375,
#  0.8477733135223389,
#  0.8760787844657898,
#  0.8973415493965149]

# %%
test_outdoor_loss
# Out:
# [1.396772861480713,
#  1.5246891975402832,
#  1.6883004903793335,
#  1.7956912517547607,
#  1.9165194034576416,
#  1.9943434000015259,
#  2.073777437210083,
#  2.0978353023529053,
#  2.175163984298706,
#  2.197798013687134]

# %%
test_belt_loss
# Out:
# [1.3882678747177124,
#  1.5366673469543457,
#  1.6920143365859985,
#  1.7915992736816406,
#  1.9255472421646118,
#  1.997384786605835,
#  2.068925619125366,
#  2.125194787979126,
#  2.1729133129119873,
#  2.2039029598236084]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5411
# FP=1729
# acc=0.7578431372549019
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 70.6896551724138%
# 2WayConnectorforFoley acc = 89.79591836734694%
# 2WayFoleyCatheter acc = 76.11940298507463%
# 3WayConnectorforFoley acc = 91.45299145299145%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 86.25%
# AlcoholPad acc = 45.23809523809524%
# BootCover acc = 57.22891566265061%
# CottonBall acc = 90.41916167664671%
# CottonSwap acc = 66.43356643356644%
# Dilator acc = 58.119658119658126%
# DisposableInfusionSet acc = 56.63716814159292%
# ExtensionTube acc = 42.27642276422765%
# FaceShield acc = 78.39506172839506%
# FrontLoadSyringe acc = 49.557522123893804%
# GauzePad acc = 65.3409090909091%
# Glove acc = 73.21428571428571%
# GuideWire acc = 45.535714285714285%
# LiquidBottle acc = 64.50381679389314%
# Mask acc = 96.62337662337663%
# NGTube acc = 42.58064516129032%
# NasalCannula acc = 59.29203539823009%
# Needle acc = 91.07142857142857%
# OxygenMask acc = 80.45112781954887%
# PPESuit acc = 91.12903225806451%
# PharmaceuticalProduct acc = 54.90654205607477%
# Pill acc = 97.05882352941177%
# PillBottle acc = 82.94573643410853%
# PrefilledHumidifier acc = 82.05128205128204%
# PressureConnectingTube acc = 65.64885496183206%
# ReusableHumidifier acc = 87.28813559322035%
# SodiumChlorideBag acc = 81.88976377952756%
# SterileHumidifierAdapter acc = 81.81818181818183%
# SurgicalBlade acc = 86.72566371681415%
# SurgicalCap acc = 90.09009009009009%
# SurgicalSuit acc = 56.060606060606055%
# Syringe acc = 96.95817490494296%
# TrachealTube acc = 42.201834862385326%
# UrineBag acc = 65.0%
# Vaccinebottle acc = 81.2206572769953%
# WingedInfusionSet acc = 66.66666666666666%
#
#
#
# all_avg_eachclass = 72.82892742645201%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 82,   1,   0, ...,   0,   4,   0],
#        [  0, 132,   0, ...,   0,   0,   0],
#        [  0,   0, 102, ...,   0,   1,  11],
#        ...,
#        [  0,   0,   0, ...,  78,   0,   0],
#        [  0,   0,   0, ...,   0, 173,   0],
#        [  0,   0,   0, ...,   0,   0,  76]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[70.68965517,  0.86206897,  0.        , ...,  0.        ,
#          3.44827586,  0.        ],
#        [ 0.        , 89.79591837,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 76.11940299, ...,  0.        ,
#          0.74626866,  8.20895522],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 65.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         81.22065728,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 66.66666667]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
