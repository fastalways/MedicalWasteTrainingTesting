# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.150),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 330ms/step - loss: 1.5276 - accuracy: 0.6081 - val_loss: 0.6480 - val_accuracy: 0.8021
# Epoch 2/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.4682 - accuracy: 0.8572 - val_loss: 0.3844 - val_accuracy: 0.8875
# Epoch 3/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.2563 - accuracy: 0.9270 - val_loss: 0.3493 - val_accuracy: 0.8875
# Epoch 4/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1848 - accuracy: 0.9457 - val_loss: 0.3042 - val_accuracy: 0.9030
# Epoch 5/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1293 - accuracy: 0.9622 - val_loss: 0.2986 - val_accuracy: 0.9017
# Epoch 6/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1015 - accuracy: 0.9719 - val_loss: 0.2372 - val_accuracy: 0.9263
# Epoch 7/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1052 - accuracy: 0.9709 - val_loss: 0.3124 - val_accuracy: 0.8875
# Epoch 8/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0699 - accuracy: 0.9809 - val_loss: 0.2323 - val_accuracy: 0.9263
# Epoch 9/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0503 - accuracy: 0.9880 - val_loss: 0.2085 - val_accuracy: 0.9314
# Epoch 10/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0441 - accuracy: 0.9893 - val_loss: 0.2651 - val_accuracy: 0.9082
# Epoch 11/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0307 - accuracy: 0.9952 - val_loss: 0.1629 - val_accuracy: 0.9560
# Epoch 12/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0240 - accuracy: 0.9955 - val_loss: 0.1824 - val_accuracy: 0.9366
# Epoch 13/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0165 - accuracy: 0.9990 - val_loss: 0.1656 - val_accuracy: 0.9405
# Epoch 14/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 0.1525 - val_accuracy: 0.9495
# Epoch 15/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9495
# Epoch 16/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9534
# Epoch 17/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 0.9521
# Epoch 18/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9534
# Epoch 19/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9534
# Epoch 20/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9483
# Epoch 21/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9547
# Epoch 22/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9483
# Epoch 23/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9508
# Epoch 24/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9534
# Epoch 25/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9547
# Epoch 26/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9547
# Epoch 27/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9534
# Epoch 28/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9521
# Epoch 29/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9560
# Epoch 30/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9560
# Epoch 31/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9547
# Epoch 32/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9547
# Epoch 33/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9560
# Epoch 34/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9547
# Epoch 35/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9573
# Epoch 36/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9560
# Epoch 37/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9534
# Epoch 38/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9573
# Epoch 39/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9573
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 40/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.8301e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9560
# Epoch 41/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.9252e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9560
# Epoch 42/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 9.3187e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9573
# Epoch 43/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3854e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9599
# Epoch 44/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.0319e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9560
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 45/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.7869e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9547
# Epoch 46/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.0566e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9547
# Epoch 47/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.2920e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9547
# Epoch 48/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.1394e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9573
# Epoch 49/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.5688e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9586
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 50/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6598e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9586
# Epoch 51/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.0263e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9586
# Epoch 52/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.1931e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 53/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.1661e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 54/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.6468e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 55/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.9965e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9586
# Epoch 56/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5380e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9586
# Epoch 57/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.8934e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 58/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.4406e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9586
# Epoch 59/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8761e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 60/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.6408e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 61/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.2530e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9586
# Epoch 62/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.9174e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9586
# Epoch 63/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.8707e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9573
# Epoch 64/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.4564e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 65/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8380e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 66/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.9555e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9573
# Epoch 67/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3725e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 68/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.4711e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 69/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.9680e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9573
# Epoch 70/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.9729e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9573
# Epoch 71/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3318e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9573
# Epoch 72/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.1094e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9573
# Epoch 73/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5423e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9573
# Epoch 74/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.0222e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9573
# Epoch 75/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2431e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9573
# Epoch 76/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2728e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9573
# Epoch 77/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.4128e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9573
# Epoch 78/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0599e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9573
# Epoch 79/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8915e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9573
# Epoch 80/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5223e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9573
# Epoch 81/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3556e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9573
# Epoch 82/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5655e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9573
# Epoch 83/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5014e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9586
# Epoch 84/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5455e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9573
# Epoch 85/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3841e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9573
# Epoch 86/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.4730e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9586
# Epoch 87/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3700e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9599
# Epoch 88/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2130e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9599
# Epoch 89/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.7898e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9599
# Epoch 90/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.7819e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9586
# Epoch 91/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.1999e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9573
# Epoch 92/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8930e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9599
# Epoch 93/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.3357e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9586
# Epoch 94/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1984e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9573
# Epoch 95/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.6625e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9586
# Epoch 96/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.2145e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9586
# Epoch 97/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.2183e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9573
# Epoch 98/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.3170e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9586
# Epoch 99/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.9953e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9573
# Epoch 100/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3841e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9586
# Epoch 101/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.8883e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9573
# Epoch 102/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8677e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9560
# Epoch 103/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0090e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9573
# Epoch 104/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0535e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9560
# Epoch 105/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.7846e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9547
# Epoch 106/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0050e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9573
# Epoch 107/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8837e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9573
# Epoch 108/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.8838e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9573
# Epoch 109/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5637e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9573
# Epoch 110/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.9448e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9560
# Epoch 111/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.1063e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9560
# Epoch 112/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0989e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9573
# Epoch 113/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6628e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9573
# Epoch 114/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0704e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9573
# Epoch 115/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.9719e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9586
# Epoch 116/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.4275e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9586
# Epoch 117/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.6715e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 118/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0738e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9586
# Epoch 119/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.7148e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9586
# Epoch 120/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9256e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 121/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2000e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 122/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9987e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9586
# Epoch 123/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0292e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9586
# Epoch 124/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.8378e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9573
# Epoch 125/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.9891e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9573
# Epoch 126/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0455e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9586
# Epoch 127/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.8021e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9573
# Epoch 128/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.6586e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9573
# Epoch 129/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7914e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9586
# Epoch 130/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.9791e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9573
# Epoch 131/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0678e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9586
# Epoch 132/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.1194e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9586
# Epoch 133/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.1223e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9599
# Epoch 134/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2316e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 135/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0559e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9586
# Epoch 136/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6131e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9586
# Epoch 137/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1692e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9586
# Epoch 138/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.4184e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9586
# Epoch 139/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6291e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 140/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3024e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9573
# Epoch 141/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8030e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9586
# Epoch 142/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.6416e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9599
# Epoch 143/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.9369e-04 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9599
# Epoch 144/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.3017e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9586
# Epoch 145/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3689e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9586
# Epoch 146/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.5603e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9586
# Epoch 147/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5129e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9573
# Epoch 148/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0847e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9573
# Epoch 149/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5037e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9586
# Epoch 150/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.5802e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9586
# Epoch 151/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4041e-04 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9586
# Epoch 152/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7383e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9586
# Epoch 153/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.1884e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9586
# Epoch 154/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.5956e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9586
# Epoch 155/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0816e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9586
# Epoch 156/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0440e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9586
# Epoch 157/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0061e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9586
# Epoch 158/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.1675e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9560
# Epoch 159/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.7110e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 160/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2585e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9599
# Epoch 161/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.3532e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9573
# Epoch 162/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0054e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9586
# Epoch 163/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.3643e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9586
# Epoch 164/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0493e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 165/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5714e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9586
# Epoch 166/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9441e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9586
# Epoch 167/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9196e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9573
# Epoch 168/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.6804e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9573
# Epoch 169/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.8073e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9573
# Epoch 170/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0135e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9586
# Epoch 171/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5253e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9573
# Epoch 172/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5967e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9560
# Epoch 173/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.6562e-04 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9573
# Epoch 174/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6404e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9586
# Epoch 175/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.4360e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9586
# Epoch 176/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.2968e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9599
# Epoch 177/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.3525e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9586
# Epoch 178/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.3571e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9586
# Epoch 179/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0921e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9599
# Epoch 180/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.7099e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9599
# Epoch 181/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9050e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9612
# Epoch 182/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.8675e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9586
# Epoch 183/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.7305e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9573
# Epoch 184/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.3235e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9573
# Epoch 185/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1102e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9625
# Epoch 186/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.1813e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9599
# Epoch 187/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.7088e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9599
# Epoch 188/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.8013e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9560
# Epoch 189/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9150e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9573
# Epoch 190/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.0051e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9573
# Epoch 191/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.1933e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9586
# Epoch 192/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9354e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9586
# Epoch 193/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.0079e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9599
# Epoch 194/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.0619e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9573
# Epoch 195/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1598e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9560
# Epoch 196/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9807e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9573
# Epoch 197/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.7403e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9599
# Epoch 198/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.7665e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9612
# Epoch 199/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.1721e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9599
# Epoch 200/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.8857e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9586
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 4.6380e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9586
# Epoch 202/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9030e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9573
# Epoch 203/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.5001e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9586
# Epoch 204/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.2844e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9573
# Epoch 205/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.5669e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9586
# Epoch 206/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.1782e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9573
# Epoch 207/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4712e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9612
# Epoch 208/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4910e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9573
# Epoch 209/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9558e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9612
# Epoch 210/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.0616e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9599
# Epoch 211/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.1999e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9586
# Epoch 212/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4439e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9612
# Epoch 213/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.0393e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9599
# Epoch 214/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8300e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9612
# Epoch 215/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8457e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9599
# Epoch 216/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.9287e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9573
# Epoch 217/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.3649e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9599
# Epoch 218/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.0435e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9573
# Epoch 219/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7466e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9586
# Epoch 220/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5661e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9586
# Epoch 221/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4643e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9612
# Epoch 222/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8984e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9599
# Epoch 223/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8485e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9573
# Epoch 224/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8539e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9586
# Epoch 225/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9592e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9625
# Epoch 226/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0625e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9573
# Epoch 227/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.9577e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9599
# Epoch 228/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7398e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9599
# Epoch 229/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8127e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9586
# Epoch 230/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.5282e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9612
# Epoch 231/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.6908e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9599
# Epoch 232/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7577e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9586
# Epoch 233/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.5736e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9612
# Epoch 234/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4355e-04 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9625
# Epoch 235/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2428e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9612
# Epoch 236/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.7014e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9599
# Epoch 237/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3850e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9586
# Epoch 238/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7561e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9599
# Epoch 239/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7937e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9599
# Epoch 240/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9649e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9599
# Epoch 241/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4063e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9599
# Epoch 242/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4923e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9586
# Epoch 243/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4189e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9625
# Epoch 244/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0049e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9599
# Epoch 245/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0464e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9612
# Epoch 246/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0117e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9599
# Epoch 247/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3713e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9599
# Epoch 248/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2408e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9599
# Epoch 249/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1326e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9599
# Epoch 250/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4885e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9612
# Epoch 251/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.7013e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9612
# Epoch 252/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0463e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9599
# Epoch 253/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1896e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9625
# Epoch 254/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0342e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9612
# Epoch 255/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0430e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9586
# Epoch 256/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8285e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9573
# Epoch 257/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1397e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9612
# Epoch 258/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8651e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9625
# Epoch 259/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7412e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9586
# Epoch 260/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0081e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9612
# Epoch 261/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.7883e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9599
# Epoch 262/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1143e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9586
# Epoch 263/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0507e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9586
# Epoch 264/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9005e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9625
# Epoch 265/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9354e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9599
# Epoch 266/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9909e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9612
# Epoch 267/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6509e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9625
# Epoch 268/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4570e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9625
# Epoch 269/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5548e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9625
# Epoch 270/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7511e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9612
# Epoch 271/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7895e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9625
# Epoch 272/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6106e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9612
# Epoch 273/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5623e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9612
# Epoch 274/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5078e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9625
# Epoch 275/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5480e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9638
# Epoch 276/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6532e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9586
# Epoch 277/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6741e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9612
# Epoch 278/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3388e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9625
# Epoch 279/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9141e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9638
# Epoch 280/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5304e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9625
# Epoch 281/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6583e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9612
# Epoch 282/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3179e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9625
# Epoch 283/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8136e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9612
# Epoch 284/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4546e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9599
# Epoch 285/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5845e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9612
# Epoch 286/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3050e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9599
# Epoch 287/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1814e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9625
# Epoch 288/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9218e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9625
# Epoch 289/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4137e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9586
# Epoch 290/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7220e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9625
# Epoch 291/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3173e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9638
# Epoch 292/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3939e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9625
# Epoch 293/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2031e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9625
# Epoch 294/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3411e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9612
# Epoch 295/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1014e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9599
# Epoch 296/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3070e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9586
# Epoch 297/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2632e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9612
# Epoch 298/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4125e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9625
# Epoch 299/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4016e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9625
# Epoch 300/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1274e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9638
# Epoch 301/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1992e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9625
# Epoch 302/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3062e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9625
# Epoch 303/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9652e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9625
# Epoch 304/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2699e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9599
# Epoch 305/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8279e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9586
# Epoch 306/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0519e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9612
# Epoch 307/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.8789e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9612
# Epoch 308/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9277e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9612
# Epoch 309/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.0192e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9599
# Epoch 310/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1304e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9586
# Epoch 311/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9200e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9612
# Epoch 312/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3720e-04 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9612
# Epoch 313/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9209e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9625
# Epoch 314/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7990e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9625
# Epoch 315/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.0248e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9625
# Epoch 316/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2092e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9625
# Epoch 317/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9252e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9599
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.4271e-07 - accuracy: 1.0000 - val_loss: 0.1645 - val_accuracy: 0.9664
# Epoch 1898/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3490e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9651
# Epoch 1899/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4253e-07 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9651
# Epoch 1900/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4985e-07 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9651
# Epoch 1901/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.4554e-07 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9664
# Epoch 1902/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4807e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9664
# Epoch 1903/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1225e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9664
# Epoch 1904/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6484e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9651
# Epoch 1905/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5296e-07 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9651
# Epoch 1906/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0012e-07 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9651
# Epoch 1907/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2419e-07 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9651
# Epoch 1908/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4723e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9651
# Epoch 1909/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5918e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9651
# Epoch 1910/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4961e-07 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9651
# Epoch 1911/2000
# 49/49 [==============================] - 9s 172ms/step - loss: 3.4330e-07 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9638
# Epoch 1912/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4017e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9638
# Epoch 1913/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7630e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9638
# Epoch 1914/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1757e-07 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9638
# Epoch 1915/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9041e-07 - accuracy: 1.0000 - val_loss: 0.1645 - val_accuracy: 0.9638
# Epoch 1916/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9793e-07 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9638
# Epoch 1917/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6965e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9638
# Epoch 1918/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.4104e-07 - accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9651
# Epoch 1919/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0912e-07 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9651
# Epoch 1920/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.7934e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9651
# Epoch 1921/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7963e-07 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9651
# Epoch 1922/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8129e-07 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9651
# Epoch 1923/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2271e-07 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9664
# Epoch 1924/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7205e-07 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 0.9651
# Epoch 1925/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8152e-07 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9651
# Epoch 1926/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1715e-07 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9651
# Epoch 1927/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4842e-07 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9638
# Epoch 1928/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2423e-07 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9638
# Epoch 1929/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6756e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9638
# Epoch 1930/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6371e-07 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9638
# Epoch 1931/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9184e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9651
# Epoch 1932/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9950e-07 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9638
# Epoch 1933/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7813e-07 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9638
# Epoch 1934/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0047e-07 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9651
# Epoch 1935/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8961e-07 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9651
# Epoch 1936/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7254e-07 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9651
# Epoch 1937/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4526e-07 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9651
# Epoch 1938/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5228e-07 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9651
# Epoch 1939/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8325e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9651
# Epoch 1940/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1226e-07 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9651
# Epoch 1941/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.5667e-07 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9651
# Epoch 1942/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7832e-07 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.9651
# Epoch 1943/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0523e-07 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.9651
# Epoch 1944/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9646e-07 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9651
# Epoch 1945/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6640e-07 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9651
# Epoch 1946/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2022e-07 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.9651
# Epoch 1947/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2647e-07 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9651
# Epoch 1948/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0193e-07 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9651
# Epoch 1949/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7732e-07 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9664
# Epoch 1950/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5307e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9664
# Epoch 1951/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7755e-07 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9664
# Epoch 1952/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4880e-07 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9651
# Epoch 1953/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7195e-07 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9651
# Epoch 1954/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8271e-07 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9651
# Epoch 1955/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4060e-07 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9651
# Epoch 1956/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0871e-07 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9651
# Epoch 1957/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9642e-07 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9651
# Epoch 1958/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5640e-07 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9651
# Epoch 1959/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1618e-07 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9651
# Epoch 1960/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3187e-07 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9638
# Epoch 1961/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7042e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9638
# Epoch 1962/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4531e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9638
# Epoch 1963/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4441e-07 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9638
# Epoch 1964/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8618e-07 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9638
# Epoch 1965/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6469e-07 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9638
# Epoch 1966/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3322e-07 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9651
# Epoch 1967/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9727e-07 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9651
# Epoch 1968/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3572e-07 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9651
# Epoch 1969/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7780e-07 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9638
# Epoch 1970/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1656e-07 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 0.9664
# Epoch 1971/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2295e-07 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9664
# Epoch 1972/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5393e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9664
# Epoch 1973/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0185e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9664
# Epoch 1974/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8583e-07 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9664
# Epoch 1975/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4327e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9651
# Epoch 1976/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4819e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9651
# Epoch 1977/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3944e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9651
# Epoch 1978/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7994e-07 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9651
# Epoch 1979/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2511e-07 - accuracy: 1.0000 - val_loss: 0.1645 - val_accuracy: 0.9638
# Epoch 1980/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9191e-07 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9638
# Epoch 1981/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4647e-07 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9638
# Epoch 1982/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7593e-07 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9651
# Epoch 1983/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4655e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9638
# Epoch 1984/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.5009e-07 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9638
# Epoch 1985/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4137e-07 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9651
# Epoch 1986/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7085e-07 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9651
# Epoch 1987/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5038e-07 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9651
# Epoch 1988/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1198e-07 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9651
# Epoch 1989/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0688e-07 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9651
# Epoch 1990/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9800e-07 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9651
# Epoch 1991/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8217e-07 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9664
# Epoch 1992/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3102e-07 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9664
# Epoch 1993/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8848e-07 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9664
# Epoch 1994/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7838e-07 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9664
# Epoch 1995/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6224e-07 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9664
# Epoch 1996/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5660e-07 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9664
# Epoch 1997/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2901e-07 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9664
# Epoch 1998/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4387e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9664
# Epoch 1999/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4997e-07 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9677
# Epoch 2000/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6592e-07 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9677
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 345ms/step - loss: 0.8819 - accuracy: 0.8411
# test_indoor_ds_results:test loss, test acc: [0.8819491863250732, 0.8411371111869812]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 412ms/step - loss: 2.2465 - accuracy: 0.7258
# test_outdoor_ds_results:test loss, test acc: [2.246537208557129, 0.7257961630821228]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 200ms/step - loss: 2.3843 - accuracy: 0.7085
# test_belt_ds_results:test loss, test acc: [2.38434100151062, 0.7085222005844116]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR150-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6290 - accuracy: 0.8328
# 50/50 [==============================] - 7s 138ms/step - loss: 1.3981 - accuracy: 0.7293
# 35/35 [==============================] - 5s 139ms/step - loss: 1.5172 - accuracy: 0.7017
# Epoch200
#  test_indoor_acc=0.832775890827179
#  test_outdoor_acc=0.7292993664741516
#  test_belt_acc=0.7017225623130798
# 29/29 [==============================] - 5s 138ms/step - loss: 0.6584 - accuracy: 0.8367
# 50/50 [==============================] - 7s 140ms/step - loss: 1.5544 - accuracy: 0.7274
# 35/35 [==============================] - 5s 140ms/step - loss: 1.6814 - accuracy: 0.7031
# Epoch400
#  test_indoor_acc=0.8366777896881104
#  test_outdoor_acc=0.7273885607719421
#  test_belt_acc=0.7030825018882751
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6956 - accuracy: 0.8395
# 50/50 [==============================] - 7s 137ms/step - loss: 1.7100 - accuracy: 0.7309
# 35/35 [==============================] - 5s 138ms/step - loss: 1.8067 - accuracy: 0.7072
# Epoch600
#  test_indoor_acc=0.8394649028778076
#  test_outdoor_acc=0.7308917045593262
#  test_belt_acc=0.7071622610092163
# 29/29 [==============================] - 5s 135ms/step - loss: 0.7512 - accuracy: 0.8384
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8148 - accuracy: 0.7334
# 35/35 [==============================] - 5s 137ms/step - loss: 1.9520 - accuracy: 0.7112
# Epoch800
#  test_indoor_acc=0.8383500576019287
#  test_outdoor_acc=0.7334395051002502
#  test_belt_acc=0.7112420797348022
# 29/29 [==============================] - 5s 140ms/step - loss: 0.7817 - accuracy: 0.8423
# 50/50 [==============================] - 7s 142ms/step - loss: 1.9447 - accuracy: 0.7287
# 35/35 [==============================] - 5s 142ms/step - loss: 2.0775 - accuracy: 0.7063
# Epoch1000
#  test_indoor_acc=0.8422519564628601
#  test_outdoor_acc=0.7286624312400818
#  test_belt_acc=0.7062556743621826
# 29/29 [==============================] - 5s 137ms/step - loss: 0.8156 - accuracy: 0.8395
# 50/50 [==============================] - 7s 138ms/step - loss: 2.0304 - accuracy: 0.7280
# 35/35 [==============================] - 5s 139ms/step - loss: 2.1552 - accuracy: 0.7094
# Epoch1200
#  test_indoor_acc=0.8394649028778076
#  test_outdoor_acc=0.728025496006012
#  test_belt_acc=0.7094288468360901
# 29/29 [==============================] - 5s 138ms/step - loss: 0.8374 - accuracy: 0.8417
# 50/50 [==============================] - 7s 139ms/step - loss: 2.1001 - accuracy: 0.7283
# 35/35 [==============================] - 5s 140ms/step - loss: 2.2431 - accuracy: 0.7090
# Epoch1400
#  test_indoor_acc=0.8416945338249207
#  test_outdoor_acc=0.7283439636230469
#  test_belt_acc=0.7089754939079285
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8556 - accuracy: 0.8406
# 50/50 [==============================] - 7s 137ms/step - loss: 2.1335 - accuracy: 0.7296
# 35/35 [==============================] - 5s 137ms/step - loss: 2.2950 - accuracy: 0.7076
# Epoch1600
#  test_indoor_acc=0.8405796885490417
#  test_outdoor_acc=0.7296178340911865
#  test_belt_acc=0.7076156139373779
# 29/29 [==============================] - 5s 137ms/step - loss: 0.8729 - accuracy: 0.8411
# 50/50 [==============================] - 7s 138ms/step - loss: 2.1905 - accuracy: 0.7303
# 35/35 [==============================] - 5s 139ms/step - loss: 2.3394 - accuracy: 0.7085
# Epoch1800
#  test_indoor_acc=0.8411371111869812
#  test_outdoor_acc=0.7302547693252563
#  test_belt_acc=0.7085222005844116
# 29/29 [==============================] - 5s 137ms/step - loss: 0.8819 - accuracy: 0.8411
# 50/50 [==============================] - 7s 139ms/step - loss: 2.2465 - accuracy: 0.7258
# 35/35 [==============================] - 5s 139ms/step - loss: 2.3843 - accuracy: 0.7085
# Epoch2000
#  test_indoor_acc=0.8411371111869812
#  test_outdoor_acc=0.7257961630821228
#  test_belt_acc=0.7085222005844116

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7610105474789938
# max index -> 3
# The [Epoch] of max acc -> 800

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.832775890827179,
#  0.8366777896881104,
#  0.8394649028778076,
#  0.8383500576019287,
#  0.8422519564628601,
#  0.8394649028778076,
#  0.8416945338249207,
#  0.8405796885490417,
#  0.8411371111869812,
#  0.8411371111869812]

# %%
test_outdoor_acc
# Out:
# [0.7292993664741516,
#  0.7273885607719421,
#  0.7308917045593262,
#  0.7334395051002502,
#  0.7286624312400818,
#  0.728025496006012,
#  0.7283439636230469,
#  0.7296178340911865,
#  0.7302547693252563,
#  0.7257961630821228]

# %%
test_belt_acc
# Out:
# [0.7017225623130798,
#  0.7030825018882751,
#  0.7071622610092163,
#  0.7112420797348022,
#  0.7062556743621826,
#  0.7094288468360901,
#  0.7089754939079285,
#  0.7076156139373779,
#  0.7085222005844116,
#  0.7085222005844116]

# %%
test_indoor_loss
# Out:
# [0.6289638876914978,
#  0.6583887934684753,
#  0.6955593228340149,
#  0.7512445449829102,
#  0.7817069888114929,
#  0.8155600428581238,
#  0.837395191192627,
#  0.8556341528892517,
#  0.8728592395782471,
#  0.8819491863250732]

# %%
test_outdoor_loss
# Out:
# [1.3980727195739746,
#  1.554366111755371,
#  1.7099864482879639,
#  1.8147693872451782,
#  1.9447308778762817,
#  2.0303640365600586,
#  2.1000804901123047,
#  2.133538246154785,
#  2.190507650375366,
#  2.246537208557129]

# %%
test_belt_loss
# Out:
# [1.517194390296936,
#  1.6813751459121704,
#  1.806726336479187,
#  1.952033519744873,
#  2.077505350112915,
#  2.1551735401153564,
#  2.2431464195251465,
#  2.2949886322021484,
#  2.3394384384155273,
#  2.38434100151062]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5376
# FP=1764
# acc=0.7529411764705882
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 59.48275862068966%
# 2WayConnectorforFoley acc = 89.1156462585034%
# 2WayFoleyCatheter acc = 78.35820895522389%
# 3WayConnectorforFoley acc = 80.34188034188034%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 81.875%
# AlcoholPad acc = 46.03174603174603%
# BootCover acc = 60.24096385542169%
# CottonBall acc = 80.23952095808383%
# CottonSwap acc = 64.33566433566433%
# Dilator acc = 70.94017094017094%
# DisposableInfusionSet acc = 54.86725663716814%
# ExtensionTube acc = 39.02439024390244%
# FaceShield acc = 81.48148148148148%
# FrontLoadSyringe acc = 33.6283185840708%
# GauzePad acc = 58.52272727272727%
# Glove acc = 80.95238095238095%
# GuideWire acc = 32.142857142857146%
# LiquidBottle acc = 73.66412213740458%
# Mask acc = 95.32467532467533%
# NGTube acc = 41.935483870967744%
# NasalCannula acc = 41.5929203539823%
# Needle acc = 90.35714285714286%
# OxygenMask acc = 96.99248120300751%
# PPESuit acc = 92.74193548387096%
# PharmaceuticalProduct acc = 57.476635514018696%
# Pill acc = 97.19887955182072%
# PillBottle acc = 77.51937984496125%
# PrefilledHumidifier acc = 80.34188034188034%
# PressureConnectingTube acc = 66.41221374045801%
# ReusableHumidifier acc = 79.66101694915254%
# SodiumChlorideBag acc = 77.95275590551181%
# SterileHumidifierAdapter acc = 80.9090909090909%
# SurgicalBlade acc = 86.72566371681415%
# SurgicalCap acc = 91.8918918918919%
# SurgicalSuit acc = 53.03030303030303%
# Syringe acc = 96.57794676806084%
# TrachealTube acc = 43.11926605504588%
# UrineBag acc = 61.66666666666667%
# Vaccinebottle acc = 87.32394366197182%
# WingedInfusionSet acc = 65.78947368421053%
#
#
#
# all_avg_eachclass = 71.38745954082883%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 69,   1,   0, ...,   0,   5,   0],
#        [  0, 131,   0, ...,   0,   0,   0],
#        [  0,   0, 105, ...,   1,   0,   4],
#        ...,
#        [  0,   0,   0, ...,  74,   0,   0],
#        [  0,   0,   0, ...,   1, 186,   0],
#        [  0,   0,   0, ...,   0,   2,  75]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[59.48275862,  0.86206897,  0.        , ...,  0.        ,
#          4.31034483,  0.        ],
#        [ 0.        , 89.11564626,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 78.35820896, ...,  0.74626866,
#          0.        ,  2.98507463],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 61.66666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.46948357,
#         87.32394366,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          1.75438596, 65.78947368]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
