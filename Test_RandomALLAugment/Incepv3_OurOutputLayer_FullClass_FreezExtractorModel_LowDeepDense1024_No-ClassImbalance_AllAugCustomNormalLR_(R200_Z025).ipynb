# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.200),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 331ms/step - loss: 1.5497 - accuracy: 0.5913 - val_loss: 0.6479 - val_accuracy: 0.8047
# Epoch 2/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.4579 - accuracy: 0.8669 - val_loss: 0.4174 - val_accuracy: 0.8719
# Epoch 3/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.2443 - accuracy: 0.9331 - val_loss: 0.3010 - val_accuracy: 0.9211
# Epoch 4/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.1596 - accuracy: 0.9599 - val_loss: 0.2846 - val_accuracy: 0.9082
# Epoch 5/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.1329 - accuracy: 0.9635 - val_loss: 0.2459 - val_accuracy: 0.9263
# Epoch 6/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0887 - accuracy: 0.9758 - val_loss: 0.2409 - val_accuracy: 0.9211
# Epoch 7/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0609 - accuracy: 0.9880 - val_loss: 0.2735 - val_accuracy: 0.9107
# Epoch 8/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0426 - accuracy: 0.9932 - val_loss: 0.2511 - val_accuracy: 0.9185
# Epoch 9/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0329 - accuracy: 0.9948 - val_loss: 0.2307 - val_accuracy: 0.9250
# Epoch 10/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0316 - accuracy: 0.9932 - val_loss: 0.2111 - val_accuracy: 0.9288
# Epoch 11/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0295 - accuracy: 0.9939 - val_loss: 0.2472 - val_accuracy: 0.9211
# Epoch 12/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0212 - accuracy: 0.9968 - val_loss: 0.2107 - val_accuracy: 0.9379
# Epoch 13/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0160 - accuracy: 0.9990 - val_loss: 0.1951 - val_accuracy: 0.9340
# Epoch 14/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.1984 - val_accuracy: 0.9340
# Epoch 15/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.1971 - val_accuracy: 0.9405
# Epoch 16/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0116 - accuracy: 0.9994 - val_loss: 0.1786 - val_accuracy: 0.9405
# Epoch 17/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.1682 - val_accuracy: 0.9431
# Epoch 18/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.9483
# Epoch 19/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9547
# Epoch 20/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.1710 - val_accuracy: 0.9495
# Epoch 21/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9431
# Epoch 22/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 0.1794 - val_accuracy: 0.9457
# Epoch 23/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.1551 - val_accuracy: 0.9573
# Epoch 24/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.1684 - val_accuracy: 0.9470
# Epoch 25/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9470
# Epoch 26/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.1639 - val_accuracy: 0.9457
# Epoch 27/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.1773 - val_accuracy: 0.9379
# Epoch 28/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.1629 - val_accuracy: 0.9470
# Epoch 29/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9521
# Epoch 30/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9508
# Epoch 31/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9483
# Epoch 32/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9483
# Epoch 33/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9547
# Epoch 34/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 9.8839e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9534
# Epoch 35/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9534
# Epoch 36/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9534
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 37/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.4970e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9508
# Epoch 38/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.7522e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9534
# Epoch 39/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9055e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9534
# Epoch 40/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6859e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9534
# Epoch 41/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4983e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9547
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 42/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6772e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 43/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6710e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 44/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8247e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9521
# Epoch 45/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1519e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9534
# Epoch 46/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1521e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 47/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4332e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9534
# Epoch 48/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4569e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 49/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7623e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 50/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8951e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9534
# Epoch 51/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6570e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 52/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4379e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 53/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9909e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 54/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 6.9983e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9521
# Epoch 55/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0349e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9521
# Epoch 56/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4419e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9521
# Epoch 57/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0845e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 58/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4231e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9534
# Epoch 59/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6807e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 60/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6279e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 61/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0629e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 62/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1591e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9534
# Epoch 63/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5056e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9534
# Epoch 64/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5302e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9534
# Epoch 65/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2065e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9534
# Epoch 66/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8558e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9534
# Epoch 67/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6659e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9534
# Epoch 68/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0634e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9534
# Epoch 69/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3588e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9534
# Epoch 70/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6830e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9534
# Epoch 71/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3085e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9534
# Epoch 72/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1291e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9534
# Epoch 73/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0993e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9534
# Epoch 74/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8061e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9534
# Epoch 75/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2914e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9534
# Epoch 76/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4910e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 77/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5560e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 78/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7074e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9534
# Epoch 79/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6550e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 80/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1856e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 81/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6659e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9534
# Epoch 82/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2228e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 83/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5753e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 84/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8788e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 85/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5751e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9534
# Epoch 86/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3107e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9534
# Epoch 87/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9290e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 88/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 6.1395e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9534
# Epoch 89/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5227e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9534
# Epoch 90/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5076e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 91/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3477e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 92/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1263e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9534
# Epoch 93/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5408e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9534
# Epoch 94/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9061e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9534
# Epoch 95/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5686e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9521
# Epoch 96/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9848e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 97/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.4749e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9534
# Epoch 98/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5970e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 99/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3033e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9534
# Epoch 100/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1235e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9534
# Epoch 101/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2145e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9534
# Epoch 102/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4157e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9534
# Epoch 103/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1936e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 104/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0832e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 105/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1678e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 106/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5298e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 107/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0913e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9534
# Epoch 108/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.5659e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9534
# Epoch 109/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0983e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9534
# Epoch 110/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3651e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9534
# Epoch 111/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9257e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9547
# Epoch 112/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7985e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9547
# Epoch 113/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3243e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 114/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3218e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9547
# Epoch 115/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5866e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9547
# Epoch 116/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9933e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9547
# Epoch 117/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8340e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9547
# Epoch 118/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6549e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 119/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4425e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9547
# Epoch 120/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9606e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 121/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0826e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9534
# Epoch 122/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6874e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9534
# Epoch 123/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.4408e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9534
# Epoch 124/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3546e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9547
# Epoch 125/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8343e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9547
# Epoch 126/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6687e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9547
# Epoch 127/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6772e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 128/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6840e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9547
# Epoch 129/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8426e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 130/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9329e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9547
# Epoch 131/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1405e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9547
# Epoch 132/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2772e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9547
# Epoch 133/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0715e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9547
# Epoch 134/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2881e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 135/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2387e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9547
# Epoch 136/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1876e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9547
# Epoch 137/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3965e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 138/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6561e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 139/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2349e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9534
# Epoch 140/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.3230e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9534
# Epoch 141/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6087e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9547
# Epoch 142/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6638e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9547
# Epoch 143/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8933e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9547
# Epoch 144/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1126e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9547
# Epoch 145/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2952e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9547
# Epoch 146/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8874e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 147/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3499e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9547
# Epoch 148/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7254e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 149/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3495e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9547
# Epoch 150/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1368e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9547
# Epoch 151/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0612e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9547
# Epoch 152/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5113e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 153/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.2889e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9547
# Epoch 154/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9952e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9547
# Epoch 155/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6395e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9547
# Epoch 156/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0723e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 157/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6614e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 158/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1553e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9547
# Epoch 159/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5084e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9534
# Epoch 160/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8960e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 161/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1223e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9521
# Epoch 162/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0940e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9534
# Epoch 163/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8929e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9534
# Epoch 164/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.4965e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9547
# Epoch 165/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9853e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9547
# Epoch 166/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3928e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9534
# Epoch 167/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9982e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9534
# Epoch 168/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.5785e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9547
# Epoch 169/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4910e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9547
# Epoch 170/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4613e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9547
# Epoch 171/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7341e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9547
# Epoch 172/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.5367e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9547
# Epoch 173/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6505e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 174/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6754e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9547
# Epoch 175/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4007e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 176/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7690e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 177/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7332e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 178/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6522e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9534
# Epoch 179/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3351e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 180/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2703e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9534
# Epoch 181/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8708e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9534
# Epoch 182/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4991e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 183/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4574e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 184/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2321e-04 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9547
# Epoch 185/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1920e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9534
# Epoch 186/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3554e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 187/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3836e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9547
# Epoch 188/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1747e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9547
# Epoch 189/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2657e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9560
# Epoch 190/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2240e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9560
# Epoch 191/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.5225e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9560
# Epoch 192/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3370e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9560
# Epoch 193/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7923e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9560
# Epoch 194/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5315e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9560
# Epoch 195/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0357e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9560
# Epoch 196/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2275e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 197/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9503e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9560
# Epoch 198/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8510e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9547
# Epoch 199/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7798e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9534
# Epoch 200/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8698e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9534
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 4.0696e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9547
# Epoch 202/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8725e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9547
# Epoch 203/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8131e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9534
# Epoch 204/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6185e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9547
# Epoch 205/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8353e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9547
# Epoch 206/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7693e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9547
# Epoch 207/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7926e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9560
# Epoch 208/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0250e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9534
# Epoch 209/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.6573e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9521
# Epoch 210/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5008e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9560
# Epoch 211/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7355e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9547
# Epoch 212/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0448e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9547
# Epoch 213/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0967e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9547
# Epoch 214/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3669e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9560
# Epoch 215/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5324e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9573
# Epoch 216/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5401e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9560
# Epoch 217/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3441e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 218/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0687e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9547
# Epoch 219/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0596e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9547
# Epoch 220/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3536e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9547
# Epoch 221/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1485e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9534
# Epoch 222/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7261e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9560
# Epoch 223/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3142e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9534
# Epoch 224/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4353e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9534
# Epoch 225/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3478e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9534
# Epoch 226/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3453e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9547
# Epoch 227/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0492e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9534
# Epoch 228/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2117e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9534
# Epoch 229/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2394e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9547
# Epoch 230/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0520e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9534
# Epoch 231/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9636e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 232/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9266e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 233/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1579e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 234/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8250e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9534
# Epoch 235/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7640e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9547
# Epoch 236/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7449e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9547
# Epoch 237/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0253e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9534
# Epoch 238/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5819e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9547
# Epoch 239/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8233e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9547
# Epoch 240/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6765e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9547
# Epoch 241/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5546e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9547
# Epoch 242/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9360e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 243/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8440e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9547
# Epoch 244/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8274e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9547
# Epoch 245/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.3475e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9547
# Epoch 246/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6526e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 247/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9567e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 248/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5076e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 249/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7834e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9547
# Epoch 250/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5453e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9521
# Epoch 251/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5677e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9547
# Epoch 252/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6796e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 253/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4518e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9547
# Epoch 254/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6371e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 255/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3782e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9547
# Epoch 256/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5292e-04 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.9547
# Epoch 257/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4246e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9547
# Epoch 258/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2673e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9547
# Epoch 259/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4188e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9547
# Epoch 260/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4494e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9547
# Epoch 261/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3418e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 262/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4581e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9547
# Epoch 263/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0956e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9547
# Epoch 264/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4879e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9547
# Epoch 265/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2628e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 266/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2963e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9547
# Epoch 267/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3848e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9547
# Epoch 268/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1272e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9547
# Epoch 269/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2932e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9534
# Epoch 270/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0820e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9534
# Epoch 271/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1980e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9547
# Epoch 272/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2752e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9560
# Epoch 273/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0770e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9560
# Epoch 274/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3097e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9534
# Epoch 275/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9274e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9547
# Epoch 276/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1927e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 277/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2779e-04 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9547
# Epoch 278/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8566e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9547
# Epoch 279/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7657e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 280/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9773e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9547
# Epoch 281/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1468e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9547
# Epoch 282/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0306e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9547
# Epoch 283/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1817e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 284/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0330e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9547
# Epoch 285/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8634e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9547
# Epoch 286/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8515e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9547
# Epoch 287/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6974e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9547
# Epoch 288/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7021e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9547
# Epoch 289/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7088e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9547
# Epoch 290/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7869e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 291/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7877e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9547
# Epoch 292/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0091e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9521
# Epoch 293/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7416e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9521
# Epoch 294/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8201e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9547
# Epoch 295/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7007e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9547
# Epoch 296/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6843e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9547
# Epoch 297/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0188e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9547
# Epoch 298/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8898e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9560
# Epoch 299/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7735e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9547
# Epoch 300/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5990e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9547
# Epoch 301/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5274e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9547
# Epoch 302/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6907e-04 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9547
# Epoch 303/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6450e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9547
# Epoch 304/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.4917e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9547
# Epoch 305/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5942e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9547
# Epoch 306/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6209e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9560
# Epoch 307/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.4613e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9560
# Epoch 308/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.4572e-04 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9547
# Epoch 309/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5047e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9547
# Epoch 310/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5525e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9547
# Epoch 311/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.2737e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9547
# Epoch 312/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5080e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9547
# Epoch 313/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6296e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9534
# Epoch 314/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5074e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9547
# Epoch 315/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.4436e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9560
# Epoch 316/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.2669e-04 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9547
# Epoch 317/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.4134e-04 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9547
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5144e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9534
# Epoch 1898/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6582e-07 - accuracy: 1.0000 - val_loss: 0.2138 - val_accuracy: 0.9547
# Epoch 1899/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2589e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9573
# Epoch 1900/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4523e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9573
# Epoch 1901/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.2975e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9573
# Epoch 1902/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6515e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9547
# Epoch 1903/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8964e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9547
# Epoch 1904/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6264e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9560
# Epoch 1905/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0905e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9547
# Epoch 1906/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4674e-07 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9547
# Epoch 1907/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2007e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9547
# Epoch 1908/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9142e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9573
# Epoch 1909/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4122e-07 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9560
# Epoch 1910/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0289e-07 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9573
# Epoch 1911/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9218e-07 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9560
# Epoch 1912/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9642e-07 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9573
# Epoch 1913/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7381e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9560
# Epoch 1914/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1989e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9547
# Epoch 1915/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3353e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9547
# Epoch 1916/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3545e-07 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9547
# Epoch 1917/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3091e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9547
# Epoch 1918/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7493e-07 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9547
# Epoch 1919/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6684e-07 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9547
# Epoch 1920/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8514e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9547
# Epoch 1921/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0031e-07 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9547
# Epoch 1922/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0767e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9534
# Epoch 1923/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.1362e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9560
# Epoch 1924/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5664e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9560
# Epoch 1925/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9115e-07 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9560
# Epoch 1926/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6958e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9560
# Epoch 1927/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2971e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9560
# Epoch 1928/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4254e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9560
# Epoch 1929/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.3867e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9534
# Epoch 1930/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7740e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9547
# Epoch 1931/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5752e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9547
# Epoch 1932/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1106e-07 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9534
# Epoch 1933/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8525e-07 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9534
# Epoch 1934/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8849e-07 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9560
# Epoch 1935/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6199e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9547
# Epoch 1936/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6184e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9547
# Epoch 1937/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.0094e-07 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9560
# Epoch 1938/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2320e-07 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9560
# Epoch 1939/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3807e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9560
# Epoch 1940/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9442e-07 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9547
# Epoch 1941/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0482e-07 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9547
# Epoch 1942/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2084e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9547
# Epoch 1943/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5527e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9547
# Epoch 1944/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3260e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9547
# Epoch 1945/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5228e-07 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9547
# Epoch 1946/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2989e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9547
# Epoch 1947/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4323e-07 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9547
# Epoch 1948/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9596e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9547
# Epoch 1949/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1238e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9547
# Epoch 1950/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5178e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9547
# Epoch 1951/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8934e-07 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9547
# Epoch 1952/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9230e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9573
# Epoch 1953/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3688e-07 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9560
# Epoch 1954/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1214e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9534
# Epoch 1955/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7874e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9534
# Epoch 1956/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4647e-07 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9547
# Epoch 1957/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6160e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9547
# Epoch 1958/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8683e-07 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9547
# Epoch 1959/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5617e-07 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9547
# Epoch 1960/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3657e-07 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9547
# Epoch 1961/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.8808e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9547
# Epoch 1962/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.4807e-07 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9560
# Epoch 1963/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9530e-07 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9560
# Epoch 1964/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1090e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9573
# Epoch 1965/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.9731e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9560
# Epoch 1966/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0517e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9560
# Epoch 1967/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6195e-07 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9547
# Epoch 1968/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7033e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9547
# Epoch 1969/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1939e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9547
# Epoch 1970/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5097e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9547
# Epoch 1971/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6345e-07 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9547
# Epoch 1972/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5254e-07 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9547
# Epoch 1973/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2290e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9547
# Epoch 1974/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5063e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9547
# Epoch 1975/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5527e-07 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9534
# Epoch 1976/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 4.1624e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9547
# Epoch 1977/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3437e-07 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9547
# Epoch 1978/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.0587e-07 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9547
# Epoch 1979/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.7695e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9547
# Epoch 1980/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2729e-07 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9547
# Epoch 1981/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1730e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9547
# Epoch 1982/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3703e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9547
# Epoch 1983/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7797e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9547
# Epoch 1984/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6923e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9547
# Epoch 1985/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7401e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9547
# Epoch 1986/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3214e-07 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9534
# Epoch 1987/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7789e-07 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9534
# Epoch 1988/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6214e-07 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9534
# Epoch 1989/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5124e-07 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9534
# Epoch 1990/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.5053e-07 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9534
# Epoch 1991/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.1116e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9534
# Epoch 1992/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.8298e-07 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9534
# Epoch 1993/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2810e-07 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9534
# Epoch 1994/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6045e-07 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9521
# Epoch 1995/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5625e-07 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9521
# Epoch 1996/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6626e-07 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9534
# Epoch 1997/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5352e-07 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9534
# Epoch 1998/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.7558e-07 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9534
# Epoch 1999/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.2303e-07 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9547
# Epoch 2000/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.6365e-07 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9534
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 350ms/step - loss: 0.8406 - accuracy: 0.8501
# test_indoor_ds_results:test loss, test acc: [0.8406181335449219, 0.8500557541847229]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 425ms/step - loss: 2.1156 - accuracy: 0.7373
# test_outdoor_ds_results:test loss, test acc: [2.115583658218384, 0.737261176109314]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 195ms/step - loss: 2.1837 - accuracy: 0.7239
# test_belt_ds_results:test loss, test acc: [2.183680295944214, 0.7239347100257874]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR200-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6059 - accuracy: 0.8389
# 50/50 [==============================] - 7s 138ms/step - loss: 1.3653 - accuracy: 0.7414
# 35/35 [==============================] - 5s 138ms/step - loss: 1.4625 - accuracy: 0.7121
# Epoch200
#  test_indoor_acc=0.8389074802398682
#  test_outdoor_acc=0.7414012551307678
#  test_belt_acc=0.7121486663818359
# 29/29 [==============================] - 5s 138ms/step - loss: 0.6451 - accuracy: 0.8462
# 50/50 [==============================] - 7s 140ms/step - loss: 1.5123 - accuracy: 0.7382
# 35/35 [==============================] - 5s 140ms/step - loss: 1.6086 - accuracy: 0.7180
# Epoch400
#  test_indoor_acc=0.8461538553237915
#  test_outdoor_acc=0.7382165789604187
#  test_belt_acc=0.718041718006134
# 29/29 [==============================] - 7s 135ms/step - loss: 0.6804 - accuracy: 0.8478
# 50/50 [==============================] - 7s 136ms/step - loss: 1.6294 - accuracy: 0.7420
# 35/35 [==============================] - 5s 137ms/step - loss: 1.7209 - accuracy: 0.7180
# Epoch600
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7420381903648376
#  test_belt_acc=0.718041718006134
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7205 - accuracy: 0.8506
# 50/50 [==============================] - 7s 137ms/step - loss: 1.7469 - accuracy: 0.7398
# 35/35 [==============================] - 5s 138ms/step - loss: 1.8487 - accuracy: 0.7194
# Epoch800
#  test_indoor_acc=0.8506131768226624
#  test_outdoor_acc=0.7398089170455933
#  test_belt_acc=0.7194016575813293
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7526 - accuracy: 0.8478
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8287 - accuracy: 0.7401
# 35/35 [==============================] - 5s 138ms/step - loss: 1.9654 - accuracy: 0.7171
# Epoch1000
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7401273846626282
#  test_belt_acc=0.7171350717544556
# 29/29 [==============================] - 5s 137ms/step - loss: 0.7824 - accuracy: 0.8495
# 50/50 [==============================] - 7s 138ms/step - loss: 1.9162 - accuracy: 0.7414
# 35/35 [==============================] - 5s 138ms/step - loss: 2.0066 - accuracy: 0.7230
# Epoch1200
#  test_indoor_acc=0.8494983315467834
#  test_outdoor_acc=0.7414012551307678
#  test_belt_acc=0.7230281233787537
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8030 - accuracy: 0.8501
# 50/50 [==============================] - 7s 135ms/step - loss: 1.9817 - accuracy: 0.7411
# 35/35 [==============================] - 5s 136ms/step - loss: 2.0794 - accuracy: 0.7217
# Epoch1400
#  test_indoor_acc=0.8500557541847229
#  test_outdoor_acc=0.7410827875137329
#  test_belt_acc=0.7216681838035583
# 29/29 [==============================] - 5s 138ms/step - loss: 0.8229 - accuracy: 0.8489
# 50/50 [==============================] - 7s 139ms/step - loss: 2.0350 - accuracy: 0.7376
# 35/35 [==============================] - 5s 140ms/step - loss: 2.1376 - accuracy: 0.7185
# Epoch1600
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.7375796437263489
#  test_belt_acc=0.7184950113296509
# 29/29 [==============================] - 5s 137ms/step - loss: 0.8388 - accuracy: 0.8506
# 50/50 [==============================] - 7s 139ms/step - loss: 2.0636 - accuracy: 0.7389
# 35/35 [==============================] - 5s 140ms/step - loss: 2.1600 - accuracy: 0.7217
# Epoch1800
#  test_indoor_acc=0.8506131768226624
#  test_outdoor_acc=0.7388535141944885
#  test_belt_acc=0.7216681838035583
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8406 - accuracy: 0.8501
# 50/50 [==============================] - 7s 138ms/step - loss: 2.1156 - accuracy: 0.7373
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1837 - accuracy: 0.7239
# Epoch2000
#  test_indoor_acc=0.8500557541847229
#  test_outdoor_acc=0.737261176109314
#  test_belt_acc=0.7239347100257874

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7713092366854349
# max index -> 5
# The [Epoch] of max acc -> 1200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8389074802398682,
#  0.8461538553237915,
#  0.8478260636329651,
#  0.8506131768226624,
#  0.8478260636329651,
#  0.8494983315467834,
#  0.8500557541847229,
#  0.848940908908844,
#  0.8506131768226624,
#  0.8500557541847229]

# %%
test_outdoor_acc
# Out:
# [0.7414012551307678,
#  0.7382165789604187,
#  0.7420381903648376,
#  0.7398089170455933,
#  0.7401273846626282,
#  0.7414012551307678,
#  0.7410827875137329,
#  0.7375796437263489,
#  0.7388535141944885,
#  0.737261176109314]

# %%
test_belt_acc
# Out:
# [0.7121486663818359,
#  0.718041718006134,
#  0.718041718006134,
#  0.7194016575813293,
#  0.7171350717544556,
#  0.7230281233787537,
#  0.7216681838035583,
#  0.7184950113296509,
#  0.7216681838035583,
#  0.7239347100257874]

# %%
test_indoor_loss
# Out:
# [0.6059229969978333,
#  0.645094633102417,
#  0.6804442405700684,
#  0.7204506397247314,
#  0.7525919675827026,
#  0.7823525667190552,
#  0.8029943108558655,
#  0.8228819370269775,
#  0.8388153910636902,
#  0.8406181335449219]

# %%
test_outdoor_loss
# Out:
# [1.3653281927108765,
#  1.5122672319412231,
#  1.6293516159057617,
#  1.746911883354187,
#  1.8287461996078491,
#  1.9162383079528809,
#  1.9817391633987427,
#  2.0350170135498047,
#  2.0636343955993652,
#  2.115583658218384]

# %%
test_belt_loss
# Out:
# [1.462456226348877,
#  1.608595848083496,
#  1.7209047079086304,
#  1.8487203121185303,
#  1.965441346168518,
#  2.0065956115722656,
#  2.079366683959961,
#  2.137613534927368,
#  2.1600215435028076,
#  2.183680295944214]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5447
# FP=1693
# acc=0.7628851540616246
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 68.10344827586206%
# 2WayConnectorforFoley acc = 87.75510204081633%
# 2WayFoleyCatheter acc = 73.13432835820896%
# 3WayConnectorforFoley acc = 95.72649572649573%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 78.75%
# AlcoholPad acc = 53.96825396825397%
# BootCover acc = 65.06024096385542%
# CottonBall acc = 87.42514970059881%
# CottonSwap acc = 71.32867132867133%
# Dilator acc = 62.39316239316239%
# DisposableInfusionSet acc = 58.4070796460177%
# ExtensionTube acc = 44.71544715447154%
# FaceShield acc = 80.24691358024691%
# FrontLoadSyringe acc = 53.09734513274337%
# GauzePad acc = 55.68181818181818%
# Glove acc = 81.54761904761905%
# GuideWire acc = 33.035714285714285%
# LiquidBottle acc = 54.58015267175572%
# Mask acc = 94.54545454545455%
# NGTube acc = 45.16129032258064%
# NasalCannula acc = 58.4070796460177%
# Needle acc = 87.14285714285714%
# OxygenMask acc = 95.48872180451127%
# PPESuit acc = 87.90322580645162%
# PharmaceuticalProduct acc = 68.45794392523365%
# Pill acc = 97.3389355742297%
# PillBottle acc = 76.74418604651163%
# PrefilledHumidifier acc = 75.21367521367522%
# PressureConnectingTube acc = 65.64885496183206%
# ReusableHumidifier acc = 87.28813559322035%
# SodiumChlorideBag acc = 85.8267716535433%
# SterileHumidifierAdapter acc = 84.54545454545455%
# SurgicalBlade acc = 84.070796460177%
# SurgicalCap acc = 89.1891891891892%
# SurgicalSuit acc = 43.93939393939394%
# Syringe acc = 96.1977186311787%
# TrachealTube acc = 47.706422018348626%
# UrineBag acc = 63.33333333333333%
# Vaccinebottle acc = 83.56807511737088%
# WingedInfusionSet acc = 66.66666666666666%
#
#
#
# all_avg_eachclass = 72.88878594372301%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 79,   0,   0, ...,   0,  10,   0],
#        [  1, 129,   0, ...,   0,   1,   0],
#        [  0,   0,  98, ...,   1,   0,  16],
#        ...,
#        [  0,   0,   0, ...,  76,   0,   0],
#        [  0,   0,   0, ...,   0, 178,   0],
#        [  0,   0,   0, ...,   2,   1,  76]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[68.10344828,  0.        ,  0.        , ...,  0.        ,
#          8.62068966,  0.        ],
#        [ 0.68027211, 87.75510204,  0.        , ...,  0.        ,
#          0.68027211,  0.        ],
#        [ 0.        ,  0.        , 73.13432836, ...,  0.74626866,
#          0.        , 11.94029851],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 63.33333333,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         83.56807512,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  1.75438596,
#          0.87719298, 66.66666667]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
