# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.VGG19(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-4].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 25088)             20024384
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 45,725,770
# Trainable params: 25,701,386
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 16/16 [==============================] - 33s 884ms/step - loss: 9.1344 - accuracy: 0.3359 - val_loss: 1.6247 - val_accuracy: 0.7059
# Epoch 2/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 1.2825 - accuracy: 0.7285 - val_loss: 0.5949 - val_accuracy: 0.8118
# Epoch 3/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.3857 - accuracy: 0.8770 - val_loss: 0.5184 - val_accuracy: 0.8431
# Epoch 4/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.2354 - accuracy: 0.9229 - val_loss: 0.3492 - val_accuracy: 0.8667
# Epoch 5/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.1636 - accuracy: 0.9434 - val_loss: 0.2890 - val_accuracy: 0.8863
# Epoch 6/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.1228 - accuracy: 0.9609 - val_loss: 0.2828 - val_accuracy: 0.8941
# Epoch 7/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.1114 - accuracy: 0.9570 - val_loss: 0.2866 - val_accuracy: 0.8863
# Epoch 8/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 0.0824 - accuracy: 0.9746 - val_loss: 0.2851 - val_accuracy: 0.8980
# Epoch 9/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0736 - accuracy: 0.9785 - val_loss: 0.2934 - val_accuracy: 0.8941
# Epoch 10/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0570 - accuracy: 0.9844 - val_loss: 0.2434 - val_accuracy: 0.9137
# Epoch 11/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0464 - accuracy: 0.9893 - val_loss: 0.2409 - val_accuracy: 0.9176
# Epoch 12/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0415 - accuracy: 0.9922 - val_loss: 0.2375 - val_accuracy: 0.9137
# Epoch 13/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0450 - accuracy: 0.9902 - val_loss: 0.2226 - val_accuracy: 0.9176
# Epoch 14/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0394 - accuracy: 0.9922 - val_loss: 0.2436 - val_accuracy: 0.9176
# Epoch 15/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0363 - accuracy: 0.9941 - val_loss: 0.2293 - val_accuracy: 0.9176
# Epoch 16/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0331 - accuracy: 0.9893 - val_loss: 0.2373 - val_accuracy: 0.9059
# Epoch 17/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0385 - accuracy: 0.9883 - val_loss: 0.2504 - val_accuracy: 0.9098
# Epoch 18/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0328 - accuracy: 0.9922 - val_loss: 0.3080 - val_accuracy: 0.9176
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0390 - accuracy: 0.9844 - val_loss: 0.2583 - val_accuracy: 0.9176
# Epoch 20/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0178 - accuracy: 0.9980 - val_loss: 0.2376 - val_accuracy: 0.9176
# Epoch 21/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0196 - accuracy: 0.9961 - val_loss: 0.2297 - val_accuracy: 0.9333
# Epoch 22/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9176
# Epoch 23/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0169 - accuracy: 0.9971 - val_loss: 0.2289 - val_accuracy: 0.9216
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 24/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0145 - accuracy: 0.9990 - val_loss: 0.2282 - val_accuracy: 0.9176
# Epoch 25/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0154 - accuracy: 0.9980 - val_loss: 0.2285 - val_accuracy: 0.9137
# Epoch 26/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0133 - accuracy: 0.9980 - val_loss: 0.2289 - val_accuracy: 0.9137
# Epoch 27/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0145 - accuracy: 0.9971 - val_loss: 0.2299 - val_accuracy: 0.9137
# Epoch 28/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9137
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 29/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0154 - accuracy: 0.9990 - val_loss: 0.2309 - val_accuracy: 0.9137
# Epoch 30/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0141 - accuracy: 0.9990 - val_loss: 0.2308 - val_accuracy: 0.9137
# Epoch 31/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0151 - accuracy: 0.9990 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 32/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 33/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0150 - accuracy: 0.9971 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 34/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0144 - accuracy: 0.9990 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 35/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 36/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 37/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9176
# Epoch 38/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 39/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0156 - accuracy: 0.9980 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 40/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0143 - accuracy: 0.9980 - val_loss: 0.2308 - val_accuracy: 0.9176
# Epoch 41/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 42/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0148 - accuracy: 0.9971 - val_loss: 0.2303 - val_accuracy: 0.9137
# Epoch 43/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0144 - accuracy: 0.9980 - val_loss: 0.2301 - val_accuracy: 0.9137
# Epoch 44/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0143 - accuracy: 0.9980 - val_loss: 0.2304 - val_accuracy: 0.9137
# Epoch 45/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0136 - accuracy: 0.9990 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 46/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0131 - accuracy: 0.9990 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 47/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0125 - accuracy: 0.9990 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 48/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0137 - accuracy: 0.9980 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 49/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0140 - accuracy: 0.9990 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 50/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0137 - accuracy: 0.9990 - val_loss: 0.2300 - val_accuracy: 0.9137
# Epoch 51/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9137
# Epoch 52/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0127 - accuracy: 0.9990 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 53/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0137 - accuracy: 0.9990 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 54/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0139 - accuracy: 0.9990 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 55/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0142 - accuracy: 0.9980 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 56/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 57/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0131 - accuracy: 0.9990 - val_loss: 0.2309 - val_accuracy: 0.9137
# Epoch 58/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 59/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0143 - accuracy: 0.9990 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 60/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0122 - accuracy: 0.9990 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 61/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9137
# Epoch 62/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0145 - accuracy: 0.9980 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 63/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 64/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 65/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0133 - accuracy: 0.9990 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 66/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.2300 - val_accuracy: 0.9216
# Epoch 67/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0131 - accuracy: 0.9990 - val_loss: 0.2301 - val_accuracy: 0.9216
# Epoch 68/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 69/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0129 - accuracy: 0.9980 - val_loss: 0.2304 - val_accuracy: 0.9216
# Epoch 70/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0129 - accuracy: 0.9990 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 71/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0124 - accuracy: 0.9990 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 72/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 73/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0155 - accuracy: 0.9971 - val_loss: 0.2298 - val_accuracy: 0.9176
# Epoch 74/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0133 - accuracy: 0.9990 - val_loss: 0.2296 - val_accuracy: 0.9176
# Epoch 75/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0127 - accuracy: 0.9990 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 76/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0139 - accuracy: 0.9990 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 77/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0141 - accuracy: 0.9980 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 78/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0139 - accuracy: 0.9980 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 79/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 80/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0127 - accuracy: 0.9980 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 81/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0130 - accuracy: 0.9980 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 82/2000
# 16/16 [==============================] - 4s 225ms/step - loss: 0.0124 - accuracy: 0.9990 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 83/2000
# 16/16 [==============================] - 4s 224ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 84/2000
# 16/16 [==============================] - 4s 224ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 85/2000
# 16/16 [==============================] - 4s 225ms/step - loss: 0.0127 - accuracy: 0.9990 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 86/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 87/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0136 - accuracy: 0.9990 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 88/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 89/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 90/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0140 - accuracy: 0.9980 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 91/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 92/2000
# 16/16 [==============================] - 4s 225ms/step - loss: 0.0130 - accuracy: 0.9980 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 93/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9176
# Epoch 94/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0129 - accuracy: 0.9980 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 95/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0130 - accuracy: 0.9990 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 96/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 97/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9216
# Epoch 98/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0124 - accuracy: 0.9990 - val_loss: 0.2305 - val_accuracy: 0.9216
# Epoch 99/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9216
# Epoch 100/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0126 - accuracy: 0.9980 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 101/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0117 - accuracy: 0.9990 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 102/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0130 - accuracy: 0.9990 - val_loss: 0.2298 - val_accuracy: 0.9216
# Epoch 103/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0131 - accuracy: 0.9980 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 104/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0130 - accuracy: 0.9990 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 105/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 106/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 107/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0126 - accuracy: 0.9980 - val_loss: 0.2308 - val_accuracy: 0.9176
# Epoch 108/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 109/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0122 - accuracy: 0.9980 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 110/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0127 - accuracy: 0.9980 - val_loss: 0.2298 - val_accuracy: 0.9216
# Epoch 111/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0110 - accuracy: 0.9990 - val_loss: 0.2297 - val_accuracy: 0.9216
# Epoch 112/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0119 - accuracy: 0.9990 - val_loss: 0.2299 - val_accuracy: 0.9216
# Epoch 113/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9176oss: 0.0125 -
# Epoch 114/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.2310 - val_accuracy: 0.9176
# Epoch 115/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.9176
# Epoch 116/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0128 - accuracy: 0.9990 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 117/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 118/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0109 - accuracy: 0.9990 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 119/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0123 - accuracy: 0.9990 - val_loss: 0.2296 - val_accuracy: 0.9176
# Epoch 120/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0124 - accuracy: 0.9990 - val_loss: 0.2293 - val_accuracy: 0.9216
# Epoch 121/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0125 - accuracy: 0.9980 - val_loss: 0.2294 - val_accuracy: 0.9216
# Epoch 122/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0125 - accuracy: 0.9980 - val_loss: 0.2295 - val_accuracy: 0.9216
# Epoch 123/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.2298 - val_accuracy: 0.9176
# Epoch 124/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0114 - accuracy: 0.9990 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 125/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 126/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0113 - accuracy: 0.9990 - val_loss: 0.2299 - val_accuracy: 0.9176
# Epoch 127/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0117 - accuracy: 0.9990 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 128/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.2313 - val_accuracy: 0.9176
# Epoch 129/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 0.2312 - val_accuracy: 0.9176
# Epoch 130/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0116 - accuracy: 0.9990 - val_loss: 0.2311 - val_accuracy: 0.9176
# Epoch 131/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 132/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 133/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9176
# Epoch 134/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0119 - accuracy: 0.9990 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 135/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 136/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 137/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 138/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0128 - accuracy: 0.9980 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 139/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9176
# Epoch 140/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0124 - accuracy: 0.9980 - val_loss: 0.2310 - val_accuracy: 0.9176
# Epoch 141/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 142/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0124 - accuracy: 0.9980 - val_loss: 0.2311 - val_accuracy: 0.9176
# Epoch 143/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9176
# Epoch 144/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0119 - accuracy: 0.9990 - val_loss: 0.2323 - val_accuracy: 0.9176
# Epoch 145/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9176
# Epoch 146/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9176
# Epoch 147/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9176
# Epoch 148/2000
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0117 - accuracy: 0.9990 - val_loss: 0.2318 - val_accuracy: 0.9176
# Epoch 149/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0117 - accuracy: 0.9980 - val_loss: 0.2313 - val_accuracy: 0.9176
# Epoch 150/2000
# 16/16 [==============================] - 3s 221ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.2309 - val_accuracy: 0.9176
# Epoch 151/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9176
# Epoch 152/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0110 - accuracy: 0.9990 - val_loss: 0.2311 - val_accuracy: 0.9176
# Epoch 153/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.2308 - val_accuracy: 0.9176oss: 0.0111 - accuracy: 0.99
# Epoch 154/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 155/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 156/2000
# 16/16 [==============================] - 4s 223ms/step - loss: 0.0116 - accuracy: 0.9980 - val_loss: 0.2301 - val_accuracy: 0.9216
# Epoch 157/2000
# 16/16 [==============================] - 4s 222ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 158/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9176
# Epoch 159/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 0.2319 - val_accuracy: 0.9176
# Epoch 160/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9176
# Epoch 161/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 0.2313 - val_accuracy: 0.9176
# Epoch 162/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.9176
# Epoch 163/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 0.2310 - val_accuracy: 0.9176
# Epoch 164/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9176
# Epoch 165/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9176
# Epoch 166/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0110 - accuracy: 0.9990 - val_loss: 0.2307 - val_accuracy: 0.9216
# Epoch 167/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9216
# Epoch 168/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.2303 - val_accuracy: 0.9216
# Epoch 169/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0100 - accuracy: 0.9980 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 170/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0107 - accuracy: 0.9990 - val_loss: 0.2309 - val_accuracy: 0.9176
# Epoch 171/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 172/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0099 - accuracy: 0.9990 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 173/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 174/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0101 - accuracy: 0.9990 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 175/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0114 - accuracy: 0.9990 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 176/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0103 - accuracy: 0.9990 - val_loss: 0.2309 - val_accuracy: 0.9176
# Epoch 177/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9176
# Epoch 178/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0101 - accuracy: 0.9990 - val_loss: 0.2316 - val_accuracy: 0.9176
# Epoch 179/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9176
# Epoch 180/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9176
# Epoch 181/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.9176
# Epoch 182/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9176
# Epoch 183/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2321 - val_accuracy: 0.9176
# Epoch 184/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9216
# Epoch 185/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2301 - val_accuracy: 0.9216
# Epoch 186/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9176
# Epoch 187/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 188/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 189/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 190/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9176
# Epoch 191/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0098 - accuracy: 0.9990 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 192/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0091 - accuracy: 0.9990 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 193/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9176
# Epoch 194/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9176
# Epoch 195/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0101 - accuracy: 0.9980 - val_loss: 0.2312 - val_accuracy: 0.9216
# Epoch 196/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9176
# Epoch 197/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9216
# Epoch 198/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9216
# Epoch 199/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 200/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.2304 - val_accuracy: 0.9176
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_VGG19\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 16/16 [==============================] - 4s 219ms/step - loss: 0.0099 - accuracy: 0.9990 - val_loss: 0.2310 - val_accuracy: 0.9176
# Epoch 202/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 203/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9176
# Epoch 204/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0099 - accuracy: 0.9990 - val_loss: 0.2310 - val_accuracy: 0.9176
# Epoch 205/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0100 - accuracy: 0.9990 - val_loss: 0.2317 - val_accuracy: 0.9176
# Epoch 206/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 207/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9216
# Epoch 208/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9216
# Epoch 209/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0102 - accuracy: 0.9980 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 210/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9216
# Epoch 211/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0089 - accuracy: 0.9990 - val_loss: 0.2309 - val_accuracy: 0.9176
# Epoch 212/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9176
# Epoch 213/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0088 - accuracy: 0.9990 - val_loss: 0.2286 - val_accuracy: 0.9216
# Epoch 214/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9176
# Epoch 215/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9176
# Epoch 216/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2304 - val_accuracy: 0.9176
# Epoch 217/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9176
# Epoch 218/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2293 - val_accuracy: 0.9176
# Epoch 219/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0107 - accuracy: 0.9990 - val_loss: 0.2293 - val_accuracy: 0.9176
# Epoch 220/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2293 - val_accuracy: 0.9176
# Epoch 221/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0095 - accuracy: 0.9990 - val_loss: 0.2291 - val_accuracy: 0.9176
# Epoch 222/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0089 - accuracy: 0.9990 - val_loss: 0.2295 - val_accuracy: 0.9216
# Epoch 223/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9216
# Epoch 224/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9216
# Epoch 225/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2294 - val_accuracy: 0.9216
# Epoch 226/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2297 - val_accuracy: 0.9216
# Epoch 227/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0091 - accuracy: 0.9990 - val_loss: 0.2298 - val_accuracy: 0.9216
# Epoch 228/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2294 - val_accuracy: 0.9176
# Epoch 229/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9216
# Epoch 230/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.2296 - val_accuracy: 0.9176
# Epoch 231/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.2301 - val_accuracy: 0.9176
# Epoch 232/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.9176
# Epoch 233/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9176
# Epoch 234/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 0.9990 - val_loss: 0.2291 - val_accuracy: 0.9176
# Epoch 235/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9176
# Epoch 236/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.2278 - val_accuracy: 0.9176
# Epoch 237/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9176
# Epoch 238/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2279 - val_accuracy: 0.9176
# Epoch 239/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9176
# Epoch 240/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9176
# Epoch 241/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9176
# Epoch 242/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.2284 - val_accuracy: 0.9216
# Epoch 243/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9216
# Epoch 244/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.2287 - val_accuracy: 0.9216
# Epoch 245/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2286 - val_accuracy: 0.9216
# Epoch 246/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9176
# Epoch 247/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9176
# Epoch 248/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9216
# Epoch 249/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9176
# Epoch 250/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9216
# Epoch 251/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9216
# Epoch 252/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9176
# Epoch 253/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9216
# Epoch 254/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.9216
# Epoch 255/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.2296 - val_accuracy: 0.9176
# Epoch 256/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9176
# Epoch 257/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.2286 - val_accuracy: 0.9216
# Epoch 258/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2286 - val_accuracy: 0.9176
# Epoch 259/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9216
# Epoch 260/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9216
# Epoch 261/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2279 - val_accuracy: 0.9216
# Epoch 262/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 0.9990 - val_loss: 0.2293 - val_accuracy: 0.9176
# Epoch 263/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9176
# Epoch 264/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9216
# Epoch 265/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9176
# Epoch 266/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9216
# Epoch 267/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9176
# Epoch 268/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9216
# Epoch 269/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9216
# Epoch 270/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2298 - val_accuracy: 0.9176
# Epoch 271/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9176
# Epoch 272/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9216
# Epoch 273/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9176
# Epoch 274/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9176
# Epoch 275/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0085 - accuracy: 0.9990 - val_loss: 0.2292 - val_accuracy: 0.9216
# Epoch 276/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.2292 - val_accuracy: 0.9216
# Epoch 277/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.2283 - val_accuracy: 0.9216
# Epoch 278/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9216
# Epoch 279/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9216
# Epoch 280/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9216
# Epoch 281/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9216
# Epoch 282/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9176
# Epoch 283/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9255
# Epoch 284/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.2297 - val_accuracy: 0.9255
# Epoch 285/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9216
# Epoch 286/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9176
# Epoch 287/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0069 - accuracy: 0.9990 - val_loss: 0.2263 - val_accuracy: 0.9216
# Epoch 288/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.9176
# Epoch 289/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9216
# Epoch 290/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9176
# Epoch 291/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0075 - accuracy: 0.9990 - val_loss: 0.2271 - val_accuracy: 0.9216
# Epoch 292/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9255
# Epoch 293/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9216
# Epoch 294/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9216
# Epoch 295/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9216
# Epoch 296/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9255
# Epoch 297/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9216
# Epoch 298/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9216
# Epoch 299/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2278 - val_accuracy: 0.9216
# Epoch 300/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9216
# Epoch 301/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9216
# Epoch 302/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9176
# Epoch 303/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9216
# Epoch 304/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9176
# Epoch 305/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9176
# Epoch 306/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9176
# Epoch 307/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2264 - val_accuracy: 0.9216
# Epoch 308/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.2255 - val_accuracy: 0.9216
# Epoch 309/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0068 - accuracy: 0.9990 - val_loss: 0.2281 - val_accuracy: 0.9216
# Epoch 310/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2294 - val_accuracy: 0.9216
# Epoch 311/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9255
# Epoch 312/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9216
# Epoch 313/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9216
# Epoch 314/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2264 - val_accuracy: 0.9176
# Epoch 315/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9176
# Epoch 316/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9176
# Epoch 317/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.2252 - val_accuracy: 0.9216
# Epoch 318/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9216
# Epoch 319/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9176
# Epoch 320/2000
# 16/16 [==============================] - 3s 220ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.2269 - val_accuracy: 0.9216
# Epoch 321/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9255
# Epoch 322/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2290 - val_accuracy: 0.9255
# Epoch 323/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2279 - val_accuracy: 0.9216
# Epoch 324/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9216
# Epoch 325/2000
# 16/16 [==============================] - 3s 219ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9216
# Epoch 326/2000
# ...
# 16/16 [==============================] - 3s 216ms/step - loss: 1.6444e-06 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9255
# Epoch 1897/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.4331e-06 - accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9294
# Epoch 1898/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.3064e-06 - accuracy: 1.0000 - val_loss: 0.3136 - val_accuracy: 0.9255
# Epoch 1899/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.0904e-06 - accuracy: 1.0000 - val_loss: 0.3166 - val_accuracy: 0.9255
# Epoch 1900/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.7324e-06 - accuracy: 1.0000 - val_loss: 0.3208 - val_accuracy: 0.9294
# Epoch 1901/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.8190e-06 - accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9255
# Epoch 1902/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.0638e-06 - accuracy: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.9255
# Epoch 1903/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.3385e-06 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.9255
# Epoch 1904/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.7112e-06 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9255
# Epoch 1905/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9412e-06 - accuracy: 1.0000 - val_loss: 0.3204 - val_accuracy: 0.9294
# Epoch 1906/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.0122e-06 - accuracy: 1.0000 - val_loss: 0.3216 - val_accuracy: 0.9255
# Epoch 1907/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6618e-06 - accuracy: 1.0000 - val_loss: 0.3201 - val_accuracy: 0.9255
# Epoch 1908/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.2968e-06 - accuracy: 1.0000 - val_loss: 0.3194 - val_accuracy: 0.9255
# Epoch 1909/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0649e-06 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9255
# Epoch 1910/2000
# 16/16 [==============================] - 3s 218ms/step - loss: 1.7302e-06 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.9294
# Epoch 1911/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 6.5024e-06 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9255
# Epoch 1912/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.9508e-06 - accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.9294
# Epoch 1913/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 3.4995e-06 - accuracy: 1.0000 - val_loss: 0.3023 - val_accuracy: 0.9294
# Epoch 1914/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.0389e-06 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9255
# Epoch 1915/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.4911e-06 - accuracy: 1.0000 - val_loss: 0.3047 - val_accuracy: 0.9294
# Epoch 1916/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.8090e-06 - accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.9255
# Epoch 1917/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.7912e-06 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9294
# Epoch 1918/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 2.5627e-06 - accuracy: 1.0000 - val_loss: 0.3092 - val_accuracy: 0.9255
# Epoch 1919/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9404e-06 - accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.9255
# Epoch 1920/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.1252e-06 - accuracy: 1.0000 - val_loss: 0.3089 - val_accuracy: 0.9294
# Epoch 1921/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.7874e-06 - accuracy: 1.0000 - val_loss: 0.3094 - val_accuracy: 0.9294
# Epoch 1922/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0546e-06 - accuracy: 1.0000 - val_loss: 0.3119 - val_accuracy: 0.9255
# Epoch 1923/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 5.7084e-06 - accuracy: 1.0000 - val_loss: 0.3258 - val_accuracy: 0.9333
# Epoch 1924/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 5.2761e-06 - accuracy: 1.0000 - val_loss: 0.3058 - val_accuracy: 0.9373
# Epoch 1925/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 2.7878e-06 - accuracy: 1.0000 - val_loss: 0.3069 - val_accuracy: 0.9294
# Epoch 1926/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9515e-06 - accuracy: 1.0000 - val_loss: 0.3071 - val_accuracy: 0.9294
# Epoch 1927/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3323e-06 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 0.9294
# Epoch 1928/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6323e-06 - accuracy: 1.0000 - val_loss: 0.3091 - val_accuracy: 0.9294
# Epoch 1929/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6316e-06 - accuracy: 1.0000 - val_loss: 0.3126 - val_accuracy: 0.9255
# Epoch 1930/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6546e-06 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9255
# Epoch 1931/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6829e-06 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9255
# Epoch 1932/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.4587e-06 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9255
# Epoch 1933/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.2136e-06 - accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9294
# Epoch 1934/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5392e-06 - accuracy: 1.0000 - val_loss: 0.3109 - val_accuracy: 0.9294
# Epoch 1935/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.5791e-06 - accuracy: 1.0000 - val_loss: 0.3112 - val_accuracy: 0.9294
# Epoch 1936/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.0906e-06 - accuracy: 1.0000 - val_loss: 0.3110 - val_accuracy: 0.9373
# Epoch 1937/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.2943e-06 - accuracy: 1.0000 - val_loss: 0.3133 - val_accuracy: 0.9294
# Epoch 1938/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.3964e-06 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.9255
# Epoch 1939/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.7055e-06 - accuracy: 1.0000 - val_loss: 0.3166 - val_accuracy: 0.9255
# Epoch 1940/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.4901e-06 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 0.9255
# Epoch 1941/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0988e-06 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.9255
# Epoch 1942/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5959e-06 - accuracy: 1.0000 - val_loss: 0.3142 - val_accuracy: 0.9255
# Epoch 1943/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0079e-06 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9255
# Epoch 1944/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6980e-06 - accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9255
# Epoch 1945/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.1840e-06 - accuracy: 1.0000 - val_loss: 0.3181 - val_accuracy: 0.9255
# Epoch 1946/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9807e-06 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9255
# Epoch 1947/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9970e-06 - accuracy: 1.0000 - val_loss: 0.3124 - val_accuracy: 0.9255
# Epoch 1948/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3578e-06 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9255
# Epoch 1949/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0892e-06 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9255
# Epoch 1950/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5136e-06 - accuracy: 1.0000 - val_loss: 0.3191 - val_accuracy: 0.9255
# Epoch 1951/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5359e-06 - accuracy: 1.0000 - val_loss: 0.3186 - val_accuracy: 0.9255
# Epoch 1952/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.1863e-06 - accuracy: 1.0000 - val_loss: 0.3157 - val_accuracy: 0.9255
# Epoch 1953/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.4180e-06 - accuracy: 1.0000 - val_loss: 0.3151 - val_accuracy: 0.9255
# Epoch 1954/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.2013e-06 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.9255
# Epoch 1955/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3067e-06 - accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9255
# Epoch 1956/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.3551e-06 - accuracy: 1.0000 - val_loss: 0.3138 - val_accuracy: 0.9255
# Epoch 1957/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.0508e-06 - accuracy: 1.0000 - val_loss: 0.3128 - val_accuracy: 0.9255
# Epoch 1958/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.4481e-06 - accuracy: 1.0000 - val_loss: 0.3157 - val_accuracy: 0.9255
# Epoch 1959/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.1569e-06 - accuracy: 1.0000 - val_loss: 0.3201 - val_accuracy: 0.9294
# Epoch 1960/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.8009e-06 - accuracy: 1.0000 - val_loss: 0.3177 - val_accuracy: 0.9255
# Epoch 1961/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.7841e-06 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.9255
# Epoch 1962/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0006e-06 - accuracy: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.9294
# Epoch 1963/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 9.8426e-07 - accuracy: 1.0000 - val_loss: 0.3183 - val_accuracy: 0.9294
# Epoch 1964/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5454e-06 - accuracy: 1.0000 - val_loss: 0.3199 - val_accuracy: 0.9294
# Epoch 1965/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3359e-06 - accuracy: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.9294
# Epoch 1966/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.8140e-06 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9294
# Epoch 1967/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5345e-06 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.9255
# Epoch 1968/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.7384e-06 - accuracy: 1.0000 - val_loss: 0.3233 - val_accuracy: 0.9333
# Epoch 1969/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 3.5377e-06 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9255
# Epoch 1970/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5487e-06 - accuracy: 1.0000 - val_loss: 0.3098 - val_accuracy: 0.9294
# Epoch 1971/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3968e-06 - accuracy: 1.0000 - val_loss: 0.3118 - val_accuracy: 0.9294
# Epoch 1972/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.6964e-06 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9255
# Epoch 1973/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3774e-06 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9255
# Epoch 1974/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.4496e-06 - accuracy: 1.0000 - val_loss: 0.3180 - val_accuracy: 0.9255
# Epoch 1975/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.5564e-06 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9255
# Epoch 1976/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.2954e-06 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9255
# Epoch 1977/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5884e-06 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.9255
# Epoch 1978/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5003e-06 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9294
# Epoch 1979/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0427e-06 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9294
# Epoch 1980/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0805e-06 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9294
# Epoch 1981/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.1928e-06 - accuracy: 1.0000 - val_loss: 0.3179 - val_accuracy: 0.9294
# Epoch 1982/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5737e-06 - accuracy: 1.0000 - val_loss: 0.3179 - val_accuracy: 0.9294
# Epoch 1983/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.2027e-06 - accuracy: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.9255
# Epoch 1984/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0364e-06 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9255
# Epoch 1985/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.2427e-06 - accuracy: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.9294
# Epoch 1986/2000
# 16/16 [==============================] - 3s 216ms/step - loss: 1.0028e-06 - accuracy: 1.0000 - val_loss: 0.3188 - val_accuracy: 0.9294
# Epoch 1987/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.5801e-06 - accuracy: 1.0000 - val_loss: 0.3256 - val_accuracy: 0.9255
# Epoch 1988/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.8258e-06 - accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.9255
# Epoch 1989/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9504e-06 - accuracy: 1.0000 - val_loss: 0.3323 - val_accuracy: 0.9255
# Epoch 1990/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.1675e-06 - accuracy: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.9255
# Epoch 1991/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.9895e-06 - accuracy: 1.0000 - val_loss: 0.3299 - val_accuracy: 0.9255
# Epoch 1992/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.0544e-06 - accuracy: 1.0000 - val_loss: 0.3287 - val_accuracy: 0.9255
# Epoch 1993/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5777e-06 - accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.9255
# Epoch 1994/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.3599e-06 - accuracy: 1.0000 - val_loss: 0.3292 - val_accuracy: 0.9255
# Epoch 1995/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.5031e-06 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.9255
# Epoch 1996/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.1662e-06 - accuracy: 1.0000 - val_loss: 0.3240 - val_accuracy: 0.9255
# Epoch 1997/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 9.0779e-07 - accuracy: 1.0000 - val_loss: 0.3248 - val_accuracy: 0.9255
# Epoch 1998/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 8.9348e-07 - accuracy: 1.0000 - val_loss: 0.3251 - val_accuracy: 0.9255
# Epoch 1999/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 1.1682e-06 - accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9255
# Epoch 2000/2000
# 16/16 [==============================] - 3s 217ms/step - loss: 2.3025e-06 - accuracy: 1.0000 - val_loss: 0.3248 - val_accuracy: 0.9255
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_VGG19\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 8/8 [==============================] - 12s 1s/step - loss: 2.0196 - accuracy: 0.7061
# test_indoor_ds_results:test loss, test acc: [2.0195770263671875, 0.7061144113540649]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 16/16 [==============================] - 17s 799ms/step - loss: 2.4500 - accuracy: 0.6765
# test_outdoor_ds_results:test loss, test acc: [2.4500370025634766, 0.6764705777168274]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 9/9 [==============================] - 10s 1s/step - loss: 1.8990 - accuracy: 0.7434
# test_belt_ds_results:test loss, test acc: [1.899002194404602, 0.7434095144271851]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 8/8 [==============================] - 1s 166ms/step - loss: 1.0624 - accuracy: 0.6805
# 16/16 [==============================] - 3s 167ms/step - loss: 1.0638 - accuracy: 0.6961
# 9/9 [==============================] - 2s 166ms/step - loss: 1.0427 - accuracy: 0.7364
# Epoch200
#  test_indoor_acc=0.6804733872413635
#  test_outdoor_acc=0.6960784196853638
#  test_belt_acc=0.7363796234130859
# 8/8 [==============================] - 1s 167ms/step - loss: 1.1465 - accuracy: 0.6844
# 16/16 [==============================] - 3s 167ms/step - loss: 1.1778 - accuracy: 0.6990
# 9/9 [==============================] - 2s 166ms/step - loss: 1.1151 - accuracy: 0.7434
# Epoch400
#  test_indoor_acc=0.6844181418418884
#  test_outdoor_acc=0.6990196108818054
#  test_belt_acc=0.7434095144271851
# 8/8 [==============================] - 1s 165ms/step - loss: 1.2597 - accuracy: 0.6903
# 16/16 [==============================] - 3s 165ms/step - loss: 1.3560 - accuracy: 0.6941
# 9/9 [==============================] - 1s 164ms/step - loss: 1.1972 - accuracy: 0.7452
# Epoch600
#  test_indoor_acc=0.6903353333473206
#  test_outdoor_acc=0.6941176652908325
#  test_belt_acc=0.7451669573783875
# 8/8 [==============================] - 1s 165ms/step - loss: 1.3907 - accuracy: 0.6982
# 16/16 [==============================] - 3s 165ms/step - loss: 1.5204 - accuracy: 0.6941
# 9/9 [==============================] - 1s 164ms/step - loss: 1.3147 - accuracy: 0.7469
# Epoch800
#  test_indoor_acc=0.6982248425483704
#  test_outdoor_acc=0.6941176652908325
#  test_belt_acc=0.7469244003295898
# 8/8 [==============================] - 1s 166ms/step - loss: 1.5225 - accuracy: 0.6982
# 16/16 [==============================] - 3s 165ms/step - loss: 1.7099 - accuracy: 0.6863
# 9/9 [==============================] - 1s 164ms/step - loss: 1.4471 - accuracy: 0.7469
# Epoch1000
#  test_indoor_acc=0.6982248425483704
#  test_outdoor_acc=0.686274528503418
#  test_belt_acc=0.7469244003295898
# 8/8 [==============================] - 1s 167ms/step - loss: 1.6067 - accuracy: 0.7002
# 16/16 [==============================] - 3s 167ms/step - loss: 1.8954 - accuracy: 0.6873
# 9/9 [==============================] - 2s 166ms/step - loss: 1.5225 - accuracy: 0.7522
# Epoch1200
#  test_indoor_acc=0.7001972198486328
#  test_outdoor_acc=0.6872549057006836
#  test_belt_acc=0.7521968483924866
# 8/8 [==============================] - 1s 165ms/step - loss: 1.7165 - accuracy: 0.7041
# 16/16 [==============================] - 3s 165ms/step - loss: 2.0173 - accuracy: 0.6912
# 9/9 [==============================] - 1s 165ms/step - loss: 1.5443 - accuracy: 0.7504
# Epoch1400
#  test_indoor_acc=0.7041420340538025
#  test_outdoor_acc=0.6911764740943909
#  test_belt_acc=0.7504393458366394
# 8/8 [==============================] - 1s 166ms/step - loss: 1.8364 - accuracy: 0.7002
# 16/16 [==============================] - 3s 167ms/step - loss: 2.1961 - accuracy: 0.6794
# 9/9 [==============================] - 2s 166ms/step - loss: 1.7169 - accuracy: 0.7487
# Epoch1600
#  test_indoor_acc=0.7001972198486328
#  test_outdoor_acc=0.679411768913269
#  test_belt_acc=0.748681902885437
# 8/8 [==============================] - 1s 165ms/step - loss: 2.0076 - accuracy: 0.7022
# 16/16 [==============================] - 3s 165ms/step - loss: 2.3612 - accuracy: 0.6775
# 9/9 [==============================] - 1s 164ms/step - loss: 1.8638 - accuracy: 0.7399
# Epoch1800
#  test_indoor_acc=0.7021695971488953
#  test_outdoor_acc=0.677450954914093
#  test_belt_acc=0.7398945689201355
# 8/8 [==============================] - 1s 165ms/step - loss: 2.0196 - accuracy: 0.7061
# 16/16 [==============================] - 3s 165ms/step - loss: 2.4500 - accuracy: 0.6765
# 9/9 [==============================] - 1s 165ms/step - loss: 1.8990 - accuracy: 0.7434
# Epoch2000
#  test_indoor_acc=0.7061144113540649
#  test_outdoor_acc=0.6764705777168274
#  test_belt_acc=0.7434095144271851

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7152526179949442
# max index -> 6
# The [Epoch] of max acc -> 1400

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.6804733872413635,
#  0.6844181418418884,
#  0.6903353333473206,
#  0.6982248425483704,
#  0.6982248425483704,
#  0.7001972198486328,
#  0.7041420340538025,
#  0.7001972198486328,
#  0.7021695971488953,
#  0.7061144113540649]

# %%
test_outdoor_acc
# Out:
# [0.6960784196853638,
#  0.6990196108818054,
#  0.6941176652908325,
#  0.6941176652908325,
#  0.686274528503418,
#  0.6872549057006836,
#  0.6911764740943909,
#  0.679411768913269,
#  0.677450954914093,
#  0.6764705777168274]

# %%
test_belt_acc
# Out:
# [0.7363796234130859,
#  0.7434095144271851,
#  0.7451669573783875,
#  0.7469244003295898,
#  0.7469244003295898,
#  0.7521968483924866,
#  0.7504393458366394,
#  0.748681902885437,
#  0.7398945689201355,
#  0.7434095144271851]

# %%
test_indoor_loss
# Out:
# [1.0623819828033447,
#  1.1465494632720947,
#  1.259667158126831,
#  1.3907111883163452,
#  1.5224992036819458,
#  1.6066601276397705,
#  1.7165298461914062,
#  1.8364039659500122,
#  2.0076446533203125,
#  2.0195770263671875]

# %%
test_outdoor_loss
# Out:
# [1.0637922286987305,
#  1.17777419090271,
#  1.3559520244598389,
#  1.5204416513442993,
#  1.7098767757415771,
#  1.8954362869262695,
#  2.0173134803771973,
#  2.1961419582366943,
#  2.3612425327301025,
#  2.4500370025634766]

# %%
test_belt_loss
# Out:
# [1.042672872543335,
#  1.1150509119033813,
#  1.197234034538269,
#  1.314721941947937,
#  1.4470818042755127,
#  1.5225244760513306,
#  1.5442548990249634,
#  1.7168766260147095,
#  1.8637840747833252,
#  1.899002194404602]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg19 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 100
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507
# train_outdoor num x,y : 1020,1020
# train_belt num x,y : 569,569
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1489
# FP=607
# acc=0.7104007633587787
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 41.04477611940299%
# CottonBall acc = 50.898203592814376%
# ExtensionTube acc = 37.39837398373984%
# Glove acc = 92.26190476190477%
# Mask acc = 86.75324675324674%
# NGTube acc = 54.83870967741935%
# Needle acc = 81.78571428571428%
# OxygenMask acc = 86.46616541353383%
# Syringe acc = 80.6083650190114%
# UrineBag acc = 15.0%
#
#
#
# all_avg_eachclass = 62.70554596067876%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 55,   1,  14,   6,  24,  21,   5,   3,   5,   0],
#        [  0,  85,   2,  46,  32,   1,   0,   0,   1,   0],
#        [  2,   0,  46,   4,  13,  50,   6,   0,   1,   1],
#        [  0,   0,   0, 310,  24,   2,   0,   0,   0,   0],
#        [  0,   1,   0,  11, 334,  12,   1,   5,  21,   0],
#        [  0,   0,   0,  19,  30,  85,   7,  10,   3,   1],
#        [  1,   0,   0,  21,  13,  11, 229,   2,   3,   0],
#        [  0,   0,   0,  14,   2,   2,   0, 115,   0,   0],
#        [  0,   1,   0,  13,  13,  10,  14,   0, 212,   0],
#        [  0,   0,   1,  20,  45,   1,   0,  28,   7,  18]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[41.04477612,  0.74626866, 10.44776119,  4.47761194, 17.91044776,
#         15.67164179,  3.73134328,  2.23880597,  3.73134328,  0.        ],
#        [ 0.        , 50.89820359,  1.19760479, 27.54491018, 19.16167665,
#          0.5988024 ,  0.        ,  0.        ,  0.5988024 ,  0.        ],
#        [ 1.62601626,  0.        , 37.39837398,  3.25203252, 10.56910569,
#         40.6504065 ,  4.87804878,  0.        ,  0.81300813,  0.81300813],
#        [ 0.        ,  0.        ,  0.        , 92.26190476,  7.14285714,
#          0.5952381 ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.25974026,  0.        ,  2.85714286, 86.75324675,
#          3.11688312,  0.25974026,  1.2987013 ,  5.45454545,  0.        ],
#        [ 0.        ,  0.        ,  0.        , 12.25806452, 19.35483871,
#         54.83870968,  4.51612903,  6.4516129 ,  1.93548387,  0.64516129],
#        [ 0.35714286,  0.        ,  0.        ,  7.5       ,  4.64285714,
#          3.92857143, 81.78571429,  0.71428571,  1.07142857,  0.        ],
#        [ 0.        ,  0.        ,  0.        , 10.52631579,  1.5037594 ,
#          1.5037594 ,  0.        , 86.46616541,  0.        ,  0.        ],
#        [ 0.        ,  0.38022814,  0.        ,  4.94296578,  4.94296578,
#          3.80228137,  5.32319392,  0.        , 80.60836502,  0.        ],
#        [ 0.        ,  0.        ,  0.83333333, 16.66666667, 37.5       ,
#          0.83333333,  0.        , 23.33333333,  5.83333333, 15.        ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
