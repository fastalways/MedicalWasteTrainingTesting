# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=331
img_width=331
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 331, 331, 3)
# (32,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import preprocess_input,NASNetLarge
#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.NASNetLarge(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 331, 331, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 165, 165, 96) 2592        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 165, 165, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 165, 165, 42) 4032        activation[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 165, 165, 42) 168         reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 165, 165, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 169, 169, 42) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 171, 171, 96) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 83, 83, 42)   2814        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 83, 83, 42)   2814        activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   3822        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 171, 171, 96) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 83, 83, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 169, 169, 96) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 83, 83, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   6432        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 83, 83, 42)   2142        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 167, 167, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   3822        activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   2814        activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 83, 83, 42)   2142        activation_10[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 83, 83, 42)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 83, 83, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 166, 166, 96) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 83, 83, 42)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add (Add)                       (None, 83, 83, 42)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 83, 83, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 165, 165, 96) 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 83, 83, 168)  0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 83, 83, 96)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 83, 83, 96)   0           cropping2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 83, 83, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 83, 83, 42)   4032        adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 83, 83, 42)   4032        adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 83, 83, 84)   14112       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 83, 83, 84)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 83, 83, 84)   336         reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 83, 83, 84)   336         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 83, 83, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 87, 87, 84)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 89, 89, 84)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 42, 42, 84)   9156        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 42, 42, 84)   9156        activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   11172       activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 89, 89, 84)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 42, 42, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 87, 87, 84)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 42, 42, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   9156        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 42, 42, 84)   7812        activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 85, 85, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   11172       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   9156        activation_19[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 42, 42, 84)   7812        activation_21[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 83, 83, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 42, 42, 84)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 42, 42, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 84, 84, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 42, 42, 84)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 42, 42, 84)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 42, 42, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 83, 83, 168)  0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 42, 42, 336)  0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 42, 42, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 42, 42, 168)  0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 42, 42, 84)   14112       adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 42, 42, 84)   14112       adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 42, 42, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 42, 42, 168)  0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 42, 42, 168)  56448       activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 42, 42, 168)  672         concatenate_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 42, 42, 168)  32424       activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 42, 42, 168)  32424       activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 42, 42, 168)  29736       activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 42, 42, 168)  32424       activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 42, 42, 168)  29736       activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 42, 42, 168)  32424       activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 42, 42, 168)  29736       activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 42, 42, 168)  29736       activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 42, 42, 168)  0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 42, 42, 168)  0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 42, 42, 1008) 0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 42, 42, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 42, 42, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 42, 42, 168)  56448       activation_33[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 42, 42, 168)  169344      activation_34[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 42, 42, 168)  672         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 42, 42, 168)  32424       activation_35[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 42, 42, 168)  32424       activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 42, 42, 168)  29736       activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 42, 42, 168)  32424       activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 42, 42, 168)  29736       activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 42, 42, 168)  32424       activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 42, 42, 168)  29736       activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 42, 42, 168)  29736       activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 42, 42, 168)  0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 42, 42, 168)  0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 42, 42, 1008) 0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 42, 42, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 42, 42, 1008) 0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 42, 42, 168)  169344      activation_45[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 42, 42, 168)  169344      activation_46[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 42, 42, 168)  672         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 42, 42, 168)  32424       activation_47[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_49[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 42, 42, 168)  32424       activation_51[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_53[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 42, 42, 168)  29736       activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 11, 11, 672)  468384      activation_238[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 11, 11, 672)  457632      activation_240[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 11, 11, 672)  468384      activation_242[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 11, 11, 672)  457632      activation_244[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 11, 11, 672)  457632      activation_246[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left1_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right1_17
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left2_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right2_17
# __________________________________________________________________________________________________
# normal_left3_17 (AveragePooling (None, 11, 11, 672)  0           normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_left4_17 (AveragePooling (None, 11, 11, 672)  0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_right4_17 (AveragePoolin (None, 11, 11, 672)  0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left5_17[
# __________________________________________________________________________________________________
# normal_add_1_17 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_17 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_17 (Add)           (None, 11, 11, 672)  0           normal_left3_17[0][0]
#                                                                  adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_add_4_17 (Add)           (None, 11, 11, 672)  0           normal_left4_17[0][0]
#                                                                  normal_right4_17[0][0]
# __________________________________________________________________________________________________
# normal_add_5_17 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_concat_17 (Concatenate)  (None, 11, 11, 4032) 0           adjust_bn_17[0][0]
#                                                                  normal_add_1_17[0][0]
#                                                                  normal_add_2_17[0][0]
#                                                                  normal_add_3_17[0][0]
#                                                                  normal_add_4_17[0][0]
#                                                                  normal_add_5_17[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 11, 11, 4032) 0           normal_concat_16[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 11, 11, 4032) 0           normal_concat_17[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_18 (Conv (None, 11, 11, 672)  2709504     activation_247[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_18 (Conv2D)       (None, 11, 11, 672)  2709504     activation_248[0][0]
# __________________________________________________________________________________________________
# adjust_bn_18 (BatchNormalizatio (None, 11, 11, 672)  2688        adjust_conv_projection_18[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_18 (BatchNormalizat (None, 11, 11, 672)  2688        normal_conv_1_18[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 11, 11, 672)  468384      activation_249[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 11, 11, 672)  457632      activation_251[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 11, 11, 672)  468384      activation_253[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 11, 11, 672)  457632      activation_255[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 11, 11, 672)  457632      activation_257[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_1_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_1_normal_right2_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left5_18[
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 11, 11, 672)  468384      activation_250[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 11, 11, 672)  457632      activation_252[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 11, 11, 672)  468384      activation_254[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 11, 11, 672)  457632      activation_256[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 11, 11, 672)  457632      activation_258[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right2_18
# __________________________________________________________________________________________________
# normal_left3_18 (AveragePooling (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_left4_18 (AveragePooling (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_right4_18 (AveragePoolin (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left5_18[
# __________________________________________________________________________________________________
# normal_add_1_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_18 (Add)           (None, 11, 11, 672)  0           normal_left3_18[0][0]
#                                                                  adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_add_4_18 (Add)           (None, 11, 11, 672)  0           normal_left4_18[0][0]
#                                                                  normal_right4_18[0][0]
# __________________________________________________________________________________________________
# normal_add_5_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_concat_18 (Concatenate)  (None, 11, 11, 4032) 0           adjust_bn_18[0][0]
#                                                                  normal_add_1_18[0][0]
#                                                                  normal_add_2_18[0][0]
#                                                                  normal_add_3_18[0][0]
#                                                                  normal_add_4_18[0][0]
#                                                                  normal_add_5_18[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 11, 11, 4032) 0           normal_concat_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 4032)         0           activation_259[0][0]
# ==================================================================================================
# Total params: 84,916,818
# Trainable params: 0
# Non-trainable params: 84,916,818
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 4032)              84916818
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4129792
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 89,056,860
# Trainable params: 4,140,042
# Non-trainable params: 84,916,818
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 32/32 [==============================] - 53s 950ms/step - loss: 0.2760 - accuracy: 0.9238 - val_loss: 0.0420 - val_accuracy: 0.9843
# Epoch 2/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 0.0160 - accuracy: 0.9941 - val_loss: 0.0679 - val_accuracy: 0.9725
# Epoch 3/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.0188 - val_accuracy: 0.9922
# Epoch 4/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 0.0124 - accuracy: 0.9951 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 5/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 6/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.8798e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 7/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.3587e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 8/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7681e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 9/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7229e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 10/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.2702e-04 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 11/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 1.1710e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 12/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.1884e-04 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 13/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.1445e-04 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 14/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.1310e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 15/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.4850e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 16/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.2626e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 17/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 1.1334e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.8421e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 19/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0816e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 20/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.3412e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 21/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0190e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 22/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.2352e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 23/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.1929e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 24/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 9.8117e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 25/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.5711e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 26/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.1644e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 27/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.8618e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 28/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0234e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 29/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.3981e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 30/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0730e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 31/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.4556e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 32/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.6995e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 33/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.7761e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 34/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.3056e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 35/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0550e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 36/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.0798e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 37/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 9.7831e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 38/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.8104e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 39/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0368e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 40/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.2701e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 41/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0380e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 42/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.1246e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 43/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.3962e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 44/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.1073e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 45/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0660e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 46/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.8361e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 47/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.0731e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 48/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0252e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 49/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.0632e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 50/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 1.0009e-04 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 51/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.7472e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 52/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.6887e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 53/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.5100e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 54/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.3069e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 55/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.6798e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 56/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.8580e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 57/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0068e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 58/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.5056e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 59/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.8592e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 60/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0258e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 61/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.3434e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 62/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.5363e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 63/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 8.6791e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 64/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.4956e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 65/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0115e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 66/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.9463e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 67/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.3985e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 68/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.7626e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 69/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.2571e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 70/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0435e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 71/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.7426e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 72/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 6.8948e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 73/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.8676e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 74/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.6966e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 75/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0256e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 76/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 8.4088e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 77/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.6010e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 78/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.2355e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 79/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.4678e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 80/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.9897e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 81/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.0326e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 82/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.5090e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 83/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.3208e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 84/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.3856e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 85/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.3776e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 86/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.7544e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 87/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.5422e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 88/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.6300e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 89/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.0747e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 90/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.1711e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 91/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.2530e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 92/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.0255e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 93/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.3233e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 94/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.9531e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 95/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.2193e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 96/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.0585e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 97/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.4756e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 98/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.5235e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 99/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 9.8436e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 100/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.6879e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 101/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.6120e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 102/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 9.0062e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9922
# Epoch 103/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.6002e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 104/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.7484e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 105/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.3337e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 106/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.1160e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 107/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.0321e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 108/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.6269e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 109/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.2290e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 110/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.8898e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 111/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.8437e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 112/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.8584e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 113/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 9.0961e-05 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 114/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.5087e-05 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 115/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 7.7495e-05 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 116/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.4758e-05 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 117/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.4223e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 118/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.9344e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 119/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.2207e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 120/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 8.1138e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 121/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.0681e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 122/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.0297e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 123/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.3583e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 124/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.2812e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9922
# Epoch 125/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.2327e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 126/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.9888e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 127/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 6.4196e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 128/2000
# 32/32 [==============================] - 23s 735ms/step - loss: 8.7400e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 129/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.9318e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 130/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.0290e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 131/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.0403e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 132/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 6.5446e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 133/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 6.5725e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 134/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.0152e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 135/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.5323e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 136/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.6813e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 137/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.4925e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 138/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.6520e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 139/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.4322e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 140/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.3938e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 141/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.7817e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 142/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.5083e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 143/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.9469e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 144/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 7.1021e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 145/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.5771e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 146/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.5061e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 147/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.6382e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 148/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.8251e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 149/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.0778e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 150/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 6.2698e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 151/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.6104e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 152/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.8258e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 153/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.6172e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 154/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 5.5994e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9961
# Epoch 155/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.0294e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 156/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.2624e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 157/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.5550e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 158/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.7017e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 159/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.5981e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 160/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 8.1944e-05 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9922
# Epoch 161/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.9456e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 162/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.0948e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9922
# Epoch 163/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.3952e-05 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 0.9961
# Epoch 164/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 7.0042e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 165/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.1067e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 166/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.4807e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 167/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 6.0093e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 168/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 5.9586e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 169/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.6040e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 170/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.6591e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 171/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.0527e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 172/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.2464e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 173/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.5532e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 174/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.0214e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 175/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 4.8578e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 176/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.1004e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 177/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.1839e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 178/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.3077e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 179/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.8122e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 180/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.7345e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 181/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 5.1452e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 182/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.5371e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 183/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.1738e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 184/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.1814e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 185/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.5080e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 186/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.3181e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 187/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.2972e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 188/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.2722e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 189/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.7440e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 190/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.6424e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 191/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.8789e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 192/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.2039e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 193/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.0270e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 194/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 5.0729e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 195/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.5003e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 196/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.1701e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 197/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.5926e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 198/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.5218e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 199/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.9568e-05 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9961
# Epoch 200/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.1705e-05 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9961
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 32/32 [==============================] - 24s 730ms/step - loss: 4.7214e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 202/2000
# 32/32 [==============================] - 23s 731ms/step - loss: 5.2167e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 203/2000
# 32/32 [==============================] - 23s 732ms/step - loss: 4.5870e-05 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9961
# Epoch 204/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.4355e-05 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9961
# Epoch 205/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 5.7792e-05 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9961
# Epoch 206/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.3488e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 207/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.1256e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 208/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 6.4623e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 209/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.0204e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 210/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.1178e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 211/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.2760e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 212/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.3431e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 213/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.6384e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 214/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.0147e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 215/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 4.3701e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 216/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.4072e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 217/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.8078e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 218/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.8426e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 219/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.0112e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 220/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 4.7062e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 221/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.9270e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 222/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.3083e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 223/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.4593e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 224/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.2177e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 225/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.4362e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 226/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.9066e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9961
# Epoch 227/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.2189e-05 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9961
# Epoch 228/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 3.8158e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 229/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.4236e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9961
# Epoch 230/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.6550e-05 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 0.9961
# Epoch 231/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.7440e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9961
# Epoch 232/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.4536e-05 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9961
# Epoch 233/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.5451e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 234/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.6298e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 235/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.1043e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 236/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.7796e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 237/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.2965e-05 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 238/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.5322e-05 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9961
# Epoch 239/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.0109e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 240/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.9295e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 241/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.1630e-05 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 242/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 2.7561e-05 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 243/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.2170e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 244/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.2995e-05 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 245/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 3.1876e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 246/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.5254e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 247/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.9831e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 248/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.5938e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 249/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.9014e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 250/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.2785e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 251/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.4649e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 252/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.2592e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 253/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.6360e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 254/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.1737e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 255/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 2.6825e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 256/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.3494e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 257/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.7562e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 258/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.9045e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 259/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.4456e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 260/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.4254e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 261/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.6509e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 262/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.4908e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 263/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.5596e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 264/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.7282e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 265/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.7303e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 266/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.1801e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 267/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9518e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 268/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.9413e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 269/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.0388e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 270/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.6153e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 271/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.1282e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 272/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.2095e-05 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 273/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.0962e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 274/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.1197e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 275/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.0832e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 276/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7959e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 277/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9757e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 278/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9113e-05 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9961
# Epoch 279/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.2474e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 280/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9432e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 281/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.6582e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 282/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9549e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 283/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7339e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 284/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7467e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 285/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.5813e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 286/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6915e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 287/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6620e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 288/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6172e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 289/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6648e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9961
# Epoch 290/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9512e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 291/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.2566e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 292/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6558e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 293/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7464e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 294/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.6443e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 295/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6855e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 296/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6669e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 297/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 2.1104e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 298/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.9098e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 299/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.6617e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 300/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.4188e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 301/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.4010e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9961
# Epoch 302/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.5187e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 303/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.5637e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 304/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.4117e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 305/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.5853e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 306/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.5285e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 307/2000
# 32/32 [==============================] - 23s 734ms/step - loss: 1.3657e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9961
# Epoch 308/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.5581e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 309/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.4110e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 310/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.7606e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 311/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.2828e-05 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 0.9961
# Epoch 312/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.1890e-05 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9961
# Epoch 313/2000
# 32/32 [==============================] - 23s 733ms/step - loss: 1.2172e-05 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9961
# Epoch 314/2000
# ...
# Epoch 1899/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.5018e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1900/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.8394e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1901/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.5949e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1902/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.5949e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1903/2000
# 32/32 [==============================] - 24s 742ms/step - loss: 1.8743e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1904/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.9441e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1905/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.9441e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1906/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.9325e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1907/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1908/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.6298e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1909/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 2.4680e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1910/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.4319e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1911/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.5832e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1912/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.2689e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1913/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.3853e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1914/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.3155e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1915/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.6880e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1916/2000
# 32/32 [==============================] - 24s 742ms/step - loss: 1.4785e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1917/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.6764e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1918/2000
# 32/32 [==============================] - 24s 739ms/step - loss: 1.4668e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1919/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.9441e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1920/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 2.1886e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1921/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.8743e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1922/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.6997e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1923/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.5600e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1924/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.1758e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1925/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 2.0140e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1926/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.8976e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1927/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.4552e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1928/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.6531e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1929/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.4901e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1930/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 2.0023e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1931/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.6997e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1932/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.3155e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1933/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.7695e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1934/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.7928e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1935/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.5483e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1936/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 2.1420e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1937/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.5018e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1938/2000
# 32/32 [==============================] - 24s 741ms/step - loss: 1.1292e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1939/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.8743e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1940/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.8510e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1941/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.6764e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1942/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.6415e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1943/2000
# 32/32 [==============================] - 24s 739ms/step - loss: 1.5949e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 0.9961
# Epoch 1944/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.4086e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1945/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.5250e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1946/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.7695e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1947/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.7346e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1948/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.5018e-08 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9961
# Epoch 1949/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.6531e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 1950/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 2.0140e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 1951/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.4552e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 1952/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 3.0966e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 1953/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.2806e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1954/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 2.0838e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1955/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.9325e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1956/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.4785e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1957/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 2.6543e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1958/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.7579e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1959/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.8859e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1960/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.6880e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1961/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.7695e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1962/2000
# 32/32 [==============================] - 23s 737ms/step - loss: 1.8044e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1963/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.4785e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1964/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.5716e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1965/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.3039e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1966/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.7346e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1967/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.3853e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1968/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.9674e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1969/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 2.1420e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1970/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.8277e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1971/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.4668e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1972/2000
# 32/32 [==============================] - 24s 739ms/step - loss: 2.1188e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1973/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.2573e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1974/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.4552e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1975/2000
# 32/32 [==============================] - 24s 739ms/step - loss: 1.4319e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1976/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.6647e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1977/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.7695e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1978/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.3970e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1979/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.4203e-08 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 1980/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.0594e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1981/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.3621e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1982/2000
# 32/32 [==============================] - 24s 739ms/step - loss: 1.9209e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1983/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.1176e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1984/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.7229e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1985/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.5949e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1986/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.3504e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1987/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.2922e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1988/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.5018e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1989/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.7229e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1990/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.5949e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1991/2000
# 32/32 [==============================] - 23s 738ms/step - loss: 1.3737e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1992/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.5949e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1993/2000
# 32/32 [==============================] - 24s 740ms/step - loss: 1.5134e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1994/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.4319e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1995/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.5134e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1996/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 2.3865e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1997/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 2.1071e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 1998/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.3155e-08 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 1999/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 1.9209e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 2000/2000
# 32/32 [==============================] - 23s 739ms/step - loss: 2.1071e-08 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 16/16 [==============================] - 12s 642ms/step - loss: 0.1326 - accuracy: 0.9704
# test_indoor_ds_results:test loss, test acc: [0.13260731101036072, 0.9704142212867737]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 32/32 [==============================] - 22s 614ms/step - loss: 0.6840 - accuracy: 0.9039
# test_outdoor_ds_results:test loss, test acc: [0.6839922666549683, 0.9039215445518494]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 18/18 [==============================] - 12s 630ms/step - loss: 1.2683 - accuracy: 0.8278
# test_belt_ds_results:test loss, test acc: [1.2683322429656982, 0.8277680277824402]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 16/16 [==============================] - 14s 576ms/step - loss: 0.0923 - accuracy: 0.9665
# 32/32 [==============================] - 19s 578ms/step - loss: 0.4575 - accuracy: 0.8990
# 18/18 [==============================] - 10s 574ms/step - loss: 0.7591 - accuracy: 0.8383
# Epoch200
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8990195989608765
#  test_belt_acc=0.8383128046989441
# 16/16 [==============================] - 14s 584ms/step - loss: 0.1025 - accuracy: 0.9684
# 32/32 [==============================] - 19s 585ms/step - loss: 0.5135 - accuracy: 0.9029
# 18/18 [==============================] - 10s 581ms/step - loss: 0.9065 - accuracy: 0.8330
# Epoch400
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9029411673545837
#  test_belt_acc=0.8330404162406921
# 16/16 [==============================] - 14s 581ms/step - loss: 0.1177 - accuracy: 0.9684
# 32/32 [==============================] - 19s 584ms/step - loss: 0.5750 - accuracy: 0.9039
# 18/18 [==============================] - 10s 578ms/step - loss: 1.0432 - accuracy: 0.8348
# Epoch600
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9039215445518494
#  test_belt_acc=0.8347979187965393
# 16/16 [==============================] - 15s 593ms/step - loss: 0.1231 - accuracy: 0.9684
# 32/32 [==============================] - 19s 594ms/step - loss: 0.6190 - accuracy: 0.9039
# 18/18 [==============================] - 11s 589ms/step - loss: 1.1315 - accuracy: 0.8295
# Epoch800
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9039215445518494
#  test_belt_acc=0.8295254707336426
# 16/16 [==============================] - 15s 595ms/step - loss: 0.1263 - accuracy: 0.9684
# 32/32 [==============================] - 19s 601ms/step - loss: 0.6507 - accuracy: 0.9029
# 18/18 [==============================] - 11s 597ms/step - loss: 1.1816 - accuracy: 0.8243
# Epoch1000
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9029411673545837
#  test_belt_acc=0.8242530822753906
# 16/16 [==============================] - 15s 606ms/step - loss: 0.1295 - accuracy: 0.9684
# 32/32 [==============================] - 20s 608ms/step - loss: 0.6558 - accuracy: 0.9059
# 18/18 [==============================] - 11s 603ms/step - loss: 1.2108 - accuracy: 0.8243
# Epoch1200
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9058823585510254
#  test_belt_acc=0.8242530822753906
# 16/16 [==============================] - 15s 598ms/step - loss: 0.1318 - accuracy: 0.9684
# 32/32 [==============================] - 19s 603ms/step - loss: 0.6644 - accuracy: 0.9039
# 18/18 [==============================] - 11s 598ms/step - loss: 1.2250 - accuracy: 0.8295
# Epoch1400
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9039215445518494
#  test_belt_acc=0.8295254707336426
# 16/16 [==============================] - 33s 596ms/step - loss: 0.1317 - accuracy: 0.9684
# 32/32 [==============================] - 19s 600ms/step - loss: 0.6722 - accuracy: 0.9039
# 18/18 [==============================] - 11s 596ms/step - loss: 1.2391 - accuracy: 0.8278
# Epoch1600
#  test_indoor_acc=0.9684418439865112
#  test_outdoor_acc=0.9039215445518494
#  test_belt_acc=0.8277680277824402
# 16/16 [==============================] - 15s 610ms/step - loss: 0.1305 - accuracy: 0.9704
# 32/32 [==============================] - 19s 608ms/step - loss: 0.6786 - accuracy: 0.9059
# 18/18 [==============================] - 11s 605ms/step - loss: 1.2572 - accuracy: 0.8278
# Epoch1800
#  test_indoor_acc=0.9704142212867737
#  test_outdoor_acc=0.9058823585510254
#  test_belt_acc=0.8277680277824402
# 16/16 [==============================] - 15s 603ms/step - loss: 0.1326 - accuracy: 0.9704
# 32/32 [==============================] - 19s 603ms/step - loss: 0.6840 - accuracy: 0.9039
# 18/18 [==============================] - 11s 601ms/step - loss: 1.2683 - accuracy: 0.8278
# Epoch2000
#  test_indoor_acc=0.9704142212867737
#  test_outdoor_acc=0.9039215445518494
#  test_belt_acc=0.8277680277824402

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.9023871024449667
# max index -> 2
# The [Epoch] of max acc -> 600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.966469407081604,
#  0.9684418439865112,
#  0.9684418439865112,
#  0.9684418439865112,
#  0.9684418439865112,
#  0.9684418439865112,
#  0.9684418439865112,
#  0.9684418439865112,
#  0.9704142212867737,
#  0.9704142212867737]

# %%
test_outdoor_acc
# Out:
# [0.8990195989608765,
#  0.9029411673545837,
#  0.9039215445518494,
#  0.9039215445518494,
#  0.9029411673545837,
#  0.9058823585510254,
#  0.9039215445518494,
#  0.9039215445518494,
#  0.9058823585510254,
#  0.9039215445518494]

# %%
test_belt_acc
# Out:
# [0.8383128046989441,
#  0.8330404162406921,
#  0.8347979187965393,
#  0.8295254707336426,
#  0.8242530822753906,
#  0.8242530822753906,
#  0.8295254707336426,
#  0.8277680277824402,
#  0.8277680277824402,
#  0.8277680277824402]

# %%
test_indoor_loss
# Out:
# [0.09231668710708618,
#  0.10249929130077362,
#  0.11766763031482697,
#  0.1231142058968544,
#  0.12625883519649506,
#  0.12951521575450897,
#  0.13176687061786652,
#  0.13169310986995697,
#  0.13050705194473267,
#  0.13260731101036072]

# %%
test_outdoor_loss
# Out:
# [0.45753610134124756,
#  0.5135216116905212,
#  0.5750155448913574,
#  0.619023859500885,
#  0.6506639122962952,
#  0.6558113694190979,
#  0.6643863320350647,
#  0.6722231507301331,
#  0.6785825490951538,
#  0.6839922666549683]

# %%
test_belt_loss
# Out:
# [0.7591443657875061,
#  0.90647292137146,
#  1.043236255645752,
#  1.1315414905548096,
#  1.181601881980896,
#  1.2108005285263062,
#  1.2250206470489502,
#  1.2391175031661987,
#  1.2571721076965332,
#  1.2683322429656982]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.nasnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=331
img_width=331
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

N = 150

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)} are predicting")
x_indoor_sets = np.array_split(x_test_indoor, N)
del x_test_indoor
y_all_sets_predicted = []
for x in x_indoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_indoor_predicted = np.concatenate(y_all_sets_predicted)
del x_indoor_sets,test_indoor_ds

x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)} are predicting")
x_outdoor_sets = np.array_split(x_test_outdoor, N)
del x_test_outdoor
y_all_sets_predicted = []
for x in x_outdoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_outdoor_predicted = np.concatenate(y_all_sets_predicted)
del x_outdoor_sets,test_outdoor_ds

x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)} are predicting")
x_belt_sets = np.array_split(x_test_belt, N)
del x_test_belt
y_all_sets_predicted = []
for x in x_belt_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_belt_predicted = np.concatenate(y_all_sets_predicted)
del x_belt_sets,test_belt_ds

y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
y_all_predicted = np.concatenate([y_indoor_predicted,y_outdoor_predicted,y_belt_predicted],axis=0)
print(f"all num x,y :{len(y_all_predicted)},{len(y_all)}")
# Out:
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507 are predicting
# train_outdoor num x,y : 1020,1020 are predicting
# train_belt num x,y : 569,569 are predicting
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1888
# FP=208
# acc=0.9007633587786259
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 87.31343283582089%
# CottonBall acc = 98.80239520958084%
# ExtensionTube acc = 52.03252032520326%
# Glove acc = 90.77380952380952%
# Mask acc = 98.18181818181819%
# NGTube acc = 80.0%
# Needle acc = 93.57142857142857%
# OxygenMask acc = 88.7218045112782%
# Syringe acc = 99.61977186311786%
# UrineBag acc = 77.5%
#
#
#
# all_avg_eachclass = 86.65169810220573%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[117,   0,   0,   3,   0,   8,   0,   6,   0,   0],
#        [  0, 165,   0,   0,   1,   0,   1,   0,   0,   0],
#        [  0,   1,  64,   0,  17,  25,   0,   1,   1,  14],
#        [ 13,   0,   0, 305,  14,   0,   1,   0,   2,   1],
#        [  1,   0,   0,   0, 378,   1,   0,   2,   0,   3],
#        [  0,   0,   0,   0,  20, 124,   8,   3,   0,   0],
#        [  0,   0,   1,   0,   3,   9, 262,   2,   1,   2],
#        [  0,   0,   3,   0,   0,   7,   0, 118,   4,   1],
#        [  0,   0,   0,   0,   0,   0,   0,   0, 262,   1],
#        [  0,   0,   0,   0,   9,   6,   0,  12,   0,  93]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[87.31343284,  0.        ,  0.        ,  2.23880597,  0.        ,
#          5.97014925,  0.        ,  4.47761194,  0.        ,  0.        ],
#        [ 0.        , 98.80239521,  0.        ,  0.        ,  0.5988024 ,
#          0.        ,  0.5988024 ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.81300813, 52.03252033,  0.        , 13.82113821,
#         20.32520325,  0.        ,  0.81300813,  0.81300813, 11.38211382],
#        [ 3.86904762,  0.        ,  0.        , 90.77380952,  4.16666667,
#          0.        ,  0.29761905,  0.        ,  0.5952381 ,  0.29761905],
#        [ 0.25974026,  0.        ,  0.        ,  0.        , 98.18181818,
#          0.25974026,  0.        ,  0.51948052,  0.        ,  0.77922078],
#        [ 0.        ,  0.        ,  0.        ,  0.        , 12.90322581,
#         80.        ,  5.16129032,  1.93548387,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.35714286,  0.        ,  1.07142857,
#          3.21428571, 93.57142857,  0.71428571,  0.35714286,  0.71428571],
#        [ 0.        ,  0.        ,  2.2556391 ,  0.        ,  0.        ,
#          5.26315789,  0.        , 88.72180451,  3.0075188 ,  0.7518797 ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        , 99.61977186,  0.38022814],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  7.5       ,
#          5.        ,  0.        , 10.        ,  0.        , 77.5       ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
