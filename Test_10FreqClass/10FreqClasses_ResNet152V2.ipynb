# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet_v2 import preprocess_input,ResNet152V2

transfered_model = keras.applications.ResNet152V2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 56, 56, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 56, 56, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 56, 56, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 28, 28, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 28, 28, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 28, 28, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 28, 28, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 28, 28, 256)  0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 28, 28, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 28, 28, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 28, 28, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv3_block5_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_relu (Activation (None, 28, 28, 128)  0           conv3_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_out (Add)          (None, 28, 28, 512)  0           conv3_block4_out[0][0]
#                                                                  conv3_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block5_out[0][0]
# __________________________________________________________________________________________________
# conv3_block6_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_relu (Activation (None, 28, 28, 128)  0           conv3_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_out (Add)          (None, 28, 28, 512)  0           conv3_block5_out[0][0]
#                                                                  conv3_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block6_out[0][0]
# __________________________________________________________________________________________________
# conv3_block7_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_relu (Activation (None, 28, 28, 128)  0           conv3_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_out (Add)          (None, 28, 28, 512)  0           conv3_block6_out[0][0]
#                                                                  conv3_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block7_out[0][0]
# __________________________________________________________________________________________________
# conv3_block8_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 14, 14, 128)  147456      conv3_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_bn (BatchNormali (None, 14, 14, 128)  512         conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_relu (Activation (None, 14, 14, 128)  0           conv3_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0           conv3_block7_out[0][0]
# __________________________________________________________________________________________________
# conv3_block8_3_conv (Conv2D)    (None, 14, 14, 512)  66048       conv3_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_out (Add)          (None, 14, 14, 512)  0           max_pooling2d_1[0][0]
#                                                                  conv3_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 14, 14, 512)  2048        conv3_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 14, 14, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 14, 14, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 14, 14, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 14, 14, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 14, 14, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 14, 14, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 14, 14, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block9_out[0][0]
# ...
# conv4_block33_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block33_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block33_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block33_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block33_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_out (Add)         (None, 14, 14, 1024) 0           conv4_block32_out[0][0]
#                                                                  conv4_block33_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block33_out[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block34_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block34_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block34_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block34_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block34_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_out (Add)         (None, 14, 14, 1024) 0           conv4_block33_out[0][0]
#                                                                  conv4_block34_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block34_out[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block35_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block35_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block35_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block35_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block35_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_out (Add)         (None, 14, 14, 1024) 0           conv4_block34_out[0][0]
#                                                                  conv4_block35_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block36_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block36_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block36_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block36_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block36_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_conv (Conv2D)   (None, 7, 7, 256)    589824      conv4_block36_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_bn (BatchNormal (None, 7, 7, 256)    1024        conv4_block36_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_relu (Activatio (None, 7, 7, 256)    0           conv4_block36_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)   0           conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      conv4_block36_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_out (Add)         (None, 7, 7, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block36_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 7, 7, 1024)   4096        conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 7, 7, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 7, 7, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           post_relu[0][0]
# ==================================================================================================
# Total params: 58,331,648
# Trainable params: 0
# Non-trainable params: 58,331,648
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              58331648
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 60,440,074
# Trainable params: 2,108,426
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 32/32 [==============================] - 27s 332ms/step - loss: 0.3598 - accuracy: 0.8828 - val_loss: 0.0470 - val_accuracy: 0.9804
# Epoch 2/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0230 - accuracy: 0.9912 - val_loss: 0.0323 - val_accuracy: 0.9922
# Epoch 3/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0085 - accuracy: 0.9980 - val_loss: 0.0131 - val_accuracy: 0.9961
# Epoch 4/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9922
# Epoch 5/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 6/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 7.4199e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 7/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 6.2798e-04 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 8/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 5.7229e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 9/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.5966e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 10/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.6547e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 11/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.5018e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 12/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.0607e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 13/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 2.8650e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 14/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.1442e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 15/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.3130e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 16/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.9135e-04 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 17/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.9286e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 18/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.6796e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 19/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.3619e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 20/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.5028e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 21/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.2714e-04 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 22/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.2209e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 23/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.2094e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 24/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.0611e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 25/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.0921e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 26/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.9202e-05 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 27/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.9668e-05 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 28/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.6136e-05 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 29/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.8773e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 30/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.8532e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 31/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.0999e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 32/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.7318e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 33/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.0856e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 34/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.8304e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 35/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.9601e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 36/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.0111e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 37/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.0781e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 38/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.6324e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 39/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.7018e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 40/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.2192e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 41/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.6086e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 42/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.5539e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 43/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.9471e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 44/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.3455e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 45/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.8203e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 46/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.0133e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 47/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.8929e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 48/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.8532e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 49/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.2998e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 50/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.1330e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 51/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.2359e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 52/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.3301e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 53/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.6346e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 54/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.5182e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 55/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.1411e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 56/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.0659e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 57/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.2782e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 58/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.0491e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 59/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.3157e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 60/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.9931e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 61/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.3642e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 62/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.3659e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 63/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.6481e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 64/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.4359e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 65/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.2191e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 66/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.7410e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 67/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 9.0202e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 68/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.9387e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 69/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.5168e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 70/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.6568e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 71/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.2339e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 72/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.4526e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 73/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.1171e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 74/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.5802e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 75/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.2673e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 76/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.2953e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 77/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.9655e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 78/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.0009e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 79/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.9617e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 80/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.1722e-05 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 81/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.0024e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 82/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.4053e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 83/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.6072e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 84/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 9.4230e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 85/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.0445e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 86/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.2965e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 87/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.8992e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 88/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.3415e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 89/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.9259e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 90/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.7445e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 91/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.0817e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 92/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.0311e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 93/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.6643e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 94/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.3861e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 95/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.3729e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 96/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.0283e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 97/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.3941e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 98/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.0179e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 99/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.7462e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 100/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7553e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 101/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.2216e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 102/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.9006e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 103/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.7650e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 104/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.6210e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 105/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.5512e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 106/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.5946e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 107/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.5208e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 108/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.5544e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 109/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.9822e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 110/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.4491e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 111/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.5623e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 112/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.1456e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 113/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.9008e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 114/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 8.3926e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 115/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7214e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 116/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.3044e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 117/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.6853e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 118/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7973e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 119/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.4480e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 120/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.9185e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 121/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.7457e-05 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 122/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7870e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 123/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.2914e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 124/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.0670e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 125/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.6192e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 126/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7476e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 127/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 7.0502e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 128/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.4331e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 129/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.9212e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 130/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 8.0945e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 131/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.1644e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 132/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7778e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 133/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.5973e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 134/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.7145e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 135/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.5988e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 136/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.1747e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 137/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.5293e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 138/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.5052e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 139/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.6321e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 140/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.7359e-05 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 141/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.1841e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 142/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.7798e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 143/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.8978e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 144/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.6573e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 145/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.2314e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 146/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.9996e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 147/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.5591e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 148/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.5507e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 149/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.2188e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 150/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.1591e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 151/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.8681e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 152/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.9222e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 153/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.7901e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 154/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.4154e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 155/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 7.0237e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 156/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.1612e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 157/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.2087e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 158/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.7346e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 159/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.6224e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 160/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.9424e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 161/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.1896e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 162/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.8718e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 163/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.7958e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 164/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.6772e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 165/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.2161e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 166/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.2331e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 167/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.8515e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 168/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.6509e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 169/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.8556e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 170/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.9408e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 171/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.1679e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 172/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.4102e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 173/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.6114e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 174/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.5719e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 175/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.7057e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 176/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.5844e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 177/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.3819e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 178/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.2430e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 179/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.5628e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 180/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.5625e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 181/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 6.1258e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 182/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.0640e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 183/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.6168e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 184/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.7992e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 185/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.9589e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 186/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.0672e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 187/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.8446e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 188/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.5945e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 189/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.4029e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 190/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.0945e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 191/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.6312e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 192/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.8088e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 193/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.1811e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 194/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.6717e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 195/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.3779e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 196/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.0296e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 197/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.5906e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 198/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.9008e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 199/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.7565e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 200/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.4608e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.1496e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 202/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 6.1729e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 203/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.9803e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 204/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.3218e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 205/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.4711e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 206/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.6709e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 207/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.7833e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 208/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.9455e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 209/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.3267e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 210/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.8993e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 211/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.5828e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 212/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.3967e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 213/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.6297e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 214/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.7961e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 215/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.1101e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 216/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.8311e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 217/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.6570e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 218/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 5.1041e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 219/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.4909e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 220/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.0390e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 221/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.4178e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 222/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.3220e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 223/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.5728e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 224/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.2293e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 225/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.2050e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 226/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.1404e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 227/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.3408e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 228/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.8049e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 229/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.3933e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 230/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.6042e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 231/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.9420e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 232/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 4.1753e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 233/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.7626e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 234/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.8701e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 235/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.4349e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 236/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.9570e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 237/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.4941e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 238/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.4266e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 239/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.6351e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 240/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.1280e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 241/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.6574e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 242/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.5046e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 243/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 5.4911e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 244/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 4.2590e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 245/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.5363e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 246/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.4232e-05 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 247/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.3962e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 248/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.4553e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 249/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.9717e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 250/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.6894e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 251/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.9276e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 252/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.7119e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 253/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.6414e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 254/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.8156e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 255/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.4618e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 256/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.6153e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 257/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.6861e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 258/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.1717e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 259/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.8874e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 260/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.4900e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 261/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.1236e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 262/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.6919e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 263/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.2413e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 264/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.8954e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 265/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.7519e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 266/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.7021e-05 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 267/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.8101e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 268/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.6754e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 269/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.4978e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 270/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.7099e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 271/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.9917e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 272/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 3.1070e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 273/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.4112e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 274/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.3747e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 275/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.6589e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 276/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.3339e-05 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 277/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.0425e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 278/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.4210e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 279/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.5511e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 280/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.5511e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 281/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.7636e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 282/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 3.3117e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 283/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.4621e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 284/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.4207e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 285/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.6539e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 286/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.5207e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 287/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.3280e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 288/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.1557e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 289/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.2721e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 290/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.2125e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 291/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.2993e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 292/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.1978e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 293/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.0854e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 294/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.3208e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 295/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.1350e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 296/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.4601e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 297/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.1849e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 298/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.0025e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 299/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.2651e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 300/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.8838e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 301/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.0863e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 302/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.2377e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 303/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.0522e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 304/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.9944e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 305/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.8917e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 306/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.3701e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 307/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.9385e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 308/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.0569e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 309/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 2.0396e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 310/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.9518e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 311/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.7478e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 312/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.6575e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 313/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 2.2155e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 314/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.8119e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 315/2000
# 32/32 [==============================] - 6s 189ms/step - loss: 1.6084e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 316/2000
# ...
# Epoch 1901/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.3039e-08 - accuracy: 1.0000 - val_loss: 2.6391e-04 - val_accuracy: 1.0000
# Epoch 1902/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 8.1491e-09 - accuracy: 1.0000 - val_loss: 2.6457e-04 - val_accuracy: 1.0000
# Epoch 1903/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.5483e-08 - accuracy: 1.0000 - val_loss: 2.6427e-04 - val_accuracy: 1.0000
# Epoch 1904/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.6880e-08 - accuracy: 1.0000 - val_loss: 2.6571e-04 - val_accuracy: 1.0000
# Epoch 1905/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.1874e-08 - accuracy: 1.0000 - val_loss: 2.6636e-04 - val_accuracy: 1.0000
# Epoch 1906/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.0361e-08 - accuracy: 1.0000 - val_loss: 2.6619e-04 - val_accuracy: 1.0000
# Epoch 1907/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.1758e-08 - accuracy: 1.0000 - val_loss: 2.6560e-04 - val_accuracy: 1.0000
# Epoch 1908/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 9.3132e-09 - accuracy: 1.0000 - val_loss: 2.6632e-04 - val_accuracy: 1.0000
# Epoch 1909/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.8743e-08 - accuracy: 1.0000 - val_loss: 2.6802e-04 - val_accuracy: 1.0000
# Epoch 1910/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.5134e-08 - accuracy: 1.0000 - val_loss: 2.6968e-04 - val_accuracy: 1.0000
# Epoch 1911/2000
# 32/32 [==============================] - 6s 186ms/step - loss: 1.0710e-08 - accuracy: 1.0000 - val_loss: 2.7022e-04 - val_accuracy: 1.0000
# Epoch 1912/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.1991e-08 - accuracy: 1.0000 - val_loss: 2.7122e-04 - val_accuracy: 1.0000
# Epoch 1913/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.5018e-08 - accuracy: 1.0000 - val_loss: 2.7179e-04 - val_accuracy: 1.0000
# Epoch 1914/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.6764e-08 - accuracy: 1.0000 - val_loss: 2.7182e-04 - val_accuracy: 1.0000
# Epoch 1915/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.1642e-08 - accuracy: 1.0000 - val_loss: 2.7168e-04 - val_accuracy: 1.0000
# Epoch 1916/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.0594e-08 - accuracy: 1.0000 - val_loss: 2.7138e-04 - val_accuracy: 1.0000
# Epoch 1917/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.4319e-08 - accuracy: 1.0000 - val_loss: 2.7317e-04 - val_accuracy: 1.0000
# Epoch 1918/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 2.1420e-08 - accuracy: 1.0000 - val_loss: 2.7399e-04 - val_accuracy: 1.0000
# Epoch 1919/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.2689e-08 - accuracy: 1.0000 - val_loss: 2.7343e-04 - val_accuracy: 1.0000
# Epoch 1920/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.6065e-08 - accuracy: 1.0000 - val_loss: 2.7351e-04 - val_accuracy: 1.0000
# Epoch 1921/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.0594e-08 - accuracy: 1.0000 - val_loss: 2.7329e-04 - val_accuracy: 1.0000
# Epoch 1922/2000
# 32/32 [==============================] - 6s 186ms/step - loss: 1.2689e-08 - accuracy: 1.0000 - val_loss: 2.7201e-04 - val_accuracy: 1.0000
# Epoch 1923/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.3853e-08 - accuracy: 1.0000 - val_loss: 2.7188e-04 - val_accuracy: 1.0000
# Epoch 1924/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0710e-08 - accuracy: 1.0000 - val_loss: 2.7028e-04 - val_accuracy: 1.0000
# Epoch 1925/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.2224e-08 - accuracy: 1.0000 - val_loss: 2.7123e-04 - val_accuracy: 1.0000
# Epoch 1926/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.5250e-08 - accuracy: 1.0000 - val_loss: 2.7245e-04 - val_accuracy: 1.0000
# Epoch 1927/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.2806e-08 - accuracy: 1.0000 - val_loss: 2.7442e-04 - val_accuracy: 1.0000
# Epoch 1928/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.8161e-08 - accuracy: 1.0000 - val_loss: 2.7270e-04 - val_accuracy: 1.0000
# Epoch 1929/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4203e-08 - accuracy: 1.0000 - val_loss: 2.7224e-04 - val_accuracy: 1.0000
# Epoch 1930/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4435e-08 - accuracy: 1.0000 - val_loss: 2.7163e-04 - val_accuracy: 1.0000
# Epoch 1931/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.2573e-08 - accuracy: 1.0000 - val_loss: 2.7337e-04 - val_accuracy: 1.0000
# Epoch 1932/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 2.6543e-08 - accuracy: 1.0000 - val_loss: 2.7578e-04 - val_accuracy: 1.0000
# Epoch 1933/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0128e-08 - accuracy: 1.0000 - val_loss: 2.7843e-04 - val_accuracy: 1.0000
# Epoch 1934/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.8743e-08 - accuracy: 1.0000 - val_loss: 2.7507e-04 - val_accuracy: 1.0000
# Epoch 1935/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.2922e-08 - accuracy: 1.0000 - val_loss: 2.7514e-04 - val_accuracy: 1.0000
# Epoch 1936/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.3388e-08 - accuracy: 1.0000 - val_loss: 2.7522e-04 - val_accuracy: 1.0000
# Epoch 1937/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 7.9162e-09 - accuracy: 1.0000 - val_loss: 2.7513e-04 - val_accuracy: 1.0000
# Epoch 1938/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.1176e-08 - accuracy: 1.0000 - val_loss: 2.7477e-04 - val_accuracy: 1.0000
# Epoch 1939/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4086e-08 - accuracy: 1.0000 - val_loss: 2.7589e-04 - val_accuracy: 1.0000
# Epoch 1940/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 9.7789e-09 - accuracy: 1.0000 - val_loss: 2.7684e-04 - val_accuracy: 1.0000
# Epoch 1941/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1991e-08 - accuracy: 1.0000 - val_loss: 2.7446e-04 - val_accuracy: 1.0000
# Epoch 1942/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 9.6625e-09 - accuracy: 1.0000 - val_loss: 2.7423e-04 - val_accuracy: 1.0000
# Epoch 1943/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1758e-08 - accuracy: 1.0000 - val_loss: 2.7398e-04 - val_accuracy: 1.0000
# Epoch 1944/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1874e-08 - accuracy: 1.0000 - val_loss: 2.7133e-04 - val_accuracy: 1.0000
# Epoch 1945/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4435e-08 - accuracy: 1.0000 - val_loss: 2.7177e-04 - val_accuracy: 1.0000
# Epoch 1946/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0361e-08 - accuracy: 1.0000 - val_loss: 2.7249e-04 - val_accuracy: 1.0000
# Epoch 1947/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0594e-08 - accuracy: 1.0000 - val_loss: 2.7265e-04 - val_accuracy: 1.0000
# Epoch 1948/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1874e-08 - accuracy: 1.0000 - val_loss: 2.7213e-04 - val_accuracy: 1.0000
# Epoch 1949/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.3155e-08 - accuracy: 1.0000 - val_loss: 2.7201e-04 - val_accuracy: 1.0000
# Epoch 1950/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.6065e-08 - accuracy: 1.0000 - val_loss: 2.7432e-04 - val_accuracy: 1.0000
# Epoch 1951/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0245e-08 - accuracy: 1.0000 - val_loss: 2.7471e-04 - val_accuracy: 1.0000
# Epoch 1952/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 9.8953e-09 - accuracy: 1.0000 - val_loss: 2.7397e-04 - val_accuracy: 1.0000
# Epoch 1953/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0594e-08 - accuracy: 1.0000 - val_loss: 2.6917e-04 - val_accuracy: 1.0000
# Epoch 1954/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.6531e-08 - accuracy: 1.0000 - val_loss: 2.6978e-04 - val_accuracy: 1.0000
# Epoch 1955/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 9.5461e-09 - accuracy: 1.0000 - val_loss: 2.6954e-04 - val_accuracy: 1.0000
# Epoch 1956/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.3853e-08 - accuracy: 1.0000 - val_loss: 2.6947e-04 - val_accuracy: 1.0000
# Epoch 1957/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.2922e-08 - accuracy: 1.0000 - val_loss: 2.6970e-04 - val_accuracy: 1.0000
# Epoch 1958/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.6764e-08 - accuracy: 1.0000 - val_loss: 2.6984e-04 - val_accuracy: 1.0000
# Epoch 1959/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.5367e-08 - accuracy: 1.0000 - val_loss: 2.7057e-04 - val_accuracy: 1.0000
# Epoch 1960/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1642e-08 - accuracy: 1.0000 - val_loss: 2.7005e-04 - val_accuracy: 1.0000
# Epoch 1961/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1758e-08 - accuracy: 1.0000 - val_loss: 2.6911e-04 - val_accuracy: 1.0000
# Epoch 1962/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.0804e-09 - accuracy: 1.0000 - val_loss: 2.6999e-04 - val_accuracy: 1.0000
# Epoch 1963/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4086e-08 - accuracy: 1.0000 - val_loss: 2.7145e-04 - val_accuracy: 1.0000
# Epoch 1964/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4785e-08 - accuracy: 1.0000 - val_loss: 2.7201e-04 - val_accuracy: 1.0000
# Epoch 1965/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 3.1781e-08 - accuracy: 1.0000 - val_loss: 2.6858e-04 - val_accuracy: 1.0000
# Epoch 1966/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 2.0256e-08 - accuracy: 1.0000 - val_loss: 2.6296e-04 - val_accuracy: 1.0000
# Epoch 1967/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 1.3737e-08 - accuracy: 1.0000 - val_loss: 2.6233e-04 - val_accuracy: 1.0000
# Epoch 1968/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.4668e-08 - accuracy: 1.0000 - val_loss: 2.6347e-04 - val_accuracy: 1.0000
# Epoch 1969/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.6182e-08 - accuracy: 1.0000 - val_loss: 2.6403e-04 - val_accuracy: 1.0000
# Epoch 1970/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.6764e-08 - accuracy: 1.0000 - val_loss: 2.6181e-04 - val_accuracy: 1.0000
# Epoch 1971/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1292e-08 - accuracy: 1.0000 - val_loss: 2.6075e-04 - val_accuracy: 1.0000
# Epoch 1972/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1991e-08 - accuracy: 1.0000 - val_loss: 2.6109e-04 - val_accuracy: 1.0000
# Epoch 1973/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.2573e-08 - accuracy: 1.0000 - val_loss: 2.6126e-04 - val_accuracy: 1.0000
# Epoch 1974/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0827e-08 - accuracy: 1.0000 - val_loss: 2.6104e-04 - val_accuracy: 1.0000
# Epoch 1975/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.6065e-08 - accuracy: 1.0000 - val_loss: 2.6041e-04 - val_accuracy: 1.0000
# Epoch 1976/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 8.7311e-09 - accuracy: 1.0000 - val_loss: 2.5458e-04 - val_accuracy: 1.0000
# Epoch 1977/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1758e-08 - accuracy: 1.0000 - val_loss: 2.5480e-04 - val_accuracy: 1.0000
# Epoch 1978/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.3970e-08 - accuracy: 1.0000 - val_loss: 2.5573e-04 - val_accuracy: 1.0000
# Epoch 1979/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.3621e-08 - accuracy: 1.0000 - val_loss: 2.5496e-04 - val_accuracy: 1.0000
# Epoch 1980/2000
# 32/32 [==============================] - 6s 188ms/step - loss: 9.7789e-09 - accuracy: 1.0000 - val_loss: 2.5508e-04 - val_accuracy: 1.0000
# Epoch 1981/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.5134e-08 - accuracy: 1.0000 - val_loss: 2.5667e-04 - val_accuracy: 1.0000
# Epoch 1982/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0361e-08 - accuracy: 1.0000 - val_loss: 2.5670e-04 - val_accuracy: 1.0000
# Epoch 1983/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 9.7789e-09 - accuracy: 1.0000 - val_loss: 2.5604e-04 - val_accuracy: 1.0000
# Epoch 1984/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.1758e-08 - accuracy: 1.0000 - val_loss: 2.5707e-04 - val_accuracy: 1.0000
# Epoch 1985/2000
# 32/32 [==============================] - 6s 187ms/step - loss: 1.0477e-08 - accuracy: 1.0000 - val_loss: 2.5780e-04 - val_accuracy: 1.0000
# Epoch 1986/2000
# 32/32 [==============================] - 6s 186ms/step - loss: 9.8953e-09 - accuracy: 1.0000 - val_loss: 2.5726e-04 - val_accuracy: 1.0000
# Epoch 1987/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.3271e-08 - accuracy: 1.0000 - val_loss: 2.5883e-04 - val_accuracy: 1.0000
# Epoch 1988/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.3039e-08 - accuracy: 1.0000 - val_loss: 2.5974e-04 - val_accuracy: 1.0000
# Epoch 1989/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.6997e-08 - accuracy: 1.0000 - val_loss: 2.6014e-04 - val_accuracy: 1.0000
# Epoch 1990/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.1991e-08 - accuracy: 1.0000 - val_loss: 2.5836e-04 - val_accuracy: 1.0000
# Epoch 1991/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.0012e-08 - accuracy: 1.0000 - val_loss: 2.5748e-04 - val_accuracy: 1.0000
# Epoch 1992/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.4552e-08 - accuracy: 1.0000 - val_loss: 2.5729e-04 - val_accuracy: 1.0000
# Epoch 1993/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.4435e-08 - accuracy: 1.0000 - val_loss: 2.5833e-04 - val_accuracy: 1.0000
# Epoch 1994/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 8.2655e-09 - accuracy: 1.0000 - val_loss: 2.5847e-04 - val_accuracy: 1.0000
# Epoch 1995/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.3853e-08 - accuracy: 1.0000 - val_loss: 2.5842e-04 - val_accuracy: 1.0000
# Epoch 1996/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.2806e-08 - accuracy: 1.0000 - val_loss: 2.5856e-04 - val_accuracy: 1.0000
# Epoch 1997/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.5134e-08 - accuracy: 1.0000 - val_loss: 2.6044e-04 - val_accuracy: 1.0000
# Epoch 1998/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.2340e-08 - accuracy: 1.0000 - val_loss: 2.6278e-04 - val_accuracy: 1.0000
# Epoch 1999/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 1.3155e-08 - accuracy: 1.0000 - val_loss: 2.6225e-04 - val_accuracy: 1.0000
# Epoch 2000/2000
# 32/32 [==============================] - 6s 185ms/step - loss: 2.2352e-08 - accuracy: 1.0000 - val_loss: 2.6186e-04 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 16/16 [==============================] - 5s 199ms/step - loss: 0.1826 - accuracy: 0.9665
# test_indoor_ds_results:test loss, test acc: [0.18258312344551086, 0.966469407081604]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 32/32 [==============================] - 10s 247ms/step - loss: 1.5050 - accuracy: 0.8637
# test_outdoor_ds_results:test loss, test acc: [1.5050033330917358, 0.863725483417511]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 18/18 [==============================] - 4s 188ms/step - loss: 1.5940 - accuracy: 0.8366
# test_belt_ds_results:test loss, test acc: [1.5939732789993286, 0.8365553617477417]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_ResNet152V2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 16/16 [==============================] - 5s 148ms/step - loss: 0.1548 - accuracy: 0.9566
# 32/32 [==============================] - 5s 149ms/step - loss: 0.9662 - accuracy: 0.8471
# 18/18 [==============================] - 3s 148ms/step - loss: 0.9672 - accuracy: 0.8383
# Epoch200
#  test_indoor_acc=0.9566075205802917
#  test_outdoor_acc=0.8470588326454163
#  test_belt_acc=0.8383128046989441
# 16/16 [==============================] - 5s 148ms/step - loss: 0.1655 - accuracy: 0.9586
# 32/32 [==============================] - 5s 149ms/step - loss: 1.1077 - accuracy: 0.8500
# 18/18 [==============================] - 3s 148ms/step - loss: 1.1665 - accuracy: 0.8383
# Epoch400
#  test_indoor_acc=0.9585798978805542
#  test_outdoor_acc=0.8500000238418579
#  test_belt_acc=0.8383128046989441
# 16/16 [==============================] - 5s 148ms/step - loss: 0.1634 - accuracy: 0.9665
# 32/32 [==============================] - 5s 148ms/step - loss: 1.2555 - accuracy: 0.8520
# 18/18 [==============================] - 3s 148ms/step - loss: 1.3311 - accuracy: 0.8383
# Epoch600
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8519607782363892
#  test_belt_acc=0.8383128046989441
# 16/16 [==============================] - 5s 148ms/step - loss: 0.1701 - accuracy: 0.9625
# 32/32 [==============================] - 5s 149ms/step - loss: 1.3444 - accuracy: 0.8559
# 18/18 [==============================] - 3s 147ms/step - loss: 1.4430 - accuracy: 0.8366
# Epoch800
#  test_indoor_acc=0.9625246524810791
#  test_outdoor_acc=0.8558823466300964
#  test_belt_acc=0.8365553617477417
# 16/16 [==============================] - 5s 148ms/step - loss: 0.1726 - accuracy: 0.9665
# 32/32 [==============================] - 5s 149ms/step - loss: 1.4121 - accuracy: 0.8569
# 18/18 [==============================] - 3s 148ms/step - loss: 1.5059 - accuracy: 0.8348
# Epoch1000
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8568627238273621
#  test_belt_acc=0.8347979187965393
# 16/16 [==============================] - 5s 149ms/step - loss: 0.1758 - accuracy: 0.9665
# 32/32 [==============================] - 5s 150ms/step - loss: 1.4415 - accuracy: 0.8578
# 18/18 [==============================] - 3s 150ms/step - loss: 1.5296 - accuracy: 0.8366
# Epoch1200
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8578431606292725
#  test_belt_acc=0.8365553617477417
# 16/16 [==============================] - 5s 149ms/step - loss: 0.1773 - accuracy: 0.9665
# 32/32 [==============================] - 5s 150ms/step - loss: 1.4614 - accuracy: 0.8608
# 18/18 [==============================] - 3s 150ms/step - loss: 1.5564 - accuracy: 0.8348
# Epoch1400
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8607842922210693
#  test_belt_acc=0.8347979187965393
# 16/16 [==============================] - 5s 149ms/step - loss: 0.1755 - accuracy: 0.9645
# 32/32 [==============================] - 5s 150ms/step - loss: 1.4806 - accuracy: 0.8618
# 18/18 [==============================] - 3s 149ms/step - loss: 1.5629 - accuracy: 0.8348
# Epoch1600
#  test_indoor_acc=0.9644970297813416
#  test_outdoor_acc=0.8617647290229797
#  test_belt_acc=0.8347979187965393
# 16/16 [==============================] - 5s 149ms/step - loss: 0.1790 - accuracy: 0.9665
# 32/32 [==============================] - 5s 150ms/step - loss: 1.4950 - accuracy: 0.8627
# 18/18 [==============================] - 3s 149ms/step - loss: 1.5884 - accuracy: 0.8366
# Epoch1800
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8627451062202454
#  test_belt_acc=0.8365553617477417
# 16/16 [==============================] - 5s 150ms/step - loss: 0.1826 - accuracy: 0.9665
# 32/32 [==============================] - 5s 150ms/step - loss: 1.5050 - accuracy: 0.8637
# 18/18 [==============================] - 3s 150ms/step - loss: 1.5940 - accuracy: 0.8366
# Epoch2000
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.863725483417511
#  test_belt_acc=0.8365553617477417

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8889167507489523
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9566075205802917,
#  0.9585798978805542,
#  0.966469407081604,
#  0.9625246524810791,
#  0.966469407081604,
#  0.966469407081604,
#  0.966469407081604,
#  0.9644970297813416,
#  0.966469407081604,
#  0.966469407081604]

# %%
test_outdoor_acc
# Out:
# [0.8470588326454163,
#  0.8500000238418579,
#  0.8519607782363892,
#  0.8558823466300964,
#  0.8568627238273621,
#  0.8578431606292725,
#  0.8607842922210693,
#  0.8617647290229797,
#  0.8627451062202454,
#  0.863725483417511]

# %%
test_belt_acc
# Out:
# [0.8383128046989441,
#  0.8383128046989441,
#  0.8383128046989441,
#  0.8365553617477417,
#  0.8347979187965393,
#  0.8365553617477417,
#  0.8347979187965393,
#  0.8347979187965393,
#  0.8365553617477417,
#  0.8365553617477417]

# %%
test_indoor_loss
# Out:
# [0.15483532845973969,
#  0.16549161076545715,
#  0.16336309909820557,
#  0.1701151579618454,
#  0.17255555093288422,
#  0.17578154802322388,
#  0.1772509068250656,
#  0.17545326054096222,
#  0.17899233102798462,
#  0.18258312344551086]

# %%
test_outdoor_loss
# Out:
# [0.9661703109741211,
#  1.1077462434768677,
#  1.2555410861968994,
#  1.3444297313690186,
#  1.4121336936950684,
#  1.441508173942566,
#  1.4613540172576904,
#  1.4805680513381958,
#  1.4950381517410278,
#  1.5050033330917358]

# %%
test_belt_loss
# Out:
# [0.9672288298606873,
#  1.1664706468582153,
#  1.3310872316360474,
#  1.4430043697357178,
#  1.505889654159546,
#  1.529572606086731,
#  1.5563771724700928,
#  1.562857985496521,
#  1.5883651971817017,
#  1.5939732789993286]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.resnet_v2 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507
# train_outdoor num x,y : 1020,1020
# train_belt num x,y : 569,569
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1849
# FP=247
# acc=0.8821564885496184
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 75.3731343283582%
# CottonBall acc = 96.40718562874252%
# ExtensionTube acc = 53.65853658536586%
# Glove acc = 95.53571428571429%
# Mask acc = 99.48051948051948%
# NGTube acc = 54.83870967741935%
# Needle acc = 95.71428571428572%
# OxygenMask acc = 93.23308270676691%
# Syringe acc = 98.85931558935361%
# UrineBag acc = 66.66666666666666%
#
#
#
# all_avg_eachclass = 82.97671506631926%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[101,   0,   2,   2,  10,   6,   7,   0,   3,   3],
#        [  0, 161,   0,   6,   0,   0,   0,   0,   0,   0],
#        [  4,   3,  66,   0,  20,  28,   0,   2,   0,   0],
#        [  1,   0,   0, 321,  14,   0,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 383,   0,   0,   2,   0,   0],
#        [  1,   1,   1,  10,  47,  85,   3,   3,   4,   0],
#        [  0,   0,   0,   1,   5,   0, 268,   1,   5,   0],
#        [  0,   0,   0,   7,   1,   0,   0, 124,   0,   1],
#        [  0,   0,   0,   0,   2,   0,   0,   1, 260,   0],
#        [  0,   0,   0,   1,  25,   0,   0,  14,   0,  80]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[75.37313433,  0.        ,  1.49253731,  1.49253731,  7.46268657,
#          4.47761194,  5.2238806 ,  0.        ,  2.23880597,  2.23880597],
#        [ 0.        , 96.40718563,  0.        ,  3.59281437,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 3.25203252,  2.43902439, 53.65853659,  0.        , 16.2601626 ,
#         22.76422764,  0.        ,  1.62601626,  0.        ,  0.        ],
#        [ 0.29761905,  0.        ,  0.        , 95.53571429,  4.16666667,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        , 99.48051948,
#          0.        ,  0.        ,  0.51948052,  0.        ,  0.        ],
#        [ 0.64516129,  0.64516129,  0.64516129,  6.4516129 , 30.32258065,
#         54.83870968,  1.93548387,  1.93548387,  2.58064516,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.35714286,  1.78571429,
#          0.        , 95.71428571,  0.35714286,  1.78571429,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  5.26315789,  0.7518797 ,
#          0.        ,  0.        , 93.23308271,  0.        ,  0.7518797 ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.76045627,
#          0.        ,  0.        ,  0.38022814, 98.85931559,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.83333333, 20.83333333,
#          0.        ,  0.        , 11.66666667,  0.        , 66.66666667]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
