# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input,MobileNetV2

mobilenetv2_model = keras.applications.MobileNetV2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

mobilenetv2_model_nooutput = mobilenetv2_model.layers[-2].output
custom_mobilenetv2_model = Model(inputs = mobilenetv2_model.input, outputs = mobilenetv2_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_mobilenetv2_model.trainable = False
for layer in custom_mobilenetv2_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_mobilenetv2_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           out_relu[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_mobilenetv2_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 3,573,828
# Trainable params: 1,315,844
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 34s 200ms/step - loss: 0.5314 - accuracy: 0.8342 - val_loss: 0.1780 - val_accuracy: 0.9340
# Epoch 2/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.1536 - accuracy: 0.9405 - val_loss: 0.1546 - val_accuracy: 0.9534
# Epoch 3/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0834 - accuracy: 0.9729 - val_loss: 0.1545 - val_accuracy: 0.9521
# Epoch 4/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0474 - accuracy: 0.9868 - val_loss: 0.1332 - val_accuracy: 0.9547
# Epoch 5/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0460 - accuracy: 0.9845 - val_loss: 0.1062 - val_accuracy: 0.9573
# Epoch 6/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0473 - accuracy: 0.9845 - val_loss: 0.1375 - val_accuracy: 0.9444
# Epoch 7/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0400 - accuracy: 0.9877 - val_loss: 0.2104 - val_accuracy: 0.9301
# Epoch 8/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0258 - accuracy: 0.9922 - val_loss: 0.1091 - val_accuracy: 0.9625
# Epoch 9/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 0.1249 - val_accuracy: 0.9508
# Epoch 10/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.1362 - val_accuracy: 0.9508
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 11/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.1110 - val_accuracy: 0.9651
# Epoch 12/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9651
# Epoch 13/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9638
# Epoch 14/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9638
# Epoch 15/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9625
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 16/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9625
# Epoch 17/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9638
# Epoch 18/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9638
# Epoch 19/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 20/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 21/2000
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
# Epoch 22/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 23/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 24/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9638
# Epoch 25/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9638
# Epoch 26/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9638loss: 0.0
# Epoch 27/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9638
# Epoch 28/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9638
# Epoch 29/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9638
# Epoch 30/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9638
# Epoch 31/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9638
# Epoch 32/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9638
# Epoch 33/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9638 accuracy: 1.00
# Epoch 34/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 35/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9638
# Epoch 36/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9638
# Epoch 37/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9638
# Epoch 38/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
# Epoch 39/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 40/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 41/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
# Epoch 42/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
# Epoch 43/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9638
# Epoch 44/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9638
# Epoch 45/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9638
# Epoch 46/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9638
# Epoch 47/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
# Epoch 48/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9638
# Epoch 49/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9638
# Epoch 50/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9638
# Epoch 51/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1155 - val_accuracy: 0.9638
# Epoch 52/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9638
# Epoch 53/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9638
# Epoch 54/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9638
# Epoch 55/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9638
# Epoch 56/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9638
# Epoch 57/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9638
# Epoch 58/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9638
# Epoch 59/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9638
# Epoch 60/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9638
# Epoch 61/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9638
# Epoch 62/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9638
# Epoch 63/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9638
# Epoch 64/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9638
# Epoch 65/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9638
# Epoch 66/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9638
# Epoch 67/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9638
# Epoch 68/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9638
# Epoch 69/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9638
# Epoch 70/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9638
# Epoch 71/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9625
# Epoch 72/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9638
# Epoch 73/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9638
# Epoch 74/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9638
# Epoch 75/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9638
# Epoch 76/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9625
# Epoch 77/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9638
# Epoch 78/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9638
# Epoch 79/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9638
# Epoch 80/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9638
# Epoch 81/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9638
# Epoch 82/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9638
# Epoch 83/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9638
# Epoch 84/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9638
# Epoch 85/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.1825e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9638
# Epoch 86/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9638
# Epoch 87/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9638
# Epoch 88/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9638
# Epoch 89/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9625
# Epoch 90/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9625
# Epoch 91/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.3952e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9638
# Epoch 92/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.4595e-04 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9638
# Epoch 93/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.6438e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9638
# Epoch 94/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.0451e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9638
# Epoch 95/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.3943e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9638
# Epoch 96/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 8.7151e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9625
# Epoch 97/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 8.5530e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9625
# Epoch 98/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 8.7449e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9625
# Epoch 99/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.6028e-04 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9625
# Epoch 100/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 8.3431e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9638
# Epoch 101/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 8.3483e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9625
# Epoch 102/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.9455e-04 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9625
# Epoch 103/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.4166e-04 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9625
# Epoch 104/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.8393e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9625
# Epoch 105/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.9791e-04 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9625
# Epoch 106/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.4849e-04 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9625
# Epoch 107/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.7262e-04 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9625
# Epoch 108/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.4992e-04 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9625
# Epoch 109/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.0197e-04 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9625
# Epoch 110/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.6842e-04 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9625
# Epoch 111/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.9832e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9625
# Epoch 112/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.5746e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9625
# Epoch 113/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.0601e-04 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9638
# Epoch 114/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.1108e-04 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9625
# Epoch 115/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 7.4541e-04 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9625
# Epoch 116/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.6462e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9625
# Epoch 117/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 7.3697e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9625
# Epoch 118/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.2547e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9612
# Epoch 119/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 7.0763e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9612
# Epoch 120/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.7709e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9625
# Epoch 121/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.2804e-04 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9625
# Epoch 122/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.4464e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9625
# Epoch 123/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.8956e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9612
# Epoch 124/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.7076e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9612
# Epoch 125/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.3479e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9612
# Epoch 126/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.0583e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9612
# Epoch 127/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.2652e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9612
# Epoch 128/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.6701e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9625
# Epoch 129/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.2134e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9625
# Epoch 130/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.7215e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9625
# Epoch 131/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 5.7423e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9625
# Epoch 132/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 5.2402e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9625
# Epoch 133/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.5938e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9625
# Epoch 134/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.6959e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9612
# Epoch 135/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.2543e-04 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9612
# Epoch 136/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.6836e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9625
# Epoch 137/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.8794e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9625
# Epoch 138/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.8943e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9625
# Epoch 139/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.1566e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9625
# Epoch 140/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.0854e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9625
# Epoch 141/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 5.1750e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9625
# Epoch 142/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.2620e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9612
# Epoch 143/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.7637e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9625
# Epoch 144/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.7235e-04 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9625
# Epoch 145/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.2907e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9625
# Epoch 146/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.9849e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9612
# Epoch 147/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.8797e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9612
# Epoch 148/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.1081e-04 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9612
# Epoch 149/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.4919e-04 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9612
# Epoch 150/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.4918e-04 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9612
# Epoch 151/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.7837e-04 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9612
# Epoch 152/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.0450e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9612
# Epoch 153/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.5321e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9625
# Epoch 154/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.5698e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9612
# Epoch 155/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.3394e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9612
# Epoch 156/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 3.9699e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9612
# Epoch 157/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 3.9804e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9612
# Epoch 158/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 4.0455e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9612
# Epoch 159/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.0933e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9612
# Epoch 160/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.0929e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9612
# Epoch 161/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.1732e-04 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9625
# Epoch 162/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.8188e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9612
# Epoch 163/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.7141e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9612
# Epoch 164/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.7616e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9612
# Epoch 165/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.4673e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9612
# Epoch 166/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.1148e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9612
# Epoch 167/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.0602e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9612
# Epoch 168/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.4957e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9612
# Epoch 169/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.5375e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9612
# Epoch 170/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.5733e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9612
# Epoch 171/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.3205e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9612
# Epoch 172/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.5624e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9612
# Epoch 173/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.2983e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9612
# Epoch 174/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.1745e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9612
# Epoch 175/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.1106e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9612
# Epoch 176/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.1250e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9612
# Epoch 177/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.6394e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9612
# Epoch 178/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.8523e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9612
# Epoch 179/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.0388e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9612
# Epoch 180/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.0345e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9612
# Epoch 181/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.9228e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9612
# Epoch 182/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.4382e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9612
# Epoch 183/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.9369e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9612
# Epoch 184/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.7235e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9612
# Epoch 185/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.9158e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9612
# Epoch 186/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.8417e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9612
# Epoch 187/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3973e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9612
# Epoch 188/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3453e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9612
# Epoch 189/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.5622e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9612
# Epoch 190/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3808e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9612
# Epoch 191/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6399e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9612
# Epoch 192/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.2617e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9612
# Epoch 193/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.2878e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9612
# Epoch 194/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.4688e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9612
# Epoch 195/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.4083e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9612
# Epoch 196/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3853e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9599
# Epoch 197/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3867e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9612
# Epoch 198/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.4293e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9612
# Epoch 199/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1645e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9612
# Epoch 200/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1033e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9612
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.4815e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9586
# Epoch 202/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1293e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9599
# Epoch 203/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1587e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9612
# Epoch 204/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.3575e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9612
# Epoch 205/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.2613e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9599
# Epoch 206/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9997e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9612
# Epoch 207/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6873e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9599
# Epoch 208/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9704e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9612
# Epoch 209/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.0194e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9612
# Epoch 210/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8810e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9612
# Epoch 211/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8343e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9599
# Epoch 212/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7457e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9612
# Epoch 213/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6672e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9599
# Epoch 214/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8326e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9612
# Epoch 215/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7481e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9612
# Epoch 216/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9340e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9612
# Epoch 217/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8877e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9599
# Epoch 218/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7546e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9599 accura
# Epoch 219/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6815e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9599
# Epoch 220/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5127e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9599
# Epoch 221/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5915e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9599
# Epoch 222/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4734e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9586
# Epoch 223/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5205e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9586
# Epoch 224/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5811e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9599
# Epoch 225/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4423e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9599
# Epoch 226/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3967e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9599
# Epoch 227/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5586e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9599
# Epoch 228/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4049e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9599
# Epoch 229/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6030e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9573
# Epoch 230/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3134e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9573
# Epoch 231/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3488e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9573
# Epoch 232/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5231e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9599
# Epoch 233/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3958e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9599
# Epoch 234/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4488e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9599
# Epoch 235/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2098e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9586
# Epoch 236/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2025e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9586
# Epoch 237/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1407e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9599
# Epoch 238/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1956e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9586
# Epoch 239/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2056e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9586
# Epoch 240/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2342e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9599
# Epoch 241/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2406e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9612
# Epoch 242/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1080e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9586
# Epoch 243/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.0728e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9599
# Epoch 244/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1910e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9586
# Epoch 245/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.0595e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9586
# Epoch 246/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1406e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9599
# Epoch 247/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1246e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9599
# Epoch 248/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1883e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9599
# Epoch 249/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.0094e-04 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9599
# Epoch 250/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.0165e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9586
# Epoch 251/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1037e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9599
# Epoch 252/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.0625e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9599
# Epoch 253/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 9.4367e-05 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9586
# Epoch 254/2000
# 49/49 [==============================] - 4s 74ms/step - loss: 8.6596e-05 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9586
# Epoch 255/2000
# 49/49 [==============================] - 4s 74ms/step - loss: 9.4727e-05 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9586
# Epoch 256/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 9.0235e-05 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9586
# Epoch 257/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.2686e-05 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9586
# Epoch 258/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.5618e-05 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9573
# Epoch 259/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 9.5328e-05 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9586
# Epoch 260/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.8166e-05 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9586
# Epoch 261/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.2581e-05 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9586
# Epoch 262/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.5710e-05 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9573
# Epoch 263/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.8858e-05 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9573
# Epoch 264/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.9138e-05 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9586
# Epoch 265/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 7.4375e-05 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9586
# Epoch 266/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 7.9830e-05 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9573
# Epoch 267/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 7.6766e-05 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9573
# Epoch 268/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 7.6421e-05 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9586
# Epoch 269/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.4970e-05 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9586
# Epoch 270/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 7.1775e-05 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9573
# Epoch 271/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.8230e-05 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9573
# Epoch 272/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 7.3810e-05 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9599
# Epoch 273/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.7036e-05 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9586
# Epoch 274/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.2383e-05 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9586
# Epoch 275/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 8.0307e-05 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9573
# Epoch 276/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.0143e-05 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9586
# Epoch 277/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.7954e-05 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9599
# Epoch 278/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.1911e-05 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9586
# Epoch 279/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.0260e-05 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9599
# Epoch 280/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.7644e-05 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9586
# Epoch 281/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.3558e-05 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9586
# Epoch 282/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.8024e-05 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9586
# Epoch 283/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.7843e-05 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9573
# Epoch 284/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.3597e-05 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9599
# Epoch 285/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.7622e-05 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9586
# Epoch 286/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.2271e-05 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9599
# Epoch 287/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.1530e-05 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9599
# Epoch 288/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 6.0581e-05 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9586
# Epoch 289/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.7029e-05 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9586
# Epoch 290/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.3497e-05 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9599
# Epoch 291/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.1874e-05 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9586
# Epoch 292/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.8319e-05 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9586
# Epoch 293/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.9372e-05 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9586
# Epoch 294/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.3786e-05 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9599
# Epoch 295/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.8469e-05 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9586
# Epoch 296/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.7518e-05 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9573
# Epoch 297/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.0835e-05 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9599
# Epoch 298/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.4907e-05 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9599
# Epoch 299/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.0663e-05 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9586
# Epoch 300/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.7965e-05 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9599
# Epoch 301/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.5295e-05 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9599
# Epoch 302/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.2695e-05 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9599
# Epoch 303/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.1100e-05 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9573
# Epoch 304/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.4892e-05 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9599
# Epoch 305/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.6448e-05 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9599
# Epoch 306/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.8405e-05 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9586
# Epoch 307/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.4164e-05 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9599
# Epoch 308/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.8271e-05 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9586
# Epoch 309/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.5019e-05 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9573
# Epoch 310/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.0745e-05 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9612
# Epoch 311/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 5.2715e-05 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9586
# Epoch 312/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.0215e-05 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9586
# Epoch 313/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.7730e-05 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9599
# Epoch 314/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.3796e-05 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9586
# Epoch 315/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.8071e-05 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9599
# Epoch 316/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.6056e-05 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9599
# Epoch 317/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 4.1650e-05 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.9599
# Epoch 318/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.2688e-05 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9599
# Epoch 319/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.3231e-05 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9599
# Epoch 320/2000
# ...
# Epoch 1898/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6177e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9612
# Epoch 1899/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.2725e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9612
# Epoch 1900/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1492e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9612
# Epoch 1901/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7333e-08 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9612
# Epoch 1902/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7101e-08 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9612
# Epoch 1903/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5753e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9612
# Epoch 1904/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7063e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9612
# Epoch 1905/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5368e-08 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9612
# Epoch 1906/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.5883e-08 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9612
# Epoch 1907/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9104e-08 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9612
# Epoch 1908/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1748e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9599
# Epoch 1909/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9143e-08 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9599
# Epoch 1910/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5214e-08 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9599
# Epoch 1911/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5561e-08 - accuracy: 1.0000 - val_loss: 0.2555 - val_accuracy: 0.9599
# Epoch 1912/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5407e-08 - accuracy: 1.0000 - val_loss: 0.2555 - val_accuracy: 0.9599
# Epoch 1913/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6562e-08 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9599
# Epoch 1914/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4521e-08 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9599
# Epoch 1915/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2788e-08 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9599
# Epoch 1916/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8796e-08 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9599
# Epoch 1917/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.2378e-08 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9599
# Epoch 1918/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.6937e-08 - accuracy: 1.0000 - val_loss: 0.2563 - val_accuracy: 0.9599
# Epoch 1919/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8026e-08 - accuracy: 1.0000 - val_loss: 0.2562 - val_accuracy: 0.9599
# Epoch 1920/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6216e-08 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9599
# Epoch 1921/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8295e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9599
# Epoch 1922/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6254e-08 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9599
# Epoch 1923/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5907e-08 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9599
# Epoch 1924/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.8425e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9599
# Epoch 1925/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4097e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9599
# Epoch 1926/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5407e-08 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9599
# Epoch 1927/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7217e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9599
# Epoch 1928/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.5151e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9599
# Epoch 1929/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.0183e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9599
# Epoch 1930/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4405e-08 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9599
# Epoch 1931/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6832e-08 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9599
# Epoch 1932/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4367e-08 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9599
# Epoch 1933/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6422e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9599
# Epoch 1934/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1723e-08 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9599
# Epoch 1935/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7641e-08 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9612
# Epoch 1936/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9605e-08 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9612
# Epoch 1937/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7602e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9612
# Epoch 1938/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5599e-08 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9612
# Epoch 1939/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8257e-08 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9612
# Epoch 1940/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2287e-08 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9612
# Epoch 1941/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3019e-08 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9612
# Epoch 1942/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.2956e-08 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9612
# Epoch 1943/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7140e-08 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9599
# Epoch 1944/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8873e-08 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9599
# Epoch 1945/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4598e-08 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9599
# Epoch 1946/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9143e-08 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9612
# Epoch 1947/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1338e-08 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9612
# Epoch 1948/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7487e-08 - accuracy: 1.0000 - val_loss: 0.2575 - val_accuracy: 0.9612
# Epoch 1949/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.4304e-08 - accuracy: 1.0000 - val_loss: 0.2577 - val_accuracy: 0.9612s - loss: 2.4304e-08 - accuracy: 1.00
# Epoch 1950/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6138e-08 - accuracy: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9612
# Epoch 1951/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9682e-08 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9612
# Epoch 1952/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0322e-08 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9612
# Epoch 1953/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2788e-08 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9612
# Epoch 1954/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5638e-08 - accuracy: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9612
# Epoch 1955/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1223e-08 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9612
# Epoch 1956/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9643e-08 - accuracy: 1.0000 - val_loss: 0.2575 - val_accuracy: 0.9612
# Epoch 1957/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9759e-08 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9612
# Epoch 1958/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8141e-08 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9612
# Epoch 1959/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.0183e-08 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9612
# Epoch 1960/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3943e-08 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9612
# Epoch 1961/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7795e-08 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9612
# Epoch 1962/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9798e-08 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9612
# Epoch 1963/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8488e-08 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9612
# Epoch 1964/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6870e-08 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9612
# Epoch 1965/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7410e-08 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9612
# Epoch 1966/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.0529e-08 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9612
# Epoch 1967/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8565e-08 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9612
# Epoch 1968/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3789e-08 - accuracy: 1.0000 - val_loss: 0.2580 - val_accuracy: 0.9612
# Epoch 1969/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7679e-08 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9612
# Epoch 1970/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6909e-08 - accuracy: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9612
# Epoch 1971/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.2455e-08 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9612
# Epoch 1972/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3866e-08 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9612
# Epoch 1973/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7987e-08 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9612
# Epoch 1974/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5830e-08 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9612
# Epoch 1975/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1786e-08 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9612
# Epoch 1976/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7101e-08 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9612
# Epoch 1977/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4944e-08 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9612
# Epoch 1978/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6961e-08 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9612
# Epoch 1979/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.6562e-08 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9612
# Epoch 1980/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.5176e-08 - accuracy: 1.0000 - val_loss: 0.2594 - val_accuracy: 0.9612
# Epoch 1981/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1800e-08 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9612
# Epoch 1982/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.7756e-08 - accuracy: 1.0000 - val_loss: 0.2594 - val_accuracy: 0.9612
# Epoch 1983/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1069e-08 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9612
# Epoch 1984/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3943e-08 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9612
# Epoch 1985/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2749e-08 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9612
# Epoch 1986/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4906e-08 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9612
# Epoch 1987/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9412e-08 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9612
# Epoch 1988/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.2840e-08 - accuracy: 1.0000 - val_loss: 0.2587 - val_accuracy: 0.9612
# Epoch 1989/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.5305e-08 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.9612
# Epoch 1990/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 3.6243e-08 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9612
# Epoch 1991/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.0876e-08 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9612
# Epoch 1992/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.8026e-08 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9612- loss: 1.8684e-08 - accuracy
# Epoch 1993/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.9027e-08 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9612
# Epoch 1994/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.2455e-08 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9612
# Epoch 1995/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3110e-08 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9612
# Epoch 1996/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.3649e-08 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9599
# Epoch 1997/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3905e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9599
# Epoch 1998/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2980e-08 - accuracy: 1.0000 - val_loss: 0.2565 - val_accuracy: 0.9599
# Epoch 1999/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2942e-08 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9599
# Epoch 2000/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.1492e-08 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9599
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 12s 290ms/step - loss: 1.0866 - accuracy: 0.8612
# test_indoor_ds_results:test loss, test acc: [1.0866163969039917, 0.8612040281295776]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 24s 410ms/step - loss: 1.1936 - accuracy: 0.8408
# test_outdoor_ds_results:test loss, test acc: [1.1935995817184448, 0.8407643437385559]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 6s 139ms/step - loss: 1.7607 - accuracy: 0.8128
# test_belt_ds_results:test loss, test acc: [1.760746955871582, 0.8127833008766174]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 3s 58ms/step - loss: 0.5453 - accuracy: 0.8623
# 50/50 [==============================] - 3s 59ms/step - loss: 0.6191 - accuracy: 0.8430
# 35/35 [==============================] - 2s 59ms/step - loss: 0.8990 - accuracy: 0.8155 0s - loss: 0.8578 -
# Epoch200
#  test_indoor_acc=0.8623188138008118
#  test_outdoor_acc=0.8429936170578003
#  test_belt_acc=0.8155031800270081
# 29/29 [==============================] - 2s 57ms/step - loss: 0.7019 - accuracy: 0.8618
# 50/50 [==============================] - 3s 58ms/step - loss: 0.7855 - accuracy: 0.8436
# 35/35 [==============================] - 2s 58ms/step - loss: 1.1408 - accuracy: 0.8123
# Epoch400
#  test_indoor_acc=0.8617614507675171
#  test_outdoor_acc=0.8436305522918701
#  test_belt_acc=0.8123300075531006
# 29/29 [==============================] - 3s 57ms/step - loss: 0.8326 - accuracy: 0.8623
# 50/50 [==============================] - 3s 58ms/step - loss: 0.9291 - accuracy: 0.8420
# 35/35 [==============================] - 2s 58ms/step - loss: 1.3540 - accuracy: 0.8132 1s - loss: 1.3755  - ETA: 0s - loss: 1
# Epoch600
#  test_indoor_acc=0.8623188138008118
#  test_outdoor_acc=0.8420382142066956
#  test_belt_acc=0.813236653804779
# 29/29 [==============================] - 2s 57ms/step - loss: 0.9293 - accuracy: 0.8634
# 50/50 [==============================] - 3s 58ms/step - loss: 1.0122 - accuracy: 0.8433
# 35/35 [==============================] - 2s 58ms/step - loss: 1.5103 - accuracy: 0.8119
# Epoch800
#  test_indoor_acc=0.8634336590766907
#  test_outdoor_acc=0.8433120846748352
#  test_belt_acc=0.8118767142295837
# 29/29 [==============================] - 3s 57ms/step - loss: 0.9834 - accuracy: 0.8618
# 50/50 [==============================] - 3s 59ms/step - loss: 1.0779 - accuracy: 0.8420
# 35/35 [==============================] - 2s 58ms/step - loss: 1.5948 - accuracy: 0.8119
# Epoch1000
#  test_indoor_acc=0.8617614507675171
#  test_outdoor_acc=0.8420382142066956
#  test_belt_acc=0.8118767142295837
# 29/29 [==============================] - 2s 57ms/step - loss: 1.0163 - accuracy: 0.8623
# 50/50 [==============================] - 3s 58ms/step - loss: 1.1168 - accuracy: 0.8411
# 35/35 [==============================] - 2s 58ms/step - loss: 1.6473 - accuracy: 0.8132
# Epoch1200
#  test_indoor_acc=0.8623188138008118
#  test_outdoor_acc=0.8410828113555908
#  test_belt_acc=0.813236653804779
# 29/29 [==============================] - 2s 57ms/step - loss: 1.0422 - accuracy: 0.8623
# 50/50 [==============================] - 3s 58ms/step - loss: 1.1385 - accuracy: 0.8427
# 35/35 [==============================] - 2s 58ms/step - loss: 1.6882 - accuracy: 0.8123
# Epoch1400
#  test_indoor_acc=0.8623188138008118
#  test_outdoor_acc=0.8426751494407654
#  test_belt_acc=0.8123300075531006
# 29/29 [==============================] - 3s 58ms/step - loss: 1.0581 - accuracy: 0.8601
# 50/50 [==============================] - 3s 59ms/step - loss: 1.1640 - accuracy: 0.8414
# 35/35 [==============================] - 2s 59ms/step - loss: 1.7069 - accuracy: 0.8128
# Epoch1600
#  test_indoor_acc=0.8600891828536987
#  test_outdoor_acc=0.8414012789726257
#  test_belt_acc=0.8127833008766174
# 29/29 [==============================] - 3s 57ms/step - loss: 1.0733 - accuracy: 0.8618
# 50/50 [==============================] - 3s 58ms/step - loss: 1.1808 - accuracy: 0.8408
# 35/35 [==============================] - 2s 58ms/step - loss: 1.7381 - accuracy: 0.8128 0s - loss: 1.6625 - accura
# Epoch1800
#  test_indoor_acc=0.8617614507675171
#  test_outdoor_acc=0.8407643437385559
#  test_belt_acc=0.8127833008766174
# 29/29 [==============================] - 2s 58ms/step - loss: 1.0866 - accuracy: 0.8612
# 50/50 [==============================] - 3s 59ms/step - loss: 1.1936 - accuracy: 0.8408
# 35/35 [==============================] - 2s 59ms/step - loss: 1.7607 - accuracy: 0.8128
# Epoch2000
#  test_indoor_acc=0.8612040281295776
#  test_outdoor_acc=0.8407643437385559
#  test_belt_acc=0.8127833008766174

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8402718702952067
# max index -> 0
# The [Epoch] of max acc -> 200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8623188138008118,
#  0.8617614507675171,
#  0.8623188138008118,
#  0.8634336590766907,
#  0.8617614507675171,
#  0.8623188138008118,
#  0.8623188138008118,
#  0.8600891828536987,
#  0.8617614507675171,
#  0.8612040281295776]

# %%
test_outdoor_acc
# Out:
# [0.8429936170578003,
#  0.8436305522918701,
#  0.8420382142066956,
#  0.8433120846748352,
#  0.8420382142066956,
#  0.8410828113555908,
#  0.8426751494407654,
#  0.8414012789726257,
#  0.8407643437385559,
#  0.8407643437385559]

# %%
test_belt_acc
# Out:
# [0.8155031800270081,
#  0.8123300075531006,
#  0.813236653804779,
#  0.8118767142295837,
#  0.8118767142295837,
#  0.813236653804779,
#  0.8123300075531006,
#  0.8127833008766174,
#  0.8127833008766174,
#  0.8127833008766174]

# %%
test_indoor_loss
# Out:
# [0.5453141331672668,
#  0.7018539905548096,
#  0.8326135873794556,
#  0.9292640686035156,
#  0.98338383436203,
#  1.0163284540176392,
#  1.0421733856201172,
#  1.0580816268920898,
#  1.0733057260513306,
#  1.0866163969039917]

# %%
test_outdoor_loss
# Out:
# [0.6190849542617798,
#  0.7855483293533325,
#  0.9290933012962341,
#  1.012224555015564,
#  1.077865719795227,
#  1.1167956590652466,
#  1.1384998559951782,
#  1.1639906167984009,
#  1.180814504623413,
#  1.1935995817184448]

# %%
test_belt_loss
# Out:
# [0.899017333984375,
#  1.1407582759857178,
#  1.3539626598358154,
#  1.510312557220459,
#  1.5947836637496948,
#  1.6473201513290405,
#  1.6882069110870361,
#  1.7069038152694702,
#  1.7380542755126953,
#  1.760746955871582]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.mobilenet_v2 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5993
# FP=1147
# acc=0.8393557422969188
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 84.57943925233646%
# 2-BloodSecretionWaste acc = 73.8328530259366%
# 3-LabWardWaste acc = 80.49327354260089%
# 4-VaccineOtherWaste acc = 93.69453526389538%
#
#
#
# all_avg_eachclass = 83.15002527119233%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1629,  226,   29,   42],
#        [ 290, 1281,   53,  111],
#        [  27,  133, 1077,  101],
#        [  11,   64,   60, 2006]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[84.57943925, 11.73416407,  1.50571132,  2.18068536],
#        [16.71469741, 73.83285303,  3.05475504,  6.39769452],
#        [ 2.01793722,  9.94020927, 80.49327354,  7.54857997],
#        [ 0.51377861,  2.98925736,  2.80242877, 93.69453526]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
