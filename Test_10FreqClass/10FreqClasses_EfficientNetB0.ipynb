# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB0

efficientnetB0_model = keras.applications.EfficientNetB0(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 224, 224, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 224, 224, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 112, 112, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 112, 112, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 112, 112, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 112, 112, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 112, 112, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 112, 112, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 112, 112, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 112, 112, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 112, 112, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 112, 112, 96) 1536        block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 112, 112, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 112, 112, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 113, 113, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 56, 56, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 56, 56, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 56, 56, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 56, 56, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 56, 56, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 56, 56, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 56, 56, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 56, 56, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 56, 56, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 56, 56, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 56, 56, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 56, 56, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 56, 56, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 56, 56, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 56, 56, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 56, 56, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 56, 56, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 56, 56, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 59, 59, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 28, 28, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 28, 28, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 28, 28, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 28, 28, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 28, 28, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 28, 28, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 28, 28, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 28, 28, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 28, 28, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 28, 28, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 28, 28, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 28, 28, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 28, 28, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 28, 28, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 28, 28, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 28, 28, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 28, 28, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 28, 28, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 29, 29, 240)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 14, 14, 240)  2160        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 14, 14, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 14, 14, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 14, 14, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 14, 14, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 14, 14, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 14, 14, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 14, 14, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 14, 14, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 14, 14, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 14, 14, 80)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 14, 14, 80)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 14, 14, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 14, 14, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 14, 14, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 14, 14, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 14, 14, 80)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 14, 14, 80)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 14, 14, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 14, 14, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 14, 14, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 14, 14, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 14, 14, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 14, 14, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 14, 14, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 14, 14, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 14, 14, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 14, 14, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 14, 14, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 14, 14, 112)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 14, 14, 112)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 14, 14, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 14, 14, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 14, 14, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 14, 14, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 14, 14, 112)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 14, 14, 112)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block6a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 14, 14, 672)  0           block6a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 17, 17, 672)  0           block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv (DepthwiseConv2D (None, 7, 7, 672)    16800       block6a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 7, 7, 672)    2688        block6a_dwconv[0][0]
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 7, 7, 672)    0           block6a_bn[0][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[0][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6a_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block6a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6a_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block6a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 7, 7, 672)    0           block6a_activation[0][0]
#                                                                  block6a_se_expand[0][0]
# __________________________________________________________________________________________________
# block6a_project_conv (Conv2D)   (None, 7, 7, 192)    129024      block6a_se_excite[0][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 7, 7, 192)    768         block6a_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 7, 7, 1152)   0           block6b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6b_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6b_dwconv[0][0]
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 7, 7, 1152)   0           block6b_bn[0][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[0][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6b_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6b_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6b_activation[0][0]
#                                                                  block6b_se_expand[0][0]
# __________________________________________________________________________________________________
# block6b_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6b_se_excite[0][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 7, 7, 192)    768         block6b_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 7, 7, 192)    0           block6b_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 7, 7, 192)    0           block6b_drop[0][0]
#                                                                  block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6b_add[0][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 7, 7, 1152)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 7, 7, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 7, 7, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 7, 7, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 7, 7, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 7, 7, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 7, 7, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 7, 7, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 7, 7, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 7, 7, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 7, 7, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 7, 7, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 7, 7, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 7, 7, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 7, 7, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 7, 7, 1280)   409600      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 7, 7, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 7, 7, 1280)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1280)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 4,049,571
# Trainable params: 0
# Non-trainable params: 4,049,571
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1280)              4049571
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 5,371,565
# Trainable params: 1,321,994
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 16/16 [==============================] - 21s 362ms/step - loss: 0.5054 - accuracy: 0.8477 - val_loss: 0.0644 - val_accuracy: 0.9765
# Epoch 2/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0482 - accuracy: 0.9854 - val_loss: 0.0155 - val_accuracy: 0.9961
# Epoch 3/2000
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0146 - accuracy: 0.9971 - val_loss: 0.0124 - val_accuracy: 0.9961
# Epoch 4/2000
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 5/2000
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 6/2000
# 16/16 [==============================] - 2s 117ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 7/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 8/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 9/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 10/2000
# 16/16 [==============================] - 2s 118ms/step - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 11/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 12/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 13/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0040 - accuracy: 0.9980 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 14/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 15/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0041 - accuracy: 0.9980 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 16/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0044 - accuracy: 0.9971 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 17/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 18/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 19/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 20/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0179 - val_accuracy: 0.9922
# Epoch 21/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0042 - accuracy: 0.9980 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 22/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0038 - accuracy: 0.9980 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 23/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 24/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 9.2207e-04 - accuracy: 1.0000 - val_loss: 9.0736e-04 - val_accuracy: 1.0000
# Epoch 25/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.7193e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 26/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.6668e-04 - accuracy: 1.0000 - val_loss: 9.1573e-04 - val_accuracy: 1.0000
# Epoch 27/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 28/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 29/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.5414e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 30/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 31/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.1748e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 32/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0015 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 33/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.3567e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 34/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.9311e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000s: 4.9311e-04 - accuracy: 1.00
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 35/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 8.3141e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 36/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.9540e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 37/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.7636e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 38/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 39/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 40/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.5837e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 41/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.3354e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 42/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 43/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.7632e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 44/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.5954e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 45/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 46/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 47/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 48/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 49/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 50/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 51/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 6.0271e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 52/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.0287e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 53/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.1328e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 54/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.8469e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 55/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.8411e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 56/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.6071e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 57/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.3278e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 58/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.0543e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 59/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 60/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.1693e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 61/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.6056e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 62/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.8174e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 63/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.2660e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 64/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.9956e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 65/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.0331e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 66/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.7246e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 67/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.4205e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 68/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.1821e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 69/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.6496e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 70/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0011 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 71/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.0739e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 72/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 73/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.5328e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 74/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.5351e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 75/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.1064e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 76/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.1167e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 77/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 78/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.1552e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 79/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0015 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 80/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2821e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 81/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.4965e-04 - accuracy: 1.0000 - val_loss: 9.9996e-04 - val_accuracy: 1.0000
# Epoch 82/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.1435e-04 - accuracy: 1.0000 - val_loss: 9.9536e-04 - val_accuracy: 1.0000
# Epoch 83/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.5383e-04 - accuracy: 1.0000 - val_loss: 9.9215e-04 - val_accuracy: 1.0000
# Epoch 84/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2796e-04 - accuracy: 1.0000 - val_loss: 9.9077e-04 - val_accuracy: 1.0000
# Epoch 85/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.4728e-04 - accuracy: 1.0000 - val_loss: 9.8942e-04 - val_accuracy: 1.0000
# Epoch 86/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.4346e-04 - accuracy: 1.0000 - val_loss: 9.8671e-04 - val_accuracy: 1.0000
# Epoch 87/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.2063e-04 - accuracy: 1.0000 - val_loss: 9.8605e-04 - val_accuracy: 1.0000
# Epoch 88/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.9888e-04 - accuracy: 1.0000 - val_loss: 9.8827e-04 - val_accuracy: 1.0000
# Epoch 89/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.3605e-04 - accuracy: 1.0000 - val_loss: 9.8624e-04 - val_accuracy: 1.0000
# Epoch 90/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.8411e-04 - val_accuracy: 1.0000
# Epoch 91/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.5056e-04 - accuracy: 1.0000 - val_loss: 9.8040e-04 - val_accuracy: 1.0000
# Epoch 92/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 9.7977e-04 - val_accuracy: 1.0000
# Epoch 93/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 9.7782e-04 - val_accuracy: 1.0000
# Epoch 94/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.8232e-04 - accuracy: 1.0000 - val_loss: 9.7408e-04 - val_accuracy: 1.0000
# Epoch 95/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.0275e-04 - accuracy: 1.0000 - val_loss: 9.7185e-04 - val_accuracy: 1.0000
# Epoch 96/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 7.2746e-04 - accuracy: 1.0000 - val_loss: 9.7068e-04 - val_accuracy: 1.0000
# Epoch 97/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.6456e-04 - val_accuracy: 1.0000
# Epoch 98/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0013 - accuracy: 0.9990 - val_loss: 9.5887e-04 - val_accuracy: 1.0000
# Epoch 99/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 9.5356e-04 - val_accuracy: 1.0000
# Epoch 100/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.9516e-04 - accuracy: 1.0000 - val_loss: 9.5165e-04 - val_accuracy: 1.0000
# Epoch 101/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 9.4263e-04 - val_accuracy: 1.0000
# Epoch 102/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 9.3767e-04 - val_accuracy: 1.0000
# Epoch 103/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.7930e-04 - accuracy: 1.0000 - val_loss: 9.3524e-04 - val_accuracy: 1.0000
# Epoch 104/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.2993e-04 - accuracy: 1.0000 - val_loss: 9.3660e-04 - val_accuracy: 1.0000
# Epoch 105/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.7527e-04 - accuracy: 1.0000 - val_loss: 9.3594e-04 - val_accuracy: 1.0000
# Epoch 106/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 7.5375e-04 - accuracy: 1.0000 - val_loss: 9.3507e-04 - val_accuracy: 1.0000
# Epoch 107/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.9105e-04 - accuracy: 1.0000 - val_loss: 9.3597e-04 - val_accuracy: 1.0000
# Epoch 108/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.0989e-04 - accuracy: 1.0000 - val_loss: 9.3704e-04 - val_accuracy: 1.0000
# Epoch 109/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.5743e-04 - accuracy: 1.0000 - val_loss: 9.3596e-04 - val_accuracy: 1.0000
# Epoch 110/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.6534e-04 - accuracy: 1.0000 - val_loss: 9.3403e-04 - val_accuracy: 1.0000
# Epoch 111/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.5832e-04 - accuracy: 1.0000 - val_loss: 9.3386e-04 - val_accuracy: 1.0000
# Epoch 112/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 6.5019e-04 - accuracy: 1.0000 - val_loss: 9.3615e-04 - val_accuracy: 1.0000
# Epoch 113/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.6379e-04 - accuracy: 1.0000 - val_loss: 9.3796e-04 - val_accuracy: 1.0000
# Epoch 114/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.6225e-04 - accuracy: 1.0000 - val_loss: 9.3937e-04 - val_accuracy: 1.0000
# Epoch 115/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.2562e-04 - accuracy: 1.0000 - val_loss: 9.3929e-04 - val_accuracy: 1.0000
# Epoch 116/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.0695e-04 - accuracy: 1.0000 - val_loss: 9.3814e-04 - val_accuracy: 1.0000
# Epoch 117/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 6.5114e-04 - accuracy: 1.0000 - val_loss: 9.3959e-04 - val_accuracy: 1.0000
# Epoch 118/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.3022e-04 - accuracy: 1.0000 - val_loss: 9.3988e-04 - val_accuracy: 1.0000
# Epoch 119/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.9192e-04 - accuracy: 1.0000 - val_loss: 9.3918e-04 - val_accuracy: 1.0000
# Epoch 120/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.6749e-04 - accuracy: 1.0000 - val_loss: 9.4066e-04 - val_accuracy: 1.0000
# Epoch 121/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.9710e-04 - accuracy: 1.0000 - val_loss: 9.4121e-04 - val_accuracy: 1.0000
# Epoch 122/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.6936e-04 - accuracy: 1.0000 - val_loss: 9.4104e-04 - val_accuracy: 1.0000
# Epoch 123/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.7313e-04 - accuracy: 1.0000 - val_loss: 9.3962e-04 - val_accuracy: 1.0000
# Epoch 124/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.4858e-04 - accuracy: 1.0000 - val_loss: 9.3645e-04 - val_accuracy: 1.0000
# Epoch 125/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.1297e-04 - accuracy: 1.0000 - val_loss: 9.3553e-04 - val_accuracy: 1.0000
# Epoch 126/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0012 - accuracy: 0.9990 - val_loss: 9.3514e-04 - val_accuracy: 1.0000
# Epoch 127/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.4267e-04 - accuracy: 1.0000 - val_loss: 9.3213e-04 - val_accuracy: 1.0000
# Epoch 128/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 1.8512e-04 - accuracy: 1.0000 - val_loss: 9.3073e-04 - val_accuracy: 1.0000
# Epoch 129/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.0000e-04 - accuracy: 1.0000 - val_loss: 9.2978e-04 - val_accuracy: 1.0000
# Epoch 130/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0014 - accuracy: 0.9990 - val_loss: 9.2944e-04 - val_accuracy: 1.0000
# Epoch 131/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.4614e-04 - accuracy: 1.0000 - val_loss: 9.3089e-04 - val_accuracy: 1.0000
# Epoch 132/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 8.2181e-04 - accuracy: 1.0000 - val_loss: 9.3153e-04 - val_accuracy: 1.0000
# Epoch 133/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 9.2990e-04 - val_accuracy: 1.0000
# Epoch 134/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0012 - accuracy: 0.9990 - val_loss: 9.3169e-04 - val_accuracy: 1.0000
# Epoch 135/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.1946e-04 - accuracy: 1.0000 - val_loss: 9.3539e-04 - val_accuracy: 1.0000
# Epoch 136/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.4897e-04 - accuracy: 1.0000 - val_loss: 9.3552e-04 - val_accuracy: 1.0000
# Epoch 137/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.9798e-04 - accuracy: 1.0000 - val_loss: 9.3542e-04 - val_accuracy: 1.0000
# Epoch 138/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.1273e-04 - accuracy: 1.0000 - val_loss: 9.3365e-04 - val_accuracy: 1.0000
# Epoch 139/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.1326e-04 - accuracy: 1.0000 - val_loss: 9.3396e-04 - val_accuracy: 1.0000
# Epoch 140/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.1618e-04 - accuracy: 1.0000 - val_loss: 9.3370e-04 - val_accuracy: 1.0000
# Epoch 141/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.6545e-04 - accuracy: 1.0000 - val_loss: 9.3246e-04 - val_accuracy: 1.0000
# Epoch 142/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.2849e-04 - val_accuracy: 1.0000
# Epoch 143/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 9.3015e-04 - val_accuracy: 1.0000
# Epoch 144/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 9.4328e-04 - accuracy: 0.9990 - val_loss: 9.3497e-04 - val_accuracy: 1.0000
# Epoch 145/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.3906e-04 - accuracy: 1.0000 - val_loss: 9.3497e-04 - val_accuracy: 1.0000
# Epoch 146/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.3196e-04 - accuracy: 1.0000 - val_loss: 9.3194e-04 - val_accuracy: 1.0000
# Epoch 147/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.0585e-04 - accuracy: 1.0000 - val_loss: 9.3204e-04 - val_accuracy: 1.0000
# Epoch 148/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 1.9994e-04 - accuracy: 1.0000 - val_loss: 9.3242e-04 - val_accuracy: 1.0000
# Epoch 149/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.9722e-04 - accuracy: 1.0000 - val_loss: 9.3147e-04 - val_accuracy: 1.0000
# Epoch 150/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.7659e-04 - accuracy: 1.0000 - val_loss: 9.3384e-04 - val_accuracy: 1.0000
# Epoch 151/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.2004e-04 - accuracy: 1.0000 - val_loss: 9.3353e-04 - val_accuracy: 1.0000
# Epoch 152/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.5471e-04 - accuracy: 1.0000 - val_loss: 9.3403e-04 - val_accuracy: 1.0000
# Epoch 153/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.6832e-04 - accuracy: 1.0000 - val_loss: 9.3821e-04 - val_accuracy: 1.0000
# Epoch 154/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 8.6894e-04 - accuracy: 1.0000 - val_loss: 9.2741e-04 - val_accuracy: 1.0000
# Epoch 155/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.7775e-04 - accuracy: 1.0000 - val_loss: 9.1295e-04 - val_accuracy: 1.0000
# Epoch 156/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.6227e-04 - accuracy: 1.0000 - val_loss: 9.0689e-04 - val_accuracy: 1.0000
# Epoch 157/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.9278e-04 - accuracy: 1.0000 - val_loss: 9.1082e-04 - val_accuracy: 1.0000
# Epoch 158/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.8664e-04 - accuracy: 1.0000 - val_loss: 9.1816e-04 - val_accuracy: 1.0000
# Epoch 159/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.4291e-04 - accuracy: 1.0000 - val_loss: 9.2091e-04 - val_accuracy: 1.0000
# Epoch 160/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.4409e-04 - accuracy: 1.0000 - val_loss: 9.2132e-04 - val_accuracy: 1.0000
# Epoch 161/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 1.6705e-04 - accuracy: 1.0000 - val_loss: 9.2028e-04 - val_accuracy: 1.0000
# Epoch 162/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.8233e-04 - accuracy: 1.0000 - val_loss: 9.1902e-04 - val_accuracy: 1.0000
# Epoch 163/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.2487e-04 - accuracy: 1.0000 - val_loss: 9.1797e-04 - val_accuracy: 1.0000
# Epoch 164/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.2834e-04 - accuracy: 1.0000 - val_loss: 9.1731e-04 - val_accuracy: 1.0000
# Epoch 165/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.0465e-04 - accuracy: 1.0000 - val_loss: 9.1554e-04 - val_accuracy: 1.0000curacy: 1.00
# Epoch 166/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.3634e-04 - accuracy: 1.0000 - val_loss: 9.1447e-04 - val_accuracy: 1.0000
# Epoch 167/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.2117e-04 - accuracy: 1.0000 - val_loss: 9.1361e-04 - val_accuracy: 1.0000
# Epoch 168/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 9.2743e-04 - val_accuracy: 1.0000
# Epoch 169/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.6455e-04 - accuracy: 1.0000 - val_loss: 9.4596e-04 - val_accuracy: 1.0000
# Epoch 170/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 9.6557e-04 - val_accuracy: 1.0000
# Epoch 171/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.4105e-04 - accuracy: 1.0000 - val_loss: 9.8478e-04 - val_accuracy: 1.0000
# Epoch 172/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.8994e-04 - accuracy: 1.0000 - val_loss: 9.8890e-04 - val_accuracy: 1.0000
# Epoch 173/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.1307e-04 - accuracy: 1.0000 - val_loss: 9.8353e-04 - val_accuracy: 1.0000
# Epoch 174/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.8085e-04 - accuracy: 1.0000 - val_loss: 9.7994e-04 - val_accuracy: 1.0000
# Epoch 175/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2087e-04 - accuracy: 1.0000 - val_loss: 9.7912e-04 - val_accuracy: 1.0000
# Epoch 176/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.0335e-04 - accuracy: 1.0000 - val_loss: 9.7610e-04 - val_accuracy: 1.0000
# Epoch 177/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.8707e-04 - accuracy: 1.0000 - val_loss: 9.7387e-04 - val_accuracy: 1.0000
# Epoch 178/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.9724e-04 - accuracy: 1.0000 - val_loss: 9.7294e-04 - val_accuracy: 1.0000
# Epoch 179/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.2243e-04 - accuracy: 1.0000 - val_loss: 9.7114e-04 - val_accuracy: 1.0000
# Epoch 180/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.7356e-04 - val_accuracy: 1.0000
# Epoch 181/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.4136e-04 - accuracy: 1.0000 - val_loss: 9.7664e-04 - val_accuracy: 1.0000
# Epoch 182/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.3154e-04 - accuracy: 1.0000 - val_loss: 9.7570e-04 - val_accuracy: 1.0000
# Epoch 183/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.4106e-04 - accuracy: 1.0000 - val_loss: 9.8156e-04 - val_accuracy: 1.0000
# Epoch 184/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.7764e-04 - accuracy: 1.0000 - val_loss: 9.8361e-04 - val_accuracy: 1.0000
# Epoch 185/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 9.8376e-04 - val_accuracy: 1.0000
# Epoch 186/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.0881e-04 - accuracy: 1.0000 - val_loss: 9.8524e-04 - val_accuracy: 1.0000
# Epoch 187/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.2359e-04 - accuracy: 1.0000 - val_loss: 9.8180e-04 - val_accuracy: 1.0000
# Epoch 188/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.2860e-04 - accuracy: 1.0000 - val_loss: 9.7630e-04 - val_accuracy: 1.0000
# Epoch 189/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.3640e-04 - accuracy: 1.0000 - val_loss: 9.7298e-04 - val_accuracy: 1.0000
# Epoch 190/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.2022e-04 - accuracy: 1.0000 - val_loss: 9.7116e-04 - val_accuracy: 1.0000
# Epoch 191/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 9.6157e-04 - val_accuracy: 1.0000
# Epoch 192/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.9237e-04 - accuracy: 1.0000 - val_loss: 9.5389e-04 - val_accuracy: 1.0000
# Epoch 193/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 2.2109e-04 - accuracy: 1.0000 - val_loss: 9.5197e-04 - val_accuracy: 1.0000
# Epoch 194/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.9079e-04 - accuracy: 1.0000 - val_loss: 9.4601e-04 - val_accuracy: 1.0000
# Epoch 195/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 6.6190e-04 - accuracy: 1.0000 - val_loss: 9.4254e-04 - val_accuracy: 1.0000
# Epoch 196/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.1257e-04 - accuracy: 1.0000 - val_loss: 9.4863e-04 - val_accuracy: 1.0000
# Epoch 197/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.8659e-04 - accuracy: 1.0000 - val_loss: 9.5277e-04 - val_accuracy: 1.0000
# Epoch 198/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 4.0547e-04 - accuracy: 1.0000 - val_loss: 9.5659e-04 - val_accuracy: 1.0000
# Epoch 199/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 3.3684e-04 - accuracy: 1.0000 - val_loss: 9.5774e-04 - val_accuracy: 1.0000
# Epoch 200/2000
# 16/16 [==============================] - 2s 114ms/step - loss: 5.0390e-04 - accuracy: 1.0000 - val_loss: 9.5459e-04 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 9.5697e-04 - val_accuracy: 1.0000
# Epoch 202/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.6326e-04 - accuracy: 1.0000 - val_loss: 9.5597e-04 - val_accuracy: 1.0000
# Epoch 203/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0012 - accuracy: 0.9990 - val_loss: 9.5149e-04 - val_accuracy: 1.0000
# Epoch 204/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.2525e-04 - accuracy: 1.0000 - val_loss: 9.4176e-04 - val_accuracy: 1.0000
# Epoch 205/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 9.6973e-04 - accuracy: 1.0000 - val_loss: 9.3141e-04 - val_accuracy: 1.0000
# Epoch 206/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.4544e-04 - accuracy: 1.0000 - val_loss: 9.3273e-04 - val_accuracy: 1.0000
# Epoch 207/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.3005e-04 - accuracy: 1.0000 - val_loss: 9.2905e-04 - val_accuracy: 1.0000
# Epoch 208/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.1391e-04 - accuracy: 1.0000 - val_loss: 9.2699e-04 - val_accuracy: 1.0000
# Epoch 209/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.1861e-04 - val_accuracy: 1.0000
# Epoch 210/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2461e-04 - accuracy: 1.0000 - val_loss: 9.1052e-04 - val_accuracy: 1.0000
# Epoch 211/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.4018e-04 - accuracy: 1.0000 - val_loss: 9.0748e-04 - val_accuracy: 1.0000
# Epoch 212/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.6757e-04 - accuracy: 1.0000 - val_loss: 9.0606e-04 - val_accuracy: 1.0000
# Epoch 213/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 6.0535e-04 - accuracy: 1.0000 - val_loss: 9.1485e-04 - val_accuracy: 1.0000
# Epoch 214/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.9235e-04 - accuracy: 1.0000 - val_loss: 9.2219e-04 - val_accuracy: 1.0000
# Epoch 215/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.4224e-04 - accuracy: 1.0000 - val_loss: 9.2462e-04 - val_accuracy: 1.0000
# Epoch 216/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.2902e-04 - accuracy: 1.0000 - val_loss: 9.3008e-04 - val_accuracy: 1.0000
# Epoch 217/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.3691e-04 - accuracy: 1.0000 - val_loss: 9.3249e-04 - val_accuracy: 1.0000
# Epoch 218/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.0393e-04 - accuracy: 1.0000 - val_loss: 9.2935e-04 - val_accuracy: 1.0000
# Epoch 219/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.9436e-04 - accuracy: 1.0000 - val_loss: 9.4054e-04 - val_accuracy: 1.0000
# Epoch 220/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.0252e-04 - accuracy: 1.0000 - val_loss: 9.4284e-04 - val_accuracy: 1.0000
# Epoch 221/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.8953e-04 - accuracy: 1.0000 - val_loss: 9.4433e-04 - val_accuracy: 1.0000
# Epoch 222/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.6886e-04 - accuracy: 1.0000 - val_loss: 9.4183e-04 - val_accuracy: 1.0000
# Epoch 223/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 9.5312e-04 - accuracy: 1.0000 - val_loss: 9.4198e-04 - val_accuracy: 1.0000
# Epoch 224/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.6938e-04 - accuracy: 1.0000 - val_loss: 9.4823e-04 - val_accuracy: 1.0000
# Epoch 225/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.9574e-04 - accuracy: 1.0000 - val_loss: 9.4979e-04 - val_accuracy: 1.0000
# Epoch 226/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.4904e-04 - accuracy: 1.0000 - val_loss: 9.5681e-04 - val_accuracy: 1.0000
# Epoch 227/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0013 - accuracy: 0.9990 - val_loss: 9.6510e-04 - val_accuracy: 1.0000
# Epoch 228/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.6125e-04 - val_accuracy: 1.0000
# Epoch 229/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.5322e-04 - accuracy: 1.0000 - val_loss: 9.5804e-04 - val_accuracy: 1.0000
# Epoch 230/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.1463e-04 - accuracy: 1.0000 - val_loss: 9.5742e-04 - val_accuracy: 1.0000
# Epoch 231/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.6208e-04 - accuracy: 1.0000 - val_loss: 9.5631e-04 - val_accuracy: 1.0000
# Epoch 232/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.8560e-04 - accuracy: 1.0000 - val_loss: 9.5484e-04 - val_accuracy: 1.0000
# Epoch 233/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.8086e-04 - accuracy: 1.0000 - val_loss: 9.5335e-04 - val_accuracy: 1.0000
# Epoch 234/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.7656e-04 - accuracy: 1.0000 - val_loss: 9.5563e-04 - val_accuracy: 1.0000
# Epoch 235/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.3610e-04 - accuracy: 1.0000 - val_loss: 9.5537e-04 - val_accuracy: 1.0000
# Epoch 236/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.9467e-04 - accuracy: 1.0000 - val_loss: 9.5550e-04 - val_accuracy: 1.0000
# Epoch 237/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.4434e-04 - accuracy: 1.0000 - val_loss: 9.6159e-04 - val_accuracy: 1.0000
# Epoch 238/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.8780e-04 - accuracy: 1.0000 - val_loss: 9.5995e-04 - val_accuracy: 1.0000
# Epoch 239/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.9579e-04 - accuracy: 1.0000 - val_loss: 9.5567e-04 - val_accuracy: 1.0000
# Epoch 240/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.3382e-04 - accuracy: 1.0000 - val_loss: 9.6062e-04 - val_accuracy: 1.0000
# Epoch 241/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.0899e-04 - accuracy: 1.0000 - val_loss: 9.6295e-04 - val_accuracy: 1.0000
# Epoch 242/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.9414e-04 - accuracy: 1.0000 - val_loss: 9.6254e-04 - val_accuracy: 1.0000
# Epoch 243/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 8.1336e-04 - accuracy: 1.0000 - val_loss: 9.7909e-04 - val_accuracy: 1.0000
# Epoch 244/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.8030e-04 - accuracy: 1.0000 - val_loss: 9.8596e-04 - val_accuracy: 1.0000
# Epoch 245/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.7863e-04 - accuracy: 1.0000 - val_loss: 9.9552e-04 - val_accuracy: 1.0000
# Epoch 246/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.8990e-04 - accuracy: 1.0000 - val_loss: 9.8891e-04 - val_accuracy: 1.0000
# Epoch 247/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.8889e-04 - accuracy: 1.0000 - val_loss: 9.8774e-04 - val_accuracy: 1.0000
# Epoch 248/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.8163e-04 - accuracy: 1.0000 - val_loss: 9.9422e-04 - val_accuracy: 1.0000
# Epoch 249/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.0178e-04 - accuracy: 1.0000 - val_loss: 9.9472e-04 - val_accuracy: 1.0000
# Epoch 250/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 251/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.3560e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 252/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 9.8351e-04 - val_accuracy: 1.0000
# Epoch 253/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 9.0711e-04 - accuracy: 1.0000 - val_loss: 9.7633e-04 - val_accuracy: 1.0000
# Epoch 254/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.7682e-04 - accuracy: 1.0000 - val_loss: 9.6979e-04 - val_accuracy: 1.0000
# Epoch 255/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 6.4457e-04 - accuracy: 1.0000 - val_loss: 9.7424e-04 - val_accuracy: 1.0000
# Epoch 256/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.3238e-04 - accuracy: 1.0000 - val_loss: 9.8265e-04 - val_accuracy: 1.0000
# Epoch 257/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 6.0586e-04 - accuracy: 1.0000 - val_loss: 9.8253e-04 - val_accuracy: 1.0000
# Epoch 258/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 9.7106e-04 - val_accuracy: 1.0000
# Epoch 259/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 7.7125e-04 - accuracy: 1.0000 - val_loss: 9.6747e-04 - val_accuracy: 1.0000
# Epoch 260/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 261/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.0980e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 262/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.6490e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 263/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.0236e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 264/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.2382e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 265/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.1688e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 266/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.8067e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 267/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.6298e-04 - accuracy: 1.0000 - val_loss: 9.9644e-04 - val_accuracy: 1.0000
# Epoch 268/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.6172e-04 - accuracy: 1.0000 - val_loss: 9.9266e-04 - val_accuracy: 1.0000
# Epoch 269/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.1099e-04 - accuracy: 1.0000 - val_loss: 9.8759e-04 - val_accuracy: 1.0000
# Epoch 270/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.4334e-04 - accuracy: 1.0000 - val_loss: 9.8347e-04 - val_accuracy: 1.0000
# Epoch 271/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0040 - accuracy: 0.9980 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 272/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 6.9172e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 273/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.8424e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 274/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.3769e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 275/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.2369e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 276/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.7614e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 277/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.4372e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 278/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.7306e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 279/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 4.3707e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 280/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 281/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.6320e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 282/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.5671e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 283/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.3468e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 284/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.4618e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 285/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.8646e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 286/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.7736e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 287/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.6286e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 288/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.1879e-04 - accuracy: 1.0000 - val_loss: 9.9902e-04 - val_accuracy: 1.0000
# Epoch 289/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.6826e-04 - accuracy: 1.0000 - val_loss: 9.9432e-04 - val_accuracy: 1.0000
# Epoch 290/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 6.3520e-04 - accuracy: 1.0000 - val_loss: 9.9378e-04 - val_accuracy: 1.0000
# Epoch 291/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.4841e-04 - accuracy: 1.0000 - val_loss: 9.9834e-04 - val_accuracy: 1.0000
# Epoch 292/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.3045e-04 - accuracy: 1.0000 - val_loss: 9.9636e-04 - val_accuracy: 1.0000
# Epoch 293/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.6297e-04 - accuracy: 1.0000 - val_loss: 9.9390e-04 - val_accuracy: 1.0000
# Epoch 294/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.9789e-04 - accuracy: 1.0000 - val_loss: 9.9226e-04 - val_accuracy: 1.0000
# Epoch 295/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.8471e-04 - accuracy: 1.0000 - val_loss: 9.9106e-04 - val_accuracy: 1.0000
# Epoch 296/2000
# 16/16 [==============================] - 2s 117ms/step - loss: 4.1854e-04 - accuracy: 1.0000 - val_loss: 9.9699e-04 - val_accuracy: 1.0000
# Epoch 297/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.8637e-04 - accuracy: 1.0000 - val_loss: 9.9664e-04 - val_accuracy: 1.0000
# Epoch 298/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.1619e-04 - accuracy: 1.0000 - val_loss: 9.9371e-04 - val_accuracy: 1.0000
# Epoch 299/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 5.5064e-04 - accuracy: 1.0000 - val_loss: 9.7366e-04 - val_accuracy: 1.0000
# Epoch 300/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.7875e-04 - val_accuracy: 1.0000
# Epoch 301/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.6337e-04 - accuracy: 1.0000 - val_loss: 9.8465e-04 - val_accuracy: 1.0000
# Epoch 302/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.9685e-04 - accuracy: 1.0000 - val_loss: 9.8338e-04 - val_accuracy: 1.0000
# Epoch 303/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.3757e-04 - accuracy: 1.0000 - val_loss: 9.8281e-04 - val_accuracy: 1.0000
# Epoch 304/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.5182e-04 - accuracy: 1.0000 - val_loss: 9.8105e-04 - val_accuracy: 1.0000
# Epoch 305/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.9749e-04 - accuracy: 1.0000 - val_loss: 9.7740e-04 - val_accuracy: 1.0000
# Epoch 306/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.3929e-04 - accuracy: 1.0000 - val_loss: 9.7855e-04 - val_accuracy: 1.0000
# Epoch 307/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.3783e-04 - accuracy: 1.0000 - val_loss: 9.7862e-04 - val_accuracy: 1.0000
# Epoch 308/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.4015e-04 - accuracy: 1.0000 - val_loss: 9.7733e-04 - val_accuracy: 1.0000
# Epoch 309/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.1736e-04 - accuracy: 1.0000 - val_loss: 9.7386e-04 - val_accuracy: 1.0000
# Epoch 310/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.5440e-04 - accuracy: 1.0000 - val_loss: 9.7372e-04 - val_accuracy: 1.0000
# Epoch 311/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 2.1571e-04 - accuracy: 1.0000 - val_loss: 9.7461e-04 - val_accuracy: 1.0000
# Epoch 312/2000
# ...
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1899/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2445e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1900/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.6173e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1901/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.9779e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1902/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2334e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1903/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.7293e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1904/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.9125e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1905/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.6914e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1906/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.9983e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1907/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 9.1259e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1908/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0013 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1909/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.5864e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1910/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.2998e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1911/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.9463e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1912/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.7004e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1913/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.8378e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1914/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.9812e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1915/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0032 - accuracy: 0.9980 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1916/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.2967e-04 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1917/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.3985e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1918/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 7.7684e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1919/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.3883e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1920/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.4041e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1921/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1922/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.9187e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1923/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.2189e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1924/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.4524e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1925/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.5758e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1926/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.1326e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1927/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.3743e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1928/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.1219e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1929/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1930/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.0786e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1931/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.6568e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1932/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.0857e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1933/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.0628e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1934/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 9.5025e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1935/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.1613e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1936/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.3288e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1937/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.3066e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1938/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.7016e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1939/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.7857e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1940/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.0220e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1941/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.9982e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1942/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.0256e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1943/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.4597e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1944/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.1392e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1945/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 7.2893e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1946/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.8780e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1947/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1948/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.5388e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1949/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.5868e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1950/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1951/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.5035e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1952/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.0803e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1953/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.8024e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1954/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.2741e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1955/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.5163e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1956/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.9610e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1957/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.7177e-04 - accuracy: 0.9990 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1958/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.1731e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1959/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.7561e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1960/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.2696e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1961/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.9017e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1962/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.9514e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1963/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.1434e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1964/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.0579e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1965/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.5842e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1966/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.7730e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1967/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.5611e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1968/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.3977e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1969/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.8761e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1970/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.6750e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1971/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.8353e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1972/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 9.5028e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1973/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 6.8875e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1974/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.6579e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1975/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.8965e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1976/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.5251e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1977/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.0271e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1978/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.5757e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1979/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 5.1833e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1980/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.2054e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1981/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.3187e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1982/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.5753e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1983/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 8.5434e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1984/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.0481e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1985/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 1.9943e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1986/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.6515e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1987/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.9883e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1988/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.3269e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 1989/2000
# 16/16 [==============================] - 2s 116ms/step - loss: 3.9172e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1990/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2042e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1991/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.0644e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1992/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.7553e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1993/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 4.8722e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1994/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 1.6560e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1995/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.5336e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1996/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.1070e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1997/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.2869e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1998/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.7176e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 1999/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 3.6603e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 2000/2000
# 16/16 [==============================] - 2s 115ms/step - loss: 2.8128e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 8/8 [==============================] - 4s 175ms/step - loss: 0.0907 - accuracy: 0.9665
# test_indoor_ds_results:test loss, test acc: [0.09072890132665634, 0.966469407081604]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 16/16 [==============================] - 9s 290ms/step - loss: 0.3412 - accuracy: 0.8971
# test_outdoor_ds_results:test loss, test acc: [0.34122955799102783, 0.8970588445663452]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 9/9 [==============================] - 3s 166ms/step - loss: 0.6748 - accuracy: 0.8594
# test_belt_ds_results:test loss, test acc: [0.6748179197311401, 0.8594024777412415]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_38712) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_38580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_65328) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_69626) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_38272) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_68459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_74239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_38099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_39244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_72418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_38928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_72589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_40524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_38811) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_37890) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_40748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_66143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_30298) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_39427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_37715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_72029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_39020) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_41130) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_74410) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_39585) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_72651) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_73803) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_69019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_66081) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_68521) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_72091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_40565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_67659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_66470) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_69081) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_39901) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_74799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_38140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_38770) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_67332) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_71462) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_71400) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_40249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_65499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_37674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_71836) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_40341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_40033) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_40473) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_40091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_69688) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_70622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_71229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_38330) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_38539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_37832) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_73865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_67270) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_63824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_68266) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_59179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_38488) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_68848) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_40132) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_62069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_40972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_69455) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_40789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_39809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_74472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_38048) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_38371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_66703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_73025) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_65561) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_67892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_70233) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_39152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_73632) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_39677) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_65888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_41013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_37623) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_70062) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_39468) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_70793) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_39860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_39376) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_40300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_39636) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_37931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_70855) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_73258) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_57402) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_67830) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_70295) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_67077) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_38979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_73196) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_39203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_40921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_66641) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_40697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 8/8 [==============================] - 2s 91ms/step - loss: 0.0857 - accuracy: 0.9645
# 16/16 [==============================] - 1s 90ms/step - loss: 0.2406 - accuracy: 0.9206
# 9/9 [==============================] - 1s 90ms/step - loss: 0.5405 - accuracy: 0.8629
# Epoch200
#  test_indoor_acc=0.9644970297813416
#  test_outdoor_acc=0.9205882549285889
#  test_belt_acc=0.862917423248291
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_100818) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_99065) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_130369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_99449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_101383) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_102480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_132205) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_131038) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_129809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_130431) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_125174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_131412) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_101159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_102322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_102363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_101210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_128620) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_102047) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_130805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_118752) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_99398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_100161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_100062) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_100553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_100329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_99490) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_133441) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_128427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_101441) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_131645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_129009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_136149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_101482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_100278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_133186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_134608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_129871) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_132812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_99182) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_134982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_131583) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_99680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_99889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_133768) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_133939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_100986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_135822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_135153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_99622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_131972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_101691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_130198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_100120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_132143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_99024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_100935) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_129180) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_102139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_100502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_134001) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_129616) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_101823) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_132750) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_127431) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_126911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_99281) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_127238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_133379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_91648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_99838) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_100777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_100370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_102271) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_100594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_132579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_126849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_127820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_120529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_101599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_100726) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_129242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_99240) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_102098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_101915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_99930) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_101251) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_134375) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_128053) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_127493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_123419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_101874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_127991) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_134546) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_126678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_101027) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_135760) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_98973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_101650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_135215) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_128682) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_130976) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_99721) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_135589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 8/8 [==============================] - 2s 93ms/step - loss: 0.0803 - accuracy: 0.9704
# 16/16 [==============================] - 1s 90ms/step - loss: 0.2572 - accuracy: 0.9186
# 9/9 [==============================] - 1s 90ms/step - loss: 0.5392 - accuracy: 0.8647
# Epoch400
#  test_indoor_acc=0.9704142212867737
#  test_outdoor_acc=0.9186274409294128
#  test_belt_acc=0.8646748661994934
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_160748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_197499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_161679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_160590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_188588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_194100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_196503) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_163448) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_152998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_161852) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_161944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_162285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_192762) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_188261) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_161239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_197172) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_162832) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_192326) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_193322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_163173) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_190359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_195896) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_162076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_161511) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_162560) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_191781) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_195289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_193493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_162949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_590920) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_619482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_625782) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_622383) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_591078) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_591735) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_591827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_590040) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_625175) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_590249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_624801) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_621605) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_622212) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_618791) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_620609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_618853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_620416) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_617711) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_591353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_590689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_589773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_589865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_582448) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_592623) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_593122) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_623379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_591302) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_624179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_589982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_591394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_620998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_619227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_591526) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_592450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_622772) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_619980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_622445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_626389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_592847) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_626560) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_621169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_592898) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_625408) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_591170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_624739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_590198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_589824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_620042) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_592282) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_593280) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_592010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_590480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_609552) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_592674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_593071) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_617649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_590081) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_592183) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_624241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_591786) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_623612) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_592241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_615974) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_619809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_625953) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_590422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_625346) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_591129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_590961) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_591959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_619420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_626622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_592491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_623550) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_623005) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_592051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_590730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 8/8 [==============================] - 2s 91ms/step - loss: 0.0907 - accuracy: 0.9665
# 16/16 [==============================] - 1s 90ms/step - loss: 0.3412 - accuracy: 0.8971
# 9/9 [==============================] - 1s 90ms/step - loss: 0.6748 - accuracy: 0.8594
# Epoch2000
#  test_indoor_acc=0.966469407081604
#  test_outdoor_acc=0.8970588445663452
#  test_belt_acc=0.8594024777412415

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.9179055094718933
# max index -> 1
# The [Epoch] of max acc -> 400

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9644970297813416,
#  0.9704142212867737,
#  0.9625246524810791,
#  0.9704142212867737,
#  0.9625246524810791,
#  0.9743589758872986,
#  0.9684418439865112,
#  0.9704142212867737,
#  0.9605522751808167,
#  0.966469407081604]

# %%
test_outdoor_acc
# Out:
# [0.9205882549285889,
#  0.9186274409294128,
#  0.9147058725357056,
#  0.908823549747467,
#  0.9078431129455566,
#  0.9019607901573181,
#  0.9029411673545837,
#  0.9009804129600525,
#  0.8970588445663452,
#  0.8970588445663452]

# %%
test_belt_acc
# Out:
# [0.862917423248291,
#  0.8646748661994934,
#  0.8664323091506958,
#  0.8611599206924438,
#  0.862917423248291,
#  0.862917423248291,
#  0.862917423248291,
#  0.8611599206924438,
#  0.8576449751853943,
#  0.8594024777412415]

# %%
test_indoor_loss
# Out:
# [0.08573678135871887,
#  0.080307237803936,
#  0.0932173877954483,
#  0.0837908685207367,
#  0.09030920267105103,
#  0.07296383380889893,
#  0.08862955868244171,
#  0.08501379936933517,
#  0.1009373813867569,
#  0.09072890132665634]

# %%
test_outdoor_loss
# Out:
# [0.24061234295368195,
#  0.25722211599349976,
#  0.25597283244132996,
#  0.27306216955184937,
#  0.28773877024650574,
#  0.3054850399494171,
#  0.3096711039543152,
#  0.3318674564361572,
#  0.3304787576198578,
#  0.34122955799102783]

# %%
test_belt_loss
# Out:
# [0.5404695272445679,
#  0.5391883254051208,
#  0.5791120529174805,
#  0.5842387676239014,
#  0.6352143287658691,
#  0.6043799519538879,
#  0.638454794883728,
#  0.6537782549858093,
#  0.6948337554931641,
#  0.6748179197311401]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_100818) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_99065) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_130369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_99449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_101383) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_102480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_132205) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_131038) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_129809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_130431) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_125174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_131412) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_101159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_102322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_102363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_101210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_128620) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_102047) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_130805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_118752) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_99398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_100161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_100062) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_100553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_100329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_99490) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_133441) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_128427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_101441) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_131645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_129009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_136149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_101482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_100278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_133186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_134608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_129871) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_132812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_99182) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_134982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_131583) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_99680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_99889) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_133768) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_133939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_100986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_135822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_135153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_99622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_131972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_101691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_130198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_100120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_132143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_99024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_100935) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_129180) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_102139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_100502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_134001) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_129616) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_101823) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_132750) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_127431) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_126911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_99281) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_127238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_133379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_91648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_99838) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_100777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_100370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_102271) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_100594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_132579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_126849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_127820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_120529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_101599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_100726) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_129242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_99240) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_102098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_101915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_99930) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_101251) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_134375) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_128053) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_127493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_123419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_101874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_127991) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_134546) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_126678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_101027) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_135760) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_98973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_101650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_135215) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_128682) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_130976) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_99721) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_135589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507
# train_outdoor num x,y : 1020,1020
# train_belt num x,y : 569,569
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1921
# FP=175
# acc=0.9165076335877863
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 76.86567164179104%
# CottonBall acc = 91.61676646706587%
# ExtensionTube acc = 63.41463414634146%
# Glove acc = 99.10714285714286%
# Mask acc = 99.48051948051948%
# NGTube acc = 71.61290322580646%
# Needle acc = 94.28571428571428%
# OxygenMask acc = 98.49624060150376%
# Syringe acc = 97.71863117870723%
# UrineBag acc = 90.0%
#
#
#
# all_avg_eachclass = 88.25982238845924%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[103,   0,   1,   9,   1,   7,   6,   2,   0,   5],
#        [  0, 153,   0,  13,   1,   0,   0,   0,   0,   0],
#        [  0,   0,  78,   0,  15,  24,   0,   0,   4,   2],
#        [  1,   0,   0, 333,   2,   0,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 383,   0,   0,   2,   0,   0],
#        [  0,   0,  11,   4,  17, 111,   0,   5,   0,   7],
#        [  0,   0,   1,   0,   3,   7, 264,   0,   5,   0],
#        [  0,   0,   0,   0,   0,   0,   0, 131,   0,   2],
#        [  0,   0,   0,   1,   1,   0,   4,   0, 257,   0],
#        [  0,   0,   0,   0,   0,   0,   0,  12,   0, 108]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[76.86567164,  0.        ,  0.74626866,  6.71641791,  0.74626866,
#          5.2238806 ,  4.47761194,  1.49253731,  0.        ,  3.73134328],
#        [ 0.        , 91.61676647,  0.        ,  7.78443114,  0.5988024 ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        , 63.41463415,  0.        , 12.19512195,
#         19.51219512,  0.        ,  0.        ,  3.25203252,  1.62601626],
#        [ 0.29761905,  0.        ,  0.        , 99.10714286,  0.5952381 ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        , 99.48051948,
#          0.        ,  0.        ,  0.51948052,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  7.09677419,  2.58064516, 10.96774194,
#         71.61290323,  0.        ,  3.22580645,  0.        ,  4.51612903],
#        [ 0.        ,  0.        ,  0.35714286,  0.        ,  1.07142857,
#          2.5       , 94.28571429,  0.        ,  1.78571429,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        , 98.4962406 ,  0.        ,  1.5037594 ],
#        [ 0.        ,  0.        ,  0.        ,  0.38022814,  0.38022814,
#          0.        ,  1.52091255,  0.        , 97.71863118,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        , 10.        ,  0.        , 90.        ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
