# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import preprocess_input,NASNetMobile
#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.NASNetMobile(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 11) 352         activation[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 11) 44          reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 11) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   396         separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   396         activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 32) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1152        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   220         activation_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   396         activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   220         activation_10[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 11)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 112, 112, 32) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 11)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 11)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 111, 111, 32) 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 44)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 32)   0           cropping2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 22)   968         activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 22)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 22)   88          reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 22)   88          concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   1034        activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   682         activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1034        activation_19[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   682         activation_21[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 22)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 57, 57, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 22)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 22)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 56, 56, 44)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 88)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 44)   0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 44)   0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 44)   3872        activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 44)   176         concatenate_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 44)   3036        activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 44)   3036        activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 44)   2332        activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 44)   3036        activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 44)   3036        activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 44)   2332        activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 44)   0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 44)   0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 44)   3872        activation_33[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 44)   11616       activation_34[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 44)   3036        activation_35[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 44)   3036        activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 44)   2332        activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 44)   3036        activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 44)   3036        activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 44)   2332        activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 44)   0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 44)   0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 28, 28, 264)  0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 44)   11616       activation_45[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 44)   11616       activation_46[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 44)   3036        activation_47[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_49[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 44)   3036        activation_51[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_53[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 44)   2332        activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_166[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_168[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_170[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_172[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_174[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_11
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_11
# __________________________________________________________________________________________________
# normal_left3_11 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_left4_11 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_right4_11 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_11[
# __________________________________________________________________________________________________
# normal_add_1_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_11 (Add)           (None, 7, 7, 176)    0           normal_left3_11[0][0]
#                                                                  adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_add_4_11 (Add)           (None, 7, 7, 176)    0           normal_left4_11[0][0]
#                                                                  normal_right4_11[0][0]
# __________________________________________________________________________________________________
# normal_add_5_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_concat_11 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_11[0][0]
#                                                                  normal_add_1_11[0][0]
#                                                                  normal_add_2_11[0][0]
#                                                                  normal_add_3_11[0][0]
#                                                                  normal_add_4_11[0][0]
#                                                                  normal_add_5_11[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 7, 7, 1056)   0           normal_concat_10[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 7, 7, 1056)   0           normal_concat_11[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_12 (Conv (None, 7, 7, 176)    185856      activation_175[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_12 (Conv2D)       (None, 7, 7, 176)    185856      activation_176[0][0]
# __________________________________________________________________________________________________
# adjust_bn_12 (BatchNormalizatio (None, 7, 7, 176)    704         adjust_conv_projection_12[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_12 (BatchNormalizat (None, 7, 7, 176)    704         normal_conv_1_12[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 176)    35376       activation_177[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 176)    32560       activation_179[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 176)    35376       activation_181[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 176)    32560       activation_183[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 176)    32560       activation_185[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right2_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left5_12[
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_178[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_180[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_182[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_184[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_186[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_12
# __________________________________________________________________________________________________
# normal_left3_12 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_left4_12 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_right4_12 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_12[
# __________________________________________________________________________________________________
# normal_add_1_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_12 (Add)           (None, 7, 7, 176)    0           normal_left3_12[0][0]
#                                                                  adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_add_4_12 (Add)           (None, 7, 7, 176)    0           normal_left4_12[0][0]
#                                                                  normal_right4_12[0][0]
# __________________________________________________________________________________________________
# normal_add_5_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_concat_12 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_12[0][0]
#                                                                  normal_add_1_12[0][0]
#                                                                  normal_add_2_12[0][0]
#                                                                  normal_add_3_12[0][0]
#                                                                  normal_add_4_12[0][0]
#                                                                  normal_add_5_12[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 7, 7, 1056)   0           normal_concat_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1056)         0           activation_187[0][0]
# ==================================================================================================
# Total params: 4,269,716
# Trainable params: 0
# Non-trainable params: 4,269,716
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1056)              4269716
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1082368
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 5,362,334
# Trainable params: 1,092,618
# Non-trainable params: 4,269,716
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 16/16 [==============================] - 27s 471ms/step - loss: 0.6697 - accuracy: 0.7852 - val_loss: 0.1456 - val_accuracy: 0.9490
# Epoch 2/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0892 - accuracy: 0.9707 - val_loss: 0.0933 - val_accuracy: 0.9765
# Epoch 3/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0482 - accuracy: 0.9883 - val_loss: 0.0739 - val_accuracy: 0.9765
# Epoch 4/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0267 - accuracy: 0.9902 - val_loss: 0.0723 - val_accuracy: 0.9765
# Epoch 5/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0170 - accuracy: 0.9980 - val_loss: 0.0699 - val_accuracy: 0.9686
# Epoch 6/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.0624 - val_accuracy: 0.9843
# Epoch 7/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.0891 - val_accuracy: 0.9725
# Epoch 8/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9882
# Epoch 9/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9843
# Epoch 10/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 11/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 12/2000
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 13/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9843
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 15/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 16/2000
# 16/16 [==============================] - 2s 139ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 17/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 18/2000
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 20/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 21/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 22/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 23/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 24/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 25/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 26/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 27/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 28/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 29/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 30/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 31/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 32/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 33/2000
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 34/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 35/2000
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 36/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 37/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 38/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 39/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 40/2000
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 41/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 42/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 43/2000
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 44/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 45/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 46/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 47/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 48/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 49/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 50/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 51/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 52/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 53/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 54/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 55/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 56/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 57/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 58/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 59/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9843
# Epoch 60/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 61/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 62/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 63/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9843
# Epoch 64/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9843
# Epoch 65/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 66/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 67/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 68/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 69/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 70/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 71/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 72/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 73/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 74/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 75/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 76/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 77/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 78/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 79/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 80/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 81/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 82/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 83/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 84/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 85/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 86/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 87/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 88/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 89/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 90/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 91/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 92/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 93/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 94/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 95/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 96/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 97/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 98/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 99/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 100/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 101/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 102/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 103/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 104/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 105/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 106/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 107/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 108/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 109/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 110/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 111/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 112/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 113/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 114/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.8671e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 115/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 116/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 117/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 118/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 119/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 120/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 121/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 122/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 123/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 124/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 125/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.2970e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 126/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 127/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 128/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 129/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.5547e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 130/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 131/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 132/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 133/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 134/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 135/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.8267e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 136/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.7922e-04 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 137/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 138/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9843
# Epoch 139/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9843
# Epoch 140/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 141/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 142/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.5483e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 143/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 144/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.9223e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 145/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.7769e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 146/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.7461e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 147/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.6763e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 148/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 149/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.4163e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 150/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.7624e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 151/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.9128e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 152/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.6550e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 153/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 9.7007e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 154/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 155/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 156/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.9963e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 157/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 158/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.7589e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 159/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.7023e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9843
# Epoch 160/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 161/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 162/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 8.7447e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 163/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.7025e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 164/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.0662e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 165/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.4104e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 166/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.4385e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 167/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.9281e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 168/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 9.6818e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 169/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.2961e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 170/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.6374e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 171/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 172/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.6559e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 173/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 9.6071e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 174/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.7344e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 175/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.5236e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 176/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 8.1654e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 177/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.3733e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 178/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.6459e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 179/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.1530e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9843
# Epoch 180/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 8.3642e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 181/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 8.2564e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 182/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.0098e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 183/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 9.0100e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 184/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.7187e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 185/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.1812e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 186/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.8240e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 187/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.3040e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 188/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.3522e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 189/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 8.0357e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 190/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 9.0743e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 191/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.8132e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 192/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.1826e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 193/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.7517e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 194/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.7771e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 195/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.3570e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 196/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.8539e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 197/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.6062e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 198/2000
# 16/16 [==============================] - 2s 132ms/step - loss: 8.1530e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 199/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.3524e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9843
# Epoch 200/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.1869e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.9416e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 202/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 7.9476e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9843
# Epoch 203/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.6541e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9843
# Epoch 204/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 8.8002e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 205/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.8044e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 206/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.4106e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 207/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.1148e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 208/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.8519e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 209/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.2344e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 210/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.4602e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 211/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.0336e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 212/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.0201e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 213/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.0169e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 214/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.2338e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 215/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.2979e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 216/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.6466e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 217/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.0695e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 218/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.7463e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 219/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.5705e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 220/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 7.6368e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 221/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.7546e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 222/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.2045e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 223/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.0704e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 224/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 8.4096e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 225/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.4078e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 226/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 7.5065e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 227/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.0227e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 228/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 7.5308e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 229/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.3413e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 230/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.5145e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 231/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.4950e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 232/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 6.2897e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 233/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.1157e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 234/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 6.3294e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 235/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.3527e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 236/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 6.7476e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 237/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.4017e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 238/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.0076e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 239/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 7.0110e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 240/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 6.0102e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 241/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 6.3951e-04 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 0.9843
# Epoch 242/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 6.7741e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 243/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.4940e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 244/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.7040e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 245/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.5282e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 246/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.8962e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 247/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.6393e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 248/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.9061e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 249/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 7.2989e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 250/2000
# 16/16 [==============================] - 2s 154ms/step - loss: 6.4241e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 251/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.1993e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 252/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.3713e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 253/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 5.5886e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 254/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 5.7542e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9843
# Epoch 255/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.1901e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 256/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 5.8475e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 257/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.1023e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 258/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.0704e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 259/2000
# 16/16 [==============================] - 2s 137ms/step - loss: 5.1357e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 260/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.3767e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 261/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.7227e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 262/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 5.8028e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 263/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.3666e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 264/2000
# 16/16 [==============================] - 2s 136ms/step - loss: 5.6711e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 265/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.3409e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 266/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 6.2375e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 267/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 6.3851e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 268/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.5811e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 269/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.5823e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9843
# Epoch 270/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.3936e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9843
# Epoch 271/2000
# 16/16 [==============================] - 2s 135ms/step - loss: 5.0379e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 272/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 6.4193e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 273/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.0552e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 274/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 6.0714e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 275/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.7004e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 276/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.7616e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 277/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.4447e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 278/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.5397e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 279/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.5438e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 280/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.4892e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 281/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.3638e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 282/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.2595e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 283/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.6327e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 284/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.8647e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 285/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.5365e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 286/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.2418e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 287/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.8081e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 288/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.0791e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 289/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.8666e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 290/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.5967e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9843
# Epoch 291/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.8782e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 292/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.9021e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9843
# Epoch 293/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.5618e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 294/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.5635e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 295/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.3302e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 296/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.2847e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 297/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.7672e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 298/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.5740e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 299/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.7078e-04 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 0.9843
# Epoch 300/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.6501e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 301/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.0258e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 302/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.4817e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 303/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.8626e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 304/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.0341e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 305/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.4312e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 306/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.8557e-04 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9843
# Epoch 307/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 5.1607e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 308/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.5852e-04 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 309/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.4108e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 310/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.2388e-04 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9843
# Epoch 311/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 4.8264e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 312/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.4018e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 313/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.7804e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 314/2000
# 16/16 [==============================] - 2s 134ms/step - loss: 4.2881e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9843
# Epoch 315/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.6774e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 316/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.2733e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 317/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.6348e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# Epoch 318/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.5042e-04 - accuracy: 1.0000 - val_loss: 0.0653 - val_accuracy: 0.9843
# Epoch 319/2000
# 16/16 [==============================] - 2s 133ms/step - loss: 4.0112e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9843
# ...
# Epoch 1899/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.7055e-07 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9843
# Epoch 1900/2000
# 16/16 [==============================] - 2s 142ms/step - loss: 1.6252e-07 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9843
# Epoch 1901/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 2.4401e-07 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9843
# Epoch 1902/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6624e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1903/2000
# 16/16 [==============================] - 2s 139ms/step - loss: 1.4179e-07 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9843
# Epoch 1904/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.6240e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1905/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.8743e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1906/2000
# 16/16 [==============================] - 2s 143ms/step - loss: 1.5495e-07 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9843
# Epoch 1907/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.8196e-07 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9843
# Epoch 1908/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6519e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1909/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5472e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1910/2000
# 16/16 [==============================] - 2s 139ms/step - loss: 1.6834e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1911/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.9511e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1912/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5867e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1913/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5437e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1914/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.9639e-07 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9843
# Epoch 1915/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5367e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1916/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.6950e-07 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9843
# Epoch 1917/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.8417e-07 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9843
# Epoch 1918/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.9115e-07 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9843
# Epoch 1919/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.9022e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1920/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5309e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1921/2000
# 16/16 [==============================] - 2s 142ms/step - loss: 1.9267e-07 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9843
# Epoch 1922/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6566e-07 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9843
# Epoch 1923/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5518e-07 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9843
# Epoch 1924/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.3609e-07 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9843
# Epoch 1925/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.6717e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1926/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6030e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1927/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5157e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1928/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.9488e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1929/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.9104e-07 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9843
# Epoch 1930/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6077e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1931/2000
# 16/16 [==============================] - 2s 142ms/step - loss: 2.1479e-07 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9843
# Epoch 1932/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.1991e-07 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9843
# Epoch 1933/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.4226e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1934/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.4633e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1935/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.6077e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1936/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 2.1118e-07 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9843
# Epoch 1937/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.8510e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1938/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.2736e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1939/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6333e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1940/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.6345e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1941/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3877e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1942/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.9197e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1943/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6508e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1944/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6286e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1945/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5646e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1946/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.7020e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1947/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.3865e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1948/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.8766e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1949/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.7788e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1950/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.4156e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1951/2000
# 16/16 [==============================] - 2s 142ms/step - loss: 1.4354e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1952/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6624e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1953/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6624e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1954/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.2934e-07 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9843
# Epoch 1955/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.3330e-07 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9843
# Epoch 1956/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.2491e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1957/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6938e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1958/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3586e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1959/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5006e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1960/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 2.3446e-07 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9843
# Epoch 1961/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6822e-07 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9843
# Epoch 1962/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6915e-07 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9843
# Epoch 1963/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.3201e-07 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9843
# Epoch 1964/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.9243e-07 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9843
# Epoch 1965/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3248e-07 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9843
# Epoch 1966/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.8440e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1967/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.4855e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1968/2000
# 16/16 [==============================] - 2s 142ms/step - loss: 1.3353e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1969/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3842e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1970/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5099e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1971/2000
# 16/16 [==============================] - 2s 139ms/step - loss: 1.2305e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1972/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.2282e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1973/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 2.0675e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1974/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.1967e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1975/2000
# 16/16 [==============================] - 2s 142ms/step - loss: 1.7602e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1976/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.2189e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1977/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.7614e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1978/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.6449e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1979/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3725e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1980/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.6938e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1981/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.2107e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1982/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5285e-07 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9843
# Epoch 1983/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.8242e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1984/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.4459e-07 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9843
# Epoch 1985/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.3015e-07 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9843
# Epoch 1986/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5215e-07 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9843
# Epoch 1987/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.4645e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1988/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5250e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1989/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3167e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1990/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.4552e-07 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 1991/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.5437e-07 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9843
# Epoch 1992/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.2130e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 1993/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 2.0570e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1994/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.7008e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1995/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.4342e-07 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9843
# Epoch 1996/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.4249e-07 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9843
# Epoch 1997/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.5658e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1998/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3516e-07 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9843
# Epoch 1999/2000
# 16/16 [==============================] - 2s 140ms/step - loss: 1.7381e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# Epoch 2000/2000
# 16/16 [==============================] - 2s 141ms/step - loss: 1.3679e-07 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9843
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 8/8 [==============================] - 4s 154ms/step - loss: 0.6249 - accuracy: 0.9093
# test_indoor_ds_results:test loss, test acc: [0.6249271631240845, 0.9092702269554138]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 16/16 [==============================] - 9s 291ms/step - loss: 1.8676 - accuracy: 0.8059
# test_outdoor_ds_results:test loss, test acc: [1.8675611019134521, 0.8058823347091675]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 9/9 [==============================] - 3s 148ms/step - loss: 1.3320 - accuracy: 0.8225
# test_belt_ds_results:test loss, test acc: [1.3320226669311523, 0.8224955797195435]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 8/8 [==============================] - 4s 109ms/step - loss: 0.3566 - accuracy: 0.9014
# 16/16 [==============================] - 2s 111ms/step - loss: 1.0060 - accuracy: 0.8000
# 9/9 [==============================] - 1s 110ms/step - loss: 0.7763 - accuracy: 0.8172
# Epoch200
#  test_indoor_acc=0.9013806581497192
#  test_outdoor_acc=0.800000011920929
#  test_belt_acc=0.8172231912612915
# 8/8 [==============================] - 4s 112ms/step - loss: 0.3874 - accuracy: 0.9014
# 16/16 [==============================] - 2s 113ms/step - loss: 1.1054 - accuracy: 0.8020
# 9/9 [==============================] - 1s 112ms/step - loss: 0.8390 - accuracy: 0.8225
# Epoch400
#  test_indoor_acc=0.9013806581497192
#  test_outdoor_acc=0.8019607663154602
#  test_belt_acc=0.8224955797195435
# 8/8 [==============================] - 11s 111ms/step - loss: 0.4172 - accuracy: 0.9034
# 16/16 [==============================] - 2s 111ms/step - loss: 1.2264 - accuracy: 0.8039
# 9/9 [==============================] - 1s 109ms/step - loss: 0.9071 - accuracy: 0.8207
# Epoch600
#  test_indoor_acc=0.9033530354499817
#  test_outdoor_acc=0.8039215803146362
#  test_belt_acc=0.8207381367683411
# 8/8 [==============================] - 4s 112ms/step - loss: 0.4581 - accuracy: 0.9053
# 16/16 [==============================] - 2s 113ms/step - loss: 1.3635 - accuracy: 0.8069
# 9/9 [==============================] - 1s 112ms/step - loss: 0.9885 - accuracy: 0.8207
# Epoch800
#  test_indoor_acc=0.9053254723548889
#  test_outdoor_acc=0.8068627715110779
#  test_belt_acc=0.8207381367683411
# 8/8 [==============================] - 4s 115ms/step - loss: 0.5050 - accuracy: 0.9053
# 16/16 [==============================] - 2s 114ms/step - loss: 1.4905 - accuracy: 0.8069
# 9/9 [==============================] - 1s 113ms/step - loss: 1.0818 - accuracy: 0.8207
# Epoch1000
#  test_indoor_acc=0.9053254723548889
#  test_outdoor_acc=0.8068627715110779
#  test_belt_acc=0.8207381367683411
# 8/8 [==============================] - 4s 111ms/step - loss: 0.5389 - accuracy: 0.9073
# 16/16 [==============================] - 2s 113ms/step - loss: 1.6050 - accuracy: 0.8069
# 9/9 [==============================] - 1s 113ms/step - loss: 1.1482 - accuracy: 0.8243
# Epoch1200
#  test_indoor_acc=0.9072978496551514
#  test_outdoor_acc=0.8068627715110779
#  test_belt_acc=0.8242530822753906
# 8/8 [==============================] - 4s 112ms/step - loss: 0.5664 - accuracy: 0.9093
# 16/16 [==============================] - 2s 111ms/step - loss: 1.6939 - accuracy: 0.8059
# 9/9 [==============================] - 1s 111ms/step - loss: 1.2105 - accuracy: 0.8243
# Epoch1400
#  test_indoor_acc=0.9092702269554138
#  test_outdoor_acc=0.8058823347091675
#  test_belt_acc=0.8242530822753906
# 8/8 [==============================] - 12s 114ms/step - loss: 0.5963 - accuracy: 0.9073
# 16/16 [==============================] - 2s 115ms/step - loss: 1.7801 - accuracy: 0.8059
# 9/9 [==============================] - 1s 114ms/step - loss: 1.2657 - accuracy: 0.8243
# Epoch1600
#  test_indoor_acc=0.9072978496551514
#  test_outdoor_acc=0.8058823347091675
#  test_belt_acc=0.8242530822753906
# 8/8 [==============================] - 4s 116ms/step - loss: 0.6157 - accuracy: 0.9073
# 16/16 [==============================] - 2s 116ms/step - loss: 1.8313 - accuracy: 0.8059
# 9/9 [==============================] - 1s 115ms/step - loss: 1.3070 - accuracy: 0.8243
# Epoch1800
#  test_indoor_acc=0.9072978496551514
#  test_outdoor_acc=0.8058823347091675
#  test_belt_acc=0.8242530822753906
# 8/8 [==============================] - 4s 112ms/step - loss: 0.6249 - accuracy: 0.9093
# 16/16 [==============================] - 2s 112ms/step - loss: 1.8676 - accuracy: 0.8059
# 9/9 [==============================] - 1s 113ms/step - loss: 1.3320 - accuracy: 0.8225
# Epoch2000
#  test_indoor_acc=0.9092702269554138
#  test_outdoor_acc=0.8058823347091675
#  test_belt_acc=0.8224955797195435

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8464685479799906
# max index -> 6
# The [Epoch] of max acc -> 1400

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9013806581497192,
#  0.9013806581497192,
#  0.9033530354499817,
#  0.9053254723548889,
#  0.9053254723548889,
#  0.9072978496551514,
#  0.9092702269554138,
#  0.9072978496551514,
#  0.9072978496551514,
#  0.9092702269554138]

# %%
test_outdoor_acc
# Out:
# [0.800000011920929,
#  0.8019607663154602,
#  0.8039215803146362,
#  0.8068627715110779,
#  0.8068627715110779,
#  0.8068627715110779,
#  0.8058823347091675,
#  0.8058823347091675,
#  0.8058823347091675,
#  0.8058823347091675]

# %%
test_belt_acc
# Out:
# [0.8172231912612915,
#  0.8224955797195435,
#  0.8207381367683411,
#  0.8207381367683411,
#  0.8207381367683411,
#  0.8242530822753906,
#  0.8242530822753906,
#  0.8242530822753906,
#  0.8242530822753906,
#  0.8224955797195435]

# %%
test_indoor_loss
# Out:
# [0.35657820105552673,
#  0.3873597979545593,
#  0.41724878549575806,
#  0.4581001400947571,
#  0.5049512982368469,
#  0.5389367341995239,
#  0.5663942098617554,
#  0.5963428616523743,
#  0.6157285571098328,
#  0.6249271631240845]

# %%
test_outdoor_loss
# Out:
# [1.0059659481048584,
#  1.1053656339645386,
#  1.2264139652252197,
#  1.3635417222976685,
#  1.4905316829681396,
#  1.6050047874450684,
#  1.6938884258270264,
#  1.7800654172897339,
#  1.8312668800354004,
#  1.8675611019134521]

# %%
test_belt_loss
# Out:
# [0.7762977480888367,
#  0.8390001654624939,
#  0.9070802330970764,
#  0.9885445833206177,
#  1.0817897319793701,
#  1.1481904983520508,
#  1.2105467319488525,
#  1.2657350301742554,
#  1.3069539070129395,
#  1.3320226669311523]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.nasnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5812
# FP=1328
# acc=0.8140056022408964
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 90.65420560747664%
# 2-BloodSecretionWaste acc = 63.74639769452449%
# 3-LabWardWaste acc = 77.27952167414051%
# 4-VaccineOtherWaste acc = 89.95796356842597%
#
#
#
# all_avg_eachclass = 80.4095221361419%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1746,   97,   34,   49],
#        [ 485, 1106,   66,   78],
#        [  81,  101, 1034,  122],
#        [  17,   99,   99, 1926]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[90.65420561,  5.03634476,  1.76531672,  2.54413292],
#        [27.95389049, 63.74639769,  3.80403458,  4.49567723],
#        [ 6.05381166,  7.54857997, 77.27952167,  9.1180867 ],
#        [ 0.79402149,  4.62400747,  4.62400747, 89.95796357]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
