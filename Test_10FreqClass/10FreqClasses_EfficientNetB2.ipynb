# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=260
img_width=260
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 260, 260, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB2

efficientnetB0_model = keras.applications.EfficientNetB2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 130, 130, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 130, 130, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 130, 130, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 130, 130, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 130, 130, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 130, 130, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 130, 130, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 130, 130, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 130, 130, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 130, 130, 16) 144         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 130, 130, 16) 64          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 130, 130, 16) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 16)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 16)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 4)      68          block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 16)     80          block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 130, 130, 16) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 130, 130, 16) 256         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 130, 130, 16) 64          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 130, 130, 16) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 130, 130, 16) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 130, 130, 96) 1536        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 130, 130, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 130, 130, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 131, 131, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 65, 65, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 65, 65, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 65, 65, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 65, 65, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 65, 65, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 65, 65, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 65, 65, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 65, 65, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 65, 65, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 65, 65, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 65, 65, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 65, 65, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 65, 65, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 65, 65, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 65, 65, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 65, 65, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 65, 65, 144)  576         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 65, 65, 144)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 65, 65, 144)  1296        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 65, 65, 144)  576         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 65, 65, 144)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 144)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 65, 65, 144)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 65, 65, 24)   3456        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 65, 65, 24)   96          block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 65, 65, 24)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 65, 65, 24)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 65, 65, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 65, 65, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 69, 69, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 33, 33, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 33, 33, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 33, 33, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 33, 33, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 33, 33, 48)   6912        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 33, 33, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 33, 33, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 33, 33, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 33, 33, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 33, 33, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 33, 33, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 33, 33, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 33, 33, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 33, 33, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 33, 33, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 33, 33, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 33, 33, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 33, 33, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 33, 33, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 33, 33, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 33, 33, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 33, 33, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 33, 33, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 33, 33, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 33, 33, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 35, 35, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 17, 17, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 17, 17, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 17, 17, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 17, 17, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 17, 17, 88)   25344       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 17, 17, 88)   352         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 17, 17, 528)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 17, 17, 528)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 528)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 17, 17, 528)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 17, 17, 88)   352         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 17, 17, 88)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 17, 17, 88)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 17, 17, 528)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 17, 17, 528)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 528)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 17, 17, 528)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 17, 17, 88)   352         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 17, 17, 88)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 17, 17, 88)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 17, 17, 528)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 17, 17, 528)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 528)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 17, 17, 528)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 17, 17, 88)   352         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 17, 17, 88)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 17, 17, 88)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 17, 17, 528)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 17, 17, 528)  13200       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 17, 17, 528)  2112        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 17, 17, 528)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 528)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 528)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 17, 17, 528)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 17, 17, 120)  63360       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 17, 17, 120)  480         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 17, 17, 720)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 17, 17, 720)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 720)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 17, 17, 720)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 17, 17, 120)  86400       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 17, 17, 120)  480         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 17, 17, 120)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 17, 17, 120)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 17, 17, 720)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 17, 17, 720)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 720)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 17, 17, 720)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 17, 17, 120)  86400       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 17, 17, 120)  480         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 17, 17, 120)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 17, 17, 120)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5c_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5d_expand_activation (Acti (None, 17, 17, 720)  0           block5d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5d_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5d_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5d_dwconv[0][0]
# __________________________________________________________________________________________________
# block5d_activation (Activation) (None, 17, 17, 720)  0           block5d_bn[0][0]
# __________________________________________________________________________________________________
# block5d_se_squeeze (GlobalAvera (None, 720)          0           block5d_activation[0][0]
# __________________________________________________________________________________________________
# block5d_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5d_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5d_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6c_expand_activation (Acti (None, 9, 9, 1248)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 9, 9, 1248)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1248)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 9, 9, 208)    832         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 9, 9, 208)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 9, 9, 208)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 9, 9, 1248)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 9, 9, 1248)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1248)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 9, 9, 208)    832         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 9, 9, 208)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 9, 9, 208)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 9, 9, 1248)   0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 9, 9, 1248)   0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1248)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 9, 9, 208)    832         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 9, 9, 208)    0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 9, 9, 208)    0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 9, 9, 1248)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   11232       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 9, 9, 1248)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1248)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 9, 9, 1248)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 9, 9, 352)    439296      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 9, 9, 352)    1408        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 9, 9, 2112)   743424      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 9, 9, 2112)   8448        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 9, 9, 2112)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 9, 9, 2112)   19008       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 9, 9, 2112)   8448        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 9, 9, 2112)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2112)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2112)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 88)     185944      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2112)   187968      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 9, 9, 2112)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 9, 9, 352)    743424      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 9, 9, 352)    1408        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 9, 9, 352)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 9, 9, 352)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 9, 9, 1408)   495616      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 9, 9, 1408)   5632        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 9, 9, 1408)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1408)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 7,768,569
# Trainable params: 0
# Non-trainable params: 7,768,569
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1408)              7768569
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1442816
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 9,221,635
# Trainable params: 1,453,066
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 16/16 [==============================] - 25s 523ms/step - loss: 0.5388 - accuracy: 0.8398 - val_loss: 0.0651 - val_accuracy: 0.9725
# Epoch 2/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 0.0417 - accuracy: 0.9902 - val_loss: 0.0319 - val_accuracy: 0.9922
# Epoch 3/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 0.0089 - accuracy: 0.9990 - val_loss: 0.0208 - val_accuracy: 0.9961
# Epoch 4/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9922
# Epoch 5/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.0198 - val_accuracy: 0.9922
# Epoch 6/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9961
# Epoch 7/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9961
# Epoch 8/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9961
# Epoch 9/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0219 - val_accuracy: 0.9961
# Epoch 10/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9961
# Epoch 11/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9961
# Epoch 12/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9961
# Epoch 13/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 0.0038 - accuracy: 0.9980 - val_loss: 0.0160 - val_accuracy: 0.9922
# Epoch 14/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 8.4391e-04 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 0.9922
# Epoch 15/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 8.3491e-04 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9961
# Epoch 16/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 6.8445e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9961
# Epoch 17/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 7.0834e-04 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9961
# Epoch 18/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0042 - accuracy: 0.9980 - val_loss: 0.0207 - val_accuracy: 0.9882
# Epoch 19/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9961
# Epoch 20/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.0170 - val_accuracy: 0.9922
# Epoch 21/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 0.9961
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 22/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9961
# Epoch 23/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.0137 - val_accuracy: 0.9961
# Epoch 24/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.4102e-04 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 0.9961
# Epoch 25/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.7582e-04 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9961
# Epoch 26/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 0.9961
# Epoch 27/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.5498e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9961
# Epoch 28/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 4.8380e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9961
# Epoch 29/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.9714e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9961
# Epoch 30/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.1265e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9961
# Epoch 31/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.0443e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 0.9961
# Epoch 32/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.6774e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9961
# Epoch 33/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 9.4417e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 34/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.3906e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 35/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 3.7975e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 36/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 7.1559e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 37/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.6936e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 38/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 9.5916e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 39/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.2171e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 40/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 4.4022e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 41/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 4.4598e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 42/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.7139e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 43/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.6650e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 44/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 3.6072e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 45/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.8182e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 46/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 9.5839e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 47/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 5.4011e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 48/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.1349e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 49/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 7.1728e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 50/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.6004e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 51/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.7869e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 52/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.5935e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 53/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 54/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.9976e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 55/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 3.2977e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 56/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.8404e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 57/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 2.7426e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 58/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.9838e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 59/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.4577e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 60/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.6019e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 61/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.6582e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 62/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.3969e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 63/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 5.5631e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 64/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.9343e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 65/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.4210e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 66/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 67/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0024 - accuracy: 0.9980 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 68/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.3100e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 69/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.4054e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 70/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.7250e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 71/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 4.0990e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 72/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 5.4294e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 73/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.9912e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 74/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.2720e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 75/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 5.8651e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 76/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.5478e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 77/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.5393e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 78/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.4804e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 79/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.9388e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 80/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 9.1080e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 81/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 7.1456e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 82/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.6632e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 83/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.8766e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 84/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.6565e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 85/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.2807e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 86/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.5686e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 87/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.9129e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 88/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.8341e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 89/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.6483e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 90/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.8834e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 91/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 8.9816e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 92/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.1283e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 93/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.9544e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 94/2000
# 16/16 [==============================] - 4s 231ms/step - loss: 4.1883e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 95/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.9225e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 96/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 97/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 98/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.7159e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9961
# Epoch 99/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.2061e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9961
# Epoch 100/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.7977e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 101/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.9470e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 102/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.7405e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 103/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 4.7116e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 104/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 4.3374e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 105/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.2556e-04 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 0.9961
# Epoch 106/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.5165e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 107/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.2062e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 108/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.2997e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 109/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.7841e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 110/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.8941e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 111/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.4454e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 112/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.0829e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 113/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.0743e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 114/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.7126e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 115/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.7887e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 116/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.1302e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 117/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.9562e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 118/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 119/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 8.1732e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 120/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.2477e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 121/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.3564e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 122/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 7.8772e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9961
# Epoch 123/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.7739e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 124/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.2981e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 125/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.1181e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 126/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.0278e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 127/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.7687e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 128/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.7757e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 129/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.4432e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 130/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.7595e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 131/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.7516e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 132/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.8177e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 133/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.9196e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 134/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.5840e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 135/2000
# 16/16 [==============================] - 4s 231ms/step - loss: 2.3596e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 136/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.1887e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 137/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.1459e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 138/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.2239e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 139/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.3590e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9961
# Epoch 140/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.7398e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 141/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.3087e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 142/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 5.1254e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 143/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.0624e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 144/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 3.6554e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 145/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.6040e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 146/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.7704e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9961
# Epoch 147/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.3152e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 148/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.6519e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 149/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.9445e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 150/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.3190e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 151/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.0870e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 152/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.8665e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 153/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.4274e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 154/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.6447e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 155/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.1175e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 156/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.7302e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 157/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.1004e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 158/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.2748e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 159/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.5962e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 160/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.9617e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 161/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 0.0016 - accuracy: 0.9990 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 162/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.4009e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 163/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.7865e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 164/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.5486e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 165/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.0588e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 166/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.8947e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 167/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.3886e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9961
# Epoch 168/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 0.0126 - accuracy: 0.9990 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 169/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.5689e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 170/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 9.6789e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 171/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.4241e-04 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9961
# Epoch 172/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.4741e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 173/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.6265e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 174/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.6634e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 175/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.9286e-04 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 0.9961
# Epoch 176/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.9803e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9961
# Epoch 177/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.9299e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9961
# Epoch 178/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 3.5642e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9961
# Epoch 179/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1707e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9961
# Epoch 180/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.8481e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 181/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.8036e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 182/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.0182e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 183/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 4.4872e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 184/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 6.6677e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 185/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.8208e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 186/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 187/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 4.1575e-04 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 188/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.3320e-04 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 189/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.5924e-04 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 190/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.6905e-04 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 191/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.4599e-04 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 192/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 5.1605e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 193/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.2218e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 194/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 195/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2089e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 196/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.8550e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 197/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.5494e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 198/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.9597e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 199/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 6.4365e-04 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9961
# Epoch 200/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 0.0012 - accuracy: 0.9990 - val_loss: 0.0103 - val_accuracy: 0.9961
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 2.5619e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 202/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.0877e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 203/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.1889e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9961
# Epoch 204/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.0833e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9961
# Epoch 205/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 4.3803e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961: 1s - loss: 5.4272e
# Epoch 206/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.9924e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 207/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.5351e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 208/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.3365e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 209/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.9476e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 210/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.1175e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 211/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.4916e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 212/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.9559e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 213/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.2465e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 214/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8865e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 215/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1247e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 216/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2446e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 217/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.7632e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 218/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 219/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 7.0455e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 220/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.3500e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 221/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1574e-04 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9961
# Epoch 222/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.3449e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9961
# Epoch 223/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.5703e-04 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9961
# Epoch 224/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.4744e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 225/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.0032e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 226/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.9387e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 227/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 4.1557e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 228/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.7824e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 229/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.6013e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 230/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1447e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 231/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.5017e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 232/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.7830e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 233/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.3041e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 234/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 4.5877e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 235/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2888e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 236/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8679e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 237/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.8044e-04 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9961
# Epoch 238/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.3435e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 239/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.0218e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 240/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.8684e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 241/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8927e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 242/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.6170e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 243/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.1268e-04 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 0.9961
# Epoch 244/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0099 - val_accuracy: 0.9961
# Epoch 245/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2281e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 246/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8650e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 247/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 5.8201e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 248/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.8175e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 249/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.8846e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 250/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.4344e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 251/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 4.5494e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 252/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.7920e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 253/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.4239e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 254/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 1.8443e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 255/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.6469e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 256/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.5491e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 257/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.1176e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 258/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.4229e-04 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9961
# Epoch 259/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 6.0840e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 260/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8116e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9961
# Epoch 261/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.1427e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 262/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.9409e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 263/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.5717e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 264/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.4466e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 265/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.9848e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 266/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 4.7264e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 267/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.3167e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 268/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.7036e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 269/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.2123e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 270/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.8167e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 271/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1002e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 272/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1820e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 273/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.0239e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 274/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2399e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 275/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 2.0774e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 276/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.6393e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 277/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.4052e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 278/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.9369e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 279/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.0246e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 280/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.0025e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 281/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.0299e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 282/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1177e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.99617e-04 - accuracy: 1.00
# Epoch 283/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1353e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 284/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.1344e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 285/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.0769e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 286/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.0150e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 287/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.7493e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 288/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8878e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 289/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.1286e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 290/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2056e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 291/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.2688e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 292/2000
# 16/16 [==============================] - 4s 228ms/step - loss: 1.6030e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 293/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.1101e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 294/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.7684e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 295/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.7581e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 296/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.5399e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 297/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.8708e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 298/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.2023e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 299/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8109e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 300/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.5429e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 301/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.4884e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 302/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.3711e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 303/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.4750e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 304/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 1.7621e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 305/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.8756e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 306/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.3886e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 307/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 2.9364e-04 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 0.9961
# Epoch 308/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.3024e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 309/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.7841e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 310/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.9664e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 311/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 3.3954e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 312/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.6656e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 313/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 1.6070e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 314/2000
# 16/16 [==============================] - 4s 227ms/step - loss: 2.7418e-04 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9961
# Epoch 315/2000
# 16/16 [==============================] - 4s 226ms/step - loss: 3.0337e-04 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9961
# Epoch 316/2000
# ...
# Epoch 1899/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.0549e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1900/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.7812e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1901/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.4757e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1902/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2676e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1903/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.4008e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1904/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.9991e-06 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1905/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.6683e-06 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1906/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.4221e-06 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1907/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.9961e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1908/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1571e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1909/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 6.0263e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1910/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2200e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1911/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.2111e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1912/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.6641e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1913/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.2655e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1914/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.5431e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1915/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.1966e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1916/2000
# 16/16 [==============================] - 4s 231ms/step - loss: 2.3814e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9961
# Epoch 1917/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.5522e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1918/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 8.5301e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1919/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0861e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1920/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.1171e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1921/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.8489e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1922/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1260e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1923/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.4830e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1924/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.1178e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1925/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 4.6660e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1926/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 9.6751e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1927/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.7183e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1928/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.7547e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1929/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1929e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1930/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.3466e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1931/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0005e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1932/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0215e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1933/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0176e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1934/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.4977e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1935/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.5989e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1936/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.5349e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1937/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.3585e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1938/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 7.8935e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1939/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.7374e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1940/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1413e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1941/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 8.7093e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1942/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.1425e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1943/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.3285e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1944/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0083e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1945/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.6016e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1946/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.9407e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1947/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.0823e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1948/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.6463e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1949/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.3870e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1950/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.0635e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1951/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.8218e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1952/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.1991e-06 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1953/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 3.3566e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1954/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.4565e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1955/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 6.6555e-06 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1956/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0569e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1957/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.4329e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1958/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.6566e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1959/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.0777e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1960/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.2807e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1961/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.1296e-05 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1962/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.0063 - val_accuracy: 0.9961
# Epoch 1963/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.1128e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1964/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.0843e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1965/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2844e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1966/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.2646e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1967/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 9.8417e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1968/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.3827e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1969/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1324e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1970/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.8649e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1971/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.3215e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1972/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2718e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1973/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 9.0305e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1974/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.0716e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1975/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.3909e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1976/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.4036e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1977/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.6235e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1978/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.1990e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1979/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 8.2889e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1980/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.8154e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1981/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.4151e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1982/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 7.5802e-06 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1983/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.9446e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9961
# Epoch 1984/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 2.5061e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1985/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 7.6376e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1986/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.1638e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1987/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.0435e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1988/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.5178e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1989/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2381e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1990/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.7434e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1991/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.6720e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1992/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 2.6705e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1993/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 1.2892e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1994/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.6469e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1995/2000
# 16/16 [==============================] - 4s 230ms/step - loss: 5.3586e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1996/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 3.0127e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1997/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 7.4781e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1998/2000
# 16/16 [==============================] - 4s 229ms/step - loss: 1.0009e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 1999/2000
# 16/16 [==============================] - 4s 231ms/step - loss: 1.0944e-05 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# Epoch 2000/2000
# 16/16 [==============================] - 4s 231ms/step - loss: 9.8871e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9961
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 8/8 [==============================] - 6s 337ms/step - loss: 0.0414 - accuracy: 0.9783
# test_indoor_ds_results:test loss, test acc: [0.04137585684657097, 0.9783037304878235]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 16/16 [==============================] - 11s 371ms/step - loss: 0.4298 - accuracy: 0.9196
# test_outdoor_ds_results:test loss, test acc: [0.4298016428947449, 0.9196078181266785]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 9/9 [==============================] - 4s 316ms/step - loss: 0.6856 - accuracy: 0.87170s - loss: 0.6828 - accu
# test_belt_ds_results:test loss, test acc: [0.685623288154602, 0.8717047572135925]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_86649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_51729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_98261) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_49204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_91769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_48591) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_48408) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_88177) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_47927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_52360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_98934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_49695) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_97047) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_92870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_92936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_95080) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_95858) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_93543) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_91703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_37466) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_94710) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_84119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_49296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_91074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_98327) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_92263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_50408) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_92329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_50367) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_97113) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_96876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_89973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_91510) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_49868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_87141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_95687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_90467) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_50576) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_88111) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_88671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_90903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_49486) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_89107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_50800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_50316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_98868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_87918) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_98697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_48316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_52518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_47968) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_50143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_100471) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_87075) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_47768) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_95317) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_50525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_48158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_97654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_52136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_97483) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_94644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_89278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_99541) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_50973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_50749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_96553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_97720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_93477) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_48863) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_93306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_50841) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_95924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_86904) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_50184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_51024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_49919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_52177) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_92092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_52401) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_96294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_51637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_100101) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_52569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_48764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_51953) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_49527) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_52610) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_87548) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_51505) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_48100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_99304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_49428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_47809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_48199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_51197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_49072) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_94473) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_49255) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_48980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_95251) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_100035) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_51464) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_90533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_48540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_47717) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_51065) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_89344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_51861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_99475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_77511) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_52085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_92699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_49644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_89907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_51912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_49031) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_98090) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_90296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_94084) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_52309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_49960) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_51296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_88737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_49736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_51413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_99864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_48822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_50617) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_48632) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_89714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_52742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_51688) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_80063) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_51255) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_87482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_88500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_48367) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_50092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_94150) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_93913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_96487) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_91140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 8/8 [==============================] - 3s 177ms/step - loss: 0.0526 - accuracy: 0.9763
# 16/16 [==============================] - 3s 177ms/step - loss: 0.4066 - accuracy: 0.9118
# 9/9 [==============================] - 2s 176ms/step - loss: 0.5489 - accuracy: 0.8699
# Epoch200
#  test_indoor_acc=0.976331353187561
#  test_outdoor_acc=0.9117646813392639
#  test_belt_acc=0.8699472546577454
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_181836) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_173245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_169283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_133240) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_168876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_131430) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_133372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_180669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_134345) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_173504) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_181210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_168639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_179218) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_131163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_172875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_131471) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_168810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_131262) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_173438) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_130715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_134095) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_171013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_176445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_132484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_132800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_131878) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_132311) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_175885) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_177659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_176986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_130557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_171449) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_169912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_133199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_170406) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_133688) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_175212) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_169217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_180062) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_132102) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_172809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_159246) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_129703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_179996) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_130807) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_131031) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_176815) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_171642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_182206) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_132708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_178848) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_119201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_132352) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_129835) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_177422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_130143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_176208) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_171708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_170472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_169653) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_133031) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_131379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_171079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_161798) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_130499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_179825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_133647) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_178782) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_172202) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_134304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_177593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_179389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_172268) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_174064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_172638) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_174671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_130051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_180603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_170842) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_181770) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_175819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_178611) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_131695) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_131919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_181039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_131827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_129544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_172031) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_178288) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_180432) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_174605) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_176379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_168384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_181599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_835418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_784351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_783870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_784259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_783660) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_826410) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_835978) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_827083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_785015) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_827646) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_823425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_825850) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_785679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_786967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_785371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_823018) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_788512) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_825221) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_788303) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_829856) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_833663) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_787448) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_784806) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_836414) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_788461) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_829249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_834877) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_786743) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_831801) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_784534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_835807) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_785903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_787580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_785239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_785587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_783911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_813454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_787672) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_833056) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_787356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_826476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_822592) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_785638) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_786259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_783752) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_825050) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_785811) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_832819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_823491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_816006) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_786086) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_826846) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_833597) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_773409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_824680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_788252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_786784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_787855) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_788079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_834204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_824443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_786310) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_831630) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_832496) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_784142) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_824054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_832237) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_825916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_825287) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_786351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_788344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_828813) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_824120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_784043) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_831867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_785862) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_825657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 8/8 [==============================] - 3s 178ms/step - loss: 0.0414 - accuracy: 0.9783
# 16/16 [==============================] - 3s 179ms/step - loss: 0.4298 - accuracy: 0.9196
# 9/9 [==============================] - 2s 177ms/step - loss: 0.6856 - accuracy: 0.8717
# Epoch2000
#  test_indoor_acc=0.9783037304878235
#  test_outdoor_acc=0.9196078181266785
#  test_belt_acc=0.8717047572135925

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.9247755209604899
# max index -> 8
# The [Epoch] of max acc -> 1800

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.976331353187561,
#  0.9783037304878235,
#  0.9783037304878235,
#  0.9783037304878235,
#  0.9783037304878235,
#  0.9802761077880859,
#  0.9783037304878235,
#  0.9783037304878235,
#  0.9802761077880859,
#  0.9783037304878235]

# %%
test_outdoor_acc
# Out:
# [0.9117646813392639,
#  0.9107843041419983,
#  0.9117646813392639,
#  0.9176470637321472,
#  0.9196078181266785,
#  0.9176470637321472,
#  0.9176470637321472,
#  0.9215686321258545,
#  0.9205882549285889,
#  0.9196078181266785]

# %%
test_belt_acc
# Out:
# [0.8699472546577454,
#  0.8717047572135925,
#  0.8734622001647949,
#  0.8734622001647949,
#  0.8717047572135925,
#  0.8752197027206421,
#  0.8717047572135925,
#  0.8664323091506958,
#  0.8734622001647949,
#  0.8717047572135925]

# %%
test_indoor_loss
# Out:
# [0.05256881192326546,
#  0.04936648905277252,
#  0.04662945866584778,
#  0.04498305916786194,
#  0.04405758157372475,
#  0.04232390224933624,
#  0.03963666781783104,
#  0.04728524014353752,
#  0.04271848127245903,
#  0.04137585684657097]

# %%
test_outdoor_loss
# Out:
# [0.40656018257141113,
#  0.4088728427886963,
#  0.4093570113182068,
#  0.39285436272621155,
#  0.3921492099761963,
#  0.395097553730011,
#  0.4136125147342682,
#  0.3916439414024353,
#  0.4030088782310486,
#  0.4298016428947449]

# %%
test_belt_loss
# Out:
# [0.548944354057312,
#  0.5654339790344238,
#  0.5845740437507629,
#  0.6051585078239441,
#  0.6256312131881714,
#  0.6259971261024475,
#  0.6267386078834534,
#  0.6557426452636719,
#  0.6666886210441589,
#  0.685623288154602]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=260
img_width=260
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_742901) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_746493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_743508) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_750717) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_744631) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_705419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_706249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_703592) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_752425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_702704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_705005) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_701932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_752491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_705852) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_705361) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_702322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_705460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_734227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_702480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_753705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_706300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_750458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_753032) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_706524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_743878) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_704740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_748874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_744697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_704256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_738283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_751211) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_743271) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_691630) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_703236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_748637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_750651) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_706473) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_748808) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_702531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_750022) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_754199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_741646) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_754635) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_702928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_705893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_752254) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_703195) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_742835) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_704124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_704348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_744460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_704689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_703808) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_751040) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_705669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_701881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_704480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_749244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_744137) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_701973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_752861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_706117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_703900) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_706906) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_742664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_754265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_753639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_748077) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_741239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_703419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_703859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_706076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_751277) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_702363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_702132) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_742275) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_704913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_745867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_751818) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_741305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_705188) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_706025) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_703691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_702572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_749415) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_704964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_748248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_743442) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_745067) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_747707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_753468) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_704032) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_706774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_747641) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_705628) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_747034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_704572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_751647) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_705229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_703368) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_706341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_704083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_746427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_749851) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_705801) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_702986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_731675) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_703027) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_749481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_704531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_746863) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_754028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_706565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_741068) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_705137) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_747100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_702796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_705577) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_742341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_745933) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_740813) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_742082) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_702091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_744071) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_706733) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_750088) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_746256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_751884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_706682) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_704307) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_703460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_745674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_703650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_703144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_702264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_741712) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_745304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_704781) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_747470) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_702755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_748314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_753098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_745238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507
# train_outdoor num x,y : 1020,1020
# train_belt num x,y : 569,569
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1933
# FP=163
# acc=0.9222328244274809
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 87.31343283582089%
# CottonBall acc = 100.0%
# ExtensionTube acc = 68.29268292682927%
# Glove acc = 97.91666666666666%
# Mask acc = 99.22077922077922%
# NGTube acc = 63.2258064516129%
# Needle acc = 93.92857142857143%
# OxygenMask acc = 98.49624060150376%
# Syringe acc = 99.23954372623575%
# UrineBag acc = 84.16666666666667%
#
#
#
# all_avg_eachclass = 89.18003905246866%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[117,   0,   0,   2,   0,   2,   2,   1,   2,   8],
#        [  0, 167,   0,   0,   0,   0,   0,   0,   0,   0],
#        [  3,   0,  84,   0,  11,  20,   1,   3,   1,   0],
#        [  3,   0,   0, 329,   1,   0,   0,   0,   2,   1],
#        [  0,   0,   0,   1, 382,   0,   0,   1,   0,   1],
#        [  0,   2,   1,  18,  28,  98,   4,   0,   2,   2],
#        [  0,   0,   0,   1,   0,   9, 263,   1,   5,   1],
#        [  0,   0,   1,   0,   0,   0,   0, 131,   0,   1],
#        [  0,   0,   0,   0,   0,   0,   2,   0, 261,   0],
#        [  0,   0,   0,   3,   4,   1,   0,  11,   0, 101]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[ 87.31343284,   0.        ,   0.        ,   1.49253731,
#           0.        ,   1.49253731,   1.49253731,   0.74626866,
#           1.49253731,   5.97014925],
#        [  0.        , 100.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ],
#        [  2.43902439,   0.        ,  68.29268293,   0.        ,
#           8.94308943,  16.2601626 ,   0.81300813,   2.43902439,
#           0.81300813,   0.        ],
#        [  0.89285714,   0.        ,   0.        ,  97.91666667,
#           0.29761905,   0.        ,   0.        ,   0.        ,
#           0.5952381 ,   0.29761905],
#        [  0.        ,   0.        ,   0.        ,   0.25974026,
#          99.22077922,   0.        ,   0.        ,   0.25974026,
#           0.        ,   0.25974026],
#        [  0.        ,   1.29032258,   0.64516129,  11.61290323,
#          18.06451613,  63.22580645,   2.58064516,   0.        ,
#           1.29032258,   1.29032258],
#        [  0.        ,   0.        ,   0.        ,   0.35714286,
#           0.        ,   3.21428571,  93.92857143,   0.35714286,
#           1.78571429,   0.35714286],
#        [  0.        ,   0.        ,   0.7518797 ,   0.        ,
#           0.        ,   0.        ,   0.        ,  98.4962406 ,
#           0.        ,   0.7518797 ],
#        [  0.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   0.76045627,   0.        ,
#          99.23954373,   0.        ],
#        [  0.        ,   0.        ,   0.        ,   2.5       ,
#           3.33333333,   0.83333333,   0.        ,   9.16666667,
#           0.        ,  84.16666667]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
