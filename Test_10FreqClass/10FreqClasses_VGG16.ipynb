# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.VGG16(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-4].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 25088)             14714688
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 40,416,074
# Trainable params: 25,701,386
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 16/16 [==============================] - 36s 829ms/step - loss: 7.9607 - accuracy: 0.3438 - val_loss: 0.8472 - val_accuracy: 0.7725
# Epoch 2/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.8084 - accuracy: 0.7568 - val_loss: 0.4540 - val_accuracy: 0.8784
# Epoch 3/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.2657 - accuracy: 0.9170 - val_loss: 0.3151 - val_accuracy: 0.8941
# Epoch 4/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.1487 - accuracy: 0.9551 - val_loss: 0.2959 - val_accuracy: 0.8902
# Epoch 5/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0795 - accuracy: 0.9834 - val_loss: 0.2272 - val_accuracy: 0.9333
# Epoch 6/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0516 - accuracy: 0.9941 - val_loss: 0.2098 - val_accuracy: 0.9294
# Epoch 7/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0415 - accuracy: 0.9932 - val_loss: 0.2098 - val_accuracy: 0.9255
# Epoch 8/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0329 - accuracy: 0.9941 - val_loss: 0.2031 - val_accuracy: 0.9294
# Epoch 9/2000
# 16/16 [==============================] - 3s 176ms/step - loss: 0.0237 - accuracy: 0.9980 - val_loss: 0.2047 - val_accuracy: 0.9333
# Epoch 10/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0208 - accuracy: 0.9971 - val_loss: 0.2153 - val_accuracy: 0.9333
# Epoch 11/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 12/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.2187 - val_accuracy: 0.9255
# Epoch 13/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0129 - accuracy: 0.9990 - val_loss: 0.2106 - val_accuracy: 0.9333
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 15/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9333
# Epoch 16/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 17/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 18/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9333
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9333
# Epoch 20/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 21/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 22/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 23/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 24/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 25/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0102 - accuracy: 0.9990 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 26/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 27/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 28/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 29/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 30/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 31/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 32/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 33/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 34/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 35/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 36/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 37/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 38/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 39/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 40/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 41/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 42/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 43/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 44/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 45/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 46/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 47/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 48/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 49/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 50/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0105 - accuracy: 0.9990 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 51/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 52/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 53/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 54/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 55/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 56/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 57/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 58/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 59/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 60/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 61/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 62/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0099 - accuracy: 0.9990 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 63/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 64/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 65/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0102 - accuracy: 0.9990 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 66/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 67/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 68/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 69/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 70/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 71/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 72/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333
# Epoch 73/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 74/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0100 - accuracy: 0.9990 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 75/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 76/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 77/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 78/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 79/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 80/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 81/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 82/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 83/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 84/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 85/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 86/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 87/2000
# 16/16 [==============================] - 3s 186ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 88/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 89/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 90/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 91/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 92/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333
# Epoch 93/2000
# 16/16 [==============================] - -0s -25156us/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 94/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 95/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 96/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 97/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 98/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 99/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 100/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 101/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 102/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 103/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 104/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 105/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 106/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 107/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 108/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 109/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 110/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 111/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333
# Epoch 112/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 113/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0095 - accuracy: 0.9990 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 114/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 115/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 116/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 117/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 118/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 119/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 120/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 121/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9333
# Epoch 122/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 123/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 124/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 125/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 126/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 127/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 128/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 129/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 130/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 131/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9333
# Epoch 132/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9333
# Epoch 133/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9333
# Epoch 134/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9333
# Epoch 135/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 136/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 137/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0080 - accuracy: 0.9990 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 138/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 139/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 140/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 141/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333
# Epoch 142/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 143/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 144/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 145/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 146/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 147/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 148/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 149/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 150/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 151/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 152/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 153/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 154/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 155/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 156/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 157/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 158/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333
# Epoch 159/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 160/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 161/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 162/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 163/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 164/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 165/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 166/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 167/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 168/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 169/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 170/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 171/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 172/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 173/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 174/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 175/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 176/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 177/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 178/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 179/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 180/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 181/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 182/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 183/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9333
# Epoch 184/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 185/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9333
# Epoch 186/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 187/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 188/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 189/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 190/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 191/2000
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 192/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 193/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 194/2000
# 16/16 [==============================] - 3s 184ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9333
# Epoch 195/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 196/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9333
# Epoch 197/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 198/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 199/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 200/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_VGG16\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 202/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9333
# Epoch 203/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9333
# Epoch 204/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9333
# Epoch 205/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9333
# Epoch 206/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9333
# Epoch 207/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9333
# Epoch 208/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9333
# Epoch 209/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9333
# Epoch 210/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 211/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 212/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 213/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 214/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 215/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 216/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 217/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 218/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 219/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 220/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 221/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 222/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 223/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 224/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 225/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 226/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9333
# Epoch 227/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 228/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9333
# Epoch 229/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9333
# Epoch 230/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9333
# Epoch 231/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9333
# Epoch 232/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9333
# Epoch 233/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9333
# Epoch 234/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9333
# Epoch 235/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9333
# Epoch 236/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9333
# Epoch 237/2000
# 16/16 [==============================] - 3s 183ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 238/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2096 - val_accuracy: 0.9333
# Epoch 239/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 240/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 241/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9333
# Epoch 242/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 243/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9333
# Epoch 244/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9333
# Epoch 245/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9333
# Epoch 246/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9333
# Epoch 247/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9333
# Epoch 248/2000
# 16/16 [==============================] - 3s 183ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9333
# Epoch 249/2000
# 16/16 [==============================] - 3s 183ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9333
# Epoch 250/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9333
# Epoch 251/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9333
# Epoch 252/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 253/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9333
# Epoch 254/2000
# 16/16 [==============================] - 3s 183ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 255/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 256/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 257/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9333
# Epoch 258/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 259/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9333
# Epoch 260/2000
# 16/16 [==============================] - 3s 183ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9333
# Epoch 261/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9333
# Epoch 262/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9333
# Epoch 263/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9333
# Epoch 264/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 265/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 266/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 267/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 268/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 269/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 270/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 271/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 272/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 273/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9333
# Epoch 274/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9333
# Epoch 275/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9333
# Epoch 276/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 277/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9333
# Epoch 278/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9333
# Epoch 279/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9333
# Epoch 280/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 281/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 282/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9333
# Epoch 283/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9333
# Epoch 284/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9333
# Epoch 285/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2127 - val_accuracy: 0.9333
# Epoch 286/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9333
# Epoch 287/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9333
# Epoch 288/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 289/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 290/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 291/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9333
# Epoch 292/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 293/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9333
# Epoch 294/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9333
# Epoch 295/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9333
# Epoch 296/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9333
# Epoch 297/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 298/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 299/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9333
# Epoch 300/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9333
# Epoch 301/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9333
# Epoch 302/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9333
# Epoch 303/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9333
# Epoch 304/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9333
# Epoch 305/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9333
# Epoch 306/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2131 - val_accuracy: 0.9333
# Epoch 307/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9333
# Epoch 308/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9333
# Epoch 309/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9333
# Epoch 310/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9333
# Epoch 311/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9333
# Epoch 312/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9333
# Epoch 313/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9333
# Epoch 314/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9333
# Epoch 315/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 316/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2120 - val_accuracy: 0.9333
# Epoch 317/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9333
# Epoch 318/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9333
# Epoch 319/2000
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9333
# Epoch 320/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9333
# Epoch 321/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9333
# Epoch 322/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9333
# Epoch 323/2000
# 16/16 [==============================] - 3s 180ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9333
# Epoch 324/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2141 - val_accuracy: 0.9333
# Epoch 325/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9333
# Epoch 326/2000
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9333
# ...
# 16/16 [==============================] - 3s 182ms/step - loss: 8.9647e-07 - accuracy: 1.0000 - val_loss: 0.3072 - val_accuracy: 0.9333
# Epoch 1897/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 5.9557e-07 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9333
# Epoch 1898/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.7998e-07 - accuracy: 1.0000 - val_loss: 0.3057 - val_accuracy: 0.9333
# Epoch 1899/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.5692e-07 - accuracy: 1.0000 - val_loss: 0.3049 - val_accuracy: 0.9333
# Epoch 1900/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.3724e-07 - accuracy: 1.0000 - val_loss: 0.3044 - val_accuracy: 0.9333
# Epoch 1901/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.6181e-07 - accuracy: 1.0000 - val_loss: 0.3047 - val_accuracy: 0.9333
# Epoch 1902/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.8207e-07 - accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.9333
# Epoch 1903/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 1.4875e-06 - accuracy: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9373
# Epoch 1904/2000
# 16/16 [==============================] - 3s 183ms/step - loss: 1.0885e-06 - accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.9373
# Epoch 1905/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 8.2838e-07 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9373
# Epoch 1906/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.5797e-07 - accuracy: 1.0000 - val_loss: 0.3046 - val_accuracy: 0.9333
# Epoch 1907/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.3269e-07 - accuracy: 1.0000 - val_loss: 0.3042 - val_accuracy: 0.9333
# Epoch 1908/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.4831e-07 - accuracy: 1.0000 - val_loss: 0.3057 - val_accuracy: 0.9333
# Epoch 1909/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.3574e-07 - accuracy: 1.0000 - val_loss: 0.3071 - val_accuracy: 0.9333
# Epoch 1910/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.9324e-07 - accuracy: 1.0000 - val_loss: 0.3085 - val_accuracy: 0.9333
# Epoch 1911/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 1.1207e-06 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9333
# Epoch 1912/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 5.4400e-07 - accuracy: 1.0000 - val_loss: 0.3077 - val_accuracy: 0.9333
# Epoch 1913/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.2305e-07 - accuracy: 1.0000 - val_loss: 0.3078 - val_accuracy: 0.9333
# Epoch 1914/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.3421e-07 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 0.9333
# Epoch 1915/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.3935e-07 - accuracy: 1.0000 - val_loss: 0.3082 - val_accuracy: 0.9333
# Epoch 1916/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.0943e-07 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9333
# Epoch 1917/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.8570e-07 - accuracy: 1.0000 - val_loss: 0.3093 - val_accuracy: 0.9333
# Epoch 1918/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.5285e-07 - accuracy: 1.0000 - val_loss: 0.3085 - val_accuracy: 0.9333
# Epoch 1919/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.0557e-07 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9333
# Epoch 1920/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 5.0442e-07 - accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.9333
# Epoch 1921/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 8.2479e-07 - accuracy: 1.0000 - val_loss: 0.3092 - val_accuracy: 0.9333
# Epoch 1922/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.7183e-07 - accuracy: 1.0000 - val_loss: 0.3082 - val_accuracy: 0.9333
# Epoch 1923/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.1466e-07 - accuracy: 1.0000 - val_loss: 0.3082 - val_accuracy: 0.9333
# Epoch 1924/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.2141e-07 - accuracy: 1.0000 - val_loss: 0.3089 - val_accuracy: 0.9333
# Epoch 1925/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 4.1013e-07 - accuracy: 1.0000 - val_loss: 0.3091 - val_accuracy: 0.9333
# Epoch 1926/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.7625e-07 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9333
# Epoch 1927/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.7555e-07 - accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.9333
# Epoch 1928/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.6561e-07 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 0.9333
# Epoch 1929/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.9499e-07 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9373
# Epoch 1930/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.5389e-07 - accuracy: 1.0000 - val_loss: 0.3151 - val_accuracy: 0.9333
# Epoch 1931/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.6848e-07 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9373
# Epoch 1932/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.2676e-07 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9373
# Epoch 1933/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.0198e-07 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.9373
# Epoch 1934/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.7567e-07 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9333
# Epoch 1935/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.9231e-07 - accuracy: 1.0000 - val_loss: 0.3156 - val_accuracy: 0.9333
# Epoch 1936/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.9441e-07 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9333
# Epoch 1937/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.6600e-07 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.9333
# Epoch 1938/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.8032e-07 - accuracy: 1.0000 - val_loss: 0.3143 - val_accuracy: 0.9373
# Epoch 1939/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 4.3679e-07 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9373
# Epoch 1940/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.9418e-07 - accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9373
# Epoch 1941/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.0220e-07 - accuracy: 1.0000 - val_loss: 0.3142 - val_accuracy: 0.9373
# Epoch 1942/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.7311e-07 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9333
# Epoch 1943/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.9604e-07 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9333
# Epoch 1944/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.2466e-07 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.9333
# Epoch 1945/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 8.4503e-07 - accuracy: 1.0000 - val_loss: 0.3121 - val_accuracy: 0.9333
# Epoch 1946/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.0419e-07 - accuracy: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9333
# Epoch 1947/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.1279e-07 - accuracy: 1.0000 - val_loss: 0.3148 - val_accuracy: 0.9333
# Epoch 1948/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.1758e-07 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9333
# Epoch 1949/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.7691e-06 - accuracy: 1.0000 - val_loss: 0.3308 - val_accuracy: 0.9333
# Epoch 1950/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 8.0337e-07 - accuracy: 1.0000 - val_loss: 0.3356 - val_accuracy: 0.9333
# Epoch 1951/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.5342e-07 - accuracy: 1.0000 - val_loss: 0.3346 - val_accuracy: 0.9333
# Epoch 1952/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.7380e-07 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9333
# Epoch 1953/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.2614e-07 - accuracy: 1.0000 - val_loss: 0.3276 - val_accuracy: 0.9333
# Epoch 1954/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.7939e-07 - accuracy: 1.0000 - val_loss: 0.3254 - val_accuracy: 0.9333
# Epoch 1955/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.1001e-07 - accuracy: 1.0000 - val_loss: 0.3250 - val_accuracy: 0.9333
# Epoch 1956/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 1.5724e-06 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9333
# Epoch 1957/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.5343e-07 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9333
# Epoch 1958/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.4168e-07 - accuracy: 1.0000 - val_loss: 0.3193 - val_accuracy: 0.9333
# Epoch 1959/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.7288e-07 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 0.9333
# Epoch 1960/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.6659e-07 - accuracy: 1.0000 - val_loss: 0.3183 - val_accuracy: 0.9333
# Epoch 1961/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 4.4924e-07 - accuracy: 1.0000 - val_loss: 0.3191 - val_accuracy: 0.9333
# Epoch 1962/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.8882e-07 - accuracy: 1.0000 - val_loss: 0.3192 - val_accuracy: 0.9333
# Epoch 1963/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.0943e-07 - accuracy: 1.0000 - val_loss: 0.3178 - val_accuracy: 0.9333
# Epoch 1964/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 6.0081e-07 - accuracy: 1.0000 - val_loss: 0.3169 - val_accuracy: 0.9333
# Epoch 1965/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.6448e-07 - accuracy: 1.0000 - val_loss: 0.3193 - val_accuracy: 0.9333
# Epoch 1966/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 5.6950e-07 - accuracy: 1.0000 - val_loss: 0.3206 - val_accuracy: 0.9333
# Epoch 1967/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.5373e-07 - accuracy: 1.0000 - val_loss: 0.3234 - val_accuracy: 0.9373
# Epoch 1968/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.0509e-07 - accuracy: 1.0000 - val_loss: 0.3225 - val_accuracy: 0.9373
# Epoch 1969/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 8.2780e-07 - accuracy: 1.0000 - val_loss: 0.3182 - val_accuracy: 0.9373
# Epoch 1970/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.8463e-07 - accuracy: 1.0000 - val_loss: 0.3175 - val_accuracy: 0.9373
# Epoch 1971/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.9593e-07 - accuracy: 1.0000 - val_loss: 0.3174 - val_accuracy: 0.9333
# Epoch 1972/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.4434e-07 - accuracy: 1.0000 - val_loss: 0.3166 - val_accuracy: 0.9333
# Epoch 1973/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.9336e-07 - accuracy: 1.0000 - val_loss: 0.3153 - val_accuracy: 0.9333
# Epoch 1974/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.2177e-07 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.9333
# Epoch 1975/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.9849e-07 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.9333
# Epoch 1976/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.0209e-07 - accuracy: 1.0000 - val_loss: 0.3175 - val_accuracy: 0.9333
# Epoch 1977/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.3713e-07 - accuracy: 1.0000 - val_loss: 0.3183 - val_accuracy: 0.9333
# Epoch 1978/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 1.4727e-06 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9333
# Epoch 1979/2000
# 16/16 [==============================] - 3s 181ms/step - loss: 4.0559e-07 - accuracy: 1.0000 - val_loss: 0.3199 - val_accuracy: 0.9333
# Epoch 1980/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.3597e-07 - accuracy: 1.0000 - val_loss: 0.3205 - val_accuracy: 0.9333
# Epoch 1981/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.5085e-07 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9333
# Epoch 1982/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.7449e-07 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9333
# Epoch 1983/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.4470e-07 - accuracy: 1.0000 - val_loss: 0.3149 - val_accuracy: 0.9333
# Epoch 1984/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.6053e-07 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.9333
# Epoch 1985/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.0838e-07 - accuracy: 1.0000 - val_loss: 0.3177 - val_accuracy: 0.9333
# Epoch 1986/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.7718e-07 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9333
# Epoch 1987/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.4610e-07 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9333
# Epoch 1988/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 7.2630e-07 - accuracy: 1.0000 - val_loss: 0.3204 - val_accuracy: 0.9333
# Epoch 1989/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.8778e-07 - accuracy: 1.0000 - val_loss: 0.3217 - val_accuracy: 0.9333
# Epoch 1990/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.4563e-07 - accuracy: 1.0000 - val_loss: 0.3211 - val_accuracy: 0.9333
# Epoch 1991/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 2.7264e-07 - accuracy: 1.0000 - val_loss: 0.3206 - val_accuracy: 0.9333
# Epoch 1992/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.5425e-07 - accuracy: 1.0000 - val_loss: 0.3204 - val_accuracy: 0.9333
# Epoch 1993/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 5.9220e-07 - accuracy: 1.0000 - val_loss: 0.3205 - val_accuracy: 0.9333
# Epoch 1994/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 2.7858e-07 - accuracy: 1.0000 - val_loss: 0.3202 - val_accuracy: 0.9333
# Epoch 1995/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 9.8898e-07 - accuracy: 1.0000 - val_loss: 0.3197 - val_accuracy: 0.9333
# Epoch 1996/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 6.7170e-07 - accuracy: 1.0000 - val_loss: 0.3182 - val_accuracy: 0.9333
# Epoch 1997/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.7660e-07 - accuracy: 1.0000 - val_loss: 0.3190 - val_accuracy: 0.9333
# Epoch 1998/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.8696e-07 - accuracy: 1.0000 - val_loss: 0.3200 - val_accuracy: 0.9333
# Epoch 1999/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 4.3341e-07 - accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.9333
# Epoch 2000/2000
# 16/16 [==============================] - 3s 182ms/step - loss: 3.9953e-07 - accuracy: 1.0000 - val_loss: 0.3221 - val_accuracy: 0.9333
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_VGG16\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 8/8 [==============================] - 12s 1s/step - loss: 1.4598 - accuracy: 0.7890
# test_indoor_ds_results:test loss, test acc: [1.4597523212432861, 0.7889546155929565]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 16/16 [==============================] - 17s 774ms/step - loss: 1.7216 - accuracy: 0.7441
# test_outdoor_ds_results:test loss, test acc: [1.721644401550293, 0.7441176176071167]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 9/9 [==============================] - 10s 1s/step - loss: 1.8352 - accuracy: 0.7627
# test_belt_ds_results:test loss, test acc: [1.8352329730987549, 0.7627416253089905]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 8/8 [==============================] - 1s 139ms/step - loss: 0.8434 - accuracy: 0.7890
# 16/16 [==============================] - 2s 140ms/step - loss: 0.8752 - accuracy: 0.7578
# 9/9 [==============================] - 1s 138ms/step - loss: 1.0666 - accuracy: 0.7522
# Epoch200
#  test_indoor_acc=0.7889546155929565
#  test_outdoor_acc=0.7578431367874146
#  test_belt_acc=0.7521968483924866
# 8/8 [==============================] - 1s 139ms/step - loss: 0.8952 - accuracy: 0.7830
# 16/16 [==============================] - 2s 140ms/step - loss: 0.9585 - accuracy: 0.7578
# 9/9 [==============================] - 1s 139ms/step - loss: 1.1451 - accuracy: 0.7557
# Epoch400
#  test_indoor_acc=0.7830374836921692
#  test_outdoor_acc=0.7578431367874146
#  test_belt_acc=0.7557117938995361
# 8/8 [==============================] - 1s 139ms/step - loss: 0.9951 - accuracy: 0.7890
# 16/16 [==============================] - 2s 140ms/step - loss: 1.0865 - accuracy: 0.7569
# 9/9 [==============================] - 1s 139ms/step - loss: 1.2552 - accuracy: 0.7557
# Epoch600
#  test_indoor_acc=0.7889546155929565
#  test_outdoor_acc=0.7568627595901489
#  test_belt_acc=0.7557117938995361
# 8/8 [==============================] - 1s 138ms/step - loss: 1.0536 - accuracy: 0.7909
# 16/16 [==============================] - 2s 140ms/step - loss: 1.1902 - accuracy: 0.7549
# 9/9 [==============================] - 1s 138ms/step - loss: 1.3413 - accuracy: 0.7592
# Epoch800
#  test_indoor_acc=0.790926992893219
#  test_outdoor_acc=0.7549019455909729
#  test_belt_acc=0.7592267394065857
# 8/8 [==============================] - 1s 140ms/step - loss: 1.1420 - accuracy: 0.7929
# 16/16 [==============================] - 2s 140ms/step - loss: 1.3296 - accuracy: 0.7520
# 9/9 [==============================] - 1s 140ms/step - loss: 1.4338 - accuracy: 0.7680
# Epoch1000
#  test_indoor_acc=0.7928994297981262
#  test_outdoor_acc=0.751960813999176
#  test_belt_acc=0.7680140733718872
# 8/8 [==============================] - 1s 140ms/step - loss: 1.2393 - accuracy: 0.7870
# 16/16 [==============================] - 2s 139ms/step - loss: 1.4408 - accuracy: 0.7461
# 9/9 [==============================] - 1s 138ms/step - loss: 1.5690 - accuracy: 0.7557
# Epoch1200
#  test_indoor_acc=0.7869822382926941
#  test_outdoor_acc=0.7460784316062927
#  test_belt_acc=0.7557117938995361
# 8/8 [==============================] - 1s 139ms/step - loss: 1.3245 - accuracy: 0.7850
# 16/16 [==============================] - 2s 139ms/step - loss: 1.5240 - accuracy: 0.7480
# 9/9 [==============================] - 1s 139ms/step - loss: 1.6681 - accuracy: 0.7557
# Epoch1400
#  test_indoor_acc=0.7850098609924316
#  test_outdoor_acc=0.748039186000824
#  test_belt_acc=0.7557117938995361
# 8/8 [==============================] - 1s 139ms/step - loss: 1.3103 - accuracy: 0.7968
# 16/16 [==============================] - 2s 139ms/step - loss: 1.5955 - accuracy: 0.7471
# 9/9 [==============================] - 1s 139ms/step - loss: 1.7143 - accuracy: 0.7645
# Epoch1600
#  test_indoor_acc=0.7968441843986511
#  test_outdoor_acc=0.7470588088035583
#  test_belt_acc=0.7644991278648376
# 8/8 [==============================] - 1s 139ms/step - loss: 1.3498 - accuracy: 0.8008
# 16/16 [==============================] - 2s 139ms/step - loss: 1.6391 - accuracy: 0.7480
# 9/9 [==============================] - 1s 139ms/step - loss: 1.7560 - accuracy: 0.7663
# Epoch1800
#  test_indoor_acc=0.800788938999176
#  test_outdoor_acc=0.748039186000824
#  test_belt_acc=0.76625657081604
# 8/8 [==============================] - 1s 139ms/step - loss: 1.4598 - accuracy: 0.7890
# 16/16 [==============================] - 2s 139ms/step - loss: 1.7216 - accuracy: 0.7441
# 9/9 [==============================] - 1s 138ms/step - loss: 1.8352 - accuracy: 0.7627
# Epoch2000
#  test_indoor_acc=0.7889546155929565
#  test_outdoor_acc=0.7441176176071167
#  test_belt_acc=0.7627416253089905

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7716948986053467
# max index -> 8
# The [Epoch] of max acc -> 1800

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.7889546155929565,
#  0.7830374836921692,
#  0.7889546155929565,
#  0.790926992893219,
#  0.7928994297981262,
#  0.7869822382926941,
#  0.7850098609924316,
#  0.7968441843986511,
#  0.800788938999176,
#  0.7889546155929565]

# %%
test_outdoor_acc
# Out:
# [0.7578431367874146,
#  0.7578431367874146,
#  0.7568627595901489,
#  0.7549019455909729,
#  0.751960813999176,
#  0.7460784316062927,
#  0.748039186000824,
#  0.7470588088035583,
#  0.748039186000824,
#  0.7441176176071167]

# %%
test_belt_acc
# Out:
# [0.7521968483924866,
#  0.7557117938995361,
#  0.7557117938995361,
#  0.7592267394065857,
#  0.7680140733718872,
#  0.7557117938995361,
#  0.7557117938995361,
#  0.7644991278648376,
#  0.76625657081604,
#  0.7627416253089905]

# %%
test_indoor_loss
# Out:
# [0.8433997631072998,
#  0.8952039480209351,
#  0.9951000809669495,
#  1.053614854812622,
#  1.1419622898101807,
#  1.2393085956573486,
#  1.3244845867156982,
#  1.310307502746582,
#  1.3497693538665771,
#  1.4597523212432861]

# %%
test_outdoor_loss
# Out:
# [0.87521892786026,
#  0.9585299491882324,
#  1.0865181684494019,
#  1.1901781558990479,
#  1.3295557498931885,
#  1.4408124685287476,
#  1.524034857749939,
#  1.595471739768982,
#  1.6390553712844849,
#  1.721644401550293]

# %%
test_belt_loss
# Out:
# [1.066636085510254,
#  1.1450579166412354,
#  1.2551658153533936,
#  1.3412652015686035,
#  1.43378484249115,
#  1.5690056085586548,
#  1.668076515197754,
#  1.7143350839614868,
#  1.755997657775879,
#  1.8352329730987549]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507
# train_outdoor num x,y : 1020,1020
# train_belt num x,y : 569,569
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1605
# FP=491
# acc=0.7657442748091603
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 41.04477611940299%
# CottonBall acc = 68.26347305389223%
# ExtensionTube acc = 32.52032520325203%
# Glove acc = 96.13095238095238%
# Mask acc = 91.94805194805194%
# NGTube acc = 65.80645161290323%
# Needle acc = 93.92857142857143%
# OxygenMask acc = 93.23308270676691%
# Syringe acc = 82.88973384030417%
# UrineBag acc = 10.0%
#
#
#
# all_avg_eachclass = 67.57654182940973%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 55,   1,   7,   3,  15,  26,  12,   8,   7,   0],
#        [  0, 114,   0,  42,   7,   3,   1,   0,   0,   0],
#        [  0,   0,  40,   0,   7,  72,   4,   0,   0,   0],
#        [  0,   0,   0, 323,  13,   0,   0,   0,   0,   0],
#        [  0,   0,   0,  10, 354,   2,   1,   7,  11,   0],
#        [  0,   0,   0,   1,  35, 102,  11,   6,   0,   0],
#        [  0,   0,   0,   8,   5,   3, 263,   0,   1,   0],
#        [  0,   0,   0,   4,   2,   3,   0, 124,   0,   0],
#        [  0,   1,   0,   3,   9,   3,  27,   1, 218,   1],
#        [  0,   0,   0,  18,  48,   0,   2,  33,   7,  12]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[41.04477612,  0.74626866,  5.2238806 ,  2.23880597, 11.19402985,
#         19.40298507,  8.95522388,  5.97014925,  5.2238806 ,  0.        ],
#        [ 0.        , 68.26347305,  0.        , 25.1497006 ,  4.19161677,
#          1.79640719,  0.5988024 ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        , 32.5203252 ,  0.        ,  5.69105691,
#         58.53658537,  3.25203252,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , 96.13095238,  3.86904762,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  2.5974026 , 91.94805195,
#          0.51948052,  0.25974026,  1.81818182,  2.85714286,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.64516129, 22.58064516,
#         65.80645161,  7.09677419,  3.87096774,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  2.85714286,  1.78571429,
#          1.07142857, 93.92857143,  0.        ,  0.35714286,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  3.0075188 ,  1.5037594 ,
#          2.2556391 ,  0.        , 93.23308271,  0.        ,  0.        ],
#        [ 0.        ,  0.38022814,  0.        ,  1.14068441,  3.42205323,
#          1.14068441, 10.2661597 ,  0.38022814, 82.88973384,  0.38022814],
#        [ 0.        ,  0.        ,  0.        , 15.        , 40.        ,
#          0.        ,  1.66666667, 27.5       ,  5.83333333, 10.        ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
