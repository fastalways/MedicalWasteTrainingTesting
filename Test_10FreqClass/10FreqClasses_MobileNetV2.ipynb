# %% [markdown]
# # 10FreqClasses

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 1024 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']
# number of class = 10

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1279 files belonging to 10 classes.
# Using 255 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 507 files belonging to 10 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1020 files belonging to 10 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 569 files belonging to 10 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input,MobileNetV2

mobilenetv2_model = keras.applications.MobileNetV2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

mobilenetv2_model_nooutput = mobilenetv2_model.layers[-2].output
custom_mobilenetv2_model = Model(inputs = mobilenetv2_model.input, outputs = mobilenetv2_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_mobilenetv2_model.trainable = False
for layer in custom_mobilenetv2_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_mobilenetv2_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           out_relu[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_mobilenetv2_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 3,579,978
# Trainable params: 1,321,994
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 16/16 [==============================] - 17s 269ms/step - loss: 0.6754 - accuracy: 0.8086 - val_loss: 0.1006 - val_accuracy: 0.9725
# Epoch 2/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0429 - accuracy: 0.9863 - val_loss: 0.0785 - val_accuracy: 0.9686
# Epoch 3/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0195 - accuracy: 0.9961 - val_loss: 0.0615 - val_accuracy: 0.9843
# Epoch 4/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.0487 - val_accuracy: 0.9843
# Epoch 5/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9922
# Epoch 6/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9765
# Epoch 7/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9882
# Epoch 8/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9882
# Epoch 9/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9922
# Epoch 10/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2467e-04 - accuracy: 1.0000 - val_loss: 0.0325 - val_accuracy: 0.9882
# Epoch 11/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 7.8053e-04 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9922
# Epoch 12/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.5337e-04 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9922
# Epoch 13/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.2277e-04 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9882
# Epoch 14/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 5.6875e-04 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9882
# Epoch 15/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.5556e-04 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9882
# Epoch 16/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.2042e-04 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9882
# Epoch 17/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 4.9141e-04 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9882
# Epoch 18/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.9750e-04 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9882
# Epoch 19/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 4.3963e-04 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 0.9922ss: 4.5030e-04 - ac
# Epoch 20/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.6490e-04 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9922
# Epoch 21/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.7041e-04 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9922
# Epoch 22/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.0601e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9922
# Epoch 23/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.6014e-04 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9882
# Epoch 24/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.0552e-04 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9882
# Epoch 25/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.6599e-04 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9882
# Epoch 26/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 2.9793e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9882
# Epoch 27/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 3.0092e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9922
# Epoch 28/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.7488e-04 - accuracy: 1.0000 - val_loss: 0.0254 - val_accuracy: 0.9882
# Epoch 29/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.2313e-04 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9922
# Epoch 30/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.4091e-04 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9922
# Epoch 31/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.2600e-04 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9882
# Epoch 32/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.0493e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 33/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.0398e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9922
# Epoch 34/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 2.2228e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 35/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.9705e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9922
# Epoch 36/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.8958e-04 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9882
# Epoch 37/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.7390e-04 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9882
# Epoch 38/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.6824e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9882
# Epoch 39/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.6508e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 40/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.5883e-04 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9922
# Epoch 41/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1463e-04 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9882
# Epoch 42/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2082e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9882
# Epoch 43/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2307e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9922
# Epoch 44/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2244e-04 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9922
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 45/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.4119e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 46/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 1.1731e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 47/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1255e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 48/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2290e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 49/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1777e-04 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9922
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 50/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1157e-04 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9922
# Epoch 51/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2862e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 52/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1131e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 53/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1092e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 54/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0165e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 55/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.4745e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 56/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1971e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 57/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1255e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 58/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2547e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 59/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2333e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 60/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3082e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 61/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2830e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 62/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0635e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 63/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3953e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 64/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2018e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 65/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.4000e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 66/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0892e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 67/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2188e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 68/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1760e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 69/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2741e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 70/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2490e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 71/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1824e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 72/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0173e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 73/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1076e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 74/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0381e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 75/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0494e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 76/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2694e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 77/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3636e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 78/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1845e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 79/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3146e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 80/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3550e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 81/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2799e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 82/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 1.3842e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 83/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1722e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 84/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0725e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 85/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1765e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 86/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 1.1040e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 87/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0584e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 88/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1910e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 89/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2333e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 90/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1972e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 91/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2577e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 92/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1532e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 93/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2487e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 94/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1977e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 95/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1650e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 96/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1813e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 97/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1803e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 98/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.5535e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 99/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1336e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 100/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2723e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 101/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1949e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 102/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3408e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 103/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0080e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 104/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1759e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 105/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1515e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 106/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1240e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 107/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1781e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 108/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3728e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 109/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2646e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 110/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1915e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 111/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2249e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 112/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1312e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 113/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2424e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 114/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0515e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 115/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0877e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 116/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1610e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 117/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1753e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 118/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2179e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 119/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1363e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 120/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2623e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 121/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1135e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 122/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1375e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 123/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0609e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 124/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0835e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 125/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1469e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 126/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2698e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 127/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2145e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 128/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1653e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 129/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1419e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 130/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1574e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 131/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1866e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 132/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0856e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 133/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0211e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 134/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1749e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 135/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1357e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 136/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2527e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 137/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1695e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 138/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1258e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 139/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0461e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 140/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 1.2431e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 141/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2793e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 142/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.3015e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 143/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1174e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 144/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0688e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 145/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0480e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 146/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1656e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 147/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0266e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 148/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0467e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 149/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1920e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 150/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0044e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 151/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8128e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 152/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1322e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 153/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2090e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 154/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2566e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 155/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2441e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 156/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0245e-04 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 157/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1504e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 158/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8708e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 159/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1276e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 160/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.7880e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 161/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0390e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 162/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1656e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 163/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1460e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 164/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1076e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 165/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0214e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 166/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.7997e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 167/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2099e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 168/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0014e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 169/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1755e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 170/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0312e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 171/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.5760e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 172/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2512e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 173/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8519e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 174/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1323e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 175/2000
# 16/16 [==============================] - 1s 76ms/step - loss: 1.0028e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 176/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0250e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 177/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1025e-04 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9922
# Epoch 178/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0953e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 179/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0075e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 180/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1221e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 181/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0579e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 182/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.7772e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 183/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0803e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 184/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.9003e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 185/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0139e-04 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 186/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1843e-04 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9922
# Epoch 187/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.2704e-04 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9922
# Epoch 188/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0755e-04 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9922
# Epoch 189/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1267e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 190/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0385e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 191/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1877e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 192/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0317e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 193/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.9157e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 194/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1298e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 195/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0169e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 196/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.4809e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 197/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0347e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 198/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8823e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 199/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1615e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 200/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.1504e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 1.1354e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 202/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1543e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 203/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0300e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 204/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1267e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 205/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 1.1820e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 206/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0611e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 207/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0717e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 208/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8156e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 209/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0827e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 210/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0327e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 211/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0507e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 212/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0449e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 213/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.7842e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 214/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0257e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 215/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2839e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 216/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0184e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 217/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9926e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 218/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0122e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 219/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8417e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 220/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.9656e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 221/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0477e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 222/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8670e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 223/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0121e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 224/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.6755e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 225/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0419e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 226/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.3271e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 227/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1181e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 228/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0153e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 229/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.4243e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 230/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0411e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 231/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1788e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 232/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.5585e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 233/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0785e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 234/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0026e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 235/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0972e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 236/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2475e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 237/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1488e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 238/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1295e-04 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 239/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.7864e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 240/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0329e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 241/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1463e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 242/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.5489e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 243/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0022e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 244/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1304e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 245/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.8856e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 246/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2216e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 247/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1640e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 248/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0405e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 249/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.3244e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 250/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0007e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 251/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.7917e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 252/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.4519e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 253/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0642e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 254/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.8791e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 255/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8303e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 256/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.9599e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 257/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0792e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 258/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9560e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 259/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1327e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 260/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.4091e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 261/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 8.2473e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 262/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1504e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 263/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.5899e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 264/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9065e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 265/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0118e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 266/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.6507e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 267/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0574e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 268/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.1378e-04 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 269/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.3780e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 270/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.6873e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 271/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.3300e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9922
# Epoch 272/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2414e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 273/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.1624e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 274/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.1737e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 275/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0037e-04 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 276/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.4973e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 277/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 8.7356e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 278/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.5561e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 279/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.5008e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 280/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.8643e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 281/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.6783e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 282/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9602e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 283/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9273e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 284/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.6826e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 285/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 8.5743e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 286/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.6536e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 287/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.2382e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 288/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.5917e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 289/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.1068e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 290/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.4180e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 291/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.9947e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 292/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.5194e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 293/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 7.6412e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 294/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.0311e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 295/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.8799e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 296/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.2537e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 297/2000
# 16/16 [==============================] - 1s 73ms/step - loss: 7.6008e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 298/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.4683e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 299/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.5781e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 300/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.9825e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 301/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.0498e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 302/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.2576e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 303/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.4308e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 304/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.1464e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 305/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.6504e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 306/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.0110e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 307/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.5233e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 308/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.9009e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 309/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.9673e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 310/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.0050e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 311/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2680e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 312/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.8292e-05 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9922
# Epoch 313/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.8077e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9922
# Epoch 314/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.9022e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 315/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.3849e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 316/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.2163e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 317/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.9923e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9922
# Epoch 318/2000
# ...
# Epoch 1898/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.4389e-08 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9922
# Epoch 1899/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.6019e-08 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9922
# Epoch 1900/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9523e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1901/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.0338e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1902/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.0804e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1903/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.0094e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1904/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.2876e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1905/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.0082e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1906/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.4273e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1907/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.2771e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1908/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.5088e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1909/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.0909e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1910/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.2399e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1911/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.6357e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1912/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.7055e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1913/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.8440e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1914/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4028e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1915/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.3691e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1916/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.0885e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1917/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.0303e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1918/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 7.9046e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1919/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.4389e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1920/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0256e-07 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1921/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.7288e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1922/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.5437e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1923/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.5449e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1924/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.1258e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1925/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.6590e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1926/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.9872e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1927/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.9605e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1928/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.7428e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1929/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.3574e-08 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9922
# Epoch 1930/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.4168e-08 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9922
# Epoch 1931/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 6.0536e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1932/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.0070e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1933/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.3598e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1934/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.9500e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1935/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0792e-07 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1936/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.6741e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1937/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.7404e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1938/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4494e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1939/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.7882e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1940/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.1351e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1941/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4494e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1942/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.8359e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1943/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.4948e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1944/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.3470e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1945/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.7544e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1946/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.3225e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1947/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.7172e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1948/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.8918e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1949/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.0536e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1950/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.1584e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1951/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.3586e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1952/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.7393e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1953/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.8231e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1954/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 5.6461e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1955/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.9500e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1956/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.8452e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1957/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.9721e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1958/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.6112e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1959/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.8091e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1960/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.4273e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1961/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.5775e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1962/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.2666e-08 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9922
# Epoch 1963/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.6252e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1964/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 9.3597e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1965/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.6601e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1966/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 4.6683e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1967/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.5786e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1968/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.2748e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1969/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 4.9476e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1970/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4378e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1971/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.1130e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1972/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.3703e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1973/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.2049e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1974/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 8.2305e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1975/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.3330e-08 - accuracy: 1.0000 - val_loss: 0.0201 - val_accuracy: 0.9922
# Epoch 1976/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4494e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1977/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.2061e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 1978/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.2864e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1979/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.5670e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1980/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4960e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1981/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.9162e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1982/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.7998e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1983/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.4727e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1984/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.3109e-08 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9922
# Epoch 1985/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.0291e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1986/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.4599e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1987/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.9500e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1988/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.4622e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1989/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.8569e-08 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 1990/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.1584e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1991/2000
# 16/16 [==============================] - 1s 75ms/step - loss: 5.4250e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1992/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.6368e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1993/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.8685e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1994/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 5.8091e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1995/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 7.1013e-08 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 0.9922
# Epoch 1996/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0687e-07 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1997/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 4.5984e-08 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1998/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 1.0303e-07 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9922
# Epoch 1999/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.1700e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# Epoch 2000/2000
# 16/16 [==============================] - 1s 74ms/step - loss: 6.2282e-08 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9922
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 8/8 [==============================] - 4s 117ms/step - loss: 0.3500 - accuracy: 0.9250
# test_indoor_ds_results:test loss, test acc: [0.3499666452407837, 0.9250493049621582]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 16/16 [==============================] - 9s 275ms/step - loss: 0.9283 - accuracy: 0.8667
# test_outdoor_ds_results:test loss, test acc: [0.9282994866371155, 0.8666666746139526]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 9/9 [==============================] - 2s 109ms/step - loss: 0.9619 - accuracy: 0.8682
# test_belt_ds_results:test loss, test acc: [0.9618924856185913, 0.868189811706543]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/10Freq_MobileNetV2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 8/8 [==============================] - 1s 59ms/step - loss: 0.2635 - accuracy: 0.9172
# 16/16 [==============================] - 1s 58ms/step - loss: 0.6186 - accuracy: 0.8569
# 9/9 [==============================] - 1s 58ms/step - loss: 0.6528 - accuracy: 0.8524
# Epoch200
#  test_indoor_acc=0.9171597361564636
#  test_outdoor_acc=0.8568627238273621
#  test_belt_acc=0.8523725867271423
# 8/8 [==============================] - 1s 58ms/step - loss: 0.2672 - accuracy: 0.9172
# 16/16 [==============================] - 1s 58ms/step - loss: 0.6369 - accuracy: 0.8569
# 9/9 [==============================] - 1s 58ms/step - loss: 0.6813 - accuracy: 0.8506
# Epoch400
#  test_indoor_acc=0.9171597361564636
#  test_outdoor_acc=0.8568627238273621
#  test_belt_acc=0.8506151437759399
# 8/8 [==============================] - 1s 58ms/step - loss: 0.2738 - accuracy: 0.9231
# 16/16 [==============================] - 1s 57ms/step - loss: 0.6848 - accuracy: 0.8559
# 9/9 [==============================] - 1s 58ms/step - loss: 0.7075 - accuracy: 0.8559
# Epoch600
#  test_indoor_acc=0.9230769276618958
#  test_outdoor_acc=0.8558823466300964
#  test_belt_acc=0.8558875322341919
# 8/8 [==============================] - 1s 58ms/step - loss: 0.2857 - accuracy: 0.9231
# 16/16 [==============================] - 1s 58ms/step - loss: 0.7516 - accuracy: 0.8569
# 9/9 [==============================] - 1s 58ms/step - loss: 0.7573 - accuracy: 0.8612
# Epoch800
#  test_indoor_acc=0.9230769276618958
#  test_outdoor_acc=0.8568627238273621
#  test_belt_acc=0.8611599206924438
# 8/8 [==============================] - 1s 59ms/step - loss: 0.3055 - accuracy: 0.9231
# 16/16 [==============================] - 1s 59ms/step - loss: 0.7910 - accuracy: 0.8598
# 9/9 [==============================] - 1s 58ms/step - loss: 0.8256 - accuracy: 0.8629
# Epoch1000
#  test_indoor_acc=0.9230769276618958
#  test_outdoor_acc=0.8598039150238037
#  test_belt_acc=0.862917423248291
# 8/8 [==============================] - 1s 59ms/step - loss: 0.3186 - accuracy: 0.9250
# 16/16 [==============================] - 1s 59ms/step - loss: 0.8420 - accuracy: 0.8637
# 9/9 [==============================] - 1s 59ms/step - loss: 0.8666 - accuracy: 0.8629
# Epoch1200
#  test_indoor_acc=0.9250493049621582
#  test_outdoor_acc=0.863725483417511
#  test_belt_acc=0.862917423248291
# 8/8 [==============================] - 1s 58ms/step - loss: 0.3234 - accuracy: 0.9250
# 16/16 [==============================] - 1s 59ms/step - loss: 0.8688 - accuracy: 0.8667
# 9/9 [==============================] - 1s 59ms/step - loss: 0.8965 - accuracy: 0.8682
# Epoch1400
#  test_indoor_acc=0.9250493049621582
#  test_outdoor_acc=0.8666666746139526
#  test_belt_acc=0.868189811706543
# 8/8 [==============================] - 1s 60ms/step - loss: 0.3341 - accuracy: 0.9250
# 16/16 [==============================] - 1s 60ms/step - loss: 0.9018 - accuracy: 0.8657
# 9/9 [==============================] - 1s 59ms/step - loss: 0.9214 - accuracy: 0.8682
# Epoch1600
#  test_indoor_acc=0.9250493049621582
#  test_outdoor_acc=0.865686297416687
#  test_belt_acc=0.868189811706543
# 8/8 [==============================] - 1s 59ms/step - loss: 0.3439 - accuracy: 0.9270
# 16/16 [==============================] - 1s 59ms/step - loss: 0.9185 - accuracy: 0.8667
# 9/9 [==============================] - 1s 59ms/step - loss: 0.9321 - accuracy: 0.8664
# Epoch1800
#  test_indoor_acc=0.9270216822624207
#  test_outdoor_acc=0.8666666746139526
#  test_belt_acc=0.8664323091506958
# 8/8 [==============================] - 1s 59ms/step - loss: 0.3500 - accuracy: 0.9250
# 16/16 [==============================] - 1s 59ms/step - loss: 0.9283 - accuracy: 0.8667
# 9/9 [==============================] - 1s 59ms/step - loss: 0.9619 - accuracy: 0.8682
# Epoch2000
#  test_indoor_acc=0.9250493049621582
#  test_outdoor_acc=0.8666666746139526
#  test_belt_acc=0.868189811706543

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8867068886756897
# max index -> 8
# The [Epoch] of max acc -> 1800

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9171597361564636,
#  0.9171597361564636,
#  0.9230769276618958,
#  0.9230769276618958,
#  0.9230769276618958,
#  0.9250493049621582,
#  0.9250493049621582,
#  0.9250493049621582,
#  0.9270216822624207,
#  0.9250493049621582]

# %%
test_outdoor_acc
# Out:
# [0.8568627238273621,
#  0.8568627238273621,
#  0.8558823466300964,
#  0.8568627238273621,
#  0.8598039150238037,
#  0.863725483417511,
#  0.8666666746139526,
#  0.865686297416687,
#  0.8666666746139526,
#  0.8666666746139526]

# %%
test_belt_acc
# Out:
# [0.8523725867271423,
#  0.8506151437759399,
#  0.8558875322341919,
#  0.8611599206924438,
#  0.862917423248291,
#  0.862917423248291,
#  0.868189811706543,
#  0.868189811706543,
#  0.8664323091506958,
#  0.868189811706543]

# %%
test_indoor_loss
# Out:
# [0.26345381140708923,
#  0.2671715319156647,
#  0.27378174662590027,
#  0.2857081890106201,
#  0.3055025339126587,
#  0.31864386796951294,
#  0.32337477803230286,
#  0.3341226279735565,
#  0.3438914716243744,
#  0.3499666452407837]

# %%
test_outdoor_loss
# Out:
# [0.6185932755470276,
#  0.6368581652641296,
#  0.684849739074707,
#  0.7516382932662964,
#  0.7910168170928955,
#  0.8420416712760925,
#  0.8688398003578186,
#  0.9018377065658569,
#  0.918547511100769,
#  0.9282994866371155]

# %%
test_belt_loss
# Out:
# [0.6528218388557434,
#  0.6813281774520874,
#  0.7075376510620117,
#  0.7573204040527344,
#  0.8255720138549805,
#  0.8666110038757324,
#  0.8965429663658142,
#  0.9213896989822388,
#  0.9321441650390625,
#  0.9618924856185913]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.mobilenet_v2 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_10FreqClasses/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['2WayFoleyCatheter', 'CottonBall', 'ExtensionTube', 'Glove', 'Mask', 'NGTube', 'Needle', 'OxygenMask', 'Syringe', 'UrineBag']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 507 files belonging to 10 classes.
# Found 1020 files belonging to 10 classes.
# Found 569 files belonging to 10 classes.
# train_indoor num x,y : 507,507
# train_outdoor num x,y : 1020,1020
# train_belt num x,y : 569,569
# all num x,y :2096,2096

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=2096
# TP=1847
# FP=249
# acc=0.8812022900763359
# all check = 2096

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 2WayFoleyCatheter acc = 70.1492537313433%
# CottonBall acc = 98.80239520958084%
# ExtensionTube acc = 55.28455284552846%
# Glove acc = 97.91666666666666%
# Mask acc = 98.7012987012987%
# NGTube acc = 56.774193548387096%
# Needle acc = 95.71428571428572%
# OxygenMask acc = 95.48872180451127%
# Syringe acc = 98.47908745247148%
# UrineBag acc = 57.49999999999999%
#
#
#
# all_avg_eachclass = 82.48104556740734%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 94,   1,  10,   2,   6,   5,  11,   0,   3,   2],
#        [  0, 165,   0,   2,   0,   0,   0,   0,   0,   0],
#        [  0,   0,  68,   0,  16,  29,   9,   1,   0,   0],
#        [  2,   0,   0, 329,   2,   0,   0,   3,   0,   0],
#        [  0,   0,   0,   3, 380,   0,   0,   2,   0,   0],
#        [  1,   0,   3,   8,  23,  88,  20,   4,   6,   2],
#        [  0,   0,   0,   1,   0,   7, 268,   0,   4,   0],
#        [  0,   0,   0,   1,   0,   1,   4, 127,   0,   0],
#        [  0,   0,   0,   0,   0,   0,   4,   0, 259,   0],
#        [  0,   0,   0,   6,  15,   0,   0,  21,   9,  69]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[70.14925373,  0.74626866,  7.46268657,  1.49253731,  4.47761194,
#          3.73134328,  8.20895522,  0.        ,  2.23880597,  1.49253731],
#        [ 0.        , 98.80239521,  0.        ,  1.19760479,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        , 55.28455285,  0.        , 13.00813008,
#         23.57723577,  7.31707317,  0.81300813,  0.        ,  0.        ],
#        [ 0.5952381 ,  0.        ,  0.        , 97.91666667,  0.5952381 ,
#          0.        ,  0.        ,  0.89285714,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.77922078, 98.7012987 ,
#          0.        ,  0.        ,  0.51948052,  0.        ,  0.        ],
#        [ 0.64516129,  0.        ,  1.93548387,  5.16129032, 14.83870968,
#         56.77419355, 12.90322581,  2.58064516,  3.87096774,  1.29032258],
#        [ 0.        ,  0.        ,  0.        ,  0.35714286,  0.        ,
#          2.5       , 95.71428571,  0.        ,  1.42857143,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.7518797 ,  0.        ,
#          0.7518797 ,  3.0075188 , 95.4887218 ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  1.52091255,  0.        , 98.47908745,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  5.        , 12.5       ,
#          0.        ,  0.        , 17.5       ,  7.5       , 57.5       ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
