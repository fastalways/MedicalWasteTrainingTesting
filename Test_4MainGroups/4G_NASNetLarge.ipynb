# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=331
img_width=331
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 331, 331, 3)
# (32,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import preprocess_input,NASNetLarge
#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.NASNetLarge(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 331, 331, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 165, 165, 96) 2592        input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 165, 165, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 165, 165, 42) 4032        activation[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 165, 165, 42) 168         reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 165, 165, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 169, 169, 42) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 171, 171, 96) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 83, 83, 42)   2814        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 83, 83, 42)   2814        activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   3822        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 171, 171, 96) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 83, 83, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 169, 169, 96) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 83, 83, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   6432        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 83, 83, 42)   2142        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 167, 167, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   3822        activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   2814        activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 83, 83, 42)   2142        activation_10[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 83, 83, 42)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 83, 83, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 166, 166, 96) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 83, 83, 42)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add (Add)                       (None, 83, 83, 42)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 83, 83, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 165, 165, 96) 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 83, 83, 168)  0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 83, 83, 96)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 83, 83, 96)   0           cropping2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 83, 83, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 83, 83, 42)   4032        adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 83, 83, 42)   4032        adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 83, 83, 84)   14112       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 83, 83, 84)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 83, 83, 84)   336         reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 83, 83, 84)   336         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 83, 83, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 87, 87, 84)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 89, 89, 84)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 42, 42, 84)   9156        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 42, 42, 84)   9156        activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   11172       activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 89, 89, 84)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 42, 42, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 87, 87, 84)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 42, 42, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   9156        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 42, 42, 84)   7812        activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 85, 85, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   11172       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   9156        activation_19[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 42, 42, 84)   7812        activation_21[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 83, 83, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 42, 42, 84)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 42, 42, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 84, 84, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 42, 42, 84)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 42, 42, 84)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 42, 42, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 83, 83, 168)  0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 42, 42, 336)  0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 42, 42, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 42, 42, 168)  0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 42, 42, 84)   14112       adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 42, 42, 84)   14112       adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 42, 42, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 42, 42, 168)  0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 42, 42, 168)  56448       activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 42, 42, 168)  672         concatenate_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 42, 42, 168)  32424       activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 42, 42, 168)  32424       activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 42, 42, 168)  29736       activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 42, 42, 168)  32424       activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 42, 42, 168)  29736       activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 42, 42, 168)  32424       activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 42, 42, 168)  29736       activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 42, 42, 168)  29736       activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 42, 42, 168)  0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 42, 42, 168)  0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 42, 42, 168)  0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 42, 42, 1008) 0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 42, 42, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 42, 42, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 42, 42, 168)  56448       activation_33[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 42, 42, 168)  169344      activation_34[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 42, 42, 168)  672         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 42, 42, 168)  32424       activation_35[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 42, 42, 168)  32424       activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 42, 42, 168)  29736       activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 42, 42, 168)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 42, 42, 168)  32424       activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 42, 42, 168)  29736       activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 42, 42, 168)  32424       activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 42, 42, 168)  29736       activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 42, 42, 168)  29736       activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 42, 42, 168)  0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 42, 42, 168)  0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 42, 42, 1008) 0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 42, 42, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 42, 42, 1008) 0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 42, 42, 168)  169344      activation_45[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 42, 42, 168)  169344      activation_46[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 42, 42, 168)  672         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 42, 42, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 42, 42, 168)  32424       activation_47[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_49[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 42, 42, 168)  32424       activation_51[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_53[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 42, 42, 168)  29736       activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 11, 11, 672)  468384      activation_238[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 11, 11, 672)  457632      activation_240[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 11, 11, 672)  468384      activation_242[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 11, 11, 672)  457632      activation_244[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 11, 11, 672)  457632      activation_246[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left1_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right1_17
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left2_17[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right2_17
# __________________________________________________________________________________________________
# normal_left3_17 (AveragePooling (None, 11, 11, 672)  0           normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_left4_17 (AveragePooling (None, 11, 11, 672)  0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_right4_17 (AveragePoolin (None, 11, 11, 672)  0           adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left5_17[
# __________________________________________________________________________________________________
# normal_add_1_17 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_17 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_17 (Add)           (None, 11, 11, 672)  0           normal_left3_17[0][0]
#                                                                  adjust_bn_17[0][0]
# __________________________________________________________________________________________________
# normal_add_4_17 (Add)           (None, 11, 11, 672)  0           normal_left4_17[0][0]
#                                                                  normal_right4_17[0][0]
# __________________________________________________________________________________________________
# normal_add_5_17 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_17[0][0]
# __________________________________________________________________________________________________
# normal_concat_17 (Concatenate)  (None, 11, 11, 4032) 0           adjust_bn_17[0][0]
#                                                                  normal_add_1_17[0][0]
#                                                                  normal_add_2_17[0][0]
#                                                                  normal_add_3_17[0][0]
#                                                                  normal_add_4_17[0][0]
#                                                                  normal_add_5_17[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 11, 11, 4032) 0           normal_concat_16[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 11, 11, 4032) 0           normal_concat_17[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_18 (Conv (None, 11, 11, 672)  2709504     activation_247[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_18 (Conv2D)       (None, 11, 11, 672)  2709504     activation_248[0][0]
# __________________________________________________________________________________________________
# adjust_bn_18 (BatchNormalizatio (None, 11, 11, 672)  2688        adjust_conv_projection_18[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_18 (BatchNormalizat (None, 11, 11, 672)  2688        normal_conv_1_18[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# activation_251 (Activation)     (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 11, 11, 672)  468384      activation_249[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 11, 11, 672)  457632      activation_251[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 11, 11, 672)  468384      activation_253[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 11, 11, 672)  457632      activation_255[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 11, 11, 672)  457632      activation_257[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_1_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_1_normal_right2_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left5_18[
# __________________________________________________________________________________________________
# activation_250 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 11, 11, 672)  468384      activation_250[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 11, 11, 672)  457632      activation_252[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 11, 11, 672)  468384      activation_254[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 11, 11, 672)  457632      activation_256[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 11, 11, 672)  457632      activation_258[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right2_18
# __________________________________________________________________________________________________
# normal_left3_18 (AveragePooling (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_left4_18 (AveragePooling (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_right4_18 (AveragePoolin (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left5_18[
# __________________________________________________________________________________________________
# normal_add_1_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_18 (Add)           (None, 11, 11, 672)  0           normal_left3_18[0][0]
#                                                                  adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_add_4_18 (Add)           (None, 11, 11, 672)  0           normal_left4_18[0][0]
#                                                                  normal_right4_18[0][0]
# __________________________________________________________________________________________________
# normal_add_5_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_concat_18 (Concatenate)  (None, 11, 11, 4032) 0           adjust_bn_18[0][0]
#                                                                  normal_add_1_18[0][0]
#                                                                  normal_add_2_18[0][0]
#                                                                  normal_add_3_18[0][0]
#                                                                  normal_add_4_18[0][0]
#                                                                  normal_add_5_18[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 11, 11, 4032) 0           normal_concat_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 4032)         0           activation_259[0][0]
# ==================================================================================================
# Total params: 84,916,818
# Trainable params: 0
# Non-trainable params: 84,916,818
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 4032)              84916818
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4129792
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 89,050,710
# Trainable params: 4,133,892
# Non-trainable params: 84,916,818
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 97/97 [==============================] - 114s 821ms/step - loss: 0.3131 - accuracy: 0.8879 - val_loss: 0.1791 - val_accuracy: 0.9301
# Epoch 2/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 0.0867 - accuracy: 0.9712 - val_loss: 0.1549 - val_accuracy: 0.9366
# Epoch 3/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 0.0475 - accuracy: 0.9829 - val_loss: 0.1457 - val_accuracy: 0.9418
# Epoch 4/2000
# 97/97 [==============================] - 71s 735ms/step - loss: 0.0417 - accuracy: 0.9835 - val_loss: 0.1658 - val_accuracy: 0.9495
# Epoch 5/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 0.0233 - accuracy: 0.9910 - val_loss: 0.1456 - val_accuracy: 0.9651
# Epoch 6/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 0.0277 - accuracy: 0.9893 - val_loss: 0.0949 - val_accuracy: 0.9715
# Epoch 7/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.1149 - val_accuracy: 0.9728
# Epoch 8/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.1402 - val_accuracy: 0.9690
# Epoch 9/2000
# 97/97 [==============================] - 71s 733ms/step - loss: 0.0129 - accuracy: 0.9971 - val_loss: 0.1844 - val_accuracy: 0.9599
# Epoch 10/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.2552 - val_accuracy: 0.9483
# Epoch 11/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.1013 - val_accuracy: 0.9715
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 12/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0943 - val_accuracy: 0.9741
# Epoch 13/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 6.2741e-04 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9767
# Epoch 14/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 6.4383e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9767
# Epoch 15/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 5.9046e-04 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9767
# Epoch 16/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 4.4773e-04 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9767
# Epoch 17/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 4.5080e-04 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9767
# Epoch 18/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 4.9450e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9780
# Epoch 19/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.6390e-04 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9780
# Epoch 20/2000
# 97/97 [==============================] - 71s 735ms/step - loss: 3.3229e-04 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9780
# Epoch 21/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.9329e-04 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 0.9793
# Epoch 22/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 3.1484e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9793
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 3.2532e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9793
# Epoch 24/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.5669e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9793
# Epoch 25/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.8569e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9793
# Epoch 26/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.6328e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9793
# Epoch 27/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 3.2480e-04 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9780
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 28/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 2.8163e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9793
# Epoch 29/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 3.1348e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9793
# Epoch 30/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.4875e-04 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9793
# Epoch 31/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 3.1446e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9793
# Epoch 32/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.7403e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9793
# Epoch 33/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.6913e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9793
# Epoch 34/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 3.1737e-04 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9793
# Epoch 35/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.8207e-04 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9793
# Epoch 36/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 2.9435e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9793
# Epoch 37/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.9171e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9793
# Epoch 38/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.3481e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9793
# Epoch 39/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 2.7068e-04 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9793
# Epoch 40/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.8311e-04 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9806
# Epoch 41/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.8788e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9793
# Epoch 42/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.5697e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9793
# Epoch 43/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.5385e-04 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9806
# Epoch 44/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.4919e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9806
# Epoch 45/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.4089e-04 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9806
# Epoch 46/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 2.6557e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9793
# Epoch 47/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.1593e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9793
# Epoch 48/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.3776e-04 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9793
# Epoch 49/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.6661e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9793
# Epoch 50/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.3907e-04 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9793
# Epoch 51/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.7737e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9806
# Epoch 52/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.2174e-04 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9793
# Epoch 53/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 2.7381e-04 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9806
# Epoch 54/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.3433e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9780
# Epoch 55/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.1642e-04 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9780
# Epoch 56/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.9355e-04 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 0.9780
# Epoch 57/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.4432e-04 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 0.9780
# Epoch 58/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.3469e-04 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9793
# Epoch 59/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.9080e-04 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9793
# Epoch 60/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.2960e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9793
# Epoch 61/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.4467e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9793
# Epoch 62/2000
# 97/97 [==============================] - 71s 733ms/step - loss: 2.1310e-04 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9806
# Epoch 63/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.3419e-04 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9806
# Epoch 64/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.4315e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9806
# Epoch 65/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.1068e-04 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9806
# Epoch 66/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.1007e-04 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 0.9806
# Epoch 67/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.2930e-04 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9806
# Epoch 68/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.0463e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9793
# Epoch 69/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.1953e-04 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9806
# Epoch 70/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.9900e-04 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9780
# Epoch 71/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.9144e-04 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9793
# Epoch 72/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 1.7780e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9793
# Epoch 73/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.1248e-04 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9793
# Epoch 74/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 1.7165e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9819
# Epoch 75/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.9096e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9780
# Epoch 76/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.1522e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9806
# Epoch 77/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.7460e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9806
# Epoch 78/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 1.9970e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9793
# Epoch 79/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 1.8210e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9793
# Epoch 80/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.5836e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9793
# Epoch 81/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.7416e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9780
# Epoch 82/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.6939e-04 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9780
# Epoch 83/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.4394e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9780
# Epoch 84/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.0864e-04 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9780
# Epoch 85/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 1.4057e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9806
# Epoch 86/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 1.7622e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9793
# Epoch 87/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 1.4085e-04 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9793
# Epoch 88/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.2985e-04 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9780
# Epoch 89/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.4809e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9793
# Epoch 90/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.4356e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9793
# Epoch 91/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.4374e-04 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9780
# Epoch 92/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.2128e-04 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9793
# Epoch 93/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.3256e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9806
# Epoch 94/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.3382e-04 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9806
# Epoch 95/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.3176e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9806
# Epoch 96/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.2287e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9780
# Epoch 97/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.3245e-04 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9780
# Epoch 98/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 1.3644e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9780
# Epoch 99/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.2154e-04 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9780
# Epoch 100/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.1032e-04 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9793
# Epoch 101/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 1.2635e-04 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9767
# Epoch 102/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.2708e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9767
# Epoch 103/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.1022e-04 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9767
# Epoch 104/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.1416e-04 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9767
# Epoch 105/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 9.4577e-05 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9767
# Epoch 106/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 1.2094e-04 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9780
# Epoch 107/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 9.2340e-05 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9780
# Epoch 108/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.2752e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9819
# Epoch 109/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 8.7211e-05 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9780
# Epoch 110/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 1.0643e-04 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9780
# Epoch 111/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.0977e-04 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9780
# Epoch 112/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 7.7055e-05 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9793
# Epoch 113/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 9.3519e-05 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9780
# Epoch 114/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 9.5776e-05 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9793
# Epoch 115/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 8.7534e-05 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9780
# Epoch 116/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 8.0156e-05 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9806
# Epoch 117/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 7.4056e-05 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9806
# Epoch 118/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 8.1479e-05 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9780
# Epoch 119/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 6.7177e-05 - accuracy: 1.0000 - val_loss: 0.1023 - val_accuracy: 0.9793
# Epoch 120/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 7.0143e-05 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9793
# Epoch 121/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 6.7981e-05 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9806
# Epoch 122/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 8.4325e-05 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9780
# Epoch 123/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 7.5277e-05 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9780
# Epoch 124/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 7.0143e-05 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9780
# Epoch 125/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.7340e-05 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9780
# Epoch 126/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 6.6732e-05 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9793
# Epoch 127/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 5.6065e-05 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9793
# Epoch 128/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 6.2942e-05 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9780
# Epoch 129/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 5.6526e-05 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9793
# Epoch 130/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.5229e-05 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9806
# Epoch 131/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 4.8014e-05 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9806
# Epoch 132/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 8.8870e-05 - accuracy: 1.0000 - val_loss: 0.1046 - val_accuracy: 0.9806
# Epoch 133/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 4.6686e-05 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 0.9793
# Epoch 134/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 6.6024e-05 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9806
# Epoch 135/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 6.1211e-05 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9806
# Epoch 136/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 4.1471e-05 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9793
# Epoch 137/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 6.2011e-05 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9793
# Epoch 138/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 6.1236e-05 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9793
# Epoch 139/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 4.9372e-05 - accuracy: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9793
# Epoch 140/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 4.5100e-05 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9793
# Epoch 141/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 4.5394e-05 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9793
# Epoch 142/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 5.2133e-05 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9780
# Epoch 143/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 3.8775e-05 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 0.9767
# Epoch 144/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 4.1940e-05 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9780
# Epoch 145/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 5.4872e-05 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.9780
# Epoch 146/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 4.0680e-05 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.9780
# Epoch 147/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 3.3029e-05 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9793
# Epoch 148/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 3.7026e-05 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9793
# Epoch 149/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 5.3017e-05 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9806
# Epoch 150/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 3.1330e-05 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9780
# Epoch 151/2000
# 97/97 [==============================] - 71s 731ms/step - loss: 3.8668e-05 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9767
# Epoch 152/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 3.1015e-05 - accuracy: 1.0000 - val_loss: 0.1090 - val_accuracy: 0.9793
# Epoch 153/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 3.8042e-05 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9793
# Epoch 154/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 3.0494e-05 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9806
# Epoch 155/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 2.9053e-05 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9806
# Epoch 156/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 3.2842e-05 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9780
# Epoch 157/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 2.9509e-05 - accuracy: 1.0000 - val_loss: 0.1090 - val_accuracy: 0.9793
# Epoch 158/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 2.6769e-05 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9793
# Epoch 159/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 4.1072e-05 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9780
# Epoch 160/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 3.0094e-05 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9793
# Epoch 161/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.7225e-05 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9793
# Epoch 162/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.5880e-05 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9793
# Epoch 163/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 3.1044e-05 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9793
# Epoch 164/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 2.4457e-05 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9793
# Epoch 165/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 2.3925e-05 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9793
# Epoch 166/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.1685e-05 - accuracy: 1.0000 - val_loss: 0.1112 - val_accuracy: 0.9793
# Epoch 167/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.4696e-05 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9793
# Epoch 168/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.9629e-05 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9780
# Epoch 169/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.2307e-05 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9806
# Epoch 170/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 2.6134e-05 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9793
# Epoch 171/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.9600e-05 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9793
# Epoch 172/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.2230e-05 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9793
# Epoch 173/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.4899e-05 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9780
# Epoch 174/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.9276e-05 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9780
# Epoch 175/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.8733e-05 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9793
# Epoch 176/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.9653e-05 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9780
# Epoch 177/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.0311e-05 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9793
# Epoch 178/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 1.6789e-05 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9793
# Epoch 179/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 1.6248e-05 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9793
# Epoch 180/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.6446e-05 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9806
# Epoch 181/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 1.5110e-05 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9806
# Epoch 182/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.0447e-05 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9806
# Epoch 183/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.0569e-05 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9806
# Epoch 184/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 1.5533e-05 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9806
# Epoch 185/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 1.4772e-05 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9793
# Epoch 186/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 1.8320e-05 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9793
# Epoch 187/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 1.3978e-05 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9793
# Epoch 188/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.5581e-05 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9793
# Epoch 189/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 1.1209e-05 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9793
# Epoch 190/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.8035e-05 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9793
# Epoch 191/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.4077e-05 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9793
# Epoch 192/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 1.4730e-05 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9780
# Epoch 193/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.2809e-05 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9780
# Epoch 194/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.1710e-05 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9793
# Epoch 195/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 1.3043e-05 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9793
# Epoch 196/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.2129e-05 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9793
# Epoch 197/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 1.5424e-05 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9793
# Epoch 198/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.3406e-05 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9793
# Epoch 199/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.0726e-05 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9793
# Epoch 200/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.0892e-05 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9793
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 9.7671e-06 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9793
# Epoch 202/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 1.3377e-05 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9793
# Epoch 203/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.0685e-05 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9806
# Epoch 204/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 9.5048e-06 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9793
# Epoch 205/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 1.2566e-05 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9793
# Epoch 206/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.2441e-05 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9806
# Epoch 207/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 1.2403e-05 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9793
# Epoch 208/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 9.0887e-06 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9793
# Epoch 209/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 8.8464e-06 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9806
# Epoch 210/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 7.9638e-06 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9793
# Epoch 211/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.0138e-05 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9806
# Epoch 212/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.0159e-05 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9806
# Epoch 213/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 7.2664e-06 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9793
# Epoch 214/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 8.0501e-06 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9806
# Epoch 215/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 9.3735e-06 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9806
# Epoch 216/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.0905e-05 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9793
# Epoch 217/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 9.7537e-06 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9793
# Epoch 218/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 8.5013e-06 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9793
# Epoch 219/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 7.6170e-06 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9793
# Epoch 220/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 7.0585e-06 - accuracy: 1.0000 - val_loss: 0.1224 - val_accuracy: 0.9793
# Epoch 221/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 7.0152e-06 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9793
# Epoch 222/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 8.0377e-06 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9793
# Epoch 223/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 4.9015e-06 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9793
# Epoch 224/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 7.1197e-06 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9793
# Epoch 225/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 8.5862e-06 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9793
# Epoch 226/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 7.1939e-06 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9793
# Epoch 227/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 5.8426e-06 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9793
# Epoch 228/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 6.4509e-06 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9793
# Epoch 229/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 6.2104e-06 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9793
# Epoch 230/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 7.2958e-06 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9793
# Epoch 231/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 6.5908e-06 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9793
# Epoch 232/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 5.2033e-06 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9793
# Epoch 233/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 7.7481e-06 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9793
# Epoch 234/2000
# 97/97 [==============================] - 71s 735ms/step - loss: 6.4500e-06 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9806
# Epoch 235/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 4.9482e-06 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9793
# Epoch 236/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.7371e-06 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9793
# Epoch 237/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 4.6340e-06 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9793
# Epoch 238/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 5.1167e-06 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9793
# Epoch 239/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 4.4969e-06 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9793
# Epoch 240/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 4.8726e-06 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9793
# Epoch 241/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 4.7059e-06 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9793
# Epoch 242/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 4.6465e-06 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9793
# Epoch 243/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 4.0911e-06 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9793
# Epoch 244/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.2027e-06 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9793
# Epoch 245/2000
# 97/97 [==============================] - 71s 732ms/step - loss: 3.8451e-06 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9793
# Epoch 246/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 4.7363e-06 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9793
# Epoch 247/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 4.5293e-06 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9793
# Epoch 248/2000
# 97/97 [==============================] - 71s 733ms/step - loss: 4.6167e-06 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9793
# Epoch 249/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 3.4504e-06 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9793
# Epoch 250/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 3.7944e-06 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9793
# Epoch 251/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.0688e-06 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9793
# Epoch 252/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 4.6124e-06 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9793
# Epoch 253/2000
# 97/97 [==============================] - 71s 735ms/step - loss: 3.5123e-06 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9793
# Epoch 254/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.9622e-06 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9793
# Epoch 255/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.6583e-06 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9793
# Epoch 256/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.5098e-06 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9793
# Epoch 257/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 4.1872e-06 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9793
# Epoch 258/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.9891e-06 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9793
# Epoch 259/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.3089e-06 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9793
# Epoch 260/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 3.3203e-06 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9793
# Epoch 261/2000
# 97/97 [==============================] - 71s 735ms/step - loss: 4.1451e-06 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9793
# Epoch 262/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.4820e-06 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9793
# Epoch 263/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 3.5209e-06 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9793
# Epoch 264/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 3.6022e-06 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9793
# Epoch 265/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.5181e-06 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9793
# Epoch 266/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.9221e-06 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9793
# Epoch 267/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.7903e-06 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9793
# Epoch 268/2000
# 97/97 [==============================] - 71s 733ms/step - loss: 2.3338e-06 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9793
# Epoch 269/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 3.4741e-06 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9793
# Epoch 270/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.8071e-06 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9793
# Epoch 271/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 2.4693e-06 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9793
# Epoch 272/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 2.5406e-06 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9793
# Epoch 273/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.5592e-06 - accuracy: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.9793
# Epoch 274/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 3.4137e-06 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9793
# Epoch 275/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.8143e-06 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9793
# Epoch 276/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.6031e-06 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9793
# Epoch 277/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.3940e-06 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9793
# Epoch 278/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.5110e-06 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9793
# Epoch 279/2000
# 97/97 [==============================] - 71s 739ms/step - loss: 2.3721e-06 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9793
# Epoch 280/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 3.1157e-06 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9793
# Epoch 281/2000
# 97/97 [==============================] - 71s 734ms/step - loss: 2.5772e-06 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9793
# Epoch 282/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 2.3931e-06 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9793
# Epoch 283/2000
# 97/97 [==============================] - 71s 732ms/step - loss: 2.5730e-06 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9793
# Epoch 284/2000
# 97/97 [==============================] - 71s 732ms/step - loss: 2.4295e-06 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9793
# Epoch 285/2000
# 97/97 [==============================] - 71s 737ms/step - loss: 2.2906e-06 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9793
# Epoch 286/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 2.0540e-06 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9793
# Epoch 287/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.3158e-06 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9793
# Epoch 288/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 2.8084e-06 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9793
# Epoch 289/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.6748e-06 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9793
# Epoch 290/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.5110e-06 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9793
# Epoch 291/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.3244e-06 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9793
# Epoch 292/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.8681e-06 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9793
# Epoch 293/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.0044e-06 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9793
# Epoch 294/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 1.7012e-06 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9793
# Epoch 295/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.8827e-06 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9793
# Epoch 296/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.9967e-06 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9793
# Epoch 297/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 2.2826e-06 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9793
# Epoch 298/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.4859e-06 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9793
# Epoch 299/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.8136e-06 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9793
# Epoch 300/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.0615e-06 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9793
# Epoch 301/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.7339e-06 - accuracy: 1.0000 - val_loss: 0.1353 - val_accuracy: 0.9793
# Epoch 302/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.8280e-06 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9793
# Epoch 303/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.6245e-06 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9793
# Epoch 304/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.4655e-06 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9793
# Epoch 305/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.7295e-06 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9793
# Epoch 306/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.0681e-06 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9793
# Epoch 307/2000
# 97/97 [==============================] - 71s 736ms/step - loss: 2.3815e-06 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9793
# Epoch 308/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 1.8311e-06 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9793
# Epoch 309/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.7415e-06 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9793
# Epoch 310/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 2.0195e-06 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9793
# Epoch 311/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 1.6905e-06 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9793
# Epoch 312/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 1.2818e-06 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9793
# Epoch 313/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 1.4402e-06 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9793
# Epoch 314/2000
# ...
# Epoch 1899/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 2.5421e-08 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9793
# Epoch 1900/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 5.2768e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9793
# Epoch 1901/2000
# 97/97 [==============================] - 73s 754ms/step - loss: 4.6990e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9793
# Epoch 1902/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 1.0284e-08 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9793
# Epoch 1903/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 5.1612e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9793
# Epoch 1904/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 6.7789e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9793
# Epoch 1905/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 7.8574e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9793
# Epoch 1906/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 6.7404e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9793
# Epoch 1907/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 5.7005e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1908/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 5.3923e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1909/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 2.0029e-08 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9793
# Epoch 1910/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 4.7376e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1911/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 6.1242e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1912/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 6.2012e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1913/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 8.1655e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1914/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 6.4323e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1915/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 4.4294e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1916/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 9.0899e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1917/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 1.4059e-08 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9793
# Epoch 1918/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 8.3196e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9793
# Epoch 1919/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 1.3173e-08 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1920/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 4.8916e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1921/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 9.5907e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1922/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 3.6206e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9806
# Epoch 1923/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 5.1612e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1924/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 4.4679e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1925/2000
# 97/97 [==============================] - 73s 750ms/step - loss: 5.5079e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1926/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 1.3789e-08 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1927/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 6.1627e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1928/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 6.3553e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1929/2000
# 97/97 [==============================] - 72s 743ms/step - loss: 8.2426e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1930/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 5.4694e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9806
# Epoch 1931/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 7.0100e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1932/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 1.5098e-08 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1933/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 4.9301e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1934/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 6.4323e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1935/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 7.0100e-09 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9806
# Epoch 1936/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 1.1555e-08 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9793
# Epoch 1937/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 6.1627e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1938/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 7.9730e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1939/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 5.3923e-09 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9806
# Epoch 1940/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 6.5864e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1941/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 5.3923e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1942/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 5.6234e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1943/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 5.7390e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1944/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 5.5849e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1945/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 5.5464e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1946/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 7.9729e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9806
# Epoch 1947/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 7.5878e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9806
# Epoch 1948/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 6.7404e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1949/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 5.1227e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1950/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 5.4309e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1951/2000
# 97/97 [==============================] - 73s 750ms/step - loss: 6.8945e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1952/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 6.6249e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1953/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 5.6234e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1954/2000
# 97/97 [==============================] - 72s 741ms/step - loss: 5.9701e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1955/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 4.2368e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1956/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 8.1270e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9806
# Epoch 1957/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 5.4694e-09 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9806
# Epoch 1958/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 4.9301e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1959/2000
# 97/97 [==============================] - 72s 739ms/step - loss: 5.6620e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1960/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 6.4323e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1961/2000
# 97/97 [==============================] - 72s 745ms/step - loss: 4.7376e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1962/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 5.9701e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1963/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 7.0871e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1964/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 6.5093e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1965/2000
# 97/97 [==============================] - 72s 740ms/step - loss: 8.0500e-09 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1966/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 6.0471e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1967/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 8.2426e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1968/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 3.4665e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1969/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 4.7376e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1970/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 3.8517e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1971/2000
# 97/97 [==============================] - 71s 738ms/step - loss: 5.9316e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1972/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 8.2041e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1973/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 9.8988e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1974/2000
# 97/97 [==============================] - 72s 746ms/step - loss: 4.5065e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1975/2000
# 97/97 [==============================] - 72s 744ms/step - loss: 3.9287e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1976/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 4.4294e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1977/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 2.6577e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1978/2000
# 97/97 [==============================] - 72s 747ms/step - loss: 3.3510e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1979/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 3.5435e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1980/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 6.3938e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1981/2000
# 97/97 [==============================] - 73s 754ms/step - loss: 5.7005e-09 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9806
# Epoch 1982/2000
# 97/97 [==============================] - 73s 752ms/step - loss: 5.3538e-09 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9806
# Epoch 1983/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 5.6234e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1984/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 9.9758e-09 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9806
# Epoch 1985/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 9.8603e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1986/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 6.6634e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1987/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 5.9701e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1988/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 6.3167e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1989/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 4.4679e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1990/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 5.5464e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1991/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 5.4309e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1992/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 3.7746e-09 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9806
# Epoch 1993/2000
# 97/97 [==============================] - 73s 749ms/step - loss: 7.5493e-09 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9806
# Epoch 1994/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 5.6620e-09 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9806
# Epoch 1995/2000
# 97/97 [==============================] - 72s 748ms/step - loss: 1.3596e-08 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9806
# Epoch 1996/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 1.0631e-08 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1997/2000
# 97/97 [==============================] - 72s 742ms/step - loss: 7.8574e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1998/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 5.9701e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 1999/2000
# 97/97 [==============================] - 72s 749ms/step - loss: 4.5065e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# Epoch 2000/2000
# 97/97 [==============================] - 73s 751ms/step - loss: 8.0500e-09 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9806
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 57/57 [==============================] - 37s 609ms/step - loss: 0.6850 - accuracy: 0.9125
# test_indoor_ds_results:test loss, test acc: [0.6849530339241028, 0.9124860763549805]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 99/99 [==============================] - 63s 612ms/step - loss: 1.4661 - accuracy: 0.8949
# test_outdoor_ds_results:test loss, test acc: [1.466086983680725, 0.8949044346809387]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 69/69 [==============================] - 44s 624ms/step - loss: 2.1219 - accuracy: 0.8341
# test_belt_ds_results:test loss, test acc: [2.121898889541626, 0.8340888619422913]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetLarge/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 57/57 [==============================] - 38s 588ms/step - loss: 0.4268 - accuracy: 0.9147
# 99/99 [==============================] - 59s 593ms/step - loss: 0.8807 - accuracy: 0.8987
# 69/69 [==============================] - 41s 597ms/step - loss: 1.3159 - accuracy: 0.8336
# Epoch200
#  test_indoor_acc=0.9147157073020935
#  test_outdoor_acc=0.8987261056900024
#  test_belt_acc=0.8336355686187744
# 57/57 [==============================] - 38s 583ms/step - loss: 0.5303 - accuracy: 0.9142
# 99/99 [==============================] - 58s 589ms/step - loss: 1.1164 - accuracy: 0.8952
# 69/69 [==============================] - 41s 595ms/step - loss: 1.6318 - accuracy: 0.8341
# Epoch400
#  test_indoor_acc=0.914158284664154
#  test_outdoor_acc=0.8952229022979736
#  test_belt_acc=0.8340888619422913
# 57/57 [==============================] - 38s 586ms/step - loss: 0.5889 - accuracy: 0.9136
# 99/99 [==============================] - 59s 592ms/step - loss: 1.2493 - accuracy: 0.8959
# 69/69 [==============================] - 41s 597ms/step - loss: 1.8101 - accuracy: 0.8350
# Epoch600
#  test_indoor_acc=0.9136009216308594
#  test_outdoor_acc=0.8958598971366882
#  test_belt_acc=0.834995448589325
# 57/57 [==============================] - 38s 586ms/step - loss: 0.6192 - accuracy: 0.9125
# 99/99 [==============================] - 59s 592ms/step - loss: 1.3313 - accuracy: 0.8955
# 69/69 [==============================] - 41s 596ms/step - loss: 1.9162 - accuracy: 0.8332
# Epoch800
#  test_indoor_acc=0.9124860763549805
#  test_outdoor_acc=0.8955414295196533
#  test_belt_acc=0.8331822156906128
# 57/57 [==============================] - 39s 588ms/step - loss: 0.6379 - accuracy: 0.9114
# 99/99 [==============================] - 59s 595ms/step - loss: 1.3677 - accuracy: 0.8968
# 69/69 [==============================] - 41s 600ms/step - loss: 1.9706 - accuracy: 0.8359
# Epoch1000
#  test_indoor_acc=0.9113712310791016
#  test_outdoor_acc=0.896815299987793
#  test_belt_acc=0.8359020948410034
# 57/57 [==============================] - 38s 588ms/step - loss: 0.6524 - accuracy: 0.9130
# 99/99 [==============================] - 59s 594ms/step - loss: 1.3951 - accuracy: 0.8959
# 69/69 [==============================] - 41s 600ms/step - loss: 2.0216 - accuracy: 0.8341
# Epoch1200
#  test_indoor_acc=0.9130434989929199
#  test_outdoor_acc=0.8958598971366882
#  test_belt_acc=0.8340888619422913
# 57/57 [==============================] - 39s 588ms/step - loss: 0.6623 - accuracy: 0.9130
# 99/99 [==============================] - 59s 595ms/step - loss: 1.4204 - accuracy: 0.8965
# 69/69 [==============================] - 41s 599ms/step - loss: 2.0529 - accuracy: 0.8345
# Epoch1400
#  test_indoor_acc=0.9130434989929199
#  test_outdoor_acc=0.8964968323707581
#  test_belt_acc=0.8345421552658081
# 57/57 [==============================] - 39s 592ms/step - loss: 0.6721 - accuracy: 0.9142
# 99/99 [==============================] - 59s 600ms/step - loss: 1.4428 - accuracy: 0.8952
# 69/69 [==============================] - 42s 614ms/step - loss: 2.0777 - accuracy: 0.8336
# Epoch1600
#  test_indoor_acc=0.914158284664154
#  test_outdoor_acc=0.8952229022979736
#  test_belt_acc=0.8336355686187744
# 57/57 [==============================] - 39s 592ms/step - loss: 0.6788 - accuracy: 0.9125
# 99/99 [==============================] - 59s 597ms/step - loss: 1.4525 - accuracy: 0.8949
# 69/69 [==============================] - 41s 600ms/step - loss: 2.1042 - accuracy: 0.8341
# Epoch1800
#  test_indoor_acc=0.9124860763549805
#  test_outdoor_acc=0.8949044346809387
#  test_belt_acc=0.8340888619422913
# 57/57 [==============================] - 39s 593ms/step - loss: 0.6850 - accuracy: 0.9125
# 99/99 [==============================] - 59s 598ms/step - loss: 1.4661 - accuracy: 0.8949
# 69/69 [==============================] - 42s 601ms/step - loss: 2.1219 - accuracy: 0.8341
# Epoch2000
#  test_indoor_acc=0.9124860763549805
#  test_outdoor_acc=0.8949044346809387
#  test_belt_acc=0.8340888619422913

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8823591272036234
# max index -> 0
# The [Epoch] of max acc -> 200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9147157073020935,
#  0.914158284664154,
#  0.9136009216308594,
#  0.9124860763549805,
#  0.9113712310791016,
#  0.9130434989929199,
#  0.9130434989929199,
#  0.914158284664154,
#  0.9124860763549805,
#  0.9124860763549805]

# %%
test_outdoor_acc
# Out:
# [0.8987261056900024,
#  0.8952229022979736,
#  0.8958598971366882,
#  0.8955414295196533,
#  0.896815299987793,
#  0.8958598971366882,
#  0.8964968323707581,
#  0.8952229022979736,
#  0.8949044346809387,
#  0.8949044346809387]

# %%
test_belt_acc
# Out:
# [0.8336355686187744,
#  0.8340888619422913,
#  0.834995448589325,
#  0.8331822156906128,
#  0.8359020948410034,
#  0.8340888619422913,
#  0.8345421552658081,
#  0.8336355686187744,
#  0.8340888619422913,
#  0.8340888619422913]

# %%
test_indoor_loss
# Out:
# [0.4267934560775757,
#  0.5303054451942444,
#  0.5889415740966797,
#  0.6192418932914734,
#  0.637933611869812,
#  0.6524142622947693,
#  0.6622565388679504,
#  0.6720813512802124,
#  0.6787636876106262,
#  0.6849530339241028]

# %%
test_outdoor_loss
# Out:
# [0.8806713223457336,
#  1.1163972616195679,
#  1.2492924928665161,
#  1.3312615156173706,
#  1.3676940202713013,
#  1.3950815200805664,
#  1.420385718345642,
#  1.4428081512451172,
#  1.4525002241134644,
#  1.466086983680725]

# %%
test_belt_loss
# Out:
# [1.3159266710281372,
#  1.6318345069885254,
#  1.8100606203079224,
#  1.9162081480026245,
#  1.9705917835235596,
#  2.0215723514556885,
#  2.0529086589813232,
#  2.0777370929718018,
#  2.1041858196258545,
#  2.121898889541626]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.nasnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=331
img_width=331
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

N = 150

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)} are predicting")
x_indoor_sets = np.array_split(x_test_indoor, N)
del x_test_indoor
y_all_sets_predicted = []
for x in x_indoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_indoor_predicted = np.concatenate(y_all_sets_predicted)
del x_indoor_sets,test_indoor_ds

x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)} are predicting")
x_outdoor_sets = np.array_split(x_test_outdoor, N)
del x_test_outdoor
y_all_sets_predicted = []
for x in x_outdoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_outdoor_predicted = np.concatenate(y_all_sets_predicted)
del x_outdoor_sets,test_outdoor_ds

x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)} are predicting")
x_belt_sets = np.array_split(x_test_belt, N)
del x_test_belt
y_all_sets_predicted = []
for x in x_belt_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_belt_predicted = np.concatenate(y_all_sets_predicted)
del x_belt_sets,test_belt_ds

y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
y_all_predicted = np.concatenate([y_indoor_predicted,y_outdoor_predicted,y_belt_predicted],axis=0)
print(f"all num x,y :{len(y_all_predicted)},{len(y_all)}")
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794 are predicting
# train_outdoor num x,y : 3140,3140 are predicting
# train_belt num x,y : 2206,2206 are predicting
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6302
# FP=838
# acc=0.8826330532212885
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 85.66978193146417%
# 2-BloodSecretionWaste acc = 80.17291066282421%
# 3-LabWardWaste acc = 91.55455904334828%
# 4-VaccineOtherWaste acc = 95.0957496496964%
#
#
#
# all_avg_eachclass = 88.12325032183327%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1650,  194,   46,   36],
#        [ 245, 1391,   36,   63],
#        [  29,   40, 1225,   44],
#        [  15,   62,   28, 2036]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[85.66978193, 10.07268951,  2.38836968,  1.86915888],
#        [14.12103746, 80.17291066,  2.07492795,  3.63112392],
#        [ 2.16741405,  2.98953662, 91.55455904,  3.28849028],
#        [ 0.70060719,  2.89584306,  1.30780009, 95.09574965]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
