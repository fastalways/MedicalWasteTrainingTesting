# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import preprocess_input,NASNetMobile
#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.NASNetMobile(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 11) 352         activation[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 11) 44          reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 11) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   396         separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   396         activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 32) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1152        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   220         activation_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   396         activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   220         activation_10[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 11)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 112, 112, 32) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 11)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 11)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 111, 111, 32) 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 44)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 32)   0           cropping2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 22)   968         activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 22)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 22)   88          reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 22)   88          concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   1034        activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   682         activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1034        activation_19[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   682         activation_21[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 22)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 57, 57, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 22)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 22)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 56, 56, 44)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 88)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 44)   0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 44)   0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 44)   3872        activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 44)   176         concatenate_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 44)   3036        activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 44)   3036        activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 44)   2332        activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 44)   3036        activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 44)   3036        activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 44)   2332        activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 44)   0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 44)   0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 44)   3872        activation_33[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 44)   11616       activation_34[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 44)   3036        activation_35[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 44)   3036        activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 44)   2332        activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 44)   3036        activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 44)   3036        activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 44)   2332        activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 44)   0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 44)   0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 28, 28, 264)  0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 44)   11616       activation_45[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 44)   11616       activation_46[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 44)   3036        activation_47[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_49[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 44)   3036        activation_51[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_53[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 44)   2332        activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_166[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_168[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_170[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_172[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_174[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_11
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_11
# __________________________________________________________________________________________________
# normal_left3_11 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_left4_11 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_right4_11 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_11[
# __________________________________________________________________________________________________
# normal_add_1_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_11 (Add)           (None, 7, 7, 176)    0           normal_left3_11[0][0]
#                                                                  adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_add_4_11 (Add)           (None, 7, 7, 176)    0           normal_left4_11[0][0]
#                                                                  normal_right4_11[0][0]
# __________________________________________________________________________________________________
# normal_add_5_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_concat_11 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_11[0][0]
#                                                                  normal_add_1_11[0][0]
#                                                                  normal_add_2_11[0][0]
#                                                                  normal_add_3_11[0][0]
#                                                                  normal_add_4_11[0][0]
#                                                                  normal_add_5_11[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 7, 7, 1056)   0           normal_concat_10[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 7, 7, 1056)   0           normal_concat_11[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_12 (Conv (None, 7, 7, 176)    185856      activation_175[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_12 (Conv2D)       (None, 7, 7, 176)    185856      activation_176[0][0]
# __________________________________________________________________________________________________
# adjust_bn_12 (BatchNormalizatio (None, 7, 7, 176)    704         adjust_conv_projection_12[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_12 (BatchNormalizat (None, 7, 7, 176)    704         normal_conv_1_12[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 176)    35376       activation_177[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 176)    32560       activation_179[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 176)    35376       activation_181[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 176)    32560       activation_183[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 176)    32560       activation_185[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right2_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left5_12[
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_178[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_180[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_182[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_184[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_186[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_12
# __________________________________________________________________________________________________
# normal_left3_12 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_left4_12 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_right4_12 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_12[
# __________________________________________________________________________________________________
# normal_add_1_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_12 (Add)           (None, 7, 7, 176)    0           normal_left3_12[0][0]
#                                                                  adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_add_4_12 (Add)           (None, 7, 7, 176)    0           normal_left4_12[0][0]
#                                                                  normal_right4_12[0][0]
# __________________________________________________________________________________________________
# normal_add_5_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_concat_12 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_12[0][0]
#                                                                  normal_add_1_12[0][0]
#                                                                  normal_add_2_12[0][0]
#                                                                  normal_add_3_12[0][0]
#                                                                  normal_add_4_12[0][0]
#                                                                  normal_add_5_12[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 7, 7, 1056)   0           normal_concat_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1056)         0           activation_187[0][0]
# ==================================================================================================
# Total params: 4,269,716
# Trainable params: 0
# Non-trainable params: 4,269,716
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1056)              4269716
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1082368
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 5,356,184
# Trainable params: 1,086,468
# Non-trainable params: 4,269,716
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 46s 299ms/step - loss: 0.5204 - accuracy: 0.8165 - val_loss: 0.2303 - val_accuracy: 0.9133
# Epoch 2/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.1870 - accuracy: 0.9321 - val_loss: 0.1621 - val_accuracy: 0.9392
# Epoch 3/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.1249 - accuracy: 0.9586 - val_loss: 0.1399 - val_accuracy: 0.9521
# Epoch 4/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0819 - accuracy: 0.9764 - val_loss: 0.1357 - val_accuracy: 0.9508
# Epoch 5/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0539 - accuracy: 0.9868 - val_loss: 0.1777 - val_accuracy: 0.9379
# Epoch 6/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0426 - accuracy: 0.9900 - val_loss: 0.1951 - val_accuracy: 0.9379
# Epoch 7/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0360 - accuracy: 0.9913 - val_loss: 0.1410 - val_accuracy: 0.9508
# Epoch 8/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0325 - accuracy: 0.9910 - val_loss: 0.1531 - val_accuracy: 0.9457
# Epoch 9/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0317 - accuracy: 0.9913 - val_loss: 0.1805 - val_accuracy: 0.9405
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 10/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0183 - accuracy: 0.9968 - val_loss: 0.1325 - val_accuracy: 0.9508
# Epoch 11/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0097 - accuracy: 0.9984 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 12/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0089 - accuracy: 0.9997 - val_loss: 0.1396 - val_accuracy: 0.9495
# Epoch 13/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0071 - accuracy: 0.9997 - val_loss: 0.1355 - val_accuracy: 0.9508
# Epoch 14/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9534
# Epoch 15/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.1405 - val_accuracy: 0.9508
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 16/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9521
# Epoch 17/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9547
# Epoch 18/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9547
# Epoch 19/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9521
# Epoch 20/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9508
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 21/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9521
# Epoch 22/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9521
# Epoch 23/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 24/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9534
# Epoch 25/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9521
# Epoch 26/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9534
# Epoch 27/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9521
# Epoch 28/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 29/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 30/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9521
# Epoch 31/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9521
# Epoch 32/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9534
# Epoch 33/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9534
# Epoch 34/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9547
# Epoch 35/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9534
# Epoch 36/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9534
# Epoch 37/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 38/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9534
# Epoch 39/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9534
# Epoch 40/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9534
# Epoch 41/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9521
# Epoch 42/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9521
# Epoch 43/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9534
# Epoch 44/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 45/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9534
# Epoch 46/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 47/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9534
# Epoch 48/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 49/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9534
# Epoch 50/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 51/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9521
# Epoch 52/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9521
# Epoch 53/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9534
# Epoch 54/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9521
# Epoch 55/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9521
# Epoch 56/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9534
# Epoch 57/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9534
# Epoch 58/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9521
# Epoch 59/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9534
# Epoch 60/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9534
# Epoch 61/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9534
# Epoch 62/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9534
# Epoch 63/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9534
# Epoch 64/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9534
# Epoch 65/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9521
# Epoch 66/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9534
# Epoch 67/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9547
# Epoch 68/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9534
# Epoch 69/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9534
# Epoch 70/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9534
# Epoch 71/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9534
# Epoch 72/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9547
# Epoch 73/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9534
# Epoch 74/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9547
# Epoch 75/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9521
# Epoch 76/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9534
# Epoch 77/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9534
# Epoch 78/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9534
# Epoch 79/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9547
# Epoch 80/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9534
# Epoch 81/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9547
# Epoch 82/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 83/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9534
# Epoch 84/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9534
# Epoch 85/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9547
# Epoch 86/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9534
# Epoch 87/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9547
# Epoch 88/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9547
# Epoch 89/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9547
# Epoch 90/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9547
# Epoch 91/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9534
# Epoch 92/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9534
# Epoch 93/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 94/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9534
# Epoch 95/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9547
# Epoch 96/2000
# 49/49 [==============================] - 6s 123ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9547
# Epoch 97/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 98/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9547
# Epoch 99/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 100/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9547
# Epoch 101/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 102/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 103/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 104/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9547
# Epoch 105/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 106/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 107/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9547
# Epoch 108/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9547
# Epoch 109/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9547
# Epoch 110/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9547
# Epoch 111/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9547
# Epoch 112/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 113/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9547
# Epoch 114/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 0.9547
# Epoch 115/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1435 - val_accuracy: 0.9547
# Epoch 116/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9547
# Epoch 117/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9547
# Epoch 118/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9547
# Epoch 119/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9560
# Epoch 120/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9560
# Epoch 121/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9560
# Epoch 122/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9560
# Epoch 123/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9547
# Epoch 124/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9560
# Epoch 125/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9560
# Epoch 126/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9560
# Epoch 127/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9547
# Epoch 128/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9547
# Epoch 129/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9560
# Epoch 130/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9560
# Epoch 131/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9573
# Epoch 132/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9560
# Epoch 133/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9547
# Epoch 134/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9573
# Epoch 135/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9560
# Epoch 136/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9560
# Epoch 137/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9560
# Epoch 138/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9560
# Epoch 139/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9560
# Epoch 140/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 141/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9547
# Epoch 142/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9573
# Epoch 143/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9560
# Epoch 144/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9560
# Epoch 145/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9560
# Epoch 146/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9560
# Epoch 147/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9560
# Epoch 148/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9560
# Epoch 149/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9560
# Epoch 150/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9560
# Epoch 151/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9547
# Epoch 152/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9560
# Epoch 153/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9560
# Epoch 154/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9560
# Epoch 155/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9560
# Epoch 156/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9560
# Epoch 157/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9560
# Epoch 158/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 159/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 160/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9547
# Epoch 161/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9560
# Epoch 162/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 163/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 164/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 165/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9560
# Epoch 166/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9560
# Epoch 167/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9560
# Epoch 168/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9560
# Epoch 169/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9560
# Epoch 170/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 171/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 172/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 173/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9547
# Epoch 174/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9560
# Epoch 175/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9560
# Epoch 176/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.5164e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9560
# Epoch 177/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9547
# Epoch 178/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.9292e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9547
# Epoch 179/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.4001e-04 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9560
# Epoch 180/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.8193e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9547
# Epoch 181/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.3929e-04 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9547
# Epoch 182/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.7590e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9547
# Epoch 183/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.8633e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9560
# Epoch 184/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.3169e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9547
# Epoch 185/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 9.1455e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9560
# Epoch 186/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.3692e-04 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9547
# Epoch 187/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 8.6552e-04 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9547
# Epoch 188/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 8.2974e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9560
# Epoch 189/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 8.5787e-04 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9560
# Epoch 190/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.9563e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9547
# Epoch 191/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.5505e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9560
# Epoch 192/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.3711e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9547
# Epoch 193/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.4422e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9547
# Epoch 194/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.0822e-04 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9560
# Epoch 195/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 8.5930e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9560
# Epoch 196/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 7.7554e-04 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9573
# Epoch 197/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 7.5557e-04 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9560
# Epoch 198/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 7.4681e-04 - accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9547
# Epoch 199/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 7.0785e-04 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9560
# Epoch 200/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 7.5396e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9573
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 7.2668e-04 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9534
# Epoch 202/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 7.2706e-04 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9560
# Epoch 203/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.9683e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9534
# Epoch 204/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 7.2136e-04 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9560
# Epoch 205/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 7.2571e-04 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9560
# Epoch 206/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.5648e-04 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9547
# Epoch 207/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.9617e-04 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9560
# Epoch 208/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.6747e-04 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.9560
# Epoch 209/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.2306e-04 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9547
# Epoch 210/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 6.6307e-04 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 0.9560
# Epoch 211/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.6053e-04 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9560
# Epoch 212/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.3116e-04 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9560
# Epoch 213/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 6.5377e-04 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9573
# Epoch 214/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.3160e-04 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9560
# Epoch 215/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.9354e-04 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9560
# Epoch 216/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.8181e-04 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.9560
# Epoch 217/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.8248e-04 - accuracy: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.9573
# Epoch 218/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 6.0519e-04 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9573
# Epoch 219/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 5.7275e-04 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9560
# Epoch 220/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 5.8265e-04 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9560
# Epoch 221/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 5.9092e-04 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.9547
# Epoch 222/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.0864e-04 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9573
# Epoch 223/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.5267e-04 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9560
# Epoch 224/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 5.3636e-04 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9573
# Epoch 225/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.7133e-04 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.9573
# Epoch 226/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.5860e-04 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9534
# Epoch 227/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.4161e-04 - accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9560
# Epoch 228/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 5.0905e-04 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9573
# Epoch 229/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.5313e-04 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9573
# Epoch 230/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.6971e-04 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9573
# Epoch 231/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.0403e-04 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9560
# Epoch 232/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 4.8113e-04 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9560
# Epoch 233/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.1335e-04 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9560
# Epoch 234/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.4831e-04 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9573
# Epoch 235/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.6335e-04 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9560
# Epoch 236/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 5.3992e-04 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9573
# Epoch 237/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.9467e-04 - accuracy: 1.0000 - val_loss: 0.1643 - val_accuracy: 0.9560
# Epoch 238/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.7074e-04 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9560
# Epoch 239/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 4.5695e-04 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9560
# Epoch 240/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 4.4024e-04 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9560
# Epoch 241/2000
# 49/49 [==============================] - 6s 128ms/step - loss: 4.6064e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9560
# Epoch 242/2000
# 49/49 [==============================] - 6s 128ms/step - loss: 4.0292e-04 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9573
# Epoch 243/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.0123e-04 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9560
# Epoch 244/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.4502e-04 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9573
# Epoch 245/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.3693e-04 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9573
# Epoch 246/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.8423e-04 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9560
# Epoch 247/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.2367e-04 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9573
# Epoch 248/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.9081e-04 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9573
# Epoch 249/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 3.5132e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9573
# Epoch 250/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.6894e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9573
# Epoch 251/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.9095e-04 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9573
# Epoch 252/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.8824e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9573
# Epoch 253/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 3.8640e-04 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9573
# Epoch 254/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.6551e-04 - accuracy: 1.0000 - val_loss: 0.1666 - val_accuracy: 0.9573
# Epoch 255/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.5348e-04 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9573
# Epoch 256/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 3.6398e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9573
# Epoch 257/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 4.0562e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9560
# Epoch 258/2000
# 49/49 [==============================] - 6s 128ms/step - loss: 3.4458e-04 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9560
# Epoch 259/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 3.7005e-04 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9560
# Epoch 260/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.5826e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9573
# Epoch 261/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.3901e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9573
# Epoch 262/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.3575e-04 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9573
# Epoch 263/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.4253e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9573
# Epoch 264/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.4200e-04 - accuracy: 1.0000 - val_loss: 0.1698 - val_accuracy: 0.9547
# Epoch 265/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.2135e-04 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9560
# Epoch 266/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.5409e-04 - accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.9560
# Epoch 267/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.8968e-04 - accuracy: 1.0000 - val_loss: 0.1704 - val_accuracy: 0.9573
# Epoch 268/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.0339e-04 - accuracy: 1.0000 - val_loss: 0.1713 - val_accuracy: 0.9573
# Epoch 269/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.7483e-04 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9560
# Epoch 270/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.7750e-04 - accuracy: 1.0000 - val_loss: 0.1721 - val_accuracy: 0.9573
# Epoch 271/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.0300e-04 - accuracy: 1.0000 - val_loss: 0.1717 - val_accuracy: 0.9560
# Epoch 272/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.9573e-04 - accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 0.9573
# Epoch 273/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.0858e-04 - accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 0.9573
# Epoch 274/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.8649e-04 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9560
# Epoch 275/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.8265e-04 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9560
# Epoch 276/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 3.1899e-04 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9547
# Epoch 277/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.9526e-04 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9560
# Epoch 278/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.7309e-04 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9573
# Epoch 279/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.6033e-04 - accuracy: 1.0000 - val_loss: 0.1719 - val_accuracy: 0.9573
# Epoch 280/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.5939e-04 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.9547
# Epoch 281/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.5750e-04 - accuracy: 1.0000 - val_loss: 0.1720 - val_accuracy: 0.9560
# Epoch 282/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.5501e-04 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.9573
# Epoch 283/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.5420e-04 - accuracy: 1.0000 - val_loss: 0.1739 - val_accuracy: 0.9573
# Epoch 284/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.3478e-04 - accuracy: 1.0000 - val_loss: 0.1735 - val_accuracy: 0.9560
# Epoch 285/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 2.3724e-04 - accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9573
# Epoch 286/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.3830e-04 - accuracy: 1.0000 - val_loss: 0.1745 - val_accuracy: 0.9560
# Epoch 287/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.2507e-04 - accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9573
# Epoch 288/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.3876e-04 - accuracy: 1.0000 - val_loss: 0.1757 - val_accuracy: 0.9573
# Epoch 289/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.4018e-04 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9547
# Epoch 290/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.4902e-04 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9547
# Epoch 291/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.2707e-04 - accuracy: 1.0000 - val_loss: 0.1749 - val_accuracy: 0.9573
# Epoch 292/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.2599e-04 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.9560
# Epoch 293/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.3970e-04 - accuracy: 1.0000 - val_loss: 0.1748 - val_accuracy: 0.9547
# Epoch 294/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 2.2068e-04 - accuracy: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9573
# Epoch 295/2000
# 49/49 [==============================] - 6s 124ms/step - loss: 2.2197e-04 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9560
# Epoch 296/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.3037e-04 - accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9573
# Epoch 297/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.1099e-04 - accuracy: 1.0000 - val_loss: 0.1773 - val_accuracy: 0.9573
# Epoch 298/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.0164e-04 - accuracy: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9560
# Epoch 299/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.9664e-04 - accuracy: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9560
# Epoch 300/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 2.0613e-04 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9573
# Epoch 301/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 2.2057e-04 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9560
# Epoch 302/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.9139e-04 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9573
# Epoch 303/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 1.9680e-04 - accuracy: 1.0000 - val_loss: 0.1772 - val_accuracy: 0.9560
# Epoch 304/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.7781e-04 - accuracy: 1.0000 - val_loss: 0.1778 - val_accuracy: 0.9560
# Epoch 305/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 2.0233e-04 - accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9573
# Epoch 306/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 1.8281e-04 - accuracy: 1.0000 - val_loss: 0.1781 - val_accuracy: 0.9560
# Epoch 307/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 1.9848e-04 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9573
# Epoch 308/2000
# 49/49 [==============================] - 6s 127ms/step - loss: 1.7409e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9560
# Epoch 309/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.6814e-04 - accuracy: 1.0000 - val_loss: 0.1794 - val_accuracy: 0.9560
# Epoch 310/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.7162e-04 - accuracy: 1.0000 - val_loss: 0.1789 - val_accuracy: 0.9560
# Epoch 311/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.8828e-04 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 0.9560
# Epoch 312/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.7051e-04 - accuracy: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9560
# Epoch 313/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 1.6969e-04 - accuracy: 1.0000 - val_loss: 0.1789 - val_accuracy: 0.9560
# Epoch 314/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.6966e-04 - accuracy: 1.0000 - val_loss: 0.1818 - val_accuracy: 0.9573
# Epoch 315/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.6220e-04 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9547
# Epoch 316/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 1.7133e-04 - accuracy: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9573
# Epoch 317/2000
# 49/49 [==============================] - 6s 126ms/step - loss: 1.6751e-04 - accuracy: 1.0000 - val_loss: 0.1797 - val_accuracy: 0.9573
# Epoch 318/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.5194e-04 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9573
# Epoch 319/2000
# 49/49 [==============================] - 6s 125ms/step - loss: 1.6350e-04 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9573
# Epoch 320/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1791e-08 - accuracy: 1.0000 - val_loss: 0.3301 - val_accuracy: 0.9599
# Epoch 1900/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 6.0933e-08 - accuracy: 1.0000 - val_loss: 0.3295 - val_accuracy: 0.9599
# Epoch 1901/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.8184e-08 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.9599
# Epoch 1902/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6398e-08 - accuracy: 1.0000 - val_loss: 0.3299 - val_accuracy: 0.9599
# Epoch 1903/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.7298e-08 - accuracy: 1.0000 - val_loss: 0.3298 - val_accuracy: 0.9599
# Epoch 1904/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9210e-08 - accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.9599
# Epoch 1905/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.7592e-08 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9599
# Epoch 1906/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.3885e-08 - accuracy: 1.0000 - val_loss: 0.3296 - val_accuracy: 0.9599
# Epoch 1907/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.6836e-08 - accuracy: 1.0000 - val_loss: 0.3299 - val_accuracy: 0.9599
# Epoch 1908/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.6682e-08 - accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.9599
# Epoch 1909/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.5541e-08 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9599
# Epoch 1910/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.3577e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1911/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1598e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1912/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5551e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1913/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.5257e-08 - accuracy: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.9599
# Epoch 1914/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.4193e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1915/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9826e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1916/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.8863e-08 - accuracy: 1.0000 - val_loss: 0.3306 - val_accuracy: 0.9599
# Epoch 1917/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9403e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1918/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0943e-08 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9599
# Epoch 1919/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6822e-08 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9599
# Epoch 1920/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0211e-08 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9599
# Epoch 1921/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.9032e-08 - accuracy: 1.0000 - val_loss: 0.3302 - val_accuracy: 0.9599
# Epoch 1922/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0134e-08 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.9599
# Epoch 1923/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9133e-08 - accuracy: 1.0000 - val_loss: 0.3306 - val_accuracy: 0.9599
# Epoch 1924/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6090e-08 - accuracy: 1.0000 - val_loss: 0.3310 - val_accuracy: 0.9599
# Epoch 1925/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0982e-08 - accuracy: 1.0000 - val_loss: 0.3309 - val_accuracy: 0.9599
# Epoch 1926/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.8993e-08 - accuracy: 1.0000 - val_loss: 0.3308 - val_accuracy: 0.9599
# Epoch 1927/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1097e-08 - accuracy: 1.0000 - val_loss: 0.3309 - val_accuracy: 0.9599
# Epoch 1928/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 6.7057e-08 - accuracy: 1.0000 - val_loss: 0.3297 - val_accuracy: 0.9599
# Epoch 1929/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.3986e-08 - accuracy: 1.0000 - val_loss: 0.3298 - val_accuracy: 0.9599
# Epoch 1930/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.4819e-08 - accuracy: 1.0000 - val_loss: 0.3298 - val_accuracy: 0.9599
# Epoch 1931/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0019e-08 - accuracy: 1.0000 - val_loss: 0.3302 - val_accuracy: 0.9599
# Epoch 1932/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0443e-08 - accuracy: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.9599
# Epoch 1933/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.6080e-08 - accuracy: 1.0000 - val_loss: 0.3311 - val_accuracy: 0.9599
# Epoch 1934/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.0428e-08 - accuracy: 1.0000 - val_loss: 0.3313 - val_accuracy: 0.9599
# Epoch 1935/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.7592e-08 - accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.9599
# Epoch 1936/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.6258e-08 - accuracy: 1.0000 - val_loss: 0.3320 - val_accuracy: 0.9599
# Epoch 1937/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.4217e-08 - accuracy: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.9599
# Epoch 1938/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6013e-08 - accuracy: 1.0000 - val_loss: 0.3317 - val_accuracy: 0.9599
# Epoch 1939/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.4987e-08 - accuracy: 1.0000 - val_loss: 0.3314 - val_accuracy: 0.9599
# Epoch 1940/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.6465e-08 - accuracy: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.9599
# Epoch 1941/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.1482e-08 - accuracy: 1.0000 - val_loss: 0.3318 - val_accuracy: 0.9599
# Epoch 1942/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9248e-08 - accuracy: 1.0000 - val_loss: 0.3317 - val_accuracy: 0.9599
# Epoch 1943/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.3009e-08 - accuracy: 1.0000 - val_loss: 0.3319 - val_accuracy: 0.9599
# Epoch 1944/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.7169e-08 - accuracy: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.9599
# Epoch 1945/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6283e-08 - accuracy: 1.0000 - val_loss: 0.3319 - val_accuracy: 0.9599
# Epoch 1946/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1714e-08 - accuracy: 1.0000 - val_loss: 0.3322 - val_accuracy: 0.9599
# Epoch 1947/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5898e-08 - accuracy: 1.0000 - val_loss: 0.3322 - val_accuracy: 0.9599
# Epoch 1948/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9403e-08 - accuracy: 1.0000 - val_loss: 0.3323 - val_accuracy: 0.9599
# Epoch 1949/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9788e-08 - accuracy: 1.0000 - val_loss: 0.3327 - val_accuracy: 0.9599
# Epoch 1950/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5705e-08 - accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.9599
# Epoch 1951/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5859e-08 - accuracy: 1.0000 - val_loss: 0.3330 - val_accuracy: 0.9599
# Epoch 1952/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1521e-08 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9599
# Epoch 1953/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.4256e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9599
# Epoch 1954/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.8979e-08 - accuracy: 1.0000 - val_loss: 0.3332 - val_accuracy: 0.9599
# Epoch 1955/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.1343e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9599
# Epoch 1956/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1097e-08 - accuracy: 1.0000 - val_loss: 0.3330 - val_accuracy: 0.9586
# Epoch 1957/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.4434e-08 - accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.9599
# Epoch 1958/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.3779e-08 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9599
# Epoch 1959/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.3384e-08 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9599
# Epoch 1960/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6052e-08 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9599
# Epoch 1961/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.2393e-08 - accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.9599
# Epoch 1962/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.4511e-08 - accuracy: 1.0000 - val_loss: 0.3326 - val_accuracy: 0.9599
# Epoch 1963/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.7530e-08 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9599
# Epoch 1964/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 6.4207e-08 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9599
# Epoch 1965/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9171e-08 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 0.9586
# Epoch 1966/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0520e-08 - accuracy: 1.0000 - val_loss: 0.3336 - val_accuracy: 0.9586
# Epoch 1967/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0481e-08 - accuracy: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.9586
# Epoch 1968/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.5295e-08 - accuracy: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.9586
# Epoch 1969/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6013e-08 - accuracy: 1.0000 - val_loss: 0.3343 - val_accuracy: 0.9586
# Epoch 1970/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.4795e-08 - accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.9586
# Epoch 1971/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9171e-08 - accuracy: 1.0000 - val_loss: 0.3339 - val_accuracy: 0.9599
# Epoch 1972/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.1059e-08 - accuracy: 1.0000 - val_loss: 0.3336 - val_accuracy: 0.9586
# Epoch 1973/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 5.4270e-08 - accuracy: 1.0000 - val_loss: 0.3343 - val_accuracy: 0.9599
# Epoch 1974/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.4324e-08 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9586
# Epoch 1975/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.5243e-08 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9586
# Epoch 1976/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.8492e-08 - accuracy: 1.0000 - val_loss: 0.3325 - val_accuracy: 0.9599
# Epoch 1977/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.1791e-08 - accuracy: 1.0000 - val_loss: 0.3328 - val_accuracy: 0.9586
# Epoch 1978/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.2022e-08 - accuracy: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9586
# Epoch 1979/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.3524e-08 - accuracy: 1.0000 - val_loss: 0.3331 - val_accuracy: 0.9599
# Epoch 1980/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 2.8194e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9599
# Epoch 1981/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.1937e-08 - accuracy: 1.0000 - val_loss: 0.3339 - val_accuracy: 0.9586
# Epoch 1982/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9980e-08 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.9586
# Epoch 1983/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.2407e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9586
# Epoch 1984/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.4718e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9586
# Epoch 1985/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.1136e-08 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 0.9586
# Epoch 1986/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.7799e-08 - accuracy: 1.0000 - val_loss: 0.3336 - val_accuracy: 0.9586
# Epoch 1987/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.3139e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9599
# Epoch 1988/2000
# 49/49 [==============================] - 7s 130ms/step - loss: 3.9634e-08 - accuracy: 1.0000 - val_loss: 0.3332 - val_accuracy: 0.9599
# Epoch 1989/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.4472e-08 - accuracy: 1.0000 - val_loss: 0.3333 - val_accuracy: 0.9599
# Epoch 1990/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.8594e-08 - accuracy: 1.0000 - val_loss: 0.3335 - val_accuracy: 0.9599
# Epoch 1991/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.9032e-08 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.9586
# Epoch 1992/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.2046e-08 - accuracy: 1.0000 - val_loss: 0.3337 - val_accuracy: 0.9586
# Epoch 1993/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 1.0753e-07 - accuracy: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.9599
# Epoch 1994/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 6.1858e-08 - accuracy: 1.0000 - val_loss: 0.3304 - val_accuracy: 0.9599
# Epoch 1995/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.4410e-08 - accuracy: 1.0000 - val_loss: 0.3307 - val_accuracy: 0.9599
# Epoch 1996/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.6013e-08 - accuracy: 1.0000 - val_loss: 0.3310 - val_accuracy: 0.9599
# Epoch 1997/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 4.0635e-08 - accuracy: 1.0000 - val_loss: 0.3309 - val_accuracy: 0.9599
# Epoch 1998/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.8170e-08 - accuracy: 1.0000 - val_loss: 0.3310 - val_accuracy: 0.9599
# Epoch 1999/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.9711e-08 - accuracy: 1.0000 - val_loss: 0.3311 - val_accuracy: 0.9599
# Epoch 2000/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 3.1160e-08 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9599
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 316ms/step - loss: 1.2911 - accuracy: 0.8551
# test_indoor_ds_results:test loss, test acc: [1.2910542488098145, 0.8550724387168884]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 418ms/step - loss: 2.1298 - accuracy: 0.8089
# test_outdoor_ds_results:test loss, test acc: [2.12978196144104, 0.808917224407196]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 7s 170ms/step - loss: 2.3844 - accuracy: 0.7788
# test_belt_ds_results:test loss, test acc: [2.3844025135040283, 0.7787851095199585]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_NASNetMobile/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 6s 105ms/step - loss: 0.6036 - accuracy: 0.8484
# 50/50 [==============================] - 5s 105ms/step - loss: 0.9545 - accuracy: 0.8131
# 35/35 [==============================] - 4s 105ms/step - loss: 1.1161 - accuracy: 0.7797
# Epoch200
#  test_indoor_acc=0.8483834862709045
#  test_outdoor_acc=0.8130573034286499
#  test_belt_acc=0.779691755771637
# 29/29 [==============================] - 6s 104ms/step - loss: 0.7616 - accuracy: 0.8523
# 50/50 [==============================] - 5s 106ms/step - loss: 1.2345 - accuracy: 0.8131
# 35/35 [==============================] - 4s 104ms/step - loss: 1.4201 - accuracy: 0.7811
# Epoch400
#  test_indoor_acc=0.8522853851318359
#  test_outdoor_acc=0.8130573034286499
#  test_belt_acc=0.7810516953468323
# 29/29 [==============================] - 6s 106ms/step - loss: 0.9119 - accuracy: 0.8567
# 50/50 [==============================] - 5s 107ms/step - loss: 1.4912 - accuracy: 0.8127
# 35/35 [==============================] - 4s 106ms/step - loss: 1.7067 - accuracy: 0.7811
# Epoch600
#  test_indoor_acc=0.8567447066307068
#  test_outdoor_acc=0.812738835811615
#  test_belt_acc=0.7810516953468323
# 29/29 [==============================] - 6s 104ms/step - loss: 1.0434 - accuracy: 0.8545
# 50/50 [==============================] - 5s 105ms/step - loss: 1.7192 - accuracy: 0.8096
# 35/35 [==============================] - 4s 104ms/step - loss: 1.9267 - accuracy: 0.7797
# Epoch800
#  test_indoor_acc=0.8545150756835938
#  test_outdoor_acc=0.8095541596412659
#  test_belt_acc=0.779691755771637
# 29/29 [==============================] - 6s 105ms/step - loss: 1.1200 - accuracy: 0.8540
# 50/50 [==============================] - 5s 105ms/step - loss: 1.8481 - accuracy: 0.8086
# 35/35 [==============================] - 4s 104ms/step - loss: 2.0785 - accuracy: 0.7806
# Epoch1000
#  test_indoor_acc=0.8539576530456543
#  test_outdoor_acc=0.8085986971855164
#  test_belt_acc=0.7805983424186707
# 29/29 [==============================] - 6s 104ms/step - loss: 1.1885 - accuracy: 0.8551
# 50/50 [==============================] - 5s 106ms/step - loss: 1.9580 - accuracy: 0.8070
# 35/35 [==============================] - 4s 105ms/step - loss: 2.1922 - accuracy: 0.7801
# Epoch1200
#  test_indoor_acc=0.8550724387168884
#  test_outdoor_acc=0.8070063591003418
#  test_belt_acc=0.7801450490951538
# 29/29 [==============================] - 7s 107ms/step - loss: 1.2314 - accuracy: 0.8545
# 50/50 [==============================] - 5s 108ms/step - loss: 2.0272 - accuracy: 0.8083
# 35/35 [==============================] - 4s 107ms/step - loss: 2.2642 - accuracy: 0.77880s - loss: 2.2642 - accuracy: 0.77
# Epoch1400
#  test_indoor_acc=0.8545150756835938
#  test_outdoor_acc=0.8082802295684814
#  test_belt_acc=0.7787851095199585
# 29/29 [==============================] - 6s 107ms/step - loss: 1.2595 - accuracy: 0.8562
# 50/50 [==============================] - 5s 108ms/step - loss: 2.0751 - accuracy: 0.8076
# 35/35 [==============================] - 4s 108ms/step - loss: 2.3223 - accuracy: 0.7779
# Epoch1600
#  test_indoor_acc=0.8561872839927673
#  test_outdoor_acc=0.8076432943344116
#  test_belt_acc=0.7778785228729248
# 29/29 [==============================] - 7s 107ms/step - loss: 1.2804 - accuracy: 0.8545
# 50/50 [==============================] - 5s 108ms/step - loss: 2.1114 - accuracy: 0.8073
# 35/35 [==============================] - 4s 108ms/step - loss: 2.3641 - accuracy: 0.7792
# Epoch1800
#  test_indoor_acc=0.8545150756835938
#  test_outdoor_acc=0.8073248267173767
#  test_belt_acc=0.7792384624481201
# 29/29 [==============================] - 7s 107ms/step - loss: 1.2911 - accuracy: 0.8551
# 50/50 [==============================] - 5s 108ms/step - loss: 2.1298 - accuracy: 0.8089
# 35/35 [==============================] - 4s 107ms/step - loss: 2.3844 - accuracy: 0.7788
# Epoch2000
#  test_indoor_acc=0.8550724387168884
#  test_outdoor_acc=0.808917224407196
#  test_belt_acc=0.7787851095199585

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8168450792630514
# max index -> 2
# The [Epoch] of max acc -> 600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8483834862709045,
#  0.8522853851318359,
#  0.8567447066307068,
#  0.8545150756835938,
#  0.8539576530456543,
#  0.8550724387168884,
#  0.8545150756835938,
#  0.8561872839927673,
#  0.8545150756835938,
#  0.8550724387168884]

# %%
test_outdoor_acc
# Out:
# [0.8130573034286499,
#  0.8130573034286499,
#  0.812738835811615,
#  0.8095541596412659,
#  0.8085986971855164,
#  0.8070063591003418,
#  0.8082802295684814,
#  0.8076432943344116,
#  0.8073248267173767,
#  0.808917224407196]

# %%
test_belt_acc
# Out:
# [0.779691755771637,
#  0.7810516953468323,
#  0.7810516953468323,
#  0.779691755771637,
#  0.7805983424186707,
#  0.7801450490951538,
#  0.7787851095199585,
#  0.7778785228729248,
#  0.7792384624481201,
#  0.7787851095199585]

# %%
test_indoor_loss
# Out:
# [0.6036080718040466,
#  0.7615585923194885,
#  0.9118874073028564,
#  1.0434105396270752,
#  1.1200246810913086,
#  1.1885483264923096,
#  1.2314118146896362,
#  1.259537935256958,
#  1.280378818511963,
#  1.2910542488098145]

# %%
test_outdoor_loss
# Out:
# [0.9544798135757446,
#  1.2344715595245361,
#  1.4912477731704712,
#  1.7191975116729736,
#  1.848055124282837,
#  1.9580003023147583,
#  2.027226448059082,
#  2.075132369995117,
#  2.111401319503784,
#  2.12978196144104]

# %%
test_belt_loss
# Out:
# [1.1161437034606934,
#  1.4200643301010132,
#  1.7066971063613892,
#  1.9267319440841675,
#  2.0785179138183594,
#  2.192232847213745,
#  2.264173746109009,
#  2.3223283290863037,
#  2.3640763759613037,
#  2.3844025135040283]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.nasnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5812
# FP=1328
# acc=0.8140056022408964
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 90.65420560747664%
# 2-BloodSecretionWaste acc = 63.74639769452449%
# 3-LabWardWaste acc = 77.27952167414051%
# 4-VaccineOtherWaste acc = 89.95796356842597%
#
#
#
# all_avg_eachclass = 80.4095221361419%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1746,   97,   34,   49],
#        [ 485, 1106,   66,   78],
#        [  81,  101, 1034,  122],
#        [  17,   99,   99, 1926]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[90.65420561,  5.03634476,  1.76531672,  2.54413292],
#        [27.95389049, 63.74639769,  3.80403458,  4.49567723],
#        [ 6.05381166,  7.54857997, 77.27952167,  9.1180867 ],
#        [ 0.79402149,  4.62400747,  4.62400747, 89.95796357]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
