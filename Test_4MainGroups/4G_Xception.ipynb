# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.xception import Xception,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.Xception(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              20861480
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 22,963,756
# Trainable params: 2,102,276
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_Xception/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 50s 476ms/step - loss: 0.3919 - accuracy: 0.8569 - val_loss: 0.1782 - val_accuracy: 0.9314
# Epoch 2/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.1327 - accuracy: 0.9515 - val_loss: 0.1239 - val_accuracy: 0.9483
# Epoch 3/2000
# 49/49 [==============================] - 17s 355ms/step - loss: 0.0679 - accuracy: 0.9796 - val_loss: 0.0979 - val_accuracy: 0.9651
# Epoch 4/2000
# 49/49 [==============================] - 17s 355ms/step - loss: 0.0421 - accuracy: 0.9897 - val_loss: 0.1061 - val_accuracy: 0.9612
# Epoch 5/2000
# 49/49 [==============================] - 17s 355ms/step - loss: 0.0286 - accuracy: 0.9935 - val_loss: 0.1307 - val_accuracy: 0.9508
# Epoch 6/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0290 - accuracy: 0.9922 - val_loss: 0.1104 - val_accuracy: 0.9521
# Epoch 7/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 0.0228 - accuracy: 0.9939 - val_loss: 0.0971 - val_accuracy: 0.9638
# Epoch 8/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 0.0133 - accuracy: 0.9981 - val_loss: 0.0855 - val_accuracy: 0.9702
# Epoch 9/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.0931 - val_accuracy: 0.9715
# Epoch 10/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9702
# Epoch 11/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9702
# Epoch 12/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9715
# Epoch 13/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0862 - val_accuracy: 0.9690
# Epoch 14/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9702
# Epoch 15/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9715
# Epoch 16/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9715
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 17/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 9.9765e-04 - accuracy: 1.0000 - val_loss: 0.0864 - val_accuracy: 0.9715
# Epoch 18/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.4598e-04 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9715
# Epoch 19/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.6756e-04 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9715
# Epoch 20/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.4745e-04 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9715
# Epoch 21/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.3713e-04 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9715
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.4738e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9715
# Epoch 23/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.7666e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 24/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.8648e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 25/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 7.1348e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 26/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.5295e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 27/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.7331e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 28/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.9720e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 29/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.2415e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 30/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.5861e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 31/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.3459e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 32/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.8614e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 33/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.6529e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 34/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.8279e-04 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9715
# Epoch 35/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.4485e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 36/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.9014e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 37/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.4248e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 38/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.5314e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 39/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.5730e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 40/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.1338e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9715
# Epoch 41/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 7.4415e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 42/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.6414e-04 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9715
# Epoch 43/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.6438e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9715
# Epoch 44/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.5656e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9715
# Epoch 45/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.2684e-04 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 0.9715
# Epoch 46/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.4908e-04 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9728
# Epoch 47/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.5549e-04 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9715
# Epoch 48/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.1750e-04 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9715
# Epoch 49/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.1889e-04 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9715
# Epoch 50/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.1635e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9715
# Epoch 51/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.5109e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9715
# Epoch 52/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.2331e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9715
# Epoch 53/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.9941e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9715
# Epoch 54/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.4819e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9715
# Epoch 55/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.8556e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9715
# Epoch 56/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.8613e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9715
# Epoch 57/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.3846e-04 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9715
# Epoch 58/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.3480e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9715
# Epoch 59/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.5284e-04 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9715
# Epoch 60/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.4206e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9715
# Epoch 61/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.1717e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9715
# Epoch 62/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.2679e-04 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9715
# Epoch 63/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.0564e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9715
# Epoch 64/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.6278e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9715
# Epoch 65/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.2409e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9715
# Epoch 66/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.8632e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9715
# Epoch 67/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.8425e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9715
# Epoch 68/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.3063e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9728
# Epoch 69/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.4295e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9728
# Epoch 70/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.3195e-04 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 0.9728
# Epoch 71/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.7466e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9728
# Epoch 72/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.1298e-04 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9715
# Epoch 73/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.2578e-04 - accuracy: 1.0000 - val_loss: 0.0893 - val_accuracy: 0.9728
# Epoch 74/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.0006e-04 - accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 0.9728
# Epoch 75/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.2851e-04 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9728
# Epoch 76/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.7076e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9715
# Epoch 77/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.9888e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9728
# Epoch 78/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.3598e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 79/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.5835e-04 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9728
# Epoch 80/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.9689e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9715
# Epoch 81/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.8296e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9715
# Epoch 82/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.9548e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9715
# Epoch 83/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.4566e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 84/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.3554e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 85/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.8266e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 86/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.4006e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 87/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.0611e-04 - accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 0.9728
# Epoch 88/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.4176e-04 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 89/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.2867e-04 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9728
# Epoch 90/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.5665e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9728
# Epoch 91/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.0618e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9728
# Epoch 92/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.1198e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9728
# Epoch 93/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.9045e-04 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 0.9728
# Epoch 94/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.2442e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9728
# Epoch 95/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.5991e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9715
# Epoch 96/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.9704e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9728
# Epoch 97/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.1855e-04 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9728
# Epoch 98/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.8916e-04 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9728
# Epoch 99/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.1859e-04 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9715
# Epoch 100/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.1707e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9728
# Epoch 101/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.7814e-04 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9715
# Epoch 102/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.4965e-04 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9715
# Epoch 103/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.8785e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9715
# Epoch 104/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.9812e-04 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9715
# Epoch 105/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.0070e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9728
# Epoch 106/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.7340e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9728
# Epoch 107/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.9579e-04 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 0.9728
# Epoch 108/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.9586e-04 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9715
# Epoch 109/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.7906e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9728
# Epoch 110/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.9725e-04 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9728
# Epoch 111/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.8982e-04 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9715
# Epoch 112/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.0240e-04 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9715
# Epoch 113/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.7841e-04 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9715
# Epoch 114/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.5609e-04 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9728
# Epoch 115/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.4360e-04 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9728
# Epoch 116/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.7600e-04 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9728
# Epoch 117/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.4011e-04 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9728
# Epoch 118/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.2457e-04 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9728
# Epoch 119/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.3990e-04 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9728
# Epoch 120/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.4222e-04 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9728
# Epoch 121/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.1802e-04 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9728
# Epoch 122/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.2483e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9728
# Epoch 123/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.0746e-04 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9715
# Epoch 124/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.3286e-04 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9728
# Epoch 125/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.1031e-04 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9715
# Epoch 126/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.6307e-04 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9715
# Epoch 127/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.1464e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9715
# Epoch 128/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.1838e-04 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9741
# Epoch 129/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.9861e-04 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9715
# Epoch 130/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.9160e-04 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9715
# Epoch 131/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.8650e-04 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9715
# Epoch 132/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.7634e-04 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9715
# Epoch 133/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.8339e-04 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9728
# Epoch 134/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5199e-04 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9715
# Epoch 135/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.6194e-04 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 0.9715
# Epoch 136/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.6044e-04 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9715
# Epoch 137/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.5480e-04 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9715
# Epoch 138/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.7935e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9715
# Epoch 139/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.5431e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9741
# Epoch 140/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5717e-04 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9741
# Epoch 141/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.5890e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9728
# Epoch 142/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.3387e-04 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9715
# Epoch 143/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.7238e-04 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9715
# Epoch 144/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.8664e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9728
# Epoch 145/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2379e-04 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9728
# Epoch 146/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0910e-04 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9728
# Epoch 147/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.4896e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9741
# Epoch 148/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2963e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9741
# Epoch 149/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0525e-04 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9715
# Epoch 150/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1527e-04 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9715
# Epoch 151/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0003e-04 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9715
# Epoch 152/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1144e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9715
# Epoch 153/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0285e-04 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9715
# Epoch 154/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8140e-04 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9715
# Epoch 155/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9403e-04 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 0.9715
# Epoch 156/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9956e-04 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9728
# Epoch 157/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9932e-04 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 0.9728
# Epoch 158/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8099e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9728
# Epoch 159/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1033e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9741
# Epoch 160/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9157e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9741
# Epoch 161/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9571e-04 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 0.9728
# Epoch 162/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7283e-04 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 0.9715
# Epoch 163/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7060e-04 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9741
# Epoch 164/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.5459e-04 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9754
# Epoch 165/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6077e-04 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9754
# Epoch 166/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4068e-04 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 0.9741
# Epoch 167/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7199e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9754
# Epoch 168/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.5102e-04 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9767
# Epoch 169/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3556e-04 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9767
# Epoch 170/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.5274e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9741
# Epoch 171/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4732e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9715
# Epoch 172/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4632e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9741
# Epoch 173/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4075e-04 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9741
# Epoch 174/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3817e-04 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 0.9767
# Epoch 175/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3929e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9741
# Epoch 176/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4099e-04 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9741
# Epoch 177/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.1990e-04 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9741
# Epoch 178/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.1842e-04 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9741
# Epoch 179/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.2077e-04 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9754
# Epoch 180/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.1664e-04 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 0.9767
# Epoch 181/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.0835e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9728
# Epoch 182/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.1211e-04 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9728
# Epoch 183/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.9457e-04 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9741
# Epoch 184/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.0235e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9741
# Epoch 185/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.9752e-04 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9741
# Epoch 186/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.8908e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9741
# Epoch 187/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.0081e-04 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9741
# Epoch 188/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.8250e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9741
# Epoch 189/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.9095e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9741
# Epoch 190/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.7519e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9741
# Epoch 191/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.8033e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9741
# Epoch 192/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.8531e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9741
# Epoch 193/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.7378e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9754
# Epoch 194/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.8482e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9754
# Epoch 195/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.7876e-04 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9754
# Epoch 196/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.8088e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9754
# Epoch 197/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.7881e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9754
# Epoch 198/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.5209e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9754
# Epoch 199/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.7277e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9728
# Epoch 200/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.6346e-04 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9754
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_Xception\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 17s 346ms/step - loss: 1.6408e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9741
# Epoch 202/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 1.5537e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9754
# Epoch 203/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 1.5803e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9741
# Epoch 204/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.4572e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9754
# Epoch 205/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.5504e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9741
# Epoch 206/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.4523e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9754
# Epoch 207/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.5293e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9754
# Epoch 208/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.3283e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9754
# Epoch 209/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.5488e-04 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9754
# Epoch 210/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.4669e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9754
# Epoch 211/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.4333e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9754
# Epoch 212/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.3157e-04 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9754
# Epoch 213/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.4010e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9767
# Epoch 214/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.2648e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9767
# Epoch 215/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.3600e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9741
# Epoch 216/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.3261e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9754
# Epoch 217/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.3248e-04 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9754
# Epoch 218/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.4062e-04 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9741
# Epoch 219/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.2851e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9754
# Epoch 220/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.2026e-04 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9767
# Epoch 221/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1422e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9741
# Epoch 222/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.2343e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9754
# Epoch 223/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1858e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9754
# Epoch 224/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1055e-04 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9754
# Epoch 225/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.0815e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9741
# Epoch 226/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.0315e-04 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9754
# Epoch 227/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.0684e-04 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9754
# Epoch 228/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.0680e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9754
# Epoch 229/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 1.1980e-04 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9767
# Epoch 230/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1311e-04 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 0.9767
# Epoch 231/2000
# 49/49 [==============================] - 17s 346ms/step - loss: 1.0033e-04 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9767
# Epoch 232/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 1.1480e-04 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9767
# Epoch 233/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.7127e-05 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9767
# Epoch 234/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.9712e-05 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9754
# Epoch 235/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.5322e-05 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9754
# Epoch 236/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 1.0121e-04 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9767
# Epoch 237/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.2002e-05 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9741
# Epoch 238/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.1002e-05 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9767
# Epoch 239/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 8.6269e-05 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 0.9754
# Epoch 240/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 8.8269e-05 - accuracy: 1.0000 - val_loss: 0.1005 - val_accuracy: 0.9767
# Epoch 241/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.5116e-05 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9754
# Epoch 242/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.8487e-05 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9754
# Epoch 243/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 8.0428e-05 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9767
# Epoch 244/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 9.3356e-05 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9754
# Epoch 245/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.7522e-05 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9754
# Epoch 246/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 8.8571e-05 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9767
# Epoch 247/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.4532e-05 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9741
# Epoch 248/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.3522e-05 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9754
# Epoch 249/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.9670e-05 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9754
# Epoch 250/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 8.0929e-05 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9754
# Epoch 251/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.8357e-05 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9767
# Epoch 252/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.9841e-05 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9767
# Epoch 253/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.8405e-05 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9767
# Epoch 254/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.9835e-05 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9767
# Epoch 255/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.2844e-05 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9767
# Epoch 256/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.7576e-05 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9767
# Epoch 257/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.4634e-05 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9754
# Epoch 258/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.8326e-05 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9767
# Epoch 259/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 7.0297e-05 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9767
# Epoch 260/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.8279e-05 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9754
# Epoch 261/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.1008e-05 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9754
# Epoch 262/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.1253e-05 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9754
# Epoch 263/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.6476e-05 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9741
# Epoch 264/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.4658e-05 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9767
# Epoch 265/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.5231e-05 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9767
# Epoch 266/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.3306e-05 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9767
# Epoch 267/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.9431e-05 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9767
# Epoch 268/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.7193e-05 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9767
# Epoch 269/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.1309e-05 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9767
# Epoch 270/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.5750e-05 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9767
# Epoch 271/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.7776e-05 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9754
# Epoch 272/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.5264e-05 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9767
# Epoch 273/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 6.4043e-05 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9741
# Epoch 274/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.2289e-05 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9767
# Epoch 275/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.1847e-05 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9767
# Epoch 276/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.0701e-05 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9767
# Epoch 277/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.0545e-05 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9754
# Epoch 278/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.3039e-05 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9741
# Epoch 279/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.5069e-05 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9754
# Epoch 280/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.2641e-05 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9767
# Epoch 281/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.7287e-05 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9741
# Epoch 282/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.7596e-05 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9741
# Epoch 283/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.9534e-05 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9741
# Epoch 284/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 5.0939e-05 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9741
# Epoch 285/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.6969e-05 - accuracy: 1.0000 - val_loss: 0.1046 - val_accuracy: 0.9741
# Epoch 286/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.5524e-05 - accuracy: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9754
# Epoch 287/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.5052e-05 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 0.9741
# Epoch 288/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.7326e-05 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 0.9741
# Epoch 289/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.2032e-05 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9741
# Epoch 290/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.3427e-05 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9754
# Epoch 291/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.0234e-05 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9754
# Epoch 292/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.0010e-05 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9767
# Epoch 293/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.9463e-05 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9754
# Epoch 294/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.4895e-05 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9754
# Epoch 295/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.6821e-05 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9754
# Epoch 296/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.7699e-05 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9741
# Epoch 297/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.9900e-05 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9741
# Epoch 298/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.5353e-05 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9754
# Epoch 299/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.6149e-05 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9767
# Epoch 300/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.1459e-05 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9754
# Epoch 301/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.8344e-05 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9767
# Epoch 302/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.3425e-05 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.9754
# Epoch 303/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.4312e-05 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 0.9754
# Epoch 304/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.0970e-05 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9741
# Epoch 305/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.4161e-05 - accuracy: 1.0000 - val_loss: 0.1080 - val_accuracy: 0.9754
# Epoch 306/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.3904e-05 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 0.9767
# Epoch 307/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.5564e-05 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9754
# Epoch 308/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.4978e-05 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9754
# Epoch 309/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.2899e-05 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 0.9754
# Epoch 310/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.0942e-05 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9767
# Epoch 311/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.2023e-05 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9754
# Epoch 312/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.2535e-05 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9754
# Epoch 313/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 3.2015e-05 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9754
# Epoch 314/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7462e-08 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9728
# Epoch 1900/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0043e-08 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9728
# Epoch 1901/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1507e-08 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9728
# Epoch 1902/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1969e-08 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9728
# Epoch 1903/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.6899e-08 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9728
# Epoch 1904/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1699e-08 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9728
# Epoch 1905/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2970e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1906/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0428e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1907/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0852e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1908/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.7246e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1909/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6538e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1910/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9234e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1911/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8387e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1912/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.9942e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1913/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0428e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1914/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4073e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1915/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1622e-08 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9728
# Epoch 1916/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2624e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1917/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8502e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1918/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6037e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1919/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5705e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1920/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9003e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1921/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1006e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1922/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.0096e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1923/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7886e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1924/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7539e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1925/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.5806e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1926/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6461e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1927/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5821e-08 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9728
# Epoch 1928/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8156e-08 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9728
# Epoch 1929/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.3702e-08 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9728
# Epoch 1930/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8965e-08 - accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9728
# Epoch 1931/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1237e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1932/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9427e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1933/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5474e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1934/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5204e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1935/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9119e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1936/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8810e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1937/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0120e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1938/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6846e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1939/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9042e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1940/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8002e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1941/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8849e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1942/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.3856e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1943/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7771e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1944/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.1584e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1945/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9196e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1946/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0351e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1947/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.4858e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1948/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.7592e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1949/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.2994e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1950/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.3047e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1951/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3534e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1952/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6153e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1953/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0467e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1954/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.8748e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1955/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8579e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1956/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.8286e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1957/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2007e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1958/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.5151e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1959/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 3.1083e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1960/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0390e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1961/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7116e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1962/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7077e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1963/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.1353e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1964/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.6052e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1965/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.4742e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1966/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9773e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1967/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6461e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1968/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6885e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1969/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8425e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1970/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.3741e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1971/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0813e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1972/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.6206e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1973/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2816e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1974/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9427e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1975/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2701e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1976/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9311e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1977/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0736e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1978/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.5859e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1979/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9273e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1980/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8772e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1981/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7771e-08 - accuracy: 1.0000 - val_loss: 0.1761 - val_accuracy: 0.9728
# Epoch 1982/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.3355e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1983/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.9350e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1984/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3303e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1985/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6692e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1986/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8002e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1987/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8579e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1988/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8695e-08 - accuracy: 1.0000 - val_loss: 0.1762 - val_accuracy: 0.9728
# Epoch 1989/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.7385e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1990/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2624e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1991/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.3047e-08 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9728
# Epoch 1992/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8849e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1993/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3842e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1994/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.5999e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1995/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.0967e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1996/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6923e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1997/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.8425e-08 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9728
# Epoch 1998/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.4343e-08 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9728
# Epoch 1999/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.3803e-08 - accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9728
# Epoch 2000/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 2.6885e-08 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9728
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_Xception\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 15s 365ms/step - loss: 0.6254 - accuracy: 0.9052
# test_indoor_ds_results:test loss, test acc: [0.6254028081893921, 0.9052397012710571]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 27s 445ms/step - loss: 1.3659 - accuracy: 0.8742
# test_outdoor_ds_results:test loss, test acc: [1.3659061193466187, 0.8742038011550903]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 12s 296ms/step - loss: 1.7124 - accuracy: 0.8173
# test_belt_ds_results:test loss, test acc: [1.7124383449554443, 0.8173164129257202]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 9s 268ms/step - loss: 0.3341 - accuracy: 0.9080
# 50/50 [==============================] - 14s 273ms/step - loss: 0.7323 - accuracy: 0.8726
# 35/35 [==============================] - 10s 274ms/step - loss: 0.9016 - accuracy: 0.8173
# Epoch200
#  test_indoor_acc=0.9080267548561096
#  test_outdoor_acc=0.8726114630699158
#  test_belt_acc=0.8173164129257202
# 29/29 [==============================] - 9s 270ms/step - loss: 0.4223 - accuracy: 0.9075
# 50/50 [==============================] - 14s 275ms/step - loss: 0.9188 - accuracy: 0.8732
# 35/35 [==============================] - 10s 276ms/step - loss: 1.1462 - accuracy: 0.8182
# Epoch400
#  test_indoor_acc=0.9074693322181702
#  test_outdoor_acc=0.8732483983039856
#  test_belt_acc=0.8182229995727539
# 29/29 [==============================] - 9s 270ms/step - loss: 0.4884 - accuracy: 0.9075
# 50/50 [==============================] - 14s 275ms/step - loss: 1.0676 - accuracy: 0.8752
# 35/35 [==============================] - 10s 276ms/step - loss: 1.3371 - accuracy: 0.8196
# Epoch600
#  test_indoor_acc=0.9074693322181702
#  test_outdoor_acc=0.8751592636108398
#  test_belt_acc=0.8195829391479492
# 29/29 [==============================] - 9s 270ms/step - loss: 0.5400 - accuracy: 0.9058
# 50/50 [==============================] - 14s 275ms/step - loss: 1.1742 - accuracy: 0.8745
# 35/35 [==============================] - 10s 276ms/step - loss: 1.4767 - accuracy: 0.8191
# Epoch800
#  test_indoor_acc=0.9057971239089966
#  test_outdoor_acc=0.8745222687721252
#  test_belt_acc=0.8191296458244324
# 29/29 [==============================] - 9s 271ms/step - loss: 0.5670 - accuracy: 0.9064
# 50/50 [==============================] - 14s 276ms/step - loss: 1.2418 - accuracy: 0.8745
# 35/35 [==============================] - 10s 277ms/step - loss: 1.5540 - accuracy: 0.8173
# Epoch1000
#  test_indoor_acc=0.9063544869422913
#  test_outdoor_acc=0.8745222687721252
#  test_belt_acc=0.8173164129257202
# 29/29 [==============================] - 9s 271ms/step - loss: 0.5858 - accuracy: 0.9052
# 50/50 [==============================] - 14s 275ms/step - loss: 1.2756 - accuracy: 0.8748
# 35/35 [==============================] - 10s 276ms/step - loss: 1.6068 - accuracy: 0.8173
# Epoch1200
#  test_indoor_acc=0.9052397012710571
#  test_outdoor_acc=0.8748407363891602
#  test_belt_acc=0.8173164129257202
# 29/29 [==============================] - 9s 270ms/step - loss: 0.5992 - accuracy: 0.9052
# 50/50 [==============================] - 14s 274ms/step - loss: 1.3089 - accuracy: 0.8745
# 35/35 [==============================] - 10s 275ms/step - loss: 1.6427 - accuracy: 0.8182
# Epoch1400
#  test_indoor_acc=0.9052397012710571
#  test_outdoor_acc=0.8745222687721252
#  test_belt_acc=0.8182229995727539
# 29/29 [==============================] - 9s 270ms/step - loss: 0.6099 - accuracy: 0.9052
# 50/50 [==============================] - 14s 275ms/step - loss: 1.3340 - accuracy: 0.8745
# 35/35 [==============================] - 10s 276ms/step - loss: 1.6726 - accuracy: 0.8173
# Epoch1600
#  test_indoor_acc=0.9052397012710571
#  test_outdoor_acc=0.8745222687721252
#  test_belt_acc=0.8173164129257202
# 29/29 [==============================] - 9s 271ms/step - loss: 0.6204 - accuracy: 0.9058
# 50/50 [==============================] - 14s 275ms/step - loss: 1.3462 - accuracy: 0.8748
# 35/35 [==============================] - 10s 276ms/step - loss: 1.6970 - accuracy: 0.8173
# Epoch1800
#  test_indoor_acc=0.9057971239089966
#  test_outdoor_acc=0.8748407363891602
#  test_belt_acc=0.8173164129257202
# 29/29 [==============================] - 9s 271ms/step - loss: 0.6254 - accuracy: 0.9052
# 50/50 [==============================] - 14s 275ms/step - loss: 1.3659 - accuracy: 0.8742
# 35/35 [==============================] - 10s 276ms/step - loss: 1.7124 - accuracy: 0.8173
# Epoch2000
#  test_indoor_acc=0.9052397012710571
#  test_outdoor_acc=0.8742038011550903
#  test_belt_acc=0.8173164129257202

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8674038449923197
# max index -> 2
# The [Epoch] of max acc -> 600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9080267548561096,
#  0.9074693322181702,
#  0.9074693322181702,
#  0.9057971239089966,
#  0.9063544869422913,
#  0.9052397012710571,
#  0.9052397012710571,
#  0.9052397012710571,
#  0.9057971239089966,
#  0.9052397012710571]

# %%
test_outdoor_acc
# Out:
# [0.8726114630699158,
#  0.8732483983039856,
#  0.8751592636108398,
#  0.8745222687721252,
#  0.8745222687721252,
#  0.8748407363891602,
#  0.8745222687721252,
#  0.8745222687721252,
#  0.8748407363891602,
#  0.8742038011550903]

# %%
test_belt_acc
# Out:
# [0.8173164129257202,
#  0.8182229995727539,
#  0.8195829391479492,
#  0.8191296458244324,
#  0.8173164129257202,
#  0.8173164129257202,
#  0.8182229995727539,
#  0.8173164129257202,
#  0.8173164129257202,
#  0.8173164129257202]

# %%
test_indoor_loss
# Out:
# [0.3341245651245117,
#  0.42229440808296204,
#  0.48839569091796875,
#  0.5399593710899353,
#  0.5670377612113953,
#  0.5858473181724548,
#  0.5992088913917542,
#  0.6099491715431213,
#  0.6203715205192566,
#  0.6254028081893921]

# %%
test_outdoor_loss
# Out:
# [0.7323490381240845,
#  0.9187796115875244,
#  1.0675994157791138,
#  1.1742055416107178,
#  1.2417773008346558,
#  1.275629997253418,
#  1.3088701963424683,
#  1.3339518308639526,
#  1.3462375402450562,
#  1.3659061193466187]

# %%
test_belt_loss
# Out:
# [0.9016346335411072,
#  1.1461970806121826,
#  1.3371491432189941,
#  1.476657509803772,
#  1.5540285110473633,
#  1.6068366765975952,
#  1.6426981687545776,
#  1.6725749969482422,
#  1.6970006227493286,
#  1.7124383449554443]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.xception import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6184
# FP=956
# acc=0.8661064425770308
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 88.47352024922118%
# 2-BloodSecretionWaste acc = 74.69740634005764%
# 3-LabWardWaste acc = 90.13452914798206%
# 4-VaccineOtherWaste acc = 92.38673517048109%
#
#
#
# all_avg_eachclass = 86.4230477269355%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1704,  155,   29,   38],
#        [ 354, 1296,   51,   34],
#        [  43,   56, 1206,   33],
#        [  16,   80,   67, 1978]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[88.47352025,  8.04776739,  1.50571132,  1.97300104],
#        [20.40345821, 74.69740634,  2.93948127,  1.95965418],
#        [ 3.21375187,  4.18535127, 90.13452915,  2.46636771],
#        [ 0.74731434,  3.7365717 ,  3.12937879, 92.38673517]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
