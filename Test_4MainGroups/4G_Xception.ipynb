# %% [markdown]
# # 5G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.xception import Xception,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.Xception(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           block14_sepconv2_act[0][0]
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              20861480
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 22,963,756
# Trainable params: 2,102,276
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_Xception/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 51s 458ms/step - loss: 0.3555 - accuracy: 0.8688 - val_loss: 0.1460 - val_accuracy: 0.9521
# Epoch 2/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 0.1095 - accuracy: 0.9651 - val_loss: 0.1230 - val_accuracy: 0.9483
# Epoch 3/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 0.0641 - accuracy: 0.9806 - val_loss: 0.1027 - val_accuracy: 0.9612
# Epoch 4/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 0.0453 - accuracy: 0.9851 - val_loss: 0.1038 - val_accuracy: 0.9560
# Epoch 5/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0466 - accuracy: 0.9826 - val_loss: 0.1108 - val_accuracy: 0.9586
# Epoch 6/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0336 - accuracy: 0.9890 - val_loss: 0.0926 - val_accuracy: 0.9638
# Epoch 7/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0186 - accuracy: 0.9952 - val_loss: 0.0750 - val_accuracy: 0.9690
# Epoch 8/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0104 - accuracy: 0.9977 - val_loss: 0.0855 - val_accuracy: 0.9702
# Epoch 9/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9702
# Epoch 10/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9702
# Epoch 11/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9728
# Epoch 12/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9728
# Epoch 13/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9728
# Epoch 14/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 8.8537e-04 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9728
# Epoch 15/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 7.9992e-04 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9728
# Epoch 16/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 7.1403e-04 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9715
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 17/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 6.9665e-04 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9728
# Epoch 18/2000
# 49/49 [==============================] - 17s 341ms/step - loss: 6.5441e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9741
# Epoch 19/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 6.2093e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9728
# Epoch 20/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.8372e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 21/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.6061e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 22/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.6310e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 23/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.3787e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9741
# Epoch 24/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.9788e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9741
# Epoch 25/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.6680e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9728
# Epoch 26/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.5710e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9728
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 27/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.5276e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9741
# Epoch 28/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.5707e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 29/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.9445e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 30/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.7667e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9741
# Epoch 31/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2269e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9741
# Epoch 32/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.4077e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9741
# Epoch 33/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2947e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 34/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.8227e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9741
# Epoch 35/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.4271e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 36/2000
# 49/49 [==============================] - 17s 341ms/step - loss: 5.5968e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 37/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.3741e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 38/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2653e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 39/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2520e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 40/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.1639e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 41/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2386e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 42/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.5058e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 43/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.6012e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9741
# Epoch 44/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.3423e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 45/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9091e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 46/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.4839e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 47/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.6077e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9741
# Epoch 48/2000
# 49/49 [==============================] - 17s 342ms/step - loss: 5.3060e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 49/2000
# 49/49 [==============================] - 17s 341ms/step - loss: 5.7020e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 50/2000
# 49/49 [==============================] - 16s 333ms/step - loss: 5.2416e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 51/2000
# 49/49 [==============================] - 16s 319ms/step - loss: 5.6051e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 52/2000
# 49/49 [==============================] - 16s 332ms/step - loss: 5.3399e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 53/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 5.0039e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 54/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.6684e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 55/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2830e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 56/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0433e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 57/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.1688e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 58/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.1926e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 59/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2687e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 60/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.4177e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9741
# Epoch 61/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.8319e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9741
# Epoch 62/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0748e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 63/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.1907e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 64/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.0055e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 65/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.8327e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 66/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.3598e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 67/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9941e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 68/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0353e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 69/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0431e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 70/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0138e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 71/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9716e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 72/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.5715e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 73/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0151e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 74/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2207e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 75/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.3242e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 76/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0355e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 77/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2408e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 78/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.5649e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 79/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9969e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
# Epoch 80/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.7130e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 81/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0871e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 82/2000
# 49/49 [==============================] - 17s 342ms/step - loss: 4.7987e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 83/2000
# 49/49 [==============================] - 17s 343ms/step - loss: 4.9517e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 84/2000
# 49/49 [==============================] - 17s 341ms/step - loss: 5.2003e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9741
# Epoch 85/2000
# 49/49 [==============================] - 17s 341ms/step - loss: 4.9980e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 86/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.4174e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 87/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.4764e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 88/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.6536e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 89/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9342e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 90/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.6140e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 91/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.5906e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9741
# Epoch 92/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0154e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 93/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9921e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9741
# Epoch 94/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.6847e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9741
# Epoch 95/2000
# 49/49 [==============================] - 17s 342ms/step - loss: 4.6220e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9741
# Epoch 96/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.2175e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9741
# Epoch 97/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.6907e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 98/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.6242e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 99/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.3635e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 100/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.6362e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9741
# Epoch 101/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.4616e-04 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9741
# Epoch 102/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.3210e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9741
# Epoch 103/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.1571e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 104/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.3193e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9741
# Epoch 105/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.1951e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9741
# Epoch 106/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.2237e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9741
# Epoch 107/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.9577e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9741
# Epoch 108/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.1764e-04 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9741
# Epoch 109/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.0057e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 110/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.3306e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9741
# Epoch 111/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.0274e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9741
# Epoch 112/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.3053e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 113/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.0964e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9741
# Epoch 114/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.7733e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9741
# Epoch 115/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.7133e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9741
# Epoch 116/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.6805e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9741
# Epoch 117/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.7078e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9741
# Epoch 118/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.6457e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9741
# Epoch 119/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.1625e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9741
# Epoch 120/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.9021e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9741
# Epoch 121/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.8083e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 122/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.9194e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 123/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.6356e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 124/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.4173e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 125/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.6432e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9741
# Epoch 126/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.6197e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9741
# Epoch 127/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.6775e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9728
# Epoch 128/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.4626e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9741
# Epoch 129/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.5510e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 130/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.5048e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 131/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.3860e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9741
# Epoch 132/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.2257e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 133/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.4554e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 134/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.6585e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 135/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.3326e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 136/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.3009e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9728
# Epoch 137/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.3523e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9741
# Epoch 138/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.1294e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9741
# Epoch 139/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.1163e-04 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9741
# Epoch 140/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.2288e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 141/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.7908e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9741
# Epoch 142/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.3212e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9741
# Epoch 143/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.1565e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 144/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.1416e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9741
# Epoch 145/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.9925e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9741
# Epoch 146/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.9529e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9741
# Epoch 147/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7146e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 148/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8567e-04 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9741
# Epoch 149/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.0510e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9728
# Epoch 150/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7222e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 151/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6866e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 152/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7651e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9741
# Epoch 153/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6611e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9741
# Epoch 154/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4153e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9741
# Epoch 155/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6668e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9741
# Epoch 156/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8397e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9741
# Epoch 157/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3678e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9741
# Epoch 158/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4261e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9741
# Epoch 159/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.8549e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9728
# Epoch 160/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7618e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9728
# Epoch 161/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3438e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9728
# Epoch 162/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3269e-04 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9741
# Epoch 163/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.1515e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 164/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6802e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 165/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.3970e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9741
# Epoch 166/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3462e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 167/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3421e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9741
# Epoch 168/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2983e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 169/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3905e-04 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9741
# Epoch 170/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.2136e-04 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9728
# Epoch 171/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.1415e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 172/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.0156e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9741
# Epoch 173/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.0419e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9741
# Epoch 174/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.1029e-04 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9741
# Epoch 175/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.0346e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9741
# Epoch 176/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.1019e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9741
# Epoch 177/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.9170e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9741
# Epoch 178/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.8683e-04 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9741
# Epoch 179/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.8054e-04 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9741
# Epoch 180/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.8732e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9741
# Epoch 181/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.8007e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9741
# Epoch 182/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.7698e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 183/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.8023e-04 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 184/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.6920e-04 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9741
# Epoch 185/2000
# 49/49 [==============================] - 17s 338ms/step - loss: 1.7289e-04 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9741
# Epoch 186/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.8064e-04 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 0.9741
# Epoch 187/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 1.7450e-04 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9741
# Epoch 188/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.7214e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9741
# Epoch 189/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.6853e-04 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 0.9728
# Epoch 190/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 1.6935e-04 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9741
# Epoch 191/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 1.7420e-04 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9741
# Epoch 192/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.4932e-04 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9741
# Epoch 193/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.6001e-04 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9728
# Epoch 194/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.6115e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9741
# Epoch 195/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.5757e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9741
# Epoch 196/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.5762e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9741
# Epoch 197/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.5742e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9728
# Epoch 198/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.4510e-04 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9728
# Epoch 199/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.4414e-04 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9728
# Epoch 200/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 1.3989e-04 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9741
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_Xception\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 17s 337ms/step - loss: 1.4832e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9741
# Epoch 202/2000
# 49/49 [==============================] - 17s 338ms/step - loss: 1.3767e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9741
# Epoch 203/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.3839e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9741
# Epoch 204/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.3996e-04 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9741
# Epoch 205/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.4500e-04 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 0.9741
# Epoch 206/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.2648e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9741
# Epoch 207/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.3472e-04 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9741
# Epoch 208/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.4595e-04 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9741
# Epoch 209/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.4005e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9741
# Epoch 210/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.2162e-04 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9741
# Epoch 211/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.0825e-04 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9741
# Epoch 212/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.1354e-04 - accuracy: 1.0000 - val_loss: 0.0786 - val_accuracy: 0.9741
# Epoch 213/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.2367e-04 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9741
# Epoch 214/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.2167e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9741
# Epoch 215/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.0482e-04 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9741
# Epoch 216/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.1355e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9741
# Epoch 217/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.1500e-04 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9741
# Epoch 218/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.0824e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9741
# Epoch 219/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 9.9034e-05 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9741
# Epoch 220/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.0800e-04 - accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 0.9741
# Epoch 221/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.1574e-04 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9741
# Epoch 222/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 1.0205e-04 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9741
# Epoch 223/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.3223e-04 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9741
# Epoch 224/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.5419e-05 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9741
# Epoch 225/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.5587e-05 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9741
# Epoch 226/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.4914e-05 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9741
# Epoch 227/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.7354e-05 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9741
# Epoch 228/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 1.0238e-04 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9741
# Epoch 229/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.3988e-05 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9741
# Epoch 230/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.2395e-05 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9741
# Epoch 231/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.1384e-05 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9741
# Epoch 232/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.5114e-05 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9728
# Epoch 233/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 7.9742e-05 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9741
# Epoch 234/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 9.6143e-05 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9741
# Epoch 235/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 8.4617e-05 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9741
# Epoch 236/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 8.7256e-05 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9728
# Epoch 237/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 8.2373e-05 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9728
# Epoch 238/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 8.0399e-05 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9741
# Epoch 239/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 8.1607e-05 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9741
# Epoch 240/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 8.2459e-05 - accuracy: 1.0000 - val_loss: 0.0805 - val_accuracy: 0.9741
# Epoch 241/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 7.4996e-05 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 0.9728
# Epoch 242/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 7.8349e-05 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9741
# Epoch 243/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.7004e-05 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9741
# Epoch 244/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.9069e-05 - accuracy: 1.0000 - val_loss: 0.0807 - val_accuracy: 0.9741
# Epoch 245/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 7.5564e-05 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9741
# Epoch 246/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.7788e-05 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9741
# Epoch 247/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 7.2301e-05 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9741
# Epoch 248/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 7.1465e-05 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 0.9741
# Epoch 249/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.3734e-05 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9741
# Epoch 250/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.6880e-05 - accuracy: 1.0000 - val_loss: 0.0807 - val_accuracy: 0.9741
# Epoch 251/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.4030e-05 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9741
# Epoch 252/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.7072e-05 - accuracy: 1.0000 - val_loss: 0.0812 - val_accuracy: 0.9741
# Epoch 253/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.3693e-05 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9741
# Epoch 254/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.4273e-05 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9741
# Epoch 255/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.1582e-05 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9741
# Epoch 256/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.2477e-05 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9741
# Epoch 257/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 6.2189e-05 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9741
# Epoch 258/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.5803e-05 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9741
# Epoch 259/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.8944e-05 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9741
# Epoch 260/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.0468e-05 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9741
# Epoch 261/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.7158e-05 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9741
# Epoch 262/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.7532e-05 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 0.9741
# Epoch 263/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.0923e-05 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9741
# Epoch 264/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.9898e-05 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9741
# Epoch 265/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2776e-05 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9741
# Epoch 266/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 5.1197e-05 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9741
# Epoch 267/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.0045e-05 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9728
# Epoch 268/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.3391e-05 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9741
# Epoch 269/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 5.2038e-05 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9741
# Epoch 270/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.9011e-05 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9741
# Epoch 271/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.7299e-05 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9741
# Epoch 272/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.5793e-05 - accuracy: 1.0000 - val_loss: 0.0825 - val_accuracy: 0.9741
# Epoch 273/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.5189e-05 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9741
# Epoch 274/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.3270e-05 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9741
# Epoch 275/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.2540e-05 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 0.9728
# Epoch 276/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.4338e-05 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9715
# Epoch 277/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.4676e-05 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9728
# Epoch 278/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.5783e-05 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9728
# Epoch 279/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.1140e-05 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9728
# Epoch 280/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.4083e-05 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9741
# Epoch 281/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.0168e-05 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9728
# Epoch 282/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 4.0737e-05 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9741
# Epoch 283/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.5936e-05 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9728
# Epoch 284/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.0720e-05 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9728
# Epoch 285/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 4.0505e-05 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9741
# Epoch 286/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.8179e-05 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 0.9741
# Epoch 287/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.6919e-05 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9741
# Epoch 288/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.9927e-05 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9728
# Epoch 289/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.6810e-05 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9741
# Epoch 290/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.3756e-05 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9741
# Epoch 291/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.5912e-05 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9741
# Epoch 292/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.5693e-05 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9741
# Epoch 293/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.2203e-05 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 0.9741
# Epoch 294/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.4223e-05 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9741
# Epoch 295/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.2113e-05 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9741
# Epoch 296/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.7112e-05 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9741
# Epoch 297/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.0619e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9741
# Epoch 298/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.4442e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9741
# Epoch 299/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.0066e-05 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9728
# Epoch 300/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.9071e-05 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9741
# Epoch 301/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.0173e-05 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9741
# Epoch 302/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.9141e-05 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9741
# Epoch 303/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.8505e-05 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9741
# Epoch 304/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 3.1911e-05 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9728
# Epoch 305/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7215e-05 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9741
# Epoch 306/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.6836e-05 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9741
# Epoch 307/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.8500e-05 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 0.9741
# Epoch 308/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.8618e-05 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9741
# Epoch 309/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.6573e-05 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9741
# Epoch 310/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.3316e-05 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9741
# Epoch 311/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.6620e-05 - accuracy: 1.0000 - val_loss: 0.0862 - val_accuracy: 0.9728
# Epoch 312/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.2856e-05 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9741
# Epoch 313/2000
# 49/49 [==============================] - 17s 340ms/step - loss: 2.4624e-05 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9741
# Epoch 314/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8040e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1900/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5151e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1901/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5036e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1902/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6731e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1903/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2994e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1904/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7000e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1905/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3072e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1906/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7077e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1907/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.9273e-08 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 1908/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8156e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1909/2000
# 49/49 [==============================] - 17s 338ms/step - loss: 2.6846e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1910/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5151e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1911/2000
# 49/49 [==============================] - 17s 338ms/step - loss: 3.1468e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1912/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7270e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1913/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7077e-08 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9715
# Epoch 1914/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.5166e-08 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 1915/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7539e-08 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 1916/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4997e-08 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 1917/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.9171e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1918/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.0274e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1919/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6731e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1920/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2109e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1921/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2840e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1922/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2725e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1923/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.1776e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1924/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.0953e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1925/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7655e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1926/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4728e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1927/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6538e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1928/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6037e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1929/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2609e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1930/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.4511e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1931/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5537e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1932/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.5705e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1933/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5922e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1934/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6654e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1935/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.9094e-08 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 1936/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2301e-08 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 1937/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6923e-08 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 1938/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2763e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1939/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8348e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1940/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7578e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1941/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4304e-08 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 1942/2000
# 49/49 [==============================] - 17s 338ms/step - loss: 4.5295e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1943/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8579e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1944/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.6475e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1945/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2725e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1946/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3803e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1947/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.1853e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1948/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.0043e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1949/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7385e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1950/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4689e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1951/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3303e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1952/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.9658e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1953/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3842e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1954/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7039e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1955/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2378e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1956/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.1800e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1957/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.2739e-08 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 1958/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8656e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1959/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4651e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1960/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4959e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1961/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7655e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1962/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5498e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1963/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4612e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1964/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.2893e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1965/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4843e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1966/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8156e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1967/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6962e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1968/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6268e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1969/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4612e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1970/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.9773e-08 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 1971/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2956e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1972/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.7578e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1973/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.3394e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1974/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.8926e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1975/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.0890e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1976/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.1146e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1977/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4073e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1978/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.5113e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1979/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.0236e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1980/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6808e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1981/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.9980e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1982/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3996e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1983/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3957e-08 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9715
# Epoch 1984/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.2648e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1985/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 3.2315e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1986/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.3264e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1987/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.0221e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1988/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6307e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1989/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.6153e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1990/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.1415e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1991/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4766e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1992/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.9542e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1993/2000
# 49/49 [==============================] - 17s 339ms/step - loss: 2.4343e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1994/2000
# 49/49 [==============================] - 16s 336ms/step - loss: 2.4458e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1995/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 2.2571e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1996/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 2.0568e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1997/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 3.2932e-08 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9715
# Epoch 1998/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 2.7578e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# Epoch 1999/2000
# 49/49 [==============================] - 16s 334ms/step - loss: 2.9658e-08 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9715
# Epoch 2000/2000
# 49/49 [==============================] - 16s 335ms/step - loss: 2.4882e-08 - accuracy: 1.0000 - val_loss: 0.1348 - val_accuracy: 0.9715
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_Xception\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 15s 368ms/step - loss: 0.5598 - accuracy: 0.9125
# test_indoor_ds_results:test loss, test acc: [0.5598021149635315, 0.9124860763549805]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 27s 450ms/step - loss: 1.2592 - accuracy: 0.8787
# test_outdoor_ds_results:test loss, test acc: [1.2592031955718994, 0.8786624073982239]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 12s 292ms/step - loss: 1.7196 - accuracy: 0.8218
# test_belt_ds_results:test loss, test acc: [1.7195507287979126, 0.821849524974823]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 8s 264ms/step - loss: 0.3242 - accuracy: 0.9142
# 50/50 [==============================] - 13s 268ms/step - loss: 0.6732 - accuracy: 0.8768
# 35/35 [==============================] - 9s 270ms/step - loss: 0.9304 - accuracy: 0.8218
# Epoch200
#  test_indoor_acc=0.914158284664154
#  test_outdoor_acc=0.8767516016960144
#  test_belt_acc=0.821849524974823
# 29/29 [==============================] - 9s 263ms/step - loss: 0.3918 - accuracy: 0.9142
# 50/50 [==============================] - 13s 268ms/step - loss: 0.8526 - accuracy: 0.8799
# 35/35 [==============================] - 9s 269ms/step - loss: 1.1702 - accuracy: 0.8232
# Epoch400
#  test_indoor_acc=0.914158284664154
#  test_outdoor_acc=0.8799362778663635
#  test_belt_acc=0.8232094049453735
# 29/29 [==============================] - 8s 264ms/step - loss: 0.4542 - accuracy: 0.9136
# 50/50 [==============================] - 13s 269ms/step - loss: 1.0000 - accuracy: 0.8812
# 35/35 [==============================] - 9s 269ms/step - loss: 1.3726 - accuracy: 0.8228
# Epoch600
#  test_indoor_acc=0.9136009216308594
#  test_outdoor_acc=0.881210207939148
#  test_belt_acc=0.8227561116218567
# 29/29 [==============================] - 8s 263ms/step - loss: 0.4901 - accuracy: 0.9130
# 50/50 [==============================] - 13s 268ms/step - loss: 1.0930 - accuracy: 0.8796
# 35/35 [==============================] - 9s 268ms/step - loss: 1.4908 - accuracy: 0.8232
# Epoch800
#  test_indoor_acc=0.9130434989929199
#  test_outdoor_acc=0.8796178102493286
#  test_belt_acc=0.8232094049453735
# 29/29 [==============================] - 8s 263ms/step - loss: 0.5138 - accuracy: 0.9130
# 50/50 [==============================] - 13s 267ms/step - loss: 1.1519 - accuracy: 0.8799
# 35/35 [==============================] - 9s 268ms/step - loss: 1.5651 - accuracy: 0.8223
# Epoch1000
#  test_indoor_acc=0.9130434989929199
#  test_outdoor_acc=0.8799362778663635
#  test_belt_acc=0.8223028182983398
# 29/29 [==============================] - 8s 264ms/step - loss: 0.5292 - accuracy: 0.9136
# 50/50 [==============================] - 13s 268ms/step - loss: 1.1824 - accuracy: 0.8796
# 35/35 [==============================] - 9s 269ms/step - loss: 1.6178 - accuracy: 0.8218
# Epoch1200
#  test_indoor_acc=0.9136009216308594
#  test_outdoor_acc=0.8796178102493286
#  test_belt_acc=0.821849524974823
# 29/29 [==============================] - 8s 263ms/step - loss: 0.5388 - accuracy: 0.9130
# 50/50 [==============================] - 13s 268ms/step - loss: 1.2055 - accuracy: 0.8799
# 35/35 [==============================] - 9s 269ms/step - loss: 1.6522 - accuracy: 0.8232
# Epoch1400
#  test_indoor_acc=0.9130434989929199
#  test_outdoor_acc=0.8799362778663635
#  test_belt_acc=0.8232094049453735
# 29/29 [==============================] - 9s 263ms/step - loss: 0.5459 - accuracy: 0.9130
# 50/50 [==============================] - 13s 268ms/step - loss: 1.2330 - accuracy: 0.8787
# 35/35 [==============================] - 9s 269ms/step - loss: 1.6758 - accuracy: 0.8214
# Epoch1600
#  test_indoor_acc=0.9130434989929199
#  test_outdoor_acc=0.8786624073982239
#  test_belt_acc=0.8213961720466614
# 29/29 [==============================] - 8s 263ms/step - loss: 0.5529 - accuracy: 0.9125
# 50/50 [==============================] - 13s 268ms/step - loss: 1.2476 - accuracy: 0.8787
# 35/35 [==============================] - 9s 269ms/step - loss: 1.6986 - accuracy: 0.8223
# Epoch1800
#  test_indoor_acc=0.9124860763549805
#  test_outdoor_acc=0.8786624073982239
#  test_belt_acc=0.8223028182983398
# 29/29 [==============================] - 8s 264ms/step - loss: 0.5598 - accuracy: 0.9125
# 50/50 [==============================] - 13s 268ms/step - loss: 1.2592 - accuracy: 0.8787
# 35/35 [==============================] - 9s 269ms/step - loss: 1.7196 - accuracy: 0.8218
# Epoch2000
#  test_indoor_acc=0.9124860763549805
#  test_outdoor_acc=0.8786624073982239
#  test_belt_acc=0.821849524974823

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8725224137306213
# max index -> 2
# The [Epoch] of max acc -> 600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.914158284664154,
#  0.914158284664154,
#  0.9136009216308594,
#  0.9130434989929199,
#  0.9130434989929199,
#  0.9136009216308594,
#  0.9130434989929199,
#  0.9130434989929199,
#  0.9124860763549805,
#  0.9124860763549805]

# %%
test_outdoor_acc
# Out:
# [0.8767516016960144,
#  0.8799362778663635,
#  0.881210207939148,
#  0.8796178102493286,
#  0.8799362778663635,
#  0.8796178102493286,
#  0.8799362778663635,
#  0.8786624073982239,
#  0.8786624073982239,
#  0.8786624073982239]

# %%
test_belt_acc
# Out:
# [0.821849524974823,
#  0.8232094049453735,
#  0.8227561116218567,
#  0.8232094049453735,
#  0.8223028182983398,
#  0.821849524974823,
#  0.8232094049453735,
#  0.8213961720466614,
#  0.8223028182983398,
#  0.821849524974823]

# %%
test_indoor_loss
# Out:
# [0.3241662085056305,
#  0.3918110132217407,
#  0.4541546702384949,
#  0.49010685086250305,
#  0.5137808918952942,
#  0.5291948914527893,
#  0.5387783646583557,
#  0.5459412932395935,
#  0.5529181361198425,
#  0.5598021149635315]

# %%
test_outdoor_loss
# Out:
# [0.6732170581817627,
#  0.852587878704071,
#  1.0000497102737427,
#  1.092972993850708,
#  1.151886224746704,
#  1.1824238300323486,
#  1.205471158027649,
#  1.2330001592636108,
#  1.2475727796554565,
#  1.2592031955718994]

# %%
test_belt_loss
# Out:
# [0.9303890466690063,
#  1.1701592206954956,
#  1.372648000717163,
#  1.490818738937378,
#  1.5650718212127686,
#  1.6178499460220337,
#  1.6521919965744019,
#  1.6758431196212769,
#  1.6985745429992676,
#  1.7195507287979126]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.xception import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6222
# FP=918
# acc=0.8714285714285714
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 87.1754932502596%
# 2-BloodSecretionWaste acc = 78.44380403458213%
# 3-LabWardWaste acc = 88.41554559043348%
# 4-VaccineOtherWaste acc = 93.3675852405418%
#
#
#
# all_avg_eachclass = 86.85060702895426%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1679,  172,   19,   56],
#        [ 296, 1361,   43,   35],
#        [  41,   73, 1183,   41],
#        [  20,   81,   41, 1999]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[87.17549325,  8.93042575,  0.98650052,  2.90758048],
#        [17.06051873, 78.44380403,  2.47838617,  2.01729107],
#        [ 3.06427504,  5.45590433, 88.41554559,  3.06427504],
#        [ 0.93414292,  3.78327884,  1.91499299, 93.36758524]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
