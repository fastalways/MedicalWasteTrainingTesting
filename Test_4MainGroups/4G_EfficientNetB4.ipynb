# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=380
img_width=380
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 380, 380, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB4

efficientnetB0_model = keras.applications.EfficientNetB4(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 380, 380, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 380, 380, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 380, 380, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 381, 381, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 190, 190, 48) 1296        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 190, 190, 48) 192         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 190, 190, 48) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 190, 190, 48) 432         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 190, 190, 48) 192         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 190, 190, 48) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 48)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 48)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 12)     588         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 48)     624         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 190, 190, 48) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 190, 190, 24) 1152        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 190, 190, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 190, 190, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 190, 190, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 190, 190, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 190, 190, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 190, 190, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 190, 190, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 190, 190, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 190, 190, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 190, 190, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 190, 190, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 190, 190, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 191, 191, 144 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 95, 95, 144)  1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 95, 95, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 95, 95, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 95, 95, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 95, 95, 32)   4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 95, 95, 32)   128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 95, 95, 192)  6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 95, 95, 192)  768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 95, 95, 192)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 95, 95, 192)  1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 95, 95, 192)  768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 95, 95, 192)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 95, 95, 192)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 95, 95, 32)   6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 95, 95, 32)   128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 95, 95, 32)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 95, 95, 32)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 95, 95, 192)  6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 95, 95, 192)  768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 95, 95, 192)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 95, 95, 192)  1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 95, 95, 192)  768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 95, 95, 192)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 95, 95, 192)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 95, 95, 32)   6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 95, 95, 32)   128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 95, 95, 32)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 95, 95, 32)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 95, 95, 192)  6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 95, 95, 192)  768         block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 95, 95, 192)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 95, 95, 192)  1728        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 95, 95, 192)  768         block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 95, 95, 192)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 192)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 95, 95, 192)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 95, 95, 32)   6144        block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 95, 95, 32)   128         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 95, 95, 32)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 95, 95, 32)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 95, 95, 192)  6144        block2d_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 95, 95, 192)  768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 95, 95, 192)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 99, 99, 192)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 48, 48, 192)  4800        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 48, 48, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 48, 48, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 48, 48, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 48, 48, 56)   10752       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 48, 48, 56)   224         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 48, 48, 336)  18816       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 48, 48, 336)  1344        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 48, 48, 336)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 48, 48, 336)  8400        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 48, 48, 336)  1344        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 48, 48, 336)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 336)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 48, 48, 336)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 48, 48, 56)   18816       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 48, 48, 56)   224         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 48, 48, 56)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 48, 48, 56)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 48, 48, 336)  18816       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 48, 48, 336)  1344        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 48, 48, 336)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 48, 48, 336)  8400        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 48, 48, 336)  1344        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 48, 48, 336)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 336)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 48, 48, 336)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 48, 48, 56)   18816       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 48, 48, 56)   224         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 48, 48, 56)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 48, 48, 56)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 48, 48, 336)  18816       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 48, 48, 336)  1344        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 48, 48, 336)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 48, 48, 336)  8400        block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 48, 48, 336)  1344        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 48, 48, 336)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 336)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 336)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 48, 48, 336)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 48, 48, 56)   18816       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 48, 48, 56)   224         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 48, 48, 56)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 48, 48, 56)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 48, 48, 336)  18816       block3d_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 48, 48, 336)  1344        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 48, 48, 336)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 49, 49, 336)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 24, 24, 336)  3024        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 24, 24, 336)  1344        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 24, 24, 336)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 336)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 336)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 14)     4718        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 336)    5040        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 24, 24, 336)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 24, 24, 112)  37632       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 24, 24, 112)  448         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 24, 24, 672)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 24, 24, 672)  6048        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 24, 24, 672)  2688        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 24, 24, 672)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 672)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 24, 24, 672)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 24, 24, 112)  75264       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 24, 24, 112)  448         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 24, 24, 112)  0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 24, 24, 112)  0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 24, 24, 672)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 24, 24, 672)  6048        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 24, 24, 672)  2688        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 24, 24, 672)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 672)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 24, 24, 672)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 24, 24, 112)  75264       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 24, 24, 112)  448         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 24, 24, 112)  0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 24, 24, 112)  0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 24, 24, 672)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 24, 24, 672)  6048        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 24, 24, 672)  2688        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 24, 24, 672)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 672)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 24, 24, 672)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 24, 24, 112)  75264       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 24, 24, 112)  448         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 24, 24, 112)  0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 24, 24, 112)  0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 24, 24, 672)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 24, 24, 672)  6048        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 24, 24, 672)  2688        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 24, 24, 672)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 672)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 672)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 24, 24, 672)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 24, 24, 112)  75264       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 24, 24, 112)  448         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (Dropout)          (None, 24, 24, 112)  0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 24, 24, 112)  0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block4f_expand_conv (Conv2D)    (None, 24, 24, 672)  75264       block4e_add[0][0]
# __________________________________________________________________________________________________
# block4f_expand_bn (BatchNormali (None, 24, 24, 672)  2688        block4f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4f_expand_activation (Acti (None, 24, 24, 672)  0           block4f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4f_dwconv (DepthwiseConv2D (None, 24, 24, 672)  6048        block4f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4f_bn (BatchNormalization) (None, 24, 24, 672)  2688        block4f_dwconv[0][0]
# __________________________________________________________________________________________________
# block4f_activation (Activation) (None, 24, 24, 672)  0           block4f_bn[0][0]
# __________________________________________________________________________________________________
# block4f_se_squeeze (GlobalAvera (None, 672)          0           block4f_activation[0][0]
# ...
# block6f_expand_activation (Acti (None, 12, 12, 1632) 0           block6f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6f_dwconv (DepthwiseConv2D (None, 12, 12, 1632) 40800       block6f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6f_bn (BatchNormalization) (None, 12, 12, 1632) 6528        block6f_dwconv[0][0]
# __________________________________________________________________________________________________
# block6f_activation (Activation) (None, 12, 12, 1632) 0           block6f_bn[0][0]
# __________________________________________________________________________________________________
# block6f_se_squeeze (GlobalAvera (None, 1632)         0           block6f_activation[0][0]
# __________________________________________________________________________________________________
# block6f_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6f_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6f_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6f_se_excite (Multiply)    (None, 12, 12, 1632) 0           block6f_activation[0][0]
#                                                                  block6f_se_expand[0][0]
# __________________________________________________________________________________________________
# block6f_project_conv (Conv2D)   (None, 12, 12, 272)  443904      block6f_se_excite[0][0]
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 12, 12, 272)  1088        block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (Dropout)          (None, 12, 12, 272)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 12, 12, 272)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block6g_expand_conv (Conv2D)    (None, 12, 12, 1632) 443904      block6f_add[0][0]
# __________________________________________________________________________________________________
# block6g_expand_bn (BatchNormali (None, 12, 12, 1632) 6528        block6g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6g_expand_activation (Acti (None, 12, 12, 1632) 0           block6g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6g_dwconv (DepthwiseConv2D (None, 12, 12, 1632) 40800       block6g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6g_bn (BatchNormalization) (None, 12, 12, 1632) 6528        block6g_dwconv[0][0]
# __________________________________________________________________________________________________
# block6g_activation (Activation) (None, 12, 12, 1632) 0           block6g_bn[0][0]
# __________________________________________________________________________________________________
# block6g_se_squeeze (GlobalAvera (None, 1632)         0           block6g_activation[0][0]
# __________________________________________________________________________________________________
# block6g_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6g_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6g_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6g_se_excite (Multiply)    (None, 12, 12, 1632) 0           block6g_activation[0][0]
#                                                                  block6g_se_expand[0][0]
# __________________________________________________________________________________________________
# block6g_project_conv (Conv2D)   (None, 12, 12, 272)  443904      block6g_se_excite[0][0]
# __________________________________________________________________________________________________
# block6g_project_bn (BatchNormal (None, 12, 12, 272)  1088        block6g_project_conv[0][0]
# __________________________________________________________________________________________________
# block6g_drop (Dropout)          (None, 12, 12, 272)  0           block6g_project_bn[0][0]
# __________________________________________________________________________________________________
# block6g_add (Add)               (None, 12, 12, 272)  0           block6g_drop[0][0]
#                                                                  block6f_add[0][0]
# __________________________________________________________________________________________________
# block6h_expand_conv (Conv2D)    (None, 12, 12, 1632) 443904      block6g_add[0][0]
# __________________________________________________________________________________________________
# block6h_expand_bn (BatchNormali (None, 12, 12, 1632) 6528        block6h_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6h_expand_activation (Acti (None, 12, 12, 1632) 0           block6h_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6h_dwconv (DepthwiseConv2D (None, 12, 12, 1632) 40800       block6h_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6h_bn (BatchNormalization) (None, 12, 12, 1632) 6528        block6h_dwconv[0][0]
# __________________________________________________________________________________________________
# block6h_activation (Activation) (None, 12, 12, 1632) 0           block6h_bn[0][0]
# __________________________________________________________________________________________________
# block6h_se_squeeze (GlobalAvera (None, 1632)         0           block6h_activation[0][0]
# __________________________________________________________________________________________________
# block6h_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block6h_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6h_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block6h_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6h_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block6h_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6h_se_excite (Multiply)    (None, 12, 12, 1632) 0           block6h_activation[0][0]
#                                                                  block6h_se_expand[0][0]
# __________________________________________________________________________________________________
# block6h_project_conv (Conv2D)   (None, 12, 12, 272)  443904      block6h_se_excite[0][0]
# __________________________________________________________________________________________________
# block6h_project_bn (BatchNormal (None, 12, 12, 272)  1088        block6h_project_conv[0][0]
# __________________________________________________________________________________________________
# block6h_drop (Dropout)          (None, 12, 12, 272)  0           block6h_project_bn[0][0]
# __________________________________________________________________________________________________
# block6h_add (Add)               (None, 12, 12, 272)  0           block6h_drop[0][0]
#                                                                  block6g_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 12, 12, 1632) 443904      block6h_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 12, 12, 1632) 6528        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 12, 12, 1632) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 12, 12, 1632) 14688       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 12, 12, 1632) 6528        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 12, 12, 1632) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1632)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1632)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 68)     111044      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1632)   112608      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 12, 12, 1632) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 12, 12, 448)  731136      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 12, 12, 448)  1792        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 12, 12, 2688) 1204224     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 12, 12, 2688) 10752       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 12, 12, 2688) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 12, 12, 2688) 24192       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 12, 12, 2688) 10752       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 12, 12, 2688) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2688)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2688)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 112)    301168      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2688)   303744      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 12, 12, 2688) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 12, 12, 448)  1204224     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 12, 12, 448)  1792        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 12, 12, 448)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 12, 12, 448)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 12, 12, 1792) 802816      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 12, 12, 1792) 7168        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 12, 12, 1792) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1792)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 17,673,823
# Trainable params: 0
# Non-trainable params: 17,673,823
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1792)              17673823
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1836032
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 19,513,955
# Trainable params: 1,840,132
# Non-trainable params: 17,673,823
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 78s 922ms/step - loss: 0.2737 - accuracy: 0.8937 - val_loss: 0.1643 - val_accuracy: 0.9470
# Epoch 2/2000
# 49/49 [==============================] - 36s 744ms/step - loss: 0.0657 - accuracy: 0.9796 - val_loss: 0.1049 - val_accuracy: 0.9638
# Epoch 3/2000
# 49/49 [==============================] - 36s 745ms/step - loss: 0.0361 - accuracy: 0.9900 - val_loss: 0.0828 - val_accuracy: 0.9715
# Epoch 4/2000
# 49/49 [==============================] - 36s 744ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.0737 - val_accuracy: 0.9651
# Epoch 5/2000
# 49/49 [==============================] - 36s 739ms/step - loss: 0.0219 - accuracy: 0.9952 - val_loss: 0.0715 - val_accuracy: 0.9728
# Epoch 6/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.0929 - val_accuracy: 0.9690
# Epoch 7/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.0732 - val_accuracy: 0.9728
# Epoch 8/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 0.0120 - accuracy: 0.9971 - val_loss: 0.0652 - val_accuracy: 0.9728
# Epoch 9/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0130 - accuracy: 0.9964 - val_loss: 0.0679 - val_accuracy: 0.9715
# Epoch 10/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.0771 - val_accuracy: 0.9780
# Epoch 11/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0257 - accuracy: 0.9903 - val_loss: 0.0808 - val_accuracy: 0.9715
# Epoch 12/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.0371 - val_accuracy: 0.9819
# Epoch 13/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0557 - val_accuracy: 0.9793
# Epoch 14/2000
# 49/49 [==============================] - 36s 738ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0410 - val_accuracy: 0.9871
# Epoch 15/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0531 - val_accuracy: 0.9845
# Epoch 16/2000
# 49/49 [==============================] - 36s 732ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0377 - val_accuracy: 0.9845
# Epoch 17/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0439 - val_accuracy: 0.9858
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 18/2000
# 49/49 [==============================] - 36s 729ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0454 - val_accuracy: 0.9845
# Epoch 19/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0466 - val_accuracy: 0.9871
# Epoch 20/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 8.8622e-04 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9884
# Epoch 21/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 9.3079e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9884
# Epoch 22/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9897
# Epoch 23/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 6.4028e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9871
# Epoch 24/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0404 - val_accuracy: 0.9884
# Epoch 25/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0555 - val_accuracy: 0.9832
# Epoch 26/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 9.1319e-04 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9858
# Epoch 27/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.7179e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9884
# Epoch 28/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.2817e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9884
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 29/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0393 - val_accuracy: 0.9884
# Epoch 30/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.0101e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9884
# Epoch 31/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0373 - val_accuracy: 0.9871
# Epoch 32/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.2284e-04 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9871
# Epoch 33/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.1518e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9884
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 34/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.0581e-04 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9884
# Epoch 35/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 6.8788e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 36/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 7.6496e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9884
# Epoch 37/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 5.5806e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9884
# Epoch 38/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.8414e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9884
# Epoch 39/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.0269e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9884
# Epoch 40/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 41/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0387 - val_accuracy: 0.9884
# Epoch 42/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0388 - val_accuracy: 0.9884
# Epoch 43/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 8.3691e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9884
# Epoch 44/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0391 - val_accuracy: 0.9884
# Epoch 45/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 9.7575e-04 - accuracy: 0.9997 - val_loss: 0.0391 - val_accuracy: 0.9884
# Epoch 46/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 9.4702e-04 - accuracy: 0.9997 - val_loss: 0.0389 - val_accuracy: 0.9884
# Epoch 47/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0388 - val_accuracy: 0.9884
# Epoch 48/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 7.9357e-04 - accuracy: 0.9997 - val_loss: 0.0388 - val_accuracy: 0.9884
# Epoch 49/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.0935e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9884
# Epoch 50/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.7593e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9884
# Epoch 51/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.3694e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 52/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 9.3916e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9884
# Epoch 53/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 4.0395e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9884
# Epoch 54/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.5467e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9884
# Epoch 55/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 6.6245e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9884
# Epoch 56/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0378 - val_accuracy: 0.9884
# Epoch 57/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0375 - val_accuracy: 0.9884
# Epoch 58/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.6267e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9884
# Epoch 59/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0380 - val_accuracy: 0.9884
# Epoch 60/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.5025e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9884
# Epoch 61/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.7966e-04 - accuracy: 0.9997 - val_loss: 0.0379 - val_accuracy: 0.9884
# Epoch 62/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 9.5944e-04 - accuracy: 0.9997 - val_loss: 0.0381 - val_accuracy: 0.9884
# Epoch 63/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.7235e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9884
# Epoch 64/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0378 - val_accuracy: 0.9884
# Epoch 65/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.3101e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 66/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.8067e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9884
# Epoch 67/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 8.6966e-04 - accuracy: 0.9997 - val_loss: 0.0373 - val_accuracy: 0.9884
# Epoch 68/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.6461e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9884
# Epoch 69/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.5894e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9884
# Epoch 70/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.3942e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 71/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.7550e-04 - accuracy: 0.9997 - val_loss: 0.0373 - val_accuracy: 0.9884
# Epoch 72/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.1022e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9884
# Epoch 73/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0361 - val_accuracy: 0.9884
# Epoch 74/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.9017e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9884
# Epoch 75/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.0860e-04 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 0.9884
# Epoch 76/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.6058e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9884
# Epoch 77/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 6.9692e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9884
# Epoch 78/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.3299e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9884
# Epoch 79/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.7635e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9884
# Epoch 80/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 8.6871e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9884
# Epoch 81/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0371 - val_accuracy: 0.9884
# Epoch 82/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 6.6711e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9884
# Epoch 83/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.9757e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9884
# Epoch 84/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.4751e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9884
# Epoch 85/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.7750e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9884
# Epoch 86/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.2573e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9884
# Epoch 87/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.9811e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9884
# Epoch 88/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 89/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 6.2950e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9884
# Epoch 90/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.5298e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9884
# Epoch 91/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.0535e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9884
# Epoch 92/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0365 - val_accuracy: 0.9884
# Epoch 93/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 8.1356e-04 - accuracy: 0.9997 - val_loss: 0.0375 - val_accuracy: 0.9884
# Epoch 94/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.7641e-04 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9884
# Epoch 95/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 8.7581e-04 - accuracy: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9884
# Epoch 96/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 9.7347e-04 - accuracy: 0.9997 - val_loss: 0.0385 - val_accuracy: 0.9884
# Epoch 97/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.4561e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 98/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0378 - val_accuracy: 0.9884
# Epoch 99/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.6507e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 100/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.2052e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9884
# Epoch 101/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.5191e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 102/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.3719e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9884
# Epoch 103/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.8699e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9884
# Epoch 104/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.4568e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9884
# Epoch 105/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.9982e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9884
# Epoch 106/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.9235e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9884
# Epoch 107/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 4.7220e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9884
# Epoch 108/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.8898e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9884
# Epoch 109/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.0695e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9884
# Epoch 110/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.0254e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9884
# Epoch 111/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 5.5902e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9884
# Epoch 112/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.8828e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9884
# Epoch 113/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.5058e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9884
# Epoch 114/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 5.9251e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9884
# Epoch 115/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.3766e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9884
# Epoch 116/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.7821e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9884
# Epoch 117/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.6763e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 118/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.8989e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9884
# Epoch 119/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.3018e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9884
# Epoch 120/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.5919e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9884
# Epoch 121/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.9492e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9871
# Epoch 122/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.0665e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9871
# Epoch 123/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.9759e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9871
# Epoch 124/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.0454e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9871
# Epoch 125/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.0750e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9871
# Epoch 126/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.8984e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9871
# Epoch 127/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.0862e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9871
# Epoch 128/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.7544e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9871
# Epoch 129/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.1064e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9871
# Epoch 130/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 8.9737e-04 - accuracy: 0.9997 - val_loss: 0.0384 - val_accuracy: 0.9884
# Epoch 131/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 8.9650e-04 - accuracy: 0.9997 - val_loss: 0.0393 - val_accuracy: 0.9871
# Epoch 132/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0399 - val_accuracy: 0.9871
# Epoch 133/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 4.5690e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 134/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.5805e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9871
# Epoch 135/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.0471e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9871
# Epoch 136/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.8630e-04 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9871
# Epoch 137/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0370 - val_accuracy: 0.9871
# Epoch 138/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 5.3411e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9871
# Epoch 139/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 8.1902e-04 - accuracy: 0.9997 - val_loss: 0.0377 - val_accuracy: 0.9858
# Epoch 140/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 8.9516e-04 - accuracy: 0.9997 - val_loss: 0.0380 - val_accuracy: 0.9871
# Epoch 141/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 9.4326e-04 - accuracy: 0.9997 - val_loss: 0.0360 - val_accuracy: 0.9871
# Epoch 142/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0359 - val_accuracy: 0.9871
# Epoch 143/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.5484e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9871
# Epoch 144/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.2847e-04 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9871
# Epoch 145/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.0006e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9871
# Epoch 146/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.5720e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 147/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.1686e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9871
# Epoch 148/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.8563e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9871
# Epoch 149/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.1804e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9871
# Epoch 150/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.2732e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9871
# Epoch 151/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.0664e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9871
# Epoch 152/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.2526e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9871
# Epoch 153/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.5139e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 154/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 4.8372e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9871
# Epoch 155/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.4152e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9871
# Epoch 156/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.3265e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9871
# Epoch 157/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.7897e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9871
# Epoch 158/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 1.7871e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9871
# Epoch 159/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.6601e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9871
# Epoch 160/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.4095e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9871
# Epoch 161/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.4144e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9871
# Epoch 162/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 9.0776e-04 - accuracy: 0.9997 - val_loss: 0.0371 - val_accuracy: 0.9871
# Epoch 163/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.2585e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9871
# Epoch 164/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.3665e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9871
# Epoch 165/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.4178e-04 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9871
# Epoch 166/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.2768e-04 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9871
# Epoch 167/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.4274e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9871
# Epoch 168/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.1551e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9871
# Epoch 169/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.7979e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 170/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 5.9182e-04 - accuracy: 0.9997 - val_loss: 0.0344 - val_accuracy: 0.9871
# Epoch 171/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.5228e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9871
# Epoch 172/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 5.2662e-04 - accuracy: 0.9997 - val_loss: 0.0349 - val_accuracy: 0.9884
# Epoch 173/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.2443e-04 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9884
# Epoch 174/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.5627e-04 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9884
# Epoch 175/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.2018e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9884
# Epoch 176/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.6143e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9871
# Epoch 177/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.9880e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9871
# Epoch 178/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.2907e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9871
# Epoch 179/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0359 - val_accuracy: 0.9871
# Epoch 180/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.0228e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9871
# Epoch 181/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.5374e-04 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9871
# Epoch 182/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.3093e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9871
# Epoch 183/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.3911e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9871
# Epoch 184/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.2905e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9858
# Epoch 185/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.0416e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9858
# Epoch 186/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0342 - val_accuracy: 0.9871
# Epoch 187/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.5203e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9871
# Epoch 188/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.6177e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9858
# Epoch 189/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.6543e-04 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9858
# Epoch 190/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 4.3967e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9858
# Epoch 191/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 8.8819e-04 - accuracy: 0.9997 - val_loss: 0.0368 - val_accuracy: 0.9871
# Epoch 192/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.9698e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9871
# Epoch 193/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 3.6424e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 194/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0354 - val_accuracy: 0.9871
# Epoch 195/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.2722e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 196/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 1.7252e-04 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 0.9871
# Epoch 197/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.3469e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 198/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 2.4628e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9871
# Epoch 199/2000
# 49/49 [==============================] - 36s 727ms/step - loss: 2.9090e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9871
# Epoch 200/2000
# 49/49 [==============================] - 35s 727ms/step - loss: 3.0903e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9871
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB4\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 5.2977e-04 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9871
# Epoch 202/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 6.0753e-04 - accuracy: 0.9997 - val_loss: 0.0375 - val_accuracy: 0.9871
# Epoch 203/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.9674e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9871
# Epoch 204/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.5852e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9871
# Epoch 205/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.1131e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9871
# Epoch 206/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 5.3874e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9871
# Epoch 207/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0361 - val_accuracy: 0.9871
# Epoch 208/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 7.6367e-04 - accuracy: 0.9997 - val_loss: 0.0343 - val_accuracy: 0.9884
# Epoch 209/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.7698e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9871
# Epoch 210/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.7315e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9871
# Epoch 211/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.9401e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9858
# Epoch 212/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.2907e-04 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9858
# Epoch 213/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.9422e-04 - accuracy: 1.0000 - val_loss: 0.0348 - val_accuracy: 0.9858
# Epoch 214/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.6420e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9858
# Epoch 215/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 8.4817e-04 - accuracy: 0.9997 - val_loss: 0.0342 - val_accuracy: 0.9871
# Epoch 216/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.4084e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9858
# Epoch 217/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.5887e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9858
# Epoch 218/2000
# 49/49 [==============================] - 36s 734ms/step - loss: 2.5955e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9858
# Epoch 219/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.4813e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9858
# Epoch 220/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.3261e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9858
# Epoch 221/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.0910e-04 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9858
# Epoch 222/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.3939e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9858
# Epoch 223/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.7137e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9858
# Epoch 224/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.0058e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9858
# Epoch 225/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.2410e-04 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9858
# Epoch 226/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.6419e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9858
# Epoch 227/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.3078e-04 - accuracy: 0.9997 - val_loss: 0.0348 - val_accuracy: 0.9858
# Epoch 228/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.2436e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9858
# Epoch 229/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.6657e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9858
# Epoch 230/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.0845e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9871
# Epoch 231/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.2972e-04 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.9871
# Epoch 232/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.1339e-04 - accuracy: 0.9997 - val_loss: 0.0327 - val_accuracy: 0.9871
# Epoch 233/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.7109e-04 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9858
# Epoch 234/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.0726e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9871
# Epoch 235/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.9339e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9858
# Epoch 236/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.3883e-04 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9871
# Epoch 237/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.6211e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9871
# Epoch 238/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.7564e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9871
# Epoch 239/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 9.7600e-04 - accuracy: 0.9997 - val_loss: 0.0354 - val_accuracy: 0.9858
# Epoch 240/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.4806e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9858
# Epoch 241/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.3874e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9858
# Epoch 242/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 7.5908e-04 - accuracy: 0.9994 - val_loss: 0.0334 - val_accuracy: 0.9858
# Epoch 243/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.7337e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9871
# Epoch 244/2000
# 49/49 [==============================] - 36s 729ms/step - loss: 1.8718e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9871
# Epoch 245/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.4457e-04 - accuracy: 0.9997 - val_loss: 0.0357 - val_accuracy: 0.9858
# Epoch 246/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 9.4176e-04 - accuracy: 0.9997 - val_loss: 0.0363 - val_accuracy: 0.9845
# Epoch 247/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.4420e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9871
# Epoch 248/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.4232e-04 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9884
# Epoch 249/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.9431e-04 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9884
# Epoch 250/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.8994e-04 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9884
# Epoch 251/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.0418e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9884
# Epoch 252/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.3259e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9884
# Epoch 253/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.8028e-04 - accuracy: 0.9997 - val_loss: 0.0348 - val_accuracy: 0.9884
# Epoch 254/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.8802e-04 - accuracy: 0.9997 - val_loss: 0.0359 - val_accuracy: 0.9871
# Epoch 255/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.6403e-04 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.9884
# Epoch 256/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.4536e-04 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9884
# Epoch 257/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.0593e-04 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9884
# Epoch 258/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.3718e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9884
# Epoch 259/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.5011e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9884
# Epoch 260/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 6.3308e-04 - accuracy: 0.9997 - val_loss: 0.0350 - val_accuracy: 0.9884
# Epoch 261/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.9485e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9884
# Epoch 262/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.1101e-04 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9884
# Epoch 263/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.9248e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9884
# Epoch 264/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.1383e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9884
# Epoch 265/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.7399e-04 - accuracy: 1.0000 - val_loss: 0.0324 - val_accuracy: 0.9871
# Epoch 266/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.5047e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9884
# Epoch 267/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.5313e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9884
# Epoch 268/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.3381e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9871
# Epoch 269/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.0705e-04 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9871
# Epoch 270/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 6.1246e-04 - accuracy: 0.9997 - val_loss: 0.0317 - val_accuracy: 0.9871
# Epoch 271/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.2986e-04 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 0.9871
# Epoch 272/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.5313e-04 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9871
# Epoch 273/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 4.9960e-04 - accuracy: 0.9997 - val_loss: 0.0316 - val_accuracy: 0.9871
# Epoch 274/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.5351e-04 - accuracy: 0.9997 - val_loss: 0.0305 - val_accuracy: 0.9871
# Epoch 275/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.6972e-04 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9871
# Epoch 276/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 9.9249e-04 - accuracy: 0.9997 - val_loss: 0.0314 - val_accuracy: 0.9871
# Epoch 277/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.3871e-04 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9871
# Epoch 278/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.5037e-04 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 0.9871
# Epoch 279/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.5658e-04 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9871
# Epoch 280/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.2187e-04 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.9871
# Epoch 281/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.4003e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9871
# Epoch 282/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.8203e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9871
# Epoch 283/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.6259e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9871
# Epoch 284/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 3.6424e-04 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.9871
# Epoch 285/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.6800e-04 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.9871
# Epoch 286/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.6280e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9871
# Epoch 287/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.8108e-04 - accuracy: 1.0000 - val_loss: 0.0350 - val_accuracy: 0.9871
# Epoch 288/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.9656e-04 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 0.9858
# Epoch 289/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.2576e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9871
# Epoch 290/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 2.5289e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9871
# Epoch 291/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.7987e-04 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.9871
# Epoch 292/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 5.5460e-04 - accuracy: 0.9997 - val_loss: 0.0343 - val_accuracy: 0.9871
# Epoch 293/2000
# 49/49 [==============================] - 36s 728ms/step - loss: 1.6405e-04 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.9871
# Epoch 294/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.6844e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9871
# Epoch 295/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.9493e-04 - accuracy: 1.0000 - val_loss: 0.0330 - val_accuracy: 0.9871
# Epoch 296/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.6922e-04 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9871
# Epoch 297/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.5298e-04 - accuracy: 1.0000 - val_loss: 0.0329 - val_accuracy: 0.9871
# Epoch 298/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.5306e-04 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9871
# Epoch 299/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.6042e-04 - accuracy: 1.0000 - val_loss: 0.0334 - val_accuracy: 0.9871
# Epoch 300/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.0135e-04 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9871
# Epoch 301/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.3736e-04 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9871
# Epoch 302/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.4485e-04 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 0.9871
# Epoch 303/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.7620e-04 - accuracy: 1.0000 - val_loss: 0.0315 - val_accuracy: 0.9871
# Epoch 304/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.8470e-04 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9871
# Epoch 305/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.9757e-04 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9871
# Epoch 306/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.8423e-04 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9871
# Epoch 307/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.4552e-04 - accuracy: 1.0000 - val_loss: 0.0321 - val_accuracy: 0.9871
# Epoch 308/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 5.8761e-04 - accuracy: 0.9997 - val_loss: 0.0310 - val_accuracy: 0.9871
# Epoch 309/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.0333 - val_accuracy: 0.9871
# Epoch 310/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.4962e-04 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9871
# Epoch 311/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 4.0803e-04 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9858
# Epoch 312/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.3669e-04 - accuracy: 1.0000 - val_loss: 0.0299 - val_accuracy: 0.9858
# Epoch 313/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.2546e-04 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9858
# Epoch 314/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.9907e-04 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9858
# Epoch 315/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 8.8475e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9909
# Epoch 1900/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 8.1553e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9909
# Epoch 1901/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 3.6665e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9909
# Epoch 1902/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 1.1251e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9909
# Epoch 1903/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.1223e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9909
# Epoch 1904/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 9.2073e-06 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9909
# Epoch 1905/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.3492e-05 - accuracy: 1.0000 - val_loss: 0.0234 - val_accuracy: 0.9909
# Epoch 1906/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 1.7724e-05 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9909
# Epoch 1907/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 5.9208e-05 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9909
# Epoch 1908/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.0990e-05 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9909
# Epoch 1909/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.1562e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9909
# Epoch 1910/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.6157e-05 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9909
# Epoch 1911/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 1.3347e-05 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9909
# Epoch 1912/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 5.6584e-05 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1913/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 1.4182e-05 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9909
# Epoch 1914/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 1.3772e-05 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9909
# Epoch 1915/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 2.2038e-05 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9909
# Epoch 1916/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.7664e-05 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9909
# Epoch 1917/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 3.6069e-05 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9909
# Epoch 1918/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 1.1370e-05 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9909
# Epoch 1919/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 2.9246e-05 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9909
# Epoch 1920/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 1.9154e-05 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9909
# Epoch 1921/2000
# 49/49 [==============================] - 36s 736ms/step - loss: 3.2066e-05 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1922/2000
# 49/49 [==============================] - 36s 737ms/step - loss: 9.2537e-06 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1923/2000
# 49/49 [==============================] - 36s 734ms/step - loss: 1.3056e-05 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1924/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.0057e-05 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1925/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.8341e-05 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1926/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.9078e-05 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9909
# Epoch 1927/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.3260e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9909
# Epoch 1928/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.3632e-05 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9909
# Epoch 1929/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.3991e-05 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9909
# Epoch 1930/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 7.4270e-04 - accuracy: 0.9997 - val_loss: 0.0241 - val_accuracy: 0.9909
# Epoch 1931/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 9.1399e-06 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9909
# Epoch 1932/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4363e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9909
# Epoch 1933/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.1379e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 1934/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.2074e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9909
# Epoch 1935/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.7460e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 1936/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.7739e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1937/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.1364e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1938/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4678e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1939/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.1377e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 1940/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.4693e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9909
# Epoch 1941/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.3015e-05 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9909
# Epoch 1942/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.0596e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9909
# Epoch 1943/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.9269e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 1944/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 5.6535e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 1945/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.1984e-05 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9909
# Epoch 1946/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 5.0513e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 1947/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 8.7231e-05 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 0.9909
# Epoch 1948/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 7.4880e-05 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9909
# Epoch 1949/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.5611e-05 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9909
# Epoch 1950/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.7140e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9909
# Epoch 1951/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.2154e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9909
# Epoch 1952/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4081e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9909
# Epoch 1953/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 7.4898e-06 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9909
# Epoch 1954/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.9642e-05 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9909
# Epoch 1955/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.5535e-05 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9909
# Epoch 1956/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.6069e-05 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 0.9909
# Epoch 1957/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.7541e-05 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9909
# Epoch 1958/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4234e-05 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1959/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.5475e-05 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9909
# Epoch 1960/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 8.1870e-06 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9909
# Epoch 1961/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.5176e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 1962/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.1106e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9909
# Epoch 1963/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.0177e-05 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9909
# Epoch 1964/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.1022e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9909
# Epoch 1965/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.0170e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 1966/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.9720e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9909
# Epoch 1967/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.7168e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1968/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.0127e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9909
# Epoch 1969/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.6200e-04 - accuracy: 0.9997 - val_loss: 0.0225 - val_accuracy: 0.9922
# Epoch 1970/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.0711e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9922
# Epoch 1971/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4402e-05 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9922
# Epoch 1972/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4149e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9922
# Epoch 1973/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.5692e-05 - accuracy: 1.0000 - val_loss: 0.0217 - val_accuracy: 0.9922
# Epoch 1974/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.6844e-05 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 0.9922
# Epoch 1975/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.7526e-05 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9922
# Epoch 1976/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.3983e-05 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9922
# Epoch 1977/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.2773e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9922
# Epoch 1978/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.0764e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9922
# Epoch 1979/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.8047e-05 - accuracy: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9922
# Epoch 1980/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.3346e-05 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9922
# Epoch 1981/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.9118e-05 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9922
# Epoch 1982/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 3.7324e-05 - accuracy: 1.0000 - val_loss: 0.0227 - val_accuracy: 0.9922
# Epoch 1983/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 9.6478e-06 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9922
# Epoch 1984/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.6485e-05 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9909
# Epoch 1985/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 8.3777e-06 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1986/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.0838e-05 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9909
# Epoch 1987/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 8.4278e-06 - accuracy: 1.0000 - val_loss: 0.0228 - val_accuracy: 0.9909
# Epoch 1988/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.0595e-05 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9909
# Epoch 1989/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 9.7805e-06 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9909
# Epoch 1990/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.8715e-04 - accuracy: 0.9997 - val_loss: 0.0241 - val_accuracy: 0.9909
# Epoch 1991/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.6524e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1992/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.1385e-05 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9909
# Epoch 1993/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.8990e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9909
# Epoch 1994/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 4.8009e-05 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9909
# Epoch 1995/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.7148e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1996/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 8.5330e-06 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 1997/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.1165e-05 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9909
# Epoch 1998/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 2.3227e-05 - accuracy: 1.0000 - val_loss: 0.0240 - val_accuracy: 0.9909
# Epoch 1999/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.0502e-04 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.9909
# Epoch 2000/2000
# 49/49 [==============================] - 36s 731ms/step - loss: 1.4578e-04 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9922
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB4\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 21s 597ms/step - loss: 0.3231 - accuracy: 0.9482
# test_indoor_ds_results:test loss, test acc: [0.3230634033679962, 0.9481605291366577]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 34s 596ms/step - loss: 0.4842 - accuracy: 0.9255
# test_outdoor_ds_results:test loss, test acc: [0.4842141568660736, 0.9254776835441589]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 23s 616ms/step - loss: 1.1850 - accuracy: 0.8336
# test_belt_ds_results:test loss, test acc: [1.1850100755691528, 0.8336355686187744]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB4/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_145820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_132766) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_78270) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_141596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_80046) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_137742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_81764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_150563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_80751) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_78501) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_147964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_82212) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_83324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_84969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_83599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_82436) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_140923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_149785) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_142763) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_84536) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_132529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_143370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_80710) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_81555) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_146143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_82884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_80975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_143740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_83772) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_144347) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_134362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_78659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_145191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_78751) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_78934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_80435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_138608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_136205) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_145754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_81382) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_150022) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_80087) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_143911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_143977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_81423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_78710) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_149349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_84047) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_81856) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_134969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_146380) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_81606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_79547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_148135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_136528) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_142697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_139168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_79430) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_82080) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_137979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_81107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_84668) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_80527) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_135339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_149178) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_123087) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_150629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_84719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_148571) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_137135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_143133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_80486) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_85101) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_138931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_84312) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_79995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_144518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_133543) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_128718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_145561) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_150392) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_150952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_148808) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_141530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_142137) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_151123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_148742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_84495) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_82752) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_78111) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_144954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_84220) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_83375) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_133736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_132700) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_78060) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_135946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_136139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_81815) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_119509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_79598) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_145125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_81199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_138349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_140316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_83548) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_83192) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_149415) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_134903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_79389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_141359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_84444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_136699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_139102) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_132274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_141966) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_133107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_146987) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_139775) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_84928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_147594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_79822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_79331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_137913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_139709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_80659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_81988) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_83996) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_79158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_136765) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_151559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_147357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_78542) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_144584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_134732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_142203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_84271) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_83151) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_81331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_78883) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_82263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_81647) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_83640) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_82039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_151189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_146314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_140145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_80934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_82711) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_146921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_140382) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_140752) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_135576) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_133173) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_78975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_82304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_135510) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_80219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_84877) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_133802) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_78152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_82528) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_82983) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_79771) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_142526) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_81158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_84760) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_79639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_63885) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_78311) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_137306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_147528) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_149956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_80318) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_79199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_83100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_80277) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_79107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_80883) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_138542) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_82660) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_82487) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_139538) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_143304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_83864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_82942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_148201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_140989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_134296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_146750) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_83823) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_79863) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_84088) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_78443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_134125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_137372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_83416) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 19s 560ms/step - loss: 0.2600 - accuracy: 0.9470
# 50/50 [==============================] - 28s 568ms/step - loss: 0.3884 - accuracy: 0.9217
# 35/35 [==============================] - 20s 570ms/step - loss: 0.9693 - accuracy: 0.8282
# Epoch200
#  test_indoor_acc=0.9470456838607788
#  test_outdoor_acc=0.92165607213974
#  test_belt_acc=0.8281958103179932
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_262002) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_209437) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_270381) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_276920) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_276189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_267934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_272718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_273391) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_209172) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_204456) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_206074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_205186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_206680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_266179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_273998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_260529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_204731) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_206548) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_205395) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_208948) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_263103) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_268000) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_208508) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_273761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_263539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_210068) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_206283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_269101) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_210333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_262496) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_205884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_265335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_207444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_270315) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_267763) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_204680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_204298) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_269537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_204904) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference__wrapped_model_1196482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1272372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1252106) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1277115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1283549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1211348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1265297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1211098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_1274193) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1271205) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1213572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1266893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1255684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1217357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1267500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1265704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1210867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1215033) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1269362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_1277722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1215580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1215748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1212195) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1271765) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1216013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_1211755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1215539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1279347) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1268802) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1216685) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1278740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1266722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1275730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1217698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_1212684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1276944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1266333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_1215349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_1217041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1214809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_1215257) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1272979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1211480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1215125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1278158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1211572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1210708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1212368) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1211531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1280191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1273349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1269732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_1277788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1210657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1266140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_1216868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1269969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1279954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1210749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1268736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1271528) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_1217092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1283720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1279584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1213531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1214901) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1267329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1266399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1269903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1212419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1272913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_1216909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1216593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1214677) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1214244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_1216817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1274563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 22s 566ms/step - loss: 0.3231 - accuracy: 0.9482
# 50/50 [==============================] - 29s 573ms/step - loss: 0.4842 - accuracy: 0.9255
# 35/35 [==============================] - 20s 575ms/step - loss: 1.1850 - accuracy: 0.8336
# Epoch2000
#  test_indoor_acc=0.9481605291366577
#  test_outdoor_acc=0.9254776835441589
#  test_belt_acc=0.8336355686187744

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.9024245937665304
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9470456838607788,
#  0.9453734755516052,
#  0.9476031064987183,
#  0.9459308981895447,
#  0.9487179517745972,
#  0.9476031064987183,
#  0.9464883208274841,
#  0.9464883208274841,
#  0.9459308981895447,
#  0.9481605291366577]

# %%
test_outdoor_acc
# Out:
# [0.92165607213974,
#  0.9219745397567749,
#  0.9232484102249146,
#  0.9197452068328857,
#  0.9242038130760193,
#  0.9261146783828735,
#  0.9254776835441589,
#  0.9264331459999084,
#  0.9229299426078796,
#  0.9254776835441589]

# %%
test_belt_acc
# Out:
# [0.8281958103179932,
#  0.8281958103179932,
#  0.8277425169944763,
#  0.8286491632461548,
#  0.8318222761154175,
#  0.8304623961448669,
#  0.8291024565696716,
#  0.8336355686187744,
#  0.8313689827919006,
#  0.8336355686187744]

# %%
test_indoor_loss
# Out:
# [0.26003819704055786,
#  0.29036739468574524,
#  0.2786743640899658,
#  0.2878265082836151,
#  0.28234294056892395,
#  0.3006402552127838,
#  0.30266261100769043,
#  0.2957506477832794,
#  0.32138028740882874,
#  0.3230634033679962]

# %%
test_outdoor_loss
# Out:
# [0.38840895891189575,
#  0.40065237879753113,
#  0.4345156252384186,
#  0.4593372642993927,
#  0.43765318393707275,
#  0.42990365624427795,
#  0.4584437310695648,
#  0.464677631855011,
#  0.5039370656013489,
#  0.4842141568660736]

# %%
test_belt_loss
# Out:
# [0.9692705869674683,
#  1.0374661684036255,
#  1.0346218347549438,
#  1.0478891134262085,
#  1.0627638101577759,
#  1.0903743505477905,
#  1.0929076671600342,
#  1.1048293113708496,
#  1.1379544734954834,
#  1.1850100755691528]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=380
img_width=380
batch_size=2

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

N = 400

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)} are predicting")
x_indoor_sets = np.array_split(x_test_indoor, N)
del x_test_indoor
y_all_sets_predicted = []
for x in x_indoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_indoor_predicted = np.concatenate(y_all_sets_predicted)
del x_indoor_sets,test_indoor_ds

x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)} are predicting")
x_outdoor_sets = np.array_split(x_test_outdoor, N)
del x_test_outdoor
y_all_sets_predicted = []
for x in x_outdoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_outdoor_predicted = np.concatenate(y_all_sets_predicted)
del x_outdoor_sets,test_outdoor_ds

x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)} are predicting")
x_belt_sets = np.array_split(x_test_belt, N)
del x_test_belt
y_all_sets_predicted = []
for x in x_belt_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_belt_predicted = np.concatenate(y_all_sets_predicted)
del x_belt_sets,test_belt_ds

y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
y_all_predicted = np.concatenate([y_indoor_predicted,y_outdoor_predicted,y_belt_predicted],axis=0)
print(f"all num x,y :{len(y_all_predicted)},{len(y_all)}")
# Out:
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1278417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1217525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1211928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1214453) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_1281946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1212027) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1269125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1214860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1283786) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1214361) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1274734) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1278911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1213348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_1273956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1216461) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1214412) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1216644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1277181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_1270510) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_1212643) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1212144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1213796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1216420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1216145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1269296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1264871) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1211040) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1274800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1211986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1283226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1284156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1213480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1283160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1273520) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1211139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1214203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_1211796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1213256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1272306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1280561) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1212874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1265126) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1213083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_1270339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_1214020) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1265770) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1275294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1216237) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1215084) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_1213979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_1277551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1279518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1212460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1210908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1281339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1270946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_1282619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1211307) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_1211704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1281405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1278351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1275123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1276337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1273586) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1216369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_1213928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1267566) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1214152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1213032) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1280125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1272135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_1217133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1212915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_1282553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1265363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1278977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1213755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1215789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1215697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1217265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1213307) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1214585) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1282989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1261315) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_1268173) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1275901) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1272742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1217474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1213704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1215921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_1282382) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1215972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1212236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1271139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1211256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1212816) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1214636) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1217316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1268543) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1213124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_1270576) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_1281775) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1266959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1275967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_1274127) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1275360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1215481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1281168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_1267936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_1215308) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_1212592) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1271699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1217566) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1276508) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1216196) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_1268107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1280798) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_1282012) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1276574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1280732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_1196482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1272372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1252106) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1277115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1283549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1211348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1265297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1211098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_1274193) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1271205) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1213572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1266893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1255684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1217357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1267500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1265704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1210867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1215033) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1269362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_1277722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1215580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1215748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1212195) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1271765) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1216013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_1211755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1215539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1279347) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1268802) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1216685) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1278740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1266722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1275730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1217698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_1212684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1276944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1266333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_1215349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_1217041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1214809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_1215257) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1272979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1211480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1215125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1278158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1211572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1210708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1212368) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1211531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1280191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1273349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1269732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_1277788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1210657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1266140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_1216868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1269969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1279954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1210749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1268736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1271528) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_1217092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1283720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1279584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1213531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1214901) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1267329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1266399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1269903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1212419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1272913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_1216909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1216593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1214677) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1214244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_1216817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1274563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794 are predicting
# train_outdoor num x,y : 3140,3140 are predicting
# train_belt num x,y : 2206,2206 are predicting
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6446
# FP=694
# acc=0.9028011204481793
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 86.91588785046729%
# 2-BloodSecretionWaste acc = 86.68587896253602%
# 3-LabWardWaste acc = 91.77877428998505%
# 4-VaccineOtherWaste acc = 95.28257823446987%
#
#
#
# all_avg_eachclass = 90.16577983436454%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1674,  228,   12,   12],
#        [ 176, 1504,   18,   37],
#        [  38,   55, 1228,   17],
#        [  12,   58,   31, 2040]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[86.91588785, 11.83800623,  0.62305296,  0.62305296],
#        [10.14409222, 86.68587896,  1.03746398,  2.13256484],
#        [ 2.84005979,  4.11061286, 91.77877429,  1.27055306],
#        [ 0.56048575,  2.70901448,  1.44792153, 95.28257823]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
