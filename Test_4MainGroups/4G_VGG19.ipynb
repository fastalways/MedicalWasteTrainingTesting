# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.VGG19(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-4].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 25088)             20024384
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 45,719,620
# Trainable params: 25,695,236
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_VGG19/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 51s 407ms/step - loss: 2.5333 - accuracy: 0.6549 - val_loss: 0.4229 - val_accuracy: 0.8448
# Epoch 2/2000
# 49/49 [==============================] - 10s 214ms/step - loss: 0.3730 - accuracy: 0.8624 - val_loss: 0.5402 - val_accuracy: 0.8228
# Epoch 3/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 0.2682 - accuracy: 0.9021 - val_loss: 0.3605 - val_accuracy: 0.8758
# Epoch 4/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 0.2707 - accuracy: 0.8969 - val_loss: 0.5573 - val_accuracy: 0.8331
# Epoch 5/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.2140 - accuracy: 0.9186 - val_loss: 0.4304 - val_accuracy: 0.8616
# Epoch 6/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.1790 - accuracy: 0.9283 - val_loss: 0.3566 - val_accuracy: 0.8797
# Epoch 7/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.1597 - accuracy: 0.9422 - val_loss: 0.3441 - val_accuracy: 0.8862
# Epoch 8/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.1407 - accuracy: 0.9519 - val_loss: 0.4056 - val_accuracy: 0.8693
# Epoch 9/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0906 - accuracy: 0.9693 - val_loss: 0.5920 - val_accuracy: 0.8305
# Epoch 10/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.1016 - accuracy: 0.9638 - val_loss: 0.4789 - val_accuracy: 0.8668
# Epoch 11/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0801 - accuracy: 0.9751 - val_loss: 0.5194 - val_accuracy: 0.8603
# Epoch 12/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0822 - accuracy: 0.9729 - val_loss: 0.4270 - val_accuracy: 0.8758
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 13/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0558 - accuracy: 0.9838 - val_loss: 0.4066 - val_accuracy: 0.8952
# Epoch 14/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0417 - accuracy: 0.9871 - val_loss: 0.3786 - val_accuracy: 0.9069
# Epoch 15/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0386 - accuracy: 0.9874 - val_loss: 0.3718 - val_accuracy: 0.9069
# Epoch 16/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0356 - accuracy: 0.9887 - val_loss: 0.3733 - val_accuracy: 0.9082
# Epoch 17/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0325 - accuracy: 0.9916 - val_loss: 0.3839 - val_accuracy: 0.9030
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0312 - accuracy: 0.9926 - val_loss: 0.3356 - val_accuracy: 0.9082
# Epoch 19/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0301 - accuracy: 0.9929 - val_loss: 0.3338 - val_accuracy: 0.9082
# Epoch 20/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0309 - accuracy: 0.9922 - val_loss: 0.3372 - val_accuracy: 0.9094
# Epoch 21/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0290 - accuracy: 0.9922 - val_loss: 0.3340 - val_accuracy: 0.9094
# Epoch 22/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0297 - accuracy: 0.9939 - val_loss: 0.3353 - val_accuracy: 0.9094
# Epoch 23/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0305 - accuracy: 0.9919 - val_loss: 0.3311 - val_accuracy: 0.9082
# Epoch 24/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0283 - accuracy: 0.9935 - val_loss: 0.3370 - val_accuracy: 0.9094
# Epoch 25/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0287 - accuracy: 0.9926 - val_loss: 0.3343 - val_accuracy: 0.9107
# Epoch 26/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0272 - accuracy: 0.9929 - val_loss: 0.3336 - val_accuracy: 0.9120
# Epoch 27/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0279 - accuracy: 0.9929 - val_loss: 0.3399 - val_accuracy: 0.9107
# Epoch 28/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0265 - accuracy: 0.9942 - val_loss: 0.3364 - val_accuracy: 0.9107
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 29/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0257 - accuracy: 0.9945 - val_loss: 0.3386 - val_accuracy: 0.9120
# Epoch 30/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0251 - accuracy: 0.9939 - val_loss: 0.3382 - val_accuracy: 0.9120
# Epoch 31/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0256 - accuracy: 0.9945 - val_loss: 0.3391 - val_accuracy: 0.9120
# Epoch 32/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0262 - accuracy: 0.9935 - val_loss: 0.3393 - val_accuracy: 0.9094
# Epoch 33/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0250 - accuracy: 0.9939 - val_loss: 0.3388 - val_accuracy: 0.9107
# Epoch 34/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0246 - accuracy: 0.9948 - val_loss: 0.3383 - val_accuracy: 0.9120
# Epoch 35/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0251 - accuracy: 0.9942 - val_loss: 0.3386 - val_accuracy: 0.9120
# Epoch 36/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0254 - accuracy: 0.9929 - val_loss: 0.3383 - val_accuracy: 0.9120
# Epoch 37/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0246 - accuracy: 0.9926 - val_loss: 0.3383 - val_accuracy: 0.9107
# Epoch 38/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0249 - accuracy: 0.9939 - val_loss: 0.3381 - val_accuracy: 0.9107
# Epoch 39/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0259 - accuracy: 0.9945 - val_loss: 0.3380 - val_accuracy: 0.9094
# Epoch 40/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0246 - accuracy: 0.9935 - val_loss: 0.3388 - val_accuracy: 0.9094
# Epoch 41/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0239 - accuracy: 0.9942 - val_loss: 0.3398 - val_accuracy: 0.9107
# Epoch 42/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0237 - accuracy: 0.9945 - val_loss: 0.3392 - val_accuracy: 0.9107
# Epoch 43/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0253 - accuracy: 0.9945 - val_loss: 0.3365 - val_accuracy: 0.9120
# Epoch 44/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0242 - accuracy: 0.9942 - val_loss: 0.3379 - val_accuracy: 0.9107
# Epoch 45/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0248 - accuracy: 0.9935 - val_loss: 0.3384 - val_accuracy: 0.9107
# Epoch 46/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0248 - accuracy: 0.9945 - val_loss: 0.3377 - val_accuracy: 0.9120
# Epoch 47/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0244 - accuracy: 0.9932 - val_loss: 0.3383 - val_accuracy: 0.9094
# Epoch 48/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0246 - accuracy: 0.9929 - val_loss: 0.3384 - val_accuracy: 0.9107
# Epoch 49/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 0.0248 - accuracy: 0.9939 - val_loss: 0.3381 - val_accuracy: 0.9107
# Epoch 50/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0246 - accuracy: 0.9945 - val_loss: 0.3401 - val_accuracy: 0.9107
# Epoch 51/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0238 - accuracy: 0.9935 - val_loss: 0.3375 - val_accuracy: 0.9107
# Epoch 52/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0240 - accuracy: 0.9948 - val_loss: 0.3375 - val_accuracy: 0.9107
# Epoch 53/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0234 - accuracy: 0.9945 - val_loss: 0.3384 - val_accuracy: 0.9107
# Epoch 54/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0236 - accuracy: 0.9948 - val_loss: 0.3383 - val_accuracy: 0.9133
# Epoch 55/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0236 - accuracy: 0.9952 - val_loss: 0.3394 - val_accuracy: 0.9107
# Epoch 56/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0230 - accuracy: 0.9952 - val_loss: 0.3425 - val_accuracy: 0.9107
# Epoch 57/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0251 - accuracy: 0.9939 - val_loss: 0.3431 - val_accuracy: 0.9094
# Epoch 58/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0239 - accuracy: 0.9942 - val_loss: 0.3397 - val_accuracy: 0.9107
# Epoch 59/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0253 - accuracy: 0.9935 - val_loss: 0.3375 - val_accuracy: 0.9120
# Epoch 60/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0225 - accuracy: 0.9958 - val_loss: 0.3382 - val_accuracy: 0.9120
# Epoch 61/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0234 - accuracy: 0.9945 - val_loss: 0.3381 - val_accuracy: 0.9120
# Epoch 62/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0237 - accuracy: 0.9945 - val_loss: 0.3400 - val_accuracy: 0.9120
# Epoch 63/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0240 - accuracy: 0.9952 - val_loss: 0.3391 - val_accuracy: 0.9120
# Epoch 64/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0228 - accuracy: 0.9958 - val_loss: 0.3397 - val_accuracy: 0.9120
# Epoch 65/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0235 - accuracy: 0.9929 - val_loss: 0.3381 - val_accuracy: 0.9107
# Epoch 66/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0232 - accuracy: 0.9945 - val_loss: 0.3383 - val_accuracy: 0.9133
# Epoch 67/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0227 - accuracy: 0.9948 - val_loss: 0.3403 - val_accuracy: 0.9094
# Epoch 68/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.3416 - val_accuracy: 0.9069
# Epoch 69/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0228 - accuracy: 0.9932 - val_loss: 0.3397 - val_accuracy: 0.9146
# Epoch 70/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0221 - accuracy: 0.9948 - val_loss: 0.3399 - val_accuracy: 0.9120
# Epoch 71/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0236 - accuracy: 0.9948 - val_loss: 0.3400 - val_accuracy: 0.9120
# Epoch 72/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0218 - accuracy: 0.9958 - val_loss: 0.3440 - val_accuracy: 0.9082
# Epoch 73/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0227 - accuracy: 0.9961 - val_loss: 0.3396 - val_accuracy: 0.9133
# Epoch 74/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0226 - accuracy: 0.9955 - val_loss: 0.3396 - val_accuracy: 0.9133
# Epoch 75/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0215 - accuracy: 0.9948 - val_loss: 0.3417 - val_accuracy: 0.9146
# Epoch 76/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0225 - accuracy: 0.9952 - val_loss: 0.3403 - val_accuracy: 0.9133
# Epoch 77/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0221 - accuracy: 0.9948 - val_loss: 0.3418 - val_accuracy: 0.9120
# Epoch 78/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0224 - accuracy: 0.9952 - val_loss: 0.3415 - val_accuracy: 0.9133
# Epoch 79/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0216 - accuracy: 0.9952 - val_loss: 0.3428 - val_accuracy: 0.9146
# Epoch 80/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0210 - accuracy: 0.9948 - val_loss: 0.3399 - val_accuracy: 0.9133
# Epoch 81/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0227 - accuracy: 0.9945 - val_loss: 0.3412 - val_accuracy: 0.9159
# Epoch 82/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0217 - accuracy: 0.9945 - val_loss: 0.3415 - val_accuracy: 0.9133
# Epoch 83/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0207 - accuracy: 0.9948 - val_loss: 0.3422 - val_accuracy: 0.9159
# Epoch 84/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0207 - accuracy: 0.9964 - val_loss: 0.3449 - val_accuracy: 0.9146
# Epoch 85/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0201 - accuracy: 0.9958 - val_loss: 0.3440 - val_accuracy: 0.9146
# Epoch 86/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0203 - accuracy: 0.9961 - val_loss: 0.3452 - val_accuracy: 0.9120
# Epoch 87/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0210 - accuracy: 0.9945 - val_loss: 0.3479 - val_accuracy: 0.9133
# Epoch 88/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0210 - accuracy: 0.9958 - val_loss: 0.3452 - val_accuracy: 0.9146
# Epoch 89/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0223 - accuracy: 0.9961 - val_loss: 0.3415 - val_accuracy: 0.9146
# Epoch 90/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0216 - accuracy: 0.9955 - val_loss: 0.3389 - val_accuracy: 0.9159
# Epoch 91/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0194 - accuracy: 0.9961 - val_loss: 0.3470 - val_accuracy: 0.9107
# Epoch 92/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0203 - accuracy: 0.9958 - val_loss: 0.3440 - val_accuracy: 0.9146
# Epoch 93/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0206 - accuracy: 0.9961 - val_loss: 0.3422 - val_accuracy: 0.9159
# Epoch 94/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0213 - accuracy: 0.9961 - val_loss: 0.3404 - val_accuracy: 0.9159
# Epoch 95/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0197 - accuracy: 0.9958 - val_loss: 0.3466 - val_accuracy: 0.9120
# Epoch 96/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0197 - accuracy: 0.9968 - val_loss: 0.3473 - val_accuracy: 0.9120
# Epoch 97/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0200 - accuracy: 0.9961 - val_loss: 0.3422 - val_accuracy: 0.9146
# Epoch 98/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0208 - accuracy: 0.9955 - val_loss: 0.3489 - val_accuracy: 0.9133
# Epoch 99/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0208 - accuracy: 0.9958 - val_loss: 0.3476 - val_accuracy: 0.9120
# Epoch 100/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0194 - accuracy: 0.9971 - val_loss: 0.3481 - val_accuracy: 0.9120
# Epoch 101/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0190 - accuracy: 0.9964 - val_loss: 0.3478 - val_accuracy: 0.9146
# Epoch 102/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0200 - accuracy: 0.9958 - val_loss: 0.3473 - val_accuracy: 0.9107
# Epoch 103/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0191 - accuracy: 0.9964 - val_loss: 0.3472 - val_accuracy: 0.9133
# Epoch 104/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0189 - accuracy: 0.9961 - val_loss: 0.3486 - val_accuracy: 0.9107
# Epoch 105/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0189 - accuracy: 0.9971 - val_loss: 0.3454 - val_accuracy: 0.9133
# Epoch 106/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0182 - accuracy: 0.9971 - val_loss: 0.3487 - val_accuracy: 0.9133
# Epoch 107/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0194 - accuracy: 0.9952 - val_loss: 0.3512 - val_accuracy: 0.9107
# Epoch 108/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0190 - accuracy: 0.9955 - val_loss: 0.3494 - val_accuracy: 0.9146
# Epoch 109/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0192 - accuracy: 0.9952 - val_loss: 0.3509 - val_accuracy: 0.9133
# Epoch 110/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0180 - accuracy: 0.9968 - val_loss: 0.3514 - val_accuracy: 0.9133
# Epoch 111/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0184 - accuracy: 0.9952 - val_loss: 0.3529 - val_accuracy: 0.9120
# Epoch 112/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.3493 - val_accuracy: 0.9133
# Epoch 113/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0178 - accuracy: 0.9968 - val_loss: 0.3492 - val_accuracy: 0.9120
# Epoch 114/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0185 - accuracy: 0.9971 - val_loss: 0.3485 - val_accuracy: 0.9172
# Epoch 115/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0182 - accuracy: 0.9958 - val_loss: 0.3525 - val_accuracy: 0.9120
# Epoch 116/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0175 - accuracy: 0.9974 - val_loss: 0.3526 - val_accuracy: 0.9120
# Epoch 117/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0176 - accuracy: 0.9971 - val_loss: 0.3518 - val_accuracy: 0.9133
# Epoch 118/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0174 - accuracy: 0.9971 - val_loss: 0.3533 - val_accuracy: 0.9120
# Epoch 119/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0182 - accuracy: 0.9968 - val_loss: 0.3532 - val_accuracy: 0.9107
# Epoch 120/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0180 - accuracy: 0.9974 - val_loss: 0.3481 - val_accuracy: 0.9146
# Epoch 121/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0173 - accuracy: 0.9971 - val_loss: 0.3528 - val_accuracy: 0.9146
# Epoch 122/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0171 - accuracy: 0.9968 - val_loss: 0.3543 - val_accuracy: 0.9107
# Epoch 123/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0165 - accuracy: 0.9977 - val_loss: 0.3517 - val_accuracy: 0.9120
# Epoch 124/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0163 - accuracy: 0.9974 - val_loss: 0.3529 - val_accuracy: 0.9120
# Epoch 125/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0171 - accuracy: 0.9971 - val_loss: 0.3513 - val_accuracy: 0.9133
# Epoch 126/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0160 - accuracy: 0.9977 - val_loss: 0.3516 - val_accuracy: 0.9146
# Epoch 127/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0169 - accuracy: 0.9964 - val_loss: 0.3560 - val_accuracy: 0.9094
# Epoch 128/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0158 - accuracy: 0.9974 - val_loss: 0.3552 - val_accuracy: 0.9159
# Epoch 129/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0154 - accuracy: 0.9971 - val_loss: 0.3551 - val_accuracy: 0.9107
# Epoch 130/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0166 - accuracy: 0.9964 - val_loss: 0.3554 - val_accuracy: 0.9107
# Epoch 131/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0159 - accuracy: 0.9977 - val_loss: 0.3569 - val_accuracy: 0.9107
# Epoch 132/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0165 - accuracy: 0.9964 - val_loss: 0.3583 - val_accuracy: 0.9133
# Epoch 133/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0159 - accuracy: 0.9971 - val_loss: 0.3561 - val_accuracy: 0.9146
# Epoch 134/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0155 - accuracy: 0.9971 - val_loss: 0.3544 - val_accuracy: 0.9146
# Epoch 135/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0154 - accuracy: 0.9981 - val_loss: 0.3539 - val_accuracy: 0.9133
# Epoch 136/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0154 - accuracy: 0.9974 - val_loss: 0.3586 - val_accuracy: 0.9107
# Epoch 137/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0147 - accuracy: 0.9984 - val_loss: 0.3603 - val_accuracy: 0.9094
# Epoch 138/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0153 - accuracy: 0.9977 - val_loss: 0.3618 - val_accuracy: 0.9094
# Epoch 139/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0159 - accuracy: 0.9971 - val_loss: 0.3580 - val_accuracy: 0.9133
# Epoch 140/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0150 - accuracy: 0.9971 - val_loss: 0.3586 - val_accuracy: 0.9107
# Epoch 141/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0152 - accuracy: 0.9971 - val_loss: 0.3584 - val_accuracy: 0.9120
# Epoch 142/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 0.3606 - val_accuracy: 0.9146
# Epoch 143/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0141 - accuracy: 0.9977 - val_loss: 0.3610 - val_accuracy: 0.9120
# Epoch 144/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0146 - accuracy: 0.9977 - val_loss: 0.3616 - val_accuracy: 0.9120
# Epoch 145/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0149 - accuracy: 0.9971 - val_loss: 0.3587 - val_accuracy: 0.9172
# Epoch 146/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0146 - accuracy: 0.9974 - val_loss: 0.3600 - val_accuracy: 0.9133
# Epoch 147/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0147 - accuracy: 0.9977 - val_loss: 0.3648 - val_accuracy: 0.9120
# Epoch 148/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0142 - accuracy: 0.9981 - val_loss: 0.3673 - val_accuracy: 0.9120
# Epoch 149/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0136 - accuracy: 0.9981 - val_loss: 0.3650 - val_accuracy: 0.9120
# Epoch 150/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0143 - accuracy: 0.9977 - val_loss: 0.3653 - val_accuracy: 0.9133
# Epoch 151/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0143 - accuracy: 0.9974 - val_loss: 0.3672 - val_accuracy: 0.9120
# Epoch 152/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0144 - accuracy: 0.9971 - val_loss: 0.3627 - val_accuracy: 0.9120
# Epoch 153/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0136 - accuracy: 0.9981 - val_loss: 0.3662 - val_accuracy: 0.9133
# Epoch 154/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0134 - accuracy: 0.9981 - val_loss: 0.3654 - val_accuracy: 0.9133
# Epoch 155/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 0.3661 - val_accuracy: 0.9120
# Epoch 156/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0139 - accuracy: 0.9974 - val_loss: 0.3696 - val_accuracy: 0.9107
# Epoch 157/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0136 - accuracy: 0.9974 - val_loss: 0.3672 - val_accuracy: 0.9107
# Epoch 158/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0133 - accuracy: 0.9981 - val_loss: 0.3672 - val_accuracy: 0.9120
# Epoch 159/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 0.3695 - val_accuracy: 0.9094
# Epoch 160/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 0.3657 - val_accuracy: 0.9133
# Epoch 161/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0131 - accuracy: 0.9977 - val_loss: 0.3602 - val_accuracy: 0.9146
# Epoch 162/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0125 - accuracy: 0.9981 - val_loss: 0.3698 - val_accuracy: 0.9120
# Epoch 163/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0123 - accuracy: 0.9977 - val_loss: 0.3715 - val_accuracy: 0.9107
# Epoch 164/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0128 - accuracy: 0.9984 - val_loss: 0.3727 - val_accuracy: 0.9107
# Epoch 165/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0123 - accuracy: 0.9984 - val_loss: 0.3746 - val_accuracy: 0.9094
# Epoch 166/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 0.3747 - val_accuracy: 0.9120
# Epoch 167/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0119 - accuracy: 0.9987 - val_loss: 0.3741 - val_accuracy: 0.9094
# Epoch 168/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0122 - accuracy: 0.9974 - val_loss: 0.3764 - val_accuracy: 0.9094
# Epoch 169/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 0.3815 - val_accuracy: 0.9082
# Epoch 170/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0116 - accuracy: 0.9981 - val_loss: 0.3782 - val_accuracy: 0.9120
# Epoch 171/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0123 - accuracy: 0.9981 - val_loss: 0.3816 - val_accuracy: 0.9069
# Epoch 172/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0118 - accuracy: 0.9984 - val_loss: 0.3847 - val_accuracy: 0.9056
# Epoch 173/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0117 - accuracy: 0.9984 - val_loss: 0.3841 - val_accuracy: 0.9069
# Epoch 174/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0120 - accuracy: 0.9981 - val_loss: 0.3789 - val_accuracy: 0.9082
# Epoch 175/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.3842 - val_accuracy: 0.9082
# Epoch 176/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0113 - accuracy: 0.9984 - val_loss: 0.3826 - val_accuracy: 0.9082
# Epoch 177/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 0.0107 - accuracy: 0.9987 - val_loss: 0.3810 - val_accuracy: 0.9082
# Epoch 178/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 0.3845 - val_accuracy: 0.9107
# Epoch 179/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 0.0114 - accuracy: 0.9984 - val_loss: 0.3826 - val_accuracy: 0.9107
# Epoch 180/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 0.0108 - accuracy: 0.9984 - val_loss: 0.3811 - val_accuracy: 0.9082
# Epoch 181/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.3811 - val_accuracy: 0.9069
# Epoch 182/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0108 - accuracy: 0.9987 - val_loss: 0.3925 - val_accuracy: 0.9082
# Epoch 183/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0113 - accuracy: 0.9977 - val_loss: 0.3764 - val_accuracy: 0.9107
# Epoch 184/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0108 - accuracy: 0.9981 - val_loss: 0.3813 - val_accuracy: 0.9082
# Epoch 185/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0106 - accuracy: 0.9981 - val_loss: 0.3880 - val_accuracy: 0.9082
# Epoch 186/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 0.0105 - accuracy: 0.9984 - val_loss: 0.3895 - val_accuracy: 0.9094
# Epoch 187/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.3896 - val_accuracy: 0.9094
# Epoch 188/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.3866 - val_accuracy: 0.9082
# Epoch 189/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.3871 - val_accuracy: 0.9159
# Epoch 190/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.3911 - val_accuracy: 0.9107
# Epoch 191/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0098 - accuracy: 0.9987 - val_loss: 0.3919 - val_accuracy: 0.9107
# Epoch 192/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0100 - accuracy: 0.9987 - val_loss: 0.3951 - val_accuracy: 0.9094
# Epoch 193/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 0.3945 - val_accuracy: 0.9133
# Epoch 194/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.3913 - val_accuracy: 0.9120
# Epoch 195/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0103 - accuracy: 0.9987 - val_loss: 0.3993 - val_accuracy: 0.9082
# Epoch 196/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.4041 - val_accuracy: 0.9069
# Epoch 197/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.3942 - val_accuracy: 0.9094
# Epoch 198/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.3986 - val_accuracy: 0.9094
# Epoch 199/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.3981 - val_accuracy: 0.9094
# Epoch 200/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.4040 - val_accuracy: 0.9082
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_VGG19\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.4057 - val_accuracy: 0.9082
# Epoch 202/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0093 - accuracy: 0.9987 - val_loss: 0.4017 - val_accuracy: 0.9107
# Epoch 203/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.3991 - val_accuracy: 0.9107
# Epoch 204/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.4017 - val_accuracy: 0.9094
# Epoch 205/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.4002 - val_accuracy: 0.9107
# Epoch 206/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 0.4074 - val_accuracy: 0.9107
# Epoch 207/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0092 - accuracy: 0.9981 - val_loss: 0.4075 - val_accuracy: 0.9094
# Epoch 208/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.4044 - val_accuracy: 0.9107
# Epoch 209/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.4064 - val_accuracy: 0.9120
# Epoch 210/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.4090 - val_accuracy: 0.9082
# Epoch 211/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 0.4081 - val_accuracy: 0.9159
# Epoch 212/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0083 - accuracy: 0.9987 - val_loss: 0.4099 - val_accuracy: 0.9094
# Epoch 213/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0082 - accuracy: 0.9981 - val_loss: 0.4028 - val_accuracy: 0.9120
# Epoch 214/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.4115 - val_accuracy: 0.9120
# Epoch 215/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.4075 - val_accuracy: 0.9120
# Epoch 216/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0088 - accuracy: 0.9981 - val_loss: 0.4062 - val_accuracy: 0.9159
# Epoch 217/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.4084 - val_accuracy: 0.9107
# Epoch 218/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.4089 - val_accuracy: 0.9107
# Epoch 219/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0082 - accuracy: 0.9987 - val_loss: 0.4147 - val_accuracy: 0.9120
# Epoch 220/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.4168 - val_accuracy: 0.9082
# Epoch 221/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.3982 - val_accuracy: 0.9159
# Epoch 222/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.4172 - val_accuracy: 0.9082
# Epoch 223/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.4131 - val_accuracy: 0.9107
# Epoch 224/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.4056 - val_accuracy: 0.9133
# Epoch 225/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0078 - accuracy: 0.9987 - val_loss: 0.4126 - val_accuracy: 0.9120
# Epoch 226/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.4127 - val_accuracy: 0.9107
# Epoch 227/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.4123 - val_accuracy: 0.9107
# Epoch 228/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 0.4168 - val_accuracy: 0.9094
# Epoch 229/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.4186 - val_accuracy: 0.9082
# Epoch 230/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.4147 - val_accuracy: 0.9133
# Epoch 231/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0073 - accuracy: 0.9990 - val_loss: 0.4205 - val_accuracy: 0.9107
# Epoch 232/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 0.4181 - val_accuracy: 0.9120
# Epoch 233/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.4189 - val_accuracy: 0.9107
# Epoch 234/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0074 - accuracy: 0.9987 - val_loss: 0.4186 - val_accuracy: 0.9120
# Epoch 235/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.4204 - val_accuracy: 0.9120
# Epoch 236/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.4191 - val_accuracy: 0.9120
# Epoch 237/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.4201 - val_accuracy: 0.9146
# Epoch 238/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.4172 - val_accuracy: 0.9120
# Epoch 239/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.4250 - val_accuracy: 0.9107
# Epoch 240/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0068 - accuracy: 0.9987 - val_loss: 0.4266 - val_accuracy: 0.9133
# Epoch 241/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.4254 - val_accuracy: 0.9120
# Epoch 242/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.4275 - val_accuracy: 0.9120
# Epoch 243/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.4252 - val_accuracy: 0.9107
# Epoch 244/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 0.4310 - val_accuracy: 0.9107
# Epoch 245/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.4304 - val_accuracy: 0.9120
# Epoch 246/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.4326 - val_accuracy: 0.9082
# Epoch 247/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.4272 - val_accuracy: 0.9120
# Epoch 248/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0061 - accuracy: 0.9994 - val_loss: 0.4335 - val_accuracy: 0.9094
# Epoch 249/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.4314 - val_accuracy: 0.9133
# Epoch 250/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.4383 - val_accuracy: 0.9107
# Epoch 251/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.4449 - val_accuracy: 0.9094
# Epoch 252/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.4344 - val_accuracy: 0.9094
# Epoch 253/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.4350 - val_accuracy: 0.9120
# Epoch 254/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.4365 - val_accuracy: 0.9120
# Epoch 255/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.4372 - val_accuracy: 0.9120
# Epoch 256/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.4399 - val_accuracy: 0.9107
# Epoch 257/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.4423 - val_accuracy: 0.9120
# Epoch 258/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.4406 - val_accuracy: 0.9120
# Epoch 259/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.4447 - val_accuracy: 0.9120
# Epoch 260/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.4337 - val_accuracy: 0.9146
# Epoch 261/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.4448 - val_accuracy: 0.9107
# Epoch 262/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.4431 - val_accuracy: 0.9120
# Epoch 263/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.4403 - val_accuracy: 0.9120
# Epoch 264/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.4412 - val_accuracy: 0.9120
# Epoch 265/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.4382 - val_accuracy: 0.9120
# Epoch 266/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.4426 - val_accuracy: 0.9120
# Epoch 267/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.4422 - val_accuracy: 0.9120
# Epoch 268/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.4453 - val_accuracy: 0.9120
# Epoch 269/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.4505 - val_accuracy: 0.9107
# Epoch 270/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.4526 - val_accuracy: 0.9107
# Epoch 271/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.4517 - val_accuracy: 0.9120
# Epoch 272/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.4473 - val_accuracy: 0.9133
# Epoch 273/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.4519 - val_accuracy: 0.9120
# Epoch 274/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.4524 - val_accuracy: 0.9120
# Epoch 275/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.4496 - val_accuracy: 0.9107
# Epoch 276/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.4510 - val_accuracy: 0.9133
# Epoch 277/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.4529 - val_accuracy: 0.9107
# Epoch 278/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.4491 - val_accuracy: 0.9107
# Epoch 279/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.4475 - val_accuracy: 0.9120
# Epoch 280/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.4523 - val_accuracy: 0.9120
# Epoch 281/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.4567 - val_accuracy: 0.9120
# Epoch 282/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.4573 - val_accuracy: 0.9120
# Epoch 283/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.4543 - val_accuracy: 0.9120
# Epoch 284/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.4484 - val_accuracy: 0.9133
# Epoch 285/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.4529 - val_accuracy: 0.9120
# Epoch 286/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.4532 - val_accuracy: 0.9133
# Epoch 287/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.4561 - val_accuracy: 0.9120
# Epoch 288/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.4581 - val_accuracy: 0.9120
# Epoch 289/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.4602 - val_accuracy: 0.9107
# Epoch 290/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.4594 - val_accuracy: 0.9107
# Epoch 291/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.4599 - val_accuracy: 0.9120
# Epoch 292/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.4680 - val_accuracy: 0.9082
# Epoch 293/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.4637 - val_accuracy: 0.9107
# Epoch 294/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.4673 - val_accuracy: 0.9082
# Epoch 295/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.4669 - val_accuracy: 0.9094
# Epoch 296/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.4654 - val_accuracy: 0.9107
# Epoch 297/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.4693 - val_accuracy: 0.9069
# Epoch 298/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.4723 - val_accuracy: 0.9069
# Epoch 299/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.4699 - val_accuracy: 0.9069
# Epoch 300/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.4802 - val_accuracy: 0.9056
# Epoch 301/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.4746 - val_accuracy: 0.9094
# Epoch 302/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.4721 - val_accuracy: 0.9069
# Epoch 303/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.4722 - val_accuracy: 0.9082
# Epoch 304/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.4778 - val_accuracy: 0.9082
# Epoch 305/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.4742 - val_accuracy: 0.9082
# Epoch 306/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.4735 - val_accuracy: 0.9120
# Epoch 307/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.4788 - val_accuracy: 0.9082
# Epoch 308/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.4772 - val_accuracy: 0.9056
# Epoch 309/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.4772 - val_accuracy: 0.9082
# Epoch 310/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.4826 - val_accuracy: 0.9069
# Epoch 311/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.4815 - val_accuracy: 0.9069
# Epoch 312/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.4762 - val_accuracy: 0.9094
# Epoch 313/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.4863 - val_accuracy: 0.9069
# Epoch 314/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.4816 - val_accuracy: 0.9069
# Epoch 315/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.4772 - val_accuracy: 0.9107
# Epoch 316/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.4871 - val_accuracy: 0.9069
# Epoch 317/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.4767 - val_accuracy: 0.9107
# Epoch 318/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.4821 - val_accuracy: 0.9107
# Epoch 319/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.4820 - val_accuracy: 0.9094
# Epoch 320/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.4838 - val_accuracy: 0.9107
# Epoch 321/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.4820 - val_accuracy: 0.9107
# Epoch 322/2000
# 49/49 [==============================] - 10s 210ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.4805 - val_accuracy: 0.9107
# Epoch 323/2000
# 49/49 [==============================] - 10s 209ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.4925 - val_accuracy: 0.9082
# Epoch 324/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6643e-07 - accuracy: 1.0000 - val_loss: 1.1826 - val_accuracy: 0.8991
# Epoch 1898/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.5678e-07 - accuracy: 1.0000 - val_loss: 1.1838 - val_accuracy: 0.9004
# Epoch 1899/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.7099e-07 - accuracy: 1.0000 - val_loss: 1.1744 - val_accuracy: 0.9017
# Epoch 1900/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4979e-07 - accuracy: 1.0000 - val_loss: 1.1772 - val_accuracy: 0.9004
# Epoch 1901/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.6510e-07 - accuracy: 1.0000 - val_loss: 1.1788 - val_accuracy: 0.8991
# Epoch 1902/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 2.0105e-07 - accuracy: 1.0000 - val_loss: 1.1833 - val_accuracy: 0.8991
# Epoch 1903/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6600e-07 - accuracy: 1.0000 - val_loss: 1.1812 - val_accuracy: 0.9017
# Epoch 1904/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.1177e-07 - accuracy: 1.0000 - val_loss: 1.1888 - val_accuracy: 0.8991
# Epoch 1905/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6774e-07 - accuracy: 1.0000 - val_loss: 1.1918 - val_accuracy: 0.8991
# Epoch 1906/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8168e-07 - accuracy: 1.0000 - val_loss: 1.1913 - val_accuracy: 0.8978
# Epoch 1907/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.2442e-07 - accuracy: 1.0000 - val_loss: 1.2010 - val_accuracy: 0.8978
# Epoch 1908/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 2.2416e-07 - accuracy: 1.0000 - val_loss: 1.1940 - val_accuracy: 0.8991
# Epoch 1909/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5152e-07 - accuracy: 1.0000 - val_loss: 1.1996 - val_accuracy: 0.8965
# Epoch 1910/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.8231e-07 - accuracy: 1.0000 - val_loss: 1.2299 - val_accuracy: 0.8978
# Epoch 1911/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5433e-07 - accuracy: 1.0000 - val_loss: 1.2181 - val_accuracy: 0.8978
# Epoch 1912/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.3371e-07 - accuracy: 1.0000 - val_loss: 1.2131 - val_accuracy: 0.8965
# Epoch 1913/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8950e-07 - accuracy: 1.0000 - val_loss: 1.2003 - val_accuracy: 0.9004
# Epoch 1914/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.7642e-07 - accuracy: 1.0000 - val_loss: 1.2096 - val_accuracy: 0.9004
# Epoch 1915/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 3.6656e-07 - accuracy: 1.0000 - val_loss: 1.2212 - val_accuracy: 0.9004A
# Epoch 1916/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 1.8934e-07 - accuracy: 1.0000 - val_loss: 1.2072 - val_accuracy: 0.8965
# Epoch 1917/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 3.5514e-07 - accuracy: 1.0000 - val_loss: 1.2007 - val_accuracy: 0.8991
# Epoch 1918/2000
# 49/49 [==============================] - 10s 213ms/step - loss: 3.8992e-07 - accuracy: 1.0000 - val_loss: 1.2167 - val_accuracy: 0.9030
# Epoch 1919/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.8575e-07 - accuracy: 1.0000 - val_loss: 1.1889 - val_accuracy: 0.9004
# Epoch 1920/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.7379e-07 - accuracy: 1.0000 - val_loss: 1.2019 - val_accuracy: 0.9004
# Epoch 1921/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8792e-07 - accuracy: 1.0000 - val_loss: 1.2052 - val_accuracy: 0.8978
# Epoch 1922/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6054e-07 - accuracy: 1.0000 - val_loss: 1.2100 - val_accuracy: 0.8965
# Epoch 1923/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4051e-07 - accuracy: 1.0000 - val_loss: 1.2080 - val_accuracy: 0.8978
# Epoch 1924/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4555e-07 - accuracy: 1.0000 - val_loss: 1.2059 - val_accuracy: 0.8991
# Epoch 1925/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.7841e-07 - accuracy: 1.0000 - val_loss: 1.2039 - val_accuracy: 0.8991
# Epoch 1926/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4120e-07 - accuracy: 1.0000 - val_loss: 1.2053 - val_accuracy: 0.8978
# Epoch 1927/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.1798e-07 - accuracy: 1.0000 - val_loss: 1.2108 - val_accuracy: 0.8978
# Epoch 1928/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.3968e-07 - accuracy: 1.0000 - val_loss: 1.2081 - val_accuracy: 0.8991
# Epoch 1929/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.9939e-07 - accuracy: 1.0000 - val_loss: 1.2134 - val_accuracy: 0.8965
# Epoch 1930/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.6389e-07 - accuracy: 1.0000 - val_loss: 1.1895 - val_accuracy: 0.8978 1s - loss: 2.993
# Epoch 1931/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4397e-07 - accuracy: 1.0000 - val_loss: 1.1958 - val_accuracy: 0.9004
# Epoch 1932/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.1628e-07 - accuracy: 1.0000 - val_loss: 1.2028 - val_accuracy: 0.8978
# Epoch 1933/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5661e-07 - accuracy: 1.0000 - val_loss: 1.2043 - val_accuracy: 0.8991
# Epoch 1934/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4166e-07 - accuracy: 1.0000 - val_loss: 1.2049 - val_accuracy: 0.8965
# Epoch 1935/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.6387e-07 - accuracy: 1.0000 - val_loss: 1.2039 - val_accuracy: 0.8978
# Epoch 1936/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6050e-07 - accuracy: 1.0000 - val_loss: 1.2094 - val_accuracy: 0.8965
# Epoch 1937/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 8.2490e-07 - accuracy: 1.0000 - val_loss: 1.2488 - val_accuracy: 0.9030
# Epoch 1938/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 4.2709e-07 - accuracy: 1.0000 - val_loss: 1.2030 - val_accuracy: 0.8978
# Epoch 1939/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.7875e-07 - accuracy: 1.0000 - val_loss: 1.2136 - val_accuracy: 0.8965
# Epoch 1940/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.4892e-07 - accuracy: 1.0000 - val_loss: 1.2119 - val_accuracy: 0.8978
# Epoch 1941/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8931e-07 - accuracy: 1.0000 - val_loss: 1.2167 - val_accuracy: 0.8965
# Epoch 1942/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6700e-07 - accuracy: 1.0000 - val_loss: 1.2207 - val_accuracy: 0.8978
# Epoch 1943/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6720e-07 - accuracy: 1.0000 - val_loss: 1.2140 - val_accuracy: 0.8965
# Epoch 1944/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.0654e-07 - accuracy: 1.0000 - val_loss: 1.2126 - val_accuracy: 0.8978
# Epoch 1945/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.0607e-07 - accuracy: 1.0000 - val_loss: 1.2131 - val_accuracy: 0.8978
# Epoch 1946/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.2945e-07 - accuracy: 1.0000 - val_loss: 1.2130 - val_accuracy: 0.8978
# Epoch 1947/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 4.1594e-07 - accuracy: 1.0000 - val_loss: 1.2135 - val_accuracy: 0.9030
# Epoch 1948/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 5.6773e-07 - accuracy: 1.0000 - val_loss: 1.1970 - val_accuracy: 0.8978
# Epoch 1949/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.1433e-07 - accuracy: 1.0000 - val_loss: 1.2014 - val_accuracy: 0.8965
# Epoch 1950/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.3230e-07 - accuracy: 1.0000 - val_loss: 1.2215 - val_accuracy: 0.8965
# Epoch 1951/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5676e-07 - accuracy: 1.0000 - val_loss: 1.2155 - val_accuracy: 0.8965
# Epoch 1952/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.0673e-07 - accuracy: 1.0000 - val_loss: 1.2415 - val_accuracy: 0.8965
# Epoch 1953/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6974e-07 - accuracy: 1.0000 - val_loss: 1.2249 - val_accuracy: 0.8978
# Epoch 1954/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.6077e-07 - accuracy: 1.0000 - val_loss: 1.2314 - val_accuracy: 0.8978
# Epoch 1955/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.7703e-07 - accuracy: 1.0000 - val_loss: 1.2291 - val_accuracy: 0.8991
# Epoch 1956/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5716e-06 - accuracy: 1.0000 - val_loss: 1.1751 - val_accuracy: 0.8965
# Epoch 1957/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 4.8135e-07 - accuracy: 1.0000 - val_loss: 1.1922 - val_accuracy: 0.8991
# Epoch 1958/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.3374e-07 - accuracy: 1.0000 - val_loss: 1.2085 - val_accuracy: 0.8978
# Epoch 1959/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.8047e-07 - accuracy: 1.0000 - val_loss: 1.1997 - val_accuracy: 0.9004
# Epoch 1960/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4779e-07 - accuracy: 1.0000 - val_loss: 1.2023 - val_accuracy: 0.8991
# Epoch 1961/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.9863e-07 - accuracy: 1.0000 - val_loss: 1.1948 - val_accuracy: 0.8978
# Epoch 1962/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.2814e-07 - accuracy: 1.0000 - val_loss: 1.1986 - val_accuracy: 0.8991
# Epoch 1963/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8152e-07 - accuracy: 1.0000 - val_loss: 1.1994 - val_accuracy: 0.9004
# Epoch 1964/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.9027e-07 - accuracy: 1.0000 - val_loss: 1.2132 - val_accuracy: 0.8965
# Epoch 1965/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8064e-07 - accuracy: 1.0000 - val_loss: 1.2194 - val_accuracy: 0.8978
# Epoch 1966/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.3494e-07 - accuracy: 1.0000 - val_loss: 1.2061 - val_accuracy: 0.8965
# Epoch 1967/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8661e-07 - accuracy: 1.0000 - val_loss: 1.1889 - val_accuracy: 0.9004
# Epoch 1968/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4775e-07 - accuracy: 1.0000 - val_loss: 1.1945 - val_accuracy: 0.8991
# Epoch 1969/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4621e-07 - accuracy: 1.0000 - val_loss: 1.1946 - val_accuracy: 0.9004
# Epoch 1970/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.7879e-07 - accuracy: 1.0000 - val_loss: 1.1896 - val_accuracy: 0.9004
# Epoch 1971/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.3834e-07 - accuracy: 1.0000 - val_loss: 1.2044 - val_accuracy: 0.8978
# Epoch 1972/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 7.5184e-08 - accuracy: 1.0000 - val_loss: 1.2027 - val_accuracy: 0.8991
# Epoch 1973/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.6819e-07 - accuracy: 1.0000 - val_loss: 1.2383 - val_accuracy: 0.8991
# Epoch 1974/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.7213e-07 - accuracy: 1.0000 - val_loss: 1.2186 - val_accuracy: 0.8978
# Epoch 1975/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 1.8780e-07 - accuracy: 1.0000 - val_loss: 1.2004 - val_accuracy: 0.8991
# Epoch 1976/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8434e-07 - accuracy: 1.0000 - val_loss: 1.2063 - val_accuracy: 0.9004
# Epoch 1977/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.2036e-07 - accuracy: 1.0000 - val_loss: 1.2029 - val_accuracy: 0.8991
# Epoch 1978/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.3361e-07 - accuracy: 1.0000 - val_loss: 1.1888 - val_accuracy: 0.8991
# Epoch 1979/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.0981e-07 - accuracy: 1.0000 - val_loss: 1.1877 - val_accuracy: 0.9004
# Epoch 1980/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.3294e-07 - accuracy: 1.0000 - val_loss: 1.1941 - val_accuracy: 0.8991
# Epoch 1981/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.3369e-07 - accuracy: 1.0000 - val_loss: 1.2007 - val_accuracy: 0.8978
# Epoch 1982/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 1.4640e-07 - accuracy: 1.0000 - val_loss: 1.2035 - val_accuracy: 0.8978
# Epoch 1983/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5680e-07 - accuracy: 1.0000 - val_loss: 1.2024 - val_accuracy: 0.8991
# Epoch 1984/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.3465e-07 - accuracy: 1.0000 - val_loss: 1.2092 - val_accuracy: 0.8991
# Epoch 1985/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 8.7047e-08 - accuracy: 1.0000 - val_loss: 1.2093 - val_accuracy: 0.8978
# Epoch 1986/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.2214e-07 - accuracy: 1.0000 - val_loss: 1.2014 - val_accuracy: 0.8978
# Epoch 1987/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.7444e-07 - accuracy: 1.0000 - val_loss: 1.2488 - val_accuracy: 0.9030
# Epoch 1988/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.5811e-07 - accuracy: 1.0000 - val_loss: 1.2112 - val_accuracy: 0.8991
# Epoch 1989/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4655e-07 - accuracy: 1.0000 - val_loss: 1.2123 - val_accuracy: 0.8991
# Epoch 1990/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.3596e-07 - accuracy: 1.0000 - val_loss: 1.2122 - val_accuracy: 0.8991
# Epoch 1991/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 1.4293e-07 - accuracy: 1.0000 - val_loss: 1.2328 - val_accuracy: 0.8991
# Epoch 1992/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.4521e-07 - accuracy: 1.0000 - val_loss: 1.2313 - val_accuracy: 0.8991
# Epoch 1993/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 3.6112e-07 - accuracy: 1.0000 - val_loss: 1.1836 - val_accuracy: 0.9017
# Epoch 1994/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.7009e-07 - accuracy: 1.0000 - val_loss: 1.1924 - val_accuracy: 0.9043
# Epoch 1995/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8430e-07 - accuracy: 1.0000 - val_loss: 1.2148 - val_accuracy: 0.9017
# Epoch 1996/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.8811e-07 - accuracy: 1.0000 - val_loss: 1.2078 - val_accuracy: 0.9004
# Epoch 1997/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.0371e-07 - accuracy: 1.0000 - val_loss: 1.2139 - val_accuracy: 0.9004
# Epoch 1998/2000
# 49/49 [==============================] - 10s 211ms/step - loss: 2.3763e-07 - accuracy: 1.0000 - val_loss: 1.1987 - val_accuracy: 0.8991
# Epoch 1999/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 2.1746e-07 - accuracy: 1.0000 - val_loss: 1.2028 - val_accuracy: 0.8991
# Epoch 2000/2000
# 49/49 [==============================] - 10s 212ms/step - loss: 1.3743e-07 - accuracy: 1.0000 - val_loss: 1.1939 - val_accuracy: 0.8991
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_VGG19\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 336ms/step - loss: 5.0210 - accuracy: 0.7046
# test_indoor_ds_results:test loss, test acc: [5.021036148071289, 0.7045707702636719]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 422ms/step - loss: 6.7303 - accuracy: 0.6430
# test_outdoor_ds_results:test loss, test acc: [6.730277061462402, 0.6429936289787292]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 12s 299ms/step - loss: 5.3642 - accuracy: 0.6587
# test_belt_ds_results:test loss, test acc: [5.364150524139404, 0.6586582064628601]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG19/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 162ms/step - loss: 1.5247 - accuracy: 0.7196
# 50/50 [==============================] - 8s 165ms/step - loss: 2.0853 - accuracy: 0.6516
# 35/35 [==============================] - 6s 165ms/step - loss: 1.6971 - accuracy: 0.6818
# Epoch200
#  test_indoor_acc=0.719620943069458
#  test_outdoor_acc=0.6515923738479614
#  test_belt_acc=0.6817770004272461
# 29/29 [==============================] - 5s 162ms/step - loss: 2.1864 - accuracy: 0.7196
# 50/50 [==============================] - 8s 165ms/step - loss: 2.9376 - accuracy: 0.6468
# 35/35 [==============================] - 6s 165ms/step - loss: 2.3929 - accuracy: 0.6759
# Epoch400
#  test_indoor_acc=0.719620943069458
#  test_outdoor_acc=0.646815299987793
#  test_belt_acc=0.675883948802948
# 29/29 [==============================] - 5s 162ms/step - loss: 2.8232 - accuracy: 0.7140
# 50/50 [==============================] - 8s 165ms/step - loss: 3.7807 - accuracy: 0.6455
# 35/35 [==============================] - 6s 165ms/step - loss: 3.0543 - accuracy: 0.6695
# Epoch600
#  test_indoor_acc=0.714046835899353
#  test_outdoor_acc=0.6455414295196533
#  test_belt_acc=0.6695376038551331
# 29/29 [==============================] - 5s 162ms/step - loss: 3.3811 - accuracy: 0.7107
# 50/50 [==============================] - 8s 165ms/step - loss: 4.5591 - accuracy: 0.6449
# 35/35 [==============================] - 6s 165ms/step - loss: 3.6361 - accuracy: 0.6636
# Epoch800
#  test_indoor_acc=0.7107023596763611
#  test_outdoor_acc=0.6449044346809387
#  test_belt_acc=0.6636446118354797
# 29/29 [==============================] - 5s 163ms/step - loss: 3.8491 - accuracy: 0.7096
# 50/50 [==============================] - 8s 166ms/step - loss: 5.1813 - accuracy: 0.6433
# 35/35 [==============================] - 6s 166ms/step - loss: 4.1302 - accuracy: 0.6641
# Epoch1000
#  test_indoor_acc=0.7095875144004822
#  test_outdoor_acc=0.6433120965957642
#  test_belt_acc=0.6640979051589966
# 29/29 [==============================] - 5s 162ms/step - loss: 4.2282 - accuracy: 0.7096
# 50/50 [==============================] - 8s 165ms/step - loss: 5.6801 - accuracy: 0.6439
# 35/35 [==============================] - 6s 166ms/step - loss: 4.5025 - accuracy: 0.6627
# Epoch1200
#  test_indoor_acc=0.7095875144004822
#  test_outdoor_acc=0.643949031829834
#  test_belt_acc=0.6627379655838013
# 29/29 [==============================] - 5s 162ms/step - loss: 4.4336 - accuracy: 0.7074
# 50/50 [==============================] - 8s 165ms/step - loss: 5.8942 - accuracy: 0.6417
# 35/35 [==============================] - 6s 165ms/step - loss: 4.7486 - accuracy: 0.6614
# Epoch1400
#  test_indoor_acc=0.7073578834533691
#  test_outdoor_acc=0.6417197585105896
#  test_belt_acc=0.6613780856132507
# 29/29 [==============================] - 5s 163ms/step - loss: 4.7173 - accuracy: 0.7085
# 50/50 [==============================] - 8s 166ms/step - loss: 6.3658 - accuracy: 0.6439
# 35/35 [==============================] - 6s 167ms/step - loss: 5.0394 - accuracy: 0.6591
# Epoch1600
#  test_indoor_acc=0.7084726691246033
#  test_outdoor_acc=0.643949031829834
#  test_belt_acc=0.659111499786377
# 29/29 [==============================] - 5s 164ms/step - loss: 4.9333 - accuracy: 0.7085
# 50/50 [==============================] - 8s 166ms/step - loss: 6.6591 - accuracy: 0.6433
# 35/35 [==============================] - 6s 167ms/step - loss: 5.2542 - accuracy: 0.6605
# Epoch1800
#  test_indoor_acc=0.7084726691246033
#  test_outdoor_acc=0.6433120965957642
#  test_belt_acc=0.6604714393615723
# 29/29 [==============================] - 5s 162ms/step - loss: 5.0210 - accuracy: 0.7046
# 50/50 [==============================] - 8s 165ms/step - loss: 6.7303 - accuracy: 0.6430
# 35/35 [==============================] - 6s 166ms/step - loss: 5.3642 - accuracy: 0.6587
# Epoch2000
#  test_indoor_acc=0.7045707702636719
#  test_outdoor_acc=0.6429936289787292
#  test_belt_acc=0.6586582064628601

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.6843301057815552
# max index -> 0
# The [Epoch] of max acc -> 200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.719620943069458,
#  0.719620943069458,
#  0.714046835899353,
#  0.7107023596763611,
#  0.7095875144004822,
#  0.7095875144004822,
#  0.7073578834533691,
#  0.7084726691246033,
#  0.7084726691246033,
#  0.7045707702636719]

# %%
test_outdoor_acc
# Out:
# [0.6515923738479614,
#  0.646815299987793,
#  0.6455414295196533,
#  0.6449044346809387,
#  0.6433120965957642,
#  0.643949031829834,
#  0.6417197585105896,
#  0.643949031829834,
#  0.6433120965957642,
#  0.6429936289787292]

# %%
test_belt_acc
# Out:
# [0.6817770004272461,
#  0.675883948802948,
#  0.6695376038551331,
#  0.6636446118354797,
#  0.6640979051589966,
#  0.6627379655838013,
#  0.6613780856132507,
#  0.659111499786377,
#  0.6604714393615723,
#  0.6586582064628601]

# %%
test_indoor_loss
# Out:
# [1.5247166156768799,
#  2.1864371299743652,
#  2.823166608810425,
#  3.3810904026031494,
#  3.8491365909576416,
#  4.228245258331299,
#  4.433594703674316,
#  4.717349529266357,
#  4.933317184448242,
#  5.021036148071289]

# %%
test_outdoor_loss
# Out:
# [2.0852646827697754,
#  2.9375650882720947,
#  3.780665397644043,
#  4.559141159057617,
#  5.181347846984863,
#  5.68007230758667,
#  5.894214630126953,
#  6.365830421447754,
#  6.659092426300049,
#  6.730277061462402]

# %%
test_belt_loss
# Out:
# [1.6970925331115723,
#  2.3928608894348145,
#  3.0543394088745117,
#  3.636138677597046,
#  4.130209445953369,
#  4.5024518966674805,
#  4.7486443519592285,
#  5.039401054382324,
#  5.2541608810424805,
#  5.364150524139404]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg19 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 100
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=4841
# FP=2299
# acc=0.6780112044817928
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 87.64278296988577%
# 2-BloodSecretionWaste acc = 40.92219020172911%
# 3-LabWardWaste acc = 42.89985052316891%
# 4-VaccineOtherWaste acc = 87.29565623540402%
#
#
#
# all_avg_eachclass = 64.69011998254696%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1688,  105,   15,  118],
#        [ 787,  710,   39,  199],
#        [ 189,  225,  574,  350],
#        [ 137,   67,   68, 1869]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[87.64278297,  5.4517134 ,  0.7788162 ,  6.12668744],
#        [45.36023055, 40.9221902 ,  2.24783862, 11.46974063],
#        [14.12556054, 16.8161435 , 42.89985052, 26.15844544],
#        [ 6.39887903,  3.12937879,  3.17608594, 87.29565624]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
