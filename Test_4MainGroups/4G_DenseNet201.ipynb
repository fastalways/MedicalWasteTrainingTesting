# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.densenet import DenseNet201,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.DenseNet201(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 114, 114, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 56, 56, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 56, 56, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 56, 56, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 56, 56, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 56, 56, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 56, 56, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 56, 56, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 56, 56, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 56, 56, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 56, 56, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 56, 56, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 56, 56, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 56, 56, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 56, 56, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 56, 56, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 56, 56, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 56, 56, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 56, 56, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 56, 56, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 56, 56, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 56, 56, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 56, 56, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 56, 56, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 56, 56, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 28, 28, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 28, 28, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 28, 28, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 28, 28, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 28, 28, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 28, 28, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 28, 28, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 28, 28, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 28, 28, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 28, 28, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 28, 28, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 28, 28, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 28, 28, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 28, 28, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 28, 28, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 28, 28, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 28, 28, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 28, 28, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 28, 28, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 28, 28, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 28, 28, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 28, 28, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 28, 28, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 28, 28, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 28, 28, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 28, 28, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 28, 28, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 28, 28, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 28, 28, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 28, 28, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 28, 28, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 28, 28, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 28, 28, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 28, 28, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 28, 28, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 28, 28, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 28, 28, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 28, 28, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 28, 28, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 28, 28, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 28, 28, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 28, 28, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 28, 28, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 14, 14, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 14, 14, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 14, 14, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 14, 14, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 14, 14, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 14, 14, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 14, 14, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 14, 14, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 14, 14, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 14, 14, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 14, 14, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 14, 14, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 14, 14, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 14, 14, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 14, 14, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 14, 14, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 14, 14, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 14, 14, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 14, 14, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 14, 14, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 14, 14, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 14, 14, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 14, 14, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 14, 14, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 14, 14, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 14, 14, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 14, 14, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 14, 14, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 14, 14, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 14, 14, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 14, 14, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 14, 14, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 14, 14, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 14, 14, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 14, 14, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 14, 14, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 14, 14, 640)  2560        conv4_block12_concat[0][0]
# ...
# conv5_block22_concat (Concatena (None, 7, 7, 1600)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 7, 7, 1600)   6400        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 7, 7, 1600)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 7, 7, 128)    204800      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 7, 7, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 7, 7, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 7, 7, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 7, 7, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 7, 7, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 7, 7, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 7, 7, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 7, 7, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 7, 7, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 7, 7, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 7, 7, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 7, 7, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 7, 7, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 7, 7, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 7, 7, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 7, 7, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 7, 7, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 7, 7, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 7, 7, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 7, 7, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 7, 7, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 7, 7, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 7, 7, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 7, 7, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 7, 7, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 7, 7, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 7, 7, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 7, 7, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 7, 7, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 7, 7, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 7, 7, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 7, 7, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 7, 7, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 7, 7, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 7, 7, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 7, 7, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 7, 7, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 7, 7, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 7, 7, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1920)         0           relu[0][0]
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 0
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1920)              18321984
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1967104
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 20,293,188
# Trainable params: 1,971,204
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_DenseNet201/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 55s 460ms/step - loss: 0.4399 - accuracy: 0.8468 - val_loss: 0.1765 - val_accuracy: 0.9327
# Epoch 2/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.1679 - accuracy: 0.9431 - val_loss: 0.1682 - val_accuracy: 0.9483
# Epoch 3/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.1040 - accuracy: 0.9641 - val_loss: 0.2142 - val_accuracy: 0.9353
# Epoch 4/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0901 - accuracy: 0.9645 - val_loss: 0.1062 - val_accuracy: 0.9651
# Epoch 5/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0572 - accuracy: 0.9800 - val_loss: 0.1150 - val_accuracy: 0.9586
# Epoch 6/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0311 - accuracy: 0.9919 - val_loss: 0.0975 - val_accuracy: 0.9638
# Epoch 7/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0197 - accuracy: 0.9964 - val_loss: 0.1215 - val_accuracy: 0.9677
# Epoch 8/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0142 - accuracy: 0.9971 - val_loss: 0.1693 - val_accuracy: 0.9534
# Epoch 9/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0094 - accuracy: 0.9994 - val_loss: 0.1112 - val_accuracy: 0.9664
# Epoch 10/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0077 - accuracy: 0.9990 - val_loss: 0.1089 - val_accuracy: 0.9664
# Epoch 11/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 0.1061 - val_accuracy: 0.9664
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 12/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9690
# Epoch 13/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9715
# Epoch 14/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9702
# Epoch 15/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 0.9702
# Epoch 16/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 0.9702
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 17/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9715
# Epoch 18/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9715
# Epoch 19/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9715
# Epoch 20/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9715
# Epoch 21/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9702
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 22/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9702
# Epoch 23/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1005 - val_accuracy: 0.9702
# Epoch 24/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9702
# Epoch 25/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9702
# Epoch 26/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9702
# Epoch 27/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9715
# Epoch 28/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9715
# Epoch 29/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9702
# Epoch 30/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9715
# Epoch 31/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9702
# Epoch 32/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9702
# Epoch 33/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9702
# Epoch 34/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9702
# Epoch 35/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9702
# Epoch 36/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9702
# Epoch 37/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9702
# Epoch 38/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9702
# Epoch 39/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9702
# Epoch 40/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9702
# Epoch 41/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9702
# Epoch 42/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9702
# Epoch 43/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9702
# Epoch 44/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9702
# Epoch 45/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9702
# Epoch 46/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9702
# Epoch 47/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9702
# Epoch 48/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9702
# Epoch 49/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9715
# Epoch 50/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9715
# Epoch 51/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9715
# Epoch 52/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9715
# Epoch 53/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9715
# Epoch 54/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9715
# Epoch 55/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9715
# Epoch 56/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9715
# Epoch 57/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9715
# Epoch 58/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9715
# Epoch 59/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9715
# Epoch 60/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9715
# Epoch 61/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9702
# Epoch 62/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9702
# Epoch 63/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9702
# Epoch 64/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9702
# Epoch 65/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9715
# Epoch 66/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9715
# Epoch 67/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1023 - val_accuracy: 0.9715
# Epoch 68/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9715
# Epoch 69/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9715
# Epoch 70/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9715
# Epoch 71/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9715
# Epoch 72/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9715
# Epoch 73/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9715
# Epoch 74/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9715
# Epoch 75/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9715
# Epoch 76/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9715
# Epoch 77/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9715
# Epoch 78/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9715
# Epoch 79/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9715
# Epoch 80/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9715
# Epoch 81/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9702
# Epoch 82/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9702
# Epoch 83/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9715
# Epoch 84/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9702
# Epoch 85/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9702
# Epoch 86/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9715
# Epoch 87/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9702
# Epoch 88/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9715
# Epoch 89/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9715
# Epoch 90/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9715
# Epoch 91/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9715
# Epoch 92/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9715
# Epoch 93/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9715
# Epoch 94/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9715
# Epoch 95/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9715
# Epoch 96/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9715
# Epoch 97/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9715
# Epoch 98/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9715
# Epoch 99/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9715
# Epoch 100/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9715
# Epoch 101/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1044 - val_accuracy: 0.9715
# Epoch 102/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9715
# Epoch 103/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9715
# Epoch 104/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9715
# Epoch 105/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9715
# Epoch 106/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9715
# Epoch 107/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9715
# Epoch 108/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9715
# Epoch 109/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9715
# Epoch 110/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 0.9715
# Epoch 111/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9715
# Epoch 112/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 9.9358e-04 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9715
# Epoch 113/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9715
# Epoch 114/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 9.6147e-04 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 0.9715
# Epoch 115/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 0.9715
# Epoch 116/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9715
# Epoch 117/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 9.9503e-04 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 0.9728
# Epoch 118/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9715
# Epoch 119/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 9.4533e-04 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9715
# Epoch 120/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 9.5659e-04 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9715
# Epoch 121/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9715
# Epoch 122/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 9.0532e-04 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9715
# Epoch 123/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 9.3278e-04 - accuracy: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9715
# Epoch 124/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 8.7561e-04 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9715
# Epoch 125/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 9.2422e-04 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 0.9715
# Epoch 126/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.6124e-04 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9715
# Epoch 127/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.0550e-04 - accuracy: 1.0000 - val_loss: 0.1063 - val_accuracy: 0.9715
# Epoch 128/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.2008e-04 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9715
# Epoch 129/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.2625e-04 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9715
# Epoch 130/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 9.3312e-04 - accuracy: 1.0000 - val_loss: 0.1063 - val_accuracy: 0.9715
# Epoch 131/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.6874e-04 - accuracy: 1.0000 - val_loss: 0.1068 - val_accuracy: 0.9715
# Epoch 132/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.0556e-04 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.9715
# Epoch 133/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.0560e-04 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9715
# Epoch 134/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.4636e-04 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9715
# Epoch 135/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.1979e-04 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9715
# Epoch 136/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 8.5310e-04 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 0.9715
# Epoch 137/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.7999e-04 - accuracy: 1.0000 - val_loss: 0.1068 - val_accuracy: 0.9715
# Epoch 138/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.2056e-04 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9715
# Epoch 139/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.4131e-04 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9728
# Epoch 140/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.4068e-04 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9728
# Epoch 141/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.5461e-04 - accuracy: 1.0000 - val_loss: 0.1075 - val_accuracy: 0.9715
# Epoch 142/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.5078e-04 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 0.9728
# Epoch 143/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.9039e-04 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 0.9728
# Epoch 144/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.8899e-04 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9715
# Epoch 145/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.7128e-04 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 0.9715
# Epoch 146/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.7256e-04 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9728
# Epoch 147/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 7.0272e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9728
# Epoch 148/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.3769e-04 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9728
# Epoch 149/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.8477e-04 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9728
# Epoch 150/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.3158e-04 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9728
# Epoch 151/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.9890e-04 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9728
# Epoch 152/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.1214e-04 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9728
# Epoch 153/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.6992e-04 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9728
# Epoch 154/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.8423e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9728
# Epoch 155/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.9429e-04 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9728
# Epoch 156/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.0648e-04 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9728
# Epoch 157/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 5.4958e-04 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9728
# Epoch 158/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 5.9263e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9728
# Epoch 159/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.5408e-04 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9728
# Epoch 160/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.6247e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9728
# Epoch 161/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.9505e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9728
# Epoch 162/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.4749e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9715
# Epoch 163/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.5472e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9715
# Epoch 164/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.5980e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9715
# Epoch 165/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.6058e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9728
# Epoch 166/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.6201e-04 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9728
# Epoch 167/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.5118e-04 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9728
# Epoch 168/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.5723e-04 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 0.9728
# Epoch 169/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.3356e-04 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9728
# Epoch 170/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.4751e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9728
# Epoch 171/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.6007e-04 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9728
# Epoch 172/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.6398e-04 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9728
# Epoch 173/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.1371e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9728
# Epoch 174/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.1188e-04 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9728
# Epoch 175/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.5387e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9728
# Epoch 176/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 4.4754e-04 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9728
# Epoch 177/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.7919e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9728
# Epoch 178/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.1319e-04 - accuracy: 1.0000 - val_loss: 0.1128 - val_accuracy: 0.9728
# Epoch 179/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.3665e-04 - accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9728
# Epoch 180/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.2842e-04 - accuracy: 1.0000 - val_loss: 0.1120 - val_accuracy: 0.9728
# Epoch 181/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.2288e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9728
# Epoch 182/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.5227e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9728
# Epoch 183/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 3.8446e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9728
# Epoch 184/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.0458e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9728
# Epoch 185/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.0719e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9728
# Epoch 186/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.1267e-04 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9728
# Epoch 187/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 3.8973e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9728
# Epoch 188/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 4.2344e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9728
# Epoch 189/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.9199e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9728
# Epoch 190/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 3.5476e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9728
# Epoch 191/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.8028e-04 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9728
# Epoch 192/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.8623e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9728
# Epoch 193/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 3.3919e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9728
# Epoch 194/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 3.8347e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9728
# Epoch 195/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.5878e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9728
# Epoch 196/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.8254e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9728
# Epoch 197/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.6464e-04 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9728
# Epoch 198/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 3.3853e-04 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9728
# Epoch 199/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.4104e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9728
# Epoch 200/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.2065e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9728
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_Xception\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 11s 229ms/step - loss: 3.0484e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9728
# Epoch 202/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.3435e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9728
# Epoch 203/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 3.1227e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9728
# Epoch 204/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.1722e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9728
# Epoch 205/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.9612e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9728
# Epoch 206/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.0952e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9728
# Epoch 207/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.9830e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9728
# Epoch 208/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.8920e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9728
# Epoch 209/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.9281e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9728
# Epoch 210/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.8848e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9728
# Epoch 211/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 3.0341e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9728
# Epoch 212/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6884e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9728
# Epoch 213/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.9023e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9728
# Epoch 214/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.5316e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9728
# Epoch 215/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6215e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9728
# Epoch 216/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6238e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9728
# Epoch 217/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6382e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9728
# Epoch 218/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.5575e-04 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9728
# Epoch 219/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6302e-04 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9728
# Epoch 220/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6474e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9728
# Epoch 221/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.6452e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9728
# Epoch 222/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.1688e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9728
# Epoch 223/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.4053e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9728
# Epoch 224/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.2819e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9728
# Epoch 225/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.1629e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9728
# Epoch 226/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.3589e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9728
# Epoch 227/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.1515e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9728
# Epoch 228/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.2486e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9728
# Epoch 229/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.3299e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9728
# Epoch 230/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.1483e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9728
# Epoch 231/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.0682e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9728
# Epoch 232/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.1135e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9728
# Epoch 233/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.0157e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9728
# Epoch 234/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.8537e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9728
# Epoch 235/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.8769e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9728
# Epoch 236/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.0838e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9728
# Epoch 237/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 2.0561e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9728
# Epoch 238/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.8330e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9728
# Epoch 239/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.9650e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9728
# Epoch 240/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.7345e-04 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9728
# Epoch 241/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.6828e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9728
# Epoch 242/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.8523e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9728
# Epoch 243/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.7851e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9728
# Epoch 244/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5994e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9728
# Epoch 245/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.7493e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9728
# Epoch 246/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5548e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9728
# Epoch 247/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5975e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9728
# Epoch 248/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.6702e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9728
# Epoch 249/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.4864e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9728
# Epoch 250/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5684e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9728
# Epoch 251/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.6744e-04 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9728
# Epoch 252/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5830e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9728
# Epoch 253/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.6020e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9728
# Epoch 254/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.4560e-04 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9728
# Epoch 255/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5251e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9728
# Epoch 256/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.4110e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9728
# Epoch 257/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5988e-04 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9728
# Epoch 258/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.5007e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9728
# Epoch 259/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.3720e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9728
# Epoch 260/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.3664e-04 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9728
# Epoch 261/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.3753e-04 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9728
# Epoch 262/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.3304e-04 - accuracy: 1.0000 - val_loss: 0.1224 - val_accuracy: 0.9728
# Epoch 263/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.4329e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9728
# Epoch 264/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.2831e-04 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9728
# Epoch 265/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.2943e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9728
# Epoch 266/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.1861e-04 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9728
# Epoch 267/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.2119e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9728
# Epoch 268/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.2638e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9728
# Epoch 269/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.1740e-04 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9728
# Epoch 270/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.2268e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9728
# Epoch 271/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.1828e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9728
# Epoch 272/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.1236e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9728
# Epoch 273/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.0214e-04 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9728
# Epoch 274/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.0363e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9728
# Epoch 275/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 9.9243e-05 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9728
# Epoch 276/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.0261e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9728
# Epoch 277/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.9347e-05 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9728
# Epoch 278/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.9007e-05 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9728
# Epoch 279/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.0313e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9728
# Epoch 280/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.9510e-05 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9728
# Epoch 281/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.6548e-05 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9728
# Epoch 282/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.8300e-05 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9728
# Epoch 283/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.9318e-05 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9728
# Epoch 284/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.9319e-05 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9728
# Epoch 285/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.4360e-05 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9728
# Epoch 286/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.8336e-05 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9728
# Epoch 287/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.8606e-05 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9728
# Epoch 288/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.3829e-05 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9728
# Epoch 289/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.9111e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9728
# Epoch 290/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 9.6026e-05 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9728
# Epoch 291/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.1070e-05 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9728
# Epoch 292/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.7472e-05 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9728
# Epoch 293/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.5663e-05 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9728
# Epoch 294/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.1402e-05 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9728
# Epoch 295/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.2531e-05 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9728
# Epoch 296/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.5802e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9728
# Epoch 297/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.7563e-05 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9728
# Epoch 298/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.6422e-05 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9728
# Epoch 299/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 8.0565e-05 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9728
# Epoch 300/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.5577e-05 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9728
# Epoch 301/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 7.5365e-05 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9728
# Epoch 302/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.3064e-05 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9728
# Epoch 303/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.3974e-05 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9728
# Epoch 304/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.9054e-05 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9728
# Epoch 305/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.6059e-05 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9728
# Epoch 306/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.1780e-05 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9728
# Epoch 307/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 7.0964e-05 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9728
# Epoch 308/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.0689e-05 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9728
# Epoch 309/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.0455e-05 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9728
# Epoch 310/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.3256e-05 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9728
# Epoch 311/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.0007e-05 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9728
# Epoch 312/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 6.7291e-05 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9728
# Epoch 313/2000
# 49/49 [==============================] - 12s 230ms/step - loss: 6.3646e-05 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9728
# Epoch 314/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.7236e-05 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9728
# Epoch 315/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.2382e-05 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9728
# Epoch 316/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.6726e-05 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9728
# Epoch 317/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 6.4144e-05 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9728
# Epoch 318/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 5.8136e-05 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9728
# Epoch 319/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.0838e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1898/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.8888e-08 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9728
# Epoch 1899/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7833e-08 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9728
# Epoch 1900/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.8618e-08 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9728
# Epoch 1901/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8527e-08 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9728
# Epoch 1902/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.3033e-08 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9728
# Epoch 1903/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 5.0803e-08 - accuracy: 1.0000 - val_loss: 0.2184 - val_accuracy: 0.9728
# Epoch 1904/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7564e-08 - accuracy: 1.0000 - val_loss: 0.2186 - val_accuracy: 0.9728
# Epoch 1905/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.2763e-08 - accuracy: 1.0000 - val_loss: 0.2192 - val_accuracy: 0.9728
# Epoch 1906/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.8310e-08 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.9728
# Epoch 1907/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.6268e-08 - accuracy: 1.0000 - val_loss: 0.2198 - val_accuracy: 0.9728
# Epoch 1908/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.0568e-08 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.9728
# Epoch 1909/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 1.7756e-08 - accuracy: 1.0000 - val_loss: 0.2201 - val_accuracy: 0.9728
# Epoch 1910/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9027e-08 - accuracy: 1.0000 - val_loss: 0.2201 - val_accuracy: 0.9728
# Epoch 1911/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2494e-08 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9728
# Epoch 1912/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8295e-08 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9728
# Epoch 1913/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9990e-08 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9728
# Epoch 1914/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.2980e-08 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9728
# Epoch 1915/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.3110e-08 - accuracy: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9728
# Epoch 1916/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.3264e-08 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9728
# Epoch 1917/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6139e-08 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9728
# Epoch 1918/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 3.0929e-08 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9728
# Epoch 1919/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2763e-08 - accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9728
# Epoch 1920/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7833e-08 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9728
# Epoch 1921/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9451e-08 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9728
# Epoch 1922/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.0144e-08 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9728
# Epoch 1923/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7679e-08 - accuracy: 1.0000 - val_loss: 0.2208 - val_accuracy: 0.9728
# Epoch 1924/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9682e-08 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9728
# Epoch 1925/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 3.3856e-08 - accuracy: 1.0000 - val_loss: 0.2198 - val_accuracy: 0.9728
# Epoch 1926/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0876e-08 - accuracy: 1.0000 - val_loss: 0.2202 - val_accuracy: 0.9728
# Epoch 1927/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6870e-08 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9728
# Epoch 1928/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0260e-08 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9728
# Epoch 1929/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.0337e-08 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9728
# Epoch 1930/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.5484e-08 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9728
# Epoch 1931/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.3187e-08 - accuracy: 1.0000 - val_loss: 0.2206 - val_accuracy: 0.9728
# Epoch 1932/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7140e-08 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9728
# Epoch 1933/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9605e-08 - accuracy: 1.0000 - val_loss: 0.2209 - val_accuracy: 0.9728
# Epoch 1934/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.4790e-08 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9728
# Epoch 1935/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.3418e-08 - accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9728
# Epoch 1936/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6293e-08 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9728
# Epoch 1937/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2109e-08 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9728
# Epoch 1938/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9875e-08 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9728
# Epoch 1939/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.7154e-08 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9728
# Epoch 1940/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.3572e-08 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9728
# Epoch 1941/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.5830e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728loss: 1.5784e-08
# Epoch 1942/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9566e-08 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9728
# Epoch 1943/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0414e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728
# Epoch 1944/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8180e-08 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9728
# Epoch 1945/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.1223e-08 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9728
# Epoch 1946/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 3.0312e-08 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9728
# Epoch 1947/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.1839e-08 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9728
# Epoch 1948/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2994e-08 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9728
# Epoch 1949/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8565e-08 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9728
# Epoch 1950/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.1146e-08 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9728
# Epoch 1951/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.1107e-08 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9728
# Epoch 1952/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.6576e-08 - accuracy: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9728
# Epoch 1953/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 3.5897e-08 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9728
# Epoch 1954/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0337e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728
# Epoch 1955/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8295e-08 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9728
# Epoch 1956/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.0876e-08 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9728
# Epoch 1957/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8604e-08 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9728
# Epoch 1958/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.3264e-08 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9728
# Epoch 1959/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.5845e-08 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9728
# Epoch 1960/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6947e-08 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9728
# Epoch 1961/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6755e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728
# Epoch 1962/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7525e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728
# Epoch 1963/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.5344e-08 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9728
# Epoch 1964/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.1839e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728- loss: 2.3757e-0
# Epoch 1965/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.4829e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1966/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8180e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1967/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6947e-08 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9728
# Epoch 1968/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9566e-08 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9728
# Epoch 1969/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2147e-08 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9728
# Epoch 1970/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 3.2893e-08 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9728
# Epoch 1971/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.2609e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728
# Epoch 1972/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.1069e-08 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9728
# Epoch 1973/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.3303e-08 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9728
# Epoch 1974/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2956e-08 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9728
# Epoch 1975/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0067e-08 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9728
# Epoch 1976/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 1.5445e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1977/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0067e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1978/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.7487e-08 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9728
# Epoch 1979/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.7655e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1980/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8026e-08 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9728
# Epoch 1981/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.4675e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728
# Epoch 1982/2000
# 49/49 [==============================] - 11s 232ms/step - loss: 2.4535e-08 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9728
# Epoch 1983/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 1.9297e-08 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9728
# Epoch 1984/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0221e-08 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9728
# Epoch 1985/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8372e-08 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9728
# Epoch 1986/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 2.4073e-08 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9728
# Epoch 1987/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.5460e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728
# Epoch 1988/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 1.8450e-08 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9728
# Epoch 1989/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.6422e-08 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9728
# Epoch 1990/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9297e-08 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9728
# Epoch 1991/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.5792e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728
# Epoch 1992/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.9682e-08 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9728
# Epoch 1993/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.7039e-08 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9728
# Epoch 1994/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.6678e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728
# Epoch 1995/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 1.9297e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728
# Epoch 1996/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 1.8064e-08 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9728
# Epoch 1997/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.0491e-08 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9728
# Epoch 1998/2000
# 49/49 [==============================] - 11s 230ms/step - loss: 1.7448e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# Epoch 1999/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.2532e-08 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9728
# Epoch 2000/2000
# 49/49 [==============================] - 11s 231ms/step - loss: 2.5922e-08 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9728
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_Xception\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 16s 410ms/step - loss: 1.4282 - accuracy: 0.8612
# test_indoor_ds_results:test loss, test acc: [1.4281588792800903, 0.8612040281295776]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 28s 463ms/step - loss: 1.2696 - accuracy: 0.8729
# test_outdoor_ds_results:test loss, test acc: [1.2695971727371216, 0.8729299306869507]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 11s 250ms/step - loss: 1.6980 - accuracy: 0.8472
# test_belt_ds_results:test loss, test acc: [1.69803786277771, 0.8472347855567932]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/5G_Xception/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 8s 183ms/step - loss: 0.6240 - accuracy: 0.8606
# 50/50 [==============================] - 9s 185ms/step - loss: 0.5819 - accuracy: 0.8742
# 35/35 [==============================] - 6s 185ms/step - loss: 0.7891 - accuracy: 0.8513
# Epoch200
#  test_indoor_acc=0.8606466054916382
#  test_outdoor_acc=0.8742038011550903
#  test_belt_acc=0.8513146042823792
# 29/29 [==============================] - 8s 183ms/step - loss: 0.8732 - accuracy: 0.8601
# 50/50 [==============================] - 9s 186ms/step - loss: 0.7910 - accuracy: 0.8726
# 35/35 [==============================] - 7s 186ms/step - loss: 1.0678 - accuracy: 0.8481
# Epoch400
#  test_indoor_acc=0.8600891828536987
#  test_outdoor_acc=0.8726114630699158
#  test_belt_acc=0.8481414318084717
# 29/29 [==============================] - 8s 181ms/step - loss: 1.0547 - accuracy: 0.8590
# 50/50 [==============================] - 9s 183ms/step - loss: 0.9544 - accuracy: 0.8736
# 35/35 [==============================] - 6s 183ms/step - loss: 1.2742 - accuracy: 0.8477
# Epoch600
#  test_indoor_acc=0.8589743375778198
#  test_outdoor_acc=0.8735668659210205
#  test_belt_acc=0.8476881384849548
# 29/29 [==============================] - 8s 182ms/step - loss: 1.1899 - accuracy: 0.8606
# 50/50 [==============================] - 9s 184ms/step - loss: 1.0737 - accuracy: 0.8723
# 35/35 [==============================] - 6s 185ms/step - loss: 1.4309 - accuracy: 0.8500
# Epoch800
#  test_indoor_acc=0.8606466054916382
#  test_outdoor_acc=0.8722929954528809
#  test_belt_acc=0.8499546647071838
# 29/29 [==============================] - 8s 183ms/step - loss: 1.2531 - accuracy: 0.8606
# 50/50 [==============================] - 9s 185ms/step - loss: 1.1329 - accuracy: 0.8729
# 35/35 [==============================] - 6s 185ms/step - loss: 1.4991 - accuracy: 0.8486
# Epoch1000
#  test_indoor_acc=0.8606466054916382
#  test_outdoor_acc=0.8729299306869507
#  test_belt_acc=0.8485947251319885
# 29/29 [==============================] - 8s 185ms/step - loss: 1.3157 - accuracy: 0.8601
# 50/50 [==============================] - 9s 186ms/step - loss: 1.1799 - accuracy: 0.8726
# 35/35 [==============================] - 7s 187ms/step - loss: 1.5692 - accuracy: 0.8490
# Epoch1200
#  test_indoor_acc=0.8600891828536987
#  test_outdoor_acc=0.8726114630699158
#  test_belt_acc=0.8490480780601501
# 29/29 [==============================] - 14s 184ms/step - loss: 1.3537 - accuracy: 0.8601
# 50/50 [==============================] - 9s 185ms/step - loss: 1.2167 - accuracy: 0.8729
# 35/35 [==============================] - 7s 185ms/step - loss: 1.6162 - accuracy: 0.8486
# Epoch1400
#  test_indoor_acc=0.8600891828536987
#  test_outdoor_acc=0.8729299306869507
#  test_belt_acc=0.8485947251319885
# 29/29 [==============================] - 8s 184ms/step - loss: 1.3818 - accuracy: 0.8606
# 50/50 [==============================] - 9s 185ms/step - loss: 1.2316 - accuracy: 0.8732
# 35/35 [==============================] - 7s 186ms/step - loss: 1.6477 - accuracy: 0.8486
# Epoch1600
#  test_indoor_acc=0.8606466054916382
#  test_outdoor_acc=0.8732483983039856
#  test_belt_acc=0.8485947251319885
# 29/29 [==============================] - 8s 184ms/step - loss: 1.4177 - accuracy: 0.8601
# 50/50 [==============================] - 9s 185ms/step - loss: 1.2609 - accuracy: 0.8726
# 35/35 [==============================] - 6s 185ms/step - loss: 1.6843 - accuracy: 0.8481
# Epoch1800
#  test_indoor_acc=0.8600891828536987
#  test_outdoor_acc=0.8726114630699158
#  test_belt_acc=0.8481414318084717
# 29/29 [==============================] - 8s 185ms/step - loss: 1.4282 - accuracy: 0.8612
# 50/50 [==============================] - 9s 188ms/step - loss: 1.2696 - accuracy: 0.8729
# 35/35 [==============================] - 7s 187ms/step - loss: 1.6980 - accuracy: 0.8472
# Epoch2000
#  test_indoor_acc=0.8612040281295776
#  test_outdoor_acc=0.8729299306869507
#  test_belt_acc=0.8472347855567932

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8620550036430359
# max index -> 0
# The [Epoch] of max acc -> 200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8606466054916382,
#  0.8600891828536987,
#  0.8589743375778198,
#  0.8606466054916382,
#  0.8606466054916382,
#  0.8600891828536987,
#  0.8600891828536987,
#  0.8606466054916382,
#  0.8600891828536987,
#  0.8612040281295776]

# %%
test_outdoor_acc
# Out:
# [0.8742038011550903,
#  0.8726114630699158,
#  0.8735668659210205,
#  0.8722929954528809,
#  0.8729299306869507,
#  0.8726114630699158,
#  0.8729299306869507,
#  0.8732483983039856,
#  0.8726114630699158,
#  0.8729299306869507]

# %%
test_belt_acc
# Out:
# [0.8513146042823792,
#  0.8481414318084717,
#  0.8476881384849548,
#  0.8499546647071838,
#  0.8485947251319885,
#  0.8490480780601501,
#  0.8485947251319885,
#  0.8485947251319885,
#  0.8481414318084717,
#  0.8472347855567932]

# %%
test_indoor_loss
# Out:
# [0.6240479946136475,
#  0.8731706738471985,
#  1.0547252893447876,
#  1.189929485321045,
#  1.253098964691162,
#  1.3157010078430176,
#  1.3537077903747559,
#  1.3818446397781372,
#  1.4176506996154785,
#  1.4281588792800903]

# %%
test_outdoor_loss
# Out:
# [0.5819379687309265,
#  0.7910240292549133,
#  0.9544166922569275,
#  1.0737262964248657,
#  1.132885217666626,
#  1.179857611656189,
#  1.216738224029541,
#  1.2316430807113647,
#  1.2608845233917236,
#  1.2695971727371216]

# %%
test_belt_loss
# Out:
# [0.7890768051147461,
#  1.0678455829620361,
#  1.274163007736206,
#  1.4309310913085938,
#  1.499130368232727,
#  1.569244384765625,
#  1.616162657737732,
#  1.6477118730545044,
#  1.684255838394165,
#  1.69803786277771]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.densenet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6167
# FP=973
# acc=0.8637254901960785
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 94.70404984423676%
# 2-BloodSecretionWaste acc = 64.6685878962536%
# 3-LabWardWaste acc = 86.6965620328849%
# 4-VaccineOtherWaste acc = 96.26342830453059%
#
#
#
# all_avg_eachclass = 85.58315701947646%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1824,   57,   23,   22],
#        [ 463, 1122,   64,   86],
#        [  44,   49, 1160,   85],
#        [  13,   24,   43, 2061]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[94.70404984,  2.95950156,  1.19418484,  1.14226376],
#        [26.68587896, 64.6685879 ,  3.68876081,  4.95677233],
#        [ 3.28849028,  3.66218236, 86.69656203,  6.35276532],
#        [ 0.6071929 ,  1.12097151,  2.00840729, 96.2634283 ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
