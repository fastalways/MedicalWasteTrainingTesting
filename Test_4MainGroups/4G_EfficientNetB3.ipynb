# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=300
img_width=300
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 300, 300, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB3

efficientnetB0_model = keras.applications.EfficientNetB3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 300, 300, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 301, 301, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 150, 150, 40) 1080        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 150, 150, 40) 160         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 150, 150, 40) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 150, 150, 40) 360         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 150, 150, 40) 160         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 150, 150, 40) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 40)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 40)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 10)     410         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 40)     440         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 150, 150, 40) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 150, 150, 24) 960         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 150, 150, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 150, 150, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 150, 150, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 150, 150, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 150, 150, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 150, 150, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 150, 150, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 150, 150, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 150, 150, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 150, 150, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 150, 150, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 150, 150, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 151, 151, 144 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 75, 75, 144)  1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 75, 75, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 75, 75, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 75, 75, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 75, 75, 32)   4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 75, 75, 32)   128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 75, 75, 192)  768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 75, 75, 192)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 75, 75, 192)  1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 75, 75, 192)  768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 75, 75, 192)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 75, 75, 192)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 75, 75, 32)   6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 75, 75, 32)   128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 75, 75, 32)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 75, 75, 32)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 75, 75, 192)  768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 75, 75, 192)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 75, 75, 192)  1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 75, 75, 192)  768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 75, 75, 192)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 75, 75, 192)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 75, 75, 32)   6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 75, 75, 32)   128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 75, 75, 32)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 75, 75, 32)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 75, 75, 192)  768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 75, 75, 192)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 79, 79, 192)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 38, 38, 192)  4800        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 38, 38, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 38, 38, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 38, 38, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 38, 38, 48)   9216        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 38, 38, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 38, 38, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 38, 38, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 38, 38, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 38, 38, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 38, 38, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 38, 38, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 38, 38, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 38, 38, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 38, 38, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 38, 38, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 38, 38, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 38, 38, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 38, 38, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 38, 38, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 38, 38, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 38, 38, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 38, 38, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 39, 39, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 19, 19, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 19, 19, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 19, 19, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 19, 19, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 19, 19, 96)   27648       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 19, 19, 96)   384         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 19, 19, 576)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 19, 19, 576)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 576)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 19, 19, 576)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 19, 19, 96)   384         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 19, 19, 96)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 19, 19, 96)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 19, 19, 576)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 19, 19, 576)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 576)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 19, 19, 576)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 19, 19, 96)   384         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 19, 19, 96)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 19, 19, 96)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 19, 19, 576)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 19, 19, 576)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 576)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 19, 19, 576)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 19, 19, 96)   384         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 19, 19, 96)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 19, 19, 96)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 19, 19, 576)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 19, 19, 576)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 576)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 19, 19, 576)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 19, 19, 96)   384         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (Dropout)          (None, 19, 19, 96)   0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 19, 19, 96)   0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4e_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 19, 19, 576)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 19, 19, 576)  14400       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 19, 19, 576)  2304        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 19, 19, 576)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 576)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 576)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 19, 19, 576)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 19, 19, 136)  78336       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 19, 19, 136)  544         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 19, 19, 816)  110976      block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 19, 19, 816)  3264        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 19, 19, 816)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 19, 19, 816)  20400       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 19, 19, 816)  3264        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 19, 19, 816)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 816)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 19, 19, 816)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 19, 19, 136)  110976      block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 19, 19, 136)  544         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 19, 19, 136)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 19, 19, 136)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 19, 19, 816)  110976      block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 19, 19, 816)  3264        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 19, 19, 816)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 19, 19, 816)  20400       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 19, 19, 816)  3264        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 19, 19, 816)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 816)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6d_expand_activation (Acti (None, 10, 10, 1392) 0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 34800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 10, 10, 1392) 0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1392)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 10, 10, 1392) 0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 10, 10, 232)  322944      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 10, 10, 232)  928         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 10, 10, 232)  0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 10, 10, 232)  0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 10, 10, 1392) 322944      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 10, 10, 1392) 5568        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 10, 10, 1392) 0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 34800       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 10, 10, 1392) 0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1392)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 10, 10, 1392) 0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 10, 10, 232)  322944      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 10, 10, 232)  928         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 10, 10, 232)  0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 10, 10, 232)  0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block6f_expand_conv (Conv2D)    (None, 10, 10, 1392) 322944      block6e_add[0][0]
# __________________________________________________________________________________________________
# block6f_expand_bn (BatchNormali (None, 10, 10, 1392) 5568        block6f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6f_expand_activation (Acti (None, 10, 10, 1392) 0           block6f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6f_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 34800       block6f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6f_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block6f_dwconv[0][0]
# __________________________________________________________________________________________________
# block6f_activation (Activation) (None, 10, 10, 1392) 0           block6f_bn[0][0]
# __________________________________________________________________________________________________
# block6f_se_squeeze (GlobalAvera (None, 1392)         0           block6f_activation[0][0]
# __________________________________________________________________________________________________
# block6f_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6f_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6f_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6f_se_excite (Multiply)    (None, 10, 10, 1392) 0           block6f_activation[0][0]
#                                                                  block6f_se_expand[0][0]
# __________________________________________________________________________________________________
# block6f_project_conv (Conv2D)   (None, 10, 10, 232)  322944      block6f_se_excite[0][0]
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 10, 10, 232)  928         block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (Dropout)          (None, 10, 10, 232)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 10, 10, 232)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 10, 10, 1392) 322944      block6f_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 10, 10, 1392) 5568        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 10, 10, 1392) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 12528       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 10, 10, 1392) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1392)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 10, 10, 1392) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 10, 10, 384)  534528      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 10, 10, 384)  1536        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 10, 10, 2304) 884736      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 10, 10, 2304) 9216        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 10, 10, 2304) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 10, 10, 2304) 20736       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 10, 10, 2304) 9216        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 10, 10, 2304) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2304)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 10, 10, 2304) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 10, 10, 384)  884736      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 10, 10, 384)  1536        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 10, 10, 384)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 10, 10, 384)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 10, 10, 1536) 589824      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 10, 10, 1536) 6144        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 10, 10, 1536) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1536)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 10,783,535
# Trainable params: 0
# Non-trainable params: 10,783,535
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1536)              10783535
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 12,361,523
# Trainable params: 1,577,988
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 55s 520ms/step - loss: 0.2711 - accuracy: 0.8973 - val_loss: 0.1041 - val_accuracy: 0.9599
# Epoch 2/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 0.0660 - accuracy: 0.9787 - val_loss: 0.0810 - val_accuracy: 0.9741
# Epoch 3/2000
# 49/49 [==============================] - 18s 366ms/step - loss: 0.0405 - accuracy: 0.9887 - val_loss: 0.0567 - val_accuracy: 0.9806
# Epoch 4/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 0.0269 - accuracy: 0.9922 - val_loss: 0.0418 - val_accuracy: 0.9858
# Epoch 5/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 0.0151 - accuracy: 0.9968 - val_loss: 0.0413 - val_accuracy: 0.9884
# Epoch 6/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 0.0146 - accuracy: 0.9958 - val_loss: 0.0548 - val_accuracy: 0.9832
# Epoch 7/2000
# 49/49 [==============================] - 18s 366ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.0478 - val_accuracy: 0.9832
# Epoch 8/2000
# 49/49 [==============================] - 18s 366ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0591 - val_accuracy: 0.9767
# Epoch 9/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.0390 - val_accuracy: 0.9871
# Epoch 10/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.0326 - val_accuracy: 0.9909
# Epoch 11/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0498 - val_accuracy: 0.9845
# Epoch 12/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.0632 - val_accuracy: 0.9806
# Epoch 13/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0554 - val_accuracy: 0.9819
# Epoch 14/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.0411 - val_accuracy: 0.9897
# Epoch 15/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0598 - val_accuracy: 0.9806
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0498 - val_accuracy: 0.9845
# Epoch 17/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0404 - val_accuracy: 0.9884
# Epoch 18/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0472 - val_accuracy: 0.9858
# Epoch 19/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9884
# Epoch 20/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0469 - val_accuracy: 0.9858
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 21/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0459 - val_accuracy: 0.9871
# Epoch 22/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0452 - val_accuracy: 0.9871
# Epoch 23/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.1162e-04 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9871
# Epoch 24/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0446 - val_accuracy: 0.9871
# Epoch 25/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0457 - val_accuracy: 0.9871
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 26/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.7786e-04 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9871
# Epoch 27/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9871
# Epoch 28/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.3139e-04 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9871
# Epoch 29/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9871
# Epoch 30/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9871
# Epoch 31/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 0.9871
# Epoch 32/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.2663e-04 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9871
# Epoch 33/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0446 - val_accuracy: 0.9871
# Epoch 34/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9871
# Epoch 35/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.5790e-04 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9871
# Epoch 36/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.1933e-04 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9871
# Epoch 37/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.4767e-04 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9871
# Epoch 38/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.5102e-04 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9871
# Epoch 39/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0443 - val_accuracy: 0.9871
# Epoch 40/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0446 - val_accuracy: 0.9871
# Epoch 41/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0439 - val_accuracy: 0.9871
# Epoch 42/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.2586e-04 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9884
# Epoch 43/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9884
# Epoch 44/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9884
# Epoch 45/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.5989e-04 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9884
# Epoch 46/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0439 - val_accuracy: 0.9871
# Epoch 47/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0444 - val_accuracy: 0.9871
# Epoch 48/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.2582e-04 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9871
# Epoch 49/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0443 - val_accuracy: 0.9884
# Epoch 50/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9884
# Epoch 51/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9884
# Epoch 52/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0452 - val_accuracy: 0.9871
# Epoch 53/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 0.9871
# Epoch 54/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.1181e-04 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.9871
# Epoch 55/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9871
# Epoch 56/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0451 - val_accuracy: 0.9871
# Epoch 57/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9884
# Epoch 58/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0441 - val_accuracy: 0.9884
# Epoch 59/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0444 - val_accuracy: 0.9871
# Epoch 60/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0441 - val_accuracy: 0.9871
# Epoch 61/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0435 - val_accuracy: 0.9884
# Epoch 62/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0432 - val_accuracy: 0.9884
# Epoch 63/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0433 - val_accuracy: 0.9884
# Epoch 64/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.3629e-04 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9871
# Epoch 65/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.6696e-04 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9871
# Epoch 66/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9884
# Epoch 67/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.8888e-04 - accuracy: 0.9997 - val_loss: 0.0433 - val_accuracy: 0.9884
# Epoch 68/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.2948e-04 - accuracy: 0.9997 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 69/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.2494e-04 - accuracy: 0.9997 - val_loss: 0.0430 - val_accuracy: 0.9884
# Epoch 70/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.3044e-04 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9884
# Epoch 71/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.6209e-04 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9884
# Epoch 72/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.5004e-04 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 73/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.6196e-04 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9871
# Epoch 74/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.5274e-04 - accuracy: 0.9997 - val_loss: 0.0435 - val_accuracy: 0.9871
# Epoch 75/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.5661e-04 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9871
# Epoch 76/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.3770e-04 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9871
# Epoch 77/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.1456e-04 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9871
# Epoch 78/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.4742e-04 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9871
# Epoch 79/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0452 - val_accuracy: 0.9871
# Epoch 80/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0454 - val_accuracy: 0.9871
# Epoch 81/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.8152e-04 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9871
# Epoch 82/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.8403e-04 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9884
# Epoch 83/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.1322e-04 - accuracy: 0.9997 - val_loss: 0.0434 - val_accuracy: 0.9897
# Epoch 84/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.0450e-04 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9897
# Epoch 85/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.5075e-04 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9897
# Epoch 86/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.5144e-04 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9884
# Epoch 87/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.9274e-04 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 0.9897
# Epoch 88/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.5752e-04 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9897
# Epoch 89/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.0793e-04 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9897
# Epoch 90/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0424 - val_accuracy: 0.9897
# Epoch 91/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.8410e-04 - accuracy: 0.9997 - val_loss: 0.0425 - val_accuracy: 0.9871
# Epoch 92/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.7718e-04 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9884
# Epoch 93/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9897
# Epoch 94/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.5580e-04 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9897
# Epoch 95/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.7533e-04 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9897
# Epoch 96/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.7331e-04 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9897
# Epoch 97/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.8792e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9897
# Epoch 98/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.9676e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9897
# Epoch 99/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.1858e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9884
# Epoch 100/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.8473e-04 - accuracy: 0.9997 - val_loss: 0.0425 - val_accuracy: 0.9897
# Epoch 101/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.0524e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 102/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0429 - val_accuracy: 0.9884
# Epoch 103/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.5698e-04 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9884
# Epoch 104/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.8042e-04 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9897
# Epoch 105/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9909
# Epoch 106/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.2972e-04 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9909
# Epoch 107/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 108/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.6707e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9909
# Epoch 109/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9909
# Epoch 110/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.7007e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9909
# Epoch 111/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.6323e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9909
# Epoch 112/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9922
# Epoch 113/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.2485e-04 - accuracy: 0.9997 - val_loss: 0.0424 - val_accuracy: 0.9909
# Epoch 114/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0432 - val_accuracy: 0.9897
# Epoch 115/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.8169e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 116/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9897
# Epoch 117/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.4363e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9884
# Epoch 118/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0419 - val_accuracy: 0.9897
# Epoch 119/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.4394e-04 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9884
# Epoch 120/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.6948e-04 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9884
# Epoch 121/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.8777e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9884
# Epoch 122/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.6117e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 123/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.7485e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 124/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0424 - val_accuracy: 0.9897
# Epoch 125/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.9543e-04 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9884
# Epoch 126/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.1119e-04 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9897
# Epoch 127/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 6.5593e-04 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9884
# Epoch 128/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9884
# Epoch 129/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0430 - val_accuracy: 0.9871
# Epoch 130/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.8433e-04 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9871
# Epoch 131/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.2711e-04 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9884
# Epoch 132/2000
# 49/49 [==============================] - 18s 360ms/step - loss: 6.7791e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9884
# Epoch 133/2000
# 49/49 [==============================] - 18s 360ms/step - loss: 7.8410e-04 - accuracy: 0.9997 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 134/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 5.3462e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9897
# Epoch 135/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 5.9468e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9897
# Epoch 136/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.1298e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9897
# Epoch 137/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.1170e-04 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9897
# Epoch 138/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 139/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 5.1179e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 140/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 3.9774e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 141/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 6.9121e-04 - accuracy: 0.9997 - val_loss: 0.0408 - val_accuracy: 0.9897
# Epoch 142/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.3678e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9897
# Epoch 143/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 4.9912e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 144/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 3.9098e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9897
# Epoch 145/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 5.6727e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9897
# Epoch 146/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9884
# Epoch 147/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 6.4982e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9897
# Epoch 148/2000
# 49/49 [==============================] - 17s 348ms/step - loss: 3.2324e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9897
# Epoch 149/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 6.7023e-04 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9897
# Epoch 150/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 8.0624e-04 - accuracy: 0.9997 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 151/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 5.1423e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9909
# Epoch 152/2000
# 49/49 [==============================] - 18s 374ms/step - loss: 4.7078e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 153/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.6928e-04 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9909
# Epoch 154/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 9.7559e-04 - accuracy: 0.9997 - val_loss: 0.0407 - val_accuracy: 0.9884
# Epoch 155/2000
# 49/49 [==============================] - 17s 359ms/step - loss: 9.4417e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 156/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.3199e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9884
# Epoch 157/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 5.4025e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9909
# Epoch 158/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 4.1563e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9897
# Epoch 159/2000
# 49/49 [==============================] - 17s 347ms/step - loss: 3.1786e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9884
# Epoch 160/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 5.1895e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9909
# Epoch 161/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 8.2282e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9884
# Epoch 162/2000
# 49/49 [==============================] - 18s 373ms/step - loss: 4.0321e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9897
# Epoch 163/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 9.8515e-04 - accuracy: 0.9997 - val_loss: 0.0421 - val_accuracy: 0.9884
# Epoch 164/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0429 - val_accuracy: 0.9871
# Epoch 165/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 4.0718e-04 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9871
# Epoch 166/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 4.8186e-04 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9884
# Epoch 167/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 5.4174e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9897
# Epoch 168/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 4.8439e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 169/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 5.3363e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9909
# Epoch 170/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 6.0884e-04 - accuracy: 0.9997 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 171/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.9874e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 172/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 6.4753e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 173/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 7.2349e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9909
# Epoch 174/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9884
# Epoch 175/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 4.3648e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9909
# Epoch 176/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9909
# Epoch 177/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 4.8428e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9909
# Epoch 178/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.4196e-04 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9909
# Epoch 179/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.1443e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 180/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.7278e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9909
# Epoch 181/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9897
# Epoch 182/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 2.6362e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9897
# Epoch 183/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 2.4697e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 184/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 185/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.0950e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9897
# Epoch 186/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 5.1391e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9897
# Epoch 187/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 4.7860e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9897
# Epoch 188/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 5.6822e-04 - accuracy: 0.9997 - val_loss: 0.0410 - val_accuracy: 0.9897
# Epoch 189/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.4576e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9897
# Epoch 190/2000
# 49/49 [==============================] - 18s 371ms/step - loss: 3.6070e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 191/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 9.9410e-04 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 192/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.4743e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9909
# Epoch 193/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 4.2204e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 194/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0409 - val_accuracy: 0.9897
# Epoch 195/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 5.9442e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 196/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 2.5135e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 197/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 4.2194e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9922
# Epoch 198/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 2.8125e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9922
# Epoch 199/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 3.5306e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9909
# Epoch 200/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 6.9956e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9922
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB3\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.2014e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9909
# Epoch 202/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.7875e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9909
# Epoch 203/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.9883e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9909
# Epoch 204/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.8072e-04 - accuracy: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9909
# Epoch 205/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0395 - val_accuracy: 0.9909
# Epoch 206/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.0925e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9897
# Epoch 207/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.0138e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9909
# Epoch 208/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.5287e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 209/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.6568e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9897
# Epoch 210/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.7308e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9909
# Epoch 211/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.7021e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9897
# Epoch 212/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.4764e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9909
# Epoch 213/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.0313e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 214/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.3638e-04 - accuracy: 0.9997 - val_loss: 0.0386 - val_accuracy: 0.9909
# Epoch 215/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.4191e-04 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9909
# Epoch 216/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.5182e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9909
# Epoch 217/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 6.1939e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9909
# Epoch 218/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.6793e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 219/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.0824e-04 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 220/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.8516e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 221/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.7097e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 222/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.8752e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 223/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.1734e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9909
# Epoch 224/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 225/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.6243e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 226/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.3602e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 227/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 6.2649e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 228/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.4037e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9922
# Epoch 229/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.2508e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 230/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.2731e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 231/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 9.7680e-04 - accuracy: 0.9994 - val_loss: 0.0408 - val_accuracy: 0.9897
# Epoch 232/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 4.5523e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9897
# Epoch 233/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.6122e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9897
# Epoch 234/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.7006e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 235/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0394 - val_accuracy: 0.9922
# Epoch 236/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 4.3155e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9922
# Epoch 237/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.5884e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9922
# Epoch 238/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.5959e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9922
# Epoch 239/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 6.0670e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 240/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.6934e-04 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 241/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.6541e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9909
# Epoch 242/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.9033e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9909
# Epoch 243/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 8.0809e-04 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9909
# Epoch 244/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.7202e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 245/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.4311e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9909
# Epoch 246/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.1550e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 247/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.8120e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 248/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.2920e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 249/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.0784e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 250/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 5.0190e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 251/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.2545e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9909
# Epoch 252/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.8550e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9909
# Epoch 253/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.0127e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9909
# Epoch 254/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.5461e-04 - accuracy: 0.9997 - val_loss: 0.0396 - val_accuracy: 0.9909
# Epoch 255/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.8979e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9909
# Epoch 256/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.7801e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 257/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.3536e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 258/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.6981e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 259/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.0562e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9909
# Epoch 260/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.0757e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9909
# Epoch 261/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 8.5949e-04 - accuracy: 0.9997 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 262/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.7587e-04 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9909
# Epoch 263/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.8488e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9909
# Epoch 264/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.0728e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9909
# Epoch 265/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.1228e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9909
# Epoch 266/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 6.7499e-04 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 267/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.9481e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9922
# Epoch 268/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.1684e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9922
# Epoch 269/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.9488e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9922
# Epoch 270/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.5553e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9922
# Epoch 271/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.3317e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9922
# Epoch 272/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.6814e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9922
# Epoch 273/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.9250e-04 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9922
# Epoch 274/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 1.9645e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9922
# Epoch 275/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.1971e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9922
# Epoch 276/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.2976e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9909
# Epoch 277/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 7.8502e-04 - accuracy: 0.9997 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 278/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.0363e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 279/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.0814e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9909
# Epoch 280/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 7.3841e-04 - accuracy: 0.9997 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 281/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 6.8666e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9909
# Epoch 282/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.7514e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9909
# Epoch 283/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.4381e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9909
# Epoch 284/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.7474e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9909
# Epoch 285/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.1107e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9909
# Epoch 286/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.3586e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9909
# Epoch 287/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.0661e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9909
# Epoch 288/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.9656e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9909
# Epoch 289/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.6595e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9909
# Epoch 290/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.9443e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9922
# Epoch 291/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 6.7416e-04 - accuracy: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9909
# Epoch 292/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.9545e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9909
# Epoch 293/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.9018e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9909
# Epoch 294/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.1838e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9897
# Epoch 295/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.4437e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9897
# Epoch 296/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0412 - val_accuracy: 0.9897
# Epoch 297/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.2866e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9909
# Epoch 298/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.8581e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9909
# Epoch 299/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 4.1173e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9922
# Epoch 300/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.7429e-04 - accuracy: 0.9997 - val_loss: 0.0391 - val_accuracy: 0.9909
# Epoch 301/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.4672e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 302/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.3753e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9922
# Epoch 303/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.9150e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9922
# Epoch 304/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 2.0541e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9922
# Epoch 305/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 3.9562e-04 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9922
# Epoch 306/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.5800e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9922
# Epoch 307/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.5355e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 308/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 2.5860e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9909
# Epoch 309/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.8863e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 310/2000
# 49/49 [==============================] - 18s 367ms/step - loss: 4.6511e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 311/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.0798e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 312/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 5.2635e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9897
# Epoch 313/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.7158e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9897
# Epoch 314/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 3.4698e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9922
# Epoch 315/2000
# 49/49 [==============================] - 18s 368ms/step - loss: 1.8287e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 316/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 7.0826e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9909
# Epoch 1900/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.1560e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9909
# Epoch 1901/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 5.9408e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 1902/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8684e-05 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 1903/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8073e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 1904/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 1.1201e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 1905/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.8955e-05 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9922
# Epoch 1906/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.6179e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9922
# Epoch 1907/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.0402e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9922
# Epoch 1908/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8121e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9909
# Epoch 1909/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 4.1266e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9922
# Epoch 1910/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.1944e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9922
# Epoch 1911/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 2.6126e-05 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9922
# Epoch 1912/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.7388e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9922
# Epoch 1913/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6202e-05 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9922
# Epoch 1914/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.1331e-05 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9922
# Epoch 1915/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3213e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9922
# Epoch 1916/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 4.3334e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9909
# Epoch 1917/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 9.5220e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9909
# Epoch 1918/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 4.0485e-05 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9909
# Epoch 1919/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8796e-05 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9909
# Epoch 1920/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 5.5924e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9909
# Epoch 1921/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.7879e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9909
# Epoch 1922/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3584e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9909
# Epoch 1923/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 8.9581e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9909
# Epoch 1924/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.5523e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9909
# Epoch 1925/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.2653e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9909
# Epoch 1926/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 7.3244e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9922
# Epoch 1927/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.5976e-05 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9922
# Epoch 1928/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8762e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9922
# Epoch 1929/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.2216e-05 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9922
# Epoch 1930/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.7182e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9922
# Epoch 1931/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8394e-05 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9922
# Epoch 1932/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.1598e-05 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9922
# Epoch 1933/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.7717e-05 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9922
# Epoch 1934/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.2387e-05 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9922
# Epoch 1935/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3039e-05 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9922
# Epoch 1936/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 5.4602e-05 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9922
# Epoch 1937/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.0187e-05 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9922
# Epoch 1938/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 5.8705e-05 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9922
# Epoch 1939/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 9.0945e-05 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9922
# Epoch 1940/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4576e-05 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 1941/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.6720e-05 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9922
# Epoch 1942/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4245e-05 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9922
# Epoch 1943/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3601e-05 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9922
# Epoch 1944/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6370e-05 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9922
# Epoch 1945/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 1.2286e-05 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9922
# Epoch 1946/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.0526e-04 - accuracy: 0.9997 - val_loss: 0.0395 - val_accuracy: 0.9922
# Epoch 1947/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4230e-05 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9922
# Epoch 1948/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 8.1413e-04 - accuracy: 0.9997 - val_loss: 0.0405 - val_accuracy: 0.9909
# Epoch 1949/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.1733e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 1950/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.7256e-05 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 1951/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.7089e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 1952/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.5769e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 1953/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.1193e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9909
# Epoch 1954/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.1965e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 1955/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.3400e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 1956/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6046e-05 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9909
# Epoch 1957/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 6.0050e-05 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9909
# Epoch 1958/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3436e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9909
# Epoch 1959/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.6410e-05 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9909
# Epoch 1960/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.4192e-05 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 1961/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.3979e-05 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9909
# Epoch 1962/2000
# 49/49 [==============================] - 18s 370ms/step - loss: 1.1359e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9909
# Epoch 1963/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4330e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9909
# Epoch 1964/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.5369e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9909
# Epoch 1965/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 8.8875e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9909
# Epoch 1966/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.1429e-05 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9897
# Epoch 1967/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.0959e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 1968/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4886e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 1969/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.7263e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9897
# Epoch 1970/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.5301e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9897
# Epoch 1971/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.6173e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 1972/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.0132e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9909
# Epoch 1973/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.0337e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9909
# Epoch 1974/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.2009e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1975/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.0234e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1976/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 4.5967e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1977/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.7186e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9909
# Epoch 1978/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6639e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9909
# Epoch 1979/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4035e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1980/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.2076e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1981/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.2117e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1982/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3037e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9909
# Epoch 1983/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.7478e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9909
# Epoch 1984/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.5884e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1985/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6966e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1986/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3490e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9909
# Epoch 1987/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 3.8727e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9909
# Epoch 1988/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.1084e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9909
# Epoch 1989/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.2141e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9909
# Epoch 1990/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.2286e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9909
# Epoch 1991/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6009e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9909
# Epoch 1992/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.1509e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9909
# Epoch 1993/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8642e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9909
# Epoch 1994/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 2.5669e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9909
# Epoch 1995/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8921e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9909
# Epoch 1996/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.6928e-05 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 1997/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.3920e-05 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9909
# Epoch 1998/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.2366e-05 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9909
# Epoch 1999/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.8425e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9909
# Epoch 2000/2000
# 49/49 [==============================] - 18s 369ms/step - loss: 1.4367e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9909
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB3\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 15s 402ms/step - loss: 0.3385 - accuracy: 0.9314
# test_indoor_ds_results:test loss, test acc: [0.33850595355033875, 0.931438148021698]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 27s 457ms/step - loss: 0.3740 - accuracy: 0.9232
# test_outdoor_ds_results:test loss, test acc: [0.37400659918785095, 0.9232484102249146]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 13s 328ms/step - loss: 1.0091 - accuracy: 0.8350
# test_belt_ds_results:test loss, test acc: [1.0091472864151, 0.834995448589325]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB3/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_119335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_120615) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_74179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_113114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_123973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_71463) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_70626) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_69962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_121156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_126547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_69180) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_69570) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_126376) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_118168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_118728) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_125940) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_120549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_113369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_127761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_73996) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_127220) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_117605) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_72568) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_121545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_116179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_73955) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_70135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_102767) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_74220) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_74785) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_70857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_128387) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_110242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_115572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_70667) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_71911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_115809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_71066) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_122996) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_69779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_69471) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_74612) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_74561) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_73016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_72619) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_71331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_124232) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_115743) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_72660) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_123603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_69738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_69088) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_114013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_128321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_117975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_122323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_72884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_120378) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_115202) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_126006) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_70003) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_70799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_118234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_124166) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_73772) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_113540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_124726) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_74653) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_119771) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_125769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_69298) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_70351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_71962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_69139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_123537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_73456) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_70234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_121782) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_120985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_125399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_73283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_72003) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_70193) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_119164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_72120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_122930) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_126983) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_71738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_71015) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_72344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_72436) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_114576) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_69687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_74128) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_73507) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_71107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_71290) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_117368) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_57529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_122389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_69339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_127827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_116438) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_71779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_122152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_125162) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_72171) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_71555) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_73074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_72792) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_114965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_125333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_126613) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_120008) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_124792) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_73731) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_117539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_116932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_118557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_128150) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_73232) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_70898) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_73115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_115136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_72212) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_74352) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_71239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_113606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_119942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_74444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_121222) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_71514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_118794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_69911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_122759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_123366) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_113947) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_72843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_116998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_74403) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_73680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_116372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_127154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_71687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_72395) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_121716) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_116761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_70575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_70402) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_119401) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_128757) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_73548) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_105661) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_114642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_127590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_73324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_73904) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_124555) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_70443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_69529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_114383) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 10s 285ms/step - loss: 0.2615 - accuracy: 0.9292
# 50/50 [==============================] - 14s 289ms/step - loss: 0.3144 - accuracy: 0.9236
# 35/35 [==============================] - 10s 289ms/step - loss: 0.8392 - accuracy: 0.8196
# Epoch200
#  test_indoor_acc=0.9292084574699402
#  test_outdoor_acc=0.9235668778419495
#  test_belt_acc=0.8195829391479492
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_177692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_180972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_181685) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_223432) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_234843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_221058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_181817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_179376) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_177160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_182133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_178132) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_178040) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_222825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_179692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_228067) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_233088) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_180921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_176869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_234236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_182250) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_225923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_223868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_217931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_182041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_221636) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_179468) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_179600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_228238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_179651) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_227460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_178356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_222072) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_236076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_224450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_181196) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_227697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_231662) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_231226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_222265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_224061) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_179860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_225057) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_231055) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_226853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_178488) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_224621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_181013) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_181237) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_181420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_181868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_176777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_231921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_179152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_227631) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_182092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_230012) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_179203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_165218) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_180481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_180804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_230078) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_176828) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_226246) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_181593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_221702) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_236010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_177600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_177028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_181145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_228674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_179809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_220803) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_177882) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_180257) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_226417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_210456) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1041163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1042085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1095207) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1042044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1042708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1085962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1083148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1089579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1043553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1041413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1043105) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1097028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1038499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1090186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1040058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1038730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1095748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1039776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1041545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1043197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1042749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1043813) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1091524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1039603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1040664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1041112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1087758) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1040532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1038381) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1040267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1088602) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1086569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1083843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1038939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1095141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1094363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1039435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1090357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1089750) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1042275) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1093927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1043604) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1038672) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1043645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1086133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1096355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1090746) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1071968) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1079443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1084944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1041769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1083777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1087995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1042881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1040756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1039112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1088365) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1041596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1093433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1084337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1094600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1093174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1074862) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1093756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1088972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1042525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1096184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1082807) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1040715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1090423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1084773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1043329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1093993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1042217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1039827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1043156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1038540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 10s 287ms/step - loss: 0.3385 - accuracy: 0.9314
# 50/50 [==============================] - 15s 291ms/step - loss: 0.3740 - accuracy: 0.9232
# 35/35 [==============================] - 10s 292ms/step - loss: 1.0091 - accuracy: 0.8350
# Epoch2000
#  test_indoor_acc=0.931438148021698
#  test_outdoor_acc=0.9232484102249146
#  test_belt_acc=0.834995448589325

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8965606689453125
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9292084574699402,
#  0.9308807253837585,
#  0.9264214038848877,
#  0.9275362491607666,
#  0.9247491359710693,
#  0.9264214038848877,
#  0.9292084574699402,
#  0.9292084574699402,
#  0.9325529336929321,
#  0.931438148021698]

# %%
test_outdoor_acc
# Out:
# [0.9235668778419495,
#  0.9219745397567749,
#  0.9213376045227051,
#  0.9238853454589844,
#  0.9197452068328857,
#  0.9203821420669556,
#  0.9191082715988159,
#  0.9184713363647461,
#  0.92165607213974,
#  0.9232484102249146]

# %%
test_belt_acc
# Out:
# [0.8195829391479492,
#  0.8213961720466614,
#  0.8272892236709595,
#  0.8259292840957642,
#  0.8272892236709595,
#  0.8272892236709595,
#  0.8300090432167053,
#  0.8313689827919006,
#  0.8340888619422913,
#  0.834995448589325]

# %%
test_indoor_loss
# Out:
# [0.2614908814430237,
#  0.2742639482021332,
#  0.3015018105506897,
#  0.30756691098213196,
#  0.3199003338813782,
#  0.33890393376350403,
#  0.32554247975349426,
#  0.32399970293045044,
#  0.3451981842517853,
#  0.33850595355033875]

# %%
test_outdoor_loss
# Out:
# [0.3144272267818451,
#  0.34119343757629395,
#  0.341726690530777,
#  0.34971678256988525,
#  0.3559161424636841,
#  0.366757333278656,
#  0.3700615167617798,
#  0.3794921040534973,
#  0.3834139108657837,
#  0.37400659918785095]

# %%
test_belt_loss
# Out:
# [0.839171826839447,
#  0.8833773136138916,
#  0.8959528803825378,
#  0.9431830644607544,
#  0.9312282800674438,
#  0.9684020280838013,
#  0.9680381417274475,
#  0.9880868196487427,
#  1.001214861869812,
#  1.0091472864151]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=300
img_width=300
batch_size=2

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

N = 400

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)} are predicting")
x_indoor_sets = np.array_split(x_test_indoor, N)
del x_test_indoor
y_all_sets_predicted = []
for x in x_indoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_indoor_predicted = np.concatenate(y_all_sets_predicted)
del x_indoor_sets,test_indoor_ds

x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)} are predicting")
x_outdoor_sets = np.array_split(x_test_outdoor, N)
del x_test_outdoor
y_all_sets_predicted = []
for x in x_outdoor_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_outdoor_predicted = np.concatenate(y_all_sets_predicted)
del x_outdoor_sets,test_outdoor_ds

x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)} are predicting")
x_belt_sets = np.array_split(x_test_belt, N)
del x_test_belt
y_all_sets_predicted = []
for x in x_belt_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_belt_predicted = np.concatenate(y_all_sets_predicted)
del x_belt_sets,test_belt_ds

y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
y_all_predicted = np.concatenate([y_indoor_predicted,y_outdoor_predicted,y_belt_predicted],axis=0)
print(f"all num x,y :{len(y_all_predicted)},{len(y_all)}")
# Out:
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1038980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_1026730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1096421) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1090983) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1082315) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1038340) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1041820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1097958) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1042973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1041372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1042932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1085010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1041861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1092567) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1040216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1041993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1085573) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1039394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1043986) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1095814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1093367) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1043762) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1083214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1041204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1094534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1039644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1042657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1096791) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1086199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1090917) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1038888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1043380) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1085380) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1039163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1089209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1087369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1092804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1040491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1097522) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1039336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1042484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1084403) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1096962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1040888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1089143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1091960) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1092197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1094970) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1039552) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1040099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1088536) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1042316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1040939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1085639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1097351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1086740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1082570) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1043421) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1089816) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1084166) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1087435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1041321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1038289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1095577) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1039204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1092738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1092131) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1086806) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1042433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1040000) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1039868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1087929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1083584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1040308) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1087176) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1091590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1091353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1040980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1043854) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1038771) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1040440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1082741) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1041637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1097588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1041163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1042085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1095207) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1042044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1042708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1085962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1083148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1089579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1043553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1041413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1043105) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1097028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1038499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1090186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1040058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1038730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1095748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1039776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1041545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1043197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1042749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1043813) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1091524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1039603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1040664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1041112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1087758) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1040532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1038381) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1040267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1088602) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1086569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1083843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1038939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1095141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1094363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1039435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1090357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1089750) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1042275) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1093927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1043604) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1038672) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1043645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1086133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1096355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1090746) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1071968) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1079443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1084944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1041769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1083777) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1087995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1042881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1040756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1039112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1088365) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1041596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1093433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1084337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1094600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1093174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1074862) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1093756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1088972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1042525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1096184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1082807) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1040715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1090423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1084773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1043329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1093993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1042217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1039827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1043156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1038540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794 are predicting
# train_outdoor num x,y : 3140,3140 are predicting
# train_belt num x,y : 2206,2206 are predicting
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6412
# FP=728
# acc=0.8980392156862745
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 89.66770508826583%
# 2-BloodSecretionWaste acc = 78.78962536023056%
# 3-LabWardWaste acc = 93.27354260089686%
# 4-VaccineOtherWaste acc = 96.6837926202709%
#
#
#
# all_avg_eachclass = 89.60366641741604%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1727,  166,   17,   16],
#        [ 263, 1367,   48,   57],
#        [  33,   29, 1248,   28],
#        [  11,   47,   13, 2070]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[89.66770509,  8.61889927,  0.88265836,  0.83073728],
#        [15.15850144, 78.78962536,  2.76657061,  3.28530259],
#        [ 2.46636771,  2.16741405, 93.2735426 ,  2.09267564],
#        [ 0.51377861,  2.19523587,  0.6071929 , 96.68379262]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
