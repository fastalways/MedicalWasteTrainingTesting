# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.VGG16(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-4].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 25088)             14714688
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 40,409,924
# Trainable params: 25,695,236
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_VGG16/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 49s 377ms/step - loss: 3.1325 - accuracy: 0.6359 - val_loss: 0.4657 - val_accuracy: 0.8435
# Epoch 2/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.3684 - accuracy: 0.8601 - val_loss: 0.4003 - val_accuracy: 0.8668
# Epoch 3/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.2372 - accuracy: 0.9189 - val_loss: 0.3484 - val_accuracy: 0.8887
# Epoch 4/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.1594 - accuracy: 0.9496 - val_loss: 0.3843 - val_accuracy: 0.8836
# Epoch 5/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.1170 - accuracy: 0.9658 - val_loss: 0.3296 - val_accuracy: 0.8978
# Epoch 6/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0910 - accuracy: 0.9816 - val_loss: 0.2995 - val_accuracy: 0.9120
# Epoch 7/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0725 - accuracy: 0.9845 - val_loss: 0.3041 - val_accuracy: 0.8862
# Epoch 8/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0747 - accuracy: 0.9780 - val_loss: 0.3366 - val_accuracy: 0.8810
# Epoch 9/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0668 - accuracy: 0.9806 - val_loss: 0.3448 - val_accuracy: 0.8810
# Epoch 10/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0665 - accuracy: 0.9803 - val_loss: 0.3349 - val_accuracy: 0.9107
# Epoch 11/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0680 - accuracy: 0.9784 - val_loss: 0.4249 - val_accuracy: 0.9094
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 12/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0362 - accuracy: 0.9910 - val_loss: 0.3223 - val_accuracy: 0.9056
# Epoch 13/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0301 - accuracy: 0.9932 - val_loss: 0.3272 - val_accuracy: 0.9159
# Epoch 14/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0247 - accuracy: 0.9961 - val_loss: 0.3216 - val_accuracy: 0.9224
# Epoch 15/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0231 - accuracy: 0.9968 - val_loss: 0.3380 - val_accuracy: 0.9224
# Epoch 16/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0216 - accuracy: 0.9964 - val_loss: 0.3266 - val_accuracy: 0.9211
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 17/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0205 - accuracy: 0.9958 - val_loss: 0.3239 - val_accuracy: 0.9198
# Epoch 18/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0193 - accuracy: 0.9961 - val_loss: 0.3254 - val_accuracy: 0.9198
# Epoch 19/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0187 - accuracy: 0.9971 - val_loss: 0.3195 - val_accuracy: 0.9185
# Epoch 20/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0193 - accuracy: 0.9964 - val_loss: 0.3216 - val_accuracy: 0.9159
# Epoch 21/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0186 - accuracy: 0.9971 - val_loss: 0.3203 - val_accuracy: 0.9198
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 22/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0178 - accuracy: 0.9964 - val_loss: 0.3218 - val_accuracy: 0.9211
# Epoch 23/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0181 - accuracy: 0.9971 - val_loss: 0.3246 - val_accuracy: 0.9198
# Epoch 24/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0185 - accuracy: 0.9974 - val_loss: 0.3246 - val_accuracy: 0.9198
# Epoch 25/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0177 - accuracy: 0.9974 - val_loss: 0.3247 - val_accuracy: 0.9198
# Epoch 26/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0179 - accuracy: 0.9974 - val_loss: 0.3256 - val_accuracy: 0.9211
# Epoch 27/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0170 - accuracy: 0.9977 - val_loss: 0.3264 - val_accuracy: 0.9211
# Epoch 28/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0181 - accuracy: 0.9964 - val_loss: 0.3260 - val_accuracy: 0.9211
# Epoch 29/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0178 - accuracy: 0.9961 - val_loss: 0.3257 - val_accuracy: 0.9211
# Epoch 30/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0173 - accuracy: 0.9974 - val_loss: 0.3253 - val_accuracy: 0.9198
# Epoch 31/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0165 - accuracy: 0.9977 - val_loss: 0.3257 - val_accuracy: 0.9211
# Epoch 32/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0172 - accuracy: 0.9971 - val_loss: 0.3274 - val_accuracy: 0.9211
# Epoch 33/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0173 - accuracy: 0.9964 - val_loss: 0.3265 - val_accuracy: 0.9198
# Epoch 34/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0168 - accuracy: 0.9974 - val_loss: 0.3238 - val_accuracy: 0.9211
# Epoch 35/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0170 - accuracy: 0.9971 - val_loss: 0.3245 - val_accuracy: 0.9211
# Epoch 36/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0173 - accuracy: 0.9974 - val_loss: 0.3233 - val_accuracy: 0.9198
# Epoch 37/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0167 - accuracy: 0.9971 - val_loss: 0.3258 - val_accuracy: 0.9224
# Epoch 38/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0173 - accuracy: 0.9974 - val_loss: 0.3241 - val_accuracy: 0.9211
# Epoch 39/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0166 - accuracy: 0.9971 - val_loss: 0.3232 - val_accuracy: 0.9237
# Epoch 40/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0167 - accuracy: 0.9974 - val_loss: 0.3242 - val_accuracy: 0.9211
# Epoch 41/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0179 - accuracy: 0.9968 - val_loss: 0.3269 - val_accuracy: 0.9211
# Epoch 42/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0169 - accuracy: 0.9971 - val_loss: 0.3225 - val_accuracy: 0.9224
# Epoch 43/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0164 - accuracy: 0.9971 - val_loss: 0.3239 - val_accuracy: 0.9224
# Epoch 44/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0163 - accuracy: 0.9971 - val_loss: 0.3230 - val_accuracy: 0.9224
# Epoch 45/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0172 - accuracy: 0.9974 - val_loss: 0.3268 - val_accuracy: 0.9250
# Epoch 46/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0152 - accuracy: 0.9981 - val_loss: 0.3234 - val_accuracy: 0.9237
# Epoch 47/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0177 - accuracy: 0.9964 - val_loss: 0.3245 - val_accuracy: 0.9224
# Epoch 48/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0165 - accuracy: 0.9968 - val_loss: 0.3229 - val_accuracy: 0.9250
# Epoch 49/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0157 - accuracy: 0.9981 - val_loss: 0.3214 - val_accuracy: 0.9224
# Epoch 50/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0159 - accuracy: 0.9974 - val_loss: 0.3226 - val_accuracy: 0.9250
# Epoch 51/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0165 - accuracy: 0.9971 - val_loss: 0.3199 - val_accuracy: 0.9224
# Epoch 52/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0165 - accuracy: 0.9974 - val_loss: 0.3212 - val_accuracy: 0.9237
# Epoch 53/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0152 - accuracy: 0.9971 - val_loss: 0.3230 - val_accuracy: 0.9237
# Epoch 54/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0162 - accuracy: 0.9977 - val_loss: 0.3245 - val_accuracy: 0.9237
# Epoch 55/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0163 - accuracy: 0.9981 - val_loss: 0.3229 - val_accuracy: 0.9237
# Epoch 56/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0160 - accuracy: 0.9971 - val_loss: 0.3223 - val_accuracy: 0.9237
# Epoch 57/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0163 - accuracy: 0.9974 - val_loss: 0.3249 - val_accuracy: 0.9263
# Epoch 58/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0161 - accuracy: 0.9974 - val_loss: 0.3215 - val_accuracy: 0.9224
# Epoch 59/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0157 - accuracy: 0.9977 - val_loss: 0.3251 - val_accuracy: 0.9237
# Epoch 60/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0156 - accuracy: 0.9971 - val_loss: 0.3248 - val_accuracy: 0.9250
# Epoch 61/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0158 - accuracy: 0.9977 - val_loss: 0.3229 - val_accuracy: 0.9250
# Epoch 62/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0161 - accuracy: 0.9977 - val_loss: 0.3259 - val_accuracy: 0.9237
# Epoch 63/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0159 - accuracy: 0.9974 - val_loss: 0.3260 - val_accuracy: 0.9224
# Epoch 64/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0147 - accuracy: 0.9974 - val_loss: 0.3277 - val_accuracy: 0.9263
# Epoch 65/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0147 - accuracy: 0.9971 - val_loss: 0.3237 - val_accuracy: 0.9250
# Epoch 66/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0149 - accuracy: 0.9981 - val_loss: 0.3235 - val_accuracy: 0.9224
# Epoch 67/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0147 - accuracy: 0.9977 - val_loss: 0.3252 - val_accuracy: 0.9237
# Epoch 68/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.3248 - val_accuracy: 0.9237
# Epoch 69/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0142 - accuracy: 0.9977 - val_loss: 0.3258 - val_accuracy: 0.9224
# Epoch 70/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0153 - accuracy: 0.9977 - val_loss: 0.3259 - val_accuracy: 0.9250
# Epoch 71/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0148 - accuracy: 0.9974 - val_loss: 0.3244 - val_accuracy: 0.9237
# Epoch 72/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0150 - accuracy: 0.9974 - val_loss: 0.3269 - val_accuracy: 0.9211
# Epoch 73/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0144 - accuracy: 0.9971 - val_loss: 0.3285 - val_accuracy: 0.9224
# Epoch 74/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0137 - accuracy: 0.9977 - val_loss: 0.3262 - val_accuracy: 0.9224
# Epoch 75/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0152 - accuracy: 0.9968 - val_loss: 0.3262 - val_accuracy: 0.9211
# Epoch 76/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0141 - accuracy: 0.9977 - val_loss: 0.3266 - val_accuracy: 0.9224
# Epoch 77/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 0.3271 - val_accuracy: 0.9224
# Epoch 78/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0143 - accuracy: 0.9971 - val_loss: 0.3254 - val_accuracy: 0.9250
# Epoch 79/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0136 - accuracy: 0.9977 - val_loss: 0.3259 - val_accuracy: 0.9237
# Epoch 80/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0130 - accuracy: 0.9981 - val_loss: 0.3279 - val_accuracy: 0.9250
# Epoch 81/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 0.3253 - val_accuracy: 0.9224
# Epoch 82/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0147 - accuracy: 0.9974 - val_loss: 0.3242 - val_accuracy: 0.9237
# Epoch 83/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0146 - accuracy: 0.9968 - val_loss: 0.3315 - val_accuracy: 0.9237
# Epoch 84/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0133 - accuracy: 0.9981 - val_loss: 0.3235 - val_accuracy: 0.9237
# Epoch 85/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0137 - accuracy: 0.9981 - val_loss: 0.3227 - val_accuracy: 0.9250
# Epoch 86/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0135 - accuracy: 0.9981 - val_loss: 0.3264 - val_accuracy: 0.9250
# Epoch 87/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0130 - accuracy: 0.9977 - val_loss: 0.3298 - val_accuracy: 0.9250
# Epoch 88/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0134 - accuracy: 0.9981 - val_loss: 0.3241 - val_accuracy: 0.9250
# Epoch 89/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0124 - accuracy: 0.9984 - val_loss: 0.3317 - val_accuracy: 0.9263
# Epoch 90/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0130 - accuracy: 0.9981 - val_loss: 0.3255 - val_accuracy: 0.9224
# Epoch 91/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0128 - accuracy: 0.9981 - val_loss: 0.3275 - val_accuracy: 0.9250
# Epoch 92/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 0.3273 - val_accuracy: 0.9250
# Epoch 93/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0120 - accuracy: 0.9984 - val_loss: 0.3284 - val_accuracy: 0.9237
# Epoch 94/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0128 - accuracy: 0.9977 - val_loss: 0.3274 - val_accuracy: 0.9250
# Epoch 95/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0123 - accuracy: 0.9977 - val_loss: 0.3316 - val_accuracy: 0.9237
# Epoch 96/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0120 - accuracy: 0.9981 - val_loss: 0.3296 - val_accuracy: 0.9250
# Epoch 97/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0121 - accuracy: 0.9981 - val_loss: 0.3251 - val_accuracy: 0.9237
# Epoch 98/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0125 - accuracy: 0.9981 - val_loss: 0.3298 - val_accuracy: 0.9237
# Epoch 99/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0122 - accuracy: 0.9981 - val_loss: 0.3334 - val_accuracy: 0.9211
# Epoch 100/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0115 - accuracy: 0.9977 - val_loss: 0.3308 - val_accuracy: 0.9237
# Epoch 101/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.3293 - val_accuracy: 0.9237
# Epoch 102/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.3296 - val_accuracy: 0.9250
# Epoch 103/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0125 - accuracy: 0.9974 - val_loss: 0.3304 - val_accuracy: 0.9237
# Epoch 104/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0111 - accuracy: 0.9984 - val_loss: 0.3342 - val_accuracy: 0.9250
# Epoch 105/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0110 - accuracy: 0.9977 - val_loss: 0.3319 - val_accuracy: 0.9250
# Epoch 106/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.3330 - val_accuracy: 0.9250
# Epoch 107/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.3318 - val_accuracy: 0.9250
# Epoch 108/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0113 - accuracy: 0.9984 - val_loss: 0.3288 - val_accuracy: 0.9250
# Epoch 109/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0115 - accuracy: 0.9977 - val_loss: 0.3340 - val_accuracy: 0.9250
# Epoch 110/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 0.3280 - val_accuracy: 0.9237
# Epoch 111/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.3343 - val_accuracy: 0.9250
# Epoch 112/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.3346 - val_accuracy: 0.9237
# Epoch 113/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.3314 - val_accuracy: 0.9237
# Epoch 114/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.3293 - val_accuracy: 0.9237
# Epoch 115/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0110 - accuracy: 0.9977 - val_loss: 0.3319 - val_accuracy: 0.9224
# Epoch 116/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0107 - accuracy: 0.9987 - val_loss: 0.3351 - val_accuracy: 0.9237
# Epoch 117/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0104 - accuracy: 0.9981 - val_loss: 0.3327 - val_accuracy: 0.9224
# Epoch 118/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.3326 - val_accuracy: 0.9237
# Epoch 119/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0105 - accuracy: 0.9977 - val_loss: 0.3356 - val_accuracy: 0.9250
# Epoch 120/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0108 - accuracy: 0.9984 - val_loss: 0.3342 - val_accuracy: 0.9237
# Epoch 121/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0105 - accuracy: 0.9981 - val_loss: 0.3360 - val_accuracy: 0.9237
# Epoch 122/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0101 - accuracy: 0.9977 - val_loss: 0.3358 - val_accuracy: 0.9237
# Epoch 123/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.3364 - val_accuracy: 0.9237
# Epoch 124/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.3393 - val_accuracy: 0.9250
# Epoch 125/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 0.3360 - val_accuracy: 0.9224
# Epoch 126/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0099 - accuracy: 0.9981 - val_loss: 0.3359 - val_accuracy: 0.9237
# Epoch 127/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.3405 - val_accuracy: 0.9237
# Epoch 128/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.3414 - val_accuracy: 0.9263
# Epoch 129/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.3393 - val_accuracy: 0.9237
# Epoch 130/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.3388 - val_accuracy: 0.9237
# Epoch 131/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.3405 - val_accuracy: 0.9237
# Epoch 132/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0092 - accuracy: 0.9984 - val_loss: 0.3421 - val_accuracy: 0.9237
# Epoch 133/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.3376 - val_accuracy: 0.9237
# Epoch 134/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.3431 - val_accuracy: 0.9276
# Epoch 135/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.3425 - val_accuracy: 0.9250
# Epoch 136/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0086 - accuracy: 0.9987 - val_loss: 0.3412 - val_accuracy: 0.9237
# Epoch 137/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.3416 - val_accuracy: 0.9250
# Epoch 138/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0081 - accuracy: 0.9987 - val_loss: 0.3413 - val_accuracy: 0.9250
# Epoch 139/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.3432 - val_accuracy: 0.9250
# Epoch 140/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.3455 - val_accuracy: 0.9211
# Epoch 141/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.3419 - val_accuracy: 0.9237
# Epoch 142/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.3455 - val_accuracy: 0.9250
# Epoch 143/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0082 - accuracy: 0.9987 - val_loss: 0.3447 - val_accuracy: 0.9237
# Epoch 144/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.3462 - val_accuracy: 0.9224
# Epoch 145/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.3475 - val_accuracy: 0.9237
# Epoch 146/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.3477 - val_accuracy: 0.9237
# Epoch 147/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0077 - accuracy: 0.9984 - val_loss: 0.3438 - val_accuracy: 0.9237
# Epoch 148/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0075 - accuracy: 0.9990 - val_loss: 0.3479 - val_accuracy: 0.9224
# Epoch 149/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.3474 - val_accuracy: 0.9237
# Epoch 150/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.3447 - val_accuracy: 0.9237
# Epoch 151/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 0.3494 - val_accuracy: 0.9224
# Epoch 152/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 0.3485 - val_accuracy: 0.9250
# Epoch 153/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 0.3484 - val_accuracy: 0.9237
# Epoch 154/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.3466 - val_accuracy: 0.9224
# Epoch 155/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.3519 - val_accuracy: 0.9237
# Epoch 156/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.3515 - val_accuracy: 0.9250
# Epoch 157/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0074 - accuracy: 0.9987 - val_loss: 0.3477 - val_accuracy: 0.9250
# Epoch 158/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.3557 - val_accuracy: 0.9250
# Epoch 159/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0069 - accuracy: 0.9994 - val_loss: 0.3508 - val_accuracy: 0.9250
# Epoch 160/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.3526 - val_accuracy: 0.9250
# Epoch 161/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.3504 - val_accuracy: 0.9250
# Epoch 162/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.3569 - val_accuracy: 0.9237
# Epoch 163/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0065 - accuracy: 0.9990 - val_loss: 0.3580 - val_accuracy: 0.9237
# Epoch 164/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.3542 - val_accuracy: 0.9237
# Epoch 165/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.3605 - val_accuracy: 0.9224
# Epoch 166/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0071 - accuracy: 0.9990 - val_loss: 0.3555 - val_accuracy: 0.9237
# Epoch 167/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.3533 - val_accuracy: 0.9224
# Epoch 168/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0065 - accuracy: 0.9990 - val_loss: 0.3546 - val_accuracy: 0.9237
# Epoch 169/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.3606 - val_accuracy: 0.9237
# Epoch 170/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0064 - accuracy: 0.9990 - val_loss: 0.3619 - val_accuracy: 0.9224
# Epoch 171/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0059 - accuracy: 0.9987 - val_loss: 0.3589 - val_accuracy: 0.9237
# Epoch 172/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.3562 - val_accuracy: 0.9250
# Epoch 173/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.3602 - val_accuracy: 0.9224
# Epoch 174/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.3591 - val_accuracy: 0.9250
# Epoch 175/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.3603 - val_accuracy: 0.9250
# Epoch 176/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.3620 - val_accuracy: 0.9250
# Epoch 177/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.3667 - val_accuracy: 0.9224
# Epoch 178/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.3603 - val_accuracy: 0.9237
# Epoch 179/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.3592 - val_accuracy: 0.9250
# Epoch 180/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.3655 - val_accuracy: 0.9237
# Epoch 181/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.3635 - val_accuracy: 0.9224
# Epoch 182/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.3694 - val_accuracy: 0.9237
# Epoch 183/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.3668 - val_accuracy: 0.9237
# Epoch 184/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.3637 - val_accuracy: 0.9250
# Epoch 185/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.3679 - val_accuracy: 0.9237
# Epoch 186/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.3642 - val_accuracy: 0.9250
# Epoch 187/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.3690 - val_accuracy: 0.9250
# Epoch 188/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.3683 - val_accuracy: 0.9250
# Epoch 189/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.3649 - val_accuracy: 0.9263
# Epoch 190/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.3665 - val_accuracy: 0.9250
# Epoch 191/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.3742 - val_accuracy: 0.9237
# Epoch 192/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.3706 - val_accuracy: 0.9250
# Epoch 193/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.3697 - val_accuracy: 0.9263
# Epoch 194/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.3708 - val_accuracy: 0.9263
# Epoch 195/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.3662 - val_accuracy: 0.9237
# Epoch 196/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 0.3700 - val_accuracy: 0.9250
# Epoch 197/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.3713 - val_accuracy: 0.9263
# Epoch 198/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.3713 - val_accuracy: 0.9263
# Epoch 199/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.3750 - val_accuracy: 0.9263
# Epoch 200/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.3671 - val_accuracy: 0.9250
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_VGG16\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.3748 - val_accuracy: 0.9263
# Epoch 202/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.3772 - val_accuracy: 0.9250
# Epoch 203/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.3790 - val_accuracy: 0.9250
# Epoch 204/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.9250
# Epoch 205/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.3748 - val_accuracy: 0.9237
# Epoch 206/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9250
# Epoch 207/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.3846 - val_accuracy: 0.9250
# Epoch 208/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.3816 - val_accuracy: 0.9250
# Epoch 209/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.3790 - val_accuracy: 0.9237
# Epoch 210/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.3797 - val_accuracy: 0.9237
# Epoch 211/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.3776 - val_accuracy: 0.9237
# Epoch 212/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3763 - val_accuracy: 0.9237
# Epoch 213/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.3791 - val_accuracy: 0.9250
# Epoch 214/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3840 - val_accuracy: 0.9250
# Epoch 215/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.3830 - val_accuracy: 0.9237
# Epoch 216/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.3821 - val_accuracy: 0.9250
# Epoch 217/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.3814 - val_accuracy: 0.9250
# Epoch 218/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.3833 - val_accuracy: 0.9250
# Epoch 219/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.3865 - val_accuracy: 0.9263
# Epoch 220/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.3899 - val_accuracy: 0.9211
# Epoch 221/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.9237
# Epoch 222/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.3900 - val_accuracy: 0.9224
# Epoch 223/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.3830 - val_accuracy: 0.9250
# Epoch 224/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.3916 - val_accuracy: 0.9237
# Epoch 225/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3889 - val_accuracy: 0.9250
# Epoch 226/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3880 - val_accuracy: 0.9250
# Epoch 227/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.3905 - val_accuracy: 0.9250
# Epoch 228/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.3944 - val_accuracy: 0.9250
# Epoch 229/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.3953 - val_accuracy: 0.9237
# Epoch 230/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.3994 - val_accuracy: 0.9224
# Epoch 231/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.9237
# Epoch 232/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.9250
# Epoch 233/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3993 - val_accuracy: 0.9250
# Epoch 234/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3986 - val_accuracy: 0.9250
# Epoch 235/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3995 - val_accuracy: 0.9237
# Epoch 236/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9224
# Epoch 237/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4028 - val_accuracy: 0.9237
# Epoch 238/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4038 - val_accuracy: 0.9250
# Epoch 239/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.3970 - val_accuracy: 0.9224
# Epoch 240/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3993 - val_accuracy: 0.9224
# Epoch 241/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.3942 - val_accuracy: 0.9250
# Epoch 242/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.4086 - val_accuracy: 0.9211
# Epoch 243/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4035 - val_accuracy: 0.9224
# Epoch 244/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3988 - val_accuracy: 0.9237
# Epoch 245/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.4050 - val_accuracy: 0.9198
# Epoch 246/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.9250
# Epoch 247/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4103 - val_accuracy: 0.9224
# Epoch 248/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4178 - val_accuracy: 0.9263
# Epoch 249/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.3947 - val_accuracy: 0.9250
# Epoch 250/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4040 - val_accuracy: 0.9211
# Epoch 251/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.9237
# Epoch 252/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4122 - val_accuracy: 0.9224
# Epoch 253/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4109 - val_accuracy: 0.9237
# Epoch 254/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.4128 - val_accuracy: 0.9211
# Epoch 255/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4120 - val_accuracy: 0.9211
# Epoch 256/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4076 - val_accuracy: 0.9224
# Epoch 257/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4205 - val_accuracy: 0.9263
# Epoch 258/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.9224
# Epoch 259/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4098 - val_accuracy: 0.9237
# Epoch 260/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4147 - val_accuracy: 0.9211
# Epoch 261/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4155 - val_accuracy: 0.9224
# Epoch 262/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4154 - val_accuracy: 0.9224
# Epoch 263/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4110 - val_accuracy: 0.9224
# Epoch 264/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.9237
# Epoch 265/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.4142 - val_accuracy: 0.9250
# Epoch 266/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4161 - val_accuracy: 0.9211
# Epoch 267/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.9237
# Epoch 268/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4080 - val_accuracy: 0.9250
# Epoch 269/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4187 - val_accuracy: 0.9224
# Epoch 270/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4227 - val_accuracy: 0.9237
# Epoch 271/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.9250
# Epoch 272/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4231 - val_accuracy: 0.9224
# Epoch 273/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4174 - val_accuracy: 0.9211
# Epoch 274/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4188 - val_accuracy: 0.9211
# Epoch 275/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4193 - val_accuracy: 0.9224
# Epoch 276/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4215 - val_accuracy: 0.9224
# Epoch 277/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.9224
# Epoch 278/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.4214 - val_accuracy: 0.9211
# Epoch 279/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4322 - val_accuracy: 0.9224
# Epoch 280/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4316 - val_accuracy: 0.9224
# Epoch 281/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4229 - val_accuracy: 0.9224
# Epoch 282/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4316 - val_accuracy: 0.9211
# Epoch 283/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4393 - val_accuracy: 0.9263
# Epoch 284/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.9263
# Epoch 285/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4244 - val_accuracy: 0.9276
# Epoch 286/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4258 - val_accuracy: 0.9263
# Epoch 287/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4294 - val_accuracy: 0.9224
# Epoch 288/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4297 - val_accuracy: 0.9224
# Epoch 289/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4304 - val_accuracy: 0.9224
# Epoch 290/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.9224
# Epoch 291/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4408 - val_accuracy: 0.9250
# Epoch 292/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4419 - val_accuracy: 0.9237
# Epoch 293/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4377 - val_accuracy: 0.9250
# Epoch 294/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4453 - val_accuracy: 0.9263
# Epoch 295/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4448 - val_accuracy: 0.9250
# Epoch 296/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4439 - val_accuracy: 0.9263
# Epoch 297/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4436 - val_accuracy: 0.9250
# Epoch 298/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4441 - val_accuracy: 0.9250
# Epoch 299/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4481 - val_accuracy: 0.9263
# Epoch 300/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4580 - val_accuracy: 0.9276
# Epoch 301/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4409 - val_accuracy: 0.9237
# Epoch 302/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4511 - val_accuracy: 0.9250
# Epoch 303/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.9237
# Epoch 304/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.9237
# Epoch 305/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4417 - val_accuracy: 0.9237
# Epoch 306/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4473 - val_accuracy: 0.9237
# Epoch 307/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4509 - val_accuracy: 0.9250
# Epoch 308/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.9237
# Epoch 309/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4500 - val_accuracy: 0.9237
# Epoch 310/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4441 - val_accuracy: 0.9224
# Epoch 311/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4507 - val_accuracy: 0.9237
# Epoch 312/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4488 - val_accuracy: 0.9237
# Epoch 313/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4501 - val_accuracy: 0.9224
# Epoch 314/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.9237
# Epoch 315/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4442 - val_accuracy: 0.9237
# Epoch 316/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4459 - val_accuracy: 0.9250
# Epoch 317/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.6693e-04 - accuracy: 1.0000 - val_loss: 0.4530 - val_accuracy: 0.9237
# Epoch 318/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.6529e-04 - accuracy: 1.0000 - val_loss: 0.4640 - val_accuracy: 0.9250
# Epoch 319/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4632 - val_accuracy: 0.9276
# Epoch 320/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.9250
# Epoch 321/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4589 - val_accuracy: 0.9250
# Epoch 322/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.9276
# Epoch 323/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.4570 - val_accuracy: 0.9224
# Epoch 324/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.0551e-04 - accuracy: 1.0000 - val_loss: 0.4627 - val_accuracy: 0.9276
# Epoch 325/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.2307e-04 - accuracy: 1.0000 - val_loss: 0.4646 - val_accuracy: 0.9263
# Epoch 326/2000
# ...
# Epoch 1896/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.3118e-08 - accuracy: 1.0000 - val_loss: 0.9782 - val_accuracy: 0.9237
# Epoch 1897/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3370e-08 - accuracy: 1.0000 - val_loss: 0.9778 - val_accuracy: 0.9224
# Epoch 1898/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.5002e-08 - accuracy: 1.0000 - val_loss: 0.9737 - val_accuracy: 0.9224
# Epoch 1899/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4616e-08 - accuracy: 1.0000 - val_loss: 0.9725 - val_accuracy: 0.9224
# Epoch 1900/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.0537e-08 - accuracy: 1.0000 - val_loss: 0.9697 - val_accuracy: 0.9224
# Epoch 1901/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.0157e-07 - accuracy: 1.0000 - val_loss: 0.9808 - val_accuracy: 0.9224
# Epoch 1902/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.5152e-07 - accuracy: 1.0000 - val_loss: 0.9772 - val_accuracy: 0.9224
# Epoch 1903/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.5174e-08 - accuracy: 1.0000 - val_loss: 0.9659 - val_accuracy: 0.9224
# Epoch 1904/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.5425e-08 - accuracy: 1.0000 - val_loss: 0.9628 - val_accuracy: 0.9211
# Epoch 1905/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.0569e-07 - accuracy: 1.0000 - val_loss: 0.9772 - val_accuracy: 0.9224
# Epoch 1906/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.2729e-08 - accuracy: 1.0000 - val_loss: 0.9681 - val_accuracy: 0.9224
# Epoch 1907/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.7871e-07 - accuracy: 1.0000 - val_loss: 0.9856 - val_accuracy: 0.9224
# Epoch 1908/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.3142e-07 - accuracy: 1.0000 - val_loss: 0.9707 - val_accuracy: 0.9211
# Epoch 1909/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.6720e-06 - accuracy: 1.0000 - val_loss: 0.9740 - val_accuracy: 0.9172
# Epoch 1910/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.5197e-07 - accuracy: 1.0000 - val_loss: 0.9759 - val_accuracy: 0.9211
# Epoch 1911/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1303e-07 - accuracy: 1.0000 - val_loss: 0.9758 - val_accuracy: 0.9224
# Epoch 1912/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2606e-07 - accuracy: 1.0000 - val_loss: 0.9612 - val_accuracy: 0.9211
# Epoch 1913/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2776e-07 - accuracy: 1.0000 - val_loss: 0.9620 - val_accuracy: 0.9211
# Epoch 1914/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.5387e-07 - accuracy: 1.0000 - val_loss: 0.9646 - val_accuracy: 0.9198
# Epoch 1915/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.1910e-08 - accuracy: 1.0000 - val_loss: 0.9611 - val_accuracy: 0.9198
# Epoch 1916/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2425e-07 - accuracy: 1.0000 - val_loss: 0.9622 - val_accuracy: 0.9198
# Epoch 1917/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5782e-08 - accuracy: 1.0000 - val_loss: 0.9637 - val_accuracy: 0.9198
# Epoch 1918/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.9662e-08 - accuracy: 1.0000 - val_loss: 0.9633 - val_accuracy: 0.9198
# Epoch 1919/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.8689e-08 - accuracy: 1.0000 - val_loss: 0.9671 - val_accuracy: 0.9198
# Epoch 1920/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.4221e-08 - accuracy: 1.0000 - val_loss: 0.9706 - val_accuracy: 0.9211
# Epoch 1921/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5718e-07 - accuracy: 1.0000 - val_loss: 0.9786 - val_accuracy: 0.9237
# Epoch 1922/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.8360e-07 - accuracy: 1.0000 - val_loss: 1.0078 - val_accuracy: 0.9224
# Epoch 1923/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0128e-08 - accuracy: 1.0000 - val_loss: 0.9931 - val_accuracy: 0.9211
# Epoch 1924/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.6970e-08 - accuracy: 1.0000 - val_loss: 0.9852 - val_accuracy: 0.9224
# Epoch 1925/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.9358e-08 - accuracy: 1.0000 - val_loss: 0.9876 - val_accuracy: 0.9224
# Epoch 1926/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.8101e-08 - accuracy: 1.0000 - val_loss: 0.9787 - val_accuracy: 0.9224
# Epoch 1927/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.8394e-08 - accuracy: 1.0000 - val_loss: 0.9835 - val_accuracy: 0.9224
# Epoch 1928/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.9512e-08 - accuracy: 1.0000 - val_loss: 0.9834 - val_accuracy: 0.9224
# Epoch 1929/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.6441e-08 - accuracy: 1.0000 - val_loss: 0.9806 - val_accuracy: 0.9224
# Epoch 1930/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.7239e-08 - accuracy: 1.0000 - val_loss: 0.9902 - val_accuracy: 0.9224
# Epoch 1931/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2036e-07 - accuracy: 1.0000 - val_loss: 1.0064 - val_accuracy: 0.9224
# Epoch 1932/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.1627e-08 - accuracy: 1.0000 - val_loss: 1.0039 - val_accuracy: 0.9224
# Epoch 1933/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1402e-07 - accuracy: 1.0000 - val_loss: 1.0001 - val_accuracy: 0.9237
# Epoch 1934/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.9522e-08 - accuracy: 1.0000 - val_loss: 0.9986 - val_accuracy: 0.9237
# Epoch 1935/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2625e-07 - accuracy: 1.0000 - val_loss: 0.9963 - val_accuracy: 0.9237
# Epoch 1936/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.1555e-07 - accuracy: 1.0000 - val_loss: 0.9692 - val_accuracy: 0.9211
# Epoch 1937/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0898e-08 - accuracy: 1.0000 - val_loss: 0.9686 - val_accuracy: 0.9211
# Epoch 1938/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.7452e-08 - accuracy: 1.0000 - val_loss: 0.9659 - val_accuracy: 0.9211
# Epoch 1939/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.1886e-07 - accuracy: 1.0000 - val_loss: 0.9770 - val_accuracy: 0.9224
# Epoch 1940/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2078e-07 - accuracy: 1.0000 - val_loss: 0.9919 - val_accuracy: 0.9224
# Epoch 1941/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1769e-08 - accuracy: 1.0000 - val_loss: 0.9865 - val_accuracy: 0.9224
# Epoch 1942/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.8752e-08 - accuracy: 1.0000 - val_loss: 0.9880 - val_accuracy: 0.9237
# Epoch 1943/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9258e-07 - accuracy: 1.0000 - val_loss: 0.9766 - val_accuracy: 0.9224
# Epoch 1944/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.3388e-07 - accuracy: 1.0000 - val_loss: 0.9870 - val_accuracy: 0.9224
# Epoch 1945/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.4862e-08 - accuracy: 1.0000 - val_loss: 0.9855 - val_accuracy: 0.9224
# Epoch 1946/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3758e-07 - accuracy: 1.0000 - val_loss: 1.0198 - val_accuracy: 0.9224
# Epoch 1947/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.5926e-08 - accuracy: 1.0000 - val_loss: 1.0136 - val_accuracy: 0.9224
# Epoch 1948/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5165e-07 - accuracy: 1.0000 - val_loss: 0.9881 - val_accuracy: 0.9237
# Epoch 1949/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2960e-07 - accuracy: 1.0000 - val_loss: 1.0003 - val_accuracy: 0.9237
# Epoch 1950/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.2281e-08 - accuracy: 1.0000 - val_loss: 0.9952 - val_accuracy: 0.9224
# Epoch 1951/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.5092e-08 - accuracy: 1.0000 - val_loss: 0.9955 - val_accuracy: 0.9224
# Epoch 1952/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.0330e-07 - accuracy: 1.0000 - val_loss: 0.9878 - val_accuracy: 0.9224
# Epoch 1953/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.9623e-08 - accuracy: 1.0000 - val_loss: 0.9819 - val_accuracy: 0.9224
# Epoch 1954/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1650e-07 - accuracy: 1.0000 - val_loss: 0.9667 - val_accuracy: 0.9211
# Epoch 1955/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.6927e-07 - accuracy: 1.0000 - val_loss: 0.9744 - val_accuracy: 0.9224
# Epoch 1956/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.6134e-07 - accuracy: 1.0000 - val_loss: 0.9646 - val_accuracy: 0.9198
# Epoch 1957/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.8265e-08 - accuracy: 1.0000 - val_loss: 0.9709 - val_accuracy: 0.9211
# Epoch 1958/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.2613e-08 - accuracy: 1.0000 - val_loss: 0.9753 - val_accuracy: 0.9224
# Epoch 1959/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.3887e-08 - accuracy: 1.0000 - val_loss: 0.9824 - val_accuracy: 0.9237
# Epoch 1960/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.7106e-08 - accuracy: 1.0000 - val_loss: 0.9802 - val_accuracy: 0.9237
# Epoch 1961/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.0037e-08 - accuracy: 1.0000 - val_loss: 0.9996 - val_accuracy: 0.9224
# Epoch 1962/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.2204e-08 - accuracy: 1.0000 - val_loss: 0.9929 - val_accuracy: 0.9224
# Epoch 1963/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0365e-08 - accuracy: 1.0000 - val_loss: 0.9923 - val_accuracy: 0.9224
# Epoch 1964/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.9946e-08 - accuracy: 1.0000 - val_loss: 0.9883 - val_accuracy: 0.9224
# Epoch 1965/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2260e-07 - accuracy: 1.0000 - val_loss: 0.9768 - val_accuracy: 0.9224
# Epoch 1966/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.0284e-07 - accuracy: 1.0000 - val_loss: 0.9794 - val_accuracy: 0.9224
# Epoch 1967/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.1251e-07 - accuracy: 1.0000 - val_loss: 0.9772 - val_accuracy: 0.9237
# Epoch 1968/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3100e-08 - accuracy: 1.0000 - val_loss: 0.9836 - val_accuracy: 0.9224
# Epoch 1969/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.3076e-08 - accuracy: 1.0000 - val_loss: 0.9874 - val_accuracy: 0.9224
# Epoch 1970/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.7277e-08 - accuracy: 1.0000 - val_loss: 0.9872 - val_accuracy: 0.9224
# Epoch 1971/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.4592e-08 - accuracy: 1.0000 - val_loss: 0.9885 - val_accuracy: 0.9224
# Epoch 1972/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.8202e-08 - accuracy: 1.0000 - val_loss: 1.0014 - val_accuracy: 0.9237
# Epoch 1973/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.3773e-08 - accuracy: 1.0000 - val_loss: 0.9878 - val_accuracy: 0.9250
# Epoch 1974/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.5454e-08 - accuracy: 1.0000 - val_loss: 0.9916 - val_accuracy: 0.9224
# Epoch 1975/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.1789e-07 - accuracy: 1.0000 - val_loss: 0.9921 - val_accuracy: 0.9224
# Epoch 1976/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5758e-08 - accuracy: 1.0000 - val_loss: 0.9921 - val_accuracy: 0.9224
# Epoch 1977/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.7291e-08 - accuracy: 1.0000 - val_loss: 0.9919 - val_accuracy: 0.9224
# Epoch 1978/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.5043e-08 - accuracy: 1.0000 - val_loss: 0.9873 - val_accuracy: 0.9237
# Epoch 1979/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.0418e-08 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.9237
# Epoch 1980/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0481e-08 - accuracy: 1.0000 - val_loss: 0.9871 - val_accuracy: 0.9237
# Epoch 1981/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.3349e-08 - accuracy: 1.0000 - val_loss: 0.9888 - val_accuracy: 0.9250
# Epoch 1982/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.6441e-08 - accuracy: 1.0000 - val_loss: 0.9927 - val_accuracy: 0.9224
# Epoch 1983/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.5274e-08 - accuracy: 1.0000 - val_loss: 0.9921 - val_accuracy: 0.9224
# Epoch 1984/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.0730e-07 - accuracy: 1.0000 - val_loss: 0.9757 - val_accuracy: 0.9211
# Epoch 1985/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.3362e-08 - accuracy: 1.0000 - val_loss: 0.9723 - val_accuracy: 0.9211
# Epoch 1986/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.9441e-08 - accuracy: 1.0000 - val_loss: 0.9820 - val_accuracy: 0.9237
# Epoch 1987/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.6619e-08 - accuracy: 1.0000 - val_loss: 0.9837 - val_accuracy: 0.9237
# Epoch 1988/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.2194e-07 - accuracy: 1.0000 - val_loss: 0.9822 - val_accuracy: 0.9237
# Epoch 1989/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.4427e-07 - accuracy: 1.0000 - val_loss: 0.9997 - val_accuracy: 0.9224
# Epoch 1990/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.8044e-08 - accuracy: 1.0000 - val_loss: 0.9917 - val_accuracy: 0.9237
# Epoch 1991/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.6556e-08 - accuracy: 1.0000 - val_loss: 0.9885 - val_accuracy: 0.9250
# Epoch 1992/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.3321e-08 - accuracy: 1.0000 - val_loss: 0.9893 - val_accuracy: 0.9237
# Epoch 1993/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.6749e-07 - accuracy: 1.0000 - val_loss: 1.0098 - val_accuracy: 0.9237
# Epoch 1994/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0629e-08 - accuracy: 1.0000 - val_loss: 0.9883 - val_accuracy: 0.9237
# Epoch 1995/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0358e-08 - accuracy: 1.0000 - val_loss: 1.0134 - val_accuracy: 0.9224
# Epoch 1996/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.8892e-08 - accuracy: 1.0000 - val_loss: 1.0108 - val_accuracy: 0.9224
# Epoch 1997/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.2796e-08 - accuracy: 1.0000 - val_loss: 0.9998 - val_accuracy: 0.9224
# Epoch 1998/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3139e-07 - accuracy: 1.0000 - val_loss: 1.0316 - val_accuracy: 0.9224
# Epoch 1999/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.4058e-07 - accuracy: 1.0000 - val_loss: 1.0659 - val_accuracy: 0.9250
# Epoch 2000/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.3820e-07 - accuracy: 1.0000 - val_loss: 1.0308 - val_accuracy: 0.9237
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/4G_VGG16\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 336ms/step - loss: 4.4407 - accuracy: 0.7129
# test_indoor_ds_results:test loss, test acc: [4.440722465515137, 0.7129319906234741]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 416ms/step - loss: 6.2745 - accuracy: 0.6436
# test_outdoor_ds_results:test loss, test acc: [6.274507999420166, 0.6436305642127991]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 11s 282ms/step - loss: 3.8912 - accuracy: 0.7403
# test_belt_ds_results:test loss, test acc: [3.8912465572357178, 0.7402538657188416]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_VGG16/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 4s 135ms/step - loss: 1.4764 - accuracy: 0.7230
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8195 - accuracy: 0.6694
# 35/35 [==============================] - 5s 138ms/step - loss: 1.3178 - accuracy: 0.7607
# Epoch200
#  test_indoor_acc=0.72296541929245
#  test_outdoor_acc=0.6694267392158508
#  test_belt_acc=0.7606527805328369
# 29/29 [==============================] - 4s 135ms/step - loss: 2.1364 - accuracy: 0.7219
# 50/50 [==============================] - 7s 137ms/step - loss: 2.7914 - accuracy: 0.6605
# 35/35 [==============================] - 5s 138ms/step - loss: 1.9341 - accuracy: 0.7520
# Epoch400
#  test_indoor_acc=0.7218506336212158
#  test_outdoor_acc=0.6605095267295837
#  test_belt_acc=0.752039909362793
# 29/29 [==============================] - 4s 135ms/step - loss: 2.7060 - accuracy: 0.7163
# 50/50 [==============================] - 7s 137ms/step - loss: 3.6615 - accuracy: 0.6541
# 35/35 [==============================] - 5s 138ms/step - loss: 2.4067 - accuracy: 0.7466
# Epoch600
#  test_indoor_acc=0.7162764668464661
#  test_outdoor_acc=0.6541401147842407
#  test_belt_acc=0.7466002106666565
# 29/29 [==============================] - 4s 136ms/step - loss: 3.0901 - accuracy: 0.7140
# 50/50 [==============================] - 7s 138ms/step - loss: 4.2604 - accuracy: 0.6519
# 35/35 [==============================] - 5s 139ms/step - loss: 2.7273 - accuracy: 0.7466
# Epoch800
#  test_indoor_acc=0.714046835899353
#  test_outdoor_acc=0.6519108414649963
#  test_belt_acc=0.7466002106666565
# 29/29 [==============================] - 4s 135ms/step - loss: 3.4239 - accuracy: 0.7168
# 50/50 [==============================] - 7s 138ms/step - loss: 4.7687 - accuracy: 0.6484
# 35/35 [==============================] - 5s 138ms/step - loss: 3.0594 - accuracy: 0.7416
# Epoch1000
#  test_indoor_acc=0.7168338894844055
#  test_outdoor_acc=0.6484076380729675
#  test_belt_acc=0.7416138052940369
# 29/29 [==============================] - 4s 135ms/step - loss: 3.6042 - accuracy: 0.7168
# 50/50 [==============================] - 7s 138ms/step - loss: 5.0751 - accuracy: 0.6487
# 35/35 [==============================] - 5s 139ms/step - loss: 3.1263 - accuracy: 0.7466
# Epoch1200
#  test_indoor_acc=0.7168338894844055
#  test_outdoor_acc=0.6487261056900024
#  test_belt_acc=0.7466002106666565
# 29/29 [==============================] - 4s 137ms/step - loss: 3.8724 - accuracy: 0.7163
# 50/50 [==============================] - 7s 139ms/step - loss: 5.4647 - accuracy: 0.6468
# 35/35 [==============================] - 5s 139ms/step - loss: 3.3334 - accuracy: 0.7439
# Epoch1400
#  test_indoor_acc=0.7162764668464661
#  test_outdoor_acc=0.646815299987793
#  test_belt_acc=0.7438803315162659
# 29/29 [==============================] - 4s 136ms/step - loss: 4.0594 - accuracy: 0.7185
# 50/50 [==============================] - 7s 138ms/step - loss: 5.6830 - accuracy: 0.6471
# 35/35 [==============================] - 5s 138ms/step - loss: 3.5725 - accuracy: 0.7416
# Epoch1600
#  test_indoor_acc=0.7185061573982239
#  test_outdoor_acc=0.6471337676048279
#  test_belt_acc=0.7416138052940369
# 29/29 [==============================] - 4s 136ms/step - loss: 4.1646 - accuracy: 0.7157
# 50/50 [==============================] - 7s 138ms/step - loss: 5.8687 - accuracy: 0.6478
# 35/35 [==============================] - 5s 138ms/step - loss: 3.6099 - accuracy: 0.7448
# Epoch1800
#  test_indoor_acc=0.7157190442085266
#  test_outdoor_acc=0.6477707028388977
#  test_belt_acc=0.7447869181632996
# 29/29 [==============================] - 4s 135ms/step - loss: 4.4407 - accuracy: 0.7129
# 50/50 [==============================] - 7s 138ms/step - loss: 6.2745 - accuracy: 0.6436
# 35/35 [==============================] - 5s 138ms/step - loss: 3.8912 - accuracy: 0.7403
# Epoch2000
#  test_indoor_acc=0.7129319906234741
#  test_outdoor_acc=0.6436305642127991
#  test_belt_acc=0.7402538657188416

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7176816463470459
# max index -> 0
# The [Epoch] of max acc -> 200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.72296541929245,
#  0.7218506336212158,
#  0.7162764668464661,
#  0.714046835899353,
#  0.7168338894844055,
#  0.7168338894844055,
#  0.7162764668464661,
#  0.7185061573982239,
#  0.7157190442085266,
#  0.7129319906234741]

# %%
test_outdoor_acc
# Out:
# [0.6694267392158508,
#  0.6605095267295837,
#  0.6541401147842407,
#  0.6519108414649963,
#  0.6484076380729675,
#  0.6487261056900024,
#  0.646815299987793,
#  0.6471337676048279,
#  0.6477707028388977,
#  0.6436305642127991]

# %%
test_belt_acc
# Out:
# [0.7606527805328369,
#  0.752039909362793,
#  0.7466002106666565,
#  0.7466002106666565,
#  0.7416138052940369,
#  0.7466002106666565,
#  0.7438803315162659,
#  0.7416138052940369,
#  0.7447869181632996,
#  0.7402538657188416]

# %%
test_indoor_loss
# Out:
# [1.4763855934143066,
#  2.1364097595214844,
#  2.7059757709503174,
#  3.0901050567626953,
#  3.423882007598877,
#  3.6041829586029053,
#  3.872382164001465,
#  4.059388160705566,
#  4.1645636558532715,
#  4.440722465515137]

# %%
test_outdoor_loss
# Out:
# [1.8194599151611328,
#  2.7913925647735596,
#  3.661494731903076,
#  4.260350704193115,
#  4.768672943115234,
#  5.075092792510986,
#  5.464745044708252,
#  5.683042526245117,
#  5.868680477142334,
#  6.274507999420166]

# %%
test_belt_loss
# Out:
# [1.3178471326828003,
#  1.9341402053833008,
#  2.4066760540008545,
#  2.7272961139678955,
#  3.0593717098236084,
#  3.126275062561035,
#  3.333441972732544,
#  3.5724527835845947,
#  3.6098520755767822,
#  3.8912465572357178]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5077
# FP=2063
# acc=0.7110644257703082
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 88.26583592938732%
# 2-BloodSecretionWaste acc = 47.31988472622478%
# 3-LabWardWaste acc = 52.615844544095665%
# 4-VaccineOtherWaste acc = 86.50163475011676%
#
#
#
# all_avg_eachclass = 68.67579998745613%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1700,   92,   17,  117],
#        [ 672,  821,   52,  190],
#        [ 132,  167,  704,  335],
#        [ 141,   36,  112, 1852]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[88.26583593,  4.77673936,  0.88265836,  6.07476636],
#        [38.73198847, 47.31988473,  2.99711816, 10.95100865],
#        [ 9.86547085, 12.4813154 , 52.61584454, 25.03736921],
#        [ 6.58570761,  1.68145726,  5.23120037, 86.50163475]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
