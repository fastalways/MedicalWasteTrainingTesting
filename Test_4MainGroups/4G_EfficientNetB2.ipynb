# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=260
img_width=260
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 260, 260, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB2

efficientnetB0_model = keras.applications.EfficientNetB2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 130, 130, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 130, 130, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 130, 130, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 130, 130, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 130, 130, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 130, 130, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 130, 130, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 130, 130, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 130, 130, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 130, 130, 16) 144         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 130, 130, 16) 64          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 130, 130, 16) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 16)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 16)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 4)      68          block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 16)     80          block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 130, 130, 16) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 130, 130, 16) 256         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 130, 130, 16) 64          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 130, 130, 16) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 130, 130, 16) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 130, 130, 96) 1536        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 130, 130, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 130, 130, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 131, 131, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 65, 65, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 65, 65, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 65, 65, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 65, 65, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 65, 65, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 65, 65, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 65, 65, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 65, 65, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 65, 65, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 65, 65, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 65, 65, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 65, 65, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 65, 65, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 65, 65, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 65, 65, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 65, 65, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 65, 65, 144)  576         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 65, 65, 144)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 65, 65, 144)  1296        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 65, 65, 144)  576         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 65, 65, 144)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 144)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 65, 65, 144)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 65, 65, 24)   3456        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 65, 65, 24)   96          block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 65, 65, 24)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 65, 65, 24)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 65, 65, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 65, 65, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 69, 69, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 33, 33, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 33, 33, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 33, 33, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 33, 33, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 33, 33, 48)   6912        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 33, 33, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 33, 33, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 33, 33, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 33, 33, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 33, 33, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 33, 33, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 33, 33, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 33, 33, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 33, 33, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 33, 33, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 33, 33, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 33, 33, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 33, 33, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 33, 33, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 33, 33, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 33, 33, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 33, 33, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 33, 33, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 33, 33, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 33, 33, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 35, 35, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 17, 17, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 17, 17, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 17, 17, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 17, 17, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 17, 17, 88)   25344       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 17, 17, 88)   352         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 17, 17, 528)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 17, 17, 528)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 528)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 17, 17, 528)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 17, 17, 88)   352         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 17, 17, 88)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 17, 17, 88)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 17, 17, 528)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 17, 17, 528)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 528)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 17, 17, 528)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 17, 17, 88)   352         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 17, 17, 88)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 17, 17, 88)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 17, 17, 528)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 17, 17, 528)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 528)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 17, 17, 528)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 17, 17, 88)   352         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 17, 17, 88)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 17, 17, 88)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 17, 17, 528)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 17, 17, 528)  13200       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 17, 17, 528)  2112        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 17, 17, 528)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 528)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 528)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 17, 17, 528)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 17, 17, 120)  63360       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 17, 17, 120)  480         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 17, 17, 720)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 17, 17, 720)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 720)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 17, 17, 720)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 17, 17, 120)  86400       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 17, 17, 120)  480         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 17, 17, 120)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 17, 17, 120)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 17, 17, 720)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 17, 17, 720)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 720)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 17, 17, 720)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 17, 17, 120)  86400       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 17, 17, 120)  480         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 17, 17, 120)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 17, 17, 120)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5c_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5d_expand_activation (Acti (None, 17, 17, 720)  0           block5d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5d_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5d_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5d_dwconv[0][0]
# __________________________________________________________________________________________________
# block5d_activation (Activation) (None, 17, 17, 720)  0           block5d_bn[0][0]
# __________________________________________________________________________________________________
# block5d_se_squeeze (GlobalAvera (None, 720)          0           block5d_activation[0][0]
# __________________________________________________________________________________________________
# block5d_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5d_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5d_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6c_expand_activation (Acti (None, 9, 9, 1248)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 9, 9, 1248)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1248)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 9, 9, 208)    832         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 9, 9, 208)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 9, 9, 208)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 9, 9, 1248)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 9, 9, 1248)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1248)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 9, 9, 208)    832         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 9, 9, 208)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 9, 9, 208)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 9, 9, 1248)   0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 9, 9, 1248)   0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1248)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 9, 9, 208)    832         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 9, 9, 208)    0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 9, 9, 208)    0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 9, 9, 1248)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   11232       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 9, 9, 1248)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1248)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 9, 9, 1248)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 9, 9, 352)    439296      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 9, 9, 352)    1408        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 9, 9, 2112)   743424      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 9, 9, 2112)   8448        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 9, 9, 2112)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 9, 9, 2112)   19008       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 9, 9, 2112)   8448        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 9, 9, 2112)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2112)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2112)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 88)     185944      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2112)   187968      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 9, 9, 2112)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 9, 9, 352)    743424      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 9, 9, 352)    1408        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 9, 9, 352)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 9, 9, 352)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 9, 9, 1408)   495616      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 9, 9, 1408)   5632        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 9, 9, 1408)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1408)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 7,768,569
# Trainable params: 0
# Non-trainable params: 7,768,569
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1408)              7768569
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1442816
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 9,215,485
# Trainable params: 1,446,916
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 46s 377ms/step - loss: 0.3070 - accuracy: 0.8853 - val_loss: 0.1293 - val_accuracy: 0.9547
# Epoch 2/2000
# 49/49 [==============================] - 11s 225ms/step - loss: 0.0902 - accuracy: 0.9706 - val_loss: 0.0941 - val_accuracy: 0.9664
# Epoch 3/2000
# 49/49 [==============================] - 11s 225ms/step - loss: 0.0515 - accuracy: 0.9842 - val_loss: 0.0568 - val_accuracy: 0.9845
# Epoch 4/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 0.0285 - accuracy: 0.9932 - val_loss: 0.0533 - val_accuracy: 0.9819
# Epoch 5/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 0.0208 - accuracy: 0.9939 - val_loss: 0.0501 - val_accuracy: 0.9819
# Epoch 6/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.0517 - val_accuracy: 0.9832
# Epoch 7/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 0.0088 - accuracy: 0.9981 - val_loss: 0.0431 - val_accuracy: 0.9832
# Epoch 8/2000
# 49/49 [==============================] - 11s 225ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.0489 - val_accuracy: 0.9806
# Epoch 9/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0580 - val_accuracy: 0.9806
# Epoch 10/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0440 - val_accuracy: 0.9845
# Epoch 11/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.0475 - val_accuracy: 0.9845
# Epoch 12/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9845
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 13/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.0465 - val_accuracy: 0.9832
# Epoch 14/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0485 - val_accuracy: 0.9832
# Epoch 15/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9845
# Epoch 16/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0459 - val_accuracy: 0.9858
# Epoch 17/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0448 - val_accuracy: 0.9871
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 18/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0449 - val_accuracy: 0.9871
# Epoch 19/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9871
# Epoch 20/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0444 - val_accuracy: 0.9871
# Epoch 21/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0439 - val_accuracy: 0.9871
# Epoch 22/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0425 - val_accuracy: 0.9858
# Epoch 23/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0426 - val_accuracy: 0.9858
# Epoch 24/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9858
# Epoch 25/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9858
# Epoch 26/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0429 - val_accuracy: 0.9858
# Epoch 27/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9845
# Epoch 28/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0418 - val_accuracy: 0.9832
# Epoch 29/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0428 - val_accuracy: 0.9845
# Epoch 30/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9845
# Epoch 31/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0430 - val_accuracy: 0.9845
# Epoch 32/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0443 - val_accuracy: 0.9858
# Epoch 33/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9845
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 34/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0448 - val_accuracy: 0.9832
# Epoch 35/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0447 - val_accuracy: 0.9832
# Epoch 36/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9832
# Epoch 37/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0441 - val_accuracy: 0.9858
# Epoch 38/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9845
# Epoch 39/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9845
# Epoch 40/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9845
# Epoch 41/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0433 - val_accuracy: 0.9845
# Epoch 42/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9845
# Epoch 43/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9845
# Epoch 44/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0426 - val_accuracy: 0.9845
# Epoch 45/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9858
# Epoch 46/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0423 - val_accuracy: 0.9858
# Epoch 47/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 48/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 49/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 50/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9845
# Epoch 51/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9832
# Epoch 52/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0421 - val_accuracy: 0.9845
# Epoch 53/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0418 - val_accuracy: 0.9845
# Epoch 54/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 55/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 56/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0422 - val_accuracy: 0.9845
# Epoch 57/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9845
# Epoch 58/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 59/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 60/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9845
# Epoch 61/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0412 - val_accuracy: 0.9845
# Epoch 62/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9845
# Epoch 63/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0418 - val_accuracy: 0.9845
# Epoch 64/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 65/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9845
# Epoch 66/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 67/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.0424 - val_accuracy: 0.9832
# Epoch 68/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 69/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9832
# Epoch 70/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0422 - val_accuracy: 0.9845
# Epoch 71/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9845
# Epoch 72/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 9.7270e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9845
# Epoch 73/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 74/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 75/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9845
# Epoch 76/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0414 - val_accuracy: 0.9845
# Epoch 77/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 78/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 79/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 80/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0418 - val_accuracy: 0.9845
# Epoch 81/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9858
# Epoch 82/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0253e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 83/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 84/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 85/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9845
# Epoch 86/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 87/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.5178e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9832
# Epoch 88/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 89/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 90/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.4850e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 91/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 92/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.2636e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9858
# Epoch 93/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9845
# Epoch 94/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0415 - val_accuracy: 0.9845
# Epoch 95/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9832
# Epoch 96/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 97/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.3686e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9845
# Epoch 98/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9845
# Epoch 99/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.5026e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9845
# Epoch 100/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0415 - val_accuracy: 0.9845
# Epoch 101/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.5462e-04 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 102/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 103/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.0930e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9832
# Epoch 104/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.1390e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9832
# Epoch 105/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9845
# Epoch 106/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0412 - val_accuracy: 0.9832
# Epoch 107/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.3478e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9832
# Epoch 108/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.7785e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9845
# Epoch 109/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0417 - val_accuracy: 0.9845
# Epoch 110/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0416 - val_accuracy: 0.9845
# Epoch 111/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0409 - val_accuracy: 0.9858
# Epoch 112/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.3480e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9858
# Epoch 113/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0404 - val_accuracy: 0.9845
# Epoch 114/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9858
# Epoch 115/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 7.0810e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 116/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0680e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 117/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0392 - val_accuracy: 0.9871
# Epoch 118/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9871
# Epoch 119/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.6379e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9858
# Epoch 120/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 8.7992e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 121/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0390 - val_accuracy: 0.9871
# Epoch 122/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 123/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 8.2465e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 124/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0395 - val_accuracy: 0.9858
# Epoch 125/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 9.4702e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 126/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0385 - val_accuracy: 0.9858
# Epoch 127/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0384 - val_accuracy: 0.9858
# Epoch 128/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9871
# Epoch 129/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0392 - val_accuracy: 0.9858
# Epoch 130/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 131/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9858
# Epoch 132/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.7515e-04 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9858
# Epoch 133/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9858
# Epoch 134/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.7307e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9858
# Epoch 135/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.4751e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9858
# Epoch 136/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0391 - val_accuracy: 0.9871
# Epoch 137/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.6760e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9871
# Epoch 138/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.4749e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9858
# Epoch 139/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.3446e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9871
# Epoch 140/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9858
# Epoch 141/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.7476e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9858
# Epoch 142/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.7918e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9845
# Epoch 143/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.9574e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9858
# Epoch 144/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0404 - val_accuracy: 0.9845
# Epoch 145/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9845
# Epoch 146/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 9.8269e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9858
# Epoch 147/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.1331e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 148/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0396 - val_accuracy: 0.9845
# Epoch 149/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.2772e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9845
# Epoch 150/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9858
# Epoch 151/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 9.7435e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9871
# Epoch 152/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0394 - val_accuracy: 0.9845
# Epoch 153/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 7.7647e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9858
# Epoch 154/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9858
# Epoch 155/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.6025e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9871
# Epoch 156/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9871
# Epoch 157/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.1094e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 158/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.2508e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9858
# Epoch 159/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.6920e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9858
# Epoch 160/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.7732e-04 - accuracy: 0.9997 - val_loss: 0.0404 - val_accuracy: 0.9858
# Epoch 161/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0405 - val_accuracy: 0.9858
# Epoch 162/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0405 - val_accuracy: 0.9845
# Epoch 163/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0402 - val_accuracy: 0.9858
# Epoch 164/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.9478e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9858
# Epoch 165/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.4589e-04 - accuracy: 0.9997 - val_loss: 0.0402 - val_accuracy: 0.9871
# Epoch 166/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0403 - val_accuracy: 0.9845
# Epoch 167/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0409 - val_accuracy: 0.9858
# Epoch 168/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.98451
# Epoch 169/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.2581e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9858
# Epoch 170/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.7118e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 171/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0804e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9858
# Epoch 172/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.9950e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9858
# Epoch 173/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.2491e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9858
# Epoch 174/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.0478e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9832
# Epoch 175/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.8211e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9832
# Epoch 176/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.0609e-04 - accuracy: 0.9997 - val_loss: 0.0407 - val_accuracy: 0.9832
# Epoch 177/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0929e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9832
# Epoch 178/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0402 - val_accuracy: 0.9832
# Epoch 179/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.3623e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9832
# Epoch 180/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.6490e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9832
# Epoch 181/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0413 - val_accuracy: 0.9832
# Epoch 182/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9832
# Epoch 183/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0411 - val_accuracy: 0.9832
# Epoch 184/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0404 - val_accuracy: 0.9832
# Epoch 185/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0934e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9832
# Epoch 186/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0400 - val_accuracy: 0.9832
# Epoch 187/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9832
# Epoch 188/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.1454e-04 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9845
# Epoch 189/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.0377e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9845
# Epoch 190/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.1800e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9845
# Epoch 191/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9858
# Epoch 192/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.9523e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9858
# Epoch 193/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.5931e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9858
# Epoch 194/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.4317e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9845
# Epoch 195/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.9497e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9845
# Epoch 196/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.7688e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9845
# Epoch 197/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.0580e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9845
# Epoch 198/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0219e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9845
# Epoch 199/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.0321e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 200/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0396 - val_accuracy: 0.9871
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 7.0341e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9884
# Epoch 202/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 5.1275e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9884
# Epoch 203/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 5.6749e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9858
# Epoch 204/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0408 - val_accuracy: 0.9845
# Epoch 205/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 7.0751e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9832
# Epoch 206/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 4.5565e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9832
# Epoch 207/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 7.6693e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9832
# Epoch 208/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 6.1315e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9845
# Epoch 209/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 7.5144e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9845
# Epoch 210/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 5.5632e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9845
# Epoch 211/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0402 - val_accuracy: 0.9858
# Epoch 212/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 6.4108e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9858
# Epoch 213/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 4.5810e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9858
# Epoch 214/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0400 - val_accuracy: 0.9858
# Epoch 215/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 6.3473e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9858
# Epoch 216/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 7.5068e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 217/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 3.7175e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9858
# Epoch 218/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9845
# Epoch 219/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 4.7801e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9845
# Epoch 220/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0403 - val_accuracy: 0.9871
# Epoch 221/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 6.8272e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9858
# Epoch 222/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 7.6278e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9858
# Epoch 223/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0400 - val_accuracy: 0.9871
# Epoch 224/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.6829e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9858
# Epoch 225/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.6079e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9884
# Epoch 226/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0397 - val_accuracy: 0.9884
# Epoch 227/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.7381e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9884
# Epoch 228/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.0334e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9884
# Epoch 229/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0399 - val_accuracy: 0.9884
# Epoch 230/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 9.5242e-04 - accuracy: 0.9997 - val_loss: 0.0404 - val_accuracy: 0.9858
# Epoch 231/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.9290e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9858
# Epoch 232/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.4914e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9845
# Epoch 233/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.3569e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9871
# Epoch 234/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.2856e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9871
# Epoch 235/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.4090e-04 - accuracy: 0.9997 - val_loss: 0.0408 - val_accuracy: 0.9858
# Epoch 236/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0403 - val_accuracy: 0.9871
# Epoch 237/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.9247e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9871
# Epoch 238/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0405 - val_accuracy: 0.9871
# Epoch 239/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.9226e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9871
# Epoch 240/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0400 - val_accuracy: 0.9871
# Epoch 241/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.5591e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9871
# Epoch 242/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.2440e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9871
# Epoch 243/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0411 - val_accuracy: 0.9845
# Epoch 244/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.1033e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9845
# Epoch 245/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0407 - val_accuracy: 0.9871
# Epoch 246/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.8006e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9858
# Epoch 247/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 9.0792e-04 - accuracy: 0.9997 - val_loss: 0.0409 - val_accuracy: 0.9858
# Epoch 248/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 5.5616e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9858
# Epoch 249/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.0049e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9871
# Epoch 250/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.4945e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9871
# Epoch 251/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.6061e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9871
# Epoch 252/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.4100e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9845
# Epoch 253/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.1307e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9845
# Epoch 254/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.1371e-04 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9845
# Epoch 255/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0406 - val_accuracy: 0.9858
# Epoch 256/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0401 - val_accuracy: 0.9845
# Epoch 257/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.7685e-04 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9871
# Epoch 258/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.9834e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9871
# Epoch 259/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.8731e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9845e-04 -
# Epoch 260/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.2908e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9845
# Epoch 261/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9845
# Epoch 262/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.8685e-04 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9845
# Epoch 263/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.1872e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9871
# Epoch 264/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.0379e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9871
# Epoch 265/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.3578e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9871
# Epoch 266/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.2126e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9871
# Epoch 267/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 5.5521e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9871
# Epoch 268/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.5549e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9845
# Epoch 269/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0424 - val_accuracy: 0.9845
# Epoch 270/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.6530e-04 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9845
# Epoch 271/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.0414 - val_accuracy: 0.9845
# Epoch 272/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.4901e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9845
# Epoch 273/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0407 - val_accuracy: 0.9845
# Epoch 274/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.3558e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9845
# Epoch 275/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0402 - val_accuracy: 0.9845
# Epoch 276/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0399 - val_accuracy: 0.9845
# Epoch 277/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.7363e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9845
# Epoch 278/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.7963e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9845
# Epoch 279/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.1192e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9845
# Epoch 280/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.8070e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9845
# Epoch 281/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.1104e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9858
# Epoch 282/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 5.2982e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9858
# Epoch 283/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.6499e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9858
# Epoch 284/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0400 - val_accuracy: 0.9845
# Epoch 285/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.4370e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9858
# Epoch 286/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.1362e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9858
# Epoch 287/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.4489e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9858
# Epoch 288/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.9917e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9871
# Epoch 289/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.9045e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9858
# Epoch 290/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.9804e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9858
# Epoch 291/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.2030e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9858
# Epoch 292/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0402 - val_accuracy: 0.9871
# Epoch 293/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.7500e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9884
# Epoch 294/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.1196e-04 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9884
# Epoch 295/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.0501e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9884
# Epoch 296/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 6.6502e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9884
# Epoch 297/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.9396e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9884
# Epoch 298/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.5337e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9871
# Epoch 299/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.9568e-04 - accuracy: 0.9997 - val_loss: 0.0405 - val_accuracy: 0.9871
# Epoch 300/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.8079e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9858
# Epoch 301/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 4.8101e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9858
# Epoch 302/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.2234e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9858
# Epoch 303/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0408 - val_accuracy: 0.9858
# Epoch 304/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.9881e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9871
# Epoch 305/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.6730e-04 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9858
# Epoch 306/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0418 - val_accuracy: 0.9858
# Epoch 307/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.8264e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9858
# Epoch 308/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.2872e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9858
# Epoch 309/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.0786e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9858
# Epoch 310/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.6187e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9871
# Epoch 311/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.5866e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9871
# Epoch 312/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.2444e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9884
# Epoch 313/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.1060e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9884
# Epoch 314/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.4412e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9871
# Epoch 315/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.0491e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9871
# Epoch 316/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0414 - val_accuracy: 0.9858
# Epoch 317/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0428 - val_accuracy: 0.9845
# Epoch 318/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.2181e-05 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9897
# Epoch 1900/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.3806e-05 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 0.9897
# Epoch 1901/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.0463e-05 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9897
# Epoch 1902/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.2871e-04 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9884
# Epoch 1903/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.3301e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9884
# Epoch 1904/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.9444e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 1905/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.3401e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 1906/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 8.5502e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 1907/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.0913e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9897
# Epoch 1908/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.6293e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9884
# Epoch 1909/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 2.3587e-04 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9897
# Epoch 1910/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 6.2142e-05 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9897
# Epoch 1911/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.5715e-05 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9897
# Epoch 1912/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.4925e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9897
# Epoch 1913/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 2.5349e-04 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9897
# Epoch 1914/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.0477e-04 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9897
# Epoch 1915/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.4097e-05 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9897
# Epoch 1916/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.2638e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9884
# Epoch 1917/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.0784e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9884
# Epoch 1918/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.6633e-05 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9897
# Epoch 1919/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.8415e-05 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9897
# Epoch 1920/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1921/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.1287e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1922/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.0934e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 1923/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 2.8331e-04 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9897
# Epoch 1924/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 7.8159e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9884
# Epoch 1925/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.0116e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9884
# Epoch 1926/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.3666e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9884
# Epoch 1927/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.0229e-04 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9884
# Epoch 1928/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.7828e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9884
# Epoch 1929/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.3693e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9884
# Epoch 1930/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 5.9435e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9884
# Epoch 1931/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.1562e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.98847249e-05 - ac
# Epoch 1932/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.7573e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9884
# Epoch 1933/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.1368e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9884
# Epoch 1934/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.9875e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9884
# Epoch 1935/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 9.5433e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 1936/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.2012e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 1937/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 6.2015e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9884
# Epoch 1938/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.7070e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9884
# Epoch 1939/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.9860e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9884
# Epoch 1940/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.9862e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9884
# Epoch 1941/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.1316e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9884
# Epoch 1942/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.4595e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9884
# Epoch 1943/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.3529e-05 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9884
# Epoch 1944/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.9927e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9884
# Epoch 1945/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.1564e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9871
# Epoch 1946/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 6.4312e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9871
# Epoch 1947/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 8.7194e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9871
# Epoch 1948/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 8.4322e-05 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9871
# Epoch 1949/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 6.2402e-05 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9884
# Epoch 1950/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 7.0182e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9871
# Epoch 1951/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.3189e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1952/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.5176e-04 - accuracy: 0.9997 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1953/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.6284e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 1954/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 5.3789e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 1955/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 2.8536e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1956/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 2.5336e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1957/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.0114e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 1958/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 2.5994e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1959/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.3973e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1960/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.7453e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1961/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.4750e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9897
# Epoch 1962/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 2.7292e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9897
# Epoch 1963/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.6254e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9897
# Epoch 1964/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 4.6947e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9897
# Epoch 1965/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 3.8855e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9897
# Epoch 1966/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.9196e-04 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9897
# Epoch 1967/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.9423e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9884
# Epoch 1968/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.0327e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9897
# Epoch 1969/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.8100e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9897
# Epoch 1970/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.0248e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9909
# Epoch 1971/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.7537e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9909
# Epoch 1972/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.5820e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9909
# Epoch 1973/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 1.0791e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9909
# Epoch 1974/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.4083e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9909
# Epoch 1975/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.7941e-05 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9909
# Epoch 1976/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.8742e-04 - accuracy: 0.9997 - val_loss: 0.0422 - val_accuracy: 0.9909
# Epoch 1977/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.6253e-05 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9909
# Epoch 1978/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.8780e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9909
# Epoch 1979/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.9657e-05 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9909
# Epoch 1980/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 1.8290e-04 - accuracy: 1.0000 - val_loss: 0.0421 - val_accuracy: 0.9909
# Epoch 1981/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.3098e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9897
# Epoch 1982/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 5.6907e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9909
# Epoch 1983/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.7896e-05 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 1984/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 6.4103e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9897
# Epoch 1985/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.4690e-04 - accuracy: 0.9997 - val_loss: 0.0413 - val_accuracy: 0.9884
# Epoch 1986/2000
# 49/49 [==============================] - 11s 220ms/step - loss: 5.3682e-05 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9884
# Epoch 1987/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 7.6033e-04 - accuracy: 0.9997 - val_loss: 0.0410 - val_accuracy: 0.9884
# Epoch 1988/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 1.7076e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9884
# Epoch 1989/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.3451e-05 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9884
# Epoch 1990/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.1836e-04 - accuracy: 0.9997 - val_loss: 0.0414 - val_accuracy: 0.9884
# Epoch 1991/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.3817e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 1992/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.6031e-05 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9884
# Epoch 1993/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.3322e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9884
# Epoch 1994/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.5410e-05 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9884
# Epoch 1995/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.7608e-04 - accuracy: 0.9997 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 1996/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 8.1535e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9897
# Epoch 1997/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 2.7728e-05 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9897
# Epoch 1998/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0421 - val_accuracy: 0.9897
# Epoch 1999/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 4.4325e-04 - accuracy: 0.9997 - val_loss: 0.0427 - val_accuracy: 0.9897
# Epoch 2000/2000
# 49/49 [==============================] - 11s 219ms/step - loss: 3.8897e-05 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9897
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB2\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 333ms/step - loss: 0.4967 - accuracy: 0.9008
# test_indoor_ds_results:test loss, test acc: [0.4967253506183624, 0.9007803797721863]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 425ms/step - loss: 0.4327 - accuracy: 0.9003
# test_outdoor_ds_results:test loss, test acc: [0.43272870779037476, 0.900318443775177]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 199ms/step - loss: 0.8938 - accuracy: 0.8463
# test_belt_ds_results:test loss, test acc: [0.8937739133834839, 0.8463281989097595]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB2/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_113909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_65112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_107263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_68301) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_112047) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_113283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_69105) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_67861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_68051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_64954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_68209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_111440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_108888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_66323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_112483) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_109125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_110709) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_64723) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_68092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_104344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_108499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_66000) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_54262) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_100915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_104714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_107329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_65618) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_116660) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_68881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_105296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_69365) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_112113) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_67545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_96859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_66939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_68932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_65204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_116897) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_115493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_107936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_113843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_105467) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_66491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_65336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_67820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_64605) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_103871) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_109732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_67372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_115057) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_68260) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_114450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_66756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_107870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_66224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_69314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_68484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_110273) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_69538) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_67993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_105903) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_94307) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_67204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_68749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_111506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_110946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_110339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_67112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_117267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_67596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_68973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_106510) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_65868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_110880) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_107092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_103937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_64896) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_116337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_104278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_105533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_106074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_64513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_108565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_65560) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_67637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_66888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_106769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_67769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_109059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_103700) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_112720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_66664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_64995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_69406) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_68708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_66051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_115123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_114279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_110102) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_113090) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_104973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_67321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_115730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_65776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_66715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_64564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_65659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_116271) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_68525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_109495) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_106140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_65387) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_66282) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_112654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_108306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_113349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_116831) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_66980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_104907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_64764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_68433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_109666) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_114886) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_115664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_111269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_114516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_67163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_69197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_69156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_65163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_68657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_65428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_66440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_106703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_66092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_107699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_103445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_67413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_116100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_113672) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_111876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_66532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_65827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 7s 169ms/step - loss: 0.3679 - accuracy: 0.9052
# 50/50 [==============================] - 9s 171ms/step - loss: 0.3698 - accuracy: 0.8904
# 35/35 [==============================] - 6s 172ms/step - loss: 0.7610 - accuracy: 0.8327
# Epoch200
#  test_indoor_acc=0.9052397012710571
#  test_outdoor_acc=0.89044588804245
#  test_belt_acc=0.832728922367096
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_213485) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_209545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_164027) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_165263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_206535) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_213722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_210475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_205109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_166144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_209308) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_212878) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_212271) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_215259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_207098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_214870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_211948) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_164650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_165314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_164217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_165355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_167256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_208938) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_165920) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_164691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_209479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_167124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_163803) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_166808) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_204132) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_163322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_166592) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_207658) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_214263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_164599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_210712) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_214092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_205691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_215430) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_167913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_211882) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_163711) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_165803) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_195458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_211253) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_164375) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_204673) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_167480) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_214329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_166900) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_166460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_166419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_166859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_203572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_208094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_167755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_209868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_166368) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_207487) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_168005) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_213115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_208331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_202470) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_204066) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_167032) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_202943) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_204739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_166650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_165711) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_167307) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_163594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_214936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_167796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_164467) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_163363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_152861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_167083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_192906) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_215866) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_165090) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_166691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_164426) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_208872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_199514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_164823) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_165039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_210105) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_207724) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_212442) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_167572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_164881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_204502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_164258) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_163762) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_205928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_954357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1002263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_995313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_953700) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_992284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_952273) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_954489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_953204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1003041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_955197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_952937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_952540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_993451) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_956482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_988292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_954540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1002434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_956742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1004644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_995076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_998086) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_952100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_999424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_954922) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1001893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_952805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_955469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_998646) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_953036) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_993887) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1000097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_953428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1004037) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1001220) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_956691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_994146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_955902) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_956533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_997109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_953469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_953659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_955146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_953868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_996265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_994469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_955370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_955428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1001827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_953153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_997650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_955678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_956915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_999253) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_995876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_953817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_952489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_955238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1004208) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_991721) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_992091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_956350) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_955861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_994640) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_995247) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_954092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_956258) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_956309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1001286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_997043) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_954041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_953245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1003714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1000467) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_954790) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_952331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_951982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_956085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 7s 168ms/step - loss: 0.4967 - accuracy: 0.9008
# 50/50 [==============================] - 9s 170ms/step - loss: 0.4327 - accuracy: 0.9003
# 35/35 [==============================] - 6s 171ms/step - loss: 0.8938 - accuracy: 0.8463
# Epoch2000
#  test_indoor_acc=0.9007803797721863
#  test_outdoor_acc=0.900318443775177
#  test_belt_acc=0.8463281989097595

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8824756741523743
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9052397012710571,
#  0.9041248559951782,
#  0.9063544869422913,
#  0.9030100107192993,
#  0.9041248559951782,
#  0.9035674333572388,
#  0.9052397012710571,
#  0.9030100107192993,
#  0.9030100107192993,
#  0.9007803797721863]

# %%
test_outdoor_acc
# Out:
# [0.89044588804245,
#  0.8910828232765198,
#  0.8898088932037354,
#  0.8933120965957642,
#  0.8942674994468689,
#  0.8961783647537231,
#  0.8907643556594849,
#  0.8936305642127991,
#  0.8917197585105896,
#  0.900318443775177]

# %%
test_belt_acc
# Out:
# [0.832728922367096,
#  0.834995448589325,
#  0.8390752673149109,
#  0.8399818539619446,
#  0.8404351472854614,
#  0.8436083197593689,
#  0.8399818539619446,
#  0.8467814922332764,
#  0.8390752673149109,
#  0.8463281989097595]

# %%
test_indoor_loss
# Out:
# [0.36791110038757324,
#  0.3874175250530243,
#  0.40278902649879456,
#  0.42134374380111694,
#  0.43196389079093933,
#  0.4553675353527069,
#  0.46904051303863525,
#  0.4732555150985718,
#  0.4697294235229492,
#  0.4967253506183624]

# %%
test_outdoor_loss
# Out:
# [0.3697795867919922,
#  0.38233059644699097,
#  0.39311477541923523,
#  0.3881973624229431,
#  0.4021886885166168,
#  0.41147923469543457,
#  0.4240087568759918,
#  0.42556557059288025,
#  0.43609732389450073,
#  0.43272870779037476]

# %%
test_belt_loss
# Out:
# [0.7610141634941101,
#  0.7834106683731079,
#  0.7920900583267212,
#  0.8058955073356628,
#  0.8430434465408325,
#  0.8325805068016052,
#  0.872077226638794,
#  0.8443141579627991,
#  0.8819783329963684,
#  0.8937739133834839]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=260
img_width=260
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_998883) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1004274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_999490) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_996436) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_952713) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1002870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_951890) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_953909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_956574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_954973) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_995683) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_998817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_954749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_984236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_955810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_954698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_952995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_997479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_952141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_954133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_952372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_952764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_998257) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_981684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_991077) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_956783) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1003477) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_952581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_955586) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1001656) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1000660) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_954316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1000031) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_953377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1002500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_995942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1000726) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_992350) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_993517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1003107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_992673) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_956034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_990822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_992844) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_991314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_951941) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_992910) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_954581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_996502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_998323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_993280) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_955014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_955637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1001049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1003648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_991655) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_991248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_994706) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_994080) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_999860) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_941639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_956126) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_997716) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_954265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_996872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_953601) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_954357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1002263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_995313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_953700) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_992284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_952273) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_954489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_953204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1003041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_955197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_952937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_952540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_993451) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_956482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_988292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_954540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1002434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_956742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1004644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_995076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_998086) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_952100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_999424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_954922) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1001893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_952805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_955469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_998646) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_953036) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_993887) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1000097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_953428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1004037) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1001220) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_956691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_994146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_955902) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_956533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_997109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_953469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_953659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_955146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_953868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_996265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_994469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_955370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_955428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1001827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_953153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_997650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_955678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_956915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_999253) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_995876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_953817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_952489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_955238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1004208) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_991721) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_992091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_956350) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_955861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_994640) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_995247) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_954092) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_956258) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_956309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1001286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_997043) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_954041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_953245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1003714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1000467) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_954790) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_952331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_951982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_956085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6310
# FP=830
# acc=0.8837535014005602
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 89.30425752855659%
# 2-BloodSecretionWaste acc = 77.23342939481267%
# 3-LabWardWaste acc = 91.62929745889387%
# 4-VaccineOtherWaste acc = 94.53526389537599%
#
#
#
# all_avg_eachclass = 88.17556206940978%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1720,  128,   23,   55],
#        [ 274, 1340,   45,   76],
#        [  20,   44, 1226,   48],
#        [  10,   88,   19, 2024]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[89.30425753,  6.64589823,  1.19418484,  2.8556594 ],
#        [15.7925072 , 77.23342939,  2.59365994,  4.38040346],
#        [ 1.49476831,  3.28849028, 91.62929746,  3.58744395],
#        [ 0.46707146,  4.11022887,  0.88743578, 94.5352639 ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
