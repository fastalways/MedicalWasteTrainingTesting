# %% [markdown]
# # 4G

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']
# number of class = 4

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 4 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 4 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 4 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 4 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB0

efficientnetB0_model = keras.applications.EfficientNetB0(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 224, 224, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 224, 224, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 225, 225, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 112, 112, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 112, 112, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 112, 112, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 112, 112, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 112, 112, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 112, 112, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 112, 112, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 112, 112, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 112, 112, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 112, 112, 96) 1536        block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 112, 112, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 112, 112, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 113, 113, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 56, 56, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 56, 56, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 56, 56, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 56, 56, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 56, 56, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 56, 56, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 56, 56, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 56, 56, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 56, 56, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 56, 56, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 56, 56, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 56, 56, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 56, 56, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 56, 56, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 56, 56, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 56, 56, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 56, 56, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 56, 56, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 56, 56, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 59, 59, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 28, 28, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 28, 28, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 28, 28, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 28, 28, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 28, 28, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 28, 28, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 28, 28, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 28, 28, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 28, 28, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 28, 28, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 28, 28, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 28, 28, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 28, 28, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 28, 28, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 28, 28, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 28, 28, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 28, 28, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 28, 28, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 28, 28, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 29, 29, 240)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 14, 14, 240)  2160        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 14, 14, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 14, 14, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 14, 14, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 14, 14, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 14, 14, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 14, 14, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 14, 14, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 14, 14, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 14, 14, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 14, 14, 80)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 14, 14, 80)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 14, 14, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 14, 14, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 14, 14, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 14, 14, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 14, 14, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 14, 14, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 14, 14, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 14, 14, 80)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 14, 14, 80)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 14, 14, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 14, 14, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 14, 14, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 14, 14, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 14, 14, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 14, 14, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 14, 14, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 14, 14, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 14, 14, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 14, 14, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 14, 14, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 14, 14, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 14, 14, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 14, 14, 112)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 14, 14, 112)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 14, 14, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 14, 14, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 14, 14, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 14, 14, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 14, 14, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 14, 14, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 14, 14, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 14, 14, 112)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 14, 14, 112)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_conv (Conv2D)    (None, 14, 14, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block6a_expand_bn (BatchNormali (None, 14, 14, 672)  2688        block6a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6a_expand_activation (Acti (None, 14, 14, 672)  0           block6a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv_pad (ZeroPadding (None, 17, 17, 672)  0           block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6a_dwconv (DepthwiseConv2D (None, 7, 7, 672)    16800       block6a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block6a_bn (BatchNormalization) (None, 7, 7, 672)    2688        block6a_dwconv[0][0]
# __________________________________________________________________________________________________
# block6a_activation (Activation) (None, 7, 7, 672)    0           block6a_bn[0][0]
# __________________________________________________________________________________________________
# block6a_se_squeeze (GlobalAvera (None, 672)          0           block6a_activation[0][0]
# __________________________________________________________________________________________________
# block6a_se_reshape (Reshape)    (None, 1, 1, 672)    0           block6a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6a_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block6a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6a_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block6a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6a_se_excite (Multiply)    (None, 7, 7, 672)    0           block6a_activation[0][0]
#                                                                  block6a_se_expand[0][0]
# __________________________________________________________________________________________________
# block6a_project_conv (Conv2D)   (None, 7, 7, 192)    129024      block6a_se_excite[0][0]
# __________________________________________________________________________________________________
# block6a_project_bn (BatchNormal (None, 7, 7, 192)    768         block6a_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6b_expand_activation (Acti (None, 7, 7, 1152)   0           block6b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6b_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6b_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6b_dwconv[0][0]
# __________________________________________________________________________________________________
# block6b_activation (Activation) (None, 7, 7, 1152)   0           block6b_bn[0][0]
# __________________________________________________________________________________________________
# block6b_se_squeeze (GlobalAvera (None, 1152)         0           block6b_activation[0][0]
# __________________________________________________________________________________________________
# block6b_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6b_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6b_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6b_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6b_activation[0][0]
#                                                                  block6b_se_expand[0][0]
# __________________________________________________________________________________________________
# block6b_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6b_se_excite[0][0]
# __________________________________________________________________________________________________
# block6b_project_bn (BatchNormal (None, 7, 7, 192)    768         block6b_project_conv[0][0]
# __________________________________________________________________________________________________
# block6b_drop (Dropout)          (None, 7, 7, 192)    0           block6b_project_bn[0][0]
# __________________________________________________________________________________________________
# block6b_add (Add)               (None, 7, 7, 192)    0           block6b_drop[0][0]
#                                                                  block6a_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6b_add[0][0]
# __________________________________________________________________________________________________
# block6c_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6c_expand_activation (Acti (None, 7, 7, 1152)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 7, 7, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 7, 7, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 7, 7, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 7, 7, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 7, 7, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 7, 7, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 7, 7, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 7, 7, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 7, 7, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 7, 7, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 7, 7, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 7, 7, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 7, 7, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 7, 7, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 7, 7, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 7, 7, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 7, 7, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 7, 7, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 7, 7, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 7, 7, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 7, 7, 1280)   409600      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 7, 7, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 7, 7, 1280)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1280)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 4,049,571
# Trainable params: 0
# Non-trainable params: 4,049,571
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1280)              4049571
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 5,365,415
# Trainable params: 1,315,844
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
#class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 38s 248ms/step - loss: 0.3414 - accuracy: 0.8714 - val_loss: 0.1345 - val_accuracy: 0.9508
# Epoch 2/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0995 - accuracy: 0.9687 - val_loss: 0.0901 - val_accuracy: 0.9677
# Epoch 3/2000
# 49/49 [==============================] - 6s 114ms/step - loss: 0.0551 - accuracy: 0.9848 - val_loss: 0.0797 - val_accuracy: 0.9754
# Epoch 4/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0376 - accuracy: 0.9893 - val_loss: 0.0711 - val_accuracy: 0.9767
# Epoch 5/2000
# 49/49 [==============================] - 6s 114ms/step - loss: 0.0200 - accuracy: 0.9952 - val_loss: 0.0710 - val_accuracy: 0.9767
# Epoch 6/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0183 - accuracy: 0.9955 - val_loss: 0.0825 - val_accuracy: 0.9754
# Epoch 7/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0153 - accuracy: 0.9964 - val_loss: 0.0656 - val_accuracy: 0.9793
# Epoch 8/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0095 - accuracy: 0.9990 - val_loss: 0.0653 - val_accuracy: 0.9832
# Epoch 9/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0888 - val_accuracy: 0.9728
# Epoch 10/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0132 - accuracy: 0.9964 - val_loss: 0.0665 - val_accuracy: 0.9819
# Epoch 11/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.0708 - val_accuracy: 0.9793
# Epoch 12/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0747 - val_accuracy: 0.9767
# Epoch 13/2000
# 49/49 [==============================] - 6s 113ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0717 - val_accuracy: 0.9832
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.0736 - val_accuracy: 0.9858
# Epoch 15/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.0702 - val_accuracy: 0.9845
# Epoch 16/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0690 - val_accuracy: 0.9858
# Epoch 17/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0688 - val_accuracy: 0.9871
# Epoch 18/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0686 - val_accuracy: 0.9858
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0677 - val_accuracy: 0.9858
# Epoch 20/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0668 - val_accuracy: 0.9858
# Epoch 21/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0670 - val_accuracy: 0.9858
# Epoch 22/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.0660 - val_accuracy: 0.9858
# Epoch 23/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0649 - val_accuracy: 0.9871
# Epoch 24/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0657 - val_accuracy: 0.9858
# Epoch 25/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.0661 - val_accuracy: 0.9832
# Epoch 26/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0655 - val_accuracy: 0.9832
# Epoch 27/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0652 - val_accuracy: 0.9858
# Epoch 28/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0646 - val_accuracy: 0.9858
# Epoch 29/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0648 - val_accuracy: 0.9871
# Epoch 30/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0654 - val_accuracy: 0.9845
# Epoch 31/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0652 - val_accuracy: 0.98580.99
# Epoch 32/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0646 - val_accuracy: 0.9871
# Epoch 33/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0643 - val_accuracy: 0.9871
# Epoch 34/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9871
# Epoch 35/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9871
# Epoch 36/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0618 - val_accuracy: 0.9871
# Epoch 37/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0632 - val_accuracy: 0.9871
# Epoch 38/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0620 - val_accuracy: 0.9871
# Epoch 39/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0627 - val_accuracy: 0.9871
# Epoch 40/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9871
# Epoch 41/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0630 - val_accuracy: 0.9858
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 42/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9858
# Epoch 43/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0632 - val_accuracy: 0.9858
# Epoch 44/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0635 - val_accuracy: 0.9858
# Epoch 45/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0636 - val_accuracy: 0.9858
# Epoch 46/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.0635 - val_accuracy: 0.9858
# Epoch 47/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9858
# Epoch 48/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0635 - val_accuracy: 0.9871
# Epoch 49/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9871
# Epoch 50/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9871
# Epoch 51/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9845
# Epoch 52/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9845
# Epoch 53/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0629 - val_accuracy: 0.9871
# Epoch 54/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.0628 - val_accuracy: 0.9845
# Epoch 55/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0627 - val_accuracy: 0.9845
# Epoch 56/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9845
# Epoch 57/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0624 - val_accuracy: 0.9845
# Epoch 58/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9845
# Epoch 59/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0624 - val_accuracy: 0.9871
# Epoch 60/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9871
# Epoch 61/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9871
# Epoch 62/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9871
# Epoch 63/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0627 - val_accuracy: 0.9871
# Epoch 64/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9871
# Epoch 65/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 66/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 67/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 68/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0625 - val_accuracy: 0.9871
# Epoch 69/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9871
# Epoch 70/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0625 - val_accuracy: 0.9871
# Epoch 71/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0622 - val_accuracy: 0.9858
# Epoch 72/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9858
# Epoch 73/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0623 - val_accuracy: 0.9858
# Epoch 74/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0630 - val_accuracy: 0.9871
# Epoch 75/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9871
# Epoch 76/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0631 - val_accuracy: 0.9871
# Epoch 77/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9858
# Epoch 78/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9871
# Epoch 79/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9858
# Epoch 80/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0627 - val_accuracy: 0.9845
# Epoch 81/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0628 - val_accuracy: 0.9845
# Epoch 82/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0630 - val_accuracy: 0.9845
# Epoch 83/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 84/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 85/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0639 - val_accuracy: 0.9845
# Epoch 86/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0638 - val_accuracy: 0.9845
# Epoch 87/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0637 - val_accuracy: 0.9858
# Epoch 88/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9858
# Epoch 89/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0637 - val_accuracy: 0.9845
# Epoch 90/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0638 - val_accuracy: 0.9845
# Epoch 91/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0637 - val_accuracy: 0.9845
# Epoch 92/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 93/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 94/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0637 - val_accuracy: 0.9845
# Epoch 95/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0635 - val_accuracy: 0.9845
# Epoch 96/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 97/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.8132e-04 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 98/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 99/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 100/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0618 - val_accuracy: 0.9845
# Epoch 101/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 102/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0625 - val_accuracy: 0.9845
# Epoch 103/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9845
# Epoch 104/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0621 - val_accuracy: 0.9845
# Epoch 105/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9845
# Epoch 106/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0625 - val_accuracy: 0.9845
# Epoch 107/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 108/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 109/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9858
# Epoch 110/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 111/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 112/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.7753e-04 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9858
# Epoch 113/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9845
# Epoch 114/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0615 - val_accuracy: 0.9858
# Epoch 115/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0609 - val_accuracy: 0.9871
# Epoch 116/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.7143e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 117/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 118/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9845
# Epoch 119/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9858
# Epoch 120/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 121/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 122/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0623 - val_accuracy: 0.9845
# Epoch 123/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 8.8480e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 124/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9858
# Epoch 125/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0621 - val_accuracy: 0.9858
# Epoch 126/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0630 - val_accuracy: 0.9845
# Epoch 127/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 128/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 129/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0630 - val_accuracy: 0.9845
# Epoch 130/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0629 - val_accuracy: 0.9845
# Epoch 131/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 132/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9845
# Epoch 133/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 134/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 135/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9832
# Epoch 136/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9987 - val_loss: 0.0635 - val_accuracy: 0.9845
# Epoch 137/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 138/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0028 - accuracy: 0.9984 - val_loss: 0.0623 - val_accuracy: 0.9845
# Epoch 139/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 140/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.1693e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9871
# Epoch 141/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.5996e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9871
# Epoch 142/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0624 - val_accuracy: 0.9871
# Epoch 143/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9871
# Epoch 144/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9858
# Epoch 145/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0617 - val_accuracy: 0.9858
# Epoch 146/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0616 - val_accuracy: 0.9858
# Epoch 147/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 148/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9845
# Epoch 149/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0613 - val_accuracy: 0.9845
# Epoch 150/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.1787e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9845
# Epoch 151/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0618 - val_accuracy: 0.9845
# Epoch 152/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0619 - val_accuracy: 0.9845
# Epoch 153/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 154/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 155/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 156/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0618 - val_accuracy: 0.9845
# Epoch 157/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 158/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9832
# Epoch 159/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0614 - val_accuracy: 0.9845
# Epoch 160/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 9.8040e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 161/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 162/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0619 - val_accuracy: 0.9845
# Epoch 163/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.3204e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9845
# Epoch 164/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 165/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0621 - val_accuracy: 0.9845
# Epoch 166/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0625 - val_accuracy: 0.9845
# Epoch 167/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9845
# Epoch 168/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 169/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9845
# Epoch 170/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0619 - val_accuracy: 0.9845
# Epoch 171/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0621 - val_accuracy: 0.9832
# Epoch 172/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9832
# Epoch 173/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0619 - val_accuracy: 0.9845
# Epoch 174/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9845
# Epoch 175/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 9.6479e-04 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9845
# Epoch 176/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9832
# Epoch 177/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 178/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0629 - val_accuracy: 0.9845
# Epoch 179/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 180/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9858
# Epoch 181/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.7369e-04 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9832
# Epoch 182/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0626 - val_accuracy: 0.9832
# Epoch 183/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0624 - val_accuracy: 0.9832
# Epoch 184/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.4615e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9832
# Epoch 185/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9845
# Epoch 186/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0616 - val_accuracy: 0.9832
# Epoch 187/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0630 - val_accuracy: 0.9819
# Epoch 188/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0631 - val_accuracy: 0.9832
# Epoch 189/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.1373e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 190/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9845
# Epoch 191/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.7076e-04 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9832
# Epoch 192/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9832
# Epoch 193/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0626 - val_accuracy: 0.9845
# Epoch 194/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9858
# Epoch 195/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0630 - val_accuracy: 0.9845
# Epoch 196/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0634 - val_accuracy: 0.9845
# Epoch 197/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.4437e-04 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9845
# Epoch 198/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 199/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 7.4501e-04 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9832
# Epoch 200/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 9.4237e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9832
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB0\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0625 - val_accuracy: 0.9832
# Epoch 202/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0618 - val_accuracy: 0.9832
# Epoch 203/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0621 - val_accuracy: 0.9845
# Epoch 204/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 6.6245e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9832
# Epoch 205/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9832
# Epoch 206/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.5126e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9832
# Epoch 207/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0626 - val_accuracy: 0.9832
# Epoch 208/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.8761e-04 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9832
# Epoch 209/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.6367e-04 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9832
# Epoch 210/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0625 - val_accuracy: 0.9832
# Epoch 211/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.9034e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9832
# Epoch 212/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.4810e-04 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9832
# Epoch 213/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0632 - val_accuracy: 0.9832
# Epoch 214/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9845
# Epoch 215/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.3736e-04 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9845
# Epoch 216/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 217/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0637 - val_accuracy: 0.9845
# Epoch 218/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0638 - val_accuracy: 0.9858
# Epoch 219/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.4365e-04 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9858
# Epoch 220/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.9495e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9858
# Epoch 221/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9858
# Epoch 222/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.0104e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9858
# Epoch 223/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9845
# Epoch 224/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0626 - val_accuracy: 0.9845
# Epoch 225/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0626 - val_accuracy: 0.9832
# Epoch 226/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0625 - val_accuracy: 0.9832
# Epoch 227/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.9735e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 228/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.2732e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9845
# Epoch 229/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.9908e-04 - accuracy: 0.9997 - val_loss: 0.0616 - val_accuracy: 0.9845
# Epoch 230/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0606 - val_accuracy: 0.9845
# Epoch 231/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0608 - val_accuracy: 0.9845
# Epoch 232/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.8723e-04 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9845
# Epoch 233/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.0261e-04 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9871
# Epoch 234/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0611 - val_accuracy: 0.9871
# Epoch 235/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.4954e-04 - accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 0.9871
# Epoch 236/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0619 - val_accuracy: 0.9871
# Epoch 237/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 238/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.5545e-04 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9858
# Epoch 239/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9858
# Epoch 240/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0617 - val_accuracy: 0.9858
# Epoch 241/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.3206e-04 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9871
# Epoch 242/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.4251e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9871
# Epoch 243/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0616 - val_accuracy: 0.9845
# Epoch 244/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 245/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0612 - val_accuracy: 0.9845
# Epoch 246/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0617 - val_accuracy: 0.9858
# Epoch 247/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.8305e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9845
# Epoch 248/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 249/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.6608e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9858
# Epoch 250/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0613 - val_accuracy: 0.9871
# Epoch 251/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0621 - val_accuracy: 0.9845
# Epoch 252/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9858
# Epoch 253/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.6800e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 254/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0610 - val_accuracy: 0.9858
# Epoch 255/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9845
# Epoch 256/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.0593e-04 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9832
# Epoch 257/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.0412e-04 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9832
# Epoch 258/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 7.8286e-04 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9832
# Epoch 259/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0620 - val_accuracy: 0.9845
# Epoch 260/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.7044e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858.8125e-04 - accuracy
# Epoch 261/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9832
# Epoch 262/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.0283e-04 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9832
# Epoch 263/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0634 - val_accuracy: 0.9832
# Epoch 264/2000
# 49/49 [==============================] - 6s 112ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.0644 - val_accuracy: 0.9832
# Epoch 265/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9832
# Epoch 266/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 7.6745e-04 - accuracy: 0.9997 - val_loss: 0.0646 - val_accuracy: 0.9845
# Epoch 267/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0649 - val_accuracy: 0.9845
# Epoch 268/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0639 - val_accuracy: 0.9832
# Epoch 269/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9832
# Epoch 270/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9832
# Epoch 271/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0631 - val_accuracy: 0.9832
# Epoch 272/2000
# 49/49 [==============================] - 6s 112ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0629 - val_accuracy: 0.9832
# Epoch 273/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.6147e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9845
# Epoch 274/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.6454e-04 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9858
# Epoch 275/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 5.6662e-04 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9832
# Epoch 276/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9858
# Epoch 277/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0631 - val_accuracy: 0.9858
# Epoch 278/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0631 - val_accuracy: 0.9858
# Epoch 279/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0643 - val_accuracy: 0.9845
# Epoch 280/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0648 - val_accuracy: 0.9845
# Epoch 281/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0635 - val_accuracy: 0.9845
# Epoch 282/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9845
# Epoch 283/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9845
# Epoch 284/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 8.6136e-04 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9858
# Epoch 285/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0640 - val_accuracy: 0.9858
# Epoch 286/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0646 - val_accuracy: 0.9858
# Epoch 287/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0648 - val_accuracy: 0.9845
# Epoch 288/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.8655e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9845
# Epoch 289/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9858
# Epoch 290/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 8.7056e-04 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 0.9845
# Epoch 291/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 7.7894e-04 - accuracy: 1.0000 - val_loss: 0.0636 - val_accuracy: 0.9845
# Epoch 292/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.7524e-04 - accuracy: 0.9997 - val_loss: 0.0635 - val_accuracy: 0.9858
# Epoch 293/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0636 - val_accuracy: 0.9858
# Epoch 294/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0633 - val_accuracy: 0.9858
# Epoch 295/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0632 - val_accuracy: 0.9858
# Epoch 296/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 4.6713e-04 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9845
# Epoch 297/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0630 - val_accuracy: 0.9858
# Epoch 298/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.4173e-04 - accuracy: 0.9997 - val_loss: 0.0630 - val_accuracy: 0.9858
# Epoch 299/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.8233e-04 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9858
# Epoch 300/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 8.6189e-04 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9858
# Epoch 301/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0622 - val_accuracy: 0.9858
# Epoch 302/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9858
# Epoch 303/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.0677e-04 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9858
# Epoch 304/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.3207e-04 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9858
# Epoch 305/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 6.4500e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 306/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0623 - val_accuracy: 0.9858
# Epoch 307/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 5.9060e-04 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9858
# Epoch 308/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.1580e-04 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9858
# Epoch 309/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0628 - val_accuracy: 0.9858
# Epoch 310/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.9051e-04 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9845
# Epoch 311/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0628 - val_accuracy: 0.9845
# Epoch 312/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.2104e-04 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9845
# Epoch 313/2000
# 49/49 [==============================] - 6s 112ms/step - loss: 9.1266e-04 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 0.9845
# Epoch 314/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0629 - val_accuracy: 0.9845
# Epoch 315/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 7.0595e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9845
# Epoch 316/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0632 - val_accuracy: 0.9858
# Epoch 317/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0628 - val_accuracy: 0.9858
# Epoch 318/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.4515e-04 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9858
# Epoch 319/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.6713e-04 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 0.9858
# Epoch 320/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0624 - val_accuracy: 0.9845
# Epoch 321/2000
# 49/49 [==============================] - 5s 112ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0624 - val_accuracy: 0.9845
# Epoch 322/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 1.9056e-04 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9858
# Epoch 1900/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.6513e-05 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1901/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.3452e-04 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9845
# Epoch 1902/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.5024e-05 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1903/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.6867e-05 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9845
# Epoch 1904/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.3228e-05 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9845
# Epoch 1905/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.2169e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9845
# Epoch 1906/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.4012e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9858
# Epoch 1907/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.1733e-05 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9858
# Epoch 1908/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.0045e-05 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9858
# Epoch 1909/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.0919e-05 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9858
# Epoch 1910/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.1041e-04 - accuracy: 0.9994 - val_loss: 0.0595 - val_accuracy: 0.9858
# Epoch 1911/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.0338e-05 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9845
# Epoch 1912/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.1828e-04 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9845
# Epoch 1913/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.3217e-05 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9845
# Epoch 1914/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 3.4351e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9845
# Epoch 1915/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.1769e-05 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9845
# Epoch 1916/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 3.2859e-04 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9858
# Epoch 1917/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.5195e-05 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9858
# Epoch 1918/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.5612e-04 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9871
# Epoch 1919/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 5.6110e-04 - accuracy: 0.9997 - val_loss: 0.0612 - val_accuracy: 0.9871
# Epoch 1920/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 4.7934e-05 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9871
# Epoch 1921/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.4390e-04 - accuracy: 0.9997 - val_loss: 0.0614 - val_accuracy: 0.9871
# Epoch 1922/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.9436e-04 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 1923/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 4.2906e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9845
# Epoch 1924/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 8.3861e-05 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 1925/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 8.4099e-05 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9871
# Epoch 1926/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.8250e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 1927/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.1692e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9845
# Epoch 1928/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 2.3829e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9845
# Epoch 1929/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 5.1114e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 1930/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.2595e-05 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 1931/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 1.3788e-04 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9845
# Epoch 1932/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 1.5476e-04 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9845
# Epoch 1933/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.7582e-05 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9845
# Epoch 1934/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.4143e-04 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9845
# Epoch 1935/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.1879e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 1936/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.0681e-05 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9858
# Epoch 1937/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0612 - val_accuracy: 0.9845
# Epoch 1938/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.2283e-04 - accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 0.9845
# Epoch 1939/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 6.4412e-05 - accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 0.9845
# Epoch 1940/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.2093e-04 - accuracy: 0.9997 - val_loss: 0.0626 - val_accuracy: 0.9858
# Epoch 1941/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 3.9630e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9858
# Epoch 1942/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.3839e-04 - accuracy: 0.9994 - val_loss: 0.0627 - val_accuracy: 0.9858
# Epoch 1943/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0619 - val_accuracy: 0.9845
# Epoch 1944/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 1.1017e-04 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9858
# Epoch 1945/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 6.3123e-04 - accuracy: 0.9997 - val_loss: 0.0619 - val_accuracy: 0.9858
# Epoch 1946/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 6.5481e-05 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 1947/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 2.6177e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9845
# Epoch 1948/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.7504e-05 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9858
# Epoch 1949/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 1.1259e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9858
# Epoch 1950/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 6.4101e-05 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9845
# Epoch 1951/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.9415e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 1952/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.9679e-05 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9871
# Epoch 1953/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.0597e-05 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9871
# Epoch 1954/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 4.7702e-05 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9871
# Epoch 1955/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 7.5794e-04 - accuracy: 0.9994 - val_loss: 0.0609 - val_accuracy: 0.9871
# Epoch 1956/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.4695e-05 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9858
# Epoch 1957/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.0059e-05 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9858
# Epoch 1958/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 1.3075e-04 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1959/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 4.0900e-05 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1960/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 9.4981e-05 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1961/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.0752e-05 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9845
# Epoch 1962/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.8004e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9845
# Epoch 1963/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.7809e-05 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9845
# Epoch 1964/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 4.6375e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9845
# Epoch 1965/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.6635e-04 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9845
# Epoch 1966/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.8929e-04 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9845
# Epoch 1967/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 7.7480e-05 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9845
# Epoch 1968/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.6736e-05 - accuracy: 1.0000 - val_loss: 0.0596 - val_accuracy: 0.9845
# Epoch 1969/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.0217e-04 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9845
# Epoch 1970/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 3.5410e-04 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1971/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 1.8027e-04 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9845
# Epoch 1972/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.2088e-05 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9845
# Epoch 1973/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 3.1728e-04 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9845
# Epoch 1974/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.8502e-04 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9845
# Epoch 1975/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 8.9154e-05 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9845
# Epoch 1976/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.8170e-05 - accuracy: 1.0000 - val_loss: 0.0606 - val_accuracy: 0.9845 - l
# Epoch 1977/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.5078e-04 - accuracy: 0.9997 - val_loss: 0.0599 - val_accuracy: 0.9845
# Epoch 1978/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.5608e-05 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9845
# Epoch 1979/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 8.0424e-05 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9845
# Epoch 1980/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.3338e-04 - accuracy: 1.0000 - val_loss: 0.0599 - val_accuracy: 0.9845
# Epoch 1981/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 4.7172e-04 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9845
# Epoch 1982/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 8.7713e-05 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9845
# Epoch 1983/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.0466e-04 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9858
# Epoch 1984/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.2417e-04 - accuracy: 0.9997 - val_loss: 0.0603 - val_accuracy: 0.9858
# Epoch 1985/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 5.5304e-05 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 0.9858
# Epoch 1986/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 6.6243e-05 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9858
# Epoch 1987/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.4763e-04 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 0.9858
# Epoch 1988/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.9176e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 1989/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 2.2759e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9858
# Epoch 1990/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 4.4283e-05 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9858
# Epoch 1991/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 3.7910e-04 - accuracy: 0.9997 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 1992/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 7.4987e-05 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 1993/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 9.1054e-05 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9858
# Epoch 1994/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.5447e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9858
# Epoch 1995/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 6.9464e-05 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 1996/2000
# 49/49 [==============================] - 6s 111ms/step - loss: 2.3767e-04 - accuracy: 1.0000 - val_loss: 0.0616 - val_accuracy: 0.9858
# Epoch 1997/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.0080e-04 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9858
# Epoch 1998/2000
# 49/49 [==============================] - 6s 110ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0611 - val_accuracy: 0.9858
# Epoch 1999/2000
# 49/49 [==============================] - 5s 111ms/step - loss: 1.3517e-04 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9858
# Epoch 2000/2000
# 49/49 [==============================] - 5s 110ms/step - loss: 1.4295e-04 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9858
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/5G_EfficientNetB0\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# c:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 312ms/step - loss: 0.6512 - accuracy: 0.8779
# test_indoor_ds_results:test loss, test acc: [0.6512216925621033, 0.8779264092445374]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 24s 396ms/step - loss: 0.6142 - accuracy: 0.8752
# test_outdoor_ds_results:test loss, test acc: [0.6142281293869019, 0.8751592636108398]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 7s 160ms/step - loss: 0.9417 - accuracy: 0.8490
# test_belt_ds_results:test loss, test acc: [0.9416840076446533, 0.8490480780601501]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/4G_EfficientNetB0/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_87071) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_90641) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_55048) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_57748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_91248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_54608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_82664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_54707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_57300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_55147) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_55356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_54666) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_90034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_56361) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_55488) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_54824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_57565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_88867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_88238) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_47074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_55106) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_75955) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_54450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_89194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_90408) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_86838) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_57025) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_91575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_55315) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_88176) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_85235) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_87009) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_86231) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_55264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_55546) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_87631) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_55587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_89427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_56453) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_56585) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_57906) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_83246) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_85857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_84435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_83853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_82337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_54399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_91186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_87569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_85795) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_90579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_57524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_57789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_84108) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_83479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_57249) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_56636) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_89365) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_85624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_82104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_57117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_89801) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_84606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_83417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_56677) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_74178) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_54875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_82919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_56152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_89972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_87398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_57697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_54916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_88612) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_85042) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_86464) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_55979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_86402) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_56020) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_56908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_56203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_85297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_57341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_91015) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_55928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_57473) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_84668) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_56867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_55704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_55796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_55755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_82275) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_80600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_56244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_82857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_56809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_54491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_78845) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_88805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_88005) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_84046) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_57076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_56412) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 4s 87ms/step - loss: 0.5246 - accuracy: 0.8779
# 50/50 [==============================] - 4s 87ms/step - loss: 0.4861 - accuracy: 0.8790 0s - loss: 0.4802
# 35/35 [==============================] - 3s 87ms/step - loss: 0.7501 - accuracy: 0.8436
# Epoch200
#  test_indoor_acc=0.8779264092445374
#  test_outdoor_acc=0.8789808750152588
#  test_belt_acc=0.8436083197593689
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_166123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_165516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_133166) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_132609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_160222) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_134985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_135642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_164520) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_133034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_167483) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_162553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_165127) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_132993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_164956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_136024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_135143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_132726) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_168697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_163353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_165749) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_164349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_132517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_166730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_133224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_135815) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_167545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_161037) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_160455) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_134927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_133474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_132784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_163160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_161535) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_134795) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_133664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_133382) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_165687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_169133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_167919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_163415) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_132942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_160393) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_135235) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_132568) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_134479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_160782) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_134703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_134530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_168759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_168526) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_168090) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_161597) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_156963) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_158718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_134362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_135459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_133433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_135866) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_166356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_134321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_168152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_133873) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_167312) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_133265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_163742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_154073) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_169693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_161971) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_133822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_162164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_135907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_125192) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_135418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_166985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_162226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_134138) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_160975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_135194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_163975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_134097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_132825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_135683) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_165189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_134754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_163913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_164582) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_133705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_135591) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_135367) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_161364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_162786) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_134046) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_135026) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_134270) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_166923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_134571) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_133606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_133914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_169366) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_169304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_166294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_152296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_162724) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 4s 87ms/step - loss: 0.5625 - accuracy: 0.8802
# 50/50 [==============================] - 4s 87ms/step - loss: 0.5241 - accuracy: 0.8790
# 35/35 [==============================] - 3s 87ms/step - loss: 0.7934 - accuracy: 0.8468
# Epoch400
#  test_indoor_acc=0.8801560997962952
#  test_outdoor_acc=0.8789808750152588
#  test_belt_acc=0.8467814922332764
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_213965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_213568) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_210975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_245073) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_241503) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_212853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_210718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_213293) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_239514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_239187) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_211624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_242125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_213344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_214016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_242732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_240121) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_213135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_240936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_211855) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_213792) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_240874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_242670) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_238605) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_213741) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_241565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_212247) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_232223) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_211532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_230446) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_785563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_792093) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_760097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_790297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_790857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_790686) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_761036) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_758776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_794303) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_786705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_782133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_760761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_793867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_786145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_760405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_777466) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_758992) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_760155) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_757995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_793260) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_758834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_757738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_760313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_760853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_750362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_793089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_791526) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_759649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_760812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_757687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_791293) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_793696) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_783888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_785392) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_785625) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_792653) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_758204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_787956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_794863) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_788523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_759965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_786534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_759491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_761194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_760196) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_785952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_760985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_759308) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_760588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_758394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_759267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_787141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_792715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_788330) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_787396) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_792482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_788912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_793322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_759532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_758112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_760364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_758163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_759084) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_790126) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_758336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_761077) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_758875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_793929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_794474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_758603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_788585) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_758644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_758552) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_787723) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_757779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_789145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_792155) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 4s 86ms/step - loss: 0.6512 - accuracy: 0.8779
# 50/50 [==============================] - 4s 87ms/step - loss: 0.6142 - accuracy: 0.8752
# 35/35 [==============================] - 3s 88ms/step - loss: 0.9417 - accuracy: 0.8490
# Epoch2000
#  test_indoor_acc=0.8779264092445374
#  test_outdoor_acc=0.8751592636108398
#  test_belt_acc=0.8490480780601501

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8695868253707886
# max index -> 5
# The [Epoch] of max acc -> 1200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8779264092445374,
#  0.8801560997962952,
#  0.8762542009353638,
#  0.874024510383606,
#  0.870680034160614,
#  0.8812708854675293,
#  0.8751393556594849,
#  0.8795986771583557,
#  0.8784838318824768,
#  0.8779264092445374]

# %%
test_outdoor_acc
# Out:
# [0.8789808750152588,
#  0.8789808750152588,
#  0.8802548050880432,
#  0.8789808750152588,
#  0.8770700693130493,
#  0.8802548050880432,
#  0.8751592636108398,
#  0.8764331340789795,
#  0.8700637221336365,
#  0.8751592636108398]

# %%
test_belt_acc
# Out:
# [0.8436083197593689,
#  0.8467814922332764,
#  0.8508613109588623,
#  0.845421552658081,
#  0.8449682593345642,
#  0.8472347855567932,
#  0.8436083197593689,
#  0.8472347855567932,
#  0.8476881384849548,
#  0.8490480780601501]

# %%
test_indoor_loss
# Out:
# [0.524627685546875,
#  0.5625439286231995,
#  0.5844677686691284,
#  0.6124362945556641,
#  0.664249062538147,
#  0.5961360931396484,
#  0.6519345641136169,
#  0.6460561156272888,
#  0.651276171207428,
#  0.6512216925621033]

# %%
test_outdoor_loss
# Out:
# [0.4861159026622772,
#  0.5241076946258545,
#  0.5318887233734131,
#  0.5438193678855896,
#  0.5914196372032166,
#  0.5663313269615173,
#  0.6196665167808533,
#  0.606756329536438,
#  0.6525271534919739,
#  0.6142281293869019]

# %%
test_belt_loss
# Out:
# [0.7500564455986023,
#  0.7934348583221436,
#  0.8062018752098083,
#  0.8633212447166443,
#  0.8986051082611084,
#  0.872087299823761,
#  0.9355055093765259,
#  0.9143866300582886,
#  0.9149328470230103,
#  0.9416840076446533]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWaste_4Groups/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1-InfectionWaste', '2-BloodSecretionWaste', '3-LabWardWaste', '4-VaccineOtherWaste']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_448191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_448466) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_473637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_446074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_474135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_482293) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_448059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_480519) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_446305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_448624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_447079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_477182) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_476015) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_445209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_475953) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_448283) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_479523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_476949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_473964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_445117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_481359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_464896) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_479585) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_480145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_473382) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_473575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_469563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_445326) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_481904) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_447743) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_446514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_447626) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_481733) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_437792) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_445824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_471318) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_477120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_446033) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_446473) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_447395) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_475324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_448018) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_479912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_474197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_445542) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_447794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_445982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_446264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_474764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_446697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_475153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_478349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_447171) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_472822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_478287) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_473055) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_445593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_474826) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_445766) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_481126) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_445865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_478894) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_478723) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_446870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_446738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_448415) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_475386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_447527) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_475760) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_445425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_447130) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_478116) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_474571) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_477727) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_478956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_446921) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_447303) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_480690) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_446206) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_476575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_476342) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_446646) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_480083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_481297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_479330) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_445384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_445634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_476513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_448507) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_445168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_447967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_477789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_480752) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_448242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_477556) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_481966) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_446962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_466673) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_447585) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_447835) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_446422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_472993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_447354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 4 classes.
# Found 3140 files belonging to 4 classes.
# Found 2206 files belonging to 4 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6214
# FP=926
# acc=0.8703081232492997
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1-InfectionWaste acc = 94.54828660436138%
# 2-BloodSecretionWaste acc = 67.43515850144092%
# 3-LabWardWaste acc = 87.81763826606877%
# 4-VaccineOtherWaste acc = 95.65623540401681%
#
#
#
# all_avg_eachclass = 86.36432969397197%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[1821,   72,   14,   19],
#        [ 447, 1170,   34,   84],
#        [  19,   50, 1175,   94],
#        [  18,   43,   32, 2048]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[94.5482866 ,  3.73831776,  0.72689512,  0.98650052],
#        [25.76368876, 67.4351585 ,  1.95965418,  4.84149856],
#        [ 1.4200299 ,  3.73692078, 87.81763827,  7.02541106],
#        [ 0.84072863,  2.00840729,  1.49462868, 95.6562354 ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (14,14))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
