# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  #layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.225,width_factor=0.225),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 321ms/step - loss: 1.5061 - accuracy: 0.6184 - val_loss: 0.5734 - val_accuracy: 0.8279
# Epoch 2/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.4324 - accuracy: 0.8727 - val_loss: 0.3668 - val_accuracy: 0.8939
# Epoch 3/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.2283 - accuracy: 0.9396 - val_loss: 0.2463 - val_accuracy: 0.9237
# Epoch 4/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.1301 - accuracy: 0.9670 - val_loss: 0.2021 - val_accuracy: 0.9405
# Epoch 5/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0923 - accuracy: 0.9774 - val_loss: 0.1910 - val_accuracy: 0.9340
# Epoch 6/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0746 - accuracy: 0.9845 - val_loss: 0.1761 - val_accuracy: 0.9508
# Epoch 7/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0596 - accuracy: 0.9880 - val_loss: 0.1542 - val_accuracy: 0.9560
# Epoch 8/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0458 - accuracy: 0.9916 - val_loss: 0.1352 - val_accuracy: 0.9612
# Epoch 9/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0282 - accuracy: 0.9955 - val_loss: 0.1465 - val_accuracy: 0.9521
# Epoch 10/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0229 - accuracy: 0.9974 - val_loss: 0.1324 - val_accuracy: 0.9599
# Epoch 11/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0210 - accuracy: 0.9968 - val_loss: 0.1496 - val_accuracy: 0.9599
# Epoch 12/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0158 - accuracy: 0.9984 - val_loss: 0.1380 - val_accuracy: 0.9612
# Epoch 13/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 0.1677 - val_accuracy: 0.9573
# Epoch 14/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0141 - accuracy: 0.9981 - val_loss: 0.2014 - val_accuracy: 0.9444
# Epoch 15/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0147 - accuracy: 0.9961 - val_loss: 0.1611 - val_accuracy: 0.9521
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0128 - accuracy: 0.9977 - val_loss: 0.1426 - val_accuracy: 0.9573
# Epoch 17/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0089 - accuracy: 0.9984 - val_loss: 0.1451 - val_accuracy: 0.9547
# Epoch 18/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.1428 - val_accuracy: 0.9586
# Epoch 19/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0075 - accuracy: 0.9990 - val_loss: 0.1315 - val_accuracy: 0.9612
# Epoch 20/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.1323 - val_accuracy: 0.9599
# Epoch 21/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 0.1425 - val_accuracy: 0.9586
# Epoch 22/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9677
# Epoch 23/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.1336 - val_accuracy: 0.9625
# Epoch 24/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 0.1292 - val_accuracy: 0.9625
# Epoch 25/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.1169 - val_accuracy: 0.9664
# Epoch 26/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9677
# Epoch 27/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9677
# Epoch 28/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9690
# Epoch 29/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9664
# Epoch 30/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9702
# Epoch 31/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9664
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 32/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9690
# Epoch 33/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 34/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 35/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9690
# Epoch 36/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 37/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 38/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 39/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 40/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 41/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9702
# Epoch 42/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9702
# Epoch 43/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9702
# Epoch 44/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9702
# Epoch 45/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9702
# Epoch 46/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9702
# Epoch 47/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9702
# Epoch 48/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9702
# Epoch 49/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9702
# Epoch 50/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9702
# Epoch 51/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9702
# Epoch 52/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9702
# Epoch 53/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9702
# Epoch 54/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9702
# Epoch 55/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 56/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 57/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9677
# Epoch 58/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9677
# Epoch 59/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9677
# Epoch 60/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9677
# Epoch 61/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 62/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9702
# Epoch 63/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9702
# Epoch 64/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9702
# Epoch 65/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 66/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 67/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 68/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 69/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 70/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 71/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9677
# Epoch 72/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9677
# Epoch 73/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9677
# Epoch 74/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9677
# Epoch 75/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9690
# Epoch 76/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9690
# Epoch 77/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 78/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 79/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 80/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 81/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9677
# Epoch 82/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 83/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 84/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 85/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 86/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 87/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 88/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 89/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 90/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 91/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 92/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 93/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 94/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9677
# Epoch 95/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9690
# Epoch 96/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 97/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 98/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 99/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 100/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 101/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 102/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9677
# Epoch 103/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 104/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 105/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 106/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 107/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9677
# Epoch 108/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 109/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 110/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9690
# Epoch 111/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 112/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 113/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 114/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 115/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 116/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 117/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 118/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 119/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9677
# Epoch 120/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9677
# Epoch 121/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 122/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 123/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 124/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 125/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 126/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 127/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 128/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9690
# Epoch 129/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 130/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 131/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 132/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 133/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 134/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9677
# Epoch 135/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 136/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 137/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 138/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 139/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 140/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9677
# Epoch 141/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9677
# Epoch 142/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 143/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 144/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9690
# Epoch 145/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 146/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 147/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 148/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 149/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 150/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 151/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 152/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 153/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 154/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 155/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 156/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9690
# Epoch 157/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 158/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 159/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9702
# Epoch 160/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9715
# Epoch 161/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 162/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9690
# Epoch 163/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 164/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 165/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 166/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 167/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9702
# Epoch 168/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 169/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 170/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 171/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9715
# Epoch 172/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9702
# Epoch 173/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9728
# Epoch 174/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9702
# Epoch 175/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9715
# Epoch 176/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9702
# Epoch 177/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9702
# Epoch 178/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9728
# Epoch 179/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9702
# Epoch 180/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9702
# Epoch 181/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9702
# Epoch 182/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9715
# Epoch 183/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9728
# Epoch 184/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9715
# Epoch 185/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9702
# Epoch 186/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9702
# Epoch 187/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9702
# Epoch 188/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9690
# Epoch 189/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9702
# Epoch 190/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9715
# Epoch 191/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9702
# Epoch 192/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9690
# Epoch 193/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9702
# Epoch 194/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9702
# Epoch 195/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9702
# Epoch 196/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9715
# Epoch 197/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.5609e-04 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 198/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9690
# Epoch 199/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.9697e-04 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9690
# Epoch 200/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9702
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.97.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.6731e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9702
# Epoch 202/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3718e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9702
# Epoch 203/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2484e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9690
# Epoch 204/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.1795e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9690
# Epoch 205/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.4172e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9715
# Epoch 206/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.3061e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9702
# Epoch 207/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.8860e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9715
# Epoch 208/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.6548e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9702
# Epoch 209/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.6717e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9690
# Epoch 210/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0055e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9677
# Epoch 211/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0642e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 212/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0737e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 213/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.5500e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 214/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.9240e-04 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9690
# Epoch 215/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.0952e-04 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9715
# Epoch 216/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.3564e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 217/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.2826e-04 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9690
# Epoch 218/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.5379e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9690
# Epoch 219/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.6860e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9690
# Epoch 220/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.4095e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9690
# Epoch 221/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.7923e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9702
# Epoch 222/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.9165e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9702
# Epoch 223/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1621e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9702
# Epoch 224/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.8486e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9715
# Epoch 225/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1295e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9728
# Epoch 226/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.9507e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9715
# Epoch 227/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.7643e-04 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9715
# Epoch 228/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.5079e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9728
# Epoch 229/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.0184e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9715
# Epoch 230/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.2506e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9728
# Epoch 231/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.6259e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9728
# Epoch 232/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.4056e-04 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9715
# Epoch 233/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.5101e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9728
# Epoch 234/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.8511e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9728
# Epoch 235/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.4214e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9728
# Epoch 236/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.9164e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9728
# Epoch 237/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.3669e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9728
# Epoch 238/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.1735e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9728
# Epoch 239/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.4105e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9728
# Epoch 240/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.3789e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9728
# Epoch 241/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.4463e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9728
# Epoch 242/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.3506e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9728
# Epoch 243/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.6788e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9728
# Epoch 244/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.7802e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9677
# Epoch 245/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.8301e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9728
# Epoch 246/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.4949e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9728
# Epoch 247/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.0605e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9715
# Epoch 248/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.5899e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9715
# Epoch 249/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.6220e-04 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9728
# Epoch 250/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.8612e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9728
# Epoch 251/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.6590e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9715
# Epoch 252/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.7827e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9728
# Epoch 253/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.8570e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9728
# Epoch 254/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4964e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9715
# Epoch 255/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.7253e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9728
# Epoch 256/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.1478e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9702
# Epoch 257/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.5691e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9702
# Epoch 258/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.6554e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9728
# Epoch 259/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.0814e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9728
# Epoch 260/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4261e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9728
# Epoch 261/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.1289e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9715
# Epoch 262/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.3698e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9728
# Epoch 263/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.7194e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9728
# Epoch 264/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4991e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9728
# Epoch 265/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.5965e-04 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9728
# Epoch 266/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.3336e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9702
# Epoch 267/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.2323e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9728
# Epoch 268/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.1148e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9728
# Epoch 269/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.3930e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9728
# Epoch 270/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.2425e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9702
# Epoch 271/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4959e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9715
# Epoch 272/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.2103e-04 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9728
# Epoch 273/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.9083e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9715
# Epoch 274/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6519e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9728
# Epoch 275/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.1278e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9715
# Epoch 276/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.9928e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9728
# Epoch 277/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5785e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9728
# Epoch 278/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3917e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9728
# Epoch 279/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3515e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9728
# Epoch 280/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5716e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9728
# Epoch 281/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3231e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9728
# Epoch 282/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5051e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9715
# Epoch 283/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.7777e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9702
# Epoch 284/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1704e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9715
# Epoch 285/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3227e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9715
# Epoch 286/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1042e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9715
# Epoch 287/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6092e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9728
# Epoch 288/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3529e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9728
# Epoch 289/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.4218e-04 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9715
# Epoch 290/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1098e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9728
# Epoch 291/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0113e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9728
# Epoch 292/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1857e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9728
# Epoch 293/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8918e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9728
# Epoch 294/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8789e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9728
# Epoch 295/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3483e-04 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9715
# Epoch 296/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0299e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9702
# Epoch 297/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1692e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9715
# Epoch 298/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5962e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9715
# Epoch 299/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.9013e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9728
# Epoch 300/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6661e-04 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9715
# Epoch 301/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7796e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9715
# Epoch 302/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5352e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9728
# Epoch 303/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1513e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9715
# Epoch 304/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8905e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9728
# Epoch 305/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5723e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9728
# Epoch 306/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1158e-04 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9715
# Epoch 307/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6003e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9728
# Epoch 308/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6656e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9728
# Epoch 309/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.4898e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9728
# Epoch 310/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8797e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9741
# Epoch 311/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1784e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9715
# Epoch 312/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2881e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9728
# Epoch 313/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7207e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9728
# Epoch 314/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.4400e-04 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9728
# Epoch 315/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2852e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9715
# Epoch 316/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.4634e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9728
# Epoch 317/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3981e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9728
# Epoch 318/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1667e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9728
# Epoch 319/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.2084e-04 - accuracy: 1.0000 - val_loss: 0.1215 - val_accuracy: 0.9728
# Epoch 320/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2521e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9728
# Epoch 321/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9117e-04 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9728
# Epoch 322/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1243e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9715
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.6711e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1898/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4997e-07 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9728
# Epoch 1899/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9153e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1900/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.5355e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1901/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8152e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1902/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0728e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9728
# Epoch 1903/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.6573e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1904/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.6746e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1905/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.6322e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1906/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9947e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1907/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0147e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1908/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.6715e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1909/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9388e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1910/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.1025e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1911/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.1896e-07 - accuracy: 1.0000 - val_loss: 0.1850 - val_accuracy: 0.9728
# Epoch 1912/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7366e-07 - accuracy: 1.0000 - val_loss: 0.1850 - val_accuracy: 0.9728
# Epoch 1913/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8179e-07 - accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9728
# Epoch 1914/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.5548e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1915/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.2762e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9728
# Epoch 1916/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7035e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9728
# Epoch 1917/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0678e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9728
# Epoch 1918/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9842e-07 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9728
# Epoch 1919/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4204e-07 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9728
# Epoch 1920/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.9043e-07 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9728
# Epoch 1921/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.3421e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1922/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7462e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1923/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.4141e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1924/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0848e-07 - accuracy: 1.0000 - val_loss: 0.1850 - val_accuracy: 0.9728
# Epoch 1925/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9261e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9728
# Epoch 1926/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.3624e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1927/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.5325e-07 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 0.9728
# Epoch 1928/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7547e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9728
# Epoch 1929/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9396e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9728
# Epoch 1930/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4289e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1931/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.2243e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1932/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5563e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1933/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8552e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9728
# Epoch 1934/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4358e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1935/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2481e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9728
# Epoch 1936/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0466e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9728
# Epoch 1937/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.5756e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9728
# Epoch 1938/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.6004e-07 - accuracy: 1.0000 - val_loss: 0.1842 - val_accuracy: 0.9728
# Epoch 1939/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7948e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1940/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9103e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1941/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4038e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9728
# Epoch 1942/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.0876e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9728
# Epoch 1943/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7424e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1944/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7046e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9728
# Epoch 1945/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8945e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9728
# Epoch 1946/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7651e-07 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9728
# Epoch 1947/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.6212e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9728
# Epoch 1948/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.1680e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9728
# Epoch 1949/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8310e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9728
# Epoch 1950/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.2858e-07 - accuracy: 1.0000 - val_loss: 0.1862 - val_accuracy: 0.9728
# Epoch 1951/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.2192e-07 - accuracy: 1.0000 - val_loss: 0.1865 - val_accuracy: 0.9728
# Epoch 1952/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8780e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9728
# Epoch 1953/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.9993e-07 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9728
# Epoch 1954/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.3890e-07 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 0.9728
# Epoch 1955/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8726e-07 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.9728
# Epoch 1956/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2193e-07 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9728
# Epoch 1957/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3695e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9728
# Epoch 1958/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0066e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9728
# Epoch 1959/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0802e-07 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9728
# Epoch 1960/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0482e-07 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9728
# Epoch 1961/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.5094e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9728
# Epoch 1962/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9962e-07 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9728
# Epoch 1963/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.4824e-07 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9728
# Epoch 1964/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1011e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9728
# Epoch 1965/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.2085e-07 - accuracy: 1.0000 - val_loss: 0.1862 - val_accuracy: 0.9728
# Epoch 1966/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4959e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9728
# Epoch 1967/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7535e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9728
# Epoch 1968/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5790e-07 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9728
# Epoch 1969/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.3632e-07 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9728
# Epoch 1970/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5348e-07 - accuracy: 1.0000 - val_loss: 0.1859 - val_accuracy: 0.9728
# Epoch 1971/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9280e-07 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9728
# Epoch 1972/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7143e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9728
# Epoch 1973/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.5475e-07 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9728
# Epoch 1974/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1109e-07 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9728
# Epoch 1975/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9804e-07 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9728
# Epoch 1976/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9392e-07 - accuracy: 1.0000 - val_loss: 0.1862 - val_accuracy: 0.9728
# Epoch 1977/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6615e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9728
# Epoch 1978/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7659e-07 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9728
# Epoch 1979/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7476e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9728
# Epoch 1980/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 1.9909e-07 - accuracy: 1.0000 - val_loss: 0.1865 - val_accuracy: 0.9728
# Epoch 1981/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7647e-07 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9728
# Epoch 1982/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3514e-07 - accuracy: 1.0000 - val_loss: 0.1865 - val_accuracy: 0.9728
# Epoch 1983/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2604e-07 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9728
# Epoch 1984/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7062e-07 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9728
# Epoch 1985/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7462e-07 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9728
# Epoch 1986/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9242e-07 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9728
# Epoch 1987/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.2085e-07 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9728
# Epoch 1988/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6106e-07 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9728
# Epoch 1989/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2727e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9728
# Epoch 1990/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.0583e-07 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9728
# Epoch 1991/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1874e-07 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9728
# Epoch 1992/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.3245e-07 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9728
# Epoch 1993/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.0271e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9728
# Epoch 1994/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.2848e-07 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9728
# Epoch 1995/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.0301e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9728
# Epoch 1996/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.8984e-07 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9728
# Epoch 1997/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1040e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9728
# Epoch 1998/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9011e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9728
# Epoch 1999/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.7998e-07 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9728
# Epoch 2000/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 2.4939e-07 - accuracy: 1.0000 - val_loss: 0.1865 - val_accuracy: 0.9728
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 325ms/step - loss: 0.8293 - accuracy: 0.8534
# test_indoor_ds_results:test loss, test acc: [0.8292986154556274, 0.8534002304077148]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 409ms/step - loss: 2.3924 - accuracy: 0.7385
# test_outdoor_ds_results:test loss, test acc: [2.392400026321411, 0.7385350465774536]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 191ms/step - loss: 2.4402 - accuracy: 0.7094
# test_belt_ds_results:test loss, test acc: [2.440194606781006, 0.7094288468360901]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Zoom225-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 139ms/step - loss: 0.5596 - accuracy: 0.8395
# 50/50 [==============================] - 7s 141ms/step - loss: 1.4126 - accuracy: 0.7338
# 35/35 [==============================] - 5s 142ms/step - loss: 1.4915 - accuracy: 0.6995
# Epoch200
#  test_indoor_acc=0.8394649028778076
#  test_outdoor_acc=0.7337579727172852
#  test_belt_acc=0.6994560360908508
# 29/29 [==============================] - 5s 138ms/step - loss: 0.6106 - accuracy: 0.8400
# 50/50 [==============================] - 7s 140ms/step - loss: 1.6109 - accuracy: 0.7325
# 35/35 [==============================] - 5s 141ms/step - loss: 1.6589 - accuracy: 0.7058
# Epoch400
#  test_indoor_acc=0.8400223255157471
#  test_outdoor_acc=0.7324841022491455
#  test_belt_acc=0.7058023810386658
# 29/29 [==============================] - 5s 141ms/step - loss: 0.6536 - accuracy: 0.8445
# 50/50 [==============================] - 7s 143ms/step - loss: 1.8009 - accuracy: 0.7347
# 35/35 [==============================] - 5s 143ms/step - loss: 1.8472 - accuracy: 0.7103
# Epoch600
#  test_indoor_acc=0.8444815874099731
#  test_outdoor_acc=0.7347133755683899
#  test_belt_acc=0.7103354334831238
# 29/29 [==============================] - 5s 138ms/step - loss: 0.7002 - accuracy: 0.8467
# 50/50 [==============================] - 7s 140ms/step - loss: 1.9732 - accuracy: 0.7366
# 35/35 [==============================] - 5s 140ms/step - loss: 2.0033 - accuracy: 0.7131
# Epoch800
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.7366241812705994
#  test_belt_acc=0.7130553126335144
# 29/29 [==============================] - 5s 139ms/step - loss: 0.7355 - accuracy: 0.8473
# 50/50 [==============================] - 7s 141ms/step - loss: 2.0912 - accuracy: 0.7360
# 35/35 [==============================] - 5s 142ms/step - loss: 2.1165 - accuracy: 0.7121
# Epoch1000
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7359872460365295
#  test_belt_acc=0.7121486663818359
# 29/29 [==============================] - 5s 138ms/step - loss: 0.7714 - accuracy: 0.8473
# 50/50 [==============================] - 7s 140ms/step - loss: 2.1821 - accuracy: 0.7395
# 35/35 [==============================] - 5s 141ms/step - loss: 2.2189 - accuracy: 0.7121
# Epoch1200
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7394904494285583
#  test_belt_acc=0.7121486663818359
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7889 - accuracy: 0.8489
# 50/50 [==============================] - 7s 138ms/step - loss: 2.2465 - accuracy: 0.7395
# 35/35 [==============================] - 5s 138ms/step - loss: 2.2920 - accuracy: 0.7112
# Epoch1400
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.7394904494285583
#  test_belt_acc=0.7112420797348022
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8050 - accuracy: 0.8495
# 50/50 [==============================] - 7s 137ms/step - loss: 2.3267 - accuracy: 0.7379
# 35/35 [==============================] - 5s 138ms/step - loss: 2.3722 - accuracy: 0.7103
# Epoch1600
#  test_indoor_acc=0.8494983315467834
#  test_outdoor_acc=0.7378981113433838
#  test_belt_acc=0.7103354334831238
# 29/29 [==============================] - 5s 138ms/step - loss: 0.8249 - accuracy: 0.8506
# 50/50 [==============================] - 7s 140ms/step - loss: 2.3731 - accuracy: 0.7379
# 35/35 [==============================] - 5s 141ms/step - loss: 2.4093 - accuracy: 0.7099
# Epoch1800
#  test_indoor_acc=0.8506131768226624
#  test_outdoor_acc=0.7378981113433838
#  test_belt_acc=0.7098821401596069
# 29/29 [==============================] - 5s 140ms/step - loss: 0.8293 - accuracy: 0.8534
# 50/50 [==============================] - 7s 142ms/step - loss: 2.3924 - accuracy: 0.7385
# 35/35 [==============================] - 5s 143ms/step - loss: 2.4402 - accuracy: 0.7094
# Epoch2000
#  test_indoor_acc=0.8534002304077148
#  test_outdoor_acc=0.7385350465774536
#  test_belt_acc=0.7094288468360901

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7671213746070862
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8394649028778076,
#  0.8400223255157471,
#  0.8444815874099731,
#  0.846711277961731,
#  0.8472687005996704,
#  0.8472687005996704,
#  0.848940908908844,
#  0.8494983315467834,
#  0.8506131768226624,
#  0.8534002304077148]

# %%
test_outdoor_acc
# Out:
# [0.7337579727172852,
#  0.7324841022491455,
#  0.7347133755683899,
#  0.7366241812705994,
#  0.7359872460365295,
#  0.7394904494285583,
#  0.7394904494285583,
#  0.7378981113433838,
#  0.7378981113433838,
#  0.7385350465774536]

# %%
test_belt_acc
# Out:
# [0.6994560360908508,
#  0.7058023810386658,
#  0.7103354334831238,
#  0.7130553126335144,
#  0.7121486663818359,
#  0.7121486663818359,
#  0.7112420797348022,
#  0.7103354334831238,
#  0.7098821401596069,
#  0.7094288468360901]

# %%
test_indoor_loss
# Out:
# [0.5596290826797485,
#  0.6106142997741699,
#  0.6536127924919128,
#  0.700234591960907,
#  0.7354629635810852,
#  0.7714076638221741,
#  0.7889201045036316,
#  0.804986298084259,
#  0.8248516321182251,
#  0.8292986154556274]

# %%
test_outdoor_loss
# Out:
# [1.4126135110855103,
#  1.6109449863433838,
#  1.8008956909179688,
#  1.973230004310608,
#  2.0912184715270996,
#  2.18211030960083,
#  2.246504783630371,
#  2.326662540435791,
#  2.373077154159546,
#  2.392400026321411]

# %%
test_belt_loss
# Out:
# [1.4915494918823242,
#  1.6588740348815918,
#  1.8472228050231934,
#  2.0032904148101807,
#  2.116501808166504,
#  2.2188615798950195,
#  2.292037010192871,
#  2.372183322906494,
#  2.4092819690704346,
#  2.440194606781006]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5415
# FP=1725
# acc=0.7584033613445378
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 81.89655172413794%
# 2WayConnectorforFoley acc = 89.1156462585034%
# 2WayFoleyCatheter acc = 72.38805970149254%
# 3WayConnectorforFoley acc = 88.03418803418803%
# 3Waystopcock acc = 96.3963963963964%
# AlcoholBottle acc = 84.375%
# AlcoholPad acc = 46.82539682539682%
# BootCover acc = 61.44578313253012%
# CottonBall acc = 83.23353293413174%
# CottonSwap acc = 71.32867132867133%
# Dilator acc = 74.35897435897436%
# DisposableInfusionSet acc = 49.557522123893804%
# ExtensionTube acc = 38.21138211382114%
# FaceShield acc = 60.49382716049383%
# FrontLoadSyringe acc = 59.29203539823009%
# GauzePad acc = 69.31818181818183%
# Glove acc = 77.97619047619048%
# GuideWire acc = 30.357142857142854%
# LiquidBottle acc = 64.50381679389314%
# Mask acc = 95.58441558441558%
# NGTube acc = 43.87096774193549%
# NasalCannula acc = 58.4070796460177%
# Needle acc = 86.42857142857143%
# OxygenMask acc = 87.96992481203007%
# PPESuit acc = 89.51612903225806%
# PharmaceuticalProduct acc = 62.850467289719624%
# Pill acc = 96.07843137254902%
# PillBottle acc = 74.4186046511628%
# PrefilledHumidifier acc = 90.5982905982906%
# PressureConnectingTube acc = 64.12213740458014%
# ReusableHumidifier acc = 83.89830508474576%
# SodiumChlorideBag acc = 81.88976377952756%
# SterileHumidifierAdapter acc = 71.81818181818181%
# SurgicalBlade acc = 81.41592920353983%
# SurgicalCap acc = 92.7927927927928%
# SurgicalSuit acc = 46.96969696969697%
# Syringe acc = 97.33840304182509%
# TrachealTube acc = 41.284403669724774%
# UrineBag acc = 72.5%
# Vaccinebottle acc = 86.85446009389672%
# WingedInfusionSet acc = 68.42105263157895%
#
#
#
# all_avg_eachclass = 72.53990995325147%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 95,   0,   0, ...,   0,   1,   1],
#        [  1, 131,   0, ...,   0,   1,   0],
#        [  0,   0,  97, ...,   0,   3,  14],
#        ...,
#        [  0,   0,   0, ...,  87,   0,   0],
#        [  0,   0,   0, ...,   1, 185,   0],
#        [  0,   0,   0, ...,   2,   1,  78]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[81.89655172,  0.        ,  0.        , ...,  0.        ,
#          0.86206897,  0.86206897],
#        [ 0.68027211, 89.11564626,  0.        , ...,  0.        ,
#          0.68027211,  0.        ],
#        [ 0.        ,  0.        , 72.3880597 , ...,  0.        ,
#          2.23880597, 10.44776119],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 72.5       ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.46948357,
#         86.85446009,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  1.75438596,
#          0.87719298, 68.42105263]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
