# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  #layers.RandomRotation(0.50),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 356ms/step - loss: 1.2531 - accuracy: 0.6643 - val_loss: 0.4650 - val_accuracy: 0.8655
# Epoch 2/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.2993 - accuracy: 0.9134 - val_loss: 0.2609 - val_accuracy: 0.9133
# Epoch 3/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.1503 - accuracy: 0.9619 - val_loss: 0.2165 - val_accuracy: 0.9301
# Epoch 4/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0968 - accuracy: 0.9780 - val_loss: 0.2149 - val_accuracy: 0.9276
# Epoch 5/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0640 - accuracy: 0.9871 - val_loss: 0.1875 - val_accuracy: 0.9405
# Epoch 6/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0547 - accuracy: 0.9842 - val_loss: 0.1718 - val_accuracy: 0.9508
# Epoch 7/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0515 - accuracy: 0.9877 - val_loss: 0.2456 - val_accuracy: 0.9276
# Epoch 8/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0361 - accuracy: 0.9922 - val_loss: 0.1560 - val_accuracy: 0.9547
# Epoch 9/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0417 - accuracy: 0.9880 - val_loss: 0.1484 - val_accuracy: 0.9651
# Epoch 10/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0307 - accuracy: 0.9919 - val_loss: 0.1981 - val_accuracy: 0.9457
# Epoch 11/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0253 - accuracy: 0.9942 - val_loss: 0.1924 - val_accuracy: 0.9495
# Epoch 12/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0162 - accuracy: 0.9964 - val_loss: 0.1810 - val_accuracy: 0.9495
# Epoch 13/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0113 - accuracy: 0.9981 - val_loss: 0.1692 - val_accuracy: 0.9560
# Epoch 14/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.1464 - val_accuracy: 0.9612
# Epoch 15/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.1664 - val_accuracy: 0.9521
# Epoch 16/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.1585 - val_accuracy: 0.9586
# Epoch 17/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.1467 - val_accuracy: 0.9638
# Epoch 18/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.1403 - val_accuracy: 0.9586
# Epoch 19/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.1786 - val_accuracy: 0.9534
# Epoch 20/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9677
# Epoch 21/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1666 - val_accuracy: 0.9573
# Epoch 22/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.1487 - val_accuracy: 0.9612
# Epoch 23/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9702
# Epoch 24/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.1553 - val_accuracy: 0.9625
# Epoch 25/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9638
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 26/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1381 - val_accuracy: 0.9728
# Epoch 27/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.1385 - val_accuracy: 0.9702
# Epoch 28/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.6278e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9677
# Epoch 29/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.4619e-04 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9702
# Epoch 30/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 9.2124e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9702
# Epoch 31/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9702
# Epoch 32/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 8.3249e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9690
# Epoch 33/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9854e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9702
# Epoch 34/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 9.0467e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9702
# Epoch 35/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.5451e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9690
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 36/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8810e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9690
# Epoch 37/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.1075e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9677
# Epoch 38/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 8.5147e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9677
# Epoch 39/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.5630e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9677
# Epoch 40/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2250e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 41/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.5425e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 42/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.5541e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9690
# Epoch 43/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.6626e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9690
# Epoch 44/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.9096e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9690
# Epoch 45/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.9305e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9690
# Epoch 46/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.9428e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9690
# Epoch 47/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2276e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 48/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.5407e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 49/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.8365e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 50/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8135e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 51/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.1625e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 52/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.9743e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 53/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.4505e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 54/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.7948e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9690
# Epoch 55/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3931e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 56/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.4069e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 57/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.4057e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 58/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2023e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 59/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.5773e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9702
# Epoch 60/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0200e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9702
# Epoch 61/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.9880e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9702
# Epoch 62/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.7097e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9702
# Epoch 63/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3465e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9702
# Epoch 64/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2263e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 65/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3141e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 66/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.5314e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9702
# Epoch 67/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.7490e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 68/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2229e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9702
# Epoch 69/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.1128e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9702
# Epoch 70/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.0054e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9690
# Epoch 71/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.6093e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9702
# Epoch 72/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.8428e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9702
# Epoch 73/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.4085e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9702
# Epoch 74/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7462e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9702
# Epoch 75/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.3576e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9702
# Epoch 76/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0356e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9702
# Epoch 77/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5838e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9702
# Epoch 78/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9760e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 79/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.4026e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9702
# Epoch 80/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6780e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9702
# Epoch 81/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7985e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9702
# Epoch 82/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0756e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9702
# Epoch 83/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.8105e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9702
# Epoch 84/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0135e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9702
# Epoch 85/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.6044e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 86/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.3282e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 87/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4828e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9702
# Epoch 88/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5974e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9702
# Epoch 89/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6444e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 90/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9562e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9690
# Epoch 91/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1849e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9690
# Epoch 92/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.6308e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9690
# Epoch 93/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.5640e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9690
# Epoch 94/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.3166e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9702
# Epoch 95/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7290e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9702
# Epoch 96/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.5010e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9690
# Epoch 97/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1693e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9690
# Epoch 98/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4930e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9690
# Epoch 99/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2147e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9677
# Epoch 100/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8620e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9690
# Epoch 101/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.3741e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9690
# Epoch 102/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.3399e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9690
# Epoch 103/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4126e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9677
# Epoch 104/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.6573e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9677
# Epoch 105/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4942e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9677
# Epoch 106/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.3897e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9677
# Epoch 107/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4333e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9690
# Epoch 108/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.4983e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9677
# Epoch 109/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5939e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9677
# Epoch 110/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6450e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 111/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.3968e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9690
# Epoch 112/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.0458e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9677
# Epoch 113/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4361e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9677
# Epoch 114/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1084e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9677
# Epoch 115/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.1566e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9702
# Epoch 116/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5155e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9690
# Epoch 117/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.2107e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9690
# Epoch 118/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.0617e-04 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9702
# Epoch 119/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.0732e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9702
# Epoch 120/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1217e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9702
# Epoch 121/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0086e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9702
# Epoch 122/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8426e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9702
# Epoch 123/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7849e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9702
# Epoch 124/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7180e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9702
# Epoch 125/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8886e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9690
# Epoch 126/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7454e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9702
# Epoch 127/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4727e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9702
# Epoch 128/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8117e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9702
# Epoch 129/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4268e-04 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9715
# Epoch 130/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.2409e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9702
# Epoch 131/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.6386e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9690
# Epoch 132/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.4837e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9702
# Epoch 133/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.8359e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9702
# Epoch 134/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5397e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9690
# Epoch 135/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5832e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9715
# Epoch 136/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5539e-04 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9702
# Epoch 137/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.4744e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9702
# Epoch 138/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.6292e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9702
# Epoch 139/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.4412e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9690
# Epoch 140/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.0598e-04 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9690
# Epoch 141/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.6825e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9702
# Epoch 142/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.6730e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9702
# Epoch 143/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8311e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9702
# Epoch 144/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7598e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 145/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.3064e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9690
# Epoch 146/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.5471e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9702
# Epoch 147/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.7786e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9702
# Epoch 148/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.7483e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9690
# Epoch 149/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.2417e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9702
# Epoch 150/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.7462e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9702
# Epoch 151/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.3074e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9715
# Epoch 152/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.4964e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9702
# Epoch 153/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.4235e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9690
# Epoch 154/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.0908e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9702
# Epoch 155/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.0591e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9702
# Epoch 156/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.7991e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9702
# Epoch 157/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.2677e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9728
# Epoch 158/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.2862e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9715
# Epoch 159/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.6912e-04 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9715
# Epoch 160/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.1157e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9715
# Epoch 161/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.9473e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9715
# Epoch 162/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.5104e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9715
# Epoch 163/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.7594e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9715
# Epoch 164/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.1902e-04 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9715
# Epoch 165/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.2115e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9715
# Epoch 166/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.2013e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9702
# Epoch 167/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.5964e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9715
# Epoch 168/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.8647e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9715
# Epoch 169/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.4219e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9715
# Epoch 170/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.5131e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9702
# Epoch 171/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.6339e-04 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9690
# Epoch 172/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.5037e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9702
# Epoch 173/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.8199e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9702
# Epoch 174/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.3699e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9702
# Epoch 175/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.1500e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9690
# Epoch 176/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.2176e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9702
# Epoch 177/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.1118e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9702
# Epoch 178/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.0406e-04 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9702
# Epoch 179/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.1951e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9690
# Epoch 180/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.3965e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9702
# Epoch 181/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.0304e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9702
# Epoch 182/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.9047e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9702
# Epoch 183/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.7867e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9702
# Epoch 184/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.1444e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9702
# Epoch 185/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.6521e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9690
# Epoch 186/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.5821e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9677
# Epoch 187/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.7409e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9690
# Epoch 188/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.8621e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9677
# Epoch 189/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.5198e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9702
# Epoch 190/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.2836e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9702
# Epoch 191/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.0437e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9702
# Epoch 192/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.5947e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9715
# Epoch 193/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.6486e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9702
# Epoch 194/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.6913e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9715
# Epoch 195/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.8959e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9715
# Epoch 196/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.6508e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9715
# Epoch 197/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.7820e-04 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 0.9715
# Epoch 198/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.5750e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9715
# Epoch 199/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.2944e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 200/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.5050e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3844e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9702
# Epoch 202/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2534e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9702
# Epoch 203/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2576e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9702
# Epoch 204/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4889e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9715
# Epoch 205/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3137e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9715
# Epoch 206/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.2181e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9702
# Epoch 207/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.5177e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9702
# Epoch 208/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3118e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9715
# Epoch 209/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1895e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9715
# Epoch 210/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2374e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9715
# Epoch 211/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.0556e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9715
# Epoch 212/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7279e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9715
# Epoch 213/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2009e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9715
# Epoch 214/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8929e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 215/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3256e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9677
# Epoch 216/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1528e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9690
# Epoch 217/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0137e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9715
# Epoch 218/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.0720e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9715
# Epoch 219/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2049e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9702
# Epoch 220/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8813e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9702
# Epoch 221/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0057e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9702
# Epoch 222/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1285e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9715
# Epoch 223/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7728e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9715
# Epoch 224/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5939e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9702
# Epoch 225/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1816e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9715
# Epoch 226/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.7827e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9715
# Epoch 227/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8549e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9715
# Epoch 228/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6644e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9690
# Epoch 229/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9594e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9702
# Epoch 230/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5983e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9728
# Epoch 231/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.5524e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9728
# Epoch 232/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2825e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9728
# Epoch 233/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8916e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9702
# Epoch 234/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.5056e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9702
# Epoch 235/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4438e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9715
# Epoch 236/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6231e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9715
# Epoch 237/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4371e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9715
# Epoch 238/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.5137e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9690
# Epoch 239/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4266e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9728
# Epoch 240/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3847e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9728
# Epoch 241/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2478e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9715
# Epoch 242/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3306e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9702
# Epoch 243/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3006e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9702
# Epoch 244/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.5318e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9715
# Epoch 245/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1553e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 246/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1197e-04 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9702
# Epoch 247/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3626e-04 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 0.9702
# Epoch 248/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1680e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9715
# Epoch 249/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1487e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9702
# Epoch 250/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3014e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9728
# Epoch 251/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9829e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9728
# Epoch 252/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1292e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.9715
# Epoch 253/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0765e-04 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9715
# Epoch 254/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1334e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9728
# Epoch 255/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0301e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9728
# Epoch 256/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0609e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9715
# Epoch 257/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8428e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9715
# Epoch 258/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8049e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9715
# Epoch 259/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8123e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9715
# Epoch 260/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0292e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9728
# Epoch 261/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1080e-04 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 0.9702
# Epoch 262/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7502e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9715
# Epoch 263/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9459e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9702
# Epoch 264/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0743e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9702
# Epoch 265/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1261e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9702
# Epoch 266/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7273e-04 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9715
# Epoch 267/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9160e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9715
# Epoch 268/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6932e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9728
# Epoch 269/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8849e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9715
# Epoch 270/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0383e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9728
# Epoch 271/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7603e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9728
# Epoch 272/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8974e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9715
# Epoch 273/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6576e-04 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9715
# Epoch 274/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7602e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9715
# Epoch 275/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6761e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9728
# Epoch 276/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5739e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9728
# Epoch 277/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5626e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9728
# Epoch 278/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6063e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9702
# Epoch 279/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5932e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9715
# Epoch 280/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7466e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9715
# Epoch 281/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6027e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9715
# Epoch 282/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6509e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9715
# Epoch 283/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.5116e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9715
# Epoch 284/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3731e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9715
# Epoch 285/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.4940e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9715
# Epoch 286/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3869e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9715
# Epoch 287/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4156e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9715
# Epoch 288/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.5492e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9728
# Epoch 289/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4718e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9728
# Epoch 290/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.4442e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9728
# Epoch 291/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4340e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9715
# Epoch 292/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4700e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9728
# Epoch 293/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3768e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9715
# Epoch 294/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3121e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9715
# Epoch 295/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4959e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9715
# Epoch 296/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3321e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9728
# Epoch 297/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4941e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9728
# Epoch 298/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4133e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9728
# Epoch 299/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3590e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9728
# Epoch 300/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3413e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9728
# Epoch 301/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3495e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9728
# Epoch 302/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3452e-04 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9728
# Epoch 303/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3205e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9728
# Epoch 304/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.2865e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9715
# Epoch 305/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.1222e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9715
# Epoch 306/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.2377e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9715
# Epoch 307/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3258e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9702
# Epoch 308/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.2247e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9715
# Epoch 309/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.1564e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9715
# Epoch 310/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.1710e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9715
# Epoch 311/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.1351e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9702
# Epoch 312/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.1004e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9715
# Epoch 313/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.1475e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9728
# Epoch 314/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.1457e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9715
# Epoch 315/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.0440e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9715
# Epoch 316/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.0723e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9715
# Epoch 317/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.0216e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9715
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.5354e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9754
# Epoch 1898/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0336e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9741
# Epoch 1899/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5407e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9754
# Epoch 1900/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7779e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9754
# Epoch 1901/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7926e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9754
# Epoch 1902/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1057e-07 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9754
# Epoch 1903/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.5292e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9728
# Epoch 1904/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.9482e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9728
# Epoch 1905/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6052e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9728
# Epoch 1906/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7463e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9728
# Epoch 1907/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7101e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9728
# Epoch 1908/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8295e-07 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9728
# Epoch 1909/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5191e-07 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9728
# Epoch 1910/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7028e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9728
# Epoch 1911/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6427e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9728
# Epoch 1912/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4517e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9728
# Epoch 1913/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4081e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9741
# Epoch 1914/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4367e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9741
# Epoch 1915/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7121e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9741
# Epoch 1916/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6034e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9741
# Epoch 1917/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8199e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9741
# Epoch 1918/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3734e-07 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9741
# Epoch 1919/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6824e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9741
# Epoch 1920/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5164e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9741
# Epoch 1921/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7071e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9741
# Epoch 1922/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1838e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9741
# Epoch 1923/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6177e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9741
# Epoch 1924/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3400e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9741
# Epoch 1925/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8530e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9741
# Epoch 1926/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4790e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9741
# Epoch 1927/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7456e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9741
# Epoch 1928/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0113e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9741
# Epoch 1929/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8619e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9741
# Epoch 1930/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7933e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9741
# Epoch 1931/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7637e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9741
# Epoch 1932/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3481e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9741
# Epoch 1933/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8311e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9741
# Epoch 1934/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 1.5626e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9741
# Epoch 1935/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1589e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9741
# Epoch 1936/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3287e-07 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9741
# Epoch 1937/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7144e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9741
# Epoch 1938/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7017e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9741
# Epoch 1939/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5599e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9741
# Epoch 1940/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5726e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9741
# Epoch 1941/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6605e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9754
# Epoch 1942/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5025e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9741
# Epoch 1943/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8592e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9754
# Epoch 1944/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4540e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9754
# Epoch 1945/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7032e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9754
# Epoch 1946/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2813e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9741
# Epoch 1947/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7895e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9741
# Epoch 1948/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3700e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9741
# Epoch 1949/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6551e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9741
# Epoch 1950/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4964e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9741
# Epoch 1951/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4320e-07 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9741
# Epoch 1952/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8977e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9741
# Epoch 1953/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6585e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9741
# Epoch 1954/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4059e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9741
# Epoch 1955/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4274e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9741
# Epoch 1956/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6073e-07 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9741
# Epoch 1957/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7768e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9741
# Epoch 1958/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6566e-07 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9741
# Epoch 1959/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6215e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9741
# Epoch 1960/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8180e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9741
# Epoch 1961/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8422e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9741
# Epoch 1962/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6058e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9741
# Epoch 1963/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7668e-07 - accuracy: 1.0000 - val_loss: 0.2013 - val_accuracy: 0.9741
# Epoch 1964/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6277e-07 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9741
# Epoch 1965/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6685e-07 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9741
# Epoch 1966/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4632e-07 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9741
# Epoch 1967/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7332e-07 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9741
# Epoch 1968/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.4390e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9741
# Epoch 1969/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5322e-07 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9741
# Epoch 1970/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6943e-07 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9754
# Epoch 1971/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5888e-07 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9754
# Epoch 1972/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5453e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9741
# Epoch 1973/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7583e-07 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9741
# Epoch 1974/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5788e-07 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9741
# Epoch 1975/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6216e-07 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9754
# Epoch 1976/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 1.3204e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9741
# Epoch 1977/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.3596e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9741
# Epoch 1978/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5707e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9741
# Epoch 1979/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5584e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9741
# Epoch 1980/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.9840e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9741
# Epoch 1981/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.6863e-07 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9741
# Epoch 1982/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.4783e-07 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9741
# Epoch 1983/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.7086e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9741
# Epoch 1984/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8838e-07 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9741
# Epoch 1985/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 1.7941e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9741
# Epoch 1986/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.5149e-07 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9741
# Epoch 1987/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8241e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9741
# Epoch 1988/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7490e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9741
# Epoch 1989/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.5118e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9741
# Epoch 1990/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6620e-07 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9741
# Epoch 1991/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9251e-07 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9741
# Epoch 1992/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.5776e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9741
# Epoch 1993/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9139e-07 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9741
# Epoch 1994/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.5726e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9741
# Epoch 1995/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.3862e-07 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9741
# Epoch 1996/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6485e-07 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9754
# Epoch 1997/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.1424e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9754
# Epoch 1998/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7124e-07 - accuracy: 1.0000 - val_loss: 0.2004 - val_accuracy: 0.9754
# Epoch 1999/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4129e-07 - accuracy: 1.0000 - val_loss: 0.2023 - val_accuracy: 0.9754
# Epoch 2000/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.5299e-07 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9754
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 321ms/step - loss: 0.8828 - accuracy: 0.8489
# test_indoor_ds_results:test loss, test acc: [0.8828445076942444, 0.848940908908844]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 422ms/step - loss: 2.4367 - accuracy: 0.7436
# test_outdoor_ds_results:test loss, test acc: [2.436694860458374, 0.743630588054657]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 199ms/step - loss: 2.6381 - accuracy: 0.7022
# test_belt_ds_results:test loss, test acc: [2.6381077766418457, 0.7021758556365967]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 138ms/step - loss: 0.6070 - accuracy: 0.8423
# 50/50 [==============================] - 7s 138ms/step - loss: 1.5101 - accuracy: 0.7414
# 35/35 [==============================] - 5s 138ms/step - loss: 1.7404 - accuracy: 0.6840
# Epoch200
#  test_indoor_acc=0.8422519564628601
#  test_outdoor_acc=0.7414012551307678
#  test_belt_acc=0.6840435266494751
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6614 - accuracy: 0.8406
# 50/50 [==============================] - 7s 135ms/step - loss: 1.7065 - accuracy: 0.7430
# 35/35 [==============================] - 5s 135ms/step - loss: 1.9224 - accuracy: 0.6940
# Epoch400
#  test_indoor_acc=0.8405796885490417
#  test_outdoor_acc=0.7429936528205872
#  test_belt_acc=0.6940163373947144
# 29/29 [==============================] - 7s 134ms/step - loss: 0.7182 - accuracy: 0.8450
# 50/50 [==============================] - 7s 134ms/step - loss: 1.8700 - accuracy: 0.7449
# 35/35 [==============================] - 5s 135ms/step - loss: 2.0967 - accuracy: 0.6963
# Epoch600
#  test_indoor_acc=0.8450390100479126
#  test_outdoor_acc=0.7449044585227966
#  test_belt_acc=0.6962828636169434
# 29/29 [==============================] - 5s 132ms/step - loss: 0.7557 - accuracy: 0.8473
# 50/50 [==============================] - 7s 134ms/step - loss: 2.0338 - accuracy: 0.7436
# 35/35 [==============================] - 5s 134ms/step - loss: 2.2360 - accuracy: 0.7008
# Epoch800
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.743630588054657
#  test_belt_acc=0.7008159756660461
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8016 - accuracy: 0.8473
# 50/50 [==============================] - 7s 135ms/step - loss: 2.1678 - accuracy: 0.7449
# 35/35 [==============================] - 5s 136ms/step - loss: 2.3866 - accuracy: 0.6967
# Epoch1000
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7449044585227966
#  test_belt_acc=0.6967361569404602
# 29/29 [==============================] - 6s 132ms/step - loss: 0.8260 - accuracy: 0.8467
# 50/50 [==============================] - 7s 134ms/step - loss: 2.2359 - accuracy: 0.7465
# 35/35 [==============================] - 5s 134ms/step - loss: 2.4475 - accuracy: 0.6999
# Epoch1200
#  test_indoor_acc=0.846711277961731
#  test_outdoor_acc=0.7464967966079712
#  test_belt_acc=0.6999093294143677
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8414 - accuracy: 0.8473
# 50/50 [==============================] - 7s 136ms/step - loss: 2.3086 - accuracy: 0.7459
# 35/35 [==============================] - 5s 136ms/step - loss: 2.5025 - accuracy: 0.7053
# Epoch1400
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7458598613739014
#  test_belt_acc=0.7053490281105042
# 29/29 [==============================] - 5s 131ms/step - loss: 0.8457 - accuracy: 0.8501
# 50/50 [==============================] - 7s 133ms/step - loss: 2.3596 - accuracy: 0.7449
# 35/35 [==============================] - 5s 133ms/step - loss: 2.5555 - accuracy: 0.7031
# Epoch1600
#  test_indoor_acc=0.8500557541847229
#  test_outdoor_acc=0.7449044585227966
#  test_belt_acc=0.7030825018882751
# 29/29 [==============================] - 6s 132ms/step - loss: 0.8678 - accuracy: 0.8495
# 50/50 [==============================] - 7s 134ms/step - loss: 2.3935 - accuracy: 0.7443
# 35/35 [==============================] - 5s 134ms/step - loss: 2.5836 - accuracy: 0.7035
# Epoch1800
#  test_indoor_acc=0.8494983315467834
#  test_outdoor_acc=0.7442675232887268
#  test_belt_acc=0.703535795211792
# 29/29 [==============================] - 5s 132ms/step - loss: 0.8828 - accuracy: 0.8489
# 50/50 [==============================] - 7s 134ms/step - loss: 2.4367 - accuracy: 0.7436
# 35/35 [==============================] - 5s 135ms/step - loss: 2.6381 - accuracy: 0.7022
# Epoch2000
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.743630588054657
#  test_belt_acc=0.7021758556365967

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.766159196694692
# max index -> 6
# The [Epoch] of max acc -> 1400

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8422519564628601,
#  0.8405796885490417,
#  0.8450390100479126,
#  0.8472687005996704,
#  0.8472687005996704,
#  0.846711277961731,
#  0.8472687005996704,
#  0.8500557541847229,
#  0.8494983315467834,
#  0.848940908908844]

# %%
test_outdoor_acc
# Out:
# [0.7414012551307678,
#  0.7429936528205872,
#  0.7449044585227966,
#  0.743630588054657,
#  0.7449044585227966,
#  0.7464967966079712,
#  0.7458598613739014,
#  0.7449044585227966,
#  0.7442675232887268,
#  0.743630588054657]

# %%
test_belt_acc
# Out:
# [0.6840435266494751,
#  0.6940163373947144,
#  0.6962828636169434,
#  0.7008159756660461,
#  0.6967361569404602,
#  0.6999093294143677,
#  0.7053490281105042,
#  0.7030825018882751,
#  0.703535795211792,
#  0.7021758556365967]

# %%
test_indoor_loss
# Out:
# [0.6070491075515747,
#  0.6614090204238892,
#  0.7181721329689026,
#  0.7557194232940674,
#  0.8016096353530884,
#  0.8260431289672852,
#  0.8413710594177246,
#  0.8457046747207642,
#  0.8677531480789185,
#  0.8828445076942444]

# %%
test_outdoor_loss
# Out:
# [1.510145664215088,
#  1.7065383195877075,
#  1.8700156211853027,
#  2.0337698459625244,
#  2.1677639484405518,
#  2.235944986343384,
#  2.3086183071136475,
#  2.3596251010894775,
#  2.3934521675109863,
#  2.436694860458374]

# %%
test_belt_loss
# Out:
# [1.7404320240020752,
#  1.9224226474761963,
#  2.096748113632202,
#  2.2360172271728516,
#  2.3865575790405273,
#  2.447511672973633,
#  2.502500295639038,
#  2.5555009841918945,
#  2.5835659503936768,
#  2.6381077766418457]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.95.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5377
# FP=1763
# acc=0.7530812324929972
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 58.620689655172406%
# 2WayConnectorforFoley acc = 91.83673469387756%
# 2WayFoleyCatheter acc = 71.64179104477611%
# 3WayConnectorforFoley acc = 88.88888888888889%
# 3Waystopcock acc = 97.2972972972973%
# AlcoholBottle acc = 86.875%
# AlcoholPad acc = 49.2063492063492%
# BootCover acc = 62.048192771084345%
# CottonBall acc = 79.64071856287424%
# CottonSwap acc = 64.33566433566433%
# Dilator acc = 68.37606837606837%
# DisposableInfusionSet acc = 57.52212389380531%
# ExtensionTube acc = 26.01626016260163%
# FaceShield acc = 80.8641975308642%
# FrontLoadSyringe acc = 51.32743362831859%
# GauzePad acc = 58.52272727272727%
# Glove acc = 79.76190476190477%
# GuideWire acc = 33.035714285714285%
# LiquidBottle acc = 64.50381679389314%
# Mask acc = 95.32467532467533%
# NGTube acc = 42.58064516129032%
# NasalCannula acc = 66.3716814159292%
# Needle acc = 91.07142857142857%
# OxygenMask acc = 91.72932330827066%
# PPESuit acc = 91.12903225806451%
# PharmaceuticalProduct acc = 57.242990654205606%
# Pill acc = 97.3389355742297%
# PillBottle acc = 85.27131782945736%
# PrefilledHumidifier acc = 79.48717948717949%
# PressureConnectingTube acc = 61.06870229007634%
# ReusableHumidifier acc = 70.33898305084746%
# SodiumChlorideBag acc = 88.9763779527559%
# SterileHumidifierAdapter acc = 81.81818181818183%
# SurgicalBlade acc = 83.1858407079646%
# SurgicalCap acc = 90.990990990991%
# SurgicalSuit acc = 40.15151515151515%
# Syringe acc = 98.09885931558935%
# TrachealTube acc = 41.284403669724774%
# UrineBag acc = 70.83333333333334%
# Vaccinebottle acc = 83.09859154929578%
# WingedInfusionSet acc = 64.91228070175438%
#
#
#
# all_avg_eachclass = 71.77138642143031%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 68,   0,   0, ...,   0,   5,   0],
#        [  1, 135,   0, ...,   0,   1,   0],
#        [  0,   0,  96, ...,   0,   1,  14],
#        ...,
#        [  0,   0,   0, ...,  85,   0,   0],
#        [  0,   0,   0, ...,   0, 177,   0],
#        [  0,   0,   0, ...,   1,   1,  74]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[58.62068966,  0.        ,  0.        , ...,  0.        ,
#          4.31034483,  0.        ],
#        [ 0.68027211, 91.83673469,  0.        , ...,  0.        ,
#          0.68027211,  0.        ],
#        [ 0.        ,  0.        , 71.64179104, ...,  0.        ,
#          0.74626866, 10.44776119],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 70.83333333,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         83.09859155,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.87719298,
#          0.87719298, 64.9122807 ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
