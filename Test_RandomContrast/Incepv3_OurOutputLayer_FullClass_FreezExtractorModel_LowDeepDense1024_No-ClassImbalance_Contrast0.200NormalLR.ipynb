# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  #layers.RandomRotation(0.50),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  layers.RandomContrast(0.200),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 334ms/step - loss: 1.3620 - accuracy: 0.6430 - val_loss: 0.4502 - val_accuracy: 0.8732
# Epoch 2/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.3237 - accuracy: 0.9047 - val_loss: 0.3143 - val_accuracy: 0.9146
# Epoch 3/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.1704 - accuracy: 0.9590 - val_loss: 0.2083 - val_accuracy: 0.9444
# Epoch 4/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1052 - accuracy: 0.9771 - val_loss: 0.1616 - val_accuracy: 0.9560
# Epoch 5/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0699 - accuracy: 0.9842 - val_loss: 0.1606 - val_accuracy: 0.9612
# Epoch 6/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0556 - accuracy: 0.9864 - val_loss: 0.1848 - val_accuracy: 0.9457
# Epoch 7/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0407 - accuracy: 0.9935 - val_loss: 0.1788 - val_accuracy: 0.9534
# Epoch 8/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0297 - accuracy: 0.9952 - val_loss: 0.1577 - val_accuracy: 0.9457
# Epoch 9/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0206 - accuracy: 0.9971 - val_loss: 0.1304 - val_accuracy: 0.9625
# Epoch 10/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0135 - accuracy: 0.9990 - val_loss: 0.1393 - val_accuracy: 0.9560
# Epoch 11/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0135 - accuracy: 0.9981 - val_loss: 0.1499 - val_accuracy: 0.9534
# Epoch 12/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0100 - accuracy: 0.9997 - val_loss: 0.1291 - val_accuracy: 0.9638
# Epoch 13/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0125 - accuracy: 0.9977 - val_loss: 0.1379 - val_accuracy: 0.9573
# Epoch 14/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.1393 - val_accuracy: 0.9560
# Epoch 15/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9651
# Epoch 16/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9599
# Epoch 17/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.1237 - val_accuracy: 0.9625
# Epoch 18/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9664
# Epoch 19/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9690
# Epoch 20/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9664
# Epoch 21/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 22/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 23/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9651
# Epoch 24/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9677
# Epoch 25/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9638
# Epoch 26/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9690
# Epoch 27/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9690
# Epoch 28/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9702
# Epoch 29/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9664
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 30/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9664
# Epoch 31/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.8124e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9664
# Epoch 32/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0749e-04 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9651
# Epoch 33/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0146e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9702
# Epoch 34/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3475e-04 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9677
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 35/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.9101e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9677
# Epoch 36/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.5602e-04 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9690
# Epoch 37/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4951e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9690
# Epoch 38/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.4644e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9690
# Epoch 39/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2884e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 40/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.9146e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 41/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.8931e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 42/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0700e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 43/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2809e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 44/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6950e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 45/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7548e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 46/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6401e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 47/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.8908e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 48/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4749e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 49/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0522e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 50/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5970e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 51/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.8541e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 52/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.9210e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 53/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.9697e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 54/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6678e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9677
# Epoch 55/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7581e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 56/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7572e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 57/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2755e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 58/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.7858e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 59/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.8024e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 60/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2976e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 61/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3748e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 62/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0052e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 63/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7975e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 64/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4765e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 65/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.4280e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 66/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7245e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 67/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.1620e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 68/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2011e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9690
# Epoch 69/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6847e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 70/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4882e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 71/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0957e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 72/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4585e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 73/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.1723e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 74/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3134e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 75/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1257e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9690
# Epoch 76/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4998e-04 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9690
# Epoch 77/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.5388e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 78/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.6397e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 79/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.6531e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 80/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3255e-04 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9690
# Epoch 81/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.7270e-04 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9690
# Epoch 82/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.6808e-04 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9690
# Epoch 83/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1839e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9690
# Epoch 84/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9675e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 85/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.6620e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9690
# Epoch 86/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9121e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9690
# Epoch 87/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0803e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 88/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.7757e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 89/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2366e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9690
# Epoch 90/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.7701e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 91/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3430e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9690
# Epoch 92/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9344e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 93/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.3856e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9690
# Epoch 94/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3126e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 95/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 8.4495e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 96/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.7190e-04 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9677
# Epoch 97/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1843e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 98/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.9355e-04 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9677
# Epoch 99/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.3071e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 100/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3449e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9702
# Epoch 101/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4735e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9690
# Epoch 102/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.6567e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 103/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.7198e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9690
# Epoch 104/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5482e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 105/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.8103e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9702
# Epoch 106/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.8725e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9690
# Epoch 107/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.9044e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9690
# Epoch 108/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.9842e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 109/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1176e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9690
# Epoch 110/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.8817e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9690
# Epoch 111/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0927e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9690
# Epoch 112/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.7014e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9690
# Epoch 113/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.6411e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9690
# Epoch 114/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.1810e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9690
# Epoch 115/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.2156e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 116/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.1416e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9690
# Epoch 117/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0291e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9690
# Epoch 118/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.1522e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9690
# Epoch 119/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.9166e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9690
# Epoch 120/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0784e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9690
# Epoch 121/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4795e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9690
# Epoch 122/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5788e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9702
# Epoch 123/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.1099e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9690
# Epoch 124/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.2969e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9702
# Epoch 125/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.7262e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9690
# Epoch 126/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.1512e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9690
# Epoch 127/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.8771e-04 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9690
# Epoch 128/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3725e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9677
# Epoch 129/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.8837e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9677
# Epoch 130/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.7596e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9677
# Epoch 131/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.5839e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9690
# Epoch 132/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 7.5796e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9702
# Epoch 133/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.3987e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9690
# Epoch 134/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.9204e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9690
# Epoch 135/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.8724e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9702
# Epoch 136/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5032e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9715
# Epoch 137/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.6541e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9690
# Epoch 138/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.2918e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9690
# Epoch 139/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.5464e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9690
# Epoch 140/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.8204e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9690
# Epoch 141/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9586e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9690
# Epoch 142/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.6945e-04 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9677
# Epoch 143/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.8705e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9690
# Epoch 144/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.0216e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9702
# Epoch 145/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 6.4792e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9690
# Epoch 146/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.1641e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9690
# Epoch 147/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.6316e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9702
# Epoch 148/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9214e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9702
# Epoch 149/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.3074e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9690
# Epoch 150/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.8726e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9690
# Epoch 151/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.7359e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9690
# Epoch 152/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6834e-04 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9690
# Epoch 153/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.1408e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9677
# Epoch 154/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.8916e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9702
# Epoch 155/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9841e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9690
# Epoch 156/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.5652e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9690
# Epoch 157/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.8041e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9690
# Epoch 158/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.7445e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9677
# Epoch 159/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.5887e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9690
# Epoch 160/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6666e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9690
# Epoch 161/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.9396e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9690
# Epoch 162/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9058e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9690
# Epoch 163/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9612e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9677
# Epoch 164/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.0714e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9690
# Epoch 165/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.3846e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9677
# Epoch 166/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.7056e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9677
# Epoch 167/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6028e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9702
# Epoch 168/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.3583e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9677
# Epoch 169/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.7043e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9677
# Epoch 170/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6508e-04 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9702
# Epoch 171/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.3043e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9702
# Epoch 172/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 5.6347e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9690
# Epoch 173/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 5.6657e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9690
# Epoch 174/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.5814e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9690
# Epoch 175/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 5.3774e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9690
# Epoch 176/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.0814e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9690
# Epoch 177/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.2344e-04 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9702
# Epoch 178/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.7994e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9690
# Epoch 179/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.2715e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9677
# Epoch 180/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.8193e-04 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9690
# Epoch 181/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.8495e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9690
# Epoch 182/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.4091e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9690
# Epoch 183/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.8086e-04 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9702
# Epoch 184/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.7092e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9702
# Epoch 185/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.8899e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9690
# Epoch 186/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.4950e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9702
# Epoch 187/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.1303e-04 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9702
# Epoch 188/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.1171e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9702
# Epoch 189/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.1163e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9702
# Epoch 190/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.3529e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9702
# Epoch 191/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.9337e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9690
# Epoch 192/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.3824e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9702
# Epoch 193/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.8282e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9702
# Epoch 194/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.2750e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9715
# Epoch 195/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.4837e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9702
# Epoch 196/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.6323e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9702
# Epoch 197/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.2979e-04 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9690
# Epoch 198/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.0858e-04 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9690
# Epoch 199/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.2328e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9690
# Epoch 200/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.4937e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9702
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.3371e-04 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9702
# Epoch 202/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.4904e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9715
# Epoch 203/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.3338e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9715
# Epoch 204/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.0801e-04 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9715
# Epoch 205/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 3.9901e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9702
# Epoch 206/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 3.9741e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9702
# Epoch 207/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 4.1182e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9690
# Epoch 208/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.6960e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9702
# Epoch 209/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.1805e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9702
# Epoch 210/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.7518e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9702
# Epoch 211/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.7446e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9702
# Epoch 212/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.7033e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9702
# Epoch 213/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.8683e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9702
# Epoch 214/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.8524e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9702
# Epoch 215/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.5628e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9702
# Epoch 216/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.7364e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9702
# Epoch 217/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.7737e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9702
# Epoch 218/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.6369e-04 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9702
# Epoch 219/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.3076e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9702
# Epoch 220/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.5570e-04 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9702
# Epoch 221/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.3479e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9702
# Epoch 222/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.3620e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9702
# Epoch 223/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.2965e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9702
# Epoch 224/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.2078e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9702
# Epoch 225/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.6463e-04 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9702
# Epoch 226/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.4452e-04 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9690
# Epoch 227/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.5104e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9702
# Epoch 228/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.4608e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9715
# Epoch 229/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.1529e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9702
# Epoch 230/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.3573e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9664
# Epoch 231/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.1466e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9715
# Epoch 232/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.0890e-04 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9690
# Epoch 233/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.8511e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9702
# Epoch 234/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.4192e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9702
# Epoch 235/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.9423e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9702
# Epoch 236/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.0676e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9702
# Epoch 237/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.0983e-04 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9702
# Epoch 238/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6500e-04 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9702
# Epoch 239/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.8106e-04 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 0.9702
# Epoch 240/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.0777e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9702
# Epoch 241/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.9940e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9702
# Epoch 242/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 2.8151e-04 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9702
# Epoch 243/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6044e-04 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9702
# Epoch 244/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.9174e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9702
# Epoch 245/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6155e-04 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9702
# Epoch 246/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6730e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9702
# Epoch 247/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.8930e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9702
# Epoch 248/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6220e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9702
# Epoch 249/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.1655e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9715
# Epoch 250/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.5817e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9715
# Epoch 251/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6410e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9715
# Epoch 252/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 2.4304e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9715
# Epoch 253/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.3773e-04 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9715
# Epoch 254/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6146e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9715
# Epoch 255/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.5787e-04 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9702
# Epoch 256/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.4519e-04 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 0.9715
# Epoch 257/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2313e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9702
# Epoch 258/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.3567e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9702
# Epoch 259/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.3241e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9715
# Epoch 260/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.4317e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9728
# Epoch 261/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.3223e-04 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9702
# Epoch 262/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.1943e-04 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9690
# Epoch 263/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.5239e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9690
# Epoch 264/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6512e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9677
# Epoch 265/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.4492e-04 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9702
# Epoch 266/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0862e-04 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9702
# Epoch 267/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9515e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9702
# Epoch 268/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2103e-04 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9702
# Epoch 269/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2895e-04 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 0.9702
# Epoch 270/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.4261e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9702
# Epoch 271/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2673e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9702
# Epoch 272/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.3138e-04 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9702
# Epoch 273/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0809e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9690
# Epoch 274/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0513e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9702
# Epoch 275/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2556e-04 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9702
# Epoch 276/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2472e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9702
# Epoch 277/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9946e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9702
# Epoch 278/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8446e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 279/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0714e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9715
# Epoch 280/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8678e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9715
# Epoch 281/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9146e-04 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 0.9715
# Epoch 282/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7709e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9702
# Epoch 283/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8984e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9702
# Epoch 284/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7064e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9702
# Epoch 285/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7849e-04 - accuracy: 1.0000 - val_loss: 0.1297 - val_accuracy: 0.9702
# Epoch 286/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7862e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9715
# Epoch 287/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9553e-04 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9715
# Epoch 288/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9794e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9677
# Epoch 289/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6903e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9702
# Epoch 290/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9840e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9702
# Epoch 291/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6679e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9702
# Epoch 292/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7588e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9702
# Epoch 293/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5769e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 294/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7504e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9702
# Epoch 295/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9123e-04 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9702
# Epoch 296/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8087e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9715
# Epoch 297/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8234e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9715
# Epoch 298/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6682e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9690
# Epoch 299/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7198e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9702
# Epoch 300/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5694e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9690
# Epoch 301/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.4279e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9690
# Epoch 302/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6454e-04 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 0.9702
# Epoch 303/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6525e-04 - accuracy: 1.0000 - val_loss: 0.1298 - val_accuracy: 0.9702
# Epoch 304/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5452e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9702
# Epoch 305/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6253e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9702
# Epoch 306/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5592e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9690
# Epoch 307/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.4112e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9702
# Epoch 308/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3338e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9702
# Epoch 309/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5491e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9702
# Epoch 310/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.4180e-04 - accuracy: 1.0000 - val_loss: 0.1341 - val_accuracy: 0.9702
# Epoch 311/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.4165e-04 - accuracy: 1.0000 - val_loss: 0.1338 - val_accuracy: 0.9702
# Epoch 312/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5528e-04 - accuracy: 1.0000 - val_loss: 0.1325 - val_accuracy: 0.9690
# Epoch 313/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3183e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9702
# Epoch 314/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3661e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9702
# Epoch 315/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5201e-04 - accuracy: 1.0000 - val_loss: 0.1333 - val_accuracy: 0.9702
# Epoch 316/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3630e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9690
# Epoch 317/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3705e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9690
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.9764e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9690
# Epoch 1898/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.5378e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9690
# Epoch 1899/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.9085e-07 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9702
# Epoch 1900/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.4943e-07 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9690
# Epoch 1901/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8669e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9690
# Epoch 1902/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9647e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9702
# Epoch 1903/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2101e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9702
# Epoch 1904/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.9659e-07 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9690
# Epoch 1905/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8453e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9677
# Epoch 1906/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.4111e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9677
# Epoch 1907/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0683e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9677
# Epoch 1908/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9774e-07 - accuracy: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9677
# Epoch 1909/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.9062e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9677
# Epoch 1910/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8627e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9677
# Epoch 1911/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8338e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9677
# Epoch 1912/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8896e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9690
# Epoch 1913/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8673e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9690
# Epoch 1914/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.7475e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9690
# Epoch 1915/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0263e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9690
# Epoch 1916/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.2569e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9702
# Epoch 1917/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0903e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9702
# Epoch 1918/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8014e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9702
# Epoch 1919/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5426e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9702
# Epoch 1920/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.3341e-07 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9702
# Epoch 1921/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.0795e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9702
# Epoch 1922/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9944e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9702
# Epoch 1923/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0171e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9702
# Epoch 1924/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5511e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9702
# Epoch 1925/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2802e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9702
# Epoch 1926/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.1030e-07 - accuracy: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9690
# Epoch 1927/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7614e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9690
# Epoch 1928/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0787e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9690
# Epoch 1929/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.9158e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9690
# Epoch 1930/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7618e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9690
# Epoch 1931/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9004e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9690
# Epoch 1932/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7255e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9690
# Epoch 1933/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2798e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9690
# Epoch 1934/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8808e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9690
# Epoch 1935/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8623e-07 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9690
# Epoch 1936/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.0244e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9690
# Epoch 1937/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7941e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9690
# Epoch 1938/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9112e-07 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9690
# Epoch 1939/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.7972e-07 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9690
# Epoch 1940/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8284e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9690
# Epoch 1941/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8107e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9690
# Epoch 1942/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.7398e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9690
# Epoch 1943/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8218e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9702
# Epoch 1944/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.5371e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9702
# Epoch 1945/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.2074e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9702
# Epoch 1946/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0210e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9690
# Epoch 1947/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.6940e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9690
# Epoch 1948/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5626e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9690
# Epoch 1949/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9428e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9690
# Epoch 1950/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.0086e-07 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9690
# Epoch 1951/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5811e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9690
# Epoch 1952/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.4667e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9690
# Epoch 1953/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8322e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9690
# Epoch 1954/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6150e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9690
# Epoch 1955/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.5414e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9690
# Epoch 1956/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6547e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9702
# Epoch 1957/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9786e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9702
# Epoch 1958/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8665e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9690
# Epoch 1959/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.2205e-07 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9702
# Epoch 1960/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9624e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9702
# Epoch 1961/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8072e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9702
# Epoch 1962/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2251e-07 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9702
# Epoch 1963/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0086e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9702
# Epoch 1964/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8958e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9702
# Epoch 1965/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.9027e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9702
# Epoch 1966/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8018e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9702
# Epoch 1967/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.0938e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9702
# Epoch 1968/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6786e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9702
# Epoch 1969/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.6755e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9702
# Epoch 1970/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9520e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9702
# Epoch 1971/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8268e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9702
# Epoch 1972/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6423e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9702
# Epoch 1973/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5626e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9702
# Epoch 1974/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5657e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9702
# Epoch 1975/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7020e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9702
# Epoch 1976/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7020e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9702
# Epoch 1977/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.6501e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9690
# Epoch 1978/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5268e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9690
# Epoch 1979/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7067e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9690
# Epoch 1980/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8107e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9690
# Epoch 1981/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.9651e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9690
# Epoch 1982/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8426e-07 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9702
# Epoch 1983/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.4178e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9702
# Epoch 1984/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.9420e-07 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9690
# Epoch 1985/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.1188e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9690
# Epoch 1986/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7718e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9690
# Epoch 1987/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.7525e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9690
# Epoch 1988/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8654e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9690
# Epoch 1989/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6593e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9690
# Epoch 1990/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.4652e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9690
# Epoch 1991/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6485e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9690
# Epoch 1992/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3138e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9690
# Epoch 1993/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.4254e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9690
# Epoch 1994/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.4683e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9690
# Epoch 1995/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.1688e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9690
# Epoch 1996/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.7972e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9690
# Epoch 1997/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6269e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9690
# Epoch 1998/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.0375e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9690
# Epoch 1999/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.7513e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9690
# Epoch 2000/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.6890e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9690
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 326ms/step - loss: 0.9051 - accuracy: 0.8495
# test_indoor_ds_results:test loss, test acc: [0.9050608277320862, 0.8494983315467834]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 402ms/step - loss: 2.4854 - accuracy: 0.7436
# test_outdoor_ds_results:test loss, test acc: [2.485421895980835, 0.743630588054657]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 196ms/step - loss: 2.6252 - accuracy: 0.7031
# test_belt_ds_results:test loss, test acc: [2.625230312347412, 0.7030825018882751]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 131ms/step - loss: 0.6154 - accuracy: 0.8417
# 50/50 [==============================] - 7s 132ms/step - loss: 1.5136 - accuracy: 0.7401
# 35/35 [==============================] - 5s 132ms/step - loss: 1.6557 - accuracy: 0.6850
# Epoch200
#  test_indoor_acc=0.8416945338249207
#  test_outdoor_acc=0.7401273846626282
#  test_belt_acc=0.6849501132965088
# 29/29 [==============================] - 5s 133ms/step - loss: 0.6787 - accuracy: 0.8434
# 50/50 [==============================] - 7s 134ms/step - loss: 1.7167 - accuracy: 0.7411
# 35/35 [==============================] - 5s 135ms/step - loss: 1.8712 - accuracy: 0.6917
# Epoch400
#  test_indoor_acc=0.843366801738739
#  test_outdoor_acc=0.7410827875137329
#  test_belt_acc=0.6917497515678406
# 29/29 [==============================] - 5s 131ms/step - loss: 0.7369 - accuracy: 0.8423
# 50/50 [==============================] - 7s 133ms/step - loss: 1.9058 - accuracy: 0.7424
# 35/35 [==============================] - 5s 133ms/step - loss: 2.0847 - accuracy: 0.6922
# Epoch600
#  test_indoor_acc=0.8422519564628601
#  test_outdoor_acc=0.7423567175865173
#  test_belt_acc=0.6922031044960022
# 29/29 [==============================] - 5s 131ms/step - loss: 0.7736 - accuracy: 0.8512
# 50/50 [==============================] - 7s 133ms/step - loss: 2.0787 - accuracy: 0.7420
# 35/35 [==============================] - 5s 134ms/step - loss: 2.2070 - accuracy: 0.7040
# Epoch800
#  test_indoor_acc=0.851170539855957
#  test_outdoor_acc=0.7420381903648376
#  test_belt_acc=0.7039891481399536
# 29/29 [==============================] - 5s 131ms/step - loss: 0.8231 - accuracy: 0.8501
# 50/50 [==============================] - 7s 132ms/step - loss: 2.2044 - accuracy: 0.7439
# 35/35 [==============================] - 5s 132ms/step - loss: 2.3434 - accuracy: 0.7026
# Epoch1000
#  test_indoor_acc=0.8500557541847229
#  test_outdoor_acc=0.7439490556716919
#  test_belt_acc=0.7026292085647583
# 29/29 [==============================] - 5s 131ms/step - loss: 0.8412 - accuracy: 0.8517
# 50/50 [==============================] - 7s 132ms/step - loss: 2.3021 - accuracy: 0.7436
# 35/35 [==============================] - 5s 132ms/step - loss: 2.4205 - accuracy: 0.7040
# Epoch1200
#  test_indoor_acc=0.8517279624938965
#  test_outdoor_acc=0.743630588054657
#  test_belt_acc=0.7039891481399536
# 29/29 [==============================] - 5s 132ms/step - loss: 0.8636 - accuracy: 0.8489
# 50/50 [==============================] - 7s 134ms/step - loss: 2.3630 - accuracy: 0.7433
# 35/35 [==============================] - 5s 134ms/step - loss: 2.4866 - accuracy: 0.7044
# Epoch1400
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.7433121204376221
#  test_belt_acc=0.7044424414634705
# 29/29 [==============================] - 5s 131ms/step - loss: 0.8799 - accuracy: 0.8489
# 50/50 [==============================] - 7s 132ms/step - loss: 2.4168 - accuracy: 0.7430
# 35/35 [==============================] - 5s 132ms/step - loss: 2.5476 - accuracy: 0.7040
# Epoch1600
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.7429936528205872
#  test_belt_acc=0.7039891481399536
# 29/29 [==============================] - 5s 131ms/step - loss: 0.8914 - accuracy: 0.8489
# 50/50 [==============================] - 7s 132ms/step - loss: 2.4517 - accuracy: 0.7436
# 35/35 [==============================] - 5s 133ms/step - loss: 2.5656 - accuracy: 0.7044
# Epoch1800
#  test_indoor_acc=0.848940908908844
#  test_outdoor_acc=0.743630588054657
#  test_belt_acc=0.7044424414634705
# 29/29 [==============================] - 5s 132ms/step - loss: 0.9051 - accuracy: 0.8495
# 50/50 [==============================] - 7s 133ms/step - loss: 2.4854 - accuracy: 0.7436
# 35/35 [==============================] - 5s 134ms/step - loss: 2.6252 - accuracy: 0.7031
# Epoch2000
#  test_indoor_acc=0.8494983315467834
#  test_outdoor_acc=0.743630588054657
#  test_belt_acc=0.7030825018882751

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7664492328961691
# max index -> 5
# The [Epoch] of max acc -> 1200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8416945338249207,
#  0.843366801738739,
#  0.8422519564628601,
#  0.851170539855957,
#  0.8500557541847229,
#  0.8517279624938965,
#  0.848940908908844,
#  0.848940908908844,
#  0.848940908908844,
#  0.8494983315467834]

# %%
test_outdoor_acc
# Out:
# [0.7401273846626282,
#  0.7410827875137329,
#  0.7423567175865173,
#  0.7420381903648376,
#  0.7439490556716919,
#  0.743630588054657,
#  0.7433121204376221,
#  0.7429936528205872,
#  0.743630588054657,
#  0.743630588054657]

# %%
test_belt_acc
# Out:
# [0.6849501132965088,
#  0.6917497515678406,
#  0.6922031044960022,
#  0.7039891481399536,
#  0.7026292085647583,
#  0.7039891481399536,
#  0.7044424414634705,
#  0.7039891481399536,
#  0.7044424414634705,
#  0.7030825018882751]

# %%
test_indoor_loss
# Out:
# [0.6153621673583984,
#  0.6786988377571106,
#  0.7368838787078857,
#  0.7736234068870544,
#  0.8231408596038818,
#  0.8412100076675415,
#  0.8635820150375366,
#  0.8799333572387695,
#  0.89142906665802,
#  0.9050608277320862]

# %%
test_outdoor_loss
# Out:
# [1.5135903358459473,
#  1.7166845798492432,
#  1.9057708978652954,
#  2.078655242919922,
#  2.204390287399292,
#  2.302130699157715,
#  2.36297345161438,
#  2.416799783706665,
#  2.4516961574554443,
#  2.485421895980835]

# %%
test_belt_loss
# Out:
# [1.6556848287582397,
#  1.8712035417556763,
#  2.084728717803955,
#  2.207014560699463,
#  2.3434250354766846,
#  2.4204890727996826,
#  2.4865715503692627,
#  2.5475754737854004,
#  2.5655789375305176,
#  2.625230312347412]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11420/3322167109.py in <module>
#       1 # Del dataset memory and reload
#       2 # RAM
# ----> 3 del train_ds
#       4 del val_ds
#       5 del test_indoor_ds
#
# NameError: name 'train_ds' is not defined

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5417
# FP=1723
# acc=0.7586834733893557
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 76.72413793103449%
# 2WayConnectorforFoley acc = 90.47619047619048%
# 2WayFoleyCatheter acc = 76.11940298507463%
# 3WayConnectorforFoley acc = 90.5982905982906%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 84.375%
# AlcoholPad acc = 49.2063492063492%
# BootCover acc = 71.08433734939759%
# CottonBall acc = 81.437125748503%
# CottonSwap acc = 78.32167832167832%
# Dilator acc = 76.06837606837607%
# DisposableInfusionSet acc = 56.63716814159292%
# ExtensionTube acc = 31.70731707317073%
# FaceShield acc = 73.4567901234568%
# FrontLoadSyringe acc = 53.09734513274337%
# GauzePad acc = 63.63636363636363%
# Glove acc = 75.59523809523809%
# GuideWire acc = 29.464285714285715%
# LiquidBottle acc = 62.213740458015266%
# Mask acc = 94.28571428571428%
# NGTube acc = 43.87096774193549%
# NasalCannula acc = 68.14159292035397%
# Needle acc = 80.71428571428572%
# OxygenMask acc = 96.2406015037594%
# PPESuit acc = 95.16129032258065%
# PharmaceuticalProduct acc = 64.25233644859813%
# Pill acc = 96.07843137254902%
# PillBottle acc = 68.9922480620155%
# PrefilledHumidifier acc = 92.3076923076923%
# PressureConnectingTube acc = 61.06870229007634%
# ReusableHumidifier acc = 76.27118644067797%
# SodiumChlorideBag acc = 82.67716535433071%
# SterileHumidifierAdapter acc = 77.27272727272727%
# SurgicalBlade acc = 82.30088495575221%
# SurgicalCap acc = 88.28828828828829%
# SurgicalSuit acc = 47.72727272727273%
# Syringe acc = 94.29657794676805%
# TrachealTube acc = 41.284403669724774%
# UrineBag acc = 60.83333333333333%
# Vaccinebottle acc = 85.44600938967136%
# WingedInfusionSet acc = 71.05263157894737%
#
#
#
# all_avg_eachclass = 72.87518488014427%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 89,   1,   0, ...,   0,   1,   0],
#        [  1, 133,   0, ...,   0,   0,   0],
#        [  0,   0, 102, ...,   0,   2,   7],
#        ...,
#        [  0,   0,   0, ...,  73,   1,   0],
#        [  1,   0,   0, ...,   1, 182,   0],
#        [  0,   0,   0, ...,   0,   0,  81]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[76.72413793,  0.86206897,  0.        , ...,  0.        ,
#          0.86206897,  0.        ],
#        [ 0.68027211, 90.47619048,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 76.11940299, ...,  0.        ,
#          1.49253731,  5.2238806 ],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 60.83333333,
#          0.83333333,  0.        ],
#        [ 0.46948357,  0.        ,  0.        , ...,  0.46948357,
#         85.44600939,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 71.05263158]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
