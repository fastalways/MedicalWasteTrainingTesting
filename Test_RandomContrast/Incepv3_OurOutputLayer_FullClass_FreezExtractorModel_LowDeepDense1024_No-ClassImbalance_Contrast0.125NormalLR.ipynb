# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  #layers.RandomRotation(0.50),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  layers.RandomContrast(0.125),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 328ms/step - loss: 1.2927 - accuracy: 0.6575 - val_loss: 0.5114 - val_accuracy: 0.8344
# Epoch 2/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.3224 - accuracy: 0.9050 - val_loss: 0.3249 - val_accuracy: 0.8965
# Epoch 3/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.1639 - accuracy: 0.9548 - val_loss: 0.2113 - val_accuracy: 0.9392
# Epoch 4/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.1191 - accuracy: 0.9645 - val_loss: 0.1974 - val_accuracy: 0.9366
# Epoch 5/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.1007 - accuracy: 0.9722 - val_loss: 0.2112 - val_accuracy: 0.9366
# Epoch 6/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0759 - accuracy: 0.9793 - val_loss: 0.1744 - val_accuracy: 0.9508
# Epoch 7/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0366 - accuracy: 0.9939 - val_loss: 0.1523 - val_accuracy: 0.9521
# Epoch 8/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0229 - accuracy: 0.9964 - val_loss: 0.1749 - val_accuracy: 0.9495
# Epoch 9/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0255 - accuracy: 0.9952 - val_loss: 0.1350 - val_accuracy: 0.9560
# Epoch 10/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0184 - accuracy: 0.9977 - val_loss: 0.1552 - val_accuracy: 0.9534
# Epoch 11/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0128 - accuracy: 0.9990 - val_loss: 0.1391 - val_accuracy: 0.9599
# Epoch 12/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9612
# Epoch 13/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0106 - accuracy: 0.9987 - val_loss: 0.1347 - val_accuracy: 0.9625
# Epoch 14/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0052 - accuracy: 0.9997 - val_loss: 0.1332 - val_accuracy: 0.9599
# Epoch 15/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9651
# Epoch 16/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9612
# Epoch 17/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9612
# Epoch 18/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9651
# Epoch 19/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9625
# Epoch 20/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9677
# Epoch 21/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9664
# Epoch 22/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9664
# Epoch 23/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9651
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 24/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9677
# Epoch 25/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9677
# Epoch 26/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9677
# Epoch 27/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 28/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9677
# Epoch 29/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9677
# Epoch 30/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 31/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9677
# Epoch 32/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9677
# Epoch 33/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9677
# Epoch 34/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9677
# Epoch 35/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9677
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 36/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9677
# Epoch 37/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9677
# Epoch 38/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9677
# Epoch 39/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9677
# Epoch 40/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9677
# Epoch 41/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9677
# Epoch 42/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9677
# Epoch 43/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 44/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 45/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 46/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9677
# Epoch 47/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 48/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9677
# Epoch 49/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 50/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 51/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 52/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 53/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 54/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 55/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 56/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9677
# Epoch 57/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9677
# Epoch 58/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9677
# Epoch 59/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 60/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9677
# Epoch 61/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 62/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 63/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 64/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 65/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 66/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 67/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 68/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9677
# Epoch 69/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 70/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9677
# Epoch 71/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9677
# Epoch 72/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 73/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 74/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9677
# Epoch 75/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9677
# Epoch 76/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 77/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9677
# Epoch 78/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9677
# Epoch 79/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 80/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9677
# Epoch 81/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9677
# Epoch 82/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 83/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 84/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 85/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 86/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9677
# Epoch 87/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9677
# Epoch 88/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9677
# Epoch 89/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 90/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9677
# Epoch 91/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9664
# Epoch 92/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9677
# Epoch 93/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9664
# Epoch 94/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9677
# Epoch 95/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 96/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9677
# Epoch 97/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9677
# Epoch 98/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 99/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9677
# Epoch 100/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 101/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 102/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9677
# Epoch 103/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9677
# Epoch 104/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9690
# Epoch 105/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.9502e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9677
# Epoch 106/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9677
# Epoch 107/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9677
# Epoch 108/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9677
# Epoch 109/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9677
# Epoch 110/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9677
# Epoch 111/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 8.7860e-04 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 112/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 113/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9677
# Epoch 114/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 115/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 9.9887e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 116/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9677
# Epoch 117/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 118/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9677
# Epoch 119/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9664
# Epoch 120/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9664
# Epoch 121/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9664
# Epoch 122/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9664
# Epoch 123/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 9.6379e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9664
# Epoch 124/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.9935e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9664
# Epoch 125/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 126/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9677
# Epoch 127/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.9105e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9677
# Epoch 128/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.4770e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9664
# Epoch 129/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 130/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.3106e-04 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9664
# Epoch 131/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.5372e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9664
# Epoch 132/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.1918e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9677
# Epoch 133/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.3913e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9677
# Epoch 134/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.6777e-04 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9677
# Epoch 135/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.4002e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9664
# Epoch 136/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.5574e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9664
# Epoch 137/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.3598e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9664
# Epoch 138/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.5444e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9664
# Epoch 139/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.4856e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9664
# Epoch 140/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.0364e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9677
# Epoch 141/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.2594e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9664
# Epoch 142/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.6908e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9664
# Epoch 143/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.6635e-04 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9664
# Epoch 144/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.8582e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9664
# Epoch 145/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.4089e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9664
# Epoch 146/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.4524e-04 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9664
# Epoch 147/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.2462e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9664
# Epoch 148/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.0429e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 149/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.2929e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9664
# Epoch 150/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.4562e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9677
# Epoch 151/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.3322e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9664
# Epoch 152/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.1596e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9664
# Epoch 153/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 7.6285e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9664
# Epoch 154/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2476e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9677
# Epoch 155/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2618e-04 - accuracy: 1.0000 - val_loss: 0.1246 - val_accuracy: 0.9664
# Epoch 156/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.3212e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 157/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.5050e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9677
# Epoch 158/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.0606e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9664
# Epoch 159/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.8561e-04 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9664
# Epoch 160/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.8413e-04 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9664
# Epoch 161/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.0710e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9664
# Epoch 162/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6345e-04 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9677
# Epoch 163/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5794e-04 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9664
# Epoch 164/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6217e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9664
# Epoch 165/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.3820e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9677
# Epoch 166/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.1614e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.9664
# Epoch 167/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.6279e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 168/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0451e-04 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9664
# Epoch 169/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.2119e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9664
# Epoch 170/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8566e-04 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9677
# Epoch 171/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0255e-04 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9677
# Epoch 172/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.2933e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9677
# Epoch 173/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.5007e-04 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 0.9664
# Epoch 174/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6034e-04 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9664
# Epoch 175/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9181e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9677
# Epoch 176/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.9920e-04 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9677
# Epoch 177/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 6.9725e-04 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9677
# Epoch 178/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.7380e-04 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 0.9664
# Epoch 179/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6127e-04 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9664
# Epoch 180/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.8779e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9677
# Epoch 181/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2409e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9677
# Epoch 182/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 7.0189e-04 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 0.9677
# Epoch 183/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.2777e-04 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9677
# Epoch 184/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.6195e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9664
# Epoch 185/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4553e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9664
# Epoch 186/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.1462e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9664
# Epoch 187/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.4654e-04 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 0.9664
# Epoch 188/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0037e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9664
# Epoch 189/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5695e-04 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 0.9677
# Epoch 190/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0998e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9664
# Epoch 191/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3907e-04 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 0.9664
# Epoch 192/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7992e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9664
# Epoch 193/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6716e-04 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9664
# Epoch 194/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.3468e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.9664
# Epoch 195/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.6802e-04 - accuracy: 1.0000 - val_loss: 0.1266 - val_accuracy: 0.9677
# Epoch 196/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.9428e-04 - accuracy: 1.0000 - val_loss: 0.1273 - val_accuracy: 0.9677
# Epoch 197/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.7551e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9664
# Epoch 198/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.8563e-04 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9664
# Epoch 199/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3875e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9677
# Epoch 200/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.1295e-04 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9664
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 171ms/step - loss: 5.4639e-04 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9664
# Epoch 202/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.5903e-04 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 0.9677
# Epoch 203/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3933e-04 - accuracy: 1.0000 - val_loss: 0.1268 - val_accuracy: 0.9664
# Epoch 204/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.1929e-04 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9664
# Epoch 205/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3107e-04 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9664
# Epoch 206/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 6.0780e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9664
# Epoch 207/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7026e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9664
# Epoch 208/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9054e-04 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9664
# Epoch 209/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.3939e-04 - accuracy: 1.0000 - val_loss: 0.1294 - val_accuracy: 0.9664
# Epoch 210/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6823e-04 - accuracy: 1.0000 - val_loss: 0.1301 - val_accuracy: 0.9664
# Epoch 211/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6448e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.9664
# Epoch 212/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9261e-04 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9664
# Epoch 213/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7716e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9677
# Epoch 214/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 5.0565e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9664
# Epoch 215/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.7356e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9664
# Epoch 216/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9883e-04 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 0.9690
# Epoch 217/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8141e-04 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 0.9677
# Epoch 218/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9007e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9677
# Epoch 219/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.8118e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9664
# Epoch 220/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.6288e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9664
# Epoch 221/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.9679e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9677
# Epoch 222/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.3996e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9664
# Epoch 223/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1643e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9677
# Epoch 224/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4112e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9664
# Epoch 225/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1962e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9664
# Epoch 226/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1770e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9677
# Epoch 227/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4347e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9664
# Epoch 228/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.4237e-04 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9677
# Epoch 229/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1691e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9677
# Epoch 230/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.1911e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9677
# Epoch 231/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.0953e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9664
# Epoch 232/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.9573e-04 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9664
# Epoch 233/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2061e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9677
# Epoch 234/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8758e-04 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9677
# Epoch 235/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8520e-04 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9664
# Epoch 236/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.8556e-04 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9664
# Epoch 237/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7657e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9677
# Epoch 238/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2273e-04 - accuracy: 1.0000 - val_loss: 0.1290 - val_accuracy: 0.9677
# Epoch 239/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7569e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9677
# Epoch 240/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5630e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9664
# Epoch 241/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7132e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9664
# Epoch 242/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5597e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9664
# Epoch 243/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2804e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9677
# Epoch 244/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7251e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9664
# Epoch 245/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6571e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9664
# Epoch 246/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.6531e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9664
# Epoch 247/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4881e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9664
# Epoch 248/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4514e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9664
# Epoch 249/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.5022e-04 - accuracy: 1.0000 - val_loss: 0.1328 - val_accuracy: 0.9677
# Epoch 250/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3117e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9690
# Epoch 251/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.7343e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9664
# Epoch 252/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1877e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9677
# Epoch 253/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2929e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9677
# Epoch 254/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4288e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9664
# Epoch 255/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1700e-04 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 0.9664
# Epoch 256/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.3003e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9664
# Epoch 257/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2943e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9677
# Epoch 258/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1442e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9664
# Epoch 259/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8689e-04 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 0.9664
# Epoch 260/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9426e-04 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 0.9664
# Epoch 261/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8752e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9677
# Epoch 262/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1810e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9664
# Epoch 263/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0094e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9664
# Epoch 264/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1740e-04 - accuracy: 1.0000 - val_loss: 0.1299 - val_accuracy: 0.9664
# Epoch 265/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7469e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9664
# Epoch 266/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9309e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9664
# Epoch 267/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7160e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9664
# Epoch 268/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9279e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9664
# Epoch 269/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1768e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9690
# Epoch 270/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1561e-04 - accuracy: 1.0000 - val_loss: 0.1315 - val_accuracy: 0.9677
# Epoch 271/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8628e-04 - accuracy: 1.0000 - val_loss: 0.1316 - val_accuracy: 0.9664
# Epoch 272/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0730e-04 - accuracy: 1.0000 - val_loss: 0.1302 - val_accuracy: 0.9664
# Epoch 273/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7142e-04 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9664
# Epoch 274/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5804e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9664
# Epoch 275/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9709e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9664
# Epoch 276/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4026e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9664
# Epoch 277/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4580e-04 - accuracy: 1.0000 - val_loss: 0.1311 - val_accuracy: 0.9677
# Epoch 278/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7187e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9690
# Epoch 279/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4451e-04 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9664
# Epoch 280/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6354e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.9677
# Epoch 281/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5993e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9664
# Epoch 282/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2981e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9664
# Epoch 283/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6376e-04 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 0.9664
# Epoch 284/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1557e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9664
# Epoch 285/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5529e-04 - accuracy: 1.0000 - val_loss: 0.1326 - val_accuracy: 0.9664
# Epoch 286/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2538e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9664
# Epoch 287/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1866e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9664
# Epoch 288/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4536e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9664
# Epoch 289/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2263e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9664
# Epoch 290/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2535e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9664
# Epoch 291/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4642e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9664
# Epoch 292/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1593e-04 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9664
# Epoch 293/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1981e-04 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9664
# Epoch 294/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2244e-04 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9677
# Epoch 295/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2766e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9664
# Epoch 296/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1379e-04 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9664
# Epoch 297/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3068e-04 - accuracy: 1.0000 - val_loss: 0.1309 - val_accuracy: 0.9664
# Epoch 298/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3649e-04 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 0.9677
# Epoch 299/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4655e-04 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9664
# Epoch 300/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0008e-04 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9664
# Epoch 301/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1397e-04 - accuracy: 1.0000 - val_loss: 0.1327 - val_accuracy: 0.9664
# Epoch 302/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1054e-04 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9664
# Epoch 303/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2404e-04 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9664
# Epoch 304/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9979e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9664
# Epoch 305/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9812e-04 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9677
# Epoch 306/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7904e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9664
# Epoch 307/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1075e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9677
# Epoch 308/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9648e-04 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9677
# Epoch 309/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7813e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9664
# Epoch 310/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0988e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9664
# Epoch 311/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8651e-04 - accuracy: 1.0000 - val_loss: 0.1351 - val_accuracy: 0.9664
# Epoch 312/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8523e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9664
# Epoch 313/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8211e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9664
# Epoch 314/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.7244e-04 - accuracy: 1.0000 - val_loss: 0.1356 - val_accuracy: 0.9664
# Epoch 315/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7947e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9677
# Epoch 316/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7225e-04 - accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9677
# Epoch 317/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7026e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9677
# Epoch 318/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.7084e-04 - accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9664
# Epoch 319/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8028e-04 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9664
# Epoch 320/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6261e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9664
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9967e-07 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9690
# Epoch 1898/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2717e-07 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9690
# Epoch 1899/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0726e-07 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9690
# Epoch 1900/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0737e-07 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9690
# Epoch 1901/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1769e-07 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9690
# Epoch 1902/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2544e-07 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9690
# Epoch 1903/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4342e-07 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.9690
# Epoch 1904/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2024e-07 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9690
# Epoch 1905/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3237e-07 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9690
# Epoch 1906/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4165e-07 - accuracy: 1.0000 - val_loss: 0.2030 - val_accuracy: 0.9690
# Epoch 1907/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9647e-07 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.9690
# Epoch 1908/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5821e-07 - accuracy: 1.0000 - val_loss: 0.2027 - val_accuracy: 0.9690
# Epoch 1909/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7556e-07 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9690
# Epoch 1910/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5582e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1911/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8553e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9690
# Epoch 1912/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7614e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1913/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.4011e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9690
# Epoch 1914/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8507e-07 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9690
# Epoch 1915/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9597e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9690
# Epoch 1916/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.4428e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1917/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8523e-07 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9702
# Epoch 1918/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3079e-07 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9702
# Epoch 1919/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1846e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9702
# Epoch 1920/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9158e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1921/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.6770e-07 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9690
# Epoch 1922/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7787e-07 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9690
# Epoch 1923/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8819e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1924/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0102e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9690
# Epoch 1925/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0175e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1926/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9408e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1927/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1939e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1928/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6435e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1929/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8218e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9690
# Epoch 1930/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9863e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9690
# Epoch 1931/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9382e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1932/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5775e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9690
# Epoch 1933/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7510e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9690
# Epoch 1934/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.5345e-07 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9690
# Epoch 1935/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8677e-07 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9690
# Epoch 1936/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.8850e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9690
# Epoch 1937/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2909e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9690
# Epoch 1938/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2829e-07 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9690
# Epoch 1939/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1666e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1940/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2386e-07 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9690
# Epoch 1941/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3595e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9690
# Epoch 1942/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1373e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1943/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.6924e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1944/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0113e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1945/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2197e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9690
# Epoch 1946/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0279e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9690
# Epoch 1947/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7444e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1948/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.3319e-07 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9690
# Epoch 1949/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2536e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9690
# Epoch 1950/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9362e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1951/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0264e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1952/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9116e-07 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9690
# Epoch 1953/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8157e-07 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9690
# Epoch 1954/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7294e-07 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9690
# Epoch 1955/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0641e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1956/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4081e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1957/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9353e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1958/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2663e-07 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9690
# Epoch 1959/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0441e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1960/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9694e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9690
# Epoch 1961/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7290e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9690
# Epoch 1962/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7313e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1963/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7305e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1964/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2597e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1965/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8700e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1966/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7163e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1967/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8631e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9690
# Epoch 1968/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8773e-07 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9690
# Epoch 1969/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1426e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1970/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8322e-07 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9690
# Epoch 1971/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8453e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1972/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4408e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1973/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0352e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9690
# Epoch 1974/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.8989e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9690
# Epoch 1975/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0267e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9690
# Epoch 1976/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1773e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9690
# Epoch 1977/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.7121e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9690
# Epoch 1978/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.9308e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1979/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.8619e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9690
# Epoch 1980/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.0949e-07 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9690
# Epoch 1981/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.2559e-07 - accuracy: 1.0000 - val_loss: 0.2046 - val_accuracy: 0.9690
# Epoch 1982/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.4552e-07 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9690
# Epoch 1983/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.5871e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9690
# Epoch 1984/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.9794e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1985/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1565e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1986/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 1.9563e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1987/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.8881e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9690
# Epoch 1988/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.7891e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9690
# Epoch 1989/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.9466e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9690
# Epoch 1990/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1650e-07 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9690
# Epoch 1991/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.0895e-07 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9690
# Epoch 1992/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.1750e-07 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9690
# Epoch 1993/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.8257e-07 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9690
# Epoch 1994/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 1.5746e-07 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9690
# Epoch 1995/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 2.3595e-07 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9702
# Epoch 1996/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 1.7899e-07 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9702
# Epoch 1997/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.7013e-07 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9702
# Epoch 1998/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 3.0823e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9690
# Epoch 1999/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.8889e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9690
# Epoch 2000/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 1.9786e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9690
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 355ms/step - loss: 0.8877 - accuracy: 0.8534
# test_indoor_ds_results:test loss, test acc: [0.8876846432685852, 0.8534002304077148]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 437ms/step - loss: 2.4767 - accuracy: 0.7354
# test_outdoor_ds_results:test loss, test acc: [2.4766976833343506, 0.7353503108024597]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 200ms/step - loss: 2.5053 - accuracy: 0.7049
# test_belt_ds_results:test loss, test acc: [2.5052661895751953, 0.7048957347869873]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Contrast125-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 132ms/step - loss: 0.6042 - accuracy: 0.8367
# 50/50 [==============================] - 7s 134ms/step - loss: 1.4979 - accuracy: 0.7363
# 35/35 [==============================] - 5s 134ms/step - loss: 1.5746 - accuracy: 0.6899
# Epoch200
#  test_indoor_acc=0.8366777896881104
#  test_outdoor_acc=0.7363057136535645
#  test_belt_acc=0.6899365186691284
# 29/29 [==============================] - 5s 131ms/step - loss: 0.6640 - accuracy: 0.8411
# 50/50 [==============================] - 7s 133ms/step - loss: 1.7175 - accuracy: 0.7366
# 35/35 [==============================] - 5s 133ms/step - loss: 1.7795 - accuracy: 0.6917
# Epoch400
#  test_indoor_acc=0.8411371111869812
#  test_outdoor_acc=0.7366241812705994
#  test_belt_acc=0.6917497515678406
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7211 - accuracy: 0.8478
# 50/50 [==============================] - 7s 135ms/step - loss: 1.9208 - accuracy: 0.7357
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9534 - accuracy: 0.6972
# Epoch600
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7356687784194946
#  test_belt_acc=0.6971895098686218
# 29/29 [==============================] - 5s 131ms/step - loss: 0.7719 - accuracy: 0.8478
# 50/50 [==============================] - 7s 133ms/step - loss: 2.0596 - accuracy: 0.7369
# 35/35 [==============================] - 5s 134ms/step - loss: 2.1198 - accuracy: 0.6967
# Epoch800
#  test_indoor_acc=0.8478260636329651
#  test_outdoor_acc=0.7369426488876343
#  test_belt_acc=0.6967361569404602
# 29/29 [==============================] - 5s 131ms/step - loss: 0.8041 - accuracy: 0.8512
# 50/50 [==============================] - 7s 133ms/step - loss: 2.1913 - accuracy: 0.7350
# 35/35 [==============================] - 5s 134ms/step - loss: 2.2203 - accuracy: 0.6995
# Epoch1000
#  test_indoor_acc=0.851170539855957
#  test_outdoor_acc=0.7350318431854248
#  test_belt_acc=0.6994560360908508
# 29/29 [==============================] - 7s 132ms/step - loss: 0.8199 - accuracy: 0.8523
# 50/50 [==============================] - 7s 133ms/step - loss: 2.2785 - accuracy: 0.7373
# 35/35 [==============================] - 5s 134ms/step - loss: 2.3205 - accuracy: 0.6999
# Epoch1200
#  test_indoor_acc=0.8522853851318359
#  test_outdoor_acc=0.737261176109314
#  test_belt_acc=0.6999093294143677
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8531 - accuracy: 0.8506
# 50/50 [==============================] - 7s 134ms/step - loss: 2.3396 - accuracy: 0.7357
# 35/35 [==============================] - 5s 135ms/step - loss: 2.3840 - accuracy: 0.7008
# Epoch1400
#  test_indoor_acc=0.8506131768226624
#  test_outdoor_acc=0.7356687784194946
#  test_belt_acc=0.7008159756660461
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8592 - accuracy: 0.8534
# 50/50 [==============================] - 7s 134ms/step - loss: 2.4016 - accuracy: 0.7389
# 35/35 [==============================] - 5s 135ms/step - loss: 2.4251 - accuracy: 0.7035
# Epoch1600
#  test_indoor_acc=0.8534002304077148
#  test_outdoor_acc=0.7388535141944885
#  test_belt_acc=0.703535795211792
# 29/29 [==============================] - 7s 134ms/step - loss: 0.8779 - accuracy: 0.8534
# 50/50 [==============================] - 7s 136ms/step - loss: 2.4304 - accuracy: 0.7379
# 35/35 [==============================] - 5s 136ms/step - loss: 2.4620 - accuracy: 0.7035
# Epoch1800
#  test_indoor_acc=0.8534002304077148
#  test_outdoor_acc=0.7378981113433838
#  test_belt_acc=0.703535795211792
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8877 - accuracy: 0.8534
# 50/50 [==============================] - 7s 135ms/step - loss: 2.4767 - accuracy: 0.7354
# 35/35 [==============================] - 5s 136ms/step - loss: 2.5053 - accuracy: 0.7049
# Epoch2000
#  test_indoor_acc=0.8534002304077148
#  test_outdoor_acc=0.7353503108024597
#  test_belt_acc=0.7048957347869873

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7652631799379984
# max index -> 7
# The [Epoch] of max acc -> 1600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8366777896881104,
#  0.8411371111869812,
#  0.8478260636329651,
#  0.8478260636329651,
#  0.851170539855957,
#  0.8522853851318359,
#  0.8506131768226624,
#  0.8534002304077148,
#  0.8534002304077148,
#  0.8534002304077148]

# %%
test_outdoor_acc
# Out:
# [0.7363057136535645,
#  0.7366241812705994,
#  0.7356687784194946,
#  0.7369426488876343,
#  0.7350318431854248,
#  0.737261176109314,
#  0.7356687784194946,
#  0.7388535141944885,
#  0.7378981113433838,
#  0.7353503108024597]

# %%
test_belt_acc
# Out:
# [0.6899365186691284,
#  0.6917497515678406,
#  0.6971895098686218,
#  0.6967361569404602,
#  0.6994560360908508,
#  0.6999093294143677,
#  0.7008159756660461,
#  0.703535795211792,
#  0.703535795211792,
#  0.7048957347869873]

# %%
test_indoor_loss
# Out:
# [0.6041646003723145,
#  0.6639962196350098,
#  0.721068263053894,
#  0.7718711495399475,
#  0.8040843605995178,
#  0.8198953866958618,
#  0.8530536890029907,
#  0.8591509461402893,
#  0.877895176410675,
#  0.8876846432685852]

# %%
test_outdoor_loss
# Out:
# [1.4979190826416016,
#  1.7175374031066895,
#  1.9208136796951294,
#  2.059633731842041,
#  2.19134783744812,
#  2.2784652709960938,
#  2.339550256729126,
#  2.401552438735962,
#  2.430375099182129,
#  2.4766976833343506]

# %%
test_belt_loss
# Out:
# [1.5745855569839478,
#  1.7794924974441528,
#  1.9533802270889282,
#  2.1197659969329834,
#  2.22031831741333,
#  2.320467233657837,
#  2.3839633464813232,
#  2.425065040588379,
#  2.46201491355896,
#  2.5052661895751953]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5403
# FP=1737
# acc=0.7567226890756302
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 75.0%
# 2WayConnectorforFoley acc = 93.19727891156462%
# 2WayFoleyCatheter acc = 74.6268656716418%
# 3WayConnectorforFoley acc = 93.16239316239316%
# 3Waystopcock acc = 98.1981981981982%
# AlcoholBottle acc = 85.0%
# AlcoholPad acc = 46.03174603174603%
# BootCover acc = 68.67469879518072%
# CottonBall acc = 82.63473053892216%
# CottonSwap acc = 76.92307692307693%
# Dilator acc = 73.50427350427351%
# DisposableInfusionSet acc = 54.86725663716814%
# ExtensionTube acc = 32.52032520325203%
# FaceShield acc = 69.1358024691358%
# FrontLoadSyringe acc = 47.78761061946903%
# GauzePad acc = 66.47727272727273%
# Glove acc = 75.59523809523809%
# GuideWire acc = 34.82142857142857%
# LiquidBottle acc = 62.59541984732825%
# Mask acc = 94.28571428571428%
# NGTube acc = 42.58064516129032%
# NasalCannula acc = 69.02654867256636%
# Needle acc = 82.85714285714286%
# OxygenMask acc = 96.99248120300751%
# PPESuit acc = 95.96774193548387%
# PharmaceuticalProduct acc = 63.78504672897196%
# Pill acc = 96.21848739495799%
# PillBottle acc = 68.21705426356588%
# PrefilledHumidifier acc = 93.16239316239316%
# PressureConnectingTube acc = 58.01526717557252%
# ReusableHumidifier acc = 76.27118644067797%
# SodiumChlorideBag acc = 81.88976377952756%
# SterileHumidifierAdapter acc = 78.18181818181819%
# SurgicalBlade acc = 84.070796460177%
# SurgicalCap acc = 87.38738738738738%
# SurgicalSuit acc = 45.45454545454545%
# Syringe acc = 94.29657794676805%
# TrachealTube acc = 37.61467889908257%
# UrineBag acc = 61.66666666666667%
# Vaccinebottle acc = 84.50704225352112%
# WingedInfusionSet acc = 71.9298245614035%
#
#
#
# all_avg_eachclass = 72.56420553120809%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 87,   0,   0, ...,   0,   0,   0],
#        [  0, 137,   0, ...,   0,   0,   0],
#        [  0,   0, 100, ...,   0,   2,   4],
#        ...,
#        [  0,   0,   0, ...,  74,   0,   0],
#        [  1,   0,   0, ...,   2, 180,   0],
#        [  0,   0,   0, ...,   1,   0,  82]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[75.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 93.19727891,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 74.62686567, ...,  0.        ,
#          1.49253731,  2.98507463],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 61.66666667,
#          0.        ,  0.        ],
#        [ 0.46948357,  0.        ,  0.        , ...,  0.93896714,
#         84.50704225,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.87719298,
#          0.        , 71.92982456]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
