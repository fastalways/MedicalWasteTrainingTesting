# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.40),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 335ms/step - loss: 1.6065 - accuracy: 0.5851 - val_loss: 0.6059 - val_accuracy: 0.8448
# Epoch 2/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.4446 - accuracy: 0.8717 - val_loss: 0.3687 - val_accuracy: 0.8978
# Epoch 3/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.2548 - accuracy: 0.9254 - val_loss: 0.3663 - val_accuracy: 0.8771
# Epoch 4/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.1573 - accuracy: 0.9593 - val_loss: 0.3071 - val_accuracy: 0.8978
# Epoch 5/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.1105 - accuracy: 0.9748 - val_loss: 0.2401 - val_accuracy: 0.9366
# Epoch 6/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0846 - accuracy: 0.9816 - val_loss: 0.2621 - val_accuracy: 0.9237
# Epoch 7/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0617 - accuracy: 0.9864 - val_loss: 0.2661 - val_accuracy: 0.9198
# Epoch 8/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0454 - accuracy: 0.9922 - val_loss: 0.2264 - val_accuracy: 0.9314
# Epoch 9/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0394 - accuracy: 0.9919 - val_loss: 0.2239 - val_accuracy: 0.9301
# Epoch 10/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0328 - accuracy: 0.9932 - val_loss: 0.2247 - val_accuracy: 0.9237
# Epoch 11/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0409 - accuracy: 0.9893 - val_loss: 0.2397 - val_accuracy: 0.9211
# Epoch 12/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0261 - accuracy: 0.9958 - val_loss: 0.1994 - val_accuracy: 0.9470
# Epoch 13/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0185 - accuracy: 0.9981 - val_loss: 0.1999 - val_accuracy: 0.9418
# Epoch 14/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0138 - accuracy: 0.9990 - val_loss: 0.2202 - val_accuracy: 0.9353
# Epoch 15/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0113 - accuracy: 0.9994 - val_loss: 0.1883 - val_accuracy: 0.9457
# Epoch 16/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0078 - accuracy: 0.9997 - val_loss: 0.1747 - val_accuracy: 0.9534
# Epoch 17/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.2298 - val_accuracy: 0.9237
# Epoch 18/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.1624 - val_accuracy: 0.9470
# Epoch 19/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0068 - accuracy: 0.9994 - val_loss: 0.1617 - val_accuracy: 0.9495
# Epoch 20/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9495
# Epoch 21/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0068 - accuracy: 0.9990 - val_loss: 0.1820 - val_accuracy: 0.9405
# Epoch 22/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9457
# Epoch 23/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9547
# Epoch 24/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9547
# Epoch 25/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9573
# Epoch 26/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9573
# Epoch 27/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 28/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9599
# Epoch 29/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 30/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9612
# Epoch 31/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9599
# Epoch 32/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9573
# Epoch 33/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 0.9677
# Epoch 34/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9612
# Epoch 35/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9573
# Epoch 36/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.9750e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9586
# Epoch 37/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9625
# Epoch 38/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9612
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 39/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 9.6131e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9573
# Epoch 40/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2597e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9586
# Epoch 41/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.3011e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9612
# Epoch 42/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.5204e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9599
# Epoch 43/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9833e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 44/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.4188e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 45/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3131e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9612
# Epoch 46/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.3812e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9612
# Epoch 47/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3819e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9599
# Epoch 48/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0945e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 49/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8224e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 50/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0126e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 51/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5480e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 52/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3214e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9612
# Epoch 53/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.9169e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9612
# Epoch 54/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.1618e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9612
# Epoch 55/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.2953e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 56/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.3440e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 57/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7117e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 58/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5592e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9599
# Epoch 59/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0397e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9599
# Epoch 60/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.1900e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 61/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0153e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 62/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7745e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9599
# Epoch 63/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7623e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9599
# Epoch 64/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2648e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 65/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7916e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9599
# Epoch 66/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3560e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 67/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.5157e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9599
# Epoch 68/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5049e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9599
# Epoch 69/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.7245e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 70/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7209e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 71/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3518e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 72/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5635e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 73/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1081e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 74/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.6406e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9599
# Epoch 75/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5401e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9612
# Epoch 76/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7140e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9612
# Epoch 77/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8767e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 78/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2646e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9599
# Epoch 79/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9997e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 80/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.2252e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9599
# Epoch 81/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.6772e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9599
# Epoch 82/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5127e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9599
# Epoch 83/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.1094e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9599
# Epoch 84/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.7227e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9599
# Epoch 85/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.5545e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9599
# Epoch 86/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8883e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9599
# Epoch 87/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.9506e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9612
# Epoch 88/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8812e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9599
# Epoch 89/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 8.3284e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 90/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.9548e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9586
# Epoch 91/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.6699e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9599
# Epoch 92/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5777e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9599
# Epoch 93/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.4458e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 94/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.3242e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 95/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8004e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9599
# Epoch 96/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.4462e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9599
# Epoch 97/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.4965e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 98/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.3496e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9612
# Epoch 99/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8381e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 100/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5765e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 101/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7035e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9599
# Epoch 102/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8263e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 103/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5234e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9599
# Epoch 104/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8337e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9599
# Epoch 105/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5626e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 106/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.8035e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 107/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5676e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 108/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8088e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9599
# Epoch 109/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7465e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9612
# Epoch 110/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7941e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9612
# Epoch 111/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5134e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 112/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.9960e-04 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9612
# Epoch 113/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1086e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9612
# Epoch 114/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0214e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9612
# Epoch 115/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.6391e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9612
# Epoch 116/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0656e-04 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9612
# Epoch 117/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.1758e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9612
# Epoch 118/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.8810e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9599
# Epoch 119/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0551e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9599
# Epoch 120/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.2632e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9612
# Epoch 121/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.7513e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9599
# Epoch 122/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5510e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9612
# Epoch 123/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.2671e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9612
# Epoch 124/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0575e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9599
# Epoch 125/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.9106e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9599
# Epoch 126/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.9771e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9586
# Epoch 127/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0155e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9599
# Epoch 128/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.7733e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9599
# Epoch 129/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 7.0683e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9599
# Epoch 130/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.7060e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9599
# Epoch 131/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0793e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 132/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6427e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9599
# Epoch 133/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.3264e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9612
# Epoch 134/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.9178e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9612
# Epoch 135/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.6618e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9599
# Epoch 136/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0847e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9599
# Epoch 137/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.5954e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9599
# Epoch 138/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.9373e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9599
# Epoch 139/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.9379e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9599
# Epoch 140/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0903e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9586
# Epoch 141/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.9172e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9599
# Epoch 142/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0517e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9586
# Epoch 143/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.8992e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9586
# Epoch 144/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.7858e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9586
# Epoch 145/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7645e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9599
# Epoch 146/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.4692e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9612
# Epoch 147/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7316e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9612
# Epoch 148/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.0279e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9612
# Epoch 149/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.3396e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9612
# Epoch 150/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.4662e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9599
# Epoch 151/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.2994e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9599
# Epoch 152/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.4267e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9612
# Epoch 153/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.5880e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 154/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7690e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9599
# Epoch 155/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.5135e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9599
# Epoch 156/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.2508e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9612
# Epoch 157/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.4257e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9612
# Epoch 158/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.6756e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# Epoch 159/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.0883e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9612
# Epoch 160/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.3726e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9612
# Epoch 161/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.4156e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9612
# Epoch 162/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.5240e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9612
# Epoch 163/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.3451e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9586
# Epoch 164/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.4381e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9599
# Epoch 165/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.8696e-04 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9599
# Epoch 166/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.1891e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9586
# Epoch 167/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.8241e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9612
# Epoch 168/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.1628e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9599
# Epoch 169/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.5172e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9612
# Epoch 170/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 6.0688e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9573
# Epoch 171/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.9323e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9599
# Epoch 172/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.7341e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9586
# Epoch 173/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.7693e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9586
# Epoch 174/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.7222e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 175/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.1996e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9612
# Epoch 176/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.1015e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9612
# Epoch 177/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.9452e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9599
# Epoch 178/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.7362e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9612
# Epoch 179/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.5889e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9612
# Epoch 180/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.5192e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9599
# Epoch 181/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.8843e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9612
# Epoch 182/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.0127e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9599
# Epoch 183/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.5217e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9586
# Epoch 184/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.5522e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9586
# Epoch 185/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.7079e-04 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9586
# Epoch 186/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.4786e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9599
# Epoch 187/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.2950e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9599
# Epoch 188/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.1747e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9612
# Epoch 189/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 5.0451e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9573
# Epoch 190/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.2490e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9586
# Epoch 191/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.2880e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9612
# Epoch 192/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.4436e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9612
# Epoch 193/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.2075e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9599
# Epoch 194/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.5025e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9586
# Epoch 195/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.3398e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9586
# Epoch 196/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.5906e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9599
# Epoch 197/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.9701e-04 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9612
# Epoch 198/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 3.9952e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9612
# Epoch 199/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.7775e-04 - accuracy: 1.0000 - val_loss: 0.1467 - val_accuracy: 0.9625
# Epoch 200/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.2820e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9612
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.96.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.2122e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9625
# Epoch 202/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.6661e-04 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9599
# Epoch 203/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.0519e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9612
# Epoch 204/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.2564e-04 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9599
# Epoch 205/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.4252e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9612
# Epoch 206/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.0222e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9599
# Epoch 207/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.9590e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9586
# Epoch 208/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.0830e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9599
# Epoch 209/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7876e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9599
# Epoch 210/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6604e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9599
# Epoch 211/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7740e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9599
# Epoch 212/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7009e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9599
# Epoch 213/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7642e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9599
# Epoch 214/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6242e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9599
# Epoch 215/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.8712e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9612
# Epoch 216/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.6526e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9586
# Epoch 217/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.4644e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9612
# Epoch 218/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6277e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9599
# Epoch 219/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7257e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9599
# Epoch 220/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6067e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 221/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.0340e-04 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9599
# Epoch 222/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.5427e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9599
# Epoch 223/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7056e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9586
# Epoch 224/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3113e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9599
# Epoch 225/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6937e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9599
# Epoch 226/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.2208e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9612
# Epoch 227/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3799e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9586
# Epoch 228/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.2891e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9573
# Epoch 229/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6437e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9586
# Epoch 230/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.4420e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9586
# Epoch 231/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3976e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9599
# Epoch 232/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6060e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9612
# Epoch 233/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3245e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9586
# Epoch 234/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7866e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9586
# Epoch 235/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7712e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9586
# Epoch 236/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3172e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9586
# Epoch 237/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.4534e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9586
# Epoch 238/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3579e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9612
# Epoch 239/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3260e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9573
# Epoch 240/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.2590e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9599
# Epoch 241/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7950e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9599
# Epoch 242/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0782e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9586
# Epoch 243/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9035e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9586
# Epoch 244/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0349e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9599
# Epoch 245/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.8526e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9625
# Epoch 246/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9000e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9586
# Epoch 247/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9890e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9586
# Epoch 248/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7609e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9625
# Epoch 249/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7850e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9586
# Epoch 250/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7473e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9599
# Epoch 251/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0024e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9599
# Epoch 252/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9086e-04 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9599
# Epoch 253/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0602e-04 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9599
# Epoch 254/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0547e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9586
# Epoch 255/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7257e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9573
# Epoch 256/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9777e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9599
# Epoch 257/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.5596e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9586
# Epoch 258/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.6063e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9573
# Epoch 259/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.6688e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9586
# Epoch 260/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7479e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9599
# Epoch 261/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9098e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9599
# Epoch 262/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.8562e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9586
# Epoch 263/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3264e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9625
# Epoch 264/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0254e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9612
# Epoch 265/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0172e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9599
# Epoch 266/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.4365e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9599
# Epoch 267/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2613e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9586
# Epoch 268/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.5491e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9599
# Epoch 269/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3112e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9599
# Epoch 270/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3385e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9586
# Epoch 271/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3686e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9586
# Epoch 272/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2615e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9612
# Epoch 273/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.4485e-04 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9586
# Epoch 274/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2961e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9612
# Epoch 275/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3639e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9612
# Epoch 276/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2243e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9612
# Epoch 277/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.4195e-04 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9586
# Epoch 278/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2102e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9599
# Epoch 279/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3209e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9599
# Epoch 280/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.0596e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9586
# Epoch 281/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.1822e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9599
# Epoch 282/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2843e-04 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9586
# Epoch 283/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2950e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9586
# Epoch 284/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.0284e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9599
# Epoch 285/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2772e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9586
# Epoch 286/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9540e-04 - accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9612
# Epoch 287/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2126e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9612
# Epoch 288/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2986e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9599
# Epoch 289/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.1954e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9599
# Epoch 290/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.0952e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9625
# Epoch 291/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.3327e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9599
# Epoch 292/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9570e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9586
# Epoch 293/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.0178e-04 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9586
# Epoch 294/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1554e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9586
# Epoch 295/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9480e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9586
# Epoch 296/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.6314e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9599
# Epoch 297/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9996e-04 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9586
# Epoch 298/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9051e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9599
# Epoch 299/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.0974e-04 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9586
# Epoch 300/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.8987e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9599
# Epoch 301/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2316e-04 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9573
# Epoch 302/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.7554e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9573
# Epoch 303/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9040e-04 - accuracy: 1.0000 - val_loss: 0.1561 - val_accuracy: 0.9586
# Epoch 304/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.5902e-04 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9599
# Epoch 305/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.7774e-04 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9573
# Epoch 306/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.1310e-04 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9612
# Epoch 307/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.1289e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9599
# Epoch 308/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.9266e-04 - accuracy: 1.0000 - val_loss: 0.1567 - val_accuracy: 0.9612
# Epoch 309/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.7632e-04 - accuracy: 1.0000 - val_loss: 0.1546 - val_accuracy: 0.9599
# Epoch 310/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.7108e-04 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9599
# Epoch 311/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.7928e-04 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9573
# Epoch 312/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.6492e-04 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9573
# Epoch 313/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.6035e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9586
# Epoch 314/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.8284e-04 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9586
# Epoch 315/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.8225e-04 - accuracy: 1.0000 - val_loss: 0.1564 - val_accuracy: 0.9599
# Epoch 316/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.6542e-04 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 0.9573
# Epoch 317/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 1.5851e-04 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9586
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0678e-07 - accuracy: 1.0000 - val_loss: 0.2211 - val_accuracy: 0.9612
# Epoch 1898/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8429e-07 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9612
# Epoch 1899/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.4418e-07 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9612
# Epoch 1900/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4049e-07 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9599
# Epoch 1901/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.5309e-07 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9599
# Epoch 1902/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9572e-07 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9599
# Epoch 1903/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.7488e-07 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9599
# Epoch 1904/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.5081e-07 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9599
# Epoch 1905/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.7935e-07 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9599
# Epoch 1906/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.6929e-07 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9599
# Epoch 1907/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.0751e-07 - accuracy: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9599
# Epoch 1908/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0143e-07 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9599
# Epoch 1909/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0309e-07 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9599
# Epoch 1910/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1483e-07 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9612
# Epoch 1911/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.7262e-07 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9599
# Epoch 1912/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9340e-07 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9599
# Epoch 1913/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.4458e-07 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9586
# Epoch 1914/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.1596e-07 - accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9586
# Epoch 1915/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8498e-07 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9586
# Epoch 1916/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3967e-07 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9586
# Epoch 1917/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7778e-07 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9586
# Epoch 1918/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0875e-07 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9586
# Epoch 1919/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.9040e-07 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9599
# Epoch 1920/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9820e-07 - accuracy: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9599
# Epoch 1921/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.1686e-07 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9599
# Epoch 1922/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.1752e-07 - accuracy: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9599
# Epoch 1923/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0363e-07 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9599
# Epoch 1924/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0243e-07 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9599
# Epoch 1925/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4002e-07 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9599
# Epoch 1926/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2446e-07 - accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9599
# Epoch 1927/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7767e-07 - accuracy: 1.0000 - val_loss: 0.2200 - val_accuracy: 0.9599
# Epoch 1928/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0659e-07 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9599
# Epoch 1929/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.2281e-07 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9599
# Epoch 1930/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.6842e-07 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9599
# Epoch 1931/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3520e-07 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9599
# Epoch 1932/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3449e-07 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9586
# Epoch 1933/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4877e-07 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9586
# Epoch 1934/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.5327e-07 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9599
# Epoch 1935/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9053e-07 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9586
# Epoch 1936/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7794e-07 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9586
# Epoch 1937/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1895e-07 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9599
# Epoch 1938/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.6610e-07 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9599
# Epoch 1939/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3374e-07 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9599
# Epoch 1940/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9078e-07 - accuracy: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.9599
# Epoch 1941/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2912e-07 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9599
# Epoch 1942/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.1017e-07 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9599
# Epoch 1943/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.1206e-07 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9599
# Epoch 1944/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3852e-07 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9599
# Epoch 1945/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7127e-07 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9599
# Epoch 1946/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0640e-07 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9599
# Epoch 1947/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7035e-07 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9599
# Epoch 1948/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7482e-07 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9599
# Epoch 1949/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7116e-07 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9599
# Epoch 1950/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.4381e-07 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9599
# Epoch 1951/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6931e-07 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9599
# Epoch 1952/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9780e-07 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9599
# Epoch 1953/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0655e-07 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9599
# Epoch 1954/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4951e-07 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9586
# Epoch 1955/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4787e-07 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9586
# Epoch 1956/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1757e-07 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9586
# Epoch 1957/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9704e-07 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9586
# Epoch 1958/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4839e-07 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9586
# Epoch 1959/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.6107e-07 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9586
# Epoch 1960/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6727e-07 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9586
# Epoch 1961/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6588e-07 - accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9586
# Epoch 1962/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0852e-07 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9586
# Epoch 1963/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.0364e-07 - accuracy: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9586
# Epoch 1964/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6942e-07 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9586
# Epoch 1965/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2862e-07 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9586
# Epoch 1966/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.0297e-07 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9586
# Epoch 1967/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8741e-07 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9586
# Epoch 1968/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.8206e-07 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9586
# Epoch 1969/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7766e-07 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9586
# Epoch 1970/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0501e-07 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9586
# Epoch 1971/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.8096e-07 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9586
# Epoch 1972/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9168e-07 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9586
# Epoch 1973/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1976e-07 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9586
# Epoch 1974/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2120e-07 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9586
# Epoch 1975/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.5117e-07 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9586
# Epoch 1976/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.5132e-07 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9586
# Epoch 1977/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4283e-07 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9586
# Epoch 1978/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.2540e-07 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9586
# Epoch 1979/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.5887e-07 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9586
# Epoch 1980/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9279e-07 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9586
# Epoch 1981/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.0353e-07 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9586
# Epoch 1982/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9076e-07 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9586
# Epoch 1983/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9176e-07 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9586
# Epoch 1984/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.0006e-07 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9586
# Epoch 1985/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5571e-07 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9586
# Epoch 1986/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.3417e-07 - accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9586
# Epoch 1987/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.4543e-07 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9599
# Epoch 1988/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6124e-07 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9599
# Epoch 1989/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6426e-07 - accuracy: 1.0000 - val_loss: 0.2257 - val_accuracy: 0.9586
# Epoch 1990/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5194e-07 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9599
# Epoch 1991/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.8833e-07 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9599
# Epoch 1992/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4175e-07 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9599
# Epoch 1993/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1922e-07 - accuracy: 1.0000 - val_loss: 0.2255 - val_accuracy: 0.9599
# Epoch 1994/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5209e-07 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9599
# Epoch 1995/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.2261e-07 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9599
# Epoch 1996/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.1329e-07 - accuracy: 1.0000 - val_loss: 0.2274 - val_accuracy: 0.9599
# Epoch 1997/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.4805e-07 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9586
# Epoch 1998/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4882e-07 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9599
# Epoch 1999/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.9507e-07 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9599
# Epoch 2000/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.6973e-07 - accuracy: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9599
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 357ms/step - loss: 0.8758 - accuracy: 0.8395
# test_indoor_ds_results:test loss, test acc: [0.8758369088172913, 0.8394649028778076]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 439ms/step - loss: 2.1330 - accuracy: 0.7439
# test_outdoor_ds_results:test loss, test acc: [2.1329941749572754, 0.7439490556716919]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 9s 205ms/step - loss: 2.3328 - accuracy: 0.7185
# test_belt_ds_results:test loss, test acc: [2.3327865600585938, 0.7184950113296509]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate400-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 136ms/step - loss: 0.5959 - accuracy: 0.8344
# 50/50 [==============================] - 7s 135ms/step - loss: 1.4068 - accuracy: 0.7376
# 35/35 [==============================] - 5s 136ms/step - loss: 1.4999 - accuracy: 0.7090
# Epoch200
#  test_indoor_acc=0.8344481587409973
#  test_outdoor_acc=0.7375796437263489
#  test_belt_acc=0.7089754939079285
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6440 - accuracy: 0.8395
# 50/50 [==============================] - 7s 136ms/step - loss: 1.5462 - accuracy: 0.7414
# 35/35 [==============================] - 5s 137ms/step - loss: 1.6712 - accuracy: 0.7140
# Epoch400
#  test_indoor_acc=0.8394649028778076
#  test_outdoor_acc=0.7414012551307678
#  test_belt_acc=0.7139618992805481
# 29/29 [==============================] - 7s 135ms/step - loss: 0.6926 - accuracy: 0.8356
# 50/50 [==============================] - 7s 136ms/step - loss: 1.6866 - accuracy: 0.7382
# 35/35 [==============================] - 5s 137ms/step - loss: 1.8288 - accuracy: 0.7117
# Epoch600
#  test_indoor_acc=0.8355630040168762
#  test_outdoor_acc=0.7382165789604187
#  test_belt_acc=0.7116953730583191
# 29/29 [==============================] - 5s 133ms/step - loss: 0.7448 - accuracy: 0.8372
# 50/50 [==============================] - 7s 135ms/step - loss: 1.8256 - accuracy: 0.7385
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9842 - accuracy: 0.7121
# Epoch800
#  test_indoor_acc=0.8372352123260498
#  test_outdoor_acc=0.7385350465774536
#  test_belt_acc=0.7121486663818359
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7649 - accuracy: 0.8400
# 50/50 [==============================] - 7s 139ms/step - loss: 1.8770 - accuracy: 0.7433
# 35/35 [==============================] - 5s 139ms/step - loss: 2.0637 - accuracy: 0.7144
# Epoch1000
#  test_indoor_acc=0.8400223255157471
#  test_outdoor_acc=0.7433121204376221
#  test_belt_acc=0.7144152522087097
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8062 - accuracy: 0.8400
# 50/50 [==============================] - 7s 137ms/step - loss: 1.9742 - accuracy: 0.7420
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1698 - accuracy: 0.7149
# Epoch1200
#  test_indoor_acc=0.8400223255157471
#  test_outdoor_acc=0.7420381903648376
#  test_belt_acc=0.7148685455322266
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8188 - accuracy: 0.8439
# 50/50 [==============================] - 7s 135ms/step - loss: 2.0309 - accuracy: 0.7417
# 35/35 [==============================] - 5s 136ms/step - loss: 2.2084 - accuracy: 0.7158
# Epoch1400
#  test_indoor_acc=0.8439241647720337
#  test_outdoor_acc=0.7417197227478027
#  test_belt_acc=0.7157751321792603
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8455 - accuracy: 0.8417
# 50/50 [==============================] - 7s 136ms/step - loss: 2.0831 - accuracy: 0.7424
# 35/35 [==============================] - 5s 137ms/step - loss: 2.2751 - accuracy: 0.7167
# Epoch1600
#  test_indoor_acc=0.8416945338249207
#  test_outdoor_acc=0.7423567175865173
#  test_belt_acc=0.7166817784309387
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8616 - accuracy: 0.8417
# 50/50 [==============================] - 7s 134ms/step - loss: 2.1122 - accuracy: 0.7436
# 35/35 [==============================] - 5s 135ms/step - loss: 2.3353 - accuracy: 0.7158
# Epoch1800
#  test_indoor_acc=0.8416945338249207
#  test_outdoor_acc=0.743630588054657
#  test_belt_acc=0.7157751321792603
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8758 - accuracy: 0.8395
# 50/50 [==============================] - 7s 134ms/step - loss: 2.1330 - accuracy: 0.7439
# 35/35 [==============================] - 5s 135ms/step - loss: 2.3328 - accuracy: 0.7185
# Epoch2000
#  test_indoor_acc=0.8394649028778076
#  test_outdoor_acc=0.7439490556716919
#  test_belt_acc=0.7184950113296509

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7673029899597168
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8344481587409973,
#  0.8394649028778076,
#  0.8355630040168762,
#  0.8372352123260498,
#  0.8400223255157471,
#  0.8400223255157471,
#  0.8439241647720337,
#  0.8416945338249207,
#  0.8416945338249207,
#  0.8394649028778076]

# %%
test_outdoor_acc
# Out:
# [0.7375796437263489,
#  0.7414012551307678,
#  0.7382165789604187,
#  0.7385350465774536,
#  0.7433121204376221,
#  0.7420381903648376,
#  0.7417197227478027,
#  0.7423567175865173,
#  0.743630588054657,
#  0.7439490556716919]

# %%
test_belt_acc
# Out:
# [0.7089754939079285,
#  0.7139618992805481,
#  0.7116953730583191,
#  0.7121486663818359,
#  0.7144152522087097,
#  0.7148685455322266,
#  0.7157751321792603,
#  0.7166817784309387,
#  0.7157751321792603,
#  0.7184950113296509]

# %%
test_indoor_loss
# Out:
# [0.5959175825119019,
#  0.6439604759216309,
#  0.6925633549690247,
#  0.7448374032974243,
#  0.7648669481277466,
#  0.8061952590942383,
#  0.8188434839248657,
#  0.8454526662826538,
#  0.8615954518318176,
#  0.8758369088172913]

# %%
test_outdoor_loss
# Out:
# [1.4067665338516235,
#  1.5461921691894531,
#  1.6866201162338257,
#  1.8256076574325562,
#  1.8770251274108887,
#  1.9741508960723877,
#  2.0309152603149414,
#  2.0831024646759033,
#  2.1121864318847656,
#  2.1329941749572754]

# %%
test_belt_loss
# Out:
# [1.4999284744262695,
#  1.6711673736572266,
#  1.8288164138793945,
#  1.9841992855072021,
#  2.0636892318725586,
#  2.169787883758545,
#  2.2084438800811768,
#  2.2750515937805176,
#  2.3353118896484375,
#  2.3327865600585938]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5426
# FP=1714
# acc=0.7599439775910364
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 67.24137931034483%
# 2WayConnectorforFoley acc = 91.15646258503402%
# 2WayFoleyCatheter acc = 73.13432835820896%
# 3WayConnectorforFoley acc = 87.17948717948718%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 79.375%
# AlcoholPad acc = 38.88888888888889%
# BootCover acc = 65.66265060240963%
# CottonBall acc = 83.8323353293413%
# CottonSwap acc = 69.93006993006993%
# Dilator acc = 68.37606837606837%
# DisposableInfusionSet acc = 55.75221238938053%
# ExtensionTube acc = 39.83739837398374%
# FaceShield acc = 80.24691358024691%
# FrontLoadSyringe acc = 45.13274336283185%
# GauzePad acc = 56.81818181818182%
# Glove acc = 79.16666666666666%
# GuideWire acc = 41.07142857142857%
# LiquidBottle acc = 66.79389312977099%
# Mask acc = 94.28571428571428%
# NGTube acc = 45.806451612903224%
# NasalCannula acc = 61.94690265486725%
# Needle acc = 85.35714285714285%
# OxygenMask acc = 95.48872180451127%
# PPESuit acc = 89.51612903225806%
# PharmaceuticalProduct acc = 59.345794392523366%
# Pill acc = 97.47899159663865%
# PillBottle acc = 82.94573643410853%
# PrefilledHumidifier acc = 78.63247863247864%
# PressureConnectingTube acc = 61.832061068702295%
# ReusableHumidifier acc = 82.20338983050848%
# SodiumChlorideBag acc = 87.4015748031496%
# SterileHumidifierAdapter acc = 83.63636363636363%
# SurgicalBlade acc = 88.49557522123894%
# SurgicalCap acc = 92.7927927927928%
# SurgicalSuit acc = 51.515151515151516%
# Syringe acc = 98.47908745247148%
# TrachealTube acc = 38.53211009174312%
# UrineBag acc = 74.16666666666667%
# Vaccinebottle acc = 78.87323943661971%
# WingedInfusionSet acc = 69.2982456140351%
#
#
#
# all_avg_eachclass = 72.84696412156178%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 78,   0,   0, ...,   0,   7,   0],
#        [  1, 134,   0, ...,   0,   1,   0],
#        [  0,   0,  98, ...,   0,   1,  15],
#        ...,
#        [  0,   0,   0, ...,  89,   0,   0],
#        [  0,   0,   0, ...,   0, 168,   0],
#        [  0,   0,   0, ...,   1,   0,  79]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[67.24137931,  0.        ,  0.        , ...,  0.        ,
#          6.03448276,  0.        ],
#        [ 0.68027211, 91.15646259,  0.        , ...,  0.        ,
#          0.68027211,  0.        ],
#        [ 0.        ,  0.        , 73.13432836, ...,  0.        ,
#          0.74626866, 11.19402985],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 74.16666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         78.87323944,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.87719298,
#          0.        , 69.29824561]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
