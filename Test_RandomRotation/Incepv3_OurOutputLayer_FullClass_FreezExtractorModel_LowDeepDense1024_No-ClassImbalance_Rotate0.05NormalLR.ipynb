# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.05),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 44s 347ms/step - loss: 1.5230 - accuracy: 0.5994 - val_loss: 0.6203 - val_accuracy: 0.8266
# Epoch 2/2000
# 49/49 [==============================] - 10s 197ms/step - loss: 0.4478 - accuracy: 0.8695 - val_loss: 0.3771 - val_accuracy: 0.8849
# Epoch 3/2000
# 49/49 [==============================] - 10s 196ms/step - loss: 0.2444 - accuracy: 0.9276 - val_loss: 0.3089 - val_accuracy: 0.8913
# Epoch 4/2000
# 49/49 [==============================] - 10s 196ms/step - loss: 0.1465 - accuracy: 0.9638 - val_loss: 0.2337 - val_accuracy: 0.9185
# Epoch 5/2000
# 49/49 [==============================] - 10s 197ms/step - loss: 0.0978 - accuracy: 0.9729 - val_loss: 0.1864 - val_accuracy: 0.9392
# Epoch 6/2000
# 49/49 [==============================] - 9s 188ms/step - loss: 0.0640 - accuracy: 0.9871 - val_loss: 0.2431 - val_accuracy: 0.9250
# Epoch 7/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 0.0579 - accuracy: 0.9864 - val_loss: 0.2520 - val_accuracy: 0.9211
# Epoch 8/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0444 - accuracy: 0.9922 - val_loss: 0.2269 - val_accuracy: 0.9314
# Epoch 9/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0303 - accuracy: 0.9939 - val_loss: 0.1479 - val_accuracy: 0.9560
# Epoch 10/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0214 - accuracy: 0.9977 - val_loss: 0.1523 - val_accuracy: 0.9547
# Epoch 11/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0188 - accuracy: 0.9974 - val_loss: 0.1478 - val_accuracy: 0.9573
# Epoch 12/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0175 - accuracy: 0.9971 - val_loss: 0.1491 - val_accuracy: 0.9560
# Epoch 13/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0121 - accuracy: 0.9997 - val_loss: 0.1456 - val_accuracy: 0.9508
# Epoch 14/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0093 - accuracy: 0.9994 - val_loss: 0.1464 - val_accuracy: 0.9573
# Epoch 15/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0095 - accuracy: 0.9997 - val_loss: 0.1298 - val_accuracy: 0.9651
# Epoch 16/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.9638
# Epoch 17/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9612
# Epoch 18/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.1298 - val_accuracy: 0.9586
# Epoch 19/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1256 - val_accuracy: 0.9586
# Epoch 20/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.9612
# Epoch 21/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1283 - val_accuracy: 0.9638
# Epoch 22/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1277 - val_accuracy: 0.9638
# Epoch 23/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.9625
# Epoch 24/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9664
# Epoch 25/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9638
# Epoch 26/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 27/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9702
# Epoch 28/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 29/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9677
# Epoch 30/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9702
# Epoch 31/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9651
# Epoch 32/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9651
# Epoch 33/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9690
# Epoch 34/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9715
# Epoch 35/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9651
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 36/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9677
# Epoch 37/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.3632e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9664
# Epoch 38/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9677
# Epoch 39/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9677
# Epoch 40/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 41/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.7243e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
# Epoch 42/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.4590e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 43/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.4961e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 44/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.1989e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 45/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.3324e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 46/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.5410e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 47/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.9680e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 48/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.4769e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 49/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.7252e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 50/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.6979e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 51/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.2181e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 52/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.4010e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 53/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.8903e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 54/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.7890e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 55/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.8087e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 56/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.4560e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 57/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.3843e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 58/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.8330e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 59/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.4316e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 60/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.5229e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 61/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.0649e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 62/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.2512e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 63/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.2462e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 64/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.1097e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 65/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.9814e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 66/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.3775e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 67/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.2036e-04 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9690
# Epoch 68/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.3604e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 69/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.2606e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 70/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.7814e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 71/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.0410e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 72/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.5683e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 73/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.7607e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 74/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.5140e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 75/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.7738e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 76/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.3483e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 77/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.4346e-04 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9690
# Epoch 78/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.6991e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 79/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.7633e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 80/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.4252e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 81/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.9154e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 82/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.1976e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 83/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.1911e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 84/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.2847e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 85/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.8785e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 86/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.5874e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 87/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.4476e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 88/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.8023e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 89/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.0533e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 90/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.2109e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 91/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.2585e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 92/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.0011e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 93/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.5383e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 94/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.1299e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 95/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.9969e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 96/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.2487e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 97/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.6857e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 98/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.8184e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 99/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.1414e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 100/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.1716e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 101/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.7730e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9690
# Epoch 102/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.0759e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9690
# Epoch 103/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.8945e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9690
# Epoch 104/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.5903e-04 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9690
# Epoch 105/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.5894e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 106/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.0006e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9690
# Epoch 107/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 9.0596e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 108/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.1071e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9690
# Epoch 109/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.9341e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 110/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.0675e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 111/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.8640e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9690
# Epoch 112/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.7885e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 113/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.0578e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 114/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.7700e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 115/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.9446e-04 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 0.9690
# Epoch 116/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.7530e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9690
# Epoch 117/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.2957e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 118/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.5625e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 119/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.9846e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 120/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.1305e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 121/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.8019e-04 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9677
# Epoch 122/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 8.4474e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9677
# Epoch 123/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.8742e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9690
# Epoch 124/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.0672e-04 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9677
# Epoch 125/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.4012e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 126/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.3119e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 127/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.7438e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9677
# Epoch 128/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.7501e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 129/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.6540e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 130/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.5546e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 131/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.2911e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 132/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.2013e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9690
# Epoch 133/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.4571e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 134/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.6025e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 135/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.6770e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9677
# Epoch 136/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.7143e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9690
# Epoch 137/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.8563e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9677
# Epoch 138/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.8033e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9690
# Epoch 139/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.9921e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9690
# Epoch 140/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.5747e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 141/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.1273e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 142/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.9810e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9690
# Epoch 143/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.2781e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 144/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.8490e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 145/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.2574e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 146/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.0220e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9677
# Epoch 147/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.7170e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9677
# Epoch 148/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.8255e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 149/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.7501e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
# Epoch 150/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.7922e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9690
# Epoch 151/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.2607e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
# Epoch 152/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 7.1331e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9690
# Epoch 153/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.4671e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9690
# Epoch 154/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.9450e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 155/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.4157e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9702
# Epoch 156/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.3988e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9690
# Epoch 157/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.2789e-04 - accuracy: 1.0000 - val_loss: 0.1160 - val_accuracy: 0.9690
# Epoch 158/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.4555e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9690
# Epoch 159/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.6107e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 160/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.1332e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9690
# Epoch 161/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.7277e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9690
# Epoch 162/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.7103e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9690
# Epoch 163/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.0179e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9702
# Epoch 164/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.6883e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9702
# Epoch 165/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.7950e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9690
# Epoch 166/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.1760e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9690
# Epoch 167/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.1877e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9702
# Epoch 168/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.0841e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9690
# Epoch 169/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.4934e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9702
# Epoch 170/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.2677e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9690
# Epoch 171/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.5372e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9690
# Epoch 172/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.3472e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9677
# Epoch 173/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.6262e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9690
# Epoch 174/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.7444e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 175/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.2653e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9690
# Epoch 176/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.4217e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9677
# Epoch 177/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.5810e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9690
# Epoch 178/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.5244e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9677
# Epoch 179/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.9859e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9677
# Epoch 180/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.9276e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9690
# Epoch 181/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.5174e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9690
# Epoch 182/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.1072e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9677
# Epoch 183/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.5475e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9690
# Epoch 184/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.1677e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9677
# Epoch 185/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.4172e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9677
# Epoch 186/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.4084e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9677
# Epoch 187/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.7230e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9677
# Epoch 188/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.3814e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9690
# Epoch 189/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.4444e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9677
# Epoch 190/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.2217e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9677
# Epoch 191/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.6250e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9690
# Epoch 192/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.5169e-04 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 0.9702
# Epoch 193/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.4393e-04 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9677
# Epoch 194/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.5868e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9677
# Epoch 195/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.9710e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9690
# Epoch 196/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.0419e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9690
# Epoch 197/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.1563e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9677
# Epoch 198/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.4252e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9677
# Epoch 199/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 5.1055e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9677
# Epoch 200/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.5162e-04 - accuracy: 1.0000 - val_loss: 0.1184 - val_accuracy: 0.9702
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.97.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.7577e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9702
# Epoch 202/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 5.4870e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9677
# Epoch 203/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.5583e-04 - accuracy: 1.0000 - val_loss: 0.1183 - val_accuracy: 0.9690
# Epoch 204/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.4938e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9690
# Epoch 205/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.5520e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9690
# Epoch 206/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 4.6921e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9677
# Epoch 207/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.4172e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9677
# Epoch 208/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.3817e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9690
# Epoch 209/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2773e-04 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9690
# Epoch 210/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.4569e-04 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9677
# Epoch 211/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.8109e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9690
# Epoch 212/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.0897e-04 - accuracy: 1.0000 - val_loss: 0.1200 - val_accuracy: 0.9690
# Epoch 213/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2548e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9677
# Epoch 214/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.5648e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9702
# Epoch 215/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2288e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9690
# Epoch 216/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.1271e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9702
# Epoch 217/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2653e-04 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 0.9677
# Epoch 218/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2817e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9690
# Epoch 219/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2523e-04 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 0.9690
# Epoch 220/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9849e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9690
# Epoch 221/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.8606e-04 - accuracy: 1.0000 - val_loss: 0.1203 - val_accuracy: 0.9664
# Epoch 222/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.8907e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9690
# Epoch 223/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.8607e-04 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9690
# Epoch 224/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6505e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9690
# Epoch 225/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.8993e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9690
# Epoch 226/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6041e-04 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 0.9690
# Epoch 227/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3547e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9690
# Epoch 228/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6648e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9690
# Epoch 229/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6023e-04 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9690
# Epoch 230/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.9618e-04 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9702
# Epoch 231/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6879e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9702
# Epoch 232/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.4261e-04 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9690
# Epoch 233/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6858e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9677
# Epoch 234/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3869e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9677
# Epoch 235/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2008e-04 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9690
# Epoch 236/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.5951e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9690
# Epoch 237/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.3788e-04 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 0.9690
# Epoch 238/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.8492e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9702
# Epoch 239/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.5165e-04 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9690
# Epoch 240/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3180e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9690
# Epoch 241/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.4688e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9690
# Epoch 242/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2983e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9677
# Epoch 243/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2530e-04 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9702
# Epoch 244/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2860e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9677
# Epoch 245/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2977e-04 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9690
# Epoch 246/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1073e-04 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9690
# Epoch 247/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3832e-04 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9702
# Epoch 248/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0967e-04 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9690
# Epoch 249/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1863e-04 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 0.9702
# Epoch 250/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2502e-04 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9702
# Epoch 251/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9207e-04 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9702
# Epoch 252/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.2730e-04 - accuracy: 1.0000 - val_loss: 0.1201 - val_accuracy: 0.9690
# Epoch 253/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0835e-04 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9702
# Epoch 254/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0464e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9690
# Epoch 255/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1721e-04 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9702
# Epoch 256/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0435e-04 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9702
# Epoch 257/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7494e-04 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9690
# Epoch 258/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9591e-04 - accuracy: 1.0000 - val_loss: 0.1223 - val_accuracy: 0.9690
# Epoch 259/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.3439e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9702
# Epoch 260/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7491e-04 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 0.9677
# Epoch 261/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1450e-04 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9702
# Epoch 262/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.9388e-04 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9664
# Epoch 263/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7796e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9690
# Epoch 264/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7552e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9690
# Epoch 265/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6293e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9677
# Epoch 266/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5691e-04 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9690
# Epoch 267/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7145e-04 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9690
# Epoch 268/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7806e-04 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9702
# Epoch 269/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5866e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9702
# Epoch 270/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4290e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9677
# Epoch 271/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6827e-04 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9690
# Epoch 272/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5620e-04 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9664
# Epoch 273/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4535e-04 - accuracy: 1.0000 - val_loss: 0.1225 - val_accuracy: 0.9690
# Epoch 274/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6607e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9677
# Epoch 275/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5614e-04 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9677
# Epoch 276/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2846e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 277/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3535e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9690
# Epoch 278/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7953e-04 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9690
# Epoch 279/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3799e-04 - accuracy: 1.0000 - val_loss: 0.1224 - val_accuracy: 0.9690
# Epoch 280/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4917e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9702
# Epoch 281/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3844e-04 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9702
# Epoch 282/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2471e-04 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9690
# Epoch 283/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4794e-04 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9702
# Epoch 284/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2499e-04 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9690
# Epoch 285/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2287e-04 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9690
# Epoch 286/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1793e-04 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9702
# Epoch 287/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2659e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9690
# Epoch 288/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7448e-04 - accuracy: 1.0000 - val_loss: 0.1232 - val_accuracy: 0.9677
# Epoch 289/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3302e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9677
# Epoch 290/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1961e-04 - accuracy: 1.0000 - val_loss: 0.1253 - val_accuracy: 0.9677
# Epoch 291/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0078e-04 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9677
# Epoch 292/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3107e-04 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9690
# Epoch 293/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2514e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9690
# Epoch 294/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2426e-04 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.9702
# Epoch 295/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0398e-04 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9702
# Epoch 296/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2692e-04 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9702
# Epoch 297/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9285e-04 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9702
# Epoch 298/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9782e-04 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9690
# Epoch 299/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0027e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 300/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0185e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9690
# Epoch 301/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8012e-04 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9702
# Epoch 302/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7881e-04 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9702
# Epoch 303/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2802e-04 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 0.9702
# Epoch 304/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1418e-04 - accuracy: 1.0000 - val_loss: 0.1228 - val_accuracy: 0.9690
# Epoch 305/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1089e-04 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9690
# Epoch 306/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9541e-04 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.9690
# Epoch 307/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7919e-04 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9702
# Epoch 308/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8143e-04 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 0.9677
# Epoch 309/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9749e-04 - accuracy: 1.0000 - val_loss: 0.1224 - val_accuracy: 0.9702
# Epoch 310/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7246e-04 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9690
# Epoch 311/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9110e-04 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 0.9690
# Epoch 312/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9670e-04 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9690
# Epoch 313/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.7682e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9690
# Epoch 314/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9628e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9690
# Epoch 315/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6300e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9702
# Epoch 316/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.6981e-04 - accuracy: 1.0000 - val_loss: 0.1235 - val_accuracy: 0.9702
# Epoch 317/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8629e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9690
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.3039e-07 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9690
# Epoch 1898/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.3455e-07 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 0.9690
# Epoch 1899/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6253e-07 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9690
# Epoch 1900/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7451e-07 - accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9690
# Epoch 1901/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7462e-07 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9690
# Epoch 1902/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.6444e-07 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9690
# Epoch 1903/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2444e-07 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9690
# Epoch 1904/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4627e-07 - accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9690
# Epoch 1905/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5979e-07 - accuracy: 1.0000 - val_loss: 0.1812 - val_accuracy: 0.9690
# Epoch 1906/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6754e-07 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9690
# Epoch 1907/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.7069e-07 - accuracy: 1.0000 - val_loss: 0.1811 - val_accuracy: 0.9690
# Epoch 1908/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1812e-07 - accuracy: 1.0000 - val_loss: 0.1814 - val_accuracy: 0.9690
# Epoch 1909/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9609e-07 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9690
# Epoch 1910/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4350e-07 - accuracy: 1.0000 - val_loss: 0.1819 - val_accuracy: 0.9690
# Epoch 1911/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.7347e-07 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9690
# Epoch 1912/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3445e-07 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9690
# Epoch 1913/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6080e-07 - accuracy: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9690
# Epoch 1914/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6172e-07 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9677
# Epoch 1915/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5933e-07 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9677
# Epoch 1916/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3880e-07 - accuracy: 1.0000 - val_loss: 0.1821 - val_accuracy: 0.9677
# Epoch 1917/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0194e-07 - accuracy: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9677
# Epoch 1918/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4939e-07 - accuracy: 1.0000 - val_loss: 0.1823 - val_accuracy: 0.9677
# Epoch 1919/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6938e-07 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9677
# Epoch 1920/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.9453e-07 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9677
# Epoch 1921/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1250e-07 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9677
# Epoch 1922/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.9257e-07 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9677
# Epoch 1923/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3599e-07 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9677
# Epoch 1924/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0884e-07 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9677
# Epoch 1925/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0021e-07 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9677
# Epoch 1926/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4928e-07 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9677
# Epoch 1927/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.7524e-07 - accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9677
# Epoch 1928/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5455e-07 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9677
# Epoch 1929/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6583e-07 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9677
# Epoch 1930/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1770e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9677
# Epoch 1931/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.8280e-07 - accuracy: 1.0000 - val_loss: 0.1834 - val_accuracy: 0.9677
# Epoch 1932/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6884e-07 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9677
# Epoch 1933/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3021e-07 - accuracy: 1.0000 - val_loss: 0.1832 - val_accuracy: 0.9677
# Epoch 1934/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4054e-07 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9677
# Epoch 1935/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6076e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9677
# Epoch 1936/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3214e-07 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9677
# Epoch 1937/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.8240e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9677
# Epoch 1938/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5113e-07 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9664
# Epoch 1939/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4546e-07 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 0.9664
# Epoch 1940/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1920e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9664
# Epoch 1941/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6592e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9664
# Epoch 1942/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.0382e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9664
# Epoch 1943/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.0293e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9664
# Epoch 1944/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.4740e-07 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9664
# Epoch 1945/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1804e-07 - accuracy: 1.0000 - val_loss: 0.1864 - val_accuracy: 0.9677
# Epoch 1946/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8517e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9690
# Epoch 1947/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3229e-07 - accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9690
# Epoch 1948/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5456e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9690
# Epoch 1949/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2940e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9690
# Epoch 1950/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.0388e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9690
# Epoch 1951/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.7743e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9677
# Epoch 1952/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5802e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9677
# Epoch 1953/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3892e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9677
# Epoch 1954/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2910e-07 - accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9677
# Epoch 1955/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4158e-07 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9690
# Epoch 1956/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2975e-07 - accuracy: 1.0000 - val_loss: 0.1854 - val_accuracy: 0.9690
# Epoch 1957/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.6376e-07 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9677
# Epoch 1958/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.6512e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9690
# Epoch 1959/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.2856e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9690
# Epoch 1960/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.3029e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9690
# Epoch 1961/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8282e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9690
# Epoch 1962/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4766e-07 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9690
# Epoch 1963/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4269e-07 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9690
# Epoch 1964/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1461e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9690
# Epoch 1965/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4785e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9690
# Epoch 1966/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.9798e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9690
# Epoch 1967/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2929e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9690
# Epoch 1968/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.6368e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9677
# Epoch 1969/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.8956e-07 - accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9677
# Epoch 1970/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 1.9228e-07 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9690
# Epoch 1971/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1192e-07 - accuracy: 1.0000 - val_loss: 0.1852 - val_accuracy: 0.9677
# Epoch 1972/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4547e-07 - accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9677
# Epoch 1973/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1391e-07 - accuracy: 1.0000 - val_loss: 0.1846 - val_accuracy: 0.9677
# Epoch 1974/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 4.7967e-07 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9664
# Epoch 1975/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.1069e-07 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9664
# Epoch 1976/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4519e-07 - accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9664
# Epoch 1977/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1450e-07 - accuracy: 1.0000 - val_loss: 0.1830 - val_accuracy: 0.9664
# Epoch 1978/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2971e-07 - accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9677
# Epoch 1979/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.4296e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9677
# Epoch 1980/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2031e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9677
# Epoch 1981/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2686e-07 - accuracy: 1.0000 - val_loss: 0.1836 - val_accuracy: 0.9677
# Epoch 1982/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.9986e-07 - accuracy: 1.0000 - val_loss: 0.1838 - val_accuracy: 0.9677
# Epoch 1983/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0183e-07 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9677
# Epoch 1984/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2032e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9677
# Epoch 1985/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.0575e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9690
# Epoch 1986/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.0976e-07 - accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9690
# Epoch 1987/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3688e-07 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9690
# Epoch 1988/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 3.1201e-07 - accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9690
# Epoch 1989/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.8694e-07 - accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9690
# Epoch 1990/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.4785e-07 - accuracy: 1.0000 - val_loss: 0.1851 - val_accuracy: 0.9690
# Epoch 1991/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.5136e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9690
# Epoch 1992/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 1.8380e-07 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.9690
# Epoch 1993/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3241e-07 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9690
# Epoch 1994/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.1881e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9690
# Epoch 1995/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.7112e-07 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9677
# Epoch 1996/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.6675e-07 - accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9677
# Epoch 1997/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.3857e-07 - accuracy: 1.0000 - val_loss: 0.1815 - val_accuracy: 0.9677
# Epoch 1998/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.5236e-07 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9677
# Epoch 1999/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 2.2536e-07 - accuracy: 1.0000 - val_loss: 0.1831 - val_accuracy: 0.9677
# Epoch 2000/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 2.2471e-07 - accuracy: 1.0000 - val_loss: 0.1826 - val_accuracy: 0.9677
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 347ms/step - loss: 0.7981 - accuracy: 0.8590
# test_indoor_ds_results:test loss, test acc: [0.7980654239654541, 0.8589743375778198]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 419ms/step - loss: 2.2654 - accuracy: 0.7420
# test_outdoor_ds_results:test loss, test acc: [2.26540207862854, 0.7420381903648376]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 202ms/step - loss: 2.3323 - accuracy: 0.7158
# test_belt_ds_results:test loss, test acc: [2.3322739601135254, 0.7157751321792603]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate050-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 6s 147ms/step - loss: 0.5372 - accuracy: 0.8584
# 50/50 [==============================] - 7s 145ms/step - loss: 1.4250 - accuracy: 0.7398
# 35/35 [==============================] - 5s 146ms/step - loss: 1.4680 - accuracy: 0.7185
# Epoch200
#  test_indoor_acc=0.8584169745445251
#  test_outdoor_acc=0.7398089170455933
#  test_belt_acc=0.7184950113296509
# 29/29 [==============================] - 5s 141ms/step - loss: 0.5891 - accuracy: 0.8579
# 50/50 [==============================] - 7s 144ms/step - loss: 1.6167 - accuracy: 0.7411
# 35/35 [==============================] - 5s 144ms/step - loss: 1.6575 - accuracy: 0.7171
# Epoch400
#  test_indoor_acc=0.8578595519065857
#  test_outdoor_acc=0.7410827875137329
#  test_belt_acc=0.7171350717544556
# 29/29 [==============================] - 5s 144ms/step - loss: 0.6442 - accuracy: 0.8590
# 50/50 [==============================] - 7s 146ms/step - loss: 1.7622 - accuracy: 0.7424
# 35/35 [==============================] - 5s 147ms/step - loss: 1.8369 - accuracy: 0.7176
# Epoch600
#  test_indoor_acc=0.8589743375778198
#  test_outdoor_acc=0.7423567175865173
#  test_belt_acc=0.7175884246826172
# 29/29 [==============================] - 5s 140ms/step - loss: 0.6897 - accuracy: 0.8584
# 50/50 [==============================] - 7s 142ms/step - loss: 1.9200 - accuracy: 0.7443
# 35/35 [==============================] - 5s 142ms/step - loss: 1.9953 - accuracy: 0.7162
# Epoch800
#  test_indoor_acc=0.8584169745445251
#  test_outdoor_acc=0.7442675232887268
#  test_belt_acc=0.7162284851074219
# 29/29 [==============================] - 5s 140ms/step - loss: 0.7207 - accuracy: 0.8595
# 50/50 [==============================] - 7s 141ms/step - loss: 2.0121 - accuracy: 0.7417
# 35/35 [==============================] - 5s 142ms/step - loss: 2.0926 - accuracy: 0.7167
# Epoch1000
#  test_indoor_acc=0.8595317602157593
#  test_outdoor_acc=0.7417197227478027
#  test_belt_acc=0.7166817784309387
# 29/29 [==============================] - 5s 143ms/step - loss: 0.7443 - accuracy: 0.8579
# 50/50 [==============================] - 7s 145ms/step - loss: 2.1315 - accuracy: 0.7389
# 35/35 [==============================] - 5s 146ms/step - loss: 2.1854 - accuracy: 0.7162
# Epoch1200
#  test_indoor_acc=0.8578595519065857
#  test_outdoor_acc=0.7388535141944885
#  test_belt_acc=0.7162284851074219
# 29/29 [==============================] - 7s 140ms/step - loss: 0.7598 - accuracy: 0.8612
# 50/50 [==============================] - 7s 141ms/step - loss: 2.1645 - accuracy: 0.7398
# 35/35 [==============================] - 5s 142ms/step - loss: 2.2410 - accuracy: 0.7140
# Epoch1400
#  test_indoor_acc=0.8612040281295776
#  test_outdoor_acc=0.7398089170455933
#  test_belt_acc=0.7139618992805481
# 29/29 [==============================] - 5s 143ms/step - loss: 0.7760 - accuracy: 0.8601
# 50/50 [==============================] - 7s 145ms/step - loss: 2.2021 - accuracy: 0.7411
# 35/35 [==============================] - 5s 146ms/step - loss: 2.2936 - accuracy: 0.7162
# Epoch1600
#  test_indoor_acc=0.8600891828536987
#  test_outdoor_acc=0.7410827875137329
#  test_belt_acc=0.7162284851074219
# 29/29 [==============================] - 5s 143ms/step - loss: 0.7867 - accuracy: 0.8595
# 50/50 [==============================] - 7s 144ms/step - loss: 2.2303 - accuracy: 0.7417
# 35/35 [==============================] - 5s 145ms/step - loss: 2.3061 - accuracy: 0.7153
# Epoch1800
#  test_indoor_acc=0.8595317602157593
#  test_outdoor_acc=0.7417197227478027
#  test_belt_acc=0.7153218388557434
# 29/29 [==============================] - 5s 140ms/step - loss: 0.7981 - accuracy: 0.8590
# 50/50 [==============================] - 7s 142ms/step - loss: 2.2654 - accuracy: 0.7420
# 35/35 [==============================] - 5s 142ms/step - loss: 2.3323 - accuracy: 0.7158
# Epoch2000
#  test_indoor_acc=0.8589743375778198
#  test_outdoor_acc=0.7420381903648376
#  test_belt_acc=0.7157751321792603

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7729731599489847
# max index -> 2
# The [Epoch] of max acc -> 600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8584169745445251,
#  0.8578595519065857,
#  0.8589743375778198,
#  0.8584169745445251,
#  0.8595317602157593,
#  0.8578595519065857,
#  0.8612040281295776,
#  0.8600891828536987,
#  0.8595317602157593,
#  0.8589743375778198]

# %%
test_outdoor_acc
# Out:
# [0.7398089170455933,
#  0.7410827875137329,
#  0.7423567175865173,
#  0.7442675232887268,
#  0.7417197227478027,
#  0.7388535141944885,
#  0.7398089170455933,
#  0.7410827875137329,
#  0.7417197227478027,
#  0.7420381903648376]

# %%
test_belt_acc
# Out:
# [0.7184950113296509,
#  0.7171350717544556,
#  0.7175884246826172,
#  0.7162284851074219,
#  0.7166817784309387,
#  0.7162284851074219,
#  0.7139618992805481,
#  0.7162284851074219,
#  0.7153218388557434,
#  0.7157751321792603]

# %%
test_indoor_loss
# Out:
# [0.5371559858322144,
#  0.5891324877738953,
#  0.6442266702651978,
#  0.689707338809967,
#  0.7207058668136597,
#  0.7442739009857178,
#  0.7598357200622559,
#  0.7760348916053772,
#  0.7866767644882202,
#  0.7980654239654541]

# %%
test_outdoor_loss
# Out:
# [1.4250317811965942,
#  1.6166863441467285,
#  1.7621517181396484,
#  1.920047640800476,
#  2.0121371746063232,
#  2.1315011978149414,
#  2.164471387863159,
#  2.2021429538726807,
#  2.2303459644317627,
#  2.26540207862854]

# %%
test_belt_loss
# Out:
# [1.468005895614624,
#  1.657463788986206,
#  1.8369041681289673,
#  1.9953161478042603,
#  2.0926320552825928,
#  2.185358762741089,
#  2.2410199642181396,
#  2.293597459793091,
#  2.3061270713806152,
#  2.3322739601135254]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.97.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5455
# FP=1685
# acc=0.7640056022408963
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 78.44827586206897%
# 2WayConnectorforFoley acc = 87.07482993197279%
# 2WayFoleyCatheter acc = 70.1492537313433%
# 3WayConnectorforFoley acc = 92.3076923076923%
# 3Waystopcock acc = 98.1981981981982%
# AlcoholBottle acc = 85.625%
# AlcoholPad acc = 52.38095238095239%
# BootCover acc = 58.43373493975904%
# CottonBall acc = 80.23952095808383%
# CottonSwap acc = 79.02097902097903%
# Dilator acc = 73.50427350427351%
# DisposableInfusionSet acc = 51.32743362831859%
# ExtensionTube acc = 40.65040650406504%
# FaceShield acc = 83.33333333333334%
# FrontLoadSyringe acc = 74.33628318584071%
# GauzePad acc = 56.81818181818182%
# Glove acc = 77.97619047619048%
# GuideWire acc = 34.82142857142857%
# LiquidBottle acc = 66.03053435114504%
# Mask acc = 94.28571428571428%
# NGTube acc = 41.935483870967744%
# NasalCannula acc = 68.14159292035397%
# Needle acc = 85.35714285714285%
# OxygenMask acc = 92.4812030075188%
# PPESuit acc = 91.93548387096774%
# PharmaceuticalProduct acc = 58.177570093457945%
# Pill acc = 97.61904761904762%
# PillBottle acc = 84.49612403100775%
# PrefilledHumidifier acc = 90.5982905982906%
# PressureConnectingTube acc = 58.01526717557252%
# ReusableHumidifier acc = 72.03389830508475%
# SodiumChlorideBag acc = 88.9763779527559%
# SterileHumidifierAdapter acc = 70.9090909090909%
# SurgicalBlade acc = 86.72566371681415%
# SurgicalCap acc = 88.28828828828829%
# SurgicalSuit acc = 54.54545454545454%
# Syringe acc = 96.95817490494296%
# TrachealTube acc = 36.69724770642202%
# UrineBag acc = 61.66666666666667%
# Vaccinebottle acc = 84.03755868544602%
# WingedInfusionSet acc = 71.05263157894737%
#
#
#
# all_avg_eachclass = 73.55147503155567%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 91,   0,   0, ...,   0,   0,   0],
#        [  2, 128,   0, ...,   0,   0,   0],
#        [  0,   0,  94, ...,   0,   1,  19],
#        ...,
#        [  0,   0,   0, ...,  74,   1,   0],
#        [  0,   0,   0, ...,   1, 179,   0],
#        [  0,   0,   0, ...,   0,   0,  81]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[78.44827586,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.36054422, 87.07482993,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 70.14925373, ...,  0.        ,
#          0.74626866, 14.17910448],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 61.66666667,
#          0.83333333,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.46948357,
#         84.03755869,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 71.05263158]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
