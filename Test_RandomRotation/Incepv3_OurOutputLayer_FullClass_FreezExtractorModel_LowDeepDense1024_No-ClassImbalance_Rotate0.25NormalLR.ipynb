# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.25),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 332ms/step - loss: 1.3212 - accuracy: 0.6514 - val_loss: 0.5290 - val_accuracy: 0.8642
# Epoch 2/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.3712 - accuracy: 0.8863 - val_loss: 0.3519 - val_accuracy: 0.8887
# Epoch 3/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.2436 - accuracy: 0.9241 - val_loss: 0.3411 - val_accuracy: 0.8875
# Epoch 4/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.1880 - accuracy: 0.9415 - val_loss: 0.3673 - val_accuracy: 0.8784
# Epoch 5/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.1565 - accuracy: 0.9522 - val_loss: 0.2417 - val_accuracy: 0.9237
# Epoch 6/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0870 - accuracy: 0.9748 - val_loss: 0.2047 - val_accuracy: 0.9366
# Epoch 7/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0546 - accuracy: 0.9868 - val_loss: 0.2131 - val_accuracy: 0.9301
# Epoch 8/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0467 - accuracy: 0.9877 - val_loss: 0.2571 - val_accuracy: 0.9224
# Epoch 9/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0431 - accuracy: 0.9910 - val_loss: 0.1897 - val_accuracy: 0.9263
# Epoch 10/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0315 - accuracy: 0.9939 - val_loss: 0.1994 - val_accuracy: 0.9327
# Epoch 11/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0257 - accuracy: 0.9945 - val_loss: 0.2338 - val_accuracy: 0.9250
# Epoch 12/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0189 - accuracy: 0.9977 - val_loss: 0.1586 - val_accuracy: 0.9483
# Epoch 13/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0112 - accuracy: 0.9994 - val_loss: 0.1751 - val_accuracy: 0.9418
# Epoch 14/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0085 - accuracy: 0.9997 - val_loss: 0.1470 - val_accuracy: 0.9457
# Epoch 15/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0061 - accuracy: 0.9997 - val_loss: 0.1553 - val_accuracy: 0.9495
# Epoch 16/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0074 - accuracy: 0.9994 - val_loss: 0.1504 - val_accuracy: 0.9483
# Epoch 17/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9534
# Epoch 18/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9457
# Epoch 19/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9483
# Epoch 20/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9534
# Epoch 21/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1350 - val_accuracy: 0.9547
# Epoch 22/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9508
# Epoch 23/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9521
# Epoch 24/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9495
# Epoch 25/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9483
# Epoch 26/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9483
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 27/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9508
# Epoch 28/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9508
# Epoch 29/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9495
# Epoch 30/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9508
# Epoch 31/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9508
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 32/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9495
# Epoch 33/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9495
# Epoch 34/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9495
# Epoch 35/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9495
# Epoch 36/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 37/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 38/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 39/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 40/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 41/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 42/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9495
# Epoch 43/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9495
# Epoch 44/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9495
# Epoch 45/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9495
# Epoch 46/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 47/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 48/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 49/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 50/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 51/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 52/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 53/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 54/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 55/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 56/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 57/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 58/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9495
# Epoch 59/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9495
# Epoch 60/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9495
# Epoch 61/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9495
# Epoch 62/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9495
# Epoch 63/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9495
# Epoch 64/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9495
# Epoch 65/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9495
# Epoch 66/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 67/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 68/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 69/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9495
# Epoch 70/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 71/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 72/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9508
# Epoch 73/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 74/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 75/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9495
# Epoch 76/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9508
# Epoch 77/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9495
# Epoch 78/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9483
# Epoch 79/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9495
# Epoch 80/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9470
# Epoch 81/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9483
# Epoch 82/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9483
# Epoch 83/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 84/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 85/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 86/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 87/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9470
# Epoch 88/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9470
# Epoch 89/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 90/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9495
# Epoch 91/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9483
# Epoch 92/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9495
# Epoch 93/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9495
# Epoch 94/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9508
# Epoch 95/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9470
# Epoch 96/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9495
# Epoch 97/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9457
# Epoch 98/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9495
# Epoch 99/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9495
# Epoch 100/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 101/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9495
# Epoch 102/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 103/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9470
# Epoch 104/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9483
# Epoch 105/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9495
# Epoch 106/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9508
# Epoch 107/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9495
# Epoch 108/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9483
# Epoch 109/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9521
# Epoch 110/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9508
# Epoch 111/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9508
# Epoch 112/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9483
# Epoch 113/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9483
# Epoch 114/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9483
# Epoch 115/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9508
# Epoch 116/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9470
# Epoch 117/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9534
# Epoch 118/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9534
# Epoch 119/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 9.7932e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9534
# Epoch 120/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 121/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9483
# Epoch 122/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9521
# Epoch 123/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9495
# Epoch 124/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9508
# Epoch 125/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9508
# Epoch 126/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 9.9429e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9521
# Epoch 127/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 9.4840e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9508
# Epoch 128/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.8757e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9508
# Epoch 129/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.7110e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9534
# Epoch 130/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9521
# Epoch 131/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 9.2474e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9521
# Epoch 132/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 133/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.4372e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9508
# Epoch 134/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.6202e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 135/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9495
# Epoch 136/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9508
# Epoch 137/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.0917e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9508
# Epoch 138/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.0994e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9508
# Epoch 139/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.2379e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9495
# Epoch 140/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9495
# Epoch 141/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.9975e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9483
# Epoch 142/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.1577e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9508
# Epoch 143/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.6294e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 144/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.5655e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9495
# Epoch 145/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.3826e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9521
# Epoch 146/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.8372e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9508
# Epoch 147/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.2654e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 148/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.8339e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9508
# Epoch 149/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.3648e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9521
# Epoch 150/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.3216e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9495
# Epoch 151/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.7623e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9508
# Epoch 152/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.5528e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9495
# Epoch 153/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 8.6738e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 154/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.7637e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9483
# Epoch 155/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8613e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9508
# Epoch 156/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.5978e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9521
# Epoch 157/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.6252e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9534
# Epoch 158/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.0929e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9508
# Epoch 159/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.2753e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9521
# Epoch 160/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.8217e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9521
# Epoch 161/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.3889e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9534
# Epoch 162/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.2904e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9547
# Epoch 163/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.3486e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9495
# Epoch 164/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.9002e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9495
# Epoch 165/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.9058e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9508
# Epoch 166/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.2370e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9495
# Epoch 167/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0860e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9508
# Epoch 168/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5581e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9483
# Epoch 169/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.5477e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9495
# Epoch 170/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.9696e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9483
# Epoch 171/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 7.9456e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9508
# Epoch 172/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 6.9255e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9508
# Epoch 173/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.6090e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9508
# Epoch 174/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 8.1523e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9521
# Epoch 175/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.6367e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9508
# Epoch 176/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 6.5367e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9508
# Epoch 177/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 7.4130e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9508
# Epoch 178/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0446e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9521
# Epoch 179/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0039e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9508
# Epoch 180/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.7009e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9534
# Epoch 181/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.7182e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9521
# Epoch 182/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.7395e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9521
# Epoch 183/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.5853e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9508
# Epoch 184/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.6941e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9508
# Epoch 185/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 6.5588e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9508
# Epoch 186/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 7.1875e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9521
# Epoch 187/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 7.5185e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9508
# Epoch 188/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.0358e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9495
# Epoch 189/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 7.1011e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9508
# Epoch 190/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0753e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9508
# Epoch 191/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.6646e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9508
# Epoch 192/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.9112e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9495
# Epoch 193/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.8972e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9521
# Epoch 194/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.5865e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9508
# Epoch 195/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.3025e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9508
# Epoch 196/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.1460e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9521
# Epoch 197/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0549e-04 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9521
# Epoch 198/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0829e-04 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 0.9521
# Epoch 199/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.8198e-04 - accuracy: 1.0000 - val_loss: 0.1374 - val_accuracy: 0.9534
# Epoch 200/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 6.0743e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9521
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.95.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 169ms/step - loss: 5.9806e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9495
# Epoch 202/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 5.4361e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9508
# Epoch 203/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 5.6912e-04 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9560
# Epoch 204/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.5071e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9534
# Epoch 205/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 5.6373e-04 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9521
# Epoch 206/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.4360e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9521
# Epoch 207/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.3836e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9508
# Epoch 208/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.8154e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9521
# Epoch 209/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.4658e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9534
# Epoch 210/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.8114e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9495
# Epoch 211/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.5524e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9534
# Epoch 212/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.3603e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 213/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.0403e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9508
# Epoch 214/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.5590e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9534
# Epoch 215/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9627e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9521
# Epoch 216/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.4560e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9521
# Epoch 217/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.7241e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9521
# Epoch 218/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9469e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9547
# Epoch 219/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.0387e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9534
# Epoch 220/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9005e-04 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 0.9534
# Epoch 221/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9058e-04 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 0.9547
# Epoch 222/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.7485e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9534
# Epoch 223/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.8150e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9521
# Epoch 224/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.0638e-04 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9534
# Epoch 225/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 5.1929e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9534
# Epoch 226/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4002e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 227/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 4.8696e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9547
# Epoch 228/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.9170e-04 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 0.9534
# Epoch 229/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.5813e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 230/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.5218e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9534
# Epoch 231/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.0489e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 232/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4349e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9560
# Epoch 233/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 4.2604e-04 - accuracy: 1.0000 - val_loss: 0.1381 - val_accuracy: 0.9521
# Epoch 234/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4332e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9534
# Epoch 235/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 4.3768e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 236/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.3071e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9534
# Epoch 237/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.4789e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9521
# Epoch 238/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.2519e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9547
# Epoch 239/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.2517e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9534
# Epoch 240/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 4.0246e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9560
# Epoch 241/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.8580e-04 - accuracy: 1.0000 - val_loss: 0.1363 - val_accuracy: 0.9547
# Epoch 242/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.7998e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9547
# Epoch 243/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.1861e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.9521
# Epoch 244/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8703e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9547
# Epoch 245/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.7153e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9547
# Epoch 246/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.2099e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9534
# Epoch 247/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 4.0079e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 248/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8016e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9521
# Epoch 249/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 4.0226e-04 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9534
# Epoch 250/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.5544e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9521
# Epoch 251/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 3.4880e-04 - accuracy: 1.0000 - val_loss: 0.1378 - val_accuracy: 0.9508
# Epoch 252/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.6516e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9521
# Epoch 253/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.6152e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9534
# Epoch 254/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.7584e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9495
# Epoch 255/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.8831e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9508
# Epoch 256/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.5503e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 257/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4489e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9521
# Epoch 258/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1256e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9534
# Epoch 259/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4145e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9547
# Epoch 260/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2227e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9508
# Epoch 261/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4198e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9508
# Epoch 262/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4986e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9521
# Epoch 263/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1695e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9547
# Epoch 264/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1943e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9547
# Epoch 265/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4016e-04 - accuracy: 1.0000 - val_loss: 0.1385 - val_accuracy: 0.9534
# Epoch 266/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2699e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9534
# Epoch 267/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.3209e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9560
# Epoch 268/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.3489e-04 - accuracy: 1.0000 - val_loss: 0.1391 - val_accuracy: 0.9547
# Epoch 269/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2657e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9534
# Epoch 270/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2105e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9573
# Epoch 271/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2434e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.9547
# Epoch 272/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1851e-04 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9547
# Epoch 273/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9752e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9534
# Epoch 274/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0176e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9521
# Epoch 275/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8626e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9534
# Epoch 276/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9250e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9547
# Epoch 277/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8085e-04 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9547
# Epoch 278/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6413e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9547
# Epoch 279/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8266e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9547
# Epoch 280/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.7774e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9547
# Epoch 281/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8005e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9547
# Epoch 282/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6580e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.9560
# Epoch 283/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5831e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9534
# Epoch 284/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9911e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9547
# Epoch 285/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5750e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9547
# Epoch 286/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4875e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9560
# Epoch 287/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8023e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9534
# Epoch 288/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8780e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9586
# Epoch 289/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8527e-04 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9560
# Epoch 290/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.5195e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9534
# Epoch 291/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.7941e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9534
# Epoch 292/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.7209e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9547
# Epoch 293/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5176e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9547
# Epoch 294/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.5511e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9547
# Epoch 295/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6081e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9547
# Epoch 296/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.3670e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9573
# Epoch 297/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3047e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9560
# Epoch 298/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2421e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9547
# Epoch 299/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3588e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9547
# Epoch 300/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4458e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9547
# Epoch 301/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2445e-04 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9547
# Epoch 302/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5734e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9508
# Epoch 303/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.3744e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9534
# Epoch 304/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1520e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9534
# Epoch 305/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1271e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9547
# Epoch 306/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1615e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9534
# Epoch 307/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.2751e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9534
# Epoch 308/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3265e-04 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 0.9534
# Epoch 309/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1749e-04 - accuracy: 1.0000 - val_loss: 0.1388 - val_accuracy: 0.9547
# Epoch 310/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.0503e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.9547
# Epoch 311/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.1527e-04 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 0.9534
# Epoch 312/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1646e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9534
# Epoch 313/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2112e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9521
# Epoch 314/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 1.9657e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9534
# Epoch 315/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1177e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9534
# Epoch 316/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.1209e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 317/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9126e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9534
# Epoch 318/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9335e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9521
# Epoch 319/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.0789e-04 - accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9547
# Epoch 320/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9127e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9547
# Epoch 321/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4231e-07 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9573
# Epoch 1898/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4785e-07 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9586
# Epoch 1899/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4678e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9573
# Epoch 1900/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8159e-07 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9573
# Epoch 1901/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0355e-07 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9586
# Epoch 1902/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.6247e-07 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 0.9586
# Epoch 1903/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4782e-07 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9573
# Epoch 1904/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8036e-07 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9586
# Epoch 1905/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2856e-07 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9586
# Epoch 1906/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6168e-07 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9586
# Epoch 1907/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4396e-07 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9586
# Epoch 1908/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.7801e-07 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9586
# Epoch 1909/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2525e-07 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9586
# Epoch 1910/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.2712e-07 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 0.9586
# Epoch 1911/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6515e-07 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9586
# Epoch 1912/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6465e-07 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9573
# Epoch 1913/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4504e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9586
# Epoch 1914/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4215e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9586
# Epoch 1915/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1280e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9586
# Epoch 1916/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9492e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9586
# Epoch 1917/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.6566e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9586
# Epoch 1918/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8418e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9586
# Epoch 1919/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3422e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9586
# Epoch 1920/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2139e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9586
# Epoch 1921/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6476e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9586
# Epoch 1922/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.0802e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9586
# Epoch 1923/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.8681e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9586
# Epoch 1924/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6226e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9599
# Epoch 1925/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.0740e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9599
# Epoch 1926/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1144e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9586
# Epoch 1927/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7836e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9586
# Epoch 1928/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7674e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9586
# Epoch 1929/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6349e-07 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9586
# Epoch 1930/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6137e-07 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9586
# Epoch 1931/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5637e-07 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9586
# Epoch 1932/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2393e-07 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9586
# Epoch 1933/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1491e-07 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9586
# Epoch 1934/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4862e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9586
# Epoch 1935/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.0314e-07 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9586
# Epoch 1936/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.2631e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9586
# Epoch 1937/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7913e-07 - accuracy: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9586
# Epoch 1938/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6615e-07 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9586
# Epoch 1939/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6314e-07 - accuracy: 1.0000 - val_loss: 0.1975 - val_accuracy: 0.9586
# Epoch 1940/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7759e-07 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9573
# Epoch 1941/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5968e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9573
# Epoch 1942/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8410e-07 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9586
# Epoch 1943/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2979e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9573
# Epoch 1944/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2998e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9573
# Epoch 1945/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3395e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9573
# Epoch 1946/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3742e-07 - accuracy: 1.0000 - val_loss: 0.1970 - val_accuracy: 0.9586
# Epoch 1947/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3626e-07 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9586
# Epoch 1948/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.7859e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9586
# Epoch 1949/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.0333e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9586
# Epoch 1950/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5094e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9586
# Epoch 1951/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2139e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9586
# Epoch 1952/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4335e-07 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9586
# Epoch 1953/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9954e-07 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9586
# Epoch 1954/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.8922e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9586
# Epoch 1955/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2863e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9586
# Epoch 1956/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1800e-07 - accuracy: 1.0000 - val_loss: 0.1999 - val_accuracy: 0.9586
# Epoch 1957/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.7951e-07 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9573
# Epoch 1958/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6680e-07 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9586
# Epoch 1959/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1550e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9586
# Epoch 1960/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.1244e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9586
# Epoch 1961/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2871e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9586
# Epoch 1962/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3075e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9586
# Epoch 1963/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.4936e-07 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9573
# Epoch 1964/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6207e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9573
# Epoch 1965/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2698e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9586
# Epoch 1966/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2998e-07 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9586
# Epoch 1967/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3980e-07 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9573
# Epoch 1968/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3091e-07 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9586
# Epoch 1969/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 3.1233e-07 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9586
# Epoch 1970/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.2763e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9599
# Epoch 1971/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.9981e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9599
# Epoch 1972/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1854e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9599
# Epoch 1973/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.5648e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9599
# Epoch 1974/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1535e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9599
# Epoch 1975/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3098e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9586
# Epoch 1976/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2031e-07 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 0.9586
# Epoch 1977/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.1423e-07 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9586
# Epoch 1978/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.9923e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9586
# Epoch 1979/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9670e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9586
# Epoch 1980/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3303e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9586
# Epoch 1981/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4797e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9586
# Epoch 1982/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4747e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9573
# Epoch 1983/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.6018e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9586
# Epoch 1984/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6075e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9586
# Epoch 1985/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4393e-07 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9599
# Epoch 1986/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 3.4995e-07 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 0.9586
# Epoch 1987/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.3360e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9586
# Epoch 1988/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6168e-07 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9586
# Epoch 1989/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4932e-07 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9586
# Epoch 1990/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 1.9274e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9586
# Epoch 1991/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.2937e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9586
# Epoch 1992/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 1.9955e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9586
# Epoch 1993/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6164e-07 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9586
# Epoch 1994/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3849e-07 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9586
# Epoch 1995/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.6141e-07 - accuracy: 1.0000 - val_loss: 0.1981 - val_accuracy: 0.9586
# Epoch 1996/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.1122e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9573
# Epoch 1997/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.3299e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9573
# Epoch 1998/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.5841e-07 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9573
# Epoch 1999/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 2.8317e-07 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9573
# Epoch 2000/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 2.4196e-07 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.9573
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 340ms/step - loss: 0.8609 - accuracy: 0.8473
# test_indoor_ds_results:test loss, test acc: [0.8609130382537842, 0.8472687005996704]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 447ms/step - loss: 2.3388 - accuracy: 0.7325
# test_outdoor_ds_results:test loss, test acc: [2.3387975692749023, 0.7324841022491455]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 202ms/step - loss: 2.3535 - accuracy: 0.7126
# test_belt_ds_results:test loss, test acc: [2.353543996810913, 0.7126020193099976]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate250-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 135ms/step - loss: 0.5860 - accuracy: 0.8439
# 50/50 [==============================] - 7s 137ms/step - loss: 1.4682 - accuracy: 0.7334
# 35/35 [==============================] - 5s 134ms/step - loss: 1.4933 - accuracy: 0.7053
# Epoch200
#  test_indoor_acc=0.8439241647720337
#  test_outdoor_acc=0.7334395051002502
#  test_belt_acc=0.7053490281105042
# 29/29 [==============================] - 5s 132ms/step - loss: 0.6334 - accuracy: 0.8428
# 50/50 [==============================] - 7s 134ms/step - loss: 1.6383 - accuracy: 0.7366
# 35/35 [==============================] - 5s 134ms/step - loss: 1.6811 - accuracy: 0.7063
# Epoch400
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.7366241812705994
#  test_belt_acc=0.7062556743621826
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6934 - accuracy: 0.8372
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8097 - accuracy: 0.7347
# 35/35 [==============================] - 5s 138ms/step - loss: 1.8635 - accuracy: 0.7067
# Epoch600
#  test_indoor_acc=0.8372352123260498
#  test_outdoor_acc=0.7347133755683899
#  test_belt_acc=0.7067089676856995
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7325 - accuracy: 0.8428
# 50/50 [==============================] - 7s 134ms/step - loss: 1.9692 - accuracy: 0.7338
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9797 - accuracy: 0.7117
# Epoch800
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.7337579727172852
#  test_belt_acc=0.7116953730583191
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7670 - accuracy: 0.8439
# 50/50 [==============================] - 7s 135ms/step - loss: 2.0748 - accuracy: 0.7341
# 35/35 [==============================] - 5s 135ms/step - loss: 2.0851 - accuracy: 0.7126
# Epoch1000
#  test_indoor_acc=0.8439241647720337
#  test_outdoor_acc=0.7340764403343201
#  test_belt_acc=0.7126020193099976
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7911 - accuracy: 0.8450
# 50/50 [==============================] - 7s 136ms/step - loss: 2.1382 - accuracy: 0.7341
# 35/35 [==============================] - 5s 136ms/step - loss: 2.1592 - accuracy: 0.7144
# Epoch1200
#  test_indoor_acc=0.8450390100479126
#  test_outdoor_acc=0.7340764403343201
#  test_belt_acc=0.7144152522087097
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8081 - accuracy: 0.8445
# 50/50 [==============================] - 7s 135ms/step - loss: 2.2001 - accuracy: 0.7341
# 35/35 [==============================] - 5s 136ms/step - loss: 2.2200 - accuracy: 0.7121
# Epoch1400
#  test_indoor_acc=0.8444815874099731
#  test_outdoor_acc=0.7340764403343201
#  test_belt_acc=0.7121486663818359
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8238 - accuracy: 0.8473
# 50/50 [==============================] - 7s 135ms/step - loss: 2.2291 - accuracy: 0.7338
# 35/35 [==============================] - 5s 136ms/step - loss: 2.2832 - accuracy: 0.7131
# Epoch1600
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7337579727172852
#  test_belt_acc=0.7130553126335144
# 29/29 [==============================] - 5s 132ms/step - loss: 0.8488 - accuracy: 0.8450
# 50/50 [==============================] - 7s 133ms/step - loss: 2.2897 - accuracy: 0.7344
# 35/35 [==============================] - 5s 134ms/step - loss: 2.3245 - accuracy: 0.7131
# Epoch1800
#  test_indoor_acc=0.8450390100479126
#  test_outdoor_acc=0.734394907951355
#  test_belt_acc=0.7130553126335144
# 29/29 [==============================] - 5s 134ms/step - loss: 0.8609 - accuracy: 0.8473
# 50/50 [==============================] - 7s 135ms/step - loss: 2.3388 - accuracy: 0.7325
# 35/35 [==============================] - 5s 136ms/step - loss: 2.3535 - accuracy: 0.7126
# Epoch2000
#  test_indoor_acc=0.8472687005996704
#  test_outdoor_acc=0.7324841022491455
#  test_belt_acc=0.7126020193099976

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7646939953168234
# max index -> 7
# The [Epoch] of max acc -> 1600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8439241647720337,
#  0.8428093791007996,
#  0.8372352123260498,
#  0.8428093791007996,
#  0.8439241647720337,
#  0.8450390100479126,
#  0.8444815874099731,
#  0.8472687005996704,
#  0.8450390100479126,
#  0.8472687005996704]

# %%
test_outdoor_acc
# Out:
# [0.7334395051002502,
#  0.7366241812705994,
#  0.7347133755683899,
#  0.7337579727172852,
#  0.7340764403343201,
#  0.7340764403343201,
#  0.7340764403343201,
#  0.7337579727172852,
#  0.734394907951355,
#  0.7324841022491455]

# %%
test_belt_acc
# Out:
# [0.7053490281105042,
#  0.7062556743621826,
#  0.7067089676856995,
#  0.7116953730583191,
#  0.7126020193099976,
#  0.7144152522087097,
#  0.7121486663818359,
#  0.7130553126335144,
#  0.7130553126335144,
#  0.7126020193099976]

# %%
test_indoor_loss
# Out:
# [0.5859597325325012,
#  0.6333972215652466,
#  0.6934298276901245,
#  0.7325271964073181,
#  0.7670173645019531,
#  0.7910894751548767,
#  0.8080907464027405,
#  0.823833167552948,
#  0.848755419254303,
#  0.8609130382537842]

# %%
test_outdoor_loss
# Out:
# [1.468205213546753,
#  1.638270616531372,
#  1.8097496032714844,
#  1.9692490100860596,
#  2.0747857093811035,
#  2.1381587982177734,
#  2.2001214027404785,
#  2.229130983352661,
#  2.2896971702575684,
#  2.3387975692749023]

# %%
test_belt_loss
# Out:
# [1.493330955505371,
#  1.6810917854309082,
#  1.863464117050171,
#  1.9796991348266602,
#  2.085055351257324,
#  2.159245491027832,
#  2.2199676036834717,
#  2.2831923961639404,
#  2.3244853019714355,
#  2.353543996810913]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.96.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5397
# FP=1743
# acc=0.7558823529411764
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 67.24137931034483%
# 2WayConnectorforFoley acc = 89.79591836734694%
# 2WayFoleyCatheter acc = 73.88059701492537%
# 3WayConnectorforFoley acc = 88.03418803418803%
# 3Waystopcock acc = 100.0%
# AlcoholBottle acc = 86.25%
# AlcoholPad acc = 50.79365079365079%
# BootCover acc = 59.63855421686747%
# CottonBall acc = 85.62874251497006%
# CottonSwap acc = 74.12587412587412%
# Dilator acc = 70.08547008547008%
# DisposableInfusionSet acc = 51.32743362831859%
# ExtensionTube acc = 29.268292682926827%
# FaceShield acc = 82.71604938271605%
# FrontLoadSyringe acc = 61.06194690265486%
# GauzePad acc = 56.25%
# Glove acc = 78.27380952380952%
# GuideWire acc = 32.142857142857146%
# LiquidBottle acc = 60.68702290076335%
# Mask acc = 94.54545454545455%
# NGTube acc = 38.70967741935484%
# NasalCannula acc = 54.86725663716814%
# Needle acc = 88.92857142857142%
# OxygenMask acc = 93.98496240601504%
# PPESuit acc = 87.09677419354838%
# PharmaceuticalProduct acc = 60.981308411214954%
# Pill acc = 96.63865546218487%
# PillBottle acc = 73.64341085271317%
# PrefilledHumidifier acc = 84.61538461538461%
# PressureConnectingTube acc = 61.06870229007634%
# ReusableHumidifier acc = 83.89830508474576%
# SodiumChlorideBag acc = 81.88976377952756%
# SterileHumidifierAdapter acc = 84.54545454545455%
# SurgicalBlade acc = 89.38053097345133%
# SurgicalCap acc = 90.09009009009009%
# SurgicalSuit acc = 48.484848484848484%
# Syringe acc = 97.33840304182509%
# TrachealTube acc = 38.53211009174312%
# UrineBag acc = 69.16666666666667%
# Vaccinebottle acc = 82.15962441314554%
# WingedInfusionSet acc = 68.42105263157895%
#
#
#
# all_avg_eachclass = 72.34606816323041%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 78,   6,   0, ...,   0,   1,   0],
#        [  1, 132,   0, ...,   0,   0,   0],
#        [  0,   0,  99, ...,   0,   2,   9],
#        ...,
#        [  0,   0,   0, ...,  83,   0,   0],
#        [  0,   0,   0, ...,   0, 175,   0],
#        [  0,   0,   1, ...,   1,   1,  78]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[67.24137931,  5.17241379,  0.        , ...,  0.        ,
#          0.86206897,  0.        ],
#        [ 0.68027211, 89.79591837,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 73.88059701, ...,  0.        ,
#          1.49253731,  6.71641791],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 69.16666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         82.15962441,  0.        ],
#        [ 0.        ,  0.        ,  0.87719298, ...,  0.87719298,
#          0.87719298, 68.42105263]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
