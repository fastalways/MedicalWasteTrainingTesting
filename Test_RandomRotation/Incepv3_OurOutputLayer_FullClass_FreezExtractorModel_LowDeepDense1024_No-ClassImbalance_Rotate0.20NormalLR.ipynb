# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.20),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 327ms/step - loss: 1.4935 - accuracy: 0.6145 - val_loss: 0.6640 - val_accuracy: 0.8008
# Epoch 2/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.4157 - accuracy: 0.8775 - val_loss: 0.3888 - val_accuracy: 0.8823
# Epoch 3/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.2374 - accuracy: 0.9312 - val_loss: 0.3617 - val_accuracy: 0.8823
# Epoch 4/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.1449 - accuracy: 0.9609 - val_loss: 0.2866 - val_accuracy: 0.9185
# Epoch 5/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0956 - accuracy: 0.9761 - val_loss: 0.2857 - val_accuracy: 0.9185
# Epoch 6/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0739 - accuracy: 0.9822 - val_loss: 0.2940 - val_accuracy: 0.9146
# Epoch 7/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0690 - accuracy: 0.9851 - val_loss: 0.2972 - val_accuracy: 0.9107
# Epoch 8/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0654 - accuracy: 0.9832 - val_loss: 0.2206 - val_accuracy: 0.9353
# Epoch 9/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0532 - accuracy: 0.9855 - val_loss: 0.2716 - val_accuracy: 0.9094
# Epoch 10/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0449 - accuracy: 0.9877 - val_loss: 0.3138 - val_accuracy: 0.8965
# Epoch 11/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0509 - accuracy: 0.9864 - val_loss: 0.2011 - val_accuracy: 0.9483
# Epoch 12/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0326 - accuracy: 0.9922 - val_loss: 0.2007 - val_accuracy: 0.9250
# Epoch 13/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0221 - accuracy: 0.9961 - val_loss: 0.2248 - val_accuracy: 0.9211
# Epoch 14/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0143 - accuracy: 0.9977 - val_loss: 0.1823 - val_accuracy: 0.9353
# Epoch 15/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 0.1706 - val_accuracy: 0.9431
# Epoch 16/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0057 - accuracy: 0.9997 - val_loss: 0.1769 - val_accuracy: 0.9418
# Epoch 17/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9495
# Epoch 18/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 0.9547
# Epoch 19/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9534
# Epoch 20/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1645 - val_accuracy: 0.9508
# Epoch 21/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9521
# Epoch 22/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1603 - val_accuracy: 0.9534
# Epoch 23/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9534
# Epoch 24/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9560
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 25/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 26/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 27/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9534
# Epoch 28/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9534
# Epoch 29/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9521
# Epoch 30/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.9534
# Epoch 31/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9534
# Epoch 32/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 33/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9560
# Epoch 34/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9547
# Epoch 35/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 36/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 37/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 38/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9547
# Epoch 39/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9547
# Epoch 40/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 41/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 42/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 43/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9534
# Epoch 44/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 45/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 46/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 47/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 48/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9534
# Epoch 49/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9534
# Epoch 50/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9534
# Epoch 51/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9534
# Epoch 52/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 53/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 54/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 55/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9547
# Epoch 56/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 57/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9534
# Epoch 58/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9547
# Epoch 59/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9547
# Epoch 60/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 61/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 62/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 63/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 64/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 65/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9547
# Epoch 66/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 67/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9547
# Epoch 68/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9547
# Epoch 69/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9547
# Epoch 70/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9547
# Epoch 71/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9547
# Epoch 72/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9547
# Epoch 73/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9547
# Epoch 74/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 75/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9547
# Epoch 76/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9547
# Epoch 77/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9547
# Epoch 78/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9547
# Epoch 79/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9560
# Epoch 80/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9560
# Epoch 81/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 82/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9547
# Epoch 83/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9547
# Epoch 84/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9547
# Epoch 85/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9560
# Epoch 86/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9547
# Epoch 87/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 88/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 89/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9547
# Epoch 90/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 91/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9547
# Epoch 92/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9547
# Epoch 93/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 94/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9547
# Epoch 95/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 96/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9560
# Epoch 97/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 98/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9547
# Epoch 99/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9547
# Epoch 100/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9534
# Epoch 101/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9560
# Epoch 102/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9560
# Epoch 103/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9560
# Epoch 104/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9547
# Epoch 105/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9547
# Epoch 106/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 107/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 108/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9560
# Epoch 109/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9560
# Epoch 110/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9560
# Epoch 111/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9560
# Epoch 112/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9560
# Epoch 113/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9573
# Epoch 114/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9560
# Epoch 115/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9547
# Epoch 116/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9560
# Epoch 117/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9560
# Epoch 118/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9560
# Epoch 119/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9547
# Epoch 120/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9560
# Epoch 121/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9534
# Epoch 122/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 123/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9547
# Epoch 124/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9573
# Epoch 125/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9547
# Epoch 126/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9573
# Epoch 127/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9573
# Epoch 128/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9573
# Epoch 129/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9573
# Epoch 130/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9560
# Epoch 131/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9547
# Epoch 132/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.9409e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9560
# Epoch 133/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9547
# Epoch 134/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9547
# Epoch 135/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9547
# Epoch 136/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.4790e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9560
# Epoch 137/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.4318e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9560
# Epoch 138/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.9985e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9560
# Epoch 139/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9573
# Epoch 140/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.5768e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9547
# Epoch 141/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.8874e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9560
# Epoch 142/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.2245e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9573
# Epoch 143/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.3494e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9573
# Epoch 144/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9586
# Epoch 145/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.7454e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9560
# Epoch 146/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.7261e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9573
# Epoch 147/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.2883e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9560
# Epoch 148/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.1588e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9573
# Epoch 149/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9599
# Epoch 150/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9573
# Epoch 151/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9560
# Epoch 152/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.7440e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9547
# Epoch 153/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.8288e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9573
# Epoch 154/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.5970e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9599
# Epoch 155/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.8024e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9586
# Epoch 156/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.6495e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9586
# Epoch 157/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.2806e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9586
# Epoch 158/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.2744e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9586
# Epoch 159/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 9.2854e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9573
# Epoch 160/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.5473e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9586
# Epoch 161/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.3439e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9586
# Epoch 162/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.1621e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9573
# Epoch 163/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.1336e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9586
# Epoch 164/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.5088e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9586
# Epoch 165/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.4842e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9573
# Epoch 166/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.5870e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9573
# Epoch 167/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.3794e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9599
# Epoch 168/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.1436e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9586
# Epoch 169/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.9159e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9573
# Epoch 170/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.8816e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9586
# Epoch 171/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.8679e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9573
# Epoch 172/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 8.4066e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9573
# Epoch 173/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.6817e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9573
# Epoch 174/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.5653e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9573
# Epoch 175/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.8097e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9560
# Epoch 176/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.6679e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9560
# Epoch 177/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.9988e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9547
# Epoch 178/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.6230e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9560
# Epoch 179/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.6875e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9573
# Epoch 180/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.4817e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9586
# Epoch 181/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.2984e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9560
# Epoch 182/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.6569e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9586
# Epoch 183/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.4982e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9599
# Epoch 184/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.8098e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9586
# Epoch 185/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.1427e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9586
# Epoch 186/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.2209e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9560
# Epoch 187/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.6248e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9586
# Epoch 188/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.5663e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9586
# Epoch 189/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.0977e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9573
# Epoch 190/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.5175e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9573
# Epoch 191/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.9918e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9599
# Epoch 192/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.6021e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9586
# Epoch 193/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.9216e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9573
# Epoch 194/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.2222e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9573
# Epoch 195/2000
# 49/49 [==============================] - 9s 183ms/step - loss: 6.4157e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9560
# Epoch 196/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.8201e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9586
# Epoch 197/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.7793e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9573
# Epoch 198/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.3916e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9586
# Epoch 199/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.5737e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9573
# Epoch 200/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.2245e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9573
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.96.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 6.8445e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9573
# Epoch 202/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 6.4541e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9560
# Epoch 203/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 6.8863e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9586
# Epoch 204/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.6322e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9612
# Epoch 205/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 6.2016e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9599
# Epoch 206/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 6.4610e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9586
# Epoch 207/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.7802e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9573
# Epoch 208/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 6.2648e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9560
# Epoch 209/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 5.7952e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9573
# Epoch 210/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.1916e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9599
# Epoch 211/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.6747e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9612
# Epoch 212/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.8417e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9599
# Epoch 213/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.7289e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9586
# Epoch 214/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.8251e-04 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9586
# Epoch 215/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 5.2105e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9599
# Epoch 216/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.7361e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9612
# Epoch 217/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.0943e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9612
# Epoch 218/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.8829e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9599
# Epoch 219/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.9041e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9599
# Epoch 220/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.4459e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9586
# Epoch 221/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.9766e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9612
# Epoch 222/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.2577e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9612
# Epoch 223/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.7190e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9586
# Epoch 224/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.1818e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9586
# Epoch 225/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.1695e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9586
# Epoch 226/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 4.5877e-04 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9586
# Epoch 227/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.1441e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9599
# Epoch 228/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.8019e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9612
# Epoch 229/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.7550e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9586
# Epoch 230/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.0970e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9599
# Epoch 231/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.2909e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9638
# Epoch 232/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.7842e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9599
# Epoch 233/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.9030e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9612
# Epoch 234/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.1159e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9612
# Epoch 235/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.4081e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9599
# Epoch 236/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.8219e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9560
# Epoch 237/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.1408e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9573
# Epoch 238/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.8167e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9586
# Epoch 239/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.5738e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9586
# Epoch 240/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.5092e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9625
# Epoch 241/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.7726e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9625
# Epoch 242/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 4.7884e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9599
# Epoch 243/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.4179e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9586
# Epoch 244/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.1451e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9573
# Epoch 245/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.3288e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9612
# Epoch 246/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.3380e-04 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9612
# Epoch 247/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.3609e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9599
# Epoch 248/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 4.1479e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9560
# Epoch 249/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.0621e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9573
# Epoch 250/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.9645e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9599
# Epoch 251/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.1447e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9612
# Epoch 252/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 4.0350e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9599
# Epoch 253/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.0143e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9586
# Epoch 254/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.4771e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9586
# Epoch 255/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.9149e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9573
# Epoch 256/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.8170e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9573
# Epoch 257/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.8955e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9586
# Epoch 258/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.6635e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9573
# Epoch 259/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.5286e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9599
# Epoch 260/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.8322e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9599
# Epoch 261/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.9789e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9612
# Epoch 262/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.4041e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9599
# Epoch 263/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.7198e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9599
# Epoch 264/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.7058e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9612
# Epoch 265/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.6422e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9599
# Epoch 266/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.8596e-04 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 267/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.7089e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9586
# Epoch 268/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 3.6145e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9586
# Epoch 269/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 3.2807e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9599
# Epoch 270/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.8361e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9573
# Epoch 271/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.3864e-04 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9612
# Epoch 272/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.4032e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9586
# Epoch 273/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.3216e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9560
# Epoch 274/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.3523e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9586
# Epoch 275/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.1069e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9599
# Epoch 276/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 3.0606e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9625
# Epoch 277/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 3.3784e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9586
# Epoch 278/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.4979e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9612
# Epoch 279/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.2301e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9612
# Epoch 280/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8179e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9612
# Epoch 281/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.2295e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9612
# Epoch 282/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 2.9399e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9612
# Epoch 283/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 3.0416e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9599
# Epoch 284/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 3.1902e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9612
# Epoch 285/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 2.9115e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9599
# Epoch 286/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8726e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9612
# Epoch 287/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.1148e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9625
# Epoch 288/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8995e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9599
# Epoch 289/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8663e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9599
# Epoch 290/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.0182e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9638
# Epoch 291/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9233e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9599
# Epoch 292/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8242e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9599
# Epoch 293/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6320e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9612
# Epoch 294/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.0217e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9599
# Epoch 295/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7905e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9599
# Epoch 296/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7702e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9599
# Epoch 297/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7842e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9586
# Epoch 298/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6805e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9599
# Epoch 299/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5043e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9586
# Epoch 300/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3905e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9599
# Epoch 301/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5929e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9599
# Epoch 302/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6322e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9599
# Epoch 303/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8654e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9612
# Epoch 304/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6575e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9625
# Epoch 305/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4479e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9599
# Epoch 306/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3851e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9625
# Epoch 307/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6676e-04 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9586
# Epoch 308/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6752e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9612
# Epoch 309/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 2.4200e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9612
# Epoch 310/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 2.2127e-04 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9586
# Epoch 311/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3938e-04 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9612
# Epoch 312/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.1848e-04 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9599
# Epoch 313/2000
# 49/49 [==============================] - 9s 186ms/step - loss: 2.4172e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9599
# Epoch 314/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3504e-04 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9612
# Epoch 315/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3290e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9612
# Epoch 316/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.0905e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9599
# Epoch 317/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2958e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9612
# Epoch 318/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3654e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9599
# Epoch 319/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.0267e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9599
# Epoch 320/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2538e-04 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9586
# Epoch 321/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7520e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9586
# Epoch 1898/2000
# 49/49 [==============================] - 9s 184ms/step - loss: 3.1367e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9586
# Epoch 1899/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7593e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9586
# Epoch 1900/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.0463e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9586
# Epoch 1901/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7004e-07 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9586
# Epoch 1902/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.5192e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9586
# Epoch 1903/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.1495e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9586
# Epoch 1904/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6453e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9586
# Epoch 1905/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.4390e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9586
# Epoch 1906/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6357e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9586
# Epoch 1907/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4057e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9586
# Epoch 1908/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.2026e-07 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9586
# Epoch 1909/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8233e-07 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9586
# Epoch 1910/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6596e-07 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9586
# Epoch 1911/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.7010e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9586
# Epoch 1912/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8626e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9586
# Epoch 1913/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.2545e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9599
# Epoch 1914/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5155e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9586
# Epoch 1915/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7304e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9599
# Epoch 1916/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5382e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9599
# Epoch 1917/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4088e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9599
# Epoch 1918/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3626e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9599
# Epoch 1919/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7805e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9586
# Epoch 1920/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.9547e-07 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9586
# Epoch 1921/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2259e-07 - accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9599
# Epoch 1922/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 1.2168e-06 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9599
# Epoch 1923/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9561e-07 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9599
# Epoch 1924/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 5.0992e-07 - accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9599
# Epoch 1925/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9685e-07 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9599
# Epoch 1926/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.3093e-07 - accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9599
# Epoch 1927/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3179e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9599
# Epoch 1928/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9280e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9599
# Epoch 1929/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8021e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9599
# Epoch 1930/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 8.2928e-07 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9612
# Epoch 1931/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8495e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9612
# Epoch 1932/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6969e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9612
# Epoch 1933/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7663e-07 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9612
# Epoch 1934/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.1865e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9612
# Epoch 1935/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9700e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9612
# Epoch 1936/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5028e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9612
# Epoch 1937/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8787e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9612
# Epoch 1938/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7555e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9612
# Epoch 1939/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 4.7752e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9612
# Epoch 1940/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9754e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9612
# Epoch 1941/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8826e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9599
# Epoch 1942/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2351e-07 - accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9599
# Epoch 1943/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4019e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9586
# Epoch 1944/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3445e-07 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9586
# Epoch 1945/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.2754e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9612
# Epoch 1946/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6407e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9612
# Epoch 1947/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.1496e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9612
# Epoch 1948/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3984e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9599
# Epoch 1949/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.7244e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9612
# Epoch 1950/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4354e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9612
# Epoch 1951/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7031e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9612
# Epoch 1952/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4816e-07 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9612
# Epoch 1953/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9211e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9612
# Epoch 1954/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.3101e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9599
# Epoch 1955/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3164e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9599
# Epoch 1956/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6588e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9599
# Epoch 1957/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2833e-07 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9599
# Epoch 1958/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6815e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9586
# Epoch 1959/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7085e-07 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9586
# Epoch 1960/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4851e-07 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9599
# Epoch 1961/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8302e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9599
# Epoch 1962/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6503e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9586
# Epoch 1963/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.0701e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9586
# Epoch 1964/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5105e-07 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9599
# Epoch 1965/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3210e-07 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9599
# Epoch 1966/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6992e-07 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9586
# Epoch 1967/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 1.7953e-07 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9586
# Epoch 1968/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3449e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9586
# Epoch 1969/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5136e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9586
# Epoch 1970/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.7341e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9586
# Epoch 1971/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.1766e-07 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9586
# Epoch 1972/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8845e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9586
# Epoch 1973/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.0720e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9586
# Epoch 1974/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.1488e-07 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9586
# Epoch 1975/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.9319e-07 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9573
# Epoch 1976/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.4359e-07 - accuracy: 1.0000 - val_loss: 0.2103 - val_accuracy: 0.9573
# Epoch 1977/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7893e-07 - accuracy: 1.0000 - val_loss: 0.2097 - val_accuracy: 0.9586
# Epoch 1978/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2586e-07 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9586
# Epoch 1979/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.2924e-07 - accuracy: 1.0000 - val_loss: 0.2095 - val_accuracy: 0.9586
# Epoch 1980/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.7971e-07 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9586
# Epoch 1981/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3060e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9586
# Epoch 1982/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.1904e-07 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9586
# Epoch 1983/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5910e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9599
# Epoch 1984/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3106e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9599
# Epoch 1985/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5529e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9586
# Epoch 1986/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4466e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9599
# Epoch 1987/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.3258e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9586
# Epoch 1988/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2309e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9586
# Epoch 1989/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.8144e-07 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9586
# Epoch 1990/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3029e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9586
# Epoch 1991/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 3.1547e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9599
# Epoch 1992/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4550e-07 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9599
# Epoch 1993/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4400e-07 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9586
# Epoch 1994/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6068e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9586
# Epoch 1995/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.2347e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9586
# Epoch 1996/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.5232e-07 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9586
# Epoch 1997/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.6950e-07 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9586
# Epoch 1998/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3803e-07 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9586
# Epoch 1999/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.3776e-07 - accuracy: 1.0000 - val_loss: 0.2107 - val_accuracy: 0.9586
# Epoch 2000/2000
# 49/49 [==============================] - 9s 185ms/step - loss: 2.4377e-07 - accuracy: 1.0000 - val_loss: 0.2108 - val_accuracy: 0.9586
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 333ms/step - loss: 0.9396 - accuracy: 0.8283
# test_indoor_ds_results:test loss, test acc: [0.9395923018455505, 0.8283166289329529]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 420ms/step - loss: 2.3707 - accuracy: 0.7229
# test_outdoor_ds_results:test loss, test acc: [2.3707053661346436, 0.7229299545288086]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 202ms/step - loss: 2.4654 - accuracy: 0.7081
# test_belt_ds_results:test loss, test acc: [2.465362310409546, 0.7080689072608948]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate200-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 142ms/step - loss: 0.6408 - accuracy: 0.8244
# 50/50 [==============================] - 7s 144ms/step - loss: 1.4615 - accuracy: 0.7223
# 35/35 [==============================] - 5s 144ms/step - loss: 1.5683 - accuracy: 0.6972
# Epoch200
#  test_indoor_acc=0.8244147300720215
#  test_outdoor_acc=0.7222930192947388
#  test_belt_acc=0.6971895098686218
# 29/29 [==============================] - 5s 142ms/step - loss: 0.6899 - accuracy: 0.8227
# 50/50 [==============================] - 7s 143ms/step - loss: 1.6366 - accuracy: 0.7226
# 35/35 [==============================] - 5s 144ms/step - loss: 1.7453 - accuracy: 0.7026
# Epoch400
#  test_indoor_acc=0.8227424621582031
#  test_outdoor_acc=0.7226114869117737
#  test_belt_acc=0.7026292085647583
# 29/29 [==============================] - 7s 143ms/step - loss: 0.7582 - accuracy: 0.8233
# 50/50 [==============================] - 7s 144ms/step - loss: 1.8100 - accuracy: 0.7258
# 35/35 [==============================] - 5s 145ms/step - loss: 1.8977 - accuracy: 0.7049
# Epoch600
#  test_indoor_acc=0.8232998847961426
#  test_outdoor_acc=0.7257961630821228
#  test_belt_acc=0.7048957347869873
# 29/29 [==============================] - 5s 141ms/step - loss: 0.7986 - accuracy: 0.8233
# 50/50 [==============================] - 7s 143ms/step - loss: 1.9407 - accuracy: 0.7280
# 35/35 [==============================] - 5s 144ms/step - loss: 2.0560 - accuracy: 0.7044
# Epoch800
#  test_indoor_acc=0.8232998847961426
#  test_outdoor_acc=0.728025496006012
#  test_belt_acc=0.7044424414634705
# 29/29 [==============================] - 5s 143ms/step - loss: 0.8414 - accuracy: 0.8239
# 50/50 [==============================] - 7s 145ms/step - loss: 2.0602 - accuracy: 0.7252
# 35/35 [==============================] - 5s 145ms/step - loss: 2.1965 - accuracy: 0.7013
# Epoch1000
#  test_indoor_acc=0.823857307434082
#  test_outdoor_acc=0.725159227848053
#  test_belt_acc=0.701269268989563
# 29/29 [==============================] - 5s 142ms/step - loss: 0.8617 - accuracy: 0.8289
# 50/50 [==============================] - 7s 144ms/step - loss: 2.1561 - accuracy: 0.7268
# 35/35 [==============================] - 5s 144ms/step - loss: 2.2632 - accuracy: 0.7072
# Epoch1200
#  test_indoor_acc=0.8288740515708923
#  test_outdoor_acc=0.7267515659332275
#  test_belt_acc=0.7071622610092163
# 29/29 [==============================] - 5s 140ms/step - loss: 0.9039 - accuracy: 0.8272
# 50/50 [==============================] - 7s 142ms/step - loss: 2.2525 - accuracy: 0.7252
# 35/35 [==============================] - 5s 143ms/step - loss: 2.3493 - accuracy: 0.7035
# Epoch1400
#  test_indoor_acc=0.827201783657074
#  test_outdoor_acc=0.725159227848053
#  test_belt_acc=0.703535795211792
# 29/29 [==============================] - 5s 143ms/step - loss: 0.9188 - accuracy: 0.8283
# 50/50 [==============================] - 7s 144ms/step - loss: 2.2800 - accuracy: 0.7252
# 35/35 [==============================] - 5s 145ms/step - loss: 2.4017 - accuracy: 0.7053
# Epoch1600
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.725159227848053
#  test_belt_acc=0.7053490281105042
# 29/29 [==============================] - 5s 143ms/step - loss: 0.9254 - accuracy: 0.8255
# 50/50 [==============================] - 7s 145ms/step - loss: 2.3282 - accuracy: 0.7242
# 35/35 [==============================] - 5s 145ms/step - loss: 2.4439 - accuracy: 0.7063
# Epoch1800
#  test_indoor_acc=0.8255295157432556
#  test_outdoor_acc=0.7242038249969482
#  test_belt_acc=0.7062556743621826
# 29/29 [==============================] - 5s 142ms/step - loss: 0.9396 - accuracy: 0.8283
# 50/50 [==============================] - 7s 144ms/step - loss: 2.3707 - accuracy: 0.7229
# 35/35 [==============================] - 5s 144ms/step - loss: 2.4654 - accuracy: 0.7081
# Epoch2000
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.7229299545288086
#  test_belt_acc=0.7080689072608948

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7542626261711121
# max index -> 5
# The [Epoch] of max acc -> 1200

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8244147300720215,
#  0.8227424621582031,
#  0.8232998847961426,
#  0.8232998847961426,
#  0.823857307434082,
#  0.8288740515708923,
#  0.827201783657074,
#  0.8283166289329529,
#  0.8255295157432556,
#  0.8283166289329529]

# %%
test_outdoor_acc
# Out:
# [0.7222930192947388,
#  0.7226114869117737,
#  0.7257961630821228,
#  0.728025496006012,
#  0.725159227848053,
#  0.7267515659332275,
#  0.725159227848053,
#  0.725159227848053,
#  0.7242038249969482,
#  0.7229299545288086]

# %%
test_belt_acc
# Out:
# [0.6971895098686218,
#  0.7026292085647583,
#  0.7048957347869873,
#  0.7044424414634705,
#  0.701269268989563,
#  0.7071622610092163,
#  0.703535795211792,
#  0.7053490281105042,
#  0.7062556743621826,
#  0.7080689072608948]

# %%
test_indoor_loss
# Out:
# [0.6408098936080933,
#  0.6899271011352539,
#  0.7581710815429688,
#  0.7985809445381165,
#  0.841385543346405,
#  0.8616577982902527,
#  0.9038687348365784,
#  0.9187507033348083,
#  0.9253564476966858,
#  0.9395923018455505]

# %%
test_outdoor_loss
# Out:
# [1.4615120887756348,
#  1.6365509033203125,
#  1.8100274801254272,
#  1.9406611919403076,
#  2.060157537460327,
#  2.1561038494110107,
#  2.2524869441986084,
#  2.2799975872039795,
#  2.3281543254852295,
#  2.3707053661346436]

# %%
test_belt_loss
# Out:
# [1.568284511566162,
#  1.7452541589736938,
#  1.8976918458938599,
#  2.0559566020965576,
#  2.196533203125,
#  2.2631964683532715,
#  2.3493266105651855,
#  2.4017369747161865,
#  2.4439306259155273,
#  2.465362310409546]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.96.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5329
# FP=1811
# acc=0.746358543417367
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 71.55172413793103%
# 2WayConnectorforFoley acc = 89.79591836734694%
# 2WayFoleyCatheter acc = 69.40298507462687%
# 3WayConnectorforFoley acc = 94.01709401709401%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 81.875%
# AlcoholPad acc = 54.761904761904766%
# BootCover acc = 60.24096385542169%
# CottonBall acc = 82.63473053892216%
# CottonSwap acc = 68.53146853146853%
# Dilator acc = 64.95726495726495%
# DisposableInfusionSet acc = 56.63716814159292%
# ExtensionTube acc = 24.390243902439025%
# FaceShield acc = 82.09876543209876%
# FrontLoadSyringe acc = 40.707964601769916%
# GauzePad acc = 47.159090909090914%
# Glove acc = 74.10714285714286%
# GuideWire acc = 25.892857142857146%
# LiquidBottle acc = 67.55725190839695%
# Mask acc = 95.58441558441558%
# NGTube acc = 43.87096774193549%
# NasalCannula acc = 59.29203539823009%
# Needle acc = 86.42857142857143%
# OxygenMask acc = 96.99248120300751%
# PPESuit acc = 88.70967741935483%
# PharmaceuticalProduct acc = 55.84112149532711%
# Pill acc = 97.61904761904762%
# PillBottle acc = 78.29457364341084%
# PrefilledHumidifier acc = 67.52136752136752%
# PressureConnectingTube acc = 61.06870229007634%
# ReusableHumidifier acc = 88.98305084745762%
# SodiumChlorideBag acc = 82.67716535433071%
# SterileHumidifierAdapter acc = 77.27272727272727%
# SurgicalBlade acc = 89.38053097345133%
# SurgicalCap acc = 89.1891891891892%
# SurgicalSuit acc = 50.0%
# Syringe acc = 96.57794676806084%
# TrachealTube acc = 44.95412844036697%
# UrineBag acc = 68.33333333333333%
# Vaccinebottle acc = 83.56807511737088%
# WingedInfusionSet acc = 64.91228070175438%
#
#
#
# all_avg_eachclass = 71.2802445751038%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 83,   0,   0, ...,   0,   2,   0],
#        [  1, 132,   0, ...,   0,   0,   0],
#        [  0,   0,  93, ...,   0,   1,  11],
#        ...,
#        [  0,   0,   0, ...,  82,   0,   0],
#        [  0,   0,   0, ...,   0, 178,   0],
#        [  0,   0,   0, ...,   0,   2,  74]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[71.55172414,  0.        ,  0.        , ...,  0.        ,
#          1.72413793,  0.        ],
#        [ 0.68027211, 89.79591837,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 69.40298507, ...,  0.        ,
#          0.74626866,  8.20895522],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 68.33333333,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         83.56807512,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          1.75438596, 64.9122807 ]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
