# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.15),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 330ms/step - loss: 1.5123 - accuracy: 0.6120 - val_loss: 0.6956 - val_accuracy: 0.7865
# Epoch 2/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.4028 - accuracy: 0.8811 - val_loss: 0.4229 - val_accuracy: 0.8745
# Epoch 3/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.2319 - accuracy: 0.9299 - val_loss: 0.3248 - val_accuracy: 0.8926
# Epoch 4/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.1612 - accuracy: 0.9551 - val_loss: 0.3414 - val_accuracy: 0.8875
# Epoch 5/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1007 - accuracy: 0.9761 - val_loss: 0.2417 - val_accuracy: 0.9301
# Epoch 6/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0871 - accuracy: 0.9761 - val_loss: 0.2488 - val_accuracy: 0.9211
# Epoch 7/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0709 - accuracy: 0.9800 - val_loss: 0.2598 - val_accuracy: 0.9198
# Epoch 8/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0571 - accuracy: 0.9880 - val_loss: 0.2128 - val_accuracy: 0.9340
# Epoch 9/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0498 - accuracy: 0.9864 - val_loss: 0.1992 - val_accuracy: 0.9418
# Epoch 10/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0261 - accuracy: 0.9958 - val_loss: 0.1777 - val_accuracy: 0.9534
# Epoch 11/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0222 - accuracy: 0.9971 - val_loss: 0.1939 - val_accuracy: 0.9392
# Epoch 12/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0169 - accuracy: 0.9984 - val_loss: 0.1708 - val_accuracy: 0.9483
# Epoch 13/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0151 - accuracy: 0.9984 - val_loss: 0.1777 - val_accuracy: 0.9444
# Epoch 14/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0136 - accuracy: 0.9984 - val_loss: 0.1691 - val_accuracy: 0.9444
# Epoch 15/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0121 - accuracy: 0.9987 - val_loss: 0.1639 - val_accuracy: 0.9444
# Epoch 16/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.1677 - val_accuracy: 0.9431
# Epoch 17/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.1586 - val_accuracy: 0.9470
# Epoch 18/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.1791 - val_accuracy: 0.9431
# Epoch 19/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.1570 - val_accuracy: 0.9418
# Epoch 20/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9418
# Epoch 21/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.9405
# Epoch 22/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.1562 - val_accuracy: 0.9470
# Epoch 23/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.9444
# Epoch 24/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9495
# Epoch 25/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2032 - val_accuracy: 0.9444
# Epoch 26/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.1906 - val_accuracy: 0.9457
# Epoch 27/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1710 - val_accuracy: 0.9470
# Epoch 28/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9521
# Epoch 29/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1465 - val_accuracy: 0.9457
# Epoch 30/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.1368 - val_accuracy: 0.9547
# Epoch 31/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9534
# Epoch 32/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9521
# Epoch 33/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9560
# Epoch 34/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9547
# Epoch 35/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 9.9082e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9534
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 36/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 37/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 8.0252e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 38/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.4891e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9560
# Epoch 39/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 8.0404e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9573
# Epoch 40/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.2609e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9534
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 41/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 8.5237e-04 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 0.9534
# Epoch 42/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.8365e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9560
# Epoch 43/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3587e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 44/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3333e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9586
# Epoch 45/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.9608e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9560
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 46/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.2385e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9560
# Epoch 47/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.5003e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9547
# Epoch 48/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.3042e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9560
# Epoch 49/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.0226e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 50/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.1568e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9547
# Epoch 51/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.4443e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 52/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.9309e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 53/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.1678e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 54/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.6017e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9534
# Epoch 55/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.8812e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 56/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.1270e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9534
# Epoch 57/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 7.8385e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9534
# Epoch 58/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.1879e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9573
# Epoch 59/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1627e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9573
# Epoch 60/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4503e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9573
# Epoch 61/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3067e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9560
# Epoch 62/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3295e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9560
# Epoch 63/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.1126e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9560
# Epoch 64/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.7712e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9560
# Epoch 65/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.8436e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9560
# Epoch 66/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9514e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9560
# Epoch 67/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.9277e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9560
# Epoch 68/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.4366e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9560
# Epoch 69/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.8172e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 70/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9814e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 71/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.7484e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 72/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.5118e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 73/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.3221e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9547
# Epoch 74/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.4994e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9547
# Epoch 75/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.5669e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9547
# Epoch 76/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.5081e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9560
# Epoch 77/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.0418e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9560
# Epoch 78/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.2796e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 79/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.3764e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9534
# Epoch 80/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8501e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9560
# Epoch 81/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7924e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9560
# Epoch 82/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4567e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 83/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.0412e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9573
# Epoch 84/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6188e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9560
# Epoch 85/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9052e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9586
# Epoch 86/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5577e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9560
# Epoch 87/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1686e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9573
# Epoch 88/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9961e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9573
# Epoch 89/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1550e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9534
# Epoch 90/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9607e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9573
# Epoch 91/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1303e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9560
# Epoch 92/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.7264e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9560
# Epoch 93/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6694e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9560
# Epoch 94/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7189e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 95/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4268e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9547
# Epoch 96/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1204e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9534
# Epoch 97/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.7413e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 98/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1072e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9573
# Epoch 99/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.9167e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9573
# Epoch 100/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6729e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9573
# Epoch 101/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.2991e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9560
# Epoch 102/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1073e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 103/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.7343e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 104/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.4221e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 105/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.2685e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9560
# Epoch 106/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.5377e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9560
# Epoch 107/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.0317e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9547
# Epoch 108/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.1639e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 109/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.4123e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 110/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.1872e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9547
# Epoch 111/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8914e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9534
# Epoch 112/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.8771e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9521
# Epoch 113/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.7792e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9521
# Epoch 114/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.6737e-04 - accuracy: 1.0000 - val_loss: 0.1422 - val_accuracy: 0.9521
# Epoch 115/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.7989e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9534
# Epoch 116/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.0300e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9534
# Epoch 117/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.4304e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9547
# Epoch 118/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.9771e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9534
# Epoch 119/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4114e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9560
# Epoch 120/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.8901e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9534
# Epoch 121/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.7973e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9560
# Epoch 122/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.9871e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9547
# Epoch 123/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.1257e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9534
# Epoch 124/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.1156e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9547
# Epoch 125/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.8666e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9534
# Epoch 126/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 6.1505e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 127/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.4843e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9534
# Epoch 128/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.1317e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9547
# Epoch 129/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 7.0283e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9560
# Epoch 130/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.6796e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9573
# Epoch 131/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.0722e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9560
# Epoch 132/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.3572e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9547
# Epoch 133/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.3293e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9547
# Epoch 134/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.4098e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9586
# Epoch 135/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.6450e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9560
# Epoch 136/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.8241e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9534
# Epoch 137/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8207e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9534
# Epoch 138/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8217e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9534
# Epoch 139/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.7258e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9560
# Epoch 140/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.5906e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9560
# Epoch 141/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.8601e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9547
# Epoch 142/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 6.1632e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9534
# Epoch 143/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.8416e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9560
# Epoch 144/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.4348e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9560
# Epoch 145/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.0354e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9547
# Epoch 146/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.6452e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9534
# Epoch 147/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.0671e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9547
# Epoch 148/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.3814e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9521
# Epoch 149/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.5897e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9534
# Epoch 150/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.8945e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9534
# Epoch 151/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.8032e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9547
# Epoch 152/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.9838e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9560
# Epoch 153/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.6369e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9573
# Epoch 154/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.5499e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9560
# Epoch 155/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 6.2950e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9560
# Epoch 156/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.6929e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9586
# Epoch 157/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.4019e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9560
# Epoch 158/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.3636e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9560
# Epoch 159/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.0223e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9547
# Epoch 160/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.9769e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9560
# Epoch 161/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.0232e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9560
# Epoch 162/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.8435e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9560
# Epoch 163/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.8494e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9547
# Epoch 164/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.2652e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9547
# Epoch 165/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 5.2809e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9534
# Epoch 166/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.8466e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9547
# Epoch 167/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.2806e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9573
# Epoch 168/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.9003e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9573
# Epoch 169/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.8798e-04 - accuracy: 1.0000 - val_loss: 0.1383 - val_accuracy: 0.9586
# Epoch 170/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.3694e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9599
# Epoch 171/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.9176e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9560
# Epoch 172/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.5833e-04 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.9547
# Epoch 173/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.7143e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9586
# Epoch 174/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.5183e-04 - accuracy: 1.0000 - val_loss: 0.1389 - val_accuracy: 0.9560
# Epoch 175/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 5.2263e-04 - accuracy: 1.0000 - val_loss: 0.1377 - val_accuracy: 0.9599
# Epoch 176/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.7458e-04 - accuracy: 1.0000 - val_loss: 0.1387 - val_accuracy: 0.9573
# Epoch 177/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 7.6786e-04 - accuracy: 0.9997 - val_loss: 0.1353 - val_accuracy: 0.9547
# Epoch 178/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.3807e-04 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9547
# Epoch 179/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.9872e-04 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9560
# Epoch 180/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.9803e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9547
# Epoch 181/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.7834e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9547
# Epoch 182/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.9273e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9573
# Epoch 183/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.3518e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9573
# Epoch 184/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.5678e-04 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 0.9586
# Epoch 185/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.5344e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9547
# Epoch 186/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.7024e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9547
# Epoch 187/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.6908e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 188/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.2357e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9560
# Epoch 189/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.5528e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9521
# Epoch 190/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.3380e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9547
# Epoch 191/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.6439e-04 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9534
# Epoch 192/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.0981e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9560
# Epoch 193/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.3054e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9547
# Epoch 194/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.8125e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9547
# Epoch 195/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.0312e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9560
# Epoch 196/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.4592e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9534
# Epoch 197/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.1218e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9534
# Epoch 198/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.3519e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9534
# Epoch 199/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.9016e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9534
# Epoch 200/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.9248e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9534
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.95.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.8558e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9534
# Epoch 202/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.9786e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9534
# Epoch 203/2000
# 49/49 [==============================] - 9s 179ms/step - loss: 4.2018e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9521
# Epoch 204/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.6009e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9547
# Epoch 205/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.8341e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 206/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.8405e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9521
# Epoch 207/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.7884e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9521
# Epoch 208/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.5404e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 209/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.6433e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9534
# Epoch 210/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.9427e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 211/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.7368e-04 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9573
# Epoch 212/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.3832e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9521
# Epoch 213/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.4392e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9534
# Epoch 214/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.4489e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 215/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.7501e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9534
# Epoch 216/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 4.0201e-04 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9560
# Epoch 217/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.8135e-04 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9547
# Epoch 218/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.3521e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9521
# Epoch 219/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1099e-04 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9586
# Epoch 220/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.4558e-04 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 0.9573
# Epoch 221/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.4461e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9534
# Epoch 222/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.4912e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9534
# Epoch 223/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1457e-04 - accuracy: 1.0000 - val_loss: 0.1411 - val_accuracy: 0.9586
# Epoch 224/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.4041e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9547
# Epoch 225/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.2138e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9508
# Epoch 226/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.0228e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9521
# Epoch 227/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.2745e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9547
# Epoch 228/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.3752e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9508
# Epoch 229/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.3063e-04 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9547
# Epoch 230/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.1231e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9534
# Epoch 231/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.9474e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9534
# Epoch 232/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.2431e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 233/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1487e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9573
# Epoch 234/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.5365e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9534
# Epoch 235/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.1665e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9508
# Epoch 236/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.3680e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9521
# Epoch 237/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.1182e-04 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9534
# Epoch 238/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.1315e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9547
# Epoch 239/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.0218e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9560
# Epoch 240/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.2649e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9547
# Epoch 241/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7984e-04 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 0.9560
# Epoch 242/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9395e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9508
# Epoch 243/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.0960e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9521
# Epoch 244/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.1125e-04 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9560
# Epoch 245/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.8713e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9521
# Epoch 246/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.9753e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9508
# Epoch 247/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9810e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9547
# Epoch 248/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7273e-04 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9534
# Epoch 249/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.4317e-04 - accuracy: 1.0000 - val_loss: 0.1419 - val_accuracy: 0.9573
# Epoch 250/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.9981e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9521
# Epoch 251/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.7377e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9573
# Epoch 252/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.7066e-04 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 0.9560
# Epoch 253/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5891e-04 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9547
# Epoch 254/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.6775e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9547
# Epoch 255/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.7470e-04 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 0.9508
# Epoch 256/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.6779e-04 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9521
# Epoch 257/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.3703e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9534
# Epoch 258/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.4553e-04 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9534
# Epoch 259/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2682e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9495
# Epoch 260/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.4811e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9560
# Epoch 261/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.8722e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9560
# Epoch 262/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5273e-04 - accuracy: 1.0000 - val_loss: 0.1439 - val_accuracy: 0.9547
# Epoch 263/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.5637e-04 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9534
# Epoch 264/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5278e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9560
# Epoch 265/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.9689e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9521
# Epoch 266/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4656e-04 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9573
# Epoch 267/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.3265e-04 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9586
# Epoch 268/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.3843e-04 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9547
# Epoch 269/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.3042e-04 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9534
# Epoch 270/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.5365e-04 - accuracy: 1.0000 - val_loss: 0.1425 - val_accuracy: 0.9586
# Epoch 271/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2364e-04 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 0.9560
# Epoch 272/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.8456e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9495
# Epoch 273/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.3490e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9547
# Epoch 274/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.9121e-04 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9560
# Epoch 275/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.2209e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9547
# Epoch 276/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.2652e-04 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9547
# Epoch 277/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.1983e-04 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 0.9521
# Epoch 278/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.3049e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9534
# Epoch 279/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2840e-04 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 0.9534
# Epoch 280/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.9820e-04 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9534
# Epoch 281/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.9891e-04 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9534
# Epoch 282/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.9311e-04 - accuracy: 1.0000 - val_loss: 0.1446 - val_accuracy: 0.9508
# Epoch 283/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.2132e-04 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9560
# Epoch 284/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.0849e-04 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 0.9560
# Epoch 285/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.0597e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9612
# Epoch 286/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.0213e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9573
# Epoch 287/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.9273e-04 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9547
# Epoch 288/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2826e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9547
# Epoch 289/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.0551e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9547
# Epoch 290/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.8651e-04 - accuracy: 1.0000 - val_loss: 0.1432 - val_accuracy: 0.9534
# Epoch 291/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1430e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9508
# Epoch 292/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.7557e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9521
# Epoch 293/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.7646e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9521
# Epoch 294/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.0473e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9547
# Epoch 295/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 2.0652e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9573
# Epoch 296/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.9981e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9547
# Epoch 297/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.7813e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9547
# Epoch 298/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.8583e-04 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 0.9586
# Epoch 299/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.7191e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 300/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.8071e-04 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 0.9534
# Epoch 301/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.9756e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9586
# Epoch 302/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.5907e-04 - accuracy: 1.0000 - val_loss: 0.1464 - val_accuracy: 0.9573
# Epoch 303/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.7037e-04 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9560
# Epoch 304/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.8727e-04 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9547
# Epoch 305/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.8169e-04 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9508
# Epoch 306/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.7510e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9547
# Epoch 307/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.8360e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9560
# Epoch 308/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.6169e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9547
# Epoch 309/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.8701e-04 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9508
# Epoch 310/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.5810e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9521
# Epoch 311/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.7551e-04 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9560
# Epoch 312/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.6157e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9534
# Epoch 313/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.6252e-04 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9534
# Epoch 314/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.4346e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9534
# Epoch 315/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.5742e-04 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9534
# Epoch 316/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.5858e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9560
# Epoch 317/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 1.6603e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9547
# Epoch 318/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6461e-07 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9560
# Epoch 1898/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.2018e-07 - accuracy: 1.0000 - val_loss: 0.1912 - val_accuracy: 0.9560
# Epoch 1899/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7478e-07 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9560
# Epoch 1900/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7763e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9560
# Epoch 1901/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1187e-07 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9560
# Epoch 1902/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5317e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9560
# Epoch 1903/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.8480e-07 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9560
# Epoch 1904/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9488e-07 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9560
# Epoch 1905/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6618e-07 - accuracy: 1.0000 - val_loss: 0.1868 - val_accuracy: 0.9560
# Epoch 1906/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6819e-07 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9573
# Epoch 1907/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9885e-07 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9573
# Epoch 1908/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6719e-07 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 0.9560
# Epoch 1909/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9469e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9560
# Epoch 1910/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6126e-07 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9560
# Epoch 1911/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1693e-07 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9560
# Epoch 1912/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5864e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9560
# Epoch 1913/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5086e-07 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9560
# Epoch 1914/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9357e-07 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9560
# Epoch 1915/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9280e-07 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9560
# Epoch 1916/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9881e-07 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9560
# Epoch 1917/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.8556e-07 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9560
# Epoch 1918/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6080e-07 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9560
# Epoch 1919/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.0994e-07 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9560
# Epoch 1920/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.0144e-07 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9573
# Epoch 1921/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.3239e-07 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9573
# Epoch 1922/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7208e-07 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9560
# Epoch 1923/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4886e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9560
# Epoch 1924/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2451e-07 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9573
# Epoch 1925/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1758e-07 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9573
# Epoch 1926/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2505e-07 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9573
# Epoch 1927/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2509e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9573
# Epoch 1928/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4581e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9573
# Epoch 1929/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4466e-07 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9573
# Epoch 1930/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6395e-07 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9560
# Epoch 1931/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1141e-07 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9547
# Epoch 1932/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5594e-07 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9560
# Epoch 1933/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5432e-07 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9560
# Epoch 1934/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4031e-07 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9560
# Epoch 1935/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3295e-07 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9560
# Epoch 1936/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1102e-07 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9547
# Epoch 1937/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.4968e-07 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9521
# Epoch 1938/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2170e-07 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9534
# Epoch 1939/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3888e-07 - accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.9534
# Epoch 1940/2000
# 49/49 [==============================] - 9s 180ms/step - loss: 3.1083e-07 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9534
# Epoch 1941/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5987e-07 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.9534
# Epoch 1942/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6407e-07 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9534
# Epoch 1943/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5895e-07 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9534
# Epoch 1944/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 3.2951e-07 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9534
# Epoch 1945/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4604e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9534
# Epoch 1946/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4720e-07 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9534
# Epoch 1947/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4974e-07 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9534
# Epoch 1948/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4543e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9534
# Epoch 1949/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7670e-07 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9547
# Epoch 1950/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4450e-07 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 0.9534
# Epoch 1951/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2336e-07 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9534
# Epoch 1952/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5090e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9534
# Epoch 1953/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 4.5779e-07 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9547
# Epoch 1954/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.8522e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9560
# Epoch 1955/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6850e-07 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9560
# Epoch 1956/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.0999e-07 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9560
# Epoch 1957/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.0737e-07 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9547
# Epoch 1958/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2139e-07 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9547
# Epoch 1959/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5201e-07 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9560
# Epoch 1960/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6326e-07 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9560
# Epoch 1961/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4597e-07 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9560
# Epoch 1962/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3349e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9560
# Epoch 1963/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3453e-07 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9560
# Epoch 1964/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9330e-07 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9560
# Epoch 1965/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6157e-07 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9560
# Epoch 1966/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 5.6123e-07 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9560
# Epoch 1967/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.0868e-07 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9560
# Epoch 1968/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6080e-07 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9560
# Epoch 1969/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2232e-07 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9560
# Epoch 1970/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.8078e-07 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.9560
# Epoch 1971/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4812e-07 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9560
# Epoch 1972/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.0274e-07 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9560
# Epoch 1973/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9854e-07 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9560
# Epoch 1974/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4997e-07 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9547
# Epoch 1975/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1746e-07 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9547
# Epoch 1976/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.1217e-07 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9547
# Epoch 1977/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.6522e-07 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9547
# Epoch 1978/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7489e-07 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9547
# Epoch 1979/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4535e-07 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9547
# Epoch 1980/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5113e-07 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9547
# Epoch 1981/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 3.2342e-07 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9560
# Epoch 1982/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3356e-07 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9560
# Epoch 1983/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1727e-07 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9560
# Epoch 1984/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.0464e-07 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9560
# Epoch 1985/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.7894e-07 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9560
# Epoch 1986/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3141e-07 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9560
# Epoch 1987/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5328e-07 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9560
# Epoch 1988/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2055e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9560
# Epoch 1989/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.9515e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9560
# Epoch 1990/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3934e-07 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9560
# Epoch 1991/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.8426e-07 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9560
# Epoch 1992/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5941e-07 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9560
# Epoch 1993/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.3168e-07 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9599
# Epoch 1994/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.4019e-07 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9599
# Epoch 1995/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.1142e-07 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9573
# Epoch 1996/2000
# 49/49 [==============================] - 9s 182ms/step - loss: 2.8587e-07 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9560
# Epoch 1997/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.7998e-07 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9560
# Epoch 1998/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 1.8831e-07 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9560
# Epoch 1999/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.2825e-07 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9560
# Epoch 2000/2000
# 49/49 [==============================] - 9s 181ms/step - loss: 2.5594e-07 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9560
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 333ms/step - loss: 1.0125 - accuracy: 0.8300
# test_indoor_ds_results:test loss, test acc: [1.0125062465667725, 0.8299888372421265]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 422ms/step - loss: 2.5094 - accuracy: 0.7226
# test_outdoor_ds_results:test loss, test acc: [2.5093722343444824, 0.7226114869117737]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 196ms/step - loss: 2.4299 - accuracy: 0.7126
# test_belt_ds_results:test loss, test acc: [2.4298653602600098, 0.7126020193099976]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.95.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate150-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6831 - accuracy: 0.8283
# 50/50 [==============================] - 7s 137ms/step - loss: 1.6043 - accuracy: 0.7194
# 35/35 [==============================] - 5s 136ms/step - loss: 1.5721 - accuracy: 0.7067
# Epoch200
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.7194267511367798
#  test_belt_acc=0.7067089676856995
# 29/29 [==============================] - 5s 133ms/step - loss: 0.7540 - accuracy: 0.8239
# 50/50 [==============================] - 7s 134ms/step - loss: 1.7913 - accuracy: 0.7178
# 35/35 [==============================] - 5s 135ms/step - loss: 1.7504 - accuracy: 0.7049
# Epoch400
#  test_indoor_acc=0.823857307434082
#  test_outdoor_acc=0.7178344130516052
#  test_belt_acc=0.7048957347869873
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8052 - accuracy: 0.8278
# 50/50 [==============================] - 7s 135ms/step - loss: 1.9717 - accuracy: 0.7178
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9090 - accuracy: 0.7085
# Epoch600
#  test_indoor_acc=0.8277592062950134
#  test_outdoor_acc=0.7178344130516052
#  test_belt_acc=0.7085222005844116
# 29/29 [==============================] - 5s 133ms/step - loss: 0.8525 - accuracy: 0.8283
# 50/50 [==============================] - 7s 135ms/step - loss: 2.1001 - accuracy: 0.7210
# 35/35 [==============================] - 5s 135ms/step - loss: 2.0408 - accuracy: 0.7126
# Epoch800
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.7210190892219543
#  test_belt_acc=0.7126020193099976
# 29/29 [==============================] - 5s 132ms/step - loss: 0.9131 - accuracy: 0.8283
# 50/50 [==============================] - 7s 133ms/step - loss: 2.2244 - accuracy: 0.7188
# 35/35 [==============================] - 5s 134ms/step - loss: 2.1647 - accuracy: 0.7072
# Epoch1000
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.71878981590271
#  test_belt_acc=0.7071622610092163
# 29/29 [==============================] - 5s 132ms/step - loss: 0.9401 - accuracy: 0.8322
# 50/50 [==============================] - 7s 134ms/step - loss: 2.3203 - accuracy: 0.7185
# 35/35 [==============================] - 5s 134ms/step - loss: 2.2439 - accuracy: 0.7090
# Epoch1200
#  test_indoor_acc=0.8322185277938843
#  test_outdoor_acc=0.718471348285675
#  test_belt_acc=0.7089754939079285
# 29/29 [==============================] - 5s 132ms/step - loss: 0.9595 - accuracy: 0.8305
# 50/50 [==============================] - 7s 134ms/step - loss: 2.3674 - accuracy: 0.7220
# 35/35 [==============================] - 5s 135ms/step - loss: 2.2981 - accuracy: 0.7094
# Epoch1400
#  test_indoor_acc=0.8305462598800659
#  test_outdoor_acc=0.7219745516777039
#  test_belt_acc=0.7094288468360901
# 29/29 [==============================] - 5s 131ms/step - loss: 0.9860 - accuracy: 0.8294
# 50/50 [==============================] - 7s 132ms/step - loss: 2.4195 - accuracy: 0.7197
# 35/35 [==============================] - 5s 133ms/step - loss: 2.3598 - accuracy: 0.7081
# Epoch1600
#  test_indoor_acc=0.829431414604187
#  test_outdoor_acc=0.7197452187538147
#  test_belt_acc=0.7080689072608948
# 29/29 [==============================] - 5s 131ms/step - loss: 1.0049 - accuracy: 0.8305
# 50/50 [==============================] - 7s 132ms/step - loss: 2.4904 - accuracy: 0.7226
# 35/35 [==============================] - 5s 133ms/step - loss: 2.4282 - accuracy: 0.7090
# Epoch1800
#  test_indoor_acc=0.8305462598800659
#  test_outdoor_acc=0.7226114869117737
#  test_belt_acc=0.7089754939079285
# 29/29 [==============================] - 5s 132ms/step - loss: 1.0125 - accuracy: 0.8300
# 50/50 [==============================] - 7s 134ms/step - loss: 2.5094 - accuracy: 0.7226
# 35/35 [==============================] - 5s 134ms/step - loss: 2.4299 - accuracy: 0.7126
# Epoch2000
#  test_indoor_acc=0.8299888372421265
#  test_outdoor_acc=0.7226114869117737
#  test_belt_acc=0.7126020193099976

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7550674478212992
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8283166289329529,
#  0.823857307434082,
#  0.8277592062950134,
#  0.8283166289329529,
#  0.8283166289329529,
#  0.8322185277938843,
#  0.8305462598800659,
#  0.829431414604187,
#  0.8305462598800659,
#  0.8299888372421265]

# %%
test_outdoor_acc
# Out:
# [0.7194267511367798,
#  0.7178344130516052,
#  0.7178344130516052,
#  0.7210190892219543,
#  0.71878981590271,
#  0.718471348285675,
#  0.7219745516777039,
#  0.7197452187538147,
#  0.7226114869117737,
#  0.7226114869117737]

# %%
test_belt_acc
# Out:
# [0.7067089676856995,
#  0.7048957347869873,
#  0.7085222005844116,
#  0.7126020193099976,
#  0.7071622610092163,
#  0.7089754939079285,
#  0.7094288468360901,
#  0.7080689072608948,
#  0.7089754939079285,
#  0.7126020193099976]

# %%
test_indoor_loss
# Out:
# [0.6830670237541199,
#  0.7539609670639038,
#  0.8051589131355286,
#  0.8524910807609558,
#  0.9130843877792358,
#  0.940087080001831,
#  0.9595039486885071,
#  0.9859989285469055,
#  1.004879117012024,
#  1.0125062465667725]

# %%
test_outdoor_loss
# Out:
# [1.6043212413787842,
#  1.791310429573059,
#  1.971657395362854,
#  2.1001241207122803,
#  2.2243974208831787,
#  2.3203225135803223,
#  2.367377281188965,
#  2.4194884300231934,
#  2.4904489517211914,
#  2.5093722343444824]

# %%
test_belt_loss
# Out:
# [1.572094440460205,
#  1.7504072189331055,
#  1.908964991569519,
#  2.040766477584839,
#  2.1647136211395264,
#  2.243852376937866,
#  2.2981081008911133,
#  2.3597874641418457,
#  2.4281773567199707,
#  2.4298653602600098]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.96.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5328
# FP=1812
# acc=0.746218487394958
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 85.34482758620689%
# 2WayConnectorforFoley acc = 89.1156462585034%
# 2WayFoleyCatheter acc = 69.40298507462687%
# 3WayConnectorforFoley acc = 91.45299145299145%
# 3Waystopcock acc = 98.1981981981982%
# AlcoholBottle acc = 80.625%
# AlcoholPad acc = 53.96825396825397%
# BootCover acc = 56.024096385542165%
# CottonBall acc = 81.437125748503%
# CottonSwap acc = 74.12587412587412%
# Dilator acc = 76.92307692307693%
# DisposableInfusionSet acc = 42.47787610619469%
# ExtensionTube acc = 38.21138211382114%
# FaceShield acc = 82.71604938271605%
# FrontLoadSyringe acc = 42.47787610619469%
# GauzePad acc = 59.09090909090909%
# Glove acc = 73.21428571428571%
# GuideWire acc = 28.57142857142857%
# LiquidBottle acc = 66.41221374045801%
# Mask acc = 93.24675324675324%
# NGTube acc = 42.58064516129032%
# NasalCannula acc = 57.52212389380531%
# Needle acc = 86.07142857142858%
# OxygenMask acc = 95.48872180451127%
# PPESuit acc = 92.74193548387096%
# PharmaceuticalProduct acc = 53.0373831775701%
# Pill acc = 97.47899159663865%
# PillBottle acc = 79.06976744186046%
# PrefilledHumidifier acc = 79.48717948717949%
# PressureConnectingTube acc = 64.8854961832061%
# ReusableHumidifier acc = 83.89830508474576%
# SodiumChlorideBag acc = 79.52755905511812%
# SterileHumidifierAdapter acc = 70.0%
# SurgicalBlade acc = 90.2654867256637%
# SurgicalCap acc = 93.69369369369369%
# SurgicalSuit acc = 37.878787878787875%
# Syringe acc = 97.71863117870723%
# TrachealTube acc = 38.53211009174312%
# UrineBag acc = 61.66666666666667%
# Vaccinebottle acc = 83.09859154929578%
# WingedInfusionSet acc = 65.78947368421053%
#
#
#
# all_avg_eachclass = 71.54804459035445%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 99,   0,   0, ...,   0,   0,   0],
#        [  2, 131,   0, ...,   0,   2,   0],
#        [  0,   0,  93, ...,   0,   1,  14],
#        ...,
#        [  0,   0,   0, ...,  74,   0,   0],
#        [  0,   0,   0, ...,   0, 177,   0],
#        [  0,   0,   0, ...,   1,   0,  75]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[85.34482759,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.36054422, 89.11564626,  0.        , ...,  0.        ,
#          1.36054422,  0.        ],
#        [ 0.        ,  0.        , 69.40298507, ...,  0.        ,
#          0.74626866, 10.44776119],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 61.66666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         83.09859155,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.87719298,
#          0.        , 65.78947368]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
