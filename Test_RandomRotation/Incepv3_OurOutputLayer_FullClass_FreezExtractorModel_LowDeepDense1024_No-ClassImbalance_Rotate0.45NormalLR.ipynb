# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = tf.keras.Sequential([
  #layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.45),
  #layers.RandomZoom(height_factor=0.3,width_factor=0.3),
  #layers.RandomContrast(0.05),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 299, 299, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3

inceptionv3_model = keras.applications.InceptionV3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

inceptionv3_model_nooutput = inceptionv3_model.layers[-2].output
custom_inceptionv3_model = Model(inputs = inceptionv3_model.input, outputs = inceptionv3_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_inceptionv3_model.trainable = False
for layer in custom_inceptionv3_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_inceptionv3_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_inceptionv3_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 23,942,985
# Trainable params: 2,140,201
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
print(len(model.layers))
tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)
# Out:
# 4

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}-val_acc{val_accuracy:.2f}.pb'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 326ms/step - loss: 1.5284 - accuracy: 0.6048 - val_loss: 0.6378 - val_accuracy: 0.8305
# Epoch 2/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.4535 - accuracy: 0.8659 - val_loss: 0.4466 - val_accuracy: 0.8771
# Epoch 3/2000
# 49/49 [==============================] - 9s 175ms/step - loss: 0.2434 - accuracy: 0.9292 - val_loss: 0.3548 - val_accuracy: 0.8965
# Epoch 4/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1579 - accuracy: 0.9544 - val_loss: 0.3183 - val_accuracy: 0.9056
# Epoch 5/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1127 - accuracy: 0.9703 - val_loss: 0.2568 - val_accuracy: 0.9211
# Epoch 6/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0808 - accuracy: 0.9835 - val_loss: 0.2433 - val_accuracy: 0.9185
# Epoch 7/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0620 - accuracy: 0.9871 - val_loss: 0.2729 - val_accuracy: 0.9082
# Epoch 8/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0575 - accuracy: 0.9877 - val_loss: 0.2900 - val_accuracy: 0.9185
# Epoch 9/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0528 - accuracy: 0.9855 - val_loss: 0.2287 - val_accuracy: 0.9301
# Epoch 10/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0409 - accuracy: 0.9919 - val_loss: 0.2687 - val_accuracy: 0.9211
# Epoch 11/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0330 - accuracy: 0.9932 - val_loss: 0.2484 - val_accuracy: 0.9301
# Epoch 12/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0337 - accuracy: 0.9906 - val_loss: 0.1964 - val_accuracy: 0.9508
# Epoch 13/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.2182 - val_accuracy: 0.9314
# Epoch 14/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0306 - accuracy: 0.9903 - val_loss: 0.2449 - val_accuracy: 0.9237
# Epoch 15/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0260 - accuracy: 0.9929 - val_loss: 0.1925 - val_accuracy: 0.9444
# Epoch 16/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0197 - accuracy: 0.9955 - val_loss: 0.1947 - val_accuracy: 0.9470
# Epoch 17/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0132 - accuracy: 0.9974 - val_loss: 0.2537 - val_accuracy: 0.9276
# Epoch 18/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0141 - accuracy: 0.9974 - val_loss: 0.2226 - val_accuracy: 0.9392
# Epoch 19/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0146 - accuracy: 0.9968 - val_loss: 0.1959 - val_accuracy: 0.9483
# Epoch 20/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0139 - accuracy: 0.9968 - val_loss: 0.3241 - val_accuracy: 0.9082
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 21/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.1508 - val_accuracy: 0.9599
# Epoch 22/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.1474 - val_accuracy: 0.9612
# Epoch 23/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 0.9599
# Epoch 24/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9638
# Epoch 25/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9625
# Epoch 26/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9599
# Epoch 27/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9638
# Epoch 28/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9612
# Epoch 29/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9638
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 30/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9638
# Epoch 31/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9638
# Epoch 32/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 33/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9638
# Epoch 34/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9625
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 35/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9625
# Epoch 36/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9625
# Epoch 37/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9625
# Epoch 38/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 39/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9638
# Epoch 40/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 41/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 42/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9651
# Epoch 43/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 44/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 45/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9638
# Epoch 46/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9638
# Epoch 47/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9625
# Epoch 48/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9625
# Epoch 49/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9625
# Epoch 50/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 51/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9625
# Epoch 52/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9625
# Epoch 53/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9638
# Epoch 54/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9638
# Epoch 55/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9612
# Epoch 56/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 57/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9612
# Epoch 58/2000
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9612
# Epoch 59/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9612
# Epoch 60/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9612
# Epoch 61/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9625
# Epoch 62/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9625
# Epoch 63/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9625
# Epoch 64/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9625
# Epoch 65/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 66/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 67/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 68/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 69/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 70/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9638
# Epoch 71/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9625
# Epoch 72/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9638
# Epoch 73/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9638
# Epoch 74/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9638
# Epoch 75/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9638
# Epoch 76/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9638
# Epoch 77/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9625
# Epoch 78/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9625
# Epoch 79/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9625
# Epoch 80/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9625
# Epoch 81/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9625
# Epoch 82/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9625
# Epoch 83/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9625
# Epoch 84/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9625
# Epoch 85/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9625
# Epoch 86/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9625
# Epoch 87/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9625
# Epoch 88/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9625
# Epoch 89/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9625
# Epoch 90/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9625
# Epoch 91/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9625
# Epoch 92/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9625
# Epoch 93/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9625
# Epoch 94/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9638
# Epoch 95/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9638
# Epoch 96/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9638
# Epoch 97/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9638
# Epoch 98/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9638
# Epoch 99/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9638
# Epoch 100/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9638
# Epoch 101/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9638
# Epoch 102/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9625
# Epoch 103/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9625
# Epoch 104/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 105/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9638
# Epoch 106/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9651
# Epoch 107/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9638
# Epoch 108/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9651
# Epoch 109/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9638
# Epoch 110/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 111/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9651
# Epoch 112/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9651
# Epoch 113/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 114/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9651
# Epoch 115/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9664
# Epoch 116/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1480 - val_accuracy: 0.9651
# Epoch 117/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9651
# Epoch 118/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9625
# Epoch 119/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9625
# Epoch 120/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9651
# Epoch 121/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9677
# Epoch 122/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9677
# Epoch 123/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9638
# Epoch 124/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9664
# Epoch 125/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9625
# Epoch 126/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9625
# Epoch 127/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9638
# Epoch 128/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9638
# Epoch 129/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9625
# Epoch 130/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9651
# Epoch 131/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9651
# Epoch 132/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9625
# Epoch 133/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1488 - val_accuracy: 0.9625
# Epoch 134/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9651
# Epoch 135/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 0.9651
# Epoch 136/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9651
# Epoch 137/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 138/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9651
# Epoch 139/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9638
# Epoch 140/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9664
# Epoch 141/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9638
# Epoch 142/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9664
# Epoch 143/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9677
# Epoch 144/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9638
# Epoch 145/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9651
# Epoch 146/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9638
# Epoch 147/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9638
# Epoch 148/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9638
# Epoch 149/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.9849e-04 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9664
# Epoch 150/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.7213e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9664
# Epoch 151/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.9702e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9664
# Epoch 152/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.9066e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9677
# Epoch 153/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3404e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9664
# Epoch 154/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.7095e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9651
# Epoch 155/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.2662e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9651
# Epoch 156/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0863e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9664
# Epoch 157/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3575e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9651
# Epoch 158/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9664
# Epoch 159/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.4825e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9651
# Epoch 160/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.4554e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9638
# Epoch 161/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.2163e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9638
# Epoch 162/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.5749e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9638
# Epoch 163/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.1233e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9664
# Epoch 164/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.7659e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9651
# Epoch 165/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.5772e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9638
# Epoch 166/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.4344e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9638
# Epoch 167/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 9.4240e-04 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9638
# Epoch 168/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1708e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9651
# Epoch 169/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1764e-04 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9651
# Epoch 170/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.0773e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 171/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.9128e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 172/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 9.3637e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9677
# Epoch 173/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.9038e-04 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 0.9651
# Epoch 174/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4222e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9651
# Epoch 175/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.2923e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9638
# Epoch 176/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.3357e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9638
# Epoch 177/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.4026e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9638
# Epoch 178/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.7944e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9638
# Epoch 179/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.1913e-04 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9638
# Epoch 180/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.1911e-04 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9651
# Epoch 181/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.4372e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9677
# Epoch 182/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 8.0782e-04 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9651
# Epoch 183/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0876e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9651
# Epoch 184/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5374e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9638
# Epoch 185/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.6837e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9638
# Epoch 186/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.3452e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9638
# Epoch 187/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5885e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9625
# Epoch 188/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.8486e-04 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9638
# Epoch 189/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.4683e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9638
# Epoch 190/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 8.0232e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9638
# Epoch 191/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.6351e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 192/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.9791e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9664
# Epoch 193/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.5995e-04 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 194/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.7071e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9664
# Epoch 195/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.6823e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9651
# Epoch 196/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.0453e-04 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9638
# Epoch 197/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.9636e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9651
# Epoch 198/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.8935e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9651
# Epoch 199/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 7.0937e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9651
# Epoch 200/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.7440e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9638
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.96.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.4478e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9638
# Epoch 202/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.2695e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9651
# Epoch 203/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 7.1187e-04 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9625
# Epoch 204/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.1326e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9625
# Epoch 205/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.9514e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9664
# Epoch 206/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.5800e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9677
# Epoch 207/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.4932e-04 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9664
# Epoch 208/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6244e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9664
# Epoch 209/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.4948e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9677
# Epoch 210/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.0907e-04 - accuracy: 1.0000 - val_loss: 0.1489 - val_accuracy: 0.9664
# Epoch 211/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.5187e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9651
# Epoch 212/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4820e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9651
# Epoch 213/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 6.9983e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9664
# Epoch 214/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.2721e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9664
# Epoch 215/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6738e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9664
# Epoch 216/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.8770e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9651
# Epoch 217/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.8267e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9651
# Epoch 218/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.7270e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9651
# Epoch 219/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.1248e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9677
# Epoch 220/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.6932e-04 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9651
# Epoch 221/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.9559e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9651
# Epoch 222/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.0293e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
# Epoch 223/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.8702e-04 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9651
# Epoch 224/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.4919e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9638
# Epoch 225/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.8475e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9651
# Epoch 226/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.9689e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9638
# Epoch 227/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 6.0512e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9638
# Epoch 228/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.4355e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9651
# Epoch 229/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.6195e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9664
# Epoch 230/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.6658e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9651
# Epoch 231/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.0264e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9638
# Epoch 232/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.6715e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9651
# Epoch 233/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.7700e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9651
# Epoch 234/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.9048e-04 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9651
# Epoch 235/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.6943e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9664
# Epoch 236/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.2310e-04 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9651
# Epoch 237/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.9549e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9664
# Epoch 238/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 5.2097e-04 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9664
# Epoch 239/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 5.0314e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9651
# Epoch 240/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.5494e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9651
# Epoch 241/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.8682e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9664
# Epoch 242/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.5781e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9638
# Epoch 243/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.2785e-04 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9664
# Epoch 244/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0636e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9664
# Epoch 245/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.3393e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9638
# Epoch 246/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.9387e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9664
# Epoch 247/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.3262e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9664
# Epoch 248/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4892e-04 - accuracy: 1.0000 - val_loss: 0.1505 - val_accuracy: 0.9651
# Epoch 249/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.8343e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9664
# Epoch 250/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3023e-04 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9664
# Epoch 251/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4319e-04 - accuracy: 1.0000 - val_loss: 0.1511 - val_accuracy: 0.9664
# Epoch 252/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.2163e-04 - accuracy: 1.0000 - val_loss: 0.1503 - val_accuracy: 0.9664
# Epoch 253/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.7522e-04 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9651
# Epoch 254/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1423e-04 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9664
# Epoch 255/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.2210e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9664
# Epoch 256/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6594e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9664
# Epoch 257/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8987e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9664
# Epoch 258/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0621e-04 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9664
# Epoch 259/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.1741e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9651
# Epoch 260/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6477e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9664
# Epoch 261/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.3070e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9664
# Epoch 262/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9605e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9664
# Epoch 263/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9245e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9664
# Epoch 264/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0996e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9664
# Epoch 265/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.2291e-04 - accuracy: 1.0000 - val_loss: 0.1518 - val_accuracy: 0.9651
# Epoch 266/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.5223e-04 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9664
# Epoch 267/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7189e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9664
# Epoch 268/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5417e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9651
# Epoch 269/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.1427e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9664
# Epoch 270/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 4.0662e-04 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9664
# Epoch 271/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7606e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9651
# Epoch 272/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7235e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
# Epoch 273/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.8928e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9651
# Epoch 274/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3644e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9664
# Epoch 275/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0829e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9651
# Epoch 276/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.7357e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9664
# Epoch 277/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7739e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
# Epoch 278/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2906e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9664
# Epoch 279/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2616e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
# Epoch 280/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0906e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
# Epoch 281/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3392e-04 - accuracy: 1.0000 - val_loss: 0.1547 - val_accuracy: 0.9664
# Epoch 282/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9214e-04 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9651
# Epoch 283/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.5274e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
# Epoch 284/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1424e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9651
# Epoch 285/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5092e-04 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9638
# Epoch 286/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1224e-04 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9664
# Epoch 287/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8342e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9664
# Epoch 288/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7245e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9664
# Epoch 289/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0491e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9664
# Epoch 290/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9452e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9664
# Epoch 291/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0035e-04 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9664
# Epoch 292/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1852e-04 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9638
# Epoch 293/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1164e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9664
# Epoch 294/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9576e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9664
# Epoch 295/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.3329e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9664
# Epoch 296/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8403e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9664
# Epoch 297/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.4686e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9651
# Epoch 298/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8175e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9664
# Epoch 299/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8037e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9664
# Epoch 300/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7914e-04 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9664
# Epoch 301/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0124e-04 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9664
# Epoch 302/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8697e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9664
# Epoch 303/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9898e-04 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9651
# Epoch 304/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5192e-04 - accuracy: 1.0000 - val_loss: 0.1526 - val_accuracy: 0.9664
# Epoch 305/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7396e-04 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 0.9651
# Epoch 306/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6920e-04 - accuracy: 1.0000 - val_loss: 0.1540 - val_accuracy: 0.9664
# Epoch 307/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6679e-04 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9638
# Epoch 308/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5573e-04 - accuracy: 1.0000 - val_loss: 0.1533 - val_accuracy: 0.9651
# Epoch 309/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9430e-04 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9664
# Epoch 310/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6505e-04 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9651
# Epoch 311/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.8389e-04 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9651
# Epoch 312/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.3054e-04 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9638
# Epoch 313/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4957e-04 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.9638
# Epoch 314/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5731e-04 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9664
# Epoch 315/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.4214e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9664
# Epoch 316/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5133e-04 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9651
# Epoch 317/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5235e-04 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9664
# Epoch 318/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.1414e-04 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9664
# Epoch 319/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7268e-04 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9651
# Epoch 320/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.3550e-04 - accuracy: 1.0000 - val_loss: 0.1508 - val_accuracy: 0.9664
# Epoch 321/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6710e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9638
# Epoch 1898/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0423e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9651
# Epoch 1899/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3482e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9638
# Epoch 1900/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1618e-07 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9638
# Epoch 1901/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9484e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9638
# Epoch 1902/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.3460e-07 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9651
# Epoch 1903/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5246e-07 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9651
# Epoch 1904/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5978e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9664
# Epoch 1905/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9088e-07 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9664
# Epoch 1906/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2169e-07 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9664
# Epoch 1907/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0424e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9664
# Epoch 1908/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8333e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9664
# Epoch 1909/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7116e-07 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9664
# Epoch 1910/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3105e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9664
# Epoch 1911/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0817e-07 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9651
# Epoch 1912/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0763e-07 - accuracy: 1.0000 - val_loss: 0.2047 - val_accuracy: 0.9651
# Epoch 1913/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2142e-07 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9664
# Epoch 1914/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0836e-07 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9664
# Epoch 1915/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2612e-07 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9664
# Epoch 1916/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0486e-07 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9651
# Epoch 1917/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8930e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9651
# Epoch 1918/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5594e-07 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9664
# Epoch 1919/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9188e-07 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9664
# Epoch 1920/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3821e-07 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9664
# Epoch 1921/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.1522e-07 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9664
# Epoch 1922/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5535e-07 - accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9651
# Epoch 1923/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7187e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9651
# Epoch 1924/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9311e-07 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9651
# Epoch 1925/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8437e-07 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9651
# Epoch 1926/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7718e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9677
# Epoch 1927/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0270e-07 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9677
# Epoch 1928/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6688e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9677
# Epoch 1929/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.8562e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9677
# Epoch 1930/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6546e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9677
# Epoch 1931/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.0278e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9677
# Epoch 1932/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3625e-07 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9664
# Epoch 1933/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0979e-07 - accuracy: 1.0000 - val_loss: 0.2065 - val_accuracy: 0.9664
# Epoch 1934/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5902e-07 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9664
# Epoch 1935/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.3852e-07 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9664
# Epoch 1936/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5316e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9664
# Epoch 1937/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0220e-07 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9664
# Epoch 1938/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4769e-07 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9664
# Epoch 1939/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8780e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9664
# Epoch 1940/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9330e-07 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9664
# Epoch 1941/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1856e-07 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9651
# Epoch 1942/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0162e-07 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9651
# Epoch 1943/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.9977e-07 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9651
# Epoch 1944/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0691e-07 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9651
# Epoch 1945/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9939e-07 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9664
# Epoch 1946/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5020e-07 - accuracy: 1.0000 - val_loss: 0.2089 - val_accuracy: 0.9651
# Epoch 1947/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7432e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9651
# Epoch 1948/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1630e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9651
# Epoch 1949/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.3202e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9651
# Epoch 1950/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.7802e-07 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9651
# Epoch 1951/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2665e-07 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9677
# Epoch 1952/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6191e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9664
# Epoch 1953/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1429e-07 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9664
# Epoch 1954/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1094e-07 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9664
# Epoch 1955/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0948e-07 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9677
# Epoch 1956/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7008e-07 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9664
# Epoch 1957/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.4507e-07 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9664
# Epoch 1958/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2412e-07 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9651
# Epoch 1959/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4882e-07 - accuracy: 1.0000 - val_loss: 0.2077 - val_accuracy: 0.9664
# Epoch 1960/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.6825e-07 - accuracy: 1.0000 - val_loss: 0.2072 - val_accuracy: 0.9664
# Epoch 1961/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1036e-07 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9664
# Epoch 1962/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5744e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9651
# Epoch 1963/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.2902e-07 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9664
# Epoch 1964/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.3125e-07 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9664
# Epoch 1965/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.4473e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9677
# Epoch 1966/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.6338e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9677
# Epoch 1967/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8475e-07 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9677
# Epoch 1968/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7878e-07 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9677
# Epoch 1969/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.2987e-07 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9677
# Epoch 1970/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4250e-07 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9677
# Epoch 1971/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9269e-07 - accuracy: 1.0000 - val_loss: 0.2053 - val_accuracy: 0.9677
# Epoch 1972/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.9130e-07 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9677
# Epoch 1973/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 1.1265e-06 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9677
# Epoch 1974/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.2321e-07 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9677
# Epoch 1975/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6750e-07 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9664
# Epoch 1976/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1171e-07 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9651
# Epoch 1977/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6800e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9651
# Epoch 1978/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1580e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9651
# Epoch 1979/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.4739e-07 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9638
# Epoch 1980/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1094e-07 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9638
# Epoch 1981/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 2.7054e-07 - accuracy: 1.0000 - val_loss: 0.2057 - val_accuracy: 0.9638
# Epoch 1982/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6257e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9638
# Epoch 1983/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.2539e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9638
# Epoch 1984/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0836e-07 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9638
# Epoch 1985/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.1391e-07 - accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9638
# Epoch 1986/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6469e-07 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9638
# Epoch 1987/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.0462e-07 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9638
# Epoch 1988/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7520e-07 - accuracy: 1.0000 - val_loss: 0.2062 - val_accuracy: 0.9638
# Epoch 1989/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.3272e-07 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9651
# Epoch 1990/2000
# 49/49 [==============================] - 9s 178ms/step - loss: 3.6166e-07 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9651
# Epoch 1991/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.9837e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9651
# Epoch 1992/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.6915e-07 - accuracy: 1.0000 - val_loss: 0.2066 - val_accuracy: 0.9651
# Epoch 1993/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.5841e-07 - accuracy: 1.0000 - val_loss: 0.2064 - val_accuracy: 0.9651
# Epoch 1994/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.5019e-07 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9651
# Epoch 1995/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 4.0699e-07 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9651
# Epoch 1996/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.8287e-07 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9664
# Epoch 1997/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.3464e-07 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9651
# Epoch 1998/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.7840e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9664
# Epoch 1999/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 3.2612e-07 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9664
# Epoch 2000/2000
# 49/49 [==============================] - 9s 177ms/step - loss: 2.1065e-07 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9651
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 332ms/step - loss: 0.8840 - accuracy: 0.8439
# test_indoor_ds_results:test loss, test acc: [0.8839848041534424, 0.8439241647720337]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 423ms/step - loss: 2.2144 - accuracy: 0.7350
# test_outdoor_ds_results:test loss, test acc: [2.2143986225128174, 0.7350318431854248]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 198ms/step - loss: 2.2498 - accuracy: 0.7267
# test_belt_ds_results:test loss, test acc: [2.2497777938842773, 0.726654589176178]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400-val_acc0.96.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800-val_acc0.97.pb',
#  'D:/ModelMedicalWasteCheckpoint/Incepv3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-Rotate450-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 137ms/step - loss: 0.6187 - accuracy: 0.8322
# 50/50 [==============================] - 7s 137ms/step - loss: 1.4569 - accuracy: 0.7252
# 35/35 [==============================] - 5s 138ms/step - loss: 1.4431 - accuracy: 0.7149
# Epoch200
#  test_indoor_acc=0.8322185277938843
#  test_outdoor_acc=0.725159227848053
#  test_belt_acc=0.7148685455322266
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6593 - accuracy: 0.8350
# 50/50 [==============================] - 7s 137ms/step - loss: 1.5763 - accuracy: 0.7287
# 35/35 [==============================] - 5s 137ms/step - loss: 1.5885 - accuracy: 0.7167
# Epoch400
#  test_indoor_acc=0.8350055813789368
#  test_outdoor_acc=0.7286624312400818
#  test_belt_acc=0.7166817784309387
# 29/29 [==============================] - 5s 135ms/step - loss: 0.6987 - accuracy: 0.8367
# 50/50 [==============================] - 7s 136ms/step - loss: 1.6870 - accuracy: 0.7331
# 35/35 [==============================] - 5s 137ms/step - loss: 1.7336 - accuracy: 0.7199
# Epoch600
#  test_indoor_acc=0.8366777896881104
#  test_outdoor_acc=0.7331210374832153
#  test_belt_acc=0.7198549509048462
# 29/29 [==============================] - 5s 136ms/step - loss: 0.7450 - accuracy: 0.8400
# 50/50 [==============================] - 7s 137ms/step - loss: 1.8196 - accuracy: 0.7373
# 35/35 [==============================] - 5s 138ms/step - loss: 1.8654 - accuracy: 0.7208
# Epoch800
#  test_indoor_acc=0.8400223255157471
#  test_outdoor_acc=0.737261176109314
#  test_belt_acc=0.7207615375518799
# 29/29 [==============================] - 5s 134ms/step - loss: 0.7828 - accuracy: 0.8423
# 50/50 [==============================] - 7s 135ms/step - loss: 1.9371 - accuracy: 0.7354
# 35/35 [==============================] - 5s 136ms/step - loss: 1.9811 - accuracy: 0.7235
# Epoch1000
#  test_indoor_acc=0.8422519564628601
#  test_outdoor_acc=0.7353503108024597
#  test_belt_acc=0.7234814167022705
# 29/29 [==============================] - 5s 137ms/step - loss: 0.8024 - accuracy: 0.8400
# 50/50 [==============================] - 7s 138ms/step - loss: 2.0332 - accuracy: 0.7325
# 35/35 [==============================] - 5s 138ms/step - loss: 2.0475 - accuracy: 0.7253
# Epoch1200
#  test_indoor_acc=0.8400223255157471
#  test_outdoor_acc=0.7324841022491455
#  test_belt_acc=0.7252946496009827
# 29/29 [==============================] - 5s 138ms/step - loss: 0.8385 - accuracy: 0.8406
# 50/50 [==============================] - 7s 138ms/step - loss: 2.0918 - accuracy: 0.7341
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1351 - accuracy: 0.7208
# Epoch1400
#  test_indoor_acc=0.8405796885490417
#  test_outdoor_acc=0.7340764403343201
#  test_belt_acc=0.7207615375518799
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8592 - accuracy: 0.8406
# 50/50 [==============================] - 7s 138ms/step - loss: 2.1404 - accuracy: 0.7366
# 35/35 [==============================] - 5s 138ms/step - loss: 2.1841 - accuracy: 0.7248
# Epoch1600
#  test_indoor_acc=0.8405796885490417
#  test_outdoor_acc=0.7366241812705994
#  test_belt_acc=0.7248413562774658
# 29/29 [==============================] - 5s 135ms/step - loss: 0.8706 - accuracy: 0.8428
# 50/50 [==============================] - 7s 137ms/step - loss: 2.1757 - accuracy: 0.7379
# 35/35 [==============================] - 5s 137ms/step - loss: 2.2213 - accuracy: 0.7248
# Epoch1800
#  test_indoor_acc=0.8428093791007996
#  test_outdoor_acc=0.7378981113433838
#  test_belt_acc=0.7248413562774658
# 29/29 [==============================] - 5s 136ms/step - loss: 0.8840 - accuracy: 0.8439
# 50/50 [==============================] - 7s 137ms/step - loss: 2.2144 - accuracy: 0.7350
# 35/35 [==============================] - 5s 137ms/step - loss: 2.2498 - accuracy: 0.7267
# Epoch2000
#  test_indoor_acc=0.8439241647720337
#  test_outdoor_acc=0.7350318431854248
#  test_belt_acc=0.726654589176178

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7685368657112122
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8322185277938843,
#  0.8350055813789368,
#  0.8366777896881104,
#  0.8400223255157471,
#  0.8422519564628601,
#  0.8400223255157471,
#  0.8405796885490417,
#  0.8405796885490417,
#  0.8428093791007996,
#  0.8439241647720337]

# %%
test_outdoor_acc
# Out:
# [0.725159227848053,
#  0.7286624312400818,
#  0.7331210374832153,
#  0.737261176109314,
#  0.7353503108024597,
#  0.7324841022491455,
#  0.7340764403343201,
#  0.7366241812705994,
#  0.7378981113433838,
#  0.7350318431854248]

# %%
test_belt_acc
# Out:
# [0.7148685455322266,
#  0.7166817784309387,
#  0.7198549509048462,
#  0.7207615375518799,
#  0.7234814167022705,
#  0.7252946496009827,
#  0.7207615375518799,
#  0.7248413562774658,
#  0.7248413562774658,
#  0.726654589176178]

# %%
test_indoor_loss
# Out:
# [0.6186990141868591,
#  0.6593201756477356,
#  0.6986549496650696,
#  0.7449633479118347,
#  0.7828471660614014,
#  0.80242520570755,
#  0.8385046124458313,
#  0.8591808676719666,
#  0.8706179857254028,
#  0.8839848041534424]

# %%
test_outdoor_loss
# Out:
# [1.4569381475448608,
#  1.5762505531311035,
#  1.6870026588439941,
#  1.8195836544036865,
#  1.937075138092041,
#  2.033154010772705,
#  2.091778039932251,
#  2.1403608322143555,
#  2.175678253173828,
#  2.2143986225128174]

# %%
test_belt_loss
# Out:
# [1.4430811405181885,
#  1.5884714126586914,
#  1.733559489250183,
#  1.8653510808944702,
#  1.9811278581619263,
#  2.04748797416687,
#  2.1350595951080322,
#  2.1840755939483643,
#  2.221266746520996,
#  2.2497777938842773]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000-val_acc0.97.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5425
# FP=1715
# acc=0.7598039215686274
# all check = 7140

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 82.75862068965517%
# 2WayConnectorforFoley acc = 89.1156462585034%
# 2WayFoleyCatheter acc = 69.40298507462687%
# 3WayConnectorforFoley acc = 90.5982905982906%
# 3Waystopcock acc = 100.0%
# AlcoholBottle acc = 85.625%
# AlcoholPad acc = 48.41269841269841%
# BootCover acc = 60.8433734939759%
# CottonBall acc = 88.02395209580838%
# CottonSwap acc = 79.72027972027972%
# Dilator acc = 61.53846153846154%
# DisposableInfusionSet acc = 53.09734513274337%
# ExtensionTube acc = 26.82926829268293%
# FaceShield acc = 73.4567901234568%
# FrontLoadSyringe acc = 51.32743362831859%
# GauzePad acc = 62.5%
# Glove acc = 79.16666666666666%
# GuideWire acc = 32.142857142857146%
# LiquidBottle acc = 63.74045801526718%
# Mask acc = 95.06493506493506%
# NGTube acc = 43.87096774193549%
# NasalCannula acc = 65.48672566371681%
# Needle acc = 87.85714285714286%
# OxygenMask acc = 92.4812030075188%
# PPESuit acc = 92.74193548387096%
# PharmaceuticalProduct acc = 54.4392523364486%
# Pill acc = 96.63865546218487%
# PillBottle acc = 75.96899224806202%
# PrefilledHumidifier acc = 79.48717948717949%
# PressureConnectingTube acc = 71.7557251908397%
# ReusableHumidifier acc = 86.4406779661017%
# SodiumChlorideBag acc = 92.1259842519685%
# SterileHumidifierAdapter acc = 86.36363636363636%
# SurgicalBlade acc = 92.92035398230088%
# SurgicalCap acc = 92.7927927927928%
# SurgicalSuit acc = 40.909090909090914%
# Syringe acc = 96.1977186311787%
# TrachealTube acc = 47.706422018348626%
# UrineBag acc = 64.16666666666667%
# Vaccinebottle acc = 80.75117370892019%
# WingedInfusionSet acc = 67.54385964912281%
#
#
#
# all_avg_eachclass = 73.2197858138599%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 96,   1,   0, ...,   0,   1,   0],
#        [  2, 131,   0, ...,   0,   0,   0],
#        [  0,   1,  93, ...,   0,   0,  18],
#        ...,
#        [  0,   0,   0, ...,  77,   0,   0],
#        [  0,   0,   0, ...,   1, 172,   0],
#        [  0,   0,   0, ...,   1,   0,  77]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[82.75862069,  0.86206897,  0.        , ...,  0.        ,
#          0.86206897,  0.        ],
#        [ 1.36054422, 89.11564626,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.74626866, 69.40298507, ...,  0.        ,
#          0.        , 13.43283582],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 64.16666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.46948357,
#         80.75117371,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.87719298,
#          0.        , 67.54385965]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
