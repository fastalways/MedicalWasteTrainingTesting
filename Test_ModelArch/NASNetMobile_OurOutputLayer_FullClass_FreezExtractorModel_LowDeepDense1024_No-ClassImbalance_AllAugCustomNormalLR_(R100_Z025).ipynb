# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import preprocess_input,NASNetMobile
#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.NASNetMobile(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile.h5
# 24231936/24227760 [==============================] - 9s 0us/step
# 24240128/24227760 [==============================] - 9s 0us/step

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 111, 111, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 111, 111, 32) 128         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 111, 111, 11) 352         activation[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 111, 111, 11) 44          reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 111, 111, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 11) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_3[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   396         separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   396         activation_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 117, 117, 32) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1920        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 115, 115, 32) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 56, 56, 11)   1152        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 56, 56, 11)   220         activation_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 113, 113, 11) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   660         activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 11)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 56, 56, 11)   396         activation_8[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 56, 56, 11)   220         activation_10[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 111, 111, 32) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 56, 56, 11)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 56, 56, 11)   44          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 56, 56, 11)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 56, 56, 11)   44          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 56, 56, 11)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 112, 112, 32) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 56, 56, 11)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 11)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 56, 56, 11)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d (Cropping2D)         (None, 111, 111, 32) 0           zero_padding2d[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 56, 56, 44)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 56, 56, 32)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 56, 56, 32)   0           cropping2d[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 56, 56, 11)   352         adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 56, 56, 22)   968         activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 22)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 56, 56, 22)   88          reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 56, 56, 22)   88          concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   1034        activation_13[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 61, 61, 22)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 22)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1562        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 59, 59, 22)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 28, 28, 22)   1034        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 28, 28, 22)   682         activation_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 57, 57, 22)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1562        activation_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 22)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 28, 28, 22)   1034        activation_19[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 28, 28, 22)   682         activation_21[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 56, 56, 44)   0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 28, 28, 22)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 28, 28, 22)   88          separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 28, 28, 22)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 28, 28, 22)   88          separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 28, 28, 22)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 57, 57, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 28, 28, 22)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 22)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 28, 28, 22)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 56, 56, 44)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 28, 28, 88)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_1[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 28, 28, 44)   0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 28, 28, 44)   0           cropping2d_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 28, 28, 22)   968         adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 44)   0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 28, 28, 44)   3872        activation_22[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 28, 28, 44)   176         concatenate_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_0 (None, 28, 28, 44)   3036        activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_25[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_0 (None, 28, 28, 44)   3036        activation_27[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_29[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_0 (None, 28, 28, 44)   2332        activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_0[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_0[0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_0 (None, 28, 28, 44)   3036        activation_24[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_26[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_0 (None, 28, 28, 44)   3036        activation_28[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_30[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_0 (None, 28, 28, 44)   2332        activation_32[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_0[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_0[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_0[
# __________________________________________________________________________________________________
# normal_left3_0 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_left4_0 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_right4_0 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_0[0
# __________________________________________________________________________________________________
# normal_add_1_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_0 (Add)            (None, 28, 28, 44)   0           normal_left3_0[0][0]
#                                                                  adjust_bn_0[0][0]
# __________________________________________________________________________________________________
# normal_add_4_0 (Add)            (None, 28, 28, 44)   0           normal_left4_0[0][0]
#                                                                  normal_right4_0[0][0]
# __________________________________________________________________________________________________
# normal_add_5_0 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
# normal_concat_0 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_0[0][0]
#                                                                  normal_add_1_0[0][0]
#                                                                  normal_add_2_0[0][0]
#                                                                  normal_add_3_0[0][0]
#                                                                  normal_add_4_0[0][0]
#                                                                  normal_add_5_0[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 88)   0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_1 (Conv2 (None, 28, 28, 44)   3872        activation_33[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_1 (Conv2D)        (None, 28, 28, 44)   11616       activation_34[0][0]
# __________________________________________________________________________________________________
# adjust_bn_1 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_1[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_1 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_1[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 28, 28, 44)   3036        activation_35[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_37[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 28, 28, 44)   3036        activation_39[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_41[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 28, 28, 44)   2332        activation_43[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right2_1[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left5_1[0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 28, 28, 44)   0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 28, 28, 44)   3036        activation_36[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 28, 28, 44)   2332        activation_38[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 28, 28, 44)   3036        activation_40[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 28, 28, 44)   2332        activation_42[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 28, 28, 44)   2332        activation_44[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 28, 28, 44)   0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 28, 28, 44)   0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 28, 28, 44)   176         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 28, 28, 44)   0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 28, 28, 44)   0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 28, 28, 44)   0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 28, 28, 264)  0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 28, 28, 264)  0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 28, 28, 264)  0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 28, 28, 44)   11616       activation_45[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 28, 28, 44)   11616       activation_46[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 28, 28, 44)   176         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 28, 28, 44)   176         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 44)   0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 28, 28, 44)   0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 28, 28, 44)   3036        activation_47[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 28, 28, 44)   2332        activation_49[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 28, 28, 44)   3036        activation_51[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 28, 28, 44)   2332        activation_53[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 28, 28, 44)   2332        activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 28, 28, 44)   176         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 28, 28, 44)   176         separable_conv_1_normal_right1_2[
# ...
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_166[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_168[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_170[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_172[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_174[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_11
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_11[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_11
# __________________________________________________________________________________________________
# normal_left3_11 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_left4_11 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_right4_11 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_11[
# __________________________________________________________________________________________________
# normal_add_1_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_11 (Add)           (None, 7, 7, 176)    0           normal_left3_11[0][0]
#                                                                  adjust_bn_11[0][0]
# __________________________________________________________________________________________________
# normal_add_4_11 (Add)           (None, 7, 7, 176)    0           normal_left4_11[0][0]
#                                                                  normal_right4_11[0][0]
# __________________________________________________________________________________________________
# normal_add_5_11 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_11[0][0]
# __________________________________________________________________________________________________
# normal_concat_11 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_11[0][0]
#                                                                  normal_add_1_11[0][0]
#                                                                  normal_add_2_11[0][0]
#                                                                  normal_add_3_11[0][0]
#                                                                  normal_add_4_11[0][0]
#                                                                  normal_add_5_11[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 7, 7, 1056)   0           normal_concat_10[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 7, 7, 1056)   0           normal_concat_11[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_12 (Conv (None, 7, 7, 176)    185856      activation_175[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_12 (Conv2D)       (None, 7, 7, 176)    185856      activation_176[0][0]
# __________________________________________________________________________________________________
# adjust_bn_12 (BatchNormalizatio (None, 7, 7, 176)    704         adjust_conv_projection_12[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_12 (BatchNormalizat (None, 7, 7, 176)    704         normal_conv_1_12[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_1 (None, 7, 7, 176)    35376       activation_177[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 7, 7, 176)    32560       activation_179[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_1 (None, 7, 7, 176)    35376       activation_181[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 7, 7, 176)    32560       activation_183[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 7, 7, 176)    32560       activation_185[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_1_normal_right2_12
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 7, 7, 176)    704         separable_conv_1_normal_left5_12[
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 7, 7, 176)    0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 7, 7, 176)    35376       activation_178[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 7, 7, 176)    32560       activation_180[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 7, 7, 176)    35376       activation_182[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 7, 7, 176)    32560       activation_184[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 7, 7, 176)    32560       activation_186[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left1_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right1_12
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left2_12[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 7, 7, 176)    704         separable_conv_2_normal_right2_12
# __________________________________________________________________________________________________
# normal_left3_12 (AveragePooling (None, 7, 7, 176)    0           normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_left4_12 (AveragePooling (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_right4_12 (AveragePoolin (None, 7, 7, 176)    0           adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 7, 7, 176)    704         separable_conv_2_normal_left5_12[
# __________________________________________________________________________________________________
# normal_add_1_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_12 (Add)           (None, 7, 7, 176)    0           normal_left3_12[0][0]
#                                                                  adjust_bn_12[0][0]
# __________________________________________________________________________________________________
# normal_add_4_12 (Add)           (None, 7, 7, 176)    0           normal_left4_12[0][0]
#                                                                  normal_right4_12[0][0]
# __________________________________________________________________________________________________
# normal_add_5_12 (Add)           (None, 7, 7, 176)    0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_12[0][0]
# __________________________________________________________________________________________________
# normal_concat_12 (Concatenate)  (None, 7, 7, 1056)   0           adjust_bn_12[0][0]
#                                                                  normal_add_1_12[0][0]
#                                                                  normal_add_2_12[0][0]
#                                                                  normal_add_3_12[0][0]
#                                                                  normal_add_4_12[0][0]
#                                                                  normal_add_5_12[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 7, 7, 1056)   0           normal_concat_12[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1056)         0           activation_187[0][0]
# ==================================================================================================
# Total params: 4,269,716
# Trainable params: 0
# Non-trainable params: 4,269,716
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1056)              4269716
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1082368
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 5,394,109
# Trainable params: 1,124,393
# Non-trainable params: 4,269,716
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 45s 287ms/step - loss: 1.3791 - accuracy: 0.6291 - val_loss: 0.6566 - val_accuracy: 0.7878
# Epoch 2/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.4593 - accuracy: 0.8533 - val_loss: 0.4488 - val_accuracy: 0.8616
# Epoch 3/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.2776 - accuracy: 0.9231 - val_loss: 0.3901 - val_accuracy: 0.8771
# Epoch 4/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.1890 - accuracy: 0.9470 - val_loss: 0.3648 - val_accuracy: 0.8784
# Epoch 5/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.1415 - accuracy: 0.9609 - val_loss: 0.3327 - val_accuracy: 0.8939
# Epoch 6/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.1050 - accuracy: 0.9712 - val_loss: 0.3080 - val_accuracy: 0.8900
# Epoch 7/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0762 - accuracy: 0.9819 - val_loss: 0.3082 - val_accuracy: 0.9004
# Epoch 8/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0641 - accuracy: 0.9851 - val_loss: 0.3109 - val_accuracy: 0.8849
# Epoch 9/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0563 - accuracy: 0.9880 - val_loss: 0.2762 - val_accuracy: 0.9004
# Epoch 10/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0466 - accuracy: 0.9913 - val_loss: 0.2856 - val_accuracy: 0.9069
# Epoch 11/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0376 - accuracy: 0.9913 - val_loss: 0.3420 - val_accuracy: 0.8862
# Epoch 12/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0247 - accuracy: 0.9955 - val_loss: 0.2403 - val_accuracy: 0.9172
# Epoch 13/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0197 - accuracy: 0.9974 - val_loss: 0.2360 - val_accuracy: 0.9198
# Epoch 14/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0204 - accuracy: 0.9961 - val_loss: 0.2829 - val_accuracy: 0.9030
# Epoch 15/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0134 - accuracy: 0.9990 - val_loss: 0.2589 - val_accuracy: 0.9172
# Epoch 16/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0151 - accuracy: 0.9971 - val_loss: 0.2575 - val_accuracy: 0.9146
# Epoch 17/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0115 - accuracy: 0.9990 - val_loss: 0.2859 - val_accuracy: 0.9069
# Epoch 18/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.9030
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0102 - accuracy: 0.9977 - val_loss: 0.2245 - val_accuracy: 0.9276
# Epoch 20/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.9314
# Epoch 21/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9288
# Epoch 22/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9288
# Epoch 23/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9340
# Epoch 24/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9327
# Epoch 25/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2258 - val_accuracy: 0.9288
# Epoch 26/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9340
# Epoch 27/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2255 - val_accuracy: 0.9327
# Epoch 28/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9327
# Epoch 29/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9301
# Epoch 30/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9314
# Epoch 31/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2189 - val_accuracy: 0.9353
# Epoch 32/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9340
# Epoch 33/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9340
# Epoch 34/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9340
# Epoch 35/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9353
# Epoch 36/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9340
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 37/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9314
# Epoch 38/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9314
# Epoch 39/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9301
# Epoch 40/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9327
# Epoch 41/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9327
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 42/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9314
# Epoch 43/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9314
# Epoch 44/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9327
# Epoch 45/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9327
# Epoch 46/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9340
# Epoch 47/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9340
# Epoch 48/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9327
# Epoch 49/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9353
# Epoch 50/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9340
# Epoch 51/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9340
# Epoch 52/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9340
# Epoch 53/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9340
# Epoch 54/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9340
# Epoch 55/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9340
# Epoch 56/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9340
# Epoch 57/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9340
# Epoch 58/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9340
# Epoch 59/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9340
# Epoch 60/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9353
# Epoch 61/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9353
# Epoch 62/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9340
# Epoch 63/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9340
# Epoch 64/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9340
# Epoch 65/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9327
# Epoch 66/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9327
# Epoch 67/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9340
# Epoch 68/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9366
# Epoch 69/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9366
# Epoch 70/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9353
# Epoch 71/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9366
# Epoch 72/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9340
# Epoch 73/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9353
# Epoch 74/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9353
# Epoch 75/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9353
# Epoch 76/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9353
# Epoch 77/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9353
# Epoch 78/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9353
# Epoch 79/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9353
# Epoch 80/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9353
# Epoch 81/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9340
# Epoch 82/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2214 - val_accuracy: 0.9353
# Epoch 83/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2218 - val_accuracy: 0.9353
# Epoch 84/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9379
# Epoch 85/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9353
# Epoch 86/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9353
# Epoch 87/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9366
# Epoch 88/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9353
# Epoch 89/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9366
# Epoch 90/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9353
# Epoch 91/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2228 - val_accuracy: 0.9353
# Epoch 92/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9353
# Epoch 93/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9353
# Epoch 94/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9340
# Epoch 95/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9327
# Epoch 96/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9353
# Epoch 97/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9353
# Epoch 98/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9327
# Epoch 99/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9327
# Epoch 100/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9353
# Epoch 101/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9353
# Epoch 102/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9353
# Epoch 103/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9353
# Epoch 104/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2235 - val_accuracy: 0.9353
# Epoch 105/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9353
# Epoch 106/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.9327
# Epoch 107/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9340
# Epoch 108/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9340
# Epoch 109/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9340
# Epoch 110/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9327
# Epoch 111/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9340
# Epoch 112/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9353
# Epoch 113/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9366
# Epoch 114/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9340
# Epoch 115/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9353
# Epoch 116/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9340
# Epoch 117/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2222 - val_accuracy: 0.9366
# Epoch 118/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9366
# Epoch 119/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2223 - val_accuracy: 0.9366
# Epoch 120/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2204 - val_accuracy: 0.9392
# Epoch 121/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9379
# Epoch 122/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9340
# Epoch 123/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9353
# Epoch 124/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9353
# Epoch 125/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9353
# Epoch 126/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9353
# Epoch 127/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9353
# Epoch 128/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9366
# Epoch 129/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9366
# Epoch 130/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2238 - val_accuracy: 0.9366
# Epoch 131/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9366
# Epoch 132/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9366
# Epoch 133/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9353
# Epoch 134/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9366
# Epoch 135/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9327
# Epoch 136/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9353
# Epoch 137/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9340
# Epoch 138/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2260 - val_accuracy: 0.9353
# Epoch 139/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9366
# Epoch 140/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9366
# Epoch 141/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2239 - val_accuracy: 0.9379
# Epoch 142/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9366
# Epoch 143/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9366
# Epoch 144/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9366
# Epoch 145/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9366
# Epoch 146/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9340
# Epoch 147/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9366
# Epoch 148/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9366
# Epoch 149/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2245 - val_accuracy: 0.9366
# Epoch 150/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.9353
# Epoch 151/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9353
# Epoch 152/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9366
# Epoch 153/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9366
# Epoch 154/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2255 - val_accuracy: 0.9366
# Epoch 155/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9353
# Epoch 156/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9340
# Epoch 157/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2253 - val_accuracy: 0.9340
# Epoch 158/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9353
# Epoch 159/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2247 - val_accuracy: 0.9353
# Epoch 160/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2230 - val_accuracy: 0.9366
# Epoch 161/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2229 - val_accuracy: 0.9366
# Epoch 162/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9366
# Epoch 163/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9366
# Epoch 164/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9353
# Epoch 165/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9340
# Epoch 166/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2226 - val_accuracy: 0.9366
# Epoch 167/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9366
# Epoch 168/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9353
# Epoch 169/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9353
# Epoch 170/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9353
# Epoch 171/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9353
# Epoch 172/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9340
# Epoch 173/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9353
# Epoch 174/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9353
# Epoch 175/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9353
# Epoch 176/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9353
# Epoch 177/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2227 - val_accuracy: 0.9366
# Epoch 178/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9353
# Epoch 179/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9353
# Epoch 180/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9353
# Epoch 181/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9353
# Epoch 182/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9379
# Epoch 183/2000
# 49/49 [==============================] - 6s 129ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9353
# Epoch 184/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9379
# Epoch 185/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9366
# Epoch 186/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9353
# Epoch 187/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9353
# Epoch 188/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2292 - val_accuracy: 0.9353
# Epoch 189/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9353
# Epoch 190/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9379
# Epoch 191/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9379
# Epoch 192/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9353
# Epoch 193/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9392
# Epoch 194/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.8391e-04 - accuracy: 1.0000 - val_loss: 0.2255 - val_accuracy: 0.9392
# Epoch 195/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9379
# Epoch 196/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2240 - val_accuracy: 0.9366
# Epoch 197/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2242 - val_accuracy: 0.9379
# Epoch 198/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.8907e-04 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9366
# Epoch 199/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9366
# Epoch 200/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.7987e-04 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9366
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 7s 132ms/step - loss: 9.5697e-04 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9353
# Epoch 202/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2268 - val_accuracy: 0.9366
# Epoch 203/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9340
# Epoch 204/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9353
# Epoch 205/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 9.7937e-04 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9353
# Epoch 206/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.8172e-04 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9366
# Epoch 207/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 9.0620e-04 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9366
# Epoch 208/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.7363e-04 - accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9353
# Epoch 209/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 9.5753e-04 - accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9353
# Epoch 210/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.5803e-04 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9340
# Epoch 211/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.5933e-04 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9340
# Epoch 212/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 9.3836e-04 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9353
# Epoch 213/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.7009e-04 - accuracy: 1.0000 - val_loss: 0.2288 - val_accuracy: 0.9340
# Epoch 214/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.3284e-04 - accuracy: 1.0000 - val_loss: 0.2254 - val_accuracy: 0.9353
# Epoch 215/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.1823e-04 - accuracy: 1.0000 - val_loss: 0.2225 - val_accuracy: 0.9353
# Epoch 216/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 8.8882e-04 - accuracy: 1.0000 - val_loss: 0.2250 - val_accuracy: 0.9353
# Epoch 217/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.7887e-04 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9379
# Epoch 218/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 8.3553e-04 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9353
# Epoch 219/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 9.2528e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9340
# Epoch 220/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.3412e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9353
# Epoch 221/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 8.6729e-04 - accuracy: 1.0000 - val_loss: 0.2294 - val_accuracy: 0.9340
# Epoch 222/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.8225e-04 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9379
# Epoch 223/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 8.8098e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9366
# Epoch 224/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.8871e-04 - accuracy: 1.0000 - val_loss: 0.2262 - val_accuracy: 0.9379
# Epoch 225/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.1847e-04 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9392
# Epoch 226/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.1146e-04 - accuracy: 1.0000 - val_loss: 0.2294 - val_accuracy: 0.9366
# Epoch 227/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 9.3234e-04 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9353
# Epoch 228/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.4446e-04 - accuracy: 1.0000 - val_loss: 0.2264 - val_accuracy: 0.9353
# Epoch 229/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 8.6137e-04 - accuracy: 1.0000 - val_loss: 0.2269 - val_accuracy: 0.9353
# Epoch 230/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.1463e-04 - accuracy: 1.0000 - val_loss: 0.2264 - val_accuracy: 0.9327
# Epoch 231/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.9546e-04 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9379
# Epoch 232/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 8.0699e-04 - accuracy: 1.0000 - val_loss: 0.2261 - val_accuracy: 0.9353
# Epoch 233/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.6295e-04 - accuracy: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9353
# Epoch 234/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.1889e-04 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9353
# Epoch 235/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.7107e-04 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9353
# Epoch 236/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.8126e-04 - accuracy: 1.0000 - val_loss: 0.2295 - val_accuracy: 0.9340
# Epoch 237/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.8636e-04 - accuracy: 1.0000 - val_loss: 0.2297 - val_accuracy: 0.9353
# Epoch 238/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 7.4743e-04 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9366
# Epoch 239/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.5231e-04 - accuracy: 1.0000 - val_loss: 0.2303 - val_accuracy: 0.9353
# Epoch 240/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.4280e-04 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9353
# Epoch 241/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.3402e-04 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9353
# Epoch 242/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 7.2629e-04 - accuracy: 1.0000 - val_loss: 0.2272 - val_accuracy: 0.9366
# Epoch 243/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.9098e-04 - accuracy: 1.0000 - val_loss: 0.2276 - val_accuracy: 0.9379
# Epoch 244/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.0325e-04 - accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9379
# Epoch 245/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.6089e-04 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9379
# Epoch 246/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.4080e-04 - accuracy: 1.0000 - val_loss: 0.2273 - val_accuracy: 0.9379
# Epoch 247/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.2320e-04 - accuracy: 1.0000 - val_loss: 0.2266 - val_accuracy: 0.9366
# Epoch 248/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.7988e-04 - accuracy: 1.0000 - val_loss: 0.2285 - val_accuracy: 0.9366
# Epoch 249/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.8964e-04 - accuracy: 1.0000 - val_loss: 0.2296 - val_accuracy: 0.9379
# Epoch 250/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 7.0413e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9340
# Epoch 251/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.6607e-04 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9353
# Epoch 252/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.9068e-04 - accuracy: 1.0000 - val_loss: 0.2287 - val_accuracy: 0.9353
# Epoch 253/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.9486e-04 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9353
# Epoch 254/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.8861e-04 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9340
# Epoch 255/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.3084e-04 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9379
# Epoch 256/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.2805e-04 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9353
# Epoch 257/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.4135e-04 - accuracy: 1.0000 - val_loss: 0.2306 - val_accuracy: 0.9340
# Epoch 258/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.4735e-04 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9340
# Epoch 259/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.4894e-04 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9379
# Epoch 260/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.6185e-04 - accuracy: 1.0000 - val_loss: 0.2308 - val_accuracy: 0.9353
# Epoch 261/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.1224e-04 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9379
# Epoch 262/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.8265e-04 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9366
# Epoch 263/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.7368e-04 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9353
# Epoch 264/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.3943e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9353
# Epoch 265/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.1417e-04 - accuracy: 1.0000 - val_loss: 0.2311 - val_accuracy: 0.9353
# Epoch 266/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.8097e-04 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9340
# Epoch 267/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.9368e-04 - accuracy: 1.0000 - val_loss: 0.2284 - val_accuracy: 0.9379
# Epoch 268/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.4964e-04 - accuracy: 1.0000 - val_loss: 0.2289 - val_accuracy: 0.9379
# Epoch 269/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.1642e-04 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9353
# Epoch 270/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 6.1805e-04 - accuracy: 1.0000 - val_loss: 0.2282 - val_accuracy: 0.9327
# Epoch 271/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.6279e-04 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.9379
# Epoch 272/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.5785e-04 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9353
# Epoch 273/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.7719e-04 - accuracy: 1.0000 - val_loss: 0.2301 - val_accuracy: 0.9379
# Epoch 274/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.4372e-04 - accuracy: 1.0000 - val_loss: 0.2301 - val_accuracy: 0.9379
# Epoch 275/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 6.0117e-04 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9379
# Epoch 276/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.5493e-04 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9366
# Epoch 277/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.6791e-04 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9366
# Epoch 278/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.2598e-04 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9353
# Epoch 279/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.1591e-04 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9353
# Epoch 280/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.4024e-04 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9366
# Epoch 281/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.4158e-04 - accuracy: 1.0000 - val_loss: 0.2302 - val_accuracy: 0.9353
# Epoch 282/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.4226e-04 - accuracy: 1.0000 - val_loss: 0.2320 - val_accuracy: 0.9353
# Epoch 283/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.4239e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9366
# Epoch 284/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.3540e-04 - accuracy: 1.0000 - val_loss: 0.2319 - val_accuracy: 0.9353
# Epoch 285/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.0180e-04 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9353
# Epoch 286/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.9446e-04 - accuracy: 1.0000 - val_loss: 0.2341 - val_accuracy: 0.9353
# Epoch 287/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.9762e-04 - accuracy: 1.0000 - val_loss: 0.2320 - val_accuracy: 0.9366
# Epoch 288/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.0991e-04 - accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.9353
# Epoch 289/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 5.2691e-04 - accuracy: 1.0000 - val_loss: 0.2312 - val_accuracy: 0.9366
# Epoch 290/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.5278e-04 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9340
# Epoch 291/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.7248e-04 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9353
# Epoch 292/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.9038e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9327
# Epoch 293/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.9270e-04 - accuracy: 1.0000 - val_loss: 0.2267 - val_accuracy: 0.9353
# Epoch 294/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.6278e-04 - accuracy: 1.0000 - val_loss: 0.2280 - val_accuracy: 0.9353
# Epoch 295/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.6614e-04 - accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9353
# Epoch 296/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.8187e-04 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9366
# Epoch 297/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.6479e-04 - accuracy: 1.0000 - val_loss: 0.2326 - val_accuracy: 0.9353
# Epoch 298/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.8962e-04 - accuracy: 1.0000 - val_loss: 0.2331 - val_accuracy: 0.9353
# Epoch 299/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.7609e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9366
# Epoch 300/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.9001e-04 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9366
# Epoch 301/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.5368e-04 - accuracy: 1.0000 - val_loss: 0.2334 - val_accuracy: 0.9353
# Epoch 302/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.5445e-04 - accuracy: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.9353
# Epoch 303/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.5940e-04 - accuracy: 1.0000 - val_loss: 0.2313 - val_accuracy: 0.9327
# Epoch 304/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.4433e-04 - accuracy: 1.0000 - val_loss: 0.2319 - val_accuracy: 0.9353
# Epoch 305/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.2664e-04 - accuracy: 1.0000 - val_loss: 0.2331 - val_accuracy: 0.9366
# Epoch 306/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.2806e-04 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9353
# Epoch 307/2000
# 49/49 [==============================] - 6s 130ms/step - loss: 4.1446e-04 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9366
# Epoch 308/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.1099e-04 - accuracy: 1.0000 - val_loss: 0.2318 - val_accuracy: 0.9366
# Epoch 309/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.2233e-04 - accuracy: 1.0000 - val_loss: 0.2327 - val_accuracy: 0.9353
# Epoch 310/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.6043e-04 - accuracy: 1.0000 - val_loss: 0.2332 - val_accuracy: 0.9366
# Epoch 311/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.6175e-04 - accuracy: 1.0000 - val_loss: 0.2331 - val_accuracy: 0.9353
# Epoch 312/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.1654e-04 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9366
# Epoch 313/2000
# 49/49 [==============================] - 6s 133ms/step - loss: 4.0839e-04 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9366
# Epoch 314/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2194e-04 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9379
# Epoch 315/2000
# 49/49 [==============================] - 6s 133ms/step - loss: 4.1054e-04 - accuracy: 1.0000 - val_loss: 0.2317 - val_accuracy: 0.9392
# Epoch 316/2000
# 49/49 [==============================] - 7s 133ms/step - loss: 4.0190e-04 - accuracy: 1.0000 - val_loss: 0.2307 - val_accuracy: 0.9353
# Epoch 317/2000
# 49/49 [==============================] - 6s 133ms/step - loss: 4.0207e-04 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9379
# Epoch 318/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.1094e-04 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9366
# Epoch 319/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.5065e-04 - accuracy: 1.0000 - val_loss: 0.2329 - val_accuracy: 0.9366
# Epoch 320/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.2825e-07 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9379
# Epoch 1900/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8504e-07 - accuracy: 1.0000 - val_loss: 0.3354 - val_accuracy: 0.9379
# Epoch 1901/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.4166e-07 - accuracy: 1.0000 - val_loss: 0.3357 - val_accuracy: 0.9366
# Epoch 1902/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.7764e-07 - accuracy: 1.0000 - val_loss: 0.3367 - val_accuracy: 0.9366
# Epoch 1903/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.6083e-07 - accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.9366
# Epoch 1904/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.7749e-07 - accuracy: 1.0000 - val_loss: 0.3354 - val_accuracy: 0.9366
# Epoch 1905/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2676e-07 - accuracy: 1.0000 - val_loss: 0.3353 - val_accuracy: 0.9379
# Epoch 1906/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.1577e-07 - accuracy: 1.0000 - val_loss: 0.3361 - val_accuracy: 0.9366
# Epoch 1907/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 6.2032e-07 - accuracy: 1.0000 - val_loss: 0.3356 - val_accuracy: 0.9366
# Epoch 1908/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.6701e-07 - accuracy: 1.0000 - val_loss: 0.3377 - val_accuracy: 0.9392
# Epoch 1909/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 5.7123e-07 - accuracy: 1.0000 - val_loss: 0.3379 - val_accuracy: 0.9379
# Epoch 1910/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5657e-07 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9366
# Epoch 1911/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9551e-07 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9366
# Epoch 1912/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 6.5702e-07 - accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9366
# Epoch 1913/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.0907e-07 - accuracy: 1.0000 - val_loss: 0.3352 - val_accuracy: 0.9379
# Epoch 1914/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5423e-07 - accuracy: 1.0000 - val_loss: 0.3361 - val_accuracy: 0.9366
# Epoch 1915/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8230e-07 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 0.9366
# Epoch 1916/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.4698e-07 - accuracy: 1.0000 - val_loss: 0.3373 - val_accuracy: 0.9366
# Epoch 1917/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2669e-07 - accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.9353
# Epoch 1918/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8257e-07 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9366
# Epoch 1919/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1747e-07 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9366
# Epoch 1920/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9432e-07 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.9366
# Epoch 1921/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5369e-07 - accuracy: 1.0000 - val_loss: 0.3367 - val_accuracy: 0.9366
# Epoch 1922/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.4672e-07 - accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.9366
# Epoch 1923/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8307e-07 - accuracy: 1.0000 - val_loss: 0.3362 - val_accuracy: 0.9366
# Epoch 1924/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.0472e-07 - accuracy: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9366
# Epoch 1925/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5515e-07 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 0.9366
# Epoch 1926/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.2817e-07 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.9379
# Epoch 1927/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5118e-07 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9379
# Epoch 1928/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.3222e-07 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9366
# Epoch 1929/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.2386e-07 - accuracy: 1.0000 - val_loss: 0.3381 - val_accuracy: 0.9366
# Epoch 1930/2000
# 49/49 [==============================] - 7s 133ms/step - loss: 4.2826e-07 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9366
# Epoch 1931/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.7294e-07 - accuracy: 1.0000 - val_loss: 0.3396 - val_accuracy: 0.9366
# Epoch 1932/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9825e-07 - accuracy: 1.0000 - val_loss: 0.3397 - val_accuracy: 0.9366
# Epoch 1933/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.4306e-07 - accuracy: 1.0000 - val_loss: 0.3389 - val_accuracy: 0.9379
# Epoch 1934/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.6127e-07 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9379
# Epoch 1935/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.0292e-07 - accuracy: 1.0000 - val_loss: 0.3386 - val_accuracy: 0.9379
# Epoch 1936/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1450e-07 - accuracy: 1.0000 - val_loss: 0.3387 - val_accuracy: 0.9366
# Epoch 1937/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.4493e-07 - accuracy: 1.0000 - val_loss: 0.3380 - val_accuracy: 0.9379
# Epoch 1938/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 6.4017e-07 - accuracy: 1.0000 - val_loss: 0.3386 - val_accuracy: 0.9379
# Epoch 1939/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.0256e-07 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9379
# Epoch 1940/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8007e-07 - accuracy: 1.0000 - val_loss: 0.3377 - val_accuracy: 0.9392
# Epoch 1941/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 6.2035e-07 - accuracy: 1.0000 - val_loss: 0.3377 - val_accuracy: 0.9392
# Epoch 1942/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5634e-07 - accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.9392
# Epoch 1943/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.4824e-07 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9392
# Epoch 1944/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.4907e-07 - accuracy: 1.0000 - val_loss: 0.3395 - val_accuracy: 0.9379
# Epoch 1945/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.3578e-07 - accuracy: 1.0000 - val_loss: 0.3410 - val_accuracy: 0.9379
# Epoch 1946/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.7807e-07 - accuracy: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.9379
# Epoch 1947/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1704e-07 - accuracy: 1.0000 - val_loss: 0.3396 - val_accuracy: 0.9392
# Epoch 1948/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1292e-07 - accuracy: 1.0000 - val_loss: 0.3388 - val_accuracy: 0.9379
# Epoch 1949/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9658e-07 - accuracy: 1.0000 - val_loss: 0.3410 - val_accuracy: 0.9366
# Epoch 1950/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 6.8010e-07 - accuracy: 1.0000 - val_loss: 0.3378 - val_accuracy: 0.9366
# Epoch 1951/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8650e-07 - accuracy: 1.0000 - val_loss: 0.3366 - val_accuracy: 0.9366
# Epoch 1952/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9848e-07 - accuracy: 1.0000 - val_loss: 0.3370 - val_accuracy: 0.9366
# Epoch 1953/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.6878e-07 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9353
# Epoch 1954/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.9314e-07 - accuracy: 1.0000 - val_loss: 0.3378 - val_accuracy: 0.9353
# Epoch 1955/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.3167e-07 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9366
# Epoch 1956/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5700e-07 - accuracy: 1.0000 - val_loss: 0.3384 - val_accuracy: 0.9366
# Epoch 1957/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.0329e-07 - accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.9366
# Epoch 1958/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9894e-07 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.9366
# Epoch 1959/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.4375e-07 - accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.9353
# Epoch 1960/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1716e-07 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9366
# Epoch 1961/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.8886e-07 - accuracy: 1.0000 - val_loss: 0.3383 - val_accuracy: 0.9366
# Epoch 1962/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.6062e-07 - accuracy: 1.0000 - val_loss: 0.3390 - val_accuracy: 0.9366
# Epoch 1963/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.6221e-07 - accuracy: 1.0000 - val_loss: 0.3395 - val_accuracy: 0.9366
# Epoch 1964/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.9591e-07 - accuracy: 1.0000 - val_loss: 0.3395 - val_accuracy: 0.9379
# Epoch 1965/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9120e-07 - accuracy: 1.0000 - val_loss: 0.3390 - val_accuracy: 0.9392
# Epoch 1966/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.1297e-07 - accuracy: 1.0000 - val_loss: 0.3388 - val_accuracy: 0.9379
# Epoch 1967/2000
# 49/49 [==============================] - 6s 131ms/step - loss: 4.5527e-07 - accuracy: 1.0000 - val_loss: 0.3384 - val_accuracy: 0.9366
# Epoch 1968/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.6514e-07 - accuracy: 1.0000 - val_loss: 0.3389 - val_accuracy: 0.9366
# Epoch 1969/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.8526e-07 - accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.9379
# Epoch 1970/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.6316e-07 - accuracy: 1.0000 - val_loss: 0.3369 - val_accuracy: 0.9379
# Epoch 1971/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.6783e-07 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9353
# Epoch 1972/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.1059e-07 - accuracy: 1.0000 - val_loss: 0.3378 - val_accuracy: 0.9353
# Epoch 1973/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.4084e-07 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9353
# Epoch 1974/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5708e-07 - accuracy: 1.0000 - val_loss: 0.3382 - val_accuracy: 0.9366
# Epoch 1975/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.9170e-07 - accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.9366
# Epoch 1976/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.7171e-07 - accuracy: 1.0000 - val_loss: 0.3395 - val_accuracy: 0.9366
# Epoch 1977/2000
# 49/49 [==============================] - 7s 133ms/step - loss: 5.2312e-07 - accuracy: 1.0000 - val_loss: 0.3401 - val_accuracy: 0.9366
# Epoch 1978/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.0206e-07 - accuracy: 1.0000 - val_loss: 0.3398 - val_accuracy: 0.9353
# Epoch 1979/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1881e-07 - accuracy: 1.0000 - val_loss: 0.3402 - val_accuracy: 0.9366
# Epoch 1980/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2168e-07 - accuracy: 1.0000 - val_loss: 0.3408 - val_accuracy: 0.9353
# Epoch 1981/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.5728e-07 - accuracy: 1.0000 - val_loss: 0.3410 - val_accuracy: 0.9366
# Epoch 1982/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.5031e-07 - accuracy: 1.0000 - val_loss: 0.3387 - val_accuracy: 0.9366
# Epoch 1983/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 7.0072e-07 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9366
# Epoch 1984/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.1425e-07 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9366
# Epoch 1985/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.5060e-07 - accuracy: 1.0000 - val_loss: 0.3390 - val_accuracy: 0.9379
# Epoch 1986/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.1314e-07 - accuracy: 1.0000 - val_loss: 0.3392 - val_accuracy: 0.9379
# Epoch 1987/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2484e-07 - accuracy: 1.0000 - val_loss: 0.3392 - val_accuracy: 0.9379
# Epoch 1988/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 5.0899e-07 - accuracy: 1.0000 - val_loss: 0.3400 - val_accuracy: 0.9366
# Epoch 1989/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.6139e-07 - accuracy: 1.0000 - val_loss: 0.3396 - val_accuracy: 0.9366
# Epoch 1990/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.3913e-07 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9366
# Epoch 1991/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.7949e-07 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9366
# Epoch 1992/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.3038e-07 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9353
# Epoch 1993/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2326e-07 - accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9353
# Epoch 1994/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.8993e-07 - accuracy: 1.0000 - val_loss: 0.3402 - val_accuracy: 0.9366
# Epoch 1995/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2869e-07 - accuracy: 1.0000 - val_loss: 0.3399 - val_accuracy: 0.9366
# Epoch 1996/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.1710e-07 - accuracy: 1.0000 - val_loss: 0.3401 - val_accuracy: 0.9366
# Epoch 1997/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.2218e-07 - accuracy: 1.0000 - val_loss: 0.3404 - val_accuracy: 0.9366
# Epoch 1998/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 4.4899e-07 - accuracy: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.9366
# Epoch 1999/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 6.5398e-07 - accuracy: 1.0000 - val_loss: 0.3401 - val_accuracy: 0.9366
# Epoch 2000/2000
# 49/49 [==============================] - 6s 132ms/step - loss: 3.6968e-07 - accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.9366
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 322ms/step - loss: 1.6906 - accuracy: 0.7676
# test_indoor_ds_results:test loss, test acc: [1.6905728578567505, 0.7675585150718689]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 413ms/step - loss: 3.2609 - accuracy: 0.6557
# test_outdoor_ds_results:test loss, test acc: [3.2609364986419678, 0.6557325124740601]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 7s 171ms/step - loss: 2.9432 - accuracy: 0.6659
# test_belt_ds_results:test loss, test acc: [2.9431777000427246, 0.6659111380577087]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/NASNetMobile_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 6s 106ms/step - loss: 1.0500 - accuracy: 0.7642
# 50/50 [==============================] - 5s 106ms/step - loss: 1.9430 - accuracy: 0.6529
# 35/35 [==============================] - 4s 107ms/step - loss: 1.8050 - accuracy: 0.6614
# Epoch200
#  test_indoor_acc=0.764214038848877
#  test_outdoor_acc=0.6528662443161011
#  test_belt_acc=0.6613780856132507
# 29/29 [==============================] - 6s 107ms/step - loss: 1.1663 - accuracy: 0.7653
# 50/50 [==============================] - 5s 108ms/step - loss: 2.2066 - accuracy: 0.6522
# 35/35 [==============================] - 4s 108ms/step - loss: 2.0176 - accuracy: 0.6600
# Epoch400
#  test_indoor_acc=0.7653288841247559
#  test_outdoor_acc=0.6522293090820312
#  test_belt_acc=0.6600181460380554
# 29/29 [==============================] - 6s 105ms/step - loss: 1.2836 - accuracy: 0.7653
# 50/50 [==============================] - 5s 106ms/step - loss: 2.4291 - accuracy: 0.6516
# 35/35 [==============================] - 4s 105ms/step - loss: 2.2244 - accuracy: 0.6659
# Epoch600
#  test_indoor_acc=0.7653288841247559
#  test_outdoor_acc=0.6515923738479614
#  test_belt_acc=0.6659111380577087
# 29/29 [==============================] - 6s 107ms/step - loss: 1.3684 - accuracy: 0.7659
# 50/50 [==============================] - 5s 108ms/step - loss: 2.6175 - accuracy: 0.6557
# 35/35 [==============================] - 4s 107ms/step - loss: 2.3867 - accuracy: 0.6641
# Epoch800
#  test_indoor_acc=0.7658863067626953
#  test_outdoor_acc=0.6557325124740601
#  test_belt_acc=0.6640979051589966
# 29/29 [==============================] - 6s 107ms/step - loss: 1.4516 - accuracy: 0.7625
# 50/50 [==============================] - 5s 108ms/step - loss: 2.7798 - accuracy: 0.6541
# 35/35 [==============================] - 4s 107ms/step - loss: 2.5439 - accuracy: 0.6646
# Epoch1000
#  test_indoor_acc=0.7625418305397034
#  test_outdoor_acc=0.6541401147842407
#  test_belt_acc=0.6645511984825134
# 29/29 [==============================] - 7s 108ms/step - loss: 1.5479 - accuracy: 0.7642
# 50/50 [==============================] - 5s 109ms/step - loss: 2.9322 - accuracy: 0.6541
# 35/35 [==============================] - 4s 109ms/step - loss: 2.6897 - accuracy: 0.6623
# Epoch1200
#  test_indoor_acc=0.764214038848877
#  test_outdoor_acc=0.6541401147842407
#  test_belt_acc=0.6622846722602844
# 29/29 [==============================] - 7s 108ms/step - loss: 1.5856 - accuracy: 0.7664
# 50/50 [==============================] - 5s 109ms/step - loss: 3.0207 - accuracy: 0.6561
# 35/35 [==============================] - 4s 108ms/step - loss: 2.7625 - accuracy: 0.6641
# Epoch1400
#  test_indoor_acc=0.7664437294006348
#  test_outdoor_acc=0.656050980091095
#  test_belt_acc=0.6640979051589966
# 29/29 [==============================] - 7s 110ms/step - loss: 1.6370 - accuracy: 0.7659
# 50/50 [==============================] - 5s 109ms/step - loss: 3.1503 - accuracy: 0.6538
# 35/35 [==============================] - 4s 109ms/step - loss: 2.8534 - accuracy: 0.6650
# Epoch1600
#  test_indoor_acc=0.7658863067626953
#  test_outdoor_acc=0.6538216471672058
#  test_belt_acc=0.665004551410675
# 29/29 [==============================] - 7s 110ms/step - loss: 1.6625 - accuracy: 0.7670
# 50/50 [==============================] - 5s 109ms/step - loss: 3.2180 - accuracy: 0.6561
# 35/35 [==============================] - 4s 109ms/step - loss: 2.9083 - accuracy: 0.6655
# Epoch1800
#  test_indoor_acc=0.7670010924339294
#  test_outdoor_acc=0.656050980091095
#  test_belt_acc=0.6654578447341919
# 29/29 [==============================] - 7s 109ms/step - loss: 1.6906 - accuracy: 0.7676
# 50/50 [==============================] - 6s 110ms/step - loss: 3.2609 - accuracy: 0.6557
# 35/35 [==============================] - 4s 109ms/step - loss: 2.9432 - accuracy: 0.66590s - loss: 2.9432 - accuracy: 0.66
# Epoch2000
#  test_indoor_acc=0.7675585150718689
#  test_outdoor_acc=0.6557325124740601
#  test_belt_acc=0.6659111380577087

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.6964007218678793
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.764214038848877,
#  0.7653288841247559,
#  0.7653288841247559,
#  0.7658863067626953,
#  0.7625418305397034,
#  0.764214038848877,
#  0.7664437294006348,
#  0.7658863067626953,
#  0.7670010924339294,
#  0.7675585150718689]

# %%
test_outdoor_acc
# Out:
# [0.6528662443161011,
#  0.6522293090820312,
#  0.6515923738479614,
#  0.6557325124740601,
#  0.6541401147842407,
#  0.6541401147842407,
#  0.656050980091095,
#  0.6538216471672058,
#  0.656050980091095,
#  0.6557325124740601]

# %%
test_belt_acc
# Out:
# [0.6613780856132507,
#  0.6600181460380554,
#  0.6659111380577087,
#  0.6640979051589966,
#  0.6645511984825134,
#  0.6622846722602844,
#  0.6640979051589966,
#  0.665004551410675,
#  0.6654578447341919,
#  0.6659111380577087]

# %%
test_indoor_loss
# Out:
# [1.0499695539474487,
#  1.166313886642456,
#  1.2836252450942993,
#  1.368361473083496,
#  1.4515831470489502,
#  1.5478999614715576,
#  1.5856369733810425,
#  1.6369866132736206,
#  1.6625351905822754,
#  1.6905728578567505]

# %%
test_outdoor_loss
# Out:
# [1.9429931640625,
#  2.206597328186035,
#  2.429128408432007,
#  2.6174755096435547,
#  2.7797741889953613,
#  2.932163953781128,
#  3.0206825733184814,
#  3.1503233909606934,
#  3.2179667949676514,
#  3.2609364986419678]

# %%
test_belt_loss
# Out:
# [1.805005431175232,
#  2.017620086669922,
#  2.224395751953125,
#  2.386744260787964,
#  2.5439281463623047,
#  2.689711093902588,
#  2.76254940032959,
#  2.853389024734497,
#  2.9083149433135986,
#  2.9431777000427246]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.nasnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=4905
# FP=2235
# acc=0.6869747899159664
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 51.724137931034484%
# 2WayConnectorforFoley acc = 85.71428571428571%
# 2WayFoleyCatheter acc = 81.34328358208955%
# 3WayConnectorforFoley acc = 91.45299145299145%
# 3Waystopcock acc = 94.5945945945946%
# AlcoholBottle acc = 71.875%
# AlcoholPad acc = 44.44444444444444%
# BootCover acc = 63.85542168674698%
# CottonBall acc = 85.62874251497006%
# CottonSwap acc = 53.14685314685315%
# Dilator acc = 52.13675213675214%
# DisposableInfusionSet acc = 37.16814159292036%
# ExtensionTube acc = 13.008130081300814%
# FaceShield acc = 65.4320987654321%
# FrontLoadSyringe acc = 56.63716814159292%
# GauzePad acc = 30.113636363636363%
# Glove acc = 74.70238095238095%
# GuideWire acc = 43.75%
# LiquidBottle acc = 58.396946564885496%
# Mask acc = 91.16883116883116%
# NGTube acc = 41.935483870967744%
# NasalCannula acc = 71.68141592920354%
# Needle acc = 90.35714285714286%
# OxygenMask acc = 69.92481203007519%
# PPESuit acc = 79.03225806451613%
# PharmaceuticalProduct acc = 54.67289719626168%
# Pill acc = 95.65826330532214%
# PillBottle acc = 50.3875968992248%
# PrefilledHumidifier acc = 58.119658119658126%
# PressureConnectingTube acc = 57.25190839694656%
# ReusableHumidifier acc = 78.8135593220339%
# SodiumChlorideBag acc = 81.10236220472441%
# SterileHumidifierAdapter acc = 70.0%
# SurgicalBlade acc = 86.72566371681415%
# SurgicalCap acc = 80.18018018018019%
# SurgicalSuit acc = 24.242424242424242%
# Syringe acc = 82.50950570342205%
# TrachealTube acc = 39.44954128440367%
# UrineBag acc = 52.5%
# Vaccinebottle acc = 74.64788732394366%
# WingedInfusionSet acc = 58.77192982456141%
#
#
#
# all_avg_eachclass = 64.49410564164802%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 60,   2,   0, ...,   0,   0,   0],
#        [  4, 126,   0, ...,   0,   2,   0],
#        [  0,   0, 109, ...,   0,   0,   3],
#        ...,
#        [  0,   0,   0, ...,  63,   0,   0],
#        [  0,   0,   0, ...,   0, 159,   0],
#        [  0,   0,   1, ...,   0,   0,  67]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[51.72413793,  1.72413793,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 2.72108844, 85.71428571,  0.        , ...,  0.        ,
#          1.36054422,  0.        ],
#        [ 0.        ,  0.        , 81.34328358, ...,  0.        ,
#          0.        ,  2.23880597],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 52.5       ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         74.64788732,  0.        ],
#        [ 0.        ,  0.        ,  0.87719298, ...,  0.        ,
#          0.        , 58.77192982]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
