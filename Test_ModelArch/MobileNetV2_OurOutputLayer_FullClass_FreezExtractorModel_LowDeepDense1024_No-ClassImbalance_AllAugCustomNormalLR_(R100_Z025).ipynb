# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

mobilenetv2_model = keras.applications.MobileNetV2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

mobilenetv2_model_nooutput = mobilenetv2_model.layers[-2].output
custom_mobilenetv2_model = Model(inputs = mobilenetv2_model.input, outputs = mobilenetv2_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_mobilenetv2_model.trainable = False
for layer in custom_mobilenetv2_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_mobilenetv2_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           out_relu[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_inceptionv3_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_mobilenetv2_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2756/1916339556.py in <module>
# ----> 1 model = tf.keras.Sequential()
#       2 # Feature Extractor
#       3 model.add(custom_mobilenetv2_model)
#       4 # Classifier
#       5 #DeepDense
#
# NameError: name 'tf' is not defined

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 3,611,753
# Trainable params: 1,353,769
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 37s 197ms/step - loss: 1.2301 - accuracy: 0.6656 - val_loss: 0.4580 - val_accuracy: 0.8551
# Epoch 2/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.2556 - accuracy: 0.9241 - val_loss: 0.3449 - val_accuracy: 0.8952
# Epoch 3/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.1332 - accuracy: 0.9603 - val_loss: 0.2686 - val_accuracy: 0.9107
# Epoch 4/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0745 - accuracy: 0.9800 - val_loss: 0.2906 - val_accuracy: 0.9082
# Epoch 5/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0548 - accuracy: 0.9890 - val_loss: 0.2480 - val_accuracy: 0.9107
# Epoch 6/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0385 - accuracy: 0.9919 - val_loss: 0.2831 - val_accuracy: 0.9043
# Epoch 7/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0188 - accuracy: 0.9971 - val_loss: 0.2149 - val_accuracy: 0.9405
# Epoch 8/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0139 - accuracy: 0.9990 - val_loss: 0.2175 - val_accuracy: 0.9431
# Epoch 9/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0110 - accuracy: 0.9987 - val_loss: 0.2151 - val_accuracy: 0.9379
# Epoch 10/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0077 - accuracy: 0.9997 - val_loss: 0.2121 - val_accuracy: 0.9353
# Epoch 11/2000
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.2130 - val_accuracy: 0.9353
# Epoch 12/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.2177 - val_accuracy: 0.9405
# Epoch 13/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.2467 - val_accuracy: 0.9314
# Epoch 14/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.1961 - val_accuracy: 0.9405
# Epoch 15/2000
# 49/49 [==============================] - 3s 70ms/step - loss: 0.0073 - accuracy: 0.9990 - val_loss: 0.2366 - val_accuracy: 0.9314
# Epoch 16/2000
# 49/49 [==============================] - 3s 70ms/step - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.2212 - val_accuracy: 0.9353
# Epoch 17/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.1971 - val_accuracy: 0.9379
# Epoch 18/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.2029 - val_accuracy: 0.9392
# Epoch 19/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9418
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 20/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9405
# Epoch 21/2000
# 49/49 [==============================] - 3s 70ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9418
# Epoch 22/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9444
# Epoch 23/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9418
# Epoch 24/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 0.9457
# Epoch 25/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9444
# Epoch 26/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9431
# Epoch 27/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9457
# Epoch 28/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9418
# Epoch 29/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9457
# Epoch 30/2000
# 49/49 [==============================] - 3s 70ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9444
# Epoch 31/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 9.6076e-04 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9444
# Epoch 32/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 9.1026e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9431
# Epoch 33/2000
# 49/49 [==============================] - 3s 70ms/step - loss: 8.9671e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9418
# Epoch 34/2000
# 49/49 [==============================] - 3s 70ms/step - loss: 8.7399e-04 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9431
# Epoch 35/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 8.5659e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9418
# Epoch 36/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 8.7013e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9431
# Epoch 37/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 8.0708e-04 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9431
# Epoch 38/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 7.8467e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9444
# Epoch 39/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 8.2811e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9444
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 40/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 7.5753e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9444
# Epoch 41/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 7.4025e-04 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 0.9457
# Epoch 42/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 7.4423e-04 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9457
# Epoch 43/2000
# 49/49 [==============================] - 3s 68ms/step - loss: 7.6958e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9457
# Epoch 44/2000
# 49/49 [==============================] - 3s 69ms/step - loss: 6.8244e-04 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9444
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 45/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 6.7640e-04 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9444
# Epoch 46/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.6917e-04 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9444
# Epoch 47/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.3838e-04 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9444
# Epoch 48/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.2971e-04 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9444
# Epoch 49/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.2399e-04 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9444
# Epoch 50/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.1450e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9444
# Epoch 51/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.0622e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9444
# Epoch 52/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.1629e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9444
# Epoch 53/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.6123e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 54/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.5379e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 55/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6459e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 56/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.8307e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9431
# Epoch 57/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.7291e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9444
# Epoch 58/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.0284e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9418
# Epoch 59/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.9991e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9418
# Epoch 60/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.7516e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9418
# Epoch 61/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.0631e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9418
# Epoch 62/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.4541e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9418
# Epoch 63/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.1750e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9418
# Epoch 64/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.9991e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9418
# Epoch 65/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.0645e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9418
# Epoch 66/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6450e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9431
# Epoch 67/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.4415e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9431
# Epoch 68/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.9361e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9431
# Epoch 69/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.9323e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9431
# Epoch 70/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.6607e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9431
# Epoch 71/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6440e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9431
# Epoch 72/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.4974e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 73/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.5933e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9431
# Epoch 74/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.2992e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 75/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.4350e-04 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9431
# Epoch 76/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.7937e-04 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 0.9431
# Epoch 77/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.6222e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9418
# Epoch 78/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.5568e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9418
# Epoch 79/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.4786e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9431
# Epoch 80/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.5389e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9431
# Epoch 81/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.5538e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9431
# Epoch 82/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6406e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9418
# Epoch 83/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.4449e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9418
# Epoch 84/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.4462e-04 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9418
# Epoch 85/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.9889e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9431
# Epoch 86/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6889e-04 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9431
# Epoch 87/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.1806e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9431
# Epoch 88/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.8001e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9431
# Epoch 89/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.3630e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9431
# Epoch 90/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.3382e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9431
# Epoch 91/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6015e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9418
# Epoch 92/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.8509e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9431
# Epoch 93/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.3916e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9431
# Epoch 94/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.3612e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9431
# Epoch 95/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.7130e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9418
# Epoch 96/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.3575e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9431
# Epoch 97/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.4942e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9431
# Epoch 98/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 6.3121e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9431
# Epoch 99/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.5585e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9431
# Epoch 100/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6251e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9431
# Epoch 101/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.2653e-04 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9444
# Epoch 102/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.7368e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9444
# Epoch 103/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.8565e-04 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9444
# Epoch 104/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.1374e-04 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9444
# Epoch 105/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.4818e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9444
# Epoch 106/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6733e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9444
# Epoch 107/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.0449e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9444
# Epoch 108/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6485e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9431
# Epoch 109/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.6229e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9431
# Epoch 110/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.9680e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9444
# Epoch 111/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.8527e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 112/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.6724e-04 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9418
# Epoch 113/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.2064e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9431
# Epoch 114/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.0888e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9431
# Epoch 115/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.9454e-04 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9444
# Epoch 116/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.2820e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9431
# Epoch 117/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 6.0984e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9431
# Epoch 118/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.8939e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9418
# Epoch 119/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.4843e-04 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9418
# Epoch 120/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.6746e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9444
# Epoch 121/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.9417e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9444
# Epoch 122/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.9209e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9444
# Epoch 123/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.5357e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9431
# Epoch 124/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.5326e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9431
# Epoch 125/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.9263e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9457
# Epoch 126/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.6350e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9431
# Epoch 127/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.8558e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9431
# Epoch 128/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.2933e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9431
# Epoch 129/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.5973e-04 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9431
# Epoch 130/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.5381e-04 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9444
# Epoch 131/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.5174e-04 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9457
# Epoch 132/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.9444e-04 - accuracy: 1.0000 - val_loss: 0.1880 - val_accuracy: 0.9457
# Epoch 133/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.2852e-04 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9431
# Epoch 134/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.8862e-04 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9418
# Epoch 135/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.1217e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9418
# Epoch 136/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.2584e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9431
# Epoch 137/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.3116e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9431
# Epoch 138/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.5603e-04 - accuracy: 1.0000 - val_loss: 0.1874 - val_accuracy: 0.9470
# Epoch 139/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.4985e-04 - accuracy: 1.0000 - val_loss: 0.1892 - val_accuracy: 0.9470
# Epoch 140/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.1208e-04 - accuracy: 1.0000 - val_loss: 0.1888 - val_accuracy: 0.9470
# Epoch 141/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.6064e-04 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 0.9444
# Epoch 142/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.1232e-04 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9431
# Epoch 143/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 5.0092e-04 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9418
# Epoch 144/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.6930e-04 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9418
# Epoch 145/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.0486e-04 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9431
# Epoch 146/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.9540e-04 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9418
# Epoch 147/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.9469e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9431
# Epoch 148/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 5.4551e-04 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9405
# Epoch 149/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.9447e-04 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9405
# Epoch 150/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.7886e-04 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 0.9405
# Epoch 151/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.4162e-04 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9405
# Epoch 152/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.8910e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9405
# Epoch 153/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.4923e-04 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9405
# Epoch 154/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.3366e-04 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 0.9431
# Epoch 155/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.4991e-04 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.9418
# Epoch 156/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.3361e-04 - accuracy: 1.0000 - val_loss: 0.1887 - val_accuracy: 0.9418
# Epoch 157/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.3211e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9405
# Epoch 158/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.5590e-04 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9392
# Epoch 159/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.5157e-04 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9392
# Epoch 160/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.1349e-04 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9418
# Epoch 161/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.3825e-04 - accuracy: 1.0000 - val_loss: 0.1886 - val_accuracy: 0.9418
# Epoch 162/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.6263e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9444
# Epoch 163/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.4143e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9457
# Epoch 164/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.7850e-04 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9418
# Epoch 165/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.3635e-04 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9405
# Epoch 166/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.3416e-04 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 0.9418
# Epoch 167/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.9778e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9418
# Epoch 168/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.2343e-04 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9418
# Epoch 169/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.0905e-04 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9405
# Epoch 170/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.9545e-04 - accuracy: 1.0000 - val_loss: 0.1898 - val_accuracy: 0.9418
# Epoch 171/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.1779e-04 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9431
# Epoch 172/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 4.2288e-04 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9444
# Epoch 173/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.9610e-04 - accuracy: 1.0000 - val_loss: 0.1889 - val_accuracy: 0.9418
# Epoch 174/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.6274e-04 - accuracy: 1.0000 - val_loss: 0.1885 - val_accuracy: 0.9418
# Epoch 175/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 4.0417e-04 - accuracy: 1.0000 - val_loss: 0.1897 - val_accuracy: 0.9418
# Epoch 176/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.7722e-04 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9418
# Epoch 177/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.9586e-04 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9418
# Epoch 178/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.8278e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9405
# Epoch 179/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.5619e-04 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9405
# Epoch 180/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.6988e-04 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9444
# Epoch 181/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.7119e-04 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9418
# Epoch 182/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.5106e-04 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9405
# Epoch 183/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.5446e-04 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9431
# Epoch 184/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.3783e-04 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9405
# Epoch 185/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.6406e-04 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9379
# Epoch 186/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.4597e-04 - accuracy: 1.0000 - val_loss: 0.1903 - val_accuracy: 0.9405
# Epoch 187/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.1081e-04 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9418
# Epoch 188/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.3590e-04 - accuracy: 1.0000 - val_loss: 0.1900 - val_accuracy: 0.9431
# Epoch 189/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.3070e-04 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9431
# Epoch 190/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.2964e-04 - accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.9431
# Epoch 191/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.2474e-04 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9405
# Epoch 192/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.8874e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9418
# Epoch 193/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 3.6179e-04 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9405
# Epoch 194/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.2484e-04 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.9444
# Epoch 195/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.2039e-04 - accuracy: 1.0000 - val_loss: 0.1896 - val_accuracy: 0.9418
# Epoch 196/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.8117e-04 - accuracy: 1.0000 - val_loss: 0.1902 - val_accuracy: 0.9392
# Epoch 197/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.9944e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9405
# Epoch 198/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.1778e-04 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9392
# Epoch 199/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.1940e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9392
# Epoch 200/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.9981e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9392
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.9193e-04 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9405
# Epoch 202/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6223e-04 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9405
# Epoch 203/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.8526e-04 - accuracy: 1.0000 - val_loss: 0.1921 - val_accuracy: 0.9392
# Epoch 204/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6332e-04 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9405
# Epoch 205/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 3.0488e-04 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9418
# Epoch 206/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6698e-04 - accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.9405
# Epoch 207/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.9452e-04 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9431
# Epoch 208/2000
# 49/49 [==============================] - 4s 74ms/step - loss: 2.7567e-04 - accuracy: 1.0000 - val_loss: 0.1904 - val_accuracy: 0.9444
# Epoch 209/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 2.6117e-04 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9444
# Epoch 210/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.3445e-04 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9431 accuracy: 1.
# Epoch 211/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.4903e-04 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9392
# Epoch 212/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.7791e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9405
# Epoch 213/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.6300e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9405
# Epoch 214/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.5974e-04 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9405
# Epoch 215/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.5053e-04 - accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9405
# Epoch 216/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.4360e-04 - accuracy: 1.0000 - val_loss: 0.1921 - val_accuracy: 0.9392
# Epoch 217/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.4439e-04 - accuracy: 1.0000 - val_loss: 0.1912 - val_accuracy: 0.9392
# Epoch 218/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.2962e-04 - accuracy: 1.0000 - val_loss: 0.1915 - val_accuracy: 0.9392
# Epoch 219/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.2422e-04 - accuracy: 1.0000 - val_loss: 0.1911 - val_accuracy: 0.9392
# Epoch 220/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.5880e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9392
# Epoch 221/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.7759e-04 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9418
# Epoch 222/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.5372e-04 - accuracy: 1.0000 - val_loss: 0.1937 - val_accuracy: 0.9405
# Epoch 223/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.2775e-04 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9392
# Epoch 224/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1205e-04 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9379
# Epoch 225/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0915e-04 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9392
# Epoch 226/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.2673e-04 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9405
# Epoch 227/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1828e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9379
# Epoch 228/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0649e-04 - accuracy: 1.0000 - val_loss: 0.1931 - val_accuracy: 0.9392
# Epoch 229/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0487e-04 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9405
# Epoch 230/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.2074e-04 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9392
# Epoch 231/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0389e-04 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9379
# Epoch 232/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0665e-04 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.9379
# Epoch 233/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9769e-04 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 0.9379
# Epoch 234/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0611e-04 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9392
# Epoch 235/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 2.0359e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9405
# Epoch 236/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.1077e-04 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9392
# Epoch 237/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.8947e-04 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9392
# Epoch 238/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.8227e-04 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9405
# Epoch 239/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.9628e-04 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9405
# Epoch 240/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.8200e-04 - accuracy: 1.0000 - val_loss: 0.1922 - val_accuracy: 0.9392
# Epoch 241/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.7707e-04 - accuracy: 1.0000 - val_loss: 0.1926 - val_accuracy: 0.9392
# Epoch 242/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9100e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9405
# Epoch 243/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.7882e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9392
# Epoch 244/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.6647e-04 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9392
# Epoch 245/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.7764e-04 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9379
# Epoch 246/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7984e-04 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9392
# Epoch 247/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.7408e-04 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9392
# Epoch 248/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 1.7191e-04 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9379
# Epoch 249/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 1.5050e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9379
# Epoch 250/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.5817e-04 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9405
# Epoch 251/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.6852e-04 - accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.9392
# Epoch 252/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.4901e-04 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9392
# Epoch 253/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5178e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9379
# Epoch 254/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.5713e-04 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9392
# Epoch 255/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.6091e-04 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9392
# Epoch 256/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 1.5112e-04 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9379
# Epoch 257/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.4077e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9392
# Epoch 258/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 1.5080e-04 - accuracy: 1.0000 - val_loss: 0.1937 - val_accuracy: 0.9379
# Epoch 259/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.5245e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9392
# Epoch 260/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 1.3723e-04 - accuracy: 1.0000 - val_loss: 0.1921 - val_accuracy: 0.9392
# Epoch 261/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 1.4513e-04 - accuracy: 1.0000 - val_loss: 0.1929 - val_accuracy: 0.9392
# Epoch 262/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4618e-04 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9392
# Epoch 263/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.3940e-04 - accuracy: 1.0000 - val_loss: 0.1945 - val_accuracy: 0.9392
# Epoch 264/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.3486e-04 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9392
# Epoch 265/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.2305e-04 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9392
# Epoch 266/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.3777e-04 - accuracy: 1.0000 - val_loss: 0.1944 - val_accuracy: 0.9366
# Epoch 267/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.3692e-04 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9405
# Epoch 268/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.1812e-04 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 0.9392
# Epoch 269/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.2971e-04 - accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9379
# Epoch 270/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.3500e-04 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9405
# Epoch 271/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.4375e-04 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9418
# Epoch 272/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.3686e-04 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9457
# Epoch 273/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.2981e-04 - accuracy: 1.0000 - val_loss: 0.1938 - val_accuracy: 0.9431
# Epoch 274/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.1524e-04 - accuracy: 1.0000 - val_loss: 0.1959 - val_accuracy: 0.9418
# Epoch 275/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.2636e-04 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9392
# Epoch 276/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.2297e-04 - accuracy: 1.0000 - val_loss: 0.1935 - val_accuracy: 0.9392
# Epoch 277/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.2109e-04 - accuracy: 1.0000 - val_loss: 0.1943 - val_accuracy: 0.9405
# Epoch 278/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2184e-04 - accuracy: 1.0000 - val_loss: 0.1949 - val_accuracy: 0.9418
# Epoch 279/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1130e-04 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 0.9405
# Epoch 280/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2395e-04 - accuracy: 1.0000 - val_loss: 0.1952 - val_accuracy: 0.9431
# Epoch 281/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0821e-04 - accuracy: 1.0000 - val_loss: 0.1965 - val_accuracy: 0.9405
# Epoch 282/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.0157e-04 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9405
# Epoch 283/2000
# 49/49 [==============================] - 4s 76ms/step - loss: 1.0875e-04 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.9431
# Epoch 284/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1150e-04 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9431
# Epoch 285/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1418e-04 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9418
# Epoch 286/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1705e-04 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9392
# Epoch 287/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1420e-04 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9431
# Epoch 288/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2608e-04 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9392
# Epoch 289/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0753e-04 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9392
# Epoch 290/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.8682e-05 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9379
# Epoch 291/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0894e-04 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9392
# Epoch 292/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.7244e-05 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9405
# Epoch 293/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.5240e-05 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9392
# Epoch 294/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0073e-04 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9392
# Epoch 295/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.0230e-05 - accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9392
# Epoch 296/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.3160e-05 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9405
# Epoch 297/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.9257e-05 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9392
# Epoch 298/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.1543e-04 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 0.9418
# Epoch 299/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 8.8046e-05 - accuracy: 1.0000 - val_loss: 0.1968 - val_accuracy: 0.9405
# Epoch 300/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 9.5451e-05 - accuracy: 1.0000 - val_loss: 0.1985 - val_accuracy: 0.9405
# Epoch 301/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.5213e-05 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9392
# Epoch 302/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.9499e-05 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.9405
# Epoch 303/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.2969e-05 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9405
# Epoch 304/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 1.0069e-04 - accuracy: 1.0000 - val_loss: 0.1977 - val_accuracy: 0.9405
# Epoch 305/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.6738e-05 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.9405
# Epoch 306/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 8.0089e-05 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9405
# Epoch 307/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.6915e-05 - accuracy: 1.0000 - val_loss: 0.1961 - val_accuracy: 0.9392
# Epoch 308/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 8.8838e-05 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.9392
# Epoch 309/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.9159e-05 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9418
# Epoch 310/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 9.1802e-05 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9418
# Epoch 311/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.3438e-05 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9418
# Epoch 312/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.6189e-05 - accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9392
# Epoch 313/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.7108e-05 - accuracy: 1.0000 - val_loss: 0.1967 - val_accuracy: 0.9405
# Epoch 314/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 8.0376e-05 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9405
# Epoch 315/2000
# 49/49 [==============================] - 3s 71ms/step - loss: 8.5193e-05 - accuracy: 1.0000 - val_loss: 0.1998 - val_accuracy: 0.9392
# Epoch 316/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 7.1865e-05 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9405
# Epoch 317/2000
# 49/49 [==============================] - 3s 72ms/step - loss: 7.0708e-05 - accuracy: 1.0000 - val_loss: 0.1990 - val_accuracy: 0.9405
# Epoch 318/2000
# ...
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5626e-07 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9418
# Epoch 1899/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0950e-07 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9418
# Epoch 1900/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3847e-07 - accuracy: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9405
# Epoch 1901/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2537e-07 - accuracy: 1.0000 - val_loss: 0.2634 - val_accuracy: 0.9418
# Epoch 1902/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3766e-07 - accuracy: 1.0000 - val_loss: 0.2634 - val_accuracy: 0.9418
# Epoch 1903/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2803e-07 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9418
# Epoch 1904/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2075e-07 - accuracy: 1.0000 - val_loss: 0.2634 - val_accuracy: 0.9418
# Epoch 1905/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1166e-07 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9418
# Epoch 1906/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 2.0790e-07 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9418
# Epoch 1907/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1709e-07 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9418
# Epoch 1908/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1170e-07 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9418
# Epoch 1909/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5125e-07 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9418
# Epoch 1910/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3854e-07 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9431
# Epoch 1911/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5907e-07 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9431
# Epoch 1912/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2110e-07 - accuracy: 1.0000 - val_loss: 0.2626 - val_accuracy: 0.9431
# Epoch 1913/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2568e-07 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9431
# Epoch 1914/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1258e-07 - accuracy: 1.0000 - val_loss: 0.2628 - val_accuracy: 0.9431
# Epoch 1915/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3658e-07 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9418
# Epoch 1916/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5118e-07 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9418
# Epoch 1917/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4455e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9431
# Epoch 1918/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.1979e-07 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9418
# Epoch 1919/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1840e-07 - accuracy: 1.0000 - val_loss: 0.2633 - val_accuracy: 0.9418
# Epoch 1920/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3854e-07 - accuracy: 1.0000 - val_loss: 0.2634 - val_accuracy: 0.9418
# Epoch 1921/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2056e-07 - accuracy: 1.0000 - val_loss: 0.2632 - val_accuracy: 0.9431
# Epoch 1922/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4478e-07 - accuracy: 1.0000 - val_loss: 0.2633 - val_accuracy: 0.9431
# Epoch 1923/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3327e-07 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9444
# Epoch 1924/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2237e-07 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9431
# Epoch 1925/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.6831e-08 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9431
# Epoch 1926/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0885e-07 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9418
# Epoch 1927/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2533e-07 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9431
# Epoch 1928/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1139e-07 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9418
# Epoch 1929/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2753e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9418
# Epoch 1930/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1324e-07 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9418
# Epoch 1931/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.8545e-07 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9405
# Epoch 1932/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1397e-07 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9405
# Epoch 1933/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1944e-07 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9405
# Epoch 1934/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4991e-07 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9418
# Epoch 1935/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4478e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9405
# Epoch 1936/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1913e-07 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9418
# Epoch 1937/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6562e-07 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9444
# Epoch 1938/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2229e-07 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9444
# Epoch 1939/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3180e-07 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9431
# Epoch 1940/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1836e-07 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9431
# Epoch 1941/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2657e-07 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9431
# Epoch 1942/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2749e-07 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9418
# Epoch 1943/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1775e-07 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9431
# Epoch 1944/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3219e-07 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9418
# Epoch 1945/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1278e-07 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9418
# Epoch 1946/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4259e-07 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9418
# Epoch 1947/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0708e-07 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9405
# Epoch 1948/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0326e-07 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9405
# Epoch 1949/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0426e-07 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9418
# Epoch 1950/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3666e-07 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9418
# Epoch 1951/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1393e-07 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9444
# Epoch 1952/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.8680e-08 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9444
# Epoch 1953/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.5175e-08 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9444
# Epoch 1954/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0638e-07 - accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9431
# Epoch 1955/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0319e-07 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9431
# Epoch 1956/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1609e-07 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9418
# Epoch 1957/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4162e-07 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9405
# Epoch 1958/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3974e-07 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9405
# Epoch 1959/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5018e-07 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9418
# Epoch 1960/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4625e-07 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9418
# Epoch 1961/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0896e-07 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9431
# Epoch 1962/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0184e-07 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9431
# Epoch 1963/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1089e-07 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9431
# Epoch 1964/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2133e-07 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9431
# Epoch 1965/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4417e-07 - accuracy: 1.0000 - val_loss: 0.2633 - val_accuracy: 0.9431
# Epoch 1966/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1532e-07 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9431
# Epoch 1967/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3227e-07 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9444
# Epoch 1968/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0434e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9431
# Epoch 1969/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1490e-07 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9431
# Epoch 1970/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2244e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9418
# Epoch 1971/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1412e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9418
# Epoch 1972/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.6743e-07 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9405
# Epoch 1973/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1258e-07 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9405
# Epoch 1974/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3623e-07 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9405
# Epoch 1975/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4051e-07 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9405
# Epoch 1976/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0091e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9418
# Epoch 1977/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0022e-07 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9418
# Epoch 1978/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3165e-07 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9405
# Epoch 1979/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1594e-07 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9405
# Epoch 1980/2000
# 49/49 [==============================] - 4s 73ms/step - loss: 1.2718e-07 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9418
# Epoch 1981/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.1670e-08 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9418
# Epoch 1982/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1713e-07 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9418
# Epoch 1983/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0669e-07 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9418
# Epoch 1984/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1890e-07 - accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9418
# Epoch 1985/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.2291e-07 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9405
# Epoch 1986/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1455e-07 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9405
# Epoch 1987/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.7871e-07 - accuracy: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9405
# Epoch 1988/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0315e-07 - accuracy: 1.0000 - val_loss: 0.2658 - val_accuracy: 0.9405
# Epoch 1989/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5329e-07 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9431
# Epoch 1990/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0272e-07 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9405
# Epoch 1991/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0866e-07 - accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9431
# Epoch 1992/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.3773e-07 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9431
# Epoch 1993/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.5598e-08 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9431
# Epoch 1994/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.0234e-07 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9431
# Epoch 1995/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 9.6022e-08 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9431
# Epoch 1996/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1089e-07 - accuracy: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9418
# Epoch 1997/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1197e-07 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9418
# Epoch 1998/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1231e-07 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9418
# Epoch 1999/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.4532e-07 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9405
# Epoch 2000/2000
# 49/49 [==============================] - 4s 72ms/step - loss: 1.1513e-07 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9405
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 319ms/step - loss: 1.4324 - accuracy: 0.7932
# test_indoor_ds_results:test loss, test acc: [1.432415246963501, 0.7931995391845703]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 429ms/step - loss: 2.5366 - accuracy: 0.6707
# test_outdoor_ds_results:test loss, test acc: [2.536611557006836, 0.6707006096839905]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 7s 149ms/step - loss: 2.4471 - accuracy: 0.7162
# test_belt_ds_results:test loss, test acc: [2.447113275527954, 0.7162284851074219]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/MobileNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 2s 57ms/step - loss: 0.9771 - accuracy: 0.7826
# 50/50 [==============================] - 3s 58ms/step - loss: 1.5617 - accuracy: 0.6755
# 35/35 [==============================] - 2s 58ms/step - loss: 1.6123 - accuracy: 0.7126
# Epoch200
#  test_indoor_acc=0.782608687877655
#  test_outdoor_acc=0.6754776835441589
#  test_belt_acc=0.7126020193099976
# 29/29 [==============================] - 2s 57ms/step - loss: 1.0878 - accuracy: 0.7865
# 50/50 [==============================] - 3s 58ms/step - loss: 1.8191 - accuracy: 0.6739
# 35/35 [==============================] - 2s 58ms/step - loss: 1.8254 - accuracy: 0.7135
# Epoch400
#  test_indoor_acc=0.7865105867385864
#  test_outdoor_acc=0.6738853454589844
#  test_belt_acc=0.7135086059570312
# 29/29 [==============================] - 3s 58ms/step - loss: 1.1776 - accuracy: 0.7910
# 50/50 [==============================] - 3s 59ms/step - loss: 2.0346 - accuracy: 0.6755
# 35/35 [==============================] - 2s 59ms/step - loss: 2.0049 - accuracy: 0.7140
# Epoch600
#  test_indoor_acc=0.7909699082374573
#  test_outdoor_acc=0.6754776835441589
#  test_belt_acc=0.7139618992805481
# 29/29 [==============================] - 2s 59ms/step - loss: 1.2454 - accuracy: 0.7943 0s - loss: 1.2657 - accuracy
# 50/50 [==============================] - 3s 60ms/step - loss: 2.1925 - accuracy: 0.6732 0s - l
# 35/35 [==============================] - 2s 60ms/step - loss: 2.1241 - accuracy: 0.7158
# Epoch800
#  test_indoor_acc=0.7943143844604492
#  test_outdoor_acc=0.6732484102249146
#  test_belt_acc=0.7157751321792603
# 29/29 [==============================] - 3s 58ms/step - loss: 1.3083 - accuracy: 0.7926
# 50/50 [==============================] - 3s 58ms/step - loss: 2.2979 - accuracy: 0.6736 2s
# 35/35 [==============================] - 2s 58ms/step - loss: 2.2284 - accuracy: 0.7158
# Epoch1000
#  test_indoor_acc=0.7926421165466309
#  test_outdoor_acc=0.6735668778419495
#  test_belt_acc=0.7157751321792603
# 29/29 [==============================] - 3s 58ms/step - loss: 1.3506 - accuracy: 0.7949
# 50/50 [==============================] - 3s 58ms/step - loss: 2.4182 - accuracy: 0.6704 0s - loss: 2.406
# 35/35 [==============================] - 2s 58ms/step - loss: 2.3168 - accuracy: 0.7140
# Epoch1200
#  test_indoor_acc=0.7948718070983887
#  test_outdoor_acc=0.6703821420669556
#  test_belt_acc=0.7139618992805481
# 29/29 [==============================] - 2s 58ms/step - loss: 1.3941 - accuracy: 0.7932
# 50/50 [==============================] - 3s 58ms/step - loss: 2.4426 - accuracy: 0.6723 1s
# 35/35 [==============================] - 2s 58ms/step - loss: 2.3520 - accuracy: 0.7158 0s -
# Epoch1400
#  test_indoor_acc=0.7931995391845703
#  test_outdoor_acc=0.6722930073738098
#  test_belt_acc=0.7157751321792603
# 29/29 [==============================] - 3s 59ms/step - loss: 1.3975 - accuracy: 0.7938
# 50/50 [==============================] - 3s 59ms/step - loss: 2.4544 - accuracy: 0.6732
# 35/35 [==============================] - 2s 59ms/step - loss: 2.3826 - accuracy: 0.7189
# Epoch1600
#  test_indoor_acc=0.7937569618225098
#  test_outdoor_acc=0.6732484102249146
#  test_belt_acc=0.7189483046531677
# 29/29 [==============================] - 3s 58ms/step - loss: 1.4196 - accuracy: 0.7960
# 50/50 [==============================] - 3s 58ms/step - loss: 2.5047 - accuracy: 0.6710
# 35/35 [==============================] - 2s 58ms/step - loss: 2.4224 - accuracy: 0.7167
# Epoch1800
#  test_indoor_acc=0.7959865927696228
#  test_outdoor_acc=0.6710191369056702
#  test_belt_acc=0.7166817784309387
# 29/29 [==============================] - 3s 57ms/step - loss: 1.4324 - accuracy: 0.7932
# 50/50 [==============================] - 3s 58ms/step - loss: 2.5366 - accuracy: 0.6707
# 35/35 [==============================] - 2s 58ms/step - loss: 2.4471 - accuracy: 0.7162 0s - loss: 2.4936 - accuracy:
# Epoch2000
#  test_indoor_acc=0.7931995391845703
#  test_outdoor_acc=0.6707006096839905
#  test_belt_acc=0.7162284851074219

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.728651225566864
# max index -> 7
# The [Epoch] of max acc -> 1600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.782608687877655,
#  0.7865105867385864,
#  0.7909699082374573,
#  0.7943143844604492,
#  0.7926421165466309,
#  0.7948718070983887,
#  0.7931995391845703,
#  0.7937569618225098,
#  0.7959865927696228,
#  0.7931995391845703]

# %%
test_outdoor_acc
# Out:
# [0.6754776835441589,
#  0.6738853454589844,
#  0.6754776835441589,
#  0.6732484102249146,
#  0.6735668778419495,
#  0.6703821420669556,
#  0.6722930073738098,
#  0.6732484102249146,
#  0.6710191369056702,
#  0.6707006096839905]

# %%
test_belt_acc
# Out:
# [0.7126020193099976,
#  0.7135086059570312,
#  0.7139618992805481,
#  0.7157751321792603,
#  0.7157751321792603,
#  0.7139618992805481,
#  0.7157751321792603,
#  0.7189483046531677,
#  0.7166817784309387,
#  0.7162284851074219]

# %%
test_indoor_loss
# Out:
# [0.9771112203598022,
#  1.0878344774246216,
#  1.1776195764541626,
#  1.2453542947769165,
#  1.3082962036132812,
#  1.3506416082382202,
#  1.3941128253936768,
#  1.3975216150283813,
#  1.4195597171783447,
#  1.432415246963501]

# %%
test_outdoor_loss
# Out:
# [1.5617135763168335,
#  1.8190559148788452,
#  2.034585475921631,
#  2.19246244430542,
#  2.2978768348693848,
#  2.418205499649048,
#  2.4425721168518066,
#  2.4543776512145996,
#  2.504664897918701,
#  2.536611557006836]

# %%
test_belt_loss
# Out:
# [1.6122746467590332,
#  1.8254114389419556,
#  2.004866361618042,
#  2.124070405960083,
#  2.228360176086426,
#  2.3167953491210938,
#  2.3520004749298096,
#  2.382622480392456,
#  2.422423839569092,
#  2.447113275527954]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5125
# FP=2015
# acc=0.7177871148459384
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 76.72413793103449%
# 2WayConnectorforFoley acc = 91.83673469387756%
# 2WayFoleyCatheter acc = 64.17910447761194%
# 3WayConnectorforFoley acc = 96.58119658119658%
# 3Waystopcock acc = 97.2972972972973%
# AlcoholBottle acc = 78.75%
# AlcoholPad acc = 44.44444444444444%
# BootCover acc = 49.39759036144578%
# CottonBall acc = 94.61077844311377%
# CottonSwap acc = 42.65734265734265%
# Dilator acc = 57.26495726495726%
# DisposableInfusionSet acc = 35.39823008849557%
# ExtensionTube acc = 30.89430894308943%
# FaceShield acc = 54.93827160493827%
# FrontLoadSyringe acc = 43.36283185840708%
# GauzePad acc = 51.70454545454546%
# Glove acc = 66.36904761904762%
# GuideWire acc = 38.392857142857146%
# LiquidBottle acc = 51.908396946564885%
# Mask acc = 92.72727272727272%
# NGTube acc = 39.35483870967742%
# NasalCannula acc = 64.60176991150442%
# Needle acc = 91.07142857142857%
# OxygenMask acc = 74.43609022556392%
# PPESuit acc = 96.7741935483871%
# PharmaceuticalProduct acc = 71.02803738317756%
# Pill acc = 97.05882352941177%
# PillBottle acc = 64.34108527131784%
# PrefilledHumidifier acc = 76.06837606837607%
# PressureConnectingTube acc = 66.41221374045801%
# ReusableHumidifier acc = 77.96610169491525%
# SodiumChlorideBag acc = 75.59055118110236%
# SterileHumidifierAdapter acc = 80.0%
# SurgicalBlade acc = 88.49557522123894%
# SurgicalCap acc = 87.38738738738738%
# SurgicalSuit acc = 30.303030303030305%
# Syringe acc = 91.63498098859316%
# TrachealTube acc = 42.201834862385326%
# UrineBag acc = 38.333333333333336%
# Vaccinebottle acc = 83.56807511737088%
# WingedInfusionSet acc = 78.94736842105263%
#
#
#
# all_avg_eachclass = 67.6832790733476%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 89,   3,   0, ...,   0,   0,   0],
#        [  0, 135,   0, ...,   0,   0,   0],
#        [  0,   0,  86, ...,   0,   0,  17],
#        ...,
#        [  0,   0,   0, ...,  46,   0,   3],
#        [  0,   0,   0, ...,   0, 178,   0],
#        [  1,   0,   0, ...,   0,   0,  90]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[76.72413793,  2.5862069 ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 91.83673469,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 64.17910448, ...,  0.        ,
#          0.        , 12.68656716],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 38.33333333,
#          0.        ,  2.5       ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         83.56807512,  0.        ],
#        [ 0.87719298,  0.        ,  0.        , ...,  0.        ,
#          0.        , 78.94736842]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
