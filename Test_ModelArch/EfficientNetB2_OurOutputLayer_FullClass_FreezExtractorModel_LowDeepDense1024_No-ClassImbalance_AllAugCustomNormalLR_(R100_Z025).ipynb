# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=260
img_width=260
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 260, 260, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB2

efficientnetB0_model = keras.applications.EfficientNetB2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2.h5
# 37437440/37432240 [==============================] - 14s 0us/step
# 37445632/37432240 [==============================] - 14s 0us/step

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 260, 260, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 260, 260, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 261, 261, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 130, 130, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 130, 130, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 130, 130, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 130, 130, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 130, 130, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 130, 130, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 130, 130, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 130, 130, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 130, 130, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 130, 130, 16) 144         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 130, 130, 16) 64          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 130, 130, 16) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 16)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 16)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 4)      68          block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 16)     80          block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 130, 130, 16) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 130, 130, 16) 256         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 130, 130, 16) 64          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 130, 130, 16) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 130, 130, 16) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 130, 130, 96) 1536        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 130, 130, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 130, 130, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 131, 131, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 65, 65, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 65, 65, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 65, 65, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 65, 65, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 65, 65, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 65, 65, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 65, 65, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 65, 65, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 65, 65, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 65, 65, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 65, 65, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 65, 65, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 65, 65, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 65, 65, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 65, 65, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 65, 65, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 65, 65, 144)  576         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 65, 65, 144)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 65, 65, 144)  1296        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 65, 65, 144)  576         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 65, 65, 144)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 144)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 65, 65, 144)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 65, 65, 24)   3456        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 65, 65, 24)   96          block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 65, 65, 24)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 65, 65, 24)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 65, 65, 144)  3456        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 65, 65, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 65, 65, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 69, 69, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 33, 33, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 33, 33, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 33, 33, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 33, 33, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 33, 33, 48)   6912        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 33, 33, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 33, 33, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 33, 33, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 33, 33, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 33, 33, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 33, 33, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 33, 33, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 33, 33, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 33, 33, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 33, 33, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 33, 33, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 33, 33, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 33, 33, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 33, 33, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 33, 33, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 33, 33, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 33, 33, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 33, 33, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 33, 33, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 33, 33, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 33, 33, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 33, 33, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 35, 35, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 17, 17, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 17, 17, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 17, 17, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 17, 17, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 17, 17, 88)   25344       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 17, 17, 88)   352         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 17, 17, 528)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 17, 17, 528)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 528)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 17, 17, 528)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 17, 17, 88)   352         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 17, 17, 88)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 17, 17, 88)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 17, 17, 528)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 17, 17, 528)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 528)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 17, 17, 528)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 17, 17, 88)   352         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 17, 17, 88)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 17, 17, 88)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 17, 17, 528)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 17, 17, 528)  4752        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 17, 17, 528)  2112        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 17, 17, 528)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 528)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 17, 17, 528)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 17, 17, 88)   46464       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 17, 17, 88)   352         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 17, 17, 88)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 17, 17, 88)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 17, 17, 528)  46464       block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 17, 17, 528)  2112        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 17, 17, 528)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 17, 17, 528)  13200       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 17, 17, 528)  2112        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 17, 17, 528)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 528)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 528)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 17, 17, 528)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 17, 17, 120)  63360       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 17, 17, 120)  480         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 17, 17, 720)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 17, 17, 720)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 720)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 17, 17, 720)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 17, 17, 120)  86400       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 17, 17, 120)  480         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 17, 17, 120)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 17, 17, 120)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 17, 17, 720)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 17, 17, 720)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 720)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 17, 17, 720)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 17, 17, 120)  86400       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 17, 17, 120)  480         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 17, 17, 120)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 17, 17, 120)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_conv (Conv2D)    (None, 17, 17, 720)  86400       block5c_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_bn (BatchNormali (None, 17, 17, 720)  2880        block5d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5d_expand_activation (Acti (None, 17, 17, 720)  0           block5d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5d_dwconv (DepthwiseConv2D (None, 17, 17, 720)  18000       block5d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5d_bn (BatchNormalization) (None, 17, 17, 720)  2880        block5d_dwconv[0][0]
# __________________________________________________________________________________________________
# block5d_activation (Activation) (None, 17, 17, 720)  0           block5d_bn[0][0]
# __________________________________________________________________________________________________
# block5d_se_squeeze (GlobalAvera (None, 720)          0           block5d_activation[0][0]
# __________________________________________________________________________________________________
# block5d_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5d_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5d_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6c_expand_activation (Acti (None, 9, 9, 1248)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 9, 9, 1248)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1248)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 9, 9, 208)    832         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 9, 9, 208)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 9, 9, 208)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 9, 9, 1248)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 9, 9, 1248)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1248)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 9, 9, 208)    832         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 9, 9, 208)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 9, 9, 208)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 9, 9, 1248)   0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   31200       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 9, 9, 1248)   0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1248)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 9, 9, 1248)   0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 9, 9, 208)    259584      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 9, 9, 208)    832         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 9, 9, 208)    0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 9, 9, 208)    0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 9, 9, 1248)   259584      block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 9, 9, 1248)   4992        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 9, 9, 1248)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 9, 9, 1248)   11232       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 9, 9, 1248)   4992        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 9, 9, 1248)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1248)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 9, 9, 1248)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 9, 9, 352)    439296      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 9, 9, 352)    1408        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 9, 9, 2112)   743424      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 9, 9, 2112)   8448        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 9, 9, 2112)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 9, 9, 2112)   19008       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 9, 9, 2112)   8448        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 9, 9, 2112)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2112)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2112)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 88)     185944      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2112)   187968      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 9, 9, 2112)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 9, 9, 352)    743424      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 9, 9, 352)    1408        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 9, 9, 352)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 9, 9, 352)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 9, 9, 1408)   495616      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 9, 9, 1408)   5632        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 9, 9, 1408)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1408)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 7,768,569
# Trainable params: 0
# Non-trainable params: 7,768,569
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1408)              7768569
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1442816
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 9,253,410
# Trainable params: 1,484,841
# Non-trainable params: 7,768,569
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 47s 364ms/step - loss: 1.0827 - accuracy: 0.7257 - val_loss: 0.2626 - val_accuracy: 0.9353
# Epoch 2/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.1978 - accuracy: 0.9435 - val_loss: 0.1607 - val_accuracy: 0.9534
# Epoch 3/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0963 - accuracy: 0.9780 - val_loss: 0.1635 - val_accuracy: 0.9470
# Epoch 4/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0643 - accuracy: 0.9874 - val_loss: 0.1401 - val_accuracy: 0.9521
# Epoch 5/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0447 - accuracy: 0.9900 - val_loss: 0.1366 - val_accuracy: 0.9560
# Epoch 6/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0380 - accuracy: 0.9910 - val_loss: 0.1102 - val_accuracy: 0.9690
# Epoch 7/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0229 - accuracy: 0.9977 - val_loss: 0.0898 - val_accuracy: 0.9715
# Epoch 8/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0169 - accuracy: 0.9974 - val_loss: 0.0876 - val_accuracy: 0.9715
# Epoch 9/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0181 - accuracy: 0.9964 - val_loss: 0.0773 - val_accuracy: 0.9767
# Epoch 10/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0149 - accuracy: 0.9977 - val_loss: 0.0842 - val_accuracy: 0.9754
# Epoch 11/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0136 - accuracy: 0.9971 - val_loss: 0.0806 - val_accuracy: 0.9741
# Epoch 12/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0124 - accuracy: 0.9974 - val_loss: 0.0950 - val_accuracy: 0.9741
# Epoch 13/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0162 - accuracy: 0.9968 - val_loss: 0.0764 - val_accuracy: 0.9780
# Epoch 14/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 0.0812 - val_accuracy: 0.9754
# Epoch 15/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.1048 - val_accuracy: 0.9715
# Epoch 16/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.0851 - val_accuracy: 0.9780
# Epoch 17/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.0853 - val_accuracy: 0.9767
# Epoch 18/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.0836 - val_accuracy: 0.9728
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0816 - val_accuracy: 0.9754
# Epoch 20/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0819 - val_accuracy: 0.9754
# Epoch 21/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0742 - val_accuracy: 0.9806
# Epoch 22/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9793
# Epoch 23/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0768 - val_accuracy: 0.9806
# Epoch 24/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.0789 - val_accuracy: 0.9780
# Epoch 25/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0696 - val_accuracy: 0.9793
# Epoch 26/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9780
# Epoch 27/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0743 - val_accuracy: 0.9767
# Epoch 28/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9780
# Epoch 29/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0723 - val_accuracy: 0.9780
# Epoch 30/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9793
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 31/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0704 - val_accuracy: 0.9793
# Epoch 32/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9793
# Epoch 33/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0718 - val_accuracy: 0.9793
# Epoch 34/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9780
# Epoch 35/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0713 - val_accuracy: 0.9793
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 36/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0713 - val_accuracy: 0.9793
# Epoch 37/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0712 - val_accuracy: 0.9793
# Epoch 38/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0715 - val_accuracy: 0.9793
# Epoch 39/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9793
# Epoch 40/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0715 - val_accuracy: 0.9793
# Epoch 41/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9806
# Epoch 42/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0715 - val_accuracy: 0.9806
# Epoch 43/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0714 - val_accuracy: 0.9806
# Epoch 44/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9793
# Epoch 45/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0711 - val_accuracy: 0.9793
# Epoch 46/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0709 - val_accuracy: 0.9793
# Epoch 47/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0703 - val_accuracy: 0.9793
# Epoch 48/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0703 - val_accuracy: 0.9793
# Epoch 49/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0701 - val_accuracy: 0.9793
# Epoch 50/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0697 - val_accuracy: 0.9793
# Epoch 51/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9793
# Epoch 52/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9819
# Epoch 53/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0698 - val_accuracy: 0.9819
# Epoch 54/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0697 - val_accuracy: 0.9819
# Epoch 55/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0704 - val_accuracy: 0.9819
# Epoch 56/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9819
# Epoch 57/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0704 - val_accuracy: 0.9819
# Epoch 58/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0709 - val_accuracy: 0.9819
# Epoch 59/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9819
# Epoch 60/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0709 - val_accuracy: 0.9819
# Epoch 61/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9819
# Epoch 62/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9806
# Epoch 63/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0702 - val_accuracy: 0.9806
# Epoch 64/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9793
# Epoch 65/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0688 - val_accuracy: 0.9806
# Epoch 66/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9806
# Epoch 67/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9780
# Epoch 68/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0694 - val_accuracy: 0.9780
# Epoch 69/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0695 - val_accuracy: 0.9793
# Epoch 70/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0690 - val_accuracy: 0.9793
# Epoch 71/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9793
# Epoch 72/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0691 - val_accuracy: 0.9793
# Epoch 73/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0700 - val_accuracy: 0.9793
# Epoch 74/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9780
# Epoch 75/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9793
# Epoch 76/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9806
# Epoch 77/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0710 - val_accuracy: 0.9806
# Epoch 78/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9806
# Epoch 79/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0714 - val_accuracy: 0.9819
# Epoch 80/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9793
# Epoch 81/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9793
# Epoch 82/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.0701 - val_accuracy: 0.9806
# Epoch 83/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0690 - val_accuracy: 0.9819
# Epoch 84/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0674 - val_accuracy: 0.9819
# Epoch 85/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9819
# Epoch 86/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 87/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 88/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 89/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 0.9793
# Epoch 90/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0690 - val_accuracy: 0.9793
# Epoch 91/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9793
# Epoch 92/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0695 - val_accuracy: 0.9793
# Epoch 93/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0696 - val_accuracy: 0.9806
# Epoch 94/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9806
# Epoch 95/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0690 - val_accuracy: 0.9806
# Epoch 96/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0689 - val_accuracy: 0.9819
# Epoch 97/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0688 - val_accuracy: 0.9819
# Epoch 98/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 99/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9806
# Epoch 100/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0685 - val_accuracy: 0.9806
# Epoch 101/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0685 - val_accuracy: 0.9806
# Epoch 102/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 0.9806
# Epoch 103/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9806
# Epoch 104/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9806
# Epoch 105/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0689 - val_accuracy: 0.9806
# Epoch 106/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0697 - val_accuracy: 0.9806
# Epoch 107/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0692 - val_accuracy: 0.9819
# Epoch 108/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0699 - val_accuracy: 0.9819
# Epoch 109/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9819
# Epoch 110/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9819
# Epoch 111/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0697 - val_accuracy: 0.9819
# Epoch 112/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9819
# Epoch 113/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0683 - val_accuracy: 0.9806
# Epoch 114/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0685 - val_accuracy: 0.9806
# Epoch 115/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0694 - val_accuracy: 0.9806
# Epoch 116/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9819
# Epoch 117/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9819
# Epoch 118/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9819
# Epoch 119/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9819
# Epoch 120/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 121/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9819
# Epoch 122/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 123/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0685 - val_accuracy: 0.9806
# Epoch 124/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9819
# Epoch 125/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9806
# Epoch 126/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0669 - val_accuracy: 0.9806
# Epoch 127/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9793
# Epoch 128/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0676 - val_accuracy: 0.9806
# Epoch 129/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9806
# Epoch 130/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9806
# Epoch 131/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.4272e-04 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9806
# Epoch 132/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9806
# Epoch 133/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9806
# Epoch 134/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9793
# Epoch 135/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9806
# Epoch 136/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 0.9819
# Epoch 137/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0679 - val_accuracy: 0.9819
# Epoch 138/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 139/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 140/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 141/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0664 - val_accuracy: 0.9806
# Epoch 142/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9806
# Epoch 143/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0672 - val_accuracy: 0.9819
# Epoch 144/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0674 - val_accuracy: 0.9819
# Epoch 145/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9819
# Epoch 146/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.0672 - val_accuracy: 0.9819
# Epoch 147/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9806
# Epoch 148/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0669 - val_accuracy: 0.9806
# Epoch 149/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9806
# Epoch 150/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9806
# Epoch 151/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0700 - val_accuracy: 0.9806
# Epoch 152/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0698 - val_accuracy: 0.9806
# Epoch 153/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.6425e-04 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9806
# Epoch 154/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0692 - val_accuracy: 0.9806
# Epoch 155/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0674 - val_accuracy: 0.9806
# Epoch 156/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9832
# Epoch 157/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9819
# Epoch 158/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 159/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 160/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9819
# Epoch 161/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0690 - val_accuracy: 0.9806
# Epoch 162/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.9051e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9819
# Epoch 163/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0704 - val_accuracy: 0.9806
# Epoch 164/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9806
# Epoch 165/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0698 - val_accuracy: 0.9819
# Epoch 166/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9819
# Epoch 167/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9819
# Epoch 168/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.2515e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9806
# Epoch 169/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 170/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9819
# Epoch 171/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.4722e-04 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9819
# Epoch 172/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9819
# Epoch 173/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9819
# Epoch 174/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9806
# Epoch 175/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0681 - val_accuracy: 0.9806
# Epoch 176/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.5793e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9819
# Epoch 177/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 178/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9819
# Epoch 179/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0683 - val_accuracy: 0.9819
# Epoch 180/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0684 - val_accuracy: 0.9819
# Epoch 181/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0677 - val_accuracy: 0.9819
# Epoch 182/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0674 - val_accuracy: 0.9832
# Epoch 183/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0670 - val_accuracy: 0.9832
# Epoch 184/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.8829e-04 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9832
# Epoch 185/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9819
# Epoch 186/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9832
# Epoch 187/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0673 - val_accuracy: 0.9832
# Epoch 188/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.8213e-04 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9832
# Epoch 189/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9832
# Epoch 190/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0697 - val_accuracy: 0.9819
# Epoch 191/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9819
# Epoch 192/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9806
# Epoch 193/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0683 - val_accuracy: 0.9806
# Epoch 194/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0686 - val_accuracy: 0.9832
# Epoch 195/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.5377e-04 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9819
# Epoch 196/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.3923e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9832
# Epoch 197/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0678 - val_accuracy: 0.9819
# Epoch 198/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0683 - val_accuracy: 0.9819
# Epoch 199/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0669 - val_accuracy: 0.9819
# Epoch 200/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9819
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0665 - val_accuracy: 0.9819
# Epoch 202/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0664 - val_accuracy: 0.9819
# Epoch 203/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9819
# Epoch 204/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0659 - val_accuracy: 0.9819
# Epoch 205/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.5640e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9819
# Epoch 206/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.5398e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9819
# Epoch 207/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9832
# Epoch 208/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0675 - val_accuracy: 0.9819
# Epoch 209/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9806
# Epoch 210/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0671 - val_accuracy: 0.9819
# Epoch 211/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9819
# Epoch 212/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9832
# Epoch 213/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.4360e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9832
# Epoch 214/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.7173e-04 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9832
# Epoch 215/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0675 - val_accuracy: 0.9819
# Epoch 216/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.8048e-04 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9832
# Epoch 217/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.4989e-04 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9832
# Epoch 218/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0673 - val_accuracy: 0.9832
# Epoch 219/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.6984e-04 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9832
# Epoch 220/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9832
# Epoch 221/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.5257e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9832
# Epoch 222/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.2215e-04 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9832
# Epoch 223/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0663 - val_accuracy: 0.9832
# Epoch 224/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0663 - val_accuracy: 0.9832
# Epoch 225/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.3899e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9819
# Epoch 226/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0666 - val_accuracy: 0.9832
# Epoch 227/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0663 - val_accuracy: 0.9832
# Epoch 228/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0660 - val_accuracy: 0.9819
# Epoch 229/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9819
# Epoch 230/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.3184e-04 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9819
# Epoch 231/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0669 - val_accuracy: 0.9819
# Epoch 232/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0665 - val_accuracy: 0.9832
# Epoch 233/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.1715e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9832
# Epoch 234/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0655 - val_accuracy: 0.9819
# Epoch 235/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0654 - val_accuracy: 0.9832
# Epoch 236/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.5551e-04 - accuracy: 1.0000 - val_loss: 0.0656 - val_accuracy: 0.9832
# Epoch 237/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.3777e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9832
# Epoch 238/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9832
# Epoch 239/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0660 - val_accuracy: 0.9832
# Epoch 240/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0661 - val_accuracy: 0.9832
# Epoch 241/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.5534e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9832
# Epoch 242/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0661 - val_accuracy: 0.9819
# Epoch 243/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0653 - val_accuracy: 0.9832
# Epoch 244/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0654 - val_accuracy: 0.9819
# Epoch 245/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0659 - val_accuracy: 0.9819
# Epoch 246/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0669 - val_accuracy: 0.9819
# Epoch 247/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 0.0662 - val_accuracy: 0.9819
# Epoch 248/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9819
# Epoch 249/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.2403e-04 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9819
# Epoch 250/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0662 - val_accuracy: 0.9832
# Epoch 251/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9819
# Epoch 252/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.9568e-04 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 0.9819
# Epoch 253/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0684 - val_accuracy: 0.9806
# Epoch 254/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9806
# Epoch 255/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0677 - val_accuracy: 0.9819
# Epoch 256/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0675 - val_accuracy: 0.9806
# Epoch 257/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9819
# Epoch 258/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9819
# Epoch 259/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0717 - val_accuracy: 0.9806
# Epoch 260/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0720 - val_accuracy: 0.9819
# Epoch 261/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9819
# Epoch 262/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9832
# Epoch 263/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.9203e-04 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9832
# Epoch 264/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.3549e-04 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9832
# Epoch 265/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0683 - val_accuracy: 0.9845
# Epoch 266/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.4048e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9832
# Epoch 267/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.2735e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9832
# Epoch 268/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.3872e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9832
# Epoch 269/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0688 - val_accuracy: 0.9845
# Epoch 270/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.4259e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9845
# Epoch 271/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.6510e-04 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9845
# Epoch 272/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0682 - val_accuracy: 0.9832
# Epoch 273/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0706 - val_accuracy: 0.9806
# Epoch 274/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.7526e-04 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9806
# Epoch 275/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.1868e-04 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9806
# Epoch 276/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0705 - val_accuracy: 0.9806
# Epoch 277/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 6.5803e-04 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9806
# Epoch 278/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.4474e-04 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9806
# Epoch 279/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9819
# Epoch 280/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.3543e-04 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9832
# Epoch 281/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9819
# Epoch 282/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 5.9994e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9819
# Epoch 283/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9832
# Epoch 284/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0689 - val_accuracy: 0.9819
# Epoch 285/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.1776e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9819
# Epoch 286/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0718 - val_accuracy: 0.9806
# Epoch 287/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0712 - val_accuracy: 0.9832
# Epoch 288/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.9906e-04 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9832
# Epoch 289/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.3493e-04 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9832
# Epoch 290/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.4479e-04 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9832
# Epoch 291/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.0063e-04 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 0.9832
# Epoch 292/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 6.9533e-04 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 0.9819
# Epoch 293/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0695 - val_accuracy: 0.9832
# Epoch 294/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 6.7676e-04 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 0.9832
# Epoch 295/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.3752e-04 - accuracy: 1.0000 - val_loss: 0.0692 - val_accuracy: 0.9832
# Epoch 296/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0697 - val_accuracy: 0.9832
# Epoch 297/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9832
# Epoch 298/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.1664e-04 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9832
# Epoch 299/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0675 - val_accuracy: 0.9832
# Epoch 300/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0666 - val_accuracy: 0.9819
# Epoch 301/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.8162e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9819
# Epoch 302/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0653 - val_accuracy: 0.9832
# Epoch 303/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0660 - val_accuracy: 0.9832
# Epoch 304/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.0963e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9832
# Epoch 305/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.0434e-04 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9819
# Epoch 306/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.3442e-04 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9819
# Epoch 307/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9819
# Epoch 308/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0673 - val_accuracy: 0.9819
# Epoch 309/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.7876e-04 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9806
# Epoch 310/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 8.1205e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9806
# Epoch 311/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.9645e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9806
# Epoch 312/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0687 - val_accuracy: 0.9819
# Epoch 313/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 9.7080e-04 - accuracy: 0.9997 - val_loss: 0.0691 - val_accuracy: 0.9819
# Epoch 314/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.2822e-04 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9806
# Epoch 315/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0680 - val_accuracy: 0.9806
# Epoch 316/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9806
# Epoch 317/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0682 - val_accuracy: 0.9819
# Epoch 318/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.8353e-04 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9832
# Epoch 319/2000
# 49/49 [==============================] - 11s 216ms/step - loss: 7.9435e-04 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9832
# Epoch 320/2000
# ...
# Epoch 1900/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 9.4937e-05 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9845
# Epoch 1901/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 1.9665e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9845
# Epoch 1902/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 9.3922e-05 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9845
# Epoch 1903/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 9.7204e-05 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9845
# Epoch 1904/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 3.4889e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9845
# Epoch 1905/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 1.1201e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9845
# Epoch 1906/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 8.9085e-05 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9845
# Epoch 1907/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 9.9963e-05 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9845
# Epoch 1908/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 1.8229e-04 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9845
# Epoch 1909/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 1.7590e-04 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9845
# Epoch 1910/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 1.2469e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9845
# Epoch 1911/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 1.8841e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9845
# Epoch 1912/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 7.9584e-05 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9845
# Epoch 1913/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 1.1226e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9845
# Epoch 1914/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.8451e-05 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9845
# Epoch 1915/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 2.0635e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9845
# Epoch 1916/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0293e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9845
# Epoch 1917/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.2043e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9845
# Epoch 1918/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 5.1723e-05 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9845
# Epoch 1919/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.7179e-05 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9845
# Epoch 1920/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0671e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9845
# Epoch 1921/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.6487e-05 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9845
# Epoch 1922/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.1519e-05 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9845
# Epoch 1923/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.9523e-05 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9845
# Epoch 1924/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.5373e-05 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9845
# Epoch 1925/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.3889e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9845
# Epoch 1926/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.6811e-05 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9845
# Epoch 1927/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 3.0387e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9845
# Epoch 1928/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.4638e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9845
# Epoch 1929/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.2296e-04 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9832
# Epoch 1930/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0367e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9819
# Epoch 1931/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 1.0231e-04 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9819
# Epoch 1932/2000
# 49/49 [==============================] - 11s 218ms/step - loss: 7.0342e-05 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9832
# Epoch 1933/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.6618e-05 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9832
# Epoch 1934/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.1660e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9845
# Epoch 1935/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.2311e-05 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9845
# Epoch 1936/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 3.8340e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9845
# Epoch 1937/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 2.4697e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9845
# Epoch 1938/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.1463e-05 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9832
# Epoch 1939/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.2768e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9832
# Epoch 1940/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 2.2606e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9832
# Epoch 1941/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0067e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9832
# Epoch 1942/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.2378e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9832
# Epoch 1943/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 4.5076e-04 - accuracy: 0.9997 - val_loss: 0.0734 - val_accuracy: 0.9832
# Epoch 1944/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.3947e-05 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9845
# Epoch 1945/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.9623e-05 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9845
# Epoch 1946/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0730 - val_accuracy: 0.9845
# Epoch 1947/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.1282e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9845
# Epoch 1948/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.0487e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9845
# Epoch 1949/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.0332e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9845
# Epoch 1950/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 3.4234e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9845
# Epoch 1951/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.1965e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9845
# Epoch 1952/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.4195e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9832
# Epoch 1953/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.4946e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9832
# Epoch 1954/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.5016e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9832
# Epoch 1955/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.9995e-05 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9832
# Epoch 1956/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.1431e-04 - accuracy: 0.9997 - val_loss: 0.0733 - val_accuracy: 0.9832
# Epoch 1957/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0732 - val_accuracy: 0.9832
# Epoch 1958/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.6481e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9832
# Epoch 1959/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.3888e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9832
# Epoch 1960/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.7914e-05 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9832
# Epoch 1961/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0565e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9819
# Epoch 1962/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.6107e-05 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9819
# Epoch 1963/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0906e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9819
# Epoch 1964/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 3.2698e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9832
# Epoch 1965/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.4400e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9845
# Epoch 1966/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 2.1354e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9832
# Epoch 1967/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.7627e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9832
# Epoch 1968/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.4432e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9832
# Epoch 1969/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0480e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9832
# Epoch 1970/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.6558e-04 - accuracy: 0.9997 - val_loss: 0.0752 - val_accuracy: 0.9832
# Epoch 1971/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.0037e-05 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9832
# Epoch 1972/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.7778e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9832
# Epoch 1973/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.7336e-05 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9832
# Epoch 1974/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.7725e-05 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9832
# Epoch 1975/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0476e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9832
# Epoch 1976/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.5923e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9832
# Epoch 1977/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.8192e-05 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9832
# Epoch 1978/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.7650e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9832
# Epoch 1979/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 8.9389e-05 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9832
# Epoch 1980/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.1211e-05 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9832
# Epoch 1981/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.4910e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9832
# Epoch 1982/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.4919e-05 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9832
# Epoch 1983/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.4759e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9832
# Epoch 1984/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.4554e-05 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9845
# Epoch 1985/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 7.2168e-05 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9832
# Epoch 1986/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 2.0972e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9832
# Epoch 1987/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 3.3089e-04 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9832
# Epoch 1988/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 5.8364e-04 - accuracy: 0.9997 - val_loss: 0.0729 - val_accuracy: 0.9832
# Epoch 1989/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0632e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9845
# Epoch 1990/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.1278e-05 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9845
# Epoch 1991/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.7351e-05 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9845
# Epoch 1992/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.3292e-04 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9832
# Epoch 1993/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.1323e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9832
# Epoch 1994/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.9495e-04 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 0.9832
# Epoch 1995/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0826e-04 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9832
# Epoch 1996/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.8577e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9832
# Epoch 1997/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.3275e-05 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9832
# Epoch 1998/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 9.2708e-05 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9845
# Epoch 1999/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 1.0753e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9845
# Epoch 2000/2000
# 49/49 [==============================] - 11s 217ms/step - loss: 6.2727e-05 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9845
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 14s 341ms/step - loss: 0.4590 - accuracy: 0.8835
# test_indoor_ds_results:test loss, test acc: [0.4590100646018982, 0.8835005760192871]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 26s 431ms/step - loss: 0.9618 - accuracy: 0.7990
# test_outdoor_ds_results:test loss, test acc: [0.9618289470672607, 0.7990446090698242]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 202ms/step - loss: 1.3069 - accuracy: 0.7638
# test_belt_ds_results:test loss, test acc: [1.3069087266921997, 0.7638259530067444]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_99161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_112661) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_114286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_66544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_101691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_109128) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_110280) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_68893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_67175) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_66294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_109673) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_104347) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_68313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_116107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_116838) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_110109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_67124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_113912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_69418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_64966) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_113097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_68221) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_66335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_112116) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_103940) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_104721) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_65880) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_69550) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_116667) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_66063) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_68761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_67333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_115126) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_65175) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_106143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_64525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_64908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_65007) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_66012) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_110342) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_116278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_66676) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_108568) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_66236) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_64735) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_68537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_104914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_67557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_104976) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_68669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_109066) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_117274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_68063) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_65671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_54274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_111447) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_65630) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_113850) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_111509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_69209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_111883) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_65124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_66951) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_67425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_65788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_67832) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_67649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_107877) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_110949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_66452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_109502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_68944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_69168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_115064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_108506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_106081) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_65572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_113290) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_69117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_106517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_67608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_104285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_112054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_107706) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_65348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_110716) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_113679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_64576) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_65440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_114519) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_95089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_116900) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_107270) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_69377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_106710) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_66768) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_107939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_67873) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_68272) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_105536) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_113352) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_107099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_65216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_68985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_108895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_68104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_68720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_103707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_106772) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_66104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_66503) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_64776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_114457) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_69326) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_64617) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_66900) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_67216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_115733) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_103878) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_67781) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_110887) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_68496) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_105303) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_108313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_105474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_105910) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_65399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_115671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_66992) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_68445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_107332) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_68005) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_114893) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_66727) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_112723) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_92537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_67384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_116340) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_112490) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_115500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_111276) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_65839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_109735) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 7s 171ms/step - loss: 0.4215 - accuracy: 0.8829
# 50/50 [==============================] - 9s 172ms/step - loss: 0.8605 - accuracy: 0.7943
# 35/35 [==============================] - 6s 173ms/step - loss: 1.1196 - accuracy: 0.7597
# Epoch200
#  test_indoor_acc=0.8829431533813477
#  test_outdoor_acc=0.7942675352096558
#  test_belt_acc=0.7597461342811584
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_211664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_166788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_207462) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_212853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_152841) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_164803) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_215841) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_202852) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_209454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_213024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_164007) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_200258) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_207633) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_208909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_164861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_210683) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_210450) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_165070) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_202914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_193656) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_167684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_203481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_208069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_212417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_166572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_213086) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_206506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_163783) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_213460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_191104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_210076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_165691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_208302) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_202274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_163742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_165243) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_208676) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_163343) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_203543) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_208847) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_208240) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_164630) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_205277) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_164139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_213693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_167063) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_211857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_214845) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_206273) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_163691) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_164671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_167328) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_164579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_167012) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_166348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_164902) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_165742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_203870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_167287) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_165518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_165992) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_197728) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_166440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_163302) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_207695) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_166175) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_211057) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_205837) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_166839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_204477) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_202445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_163184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_165559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_167104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_168117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_207073) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_214300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_167985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_167776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_167735) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_163475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_166399) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_215405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_206444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_205339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_167460) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_211919) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_210621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_205084) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_163966) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_202507) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_211290) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_163533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_207135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_951884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_952366) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_956252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_995865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_953422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_953811) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_997468) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_998246) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_952575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_956476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_952758) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_992335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_953694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_991644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_955580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_955191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_953862) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_952707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1004197) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_953371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_996425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1001038) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_953198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_999849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_996487) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_999413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_952799) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_953463) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_986520) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_996254) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_952135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_999475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_954259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1002485) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_956120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_953239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_999242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_991237) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_956303) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1001209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_951976) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1001878) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_953653) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_989050) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_993269) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_954784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_955008) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1002859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_997701) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_955364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_995298) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_993502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_953030) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_956344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_952931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_954310) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_954692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_956527) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_956909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1004259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_956568) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_954967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1000711) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_952325) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_998308) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1003699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_952094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_994458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_992895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_954127) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_955631) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1000649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_995672) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_954575) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_998806) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_997032) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1002423) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 7s 171ms/step - loss: 0.4590 - accuracy: 0.8835
# 50/50 [==============================] - 9s 173ms/step - loss: 0.9618 - accuracy: 0.7990
# 35/35 [==============================] - 6s 174ms/step - loss: 1.3069 - accuracy: 0.7638
# Epoch2000
#  test_indoor_acc=0.8835005760192871
#  test_outdoor_acc=0.7990446090698242
#  test_belt_acc=0.7638259530067444

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8186155954996744
# max index -> 7
# The [Epoch] of max acc -> 1600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8829431533813477,
#  0.8851727843284607,
#  0.886845052242279,
#  0.8907469511032104,
#  0.8829431533813477,
#  0.886845052242279,
#  0.8862876296043396,
#  0.8907469511032104,
#  0.886845052242279,
#  0.8835005760192871]

# %%
test_outdoor_acc
# Out:
# [0.7942675352096558,
#  0.7920382022857666,
#  0.7974522113800049,
#  0.7933120727539062,
#  0.7945860028266907,
#  0.7993630766868591,
#  0.800000011920929,
#  0.8012738823890686,
#  0.79713374376297,
#  0.7990446090698242]

# %%
test_belt_acc
# Out:
# [0.7597461342811584,
#  0.7579329013824463,
#  0.7579329013824463,
#  0.7611060738563538,
#  0.7624660134315491,
#  0.7629193067550659,
#  0.7615593671798706,
#  0.7638259530067444,
#  0.7651858329772949,
#  0.7638259530067444]

# %%
test_indoor_loss
# Out:
# [0.4214951694011688,
#  0.42369726300239563,
#  0.4198642075061798,
#  0.42020004987716675,
#  0.44414228200912476,
#  0.4397401809692383,
#  0.4352348744869232,
#  0.4360485076904297,
#  0.44839948415756226,
#  0.4590100646018982]

# %%
test_outdoor_loss
# Out:
# [0.8604943156242371,
#  0.8957095742225647,
#  0.8795545697212219,
#  0.9206241369247437,
#  0.9347051978111267,
#  0.9391591548919678,
#  0.9357759356498718,
#  0.9484843015670776,
#  0.9700547456741333,
#  0.9618289470672607]

# %%
test_belt_loss
# Out:
# [1.1196303367614746,
#  1.171368956565857,
#  1.1908763647079468,
#  1.1826605796813965,
#  1.2220884561538696,
#  1.219740629196167,
#  1.2455042600631714,
#  1.2584959268569946,
#  1.262234091758728,
#  1.3069087266921997]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=260
img_width=260
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_804680) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_759579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_807061) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_794039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_759538) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_757377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_757061) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_759105) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_758881) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_759711) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_805661) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_803451) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_756455) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_757494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_756929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_756224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_798729) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_782698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_758224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_756664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_758606) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_757810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_806439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_758034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_755733) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_805054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_804618) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_799663) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_804011) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_802884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_796933) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_757336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_759487) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_791852) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_806268) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_755127) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_801110) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_785250) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_756613) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_758166) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_805225) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_756000) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_756041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_757942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_799227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_755509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_758657) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_800877) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_797260) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_789322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_757545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_806501) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_755949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_797431) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_802822) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_755377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_759054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_800441) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_801670) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_807435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_802044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_794446) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_796678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_758265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_754778) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_798474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_805287) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_758433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_805832) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_756173) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_799289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_757112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_754686) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_793868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_801608) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_754737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_759146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_754937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_744435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_796242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_805894) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_798100) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_799834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_756397) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_755285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_755168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_754896) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_806828) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_757769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_796871) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_757993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_799056) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_755832) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_755069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_802651) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_758474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_796304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_794882) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_795137) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_806999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_759329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_798667) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_795697) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_755601) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_794508) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_759370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_757586) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_801048) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_755560) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_794101) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_758922) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_799896) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_795464) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_758382) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_756705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_757153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_803840) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_804447) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_755791) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_803513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_795075) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_756265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_756837) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_757718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_798038) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_756888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_795635) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_757285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_755336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_804073) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_797867) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_802215) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_801437) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_759278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_758830) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_803258) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_758698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_800270) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_797493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_802277) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_756496) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_800503) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_796071) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5798
# FP=1342
# acc=0.8120448179271709
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 81.03448275862068%
# 2WayConnectorforFoley acc = 97.95918367346938%
# 2WayFoleyCatheter acc = 88.05970149253731%
# 3WayConnectorforFoley acc = 98.29059829059828%
# 3Waystopcock acc = 98.1981981981982%
# AlcoholBottle acc = 86.875%
# AlcoholPad acc = 48.41269841269841%
# BootCover acc = 65.66265060240963%
# CottonBall acc = 92.21556886227546%
# CottonSwap acc = 74.82517482517483%
# Dilator acc = 84.61538461538461%
# DisposableInfusionSet acc = 91.1504424778761%
# ExtensionTube acc = 50.40650406504065%
# FaceShield acc = 73.4567901234568%
# FrontLoadSyringe acc = 63.716814159292035%
# GauzePad acc = 48.86363636363637%
# Glove acc = 71.72619047619048%
# GuideWire acc = 53.57142857142857%
# LiquidBottle acc = 62.213740458015266%
# Mask acc = 98.96103896103897%
# NGTube acc = 43.87096774193549%
# NasalCannula acc = 62.83185840707964%
# Needle acc = 93.57142857142857%
# OxygenMask acc = 94.73684210526315%
# PPESuit acc = 93.54838709677419%
# PharmaceuticalProduct acc = 81.07476635514018%
# Pill acc = 96.77871148459384%
# PillBottle acc = 81.3953488372093%
# PrefilledHumidifier acc = 82.05128205128204%
# PressureConnectingTube acc = 72.51908396946564%
# ReusableHumidifier acc = 86.4406779661017%
# SodiumChlorideBag acc = 95.2755905511811%
# SterileHumidifierAdapter acc = 80.9090909090909%
# SurgicalBlade acc = 89.38053097345133%
# SurgicalCap acc = 91.8918918918919%
# SurgicalSuit acc = 40.15151515151515%
# Syringe acc = 98.47908745247148%
# TrachealTube acc = 56.88073394495413%
# UrineBag acc = 90.0%
# Vaccinebottle acc = 88.73239436619718%
# WingedInfusionSet acc = 86.8421052631579%
#
#
#
# all_avg_eachclass = 78.96530542628115%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 94,   0,   0, ...,   0,   0,   0],
#        [  0, 144,   0, ...,   0,   0,   0],
#        [  0,   0, 118, ...,   0,   0,   1],
#        ...,
#        [  0,   0,   0, ..., 108,   0,   0],
#        [  0,   0,   0, ...,   0, 189,   0],
#        [  0,   0,   0, ...,   0,   0,  99]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[81.03448276,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 97.95918367,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 88.05970149, ...,  0.        ,
#          0.        ,  0.74626866],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 90.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         88.73239437,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 86.84210526]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
