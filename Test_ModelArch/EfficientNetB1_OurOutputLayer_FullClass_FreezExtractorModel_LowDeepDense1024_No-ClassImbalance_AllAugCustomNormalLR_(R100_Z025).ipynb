# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=240
img_width=240
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 240, 240, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import EfficientNetB1

efficientnetB0_model = keras.applications.EfficientNetB1(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1.h5
# 32153600/32148312 [==============================] - 25s 1us/step
# 32161792/32148312 [==============================] - 25s 1us/step

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 240, 240, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 240, 240, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 240, 240, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 241, 241, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 120, 120, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 120, 120, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 120, 120, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 120, 120, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 120, 120, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 120, 120, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 120, 120, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 120, 120, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 120, 120, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 120, 120, 16) 144         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 120, 120, 16) 64          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 120, 120, 16) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 16)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 16)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 4)      68          block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 16)     80          block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 120, 120, 16) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 120, 120, 16) 256         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 120, 120, 16) 64          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 120, 120, 16) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 120, 120, 16) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 120, 120, 96) 1536        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 120, 120, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 120, 120, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 121, 121, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 60, 60, 96)   864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 60, 60, 96)   384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 60, 60, 96)   0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 60, 60, 96)   0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 60, 60, 24)   2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 60, 60, 24)   96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 60, 60, 144)  3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 60, 60, 144)  576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 60, 60, 144)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 60, 60, 144)  1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 60, 60, 144)  576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 60, 60, 144)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 60, 60, 144)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 60, 60, 24)   3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 60, 60, 24)   96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 60, 60, 24)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 60, 60, 24)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 60, 60, 144)  3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 60, 60, 144)  576         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 60, 60, 144)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 60, 60, 144)  1296        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 60, 60, 144)  576         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 60, 60, 144)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 144)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 60, 60, 144)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 60, 60, 24)   3456        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 60, 60, 24)   96          block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 60, 60, 24)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 60, 60, 24)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 60, 60, 144)  3456        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 60, 60, 144)  576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 60, 60, 144)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 63, 63, 144)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 30, 30, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 30, 30, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 30, 30, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 30, 30, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 30, 30, 40)   5760        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 30, 30, 40)   160         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 30, 30, 240)  9600        block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 30, 30, 240)  960         block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 30, 30, 240)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 30, 30, 240)  6000        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 30, 30, 240)  960         block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 30, 30, 240)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 240)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 30, 30, 240)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 30, 30, 40)   9600        block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 30, 30, 40)   160         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 30, 30, 40)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 30, 30, 40)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 30, 30, 240)  9600        block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 30, 30, 240)  960         block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 30, 30, 240)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 30, 30, 240)  6000        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 30, 30, 240)  960         block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 30, 30, 240)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 240)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 240)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 30, 30, 240)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 30, 30, 40)   9600        block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 30, 30, 40)   160         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 30, 30, 40)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 30, 30, 40)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 30, 30, 240)  9600        block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 30, 30, 240)  960         block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 30, 30, 240)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 31, 31, 240)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 15, 15, 240)  2160        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 15, 15, 240)  960         block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 15, 15, 240)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 240)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 240)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 10)     2410        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 240)    2640        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 15, 15, 240)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 15, 15, 80)   19200       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 15, 15, 80)   320         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 15, 15, 480)  38400       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 15, 15, 480)  1920        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 15, 15, 480)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 15, 15, 480)  4320        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 15, 15, 480)  1920        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 15, 15, 480)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 480)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 15, 15, 480)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 15, 15, 80)   38400       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 15, 15, 80)   320         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 15, 15, 80)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 15, 15, 80)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 15, 15, 480)  38400       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 15, 15, 480)  1920        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 15, 15, 480)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 15, 15, 480)  4320        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 15, 15, 480)  1920        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 15, 15, 480)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 480)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 15, 15, 480)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 15, 15, 80)   38400       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 15, 15, 80)   320         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 15, 15, 80)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 15, 15, 80)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 15, 15, 480)  38400       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 15, 15, 480)  1920        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 15, 15, 480)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 15, 15, 480)  4320        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 15, 15, 480)  1920        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 15, 15, 480)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 480)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 15, 15, 480)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 15, 15, 80)   38400       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 15, 15, 80)   320         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 15, 15, 80)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 15, 15, 80)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 15, 15, 480)  38400       block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 15, 15, 480)  1920        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 15, 15, 480)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 15, 15, 480)  12000       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 15, 15, 480)  1920        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 15, 15, 480)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 480)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 480)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 15, 15, 480)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 15, 15, 112)  53760       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 15, 15, 112)  448         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 15, 15, 672)  75264       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 15, 15, 672)  2688        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 15, 15, 672)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 15, 15, 672)  16800       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 15, 15, 672)  2688        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 15, 15, 672)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 672)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 15, 15, 672)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 15, 15, 112)  75264       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 15, 15, 112)  448         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 15, 15, 112)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 15, 15, 112)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 15, 15, 672)  75264       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 15, 15, 672)  2688        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 15, 15, 672)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 15, 15, 672)  16800       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 15, 15, 672)  2688        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 15, 15, 672)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 672)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 672)    19488       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 15, 15, 672)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 15, 15, 112)  75264       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 15, 15, 112)  448         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 15, 15, 112)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 15, 15, 112)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_conv (Conv2D)    (None, 15, 15, 672)  75264       block5c_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_bn (BatchNormali (None, 15, 15, 672)  2688        block5d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5d_expand_activation (Acti (None, 15, 15, 672)  0           block5d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5d_dwconv (DepthwiseConv2D (None, 15, 15, 672)  16800       block5d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5d_bn (BatchNormalization) (None, 15, 15, 672)  2688        block5d_dwconv[0][0]
# __________________________________________________________________________________________________
# block5d_activation (Activation) (None, 15, 15, 672)  0           block5d_bn[0][0]
# __________________________________________________________________________________________________
# block5d_se_squeeze (GlobalAvera (None, 672)          0           block5d_activation[0][0]
# __________________________________________________________________________________________________
# block5d_se_reshape (Reshape)    (None, 1, 1, 672)    0           block5d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5d_se_reduce (Conv2D)      (None, 1, 1, 28)     18844       block5d_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6c_expand_activation (Acti (None, 8, 8, 1152)   0           block6c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6c_dwconv (DepthwiseConv2D (None, 8, 8, 1152)   28800       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 8, 8, 1152)   4608        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 8, 8, 1152)   0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1152)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 8, 8, 1152)   0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 8, 8, 192)    221184      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 8, 8, 192)    768         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 8, 8, 192)    0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 8, 8, 192)    0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 8, 8, 1152)   221184      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 8, 8, 1152)   4608        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 8, 8, 1152)   0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 8, 8, 1152)   28800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 8, 8, 1152)   4608        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 8, 8, 1152)   0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1152)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 8, 8, 1152)   0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 8, 8, 192)    221184      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 8, 8, 192)    768         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 8, 8, 192)    0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 8, 8, 192)    0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 8, 8, 1152)   221184      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 8, 8, 1152)   4608        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 8, 8, 1152)   0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 8, 8, 1152)   28800       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 8, 8, 1152)   4608        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 8, 8, 1152)   0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1152)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 8, 8, 1152)   0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 8, 8, 192)    221184      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 8, 8, 192)    768         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 8, 8, 192)    0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 8, 8, 192)    0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 8, 8, 1152)   221184      block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 8, 8, 1152)   4608        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 8, 8, 1152)   0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 8, 8, 1152)   10368       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 8, 8, 1152)   4608        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 8, 8, 1152)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1152)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1152)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 48)     55344       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1152)   56448       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 8, 8, 1152)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 8, 8, 320)    368640      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 8, 8, 320)    1280        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 8, 8, 1920)   614400      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 8, 8, 1920)   7680        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 8, 8, 1920)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 8, 8, 1920)   17280       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 8, 8, 1920)   7680        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 8, 8, 1920)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 1920)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 1920)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 80)     153680      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 1920)   155520      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 8, 8, 1920)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 8, 8, 320)    614400      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 8, 8, 320)    1280        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 8, 8, 320)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 8, 8, 320)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 8, 8, 1280)   409600      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 8, 8, 1280)   5120        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 8, 8, 1280)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1280)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 6,575,239
# Trainable params: 0
# Non-trainable params: 6,575,239
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1280)              6575239
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1311744
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 7,929,008
# Trainable params: 1,353,769
# Non-trainable params: 6,575,239
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 43s 311ms/step - loss: 1.0533 - accuracy: 0.7250 - val_loss: 0.2751 - val_accuracy: 0.9301
# Epoch 2/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.1728 - accuracy: 0.9561 - val_loss: 0.1594 - val_accuracy: 0.9521
# Epoch 3/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0797 - accuracy: 0.9858 - val_loss: 0.1309 - val_accuracy: 0.9560
# Epoch 4/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0559 - accuracy: 0.9893 - val_loss: 0.1495 - val_accuracy: 0.9560
# Epoch 5/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0393 - accuracy: 0.9926 - val_loss: 0.1339 - val_accuracy: 0.9560
# Epoch 6/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0246 - accuracy: 0.9968 - val_loss: 0.1472 - val_accuracy: 0.9405
# Epoch 7/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0192 - accuracy: 0.9981 - val_loss: 0.1104 - val_accuracy: 0.9612
# Epoch 8/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0178 - accuracy: 0.9968 - val_loss: 0.1089 - val_accuracy: 0.9612
# Epoch 9/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0180 - accuracy: 0.9968 - val_loss: 0.1082 - val_accuracy: 0.9612
# Epoch 10/2000
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0117 - accuracy: 0.9981 - val_loss: 0.1218 - val_accuracy: 0.9560
# Epoch 11/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0122 - accuracy: 0.9981 - val_loss: 0.0957 - val_accuracy: 0.9651
# Epoch 12/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0150 - accuracy: 0.9961 - val_loss: 0.1089 - val_accuracy: 0.9651
# Epoch 13/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0129 - accuracy: 0.9977 - val_loss: 0.0898 - val_accuracy: 0.9651
# Epoch 14/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0130 - accuracy: 0.9971 - val_loss: 0.1126 - val_accuracy: 0.9612
# Epoch 15/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0135 - accuracy: 0.9974 - val_loss: 0.0981 - val_accuracy: 0.9612
# Epoch 16/2000
# 49/49 [==============================] - 8s 172ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.1159 - val_accuracy: 0.9586
# Epoch 17/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0099 - accuracy: 0.9981 - val_loss: 0.1141 - val_accuracy: 0.9599
# Epoch 18/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0258 - accuracy: 0.9919 - val_loss: 0.0993 - val_accuracy: 0.9677
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 19/2000
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0063 - accuracy: 0.9990 - val_loss: 0.0749 - val_accuracy: 0.9754
# Epoch 20/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.0719 - val_accuracy: 0.9767
# Epoch 21/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0789 - val_accuracy: 0.9741
# Epoch 22/2000
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 23/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0770 - val_accuracy: 0.9741
# Epoch 24/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0794 - val_accuracy: 0.9728
# Epoch 25/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0685 - val_accuracy: 0.9767
# Epoch 26/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9754
# Epoch 27/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 28/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9741
# Epoch 29/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0757 - val_accuracy: 0.9728
# Epoch 30/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9741
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 31/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0750 - val_accuracy: 0.9741
# Epoch 32/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 33/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 0.0749 - val_accuracy: 0.9741
# Epoch 34/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9728
# Epoch 35/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9728
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 36/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0749 - val_accuracy: 0.9728
# Epoch 37/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9728
# Epoch 38/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9728
# Epoch 39/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9728
# Epoch 40/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0745 - val_accuracy: 0.9728
# Epoch 41/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9728
# Epoch 42/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9728
# Epoch 43/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0743 - val_accuracy: 0.9728
# Epoch 44/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9741
# Epoch 45/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9741
# Epoch 46/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9754
# Epoch 47/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 48/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0743 - val_accuracy: 0.9754
# Epoch 49/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9754
# Epoch 50/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0745 - val_accuracy: 0.9754
# Epoch 51/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0744 - val_accuracy: 0.9754
# Epoch 52/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9754
# Epoch 53/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9754
# Epoch 54/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 55/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9754
# Epoch 56/2000
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0748 - val_accuracy: 0.9754
# Epoch 57/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0742 - val_accuracy: 0.9754
# Epoch 58/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0751 - val_accuracy: 0.9741
# Epoch 59/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.0762 - val_accuracy: 0.9728
# Epoch 60/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0764 - val_accuracy: 0.9741
# Epoch 61/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9754
# Epoch 62/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0761 - val_accuracy: 0.9754
# Epoch 63/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0765 - val_accuracy: 0.9754
# Epoch 64/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9767
# Epoch 65/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9754
# Epoch 66/2000
# 49/49 [==============================] - 8s 162ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 67/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0764 - val_accuracy: 0.9741
# Epoch 68/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0771 - val_accuracy: 0.9741
# Epoch 69/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0767 - val_accuracy: 0.9754
# Epoch 70/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9754
# Epoch 71/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9754
# Epoch 72/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9754
# Epoch 73/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9741
# Epoch 74/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 75/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9741
# Epoch 76/2000
# 49/49 [==============================] - 8s 163ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 77/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9741
# Epoch 78/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 79/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 80/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9741
# Epoch 81/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9741
# Epoch 82/2000
# 49/49 [==============================] - 8s 164ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9741
# Epoch 83/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9754
# Epoch 84/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9754
# Epoch 85/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0756 - val_accuracy: 0.9754
# Epoch 86/2000
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0753 - val_accuracy: 0.9754
# Epoch 87/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0743 - val_accuracy: 0.9754
# Epoch 88/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0751 - val_accuracy: 0.9741
# Epoch 89/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9754
# Epoch 90/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9754
# Epoch 91/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 92/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0756 - val_accuracy: 0.9741
# Epoch 93/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0768 - val_accuracy: 0.9754
# Epoch 94/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9754
# Epoch 95/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9754
# Epoch 96/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0755 - val_accuracy: 0.9754
# Epoch 97/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9754
# Epoch 98/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9754
# Epoch 99/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0751 - val_accuracy: 0.9754
# Epoch 100/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9767
# Epoch 101/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9767
# Epoch 102/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9754
# Epoch 103/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0735 - val_accuracy: 0.9754
# Epoch 104/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9767
# Epoch 105/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0742 - val_accuracy: 0.9754
# Epoch 106/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 107/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9741
# Epoch 108/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9754
# Epoch 109/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0760 - val_accuracy: 0.9754
# Epoch 110/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0771 - val_accuracy: 0.9754
# Epoch 111/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9754
# Epoch 112/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0800 - val_accuracy: 0.9754
# Epoch 113/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0807 - val_accuracy: 0.9741
# Epoch 114/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.0812 - val_accuracy: 0.9741
# Epoch 115/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0803 - val_accuracy: 0.9741
# Epoch 116/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0800 - val_accuracy: 0.9741
# Epoch 117/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0804 - val_accuracy: 0.9728
# Epoch 118/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.9685e-04 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 0.9728
# Epoch 119/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0780 - val_accuracy: 0.9741
# Epoch 120/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0768 - val_accuracy: 0.9741
# Epoch 121/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9741
# Epoch 122/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9741
# Epoch 123/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0758 - val_accuracy: 0.9754
# Epoch 124/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.0762 - val_accuracy: 0.9767
# Epoch 125/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0759 - val_accuracy: 0.9754
# Epoch 126/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.7593e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9754
# Epoch 127/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0750 - val_accuracy: 0.9754
# Epoch 128/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0751 - val_accuracy: 0.9754
# Epoch 129/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0749 - val_accuracy: 0.9754
# Epoch 130/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9754
# Epoch 131/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0771 - val_accuracy: 0.9754
# Epoch 132/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0772 - val_accuracy: 0.9754
# Epoch 133/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9754
# Epoch 134/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9741
# Epoch 135/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0784 - val_accuracy: 0.9741
# Epoch 136/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9754
# Epoch 137/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0772 - val_accuracy: 0.9754
# Epoch 138/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0778 - val_accuracy: 0.9754
# Epoch 139/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0781 - val_accuracy: 0.9754
# Epoch 140/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0766 - val_accuracy: 0.9754
# Epoch 141/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9754
# Epoch 142/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 0.9767
# Epoch 143/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9767
# Epoch 144/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9767
# Epoch 145/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0764 - val_accuracy: 0.9767
# Epoch 146/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0750 - val_accuracy: 0.9767
# Epoch 147/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0755 - val_accuracy: 0.9767
# Epoch 148/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9754
# Epoch 149/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9741
# Epoch 150/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9741
# Epoch 151/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 152/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0747 - val_accuracy: 0.9741
# Epoch 153/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0748 - val_accuracy: 0.9754
# Epoch 154/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0765 - val_accuracy: 0.9767
# Epoch 155/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.1763e-04 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9754
# Epoch 156/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0790 - val_accuracy: 0.9767
# Epoch 157/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9767
# Epoch 158/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0789 - val_accuracy: 0.9767
# Epoch 159/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0780 - val_accuracy: 0.9767
# Epoch 160/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0773 - val_accuracy: 0.9767
# Epoch 161/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9767
# Epoch 162/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9767
# Epoch 163/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9754
# Epoch 164/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9754
# Epoch 165/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0752 - val_accuracy: 0.9754
# Epoch 166/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.6660e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 167/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.0752 - val_accuracy: 0.9767
# Epoch 168/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0775 - val_accuracy: 0.9767
# Epoch 169/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9767
# Epoch 170/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9767
# Epoch 171/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9754
# Epoch 172/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0752 - val_accuracy: 0.9754
# Epoch 173/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.0209e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9754
# Epoch 174/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.4656e-04 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9754
# Epoch 175/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9741
# Epoch 176/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0790 - val_accuracy: 0.9741
# Epoch 177/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0789 - val_accuracy: 0.9741
# Epoch 178/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.0237e-04 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 0.9741
# Epoch 179/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9741
# Epoch 180/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.5470e-04 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9741
# Epoch 181/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0768 - val_accuracy: 0.9741
# Epoch 182/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0770 - val_accuracy: 0.9741
# Epoch 183/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0775 - val_accuracy: 0.9754
# Epoch 184/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0776 - val_accuracy: 0.9754
# Epoch 185/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.0622e-04 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9754
# Epoch 186/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 187/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0757 - val_accuracy: 0.9741
# Epoch 188/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 0.9741
# Epoch 189/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9741
# Epoch 190/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0761 - val_accuracy: 0.9754
# Epoch 191/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0766 - val_accuracy: 0.9754
# Epoch 192/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.3738e-04 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9754
# Epoch 193/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0771 - val_accuracy: 0.9754
# Epoch 194/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9754
# Epoch 195/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9754
# Epoch 196/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.8712e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9754
# Epoch 197/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0759 - val_accuracy: 0.9754
# Epoch 198/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0749 - val_accuracy: 0.9754
# Epoch 199/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.3999e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9754
# Epoch 200/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0739 - val_accuracy: 0.9754
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.3152e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9754
# Epoch 202/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.1409e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9754
# Epoch 203/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.3493e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9754
# Epoch 204/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.5493e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9754
# Epoch 205/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.8986e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9754
# Epoch 206/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0738 - val_accuracy: 0.9741
# Epoch 207/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0746 - val_accuracy: 0.9741
# Epoch 208/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0750 - val_accuracy: 0.9741
# Epoch 209/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0754 - val_accuracy: 0.9741
# Epoch 210/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.0379e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9741
# Epoch 211/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0745 - val_accuracy: 0.9754
# Epoch 212/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0750 - val_accuracy: 0.9754
# Epoch 213/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9767
# Epoch 214/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0755 - val_accuracy: 0.9754
# Epoch 215/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9754
# Epoch 216/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.0899e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9754
# Epoch 217/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0759 - val_accuracy: 0.9754
# Epoch 218/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0774 - val_accuracy: 0.9754
# Epoch 219/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.6641e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9754
# Epoch 220/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.7151e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9754
# Epoch 221/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0765 - val_accuracy: 0.9754
# Epoch 222/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.0663e-04 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9754
# Epoch 223/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0763 - val_accuracy: 0.9741
# Epoch 224/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.0262e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9741
# Epoch 225/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.0431e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9741
# Epoch 226/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 0.9741
# Epoch 227/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0773 - val_accuracy: 0.9754
# Epoch 228/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 7.4205e-04 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9767
# Epoch 229/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 8.9896e-04 - accuracy: 1.0000 - val_loss: 0.0774 - val_accuracy: 0.9767
# Epoch 230/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9767
# Epoch 231/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.8630e-04 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9767
# Epoch 232/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0752 - val_accuracy: 0.9754
# Epoch 233/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.8915e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9754
# Epoch 234/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 6.8119e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9754
# Epoch 235/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0744 - val_accuracy: 0.9741
# Epoch 236/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.7055e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9728
# Epoch 237/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0754 - val_accuracy: 0.9728
# Epoch 238/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.9416e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9728
# Epoch 239/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0731 - val_accuracy: 0.9741
# Epoch 240/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.3865e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9741
# Epoch 241/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0733 - val_accuracy: 0.9741
# Epoch 242/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0734 - val_accuracy: 0.9754
# Epoch 243/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.6625e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 244/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.1687e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9754
# Epoch 245/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.7574e-04 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 0.9767
# Epoch 246/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.9632e-04 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9767
# Epoch 247/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.0900e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9767
# Epoch 248/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.5312e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9767
# Epoch 249/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.9030e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9767
# Epoch 250/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 9.1284e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9767
# Epoch 251/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0725 - val_accuracy: 0.9754
# Epoch 252/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.0250e-04 - accuracy: 0.9997 - val_loss: 0.0722 - val_accuracy: 0.9754
# Epoch 253/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.5419e-04 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9754
# Epoch 254/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.0026e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9754
# Epoch 255/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.8783e-04 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9754
# Epoch 256/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0724 - val_accuracy: 0.9754
# Epoch 257/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.0581e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9754
# Epoch 258/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0733 - val_accuracy: 0.9754
# Epoch 259/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 6.1540e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9754
# Epoch 260/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0706 - val_accuracy: 0.9767
# Epoch 261/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 7.2053e-04 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9767
# Epoch 262/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 7.1590e-04 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9754
# Epoch 263/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.8795e-04 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9754
# Epoch 264/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0723 - val_accuracy: 0.9754
# Epoch 265/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9754
# Epoch 266/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.7686e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9754
# Epoch 267/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.0129e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9754
# Epoch 268/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.6379e-04 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9754
# Epoch 269/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0740 - val_accuracy: 0.9754
# Epoch 270/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.9081e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 271/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.1628e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9754
# Epoch 272/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.6384e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9754
# Epoch 273/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0739 - val_accuracy: 0.9741
# Epoch 274/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0733 - val_accuracy: 0.9754
# Epoch 275/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.8285e-04 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9767
# Epoch 276/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0738 - val_accuracy: 0.9767
# Epoch 277/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.5160e-04 - accuracy: 0.9997 - val_loss: 0.0744 - val_accuracy: 0.9754
# Epoch 278/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.4251e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9754
# Epoch 279/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.2244e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9754
# Epoch 280/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.8127e-04 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9741
# Epoch 281/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.6255e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9741
# Epoch 282/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.5145e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9741
# Epoch 283/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9741
# Epoch 284/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0775 - val_accuracy: 0.9741
# Epoch 285/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.1603e-04 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9741
# Epoch 286/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.6673e-04 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9741
# Epoch 287/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0778 - val_accuracy: 0.9741
# Epoch 288/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0763 - val_accuracy: 0.9754
# Epoch 289/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.2426e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9754
# Epoch 290/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.1395e-04 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9754
# Epoch 291/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0759 - val_accuracy: 0.9767
# Epoch 292/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.4620e-04 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9767
# Epoch 293/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.4345e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 294/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.7208e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9767
# Epoch 295/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.8483e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 296/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.7332e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 297/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.6720e-04 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9767
# Epoch 298/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.9436e-04 - accuracy: 0.9997 - val_loss: 0.0731 - val_accuracy: 0.9754
# Epoch 299/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.3519e-04 - accuracy: 1.0000 - val_loss: 0.0721 - val_accuracy: 0.9754
# Epoch 300/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.0881e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9754
# Epoch 301/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.8502e-04 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9754
# Epoch 302/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 7.0299e-04 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9754
# Epoch 303/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0724 - val_accuracy: 0.9754
# Epoch 304/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.3527e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9754
# Epoch 305/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0719 - val_accuracy: 0.9754
# Epoch 306/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0723 - val_accuracy: 0.9741
# Epoch 307/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0705 - val_accuracy: 0.9754
# Epoch 308/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0704 - val_accuracy: 0.9754
# Epoch 309/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.8468e-04 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9767
# Epoch 310/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.4712e-04 - accuracy: 0.9997 - val_loss: 0.0709 - val_accuracy: 0.9767
# Epoch 311/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.2025e-04 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9767
# Epoch 312/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.7116e-04 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9767
# Epoch 313/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.2148e-04 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 0.9767
# Epoch 314/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.1452e-04 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9767
# Epoch 315/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 5.2583e-04 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9767
# Epoch 316/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.5344e-04 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9767
# Epoch 317/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.5120e-04 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9767
# Epoch 318/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 4.2982e-04 - accuracy: 1.0000 - val_loss: 0.0714 - val_accuracy: 0.9767
# Epoch 319/2000
# 49/49 [==============================] - 8s 165ms/step - loss: 8.1472e-04 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9767
# Epoch 320/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.7640e-04 - accuracy: 0.9997 - val_loss: 0.0705 - val_accuracy: 0.9767
# Epoch 321/2000
# ...
# Epoch 1899/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8520e-04 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9767
# Epoch 1900/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.6331e-05 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9767
# Epoch 1901/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6064e-04 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9767
# Epoch 1902/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.7453e-05 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9767
# Epoch 1903/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.2834e-04 - accuracy: 0.9997 - val_loss: 0.0718 - val_accuracy: 0.9767
# Epoch 1904/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.1529e-04 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9767
# Epoch 1905/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.1422e-04 - accuracy: 1.0000 - val_loss: 0.0714 - val_accuracy: 0.9767
# Epoch 1906/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0708 - val_accuracy: 0.9767
# Epoch 1907/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.2896e-04 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9767
# Epoch 1908/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.3949e-05 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9754
# Epoch 1909/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.0201e-04 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9754
# Epoch 1910/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.7708e-05 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9754
# Epoch 1911/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.8424e-04 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9754
# Epoch 1912/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.5696e-04 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9767
# Epoch 1913/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.3966e-04 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9767
# Epoch 1914/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 6.3192e-05 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9767
# Epoch 1915/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.7183e-05 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9767
# Epoch 1916/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.8975e-05 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9767
# Epoch 1917/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 6.8803e-05 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9767
# Epoch 1918/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.1878e-05 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 0.9767
# Epoch 1919/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.9715e-05 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9767
# Epoch 1920/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.3954e-04 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 0.9767
# Epoch 1921/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.0330e-05 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9767
# Epoch 1922/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.1822e-05 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9767
# Epoch 1923/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.5502e-04 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9767
# Epoch 1924/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.4002e-04 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9780
# Epoch 1925/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.1612e-05 - accuracy: 1.0000 - val_loss: 0.0700 - val_accuracy: 0.9780
# Epoch 1926/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.3058e-04 - accuracy: 0.9997 - val_loss: 0.0721 - val_accuracy: 0.9780
# Epoch 1927/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.0565e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9780
# Epoch 1928/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.7762e-05 - accuracy: 1.0000 - val_loss: 0.0721 - val_accuracy: 0.9780
# Epoch 1929/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.7950e-05 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9780
# Epoch 1930/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.0304e-05 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9780
# Epoch 1931/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.3393e-04 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 0.9780
# Epoch 1932/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.9778e-05 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 0.9767
# Epoch 1933/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.6351e-05 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9780
# Epoch 1934/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.0458e-04 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9780
# Epoch 1935/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0720 - val_accuracy: 0.9780
# Epoch 1936/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.5356e-04 - accuracy: 0.9997 - val_loss: 0.0733 - val_accuracy: 0.9780
# Epoch 1937/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.5998e-05 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9780
# Epoch 1938/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.0523e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9767
# Epoch 1939/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.3401e-04 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9767
# Epoch 1940/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.4974e-05 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9767
# Epoch 1941/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.0658e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 1942/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.0325e-05 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9767
# Epoch 1943/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 5.9815e-04 - accuracy: 0.9997 - val_loss: 0.0752 - val_accuracy: 0.9767
# Epoch 1944/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.7782e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9767
# Epoch 1945/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.9813e-05 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9767
# Epoch 1946/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.3866e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9767
# Epoch 1947/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.1301e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9767
# Epoch 1948/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 6.0124e-05 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9767
# Epoch 1949/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.6224e-04 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9767
# Epoch 1950/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.9565e-05 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9767
# Epoch 1951/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 5.1609e-05 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9767
# Epoch 1952/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 3.5543e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9767
# Epoch 1953/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.3452e-04 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9780
# Epoch 1954/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.1276e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9793
# Epoch 1955/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.2920e-05 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9793
# Epoch 1956/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.0300e-05 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 0.9793
# Epoch 1957/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.6751e-05 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9780
# Epoch 1958/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.8838e-05 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9793
# Epoch 1959/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 6.1578e-04 - accuracy: 0.9997 - val_loss: 0.0720 - val_accuracy: 0.9780
# Epoch 1960/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 3.4278e-04 - accuracy: 0.9997 - val_loss: 0.0722 - val_accuracy: 0.9780
# Epoch 1961/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.8031e-05 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9780
# Epoch 1962/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.1119e-05 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9767
# Epoch 1963/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.9602e-05 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9780
# Epoch 1964/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.5832e-04 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 0.9767
# Epoch 1965/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.8101e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9767
# Epoch 1966/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 2.0628e-04 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 0.9767
# Epoch 1967/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.6398e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9767
# Epoch 1968/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.2678e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9767
# Epoch 1969/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.6868e-05 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9767
# Epoch 1970/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.0091e-04 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9767
# Epoch 1971/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.9461e-05 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 0.9767
# Epoch 1972/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.9829e-05 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9767
# Epoch 1973/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.4447e-04 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9767
# Epoch 1974/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.1127e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9767
# Epoch 1975/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.2524e-05 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9767
# Epoch 1976/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 3.8974e-04 - accuracy: 0.9997 - val_loss: 0.0739 - val_accuracy: 0.9767
# Epoch 1977/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 5.2171e-05 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9767
# Epoch 1978/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.4711e-05 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9767
# Epoch 1979/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.2984e-04 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9767
# Epoch 1980/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 9.4422e-04 - accuracy: 0.9997 - val_loss: 0.0760 - val_accuracy: 0.9767
# Epoch 1981/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.8962e-04 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9767
# Epoch 1982/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 9.0964e-05 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 0.9767
# Epoch 1983/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 5.7205e-05 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9767
# Epoch 1984/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 5.9806e-05 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9767
# Epoch 1985/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 2.6435e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9767
# Epoch 1986/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.1102e-05 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9767
# Epoch 1987/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.4851e-04 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9767
# Epoch 1988/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.0865e-04 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9767
# Epoch 1989/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.3214e-04 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 0.9767
# Epoch 1990/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 7.1560e-05 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9767
# Epoch 1991/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0743 - val_accuracy: 0.9767
# Epoch 1992/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.6494e-04 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9767
# Epoch 1993/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.7776e-05 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 0.9767
# Epoch 1994/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 6.6770e-05 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9767
# Epoch 1995/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 6.7637e-05 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9767
# Epoch 1996/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 7.6984e-05 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9767
# Epoch 1997/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 1.0516e-04 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9767
# Epoch 1998/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 8.4214e-05 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9767
# Epoch 1999/2000
# 49/49 [==============================] - 8s 166ms/step - loss: 1.1753e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9767
# Epoch 2000/2000
# 49/49 [==============================] - 8s 167ms/step - loss: 8.8147e-05 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9767
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 322ms/step - loss: 0.4664 - accuracy: 0.8969
# test_indoor_ds_results:test loss, test acc: [0.46641117334365845, 0.8968784809112549]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 24s 405ms/step - loss: 1.0026 - accuracy: 0.8083
# test_outdoor_ds_results:test loss, test acc: [1.002568006515503, 0.8082802295684814]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 8s 172ms/step - loss: 1.4894 - accuracy: 0.7443
# test_belt_ds_results:test loss, test acc: [1.4893556833267212, 0.7443336248397827]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB1_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_106759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_110765) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_64661) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_103993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_68764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_115113) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_65219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_66720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_64820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_114572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_110395) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_111325) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_107148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_114942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_69212) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_64620) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_111932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_106130) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_68988) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_111002) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_108555) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_104334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_65392) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_65715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_105029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_107385) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_66944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_65674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_66107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_68805) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_96915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_68489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_69161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_113405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_67219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_65924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_64952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_68265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_68713) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_65010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_103927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_69594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_65616) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_114506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_113146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_109722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_65484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_105523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_66588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_110158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_113339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_105959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_116327) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_67876) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_68581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_69462) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_106825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_67652) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_107992) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_68357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_112776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_104963) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_104400) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_68316) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_66056) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_108362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_66379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_109181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_65168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_66547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_109551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_67260) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_115720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_116393) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_66338) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_105352) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_65051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_115549) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_54318) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_66771) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_115179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_115786) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_112710) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_117323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_107926) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_106566) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_104770) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_105589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_68148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_66148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_65883) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_94363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_67601) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_109788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_66812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_69029) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_108944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_67036) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_111496) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_69253) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_112169) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_67428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_67469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_109115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_107319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_103501) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_113899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_113965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_66995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_103756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_116716) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_69370) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_65832) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_68107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_66496) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_65260) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_68049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_108621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_64569) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_67168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_112539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_110329) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_110936) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_116953) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_67693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_112103) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_107755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_114335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_66280) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_116156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_67377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_100971) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_64779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_65443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_116887) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_69421) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_67825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_113728) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_68540) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_111562) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_68937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_67917) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_106196) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 6s 132ms/step - loss: 0.4540 - accuracy: 0.8891
# 50/50 [==============================] - 7s 133ms/step - loss: 0.9291 - accuracy: 0.7968
# 35/35 [==============================] - 5s 134ms/step - loss: 1.2984 - accuracy: 0.7325
# Epoch200
#  test_indoor_acc=0.8890746831893921
#  test_outdoor_acc=0.7968152761459351
#  test_belt_acc=0.7325475811958313
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_163209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_208984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_167302) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_164205) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_203359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_163981) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_164927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_202345) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_208311) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_207704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_165401) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_211128) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_205737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_152907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_165808) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_202923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_166190) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_167959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_163158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_214309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_167353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_213095) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_166854) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_204178) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_210085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_166241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_207210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_204112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_166058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_165360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_205908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_163808) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_214916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_164304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_211299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_166017) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_202090) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_164263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_205974) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_165177) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_195504) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_204719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_164472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_207144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_165584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_167394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_210758) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_166506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_208918) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_208377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_207770) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_166905) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_203552) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_167129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_163599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_206581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_167801) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_212488) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_202516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_165625) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_202582) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_167170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_167618) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_206344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_164513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_213161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_214982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_168183) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_164032) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_168010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_165849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_166737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_209354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_192952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_167750) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_163640) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_205414) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_210521) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_164869) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_206515) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_167078) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_210692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_167526) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_204548) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_209914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_205155) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_205348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_204785) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_199560) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_163757) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_165309) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_163409) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_210151) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_211735) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1001268) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_998694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_953707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_951938) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_997091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_991296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_952148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_953252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_956357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_952030) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_952812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_955950) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_955418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_952761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_956133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_952420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_992398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_998371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_952629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_984284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_955286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_954405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1000515) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_988340) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_995924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_993328) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_955245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_956398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_955021) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_953201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_992958) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_954537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_998931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_941687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_956581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_955517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_995731) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_954089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_997157) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1000708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1000774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_955858) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_953043) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1001334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1000145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_993565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_991362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1003696) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_952588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_953649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_955909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_954140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_955476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_954588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_955634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_953916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1003089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_954181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_956963) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_994688) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_956790) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_995124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_999472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_998305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_995295) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_996313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_954313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_953476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1003762) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_956739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_996484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_953293) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_991125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_998134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1004692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1001097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_990870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 6s 132ms/step - loss: 0.4664 - accuracy: 0.8969
# 50/50 [==============================] - 7s 134ms/step - loss: 1.0026 - accuracy: 0.8083
# 35/35 [==============================] - 5s 134ms/step - loss: 1.4894 - accuracy: 0.7443
# Epoch2000
#  test_indoor_acc=0.8968784809112549
#  test_outdoor_acc=0.8082802295684814
#  test_belt_acc=0.7443336248397827

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8164974451065063
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8890746831893921,
#  0.8890746831893921,
#  0.8896321058273315,
#  0.8918617367744446,
#  0.8857302069664001,
#  0.8896321058273315,
#  0.8896321058273315,
#  0.8929765820503235,
#  0.8991081118583679,
#  0.8968784809112549]

# %%
test_outdoor_acc
# Out:
# [0.7968152761459351,
#  0.8015923500061035,
#  0.8047770857810974,
#  0.8012738823890686,
#  0.8006369471549988,
#  0.8047770857810974,
#  0.8108280301094055,
#  0.8085986971855164,
#  0.8076432943344116,
#  0.8082802295684814]

# %%
test_belt_acc
# Out:
# [0.7325475811958313,
#  0.7357207536697388,
#  0.7379872798919678,
#  0.7438803315162659,
#  0.7411604523658752,
#  0.745693564414978,
#  0.7443336248397827,
#  0.7416138052940369,
#  0.7425203919410706,
#  0.7443336248397827]

# %%
test_indoor_loss
# Out:
# [0.4540313184261322,
#  0.47151803970336914,
#  0.47002679109573364,
#  0.47254693508148193,
#  0.48998787999153137,
#  0.48040905594825745,
#  0.4820763170719147,
#  0.48726192116737366,
#  0.4688716232776642,
#  0.46641117334365845]

# %%
test_outdoor_loss
# Out:
# [0.9290580153465271,
#  0.9456980228424072,
#  0.9433155059814453,
#  0.9945086240768433,
#  1.000180959701538,
#  0.996296226978302,
#  0.9865005016326904,
#  1.0030518770217896,
#  0.9985316395759583,
#  1.002568006515503]

# %%
test_belt_loss
# Out:
# [1.298422932624817,
#  1.3489832878112793,
#  1.3763450384140015,
#  1.3829199075698853,
#  1.43258535861969,
#  1.4283273220062256,
#  1.4389880895614624,
#  1.486647367477417,
#  1.4784449338912964,
#  1.4893556833267212]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=240
img_width=240
batch_size=64

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=128)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1001941) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_955062) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_951989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_981732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1001704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_956530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_952321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_952853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1004322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_953865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_956082) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_994128) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_994194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_953425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_954364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_993935) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_997698) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_997527) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_991703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1002482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_952189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_997764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1004256) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_996920) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_952537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_955194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1004085) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_956831) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_954970) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_998865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_999301) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_954838) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_953957) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_996550) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_954746) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_992721) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_992139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_952379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_992892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_953517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_956174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_994754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_954629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_952985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_993499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_999908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1000079) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_995990) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_956622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1003525) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1003155) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_992332) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1002311) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_953748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_955685) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_955726) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1002548) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1002918) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_999538) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1001875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_953084) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_995361) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_956306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_954797) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_991769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_994517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1001268) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_998694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_953707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_951938) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_997091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_991296) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_952148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_953252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_956357) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_952030) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_952812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_955950) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_955418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_952761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_956133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_952420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_992398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_998371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_952629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_984284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_955286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_954405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1000515) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_988340) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_995924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_993328) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_955245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_956398) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_955021) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_953201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_992958) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_954537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_998931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_941687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_956581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_955517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_995731) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_954089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_997157) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1000708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1000774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_955858) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_953043) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1001334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1000145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_993565) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_991362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1003696) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_952588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_953649) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_955909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_954140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_955476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_954588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_955634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_953916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1003089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_954181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_956963) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_994688) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_956790) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_995124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_999472) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_998305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_995295) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_996313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_954313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_953476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1003762) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_956739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_996484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_953293) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_991125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_998134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1004692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1001097) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_990870) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5789
# FP=1351
# acc=0.8107843137254902
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 83.62068965517241%
# 2WayConnectorforFoley acc = 91.83673469387756%
# 2WayFoleyCatheter acc = 78.35820895522389%
# 3WayConnectorforFoley acc = 77.77777777777779%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 83.125%
# AlcoholPad acc = 53.17460317460318%
# BootCover acc = 60.8433734939759%
# CottonBall acc = 76.04790419161677%
# CottonSwap acc = 82.51748251748252%
# Dilator acc = 81.19658119658119%
# DisposableInfusionSet acc = 80.53097345132744%
# ExtensionTube acc = 64.22764227642277%
# FaceShield acc = 84.5679012345679%
# FrontLoadSyringe acc = 69.91150442477876%
# GauzePad acc = 40.340909090909086%
# Glove acc = 57.738095238095234%
# GuideWire acc = 73.21428571428571%
# LiquidBottle acc = 70.99236641221374%
# Mask acc = 98.7012987012987%
# NGTube acc = 48.38709677419355%
# NasalCannula acc = 59.29203539823009%
# Needle acc = 90.35714285714286%
# OxygenMask acc = 84.21052631578947%
# PPESuit acc = 92.74193548387096%
# PharmaceuticalProduct acc = 84.81308411214953%
# Pill acc = 97.3389355742297%
# PillBottle acc = 89.14728682170544%
# PrefilledHumidifier acc = 85.47008547008546%
# PressureConnectingTube acc = 68.70229007633588%
# ReusableHumidifier acc = 91.52542372881356%
# SodiumChlorideBag acc = 96.06299212598425%
# SterileHumidifierAdapter acc = 89.0909090909091%
# SurgicalBlade acc = 91.1504424778761%
# SurgicalCap acc = 82.88288288288288%
# SurgicalSuit acc = 58.333333333333336%
# Syringe acc = 96.95817490494296%
# TrachealTube acc = 55.96330275229357%
# UrineBag acc = 91.66666666666666%
# Vaccinebottle acc = 96.24413145539906%
# WingedInfusionSet acc = 83.33333333333334%
#
#
#
# all_avg_eachclass = 79.060840071597%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 97,   0,   0, ...,   0,   0,   0],
#        [  0, 135,   0, ...,   0,   0,   0],
#        [  0,   0, 105, ...,   0,   0,   6],
#        ...,
#        [  0,   0,   0, ..., 110,   0,   0],
#        [  0,   0,   0, ...,   0, 205,   0],
#        [  0,   0,   0, ...,   0,   0,  95]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[83.62068966,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 91.83673469,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 78.35820896, ...,  0.        ,
#          0.        ,  4.47761194],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 91.66666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         96.24413146,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 83.33333333]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
