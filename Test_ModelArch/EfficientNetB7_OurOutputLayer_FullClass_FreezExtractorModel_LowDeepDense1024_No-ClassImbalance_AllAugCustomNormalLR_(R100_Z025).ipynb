# %% [markdown]
# # FullClass-TrainCNN(InceptionV3)_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=600
img_width=600
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 600, 600, 3)
# (32,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import EfficientNetB7

efficientnetB0_model = keras.applications.EfficientNetB7(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 600, 600, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 600, 600, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 600, 600, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 601, 601, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 300, 300, 64) 1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 300, 300, 64) 256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 300, 300, 64) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 300, 300, 64) 576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 300, 300, 64) 256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 300, 300, 64) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 300, 300, 64) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 300, 300, 32) 2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 300, 300, 32) 128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 300, 300, 32) 288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 300, 300, 32) 128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 300, 300, 32) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 300, 300, 32) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 300, 300, 32) 1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 300, 300, 32) 128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 300, 300, 32) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 300, 300, 32) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 300, 300, 32) 288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 300, 300, 32) 128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 300, 300, 32) 0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 300, 300, 32) 0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 300, 300, 32) 1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 300, 300, 32) 128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 300, 300, 32) 0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 300, 300, 32) 0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 300, 300, 32) 288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 300, 300, 32) 128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 300, 300, 32) 0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 300, 300, 32) 0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 300, 300, 32) 1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 300, 300, 32) 128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 300, 300, 32) 0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 300, 300, 32) 0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 300, 300, 192 6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 300, 300, 192 768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 300, 300, 192 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 301, 301, 192 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 150, 150, 192 1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 150, 150, 192 768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 150, 150, 192 0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 150, 150, 192 0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 150, 150, 48) 9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 150, 150, 48) 192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 150, 150, 288 1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 150, 150, 288 0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 150, 150, 288 2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 150, 150, 288 1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 150, 150, 288 0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 150, 150, 288 0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 150, 150, 48) 13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 150, 150, 48) 192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 150, 150, 48) 0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 150, 150, 48) 0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 150, 150, 288 1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 150, 150, 288 0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 150, 150, 288 2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 150, 150, 288 1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 150, 150, 288 0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 150, 150, 288 0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 150, 150, 48) 13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 150, 150, 48) 192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 150, 150, 48) 0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 150, 150, 48) 0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 150, 150, 288 1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 150, 150, 288 0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 150, 150, 288 2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 150, 150, 288 1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 150, 150, 288 0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 150, 150, 288 0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 150, 150, 48) 13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 150, 150, 48) 192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 150, 150, 48) 0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 150, 150, 48) 0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 150, 150, 288 1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 150, 150, 288 0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 150, 150, 288 2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 150, 150, 288 1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 150, 150, 288 0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 150, 150, 288 0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 150, 150, 48) 13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 150, 150, 48) 192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 150, 150, 48) 0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 150, 150, 48) 0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 150, 150, 288 1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 150, 150, 288 0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 150, 150, 288 2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 150, 150, 288 1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 150, 150, 288 0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 150, 150, 288 0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 150, 150, 48) 13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 150, 150, 48) 192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 150, 150, 48) 0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 150, 150, 48) 0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 150, 150, 288 1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 150, 150, 288 0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 150, 150, 288 2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 150, 150, 288 1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 150, 150, 288 0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 150, 150, 288 0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 150, 150, 48) 13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 150, 150, 48) 192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 150, 150, 48) 0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 150, 150, 48) 0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 150, 150, 288 13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 150, 150, 288 1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 150, 150, 288 0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 153, 153, 288 0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 75, 75, 288)  7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 75, 75, 288)  1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 75, 75, 288)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 75, 75, 288)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 75, 75, 80)   23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 75, 75, 80)   320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 75, 75, 480)  38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 75, 75, 480)  1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 75, 75, 480)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 75, 75, 480)  12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 75, 75, 480)  1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 75, 75, 480)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 75, 75, 480)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 75, 75, 80)   38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 75, 75, 80)   320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 75, 75, 80)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 75, 75, 80)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 75, 75, 480)  38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 75, 75, 480)  1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 75, 75, 480)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 75, 75, 480)  12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 75, 75, 480)  1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 75, 75, 480)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 75, 75, 480)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 75, 75, 80)   38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 75, 75, 80)   320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 75, 75, 80)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 75, 75, 80)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 75, 75, 480)  38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 75, 75, 480)  1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 75, 75, 480)  0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 75, 75, 480)  12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 75, 75, 480)  1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 75, 75, 480)  0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 75, 75, 480)  0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 75, 75, 80)   38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 75, 75, 80)   320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 75, 75, 80)   0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 75, 75, 80)   0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 75, 75, 480)  38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 75, 75, 480)  1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 75, 75, 480)  0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 75, 75, 480)  12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 75, 75, 480)  1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 75, 75, 480)  0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 75, 75, 480)  0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# block6m_expand_activation (Acti (None, 19, 19, 2304) 0           block6m_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6m_dwconv (DepthwiseConv2D (None, 19, 19, 2304) 57600       block6m_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6m_bn (BatchNormalization) (None, 19, 19, 2304) 9216        block6m_dwconv[0][0]
# __________________________________________________________________________________________________
# block6m_activation (Activation) (None, 19, 19, 2304) 0           block6m_bn[0][0]
# __________________________________________________________________________________________________
# block6m_se_squeeze (GlobalAvera (None, 2304)         0           block6m_activation[0][0]
# __________________________________________________________________________________________________
# block6m_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block6m_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6m_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block6m_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6m_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block6m_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6m_se_excite (Multiply)    (None, 19, 19, 2304) 0           block6m_activation[0][0]
#                                                                  block6m_se_expand[0][0]
# __________________________________________________________________________________________________
# block6m_project_conv (Conv2D)   (None, 19, 19, 384)  884736      block6m_se_excite[0][0]
# __________________________________________________________________________________________________
# block6m_project_bn (BatchNormal (None, 19, 19, 384)  1536        block6m_project_conv[0][0]
# __________________________________________________________________________________________________
# block6m_drop (Dropout)          (None, 19, 19, 384)  0           block6m_project_bn[0][0]
# __________________________________________________________________________________________________
# block6m_add (Add)               (None, 19, 19, 384)  0           block6m_drop[0][0]
#                                                                  block6l_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 19, 19, 2304) 884736      block6m_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 19, 19, 2304) 9216        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 19, 19, 2304) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 19, 19, 2304) 20736       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 19, 19, 2304) 9216        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 19, 19, 2304) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2304)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 19, 19, 2304) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 19, 19, 640)  1474560     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 19, 19, 640)  2560        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 19, 19, 3840) 2457600     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 19, 19, 3840) 15360       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 19, 19, 3840) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 19, 19, 3840) 34560       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 19, 19, 3840) 15360       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 19, 19, 3840) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3840)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 19, 19, 3840) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 19, 19, 640)  2457600     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 19, 19, 640)  2560        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 19, 19, 640)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 19, 19, 640)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 19, 19, 3840) 2457600     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 19, 19, 3840) 15360       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 19, 19, 3840) 0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 19, 19, 3840) 34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 19, 19, 3840) 15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 19, 19, 3840) 0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 19, 19, 3840) 0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 19, 19, 640)  2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 19, 19, 640)  2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 19, 19, 640)  0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 19, 19, 640)  0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 19, 19, 3840) 2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 19, 19, 3840) 15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 19, 19, 3840) 0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 19, 19, 3840) 34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 19, 19, 3840) 15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 19, 19, 3840) 0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 19, 19, 3840) 0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 19, 19, 640)  2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 19, 19, 640)  2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (Dropout)          (None, 19, 19, 640)  0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 19, 19, 640)  0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 19, 19, 2560) 1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 19, 19, 2560) 10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 19, 19, 2560) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2560)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 64,097,687
# Trainable params: 0
# Non-trainable params: 64,097,687
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 2560)              64097687
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2622464
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 66,762,176
# Trainable params: 2,664,489
# Non-trainable params: 64,097,687
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 97/97 [==============================] - 259s 2s/step - loss: 0.7204 - accuracy: 0.8055 - val_loss: 0.1536 - val_accuracy: 0.9573
# Epoch 2/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.1268 - accuracy: 0.9628 - val_loss: 0.1057 - val_accuracy: 0.9702
# Epoch 3/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0660 - accuracy: 0.9813 - val_loss: 0.0955 - val_accuracy: 0.9702
# Epoch 4/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0412 - accuracy: 0.9877 - val_loss: 0.0838 - val_accuracy: 0.9741
# Epoch 5/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0385 - accuracy: 0.9906 - val_loss: 0.0880 - val_accuracy: 0.9741
# Epoch 6/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0299 - accuracy: 0.9916 - val_loss: 0.0570 - val_accuracy: 0.9845
# Epoch 7/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0193 - accuracy: 0.9952 - val_loss: 0.0569 - val_accuracy: 0.9806
# Epoch 8/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0296 - accuracy: 0.9916 - val_loss: 0.0413 - val_accuracy: 0.9832
# Epoch 9/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0262 - accuracy: 0.9906 - val_loss: 0.0446 - val_accuracy: 0.9897
# Epoch 10/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.0537 - val_accuracy: 0.9871
# Epoch 11/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0173 - accuracy: 0.9952 - val_loss: 0.0650 - val_accuracy: 0.9780
# Epoch 12/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0266 - accuracy: 0.9919 - val_loss: 0.0541 - val_accuracy: 0.9858
# Epoch 13/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0231 - accuracy: 0.9913 - val_loss: 0.1500 - val_accuracy: 0.9651
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0549 - val_accuracy: 0.9858
# Epoch 15/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0543 - val_accuracy: 0.9884
# Epoch 16/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0534 - val_accuracy: 0.9897
# Epoch 17/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 0.9897
# Epoch 18/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0498 - val_accuracy: 0.9897
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0501 - val_accuracy: 0.9884
# Epoch 20/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0481 - val_accuracy: 0.9884
# Epoch 21/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0478 - val_accuracy: 0.9897
# Epoch 22/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.0481 - val_accuracy: 0.9897
# Epoch 23/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.0492 - val_accuracy: 0.9909
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 24/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.0490 - val_accuracy: 0.9909
# Epoch 25/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0488 - val_accuracy: 0.9909
# Epoch 26/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0486 - val_accuracy: 0.9909
# Epoch 27/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0484 - val_accuracy: 0.9909
# Epoch 28/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9909
# Epoch 29/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9909
# Epoch 30/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9897
# Epoch 31/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 0.9909
# Epoch 32/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0480 - val_accuracy: 0.9909
# Epoch 33/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9909
# Epoch 34/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0478 - val_accuracy: 0.9909
# Epoch 35/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0477 - val_accuracy: 0.9909
# Epoch 36/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0483 - val_accuracy: 0.9909
# Epoch 37/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0481 - val_accuracy: 0.9909
# Epoch 38/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9909
# Epoch 39/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 0.9909
# Epoch 40/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0477 - val_accuracy: 0.9909
# Epoch 41/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 0.9909
# Epoch 42/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0458 - val_accuracy: 0.9897
# Epoch 43/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0459 - val_accuracy: 0.9897
# Epoch 44/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9897
# Epoch 45/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9897
# Epoch 46/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9897
# Epoch 47/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0465 - val_accuracy: 0.9897
# Epoch 48/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 0.9897
# Epoch 49/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0459 - val_accuracy: 0.9897
# Epoch 50/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 0.9897
# Epoch 51/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0450 - val_accuracy: 0.9897
# Epoch 52/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9897
# Epoch 53/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0456 - val_accuracy: 0.9897
# Epoch 54/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9897
# Epoch 55/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0457 - val_accuracy: 0.9909
# Epoch 56/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0458 - val_accuracy: 0.9909
# Epoch 57/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0453 - val_accuracy: 0.9909
# Epoch 58/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0449 - val_accuracy: 0.9909
# Epoch 59/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9909
# Epoch 60/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9909
# Epoch 61/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0437 - val_accuracy: 0.9935
# Epoch 62/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9922
# Epoch 63/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.8805e-04 - accuracy: 1.0000 - val_loss: 0.0442 - val_accuracy: 0.9922
# Epoch 64/2000
# 97/97 [==============================] - 211s 2s/step - loss: 8.2344e-04 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9922
# Epoch 65/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0453 - val_accuracy: 0.9922
# Epoch 66/2000
# 97/97 [==============================] - 211s 2s/step - loss: 8.9748e-04 - accuracy: 1.0000 - val_loss: 0.0457 - val_accuracy: 0.9922
# Epoch 67/2000
# 97/97 [==============================] - 211s 2s/step - loss: 8.9835e-04 - accuracy: 1.0000 - val_loss: 0.0447 - val_accuracy: 0.9922
# Epoch 68/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9922
# Epoch 69/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0423 - val_accuracy: 0.9922
# Epoch 70/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0415 - val_accuracy: 0.9922
# Epoch 71/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9922
# Epoch 72/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.6073e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9922
# Epoch 73/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9909
# Epoch 74/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.4386e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9909
# Epoch 75/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0430 - val_accuracy: 0.9922
# Epoch 76/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9922
# Epoch 77/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.7497e-04 - accuracy: 1.0000 - val_loss: 0.0437 - val_accuracy: 0.9922
# Epoch 78/2000
# 97/97 [==============================] - 211s 2s/step - loss: 8.3266e-04 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9922
# Epoch 79/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.9953e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9922
# Epoch 80/2000
# 97/97 [==============================] - 211s 2s/step - loss: 6.6215e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9922
# Epoch 81/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9935
# Epoch 82/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.9610e-04 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 0.9935
# Epoch 83/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0438 - val_accuracy: 0.9922
# Epoch 84/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.6470e-04 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9922
# Epoch 85/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0437 - val_accuracy: 0.9922
# Epoch 86/2000
# 97/97 [==============================] - 211s 2s/step - loss: 7.1077e-04 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 0.9922
# Epoch 87/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.8503e-04 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9922
# Epoch 88/2000
# 97/97 [==============================] - 211s 2s/step - loss: 8.9133e-04 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9922
# Epoch 89/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.1919e-04 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9922
# Epoch 90/2000
# 97/97 [==============================] - 211s 2s/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.0446 - val_accuracy: 0.9935
# Epoch 91/2000
# 97/97 [==============================] - 210s 2s/step - loss: 8.3919e-04 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 0.9922
# Epoch 92/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.3526e-04 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9922
# Epoch 93/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.6338e-04 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 0.9922
# Epoch 94/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.7344e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9935
# Epoch 95/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.2917e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9935
# Epoch 96/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0396 - val_accuracy: 0.9922
# Epoch 97/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0417 - val_accuracy: 0.9935
# Epoch 98/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.9702e-04 - accuracy: 0.9997 - val_loss: 0.0419 - val_accuracy: 0.9922
# Epoch 99/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0411 - val_accuracy: 0.9922
# Epoch 100/2000
# 97/97 [==============================] - 210s 2s/step - loss: 8.2418e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9935
# Epoch 101/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.9328e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9935
# Epoch 102/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9922
# Epoch 103/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.5398e-04 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9922
# Epoch 104/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.2533e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9922
# Epoch 105/2000
# 97/97 [==============================] - 210s 2s/step - loss: 8.6211e-04 - accuracy: 0.9997 - val_loss: 0.0412 - val_accuracy: 0.9935
# Epoch 106/2000
# 97/97 [==============================] - 210s 2s/step - loss: 8.1481e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9935
# Epoch 107/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.8937e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9935
# Epoch 108/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9935
# Epoch 109/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.4729e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9935
# Epoch 110/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.9283e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9935
# Epoch 111/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.8887e-04 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9935
# Epoch 112/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.4754e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9948
# Epoch 113/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.3844e-04 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9935
# Epoch 114/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.6273e-04 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 115/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.7814e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9935
# Epoch 116/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.8485e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9935
# Epoch 117/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.7127e-04 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9935
# Epoch 118/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.4514e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9935
# Epoch 119/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.1675e-04 - accuracy: 0.9997 - val_loss: 0.0407 - val_accuracy: 0.9935
# Epoch 120/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.9915e-04 - accuracy: 0.9997 - val_loss: 0.0396 - val_accuracy: 0.9935
# Epoch 121/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.7936e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9948
# Epoch 122/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.8204e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9948
# Epoch 123/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0401 - val_accuracy: 0.9948
# Epoch 124/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.5918e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9948
# Epoch 125/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.6106e-04 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9922
# Epoch 126/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.9944e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9935
# Epoch 127/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.8604e-04 - accuracy: 0.9997 - val_loss: 0.0415 - val_accuracy: 0.9935
# Epoch 128/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.9193e-04 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9935
# Epoch 129/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.4555e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9935
# Epoch 130/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.4200e-04 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 131/2000
# 97/97 [==============================] - 210s 2s/step - loss: 8.2619e-04 - accuracy: 0.9997 - val_loss: 0.0407 - val_accuracy: 0.9948
# Epoch 132/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.1651e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9935
# Epoch 133/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.8540e-04 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9935
# Epoch 134/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.9765e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9935
# Epoch 135/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.8776e-04 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9935
# Epoch 136/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.5978e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9935
# Epoch 137/2000
# 97/97 [==============================] - 210s 2s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0383 - val_accuracy: 0.9935
# Epoch 138/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.1240e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9935
# Epoch 139/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.2024e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9935
# Epoch 140/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.1283e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9935
# Epoch 141/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.0958e-04 - accuracy: 0.9997 - val_loss: 0.0390 - val_accuracy: 0.9935
# Epoch 142/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.7487e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9935
# Epoch 143/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.5858e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9935
# Epoch 144/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.2216e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9935
# Epoch 145/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.5039e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9935
# Epoch 146/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.4320e-04 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9935
# Epoch 147/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.7248e-04 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9948
# Epoch 148/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.3523e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9922
# Epoch 149/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.5990e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 150/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.6896e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9922
# Epoch 151/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.6051e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9948
# Epoch 152/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.2770e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9935
# Epoch 153/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.9483e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9948
# Epoch 154/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.2083e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9948
# Epoch 155/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.4630e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 156/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.5569e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 157/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.5067e-04 - accuracy: 0.9997 - val_loss: 0.0382 - val_accuracy: 0.9935
# Epoch 158/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.6615e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9935
# Epoch 159/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.7023e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9935
# Epoch 160/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.1937e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9935
# Epoch 161/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.7520e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9935
# Epoch 162/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.9768e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9948
# Epoch 163/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.7149e-04 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9948
# Epoch 164/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.6685e-04 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9948
# Epoch 165/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.7786e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9948
# Epoch 166/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.8814e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 167/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.7798e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9948
# Epoch 168/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.1951e-04 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 169/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.7102e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9948
# Epoch 170/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.9424e-04 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9948
# Epoch 171/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.7414e-04 - accuracy: 0.9997 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 172/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.8978e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9948
# Epoch 173/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.3441e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9948
# Epoch 174/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.1581e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 175/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.0541e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 176/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.3505e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9948
# Epoch 177/2000
# 97/97 [==============================] - 210s 2s/step - loss: 6.2963e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9948
# Epoch 178/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.8586e-04 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9948
# Epoch 179/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.7951e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9948
# Epoch 180/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.1691e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9948
# Epoch 181/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.9108e-04 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9948
# Epoch 182/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.7456e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9948
# Epoch 183/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.1123e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9948
# Epoch 184/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.1583e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9948
# Epoch 185/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.9376e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9948
# Epoch 186/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.4819e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9948
# Epoch 187/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.0140e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9948
# Epoch 188/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.0273e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9948
# Epoch 189/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.5553e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 190/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.7827e-04 - accuracy: 0.9997 - val_loss: 0.0359 - val_accuracy: 0.9935
# Epoch 191/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.4987e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9935
# Epoch 192/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6887e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9935
# Epoch 193/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.7761e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9935
# Epoch 194/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.4905e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9935
# Epoch 195/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.1011e-04 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9948
# Epoch 196/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.0342e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 197/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.3417e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9948
# Epoch 198/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.3946e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9948
# Epoch 199/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.9395e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9948
# Epoch 200/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1185e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9948
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.2528e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9948
# Epoch 202/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.0103e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9948
# Epoch 203/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.7686e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9948
# Epoch 204/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6883e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9948
# Epoch 205/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6636e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9948
# Epoch 206/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.9014e-04 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9948
# Epoch 207/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.3713e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9948
# Epoch 208/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.4995e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9948
# Epoch 209/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.5524e-04 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9948
# Epoch 210/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6335e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 211/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.9056e-04 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9935
# Epoch 212/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1293e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9935
# Epoch 213/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.6472e-04 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9935
# Epoch 214/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6711e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9935
# Epoch 215/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2755e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9935
# Epoch 216/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.0339e-04 - accuracy: 1.0000 - val_loss: 0.0390 - val_accuracy: 0.9935
# Epoch 217/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.4804e-04 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9948
# Epoch 218/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.5461e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9948
# Epoch 219/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.7493e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9948
# Epoch 220/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.8682e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9948
# Epoch 221/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.5449e-04 - accuracy: 0.9997 - val_loss: 0.0386 - val_accuracy: 0.9948
# Epoch 222/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.2026e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9948
# Epoch 223/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6863e-04 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9948
# Epoch 224/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.5660e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 225/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2671e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 226/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.7538e-04 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9935
# Epoch 227/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.8587e-04 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9935
# Epoch 228/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.4828e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9935
# Epoch 229/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.1194e-04 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9935
# Epoch 230/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.4164e-04 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9935
# Epoch 231/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.5011e-04 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9935
# Epoch 232/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.9485e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 233/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.3964e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9922
# Epoch 234/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2861e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9922
# Epoch 235/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2438e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9922
# Epoch 236/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2247e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9922
# Epoch 237/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.3749e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9935
# Epoch 238/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.0210e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9935
# Epoch 239/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.0051e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9935
# Epoch 240/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.6463e-04 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 0.9935
# Epoch 241/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.7455e-04 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9935
# Epoch 242/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.8162e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9948
# Epoch 243/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.3070e-04 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9948
# Epoch 244/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.4131e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9948
# Epoch 245/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.4384e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9948
# Epoch 246/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6032e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9948
# Epoch 247/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.4009e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9948
# Epoch 248/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.9692e-04 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9948
# Epoch 249/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6037e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9948
# Epoch 250/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6102e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9935
# Epoch 251/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.8223e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9948
# Epoch 252/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9977e-04 - accuracy: 1.0000 - val_loss: 0.0377 - val_accuracy: 0.9948
# Epoch 253/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.7848e-04 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9948
# Epoch 254/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6771e-04 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 0.9948
# Epoch 255/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2959e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9948
# Epoch 256/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.3746e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9948
# Epoch 257/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1901e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9948
# Epoch 258/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.8455e-04 - accuracy: 0.9997 - val_loss: 0.0374 - val_accuracy: 0.9948
# Epoch 259/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.3964e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9948
# Epoch 260/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.0063e-04 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9935
# Epoch 261/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.0309e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9935
# Epoch 262/2000
# 97/97 [==============================] - 210s 2s/step - loss: 5.3958e-04 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9935
# Epoch 263/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9864e-04 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.9935
# Epoch 264/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.0275e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9935
# Epoch 265/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.0360e-04 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.9935
# Epoch 266/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.6740e-04 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9935
# Epoch 267/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.9421e-04 - accuracy: 1.0000 - val_loss: 0.0353 - val_accuracy: 0.9935
# Epoch 268/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6251e-04 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9935
# Epoch 269/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6259e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9935
# Epoch 270/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.1422e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9935
# Epoch 271/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.8257e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9935
# Epoch 272/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.7325e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9935
# Epoch 273/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9306e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9935
# Epoch 274/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6781e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9935
# Epoch 275/2000
# 97/97 [==============================] - 210s 2s/step - loss: 7.0328e-04 - accuracy: 0.9997 - val_loss: 0.0356 - val_accuracy: 0.9935
# Epoch 276/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.4949e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9935
# Epoch 277/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.2250e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9935
# Epoch 278/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9158e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9935
# Epoch 279/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.5222e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9935
# Epoch 280/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.9039e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9935
# Epoch 281/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.0710e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9935
# Epoch 282/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.3721e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9922
# Epoch 283/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.4596e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9922
# Epoch 284/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.8076e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9922
# Epoch 285/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.0043e-04 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 0.9922
# Epoch 286/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.8053e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9935
# Epoch 287/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6120e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9922
# Epoch 288/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.5043e-04 - accuracy: 1.0000 - val_loss: 0.0369 - val_accuracy: 0.9935
# Epoch 289/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.7658e-04 - accuracy: 1.0000 - val_loss: 0.0373 - val_accuracy: 0.9948
# Epoch 290/2000
# 97/97 [==============================] - 210s 2s/step - loss: 9.6476e-04 - accuracy: 0.9997 - val_loss: 0.0372 - val_accuracy: 0.9948
# Epoch 291/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.4136e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9948
# Epoch 292/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9189e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9948
# Epoch 293/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9126e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9935
# Epoch 294/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6841e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9935
# Epoch 295/2000
# 97/97 [==============================] - 210s 2s/step - loss: 4.3014e-04 - accuracy: 0.9997 - val_loss: 0.0361 - val_accuracy: 0.9935
# Epoch 296/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.4541e-04 - accuracy: 1.0000 - val_loss: 0.0363 - val_accuracy: 0.9935
# Epoch 297/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6761e-04 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 0.9935
# Epoch 298/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.3881e-04 - accuracy: 1.0000 - val_loss: 0.0370 - val_accuracy: 0.9948
# Epoch 299/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1064e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9935
# Epoch 300/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.7803e-04 - accuracy: 1.0000 - val_loss: 0.0357 - val_accuracy: 0.9935
# Epoch 301/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1367e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9935
# Epoch 302/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1993e-04 - accuracy: 1.0000 - val_loss: 0.0354 - val_accuracy: 0.9935
# Epoch 303/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.4491e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9948
# Epoch 304/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.2914e-04 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9948
# Epoch 305/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.6719e-04 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9948
# Epoch 306/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.3517e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9948
# Epoch 307/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.9704e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9948
# Epoch 308/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.6406e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9948
# Epoch 309/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.3550e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9948
# Epoch 310/2000
# 97/97 [==============================] - 210s 2s/step - loss: 3.5563e-04 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 0.9948
# Epoch 311/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.5993e-04 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9948
# Epoch 312/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.2242e-04 - accuracy: 1.0000 - val_loss: 0.0388 - val_accuracy: 0.9948
# Epoch 313/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.1138e-04 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9948
# Epoch 314/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.1565e-04 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9948
# Epoch 315/2000
# 97/97 [==============================] - 210s 2s/step - loss: 2.3606e-04 - accuracy: 1.0000 - val_loss: 0.0379 - val_accuracy: 0.9948
# Epoch 316/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.8324e-04 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9948
# Epoch 317/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.2536e-04 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9948
# Epoch 318/2000
# 97/97 [==============================] - 210s 2s/step - loss: 1.7894e-04 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9948
# Epoch 319/2000
# ...
# 97/97 [==============================] - 211s 2s/step - loss: 5.3507e-06 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9948
# Epoch 1899/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.2223e-06 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9948
# Epoch 1900/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.9620e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1901/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.9320e-06 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9948
# Epoch 1902/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.7400e-06 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9948
# Epoch 1903/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.0598e-06 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 0.9948
# Epoch 1904/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.3367e-06 - accuracy: 1.0000 - val_loss: 0.0404 - val_accuracy: 0.9948
# Epoch 1905/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.4796e-06 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 0.9948
# Epoch 1906/2000
# 97/97 [==============================] - 212s 2s/step - loss: 2.4821e-06 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9948
# Epoch 1907/2000
# 97/97 [==============================] - 211s 2s/step - loss: 6.0365e-06 - accuracy: 1.0000 - val_loss: 0.0384 - val_accuracy: 0.9948
# Epoch 1908/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.8025e-06 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9948
# Epoch 1909/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.5581e-06 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9948
# Epoch 1910/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.3135e-06 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9948
# Epoch 1911/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.7156e-05 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9948
# Epoch 1912/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.8730e-04 - accuracy: 0.9997 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 1913/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.8315e-06 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9948
# Epoch 1914/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.7185e-06 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9948
# Epoch 1915/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.9264e-06 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9948
# Epoch 1916/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.7121e-06 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9948
# Epoch 1917/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.1709e-06 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 1918/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.3509e-06 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 1919/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.7715e-06 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9948
# Epoch 1920/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.6406e-06 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 0.9948
# Epoch 1921/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.1143e-06 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 1922/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.9363e-06 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 1923/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.9277e-06 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 0.9948
# Epoch 1924/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.7621e-06 - accuracy: 1.0000 - val_loss: 0.0399 - val_accuracy: 0.9948
# Epoch 1925/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.9029e-06 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9948
# Epoch 1926/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.5873e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9948
# Epoch 1927/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.1780e-06 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9948
# Epoch 1928/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.9470e-06 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9948
# Epoch 1929/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.5974e-05 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 0.9948
# Epoch 1930/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.1711e-06 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 1931/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.3442e-06 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9948
# Epoch 1932/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.9471e-06 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9948
# Epoch 1933/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.0460e-06 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9948
# Epoch 1934/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.1271e-06 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9948
# Epoch 1935/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.3828e-06 - accuracy: 1.0000 - val_loss: 0.0395 - val_accuracy: 0.9948
# Epoch 1936/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.7354e-06 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9948
# Epoch 1937/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.9775e-06 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9948
# Epoch 1938/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.4182e-06 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 0.9948
# Epoch 1939/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.1014e-06 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9948
# Epoch 1940/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.8449e-06 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 1941/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.6976e-06 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 0.9948
# Epoch 1942/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.6751e-06 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9948
# Epoch 1943/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.2583e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9948
# Epoch 1944/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.0545e-06 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9948
# Epoch 1945/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.1201e-06 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9948
# Epoch 1946/2000
# 97/97 [==============================] - 212s 2s/step - loss: 5.0802e-05 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9948
# Epoch 1947/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.1700e-05 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9948
# Epoch 1948/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.5352e-05 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 0.9948
# Epoch 1949/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.5724e-06 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9948
# Epoch 1950/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.9657e-06 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9948
# Epoch 1951/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.0328e-06 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 0.9948
# Epoch 1952/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.7752e-06 - accuracy: 1.0000 - val_loss: 0.0407 - val_accuracy: 0.9948
# Epoch 1953/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.8757e-06 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9948
# Epoch 1954/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.5151e-06 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9948
# Epoch 1955/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.5818e-06 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9948
# Epoch 1956/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.2907e-06 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9948
# Epoch 1957/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.5668e-06 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9948
# Epoch 1958/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.6130e-06 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9948
# Epoch 1959/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.5112e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1960/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.1779e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1961/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.9850e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1962/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.3340e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1963/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.2254e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1964/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.3361e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1965/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.8932e-06 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9948
# Epoch 1966/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.8641e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1967/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.3657e-05 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9948
# Epoch 1968/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.2624e-06 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9948
# Epoch 1969/2000
# 97/97 [==============================] - 211s 2s/step - loss: 9.2134e-06 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 0.9948
# Epoch 1970/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.2679e-05 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1971/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.8416e-06 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9948
# Epoch 1972/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.9856e-06 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9948
# Epoch 1973/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.7593e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1974/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.9780e-06 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9948
# Epoch 1975/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.3741e-06 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9948
# Epoch 1976/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.6892e-06 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9948
# Epoch 1977/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.2971e-06 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9948
# Epoch 1978/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.4737e-06 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 0.9948
# Epoch 1979/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.0311e-06 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9948
# Epoch 1980/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.5496e-05 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9948
# Epoch 1981/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.4317e-06 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 0.9948
# Epoch 1982/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.9218e-05 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9948
# Epoch 1983/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.0837e-06 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9948
# Epoch 1984/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.2216e-06 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9948
# Epoch 1985/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.5966e-06 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9948
# Epoch 1986/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.8334e-06 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9948
# Epoch 1987/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.2133e-06 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9948
# Epoch 1988/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.5831e-06 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9948
# Epoch 1989/2000
# 97/97 [==============================] - 211s 2s/step - loss: 1.6297e-05 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9948
# Epoch 1990/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.5365e-06 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9948
# Epoch 1991/2000
# 97/97 [==============================] - 211s 2s/step - loss: 7.0377e-06 - accuracy: 1.0000 - val_loss: 0.0425 - val_accuracy: 0.9948
# Epoch 1992/2000
# 97/97 [==============================] - 212s 2s/step - loss: 7.0046e-06 - accuracy: 1.0000 - val_loss: 0.0426 - val_accuracy: 0.9948
# Epoch 1993/2000
# 97/97 [==============================] - 212s 2s/step - loss: 3.8227e-06 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9948
# Epoch 1994/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.5465e-06 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9948
# Epoch 1995/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.1495e-06 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 0.9948
# Epoch 1996/2000
# 97/97 [==============================] - 211s 2s/step - loss: 5.1915e-06 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 1997/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.0441e-06 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9948
# Epoch 1998/2000
# 97/97 [==============================] - 211s 2s/step - loss: 4.8564e-06 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9948
# Epoch 1999/2000
# 97/97 [==============================] - 211s 2s/step - loss: 2.0716e-06 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9948
# Epoch 2000/2000
# 97/97 [==============================] - 211s 2s/step - loss: 3.0137e-06 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9948
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 57/57 [==============================] - 100s 2s/step - loss: 0.3976 - accuracy: 0.9376
# test_indoor_ds_results:test loss, test acc: [0.3976105749607086, 0.9375696778297424]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 99/99 [==============================] - 174s 2s/step - loss: 0.5712 - accuracy: 0.8882
# test_outdoor_ds_results:test loss, test acc: [0.5711514353752136, 0.8882165551185608]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 69/69 [==============================] - 122s 2s/step - loss: 1.4821 - accuracy: 0.7738
# test_belt_ds_results:test loss, test acc: [1.4821045398712158, 0.7737987041473389]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB7_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_229392) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1d_activation_layer_call_and_return_conditional_losses_230300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_253892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_146069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_expand_activation_layer_call_and_return_conditional_losses_256690) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_expand_activation_layer_call_and_return_conditional_losses_260285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_142849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_expand_activation_layer_call_and_return_conditional_losses_244015) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_expand_activation_layer_call_and_return_conditional_losses_146873) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_expand_activation_layer_call_and_return_conditional_losses_257297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_145397) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_142493) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_137596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_254262) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_236927) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_144633) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_229051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_activation_layer_call_and_return_conditional_losses_244793) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_140227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_240373) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_222427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_se_reduce_layer_call_and_return_conditional_losses_244252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_activation_layer_call_and_return_conditional_losses_141795) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_241217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_139156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_230995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_145529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_138616) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_expand_activation_layer_call_and_return_conditional_losses_146201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_expand_activation_layer_call_and_return_conditional_losses_141520) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_activation_layer_call_and_return_conditional_losses_249602) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_se_reduce_layer_call_and_return_conditional_losses_138044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_activation_layer_call_and_return_conditional_losses_256861) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_activation_layer_call_and_return_conditional_losses_138227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_expand_activation_layer_call_and_return_conditional_losses_250038) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1c_se_reduce_layer_call_and_return_conditional_losses_229912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_activation_layer_call_and_return_conditional_losses_137779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_expand_activation_layer_call_and_return_conditional_losses_143969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_se_reduce_layer_call_and_return_conditional_losses_141612) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_236756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_140400) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_255106) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_140268) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_se_reduce_layer_call_and_return_conditional_losses_141388) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_se_reduce_layer_call_and_return_conditional_losses_243645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_activation_layer_call_and_return_conditional_losses_147148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_expand_activation_layer_call_and_return_conditional_losses_146425) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_147372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_136939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_142676) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_237363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_138400) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_activation_layer_call_and_return_conditional_losses_238141) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_144949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_145621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_expand_activation_layer_call_and_return_conditional_losses_141744) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_activation_layer_call_and_return_conditional_losses_139787) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_activation_layer_call_and_return_conditional_losses_233917) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_253285) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_240544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_expand_activation_layer_call_and_return_conditional_losses_144193) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_144725) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_231555) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_140675) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_143389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1c_activation_layer_call_and_return_conditional_losses_229846) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_230736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_136160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_136201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_261499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_se_reduce_layer_call_and_return_conditional_losses_146293) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_231925) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_246026) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_142401) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_activation_layer_call_and_return_conditional_losses_256254) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_236149) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_140940) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_255040) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_235713) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_235779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_se_reduce_layer_call_and_return_conditional_losses_144061) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_141123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_228559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_248454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_se_reduce_layer_call_and_return_conditional_losses_137820) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_140059) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_144857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_expand_activation_layer_call_and_return_conditional_losses_147754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_232096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_259678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_245960) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_145305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_254499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_140848) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_142717) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_251511) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_145804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_246567) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_246633) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_expand_activation_layer_call_and_return_conditional_losses_243408) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1d_activation_layer_call_and_return_conditional_losses_136667) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_140899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1c_se_reduce_layer_call_and_return_conditional_losses_136534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_254433) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_activation_layer_call_and_return_conditional_losses_234524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_251252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_252612) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_229458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_142900) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_se_reduce_layer_call_and_return_conditional_losses_258748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_se_reduce_layer_call_and_return_conditional_losses_146517) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_228814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_activation_layer_call_and_return_conditional_losses_146252) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_138458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_activation_layer_call_and_return_conditional_losses_138003) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_142192) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_212857) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_145580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_139288) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_232703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_activation_layer_call_and_return_conditional_losses_142019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_231489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_se_reduce_layer_call_and_return_conditional_losses_143837) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_145977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_145845) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_246396) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_252071) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_activation_layer_call_and_return_conditional_losses_248995) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_253655) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_activation_layer_call_and_return_conditional_losses_143572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_se_reduce_layer_call_and_return_conditional_losses_141836) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_activation_layer_call_and_return_conditional_losses_144020) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_242365) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_259915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_expand_activation_layer_call_and_return_conditional_losses_139736) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_expand_activation_layer_call_and_return_conditional_losses_141968) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_240980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_activation_layer_call_and_return_conditional_losses_139563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_147530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_143297) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_145132) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_se_reduce_layer_call_and_return_conditional_losses_237600) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_se_reduce_layer_call_and_return_conditional_losses_250275) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_235219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_255713) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_240610) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_se_reduce_layer_call_and_return_conditional_losses_233376) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_242194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_expand_activation_layer_call_and_return_conditional_losses_248824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_236386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_expand_activation_layer_call_and_return_conditional_losses_137952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_231318) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_140176) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_138840) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_activation_layer_call_and_return_conditional_losses_237534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_259118) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_146965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_148202) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_137372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_145753) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_activation_layer_call_and_return_conditional_losses_233310) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_245229) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_expand_activation_layer_call_and_return_conditional_losses_139512) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_expand_activation_layer_call_and_return_conditional_losses_137728) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_228985) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_expand_activation_layer_call_and_return_conditional_losses_256083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_144908) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_239766) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_expand_activation_layer_call_and_return_conditional_losses_260892) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_251834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_140492) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_136360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_activation_layer_call_and_return_conditional_losses_243579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_141164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_140451) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_248217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_se_reduce_layer_call_and_return_conditional_losses_256320) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_255476) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_252678) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_259355) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_112158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_247240) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_232162) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_se_reduce_layer_call_and_return_conditional_losses_146741) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_140018) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_147622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_136898) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_activation_layer_call_and_return_conditional_losses_250209) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_241824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_206703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_143165) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_236993) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_259289) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_se_reduce_layer_call_and_return_conditional_losses_249061) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_expand_activation_layer_call_and_return_conditional_losses_244622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_139960) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_expand_activation_layer_call_and_return_conditional_losses_138176) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_239377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_se_reduce_layer_call_and_return_conditional_losses_250882) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_143348) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_138499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_se_reduce_layer_call_and_return_conditional_losses_260522) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_230929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_142243) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_activation_layer_call_and_return_conditional_losses_242972) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_147413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_activation_layer_call_and_return_conditional_losses_238748) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_145356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_se_reduce_layer_call_and_return_conditional_losses_142060) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_259849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_expand_activation_layer_call_and_return_conditional_losses_237970) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_activation_layer_call_and_return_conditional_losses_141347) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_245789) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_136319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_141072) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_241151) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_activation_layer_call_and_return_conditional_losses_144244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_145081) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_activation_layer_call_and_return_conditional_losses_258075) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_138708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1d_se_reduce_layer_call_and_return_conditional_losses_136708) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_235153) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_247174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_expand_activation_layer_call_and_return_conditional_losses_250645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_se_reduce_layer_call_and_return_conditional_losses_238814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_se_reduce_layer_call_and_return_conditional_losses_147189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_239443) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_se_reduce_layer_call_and_return_conditional_losses_148070) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_239937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_se_reduce_layer_call_and_return_conditional_losses_244859) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_241587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_activation_layer_call_and_return_conditional_losses_146924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_253219) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_se_reduce_layer_call_and_return_conditional_losses_233983) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_251445) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_241758) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_se_reduce_layer_call_and_return_conditional_losses_234590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_expand_activation_layer_call_and_return_conditional_losses_143745) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block6i_expand_activation_layer_call_and_return_conditional_losses_2108500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_expand_activation_layer_call_and_return_conditional_losses_2100475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_expand_activation_layer_call_and_return_conditional_losses_2218989) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_2099671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_2105688) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_2101587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_2107207) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_2107156) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_activation_layer_call_and_return_conditional_losses_2108775) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_activation_layer_call_and_return_conditional_losses_2201047) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_activation_layer_call_and_return_conditional_losses_2196216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2109712) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_2204664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_2201742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_se_reduce_layer_call_and_return_conditional_losses_2199899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_2098618) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_2110501) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_2202843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_se_reduce_layer_call_and_return_conditional_losses_2108816) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_activation_layer_call_and_return_conditional_losses_2200440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_2214133) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2221654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_expand_activation_layer_call_and_return_conditional_losses_2196652) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_2209302) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_2101414) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_expand_activation_layer_call_and_return_conditional_losses_2110053) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_2209539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_2214977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_2204730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_2199292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_2105372) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_2105647) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_2098659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_2194395) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_2108276) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_2103371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_2109829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_se_reduce_layer_call_and_return_conditional_losses_2110145) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_2074457) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_2208695) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_2107024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_expand_activation_layer_call_and_return_conditional_losses_2212944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_2108144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_2099447) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_2107879) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_se_reduce_layer_call_and_return_conditional_losses_2211967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_2193035) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_se_reduce_layer_call_and_return_conditional_losses_2219833) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_activation_layer_call_and_return_conditional_losses_2109223) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_2220440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_expand_activation_layer_call_and_return_conditional_losses_2103819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_2209473) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_2203279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_2199662) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_2201676) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_2099803) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_activation_layer_call_and_return_conditional_losses_2219160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_2215584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_activation_layer_call_and_return_conditional_losses_2100526) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_2106932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_2201483) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_2217946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_2101231) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_2109264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_2216125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_2104583) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_2105016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_2214740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_2103463) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_2197518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_2208932) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_expand_activation_layer_call_and_return_conditional_losses_2211730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_2099854) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_2108103) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_2213810) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_2216561) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_activation_layer_call_and_return_conditional_losses_2222755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 57/57 [==============================] - 101s 2s/step - loss: 0.3976 - accuracy: 0.9376
# 99/99 [==============================] - 170s 2s/step - loss: 0.5712 - accuracy: 0.8882
# 69/69 [==============================] - 119s 2s/step - loss: 1.4821 - accuracy: 0.7738
# Epoch2000
#  test_indoor_acc=0.9375696778297424
#  test_outdoor_acc=0.8882165551185608
#  test_belt_acc=0.7737987041473389

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8670548995335897
# max index -> 8
# The [Epoch] of max acc -> 1800

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.9264214038848877,
#  0.928093671798706,
#  0.9308807253837585,
#  0.933667778968811,
#  0.9358974099159241,
#  0.9342252016067505,
#  0.9358974099159241,
#  0.933667778968811,
#  0.9386845231056213,
#  0.9375696778297424]

# %%
test_outdoor_acc
# Out:
# [0.8786624073982239,
#  0.8863057494163513,
#  0.8882165551185608,
#  0.8888534903526306,
#  0.8882165551185608,
#  0.8891719579696655,
#  0.8920382261276245,
#  0.8882165551185608,
#  0.8914012908935547,
#  0.8882165551185608]

# %%
test_belt_acc
# Out:
# [0.7615593671798706,
#  0.7674524188041687,
#  0.768812358379364,
#  0.7683590054512024,
#  0.768812358379364,
#  0.7760652899742126,
#  0.7724388241767883,
#  0.7706255912780762,
#  0.771078884601593,
#  0.7737987041473389]

# %%
test_indoor_loss
# Out:
# [0.3637802004814148,
#  0.3621405065059662,
#  0.37157803773880005,
#  0.3905397355556488,
#  0.3803381323814392,
#  0.39670056104660034,
#  0.409707635641098,
#  0.40336474776268005,
#  0.40761181712150574,
#  0.3976105749607086]

# %%
test_outdoor_loss
# Out:
# [0.5037822723388672,
#  0.4948079288005829,
#  0.5085612535476685,
#  0.5198873281478882,
#  0.529297947883606,
#  0.5458501577377319,
#  0.5487798452377319,
#  0.5707913041114807,
#  0.5609510540962219,
#  0.5711514353752136]

# %%
test_belt_loss
# Out:
# [1.158370018005371,
#  1.226511001586914,
#  1.2775431871414185,
#  1.3268173933029175,
#  1.3559504747390747,
#  1.3741787672042847,
#  1.4270552396774292,
#  1.4435462951660156,
#  1.4960732460021973,
#  1.4821045398712158]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=600
img_width=600
batch_size=1

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 1000
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1889343) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_1890066) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_activation_layer_call_and_return_conditional_losses_1883601) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1888946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_se_reduce_layer_call_and_return_conditional_losses_2003010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_se_reduce_layer_call_and_return_conditional_losses_2001189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1998761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_se_reduce_layer_call_and_return_conditional_losses_1887875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_se_reduce_layer_call_and_return_conditional_losses_1977638) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1884662) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_activation_layer_call_and_return_conditional_losses_1982403) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_activation_layer_call_and_return_conditional_losses_1882041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1888679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1985242) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_1891227) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_1881858) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1950965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_1885426) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_1981255) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1998695) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_activation_layer_call_and_return_conditional_losses_2001730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1889435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1880622) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1887111) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_expand_activation_layer_call_and_return_conditional_losses_1890911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_expand_activation_layer_call_and_return_conditional_losses_1982232) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1973654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1889883) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1881318) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_se_reduce_layer_call_and_return_conditional_losses_1888099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1976358) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1984265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1997917) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_1887559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_1890331) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_1890015) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1973247) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1980648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1975257) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_activation_layer_call_and_return_conditional_losses_1884049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_expand_activation_layer_call_and_return_conditional_losses_1987063) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_expand_activation_layer_call_and_return_conditional_losses_1993086) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_expand_activation_layer_call_and_return_conditional_losses_1978008) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1985479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_se_reduce_layer_call_and_return_conditional_losses_1993323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1889567) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1886505) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1998524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1889842) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_activation_layer_call_and_return_conditional_losses_1890514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1891675) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_se_reduce_layer_call_and_return_conditional_losses_2002403) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1888778) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_se_reduce_layer_call_and_return_conditional_losses_1891451) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1995514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1983446) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_activation_layer_call_and_return_conditional_losses_2001123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1983705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_activation_layer_call_and_return_conditional_losses_2000516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1996096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_expand_activation_layer_call_and_return_conditional_losses_1886006) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1882929) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1984028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_se_reduce_layer_call_and_return_conditional_losses_1882306) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_se_reduce_layer_call_and_return_conditional_losses_1981862) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1882970) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_activation_layer_call_and_return_conditional_losses_1886281) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_se_reduce_layer_call_and_return_conditional_losses_1986693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1c_se_reduce_layer_call_and_return_conditional_losses_1974174) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_2004111) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_activation_layer_call_and_return_conditional_losses_1987234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_se_reduce_layer_call_and_return_conditional_losses_2005391) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_se_reduce_layer_call_and_return_conditional_losses_1888323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_expand_activation_layer_call_and_return_conditional_losses_1888231) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1884886) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1990829) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_se_reduce_layer_call_and_return_conditional_losses_1886098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_2004177) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1991436) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_expand_activation_layer_call_and_return_conditional_losses_1977401) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1991872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_expand_activation_layer_call_and_return_conditional_losses_1994300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1991265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1883102) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1980411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_se_reduce_layer_call_and_return_conditional_losses_1885650) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_se_reduce_layer_call_and_return_conditional_losses_1883418) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_se_reduce_layer_call_and_return_conditional_losses_1999975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_activation_layer_call_and_return_conditional_losses_1999302) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_se_reduce_layer_call_and_return_conditional_losses_1882530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_se_reduce_layer_call_and_return_conditional_losses_1884090) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_expand_activation_layer_call_and_return_conditional_losses_2002166) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_activation_layer_call_and_return_conditional_losses_1888282) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1995707) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_activation_layer_call_and_return_conditional_losses_1989055) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_se_reduce_layer_call_and_return_conditional_losses_1888547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_1890239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_se_reduce_layer_call_and_return_conditional_losses_1993930) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_activation_layer_call_and_return_conditional_losses_1890738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1884937) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_expand_activation_layer_call_and_return_conditional_losses_1987670) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1984806) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1975580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1983639) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_expand_activation_layer_call_and_return_conditional_losses_2001559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1995773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1979975) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_activation_layer_call_and_return_conditional_losses_1892291) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1d_activation_layer_call_and_return_conditional_losses_1974562) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1997481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_activation_layer_call_and_return_conditional_losses_1882265) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_2003617) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1886546) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_2003940) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_expand_activation_layer_call_and_return_conditional_losses_2004547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_activation_layer_call_and_return_conditional_losses_2004718) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1886663) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1980582) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1990895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_activation_layer_call_and_return_conditional_losses_1983010) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1c_activation_layer_call_and_return_conditional_losses_1880755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1975191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1891884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1886938) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1996940) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_2005761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1887162) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1973076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_expand_activation_layer_call_and_return_conditional_losses_1882214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1880422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_expand_activation_layer_call_and_return_conditional_losses_2000952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_expand_activation_layer_call_and_return_conditional_losses_1883998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1996703) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1976424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_activation_layer_call_and_return_conditional_losses_1885609) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_se_reduce_layer_call_and_return_conditional_losses_1989121) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1887427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_expand_activation_layer_call_and_return_conditional_losses_1976794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1884280) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_activation_layer_call_and_return_conditional_losses_1891186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_activation_layer_call_and_return_conditional_losses_1892067) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_expand_activation_layer_call_and_return_conditional_losses_1892240) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1889394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_1992716) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_expand_activation_layer_call_and_return_conditional_losses_1882438) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_se_reduce_layer_call_and_return_conditional_losses_1885874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_expand_activation_layer_call_and_return_conditional_losses_1885558) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1880581) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_activation_layer_call_and_return_conditional_losses_1978179) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1984199) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_expand_activation_layer_call_and_return_conditional_losses_1978615) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2f_se_reduce_layer_call_and_return_conditional_losses_1978245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1881410) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1886979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1979804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1881160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1884530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1882662) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_se_reduce_layer_call_and_return_conditional_losses_1890555) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_expand_activation_layer_call_and_return_conditional_losses_1892016) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1979481) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1975751) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1882720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_2003380) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1887203) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_activation_layer_call_and_return_conditional_losses_1995078) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_expand_activation_layer_call_and_return_conditional_losses_1999738) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_expand_activation_layer_call_and_return_conditional_losses_1890463) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1985413) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_activation_layer_call_and_return_conditional_losses_1978786) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_expand_activation_layer_call_and_return_conditional_losses_1888007) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_se_reduce_layer_call_and_return_conditional_losses_1890779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1998088) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1882761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1880463) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1972821) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1892464) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1889170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1990051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6j_expand_activation_layer_call_and_return_conditional_losses_1890687) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_expand_activation_layer_call_and_return_conditional_losses_1885782) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1881593) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_1883550) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1957119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1979415) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_activation_layer_call_and_return_conditional_losses_1887610) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_expand_activation_layer_call_and_return_conditional_losses_1891359) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_se_reduce_layer_call_and_return_conditional_losses_1983076) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1881369) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_se_reduce_layer_call_and_return_conditional_losses_1887651) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1891843) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1891634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_activation_layer_call_and_return_conditional_losses_1887834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_se_reduce_layer_call_and_return_conditional_losses_1978852) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1997310) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1990222) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_se_reduce_layer_call_and_return_conditional_losses_1892108) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_se_reduce_layer_call_and_return_conditional_losses_1883866) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1973720) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1891583) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1990658) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_1883377) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_activation_layer_call_and_return_conditional_losses_1888058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1886755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1976187) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_se_reduce_layer_call_and_return_conditional_losses_1891003) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1886454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_1986456) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1888737) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_activation_layer_call_and_return_conditional_losses_1885385) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1c_se_reduce_layer_call_and_return_conditional_losses_1880796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_activation_layer_call_and_return_conditional_losses_1981796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_expand_activation_layer_call_and_return_conditional_losses_1999131) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1884978) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1885161) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_se_reduce_layer_call_and_return_conditional_losses_1977031) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6h_activation_layer_call_and_return_conditional_losses_1999909) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1889791) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1974998) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4g_se_reduce_layer_call_and_return_conditional_losses_1987300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1884222) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1885202) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1984872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_activation_layer_call_and_return_conditional_losses_2002944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_expand_activation_layer_call_and_return_conditional_losses_1993693) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1989662) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1975817) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_se_reduce_layer_call_and_return_conditional_losses_1995144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_se_reduce_layer_call_and_return_conditional_losses_1886322) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1985849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1884713) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1996333) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5f_expand_activation_layer_call_and_return_conditional_losses_1992479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_activation_layer_call_and_return_conditional_losses_1994471) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1889659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2d_activation_layer_call_and_return_conditional_losses_1976965) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1891792) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1986086) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_expand_activation_layer_call_and_return_conditional_losses_1887783) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2g_activation_layer_call_and_return_conditional_losses_1882489) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_activation_layer_call_and_return_conditional_losses_1987841) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1986020) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1884438) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1887386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1991502) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_activation_layer_call_and_return_conditional_losses_1981189) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_activation_layer_call_and_return_conditional_losses_1883825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_expand_activation_layer_call_and_return_conditional_losses_2005154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_expand_activation_layer_call_and_return_conditional_losses_1994907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_expand_activation_layer_call_and_return_conditional_losses_1883774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_activation_layer_call_and_return_conditional_losses_2005325) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_expand_activation_layer_call_and_return_conditional_losses_1891135) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7c_se_reduce_layer_call_and_return_conditional_losses_2004784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5g_activation_layer_call_and_return_conditional_losses_1993257) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1996267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_activation_layer_call_and_return_conditional_losses_1888506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1880371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_activation_layer_call_and_return_conditional_losses_1885833) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1998154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_se_reduce_layer_call_and_return_conditional_losses_1882082) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1889119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1889618) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6i_se_reduce_layer_call_and_return_conditional_losses_2000582) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3f_se_reduce_layer_call_and_return_conditional_losses_1982469) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_se_reduce_layer_call_and_return_conditional_losses_1988514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1881102) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1973313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1881201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7d_se_reduce_layer_call_and_return_conditional_losses_1892332) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1992109) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6l_activation_layer_call_and_return_conditional_losses_2002337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1884321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1888895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_expand_activation_layer_call_and_return_conditional_losses_2002773) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_activation_layer_call_and_return_conditional_losses_1890962) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1980041) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6k_se_reduce_layer_call_and_return_conditional_losses_2001796) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_1856420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1882878) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_activation_layer_call_and_return_conditional_losses_1886057) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4f_expand_activation_layer_call_and_return_conditional_losses_1885334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5j_expand_activation_layer_call_and_return_conditional_losses_1888455) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1884754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5i_se_reduce_layer_call_and_return_conditional_losses_1994537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_1883326) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_activation_layer_call_and_return_conditional_losses_1977572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1887335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2e_expand_activation_layer_call_and_return_conditional_losses_1881990) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1989728) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1997547) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_activation_layer_call_and_return_conditional_losses_1988448) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1881542) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_expand_activation_layer_call_and_return_conditional_losses_1886230) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3d_expand_activation_layer_call_and_return_conditional_losses_1981018) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_2003551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1996874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1886887) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_expand_activation_layer_call_and_return_conditional_losses_1981625) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1979222) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4j_expand_activation_layer_call_and_return_conditional_losses_1988884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1889211) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5h_activation_layer_call_and_return_conditional_losses_1993864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4i_expand_activation_layer_call_and_return_conditional_losses_1988277) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1966689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3e_se_reduce_layer_call_and_return_conditional_losses_1883642) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_1999368) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4h_se_reduce_layer_call_and_return_conditional_losses_1987907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1881634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6g_se_reduce_layer_call_and_return_conditional_losses_1890107) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6m_activation_layer_call_and_return_conditional_losses_1891410) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3g_expand_activation_layer_call_and_return_conditional_losses_1982839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15876/139244809.py in <module>
#      91   y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
#      92 y_all_predicted = np.concatenate(y_all_sets_predicted)
# ---> 93 del x_all
#
# NameError: name 'x_all' is not defined

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=6184
# FP=956
# acc=0.8661064425770308
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 91.37931034482759%
# 2WayConnectorforFoley acc = 94.5578231292517%
# 2WayFoleyCatheter acc = 74.6268656716418%
# 3WayConnectorforFoley acc = 94.87179487179486%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 85.0%
# AlcoholPad acc = 54.761904761904766%
# BootCover acc = 70.48192771084338%
# CottonBall acc = 96.40718562874252%
# CottonSwap acc = 81.81818181818183%
# Dilator acc = 82.90598290598291%
# DisposableInfusionSet acc = 95.57522123893806%
# ExtensionTube acc = 73.17073170731707%
# FaceShield acc = 68.51851851851852%
# FrontLoadSyringe acc = 79.64601769911505%
# GauzePad acc = 69.31818181818183%
# Glove acc = 77.08333333333334%
# GuideWire acc = 67.85714285714286%
# LiquidBottle acc = 87.40458015267176%
# Mask acc = 99.48051948051948%
# NGTube acc = 82.58064516129032%
# NasalCannula acc = 81.41592920353983%
# Needle acc = 92.85714285714286%
# OxygenMask acc = 99.24812030075188%
# PPESuit acc = 97.58064516129032%
# PharmaceuticalProduct acc = 89.25233644859813%
# Pill acc = 96.07843137254902%
# PillBottle acc = 79.06976744186046%
# PrefilledHumidifier acc = 97.43589743589743%
# PressureConnectingTube acc = 73.2824427480916%
# ReusableHumidifier acc = 92.37288135593221%
# SodiumChlorideBag acc = 92.1259842519685%
# SterileHumidifierAdapter acc = 98.18181818181819%
# SurgicalBlade acc = 76.99115044247787%
# SurgicalCap acc = 96.3963963963964%
# SurgicalSuit acc = 49.24242424242424%
# Syringe acc = 97.33840304182509%
# TrachealTube acc = 73.39449541284404%
# UrineBag acc = 95.0%
# Vaccinebottle acc = 92.95774647887323%
# WingedInfusionSet acc = 86.8421052631579%
#
#
#
# all_avg_eachclass = 84.96607526699361%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[106,   1,   0, ...,   0,   0,   0],
#        [  0, 139,   0, ...,   0,   0,   0],
#        [  0,   0, 100, ...,   0,   0,  20],
#        ...,
#        [  0,   0,   0, ..., 114,   0,   0],
#        [  0,   0,   0, ...,   0, 198,   0],
#        [  0,   0,   0, ...,   0,   0,  99]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[91.37931034,  0.86206897,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 94.55782313,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 74.62686567, ...,  0.        ,
#          0.        , 14.92537313],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 95.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         92.95774648,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 86.84210526]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
