# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=299
img_width=299
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 299, 299, 3)
# (32,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input,InceptionResNetV2

InceptionResNetV2_model = keras.applications.InceptionResNetV2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

InceptionResNetV2_model_nooutput = InceptionResNetV2_model.layers[-2].output
custom_InceptionResNetV2_model = Model(inputs = InceptionResNetV2_model.input, outputs = InceptionResNetV2_model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_InceptionResNetV2_model.trainable = False
for layer in custom_InceptionResNetV2_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_InceptionResNetV2_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 96)   18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 64)   12288       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 96)   288         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 64)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 96)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 35, 35, 320)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 32)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 48)   13824       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 32)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 48)   144         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 48)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 32)   9216        activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 64)   27648       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 32)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 64)   192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 35, 35, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 35, 35, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 32)   96          conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 48)   13824       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 32)   96          conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 48)   144         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 48)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 32)   9216        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 64)   27648       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 32)   96          conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 32)   96          conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 32)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_18[0][0]
#                                                                  activation_20[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 35, 35, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 35, 35, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 32)   96          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 48)   13824       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 32)   96          conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 48)   144         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 48)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 32)   9216        activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 64)   27648       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 32)   96          conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 32)   96          conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 35, 35, 64)   192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 35, 35, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 35, 35, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 35, 35, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 35, 35, 32)   96          conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 35, 35, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 35, 35, 48)   13824       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 35, 35, 32)   96          conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 35, 35, 48)   144         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 35, 35, 32)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 35, 35, 48)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 35, 35, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 35, 35, 32)   9216        activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 35, 35, 64)   27648       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 35, 35, 32)   96          conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 35, 35, 32)   96          conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 35, 35, 64)   192         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 35, 35, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 35, 35, 32)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 35, 35, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_30[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 35, 35, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 35, 35, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 35, 35, 32)   96          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 35, 35, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 35, 35, 48)   13824       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 35, 35, 32)   96          conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 35, 35, 48)   144         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 35, 35, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 35, 35, 48)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 35, 35, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 35, 35, 32)   9216        activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 35, 35, 64)   27648       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 35, 35, 32)   96          conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 35, 35, 32)   96          conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 35, 35, 64)   192         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 35, 35, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 35, 35, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 35, 35, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 35, 35, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 35, 35, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 35, 35, 32)   96          conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 35, 35, 32)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 35, 35, 48)   13824       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 35, 35, 32)   96          conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 35, 35, 48)   144         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 35, 35, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 35, 35, 48)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 35, 35, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 35, 35, 32)   9216        activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 35, 35, 64)   27648       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 35, 35, 32)   96          conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 35, 35, 32)   96          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 35, 35, 64)   192         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 35, 35, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 35, 35, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 35, 35, 64)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 35, 35, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 35, 35, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 35, 35, 32)   96          conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 35, 35, 32)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 35, 35, 48)   13824       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 35, 35, 32)   96          conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 35, 35, 48)   144         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 35, 35, 32)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 35, 35, 48)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 35, 35, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 35, 35, 32)   9216        activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 35, 35, 64)   27648       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 35, 35, 32)   96          conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 35, 35, 32)   96          conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 35, 35, 64)   192         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 35, 35, 32)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 35, 35, 32)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 35, 35, 64)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_48[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 35, 35, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 35, 35, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 35, 35, 32)   96          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 35, 35, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 35, 35, 48)   13824       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 35, 35, 32)   96          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 35, 35, 48)   144         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 35, 35, 32)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 35, 35, 48)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 35, 35, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 35, 35, 32)   9216        activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 35, 35, 64)   27648       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 35, 35, 32)   96          conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 35, 35, 32)   96          conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 35, 35, 64)   192         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 35, 35, 32)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 35, 35, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 35, 35, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 35, 35, 128)  0           activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 35, 35, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 35, 35, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 35, 35, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 35, 35, 32)   96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 35, 35, 32)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 35, 35, 48)   13824       activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 35, 35, 32)   96          conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 35, 35, 48)   144         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 35, 35, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 35, 35, 48)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 35, 35, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 8, 8, 256)    768         conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 8, 8, 192)    0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 8, 8, 256)    0           batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# block8_6_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_183[0][0]
#                                                                  activation_186[0][0]
# __________________________________________________________________________________________________
# block8_6_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_6_mixed[0][0]
# __________________________________________________________________________________________________
# block8_6 (Lambda)               (None, 8, 8, 2080)   0           block8_5_ac[0][0]
#                                                                  block8_6_conv[0][0]
# __________________________________________________________________________________________________
# block8_6_ac (Activation)        (None, 8, 8, 2080)   0           block8_6[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 8, 8, 192)    576         conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 8, 8, 192)    0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 8, 8, 224)    129024      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 8, 8, 224)    672         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 8, 8, 224)    0           batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 8, 8, 192)    399360      block8_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 8, 8, 256)    172032      activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 8, 8, 192)    576         conv2d_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 8, 8, 256)    768         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 8, 8, 192)    0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 8, 8, 256)    0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# block8_7_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_187[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# block8_7_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_7_mixed[0][0]
# __________________________________________________________________________________________________
# block8_7 (Lambda)               (None, 8, 8, 2080)   0           block8_6_ac[0][0]
#                                                                  block8_7_conv[0][0]
# __________________________________________________________________________________________________
# block8_7_ac (Activation)        (None, 8, 8, 2080)   0           block8_7[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 8, 8, 192)    576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 8, 8, 192)    0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 8, 8, 224)    129024      activation_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 8, 8, 224)    672         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 8, 8, 224)    0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 8, 8, 192)    399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 8, 8, 256)    172032      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 8, 8, 192)    576         conv2d_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 8, 8, 256)    768         conv2d_194[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 8, 8, 192)    0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 8, 8, 256)    0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_191[0][0]
#                                                                  activation_194[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 8, 8, 2080)   0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 8, 8, 2080)   0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 8, 8, 192)    576         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 8, 8, 192)    0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 8, 8, 224)    129024      activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 8, 8, 224)    672         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 8, 8, 224)    0           batch_normalization_197[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 8, 8, 192)    399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 8, 8, 256)    172032      activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 8, 8, 192)    576         conv2d_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 8, 8, 256)    768         conv2d_198[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 8, 8, 192)    0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 8, 8, 256)    0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 8, 8, 448)    0           activation_195[0][0]
#                                                                  activation_198[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 8, 8, 2080)   933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 8, 8, 2080)   0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 8, 8, 2080)   0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 8, 8, 192)    576         conv2d_200[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 8, 8, 192)    0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 8, 8, 224)    129024      activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 8, 8, 224)    672         conv2d_201[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 8, 8, 224)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 8, 8, 192)    399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 8, 8, 256)    172032      activation_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 8, 8, 192)    576         conv2d_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 8, 8, 256)    768         conv2d_202[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 8, 8, 192)    0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 8, 8, 256)    0           batch_normalization_202[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 8, 8, 448)    0           activation_199[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 8, 8, 2080)   933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 8, 8, 2080)   0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 8, 8, 1536)   3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 8, 8, 1536)   4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 8, 8, 1536)   0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1536)         0           conv_7b_ac[0][0]
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 0
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_InceptionResNetV2_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1536)              54336736
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 55,952,649
# Trainable params: 1,615,913
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 97/97 [==============================] - 62s 326ms/step - loss: 1.1877 - accuracy: 0.6788 - val_loss: 0.5566 - val_accuracy: 0.8034
# Epoch 2/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.4151 - accuracy: 0.8691 - val_loss: 0.3710 - val_accuracy: 0.8680
# Epoch 3/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.2896 - accuracy: 0.9021 - val_loss: 0.3374 - val_accuracy: 0.8875
# Epoch 4/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.2096 - accuracy: 0.9351 - val_loss: 0.2584 - val_accuracy: 0.8991
# Epoch 5/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.1528 - accuracy: 0.9480 - val_loss: 0.2974 - val_accuracy: 0.8926
# Epoch 6/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.1194 - accuracy: 0.9635 - val_loss: 0.2249 - val_accuracy: 0.9146
# Epoch 7/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.1040 - accuracy: 0.9690 - val_loss: 0.2977 - val_accuracy: 0.9107
# Epoch 8/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0888 - accuracy: 0.9745 - val_loss: 0.2296 - val_accuracy: 0.9198
# Epoch 9/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0720 - accuracy: 0.9774 - val_loss: 0.1927 - val_accuracy: 0.9340
# Epoch 10/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0644 - accuracy: 0.9803 - val_loss: 0.1591 - val_accuracy: 0.9431
# Epoch 11/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0626 - accuracy: 0.9806 - val_loss: 0.1655 - val_accuracy: 0.9418
# Epoch 12/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0449 - accuracy: 0.9874 - val_loss: 0.1723 - val_accuracy: 0.9521
# Epoch 13/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.2425 - val_accuracy: 0.9366
# Epoch 14/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0574 - accuracy: 0.9832 - val_loss: 0.1814 - val_accuracy: 0.9483
# Epoch 15/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0549 - accuracy: 0.9845 - val_loss: 0.2074 - val_accuracy: 0.9444
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0238 - accuracy: 0.9945 - val_loss: 0.1709 - val_accuracy: 0.9560
# Epoch 17/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0165 - accuracy: 0.9961 - val_loss: 0.1654 - val_accuracy: 0.9599
# Epoch 18/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0131 - accuracy: 0.9981 - val_loss: 0.1606 - val_accuracy: 0.9599
# Epoch 19/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0114 - accuracy: 0.9977 - val_loss: 0.1637 - val_accuracy: 0.9599
# Epoch 20/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0090 - accuracy: 0.9987 - val_loss: 0.1581 - val_accuracy: 0.9625
# Epoch 21/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0083 - accuracy: 0.9997 - val_loss: 0.1533 - val_accuracy: 0.9638
# Epoch 22/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.1553 - val_accuracy: 0.9638
# Epoch 23/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0078 - accuracy: 0.9994 - val_loss: 0.1518 - val_accuracy: 0.9612
# Epoch 24/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 0.1526 - val_accuracy: 0.9625
# Epoch 25/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0069 - accuracy: 0.9997 - val_loss: 0.1557 - val_accuracy: 0.9638
# Epoch 26/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0064 - accuracy: 0.9997 - val_loss: 0.1534 - val_accuracy: 0.9625
# Epoch 27/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9651
# Epoch 28/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.1532 - val_accuracy: 0.9651
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 29/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1471 - val_accuracy: 0.9677
# Epoch 30/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9664
# Epoch 31/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9651
# Epoch 32/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9638
# Epoch 33/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1520 - val_accuracy: 0.9638
# Epoch 34/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9664
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 35/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.1503 - val_accuracy: 0.9664
# Epoch 36/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 37/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9651
# Epoch 38/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 0.9651
# Epoch 39/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9664
# Epoch 40/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9651
# Epoch 41/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9651
# Epoch 42/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1478 - val_accuracy: 0.9651
# Epoch 43/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9651
# Epoch 44/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9651
# Epoch 45/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9651
# Epoch 46/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1493 - val_accuracy: 0.9651
# Epoch 47/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9651
# Epoch 48/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9651
# Epoch 49/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9651
# Epoch 50/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.1480 - val_accuracy: 0.9651
# Epoch 51/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1479 - val_accuracy: 0.9651
# Epoch 52/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 0.9651
# Epoch 53/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1491 - val_accuracy: 0.9664
# Epoch 54/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9664
# Epoch 55/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.1517 - val_accuracy: 0.9664
# Epoch 56/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9651
# Epoch 57/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9651
# Epoch 58/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.9651
# Epoch 59/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9664
# Epoch 60/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1504 - val_accuracy: 0.9651
# Epoch 61/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1517 - val_accuracy: 0.9651
# Epoch 62/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9651
# Epoch 63/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1512 - val_accuracy: 0.9651
# Epoch 64/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.1508 - val_accuracy: 0.9638
# Epoch 65/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1502 - val_accuracy: 0.9651
# Epoch 66/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9651
# Epoch 67/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9651
# Epoch 68/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 0.9638
# Epoch 69/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1500 - val_accuracy: 0.9638
# Epoch 70/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.1488 - val_accuracy: 0.9638
# Epoch 71/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.1521 - val_accuracy: 0.9651
# Epoch 72/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9651
# Epoch 73/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9651
# Epoch 74/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1529 - val_accuracy: 0.9651
# Epoch 75/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9651
# Epoch 76/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1509 - val_accuracy: 0.9651
# Epoch 77/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9651
# Epoch 78/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.1512 - val_accuracy: 0.9651
# Epoch 79/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9651
# Epoch 80/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1490 - val_accuracy: 0.9638
# Epoch 81/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9638
# Epoch 82/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1514 - val_accuracy: 0.9638
# Epoch 83/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 0.9651
# Epoch 84/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.1523 - val_accuracy: 0.9651
# Epoch 85/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1522 - val_accuracy: 0.9664
# Epoch 86/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 0.9664
# Epoch 87/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9664
# Epoch 88/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9651
# Epoch 89/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9651
# Epoch 90/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9638
# Epoch 91/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 0.9651
# Epoch 92/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9664
# Epoch 93/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.1544 - val_accuracy: 0.9638
# Epoch 94/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9651
# Epoch 95/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9638
# Epoch 96/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1545 - val_accuracy: 0.9651
# Epoch 97/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1536 - val_accuracy: 0.9651
# Epoch 98/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9664
# Epoch 99/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9664
# Epoch 100/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9651
# Epoch 101/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9664
# Epoch 102/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.9664
# Epoch 103/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1544 - val_accuracy: 0.9651
# Epoch 104/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 0.9664
# Epoch 105/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9651
# Epoch 106/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9651
# Epoch 107/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9638
# Epoch 108/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1558 - val_accuracy: 0.9664
# Epoch 109/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9651
# Epoch 110/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1537 - val_accuracy: 0.9638
# Epoch 111/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1548 - val_accuracy: 0.9638
# Epoch 112/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1542 - val_accuracy: 0.9651
# Epoch 113/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9638
# Epoch 114/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1541 - val_accuracy: 0.9651
# Epoch 115/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1527 - val_accuracy: 0.9664
# Epoch 116/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1534 - val_accuracy: 0.9664
# Epoch 117/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9677
# Epoch 118/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1560 - val_accuracy: 0.9664
# Epoch 119/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9651
# Epoch 120/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9651
# Epoch 121/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1556 - val_accuracy: 0.9677
# Epoch 122/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9664
# Epoch 123/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9651
# Epoch 124/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9677
# Epoch 125/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1519 - val_accuracy: 0.9664
# Epoch 126/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9651
# Epoch 127/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9651
# Epoch 128/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9664
# Epoch 129/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9651
# Epoch 130/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9664
# Epoch 131/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9677
# Epoch 132/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9651
# Epoch 133/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1553 - val_accuracy: 0.9664
# Epoch 134/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 0.9677
# Epoch 135/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 0.9664
# Epoch 136/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1552 - val_accuracy: 0.9664
# Epoch 137/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1555 - val_accuracy: 0.9677
# Epoch 138/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9677
# Epoch 139/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1568 - val_accuracy: 0.9690
# Epoch 140/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.9664
# Epoch 141/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9677
# Epoch 142/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 0.9651
# Epoch 143/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9664
# Epoch 144/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 0.9677
# Epoch 145/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9677
# Epoch 146/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 0.9677
# Epoch 147/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1575 - val_accuracy: 0.9664
# Epoch 148/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9664
# Epoch 149/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9664
# Epoch 150/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9664
# Epoch 151/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.9664
# Epoch 152/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9651
# Epoch 153/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9638
# Epoch 154/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.9651
# Epoch 155/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9664
# Epoch 156/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9677
# Epoch 157/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9651
# Epoch 158/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9664
# Epoch 159/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9677
# Epoch 160/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9677
# Epoch 161/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9677
# Epoch 162/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9664
# Epoch 163/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9677
# Epoch 164/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9677
# Epoch 165/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1581 - val_accuracy: 0.9690
# Epoch 166/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9664
# Epoch 167/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.9638
# Epoch 168/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.9651
# Epoch 169/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9677
# Epoch 170/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.9638
# Epoch 171/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9677
# Epoch 172/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9690
# Epoch 173/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9664
# Epoch 174/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9664
# Epoch 175/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9677
# Epoch 176/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1580 - val_accuracy: 0.9677
# Epoch 177/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1574 - val_accuracy: 0.9664
# Epoch 178/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.9677
# Epoch 179/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9664
# Epoch 180/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.9664
# Epoch 181/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9638
# Epoch 182/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1598 - val_accuracy: 0.9651
# Epoch 183/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9664
# Epoch 184/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1612 - val_accuracy: 0.9677
# Epoch 185/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9651
# Epoch 186/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9677
# Epoch 187/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9664
# Epoch 188/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9664
# Epoch 189/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9664
# Epoch 190/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9690
# Epoch 191/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9677
# Epoch 192/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9677
# Epoch 193/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9690
# Epoch 194/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1582 - val_accuracy: 0.9677
# Epoch 195/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9677
# Epoch 196/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.9651
# Epoch 197/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9664
# Epoch 198/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9677
# Epoch 199/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9677
# Epoch 200/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 0.9664
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9664
# Epoch 202/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9664
# Epoch 203/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9664
# Epoch 204/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.4139e-04 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9690
# Epoch 205/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9677
# Epoch 206/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9638
# Epoch 207/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1599 - val_accuracy: 0.9664
# Epoch 208/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9677
# Epoch 209/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 0.9664
# Epoch 210/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9664
# Epoch 211/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9664
# Epoch 212/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 0.9651
# Epoch 213/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9651
# Epoch 214/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9664
# Epoch 215/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9664
# Epoch 216/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.1896e-04 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9664
# Epoch 217/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 0.9677
# Epoch 218/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9638
# Epoch 219/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1639 - val_accuracy: 0.9651
# Epoch 220/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.5309e-04 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9638
# Epoch 221/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9677
# Epoch 222/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.8200e-04 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.9677
# Epoch 223/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.8598e-04 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.9651
# Epoch 224/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.6475e-04 - accuracy: 1.0000 - val_loss: 0.1600 - val_accuracy: 0.9677
# Epoch 225/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9664
# Epoch 226/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.7818e-04 - accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9677
# Epoch 227/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.4589e-04 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 0.9690
# Epoch 228/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.7117e-04 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9690
# Epoch 229/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.1112e-04 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9677
# Epoch 230/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.5651e-04 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.9664
# Epoch 231/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.6811e-04 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9664
# Epoch 232/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.7061e-04 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9664
# Epoch 233/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.8615e-04 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9651
# Epoch 234/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.6153e-04 - accuracy: 1.0000 - val_loss: 0.1619 - val_accuracy: 0.9664
# Epoch 235/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.8898e-04 - accuracy: 1.0000 - val_loss: 0.1634 - val_accuracy: 0.9651
# Epoch 236/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.6027e-04 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 0.9664
# Epoch 237/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.8386e-04 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9638
# Epoch 238/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.8581e-04 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9664
# Epoch 239/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.8890e-04 - accuracy: 1.0000 - val_loss: 0.1606 - val_accuracy: 0.9677
# Epoch 240/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.3058e-04 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9664
# Epoch 241/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.6563e-04 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9664
# Epoch 242/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 9.6128e-04 - accuracy: 1.0000 - val_loss: 0.1645 - val_accuracy: 0.9664
# Epoch 243/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.5194e-04 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 0.9664
# Epoch 244/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.6762e-04 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9664
# Epoch 245/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.6547e-04 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9664
# Epoch 246/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.2883e-04 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9638
# Epoch 247/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.4721e-04 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9664
# Epoch 248/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.6856e-04 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9664
# Epoch 249/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.7322e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9664
# Epoch 250/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.1193e-04 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9651
# Epoch 251/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.8623e-04 - accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9664
# Epoch 252/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.0601e-04 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9651
# Epoch 253/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.8311e-04 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 0.9664
# Epoch 254/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.5845e-04 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9651
# Epoch 255/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.6536e-04 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9651
# Epoch 256/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.1212e-04 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9651
# Epoch 257/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 8.3052e-04 - accuracy: 1.0000 - val_loss: 0.1669 - val_accuracy: 0.9651
# Epoch 258/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 6.8744e-04 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9664
# Epoch 259/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.7011e-04 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9664
# Epoch 260/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 7.3162e-04 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9664
# Epoch 261/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 7.9767e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9664
# Epoch 262/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 7.2426e-04 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9677
# Epoch 263/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 7.4941e-04 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9664
# Epoch 264/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.7918e-04 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9664
# Epoch 265/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.7694e-04 - accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9664
# Epoch 266/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.8688e-04 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9664
# Epoch 267/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.7576e-04 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9651
# Epoch 268/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 7.3112e-04 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 0.9651
# Epoch 269/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 6.6198e-04 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9664
# Epoch 270/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.8131e-04 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9664
# Epoch 271/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 7.2628e-04 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9651
# Epoch 272/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.7061e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9664
# Epoch 273/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.5352e-04 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9664
# Epoch 274/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.9172e-04 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9664
# Epoch 275/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.5546e-04 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9664
# Epoch 276/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.6453e-04 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9690
# Epoch 277/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.7959e-04 - accuracy: 1.0000 - val_loss: 0.1667 - val_accuracy: 0.9651
# Epoch 278/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.6080e-04 - accuracy: 1.0000 - val_loss: 0.1646 - val_accuracy: 0.9690
# Epoch 279/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.8193e-04 - accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9664
# Epoch 280/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.1996e-04 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9651
# Epoch 281/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.3982e-04 - accuracy: 1.0000 - val_loss: 0.1650 - val_accuracy: 0.9677
# Epoch 282/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 5.7709e-04 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9651
# Epoch 283/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.9132e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9638
# Epoch 284/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.5616e-04 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9664
# Epoch 285/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.6805e-04 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9651
# Epoch 286/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.3255e-04 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9677
# Epoch 287/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.4103e-04 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9664
# Epoch 288/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.9303e-04 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9664
# Epoch 289/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.5627e-04 - accuracy: 1.0000 - val_loss: 0.1700 - val_accuracy: 0.9651
# Epoch 290/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.1320e-04 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9664
# Epoch 291/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.6840e-04 - accuracy: 1.0000 - val_loss: 0.1658 - val_accuracy: 0.9664
# Epoch 292/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.6387e-04 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9677
# Epoch 293/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.6899e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9677
# Epoch 294/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.3477e-04 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9677
# Epoch 295/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.4751e-04 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9651
# Epoch 296/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.1583e-04 - accuracy: 1.0000 - val_loss: 0.1703 - val_accuracy: 0.9664
# Epoch 297/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.0901e-04 - accuracy: 1.0000 - val_loss: 0.1698 - val_accuracy: 0.9664
# Epoch 298/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.2641e-04 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9664
# Epoch 299/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.9262e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9651
# Epoch 300/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 6.0269e-04 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9664
# Epoch 301/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.5702e-04 - accuracy: 1.0000 - val_loss: 0.1707 - val_accuracy: 0.9664
# Epoch 302/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.5009e-04 - accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9638
# Epoch 303/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.7714e-04 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 0.9651
# Epoch 304/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.7174e-04 - accuracy: 1.0000 - val_loss: 0.1702 - val_accuracy: 0.9664
# Epoch 305/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.6262e-04 - accuracy: 1.0000 - val_loss: 0.1715 - val_accuracy: 0.9651
# Epoch 306/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.1926e-04 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9664
# Epoch 307/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.9064e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9664
# Epoch 308/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.6571e-04 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9664
# Epoch 309/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.2330e-04 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9677
# Epoch 310/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.6762e-04 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9677
# Epoch 311/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.5437e-04 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9690
# Epoch 312/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.6876e-04 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9677
# Epoch 313/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.7659e-04 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9677
# Epoch 314/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 5.6177e-04 - accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9690
# Epoch 315/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.8360e-04 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9690
# Epoch 316/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.1721e-04 - accuracy: 1.0000 - val_loss: 0.1698 - val_accuracy: 0.9677
# Epoch 317/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.5478e-04 - accuracy: 1.0000 - val_loss: 0.1674 - val_accuracy: 0.9677
# Epoch 318/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.5680e-04 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9677
# Epoch 319/2000
# 97/97 [==============================] - 24s 249ms/step - loss: 4.5523e-04 - accuracy: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.9690
# Epoch 320/2000
# 97/97 [==============================] - 24s 250ms/step - loss: 4.9321e-04 - accuracy: 1.0000 - val_loss: 0.1717 - val_accuracy: 0.9664
# Epoch 321/2000
# ...
# Epoch 1898/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.9883e-07 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9664
# Epoch 1899/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.5513e-07 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9651
# Epoch 1900/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.1078e-07 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9651
# Epoch 1901/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.0470e-07 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9651
# Epoch 1902/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.0283e-07 - accuracy: 1.0000 - val_loss: 0.2633 - val_accuracy: 0.9651
# Epoch 1903/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 7.1086e-07 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9651
# Epoch 1904/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.8014e-07 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9651
# Epoch 1905/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.2315e-07 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 0.9651
# Epoch 1906/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.2928e-07 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9664
# Epoch 1907/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.3081e-07 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9664
# Epoch 1908/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.6555e-07 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9651
# Epoch 1909/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.3719e-07 - accuracy: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9651
# Epoch 1910/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.9289e-07 - accuracy: 1.0000 - val_loss: 0.2663 - val_accuracy: 0.9651
# Epoch 1911/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.6728e-07 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9651
# Epoch 1912/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.9638e-07 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9664
# Epoch 1913/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.0523e-07 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9664
# Epoch 1914/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.1390e-07 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9651
# Epoch 1915/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 1.0826e-06 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9651
# Epoch 1916/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.9289e-07 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9651
# Epoch 1917/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.2501e-07 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9638
# Epoch 1918/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.8154e-07 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9638
# Epoch 1919/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.5399e-07 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9638
# Epoch 1920/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.6597e-07 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9638
# Epoch 1921/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.7549e-07 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9638
# Epoch 1922/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.5331e-07 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9638
# Epoch 1923/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.0343e-07 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9638
# Epoch 1924/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.4074e-07 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9638
# Epoch 1925/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.8654e-07 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9638
# Epoch 1926/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.3717e-07 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9638
# Epoch 1927/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.2475e-07 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9638
# Epoch 1928/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.3264e-07 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9664
# Epoch 1929/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.1538e-06 - accuracy: 1.0000 - val_loss: 0.2703 - val_accuracy: 0.9638
# Epoch 1930/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.6975e-07 - accuracy: 1.0000 - val_loss: 0.2693 - val_accuracy: 0.9638
# Epoch 1931/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.7474e-07 - accuracy: 1.0000 - val_loss: 0.2676 - val_accuracy: 0.9651
# Epoch 1932/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 6.3078e-07 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.9651
# Epoch 1933/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 7.7602e-07 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9651
# Epoch 1934/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.8246e-07 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9651
# Epoch 1935/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.9745e-07 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9651
# Epoch 1936/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.1614e-07 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9664
# Epoch 1937/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.9939e-07 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9664
# Epoch 1938/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.0384e-07 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.9664
# Epoch 1939/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.1574e-07 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9664
# Epoch 1940/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.0503e-07 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9664
# Epoch 1941/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.4404e-07 - accuracy: 1.0000 - val_loss: 0.2666 - val_accuracy: 0.9664
# Epoch 1942/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.9048e-07 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9664
# Epoch 1943/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.2803e-07 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.9664
# Epoch 1944/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.0375e-07 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9664
# Epoch 1945/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.2892e-07 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9664
# Epoch 1946/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.3129e-07 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9664
# Epoch 1947/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 6.6979e-07 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9664
# Epoch 1948/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.5507e-07 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9664
# Epoch 1949/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.4024e-07 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.9664
# Epoch 1950/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.7631e-07 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9664
# Epoch 1951/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.5929e-07 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9664
# Epoch 1952/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.4919e-07 - accuracy: 1.0000 - val_loss: 0.2692 - val_accuracy: 0.9651
# Epoch 1953/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 4.4621e-07 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9651
# Epoch 1954/2000
# 97/97 [==============================] - 24s 252ms/step - loss: 5.7456e-07 - accuracy: 1.0000 - val_loss: 0.2664 - val_accuracy: 0.9664
# Epoch 1955/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.7136e-07 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9664
# Epoch 1956/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.4989e-07 - accuracy: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9664
# Epoch 1957/2000
# 97/97 [==============================] - 25s 253ms/step - loss: 5.7918e-07 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9651
# Epoch 1958/2000
# 97/97 [==============================] - 25s 253ms/step - loss: 4.4948e-07 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9651
# Epoch 1959/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.2699e-07 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9651
# Epoch 1960/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.8979e-07 - accuracy: 1.0000 - val_loss: 0.2683 - val_accuracy: 0.9651
# Epoch 1961/2000
# 97/97 [==============================] - 25s 253ms/step - loss: 3.6175e-07 - accuracy: 1.0000 - val_loss: 0.2685 - val_accuracy: 0.9651
# Epoch 1962/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.7248e-07 - accuracy: 1.0000 - val_loss: 0.2683 - val_accuracy: 0.9651
# Epoch 1963/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 9.3264e-07 - accuracy: 1.0000 - val_loss: 0.2676 - val_accuracy: 0.9651
# Epoch 1964/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.6658e-07 - accuracy: 1.0000 - val_loss: 0.2680 - val_accuracy: 0.9651
# Epoch 1965/2000
# 97/97 [==============================] - 25s 253ms/step - loss: 5.8486e-07 - accuracy: 1.0000 - val_loss: 0.2686 - val_accuracy: 0.9651
# Epoch 1966/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 3.8378e-07 - accuracy: 1.0000 - val_loss: 0.2683 - val_accuracy: 0.9651
# Epoch 1967/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.0799e-07 - accuracy: 1.0000 - val_loss: 0.2685 - val_accuracy: 0.9651
# Epoch 1968/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.4821e-07 - accuracy: 1.0000 - val_loss: 0.2674 - val_accuracy: 0.9664
# Epoch 1969/2000
# 97/97 [==============================] - 25s 253ms/step - loss: 4.7614e-07 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9664
# Epoch 1970/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 7.6622e-07 - accuracy: 1.0000 - val_loss: 0.2702 - val_accuracy: 0.9664
# Epoch 1971/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.2147e-07 - accuracy: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9664
# Epoch 1972/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.2280e-07 - accuracy: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9664
# Epoch 1973/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 6.1968e-07 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.9664
# Epoch 1974/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.0477e-07 - accuracy: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9664
# Epoch 1975/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.4952e-07 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.9664
# Epoch 1976/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.6427e-07 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.9664
# Epoch 1977/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 1.6491e-06 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9664
# Epoch 1978/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.8380e-07 - accuracy: 1.0000 - val_loss: 0.2668 - val_accuracy: 0.9651
# Epoch 1979/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 6.7757e-07 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9664
# Epoch 1980/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.9447e-07 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9664
# Epoch 1981/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 1.4393e-06 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9664
# Epoch 1982/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.2667e-07 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9664
# Epoch 1983/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 6.1756e-07 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.9664
# Epoch 1984/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.0325e-07 - accuracy: 1.0000 - val_loss: 0.2707 - val_accuracy: 0.9664
# Epoch 1985/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.2916e-07 - accuracy: 1.0000 - val_loss: 0.2704 - val_accuracy: 0.9664
# Epoch 1986/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 6.7884e-07 - accuracy: 1.0000 - val_loss: 0.2688 - val_accuracy: 0.9664
# Epoch 1987/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.2564e-07 - accuracy: 1.0000 - val_loss: 0.2693 - val_accuracy: 0.9664
# Epoch 1988/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.4998e-07 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9664
# Epoch 1989/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.8887e-07 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.9664
# Epoch 1990/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.6626e-07 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9664
# Epoch 1991/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.0854e-07 - accuracy: 1.0000 - val_loss: 0.2692 - val_accuracy: 0.9664
# Epoch 1992/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.2863e-07 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9664
# Epoch 1993/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.7283e-07 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.9664
# Epoch 1994/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.1957e-07 - accuracy: 1.0000 - val_loss: 0.2695 - val_accuracy: 0.9664
# Epoch 1995/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.8646e-07 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9664
# Epoch 1996/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 5.2451e-07 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9664
# Epoch 1997/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.8511e-07 - accuracy: 1.0000 - val_loss: 0.2703 - val_accuracy: 0.9664
# Epoch 1998/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.5519e-07 - accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9664
# Epoch 1999/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.5014e-07 - accuracy: 1.0000 - val_loss: 0.2709 - val_accuracy: 0.9664
# Epoch 2000/2000
# 97/97 [==============================] - 24s 253ms/step - loss: 4.2911e-07 - accuracy: 1.0000 - val_loss: 0.2718 - val_accuracy: 0.9651
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 57/57 [==============================] - 16s 231ms/step - loss: 1.0985 - accuracy: 0.8595
# test_indoor_ds_results:test loss, test acc: [1.098549485206604, 0.8595317602157593]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 99/99 [==============================] - 29s 266ms/step - loss: 2.0920 - accuracy: 0.7761
# test_outdoor_ds_results:test loss, test acc: [2.091986894607544, 0.7761146426200867]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 69/69 [==============================] - 16s 227ms/step - loss: 2.5080 - accuracy: 0.7416
# test_belt_ds_results:test loss, test acc: [2.507967233657837, 0.7416138052940369]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/InceptionResNetV2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 57/57 [==============================] - 14s 204ms/step - loss: 0.6470 - accuracy: 0.8584
# 99/99 [==============================] - 20s 205ms/step - loss: 1.2525 - accuracy: 0.7678
# 69/69 [==============================] - 14s 205ms/step - loss: 1.5326 - accuracy: 0.7366
# Epoch200
#  test_indoor_acc=0.8584169745445251
#  test_outdoor_acc=0.7678343653678894
#  test_belt_acc=0.7366273999214172
# 57/57 [==============================] - 14s 202ms/step - loss: 0.7218 - accuracy: 0.8579
# 99/99 [==============================] - 20s 203ms/step - loss: 1.3843 - accuracy: 0.7726
# 69/69 [==============================] - 14s 205ms/step - loss: 1.7205 - accuracy: 0.7380
# Epoch400
#  test_indoor_acc=0.8578595519065857
#  test_outdoor_acc=0.7726114392280579
#  test_belt_acc=0.7379872798919678
# 57/57 [==============================] - 14s 201ms/step - loss: 0.8086 - accuracy: 0.8528
# 99/99 [==============================] - 20s 202ms/step - loss: 1.5172 - accuracy: 0.7755
# 69/69 [==============================] - 14s 203ms/step - loss: 1.9091 - accuracy: 0.7357
# Epoch600
#  test_indoor_acc=0.8528428077697754
#  test_outdoor_acc=0.7754777073860168
#  test_belt_acc=0.7357207536697388
# 57/57 [==============================] - 19s 201ms/step - loss: 0.8737 - accuracy: 0.8551
# 99/99 [==============================] - 20s 203ms/step - loss: 1.6394 - accuracy: 0.7755
# 69/69 [==============================] - 14s 204ms/step - loss: 2.0155 - accuracy: 0.7384
# Epoch800
#  test_indoor_acc=0.8550724387168884
#  test_outdoor_acc=0.7754777073860168
#  test_belt_acc=0.7384406328201294
# 57/57 [==============================] - 14s 204ms/step - loss: 0.9265 - accuracy: 0.8573
# 99/99 [==============================] - 20s 205ms/step - loss: 1.7357 - accuracy: 0.7752
# 69/69 [==============================] - 14s 206ms/step - loss: 2.1655 - accuracy: 0.7380
# Epoch1000
#  test_indoor_acc=0.8573021292686462
#  test_outdoor_acc=0.7751592397689819
#  test_belt_acc=0.7379872798919678
# 57/57 [==============================] - 14s 204ms/step - loss: 0.9704 - accuracy: 0.8567
# 99/99 [==============================] - 20s 204ms/step - loss: 1.8392 - accuracy: 0.7736
# 69/69 [==============================] - 14s 205ms/step - loss: 2.2250 - accuracy: 0.7421
# Epoch1200
#  test_indoor_acc=0.8567447066307068
#  test_outdoor_acc=0.7735669016838074
#  test_belt_acc=0.7420670986175537
# 57/57 [==============================] - 14s 203ms/step - loss: 1.0240 - accuracy: 0.8567
# 99/99 [==============================] - 20s 204ms/step - loss: 1.9085 - accuracy: 0.7748
# 69/69 [==============================] - 14s 206ms/step - loss: 2.3412 - accuracy: 0.7398
# Epoch1400
#  test_indoor_acc=0.8567447066307068
#  test_outdoor_acc=0.774840772151947
#  test_belt_acc=0.7398005723953247
# 57/57 [==============================] - 14s 203ms/step - loss: 1.0565 - accuracy: 0.8590
# 99/99 [==============================] - 20s 204ms/step - loss: 2.0043 - accuracy: 0.7742
# 69/69 [==============================] - 14s 205ms/step - loss: 2.4257 - accuracy: 0.7416
# Epoch1600
#  test_indoor_acc=0.8589743375778198
#  test_outdoor_acc=0.7742038369178772
#  test_belt_acc=0.7416138052940369
# 57/57 [==============================] - 14s 204ms/step - loss: 1.0846 - accuracy: 0.8579
# 99/99 [==============================] - 20s 205ms/step - loss: 2.0342 - accuracy: 0.7748
# 69/69 [==============================] - 14s 206ms/step - loss: 2.4779 - accuracy: 0.7412
# Epoch1800
#  test_indoor_acc=0.8578595519065857
#  test_outdoor_acc=0.774840772151947
#  test_belt_acc=0.7411604523658752
# 57/57 [==============================] - 15s 204ms/step - loss: 1.0985 - accuracy: 0.8595
# 99/99 [==============================] - 20s 205ms/step - loss: 2.0920 - accuracy: 0.7761
# 69/69 [==============================] - 14s 206ms/step - loss: 2.5080 - accuracy: 0.7416
# Epoch2000
#  test_indoor_acc=0.8595317602157593
#  test_outdoor_acc=0.7761146426200867
#  test_belt_acc=0.7416138052940369

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7924200693766276
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8584169745445251,
#  0.8578595519065857,
#  0.8528428077697754,
#  0.8550724387168884,
#  0.8573021292686462,
#  0.8567447066307068,
#  0.8567447066307068,
#  0.8589743375778198,
#  0.8578595519065857,
#  0.8595317602157593]

# %%
test_outdoor_acc
# Out:
# [0.7678343653678894,
#  0.7726114392280579,
#  0.7754777073860168,
#  0.7754777073860168,
#  0.7751592397689819,
#  0.7735669016838074,
#  0.774840772151947,
#  0.7742038369178772,
#  0.774840772151947,
#  0.7761146426200867]

# %%
test_belt_acc
# Out:
# [0.7366273999214172,
#  0.7379872798919678,
#  0.7357207536697388,
#  0.7384406328201294,
#  0.7379872798919678,
#  0.7420670986175537,
#  0.7398005723953247,
#  0.7416138052940369,
#  0.7411604523658752,
#  0.7416138052940369]

# %%
test_indoor_loss
# Out:
# [0.6470178961753845,
#  0.7218133807182312,
#  0.8085594773292542,
#  0.8737148642539978,
#  0.9265133142471313,
#  0.9704364538192749,
#  1.0240122079849243,
#  1.0564910173416138,
#  1.0846142768859863,
#  1.098549485206604]

# %%
test_outdoor_loss
# Out:
# [1.2524657249450684,
#  1.3842633962631226,
#  1.5171730518341064,
#  1.6393864154815674,
#  1.7357388734817505,
#  1.8391649723052979,
#  1.9085402488708496,
#  2.0043418407440186,
#  2.0342295169830322,
#  2.091986894607544]

# %%
test_belt_loss
# Out:
# [1.5326337814331055,
#  1.7205265760421753,
#  1.9090657234191895,
#  2.015542984008789,
#  2.1655192375183105,
#  2.2249879837036133,
#  2.3411529064178467,
#  2.4257426261901855,
#  2.4778757095336914,
#  2.507967233657837]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.inception_resnet_v2 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=299
img_width=299
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24452/546754331.py in <module>
#      91   y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
#      92 y_all_predicted = np.concatenate(y_all_sets_predicted)
# ---> 93 del x_all
#
# NameError: name 'x_all' is not defined

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5615
# FP=1525
# acc=0.7864145658263305
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 82.75862068965517%
# 2WayConnectorforFoley acc = 85.03401360544217%
# 2WayFoleyCatheter acc = 73.13432835820896%
# 3WayConnectorforFoley acc = 97.43589743589743%
# 3Waystopcock acc = 94.5945945945946%
# AlcoholBottle acc = 79.375%
# AlcoholPad acc = 47.61904761904761%
# BootCover acc = 64.45783132530121%
# CottonBall acc = 99.40119760479041%
# CottonSwap acc = 85.3146853146853%
# Dilator acc = 78.63247863247864%
# DisposableInfusionSet acc = 63.716814159292035%
# ExtensionTube acc = 53.65853658536586%
# FaceShield acc = 50.0%
# FrontLoadSyringe acc = 53.09734513274337%
# GauzePad acc = 68.75%
# Glove acc = 79.76190476190477%
# GuideWire acc = 32.142857142857146%
# LiquidBottle acc = 70.61068702290076%
# Mask acc = 97.40259740259741%
# NGTube acc = 49.67741935483871%
# NasalCannula acc = 61.94690265486725%
# Needle acc = 90.35714285714286%
# OxygenMask acc = 84.21052631578947%
# PPESuit acc = 90.32258064516128%
# PharmaceuticalProduct acc = 78.73831775700934%
# Pill acc = 95.37815126050421%
# PillBottle acc = 88.37209302325581%
# PrefilledHumidifier acc = 76.92307692307693%
# PressureConnectingTube acc = 67.17557251908397%
# ReusableHumidifier acc = 87.28813559322035%
# SodiumChlorideBag acc = 88.9763779527559%
# SterileHumidifierAdapter acc = 85.45454545454545%
# SurgicalBlade acc = 92.92035398230088%
# SurgicalCap acc = 86.48648648648648%
# SurgicalSuit acc = 21.96969696969697%
# Syringe acc = 96.95817490494296%
# TrachealTube acc = 47.706422018348626%
# UrineBag acc = 79.16666666666666%
# Vaccinebottle acc = 81.69014084507043%
# WingedInfusionSet acc = 78.0701754385965%
#
#
#
# all_avg_eachclass = 75.28505846368596%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 96,   0,   0, ...,   0,   0,   0],
#        [  1, 125,   0, ...,   0,   0,   1],
#        [  0,   0,  98, ...,   1,   1,  10],
#        ...,
#        [  0,   0,   0, ...,  95,   0,   0],
#        [  0,   0,   0, ...,   0, 174,   0],
#        [  0,   0,   0, ...,   2,   0,  89]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[82.75862069,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.68027211, 85.03401361,  0.        , ...,  0.        ,
#          0.        ,  0.68027211],
#        [ 0.        ,  0.        , 73.13432836, ...,  0.74626866,
#          0.74626866,  7.46268657],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 79.16666667,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         81.69014085,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  1.75438596,
#          0.        , 78.07017544]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
