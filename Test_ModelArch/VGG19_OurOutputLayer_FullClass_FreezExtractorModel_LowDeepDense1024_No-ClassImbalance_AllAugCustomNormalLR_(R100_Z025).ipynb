# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.VGG19(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-4].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 25088)             20024384
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 45,757,545
# Trainable params: 25,733,161
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 49s 375ms/step - loss: 4.1479 - accuracy: 0.3806 - val_loss: 1.4788 - val_accuracy: 0.5990
# Epoch 2/2000
# 49/49 [==============================] - 10s 199ms/step - loss: 1.1831 - accuracy: 0.6795 - val_loss: 1.1172 - val_accuracy: 0.6792
# Epoch 3/2000
# 49/49 [==============================] - 10s 199ms/step - loss: 0.7339 - accuracy: 0.8081 - val_loss: 0.9157 - val_accuracy: 0.7296
# Epoch 4/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.5047 - accuracy: 0.8711 - val_loss: 0.7934 - val_accuracy: 0.7594
# Epoch 5/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.3609 - accuracy: 0.9150 - val_loss: 0.7107 - val_accuracy: 0.7788
# Epoch 6/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.2803 - accuracy: 0.9325 - val_loss: 0.7459 - val_accuracy: 0.7827
# Epoch 7/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.2315 - accuracy: 0.9486 - val_loss: 0.7094 - val_accuracy: 0.7943
# Epoch 8/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.2102 - accuracy: 0.9538 - val_loss: 0.6874 - val_accuracy: 0.7956
# Epoch 9/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.1681 - accuracy: 0.9616 - val_loss: 0.7359 - val_accuracy: 0.7827
# Epoch 10/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.1496 - accuracy: 0.9674 - val_loss: 0.7811 - val_accuracy: 0.7671
# Epoch 11/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.1323 - accuracy: 0.9683 - val_loss: 0.7751 - val_accuracy: 0.7633
# Epoch 12/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.1178 - accuracy: 0.9748 - val_loss: 0.7276 - val_accuracy: 0.7840
# Epoch 13/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0948 - accuracy: 0.9777 - val_loss: 0.8534 - val_accuracy: 0.7671
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0722 - accuracy: 0.9842 - val_loss: 0.6577 - val_accuracy: 0.8124
# Epoch 15/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0533 - accuracy: 0.9887 - val_loss: 0.6497 - val_accuracy: 0.8085
# Epoch 16/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0530 - accuracy: 0.9900 - val_loss: 0.6493 - val_accuracy: 0.8008
# Epoch 17/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0522 - accuracy: 0.9900 - val_loss: 0.6330 - val_accuracy: 0.8124
# Epoch 18/2000
# 49/49 [==============================] - 10s 202ms/step - loss: 0.0472 - accuracy: 0.9897 - val_loss: 0.6355 - val_accuracy: 0.8124
# Epoch 19/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0455 - accuracy: 0.9910 - val_loss: 0.6295 - val_accuracy: 0.8176
# Epoch 20/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0450 - accuracy: 0.9922 - val_loss: 0.6384 - val_accuracy: 0.8163
# Epoch 21/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0487 - accuracy: 0.9913 - val_loss: 0.6211 - val_accuracy: 0.8176
# Epoch 22/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0435 - accuracy: 0.9922 - val_loss: 0.6352 - val_accuracy: 0.8163
# Epoch 23/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0438 - accuracy: 0.9916 - val_loss: 0.6440 - val_accuracy: 0.8137
# Epoch 24/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0449 - accuracy: 0.9922 - val_loss: 0.6221 - val_accuracy: 0.8176
# Epoch 25/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0413 - accuracy: 0.9922 - val_loss: 0.6217 - val_accuracy: 0.8241
# Epoch 26/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0393 - accuracy: 0.9932 - val_loss: 0.6311 - val_accuracy: 0.8202
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 27/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0365 - accuracy: 0.9926 - val_loss: 0.6103 - val_accuracy: 0.8202
# Epoch 28/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0314 - accuracy: 0.9952 - val_loss: 0.6175 - val_accuracy: 0.8241
# Epoch 29/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0345 - accuracy: 0.9942 - val_loss: 0.6208 - val_accuracy: 0.8202
# Epoch 30/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0331 - accuracy: 0.9942 - val_loss: 0.6189 - val_accuracy: 0.8189
# Epoch 31/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0324 - accuracy: 0.9942 - val_loss: 0.6147 - val_accuracy: 0.8215
# Epoch 32/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0335 - accuracy: 0.9961 - val_loss: 0.6152 - val_accuracy: 0.8215
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 33/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0306 - accuracy: 0.9952 - val_loss: 0.6139 - val_accuracy: 0.8202
# Epoch 34/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0292 - accuracy: 0.9952 - val_loss: 0.6128 - val_accuracy: 0.8176
# Epoch 35/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0322 - accuracy: 0.9948 - val_loss: 0.6150 - val_accuracy: 0.8189
# Epoch 36/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0317 - accuracy: 0.9952 - val_loss: 0.6129 - val_accuracy: 0.8215
# Epoch 37/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0293 - accuracy: 0.9952 - val_loss: 0.6103 - val_accuracy: 0.8228
# Epoch 38/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0287 - accuracy: 0.9952 - val_loss: 0.6100 - val_accuracy: 0.8215
# Epoch 39/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0287 - accuracy: 0.9948 - val_loss: 0.6110 - val_accuracy: 0.8202
# Epoch 40/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0316 - accuracy: 0.9952 - val_loss: 0.6089 - val_accuracy: 0.8254
# Epoch 41/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0297 - accuracy: 0.9958 - val_loss: 0.6093 - val_accuracy: 0.8241
# Epoch 42/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0326 - accuracy: 0.9935 - val_loss: 0.6101 - val_accuracy: 0.8241
# Epoch 43/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0296 - accuracy: 0.9955 - val_loss: 0.6097 - val_accuracy: 0.8228
# Epoch 44/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0313 - accuracy: 0.9958 - val_loss: 0.6089 - val_accuracy: 0.8241
# Epoch 45/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0292 - accuracy: 0.9952 - val_loss: 0.6089 - val_accuracy: 0.8241
# Epoch 46/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0290 - accuracy: 0.9964 - val_loss: 0.6102 - val_accuracy: 0.8228
# Epoch 47/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0306 - accuracy: 0.9955 - val_loss: 0.6091 - val_accuracy: 0.8228
# Epoch 48/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0269 - accuracy: 0.9964 - val_loss: 0.6127 - val_accuracy: 0.8215
# Epoch 49/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0291 - accuracy: 0.9964 - val_loss: 0.6111 - val_accuracy: 0.8241
# Epoch 50/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0283 - accuracy: 0.9955 - val_loss: 0.6100 - val_accuracy: 0.8228
# Epoch 51/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0299 - accuracy: 0.9935 - val_loss: 0.6072 - val_accuracy: 0.8266
# Epoch 52/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0299 - accuracy: 0.9948 - val_loss: 0.6140 - val_accuracy: 0.8215
# Epoch 53/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0297 - accuracy: 0.9952 - val_loss: 0.6122 - val_accuracy: 0.8228
# Epoch 54/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0302 - accuracy: 0.9955 - val_loss: 0.6125 - val_accuracy: 0.8215
# Epoch 55/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0278 - accuracy: 0.9971 - val_loss: 0.6153 - val_accuracy: 0.8266
# Epoch 56/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0278 - accuracy: 0.9971 - val_loss: 0.6147 - val_accuracy: 0.8228
# Epoch 57/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0277 - accuracy: 0.9964 - val_loss: 0.6167 - val_accuracy: 0.8215
# Epoch 58/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0281 - accuracy: 0.9955 - val_loss: 0.6124 - val_accuracy: 0.8228
# Epoch 59/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0272 - accuracy: 0.9964 - val_loss: 0.6100 - val_accuracy: 0.8215
# Epoch 60/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0297 - accuracy: 0.9961 - val_loss: 0.6106 - val_accuracy: 0.8228
# Epoch 61/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0283 - accuracy: 0.9958 - val_loss: 0.6140 - val_accuracy: 0.8228
# Epoch 62/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0281 - accuracy: 0.9964 - val_loss: 0.6119 - val_accuracy: 0.8241
# Epoch 63/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0278 - accuracy: 0.9958 - val_loss: 0.6147 - val_accuracy: 0.8228
# Epoch 64/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0296 - accuracy: 0.9961 - val_loss: 0.6118 - val_accuracy: 0.8215
# Epoch 65/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0274 - accuracy: 0.9964 - val_loss: 0.6107 - val_accuracy: 0.8215
# Epoch 66/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0272 - accuracy: 0.9955 - val_loss: 0.6119 - val_accuracy: 0.8215
# Epoch 67/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0283 - accuracy: 0.9955 - val_loss: 0.6087 - val_accuracy: 0.8228
# Epoch 68/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0255 - accuracy: 0.9961 - val_loss: 0.6110 - val_accuracy: 0.8228
# Epoch 69/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0294 - accuracy: 0.9952 - val_loss: 0.6123 - val_accuracy: 0.8215
# Epoch 70/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0299 - accuracy: 0.9945 - val_loss: 0.6077 - val_accuracy: 0.8215
# Epoch 71/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0290 - accuracy: 0.9955 - val_loss: 0.6106 - val_accuracy: 0.8202
# Epoch 72/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0284 - accuracy: 0.9952 - val_loss: 0.6100 - val_accuracy: 0.8241
# Epoch 73/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0271 - accuracy: 0.9961 - val_loss: 0.6126 - val_accuracy: 0.8215
# Epoch 74/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0263 - accuracy: 0.9968 - val_loss: 0.6086 - val_accuracy: 0.8241
# Epoch 75/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0271 - accuracy: 0.9958 - val_loss: 0.6074 - val_accuracy: 0.8228
# Epoch 76/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0264 - accuracy: 0.9964 - val_loss: 0.6142 - val_accuracy: 0.8202
# Epoch 77/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0253 - accuracy: 0.9974 - val_loss: 0.6124 - val_accuracy: 0.8215
# Epoch 78/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0275 - accuracy: 0.9961 - val_loss: 0.6116 - val_accuracy: 0.8215
# Epoch 79/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0263 - accuracy: 0.9961 - val_loss: 0.6123 - val_accuracy: 0.8241
# Epoch 80/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0288 - accuracy: 0.9958 - val_loss: 0.6150 - val_accuracy: 0.8241
# Epoch 81/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0272 - accuracy: 0.9971 - val_loss: 0.6141 - val_accuracy: 0.8254
# Epoch 82/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0277 - accuracy: 0.9955 - val_loss: 0.6181 - val_accuracy: 0.8228
# Epoch 83/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0251 - accuracy: 0.9968 - val_loss: 0.6131 - val_accuracy: 0.8254
# Epoch 84/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0268 - accuracy: 0.9958 - val_loss: 0.6114 - val_accuracy: 0.8266
# Epoch 85/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0254 - accuracy: 0.9964 - val_loss: 0.6107 - val_accuracy: 0.8254
# Epoch 86/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0258 - accuracy: 0.9961 - val_loss: 0.6086 - val_accuracy: 0.8241
# Epoch 87/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0285 - accuracy: 0.9955 - val_loss: 0.6140 - val_accuracy: 0.8189
# Epoch 88/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0267 - accuracy: 0.9961 - val_loss: 0.6059 - val_accuracy: 0.8228
# Epoch 89/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0252 - accuracy: 0.9964 - val_loss: 0.6174 - val_accuracy: 0.8215
# Epoch 90/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0267 - accuracy: 0.9968 - val_loss: 0.6122 - val_accuracy: 0.8254
# Epoch 91/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0254 - accuracy: 0.9952 - val_loss: 0.6137 - val_accuracy: 0.8241
# Epoch 92/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0254 - accuracy: 0.9961 - val_loss: 0.6103 - val_accuracy: 0.8215
# Epoch 93/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0244 - accuracy: 0.9964 - val_loss: 0.6197 - val_accuracy: 0.8228
# Epoch 94/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0239 - accuracy: 0.9974 - val_loss: 0.6144 - val_accuracy: 0.8241
# Epoch 95/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0247 - accuracy: 0.9958 - val_loss: 0.6147 - val_accuracy: 0.8215
# Epoch 96/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0247 - accuracy: 0.9961 - val_loss: 0.6177 - val_accuracy: 0.8228
# Epoch 97/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0241 - accuracy: 0.9974 - val_loss: 0.6136 - val_accuracy: 0.8228
# Epoch 98/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0264 - accuracy: 0.9955 - val_loss: 0.6146 - val_accuracy: 0.8228
# Epoch 99/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0237 - accuracy: 0.9981 - val_loss: 0.6103 - val_accuracy: 0.8228
# Epoch 100/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0267 - accuracy: 0.9968 - val_loss: 0.6072 - val_accuracy: 0.8241
# Epoch 101/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0251 - accuracy: 0.9964 - val_loss: 0.6138 - val_accuracy: 0.8228
# Epoch 102/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0240 - accuracy: 0.9964 - val_loss: 0.6092 - val_accuracy: 0.8215
# Epoch 103/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0235 - accuracy: 0.9964 - val_loss: 0.6126 - val_accuracy: 0.8254
# Epoch 104/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0215 - accuracy: 0.9984 - val_loss: 0.6211 - val_accuracy: 0.8228
# Epoch 105/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0259 - accuracy: 0.9961 - val_loss: 0.6103 - val_accuracy: 0.8189
# Epoch 106/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0232 - accuracy: 0.9977 - val_loss: 0.6166 - val_accuracy: 0.8215
# Epoch 107/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0244 - accuracy: 0.9968 - val_loss: 0.6091 - val_accuracy: 0.8202
# Epoch 108/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0247 - accuracy: 0.9964 - val_loss: 0.6095 - val_accuracy: 0.8215
# Epoch 109/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0233 - accuracy: 0.9974 - val_loss: 0.6130 - val_accuracy: 0.8241
# Epoch 110/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0226 - accuracy: 0.9971 - val_loss: 0.6110 - val_accuracy: 0.8241
# Epoch 111/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0242 - accuracy: 0.9961 - val_loss: 0.6167 - val_accuracy: 0.8279
# Epoch 112/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0230 - accuracy: 0.9974 - val_loss: 0.6187 - val_accuracy: 0.8266
# Epoch 113/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0218 - accuracy: 0.9977 - val_loss: 0.6160 - val_accuracy: 0.8254
# Epoch 114/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0234 - accuracy: 0.9964 - val_loss: 0.6186 - val_accuracy: 0.8266
# Epoch 115/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0219 - accuracy: 0.9968 - val_loss: 0.6209 - val_accuracy: 0.8292
# Epoch 116/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0206 - accuracy: 0.9981 - val_loss: 0.6234 - val_accuracy: 0.8228
# Epoch 117/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0245 - accuracy: 0.9952 - val_loss: 0.6221 - val_accuracy: 0.8254
# Epoch 118/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0221 - accuracy: 0.9981 - val_loss: 0.6131 - val_accuracy: 0.8228
# Epoch 119/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0218 - accuracy: 0.9964 - val_loss: 0.6151 - val_accuracy: 0.8241
# Epoch 120/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0210 - accuracy: 0.9971 - val_loss: 0.6181 - val_accuracy: 0.8254
# Epoch 121/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0230 - accuracy: 0.9961 - val_loss: 0.6165 - val_accuracy: 0.8266
# Epoch 122/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0226 - accuracy: 0.9964 - val_loss: 0.6131 - val_accuracy: 0.8241
# Epoch 123/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0217 - accuracy: 0.9974 - val_loss: 0.6157 - val_accuracy: 0.8266
# Epoch 124/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0227 - accuracy: 0.9968 - val_loss: 0.6177 - val_accuracy: 0.8241
# Epoch 125/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0229 - accuracy: 0.9955 - val_loss: 0.6120 - val_accuracy: 0.8254
# Epoch 126/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0230 - accuracy: 0.9971 - val_loss: 0.6103 - val_accuracy: 0.8228
# Epoch 127/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0229 - accuracy: 0.9968 - val_loss: 0.6164 - val_accuracy: 0.8215
# Epoch 128/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0206 - accuracy: 0.9984 - val_loss: 0.6197 - val_accuracy: 0.8241
# Epoch 129/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0215 - accuracy: 0.9974 - val_loss: 0.6199 - val_accuracy: 0.8215
# Epoch 130/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0226 - accuracy: 0.9971 - val_loss: 0.6173 - val_accuracy: 0.8215
# Epoch 131/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0201 - accuracy: 0.9974 - val_loss: 0.6138 - val_accuracy: 0.8241
# Epoch 132/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0206 - accuracy: 0.9968 - val_loss: 0.6114 - val_accuracy: 0.8241
# Epoch 133/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0229 - accuracy: 0.9958 - val_loss: 0.6126 - val_accuracy: 0.8254
# Epoch 134/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0204 - accuracy: 0.9984 - val_loss: 0.6198 - val_accuracy: 0.8215
# Epoch 135/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0196 - accuracy: 0.9981 - val_loss: 0.6201 - val_accuracy: 0.8266
# Epoch 136/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0210 - accuracy: 0.9977 - val_loss: 0.6128 - val_accuracy: 0.8228
# Epoch 137/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0216 - accuracy: 0.9977 - val_loss: 0.6178 - val_accuracy: 0.8202
# Epoch 138/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0199 - accuracy: 0.9987 - val_loss: 0.6186 - val_accuracy: 0.8202
# Epoch 139/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0194 - accuracy: 0.9977 - val_loss: 0.6186 - val_accuracy: 0.8228
# Epoch 140/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0204 - accuracy: 0.9981 - val_loss: 0.6115 - val_accuracy: 0.8228
# Epoch 141/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0217 - accuracy: 0.9974 - val_loss: 0.6183 - val_accuracy: 0.8228
# Epoch 142/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0199 - accuracy: 0.9974 - val_loss: 0.6162 - val_accuracy: 0.8215
# Epoch 143/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0211 - accuracy: 0.9971 - val_loss: 0.6232 - val_accuracy: 0.8228
# Epoch 144/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0217 - accuracy: 0.9977 - val_loss: 0.6017 - val_accuracy: 0.8254
# Epoch 145/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0198 - accuracy: 0.9968 - val_loss: 0.6141 - val_accuracy: 0.8266
# Epoch 146/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0209 - accuracy: 0.9977 - val_loss: 0.6104 - val_accuracy: 0.8215
# Epoch 147/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0209 - accuracy: 0.9971 - val_loss: 0.6166 - val_accuracy: 0.8241
# Epoch 148/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0198 - accuracy: 0.9981 - val_loss: 0.6228 - val_accuracy: 0.8241
# Epoch 149/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0194 - accuracy: 0.9977 - val_loss: 0.6180 - val_accuracy: 0.8215
# Epoch 150/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0182 - accuracy: 0.9981 - val_loss: 0.6243 - val_accuracy: 0.8202
# Epoch 151/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0200 - accuracy: 0.9974 - val_loss: 0.6186 - val_accuracy: 0.8228
# Epoch 152/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0200 - accuracy: 0.9984 - val_loss: 0.6190 - val_accuracy: 0.8228
# Epoch 153/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0200 - accuracy: 0.9977 - val_loss: 0.6141 - val_accuracy: 0.8254
# Epoch 154/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0191 - accuracy: 0.9984 - val_loss: 0.6151 - val_accuracy: 0.8241
# Epoch 155/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0175 - accuracy: 0.9987 - val_loss: 0.6095 - val_accuracy: 0.8228
# Epoch 156/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0195 - accuracy: 0.9987 - val_loss: 0.6116 - val_accuracy: 0.8266
# Epoch 157/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0188 - accuracy: 0.9971 - val_loss: 0.6103 - val_accuracy: 0.8215
# Epoch 158/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0192 - accuracy: 0.9974 - val_loss: 0.6099 - val_accuracy: 0.8228
# Epoch 159/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0179 - accuracy: 0.9977 - val_loss: 0.6152 - val_accuracy: 0.8228
# Epoch 160/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0181 - accuracy: 0.9977 - val_loss: 0.6158 - val_accuracy: 0.8241
# Epoch 161/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0177 - accuracy: 0.9987 - val_loss: 0.6186 - val_accuracy: 0.8202
# Epoch 162/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0169 - accuracy: 0.9981 - val_loss: 0.6208 - val_accuracy: 0.8228
# Epoch 163/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0181 - accuracy: 0.9981 - val_loss: 0.6293 - val_accuracy: 0.8254
# Epoch 164/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0192 - accuracy: 0.9977 - val_loss: 0.6218 - val_accuracy: 0.8228
# Epoch 165/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0165 - accuracy: 0.9987 - val_loss: 0.6169 - val_accuracy: 0.8202
# Epoch 166/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0176 - accuracy: 0.9987 - val_loss: 0.6184 - val_accuracy: 0.8241
# Epoch 167/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0176 - accuracy: 0.9977 - val_loss: 0.6210 - val_accuracy: 0.8241
# Epoch 168/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0174 - accuracy: 0.9981 - val_loss: 0.6206 - val_accuracy: 0.8228
# Epoch 169/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0170 - accuracy: 0.9977 - val_loss: 0.6227 - val_accuracy: 0.8215
# Epoch 170/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0186 - accuracy: 0.9977 - val_loss: 0.6266 - val_accuracy: 0.8241
# Epoch 171/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0168 - accuracy: 0.9984 - val_loss: 0.6234 - val_accuracy: 0.8241
# Epoch 172/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0175 - accuracy: 0.9984 - val_loss: 0.6170 - val_accuracy: 0.8241
# Epoch 173/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0175 - accuracy: 0.9981 - val_loss: 0.6228 - val_accuracy: 0.8176
# Epoch 174/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0180 - accuracy: 0.9974 - val_loss: 0.6221 - val_accuracy: 0.8202
# Epoch 175/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0176 - accuracy: 0.9977 - val_loss: 0.6298 - val_accuracy: 0.8228
# Epoch 176/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0155 - accuracy: 0.9981 - val_loss: 0.6173 - val_accuracy: 0.8202
# Epoch 177/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0173 - accuracy: 0.9977 - val_loss: 0.6260 - val_accuracy: 0.8202
# Epoch 178/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0160 - accuracy: 0.9981 - val_loss: 0.6277 - val_accuracy: 0.8215
# Epoch 179/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0176 - accuracy: 0.9981 - val_loss: 0.6233 - val_accuracy: 0.8241
# Epoch 180/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0178 - accuracy: 0.9977 - val_loss: 0.6228 - val_accuracy: 0.8202
# Epoch 181/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0159 - accuracy: 0.9974 - val_loss: 0.6258 - val_accuracy: 0.8189
# Epoch 182/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0171 - accuracy: 0.9981 - val_loss: 0.6283 - val_accuracy: 0.8202
# Epoch 183/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0156 - accuracy: 0.9984 - val_loss: 0.6223 - val_accuracy: 0.8215
# Epoch 184/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0145 - accuracy: 0.9987 - val_loss: 0.6256 - val_accuracy: 0.8176
# Epoch 185/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0162 - accuracy: 0.9987 - val_loss: 0.6267 - val_accuracy: 0.8202
# Epoch 186/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0151 - accuracy: 0.9984 - val_loss: 0.6243 - val_accuracy: 0.8202
# Epoch 187/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0171 - accuracy: 0.9981 - val_loss: 0.6230 - val_accuracy: 0.8215
# Epoch 188/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0159 - accuracy: 0.9990 - val_loss: 0.6258 - val_accuracy: 0.8189
# Epoch 189/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0156 - accuracy: 0.9987 - val_loss: 0.6248 - val_accuracy: 0.8189
# Epoch 190/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0155 - accuracy: 0.9990 - val_loss: 0.6315 - val_accuracy: 0.8228
# Epoch 191/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0154 - accuracy: 0.9990 - val_loss: 0.6261 - val_accuracy: 0.8215
# Epoch 192/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0165 - accuracy: 0.9977 - val_loss: 0.6235 - val_accuracy: 0.8241
# Epoch 193/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0148 - accuracy: 0.9984 - val_loss: 0.6320 - val_accuracy: 0.8228
# Epoch 194/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0157 - accuracy: 0.9994 - val_loss: 0.6223 - val_accuracy: 0.8241
# Epoch 195/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0148 - accuracy: 0.9984 - val_loss: 0.6273 - val_accuracy: 0.8215
# Epoch 196/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0143 - accuracy: 0.9984 - val_loss: 0.6264 - val_accuracy: 0.8189
# Epoch 197/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0161 - accuracy: 0.9987 - val_loss: 0.6289 - val_accuracy: 0.8202
# Epoch 198/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0151 - accuracy: 0.9990 - val_loss: 0.6280 - val_accuracy: 0.8189
# Epoch 199/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0150 - accuracy: 0.9981 - val_loss: 0.6251 - val_accuracy: 0.8215
# Epoch 200/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0157 - accuracy: 0.9981 - val_loss: 0.6271 - val_accuracy: 0.8266
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0158 - accuracy: 0.9984 - val_loss: 0.6242 - val_accuracy: 0.8241
# Epoch 202/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0159 - accuracy: 0.9987 - val_loss: 0.6261 - val_accuracy: 0.8215
# Epoch 203/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0145 - accuracy: 0.9987 - val_loss: 0.6231 - val_accuracy: 0.8228
# Epoch 204/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0158 - accuracy: 0.9990 - val_loss: 0.6109 - val_accuracy: 0.8241
# Epoch 205/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0149 - accuracy: 0.9984 - val_loss: 0.6187 - val_accuracy: 0.8228
# Epoch 206/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0154 - accuracy: 0.9984 - val_loss: 0.6238 - val_accuracy: 0.8215
# Epoch 207/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0146 - accuracy: 0.9984 - val_loss: 0.6293 - val_accuracy: 0.8215
# Epoch 208/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0146 - accuracy: 0.9987 - val_loss: 0.6256 - val_accuracy: 0.8228
# Epoch 209/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0145 - accuracy: 0.9984 - val_loss: 0.6335 - val_accuracy: 0.8215
# Epoch 210/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0130 - accuracy: 0.9987 - val_loss: 0.6357 - val_accuracy: 0.8215
# Epoch 211/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0131 - accuracy: 0.9987 - val_loss: 0.6277 - val_accuracy: 0.8215
# Epoch 212/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0139 - accuracy: 0.9977 - val_loss: 0.6270 - val_accuracy: 0.8228
# Epoch 213/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0135 - accuracy: 0.9984 - val_loss: 0.6323 - val_accuracy: 0.8215
# Epoch 214/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0152 - accuracy: 0.9984 - val_loss: 0.6266 - val_accuracy: 0.8215
# Epoch 215/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0143 - accuracy: 0.9984 - val_loss: 0.6274 - val_accuracy: 0.8228
# Epoch 216/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0137 - accuracy: 0.9987 - val_loss: 0.6271 - val_accuracy: 0.8228
# Epoch 217/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0141 - accuracy: 0.9990 - val_loss: 0.6251 - val_accuracy: 0.8266
# Epoch 218/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0117 - accuracy: 0.9987 - val_loss: 0.6291 - val_accuracy: 0.8215
# Epoch 219/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0123 - accuracy: 0.9994 - val_loss: 0.6308 - val_accuracy: 0.8241
# Epoch 220/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0132 - accuracy: 0.9987 - val_loss: 0.6362 - val_accuracy: 0.8215
# Epoch 221/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0135 - accuracy: 0.9984 - val_loss: 0.6303 - val_accuracy: 0.8241
# Epoch 222/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0141 - accuracy: 0.9987 - val_loss: 0.6274 - val_accuracy: 0.8228
# Epoch 223/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0128 - accuracy: 0.9987 - val_loss: 0.6364 - val_accuracy: 0.8189
# Epoch 224/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0139 - accuracy: 0.9981 - val_loss: 0.6261 - val_accuracy: 0.8228
# Epoch 225/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0131 - accuracy: 0.9984 - val_loss: 0.6258 - val_accuracy: 0.8254
# Epoch 226/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.6342 - val_accuracy: 0.8228
# Epoch 227/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0134 - accuracy: 0.9981 - val_loss: 0.6353 - val_accuracy: 0.8176
# Epoch 228/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0141 - accuracy: 0.9990 - val_loss: 0.6310 - val_accuracy: 0.8215
# Epoch 229/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0118 - accuracy: 0.9990 - val_loss: 0.6286 - val_accuracy: 0.8228
# Epoch 230/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0112 - accuracy: 0.9994 - val_loss: 0.6297 - val_accuracy: 0.8215
# Epoch 231/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0126 - accuracy: 0.9994 - val_loss: 0.6217 - val_accuracy: 0.8228
# Epoch 232/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0132 - accuracy: 0.9990 - val_loss: 0.6361 - val_accuracy: 0.8202
# Epoch 233/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0116 - accuracy: 0.9997 - val_loss: 0.6314 - val_accuracy: 0.8228
# Epoch 234/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0134 - accuracy: 0.9981 - val_loss: 0.6400 - val_accuracy: 0.8189
# Epoch 235/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0118 - accuracy: 0.9994 - val_loss: 0.6414 - val_accuracy: 0.8176
# Epoch 236/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0114 - accuracy: 0.9990 - val_loss: 0.6403 - val_accuracy: 0.8215
# Epoch 237/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0118 - accuracy: 0.9990 - val_loss: 0.6467 - val_accuracy: 0.8228
# Epoch 238/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0122 - accuracy: 0.9990 - val_loss: 0.6355 - val_accuracy: 0.8254
# Epoch 239/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0139 - accuracy: 0.9984 - val_loss: 0.6346 - val_accuracy: 0.8215
# Epoch 240/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0128 - accuracy: 0.9987 - val_loss: 0.6318 - val_accuracy: 0.8241
# Epoch 241/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0109 - accuracy: 0.9997 - val_loss: 0.6388 - val_accuracy: 0.8228
# Epoch 242/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0129 - accuracy: 0.9990 - val_loss: 0.6344 - val_accuracy: 0.8215
# Epoch 243/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0131 - accuracy: 0.9981 - val_loss: 0.6335 - val_accuracy: 0.8241
# Epoch 244/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0112 - accuracy: 0.9994 - val_loss: 0.6291 - val_accuracy: 0.8228
# Epoch 245/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0107 - accuracy: 0.9997 - val_loss: 0.6270 - val_accuracy: 0.8228
# Epoch 246/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0112 - accuracy: 0.9994 - val_loss: 0.6277 - val_accuracy: 0.8202
# Epoch 247/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0112 - accuracy: 0.9994 - val_loss: 0.6323 - val_accuracy: 0.8215
# Epoch 248/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0123 - accuracy: 0.9990 - val_loss: 0.6412 - val_accuracy: 0.8215
# Epoch 249/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0111 - accuracy: 0.9987 - val_loss: 0.6406 - val_accuracy: 0.8228
# Epoch 250/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0127 - accuracy: 0.9987 - val_loss: 0.6346 - val_accuracy: 0.8241
# Epoch 251/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0108 - accuracy: 0.9994 - val_loss: 0.6427 - val_accuracy: 0.8228
# Epoch 252/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0119 - accuracy: 0.9987 - val_loss: 0.6359 - val_accuracy: 0.8202
# Epoch 253/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0114 - accuracy: 0.9994 - val_loss: 0.6392 - val_accuracy: 0.8215
# Epoch 254/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0126 - accuracy: 0.9990 - val_loss: 0.6452 - val_accuracy: 0.8202
# Epoch 255/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0116 - accuracy: 0.9994 - val_loss: 0.6312 - val_accuracy: 0.8215
# Epoch 256/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0111 - accuracy: 0.9990 - val_loss: 0.6384 - val_accuracy: 0.8215
# Epoch 257/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0106 - accuracy: 0.9990 - val_loss: 0.6373 - val_accuracy: 0.8241
# Epoch 258/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0111 - accuracy: 0.9997 - val_loss: 0.6430 - val_accuracy: 0.8215
# Epoch 259/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.6349 - val_accuracy: 0.8202
# Epoch 260/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0091 - accuracy: 0.9997 - val_loss: 0.6435 - val_accuracy: 0.8241
# Epoch 261/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0098 - accuracy: 0.9990 - val_loss: 0.6361 - val_accuracy: 0.8215
# Epoch 262/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0111 - accuracy: 0.9984 - val_loss: 0.6350 - val_accuracy: 0.8228
# Epoch 263/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0101 - accuracy: 0.9987 - val_loss: 0.6469 - val_accuracy: 0.8228
# Epoch 264/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0115 - accuracy: 0.9984 - val_loss: 0.6386 - val_accuracy: 0.8228
# Epoch 265/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0102 - accuracy: 0.9994 - val_loss: 0.6445 - val_accuracy: 0.8202
# Epoch 266/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0119 - accuracy: 0.9984 - val_loss: 0.6375 - val_accuracy: 0.8241
# Epoch 267/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0104 - accuracy: 0.9990 - val_loss: 0.6335 - val_accuracy: 0.8215
# Epoch 268/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0103 - accuracy: 0.9990 - val_loss: 0.6323 - val_accuracy: 0.8215
# Epoch 269/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0118 - accuracy: 0.9990 - val_loss: 0.6481 - val_accuracy: 0.8189
# Epoch 270/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0115 - accuracy: 0.9994 - val_loss: 0.6461 - val_accuracy: 0.8176
# Epoch 271/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0093 - accuracy: 0.9994 - val_loss: 0.6409 - val_accuracy: 0.8189
# Epoch 272/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0099 - accuracy: 0.9994 - val_loss: 0.6412 - val_accuracy: 0.8150
# Epoch 273/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.6448 - val_accuracy: 0.8189
# Epoch 274/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0097 - accuracy: 0.9994 - val_loss: 0.6464 - val_accuracy: 0.8202
# Epoch 275/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0106 - accuracy: 0.9994 - val_loss: 0.6387 - val_accuracy: 0.8228
# Epoch 276/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0102 - accuracy: 0.9994 - val_loss: 0.6326 - val_accuracy: 0.8163
# Epoch 277/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0096 - accuracy: 0.9994 - val_loss: 0.6391 - val_accuracy: 0.8228
# Epoch 278/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 0.6374 - val_accuracy: 0.8228
# Epoch 279/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0091 - accuracy: 0.9990 - val_loss: 0.6341 - val_accuracy: 0.8228
# Epoch 280/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0102 - accuracy: 0.9997 - val_loss: 0.6406 - val_accuracy: 0.8228
# Epoch 281/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.6451 - val_accuracy: 0.8228
# Epoch 282/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0101 - accuracy: 0.9990 - val_loss: 0.6411 - val_accuracy: 0.8279
# Epoch 283/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0103 - accuracy: 0.9990 - val_loss: 0.6345 - val_accuracy: 0.8241
# Epoch 284/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 0.6451 - val_accuracy: 0.8228
# Epoch 285/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0096 - accuracy: 0.9997 - val_loss: 0.6428 - val_accuracy: 0.8215
# Epoch 286/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0093 - accuracy: 0.9994 - val_loss: 0.6502 - val_accuracy: 0.8228
# Epoch 287/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0097 - accuracy: 0.9994 - val_loss: 0.6388 - val_accuracy: 0.8202
# Epoch 288/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.6439 - val_accuracy: 0.8215
# Epoch 289/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0088 - accuracy: 0.9994 - val_loss: 0.6330 - val_accuracy: 0.8202
# Epoch 290/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0107 - accuracy: 0.9987 - val_loss: 0.6450 - val_accuracy: 0.8189
# Epoch 291/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 0.6462 - val_accuracy: 0.8176
# Epoch 292/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0086 - accuracy: 0.9994 - val_loss: 0.6432 - val_accuracy: 0.8189
# Epoch 293/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0084 - accuracy: 0.9997 - val_loss: 0.6462 - val_accuracy: 0.8202
# Epoch 294/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0088 - accuracy: 0.9994 - val_loss: 0.6387 - val_accuracy: 0.8215
# Epoch 295/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.6427 - val_accuracy: 0.8215
# Epoch 296/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0094 - accuracy: 0.9994 - val_loss: 0.6515 - val_accuracy: 0.8202
# Epoch 297/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0086 - accuracy: 0.9997 - val_loss: 0.6498 - val_accuracy: 0.8215
# Epoch 298/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.6441 - val_accuracy: 0.8189
# Epoch 299/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0089 - accuracy: 0.9990 - val_loss: 0.6413 - val_accuracy: 0.8202
# Epoch 300/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 0.6363 - val_accuracy: 0.8189
# Epoch 301/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0095 - accuracy: 0.9994 - val_loss: 0.6356 - val_accuracy: 0.8202
# Epoch 302/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0092 - accuracy: 0.9994 - val_loss: 0.6382 - val_accuracy: 0.8215
# Epoch 303/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0082 - accuracy: 0.9997 - val_loss: 0.6513 - val_accuracy: 0.8241
# Epoch 304/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0082 - accuracy: 0.9990 - val_loss: 0.6427 - val_accuracy: 0.8202
# Epoch 305/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0080 - accuracy: 0.9994 - val_loss: 0.6479 - val_accuracy: 0.8215
# Epoch 306/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0081 - accuracy: 0.9997 - val_loss: 0.6568 - val_accuracy: 0.8150
# Epoch 307/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0094 - accuracy: 0.9997 - val_loss: 0.6448 - val_accuracy: 0.8189
# Epoch 308/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0087 - accuracy: 0.9994 - val_loss: 0.6491 - val_accuracy: 0.8215
# Epoch 309/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.6489 - val_accuracy: 0.8215
# Epoch 310/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0093 - accuracy: 0.9994 - val_loss: 0.6527 - val_accuracy: 0.8215
# Epoch 311/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0080 - accuracy: 0.9994 - val_loss: 0.6432 - val_accuracy: 0.8215
# Epoch 312/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.6440 - val_accuracy: 0.8189
# Epoch 313/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0088 - accuracy: 0.9994 - val_loss: 0.6434 - val_accuracy: 0.8241
# Epoch 314/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.6399 - val_accuracy: 0.8215
# Epoch 315/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0091 - accuracy: 0.9990 - val_loss: 0.6449 - val_accuracy: 0.8202
# Epoch 316/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 0.6329 - val_accuracy: 0.8266
# Epoch 317/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.6420 - val_accuracy: 0.8228
# Epoch 318/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0085 - accuracy: 0.9994 - val_loss: 0.6449 - val_accuracy: 0.8241
# Epoch 319/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.6463 - val_accuracy: 0.8215
# Epoch 320/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.6494 - val_accuracy: 0.8189
# Epoch 321/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.6408 - val_accuracy: 0.8189
# Epoch 322/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.6381 - val_accuracy: 0.8202
# Epoch 323/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.6400 - val_accuracy: 0.8215
# Epoch 324/2000
# ...
# Epoch 1898/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 8.2664e-05 - accuracy: 1.0000 - val_loss: 0.9056 - val_accuracy: 0.8266
# Epoch 1899/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 9.3612e-05 - accuracy: 1.0000 - val_loss: 0.9197 - val_accuracy: 0.8305
# Epoch 1900/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 7.2631e-05 - accuracy: 1.0000 - val_loss: 0.9320 - val_accuracy: 0.8228
# Epoch 1901/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 7.5738e-05 - accuracy: 1.0000 - val_loss: 0.9327 - val_accuracy: 0.8292
# Epoch 1902/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.2140e-05 - accuracy: 1.0000 - val_loss: 0.9245 - val_accuracy: 0.8266
# Epoch 1903/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.2796e-05 - accuracy: 1.0000 - val_loss: 0.9151 - val_accuracy: 0.8266
# Epoch 1904/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.4894e-05 - accuracy: 1.0000 - val_loss: 0.9223 - val_accuracy: 0.8279
# Epoch 1905/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.3859e-05 - accuracy: 1.0000 - val_loss: 0.9206 - val_accuracy: 0.8241
# Epoch 1906/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 6.1174e-05 - accuracy: 1.0000 - val_loss: 0.9280 - val_accuracy: 0.8266
# Epoch 1907/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.6099e-05 - accuracy: 1.0000 - val_loss: 0.9053 - val_accuracy: 0.8215
# Epoch 1908/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.6457e-05 - accuracy: 1.0000 - val_loss: 0.9004 - val_accuracy: 0.8254
# Epoch 1909/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.1611e-05 - accuracy: 1.0000 - val_loss: 0.9048 - val_accuracy: 0.8279
# Epoch 1910/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.3911e-05 - accuracy: 1.0000 - val_loss: 0.9033 - val_accuracy: 0.8241
# Epoch 1911/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.6107e-05 - accuracy: 1.0000 - val_loss: 0.9050 - val_accuracy: 0.8292
# Epoch 1912/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.9240e-05 - accuracy: 1.0000 - val_loss: 0.8978 - val_accuracy: 0.8305
# Epoch 1913/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.0350e-05 - accuracy: 1.0000 - val_loss: 0.8765 - val_accuracy: 0.8305
# Epoch 1914/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 7.4591e-05 - accuracy: 1.0000 - val_loss: 0.8962 - val_accuracy: 0.8292
# Epoch 1915/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 6.0732e-05 - accuracy: 1.0000 - val_loss: 0.9171 - val_accuracy: 0.8331
# Epoch 1916/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 4.3144e-05 - accuracy: 1.0000 - val_loss: 0.9048 - val_accuracy: 0.8305
# Epoch 1917/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.8916e-05 - accuracy: 1.0000 - val_loss: 0.8882 - val_accuracy: 0.8292
# Epoch 1918/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.9146e-05 - accuracy: 1.0000 - val_loss: 0.8874 - val_accuracy: 0.8266
# Epoch 1919/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.9637e-05 - accuracy: 1.0000 - val_loss: 0.8799 - val_accuracy: 0.8292
# Epoch 1920/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.3049e-05 - accuracy: 1.0000 - val_loss: 0.8847 - val_accuracy: 0.8266
# Epoch 1921/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 4.1705e-05 - accuracy: 1.0000 - val_loss: 0.8816 - val_accuracy: 0.8266
# Epoch 1922/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.2546e-05 - accuracy: 1.0000 - val_loss: 0.8863 - val_accuracy: 0.8266
# Epoch 1923/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.1213e-05 - accuracy: 1.0000 - val_loss: 0.8930 - val_accuracy: 0.8254
# Epoch 1924/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 4.5478e-05 - accuracy: 1.0000 - val_loss: 0.9263 - val_accuracy: 0.8254
# Epoch 1925/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.2003e-05 - accuracy: 1.0000 - val_loss: 0.9219 - val_accuracy: 0.8215
# Epoch 1926/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.1590e-05 - accuracy: 1.0000 - val_loss: 0.9220 - val_accuracy: 0.8241
# Epoch 1927/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.6346e-05 - accuracy: 1.0000 - val_loss: 0.9147 - val_accuracy: 0.8254
# Epoch 1928/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.9462e-05 - accuracy: 1.0000 - val_loss: 0.9199 - val_accuracy: 0.8241
# Epoch 1929/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.0446e-05 - accuracy: 1.0000 - val_loss: 0.9108 - val_accuracy: 0.8241
# Epoch 1930/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.8591e-05 - accuracy: 1.0000 - val_loss: 0.9059 - val_accuracy: 0.8254
# Epoch 1931/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.6734e-05 - accuracy: 1.0000 - val_loss: 0.8962 - val_accuracy: 0.8254
# Epoch 1932/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 4.1859e-05 - accuracy: 1.0000 - val_loss: 0.8809 - val_accuracy: 0.8279
# Epoch 1933/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.8774e-05 - accuracy: 1.0000 - val_loss: 0.8837 - val_accuracy: 0.8228
# Epoch 1934/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.2439e-04 - accuracy: 1.0000 - val_loss: 0.9379 - val_accuracy: 0.8266
# Epoch 1935/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 6.6353e-05 - accuracy: 1.0000 - val_loss: 0.9256 - val_accuracy: 0.8254
# Epoch 1936/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 6.7656e-05 - accuracy: 1.0000 - val_loss: 0.9135 - val_accuracy: 0.8292
# Epoch 1937/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.6309e-05 - accuracy: 1.0000 - val_loss: 0.9073 - val_accuracy: 0.8292
# Epoch 1938/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.5685e-05 - accuracy: 1.0000 - val_loss: 0.9064 - val_accuracy: 0.8305
# Epoch 1939/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.6663e-05 - accuracy: 1.0000 - val_loss: 0.9105 - val_accuracy: 0.8279
# Epoch 1940/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.5368e-05 - accuracy: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.8292
# Epoch 1941/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.9384e-05 - accuracy: 1.0000 - val_loss: 0.8983 - val_accuracy: 0.8254
# Epoch 1942/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.9276e-05 - accuracy: 1.0000 - val_loss: 0.8981 - val_accuracy: 0.8279
# Epoch 1943/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.8421e-05 - accuracy: 1.0000 - val_loss: 0.9069 - val_accuracy: 0.8279
# Epoch 1944/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.8688e-05 - accuracy: 1.0000 - val_loss: 0.9118 - val_accuracy: 0.8266
# Epoch 1945/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.6351e-05 - accuracy: 1.0000 - val_loss: 0.8982 - val_accuracy: 0.8266
# Epoch 1946/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.3288e-05 - accuracy: 1.0000 - val_loss: 0.8998 - val_accuracy: 0.8254
# Epoch 1947/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.4271e-05 - accuracy: 1.0000 - val_loss: 0.9273 - val_accuracy: 0.8241
# Epoch 1948/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.6605e-05 - accuracy: 1.0000 - val_loss: 0.9254 - val_accuracy: 0.8266
# Epoch 1949/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.2770e-05 - accuracy: 1.0000 - val_loss: 0.9190 - val_accuracy: 0.8266
# Epoch 1950/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.3437e-05 - accuracy: 1.0000 - val_loss: 0.9037 - val_accuracy: 0.8279
# Epoch 1951/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.9589e-05 - accuracy: 1.0000 - val_loss: 0.9116 - val_accuracy: 0.8254
# Epoch 1952/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.5007e-05 - accuracy: 1.0000 - val_loss: 0.9084 - val_accuracy: 0.8254
# Epoch 1953/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.8348e-05 - accuracy: 1.0000 - val_loss: 0.9001 - val_accuracy: 0.8254
# Epoch 1954/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.8242e-05 - accuracy: 1.0000 - val_loss: 0.9032 - val_accuracy: 0.8279
# Epoch 1955/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.7919e-05 - accuracy: 1.0000 - val_loss: 0.9075 - val_accuracy: 0.8266
# Epoch 1956/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.4201e-05 - accuracy: 1.0000 - val_loss: 0.9052 - val_accuracy: 0.8228
# Epoch 1957/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.0951e-05 - accuracy: 1.0000 - val_loss: 0.9038 - val_accuracy: 0.8228
# Epoch 1958/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.8023e-05 - accuracy: 1.0000 - val_loss: 0.9114 - val_accuracy: 0.8228
# Epoch 1959/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.1252e-05 - accuracy: 1.0000 - val_loss: 0.9047 - val_accuracy: 0.8241
# Epoch 1960/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.0435e-05 - accuracy: 1.0000 - val_loss: 0.9070 - val_accuracy: 0.8241
# Epoch 1961/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.7049e-05 - accuracy: 1.0000 - val_loss: 0.9179 - val_accuracy: 0.8241
# Epoch 1962/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.3137e-05 - accuracy: 1.0000 - val_loss: 0.9178 - val_accuracy: 0.8202
# Epoch 1963/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.8340e-05 - accuracy: 1.0000 - val_loss: 0.9138 - val_accuracy: 0.8241
# Epoch 1964/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.6572e-05 - accuracy: 1.0000 - val_loss: 0.9220 - val_accuracy: 0.8254
# Epoch 1965/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.3821e-05 - accuracy: 1.0000 - val_loss: 0.9186 - val_accuracy: 0.8254
# Epoch 1966/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.8156e-05 - accuracy: 1.0000 - val_loss: 0.9154 - val_accuracy: 0.8254
# Epoch 1967/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.5446e-05 - accuracy: 1.0000 - val_loss: 0.9147 - val_accuracy: 0.8266
# Epoch 1968/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.1391e-05 - accuracy: 1.0000 - val_loss: 0.9075 - val_accuracy: 0.8254
# Epoch 1969/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.2346e-05 - accuracy: 1.0000 - val_loss: 0.9053 - val_accuracy: 0.8266
# Epoch 1970/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.2725e-05 - accuracy: 1.0000 - val_loss: 0.8992 - val_accuracy: 0.8254
# Epoch 1971/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.2857e-05 - accuracy: 1.0000 - val_loss: 0.8998 - val_accuracy: 0.8254
# Epoch 1972/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.8737e-05 - accuracy: 1.0000 - val_loss: 0.9060 - val_accuracy: 0.8279
# Epoch 1973/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.5305e-05 - accuracy: 1.0000 - val_loss: 0.9096 - val_accuracy: 0.8241
# Epoch 1974/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.3976e-05 - accuracy: 1.0000 - val_loss: 0.9215 - val_accuracy: 0.8266
# Epoch 1975/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.8559e-05 - accuracy: 1.0000 - val_loss: 0.9241 - val_accuracy: 0.8305
# Epoch 1976/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.7199e-05 - accuracy: 1.0000 - val_loss: 0.9164 - val_accuracy: 0.8241
# Epoch 1977/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.5658e-05 - accuracy: 1.0000 - val_loss: 0.9315 - val_accuracy: 0.8254
# Epoch 1978/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.3604e-05 - accuracy: 1.0000 - val_loss: 0.9298 - val_accuracy: 0.8254
# Epoch 1979/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.0959e-05 - accuracy: 1.0000 - val_loss: 0.9328 - val_accuracy: 0.8241
# Epoch 1980/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.6016e-05 - accuracy: 1.0000 - val_loss: 0.9261 - val_accuracy: 0.8254
# Epoch 1981/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.8830e-05 - accuracy: 1.0000 - val_loss: 0.9212 - val_accuracy: 0.8254
# Epoch 1982/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.2473e-05 - accuracy: 1.0000 - val_loss: 0.9096 - val_accuracy: 0.8254
# Epoch 1983/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.3307e-05 - accuracy: 1.0000 - val_loss: 0.9046 - val_accuracy: 0.8254
# Epoch 1984/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.1746e-05 - accuracy: 1.0000 - val_loss: 0.9122 - val_accuracy: 0.8254
# Epoch 1985/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.9753e-05 - accuracy: 1.0000 - val_loss: 0.9210 - val_accuracy: 0.8266
# Epoch 1986/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.8699e-05 - accuracy: 1.0000 - val_loss: 0.9352 - val_accuracy: 0.8228
# Epoch 1987/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.9455e-05 - accuracy: 1.0000 - val_loss: 0.9307 - val_accuracy: 0.8215
# Epoch 1988/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.9276e-05 - accuracy: 1.0000 - val_loss: 0.9273 - val_accuracy: 0.8254
# Epoch 1989/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.2259e-05 - accuracy: 1.0000 - val_loss: 0.9356 - val_accuracy: 0.8254
# Epoch 1990/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.9623e-05 - accuracy: 1.0000 - val_loss: 0.9355 - val_accuracy: 0.8266
# Epoch 1991/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.4702e-05 - accuracy: 1.0000 - val_loss: 0.9325 - val_accuracy: 0.8254
# Epoch 1992/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.9769e-05 - accuracy: 1.0000 - val_loss: 0.9124 - val_accuracy: 0.8266
# Epoch 1993/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.9852e-05 - accuracy: 1.0000 - val_loss: 0.9173 - val_accuracy: 0.8279
# Epoch 1994/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.7815e-05 - accuracy: 1.0000 - val_loss: 0.9347 - val_accuracy: 0.8254
# Epoch 1995/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 2.7700e-05 - accuracy: 1.0000 - val_loss: 0.9276 - val_accuracy: 0.8254
# Epoch 1996/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.1220e-05 - accuracy: 1.0000 - val_loss: 0.9211 - val_accuracy: 0.8254
# Epoch 1997/2000
# 49/49 [==============================] - 10s 201ms/step - loss: 3.6810e-05 - accuracy: 1.0000 - val_loss: 0.9087 - val_accuracy: 0.8254
# Epoch 1998/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 3.8989e-05 - accuracy: 1.0000 - val_loss: 0.9289 - val_accuracy: 0.8241
# Epoch 1999/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 4.4215e-05 - accuracy: 1.0000 - val_loss: 0.9256 - val_accuracy: 0.8241
# Epoch 2000/2000
# 49/49 [==============================] - 10s 200ms/step - loss: 5.4719e-05 - accuracy: 1.0000 - val_loss: 0.9214 - val_accuracy: 0.8241
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 344ms/step - loss: 3.4603 - accuracy: 0.5251
# test_indoor_ds_results:test loss, test acc: [3.460272789001465, 0.525083601474762]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 408ms/step - loss: 5.8626 - accuracy: 0.4051
# test_outdoor_ds_results:test loss, test acc: [5.862569808959961, 0.40509554743766785]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 11s 281ms/step - loss: 3.8083 - accuracy: 0.5267
# test_belt_ds_results:test loss, test acc: [3.808290958404541, 0.5267452597618103]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG19_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 5s 152ms/step - loss: 2.1772 - accuracy: 0.5167
# 50/50 [==============================] - 8s 154ms/step - loss: 3.3960 - accuracy: 0.4124
# 35/35 [==============================] - 5s 155ms/step - loss: 2.4033 - accuracy: 0.5159
# Epoch200
#  test_indoor_acc=0.5167223811149597
#  test_outdoor_acc=0.412420392036438
#  test_belt_acc=0.5158658027648926
# 29/29 [==============================] - 5s 152ms/step - loss: 2.3345 - accuracy: 0.5251
# 50/50 [==============================] - 8s 155ms/step - loss: 3.9073 - accuracy: 0.4032
# 35/35 [==============================] - 5s 155ms/step - loss: 2.5878 - accuracy: 0.5222
# Epoch400
#  test_indoor_acc=0.525083601474762
#  test_outdoor_acc=0.403184711933136
#  test_belt_acc=0.5222121477127075
# 29/29 [==============================] - 5s 152ms/step - loss: 2.5357 - accuracy: 0.5240
# 50/50 [==============================] - 8s 155ms/step - loss: 4.1745 - accuracy: 0.4134
# 35/35 [==============================] - 5s 155ms/step - loss: 2.8372 - accuracy: 0.5190
# Epoch600
#  test_indoor_acc=0.5239687561988831
#  test_outdoor_acc=0.4133757948875427
#  test_belt_acc=0.5190389752388
# 29/29 [==============================] - 5s 152ms/step - loss: 2.6925 - accuracy: 0.5234
# 50/50 [==============================] - 8s 155ms/step - loss: 4.5386 - accuracy: 0.4105
# 35/35 [==============================] - 5s 155ms/step - loss: 2.9955 - accuracy: 0.5240
# Epoch800
#  test_indoor_acc=0.5234113931655884
#  test_outdoor_acc=0.41050955653190613
#  test_belt_acc=0.5240253806114197
# 29/29 [==============================] - 5s 152ms/step - loss: 2.8576 - accuracy: 0.5229
# 50/50 [==============================] - 8s 155ms/step - loss: 4.8985 - accuracy: 0.4057
# 35/35 [==============================] - 5s 156ms/step - loss: 3.1879 - accuracy: 0.5209
# Epoch1000
#  test_indoor_acc=0.5228539705276489
#  test_outdoor_acc=0.40573248267173767
#  test_belt_acc=0.5208522081375122
# 29/29 [==============================] - 5s 154ms/step - loss: 3.0072 - accuracy: 0.5256
# 50/50 [==============================] - 8s 156ms/step - loss: 5.0938 - accuracy: 0.4061
# 35/35 [==============================] - 5s 157ms/step - loss: 3.3172 - accuracy: 0.5254
# Epoch1200
#  test_indoor_acc=0.5256410241127014
#  test_outdoor_acc=0.4060509502887726
#  test_belt_acc=0.525385320186615
# 29/29 [==============================] - 5s 153ms/step - loss: 3.0368 - accuracy: 0.5301
# 50/50 [==============================] - 8s 155ms/step - loss: 5.4059 - accuracy: 0.4035
# 35/35 [==============================] - 5s 156ms/step - loss: 3.3766 - accuracy: 0.5286
# Epoch1400
#  test_indoor_acc=0.5301003456115723
#  test_outdoor_acc=0.4035031795501709
#  test_belt_acc=0.5285584926605225
# 29/29 [==============================] - 5s 153ms/step - loss: 3.2109 - accuracy: 0.5318
# 50/50 [==============================] - 8s 156ms/step - loss: 5.6414 - accuracy: 0.4045
# 35/35 [==============================] - 5s 156ms/step - loss: 3.5306 - accuracy: 0.5267
# Epoch1600
#  test_indoor_acc=0.5317725539207458
#  test_outdoor_acc=0.404458612203598
#  test_belt_acc=0.5267452597618103
# 29/29 [==============================] - 5s 154ms/step - loss: 3.3644 - accuracy: 0.5256
# 50/50 [==============================] - 8s 157ms/step - loss: 5.6444 - accuracy: 0.4054
# 35/35 [==============================] - 6s 157ms/step - loss: 3.6817 - accuracy: 0.5258
# Epoch1800
#  test_indoor_acc=0.5256410241127014
#  test_outdoor_acc=0.40541401505470276
#  test_belt_acc=0.5258386135101318
# 29/29 [==============================] - 5s 152ms/step - loss: 3.4603 - accuracy: 0.5251
# 50/50 [==============================] - 8s 155ms/step - loss: 5.8626 - accuracy: 0.4051
# 35/35 [==============================] - 5s 155ms/step - loss: 3.8083 - accuracy: 0.5267
# Epoch2000
#  test_indoor_acc=0.525083601474762
#  test_outdoor_acc=0.40509554743766785
#  test_belt_acc=0.5267452597618103

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.4876588086287181
# max index -> 7
# The [Epoch] of max acc -> 1600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.5167223811149597,
#  0.525083601474762,
#  0.5239687561988831,
#  0.5234113931655884,
#  0.5228539705276489,
#  0.5256410241127014,
#  0.5301003456115723,
#  0.5317725539207458,
#  0.5256410241127014,
#  0.525083601474762]

# %%
test_outdoor_acc
# Out:
# [0.412420392036438,
#  0.403184711933136,
#  0.4133757948875427,
#  0.41050955653190613,
#  0.40573248267173767,
#  0.4060509502887726,
#  0.4035031795501709,
#  0.404458612203598,
#  0.40541401505470276,
#  0.40509554743766785]

# %%
test_belt_acc
# Out:
# [0.5158658027648926,
#  0.5222121477127075,
#  0.5190389752388,
#  0.5240253806114197,
#  0.5208522081375122,
#  0.525385320186615,
#  0.5285584926605225,
#  0.5267452597618103,
#  0.5258386135101318,
#  0.5267452597618103]

# %%
test_indoor_loss
# Out:
# [2.177238702774048,
#  2.3344733715057373,
#  2.535676956176758,
#  2.6924638748168945,
#  2.8575637340545654,
#  3.0071818828582764,
#  3.036820411682129,
#  3.210918664932251,
#  3.364407777786255,
#  3.460272789001465]

# %%
test_outdoor_loss
# Out:
# [3.3960254192352295,
#  3.9072582721710205,
#  4.1745100021362305,
#  4.538634300231934,
#  4.898538589477539,
#  5.0938401222229,
#  5.4058837890625,
#  5.641351699829102,
#  5.644377708435059,
#  5.862569808959961]

# %%
test_belt_loss
# Out:
# [2.403323173522949,
#  2.5878264904022217,
#  2.8372251987457275,
#  2.9955246448516846,
#  3.187901735305786,
#  3.317168712615967,
#  3.376615285873413,
#  3.530590057373047,
#  3.6817240715026855,
#  3.808290958404541]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg19 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 100
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=3386
# FP=3754
# acc=0.4742296918767507
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 18.96551724137931%
# 2WayConnectorforFoley acc = 33.33333333333333%
# 2WayFoleyCatheter acc = 38.80597014925373%
# 3WayConnectorforFoley acc = 58.97435897435898%
# 3Waystopcock acc = 73.87387387387388%
# AlcoholBottle acc = 72.5%
# AlcoholPad acc = 8.73015873015873%
# BootCover acc = 18.072289156626507%
# CottonBall acc = 50.29940119760479%
# CottonSwap acc = 23.776223776223777%
# Dilator acc = 29.914529914529915%
# DisposableInfusionSet acc = 19.469026548672566%
# ExtensionTube acc = 18.69918699186992%
# FaceShield acc = 50.0%
# FrontLoadSyringe acc = 16.8141592920354%
# GauzePad acc = 3.4090909090909087%
# Glove acc = 66.07142857142857%
# GuideWire acc = 17.857142857142858%
# LiquidBottle acc = 23.66412213740458%
# Mask acc = 66.49350649350649%
# NGTube acc = 33.5483870967742%
# NasalCannula acc = 38.93805309734513%
# Needle acc = 80.35714285714286%
# OxygenMask acc = 79.69924812030075%
# PPESuit acc = 52.41935483870967%
# PharmaceuticalProduct acc = 35.046728971962615%
# Pill acc = 93.69747899159664%
# PillBottle acc = 28.68217054263566%
# PrefilledHumidifier acc = 6.837606837606838%
# PressureConnectingTube acc = 50.38167938931297%
# ReusableHumidifier acc = 32.20338983050847%
# SodiumChlorideBag acc = 58.26771653543307%
# SterileHumidifierAdapter acc = 34.54545454545455%
# SurgicalBlade acc = 42.47787610619469%
# SurgicalCap acc = 77.47747747747748%
# SurgicalSuit acc = 16.666666666666664%
# Syringe acc = 49.049429657794676%
# TrachealTube acc = 29.357798165137616%
# UrineBag acc = 9.166666666666666%
# Vaccinebottle acc = 69.48356807511738%
# WingedInfusionSet acc = 37.719298245614034%
#
#
#
# all_avg_eachclass = 40.62796372838895%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 22,   1,   0, ...,   0,   2,   0],
#        [  0,  49,   0, ...,   0,   2,   0],
#        [  0,   0,  52, ...,   0,   5,   5],
#        ...,
#        [  0,   0,   0, ...,  11,  31,   1],
#        [  0,   0,   0, ...,   0, 148,   0],
#        [  0,   0,   3, ...,   0,  19,  43]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[18.96551724,  0.86206897,  0.        , ...,  0.        ,
#          1.72413793,  0.        ],
#        [ 0.        , 33.33333333,  0.        , ...,  0.        ,
#          1.36054422,  0.        ],
#        [ 0.        ,  0.        , 38.80597015, ...,  0.        ,
#          3.73134328,  3.73134328],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  9.16666667,
#         25.83333333,  0.83333333],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         69.48356808,  0.        ],
#        [ 0.        ,  0.        ,  2.63157895, ...,  0.        ,
#         16.66666667, 37.71929825]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
