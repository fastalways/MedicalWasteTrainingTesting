# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet_v2 import preprocess_input,ResNet152V2

transfered_model = keras.applications.ResNet152V2(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels.h5
# 242753536/242745792 [==============================] - 450s 2us/step
# 242761728/242745792 [==============================] - 450s 2us/step

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 56, 56, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 56, 56, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 56, 56, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 56, 56, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 56, 56, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 58, 58, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 28, 28, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 28, 28, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 28, 28, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 28, 28, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 28, 28, 256)  0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 28, 28, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 28, 28, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 28, 28, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv3_block5_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_relu (Activation (None, 28, 28, 128)  0           conv3_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_out (Add)          (None, 28, 28, 512)  0           conv3_block4_out[0][0]
#                                                                  conv3_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block5_out[0][0]
# __________________________________________________________________________________________________
# conv3_block6_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_relu (Activation (None, 28, 28, 128)  0           conv3_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_out (Add)          (None, 28, 28, 512)  0           conv3_block5_out[0][0]
#                                                                  conv3_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block6_out[0][0]
# __________________________________________________________________________________________________
# conv3_block7_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 128)  147456      conv3_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_relu (Activation (None, 28, 28, 128)  0           conv3_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_out (Add)          (None, 28, 28, 512)  0           conv3_block6_out[0][0]
#                                                                  conv3_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_preact_bn (BatchNo (None, 28, 28, 512)  2048        conv3_block7_out[0][0]
# __________________________________________________________________________________________________
# conv3_block8_preact_relu (Activ (None, 28, 28, 512)  0           conv3_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  65536       conv3_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_pad (ZeroPadding (None, 30, 30, 128)  0           conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 14, 14, 128)  147456      conv3_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_bn (BatchNormali (None, 14, 14, 128)  512         conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_relu (Activation (None, 14, 14, 128)  0           conv3_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0           conv3_block7_out[0][0]
# __________________________________________________________________________________________________
# conv3_block8_3_conv (Conv2D)    (None, 14, 14, 512)  66048       conv3_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_out (Add)          (None, 14, 14, 512)  0           max_pooling2d_1[0][0]
#                                                                  conv3_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 14, 14, 512)  2048        conv3_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 14, 14, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv4_block7_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block7_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block7_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 256)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block7_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_relu (Activation (None, 14, 14, 256)  0           conv4_block7_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block7_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Add)          (None, 14, 14, 1024) 0           conv4_block6_out[0][0]
#                                                                  conv4_block7_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block8_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block8_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 256)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block8_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 14, 14, 256)  0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Add)          (None, 14, 14, 1024) 0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_bn (BatchNo (None, 14, 14, 1024) 4096        conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_preact_relu (Activ (None, 14, 14, 1024) 0           conv4_block9_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 256)  262144      conv4_block9_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 256)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_pad (ZeroPadding (None, 16, 16, 256)  0           conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 256)  589824      conv4_block9_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 14, 14, 256)  0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Add)          (None, 14, 14, 1024) 0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block9_out[0][0]
# ...
# conv4_block33_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block33_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block33_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block33_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block33_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block33_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block33_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block33_out (Add)         (None, 14, 14, 1024) 0           conv4_block32_out[0][0]
#                                                                  conv4_block33_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block33_out[0][0]
# __________________________________________________________________________________________________
# conv4_block34_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block34_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block34_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block34_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block34_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block34_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block34_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block34_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block34_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block34_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block34_out (Add)         (None, 14, 14, 1024) 0           conv4_block33_out[0][0]
#                                                                  conv4_block34_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block34_out[0][0]
# __________________________________________________________________________________________________
# conv4_block35_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block35_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block35_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block35_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_conv (Conv2D)   (None, 14, 14, 256)  589824      conv4_block35_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block35_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block35_2_relu (Activatio (None, 14, 14, 256)  0           conv4_block35_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block35_3_conv (Conv2D)   (None, 14, 14, 1024) 263168      conv4_block35_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block35_out (Add)         (None, 14, 14, 1024) 0           conv4_block34_out[0][0]
#                                                                  conv4_block35_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_bn (BatchN (None, 14, 14, 1024) 4096        conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_preact_relu (Acti (None, 14, 14, 1024) 0           conv4_block36_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_conv (Conv2D)   (None, 14, 14, 256)  262144      conv4_block36_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_bn (BatchNormal (None, 14, 14, 256)  1024        conv4_block36_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_1_relu (Activatio (None, 14, 14, 256)  0           conv4_block36_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_pad (ZeroPaddin (None, 16, 16, 256)  0           conv4_block36_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_conv (Conv2D)   (None, 7, 7, 256)    589824      conv4_block36_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_bn (BatchNormal (None, 7, 7, 256)    1024        conv4_block36_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block36_2_relu (Activatio (None, 7, 7, 256)    0           conv4_block36_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)   0           conv4_block35_out[0][0]
# __________________________________________________________________________________________________
# conv4_block36_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      conv4_block36_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block36_out (Add)         (None, 7, 7, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block36_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 7, 7, 1024)   4096        conv4_block36_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 7, 7, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 7, 7, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 7, 7, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 9, 9, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 7, 7, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 7, 7, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           post_relu[0][0]
# ==================================================================================================
# Total params: 58,331,648
# Trainable params: 0
# Non-trainable params: 58,331,648
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Functional)         (None, 2048)              58331648
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 60,471,849
# Trainable params: 2,140,201
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 97/97 [==============================] - 27s 210ms/step - loss: 0.9195 - accuracy: 0.7564 - val_loss: 0.2897 - val_accuracy: 0.9094
# Epoch 2/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.1802 - accuracy: 0.9460 - val_loss: 0.3116 - val_accuracy: 0.9288
# Epoch 3/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0904 - accuracy: 0.9745 - val_loss: 0.2228 - val_accuracy: 0.9431
# Epoch 4/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0481 - accuracy: 0.9874 - val_loss: 0.2742 - val_accuracy: 0.9301
# Epoch 5/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0450 - accuracy: 0.9838 - val_loss: 0.2483 - val_accuracy: 0.9366
# Epoch 6/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0176 - accuracy: 0.9981 - val_loss: 0.2137 - val_accuracy: 0.9483
# Epoch 7/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.2242 - val_accuracy: 0.9418
# Epoch 8/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.2105 - val_accuracy: 0.9508
# Epoch 9/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0162 - accuracy: 0.9974 - val_loss: 0.2589 - val_accuracy: 0.9431
# Epoch 10/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0201 - accuracy: 0.9939 - val_loss: 0.3097 - val_accuracy: 0.9211
# Epoch 11/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0460 - accuracy: 0.9910 - val_loss: 0.2752 - val_accuracy: 0.9327
# Epoch 12/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0343 - accuracy: 0.9900 - val_loss: 0.2925 - val_accuracy: 0.9237
# Epoch 13/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0607 - accuracy: 0.9793 - val_loss: 0.4043 - val_accuracy: 0.9004
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 14/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0154 - accuracy: 0.9958 - val_loss: 0.2502 - val_accuracy: 0.9418
# Epoch 15/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.2661 - val_accuracy: 0.9392
# Epoch 16/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.2530 - val_accuracy: 0.9405
# Epoch 17/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9418
# Epoch 18/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9444
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 19/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2555 - val_accuracy: 0.9444
# Epoch 20/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2550 - val_accuracy: 0.9444
# Epoch 21/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2542 - val_accuracy: 0.9444
# Epoch 22/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2507 - val_accuracy: 0.9444
# Epoch 23/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2476 - val_accuracy: 0.9418
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 24/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 0.9418
# Epoch 25/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2482 - val_accuracy: 0.9418
# Epoch 26/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2486 - val_accuracy: 0.9418
# Epoch 27/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9431
# Epoch 28/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2499 - val_accuracy: 0.9444
# Epoch 29/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2500 - val_accuracy: 0.9444
# Epoch 30/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2506 - val_accuracy: 0.9444
# Epoch 31/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.9029e-04 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9444
# Epoch 32/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9431
# Epoch 33/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9444
# Epoch 34/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2502 - val_accuracy: 0.9444
# Epoch 35/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.9627e-04 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9444
# Epoch 36/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9444
# Epoch 37/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.6827e-04 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9431
# Epoch 38/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2519 - val_accuracy: 0.9444
# Epoch 39/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.0902e-04 - accuracy: 1.0000 - val_loss: 0.2512 - val_accuracy: 0.9444
# Epoch 40/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2496 - val_accuracy: 0.9444
# Epoch 41/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.2025e-04 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 0.9444
# Epoch 42/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2503 - val_accuracy: 0.9431
# Epoch 43/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.2497 - val_accuracy: 0.9444
# Epoch 44/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2507 - val_accuracy: 0.9444
# Epoch 45/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.5231e-04 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9444
# Epoch 46/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.5162e-04 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9444
# Epoch 47/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.4963e-04 - accuracy: 1.0000 - val_loss: 0.2516 - val_accuracy: 0.9444
# Epoch 48/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.8425e-04 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9444
# Epoch 49/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.6968e-04 - accuracy: 1.0000 - val_loss: 0.2521 - val_accuracy: 0.9444
# Epoch 50/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.8899e-04 - accuracy: 1.0000 - val_loss: 0.2523 - val_accuracy: 0.9444
# Epoch 51/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.8740e-04 - accuracy: 1.0000 - val_loss: 0.2523 - val_accuracy: 0.9457
# Epoch 52/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.2920e-04 - accuracy: 1.0000 - val_loss: 0.2522 - val_accuracy: 0.9457
# Epoch 53/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.8464e-04 - accuracy: 1.0000 - val_loss: 0.2535 - val_accuracy: 0.9483
# Epoch 54/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.5617e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9483
# Epoch 55/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.8315e-04 - accuracy: 1.0000 - val_loss: 0.2534 - val_accuracy: 0.9483
# Epoch 56/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2547 - val_accuracy: 0.9470
# Epoch 57/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.4764e-04 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9483
# Epoch 58/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.6080e-04 - accuracy: 1.0000 - val_loss: 0.2520 - val_accuracy: 0.9483
# Epoch 59/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.8506e-04 - accuracy: 1.0000 - val_loss: 0.2518 - val_accuracy: 0.9470
# Epoch 60/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.9885e-04 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9483
# Epoch 61/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.4649e-04 - accuracy: 1.0000 - val_loss: 0.2516 - val_accuracy: 0.9470
# Epoch 62/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.9711e-04 - accuracy: 1.0000 - val_loss: 0.2531 - val_accuracy: 0.9470
# Epoch 63/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.0794e-04 - accuracy: 1.0000 - val_loss: 0.2540 - val_accuracy: 0.9470
# Epoch 64/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.3576e-04 - accuracy: 1.0000 - val_loss: 0.2533 - val_accuracy: 0.9470
# Epoch 65/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.6665e-04 - accuracy: 1.0000 - val_loss: 0.2520 - val_accuracy: 0.9470
# Epoch 66/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.4332e-04 - accuracy: 1.0000 - val_loss: 0.2546 - val_accuracy: 0.9470
# Epoch 67/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.9170e-04 - accuracy: 1.0000 - val_loss: 0.2524 - val_accuracy: 0.9457
# Epoch 68/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.5844e-04 - accuracy: 1.0000 - val_loss: 0.2532 - val_accuracy: 0.9457
# Epoch 69/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.6069e-04 - accuracy: 1.0000 - val_loss: 0.2527 - val_accuracy: 0.9457
# Epoch 70/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.2956e-04 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9444
# Epoch 71/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.2983e-04 - accuracy: 1.0000 - val_loss: 0.2544 - val_accuracy: 0.9470
# Epoch 72/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.1113e-04 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9483
# Epoch 73/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.9077e-04 - accuracy: 1.0000 - val_loss: 0.2546 - val_accuracy: 0.9470
# Epoch 74/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.4783e-04 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9483
# Epoch 75/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.1113e-04 - accuracy: 1.0000 - val_loss: 0.2548 - val_accuracy: 0.9483
# Epoch 76/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.7859e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9483
# Epoch 77/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.4070e-04 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9483
# Epoch 78/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.3604e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9483
# Epoch 79/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.6906e-04 - accuracy: 1.0000 - val_loss: 0.2548 - val_accuracy: 0.9470
# Epoch 80/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.7715e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9470
# Epoch 81/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.6336e-04 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9470
# Epoch 82/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.8908e-04 - accuracy: 1.0000 - val_loss: 0.2482 - val_accuracy: 0.9495
# Epoch 83/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.1383e-04 - accuracy: 1.0000 - val_loss: 0.2493 - val_accuracy: 0.9483
# Epoch 84/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.8957e-04 - accuracy: 1.0000 - val_loss: 0.2491 - val_accuracy: 0.9483
# Epoch 85/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.4641e-04 - accuracy: 1.0000 - val_loss: 0.2484 - val_accuracy: 0.9483
# Epoch 86/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.6781e-04 - accuracy: 1.0000 - val_loss: 0.2523 - val_accuracy: 0.9508
# Epoch 87/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.3558e-04 - accuracy: 1.0000 - val_loss: 0.2519 - val_accuracy: 0.9495
# Epoch 88/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.5535e-04 - accuracy: 1.0000 - val_loss: 0.2523 - val_accuracy: 0.9508
# Epoch 89/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.1259e-04 - accuracy: 1.0000 - val_loss: 0.2547 - val_accuracy: 0.9495
# Epoch 90/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.7044e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9495
# Epoch 91/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.5946e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9495
# Epoch 92/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.3303e-04 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9495
# Epoch 93/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1181e-04 - accuracy: 1.0000 - val_loss: 0.2579 - val_accuracy: 0.9495
# Epoch 94/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.9748e-04 - accuracy: 1.0000 - val_loss: 0.2569 - val_accuracy: 0.9495
# Epoch 95/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2730e-04 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9495
# Epoch 96/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1590e-04 - accuracy: 1.0000 - val_loss: 0.2562 - val_accuracy: 0.9495
# Epoch 97/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.6999e-04 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9495
# Epoch 98/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.6938e-04 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9483
# Epoch 99/2000
# 97/97 [==============================] - 18s 185ms/step - loss: 3.8677e-04 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.9470
# Epoch 100/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1150e-04 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9495
# Epoch 101/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.6742e-04 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9495
# Epoch 102/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6610e-04 - accuracy: 1.0000 - val_loss: 0.2566 - val_accuracy: 0.9495
# Epoch 103/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.5476e-04 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9495
# Epoch 104/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.7581e-04 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9495
# Epoch 105/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6050e-04 - accuracy: 1.0000 - val_loss: 0.2596 - val_accuracy: 0.9495
# Epoch 106/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.7758e-04 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.9483
# Epoch 107/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.9789e-04 - accuracy: 1.0000 - val_loss: 0.2610 - val_accuracy: 0.9483
# Epoch 108/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.8664e-04 - accuracy: 1.0000 - val_loss: 0.2545 - val_accuracy: 0.9483
# Epoch 109/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.5384e-04 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9483
# Epoch 110/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.9850e-04 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9483
# Epoch 111/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.7544e-04 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9495
# Epoch 112/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 1.9377e-04 - accuracy: 1.0000 - val_loss: 0.2572 - val_accuracy: 0.9495
# Epoch 113/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.0839e-04 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9495
# Epoch 114/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.7834e-04 - accuracy: 1.0000 - val_loss: 0.2559 - val_accuracy: 0.9495
# Epoch 115/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0486e-04 - accuracy: 1.0000 - val_loss: 0.2564 - val_accuracy: 0.9495
# Epoch 116/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.8724e-04 - accuracy: 1.0000 - val_loss: 0.2560 - val_accuracy: 0.9495
# Epoch 117/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1390e-04 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.9483
# Epoch 118/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0189e-04 - accuracy: 1.0000 - val_loss: 0.2586 - val_accuracy: 0.9508
# Epoch 119/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 1.8851e-04 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9495
# Epoch 120/2000
# 97/97 [==============================] - 40s 419ms/step - loss: 1.9049e-04 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9495
# Epoch 121/2000
# 97/97 [==============================] - 18s 185ms/step - loss: 1.6988e-04 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9495
# Epoch 122/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.6920e-04 - accuracy: 1.0000 - val_loss: 0.2571 - val_accuracy: 0.9495
# Epoch 123/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.8434e-04 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9495
# Epoch 124/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.6392e-04 - accuracy: 1.0000 - val_loss: 0.2591 - val_accuracy: 0.9483
# Epoch 125/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.8547e-04 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.9483
# Epoch 126/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.5596e-04 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9495
# Epoch 127/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.5438e-04 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9483
# Epoch 128/2000
# 97/97 [==============================] - 18s 185ms/step - loss: 1.5039e-04 - accuracy: 1.0000 - val_loss: 0.2610 - val_accuracy: 0.9521
# Epoch 129/2000
# 97/97 [==============================] - 18s 185ms/step - loss: 1.6838e-04 - accuracy: 1.0000 - val_loss: 0.2636 - val_accuracy: 0.9508
# Epoch 130/2000
# 97/97 [==============================] - 18s 186ms/step - loss: 1.3450e-04 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9508
# Epoch 131/2000
# 97/97 [==============================] - 18s 185ms/step - loss: 1.5692e-04 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9508
# Epoch 132/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 1.4730e-04 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9521
# Epoch 133/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 1.1339e-04 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9508
# Epoch 134/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 1.3001e-04 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9495
# Epoch 135/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.1432e-04 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9508
# Epoch 136/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.4982e-04 - accuracy: 1.0000 - val_loss: 0.2593 - val_accuracy: 0.9508
# Epoch 137/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2507e-04 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9483
# Epoch 138/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.3305e-04 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9495
# Epoch 139/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.4859e-04 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9521
# Epoch 140/2000
# 97/97 [==============================] - 18s 185ms/step - loss: 1.3343e-04 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9521
# Epoch 141/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.9703e-05 - accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9521
# Epoch 142/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2051e-04 - accuracy: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9534
# Epoch 143/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.3101e-04 - accuracy: 1.0000 - val_loss: 0.2672 - val_accuracy: 0.9521
# Epoch 144/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.0705e-04 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9508
# Epoch 145/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.0201e-05 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9521
# Epoch 146/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.0550e-05 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9521
# Epoch 147/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.0302e-04 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9521
# Epoch 148/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.1602e-05 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9534
# Epoch 149/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.9829e-05 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9521
# Epoch 150/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.9312e-05 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9521
# Epoch 151/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.7099e-05 - accuracy: 1.0000 - val_loss: 0.2663 - val_accuracy: 0.9508
# Epoch 152/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.2782e-05 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9521
# Epoch 153/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.6487e-05 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9521
# Epoch 154/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.4826e-05 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9521
# Epoch 155/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.5148e-05 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9508
# Epoch 156/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.9931e-05 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9521
# Epoch 157/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.3150e-05 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9521
# Epoch 158/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.4950e-05 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9521
# Epoch 159/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.3431e-05 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9521
# Epoch 160/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.9768e-05 - accuracy: 1.0000 - val_loss: 0.2626 - val_accuracy: 0.9521
# Epoch 161/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.0005e-05 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9508
# Epoch 162/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.5255e-05 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9508
# Epoch 163/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.7470e-05 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.9521
# Epoch 164/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.8692e-05 - accuracy: 1.0000 - val_loss: 0.2664 - val_accuracy: 0.9508
# Epoch 165/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.1512e-05 - accuracy: 1.0000 - val_loss: 0.2680 - val_accuracy: 0.9508
# Epoch 166/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.0014e-05 - accuracy: 1.0000 - val_loss: 0.2682 - val_accuracy: 0.9508
# Epoch 167/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.4549e-05 - accuracy: 1.0000 - val_loss: 0.2684 - val_accuracy: 0.9508
# Epoch 168/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.3967e-05 - accuracy: 1.0000 - val_loss: 0.2692 - val_accuracy: 0.9508
# Epoch 169/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.6008e-05 - accuracy: 1.0000 - val_loss: 0.2715 - val_accuracy: 0.9508
# Epoch 170/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.4585e-05 - accuracy: 1.0000 - val_loss: 0.2694 - val_accuracy: 0.9521
# Epoch 171/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.3126e-05 - accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.9534
# Epoch 172/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.3281e-05 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.9521
# Epoch 173/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.0206e-05 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.9521
# Epoch 174/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.6141e-05 - accuracy: 1.0000 - val_loss: 0.2686 - val_accuracy: 0.9521
# Epoch 175/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.7073e-05 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9534
# Epoch 176/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.4343e-05 - accuracy: 1.0000 - val_loss: 0.2703 - val_accuracy: 0.9534
# Epoch 177/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.7158e-05 - accuracy: 1.0000 - val_loss: 0.2736 - val_accuracy: 0.9495
# Epoch 178/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.5107e-05 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9534
# Epoch 179/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.9381e-05 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9534
# Epoch 180/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.9660e-05 - accuracy: 1.0000 - val_loss: 0.2680 - val_accuracy: 0.9534
# Epoch 181/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.9956e-05 - accuracy: 1.0000 - val_loss: 0.2700 - val_accuracy: 0.9534
# Epoch 182/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.9714e-05 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9534
# Epoch 183/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.3443e-05 - accuracy: 1.0000 - val_loss: 0.2687 - val_accuracy: 0.9534
# Epoch 184/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.0107e-05 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9534
# Epoch 185/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.7555e-05 - accuracy: 1.0000 - val_loss: 0.2691 - val_accuracy: 0.9534
# Epoch 186/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.8285e-05 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9534
# Epoch 187/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2960e-05 - accuracy: 1.0000 - val_loss: 0.2714 - val_accuracy: 0.9521
# Epoch 188/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1570e-05 - accuracy: 1.0000 - val_loss: 0.2717 - val_accuracy: 0.9521
# Epoch 189/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.8779e-05 - accuracy: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9521
# Epoch 190/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1730e-05 - accuracy: 1.0000 - val_loss: 0.2745 - val_accuracy: 0.9534
# Epoch 191/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1224e-05 - accuracy: 1.0000 - val_loss: 0.2739 - val_accuracy: 0.9521
# Epoch 192/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.4522e-05 - accuracy: 1.0000 - val_loss: 0.2742 - val_accuracy: 0.9521
# Epoch 193/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.4369e-05 - accuracy: 1.0000 - val_loss: 0.2718 - val_accuracy: 0.9534
# Epoch 194/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1032e-05 - accuracy: 1.0000 - val_loss: 0.2729 - val_accuracy: 0.9521
# Epoch 195/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.8361e-05 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9534
# Epoch 196/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.4231e-05 - accuracy: 1.0000 - val_loss: 0.2741 - val_accuracy: 0.9534
# Epoch 197/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.0452e-05 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.9534
# Epoch 198/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.9136e-05 - accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 0.9547
# Epoch 199/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.6186e-05 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9534
# Epoch 200/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.1234e-05 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.9521
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6219e-05 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9508
# Epoch 202/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2041e-05 - accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 0.9521
# Epoch 203/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.5078e-05 - accuracy: 1.0000 - val_loss: 0.2877 - val_accuracy: 0.9534
# Epoch 204/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0765e-05 - accuracy: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.9534
# Epoch 205/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1949e-05 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.9534
# Epoch 206/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6353e-05 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9534
# Epoch 207/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6065e-05 - accuracy: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.9534
# Epoch 208/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.4780e-05 - accuracy: 1.0000 - val_loss: 0.2774 - val_accuracy: 0.9547
# Epoch 209/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.8213e-05 - accuracy: 1.0000 - val_loss: 0.2814 - val_accuracy: 0.9534
# Epoch 210/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.2384e-05 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.9534
# Epoch 211/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.2545e-05 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.9534
# Epoch 212/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1690e-05 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9534
# Epoch 213/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1796e-05 - accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.9521
# Epoch 214/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.4831e-05 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.9521
# Epoch 215/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0557e-05 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9521
# Epoch 216/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.8968e-05 - accuracy: 1.0000 - val_loss: 0.2826 - val_accuracy: 0.9534
# Epoch 217/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.2038e-05 - accuracy: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9534
# Epoch 218/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.8765e-05 - accuracy: 1.0000 - val_loss: 0.2821 - val_accuracy: 0.9534
# Epoch 219/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.9822e-05 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9534
# Epoch 220/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1144e-05 - accuracy: 1.0000 - val_loss: 0.2818 - val_accuracy: 0.9547
# Epoch 221/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.5877e-05 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9534
# Epoch 222/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.6913e-05 - accuracy: 1.0000 - val_loss: 0.2837 - val_accuracy: 0.9521
# Epoch 223/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.9176e-05 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9534
# Epoch 224/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.7887e-05 - accuracy: 1.0000 - val_loss: 0.2808 - val_accuracy: 0.9547
# Epoch 225/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.8654e-05 - accuracy: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9534
# Epoch 226/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.5547e-05 - accuracy: 1.0000 - val_loss: 0.2799 - val_accuracy: 0.9534
# Epoch 227/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.5436e-05 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.9534
# Epoch 228/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.8573e-05 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.9547
# Epoch 229/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.7400e-05 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9547
# Epoch 230/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.5905e-05 - accuracy: 1.0000 - val_loss: 0.2831 - val_accuracy: 0.9547
# Epoch 231/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.3045e-05 - accuracy: 1.0000 - val_loss: 0.2822 - val_accuracy: 0.9547
# Epoch 232/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.3881e-05 - accuracy: 1.0000 - val_loss: 0.2840 - val_accuracy: 0.9547
# Epoch 233/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.5474e-05 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9534
# Epoch 234/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2683e-05 - accuracy: 1.0000 - val_loss: 0.2855 - val_accuracy: 0.9534
# Epoch 235/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.4476e-05 - accuracy: 1.0000 - val_loss: 0.2872 - val_accuracy: 0.9521
# Epoch 236/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.1180e-05 - accuracy: 1.0000 - val_loss: 0.2866 - val_accuracy: 0.9534
# Epoch 237/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2458e-05 - accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 0.9547
# Epoch 238/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.0777e-05 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.9547
# Epoch 239/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.4590e-05 - accuracy: 1.0000 - val_loss: 0.2870 - val_accuracy: 0.9547
# Epoch 240/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.6611e-05 - accuracy: 1.0000 - val_loss: 0.2879 - val_accuracy: 0.9534
# Epoch 241/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2925e-05 - accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9534
# Epoch 242/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.1647e-05 - accuracy: 1.0000 - val_loss: 0.2867 - val_accuracy: 0.9534
# Epoch 243/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.1059e-05 - accuracy: 1.0000 - val_loss: 0.2875 - val_accuracy: 0.9534
# Epoch 244/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.4239e-05 - accuracy: 1.0000 - val_loss: 0.2894 - val_accuracy: 0.9508
# Epoch 245/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.4229e-05 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9521
# Epoch 246/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.0299e-05 - accuracy: 1.0000 - val_loss: 0.2889 - val_accuracy: 0.9534
# Epoch 247/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.3121e-05 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.9521
# Epoch 248/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.0446e-05 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9521
# Epoch 249/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.1252e-06 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9521
# Epoch 250/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2487e-05 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9534
# Epoch 251/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.9265e-06 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.9534
# Epoch 252/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 1.0538e-05 - accuracy: 1.0000 - val_loss: 0.2902 - val_accuracy: 0.9534
# Epoch 253/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.2500e-05 - accuracy: 1.0000 - val_loss: 0.2900 - val_accuracy: 0.9534
# Epoch 254/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 9.4299e-06 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.9534
# Epoch 255/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 7.7726e-06 - accuracy: 1.0000 - val_loss: 0.2899 - val_accuracy: 0.9534
# Epoch 256/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 1.0408e-05 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9547
# Epoch 257/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 9.2105e-06 - accuracy: 1.0000 - val_loss: 0.2926 - val_accuracy: 0.9547
# Epoch 258/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 9.2340e-06 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.9547
# Epoch 259/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 8.2578e-06 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9534
# Epoch 260/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 9.3317e-06 - accuracy: 1.0000 - val_loss: 0.2924 - val_accuracy: 0.9534
# Epoch 261/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 7.3396e-06 - accuracy: 1.0000 - val_loss: 0.2918 - val_accuracy: 0.9534
# Epoch 262/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 8.1225e-06 - accuracy: 1.0000 - val_loss: 0.2915 - val_accuracy: 0.9534
# Epoch 263/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 1.0658e-05 - accuracy: 1.0000 - val_loss: 0.2906 - val_accuracy: 0.9534
# Epoch 264/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 8.0370e-06 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.9534
# Epoch 265/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 9.0023e-06 - accuracy: 1.0000 - val_loss: 0.2956 - val_accuracy: 0.9547
# Epoch 266/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 8.3573e-06 - accuracy: 1.0000 - val_loss: 0.2885 - val_accuracy: 0.9547
# Epoch 267/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 8.4882e-06 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.9547
# Epoch 268/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 7.0257e-06 - accuracy: 1.0000 - val_loss: 0.2920 - val_accuracy: 0.9521
# Epoch 269/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 7.4657e-06 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9521
# Epoch 270/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 9.1926e-06 - accuracy: 1.0000 - val_loss: 0.2947 - val_accuracy: 0.9534
# Epoch 271/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.9206e-06 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9534
# Epoch 272/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 6.7046e-06 - accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 0.9547
# Epoch 273/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 7.2152e-06 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.9534
# Epoch 274/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 7.4355e-06 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.9534
# Epoch 275/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 6.2955e-06 - accuracy: 1.0000 - val_loss: 0.2926 - val_accuracy: 0.9547
# Epoch 276/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 6.5528e-06 - accuracy: 1.0000 - val_loss: 0.2943 - val_accuracy: 0.9534
# Epoch 277/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 6.4861e-06 - accuracy: 1.0000 - val_loss: 0.2947 - val_accuracy: 0.9534
# Epoch 278/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.2055e-06 - accuracy: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.9534
# Epoch 279/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.0018e-06 - accuracy: 1.0000 - val_loss: 0.2941 - val_accuracy: 0.9534
# Epoch 280/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 6.4035e-06 - accuracy: 1.0000 - val_loss: 0.2944 - val_accuracy: 0.9534
# Epoch 281/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.1636e-06 - accuracy: 1.0000 - val_loss: 0.2968 - val_accuracy: 0.9534
# Epoch 282/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.6391e-06 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9534
# Epoch 283/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 5.3235e-06 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9534
# Epoch 284/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 8.9074e-06 - accuracy: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.9521
# Epoch 285/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.2161e-06 - accuracy: 1.0000 - val_loss: 0.2995 - val_accuracy: 0.9534
# Epoch 286/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 6.0333e-06 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9534
# Epoch 287/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.8066e-06 - accuracy: 1.0000 - val_loss: 0.2990 - val_accuracy: 0.9534
# Epoch 288/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.9701e-06 - accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9534
# Epoch 289/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.5187e-06 - accuracy: 1.0000 - val_loss: 0.2984 - val_accuracy: 0.9534
# Epoch 290/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 5.1904e-06 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9521
# Epoch 291/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.5040e-06 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.9534
# Epoch 292/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 8.3384e-06 - accuracy: 1.0000 - val_loss: 0.2940 - val_accuracy: 0.9534
# Epoch 293/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 5.0582e-06 - accuracy: 1.0000 - val_loss: 0.2903 - val_accuracy: 0.9534
# Epoch 294/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 7.0367e-06 - accuracy: 1.0000 - val_loss: 0.2939 - val_accuracy: 0.9534
# Epoch 295/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.7514e-06 - accuracy: 1.0000 - val_loss: 0.2932 - val_accuracy: 0.9547
# Epoch 296/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.3964e-06 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.9534
# Epoch 297/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.1878e-06 - accuracy: 1.0000 - val_loss: 0.2928 - val_accuracy: 0.9534
# Epoch 298/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 4.7992e-06 - accuracy: 1.0000 - val_loss: 0.2928 - val_accuracy: 0.9534
# Epoch 299/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.1705e-06 - accuracy: 1.0000 - val_loss: 0.2904 - val_accuracy: 0.9534
# Epoch 300/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.7648e-06 - accuracy: 1.0000 - val_loss: 0.2942 - val_accuracy: 0.9534
# Epoch 301/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 4.5087e-06 - accuracy: 1.0000 - val_loss: 0.2967 - val_accuracy: 0.9534
# Epoch 302/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.3854e-06 - accuracy: 1.0000 - val_loss: 0.2960 - val_accuracy: 0.9534
# Epoch 303/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.5035e-06 - accuracy: 1.0000 - val_loss: 0.2951 - val_accuracy: 0.9534
# Epoch 304/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 4.3086e-06 - accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9534
# Epoch 305/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.7686e-06 - accuracy: 1.0000 - val_loss: 0.2964 - val_accuracy: 0.9534
# Epoch 306/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.1665e-06 - accuracy: 1.0000 - val_loss: 0.2952 - val_accuracy: 0.9534
# Epoch 307/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 3.7524e-06 - accuracy: 1.0000 - val_loss: 0.2969 - val_accuracy: 0.9534
# Epoch 308/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.4681e-06 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9534
# Epoch 309/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.3616e-06 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9560
# Epoch 310/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.1697e-06 - accuracy: 1.0000 - val_loss: 0.2961 - val_accuracy: 0.9547
# Epoch 311/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.8031e-06 - accuracy: 1.0000 - val_loss: 0.2974 - val_accuracy: 0.9534
# Epoch 312/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 5.6048e-06 - accuracy: 1.0000 - val_loss: 0.2965 - val_accuracy: 0.9534
# Epoch 313/2000
# 97/97 [==============================] - 18s 182ms/step - loss: 4.6217e-06 - accuracy: 1.0000 - val_loss: 0.2994 - val_accuracy: 0.9534
# Epoch 314/2000
# ...
# Epoch 1900/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.7462e-08 - accuracy: 1.0000 - val_loss: 0.3707 - val_accuracy: 0.9560
# Epoch 1901/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.3047e-08 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.9560
# Epoch 1902/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.6769e-08 - accuracy: 1.0000 - val_loss: 0.3712 - val_accuracy: 0.9560
# Epoch 1903/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.5960e-08 - accuracy: 1.0000 - val_loss: 0.3713 - val_accuracy: 0.9560
# Epoch 1904/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 1.3248e-07 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9560
# Epoch 1905/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.2494e-08 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9560
# Epoch 1906/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 4.8877e-08 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.9560
# Epoch 1907/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.7732e-08 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.9560
# Epoch 1908/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.5074e-08 - accuracy: 1.0000 - val_loss: 0.3709 - val_accuracy: 0.9560
# Epoch 1909/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.0082e-08 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.9560
# Epoch 1910/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.1454e-08 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.9560
# Epoch 1911/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.0582e-08 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9560
# Epoch 1912/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.0390e-08 - accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.9560
# Epoch 1913/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.4651e-08 - accuracy: 1.0000 - val_loss: 0.3707 - val_accuracy: 0.9560
# Epoch 1914/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.7539e-08 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.9560
# Epoch 1915/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.6181e-08 - accuracy: 1.0000 - val_loss: 0.3715 - val_accuracy: 0.9560
# Epoch 1916/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 4.1675e-08 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.9560
# Epoch 1917/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.4111e-08 - accuracy: 1.0000 - val_loss: 0.3710 - val_accuracy: 0.9560
# Epoch 1918/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.0813e-08 - accuracy: 1.0000 - val_loss: 0.3712 - val_accuracy: 0.9560
# Epoch 1919/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2893e-08 - accuracy: 1.0000 - val_loss: 0.3719 - val_accuracy: 0.9560
# Epoch 1920/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.4010e-08 - accuracy: 1.0000 - val_loss: 0.3718 - val_accuracy: 0.9560
# Epoch 1921/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3380e-08 - accuracy: 1.0000 - val_loss: 0.3719 - val_accuracy: 0.9560
# Epoch 1922/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 6.4360e-08 - accuracy: 1.0000 - val_loss: 0.3728 - val_accuracy: 0.9560
# Epoch 1923/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.8310e-08 - accuracy: 1.0000 - val_loss: 0.3740 - val_accuracy: 0.9560
# Epoch 1924/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.3278e-08 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9560
# Epoch 1925/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.7077e-08 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9560
# Epoch 1926/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2393e-08 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9560
# Epoch 1927/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1184e-08 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9560
# Epoch 1928/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3957e-08 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9560
# Epoch 1929/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.0621e-08 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9560
# Epoch 1930/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 4.0827e-08 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.9560
# Epoch 1931/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.8954e-08 - accuracy: 1.0000 - val_loss: 0.3741 - val_accuracy: 0.9560
# Epoch 1932/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.4073e-08 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.9560
# Epoch 1933/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6923e-08 - accuracy: 1.0000 - val_loss: 0.3735 - val_accuracy: 0.9560
# Epoch 1934/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.5835e-08 - accuracy: 1.0000 - val_loss: 0.3734 - val_accuracy: 0.9560
# Epoch 1935/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.2109e-08 - accuracy: 1.0000 - val_loss: 0.3735 - val_accuracy: 0.9560
# Epoch 1936/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.2301e-08 - accuracy: 1.0000 - val_loss: 0.3735 - val_accuracy: 0.9560
# Epoch 1937/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.0452e-08 - accuracy: 1.0000 - val_loss: 0.3731 - val_accuracy: 0.9560
# Epoch 1938/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 4.0828e-08 - accuracy: 1.0000 - val_loss: 0.3724 - val_accuracy: 0.9560
# Epoch 1939/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2932e-08 - accuracy: 1.0000 - val_loss: 0.3725 - val_accuracy: 0.9560
# Epoch 1940/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.2879e-08 - accuracy: 1.0000 - val_loss: 0.3727 - val_accuracy: 0.9560
# Epoch 1941/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.5460e-08 - accuracy: 1.0000 - val_loss: 0.3729 - val_accuracy: 0.9560
# Epoch 1942/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.4073e-08 - accuracy: 1.0000 - val_loss: 0.3729 - val_accuracy: 0.9560
# Epoch 1943/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.9350e-08 - accuracy: 1.0000 - val_loss: 0.3726 - val_accuracy: 0.9560
# Epoch 1944/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.0799e-08 - accuracy: 1.0000 - val_loss: 0.3722 - val_accuracy: 0.9560
# Epoch 1945/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.0890e-08 - accuracy: 1.0000 - val_loss: 0.3722 - val_accuracy: 0.9560
# Epoch 1946/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 5.0002e-07 - accuracy: 1.0000 - val_loss: 0.3787 - val_accuracy: 0.9547
# Epoch 1947/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.9865e-08 - accuracy: 1.0000 - val_loss: 0.3784 - val_accuracy: 0.9547
# Epoch 1948/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.8387e-08 - accuracy: 1.0000 - val_loss: 0.3778 - val_accuracy: 0.9547
# Epoch 1949/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3765e-08 - accuracy: 1.0000 - val_loss: 0.3776 - val_accuracy: 0.9547
# Epoch 1950/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3842e-08 - accuracy: 1.0000 - val_loss: 0.3774 - val_accuracy: 0.9547
# Epoch 1951/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2431e-08 - accuracy: 1.0000 - val_loss: 0.3773 - val_accuracy: 0.9547
# Epoch 1952/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2007e-08 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9547
# Epoch 1953/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.2238e-08 - accuracy: 1.0000 - val_loss: 0.3760 - val_accuracy: 0.9547
# Epoch 1954/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.6615e-08 - accuracy: 1.0000 - val_loss: 0.3758 - val_accuracy: 0.9547
# Epoch 1955/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.8502e-08 - accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.9547
# Epoch 1956/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.0313e-08 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.9560
# Epoch 1957/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.3947e-08 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.9560
# Epoch 1958/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.1121e-08 - accuracy: 1.0000 - val_loss: 0.3747 - val_accuracy: 0.9560
# Epoch 1959/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6499e-08 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.9560
# Epoch 1960/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.8940e-08 - accuracy: 1.0000 - val_loss: 0.3744 - val_accuracy: 0.9560
# Epoch 1961/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.5999e-08 - accuracy: 1.0000 - val_loss: 0.3740 - val_accuracy: 0.9560
# Epoch 1962/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.2624e-08 - accuracy: 1.0000 - val_loss: 0.3742 - val_accuracy: 0.9560
# Epoch 1963/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.9465e-08 - accuracy: 1.0000 - val_loss: 0.3740 - val_accuracy: 0.9560
# Epoch 1964/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.8040e-08 - accuracy: 1.0000 - val_loss: 0.3742 - val_accuracy: 0.9560
# Epoch 1965/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3072e-08 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9560
# Epoch 1966/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.6654e-08 - accuracy: 1.0000 - val_loss: 0.3733 - val_accuracy: 0.9560
# Epoch 1967/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0029e-08 - accuracy: 1.0000 - val_loss: 0.3729 - val_accuracy: 0.9560
# Epoch 1968/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3957e-08 - accuracy: 1.0000 - val_loss: 0.3730 - val_accuracy: 0.9560
# Epoch 1969/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.4959e-08 - accuracy: 1.0000 - val_loss: 0.3725 - val_accuracy: 0.9560
# Epoch 1970/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3418e-08 - accuracy: 1.0000 - val_loss: 0.3725 - val_accuracy: 0.9560
# Epoch 1971/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.5421e-08 - accuracy: 1.0000 - val_loss: 0.3725 - val_accuracy: 0.9560
# Epoch 1972/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.8194e-08 - accuracy: 1.0000 - val_loss: 0.3722 - val_accuracy: 0.9560
# Epoch 1973/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.8194e-08 - accuracy: 1.0000 - val_loss: 0.3723 - val_accuracy: 0.9560
# Epoch 1974/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.7963e-08 - accuracy: 1.0000 - val_loss: 0.3723 - val_accuracy: 0.9560
# Epoch 1975/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 4.9224e-08 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9560
# Epoch 1976/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.0491e-08 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9560
# Epoch 1977/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.0582e-08 - accuracy: 1.0000 - val_loss: 0.3707 - val_accuracy: 0.9560
# Epoch 1978/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.5074e-08 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.9560
# Epoch 1979/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.9875e-08 - accuracy: 1.0000 - val_loss: 0.3707 - val_accuracy: 0.9560
# Epoch 1980/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.9465e-08 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.9560
# Epoch 1981/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.9913e-08 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.9560
# Epoch 1982/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 5.2767e-08 - accuracy: 1.0000 - val_loss: 0.3702 - val_accuracy: 0.9560
# Epoch 1983/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.8233e-08 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9560
# Epoch 1984/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0529e-08 - accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.9560
# Epoch 1985/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.2277e-08 - accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.9560
# Epoch 1986/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 3.7785e-08 - accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.9560
# Epoch 1987/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.1839e-08 - accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.9560
# Epoch 1988/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.3033e-08 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9560
# Epoch 1989/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.6577e-08 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.9560
# Epoch 1990/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.1213e-08 - accuracy: 1.0000 - val_loss: 0.3699 - val_accuracy: 0.9560
# Epoch 1991/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.9350e-08 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9560
# Epoch 1992/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.6191e-08 - accuracy: 1.0000 - val_loss: 0.3702 - val_accuracy: 0.9560
# Epoch 1993/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.3803e-08 - accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.9560
# Epoch 1994/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 3.3355e-08 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9560
# Epoch 1995/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 4.0981e-08 - accuracy: 1.0000 - val_loss: 0.3705 - val_accuracy: 0.9560
# Epoch 1996/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 2.0992e-08 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9560
# Epoch 1997/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.6793e-08 - accuracy: 1.0000 - val_loss: 0.3704 - val_accuracy: 0.9560
# Epoch 1998/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 6.2472e-08 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9560
# Epoch 1999/2000
# 97/97 [==============================] - 18s 183ms/step - loss: 1.0487e-07 - accuracy: 1.0000 - val_loss: 0.3687 - val_accuracy: 0.9560
# Epoch 2000/2000
# 97/97 [==============================] - 18s 184ms/step - loss: 2.4689e-08 - accuracy: 1.0000 - val_loss: 0.3682 - val_accuracy: 0.9560
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 57/57 [==============================] - 14s 206ms/step - loss: 1.3469 - accuracy: 0.8300
# test_indoor_ds_results:test loss, test acc: [1.3469152450561523, 0.8299888372421265]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 99/99 [==============================] - 26s 233ms/step - loss: 2.3666 - accuracy: 0.7481
# test_outdoor_ds_results:test loss, test acc: [2.3666274547576904, 0.7480891942977905]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 69/69 [==============================] - 12s 159ms/step - loss: 2.5323 - accuracy: 0.7652
# test_belt_ds_results:test loss, test acc: [2.5323140621185303, 0.7651858329772949]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/ResNet152V2_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 57/57 [==============================] - 10s 147ms/step - loss: 1.0396 - accuracy: 0.8161
# 99/99 [==============================] - 15s 147ms/step - loss: 1.7509 - accuracy: 0.7424
# 69/69 [==============================] - 10s 148ms/step - loss: 1.8213 - accuracy: 0.7616
# Epoch200
#  test_indoor_acc=0.8160535097122192
#  test_outdoor_acc=0.7423567175865173
#  test_belt_acc=0.7615593671798706
# 57/57 [==============================] - 11s 147ms/step - loss: 1.1518 - accuracy: 0.8278
# 99/99 [==============================] - 15s 147ms/step - loss: 2.0044 - accuracy: 0.7459
# 69/69 [==============================] - 10s 148ms/step - loss: 2.1284 - accuracy: 0.7634
# Epoch400
#  test_indoor_acc=0.8277592062950134
#  test_outdoor_acc=0.7458598613739014
#  test_belt_acc=0.7633726000785828
# 57/57 [==============================] - 10s 146ms/step - loss: 1.2069 - accuracy: 0.8305
# 99/99 [==============================] - 15s 147ms/step - loss: 2.1440 - accuracy: 0.7452
# 69/69 [==============================] - 10s 148ms/step - loss: 2.2357 - accuracy: 0.7670
# Epoch600
#  test_indoor_acc=0.8305462598800659
#  test_outdoor_acc=0.7452229261398315
#  test_belt_acc=0.7669990658760071
# 57/57 [==============================] - 11s 147ms/step - loss: 1.2668 - accuracy: 0.8278
# 99/99 [==============================] - 15s 147ms/step - loss: 2.2188 - accuracy: 0.7452
# 69/69 [==============================] - 10s 148ms/step - loss: 2.3553 - accuracy: 0.7638
# Epoch800
#  test_indoor_acc=0.8277592062950134
#  test_outdoor_acc=0.7452229261398315
#  test_belt_acc=0.7638259530067444
# 57/57 [==============================] - 11s 147ms/step - loss: 1.2987 - accuracy: 0.8283
# 99/99 [==============================] - 15s 147ms/step - loss: 2.2917 - accuracy: 0.7446
# 69/69 [==============================] - 10s 148ms/step - loss: 2.4057 - accuracy: 0.7625
# Epoch1000
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.7445859909057617
#  test_belt_acc=0.7624660134315491
# 57/57 [==============================] - 11s 147ms/step - loss: 1.3081 - accuracy: 0.8278
# 99/99 [==============================] - 15s 148ms/step - loss: 2.2990 - accuracy: 0.7446
# 69/69 [==============================] - 10s 149ms/step - loss: 2.4363 - accuracy: 0.7670
# Epoch1200
#  test_indoor_acc=0.8277592062950134
#  test_outdoor_acc=0.7445859909057617
#  test_belt_acc=0.7669990658760071
# 57/57 [==============================] - 11s 149ms/step - loss: 1.3224 - accuracy: 0.8289
# 99/99 [==============================] - 15s 149ms/step - loss: 2.3311 - accuracy: 0.7449
# 69/69 [==============================] - 10s 150ms/step - loss: 2.4745 - accuracy: 0.7661
# Epoch1400
#  test_indoor_acc=0.8288740515708923
#  test_outdoor_acc=0.7449044585227966
#  test_belt_acc=0.7660924792289734
# 57/57 [==============================] - 11s 148ms/step - loss: 1.3295 - accuracy: 0.8283
# 99/99 [==============================] - 15s 149ms/step - loss: 2.3692 - accuracy: 0.7439
# 69/69 [==============================] - 10s 150ms/step - loss: 2.5018 - accuracy: 0.7661
# Epoch1600
#  test_indoor_acc=0.8283166289329529
#  test_outdoor_acc=0.7439490556716919
#  test_belt_acc=0.7660924792289734
# 57/57 [==============================] - 11s 147ms/step - loss: 1.3374 - accuracy: 0.8300
# 99/99 [==============================] - 15s 148ms/step - loss: 2.3723 - accuracy: 0.7455
# 69/69 [==============================] - 10s 149ms/step - loss: 2.5181 - accuracy: 0.7675
# Epoch1800
#  test_indoor_acc=0.8299888372421265
#  test_outdoor_acc=0.7455413937568665
#  test_belt_acc=0.7674524188041687
# 57/57 [==============================] - 11s 149ms/step - loss: 1.3469 - accuracy: 0.8300
# 99/99 [==============================] - 15s 149ms/step - loss: 2.3666 - accuracy: 0.7481
# 69/69 [==============================] - 10s 150ms/step - loss: 2.5323 - accuracy: 0.7652
# Epoch2000
#  test_indoor_acc=0.8299888372421265
#  test_outdoor_acc=0.7480891942977905
#  test_belt_acc=0.7651858329772949

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7810879548390707
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8160535097122192,
#  0.8277592062950134,
#  0.8305462598800659,
#  0.8277592062950134,
#  0.8283166289329529,
#  0.8277592062950134,
#  0.8288740515708923,
#  0.8283166289329529,
#  0.8299888372421265,
#  0.8299888372421265]

# %%
test_outdoor_acc
# Out:
# [0.7423567175865173,
#  0.7458598613739014,
#  0.7452229261398315,
#  0.7452229261398315,
#  0.7445859909057617,
#  0.7445859909057617,
#  0.7449044585227966,
#  0.7439490556716919,
#  0.7455413937568665,
#  0.7480891942977905]

# %%
test_belt_acc
# Out:
# [0.7615593671798706,
#  0.7633726000785828,
#  0.7669990658760071,
#  0.7638259530067444,
#  0.7624660134315491,
#  0.7669990658760071,
#  0.7660924792289734,
#  0.7660924792289734,
#  0.7674524188041687,
#  0.7651858329772949]

# %%
test_indoor_loss
# Out:
# [1.0396335124969482,
#  1.1517835855484009,
#  1.2068569660186768,
#  1.26683509349823,
#  1.2987147569656372,
#  1.3081250190734863,
#  1.3223599195480347,
#  1.32949697971344,
#  1.3373675346374512,
#  1.3469152450561523]

# %%
test_outdoor_loss
# Out:
# [1.7508749961853027,
#  2.004366159439087,
#  2.1440322399139404,
#  2.2187910079956055,
#  2.2917182445526123,
#  2.2989609241485596,
#  2.331070899963379,
#  2.369169235229492,
#  2.372293710708618,
#  2.3666274547576904]

# %%
test_belt_loss
# Out:
# [1.821347951889038,
#  2.1284096240997314,
#  2.235685348510742,
#  2.3553249835968018,
#  2.405691623687744,
#  2.4363386631011963,
#  2.474459409713745,
#  2.50176739692688,
#  2.518134117126465,
#  2.5323140621185303]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.resnet_v2 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5526
# FP=1614
# acc=0.7739495798319328
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 84.48275862068965%
# 2WayConnectorforFoley acc = 96.5986394557823%
# 2WayFoleyCatheter acc = 61.940298507462686%
# 3WayConnectorforFoley acc = 90.5982905982906%
# 3Waystopcock acc = 100.0%
# AlcoholBottle acc = 78.75%
# AlcoholPad acc = 48.41269841269841%
# BootCover acc = 62.048192771084345%
# CottonBall acc = 97.0059880239521%
# CottonSwap acc = 70.62937062937063%
# Dilator acc = 71.7948717948718%
# DisposableInfusionSet acc = 46.017699115044245%
# ExtensionTube acc = 22.76422764227642%
# FaceShield acc = 75.30864197530865%
# FrontLoadSyringe acc = 73.45132743362832%
# GauzePad acc = 66.47727272727273%
# Glove acc = 81.25%
# GuideWire acc = 29.464285714285715%
# LiquidBottle acc = 67.17557251908397%
# Mask acc = 97.92207792207792%
# NGTube acc = 52.903225806451616%
# NasalCannula acc = 57.52212389380531%
# Needle acc = 93.92857142857143%
# OxygenMask acc = 77.44360902255639%
# PPESuit acc = 70.96774193548387%
# PharmaceuticalProduct acc = 71.26168224299066%
# Pill acc = 97.3389355742297%
# PillBottle acc = 78.29457364341084%
# PrefilledHumidifier acc = 84.61538461538461%
# PressureConnectingTube acc = 65.64885496183206%
# ReusableHumidifier acc = 66.94915254237289%
# SodiumChlorideBag acc = 95.2755905511811%
# SterileHumidifierAdapter acc = 94.54545454545455%
# SurgicalBlade acc = 98.23008849557522%
# SurgicalCap acc = 81.98198198198197%
# SurgicalSuit acc = 31.818181818181817%
# Syringe acc = 95.43726235741445%
# TrachealTube acc = 40.36697247706422%
# UrineBag acc = 66.66666666666666%
# Vaccinebottle acc = 92.01877934272301%
# WingedInfusionSet acc = 71.9298245614035%
#
#
#
# all_avg_eachclass = 73.34724078848578%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 98,   1,   0, ...,   0,   0,   0],
#        [  0, 142,   0, ...,   0,   0,   0],
#        [  0,   0,  83, ...,   1,   1,  22],
#        ...,
#        [  0,   0,   0, ...,  80,   0,   3],
#        [  0,   0,   0, ...,   0, 196,   1],
#        [  0,   0,   0, ...,   0,   0,  82]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[84.48275862,  0.86206897,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 96.59863946,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 61.94029851, ...,  0.74626866,
#          0.74626866, 16.41791045],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 66.66666667,
#          0.        ,  2.5       ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         92.01877934,  0.46948357],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 71.92982456]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
