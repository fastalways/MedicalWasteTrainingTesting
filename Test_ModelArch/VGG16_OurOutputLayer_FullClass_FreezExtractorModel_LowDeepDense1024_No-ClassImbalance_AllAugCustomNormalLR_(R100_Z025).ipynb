# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.VGG16(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax") #

model_nooutput = transfered_model.layers[-4].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 25088)             14714688
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 40,447,849
# Trainable params: 25,733,161
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 47s 347ms/step - loss: 3.8565 - accuracy: 0.4100 - val_loss: 1.3075 - val_accuracy: 0.6300
# Epoch 2/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.9417 - accuracy: 0.7412 - val_loss: 0.8816 - val_accuracy: 0.7348
# Epoch 3/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 0.5048 - accuracy: 0.8666 - val_loss: 0.7535 - val_accuracy: 0.7801
# Epoch 4/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.3109 - accuracy: 0.9225 - val_loss: 0.6579 - val_accuracy: 0.8008
# Epoch 5/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.2135 - accuracy: 0.9477 - val_loss: 0.7369 - val_accuracy: 0.7710
# Epoch 6/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.1604 - accuracy: 0.9651 - val_loss: 0.6137 - val_accuracy: 0.8137
# Epoch 7/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.1236 - accuracy: 0.9742 - val_loss: 0.5923 - val_accuracy: 0.8150
# Epoch 8/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0959 - accuracy: 0.9777 - val_loss: 0.6143 - val_accuracy: 0.8176
# Epoch 9/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0836 - accuracy: 0.9822 - val_loss: 0.5866 - val_accuracy: 0.8370
# Epoch 10/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0562 - accuracy: 0.9900 - val_loss: 0.5304 - val_accuracy: 0.8357
# Epoch 11/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0500 - accuracy: 0.9922 - val_loss: 0.5349 - val_accuracy: 0.8370
# Epoch 12/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0399 - accuracy: 0.9932 - val_loss: 0.4951 - val_accuracy: 0.8499
# Epoch 13/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0350 - accuracy: 0.9948 - val_loss: 0.5548 - val_accuracy: 0.8331
# Epoch 14/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0328 - accuracy: 0.9955 - val_loss: 0.5021 - val_accuracy: 0.8525
# Epoch 15/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0294 - accuracy: 0.9942 - val_loss: 0.5183 - val_accuracy: 0.8486
# Epoch 16/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0265 - accuracy: 0.9971 - val_loss: 0.5103 - val_accuracy: 0.8409
# Epoch 17/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0205 - accuracy: 0.9968 - val_loss: 0.5333 - val_accuracy: 0.8448
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 18/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0173 - accuracy: 0.9971 - val_loss: 0.5400 - val_accuracy: 0.8448
# Epoch 19/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0136 - accuracy: 0.9974 - val_loss: 0.5070 - val_accuracy: 0.8435
# Epoch 20/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0116 - accuracy: 0.9997 - val_loss: 0.5328 - val_accuracy: 0.8383
# Epoch 21/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0096 - accuracy: 0.9994 - val_loss: 0.5092 - val_accuracy: 0.8525
# Epoch 22/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0092 - accuracy: 0.9990 - val_loss: 0.5147 - val_accuracy: 0.8499
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0090 - accuracy: 0.9990 - val_loss: 0.5138 - val_accuracy: 0.8499
# Epoch 24/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0086 - accuracy: 0.9997 - val_loss: 0.5134 - val_accuracy: 0.8525
# Epoch 25/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0076 - accuracy: 0.9997 - val_loss: 0.5129 - val_accuracy: 0.8512
# Epoch 26/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.5102 - val_accuracy: 0.8512
# Epoch 27/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0087 - accuracy: 0.9997 - val_loss: 0.5143 - val_accuracy: 0.8512
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 28/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5150 - val_accuracy: 0.8512
# Epoch 29/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.8512
# Epoch 30/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5163 - val_accuracy: 0.8499
# Epoch 31/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8525
# Epoch 32/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.5169 - val_accuracy: 0.8525
# Epoch 33/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.5172 - val_accuracy: 0.8499
# Epoch 34/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0084 - accuracy: 0.9994 - val_loss: 0.5163 - val_accuracy: 0.8499
# Epoch 35/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0077 - accuracy: 0.9990 - val_loss: 0.5176 - val_accuracy: 0.8499
# Epoch 36/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.5179 - val_accuracy: 0.8499
# Epoch 37/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5186 - val_accuracy: 0.8512
# Epoch 38/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0070 - accuracy: 0.9994 - val_loss: 0.5175 - val_accuracy: 0.8473
# Epoch 39/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.8473
# Epoch 40/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0076 - accuracy: 0.9990 - val_loss: 0.5180 - val_accuracy: 0.8473
# Epoch 41/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0086 - accuracy: 0.9994 - val_loss: 0.5173 - val_accuracy: 0.8473
# Epoch 42/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.5175 - val_accuracy: 0.8473
# Epoch 43/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0082 - accuracy: 0.9987 - val_loss: 0.5146 - val_accuracy: 0.8461
# Epoch 44/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.5152 - val_accuracy: 0.8473
# Epoch 45/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0089 - accuracy: 0.9994 - val_loss: 0.5163 - val_accuracy: 0.8473
# Epoch 46/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5139 - val_accuracy: 0.8499
# Epoch 47/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0082 - accuracy: 0.9994 - val_loss: 0.5151 - val_accuracy: 0.8486
# Epoch 48/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.5121 - val_accuracy: 0.8512
# Epoch 49/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.5140 - val_accuracy: 0.8499
# Epoch 50/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9994 - val_loss: 0.5152 - val_accuracy: 0.8486
# Epoch 51/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0081 - accuracy: 0.9997 - val_loss: 0.5155 - val_accuracy: 0.8486
# Epoch 52/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.5157 - val_accuracy: 0.8486
# Epoch 53/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0072 - accuracy: 0.9997 - val_loss: 0.5150 - val_accuracy: 0.8486
# Epoch 54/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.5145 - val_accuracy: 0.8486
# Epoch 55/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 0.5123 - val_accuracy: 0.8486
# Epoch 56/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.5131 - val_accuracy: 0.8473
# Epoch 57/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0087 - accuracy: 0.9990 - val_loss: 0.5127 - val_accuracy: 0.8486
# Epoch 58/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0071 - accuracy: 0.9997 - val_loss: 0.5136 - val_accuracy: 0.8461
# Epoch 59/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.5133 - val_accuracy: 0.8473
# Epoch 60/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.5140 - val_accuracy: 0.8473
# Epoch 61/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 0.5111 - val_accuracy: 0.8473
# Epoch 62/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5099 - val_accuracy: 0.8512
# Epoch 63/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0069 - accuracy: 0.9997 - val_loss: 0.5116 - val_accuracy: 0.8486
# Epoch 64/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.5119 - val_accuracy: 0.8486
# Epoch 65/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0072 - accuracy: 0.9997 - val_loss: 0.5110 - val_accuracy: 0.8512
# Epoch 66/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0074 - accuracy: 0.9994 - val_loss: 0.5147 - val_accuracy: 0.8473
# Epoch 67/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8473
# Epoch 68/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.5102 - val_accuracy: 0.8473
# Epoch 69/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5088 - val_accuracy: 0.8473
# Epoch 70/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 0.5105 - val_accuracy: 0.8486
# Epoch 71/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5102 - val_accuracy: 0.8473
# Epoch 72/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.5100 - val_accuracy: 0.8473
# Epoch 73/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0067 - accuracy: 0.9997 - val_loss: 0.5101 - val_accuracy: 0.8486
# Epoch 74/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0064 - accuracy: 0.9997 - val_loss: 0.5123 - val_accuracy: 0.8486
# Epoch 75/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.5107 - val_accuracy: 0.8486
# Epoch 76/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0068 - accuracy: 0.9997 - val_loss: 0.5063 - val_accuracy: 0.8499
# Epoch 77/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0074 - accuracy: 0.9997 - val_loss: 0.5081 - val_accuracy: 0.8499
# Epoch 78/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.8473
# Epoch 79/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.8461
# Epoch 80/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0071 - accuracy: 0.9997 - val_loss: 0.5164 - val_accuracy: 0.8486
# Epoch 81/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8473
# Epoch 82/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8486
# Epoch 83/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 0.5131 - val_accuracy: 0.8499
# Epoch 84/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0067 - accuracy: 0.9994 - val_loss: 0.5118 - val_accuracy: 0.8486
# Epoch 85/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.5104 - val_accuracy: 0.8486
# Epoch 86/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5109 - val_accuracy: 0.8473
# Epoch 87/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5127 - val_accuracy: 0.8512
# Epoch 88/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0074 - accuracy: 0.9987 - val_loss: 0.5106 - val_accuracy: 0.8486
# Epoch 89/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0072 - accuracy: 0.9994 - val_loss: 0.5083 - val_accuracy: 0.8499
# Epoch 90/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0063 - accuracy: 0.9997 - val_loss: 0.5158 - val_accuracy: 0.8473
# Epoch 91/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8473
# Epoch 92/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.8499
# Epoch 93/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0072 - accuracy: 0.9994 - val_loss: 0.5099 - val_accuracy: 0.8473
# Epoch 94/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 0.5066 - val_accuracy: 0.8525
# Epoch 95/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8512
# Epoch 96/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.8512
# Epoch 97/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.5119 - val_accuracy: 0.8486
# Epoch 98/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.5126 - val_accuracy: 0.8499
# Epoch 99/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0061 - accuracy: 0.9997 - val_loss: 0.5138 - val_accuracy: 0.8486
# Epoch 100/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0066 - accuracy: 0.9994 - val_loss: 0.5132 - val_accuracy: 0.8499
# Epoch 101/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0062 - accuracy: 0.9997 - val_loss: 0.5160 - val_accuracy: 0.8486
# Epoch 102/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5201 - val_accuracy: 0.8473
# Epoch 103/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.5173 - val_accuracy: 0.8486
# Epoch 104/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5160 - val_accuracy: 0.8499
# Epoch 105/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8512
# Epoch 106/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.5151 - val_accuracy: 0.8486
# Epoch 107/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.5149 - val_accuracy: 0.8473
# Epoch 108/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.5147 - val_accuracy: 0.8512
# Epoch 109/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.5218 - val_accuracy: 0.8499
# Epoch 110/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.5179 - val_accuracy: 0.8499
# Epoch 111/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.5202 - val_accuracy: 0.8486
# Epoch 112/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0059 - accuracy: 0.9997 - val_loss: 0.5147 - val_accuracy: 0.8499
# Epoch 113/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0060 - accuracy: 0.9997 - val_loss: 0.5155 - val_accuracy: 0.8499
# Epoch 114/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.5204 - val_accuracy: 0.8486
# Epoch 115/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.8525
# Epoch 116/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0056 - accuracy: 0.9997 - val_loss: 0.5149 - val_accuracy: 0.8512
# Epoch 117/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.5115 - val_accuracy: 0.8512
# Epoch 118/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.5148 - val_accuracy: 0.8512
# Epoch 119/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.5122 - val_accuracy: 0.8512
# Epoch 120/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 0.5091 - val_accuracy: 0.8499
# Epoch 121/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5178 - val_accuracy: 0.8486
# Epoch 122/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.5162 - val_accuracy: 0.8486
# Epoch 123/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 0.5208 - val_accuracy: 0.8473
# Epoch 124/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5198 - val_accuracy: 0.8486
# Epoch 125/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5220 - val_accuracy: 0.8473
# Epoch 126/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0053 - accuracy: 0.9997 - val_loss: 0.5244 - val_accuracy: 0.8461
# Epoch 127/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.5227 - val_accuracy: 0.8461
# Epoch 128/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0046 - accuracy: 0.9997 - val_loss: 0.5210 - val_accuracy: 0.8499
# Epoch 129/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.5191 - val_accuracy: 0.8486
# Epoch 130/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.8512
# Epoch 131/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5223 - val_accuracy: 0.8499
# Epoch 132/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0049 - accuracy: 0.9997 - val_loss: 0.5246 - val_accuracy: 0.8486
# Epoch 133/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0047 - accuracy: 0.9997 - val_loss: 0.5245 - val_accuracy: 0.8473
# Epoch 134/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 0.5215 - val_accuracy: 0.8473
# Epoch 135/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0054 - accuracy: 0.9997 - val_loss: 0.5291 - val_accuracy: 0.8473
# Epoch 136/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.5212 - val_accuracy: 0.8461
# Epoch 137/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8499
# Epoch 138/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.8499
# Epoch 139/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.8499
# Epoch 140/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5202 - val_accuracy: 0.8512
# Epoch 141/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8499
# Epoch 142/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.5219 - val_accuracy: 0.8486
# Epoch 143/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0048 - accuracy: 0.9997 - val_loss: 0.5137 - val_accuracy: 0.8486
# Epoch 144/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0051 - accuracy: 0.9997 - val_loss: 0.5108 - val_accuracy: 0.8551
# Epoch 145/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5138 - val_accuracy: 0.8512
# Epoch 146/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.5150 - val_accuracy: 0.8525
# Epoch 147/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.5204 - val_accuracy: 0.8499
# Epoch 148/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0049 - accuracy: 0.9997 - val_loss: 0.5213 - val_accuracy: 0.8499
# Epoch 149/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5242 - val_accuracy: 0.8486
# Epoch 150/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.5200 - val_accuracy: 0.8499
# Epoch 151/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0046 - accuracy: 0.9997 - val_loss: 0.5222 - val_accuracy: 0.8499
# Epoch 152/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0042 - accuracy: 0.9997 - val_loss: 0.5262 - val_accuracy: 0.8486
# Epoch 153/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.8499
# Epoch 154/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.5230 - val_accuracy: 0.8499
# Epoch 155/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0045 - accuracy: 0.9997 - val_loss: 0.5207 - val_accuracy: 0.8486
# Epoch 156/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.5168 - val_accuracy: 0.8512
# Epoch 157/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0.5209 - val_accuracy: 0.8525
# Epoch 158/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5257 - val_accuracy: 0.8486
# Epoch 159/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.5203 - val_accuracy: 0.8499
# Epoch 160/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.5189 - val_accuracy: 0.8525
# Epoch 161/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5256 - val_accuracy: 0.8486
# Epoch 162/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5183 - val_accuracy: 0.8512
# Epoch 163/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5208 - val_accuracy: 0.8512
# Epoch 164/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.5233 - val_accuracy: 0.8512
# Epoch 165/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0050 - accuracy: 0.9994 - val_loss: 0.5198 - val_accuracy: 0.8512
# Epoch 166/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.5246 - val_accuracy: 0.8512
# Epoch 167/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.5208 - val_accuracy: 0.8525
# Epoch 168/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0046 - accuracy: 0.9997 - val_loss: 0.5134 - val_accuracy: 0.8512
# Epoch 169/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.5202 - val_accuracy: 0.8499
# Epoch 170/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.5240 - val_accuracy: 0.8525
# Epoch 171/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.5255 - val_accuracy: 0.8499
# Epoch 172/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.5246 - val_accuracy: 0.8512
# Epoch 173/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.5210 - val_accuracy: 0.8525
# Epoch 174/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5295 - val_accuracy: 0.8512
# Epoch 175/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.5261 - val_accuracy: 0.8499
# Epoch 176/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5243 - val_accuracy: 0.8499
# Epoch 177/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.5242 - val_accuracy: 0.8525
# Epoch 178/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.5267 - val_accuracy: 0.8499
# Epoch 179/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.5226 - val_accuracy: 0.8538
# Epoch 180/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5257 - val_accuracy: 0.8525
# Epoch 181/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5290 - val_accuracy: 0.8525
# Epoch 182/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.5307 - val_accuracy: 0.8499
# Epoch 183/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.8525
# Epoch 184/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.5344 - val_accuracy: 0.8512
# Epoch 185/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5317 - val_accuracy: 0.8538
# Epoch 186/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.5312 - val_accuracy: 0.8551
# Epoch 187/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.5245 - val_accuracy: 0.8590
# Epoch 188/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5223 - val_accuracy: 0.8525
# Epoch 189/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.5257 - val_accuracy: 0.8564
# Epoch 190/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5268 - val_accuracy: 0.8538
# Epoch 191/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5335 - val_accuracy: 0.8525
# Epoch 192/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.5327 - val_accuracy: 0.8512
# Epoch 193/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5352 - val_accuracy: 0.8512
# Epoch 194/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5358 - val_accuracy: 0.8512
# Epoch 195/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5367 - val_accuracy: 0.8486
# Epoch 196/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5392 - val_accuracy: 0.8486
# Epoch 197/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.5395 - val_accuracy: 0.8473
# Epoch 198/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5391 - val_accuracy: 0.8538
# Epoch 199/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.5426 - val_accuracy: 0.8525
# Epoch 200/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.5326 - val_accuracy: 0.8551
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.8551
# Epoch 202/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5341 - val_accuracy: 0.8551
# Epoch 203/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5305 - val_accuracy: 0.8590
# Epoch 204/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.8551
# Epoch 205/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5371 - val_accuracy: 0.8525
# Epoch 206/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.8499
# Epoch 207/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5311 - val_accuracy: 0.8499
# Epoch 208/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.5298 - val_accuracy: 0.8512
# Epoch 209/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5319 - val_accuracy: 0.8499
# Epoch 210/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.5294 - val_accuracy: 0.8525
# Epoch 211/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5302 - val_accuracy: 0.8512
# Epoch 212/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5316 - val_accuracy: 0.8512
# Epoch 213/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.8525
# Epoch 214/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.5288 - val_accuracy: 0.8538
# Epoch 215/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5262 - val_accuracy: 0.8538
# Epoch 216/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.5341 - val_accuracy: 0.8525
# Epoch 217/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.8538
# Epoch 218/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5330 - val_accuracy: 0.8512
# Epoch 219/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5327 - val_accuracy: 0.8512
# Epoch 220/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.8538
# Epoch 221/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.5399 - val_accuracy: 0.8538
# Epoch 222/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5423 - val_accuracy: 0.8538
# Epoch 223/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5470 - val_accuracy: 0.8512
# Epoch 224/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.8512
# Epoch 225/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5455 - val_accuracy: 0.8473
# Epoch 226/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5472 - val_accuracy: 0.8512
# Epoch 227/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8486
# Epoch 228/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.5481 - val_accuracy: 0.8538
# Epoch 229/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.5456 - val_accuracy: 0.8512
# Epoch 230/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.8525
# Epoch 231/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.5336 - val_accuracy: 0.8551
# Epoch 232/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.5355 - val_accuracy: 0.8538
# Epoch 233/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.5391 - val_accuracy: 0.8512
# Epoch 234/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5412 - val_accuracy: 0.8512
# Epoch 235/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5374 - val_accuracy: 0.8538
# Epoch 236/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.5500 - val_accuracy: 0.8499
# Epoch 237/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5409 - val_accuracy: 0.8473
# Epoch 238/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8499
# Epoch 239/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5516 - val_accuracy: 0.8473
# Epoch 240/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5512 - val_accuracy: 0.8473
# Epoch 241/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.8525
# Epoch 242/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5464 - val_accuracy: 0.8525
# Epoch 243/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5519 - val_accuracy: 0.8486
# Epoch 244/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8551
# Epoch 245/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.5525 - val_accuracy: 0.8499
# Epoch 246/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.8538
# Epoch 247/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.8551
# Epoch 248/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5412 - val_accuracy: 0.8499
# Epoch 249/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5495 - val_accuracy: 0.8486
# Epoch 250/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5389 - val_accuracy: 0.8538
# Epoch 251/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5352 - val_accuracy: 0.8538
# Epoch 252/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5402 - val_accuracy: 0.8512
# Epoch 253/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.8486
# Epoch 254/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5467 - val_accuracy: 0.8499
# Epoch 255/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8525
# Epoch 256/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5464 - val_accuracy: 0.8499
# Epoch 257/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.5487 - val_accuracy: 0.8486
# Epoch 258/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5505 - val_accuracy: 0.8525
# Epoch 259/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5513 - val_accuracy: 0.8499
# Epoch 260/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5546 - val_accuracy: 0.8499
# Epoch 261/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5571 - val_accuracy: 0.8512
# Epoch 262/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5603 - val_accuracy: 0.8486
# Epoch 263/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5539 - val_accuracy: 0.8473
# Epoch 264/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8473
# Epoch 265/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5427 - val_accuracy: 0.8486
# Epoch 266/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.5444 - val_accuracy: 0.8486
# Epoch 267/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5403 - val_accuracy: 0.8486
# Epoch 268/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5426 - val_accuracy: 0.8499
# Epoch 269/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5496 - val_accuracy: 0.8499
# Epoch 270/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5475 - val_accuracy: 0.8499
# Epoch 271/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5485 - val_accuracy: 0.8525
# Epoch 272/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5473 - val_accuracy: 0.8486
# Epoch 273/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.8512
# Epoch 274/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5566 - val_accuracy: 0.8525
# Epoch 275/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5411 - val_accuracy: 0.8564
# Epoch 276/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5496 - val_accuracy: 0.8525
# Epoch 277/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.5569 - val_accuracy: 0.8486
# Epoch 278/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5499 - val_accuracy: 0.8499
# Epoch 279/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5488 - val_accuracy: 0.8486
# Epoch 280/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5505 - val_accuracy: 0.8499
# Epoch 281/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.8486
# Epoch 282/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8499
# Epoch 283/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.8486
# Epoch 284/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5563 - val_accuracy: 0.8525
# Epoch 285/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5561 - val_accuracy: 0.8512
# Epoch 286/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5609 - val_accuracy: 0.8525
# Epoch 287/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8538
# Epoch 288/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8577
# Epoch 289/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.8564
# Epoch 290/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.8538
# Epoch 291/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5635 - val_accuracy: 0.8512
# Epoch 292/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5587 - val_accuracy: 0.8525
# Epoch 293/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5541 - val_accuracy: 0.8525
# Epoch 294/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5420 - val_accuracy: 0.8538
# Epoch 295/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.5549 - val_accuracy: 0.8538
# Epoch 296/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5585 - val_accuracy: 0.8551
# Epoch 297/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5568 - val_accuracy: 0.8512
# Epoch 298/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5575 - val_accuracy: 0.8486
# Epoch 299/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5594 - val_accuracy: 0.8512
# Epoch 300/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5547 - val_accuracy: 0.8512
# Epoch 301/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5549 - val_accuracy: 0.8512
# Epoch 302/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.8512
# Epoch 303/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5623 - val_accuracy: 0.8564
# Epoch 304/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5630 - val_accuracy: 0.8512
# Epoch 305/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.8525
# Epoch 306/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5586 - val_accuracy: 0.8512
# Epoch 307/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5578 - val_accuracy: 0.8538
# Epoch 308/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5610 - val_accuracy: 0.8525
# Epoch 309/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5609 - val_accuracy: 0.8525
# Epoch 310/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5627 - val_accuracy: 0.8499
# Epoch 311/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5676 - val_accuracy: 0.8486
# Epoch 312/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5672 - val_accuracy: 0.8512
# Epoch 313/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5551 - val_accuracy: 0.8538
# Epoch 314/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.8454e-04 - accuracy: 1.0000 - val_loss: 0.5577 - val_accuracy: 0.8499
# Epoch 315/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.8551
# Epoch 316/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5626 - val_accuracy: 0.8499
# Epoch 317/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5517 - val_accuracy: 0.8512
# Epoch 318/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5551 - val_accuracy: 0.8512
# Epoch 319/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5572 - val_accuracy: 0.8499
# Epoch 320/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.8512
# Epoch 321/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.8499
# Epoch 322/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5654 - val_accuracy: 0.8512
# Epoch 323/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5612 - val_accuracy: 0.8538
# Epoch 324/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5657 - val_accuracy: 0.8512
# Epoch 325/2000
# 49/49 [==============================] - 8s 170ms/step - loss: 9.8535e-04 - accuracy: 1.0000 - val_loss: 0.5622 - val_accuracy: 0.8512
# Epoch 326/2000
# ...
# Epoch 1897/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 1.9882e-06 - accuracy: 1.0000 - val_loss: 0.7672 - val_accuracy: 0.8668
# Epoch 1898/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7472e-06 - accuracy: 1.0000 - val_loss: 0.7709 - val_accuracy: 0.8668
# Epoch 1899/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.3752e-06 - accuracy: 1.0000 - val_loss: 0.7656 - val_accuracy: 0.8668
# Epoch 1900/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.1678e-06 - accuracy: 1.0000 - val_loss: 0.7632 - val_accuracy: 0.8668
# Epoch 1901/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.3448e-06 - accuracy: 1.0000 - val_loss: 0.7696 - val_accuracy: 0.8680
# Epoch 1902/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.9119e-06 - accuracy: 1.0000 - val_loss: 0.7664 - val_accuracy: 0.8693
# Epoch 1903/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.4502e-06 - accuracy: 1.0000 - val_loss: 0.7722 - val_accuracy: 0.8655
# Epoch 1904/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.0048e-06 - accuracy: 1.0000 - val_loss: 0.7783 - val_accuracy: 0.8668
# Epoch 1905/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.5722e-06 - accuracy: 1.0000 - val_loss: 0.7756 - val_accuracy: 0.8693
# Epoch 1906/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9975e-06 - accuracy: 1.0000 - val_loss: 0.7746 - val_accuracy: 0.8680
# Epoch 1907/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5833e-06 - accuracy: 1.0000 - val_loss: 0.7707 - val_accuracy: 0.8680
# Epoch 1908/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.4799e-06 - accuracy: 1.0000 - val_loss: 0.7760 - val_accuracy: 0.8693
# Epoch 1909/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.6296e-06 - accuracy: 1.0000 - val_loss: 0.7822 - val_accuracy: 0.8706
# Epoch 1910/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 5.3723e-06 - accuracy: 1.0000 - val_loss: 0.8198 - val_accuracy: 0.8616
# Epoch 1911/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.6543e-06 - accuracy: 1.0000 - val_loss: 0.8138 - val_accuracy: 0.8616
# Epoch 1912/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7705e-06 - accuracy: 1.0000 - val_loss: 0.8081 - val_accuracy: 0.8668
# Epoch 1913/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5080e-06 - accuracy: 1.0000 - val_loss: 0.8012 - val_accuracy: 0.8655
# Epoch 1914/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7246e-06 - accuracy: 1.0000 - val_loss: 0.7984 - val_accuracy: 0.8655
# Epoch 1915/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5361e-05 - accuracy: 1.0000 - val_loss: 0.7805 - val_accuracy: 0.8668
# Epoch 1916/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.1785e-06 - accuracy: 1.0000 - val_loss: 0.7767 - val_accuracy: 0.8655
# Epoch 1917/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7452e-06 - accuracy: 1.0000 - val_loss: 0.7734 - val_accuracy: 0.8642
# Epoch 1918/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9497e-06 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.8642
# Epoch 1919/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.9768e-06 - accuracy: 1.0000 - val_loss: 0.7695 - val_accuracy: 0.8642
# Epoch 1920/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.9996e-06 - accuracy: 1.0000 - val_loss: 0.7673 - val_accuracy: 0.8629
# Epoch 1921/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 4.1009e-06 - accuracy: 1.0000 - val_loss: 0.7632 - val_accuracy: 0.8629
# Epoch 1922/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.3114e-06 - accuracy: 1.0000 - val_loss: 0.7659 - val_accuracy: 0.8629
# Epoch 1923/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.6809e-06 - accuracy: 1.0000 - val_loss: 0.7733 - val_accuracy: 0.8642
# Epoch 1924/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.1595e-06 - accuracy: 1.0000 - val_loss: 0.7714 - val_accuracy: 0.8629
# Epoch 1925/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.8266e-06 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.8616
# Epoch 1926/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.6588e-06 - accuracy: 1.0000 - val_loss: 0.7688 - val_accuracy: 0.8616
# Epoch 1927/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 6.1496e-06 - accuracy: 1.0000 - val_loss: 0.7796 - val_accuracy: 0.8577
# Epoch 1928/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.7426e-06 - accuracy: 1.0000 - val_loss: 0.7710 - val_accuracy: 0.8590
# Epoch 1929/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.4216e-06 - accuracy: 1.0000 - val_loss: 0.7725 - val_accuracy: 0.8590
# Epoch 1930/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.0382e-06 - accuracy: 1.0000 - val_loss: 0.7851 - val_accuracy: 0.8577
# Epoch 1931/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.6773e-06 - accuracy: 1.0000 - val_loss: 0.7853 - val_accuracy: 0.8551
# Epoch 1932/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.9903e-06 - accuracy: 1.0000 - val_loss: 0.7841 - val_accuracy: 0.8577
# Epoch 1933/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.0566e-06 - accuracy: 1.0000 - val_loss: 0.7682 - val_accuracy: 0.8551
# Epoch 1934/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.0072e-06 - accuracy: 1.0000 - val_loss: 0.7691 - val_accuracy: 0.8564
# Epoch 1935/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 1.8375e-06 - accuracy: 1.0000 - val_loss: 0.7743 - val_accuracy: 0.8564
# Epoch 1936/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.0544e-06 - accuracy: 1.0000 - val_loss: 0.7729 - val_accuracy: 0.8577
# Epoch 1937/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9951e-06 - accuracy: 1.0000 - val_loss: 0.7693 - val_accuracy: 0.8590
# Epoch 1938/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.6478e-06 - accuracy: 1.0000 - val_loss: 0.7730 - val_accuracy: 0.8603
# Epoch 1939/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.9159e-06 - accuracy: 1.0000 - val_loss: 0.7769 - val_accuracy: 0.8616
# Epoch 1940/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9478e-06 - accuracy: 1.0000 - val_loss: 0.7798 - val_accuracy: 0.8616
# Epoch 1941/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 1.7679e-06 - accuracy: 1.0000 - val_loss: 0.7757 - val_accuracy: 0.8629
# Epoch 1942/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.8799e-06 - accuracy: 1.0000 - val_loss: 0.7742 - val_accuracy: 0.8603
# Epoch 1943/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.8987e-06 - accuracy: 1.0000 - val_loss: 0.7731 - val_accuracy: 0.8603
# Epoch 1944/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7213e-06 - accuracy: 1.0000 - val_loss: 0.7714 - val_accuracy: 0.8629
# Epoch 1945/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5625e-06 - accuracy: 1.0000 - val_loss: 0.7738 - val_accuracy: 0.8629
# Epoch 1946/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7352e-06 - accuracy: 1.0000 - val_loss: 0.7715 - val_accuracy: 0.8655
# Epoch 1947/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.4990e-06 - accuracy: 1.0000 - val_loss: 0.7724 - val_accuracy: 0.8655
# Epoch 1948/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.0626e-06 - accuracy: 1.0000 - val_loss: 0.7698 - val_accuracy: 0.8668
# Epoch 1949/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.3381e-06 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.8668
# Epoch 1950/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.1384e-06 - accuracy: 1.0000 - val_loss: 0.7667 - val_accuracy: 0.8668
# Epoch 1951/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.5704e-06 - accuracy: 1.0000 - val_loss: 0.7745 - val_accuracy: 0.8655
# Epoch 1952/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7731e-06 - accuracy: 1.0000 - val_loss: 0.7727 - val_accuracy: 0.8629
# Epoch 1953/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.8302e-06 - accuracy: 1.0000 - val_loss: 0.7830 - val_accuracy: 0.8655
# Epoch 1954/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.3591e-06 - accuracy: 1.0000 - val_loss: 0.7827 - val_accuracy: 0.8668
# Epoch 1955/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.3847e-06 - accuracy: 1.0000 - val_loss: 0.7884 - val_accuracy: 0.8629
# Epoch 1956/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 5.8731e-06 - accuracy: 1.0000 - val_loss: 0.7773 - val_accuracy: 0.8616
# Epoch 1957/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7810e-06 - accuracy: 1.0000 - val_loss: 0.7687 - val_accuracy: 0.8629
# Epoch 1958/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5853e-06 - accuracy: 1.0000 - val_loss: 0.7676 - val_accuracy: 0.8603
# Epoch 1959/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7168e-06 - accuracy: 1.0000 - val_loss: 0.7683 - val_accuracy: 0.8590
# Epoch 1960/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.2983e-06 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.8616
# Epoch 1961/2000
# 49/49 [==============================] - 8s 169ms/step - loss: 2.2319e-06 - accuracy: 1.0000 - val_loss: 0.7802 - val_accuracy: 0.8577
# Epoch 1962/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.6673e-06 - accuracy: 1.0000 - val_loss: 0.7854 - val_accuracy: 0.8629
# Epoch 1963/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.2621e-06 - accuracy: 1.0000 - val_loss: 0.7856 - val_accuracy: 0.8629
# Epoch 1964/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.2214e-06 - accuracy: 1.0000 - val_loss: 0.7936 - val_accuracy: 0.8629
# Epoch 1965/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9593e-06 - accuracy: 1.0000 - val_loss: 0.7903 - val_accuracy: 0.8629
# Epoch 1966/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9119e-06 - accuracy: 1.0000 - val_loss: 0.7890 - val_accuracy: 0.8642
# Epoch 1967/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.3357e-06 - accuracy: 1.0000 - val_loss: 0.7919 - val_accuracy: 0.8642
# Epoch 1968/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.0857e-06 - accuracy: 1.0000 - val_loss: 0.7939 - val_accuracy: 0.8603
# Epoch 1969/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.1598e-06 - accuracy: 1.0000 - val_loss: 0.7852 - val_accuracy: 0.8590
# Epoch 1970/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.0786e-06 - accuracy: 1.0000 - val_loss: 0.7851 - val_accuracy: 0.8603
# Epoch 1971/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.8681e-06 - accuracy: 1.0000 - val_loss: 0.7726 - val_accuracy: 0.8642
# Epoch 1972/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.4001e-06 - accuracy: 1.0000 - val_loss: 0.7715 - val_accuracy: 0.8616
# Epoch 1973/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.6863e-06 - accuracy: 1.0000 - val_loss: 0.7717 - val_accuracy: 0.8642
# Epoch 1974/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.8670e-06 - accuracy: 1.0000 - val_loss: 0.7724 - val_accuracy: 0.8616
# Epoch 1975/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.8066e-06 - accuracy: 1.0000 - val_loss: 0.7776 - val_accuracy: 0.8590
# Epoch 1976/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.3664e-06 - accuracy: 1.0000 - val_loss: 0.7802 - val_accuracy: 0.8603
# Epoch 1977/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5765e-06 - accuracy: 1.0000 - val_loss: 0.7911 - val_accuracy: 0.8590
# Epoch 1978/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5862e-06 - accuracy: 1.0000 - val_loss: 0.7986 - val_accuracy: 0.8603
# Epoch 1979/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7343e-06 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.8603
# Epoch 1980/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7398e-06 - accuracy: 1.0000 - val_loss: 0.7875 - val_accuracy: 0.8603
# Epoch 1981/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9133e-06 - accuracy: 1.0000 - val_loss: 0.7823 - val_accuracy: 0.8603
# Epoch 1982/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.2652e-06 - accuracy: 1.0000 - val_loss: 0.7822 - val_accuracy: 0.8603
# Epoch 1983/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.7794e-06 - accuracy: 1.0000 - val_loss: 0.7833 - val_accuracy: 0.8616
# Epoch 1984/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9104e-06 - accuracy: 1.0000 - val_loss: 0.7934 - val_accuracy: 0.8629
# Epoch 1985/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.4106e-06 - accuracy: 1.0000 - val_loss: 0.7970 - val_accuracy: 0.8616
# Epoch 1986/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 3.4011e-06 - accuracy: 1.0000 - val_loss: 0.8079 - val_accuracy: 0.8590
# Epoch 1987/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.5593e-06 - accuracy: 1.0000 - val_loss: 0.7635 - val_accuracy: 0.8655
# Epoch 1988/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9674e-06 - accuracy: 1.0000 - val_loss: 0.7683 - val_accuracy: 0.8655
# Epoch 1989/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.2939e-06 - accuracy: 1.0000 - val_loss: 0.7737 - val_accuracy: 0.8680
# Epoch 1990/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.3655e-06 - accuracy: 1.0000 - val_loss: 0.7900 - val_accuracy: 0.8655
# Epoch 1991/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 4.5237e-06 - accuracy: 1.0000 - val_loss: 0.7942 - val_accuracy: 0.8616
# Epoch 1992/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 5.1599e-06 - accuracy: 1.0000 - val_loss: 0.7898 - val_accuracy: 0.8655
# Epoch 1993/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.3008e-06 - accuracy: 1.0000 - val_loss: 0.7872 - val_accuracy: 0.8603
# Epoch 1994/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.9145e-06 - accuracy: 1.0000 - val_loss: 0.7885 - val_accuracy: 0.8616
# Epoch 1995/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.6785e-06 - accuracy: 1.0000 - val_loss: 0.7920 - val_accuracy: 0.8616
# Epoch 1996/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.5291e-06 - accuracy: 1.0000 - val_loss: 0.7948 - val_accuracy: 0.8629
# Epoch 1997/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.4957e-06 - accuracy: 1.0000 - val_loss: 0.7947 - val_accuracy: 0.8629
# Epoch 1998/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.4321e-06 - accuracy: 1.0000 - val_loss: 0.7942 - val_accuracy: 0.8577
# Epoch 1999/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 2.0507e-06 - accuracy: 1.0000 - val_loss: 0.7882 - val_accuracy: 0.8590
# Epoch 2000/2000
# 49/49 [==============================] - 8s 168ms/step - loss: 1.3793e-06 - accuracy: 1.0000 - val_loss: 0.7885 - val_accuracy: 0.8590
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 13s 312ms/step - loss: 3.1439 - accuracy: 0.5329
# test_indoor_ds_results:test loss, test acc: [3.1438941955566406, 0.5328873991966248]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 25s 413ms/step - loss: 5.3405 - accuracy: 0.4475
# test_outdoor_ds_results:test loss, test acc: [5.340490818023682, 0.44745221734046936]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 11s 272ms/step - loss: 3.1811 - accuracy: 0.5734
# test_belt_ds_results:test loss, test acc: [3.181084632873535, 0.5734360814094543]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/VGG16_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 4s 128ms/step - loss: 1.9787 - accuracy: 0.5340
# 50/50 [==============================] - 7s 130ms/step - loss: 3.2743 - accuracy: 0.4411
# 35/35 [==============================] - 5s 131ms/step - loss: 2.0345 - accuracy: 0.5671
# Epoch200
#  test_indoor_acc=0.5340022444725037
#  test_outdoor_acc=0.44108280539512634
#  test_belt_acc=0.5670897364616394
# 29/29 [==============================] - 4s 128ms/step - loss: 2.1565 - accuracy: 0.5373
# 50/50 [==============================] - 7s 130ms/step - loss: 3.7169 - accuracy: 0.4392
# 35/35 [==============================] - 5s 131ms/step - loss: 2.2132 - accuracy: 0.5730
# Epoch400
#  test_indoor_acc=0.5373467206954956
#  test_outdoor_acc=0.4391719698905945
#  test_belt_acc=0.5729827880859375
# 29/29 [==============================] - 4s 128ms/step - loss: 2.3677 - accuracy: 0.5329
# 50/50 [==============================] - 7s 130ms/step - loss: 3.9576 - accuracy: 0.4465
# 35/35 [==============================] - 5s 131ms/step - loss: 2.4014 - accuracy: 0.5734
# Epoch600
#  test_indoor_acc=0.5328873991966248
#  test_outdoor_acc=0.4464968144893646
#  test_belt_acc=0.5734360814094543
# 29/29 [==============================] - 4s 130ms/step - loss: 2.4639 - accuracy: 0.5373
# 50/50 [==============================] - 7s 132ms/step - loss: 4.2826 - accuracy: 0.4452
# 35/35 [==============================] - 5s 132ms/step - loss: 2.5171 - accuracy: 0.5789
# Epoch800
#  test_indoor_acc=0.5373467206954956
#  test_outdoor_acc=0.445222944021225
#  test_belt_acc=0.5788757801055908
# 29/29 [==============================] - 4s 129ms/step - loss: 2.6284 - accuracy: 0.5312
# 50/50 [==============================] - 7s 131ms/step - loss: 4.5825 - accuracy: 0.4417
# 35/35 [==============================] - 5s 132ms/step - loss: 2.6721 - accuracy: 0.5775
# Epoch1000
#  test_indoor_acc=0.5312151908874512
#  test_outdoor_acc=0.44171974062919617
#  test_belt_acc=0.5775158405303955
# 29/29 [==============================] - 4s 129ms/step - loss: 2.7500 - accuracy: 0.5390
# 50/50 [==============================] - 7s 131ms/step - loss: 4.8253 - accuracy: 0.4420
# 35/35 [==============================] - 5s 131ms/step - loss: 2.8006 - accuracy: 0.5771
# Epoch1200
#  test_indoor_acc=0.5390189290046692
#  test_outdoor_acc=0.4420382082462311
#  test_belt_acc=0.5770625472068787
# 29/29 [==============================] - 4s 130ms/step - loss: 2.8886 - accuracy: 0.5273
# 50/50 [==============================] - 7s 132ms/step - loss: 5.0134 - accuracy: 0.4459
# 35/35 [==============================] - 5s 132ms/step - loss: 2.9457 - accuracy: 0.5716
# Epoch1400
#  test_indoor_acc=0.5273132920265198
#  test_outdoor_acc=0.4458598792552948
#  test_belt_acc=0.5716228485107422
# 29/29 [==============================] - 4s 130ms/step - loss: 3.0015 - accuracy: 0.5312
# 50/50 [==============================] - 7s 132ms/step - loss: 5.1822 - accuracy: 0.4478
# 35/35 [==============================] - 5s 133ms/step - loss: 3.0225 - accuracy: 0.5716
# Epoch1600
#  test_indoor_acc=0.5312151908874512
#  test_outdoor_acc=0.44777071475982666
#  test_belt_acc=0.5716228485107422
# 29/29 [==============================] - 4s 129ms/step - loss: 3.0568 - accuracy: 0.5329
# 50/50 [==============================] - 7s 131ms/step - loss: 5.2048 - accuracy: 0.4462
# 35/35 [==============================] - 5s 132ms/step - loss: 3.0775 - accuracy: 0.5734
# Epoch1800
#  test_indoor_acc=0.5328873991966248
#  test_outdoor_acc=0.4461783468723297
#  test_belt_acc=0.5734360814094543
# 29/29 [==============================] - 4s 130ms/step - loss: 3.1439 - accuracy: 0.5329
# 50/50 [==============================] - 7s 132ms/step - loss: 5.3405 - accuracy: 0.4475
# 35/35 [==============================] - 5s 132ms/step - loss: 3.1811 - accuracy: 0.5734
# Epoch2000
#  test_indoor_acc=0.5328873991966248
#  test_outdoor_acc=0.44745221734046936
#  test_belt_acc=0.5734360814094543

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.5204818149407705
# max index -> 3
# The [Epoch] of max acc -> 800

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.5340022444725037,
#  0.5373467206954956,
#  0.5328873991966248,
#  0.5373467206954956,
#  0.5312151908874512,
#  0.5390189290046692,
#  0.5273132920265198,
#  0.5312151908874512,
#  0.5328873991966248,
#  0.5328873991966248]

# %%
test_outdoor_acc
# Out:
# [0.44108280539512634,
#  0.4391719698905945,
#  0.4464968144893646,
#  0.445222944021225,
#  0.44171974062919617,
#  0.4420382082462311,
#  0.4458598792552948,
#  0.44777071475982666,
#  0.4461783468723297,
#  0.44745221734046936]

# %%
test_belt_acc
# Out:
# [0.5670897364616394,
#  0.5729827880859375,
#  0.5734360814094543,
#  0.5788757801055908,
#  0.5775158405303955,
#  0.5770625472068787,
#  0.5716228485107422,
#  0.5716228485107422,
#  0.5734360814094543,
#  0.5734360814094543]

# %%
test_indoor_loss
# Out:
# [1.978704571723938,
#  2.1565327644348145,
#  2.3677492141723633,
#  2.463895559310913,
#  2.628424882888794,
#  2.7500038146972656,
#  2.888570785522461,
#  3.001452922821045,
#  3.056837320327759,
#  3.1438941955566406]

# %%
test_outdoor_loss
# Out:
# [3.2742862701416016,
#  3.7169337272644043,
#  3.957589626312256,
#  4.282643795013428,
#  4.58254337310791,
#  4.82526969909668,
#  5.013433456420898,
#  5.182183742523193,
#  5.204768180847168,
#  5.340490818023682]

# %%
test_belt_loss
# Out:
# [2.0344719886779785,
#  2.2131595611572266,
#  2.4014487266540527,
#  2.5171303749084473,
#  2.672050952911377,
#  2.800602436065674,
#  2.945695161819458,
#  3.02252197265625,
#  3.077477216720581,
#  3.181084632873535]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.vgg16 import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=3639
# FP=3501
# acc=0.5096638655462185
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 22.413793103448278%
# 2WayConnectorforFoley acc = 46.25850340136054%
# 2WayFoleyCatheter acc = 47.76119402985074%
# 3WayConnectorforFoley acc = 58.97435897435898%
# 3Waystopcock acc = 83.78378378378379%
# AlcoholBottle acc = 64.375%
# AlcoholPad acc = 22.22222222222222%
# BootCover acc = 19.27710843373494%
# CottonBall acc = 55.08982035928144%
# CottonSwap acc = 26.573426573426573%
# Dilator acc = 42.73504273504273%
# DisposableInfusionSet acc = 15.04424778761062%
# ExtensionTube acc = 21.951219512195124%
# FaceShield acc = 30.246913580246915%
# FrontLoadSyringe acc = 4.424778761061947%
# GauzePad acc = 2.272727272727273%
# Glove acc = 74.40476190476191%
# GuideWire acc = 32.142857142857146%
# LiquidBottle acc = 22.900763358778626%
# Mask acc = 78.18181818181819%
# NGTube acc = 37.41935483870968%
# NasalCannula acc = 50.442477876106196%
# Needle acc = 91.78571428571428%
# OxygenMask acc = 73.68421052631578%
# PPESuit acc = 62.096774193548384%
# PharmaceuticalProduct acc = 50.93457943925234%
# Pill acc = 89.91596638655463%
# PillBottle acc = 28.68217054263566%
# PrefilledHumidifier acc = 11.965811965811966%
# PressureConnectingTube acc = 45.80152671755725%
# ReusableHumidifier acc = 27.11864406779661%
# SodiumChlorideBag acc = 55.118110236220474%
# SterileHumidifierAdapter acc = 24.545454545454547%
# SurgicalBlade acc = 31.858407079646017%
# SurgicalCap acc = 84.68468468468468%
# SurgicalSuit acc = 34.090909090909086%
# Syringe acc = 55.51330798479087%
# TrachealTube acc = 39.44954128440367%
# UrineBag acc = 10.833333333333334%
# Vaccinebottle acc = 73.70892018779342%
# WingedInfusionSet acc = 40.35087719298245%
#
#
#
# all_avg_eachclass = 43.68378335558021%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 26,   1,   0, ...,   0,   3,   0],
#        [  0,  68,   0, ...,   0,   0,   0],
#        [  0,   1,  64, ...,   0,   1,  17],
#        ...,
#        [  0,   0,   0, ...,  13,  24,   2],
#        [  0,   0,   0, ...,   0, 157,   0],
#        [  0,   0,   3, ...,   0,  11,  46]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[22.4137931 ,  0.86206897,  0.        , ...,  0.        ,
#          2.5862069 ,  0.        ],
#        [ 0.        , 46.2585034 ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.74626866, 47.76119403, ...,  0.        ,
#          0.74626866, 12.68656716],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 10.83333333,
#         20.        ,  1.66666667],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         73.70892019,  0.        ],
#        [ 0.        ,  0.        ,  2.63157895, ...,  0.        ,
#          9.64912281, 40.35087719]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
