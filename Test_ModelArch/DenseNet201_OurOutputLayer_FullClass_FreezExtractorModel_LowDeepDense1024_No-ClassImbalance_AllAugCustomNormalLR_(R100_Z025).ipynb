# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=224
img_width=224
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 224, 224, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.densenet import DenseNet201,preprocess_input

#                                                                                                                               VVVVVV  another model don't forgot to put softmax
transfered_model = keras.applications.DenseNet201(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet") #,classifier_activation="softmax"

model_nooutput = transfered_model.layers[-2].output
custom_model = Model(inputs = transfered_model.input, outputs = model_nooutput)

# %% [markdown]
# ## Freez Extractor+

# %%
custom_model.trainable = False
for layer in custom_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_model.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 230, 230, 3)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 114, 114, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 56, 56, 64)   0           zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 56, 56, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 56, 56, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 56, 56, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 56, 56, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 56, 56, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 56, 56, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 56, 56, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 56, 56, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 56, 56, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 56, 56, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 56, 56, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 56, 56, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 56, 56, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 56, 56, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 56, 56, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 56, 56, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 56, 56, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 56, 56, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 56, 56, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 56, 56, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 56, 56, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 56, 56, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 56, 56, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 56, 56, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 56, 56, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 56, 56, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 56, 56, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 28, 28, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 28, 28, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 28, 28, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 28, 28, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 28, 28, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 28, 28, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 28, 28, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 28, 28, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 28, 28, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 28, 28, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 28, 28, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 28, 28, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 28, 28, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 28, 28, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 28, 28, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 28, 28, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 28, 28, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 28, 28, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 28, 28, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 28, 28, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 28, 28, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 28, 28, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 28, 28, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 28, 28, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 28, 28, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 28, 28, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 28, 28, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 28, 28, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 28, 28, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 28, 28, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 28, 28, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 28, 28, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 28, 28, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 28, 28, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 28, 28, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 28, 28, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 28, 28, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 28, 28, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 28, 28, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 28, 28, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 28, 28, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 28, 28, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 28, 28, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 28, 28, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 28, 28, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 28, 28, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 28, 28, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 28, 28, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 28, 28, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 28, 28, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 28, 28, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 28, 28, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 28, 28, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 28, 28, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 28, 28, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 28, 28, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 14, 14, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 14, 14, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 14, 14, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 14, 14, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 14, 14, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 14, 14, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 14, 14, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 14, 14, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 14, 14, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 14, 14, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 14, 14, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 14, 14, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 14, 14, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 14, 14, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 14, 14, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 14, 14, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 14, 14, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 14, 14, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 14, 14, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 14, 14, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 14, 14, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 14, 14, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 14, 14, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 14, 14, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 14, 14, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 14, 14, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 14, 14, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 14, 14, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 14, 14, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 14, 14, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 14, 14, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 14, 14, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 14, 14, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 14, 14, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 14, 14, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 14, 14, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 14, 14, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 14, 14, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 14, 14, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 14, 14, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 14, 14, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 14, 14, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 14, 14, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 14, 14, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 14, 14, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 14, 14, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 14, 14, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 14, 14, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 14, 14, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 14, 14, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 14, 14, 640)  2560        conv4_block12_concat[0][0]
# ...
# conv5_block22_concat (Concatena (None, 7, 7, 1600)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 7, 7, 1600)   6400        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 7, 7, 1600)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 7, 7, 128)    204800      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 7, 7, 1632)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 7, 7, 1632)   6528        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 7, 7, 1632)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 7, 7, 128)    208896      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 7, 7, 1664)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 7, 7, 1664)   6656        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 7, 7, 1664)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 7, 7, 128)    212992      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 7, 7, 1696)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 7, 7, 1696)   6784        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 7, 7, 1696)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 7, 7, 128)    217088      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 7, 7, 1728)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 7, 7, 1728)   6912        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 7, 7, 1728)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 7, 7, 128)    221184      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 7, 7, 1760)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 7, 7, 1760)   7040        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 7, 7, 1760)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 7, 7, 128)    225280      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 7, 7, 1792)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 7, 7, 1792)   7168        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 7, 7, 1792)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 7, 7, 128)    229376      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 7, 7, 1824)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 7, 7, 1824)   7296        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 7, 7, 1824)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 7, 7, 128)    233472      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 7, 7, 1856)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 7, 7, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 7, 7, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 7, 7, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 7, 7, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 7, 7, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 7, 7, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 7, 7, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 7, 7, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 7, 7, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 7, 7, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 7, 7, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 7, 7, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 7, 7, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1920)         0           relu[0][0]
# ==================================================================================================
# Total params: 18,321,984
# Trainable params: 0
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(ResNet152_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_3 (Functional)         (None, 1920)              18321984
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1967104
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 20,331,113
# Trainable params: 2,009,129
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 53s 430ms/step - loss: 1.4113 - accuracy: 0.6488 - val_loss: 0.4862 - val_accuracy: 0.8551
# Epoch 2/2000
# 49/49 [==============================] - 11s 221ms/step - loss: 0.3329 - accuracy: 0.9037 - val_loss: 0.2624 - val_accuracy: 0.9159
# Epoch 3/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.1631 - accuracy: 0.9583 - val_loss: 0.2175 - val_accuracy: 0.9314
# Epoch 4/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.1083 - accuracy: 0.9777 - val_loss: 0.2193 - val_accuracy: 0.9340
# Epoch 5/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0639 - accuracy: 0.9880 - val_loss: 0.1812 - val_accuracy: 0.9457
# Epoch 6/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0366 - accuracy: 0.9942 - val_loss: 0.1732 - val_accuracy: 0.9483
# Epoch 7/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0279 - accuracy: 0.9974 - val_loss: 0.1689 - val_accuracy: 0.9508
# Epoch 8/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0261 - accuracy: 0.9971 - val_loss: 0.1808 - val_accuracy: 0.9392
# Epoch 9/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0193 - accuracy: 0.9977 - val_loss: 0.2293 - val_accuracy: 0.9263
# Epoch 10/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0216 - accuracy: 0.9958 - val_loss: 0.1411 - val_accuracy: 0.9586
# Epoch 11/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0162 - accuracy: 0.9977 - val_loss: 0.2036 - val_accuracy: 0.9314
# Epoch 12/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0149 - accuracy: 0.9981 - val_loss: 0.1868 - val_accuracy: 0.9431
# Epoch 13/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0124 - accuracy: 0.9987 - val_loss: 0.1527 - val_accuracy: 0.9483
# Epoch 14/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.1467 - val_accuracy: 0.9612
# Epoch 15/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0134 - accuracy: 0.9981 - val_loss: 0.1299 - val_accuracy: 0.9599
# Epoch 16/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0164 - accuracy: 0.9958 - val_loss: 0.2450 - val_accuracy: 0.9327
# Epoch 17/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0075 - accuracy: 0.9987 - val_loss: 0.1232 - val_accuracy: 0.9599
# Epoch 18/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.1188 - val_accuracy: 0.9625
# Epoch 19/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.1422 - val_accuracy: 0.9560
# Epoch 20/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0037 - accuracy: 0.9994 - val_loss: 0.1111 - val_accuracy: 0.9599
# Epoch 21/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9638
# Epoch 22/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1069 - val_accuracy: 0.9625
# Epoch 23/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9612
# Epoch 24/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9612
# Epoch 25/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 0.9638
# Epoch 26/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 0.9715
# Epoch 27/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 9.7436e-04 - accuracy: 1.0000 - val_loss: 0.1090 - val_accuracy: 0.9690
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 28/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 8.5454e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9702
# Epoch 29/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 8.1658e-04 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 0.9690
# Epoch 30/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 8.3231e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9690
# Epoch 31/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.5306e-04 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9690
# Epoch 32/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.4515e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9677
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 33/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.4864e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9677
# Epoch 34/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.1683e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 35/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.7278e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 36/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.6884e-04 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9664
# Epoch 37/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 8.2361e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9664
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 38/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.3570e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 39/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.1097e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 40/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.3014e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 41/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.4630e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 42/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.9952e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 43/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.1460e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 44/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.5378e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 45/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.8500e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9664
# Epoch 46/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8337e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 47/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8437e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 48/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.2610e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 49/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.0703e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 50/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 6.5123e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 51/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.5440e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 52/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.2005e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 53/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6815e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 54/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8058e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 55/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.4696e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 56/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 6.9299e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 57/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 6.7158e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 58/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.0005e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 59/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6608e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 60/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.6601e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 61/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.7033e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 62/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.4339e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 63/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.8253e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 64/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 6.8274e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 65/2000
# 49/49 [==============================] - 11s 222ms/step - loss: 7.3831e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 66/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.7107e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9664
# Epoch 67/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.1176e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 68/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.9660e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 69/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.0851e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 70/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.4193e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 71/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6497e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 72/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6871e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9664
# Epoch 73/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.5861e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9664
# Epoch 74/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.4947e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 75/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.5894e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 76/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.8345e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 77/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.0567e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 78/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.5144e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9677
# Epoch 79/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6353e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9677
# Epoch 80/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.1475e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 81/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6792e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 82/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.9715e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 83/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6577e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 84/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6498e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 85/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6543e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 86/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.7587e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 87/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6233e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 88/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.9521e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9664
# Epoch 89/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.1265e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9664
# Epoch 90/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8534e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9664
# Epoch 91/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.1001e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 92/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 8.1156e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9677
# Epoch 93/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.3280e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 94/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6562e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9664
# Epoch 95/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.8320e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9664
# Epoch 96/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.5711e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9664
# Epoch 97/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.0093e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 98/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8248e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9690
# Epoch 99/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.5108e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9664
# Epoch 100/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8589e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 101/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.4130e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 102/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.7039e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 103/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.4539e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9651
# Epoch 104/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.3098e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9664
# Epoch 105/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.5321e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9664
# Epoch 106/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.2005e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9664
# Epoch 107/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.8705e-04 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9664
# Epoch 108/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.6316e-04 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 0.9664
# Epoch 109/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 7.1253e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9664
# Epoch 110/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6139e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9677
# Epoch 111/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.8958e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9677
# Epoch 112/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.8304e-04 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9677
# Epoch 113/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.9354e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9677
# Epoch 114/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.3744e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9677
# Epoch 115/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.3014e-04 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9677
# Epoch 116/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 6.5414e-04 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9715
# Epoch 117/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.6019e-04 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9715
# Epoch 118/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.7039e-04 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 0.9715
# Epoch 119/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.4895e-04 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 0.9702
# Epoch 120/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.6523e-04 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9677
# Epoch 121/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 7.3476e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9702
# Epoch 122/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.9150e-04 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9690
# Epoch 123/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.5181e-04 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9677
# Epoch 124/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.8689e-04 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9677
# Epoch 125/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.9123e-04 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9664
# Epoch 126/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.1775e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9677
# Epoch 127/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.5040e-04 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9690
# Epoch 128/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.9662e-04 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9702
# Epoch 129/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.9735e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9690
# Epoch 130/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.6974e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9677
# Epoch 131/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.6302e-04 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9664
# Epoch 132/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.7719e-04 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9651
# Epoch 133/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.4444e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9651
# Epoch 134/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.3271e-04 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9664
# Epoch 135/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 6.1507e-04 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9664
# Epoch 136/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.6936e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9690
# Epoch 137/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.7264e-04 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9702
# Epoch 138/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.2572e-04 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9690
# Epoch 139/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.6677e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9715
# Epoch 140/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.4339e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9702
# Epoch 141/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.5127e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9702
# Epoch 142/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.4712e-04 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9690
# Epoch 143/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.1124e-04 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9664
# Epoch 144/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.5820e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9651
# Epoch 145/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.2740e-04 - accuracy: 1.0000 - val_loss: 0.1112 - val_accuracy: 0.9664
# Epoch 146/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.3115e-04 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9664
# Epoch 147/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.3590e-04 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9651
# Epoch 148/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.5311e-04 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9664
# Epoch 149/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.4460e-04 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9664
# Epoch 150/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.8917e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9677
# Epoch 151/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.7635e-04 - accuracy: 1.0000 - val_loss: 0.1112 - val_accuracy: 0.9651
# Epoch 152/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.0338e-04 - accuracy: 1.0000 - val_loss: 0.1112 - val_accuracy: 0.9664
# Epoch 153/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.3252e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9664
# Epoch 154/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.8481e-04 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9664
# Epoch 155/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.3697e-04 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9638
# Epoch 156/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.8822e-04 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9638
# Epoch 157/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.7378e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9651
# Epoch 158/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.1500e-04 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9664
# Epoch 159/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 5.5309e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9638
# Epoch 160/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.7402e-04 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9651
# Epoch 161/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.6619e-04 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9638
# Epoch 162/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.9251e-04 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9664
# Epoch 163/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.5040e-04 - accuracy: 1.0000 - val_loss: 0.1106 - val_accuracy: 0.9664
# Epoch 164/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 5.0024e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9715
# Epoch 165/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.5840e-04 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9702
# Epoch 166/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.3118e-04 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9690
# Epoch 167/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.4733e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9664
# Epoch 168/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.6321e-04 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9664
# Epoch 169/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.5145e-04 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9677
# Epoch 170/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.2019e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9651
# Epoch 171/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.6935e-04 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9677
# Epoch 172/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.3226e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9677
# Epoch 173/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.4089e-04 - accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9677
# Epoch 174/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.3952e-04 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9677
# Epoch 175/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.0600e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9664
# Epoch 176/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.9713e-04 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9690
# Epoch 177/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.5540e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9702
# Epoch 178/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.2212e-04 - accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9651
# Epoch 179/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.7116e-04 - accuracy: 1.0000 - val_loss: 0.1126 - val_accuracy: 0.9677
# Epoch 180/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.0712e-04 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9677
# Epoch 181/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.0930e-04 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9677
# Epoch 182/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.7431e-04 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9702
# Epoch 183/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.1357e-04 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9690
# Epoch 184/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 4.2927e-04 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9702
# Epoch 185/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.1799e-04 - accuracy: 1.0000 - val_loss: 0.1120 - val_accuracy: 0.9664
# Epoch 186/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.1980e-04 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9690
# Epoch 187/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 4.1044e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9677
# Epoch 188/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.7814e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9677
# Epoch 189/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.9809e-04 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9702
# Epoch 190/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.8499e-04 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.9690
# Epoch 191/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.7668e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9690
# Epoch 192/2000
# 49/49 [==============================] - 11s 225ms/step - loss: 3.6516e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9690
# Epoch 193/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.8484e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9677
# Epoch 194/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.5979e-04 - accuracy: 1.0000 - val_loss: 0.1116 - val_accuracy: 0.9690
# Epoch 195/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.4063e-04 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9677
# Epoch 196/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.4738e-04 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9664
# Epoch 197/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.6252e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9664
# Epoch 198/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.6013e-04 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9638
# Epoch 199/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.1568e-04 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9677
# Epoch 200/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.9401e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9651
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# Epoch 201/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.3603e-04 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9677
# Epoch 202/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.2295e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9664
# Epoch 203/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.5235e-04 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9651
# Epoch 204/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.1272e-04 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9664
# Epoch 205/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.4180e-04 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9638
# Epoch 206/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.4740e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9677
# Epoch 207/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.3449e-04 - accuracy: 1.0000 - val_loss: 0.1122 - val_accuracy: 0.9651
# Epoch 208/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.1164e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9651
# Epoch 209/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.0944e-04 - accuracy: 1.0000 - val_loss: 0.1134 - val_accuracy: 0.9651
# Epoch 210/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.1926e-04 - accuracy: 1.0000 - val_loss: 0.1124 - val_accuracy: 0.9677
# Epoch 211/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.8633e-04 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9677
# Epoch 212/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.2113e-04 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9651
# Epoch 213/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 3.3560e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9651
# Epoch 214/2000
# 49/49 [==============================] - 11s 225ms/step - loss: 3.4014e-04 - accuracy: 1.0000 - val_loss: 0.1134 - val_accuracy: 0.9651
# Epoch 215/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.0410e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9664
# Epoch 216/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.9656e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9690
# Epoch 217/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.0298e-04 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 0.9690
# Epoch 218/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.7668e-04 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9651
# Epoch 219/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.7991e-04 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9651
# Epoch 220/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 3.0412e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9651
# Epoch 221/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.6208e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9651
# Epoch 222/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.7947e-04 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9651
# Epoch 223/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.8091e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9651
# Epoch 224/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.7876e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9677
# Epoch 225/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.8278e-04 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9690
# Epoch 226/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.7921e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9702
# Epoch 227/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.9253e-04 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9690
# Epoch 228/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.7648e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9690
# Epoch 229/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.6316e-04 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9664
# Epoch 230/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.7095e-04 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9677
# Epoch 231/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.4935e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9651
# Epoch 232/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.8902e-04 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9664
# Epoch 233/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.7352e-04 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9664
# Epoch 234/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.3570e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9677
# Epoch 235/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.5321e-04 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9677
# Epoch 236/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.4187e-04 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9664
# Epoch 237/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.4037e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9664
# Epoch 238/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.4128e-04 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9677
# Epoch 239/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.2517e-04 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9677
# Epoch 240/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.1966e-04 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 0.9664
# Epoch 241/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.5368e-04 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9664
# Epoch 242/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.1965e-04 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9664
# Epoch 243/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.4789e-04 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.9664
# Epoch 244/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.4609e-04 - accuracy: 1.0000 - val_loss: 0.1131 - val_accuracy: 0.9664
# Epoch 245/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.3864e-04 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.9677
# Epoch 246/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.4874e-04 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9690
# Epoch 247/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.4396e-04 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9690
# Epoch 248/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.1419e-04 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9690
# Epoch 249/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.0989e-04 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9677
# Epoch 250/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.3819e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9664
# Epoch 251/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.2614e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9664
# Epoch 252/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.2110e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9677
# Epoch 253/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.0404e-04 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 0.9664
# Epoch 254/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.0101e-04 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9664
# Epoch 255/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.0884e-04 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9664
# Epoch 256/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.0240e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9664
# Epoch 257/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.1422e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9677
# Epoch 258/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.1031e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9677
# Epoch 259/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.9175e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9664
# Epoch 260/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.3067e-04 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 0.9664
# Epoch 261/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 2.1201e-04 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9677
# Epoch 262/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.9064e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9677
# Epoch 263/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.0028e-04 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9664ss: 1.9915e-04
# Epoch 264/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 2.0437e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9677
# Epoch 265/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.8201e-04 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9677
# Epoch 266/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.6837e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9690
# Epoch 267/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.8388e-04 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 0.9690
# Epoch 268/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.9022e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9690
# Epoch 269/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.7431e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9664
# Epoch 270/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.8974e-04 - accuracy: 1.0000 - val_loss: 0.1144 - val_accuracy: 0.9677
# Epoch 271/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.8335e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9664
# Epoch 272/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.7174e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9664
# Epoch 273/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.6974e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9690
# Epoch 274/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.7774e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9690
# Epoch 275/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.8620e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9677
# Epoch 276/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.7424e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9677
# Epoch 277/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.5497e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9677
# Epoch 278/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.4846e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9677
# Epoch 279/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.5783e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9651
# Epoch 280/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.5141e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9651
# Epoch 281/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.6581e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9664
# Epoch 282/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.7624e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9677
# Epoch 283/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.5409e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9677
# Epoch 284/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.6895e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9677
# Epoch 285/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3613e-04 - accuracy: 1.0000 - val_loss: 0.1167 - val_accuracy: 0.9677
# Epoch 286/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.4806e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9677
# Epoch 287/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.4792e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9677
# Epoch 288/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.4258e-04 - accuracy: 1.0000 - val_loss: 0.1155 - val_accuracy: 0.9677
# Epoch 289/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.5955e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9651
# Epoch 290/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.4670e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9664
# Epoch 291/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.3151e-04 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 0.9651
# Epoch 292/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3334e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
# Epoch 293/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.5232e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9690
# Epoch 294/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.4529e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
# Epoch 295/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3717e-04 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9664
# Epoch 296/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2916e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9664
# Epoch 297/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3646e-04 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 0.9651
# Epoch 298/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3951e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9664
# Epoch 299/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.2971e-04 - accuracy: 1.0000 - val_loss: 0.1174 - val_accuracy: 0.9677
# Epoch 300/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3130e-04 - accuracy: 1.0000 - val_loss: 0.1157 - val_accuracy: 0.9677
# Epoch 301/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3106e-04 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 0.9664
# Epoch 302/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.5716e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9651
# Epoch 303/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.3422e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9664
# Epoch 304/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.3162e-04 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9677
# Epoch 305/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2788e-04 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9702
# Epoch 306/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.1918e-04 - accuracy: 1.0000 - val_loss: 0.1173 - val_accuracy: 0.9690
# Epoch 307/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.1558e-04 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9690
# Epoch 308/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2482e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9664
# Epoch 309/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2165e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9677
# Epoch 310/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.1733e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9677
# Epoch 311/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2521e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9677
# Epoch 312/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.1945e-04 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9677
# Epoch 313/2000
# 49/49 [==============================] - 11s 223ms/step - loss: 1.0408e-04 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.9651
# Epoch 314/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2166e-04 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9651
# Epoch 315/2000
# 49/49 [==============================] - 11s 224ms/step - loss: 1.2728e-04 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 0.9664
# Epoch 316/2000
# ...
# Epoch 1898/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.6826e-07 - accuracy: 1.0000 - val_loss: 0.1666 - val_accuracy: 0.9690
# Epoch 1899/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6932e-07 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9690
# Epoch 1900/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4702e-07 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9690
# Epoch 1901/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6366e-07 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9690
# Epoch 1902/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.5699e-07 - accuracy: 1.0000 - val_loss: 0.1669 - val_accuracy: 0.9690
# Epoch 1903/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.3352e-07 - accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9690
# Epoch 1904/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.3272e-07 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9677
# Epoch 1905/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.1908e-07 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9677
# Epoch 1906/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.3888e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9677
# Epoch 1907/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.5887e-07 - accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9677
# Epoch 1908/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.5857e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9677
# Epoch 1909/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6658e-07 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 0.9690
# Epoch 1910/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.8195e-07 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9677
# Epoch 1911/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4055e-07 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9677
# Epoch 1912/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.9139e-07 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9677
# Epoch 1913/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.6819e-07 - accuracy: 1.0000 - val_loss: 0.1666 - val_accuracy: 0.9690
# Epoch 1914/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6805e-07 - accuracy: 1.0000 - val_loss: 0.1666 - val_accuracy: 0.9690
# Epoch 1915/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6085e-07 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9690
# Epoch 1916/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.8603e-07 - accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9690
# Epoch 1917/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.8226e-07 - accuracy: 1.0000 - val_loss: 0.1670 - val_accuracy: 0.9690
# Epoch 1918/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.0129e-07 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9690
# Epoch 1919/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.7325e-07 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9690
# Epoch 1920/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6212e-07 - accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9690
# Epoch 1921/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.0995e-07 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9690
# Epoch 1922/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8403e-07 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9690
# Epoch 1923/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4190e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9690
# Epoch 1924/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6643e-07 - accuracy: 1.0000 - val_loss: 0.1669 - val_accuracy: 0.9677
# Epoch 1925/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6709e-07 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.9677
# Epoch 1926/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.6260e-07 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9690
# Epoch 1927/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6655e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9690
# Epoch 1928/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6127e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9690
# Epoch 1929/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.5360e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9690
# Epoch 1930/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4713e-07 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9690
# Epoch 1931/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.5630e-07 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9690
# Epoch 1932/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.5231e-07 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9690
# Epoch 1933/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4378e-07 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9690
# Epoch 1934/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.5888e-07 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9690
# Epoch 1935/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.9743e-07 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9690
# Epoch 1936/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.8446e-07 - accuracy: 1.0000 - val_loss: 0.1685 - val_accuracy: 0.9690
# Epoch 1937/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.3793e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9690
# Epoch 1938/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.0206e-07 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9690
# Epoch 1939/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7613e-07 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9690
# Epoch 1940/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7047e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9690
# Epoch 1941/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 2.8536e-07 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9690
# Epoch 1942/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4174e-07 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9690
# Epoch 1943/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6296e-07 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9690
# Epoch 1944/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 3.1989e-07 - accuracy: 1.0000 - val_loss: 0.1696 - val_accuracy: 0.9690
# Epoch 1945/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6069e-07 - accuracy: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.9690
# Epoch 1946/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.5838e-07 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9677
# Epoch 1947/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4787e-07 - accuracy: 1.0000 - val_loss: 0.1695 - val_accuracy: 0.9677
# Epoch 1948/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6212e-07 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9677
# Epoch 1949/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6135e-07 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9677: 1.6373e-07 - accuracy: 1.
# Epoch 1950/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7879e-07 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9677
# Epoch 1951/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7232e-07 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9677
# Epoch 1952/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4494e-07 - accuracy: 1.0000 - val_loss: 0.1689 - val_accuracy: 0.9677
# Epoch 1953/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4394e-07 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9677
# Epoch 1954/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4101e-07 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9677
# Epoch 1955/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.9505e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9677
# Epoch 1956/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6027e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1957/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8696e-07 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9677
# Epoch 1958/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6508e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9677
# Epoch 1959/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.5746e-07 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9677
# Epoch 1960/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6770e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9677
# Epoch 1961/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6543e-07 - accuracy: 1.0000 - val_loss: 0.1678 - val_accuracy: 0.9677
# Epoch 1962/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7209e-07 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9677
# Epoch 1963/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7394e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9690
# Epoch 1964/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4783e-07 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 0.9690
# Epoch 1965/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7506e-07 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9677
# Epoch 1966/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8134e-07 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9677
# Epoch 1967/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6189e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1968/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4201e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1969/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.2687e-07 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9677
# Epoch 1970/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.3442e-07 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9677
# Epoch 1971/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6943e-07 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9677
# Epoch 1972/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.9867e-07 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.9677
# Epoch 1973/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.9185e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9677
# Epoch 1974/2000
# 49/49 [==============================] - 11s 228ms/step - loss: 1.6647e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1975/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.7556e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9677
# Epoch 1976/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6081e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1977/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6285e-07 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9677
# Epoch 1978/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8499e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1979/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8819e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9677
# Epoch 1980/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 2.0036e-07 - accuracy: 1.0000 - val_loss: 0.1680 - val_accuracy: 0.9677
# Epoch 1981/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.5445e-07 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9677
# Epoch 1982/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.8207e-07 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.9677
# Epoch 1983/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4702e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1984/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7028e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9677
# Epoch 1985/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8087e-07 - accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9677
# Epoch 1986/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.7383e-07 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9677
# Epoch 1987/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.6970e-07 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9664
# Epoch 1988/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.7752e-07 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9664
# Epoch 1989/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4502e-07 - accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9664
# Epoch 1990/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.8503e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9677
# Epoch 1991/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7020e-07 - accuracy: 1.0000 - val_loss: 0.1683 - val_accuracy: 0.9677
# Epoch 1992/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.7668e-07 - accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9677
# Epoch 1993/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.5291e-07 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9677
# Epoch 1994/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.5387e-07 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9677
# Epoch 1995/2000
# 49/49 [==============================] - 11s 227ms/step - loss: 1.4902e-07 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9677
# Epoch 1996/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6578e-07 - accuracy: 1.0000 - val_loss: 0.1684 - val_accuracy: 0.9677
# Epoch 1997/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.5383e-07 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9677
# Epoch 1998/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.4386e-07 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9677
# Epoch 1999/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.5330e-07 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9677
# Epoch 2000/2000
# 49/49 [==============================] - 11s 226ms/step - loss: 1.6061e-07 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.9677
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 15s 396ms/step - loss: 0.8882 - accuracy: 0.8322
# test_indoor_ds_results:test loss, test acc: [0.8882243037223816, 0.8322185277938843]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 28s 470ms/step - loss: 3.5768 - accuracy: 0.6446
# test_outdoor_ds_results:test loss, test acc: [3.5768160820007324, 0.6445859670639038]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 10s 246ms/step - loss: 1.9592 - accuracy: 0.7443
# test_belt_ds_results:test loss, test acc: [1.9592138528823853, 0.7443336248397827]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/DenseNet201_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# 29/29 [==============================] - 8s 179ms/step - loss: 0.6102 - accuracy: 0.8294
# 50/50 [==============================] - 9s 181ms/step - loss: 2.1133 - accuracy: 0.6503
# 35/35 [==============================] - 6s 181ms/step - loss: 1.2692 - accuracy: 0.7380
# Epoch200
#  test_indoor_acc=0.829431414604187
#  test_outdoor_acc=0.650318443775177
#  test_belt_acc=0.7379872798919678
# 29/29 [==============================] - 8s 181ms/step - loss: 0.6550 - accuracy: 0.8317
# 50/50 [==============================] - 9s 183ms/step - loss: 2.3899 - accuracy: 0.6494
# 35/35 [==============================] - 6s 183ms/step - loss: 1.4187 - accuracy: 0.7371
# Epoch400
#  test_indoor_acc=0.8316611051559448
#  test_outdoor_acc=0.6493630409240723
#  test_belt_acc=0.7370806932449341
# 29/29 [==============================] - 8s 182ms/step - loss: 0.7201 - accuracy: 0.8339
# 50/50 [==============================] - 9s 184ms/step - loss: 2.6700 - accuracy: 0.6500
# 35/35 [==============================] - 6s 184ms/step - loss: 1.5640 - accuracy: 0.74251s - loss: 1.5
# Epoch600
#  test_indoor_acc=0.8338907361030579
#  test_outdoor_acc=0.6499999761581421
#  test_belt_acc=0.7425203919410706
# 29/29 [==============================] - 8s 179ms/step - loss: 0.7650 - accuracy: 0.8311
# 50/50 [==============================] - 9s 181ms/step - loss: 2.9193 - accuracy: 0.6484
# 35/35 [==============================] - 6s 181ms/step - loss: 1.6864 - accuracy: 0.7461
# Epoch800
#  test_indoor_acc=0.8311036825180054
#  test_outdoor_acc=0.6484076380729675
#  test_belt_acc=0.7461468577384949
# 29/29 [==============================] - 8s 182ms/step - loss: 0.7964 - accuracy: 0.8317
# 50/50 [==============================] - 9s 183ms/step - loss: 3.1108 - accuracy: 0.6475
# 35/35 [==============================] - 6s 184ms/step - loss: 1.7514 - accuracy: 0.7452
# Epoch1000
#  test_indoor_acc=0.8316611051559448
#  test_outdoor_acc=0.6474522352218628
#  test_belt_acc=0.7452402710914612
# 29/29 [==============================] - 8s 180ms/step - loss: 0.8204 - accuracy: 0.8339
# 50/50 [==============================] - 9s 182ms/step - loss: 3.2894 - accuracy: 0.6439
# 35/35 [==============================] - 6s 183ms/step - loss: 1.8129 - accuracy: 0.7443
# Epoch1200
#  test_indoor_acc=0.8338907361030579
#  test_outdoor_acc=0.643949031829834
#  test_belt_acc=0.7443336248397827
# 29/29 [==============================] - 8s 183ms/step - loss: 0.8561 - accuracy: 0.8333
# 50/50 [==============================] - 9s 184ms/step - loss: 3.3930 - accuracy: 0.6439
# 35/35 [==============================] - 6s 184ms/step - loss: 1.8958 - accuracy: 0.7439
# Epoch1400
#  test_indoor_acc=0.8333333134651184
#  test_outdoor_acc=0.643949031829834
#  test_belt_acc=0.7438803315162659
# 29/29 [==============================] - 8s 180ms/step - loss: 0.8609 - accuracy: 0.8339
# 50/50 [==============================] - 9s 182ms/step - loss: 3.4572 - accuracy: 0.6468
# 35/35 [==============================] - 6s 182ms/step - loss: 1.9108 - accuracy: 0.7457
# Epoch1600
#  test_indoor_acc=0.8338907361030579
#  test_outdoor_acc=0.646815299987793
#  test_belt_acc=0.745693564414978
# 29/29 [==============================] - 8s 182ms/step - loss: 0.8638 - accuracy: 0.8361
# 50/50 [==============================] - 9s 184ms/step - loss: 3.6022 - accuracy: 0.6420
# 35/35 [==============================] - 6s 185ms/step - loss: 1.9381 - accuracy: 0.7421
# Epoch1800
#  test_indoor_acc=0.8361204266548157
#  test_outdoor_acc=0.6420382261276245
#  test_belt_acc=0.7420670986175537
# 29/29 [==============================] - 8s 181ms/step - loss: 0.8882 - accuracy: 0.8322
# 50/50 [==============================] - 9s 182ms/step - loss: 3.5768 - accuracy: 0.64461s - loss: 3.5906 -
# 35/35 [==============================] - 6s 183ms/step - loss: 1.9592 - accuracy: 0.7443
# Epoch2000
#  test_indoor_acc=0.8322185277938843
#  test_outdoor_acc=0.6445859670639038
#  test_belt_acc=0.7443336248397827

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.7421370347340902
# max index -> 2
# The [Epoch] of max acc -> 600

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.829431414604187,
#  0.8316611051559448,
#  0.8338907361030579,
#  0.8311036825180054,
#  0.8316611051559448,
#  0.8338907361030579,
#  0.8333333134651184,
#  0.8338907361030579,
#  0.8361204266548157,
#  0.8322185277938843]

# %%
test_outdoor_acc
# Out:
# [0.650318443775177,
#  0.6493630409240723,
#  0.6499999761581421,
#  0.6484076380729675,
#  0.6474522352218628,
#  0.643949031829834,
#  0.643949031829834,
#  0.646815299987793,
#  0.6420382261276245,
#  0.6445859670639038]

# %%
test_belt_acc
# Out:
# [0.7379872798919678,
#  0.7370806932449341,
#  0.7425203919410706,
#  0.7461468577384949,
#  0.7452402710914612,
#  0.7443336248397827,
#  0.7438803315162659,
#  0.745693564414978,
#  0.7420670986175537,
#  0.7443336248397827]

# %%
test_indoor_loss
# Out:
# [0.610243558883667,
#  0.654995858669281,
#  0.7201437950134277,
#  0.7649837136268616,
#  0.7964437007904053,
#  0.8203836679458618,
#  0.8560689687728882,
#  0.8608883023262024,
#  0.8637754917144775,
#  0.8882243037223816]

# %%
test_outdoor_loss
# Out:
# [2.1133220195770264,
#  2.389908790588379,
#  2.6700046062469482,
#  2.919269323348999,
#  3.110809326171875,
#  3.28938627243042,
#  3.3929967880249023,
#  3.4571938514709473,
#  3.602243185043335,
#  3.5768160820007324]

# %%
test_belt_loss
# Out:
# [1.269199013710022,
#  1.4186720848083496,
#  1.5640404224395752,
#  1.6864259243011475,
#  1.7514362335205078,
#  1.812928318977356,
#  1.895822525024414,
#  1.910771131515503,
#  1.9381223917007446,
#  1.9592138528823853]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.densenet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=224
img_width=224
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
### VRAM not enough -> we split into N set
del x_test_indoor,x_test_outdoor,x_test_belt
N = 200
x_all_sets = np.array_split(x_all, N)
del x_all
y_all_sets_predicted = []
for x in x_all_sets:
  y_all_sets_predicted.append(last_epoch_model.predict(x,batch_size=batch_size))
y_all_predicted = np.concatenate(y_all_sets_predicted)
# Out:
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5175
# FP=1965
# acc=0.7247899159663865
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 71.55172413793103%
# 2WayConnectorforFoley acc = 84.35374149659864%
# 2WayFoleyCatheter acc = 61.19402985074627%
# 3WayConnectorforFoley acc = 100.0%
# 3Waystopcock acc = 98.1981981981982%
# AlcoholBottle acc = 83.75%
# AlcoholPad acc = 40.476190476190474%
# BootCover acc = 60.8433734939759%
# CottonBall acc = 81.437125748503%
# CottonSwap acc = 66.43356643356644%
# Dilator acc = 63.24786324786324%
# DisposableInfusionSet acc = 59.29203539823009%
# ExtensionTube acc = 17.073170731707318%
# FaceShield acc = 70.98765432098766%
# FrontLoadSyringe acc = 40.707964601769916%
# GauzePad acc = 51.13636363636363%
# Glove acc = 71.42857142857143%
# GuideWire acc = 41.07142857142857%
# LiquidBottle acc = 32.06106870229007%
# Mask acc = 95.32467532467533%
# NGTube acc = 52.903225806451616%
# NasalCannula acc = 63.716814159292035%
# Needle acc = 79.64285714285714%
# OxygenMask acc = 93.23308270676691%
# PPESuit acc = 87.09677419354838%
# PharmaceuticalProduct acc = 59.813084112149525%
# Pill acc = 96.63865546218487%
# PillBottle acc = 58.139534883720934%
# PrefilledHumidifier acc = 75.21367521367522%
# PressureConnectingTube acc = 65.64885496183206%
# ReusableHumidifier acc = 72.88135593220339%
# SodiumChlorideBag acc = 76.37795275590551%
# SterileHumidifierAdapter acc = 95.45454545454545%
# SurgicalBlade acc = 87.61061946902655%
# SurgicalCap acc = 83.78378378378379%
# SurgicalSuit acc = 58.333333333333336%
# Syringe acc = 95.05703422053232%
# TrachealTube acc = 44.03669724770643%
# UrineBag acc = 55.833333333333336%
# Vaccinebottle acc = 89.2018779342723%
# WingedInfusionSet acc = 67.54385964912281%
#
#
#
# all_avg_eachclass = 69.48121213550831%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 83,   0,   0, ...,   0,   0,   0],
#        [  2, 124,   0, ...,   0,   0,   0],
#        [  0,   0,  82, ...,   0,   0,  16],
#        ...,
#        [  0,   0,   0, ...,  67,   6,   0],
#        [  0,   0,   0, ...,   0, 190,   0],
#        [  0,   0,   1, ...,   0,   2,  77]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[71.55172414,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.36054422, 84.3537415 ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 61.19402985, ...,  0.        ,
#          0.        , 11.94029851],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 55.83333333,
#          5.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         89.20187793,  0.        ],
#        [ 0.        ,  0.        ,  0.87719298, ...,  0.        ,
#          1.75438596, 67.54385965]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
