# %% [markdown]
# # FullClass-TrainCNN_NoFreezModel_No-ClassImbalance

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np

# %% [markdown]
# ## Training Set DIR

# %%
train_dataset_path='D:/DatasetMedicalWasteCropped/'

# %%
#train_dataset_path='D:/DatasetMedicalWasteCroppedBalanced/'

# %% [markdown]
# ## Testing Set DIR

# %%
test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

# %%
img_height=300
img_width=300
batch_size=64

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 3095 files for training.

# %%
class_names = train_ds.class_names
class_number = len(class_names)
print(class_names)
print(f'number of class = {class_number}')
# Out:
# ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']
# number of class = 41

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dataset_path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3868 files belonging to 41 classes.
# Using 773 files for validation.

# %%
test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1794 files belonging to 41 classes.

# %%
test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3140 files belonging to 41 classes.

# %%
test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2206 files belonging to 41 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Augmentation

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("vertical"),
  layers.RandomRotation(0.100),
  layers.RandomZoom(height_factor=0.025,width_factor=0.025),
  #layers.RandomContrast(0.300),
])

# %%
normalization_layer = layers.Rescaling(1./255)

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  # ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, shuffle=True, augment=True)
val_ds = prepare(val_ds)
test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

# %%
# Test -> Fetching Mini Batch
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (64, 300, 300, 3)
# (64,)

# %%
'''
vgg16_model = keras.applications.vgg16.VGG16()
model = Sequential()

for layer in vgg16_model.layers[:-1]: # this is where I changed your code
    model.add(layer)    

# Freeze the layers 
for layer in model.layers:
    layer.trainable = False

# Add 'softmax' instead of earlier 'prediction' layer.
model.add(Dense(2, activation='softmax'))
'''
import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.backend as K
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input, Layer
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB3

efficientnetB0_model = keras.applications.EfficientNetB3(input_shape=(img_height,img_width,3),include_top=True,weights="imagenet",classifier_activation="softmax")

efficientnetB0_model_nooutput = efficientnetB0_model.layers[-3].output
custom_efficientnetB0_model = Model(inputs = efficientnetB0_model.input, outputs = efficientnetB0_model_nooutput)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3.h5
# 50102272/50095040 [==============================] - 36s 1us/step
# 50110464/50095040 [==============================] - 36s 1us/step

# %% [markdown]
# ## Freez Extractor+

# %%
custom_efficientnetB0_model.trainable = False
for layer in custom_efficientnetB0_model.layers:
    layer.trainable = False
## Freez
#custom_inceptionv3_model.layers[-1].trainable = True
#custom_inceptionv3_model.layers[-2].trainable = True
#custom_inceptionv3_model.layers[-3].trainable = True
print(custom_efficientnetB0_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 300, 300, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 301, 301, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 150, 150, 40) 1080        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 150, 150, 40) 160         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 150, 150, 40) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 150, 150, 40) 360         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 150, 150, 40) 160         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 150, 150, 40) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 40)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 40)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 10)     410         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 40)     440         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 150, 150, 40) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 150, 150, 24) 960         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 150, 150, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 150, 150, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 150, 150, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 150, 150, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 150, 150, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 150, 150, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 150, 150, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 150, 150, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 150, 150, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 150, 150, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 150, 150, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 150, 150, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 151, 151, 144 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 75, 75, 144)  1296        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 75, 75, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 75, 75, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 75, 75, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 75, 75, 32)   4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 75, 75, 32)   128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 75, 75, 192)  768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 75, 75, 192)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 75, 75, 192)  1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 75, 75, 192)  768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 75, 75, 192)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 75, 75, 192)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 75, 75, 32)   6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 75, 75, 32)   128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 75, 75, 32)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 75, 75, 32)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 75, 75, 192)  768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 75, 75, 192)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 75, 75, 192)  1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 75, 75, 192)  768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 75, 75, 192)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 75, 75, 192)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 75, 75, 32)   6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 75, 75, 32)   128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 75, 75, 32)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 75, 75, 32)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 75, 75, 192)  6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 75, 75, 192)  768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 75, 75, 192)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 79, 79, 192)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 38, 38, 192)  4800        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 38, 38, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 38, 38, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 38, 38, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 38, 38, 48)   9216        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 38, 38, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 38, 38, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 38, 38, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 38, 38, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 38, 38, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 38, 38, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 38, 38, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 38, 38, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 38, 38, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 38, 38, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 38, 38, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 38, 38, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 38, 38, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 38, 38, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 38, 38, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 38, 38, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 38, 38, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 38, 38, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 38, 38, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 38, 38, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 38, 38, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 39, 39, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 19, 19, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 19, 19, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 19, 19, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 19, 19, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 19, 19, 96)   27648       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 19, 19, 96)   384         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 19, 19, 576)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 19, 19, 576)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 576)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 19, 19, 576)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 19, 19, 96)   384         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 19, 19, 96)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 19, 19, 96)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 19, 19, 576)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 19, 19, 576)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 576)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 19, 19, 576)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 19, 19, 96)   384         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 19, 19, 96)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 19, 19, 96)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 19, 19, 576)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 19, 19, 576)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 576)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 19, 19, 576)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 19, 19, 96)   384         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 19, 19, 96)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 19, 19, 96)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 19, 19, 576)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 19, 19, 576)  5184        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 19, 19, 576)  2304        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 19, 19, 576)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 576)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 19, 19, 576)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 19, 19, 96)   55296       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 19, 19, 96)   384         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (Dropout)          (None, 19, 19, 96)   0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 19, 19, 96)   0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 19, 19, 576)  55296       block4e_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 19, 19, 576)  2304        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 19, 19, 576)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 19, 19, 576)  14400       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 19, 19, 576)  2304        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 19, 19, 576)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 576)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 576)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 19, 19, 576)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 19, 19, 136)  78336       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 19, 19, 136)  544         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 19, 19, 816)  110976      block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 19, 19, 816)  3264        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 19, 19, 816)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 19, 19, 816)  20400       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 19, 19, 816)  3264        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 19, 19, 816)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 816)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 19, 19, 816)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 19, 19, 136)  110976      block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 19, 19, 136)  544         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 19, 19, 136)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 19, 19, 136)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 19, 19, 816)  110976      block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 19, 19, 816)  3264        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 19, 19, 816)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 19, 19, 816)  20400       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 19, 19, 816)  3264        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 19, 19, 816)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 816)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6d_expand_activation (Acti (None, 10, 10, 1392) 0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 34800       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 10, 10, 1392) 0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1392)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 10, 10, 1392) 0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 10, 10, 232)  322944      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 10, 10, 232)  928         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 10, 10, 232)  0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 10, 10, 232)  0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 10, 10, 1392) 322944      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 10, 10, 1392) 5568        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 10, 10, 1392) 0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 34800       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 10, 10, 1392) 0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1392)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 10, 10, 1392) 0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 10, 10, 232)  322944      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 10, 10, 232)  928         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 10, 10, 232)  0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 10, 10, 232)  0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block6f_expand_conv (Conv2D)    (None, 10, 10, 1392) 322944      block6e_add[0][0]
# __________________________________________________________________________________________________
# block6f_expand_bn (BatchNormali (None, 10, 10, 1392) 5568        block6f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6f_expand_activation (Acti (None, 10, 10, 1392) 0           block6f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6f_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 34800       block6f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6f_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block6f_dwconv[0][0]
# __________________________________________________________________________________________________
# block6f_activation (Activation) (None, 10, 10, 1392) 0           block6f_bn[0][0]
# __________________________________________________________________________________________________
# block6f_se_squeeze (GlobalAvera (None, 1392)         0           block6f_activation[0][0]
# __________________________________________________________________________________________________
# block6f_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block6f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6f_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block6f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6f_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block6f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6f_se_excite (Multiply)    (None, 10, 10, 1392) 0           block6f_activation[0][0]
#                                                                  block6f_se_expand[0][0]
# __________________________________________________________________________________________________
# block6f_project_conv (Conv2D)   (None, 10, 10, 232)  322944      block6f_se_excite[0][0]
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 10, 10, 232)  928         block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (Dropout)          (None, 10, 10, 232)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 10, 10, 232)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 10, 10, 1392) 322944      block6f_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 10, 10, 1392) 5568        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 10, 10, 1392) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 10, 10, 1392) 12528       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 10, 10, 1392) 5568        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 10, 10, 1392) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1392)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 10, 10, 1392) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 10, 10, 384)  534528      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 10, 10, 384)  1536        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 10, 10, 2304) 884736      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 10, 10, 2304) 9216        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 10, 10, 2304) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 10, 10, 2304) 20736       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 10, 10, 2304) 9216        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 10, 10, 2304) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2304)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 10, 10, 2304) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 10, 10, 384)  884736      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 10, 10, 384)  1536        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 10, 10, 384)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 10, 10, 384)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 10, 10, 1536) 589824      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 10, 10, 1536) 6144        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 10, 10, 1536) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1536)         0           top_activation[0][0]
# ==================================================================================================
# Total params: 10,783,535
# Trainable params: 0
# Non-trainable params: 10,783,535
# __________________________________________________________________________________________________
# None

# %%
#tf.keras.utils.plot_model(custom_efficientnetB0_model, to_file="InceptionRemoveOutput.png", show_shapes=True)

# %%
model = tf.keras.Sequential()
# Feature Extractor
model.add(custom_efficientnetB0_model)
# Classifier
#DeepDense
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.2))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax', trainable=True))
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 1536)              10783535
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 41)                42025
# =================================================================
# Total params: 12,399,448
# Trainable params: 1,615,913
# Non-trainable params: 10,783,535
# _________________________________________________________________

# %%
class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']

# %%
#model.layers[-1]._name = 'Classifier'
#model.layers[-2]._name = 'InceptionV3'
#print(len(model.layers))
#tf.keras.utils.plot_model(model, to_file="Incepv3_FreezExtractorOurOutputLayer.png", show_shapes=True)

# %% [markdown]
# # Fitting

# %%
path_to_model = 'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/'

# %%
EPOCHS = 2000
save_model_interval = 200
checkpoint_filepath = path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch{epoch:04d}.pb' # -val_acc{val_accuracy:.2f}
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_freq='epoch',
    period=save_model_interval,
    save_best_only=False)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                  patience=5, min_lr=0.00001,cooldown=1, verbose=1)
# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
history = model.fit(train_ds,validation_data=val_ds,epochs=EPOCHS, callbacks=[model_checkpoint_callback,reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2000
# 49/49 [==============================] - 55s 501ms/step - loss: 0.9925 - accuracy: 0.7370 - val_loss: 0.2726 - val_accuracy: 0.9211
# Epoch 2/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.1595 - accuracy: 0.9583 - val_loss: 0.1432 - val_accuracy: 0.9638
# Epoch 3/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0823 - accuracy: 0.9819 - val_loss: 0.1343 - val_accuracy: 0.9651
# Epoch 4/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0528 - accuracy: 0.9890 - val_loss: 0.1244 - val_accuracy: 0.9560
# Epoch 5/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0372 - accuracy: 0.9906 - val_loss: 0.1125 - val_accuracy: 0.9690
# Epoch 6/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0310 - accuracy: 0.9929 - val_loss: 0.1082 - val_accuracy: 0.9677
# Epoch 7/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0206 - accuracy: 0.9958 - val_loss: 0.0855 - val_accuracy: 0.9767
# Epoch 8/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0158 - accuracy: 0.9974 - val_loss: 0.0875 - val_accuracy: 0.9715
# Epoch 9/2000
# 49/49 [==============================] - 17s 354ms/step - loss: 0.0129 - accuracy: 0.9974 - val_loss: 0.0742 - val_accuracy: 0.9767
# Epoch 10/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0076 - accuracy: 0.9997 - val_loss: 0.0678 - val_accuracy: 0.9819
# Epoch 11/2000
# 49/49 [==============================] - 17s 354ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.0695 - val_accuracy: 0.9806
# Epoch 12/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0074 - accuracy: 0.9990 - val_loss: 0.0778 - val_accuracy: 0.9690
# Epoch 13/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.0748 - val_accuracy: 0.9754
# Epoch 14/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0912 - val_accuracy: 0.9728
# Epoch 15/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0069 - accuracy: 0.9994 - val_loss: 0.0662 - val_accuracy: 0.9819
# Epoch 16/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0719 - val_accuracy: 0.9806
# Epoch 17/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 0.0065 - accuracy: 0.9987 - val_loss: 0.0766 - val_accuracy: 0.9780
# Epoch 18/2000
# 49/49 [==============================] - 17s 354ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0579 - val_accuracy: 0.9819
# Epoch 19/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.0747 - val_accuracy: 0.9793
# Epoch 20/2000
# 49/49 [==============================] - 18s 360ms/step - loss: 0.0117 - accuracy: 0.9968 - val_loss: 0.1077 - val_accuracy: 0.9690
# Epoch 21/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.0915 - val_accuracy: 0.9780
# Epoch 22/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.1482 - val_accuracy: 0.9586
# Epoch 23/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.1610 - val_accuracy: 0.9625
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 24/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0060 - accuracy: 0.9987 - val_loss: 0.1303 - val_accuracy: 0.9690
# Epoch 25/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.1168 - val_accuracy: 0.9754
# Epoch 26/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.1252 - val_accuracy: 0.9767
# Epoch 27/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.9754
# Epoch 28/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1119 - val_accuracy: 0.9767
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 29/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1113 - val_accuracy: 0.9767
# Epoch 30/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 0.9767
# Epoch 31/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 0.9767
# Epoch 32/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9767
# Epoch 33/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1112 - val_accuracy: 0.9767
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 34/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9767
# Epoch 35/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1109 - val_accuracy: 0.9767
# Epoch 36/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9767
# Epoch 37/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1106 - val_accuracy: 0.9767
# Epoch 38/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1108 - val_accuracy: 0.9767
# Epoch 39/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1107 - val_accuracy: 0.9767
# Epoch 40/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9767
# Epoch 41/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1107 - val_accuracy: 0.9767
# Epoch 42/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.1102 - val_accuracy: 0.9767
# Epoch 43/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.1105 - val_accuracy: 0.9780
# Epoch 44/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9780
# Epoch 45/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9780
# Epoch 46/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0024 - accuracy: 0.9997 - val_loss: 0.1100 - val_accuracy: 0.9780
# Epoch 47/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.1101 - val_accuracy: 0.9780
# Epoch 48/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1096 - val_accuracy: 0.9780
# Epoch 49/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1098 - val_accuracy: 0.9780
# Epoch 50/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1098 - val_accuracy: 0.9780
# Epoch 51/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9780
# Epoch 52/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1095 - val_accuracy: 0.9767
# Epoch 53/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9767
# Epoch 54/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1094 - val_accuracy: 0.9767
# Epoch 55/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1090 - val_accuracy: 0.9767
# Epoch 56/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1089 - val_accuracy: 0.9780
# Epoch 57/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1081 - val_accuracy: 0.9780
# Epoch 58/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.1076 - val_accuracy: 0.9780
# Epoch 59/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 0.9780
# Epoch 60/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.1077 - val_accuracy: 0.9780
# Epoch 61/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1077 - val_accuracy: 0.9780
# Epoch 62/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1066 - val_accuracy: 0.9780
# Epoch 63/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1058 - val_accuracy: 0.9780
# Epoch 64/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1061 - val_accuracy: 0.9767
# Epoch 65/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9780
# Epoch 66/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1061 - val_accuracy: 0.9780
# Epoch 67/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9780
# Epoch 68/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9780
# Epoch 69/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9780
# Epoch 70/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9780
# Epoch 71/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1057 - val_accuracy: 0.9767
# Epoch 72/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 0.9767
# Epoch 73/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1060 - val_accuracy: 0.9767
# Epoch 74/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9767
# Epoch 75/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9767
# Epoch 76/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.7391e-04 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9767
# Epoch 77/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1052 - val_accuracy: 0.9767
# Epoch 78/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9767
# Epoch 79/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1044 - val_accuracy: 0.9767
# Epoch 80/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9767
# Epoch 81/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9767
# Epoch 82/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1054 - val_accuracy: 0.9767
# Epoch 83/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1058 - val_accuracy: 0.9767
# Epoch 84/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1067 - val_accuracy: 0.9793
# Epoch 85/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1080 - val_accuracy: 0.9793
# Epoch 86/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.7461e-04 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 0.9793
# Epoch 87/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9780
# Epoch 88/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 0.9793
# Epoch 89/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9780
# Epoch 90/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1063 - val_accuracy: 0.9780
# Epoch 91/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 0.9780
# Epoch 92/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 0.9780
# Epoch 93/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.4870e-04 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9780
# Epoch 94/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1051 - val_accuracy: 0.9780
# Epoch 95/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9780
# Epoch 96/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1032 - val_accuracy: 0.9780
# Epoch 97/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.0860e-04 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9780
# Epoch 98/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.9946e-04 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9780
# Epoch 99/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.1030 - val_accuracy: 0.9780
# Epoch 100/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9793
# Epoch 101/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1033 - val_accuracy: 0.9793
# Epoch 102/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9793
# Epoch 103/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1037 - val_accuracy: 0.9780
# Epoch 104/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1034 - val_accuracy: 0.9793
# Epoch 105/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9793
# Epoch 106/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9793
# Epoch 107/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.7913e-04 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9793
# Epoch 108/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 8.7376e-04 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9806
# Epoch 109/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9793
# Epoch 110/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.5343e-04 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9793
# Epoch 111/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.5375e-04 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9793
# Epoch 112/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.6383e-04 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9793
# Epoch 113/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9793
# Epoch 114/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9793
# Epoch 115/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.0408e-04 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9793
# Epoch 116/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1049 - val_accuracy: 0.9793
# Epoch 117/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.1062 - val_accuracy: 0.9806
# Epoch 118/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.7377e-04 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9806
# Epoch 119/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1058 - val_accuracy: 0.9780
# Epoch 120/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1055 - val_accuracy: 0.9780
# Epoch 121/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.9520e-04 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9780
# Epoch 122/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9780
# Epoch 123/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 8.9621e-04 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9780
# Epoch 124/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1044 - val_accuracy: 0.9793
# Epoch 125/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.1031 - val_accuracy: 0.9780
# Epoch 126/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 0.9780
# Epoch 127/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1035 - val_accuracy: 0.9780
# Epoch 128/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9780
# Epoch 129/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9780
# Epoch 130/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.5380e-04 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9780
# Epoch 131/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 0.9780
# Epoch 132/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.4060e-04 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9780
# Epoch 133/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.8182e-04 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9780
# Epoch 134/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1033 - val_accuracy: 0.9780
# Epoch 135/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9780
# Epoch 136/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9793
# Epoch 137/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.6837e-04 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9793
# Epoch 138/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 8.0954e-04 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9793
# Epoch 139/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9793
# Epoch 140/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0999 - val_accuracy: 0.9793
# Epoch 141/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 7.9553e-04 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9793
# Epoch 142/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1008 - val_accuracy: 0.9793
# Epoch 143/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.1011 - val_accuracy: 0.9793
# Epoch 144/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1005 - val_accuracy: 0.9793
# Epoch 145/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1005 - val_accuracy: 0.9793
# Epoch 146/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9793
# Epoch 147/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9793
# Epoch 148/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.7848e-04 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9793
# Epoch 149/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.8143e-04 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9793
# Epoch 150/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 7.8749e-04 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9780
# Epoch 151/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.1465e-04 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9780
# Epoch 152/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1011 - val_accuracy: 0.9780
# Epoch 153/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.3587e-04 - accuracy: 0.9997 - val_loss: 0.0998 - val_accuracy: 0.9780
# Epoch 154/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 8.1731e-04 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 0.9780
# Epoch 155/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.1019 - val_accuracy: 0.9793
# Epoch 156/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1009 - val_accuracy: 0.9780
# Epoch 157/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.1004 - val_accuracy: 0.9793
# Epoch 158/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9793
# Epoch 159/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.2379e-04 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9793
# Epoch 160/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.8485e-04 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9793
# Epoch 161/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.2862e-04 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9793
# Epoch 162/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.5221e-04 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9793
# Epoch 163/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9793
# Epoch 164/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.9368e-04 - accuracy: 0.9997 - val_loss: 0.1018 - val_accuracy: 0.9780
# Epoch 165/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.1008 - val_accuracy: 0.9780
# Epoch 166/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9793
# Epoch 167/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0989 - val_accuracy: 0.9780
# Epoch 168/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.3017e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9793
# Epoch 169/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 8.3358e-04 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9793
# Epoch 170/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1001 - val_accuracy: 0.9793
# Epoch 171/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.0504e-04 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9793
# Epoch 172/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.7450e-04 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9793
# Epoch 173/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 6.5822e-04 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9806
# Epoch 174/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.8276e-04 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9806
# Epoch 175/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9819
# Epoch 176/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1004 - val_accuracy: 0.9819
# Epoch 177/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9819
# Epoch 178/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.1439e-04 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9806
# Epoch 179/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0991 - val_accuracy: 0.9806
# Epoch 180/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0985 - val_accuracy: 0.9806
# Epoch 181/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.1418e-04 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 0.9819
# Epoch 182/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0981 - val_accuracy: 0.9806
# Epoch 183/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 5.8350e-04 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9806
# Epoch 184/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 5.3418e-04 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9806
# Epoch 185/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.8336e-04 - accuracy: 0.9997 - val_loss: 0.0984 - val_accuracy: 0.9806
# Epoch 186/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 7.4530e-04 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9806
# Epoch 187/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.7147e-04 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9806
# Epoch 188/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.3058e-04 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9819
# Epoch 189/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 6.6714e-04 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9819
# Epoch 190/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 7.3265e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9819
# Epoch 191/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.2875e-04 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9819
# Epoch 192/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 9.9155e-04 - accuracy: 0.9997 - val_loss: 0.0982 - val_accuracy: 0.9819
# Epoch 193/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0981 - val_accuracy: 0.9819
# Epoch 194/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 7.6613e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9819
# Epoch 195/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 7.6026e-04 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9819
# Epoch 196/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 5.3708e-04 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9819
# Epoch 197/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0983 - val_accuracy: 0.9819
# Epoch 198/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.8695e-04 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9819
# Epoch 199/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0977 - val_accuracy: 0.9806
# Epoch 200/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 9.5173e-04 - accuracy: 0.9997 - val_loss: 0.0981 - val_accuracy: 0.9806
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 201/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.7997e-04 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9806
# Epoch 202/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 7.3362e-04 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9806
# Epoch 203/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0964 - val_accuracy: 0.9806
# Epoch 204/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 6.6284e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9806
# Epoch 205/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0974 - val_accuracy: 0.9806
# Epoch 206/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 8.0475e-04 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9806
# Epoch 207/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.0228e-04 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9806
# Epoch 208/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 8.6173e-04 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9806
# Epoch 209/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 5.4940e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9806
# Epoch 210/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 4.9670e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9806
# Epoch 211/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 6.5855e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9806
# Epoch 212/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 5.5429e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9806
# Epoch 213/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 4.3452e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9806
# Epoch 214/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0963 - val_accuracy: 0.9806
# Epoch 215/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 7.4233e-04 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9793
# Epoch 216/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 8.4901e-04 - accuracy: 0.9997 - val_loss: 0.0983 - val_accuracy: 0.9793
# Epoch 217/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 6.2925e-04 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9793
# Epoch 218/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 5.3891e-04 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9793
# Epoch 219/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0974 - val_accuracy: 0.9793
# Epoch 220/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 7.4295e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9793
# Epoch 221/2000
# 49/49 [==============================] - 17s 351ms/step - loss: 5.7113e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9793
# Epoch 222/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 4.1675e-04 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9806
# Epoch 223/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.2687e-04 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9806
# Epoch 224/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.7181e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9806
# Epoch 225/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0975 - val_accuracy: 0.9793
# Epoch 226/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.1384e-04 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9793
# Epoch 227/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.2770e-04 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9793
# Epoch 228/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.2465e-04 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9793
# Epoch 229/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 4.3546e-04 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 0.9793
# Epoch 230/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0976 - val_accuracy: 0.9793
# Epoch 231/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.6534e-04 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9793
# Epoch 232/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.3760e-04 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9793
# Epoch 233/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9793
# Epoch 234/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0979 - val_accuracy: 0.9793
# Epoch 235/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0978 - val_accuracy: 0.9793
# Epoch 236/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 4.6215e-04 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9793
# Epoch 237/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.7541e-04 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9793
# Epoch 238/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 7.7039e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9806
# Epoch 239/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0968 - val_accuracy: 0.9780
# Epoch 240/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 9.5583e-04 - accuracy: 0.9997 - val_loss: 0.0969 - val_accuracy: 0.9793
# Epoch 241/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.8585e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9780
# Epoch 242/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.0045e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9780
# Epoch 243/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.4488e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9780
# Epoch 244/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0963 - val_accuracy: 0.9793
# Epoch 245/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 7.4986e-04 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9793
# Epoch 246/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 7.7152e-04 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9793
# Epoch 247/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.4065e-04 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9793
# Epoch 248/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.5495e-04 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9793
# Epoch 249/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.0321e-04 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9793
# Epoch 250/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.1110e-04 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9793
# Epoch 251/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 3.9776e-04 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9793
# Epoch 252/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.8246e-04 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9793
# Epoch 253/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 7.6403e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9793
# Epoch 254/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 7.2902e-04 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9806
# Epoch 255/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.0744e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9819
# Epoch 256/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 4.6304e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9819
# Epoch 257/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0953 - val_accuracy: 0.9806
# Epoch 258/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 4.6138e-04 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9806
# Epoch 259/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 3.8417e-04 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9806
# Epoch 260/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.0361e-04 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9819
# Epoch 261/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 4.7431e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9806
# Epoch 262/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.9555e-04 - accuracy: 0.9997 - val_loss: 0.0957 - val_accuracy: 0.9806
# Epoch 263/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0961 - val_accuracy: 0.9806
# Epoch 264/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 4.7565e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9806
# Epoch 265/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0969 - val_accuracy: 0.9793
# Epoch 266/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.8943e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9780
# Epoch 267/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.4255e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9793
# Epoch 268/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.0108e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9793
# Epoch 269/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 6.0748e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9793
# Epoch 270/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.4442e-04 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 0.9793
# Epoch 271/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 5.6711e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9793
# Epoch 272/2000
# 49/49 [==============================] - 17s 352ms/step - loss: 7.8788e-04 - accuracy: 0.9997 - val_loss: 0.0955 - val_accuracy: 0.9806
# Epoch 273/2000
# 49/49 [==============================] - 17s 353ms/step - loss: 6.7610e-04 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 0.9806
# Epoch 274/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 7.6808e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9806
# Epoch 275/2000
# 49/49 [==============================] - 18s 360ms/step - loss: 5.3427e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9793
# Epoch 276/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 3.3204e-04 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9793
# Epoch 277/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0957 - val_accuracy: 0.9793
# Epoch 278/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 3.9145e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9793
# Epoch 279/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 8.1196e-04 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9793
# Epoch 280/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.0741e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9793
# Epoch 281/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.0061e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9793
# Epoch 282/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.1170e-04 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9793
# Epoch 283/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0954 - val_accuracy: 0.9793
# Epoch 284/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.7275e-04 - accuracy: 0.9997 - val_loss: 0.0950 - val_accuracy: 0.9793
# Epoch 285/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.6072e-04 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9793
# Epoch 286/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0954 - val_accuracy: 0.9793
# Epoch 287/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 7.2498e-04 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9806
# Epoch 288/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.4147e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9793
# Epoch 289/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.4722e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9793
# Epoch 290/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.2055e-04 - accuracy: 0.9997 - val_loss: 0.0960 - val_accuracy: 0.9793
# Epoch 291/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.0832e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9793
# Epoch 292/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 8.8632e-04 - accuracy: 0.9997 - val_loss: 0.0960 - val_accuracy: 0.9806
# Epoch 293/2000
# 49/49 [==============================] - 17s 356ms/step - loss: 4.4945e-04 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9806
# Epoch 294/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0967 - val_accuracy: 0.9806
# Epoch 295/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 4.0248e-04 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9806
# Epoch 296/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.8057e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9806
# Epoch 297/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 3.7259e-04 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9806
# Epoch 298/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 3.4670e-04 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 0.9806
# Epoch 299/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.0769e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9806
# Epoch 300/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.0481e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9806
# Epoch 301/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 6.0376e-04 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9819
# Epoch 302/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 5.5203e-04 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9806
# Epoch 303/2000
# 49/49 [==============================] - 17s 357ms/step - loss: 4.4740e-04 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9806
# Epoch 304/2000
# 49/49 [==============================] - 17s 358ms/step - loss: 4.7864e-04 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9806
# Epoch 305/2000
# 49/49 [==============================] - 18s 363ms/step - loss: 3.6125e-04 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9806
# Epoch 306/2000
# 49/49 [==============================] - 18s 363ms/step - loss: 5.8234e-04 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9793
# Epoch 307/2000
# 49/49 [==============================] - 18s 361ms/step - loss: 4.0232e-04 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9793
# Epoch 308/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 8.7756e-04 - accuracy: 0.9997 - val_loss: 0.0958 - val_accuracy: 0.9793
# Epoch 309/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 9.9514e-04 - accuracy: 0.9997 - val_loss: 0.0967 - val_accuracy: 0.9806
# Epoch 310/2000
# 49/49 [==============================] - 18s 365ms/step - loss: 4.0620e-04 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9819
# Epoch 311/2000
# 49/49 [==============================] - 18s 361ms/step - loss: 5.7139e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9819
# Epoch 312/2000
# 49/49 [==============================] - 18s 362ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0951 - val_accuracy: 0.9806
# Epoch 313/2000
# 49/49 [==============================] - 18s 361ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0937 - val_accuracy: 0.9806
# Epoch 314/2000
# 49/49 [==============================] - 18s 361ms/step - loss: 9.9806e-04 - accuracy: 0.9997 - val_loss: 0.0937 - val_accuracy: 0.9806
# Epoch 315/2000
# 49/49 [==============================] - 18s 361ms/step - loss: 5.2480e-04 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9806
# Epoch 316/2000
# 49/49 [==============================] - 18s 361ms/step - loss: 3.1952e-04 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9806
# Epoch 317/2000
# ...
# Epoch 1900/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.3950e-05 - accuracy: 1.0000 - val_loss: 0.0841 - val_accuracy: 0.9845
# Epoch 1901/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.3635e-04 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 0.9832
# Epoch 1902/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.9155e-04 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9832
# Epoch 1903/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1515e-04 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9819
# Epoch 1904/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.9197e-05 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9819
# Epoch 1905/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 8.7696e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9819
# Epoch 1906/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.0716e-05 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9819
# Epoch 1907/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.7434e-05 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9819
# Epoch 1908/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.5339e-05 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9819
# Epoch 1909/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.5768e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9819
# Epoch 1910/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.3165e-04 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9806
# Epoch 1911/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.9012e-05 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9806
# Epoch 1912/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.4318e-04 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9806
# Epoch 1913/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.3988e-05 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9819
# Epoch 1914/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.6977e-05 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9819
# Epoch 1915/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.6266e-05 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9819
# Epoch 1916/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.9191e-05 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9819
# Epoch 1917/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 9.0789e-05 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9819
# Epoch 1918/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.1065e-05 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9819
# Epoch 1919/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1108e-04 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9806
# Epoch 1920/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.5875e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9819
# Epoch 1921/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.0041e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9806
# Epoch 1922/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.8183e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9819
# Epoch 1923/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0860 - val_accuracy: 0.9819
# Epoch 1924/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.4179e-05 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9832
# Epoch 1925/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.0596e-05 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9832
# Epoch 1926/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.7210e-05 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9832
# Epoch 1927/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.1145e-05 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9832
# Epoch 1928/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.1551e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9832
# Epoch 1929/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.3252e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9832
# Epoch 1930/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.6242e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9832
# Epoch 1931/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1423e-04 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9819
# Epoch 1932/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 4.2798e-05 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9806
# Epoch 1933/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 9.9836e-05 - accuracy: 1.0000 - val_loss: 0.0862 - val_accuracy: 0.9793
# Epoch 1934/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.4153e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9793
# Epoch 1935/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 8.5807e-04 - accuracy: 0.9997 - val_loss: 0.0860 - val_accuracy: 0.9793
# Epoch 1936/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.7744e-04 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9806
# Epoch 1937/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.5094e-05 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9806
# Epoch 1938/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.8234e-05 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9806
# Epoch 1939/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.8904e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9806
# Epoch 1940/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.3180e-05 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9806
# Epoch 1941/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.3720e-04 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9806
# Epoch 1942/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.2945e-04 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9806
# Epoch 1943/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.4898e-05 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9806
# Epoch 1944/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.5403e-04 - accuracy: 1.0000 - val_loss: 0.0867 - val_accuracy: 0.9806
# Epoch 1945/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 2.8966e-05 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9806
# Epoch 1946/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.0022e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9806
# Epoch 1947/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.0560e-05 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9806
# Epoch 1948/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.0352e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9806
# Epoch 1949/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1099e-04 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9806
# Epoch 1950/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.1231e-05 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 0.9819
# Epoch 1951/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.4742e-05 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9819
# Epoch 1952/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.5558e-05 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9819
# Epoch 1953/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 8.2535e-05 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9819
# Epoch 1954/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 9.8455e-04 - accuracy: 0.9997 - val_loss: 0.0875 - val_accuracy: 0.9832
# Epoch 1955/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.3377e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9832
# Epoch 1956/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.4363e-04 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9832
# Epoch 1957/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.8753e-05 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9832
# Epoch 1958/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 7.6253e-05 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9832
# Epoch 1959/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.0010e-04 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9819
# Epoch 1960/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.2643e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9819
# Epoch 1961/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.9890e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9819
# Epoch 1962/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.5735e-05 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9819
# Epoch 1963/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.9551e-05 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9819
# Epoch 1964/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.6234e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9819
# Epoch 1965/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.6454e-05 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9819
# Epoch 1966/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.1792e-05 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9819
# Epoch 1967/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.8478e-05 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 0.9832
# Epoch 1968/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.2612e-04 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9832
# Epoch 1969/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.4171e-05 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9832
# Epoch 1970/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.2507e-04 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9832
# Epoch 1971/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.6338e-04 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 0.9832
# Epoch 1972/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.4476e-05 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9832
# Epoch 1973/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.4960e-05 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9832
# Epoch 1974/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.8612e-05 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9832
# Epoch 1975/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.1411e-05 - accuracy: 1.0000 - val_loss: 0.0854 - val_accuracy: 0.9832
# Epoch 1976/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 8.1620e-05 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9819
# Epoch 1977/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.5523e-05 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9819
# Epoch 1978/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.9415e-05 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9832
# Epoch 1979/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 6.5392e-05 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 0.9832
# Epoch 1980/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.0123e-04 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 0.9819
# Epoch 1981/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.9914e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9819
# Epoch 1982/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.7108e-05 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9819
# Epoch 1983/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.9557e-04 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9819
# Epoch 1984/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.9237e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9819
# Epoch 1985/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 7.0552e-04 - accuracy: 0.9997 - val_loss: 0.0845 - val_accuracy: 0.9819
# Epoch 1986/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 1.1583e-04 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9832
# Epoch 1987/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 4.1418e-05 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9832
# Epoch 1988/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 8.2841e-05 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 0.9845
# Epoch 1989/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 3.2594e-05 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9832
# Epoch 1990/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.0175e-05 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9832
# Epoch 1991/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.9970e-05 - accuracy: 1.0000 - val_loss: 0.0851 - val_accuracy: 0.9832
# Epoch 1992/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 9.3438e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9819
# Epoch 1993/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.8868e-05 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9819
# Epoch 1994/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 8.1581e-05 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9819
# Epoch 1995/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 8.8188e-05 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9819
# Epoch 1996/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 5.4899e-05 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9819
# Epoch 1997/2000
# 49/49 [==============================] - 17s 349ms/step - loss: 2.9126e-05 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 0.9819
# Epoch 1998/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.8095e-05 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9819
# Epoch 1999/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 5.4549e-04 - accuracy: 0.9997 - val_loss: 0.0857 - val_accuracy: 0.9832
# Epoch 2000/2000
# 49/49 [==============================] - 17s 350ms/step - loss: 3.3871e-05 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9819
# INFO:tensorflow:Assets written to: D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR\OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb\assets
# C:\Program Files\Python38\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 16))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16, 16))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#indoor testset
test_indoor_ds_results = model.evaluate(test_indoor_ds)
print("test_indoor_ds_results:test loss, test acc:", test_indoor_ds_results)
# Out:
# 29/29 [==============================] - 15s 395ms/step - loss: 0.4214 - accuracy: 0.9075
# test_indoor_ds_results:test loss, test acc: [0.4213620722293854, 0.9074693322181702]

# %%
#outdoor testset
test_outdoor_ds_results = model.evaluate(test_outdoor_ds)
print("test_outdoor_ds_results:test loss, test acc:", test_outdoor_ds_results)
# Out:
# 50/50 [==============================] - 27s 462ms/step - loss: 0.7175 - accuracy: 0.8452
# test_outdoor_ds_results:test loss, test acc: [0.7175272107124329, 0.8452229499816895]

# %%
#belt testset
test_belt_ds_results = model.evaluate(test_belt_ds)
print("test_belt_ds_results:test loss, test acc:", test_belt_ds_results)
# Out:
# 35/35 [==============================] - 12s 311ms/step - loss: 1.4141 - accuracy: 0.7706
# test_belt_ds_results:test loss, test acc: [1.4141488075256348, 0.7706255912780762]

# %%
# Read path of trained model
import os, os.path
trained_path = path_to_model
models_paths = []
for name_folder in os.listdir(trained_path):
    if os.path.isdir(os.path.join(trained_path, name_folder)):
        models_paths.append(os.path.join(trained_path, name_folder))
models_paths
# Out:
# ['D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch0800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1000.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1200.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1400.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1600.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch1800.pb',
#  'D:/ModelMedicalWasteCheckpoint/EfficientNetB3_FreezExtractorOurOutputLayer_LowDeepDense1024-NoClassImbalanced-ALLAugCustomR100-Z025-NormalLR/OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb']

# %% [markdown]
# # Testing in testset

# %%
test_indoor_acc = []
test_outdoor_acc = []
test_belt_acc = []
test_indoor_loss = []
test_outdoor_loss = []
test_belt_loss = []

for lm_idx,plmodel in enumerate(models_paths):
    loaded_model=tf.keras.models.load_model(plmodel)
    ## -> keep loss / acc in each epoch
    #indoor
    test_indoor_results = loaded_model.evaluate(test_indoor_ds)
    test_indoor_loss.append(test_indoor_results[0]) # append loss
    test_indoor_acc.append(test_indoor_results[1]) # append acc
    #outdoor
    test_outdoor_results = loaded_model.evaluate(test_outdoor_ds)
    test_outdoor_loss.append(test_outdoor_results[0]) # append loss
    test_outdoor_acc.append(test_outdoor_results[1]) # append acc
    #belt
    test_belt_results = loaded_model.evaluate(test_belt_ds)
    test_belt_loss.append(test_belt_results[0]) # append loss
    test_belt_acc.append(test_belt_results[1]) # append acc
    # printout
    lm_idx_show = (lm_idx+1) * save_model_interval
    print(f"Epoch{lm_idx_show:03d} \n test_indoor_acc={test_indoor_acc[lm_idx]} \n test_outdoor_acc={test_outdoor_acc[lm_idx]} \n test_belt_acc={test_belt_acc[lm_idx]}")
# Out:
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_70427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_121206) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_71498) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_73664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_122373) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_116982) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_123521) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_116422) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_122743) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_70177) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_73440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_118778) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_124539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_128134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_126967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_121140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_72379) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_119319) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_120969) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_74769) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_72868) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_118152) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_74637) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_72155) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_74204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_69987) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_73980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_73308) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_115186) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_73715) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_117523) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_119992) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_128741) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_115556) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_69513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_115120) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_113590) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_70610) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_69895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_122136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_71763) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_121700) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_117589) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_73216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_71091) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_113353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_123957) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_73939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_72603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_73491) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_57513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_114949) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_69722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_125383) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_71315) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_72104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_70335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_128371) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_128305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_118541) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_114626) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_114367) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_127204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_118712) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_69164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_120362) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_72644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_73532) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_71671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_70841) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_70999) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_116163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_117352) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_73267) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_69123) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_125753) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_123350) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_71946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_102751) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_127811) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_127138) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_122980) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_70651) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_71895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_127574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_74545) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_124216) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_74163) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_120599) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_73099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_119926) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_120533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_121766) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_71722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_69946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_71539) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_72552) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_74596) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_115793) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_70119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_114560) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_71447) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_125990) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_119755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_117959) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_116916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_122914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_113524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_73000) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_72328) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_110226) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_113997) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_118218) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_115727) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_71274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_73756) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_124710) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_70559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_74428) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_116745) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_119148) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_69072) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_71987) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_116356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_69455) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_127745) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_126531) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_71050) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_71223) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_125146) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_73888) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_70783) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_69323) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_70882) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_122307) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_69763) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_125317) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_70218) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_73058) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_124150) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_119385) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_69671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_69282) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_69554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_113931) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_74336) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_74387) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_125924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_126597) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_105645) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_72827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_124776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_72196) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_70386) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_72420) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_126360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_72776) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_74112) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_123587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_121529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_113098) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 10s 272ms/step - loss: 0.4059 - accuracy: 0.8952
# 50/50 [==============================] - 14s 276ms/step - loss: 0.6905 - accuracy: 0.8293
# 35/35 [==============================] - 10s 277ms/step - loss: 1.1878 - accuracy: 0.7561
# Epoch200
#  test_indoor_acc=0.8952062726020813
#  test_outdoor_acc=0.8292993903160095
#  test_belt_acc=0.7561196684837341
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_177411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_178248) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_234049) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_181801) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_178024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_220787) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_181129) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_178739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_221213) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_228895) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_177866) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_224605) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_230603) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_177243) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_222875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_182234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_228658) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_231210) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_233442) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_226401) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_222809) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_182458) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_210440) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_177452) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_178530) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_232465) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_224434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_221042) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_223416) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_225841) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_180956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_227008) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_222056) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_235994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_234286) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_178912) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_221279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_231839) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_233006) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_223245) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_180017) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_222638) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_228288) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_229996) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_233679) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_225907) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_176812) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_177360) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_229389) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_231039) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_180689) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_217915) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_179004) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_181628) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_224671) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_228051) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_177635) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_235500) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_227444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_221686) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_226467) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_180241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_178963) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_235263) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_213334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_226230) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_223482) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_227074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_224045) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_228222) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_176853) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_225278) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_179411) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_179136) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_181669) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_180516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1093417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1042641) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1088349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1042865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1083198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1082554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1087742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1039378) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1041096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1092722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1082299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1087160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1043089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1042957) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1089734) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1093158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1041753) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1089193) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1087979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1038656) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1041305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1082725) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1089800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1038524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1088586) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1097012) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1086790) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1039096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1038324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1039188) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1040923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1040740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1041529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1040200) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1039320) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1042069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1042201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1093911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1043746) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1093351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1090730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1088520) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1042916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1091944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1090341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1043588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1040292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1097572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1039147) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1086117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1097335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1085364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1088956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1039587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1038964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1043313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1093977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1087419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1074846) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1040475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1086553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1040872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1041977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1038923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1096339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1042509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1092551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1042028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1096405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1097942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1041188) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1041621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1042417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1084387) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1042692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1085623) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 29/29 [==============================] - 10s 271ms/step - loss: 0.4214 - accuracy: 0.9075
# 50/50 [==============================] - 14s 275ms/step - loss: 0.7175 - accuracy: 0.8452
# 35/35 [==============================] - 10s 276ms/step - loss: 1.4141 - accuracy: 0.7706
# Epoch2000
#  test_indoor_acc=0.9074693322181702
#  test_outdoor_acc=0.8452229499816895
#  test_belt_acc=0.7706255912780762

# %%
#Average
test_avg_acc = []
for i in range(len(test_indoor_acc)):
    tmp_avg = (test_indoor_acc[i] + test_outdoor_acc[i] + test_belt_acc[i]) / 3.0
    test_avg_acc.append(tmp_avg)

# %%
# loss / acc in each epoch graph ploting
#EPOCHS = 400
import matplotlib.pyplot as plt
epochs_range = range(save_model_interval,EPOCHS+save_model_interval,save_model_interval)
print(epochs_range)
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, test_indoor_acc, label='IndoorDS Tesing Accuracy')
plt.plot(epochs_range, test_outdoor_acc, label='OutdoorDS Tesing Accuracy')
plt.plot(epochs_range, test_belt_acc, label='OnConveyorBeltDS Tesing Accuracy')
plt.plot(epochs_range, test_avg_acc, label='Average Tesing Accuracy',linewidth=3)
plt.legend(loc='lower right')
plt.title('Testing(EvaluationModel) Accuracy')
# Out:
# range(200, 2200, 200)
# Text(0.5, 1.0, 'Testing(EvaluationModel) Accuracy')

# %% [markdown]
# ### Max acc

# %%
#Find Max Index and Value
print(f"max acc -> {max(test_avg_acc)}")
max_index = test_avg_acc.index(max(test_avg_acc))
print(f"max index -> {max_index}")
print(f"The [Epoch] of max acc -> {(max_index+1)*save_model_interval}")
# Out:
# max acc -> 0.8411059578259786
# max index -> 9
# The [Epoch] of max acc -> 2000

# %%
plt.figure(figsize=(20, 22))
#plt.subplot(1, 2, 2)
plt.plot(epochs_range, test_indoor_loss, label='IndoorDS Tesing Loss')
plt.plot(epochs_range, test_outdoor_loss, label='OutdoorDS Tesing Loss')
plt.plot(epochs_range, test_belt_loss, label='OnConveyorBeltDS Tesing Loss')
plt.legend(loc='upper right')
plt.title('Testing(EvaluationModel) Loss')
plt.show()

# %%
test_indoor_acc
# Out:
# [0.8952062726020813,
#  0.9002229571342468,
#  0.9007803797721863,
#  0.9030100107192993,
#  0.9052397012710571,
#  0.9069119095802307,
#  0.9030100107192993,
#  0.9080267548561096,
#  0.9108138084411621,
#  0.9074693322181702]

# %%
test_outdoor_acc
# Out:
# [0.8292993903160095,
#  0.8340764045715332,
#  0.82834392786026,
#  0.8366242051124573,
#  0.8385350108146667,
#  0.8455414175987244,
#  0.8401274085044861,
#  0.8433120846748352,
#  0.8394904732704163,
#  0.8452229499816895]

# %%
test_belt_acc
# Out:
# [0.7561196684837341,
#  0.768812358379364,
#  0.7679057121276855,
#  0.7669990658760071,
#  0.7679057121276855,
#  0.7669990658760071,
#  0.7674524188041687,
#  0.7701722383499146,
#  0.7701722383499146,
#  0.7706255912780762]

# %%
test_indoor_loss
# Out:
# [0.4058855473995209,
#  0.3975241482257843,
#  0.4068019986152649,
#  0.40691378712654114,
#  0.40577876567840576,
#  0.40728265047073364,
#  0.43385303020477295,
#  0.4173567295074463,
#  0.4171346426010132,
#  0.4213620722293854]

# %%
test_outdoor_loss
# Out:
# [0.6905266642570496,
#  0.674938976764679,
#  0.7189233899116516,
#  0.7040836811065674,
#  0.6867691874504089,
#  0.6857939958572388,
#  0.7096878886222839,
#  0.7198189496994019,
#  0.732848048210144,
#  0.7175272107124329]

# %%
test_belt_loss
# Out:
# [1.18780517578125,
#  1.206549048423767,
#  1.261544108390808,
#  1.2832858562469482,
#  1.306390643119812,
#  1.3306761980056763,
#  1.372285008430481,
#  1.3687535524368286,
#  1.403221607208252,
#  1.4141488075256348]

# %% [markdown]
# ## Load Last Epoch and test in each class

# %%
# Del dataset memory and reload
# RAM
del train_ds
del val_ds
del test_indoor_ds
del test_outdoor_ds
del test_belt_ds
# VRAM
#from numba import cuda
#cuda.select_device(0)
#cuda.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20908/3322167109.py in <module>
#       1 # Del dataset memory and reload
#       2 # RAM
# ----> 3 del train_ds
#       4 del val_ds
#       5 del test_indoor_ds
#
# NameError: name 'train_ds' is not defined

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
import numpy as np
from keras.applications.efficientnet import preprocess_input

last_epoch_model = tf.keras.models.load_model(path_to_model+'OurOutputLayer_DeepDense-NoClassImbalanced-NoAug-epoch2000.pb')

test_indoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/indoor'
test_outdoor_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/outdoor'
test_belt_dataset_path='D:/DatasetMedicalWasteTestLabeledCropped/belt'

img_height=300
img_width=300
batch_size=32

test_indoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_indoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_outdoor_ds = tf.keras.utils.image_dataset_from_directory(
  test_outdoor_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

test_belt_ds = tf.keras.utils.image_dataset_from_directory(
  test_belt_dataset_path,
  image_size=(img_height, img_width),
  batch_size=batch_size)

normalization_layer = layers.Rescaling(1./255)

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.RandomZoom(height_factor=0.1),
  layers.RandomContrast(0.05),
])

#Apply the preprocessing layers to your dataset
AUTOTUNE = tf.data.AUTOTUNE
#train_ds = train_ds.cache().shuffle(2000).prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

def prepare(ds, shuffle=False, augment=False):
  # Normalize by 255 all datasets.
  #ds = ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

  if shuffle:
    ds = ds.shuffle(2000)

  # Batch all datasets.
  #ds = ds.batch(batch_size)

  # Use data augmentation only on the training set.
  if augment:
    ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

  # Use buffered prefetching on all datasets.
  return ds.cache().prefetch(buffer_size=AUTOTUNE)

test_indoor_ds = prepare(test_indoor_ds)
test_outdoor_ds = prepare(test_outdoor_ds)
test_belt_ds = prepare(test_belt_ds)

class_names = ['1WayConnectorforFoley', '2WayConnectorforFoley', '2WayFoleyCatheter', '3WayConnectorforFoley', '3Waystopcock', 'AlcoholBottle', 'AlcoholPad', 'BootCover', 'CottonBall', 'CottonSwap', 'Dilator', 'DisposableInfusionSet', 'ExtensionTube', 'FaceShield', 'FrontLoadSyringe', 'GauzePad', 'Glove', 'GuideWire', 'LiquidBottle', 'Mask', 'NGTube', 'NasalCannula', 'Needle', 'OxygenMask', 'PPESuit', 'PharmaceuticalProduct', 'Pill', 'PillBottle', 'PrefilledHumidifier', 'PressureConnectingTube', 'ReusableHumidifier', 'SodiumChlorideBag', 'SterileHumidifierAdapter', 'SurgicalBlade', 'SurgicalCap', 'SurgicalSuit', 'Syringe', 'TrachealTube', 'UrineBag', 'Vaccinebottle', 'WingedInfusionSet']


x_test_indoor = np.concatenate([ x for x,y in test_indoor_ds],axis=0)
x_test_outdoor = np.concatenate([ x for x,y in test_outdoor_ds],axis=0)
x_test_belt = np.concatenate([ x for x,y in test_belt_ds],axis=0)
y_test_indoor = np.concatenate([ y for x,y in test_indoor_ds],axis=0)
y_test_outdoor = np.concatenate([ y for x,y in test_outdoor_ds],axis=0)
y_test_belt = np.concatenate([ y for x,y in test_belt_ds],axis=0)
print(f"train_indoor num x,y : {len(x_test_indoor)},{len(y_test_indoor)}")
print(f"train_outdoor num x,y : {len(x_test_outdoor)},{len(y_test_outdoor)}")
print(f"train_belt num x,y : {len(x_test_belt)},{len(y_test_belt)}")
x_all = np.concatenate([x_test_indoor,x_test_outdoor,x_test_belt],axis=0)
y_all = np.concatenate([y_test_indoor,y_test_outdoor,y_test_belt],axis=0)
print(f"all num x,y :{len(x_all)},{len(y_all)}")
# let's predict
y_all_predicted = last_epoch_model.predict(x_all,batch_size=batch_size)
del x_test_indoor,x_test_outdoor,x_test_belt
del x_all
# Out:
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1041580) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1041804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1041845) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1096775) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1042468) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1039419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1039984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1042733) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1083827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1043140) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1043838) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1090407) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1086724) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1097506) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1090967) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1039536) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_activation_layer_call_and_return_conditional_losses_1039811) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1079427) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1039760) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1042259) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1040424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1084757) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1041356) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1096168) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1084150) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_expand_activation_layer_call_and_return_conditional_losses_1043537) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1089127) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1095561) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1038365) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_se_reduce_layer_call_and_return_conditional_losses_1038755) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1094954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_expand_activation_layer_call_and_return_conditional_losses_1085946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1038483) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1083761) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1041147) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1091337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1043405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1040083) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1039852) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1040516) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1087353) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1091574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1094347) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_activation_layer_call_and_return_conditional_losses_1095732) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1043181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1095125) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1043970) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1087913) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1042300) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1038273) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_se_reduce_layer_call_and_return_conditional_losses_1041397) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1095191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1094518) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1043629) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1085557) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1090170) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1083568) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1084928) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1089563) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_activation_layer_call_and_return_conditional_losses_1038714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_se_reduce_layer_call_and_return_conditional_losses_1082791) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1039628) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_activation_layer_call_and_return_conditional_losses_1043797) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_activation_layer_call_and_return_conditional_losses_1092115) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_activation_layer_call_and_return_conditional_losses_1040251) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1084321) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_activation_layer_call_and_return_conditional_losses_1083132) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_activation_layer_call_and_return_conditional_losses_1090901) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1071952) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_activation_layer_call_and_return_conditional_losses_1091508) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1040964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_se_reduce_layer_call_and_return_conditional_losses_1094584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1093740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1084994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_expand_activation_layer_call_and_return_conditional_losses_1038872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_se_reduce_layer_call_and_return_conditional_losses_1086183) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1096946) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_se_reduce_layer_call_and_return_conditional_losses_1095798) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_se_reduce_layer_call_and_return_conditional_losses_1092181) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1040648) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1092788) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1043364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference__wrapped_model_1026714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_activation_layer_call_and_return_conditional_losses_1040699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_activation_layer_call_and_return_conditional_losses_1040042) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_se_reduce_layer_call_and_return_conditional_losses_1093417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_expand_activation_layer_call_and_return_conditional_losses_1042641) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_expand_activation_layer_call_and_return_conditional_losses_1088349) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_expand_activation_layer_call_and_return_conditional_losses_1042865) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1083198) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_stem_activation_layer_call_and_return_conditional_losses_1082554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1087742) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_activation_layer_call_and_return_conditional_losses_1039378) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_expand_activation_layer_call_and_return_conditional_losses_1041096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1092722) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_model_layer_call_and_return_conditional_losses_1082299) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_expand_activation_layer_call_and_return_conditional_losses_1087160) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6e_expand_activation_layer_call_and_return_conditional_losses_1043089) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_se_reduce_layer_call_and_return_conditional_losses_1042957) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1089734) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1093158) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1041753) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1089193) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1087979) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2a_expand_activation_layer_call_and_return_conditional_losses_1038656) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1041305) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1082725) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_se_reduce_layer_call_and_return_conditional_losses_1089800) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1b_se_reduce_layer_call_and_return_conditional_losses_1038524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_se_reduce_layer_call_and_return_conditional_losses_1088586) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_se_reduce_layer_call_and_return_conditional_losses_1097012) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_se_reduce_layer_call_and_return_conditional_losses_1086790) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_expand_activation_layer_call_and_return_conditional_losses_1039096) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block1a_activation_layer_call_and_return_conditional_losses_1038324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_se_reduce_layer_call_and_return_conditional_losses_1039188) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_activation_layer_call_and_return_conditional_losses_1040923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_se_reduce_layer_call_and_return_conditional_losses_1040740) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_expand_activation_layer_call_and_return_conditional_losses_1041529) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_expand_activation_layer_call_and_return_conditional_losses_1040200) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1039320) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_se_reduce_layer_call_and_return_conditional_losses_1042069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_expand_activation_layer_call_and_return_conditional_losses_1042201) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_activation_layer_call_and_return_conditional_losses_1093911) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1043746) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6a_activation_layer_call_and_return_conditional_losses_1093351) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5b_expand_activation_layer_call_and_return_conditional_losses_1090730) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1088520) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6d_activation_layer_call_and_return_conditional_losses_1042916) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5d_expand_activation_layer_call_and_return_conditional_losses_1091944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_activation_layer_call_and_return_conditional_losses_1090341) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7a_activation_layer_call_and_return_conditional_losses_1043588) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4b_se_reduce_layer_call_and_return_conditional_losses_1040292) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_se_reduce_layer_call_and_return_conditional_losses_1097572) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2c_activation_layer_call_and_return_conditional_losses_1039147) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1086117) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block7b_expand_activation_layer_call_and_return_conditional_losses_1097335) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_expand_activation_layer_call_and_return_conditional_losses_1085364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4d_expand_activation_layer_call_and_return_conditional_losses_1088956) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3b_activation_layer_call_and_return_conditional_losses_1039587) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1038964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_expand_activation_layer_call_and_return_conditional_losses_1043313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1093977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4a_se_reduce_layer_call_and_return_conditional_losses_1087419) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sequential_1_layer_call_and_return_conditional_losses_1074846) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4c_activation_layer_call_and_return_conditional_losses_1040475) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3c_expand_activation_layer_call_and_return_conditional_losses_1086553) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block4e_expand_activation_layer_call_and_return_conditional_losses_1040872) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1041977) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_activation_layer_call_and_return_conditional_losses_1038923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_activation_layer_call_and_return_conditional_losses_1096339) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_se_reduce_layer_call_and_return_conditional_losses_1042509) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_expand_activation_layer_call_and_return_conditional_losses_1092551) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5e_activation_layer_call_and_return_conditional_losses_1042028) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6f_se_reduce_layer_call_and_return_conditional_losses_1096405) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_top_activation_layer_call_and_return_conditional_losses_1097942) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5a_se_reduce_layer_call_and_return_conditional_losses_1041188) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block5c_se_reduce_layer_call_and_return_conditional_losses_1041621) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6b_expand_activation_layer_call_and_return_conditional_losses_1042417) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block2b_se_reduce_layer_call_and_return_conditional_losses_1084387) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block6c_activation_layer_call_and_return_conditional_losses_1042692) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_block3a_se_reduce_layer_call_and_return_conditional_losses_1085623) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# Found 1794 files belonging to 41 classes.
# Found 3140 files belonging to 41 classes.
# Found 2206 files belonging to 41 classes.
# train_indoor num x,y : 1794,1794
# train_outdoor num x,y : 3140,3140
# train_belt num x,y : 2206,2206
# all num x,y :7140,7140

# %%
y_all_predicted_max = np.array([],dtype=np.int)
# acc all
TP = 0
FP = 0
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP = TP + 1
    else :
        FP = FP + 1
    y_all_predicted_max=np.append(y_all_predicted_max,np.argmax(y_all_predicted[i]))
print(f'all={TP+FP}')
print(f'TP={TP}')
print(f'FP={FP}')
print(f'acc={TP/(TP+FP)}')

# acc eachclass
TP_eachclass = [0] * 41
FP_eachclass = [0] * 41
for i in range(len(y_all)):
    if(y_all[i]==np.argmax(y_all_predicted[i])):
        TP_eachclass[y_all[i]] = TP_eachclass[y_all[i]] + 1
    else :
        FP_eachclass[y_all[i]] = FP_eachclass[y_all[i]] + 1
#recheck
print(f'all check = {sum(TP_eachclass)+sum(FP_eachclass)}')
# Out:
# all=7140
# TP=5982
# FP=1158
# acc=0.8378151260504202
# all check = 7140

# %% [markdown]
# ### acc

# %%
avg_acc_eachclass = []
for i in range(len(class_names)):
    print(f'{class_names[i]} acc = {TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100}%')
    avg_acc_eachclass.append(TP_eachclass[i]/(TP_eachclass[i]+FP_eachclass[i])*100)
all_avg_eachclass = sum(avg_acc_eachclass) / len(avg_acc_eachclass)
print(f'\n\n\nall_avg_eachclass = {all_avg_eachclass}%')
# Out:
# 1WayConnectorforFoley acc = 84.48275862068965%
# 2WayConnectorforFoley acc = 97.95918367346938%
# 2WayFoleyCatheter acc = 77.61194029850746%
# 3WayConnectorforFoley acc = 95.72649572649573%
# 3Waystopcock acc = 99.09909909909909%
# AlcoholBottle acc = 83.125%
# AlcoholPad acc = 46.82539682539682%
# BootCover acc = 63.25301204819277%
# CottonBall acc = 89.82035928143712%
# CottonSwap acc = 90.20979020979021%
# Dilator acc = 85.47008547008546%
# DisposableInfusionSet acc = 92.03539823008849%
# ExtensionTube acc = 62.601626016260155%
# FaceShield acc = 72.22222222222221%
# FrontLoadSyringe acc = 62.83185840707964%
# GauzePad acc = 57.95454545454546%
# Glove acc = 78.86904761904762%
# GuideWire acc = 72.32142857142857%
# LiquidBottle acc = 79.00763358778626%
# Mask acc = 97.14285714285714%
# NGTube acc = 44.516129032258064%
# NasalCannula acc = 79.64601769911505%
# Needle acc = 91.07142857142857%
# OxygenMask acc = 91.72932330827066%
# PPESuit acc = 97.58064516129032%
# PharmaceuticalProduct acc = 83.8785046728972%
# Pill acc = 96.35854341736695%
# PillBottle acc = 82.94573643410853%
# PrefilledHumidifier acc = 78.63247863247864%
# PressureConnectingTube acc = 67.93893129770993%
# ReusableHumidifier acc = 84.7457627118644%
# SodiumChlorideBag acc = 90.5511811023622%
# SterileHumidifierAdapter acc = 94.54545454545455%
# SurgicalBlade acc = 94.69026548672566%
# SurgicalCap acc = 95.4954954954955%
# SurgicalSuit acc = 50.0%
# Syringe acc = 96.1977186311787%
# TrachealTube acc = 72.47706422018348%
# UrineBag acc = 90.83333333333333%
# Vaccinebottle acc = 96.24413145539906%
# WingedInfusionSet acc = 91.22807017543859%
#
#
#
# all_avg_eachclass = 81.94819399728874%

# %%
# for plotting
import matplotlib.pyplot as plt
# for using scikit-learn's built-in metrics
from sklearn.metrics import *
# for using tesnorflow/keras' built-in metrics
import tensorflow.keras.backend as K
''' ndarray of shape (n_classes, n_classes)
Confusion matrix whose i-th row and j-th column entry indicates the number of samples with  {true label being i-th row class} and {predicted label being column j-th class}.
> Example
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
array([[2, 0, 0],
       [0, 0, 1],
       [1, 0, 2]])
พุดง่ายๆ แถวคือด้านความจริง
       หลักคือด้านที่ระบบทำนาย
'''
# 
confusionMat = confusion_matrix(y_all, y_all_predicted_max, labels=range(len(class_names)))
confusionMat
# Out:
# array([[ 98,   0,   0, ...,   0,   0,   0],
#        [  0, 144,   0, ...,   0,   0,   0],
#        [  0,   0, 104, ...,   5,   3,   9],
#        ...,
#        [  0,   0,   0, ..., 109,   1,   0],
#        [  0,   0,   0, ...,   0, 205,   0],
#        [  0,   0,   0, ...,   0,   0, 104]], dtype=int64)

# %%
confusionMatFloat = confusionMat.astype('float64')
confusionMatFloatPercent=confusionMatFloat/confusionMatFloat.sum(axis=1)[:,None]  # divided by number of sample in each class (sum of each row)
confusionMatFloatPercent*=100
confusionMatFloatPercent
# Out:
# array([[84.48275862,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        , 97.95918367,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.        , 77.6119403 , ...,  3.73134328,
#          2.23880597,  6.71641791],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ..., 90.83333333,
#          0.83333333,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         96.24413146,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        , 91.22807018]])

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMat, index = class_names,
                  columns = class_names)
plt.figure(figsize = (37,37))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt="d")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(confusionMatFloatPercent, index = class_names,
                  columns = class_names)
plt.figure(figsize = (30,30))
sn.heatmap(df_cm, annot=True,cmap="YlGnBu",fmt=".2f")
# Out:
# <AxesSubplot:>
